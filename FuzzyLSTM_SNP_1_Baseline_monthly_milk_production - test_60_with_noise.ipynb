# %% [markdown]
# ## Theory: LSTM-SNP Architecture
#
# The LSTM-SNP model uses a custom recurrent cell inspired by Spiking Neural P (SNP) systems.
#
# ### Gate Equations
#
# $$r(t) = \rho(W_r x(t) + U_r u(t-1) + b_r)$$ — Reset gate
#
# $$c(t) = \rho(W_c x(t) + U_c u(t-1) + b_c)$$ — Consumption gate
#
# $$o(t) = \rho(W_o x(t) + U_o u(t-1) + b_o)$$ — Output gate
#
# $$a(t) = f(W_a x(t) + U_a u(t-1) + b_a)$$ — Generated spikes
#
# ### State Update
#
# $$u(t) = r(t) \cdot u(t-1) - c(t) \cdot a(t)$$
#
# $$h(t) = o(t) \cdot a(t)$$
#
# where $\rho$ = hard sigmoid, $f$ = tanh

# %% [markdown]
# # Baseline LSTM-SNP — Monthly Milk Production
# ## + Gaussian Input-Noise Robustness (0.5% / 5% / 10% / 15%)
#
# x_noisy(t) = x(t) + eps(t),  eps(t) ~ N(0, sigma_eps^2),  sigma_eps = eta * std(x)
#
# Noise is injected into input features only (never targets), so the resulting
# metrics reflect model sensitivity to input perturbation, not label corruption.
#
# This version includes: a corrected NMSE denominator, validation-based early
# stopping, gradient clipping, and noise-sweep averaging over multiple ε(t)
# draws with a paired per-model degradation test.

# %%
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from math import sqrt
from scipy import stats
import matplotlib.pyplot as plt

print(f"PyTorch version: {torch.__version__}")
print(f"NumPy version: {np.__version__}")

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"Using device: {device}")
# Out:
# PyTorch version: 2.11.0+cu128
# NumPy version: 2.5.1
# Using device: cuda

# %% [markdown]
# ## Model Architecture & Implementation

# %% [markdown]
# ### LSTM-SNP Cell

# %%
#with noise


class LSTMSNPCell(nn.Module):
    """
    LSTM-SNP Cell: gates r, c, o (hard sigmoid) and generated spikes a (tanh).
    u(t) = r(t)*u(t-1) - c(t)*a(t)
    h(t) = o(t)*a(t)
    """
    def __init__(self, input_size, hidden_size):
        super().__init__()
        self.hidden_size = hidden_size
        self.kernel = nn.Linear(input_size, hidden_size * 4, bias=False)
        self.recurrent_kernel = nn.Linear(hidden_size, hidden_size * 4, bias=False)
        self.bias = nn.Parameter(torch.zeros(hidden_size * 4))

        nn.init.xavier_uniform_(self.kernel.weight)
        nn.init.orthogonal_(self.recurrent_kernel.weight)

    def hard_sigmoid(self, x):
        return torch.clamp(0.2 * x + 0.5, 0.0, 1.0)

    def forward(self, x, u_tm1):
        z = self.kernel(x) + self.recurrent_kernel(u_tm1) + self.bias
        z0, z1, z2, z3 = z.chunk(4, dim=-1)

        r = self.hard_sigmoid(z0)   # reset
        c = self.hard_sigmoid(z1)   # consumption
        o = self.hard_sigmoid(z2)   # output/generation
        a = torch.tanh(z3)          # generated spikes

        u = r * u_tm1 - c * a
        h = o * a
        return h, u

# %% [markdown]
# ### Build Model

# %%
#with noise
class RNNModel(nn.Module):
    def __init__(self, input_size, hidden_size):
        super().__init__()
        self.hidden_size = hidden_size
        self.cell = LSTMSNPCell(input_size, hidden_size)
        self.out = nn.Linear(hidden_size, 1)
        self.u = None

    def reset_states(self, batch_size, device):
        self.u = torch.zeros(batch_size, self.hidden_size, device=device)

    def forward(self, x):
        # x is (batch, 1, input_size)
        if self.u is None or self.u.device != x.device:
            self.reset_states(x.size(0), x.device)
        h, self.u = self.cell(x[:, 0, :], self.u)
        return self.out(h)


def build_model(input_dim, units):
    return RNNModel(input_dim, units)

# %%
#with noise
model = build_model(input_dim=1, units=8).to(device)
print(model)

total_params = sum(p.numel() for p in model.parameters())
trainable_params = sum(p.numel() for p in model.parameters() if p.requires_grad)
print(f"\nTotal params: {total_params:,}")
print(f"Trainable params: {trainable_params:,}")
# Out:
# RNNModel(
#   (cell): LSTMSNPCell(
#     (kernel): Linear(in_features=1, out_features=32, bias=False)
#     (recurrent_kernel): Linear(in_features=8, out_features=32, bias=False)
#   )
#   (out): Linear(in_features=8, out_features=1, bias=True)
# )
#
# Total params: 329
# Trainable params: 329

# %% [markdown]
# ## Data Pipeline — Monthly Milk Production

# %%
DATA_PATH = r'C:\Users\paulp\OneDrive\Desktop\fuzzy_LSTM\dataset\monthly-milk-production-pounds-p.csv'

series = pd.read_csv(DATA_PATH, header=0, parse_dates=[0], index_col=0)
raw_values = series.values.flatten()

# %%
# ============================================================
# 2. First-Order Differencing
# ============================================================

def difference(dataset, interval=1):
    diff = []
    for i in range(interval, len(dataset)):
        value = dataset[i] - dataset[i - interval]
        diff.append(value)
    return np.array(diff)

diff_values = difference(raw_values, 1)

# %%
# ============================================================
# 3. Convert to Supervised Learning Format (lag=1)
# ============================================================

def timeseries_to_supervised(data, lag=1):
    df = pd.DataFrame(data)
    columns = [df.shift(i) for i in range(1, lag+1)]
    columns.append(df)
    df = pd.concat(columns, axis=1)
    df.fillna(0, inplace=True)
    return df.values

supervised = timeseries_to_supervised(diff_values, 1)
print(f"Supervised data shape: {supervised.shape}")
# Out:
# Supervised data shape: (167, 2)

# %%
#with noise Train-Validation-Test Split (Last 60 points as Test)
n = len(supervised)
test_size = 60
train_val = supervised[:n - test_size]
test = supervised[n - test_size:]

val_size = int(len(train_val) * 0.1)
train = train_val[:-val_size]
val = train_val[-val_size:]

print(f"Train: {train.shape}, Val: {val.shape}, Test: {test.shape}")

scaler = MinMaxScaler(feature_range=(-1, 1))
scaler.fit(train)  # fit only on train to avoid leakage
train_scaled = scaler.transform(train)
val_scaled = scaler.transform(val)
test_scaled = scaler.transform(test)
# Out:
# Train: (97, 2), Val: (10, 2), Test: (60, 2)

# %%
# ============================================================
# 6. Reshape for RNN Input
# ============================================================

X_train, y_train = train_scaled[:, 0:-1], train_scaled[:, -1]
X_train = X_train.reshape((X_train.shape[0], 1, X_train.shape[1]))

X_test, y_test = test_scaled[:, 0:-1], test_scaled[:, -1]
print(f"X_train shape: {X_train.shape}, y_train shape: {y_train.shape}")
# Out:
# X_train shape: (97, 1, 1), y_train shape: (97,)

# %%
#Gaussian noise injection (Eq. 29–30)
ref_std = X_train.std()
print(f"Reference std(x) used for noise scaling (train inputs): {ref_std:.6f}")

NOISE_LEVELS = [0.005, 0.05, 0.10, 0.15]  # 0.5%, 5%, 10%, 15%

def add_gaussian_noise(X, noise_level, ref_std, seed=None):
    """
    x_noisy(t) = x(t) + eps(t),  eps(t) ~ N(0, sigma_eps^2),  sigma_eps = noise_level * std(x)
    Applied to input features X only — never to targets/labels.
    """
    rng = np.random.default_rng(seed)
    sigma_eps = noise_level * ref_std
    eps = rng.normal(loc=0.0, scale=sigma_eps, size=X.shape)
    return X + eps
# Out:
# Reference std(x) used for noise scaling (train inputs): 0.524874

# %%
#Evaluation function

def evaluate_on_test(model, X_test_eval, train, train_scaled, raw_values, scaler, device):
    """
    Warms up the model's recurrent state on clean training data, then runs
    single-step-ahead prediction on X_test_eval (clean or Gaussian-noise-corrupted
    input features). Test targets are always the clean, ground-truth values.
    """
    model.eval()
    model.reset_states(1, device)

    with torch.no_grad():
        for i in range(len(train_scaled)):
            X_raw = train_scaled[i, 0:-1]
            X_input = torch.tensor(X_raw, dtype=torch.float32).view(1, 1, len(X_raw)).to(device)
            model(X_input)

        predictions = []
        for i in range(len(X_test_eval)):
            X = X_test_eval[i]
            X_input = torch.tensor(X, dtype=torch.float32).view(1, 1, len(X)).to(device)
            yhat = model(X_input).item()

            new_row = [x for x in X] + [yhat]
            array = np.array(new_row).reshape(1, len(new_row))
            inverted = scaler.inverse_transform(array)[0, -1]
            inverted = inverted + raw_values[len(train) + i]
            predictions.append(inverted)

    actual = raw_values[-len(X_test_eval):]
    mse = mean_squared_error(actual, predictions)
    rmse = sqrt(mse)
    meanV = np.mean(actual)
    dominator = np.linalg.norm(np.array(actual) - meanV, 2)   # FIX: was predictions - meanV
    nmse = mse / np.power(dominator, 2)
    return predictions, rmse, mse, nmse

# %% [markdown]
# #Training loop

# %%
import os

#Training loop (60 runs, early stopping + gradient clipping) -- with checkpointing
#
# Checkpointing: after every run, the trained (best-val) model's state_dict +
# that run's metrics are written to disk under CHECKPOINT_DIR. If this cell is
# re-run (kernel restart, crash, "Restart & Run All", etc.), it picks up from
# the last completed run instead of retraining from scratch.

CHECKPOINT_DIR = "checkpoints_sp500"
os.makedirs(CHECKPOINT_DIR, exist_ok=True)

def _ckpt_path(run):
    return os.path.join(CHECKPOINT_DIR, f"run_{run}.pt")

def _summary_path():
    return os.path.join(CHECKPOINT_DIR, "summary.pt")

all_rmse = []
all_mse = []
all_nmse = []
all_predictions = []
all_losses = []
all_models = []  # keep every trained model for later noise-robustness eval

print(f"\n--- [PyTorch] RUNNING ON {device} ---\n")
print(f"Checkpoints will be read/written under: {os.path.abspath(CHECKPOINT_DIR)}\n")

N_RUNS = 60
val_X = val_scaled[:, 0:-1]
PATIENCE = 10

# If a fully-completed summary already exists (e.g. all 60 runs finished in a
# previous session), just reload it and skip training entirely.
summary_path = _summary_path()
if os.path.exists(summary_path):
    print("Found completed checkpoint summary -> loading, skipping training.")
    saved = torch.load(summary_path, map_location=device, weights_only=False)

    all_models = []
    for sd in saved['model_state_dicts']:
        m = build_model(input_dim=1, units=8).to(device)
        m.load_state_dict(sd)
        m.eval()
        all_models.append(m)

    all_rmse = saved['rmse']
    all_mse = saved['mse']
    all_nmse = saved['nmse']
    all_predictions = saved['predictions']
    all_losses = saved['losses']
    print(f"Loaded {len(all_models)} models from checkpoint.")

else:
    for run in range(N_RUNS):

        # Resume mid-run-set: if this specific run was already checkpointed
        # (e.g. the kernel died partway through), reload it instead of
        # retraining.
        run_ckpt_path = _ckpt_path(run)
        if os.path.exists(run_ckpt_path):
            print(f'\n===== RUN {run + 1}/{N_RUNS} (resumed from checkpoint) =====')
            ckpt = torch.load(run_ckpt_path, map_location=device, weights_only=False)

            model = build_model(input_dim=1, units=8).to(device)
            model.load_state_dict(ckpt['model_state_dict'])
            model.eval()

            all_losses.append(ckpt['run_losses'])
            all_models.append(model)
            all_rmse.append(ckpt['rmse'])
            all_mse.append(ckpt['mse'])
            all_nmse.append(ckpt['nmse'])
            all_predictions.append(ckpt['predictions'])
            print(f"Loaded run {run + 1} -- RMSE: {ckpt['rmse']:.6f}, MSE: {ckpt['mse']:.6f}, NMSE: {ckpt['nmse']:.10f} "
                  f"(best val RMSE: {ckpt['best_val_rmse']:.6f})")
            continue

        print(f'\n===== RUN {run + 1}/{N_RUNS} =====')

        np.random.seed(run)
        torch.manual_seed(run)
        model = build_model(input_dim=1, units=8).to(device)

        with torch.no_grad():
            hs = model.hidden_size
            model.cell.bias.data[hs:2 * hs] = 1.0

        optimizer = torch.optim.Adam(model.parameters(), lr=0.001)
        criterion = nn.MSELoss()
        run_losses = []

        X_train_t = torch.tensor(X_train, dtype=torch.float32).to(device)
        y_train_t = torch.tensor(y_train, dtype=torch.float32).to(device)
        n_samples = X_train_t.size(0)

        best_val_rmse = float('inf')
        best_state = None
        patience_ctr = 0

        for epoch in range(100):
            model.train()
            model.reset_states(1, device)
            epoch_loss = 0.0

            for i in range(n_samples):
                x_i = X_train_t[i:i + 1]
                y_i = y_train_t[i:i + 1]

                optimizer.zero_grad()
                pred = model(x_i)
                loss = criterion(pred.squeeze(-1), y_i)
                loss.backward()
                torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)  # FIX: stabilize online updates
                optimizer.step()

                model.u = model.u.detach()
                epoch_loss += loss.item()

            avg_loss = epoch_loss / n_samples
            run_losses.append(avg_loss)

            # FIX: early stopping on the validation split (previously computed, never used)
            _, val_rmse, _, _ = evaluate_on_test(model, val_X, train, train_scaled, raw_values, scaler, device)
            print(f"Epoch {epoch + 1}/100 — train loss: {avg_loss:.6f}  val RMSE: {val_rmse:.6f}")

            if val_rmse < best_val_rmse:
                best_val_rmse = val_rmse
                best_state = {k: v.clone() for k, v in model.state_dict().items()}
                patience_ctr = 0
            else:
                patience_ctr += 1
                if patience_ctr >= PATIENCE:
                    print(f"Early stopping at epoch {epoch + 1} (best val RMSE: {best_val_rmse:.6f})")
                    break

        model.load_state_dict(best_state)  # restore best-val checkpoint
        model.reset_states(1, device)      # clear stale hidden state before storing

        all_losses.append(run_losses)
        all_models.append(model)
        print(f'Training complete for run {run + 1} (best val RMSE: {best_val_rmse:.6f})')

        predictions, rmse, mse, nmse = evaluate_on_test(
            model, X_test, train, train_scaled, raw_values, scaler, device
        )

        all_rmse.append(rmse)
        all_mse.append(mse)
        all_nmse.append(nmse)
        all_predictions.append(predictions)

        print(f'Run {run + 1} — RMSE: {rmse:.6f}, MSE: {mse:.6f}, NMSE: {nmse:.10f}')

        # Checkpoint this run to disk immediately, so a crash later never
        # loses this run's work.
        torch.save({
            'model_state_dict': model.state_dict(),
            'run_losses': run_losses,
            'rmse': rmse,
            'mse': mse,
            'nmse': nmse,
            'predictions': predictions,
            'best_val_rmse': best_val_rmse,
        }, run_ckpt_path)

    # Consolidated checkpoint (metrics + all 60 state_dicts), so a fully
    # completed run-set never needs to be retrained even if the individual
    # per-run checkpoint files above are deleted/cleaned up later.
    torch.save({
        'rmse': all_rmse,
        'mse': all_mse,
        'nmse': all_nmse,
        'predictions': all_predictions,
        'losses': all_losses,
        'model_state_dicts': [m.state_dict() for m in all_models],
    }, summary_path)
# Out:
# --- [PyTorch] RUNNING ON cuda ---
#
# Checkpoints will be read/written under: c:\Users\paulp\OneDrive\Desktop\fuzzy_LSTM\with noise\type_1\type_1_baseline_test_60\checkpoints_sp500
#
#
# ===== RUN 1/60 =====
# Epoch 1/100 — train loss: 0.294729  val RMSE: 90.599719
# Epoch 2/100 — train loss: 0.277652  val RMSE: 95.735807
# Epoch 3/100 — train loss: 0.272657  val RMSE: 99.173139
# Epoch 4/100 — train loss: 0.271865  val RMSE: 100.866327
# Epoch 5/100 — train loss: 0.270826  val RMSE: 101.720012
# Epoch 6/100 — train loss: 0.269298  val RMSE: 102.254457
# Epoch 7/100 — train loss: 0.267563  val RMSE: 102.661338
# Epoch 8/100 — train loss: 0.265735  val RMSE: 102.997101
# Epoch 9/100 — train loss: 0.263818  val RMSE: 103.273847
# Epoch 10/100 — train loss: 0.261783  val RMSE: 103.506729
# Epoch 11/100 — train loss: 0.259566  val RMSE: 103.700842
# Early stopping at epoch 11 (best val RMSE: 90.599719)
# Training complete for run 1 (best val RMSE: 90.599719)
# Run 1 — RMSE: 53.345932, MSE: 2845.788431, NMSE: 0.0133687824
#
# ===== RUN 2/60 =====
# Epoch 1/100 — train loss: 0.344972  val RMSE: 84.338614
# Epoch 2/100 — train loss: 0.306698  val RMSE: 90.952938
# Epoch 3/100 — train loss: 0.288097  val RMSE: 96.808577
# Epoch 4/100 — train loss: 0.284181  val RMSE: 100.556958
# Epoch 5/100 — train loss: 0.284387  val RMSE: 102.080208
# Epoch 6/100 — train loss: 0.283430  val RMSE: 102.597706
# Epoch 7/100 — train loss: 0.281453  val RMSE: 102.773710
# Epoch 8/100 — train loss: 0.279109  val RMSE: 102.835074
# Epoch 9/100 — train loss: 0.276771  val RMSE: 102.891650
# Epoch 10/100 — train loss: 0.274741  val RMSE: 103.015198
# Epoch 11/100 — train loss: 0.273207  val RMSE: 103.236221
# Early stopping at epoch 11 (best val RMSE: 84.338614)
# Training complete for run 2 (best val RMSE: 84.338614)
# Run 2 — RMSE: 52.239065, MSE: 2728.919880, NMSE: 0.0128197640
#
# ===== RUN 3/60 =====
# Epoch 1/100 — train loss: 0.418020  val RMSE: 80.661621
# Epoch 2/100 — train loss: 0.301960  val RMSE: 98.514971
# Epoch 3/100 — train loss: 0.283666  val RMSE: 103.626535
# Epoch 4/100 — train loss: 0.284541  val RMSE: 104.959674
# Epoch 5/100 — train loss: 0.283890  val RMSE: 105.656069
# Epoch 6/100 — train loss: 0.283004  val RMSE: 106.155038
# Epoch 7/100 — train loss: 0.282291  val RMSE: 106.624852
# Epoch 8/100 — train loss: 0.282034  val RMSE: 107.105377
# Epoch 9/100 — train loss: 0.282194  val RMSE: 107.645309
# Epoch 10/100 — train loss: 0.282809  val RMSE: 108.212424
# Epoch 11/100 — train loss: 0.283672  val RMSE: 108.738122
# Early stopping at epoch 11 (best val RMSE: 80.661621)
# Training complete for run 3 (best val RMSE: 80.661621)
# Run 3 — RMSE: 52.339977, MSE: 2739.473182, NMSE: 0.0128693407
#
# ===== RUN 4/60 =====
# Epoch 1/100 — train loss: 0.283276  val RMSE: 94.715721
# Epoch 2/100 — train loss: 0.277147  val RMSE: 97.572514
# Epoch 3/100 — train loss: 0.274524  val RMSE: 100.233956
# Epoch 4/100 — train loss: 0.274420  val RMSE: 102.326019
# Epoch 5/100 — train loss: 0.275193  val RMSE: 103.811817
# Epoch 6/100 — train loss: 0.275804  val RMSE: 104.811224
# Epoch 7/100 — train loss: 0.275968  val RMSE: 105.510208
# Epoch 8/100 — train loss: 0.275684  val RMSE: 106.019400
# Epoch 9/100 — train loss: 0.274931  val RMSE: 106.376412
# Epoch 10/100 — train loss: 0.273632  val RMSE: 106.600732
# Epoch 11/100 — train loss: 0.271702  val RMSE: 106.691171
# Early stopping at epoch 11 (best val RMSE: 94.715721)
# Training complete for run 4 (best val RMSE: 94.715721)
# Run 4 — RMSE: 54.301271, MSE: 2948.628033, NMSE: 0.0138518965
#
# ===== RUN 5/60 =====
# Epoch 1/100 — train loss: 0.434346  val RMSE: 83.070333
# Epoch 2/100 — train loss: 0.297607  val RMSE: 103.218829
# Epoch 3/100 — train loss: 0.294046  val RMSE: 105.281970
# Epoch 4/100 — train loss: 0.294671  val RMSE: 105.710486
# Epoch 5/100 — train loss: 0.294408  val RMSE: 105.939545
# Epoch 6/100 — train loss: 0.294042  val RMSE: 106.110064
# Epoch 7/100 — train loss: 0.293659  val RMSE: 106.242088
# Epoch 8/100 — train loss: 0.293277  val RMSE: 106.355771
# Epoch 9/100 — train loss: 0.292913  val RMSE: 106.464066
# Epoch 10/100 — train loss: 0.292578  val RMSE: 106.572730
# Epoch 11/100 — train loss: 0.292281  val RMSE: 106.672818
# Early stopping at epoch 11 (best val RMSE: 83.070333)
# Training complete for run 5 (best val RMSE: 83.070333)
# Run 5 — RMSE: 52.049942, MSE: 2709.196487, NMSE: 0.0127271086
#
# ===== RUN 6/60 =====
# Epoch 1/100 — train loss: 0.277988  val RMSE: 99.428586
# Epoch 2/100 — train loss: 0.273248  val RMSE: 100.309341
# Epoch 3/100 — train loss: 0.269075  val RMSE: 101.074619
# Epoch 4/100 — train loss: 0.263902  val RMSE: 101.683924
# Epoch 5/100 — train loss: 0.256548  val RMSE: 102.080573
# Epoch 6/100 — train loss: 0.246049  val RMSE: 102.207210
# Epoch 7/100 — train loss: 0.232329  val RMSE: 102.174086
# Epoch 8/100 — train loss: 0.218587  val RMSE: 102.134669
# Epoch 9/100 — train loss: 0.208067  val RMSE: 101.021757
# Epoch 10/100 — train loss: 0.198535  val RMSE: 100.729137
# Epoch 11/100 — train loss: 0.212432  val RMSE: 98.174164
# Epoch 12/100 — train loss: 0.213313  val RMSE: 97.961853
# Epoch 13/100 — train loss: 0.207039  val RMSE: 96.553334
# Epoch 14/100 — train loss: 0.217149  val RMSE: 98.298142
# Epoch 15/100 — train loss: 0.205909  val RMSE: 95.956546
# Epoch 16/100 — train loss: 0.221179  val RMSE: 100.287670
# Epoch 17/100 — train loss: 0.203358  val RMSE: 97.829327
# Epoch 18/100 — train loss: 0.227757  val RMSE: 102.624784
# Epoch 19/100 — train loss: 0.205964  val RMSE: 101.525075
# Epoch 20/100 — train loss: 0.241686  val RMSE: 103.280245
# Epoch 21/100 — train loss: 0.216115  val RMSE: 102.019923
# Epoch 22/100 — train loss: 0.241293  val RMSE: 103.540973
# Epoch 23/100 — train loss: 0.214177  val RMSE: 101.679686
# Epoch 24/100 — train loss: 0.232852  val RMSE: 103.621770
# Epoch 25/100 — train loss: 0.205652  val RMSE: 102.007619
# Early stopping at epoch 25 (best val RMSE: 95.956546)
# Training complete for run 6 (best val RMSE: 95.956546)
# Run 6 — RMSE: 70.265347, MSE: 4937.219059, NMSE: 0.0231937859
#
# ===== RUN 7/60 =====
# Epoch 1/100 — train loss: 0.436677  val RMSE: 75.678863
# Epoch 2/100 — train loss: 0.324495  val RMSE: 99.202805
# Epoch 3/100 — train loss: 0.290062  val RMSE: 104.209438
# Epoch 4/100 — train loss: 0.290963  val RMSE: 105.123511
# Epoch 5/100 — train loss: 0.290520  val RMSE: 105.716180
# Epoch 6/100 — train loss: 0.290277  val RMSE: 106.211856
# Epoch 7/100 — train loss: 0.290296  val RMSE: 106.639961
# Epoch 8/100 — train loss: 0.290548  val RMSE: 107.036544
# Epoch 9/100 — train loss: 0.291028  val RMSE: 107.405204
# Epoch 10/100 — train loss: 0.291689  val RMSE: 107.757790
# Epoch 11/100 — train loss: 0.292487  val RMSE: 108.094320
# Early stopping at epoch 11 (best val RMSE: 75.678863)
# Training complete for run 7 (best val RMSE: 75.678863)
# Run 7 — RMSE: 53.479362, MSE: 2860.042116, NMSE: 0.0134357426
#
# ===== RUN 8/60 =====
# Epoch 1/100 — train loss: 0.308331  val RMSE: 88.104558
# Epoch 2/100 — train loss: 0.287095  val RMSE: 92.701787
# Epoch 3/100 — train loss: 0.275799  val RMSE: 96.513729
# Epoch 4/100 — train loss: 0.271397  val RMSE: 99.137264
# Epoch 5/100 — train loss: 0.270046  val RMSE: 100.790866
# Epoch 6/100 — train loss: 0.269565  val RMSE: 101.859783
# Epoch 7/100 — train loss: 0.269229  val RMSE: 102.605387
# Epoch 8/100 — train loss: 0.268859  val RMSE: 103.180829
# Epoch 9/100 — train loss: 0.268374  val RMSE: 103.659890
# Epoch 10/100 — train loss: 0.267688  val RMSE: 104.061560
# Epoch 11/100 — train loss: 0.266715  val RMSE: 104.387161
# Early stopping at epoch 11 (best val RMSE: 88.104558)
# Training complete for run 8 (best val RMSE: 88.104558)
# Run 8 — RMSE: 51.862168, MSE: 2689.684445, NMSE: 0.0126354460
#
# ===== RUN 9/60 =====
# Epoch 1/100 — train loss: 0.385921  val RMSE: 78.940868
# Epoch 2/100 — train loss: 0.321938  val RMSE: 90.300183
# Epoch 3/100 — train loss: 0.289316  val RMSE: 99.300157
# Epoch 4/100 — train loss: 0.288570  val RMSE: 101.060595
# Epoch 5/100 — train loss: 0.287588  val RMSE: 101.610169
# Epoch 6/100 — train loss: 0.286131  val RMSE: 101.951654
# Epoch 7/100 — train loss: 0.284742  val RMSE: 102.267273
# Epoch 8/100 — train loss: 0.283512  val RMSE: 102.574654
# Epoch 9/100 — train loss: 0.282469  val RMSE: 102.878994
# Epoch 10/100 — train loss: 0.281602  val RMSE: 103.176929
# Epoch 11/100 — train loss: 0.280906  val RMSE: 103.471095
# Early stopping at epoch 11 (best val RMSE: 78.940868)
# Training complete for run 9 (best val RMSE: 78.940868)
# Run 9 — RMSE: 53.608972, MSE: 2873.921857, NMSE: 0.0135009460
#
# ===== RUN 10/60 =====
# Epoch 1/100 — train loss: 0.338536  val RMSE: 85.780500
# Epoch 2/100 — train loss: 0.291505  val RMSE: 95.574561
# Epoch 3/100 — train loss: 0.277012  val RMSE: 102.660031
# Epoch 4/100 — train loss: 0.273754  val RMSE: 103.922930
# Epoch 5/100 — train loss: 0.265530  val RMSE: 103.630031
# Epoch 6/100 — train loss: 0.255594  val RMSE: 102.962763
# Epoch 7/100 — train loss: 0.245168  val RMSE: 103.294846
# Epoch 8/100 — train loss: 0.236612  val RMSE: 120.310745
# Epoch 9/100 — train loss: 0.235692  val RMSE: 136.250767
# Epoch 10/100 — train loss: 0.230628  val RMSE: 109.713209
# Epoch 11/100 — train loss: 0.216555  val RMSE: 102.910775
# Early stopping at epoch 11 (best val RMSE: 85.780500)
# Training complete for run 10 (best val RMSE: 85.780500)
# Run 10 — RMSE: 52.549518, MSE: 2761.451820, NMSE: 0.0129725907
#
# ===== RUN 11/60 =====
# Epoch 1/100 — train loss: 0.533072  val RMSE: 69.197974
# Epoch 2/100 — train loss: 0.385042  val RMSE: 113.033552
# Epoch 3/100 — train loss: 0.316902  val RMSE: 92.477989
# Epoch 4/100 — train loss: 0.299901  val RMSE: 93.337013
# Epoch 5/100 — train loss: 0.295799  val RMSE: 93.752641
# Epoch 6/100 — train loss: 0.294743  val RMSE: 93.086770
# Epoch 7/100 — train loss: 0.293718  val RMSE: 93.500722
# Epoch 8/100 — train loss: 0.292483  val RMSE: 93.977472
# Epoch 9/100 — train loss: 0.291405  val RMSE: 94.837679
# Epoch 10/100 — train loss: 0.290742  val RMSE: 95.576934
# Epoch 11/100 — train loss: 0.290515  val RMSE: 96.285799
# Early stopping at epoch 11 (best val RMSE: 69.197974)
# Training complete for run 11 (best val RMSE: 69.197974)
# Run 11 — RMSE: 55.565258, MSE: 3087.497858, NMSE: 0.0145042712
#
# ===== RUN 12/60 =====
# Epoch 1/100 — train loss: 0.379085  val RMSE: 96.424393
# Epoch 2/100 — train loss: 0.295108  val RMSE: 105.521951
# Epoch 3/100 — train loss: 0.295574  val RMSE: 106.153417
# Epoch 4/100 — train loss: 0.294790  val RMSE: 106.328882
# Epoch 5/100 — train loss: 0.293946  val RMSE: 106.460918
# Epoch 6/100 — train loss: 0.293269  val RMSE: 106.615317
# Epoch 7/100 — train loss: 0.292807  val RMSE: 106.813122
# Epoch 8/100 — train loss: 0.292526  val RMSE: 107.003672
# Epoch 9/100 — train loss: 0.292409  val RMSE: 107.210358
# Epoch 10/100 — train loss: 0.292450  val RMSE: 107.432595
# Epoch 11/100 — train loss: 0.292596  val RMSE: 107.656346
# Early stopping at epoch 11 (best val RMSE: 96.424393)
# Training complete for run 12 (best val RMSE: 96.424393)
# Run 12 — RMSE: 53.332834, MSE: 2844.391216, NMSE: 0.0133622187
#
# ===== RUN 13/60 =====
# Epoch 1/100 — train loss: 0.417375  val RMSE: 76.932506
# Epoch 2/100 — train loss: 0.350193  val RMSE: 84.498625
# Epoch 3/100 — train loss: 0.312254  val RMSE: 90.757873
# Epoch 4/100 — train loss: 0.295439  val RMSE: 94.785642
# Epoch 5/100 — train loss: 0.287120  val RMSE: 97.279421
# Epoch 6/100 — train loss: 0.281891  val RMSE: 99.100959
# Epoch 7/100 — train loss: 0.278189  val RMSE: 100.544031
# Epoch 8/100 — train loss: 0.275378  val RMSE: 101.793368
# Epoch 9/100 — train loss: 0.273083  val RMSE: 102.878254
# Epoch 10/100 — train loss: 0.270987  val RMSE: 103.839661
# Epoch 11/100 — train loss: 0.268832  val RMSE: 104.695930
# Early stopping at epoch 11 (best val RMSE: 76.932506)
# Training complete for run 13 (best val RMSE: 76.932506)
# Run 13 — RMSE: 53.700231, MSE: 2883.714829, NMSE: 0.0135469509
#
# ===== RUN 14/60 =====
# Epoch 1/100 — train loss: 0.282913  val RMSE: 95.882189
# Epoch 2/100 — train loss: 0.276530  val RMSE: 98.110067
# Epoch 3/100 — train loss: 0.272329  val RMSE: 99.979195
# Epoch 4/100 — train loss: 0.268927  val RMSE: 101.448707
# Epoch 5/100 — train loss: 0.265346  val RMSE: 102.387018
# Epoch 6/100 — train loss: 0.260751  val RMSE: 102.757659
# Epoch 7/100 — train loss: 0.254716  val RMSE: 102.426452
# Epoch 8/100 — train loss: 0.247629  val RMSE: 101.803747
# Epoch 9/100 — train loss: 0.241513  val RMSE: 103.616590
# Epoch 10/100 — train loss: 0.238555  val RMSE: 104.705412
# Epoch 11/100 — train loss: 0.234092  val RMSE: 102.898143
# Early stopping at epoch 11 (best val RMSE: 95.882189)
# Training complete for run 14 (best val RMSE: 95.882189)
# Run 14 — RMSE: 53.255033, MSE: 2836.098568, NMSE: 0.0133232620
#
# ===== RUN 15/60 =====
# Epoch 1/100 — train loss: 0.277052  val RMSE: 100.030240
# Epoch 2/100 — train loss: 0.273905  val RMSE: 100.917597
# Epoch 3/100 — train loss: 0.270558  val RMSE: 101.416704
# Epoch 4/100 — train loss: 0.266244  val RMSE: 101.517504
# Epoch 5/100 — train loss: 0.260892  val RMSE: 101.231499
# Epoch 6/100 — train loss: 0.254894  val RMSE: 100.672449
# Epoch 7/100 — train loss: 0.248785  val RMSE: 100.045600
# Epoch 8/100 — train loss: 0.242929  val RMSE: 99.493511
# Epoch 9/100 — train loss: 0.237331  val RMSE: 98.975325
# Epoch 10/100 — train loss: 0.231899  val RMSE: 98.451951
# Epoch 11/100 — train loss: 0.226667  val RMSE: 97.946966
# Epoch 12/100 — train loss: 0.221814  val RMSE: 97.454469
# Epoch 13/100 — train loss: 0.217502  val RMSE: 97.005945
# Epoch 14/100 — train loss: 0.213937  val RMSE: 96.667128
# Epoch 15/100 — train loss: 0.211318  val RMSE: 96.558581
# Epoch 16/100 — train loss: 0.209900  val RMSE: 96.885618
# Epoch 17/100 — train loss: 0.210037  val RMSE: 97.898247
# Epoch 18/100 — train loss: 0.211930  val RMSE: 99.565421
# Epoch 19/100 — train loss: 0.215075  val RMSE: 100.964480
# Epoch 20/100 — train loss: 0.217767  val RMSE: 101.130785
# Epoch 21/100 — train loss: 0.218557  val RMSE: 100.734958
# Epoch 22/100 — train loss: 0.218206  val RMSE: 100.449122
# Epoch 23/100 — train loss: 0.217570  val RMSE: 100.122950
# Epoch 24/100 — train loss: 0.216454  val RMSE: 99.785321
# Epoch 25/100 — train loss: 0.214920  val RMSE: 99.547301
# Early stopping at epoch 25 (best val RMSE: 96.558581)
# Training complete for run 15 (best val RMSE: 96.558581)
# Run 15 — RMSE: 68.325251, MSE: 4668.339867, NMSE: 0.0219306605
#
# ===== RUN 16/60 =====
# Epoch 1/100 — train loss: 0.367003  val RMSE: 80.096807
# Epoch 2/100 — train loss: 0.318505  val RMSE: 87.652680
# Epoch 3/100 — train loss: 0.283284  val RMSE: 98.254800
# Epoch 4/100 — train loss: 0.279830  val RMSE: 101.393272
# Epoch 5/100 — train loss: 0.280312  val RMSE: 102.186968
# Epoch 6/100 — train loss: 0.280127  val RMSE: 102.662717
# Epoch 7/100 — train loss: 0.279991  val RMSE: 103.009836
# Epoch 8/100 — train loss: 0.279950  val RMSE: 103.306372
# Epoch 9/100 — train loss: 0.280021  val RMSE: 103.587092
# Epoch 10/100 — train loss: 0.280175  val RMSE: 103.855783
# Epoch 11/100 — train loss: 0.280356  val RMSE: 104.105636
# Early stopping at epoch 11 (best val RMSE: 80.096807)
# Training complete for run 16 (best val RMSE: 80.096807)
# Run 16 — RMSE: 51.500448, MSE: 2652.296168, NMSE: 0.0124598055
#
# ===== RUN 17/60 =====
# Epoch 1/100 — train loss: 0.279092  val RMSE: 100.495634
# Epoch 2/100 — train loss: 0.275047  val RMSE: 101.220546
# Epoch 3/100 — train loss: 0.270503  val RMSE: 101.802609
# Epoch 4/100 — train loss: 0.264317  val RMSE: 102.226387
# Epoch 5/100 — train loss: 0.255453  val RMSE: 102.429266
# Epoch 6/100 — train loss: 0.243175  val RMSE: 102.273981
# Epoch 7/100 — train loss: 0.227776  val RMSE: 101.561980
# Epoch 8/100 — train loss: 0.211705  val RMSE: 100.175148
# Epoch 9/100 — train loss: 0.197648  val RMSE: 98.350906
# Epoch 10/100 — train loss: 0.186796  val RMSE: 96.516433
# Epoch 11/100 — train loss: 0.178735  val RMSE: 94.902669
# Epoch 12/100 — train loss: 0.172472  val RMSE: 93.532986
# Epoch 13/100 — train loss: 0.167307  val RMSE: 92.357326
# Epoch 14/100 — train loss: 0.163123  val RMSE: 91.372172
# Epoch 15/100 — train loss: 0.160036  val RMSE: 90.681464
# Epoch 16/100 — train loss: 0.158020  val RMSE: 90.174289
# Epoch 17/100 — train loss: 0.156886  val RMSE: 89.668245
# Epoch 18/100 — train loss: 0.156393  val RMSE: 89.087439
# Epoch 19/100 — train loss: 0.156369  val RMSE: 88.526105
# Epoch 20/100 — train loss: 0.156397  val RMSE: 87.961035
# Epoch 21/100 — train loss: 0.156126  val RMSE: 87.483469
# Epoch 22/100 — train loss: 0.155622  val RMSE: 87.104602
# Epoch 23/100 — train loss: 0.154884  val RMSE: 86.806261
# Epoch 24/100 — train loss: 0.153878  val RMSE: 86.548784
# Epoch 25/100 — train loss: 0.152643  val RMSE: 86.300480
# Epoch 26/100 — train loss: 0.151259  val RMSE: 86.049076
# Epoch 27/100 — train loss: 0.149812  val RMSE: 85.791183
# Epoch 28/100 — train loss: 0.148355  val RMSE: 85.534685
# Epoch 29/100 — train loss: 0.146886  val RMSE: 85.311271
# Epoch 30/100 — train loss: 0.145400  val RMSE: 85.103743
# Epoch 31/100 — train loss: 0.143942  val RMSE: 84.893096
# Epoch 32/100 — train loss: 0.142526  val RMSE: 84.671664
# Epoch 33/100 — train loss: 0.141155  val RMSE: 84.399401
# Epoch 34/100 — train loss: 0.139825  val RMSE: 84.089789
# Epoch 35/100 — train loss: 0.138551  val RMSE: 83.862002
# Epoch 36/100 — train loss: 0.137424  val RMSE: 83.703481
# Epoch 37/100 — train loss: 0.136527  val RMSE: 83.831943
# Epoch 38/100 — train loss: 0.136009  val RMSE: 84.448343
# Epoch 39/100 — train loss: 0.136075  val RMSE: 85.651177
# Epoch 40/100 — train loss: 0.137017  val RMSE: 87.508427
# Epoch 41/100 — train loss: 0.139220  val RMSE: 89.340606
# Epoch 42/100 — train loss: 0.141945  val RMSE: 90.337143
# Epoch 43/100 — train loss: 0.143582  val RMSE: 90.327221
# Epoch 44/100 — train loss: 0.143842  val RMSE: 90.417817
# Epoch 45/100 — train loss: 0.144091  val RMSE: 90.500227
# Epoch 46/100 — train loss: 0.144217  val RMSE: 90.520656
# Early stopping at epoch 46 (best val RMSE: 83.703481)
# Training complete for run 17 (best val RMSE: 83.703481)
# Run 17 — RMSE: 76.092094, MSE: 5790.006837, NMSE: 0.0271999636
#
# ===== RUN 18/60 =====
# Epoch 1/100 — train loss: 0.294776  val RMSE: 91.653415
# Epoch 2/100 — train loss: 0.285368  val RMSE: 94.771993
# Epoch 3/100 — train loss: 0.280899  val RMSE: 97.545884
# Epoch 4/100 — train loss: 0.279361  val RMSE: 99.794126
# Epoch 5/100 — train loss: 0.279250  val RMSE: 101.488005
# Epoch 6/100 — train loss: 0.279630  val RMSE: 102.754700
# Epoch 7/100 — train loss: 0.280107  val RMSE: 103.709281
# Epoch 8/100 — train loss: 0.280265  val RMSE: 104.467114
# Epoch 9/100 — train loss: 0.279456  val RMSE: 105.056813
# Epoch 10/100 — train loss: 0.276868  val RMSE: 105.303977
# Epoch 11/100 — train loss: 0.271788  val RMSE: 104.908015
# Early stopping at epoch 11 (best val RMSE: 91.653415)
# Training complete for run 18 (best val RMSE: 91.653415)
# Run 18 — RMSE: 52.338644, MSE: 2739.333623, NMSE: 0.0128686851
#
# ===== RUN 19/60 =====
# Epoch 1/100 — train loss: 0.419148  val RMSE: 78.956481
# Epoch 2/100 — train loss: 0.320151  val RMSE: 92.935075
# Epoch 3/100 — train loss: 0.293368  val RMSE: 97.600566
# Epoch 4/100 — train loss: 0.288069  val RMSE: 99.341052
# Epoch 5/100 — train loss: 0.284518  val RMSE: 100.394765
# Epoch 6/100 — train loss: 0.281886  val RMSE: 101.245103
# Epoch 7/100 — train loss: 0.280016  val RMSE: 101.992466
# Epoch 8/100 — train loss: 0.278739  val RMSE: 102.646363
# Epoch 9/100 — train loss: 0.277846  val RMSE: 103.176907
# Epoch 10/100 — train loss: 0.277241  val RMSE: 103.651937
# Epoch 11/100 — train loss: 0.276888  val RMSE: 104.089453
# Early stopping at epoch 11 (best val RMSE: 78.956481)
# Training complete for run 19 (best val RMSE: 78.956481)
# Run 19 — RMSE: 50.826328, MSE: 2583.315624, NMSE: 0.0121357527
#
# ===== RUN 20/60 =====
# Epoch 1/100 — train loss: 0.294595  val RMSE: 106.918827
# Epoch 2/100 — train loss: 0.281530  val RMSE: 105.504930
# Epoch 3/100 — train loss: 0.268267  val RMSE: 104.033561
# Epoch 4/100 — train loss: 0.254458  val RMSE: 102.457074
# Epoch 5/100 — train loss: 0.241731  val RMSE: 101.079476
# Epoch 6/100 — train loss: 0.230117  val RMSE: 99.973116
# Epoch 7/100 — train loss: 0.218480  val RMSE: 98.819778
# Epoch 8/100 — train loss: 0.206363  val RMSE: 97.553329
# Epoch 9/100 — train loss: 0.194384  val RMSE: 96.159779
# Epoch 10/100 — train loss: 0.183515  val RMSE: 94.759323
# Epoch 11/100 — train loss: 0.174744  val RMSE: 93.527621
# Epoch 12/100 — train loss: 0.168195  val RMSE: 92.652198
# Epoch 13/100 — train loss: 0.163393  val RMSE: 92.257290
# Epoch 14/100 — train loss: 0.160062  val RMSE: 92.281081
# Epoch 15/100 — train loss: 0.157906  val RMSE: 92.547179
# Epoch 16/100 — train loss: 0.156688  val RMSE: 92.097788
# Epoch 17/100 — train loss: 0.155878  val RMSE: 91.207302
# Epoch 18/100 — train loss: 0.155422  val RMSE: 90.314195
# Epoch 19/100 — train loss: 0.154996  val RMSE: 89.896332
# Epoch 20/100 — train loss: 0.153777  val RMSE: 89.925723
# Epoch 21/100 — train loss: 0.151917  val RMSE: 90.008329
# Epoch 22/100 — train loss: 0.150033  val RMSE: 89.903319
# Epoch 23/100 — train loss: 0.148290  val RMSE: 89.542996
# Epoch 24/100 — train loss: 0.146790  val RMSE: 89.066139
# Epoch 25/100 — train loss: 0.145536  val RMSE: 88.552568
# Epoch 26/100 — train loss: 0.144515  val RMSE: 87.980475
# Epoch 27/100 — train loss: 0.143735  val RMSE: 87.384056
# Epoch 28/100 — train loss: 0.143166  val RMSE: 86.811910
# Epoch 29/100 — train loss: 0.142582  val RMSE: 86.299413
# Epoch 30/100 — train loss: 0.141901  val RMSE: 85.825237
# Epoch 31/100 — train loss: 0.141178  val RMSE: 85.379036
# Epoch 32/100 — train loss: 0.140447  val RMSE: 84.978806
# Epoch 33/100 — train loss: 0.139633  val RMSE: 84.671267
# Epoch 34/100 — train loss: 0.138708  val RMSE: 84.456904
# Epoch 35/100 — train loss: 0.137727  val RMSE: 84.339400
# Epoch 36/100 — train loss: 0.136734  val RMSE: 84.285053
# Epoch 37/100 — train loss: 0.135756  val RMSE: 84.284152
# Epoch 38/100 — train loss: 0.134788  val RMSE: 84.304784
# Epoch 39/100 — train loss: 0.133839  val RMSE: 84.344666
# Epoch 40/100 — train loss: 0.132908  val RMSE: 84.424173
# Epoch 41/100 — train loss: 0.132030  val RMSE: 84.529820
# Epoch 42/100 — train loss: 0.131214  val RMSE: 84.625252
# Epoch 43/100 — train loss: 0.130454  val RMSE: 84.715380
# Epoch 44/100 — train loss: 0.129745  val RMSE: 84.797476
# Epoch 45/100 — train loss: 0.129092  val RMSE: 84.871216
# Epoch 46/100 — train loss: 0.128490  val RMSE: 84.981930
# Epoch 47/100 — train loss: 0.127962  val RMSE: 85.153481
# Early stopping at epoch 47 (best val RMSE: 84.284152)
# Training complete for run 20 (best val RMSE: 84.284152)
# Run 20 — RMSE: 81.258205, MSE: 6602.895807, NMSE: 0.0310187070
#
# ===== RUN 21/60 =====
# Epoch 1/100 — train loss: 0.367039  val RMSE: 80.974431
# Epoch 2/100 — train loss: 0.319764  val RMSE: 88.350251
# Epoch 3/100 — train loss: 0.292781  val RMSE: 94.546642
# Epoch 4/100 — train loss: 0.285217  val RMSE: 97.931602
# Epoch 5/100 — train loss: 0.282069  val RMSE: 99.437325
# Epoch 6/100 — train loss: 0.279188  val RMSE: 100.275579
# Epoch 7/100 — train loss: 0.276616  val RMSE: 100.884074
# Epoch 8/100 — train loss: 0.274559  val RMSE: 101.439406
# Epoch 9/100 — train loss: 0.273034  val RMSE: 101.951270
# Epoch 10/100 — train loss: 0.271989  val RMSE: 102.436471
# Epoch 11/100 — train loss: 0.271354  val RMSE: 102.896157
# Early stopping at epoch 11 (best val RMSE: 80.974431)
# Training complete for run 21 (best val RMSE: 80.974431)
# Run 21 — RMSE: 52.713728, MSE: 2778.737164, NMSE: 0.0130537928
#
# ===== RUN 22/60 =====
# Epoch 1/100 — train loss: 0.372903  val RMSE: 83.922183
# Epoch 2/100 — train loss: 0.300528  val RMSE: 119.974799
# Epoch 3/100 — train loss: 0.308603  val RMSE: 121.359079
# Epoch 4/100 — train loss: 0.303011  val RMSE: 126.249024
# Epoch 5/100 — train loss: 0.297947  val RMSE: 120.798002
# Epoch 6/100 — train loss: 0.299834  val RMSE: 127.237164
# Epoch 7/100 — train loss: 0.293644  val RMSE: 114.257537
# Epoch 8/100 — train loss: 0.290300  val RMSE: 106.053278
# Epoch 9/100 — train loss: 0.292548  val RMSE: 104.685473
# Epoch 10/100 — train loss: 0.289524  val RMSE: 106.145267
# Epoch 11/100 — train loss: 0.300097  val RMSE: 103.680777
# Early stopping at epoch 11 (best val RMSE: 83.922183)
# Training complete for run 22 (best val RMSE: 83.922183)
# Run 22 — RMSE: 52.825069, MSE: 2790.487917, NMSE: 0.0131089948
#
# ===== RUN 23/60 =====
# Epoch 1/100 — train loss: 0.271131  val RMSE: 98.742396
# Epoch 2/100 — train loss: 0.269183  val RMSE: 99.990108
# Epoch 3/100 — train loss: 0.268021  val RMSE: 100.952961
# Epoch 4/100 — train loss: 0.267215  val RMSE: 101.709005
# Epoch 5/100 — train loss: 0.266619  val RMSE: 102.300699
# Epoch 6/100 — train loss: 0.266129  val RMSE: 102.764478
# Epoch 7/100 — train loss: 0.265663  val RMSE: 103.123394
# Epoch 8/100 — train loss: 0.265151  val RMSE: 103.394144
# Epoch 9/100 — train loss: 0.264546  val RMSE: 103.589888
# Epoch 10/100 — train loss: 0.263817  val RMSE: 103.721955
# Epoch 11/100 — train loss: 0.262951  val RMSE: 103.800091
# Early stopping at epoch 11 (best val RMSE: 98.742396)
# Training complete for run 23 (best val RMSE: 98.742396)
# Run 23 — RMSE: 55.215298, MSE: 3048.729133, NMSE: 0.0143221457
#
# ===== RUN 24/60 =====
# Epoch 1/100 — train loss: 0.323915  val RMSE: 87.870531
# Epoch 2/100 — train loss: 0.298867  val RMSE: 93.522166
# Epoch 3/100 — train loss: 0.290136  val RMSE: 97.350101
# Epoch 4/100 — train loss: 0.287156  val RMSE: 99.682642
# Epoch 5/100 — train loss: 0.285478  val RMSE: 101.177226
# Epoch 6/100 — train loss: 0.284051  val RMSE: 102.314681
# Epoch 7/100 — train loss: 0.282810  val RMSE: 103.296457
# Epoch 8/100 — train loss: 0.281670  val RMSE: 104.199366
# Epoch 9/100 — train loss: 0.280393  val RMSE: 105.028752
# Epoch 10/100 — train loss: 0.278518  val RMSE: 105.769663
# Epoch 11/100 — train loss: 0.275478  val RMSE: 106.384539
# Early stopping at epoch 11 (best val RMSE: 87.870531)
# Training complete for run 24 (best val RMSE: 87.870531)
# Run 24 — RMSE: 52.606305, MSE: 2767.423358, NMSE: 0.0130006435
#
# ===== RUN 25/60 =====
# Epoch 1/100 — train loss: 0.345250  val RMSE: 82.325592
# Epoch 2/100 — train loss: 0.306274  val RMSE: 86.957765
# Epoch 3/100 — train loss: 0.274675  val RMSE: 92.408061
# Epoch 4/100 — train loss: 0.252075  val RMSE: 96.914875
# Epoch 5/100 — train loss: 0.234505  val RMSE: 98.216883
# Epoch 6/100 — train loss: 0.216113  val RMSE: 98.163859
# Epoch 7/100 — train loss: 0.200896  val RMSE: 97.851904
# Epoch 8/100 — train loss: 0.191116  val RMSE: 97.512078
# Epoch 9/100 — train loss: 0.185971  val RMSE: 96.954167
# Epoch 10/100 — train loss: 0.183543  val RMSE: 96.115225
# Epoch 11/100 — train loss: 0.181851  val RMSE: 95.006710
# Early stopping at epoch 11 (best val RMSE: 82.325592)
# Training complete for run 25 (best val RMSE: 82.325592)
# Run 25 — RMSE: 51.519995, MSE: 2654.309878, NMSE: 0.0124692654
#
# ===== RUN 26/60 =====
# Epoch 1/100 — train loss: 0.283777  val RMSE: 99.656526
# Epoch 2/100 — train loss: 0.275891  val RMSE: 100.471034
# Epoch 3/100 — train loss: 0.269305  val RMSE: 100.961734
# Epoch 4/100 — train loss: 0.262566  val RMSE: 100.875257
# Epoch 5/100 — train loss: 0.255529  val RMSE: 100.233074
# Epoch 6/100 — train loss: 0.249057  val RMSE: 99.725702
# Epoch 7/100 — train loss: 0.244329  val RMSE: 99.634537
# Epoch 8/100 — train loss: 0.240634  val RMSE: 99.085301
# Epoch 9/100 — train loss: 0.236147  val RMSE: 98.756732
# Epoch 10/100 — train loss: 0.231401  val RMSE: 98.472318
# Epoch 11/100 — train loss: 0.226424  val RMSE: 98.220230
# Epoch 12/100 — train loss: 0.221282  val RMSE: 97.871584
# Epoch 13/100 — train loss: 0.215839  val RMSE: 97.391726
# Epoch 14/100 — train loss: 0.210047  val RMSE: 96.820438
# Epoch 15/100 — train loss: 0.203908  val RMSE: 96.139710
# Epoch 16/100 — train loss: 0.197397  val RMSE: 95.361733
# Epoch 17/100 — train loss: 0.190594  val RMSE: 94.481759
# Epoch 18/100 — train loss: 0.183544  val RMSE: 93.504724
# Epoch 19/100 — train loss: 0.176333  val RMSE: 92.431635
# Epoch 20/100 — train loss: 0.169057  val RMSE: 91.278696
# Epoch 21/100 — train loss: 0.161876  val RMSE: 90.009328
# Epoch 22/100 — train loss: 0.154862  val RMSE: 88.915750
# Epoch 23/100 — train loss: 0.148580  val RMSE: 87.921481
# Epoch 24/100 — train loss: 0.143527  val RMSE: 87.211502
# Epoch 25/100 — train loss: 0.140326  val RMSE: 86.738064
# Epoch 26/100 — train loss: 0.138274  val RMSE: 86.504366
# Epoch 27/100 — train loss: 0.136644  val RMSE: 86.350753
# Epoch 28/100 — train loss: 0.135485  val RMSE: 86.197846
# Epoch 29/100 — train loss: 0.134594  val RMSE: 86.013861
# Epoch 30/100 — train loss: 0.133649  val RMSE: 85.769470
# Epoch 31/100 — train loss: 0.132555  val RMSE: 85.465668
# Epoch 32/100 — train loss: 0.131236  val RMSE: 85.138350
# Epoch 33/100 — train loss: 0.129571  val RMSE: 84.838037
# Epoch 34/100 — train loss: 0.127671  val RMSE: 84.577391
# Epoch 35/100 — train loss: 0.125639  val RMSE: 84.363645
# Epoch 36/100 — train loss: 0.123512  val RMSE: 84.191305
# Epoch 37/100 — train loss: 0.121391  val RMSE: 84.049928
# Epoch 38/100 — train loss: 0.119323  val RMSE: 83.927448
# Epoch 39/100 — train loss: 0.117326  val RMSE: 83.817245
# Epoch 40/100 — train loss: 0.115422  val RMSE: 83.716824
# Epoch 41/100 — train loss: 0.113592  val RMSE: 83.629505
# Epoch 42/100 — train loss: 0.111831  val RMSE: 83.555056
# Epoch 43/100 — train loss: 0.110162  val RMSE: 83.495088
# Epoch 44/100 — train loss: 0.108583  val RMSE: 83.450719
# Epoch 45/100 — train loss: 0.107092  val RMSE: 83.420770
# Epoch 46/100 — train loss: 0.105689  val RMSE: 83.397613
# Epoch 47/100 — train loss: 0.104371  val RMSE: 83.385929
# Epoch 48/100 — train loss: 0.103135  val RMSE: 83.382127
# Epoch 49/100 — train loss: 0.101952  val RMSE: 83.361601
# Epoch 50/100 — train loss: 0.100836  val RMSE: 83.343219
# Epoch 51/100 — train loss: 0.099773  val RMSE: 83.334072
# Epoch 52/100 — train loss: 0.098763  val RMSE: 83.333316
# Epoch 53/100 — train loss: 0.097814  val RMSE: 83.359528
# Epoch 54/100 — train loss: 0.096927  val RMSE: 83.395361
# Epoch 55/100 — train loss: 0.096088  val RMSE: 83.432918
# Epoch 56/100 — train loss: 0.095293  val RMSE: 83.465864
# Epoch 57/100 — train loss: 0.094534  val RMSE: 83.495276
# Epoch 58/100 — train loss: 0.093817  val RMSE: 83.528819
# Epoch 59/100 — train loss: 0.093176  val RMSE: 83.574529
# Epoch 60/100 — train loss: 0.092577  val RMSE: 83.627663
# Epoch 61/100 — train loss: 0.091991  val RMSE: 83.682494
# Epoch 62/100 — train loss: 0.091403  val RMSE: 83.742383
# Early stopping at epoch 62 (best val RMSE: 83.333316)
# Training complete for run 26 (best val RMSE: 83.333316)
# Run 26 — RMSE: 80.941196, MSE: 6551.477165, NMSE: 0.0307771554
#
# ===== RUN 27/60 =====
# Epoch 1/100 — train loss: 0.448255  val RMSE: 74.966765
# Epoch 2/100 — train loss: 0.345152  val RMSE: 89.509745
# Epoch 3/100 — train loss: 0.287456  val RMSE: 103.084527
# Epoch 4/100 — train loss: 0.284992  val RMSE: 105.002554
# Epoch 5/100 — train loss: 0.280881  val RMSE: 105.892177
# Epoch 6/100 — train loss: 0.277061  val RMSE: 106.425799
# Epoch 7/100 — train loss: 0.273722  val RMSE: 106.752567
# Epoch 8/100 — train loss: 0.271045  val RMSE: 106.877633
# Epoch 9/100 — train loss: 0.268693  val RMSE: 106.859754
# Epoch 10/100 — train loss: 0.266366  val RMSE: 106.764035
# Epoch 11/100 — train loss: 0.264145  val RMSE: 106.605054
# Early stopping at epoch 11 (best val RMSE: 74.966765)
# Training complete for run 27 (best val RMSE: 74.966765)
# Run 27 — RMSE: 55.060299, MSE: 3031.636557, NMSE: 0.0142418492
#
# ===== RUN 28/60 =====
# Epoch 1/100 — train loss: 0.278249  val RMSE: 93.540171
# Epoch 2/100 — train loss: 0.269803  val RMSE: 95.688007
# Epoch 3/100 — train loss: 0.262895  val RMSE: 97.794444
# Epoch 4/100 — train loss: 0.258070  val RMSE: 99.512816
# Epoch 5/100 — train loss: 0.254960  val RMSE: 100.786024
# Epoch 6/100 — train loss: 0.252798  val RMSE: 101.696052
# Epoch 7/100 — train loss: 0.250905  val RMSE: 102.321919
# Epoch 8/100 — train loss: 0.248641  val RMSE: 102.741476
# Epoch 9/100 — train loss: 0.245360  val RMSE: 102.961127
# Epoch 10/100 — train loss: 0.240416  val RMSE: 102.909772
# Epoch 11/100 — train loss: 0.233371  val RMSE: 102.402706
# Early stopping at epoch 11 (best val RMSE: 93.540171)
# Training complete for run 28 (best val RMSE: 93.540171)
# Run 28 — RMSE: 53.336500, MSE: 2844.782239, NMSE: 0.0133640556
#
# ===== RUN 29/60 =====
# Epoch 1/100 — train loss: 0.543445  val RMSE: 70.844758
# Epoch 2/100 — train loss: 0.331493  val RMSE: 105.316517
# Epoch 3/100 — train loss: 0.305353  val RMSE: 104.484302
# Epoch 4/100 — train loss: 0.300257  val RMSE: 104.914074
# Epoch 5/100 — train loss: 0.297931  val RMSE: 105.260494
# Epoch 6/100 — train loss: 0.296348  val RMSE: 105.685799
# Epoch 7/100 — train loss: 0.295567  val RMSE: 106.177442
# Epoch 8/100 — train loss: 0.295292  val RMSE: 106.857748
# Epoch 9/100 — train loss: 0.295682  val RMSE: 107.634077
# Epoch 10/100 — train loss: 0.296670  val RMSE: 108.438329
# Epoch 11/100 — train loss: 0.298010  val RMSE: 109.170800
# Early stopping at epoch 11 (best val RMSE: 70.844758)
# Training complete for run 29 (best val RMSE: 70.844758)
# Run 29 — RMSE: 55.477748, MSE: 3077.780553, NMSE: 0.0144586218
#
# ===== RUN 30/60 =====
# Epoch 1/100 — train loss: 0.341976  val RMSE: 84.770264
# Epoch 2/100 — train loss: 0.302739  val RMSE: 94.511012
# Epoch 3/100 — train loss: 0.284482  val RMSE: 103.631849
# Epoch 4/100 — train loss: 0.287291  val RMSE: 105.328454
# Epoch 5/100 — train loss: 0.286823  val RMSE: 105.858603
# Epoch 6/100 — train loss: 0.285735  val RMSE: 106.289846
# Epoch 7/100 — train loss: 0.284712  val RMSE: 106.682798
# Epoch 8/100 — train loss: 0.283782  val RMSE: 107.041600
# Epoch 9/100 — train loss: 0.282881  val RMSE: 107.355857
# Epoch 10/100 — train loss: 0.282029  val RMSE: 107.639990
# Epoch 11/100 — train loss: 0.281209  val RMSE: 107.881003
# Early stopping at epoch 11 (best val RMSE: 84.770264)
# Training complete for run 30 (best val RMSE: 84.770264)
# Run 30 — RMSE: 52.669849, MSE: 2774.112991, NMSE: 0.0130320696
#
# ===== RUN 31/60 =====
# Epoch 1/100 — train loss: 0.279388  val RMSE: 95.309552
# Epoch 2/100 — train loss: 0.270897  val RMSE: 98.749836
# Epoch 3/100 — train loss: 0.267139  val RMSE: 101.211179
# Epoch 4/100 — train loss: 0.264081  val RMSE: 102.363003
# Epoch 5/100 — train loss: 0.258837  val RMSE: 102.843280
# Epoch 6/100 — train loss: 0.251041  val RMSE: 102.975436
# Epoch 7/100 — train loss: 0.240439  val RMSE: 102.760964
# Epoch 8/100 — train loss: 0.227646  val RMSE: 102.055308
# Epoch 9/100 — train loss: 0.214885  val RMSE: 100.870148
# Epoch 10/100 — train loss: 0.204563  val RMSE: 99.468915
# Epoch 11/100 — train loss: 0.197818  val RMSE: 98.151686
# Early stopping at epoch 11 (best val RMSE: 95.309552)
# Training complete for run 31 (best val RMSE: 95.309552)
# Run 31 — RMSE: 54.635507, MSE: 2985.038624, NMSE: 0.0140229440
#
# ===== RUN 32/60 =====
# Epoch 1/100 — train loss: 0.279021  val RMSE: 94.296225
# Epoch 2/100 — train loss: 0.272829  val RMSE: 96.437020
# Epoch 3/100 — train loss: 0.268782  val RMSE: 98.134077
# Epoch 4/100 — train loss: 0.265292  val RMSE: 99.471752
# Epoch 5/100 — train loss: 0.261447  val RMSE: 100.450500
# Epoch 6/100 — train loss: 0.256572  val RMSE: 101.011269
# Epoch 7/100 — train loss: 0.250265  val RMSE: 101.021228
# Epoch 8/100 — train loss: 0.242607  val RMSE: 100.324597
# Epoch 9/100 — train loss: 0.234489  val RMSE: 99.212753
# Epoch 10/100 — train loss: 0.227630  val RMSE: 99.051309
# Epoch 11/100 — train loss: 0.222981  val RMSE: 101.280274
# Early stopping at epoch 11 (best val RMSE: 94.296225)
# Training complete for run 32 (best val RMSE: 94.296225)
# Run 32 — RMSE: 53.064160, MSE: 2815.805078, NMSE: 0.0132279284
#
# ===== RUN 33/60 =====
# Epoch 1/100 — train loss: 0.291923  val RMSE: 92.756661
# Epoch 2/100 — train loss: 0.284284  val RMSE: 94.543696
# Epoch 3/100 — train loss: 0.279350  val RMSE: 96.026939
# Epoch 4/100 — train loss: 0.275697  val RMSE: 97.276470
# Epoch 5/100 — train loss: 0.272682  val RMSE: 98.317752
# Epoch 6/100 — train loss: 0.269962  val RMSE: 99.142679
# Epoch 7/100 — train loss: 0.267311  val RMSE: 99.739342
# Epoch 8/100 — train loss: 0.264574  val RMSE: 100.086122
# Epoch 9/100 — train loss: 0.261702  val RMSE: 100.197325
# Epoch 10/100 — train loss: 0.258769  val RMSE: 100.148852
# Epoch 11/100 — train loss: 0.255930  val RMSE: 100.026584
# Early stopping at epoch 11 (best val RMSE: 92.756661)
# Training complete for run 33 (best val RMSE: 92.756661)
# Run 33 — RMSE: 51.334075, MSE: 2635.187280, NMSE: 0.0123794324
#
# ===== RUN 34/60 =====
# Epoch 1/100 — train loss: 0.520058  val RMSE: 71.051127
# Epoch 2/100 — train loss: 0.355933  val RMSE: 94.477547
# Epoch 3/100 — train loss: 0.291383  val RMSE: 103.003456
# Epoch 4/100 — train loss: 0.292798  val RMSE: 104.209724
# Epoch 5/100 — train loss: 0.292283  val RMSE: 104.607158
# Epoch 6/100 — train loss: 0.291344  val RMSE: 104.846720
# Epoch 7/100 — train loss: 0.290370  val RMSE: 105.034252
# Epoch 8/100 — train loss: 0.289391  val RMSE: 105.209417
# Epoch 9/100 — train loss: 0.288431  val RMSE: 105.368799
# Epoch 10/100 — train loss: 0.287470  val RMSE: 105.523672
# Epoch 11/100 — train loss: 0.286491  val RMSE: 105.673935
# Early stopping at epoch 11 (best val RMSE: 71.051127)
# Training complete for run 34 (best val RMSE: 71.051127)
# Run 34 — RMSE: 56.189494, MSE: 3157.259221, NMSE: 0.0148319921
#
# ===== RUN 35/60 =====
# Epoch 1/100 — train loss: 0.501914  val RMSE: 71.217361
# Epoch 2/100 — train loss: 0.387575  val RMSE: 83.718782
# Epoch 3/100 — train loss: 0.298156  val RMSE: 102.461852
# Epoch 4/100 — train loss: 0.292588  val RMSE: 104.398425
# Epoch 5/100 — train loss: 0.291622  val RMSE: 104.965461
# Epoch 6/100 — train loss: 0.290388  val RMSE: 105.396584
# Epoch 7/100 — train loss: 0.289148  val RMSE: 105.731698
# Epoch 8/100 — train loss: 0.287845  val RMSE: 106.064521
# Epoch 9/100 — train loss: 0.286567  val RMSE: 106.399185
# Epoch 10/100 — train loss: 0.285208  val RMSE: 106.711103
# Epoch 11/100 — train loss: 0.283731  val RMSE: 107.015677
# Early stopping at epoch 11 (best val RMSE: 71.217361)
# Training complete for run 35 (best val RMSE: 71.217361)
# Run 35 — RMSE: 56.978368, MSE: 3246.534372, NMSE: 0.0152513838
#
# ===== RUN 36/60 =====
# Epoch 1/100 — train loss: 0.327990  val RMSE: 85.201676
# Epoch 2/100 — train loss: 0.295883  val RMSE: 92.337152
# Epoch 3/100 — train loss: 0.278054  val RMSE: 103.779037
# Epoch 4/100 — train loss: 0.282878  val RMSE: 104.995044
# Epoch 5/100 — train loss: 0.280238  val RMSE: 105.415856
# Epoch 6/100 — train loss: 0.277261  val RMSE: 105.692584
# Epoch 7/100 — train loss: 0.273665  val RMSE: 105.851866
# Epoch 8/100 — train loss: 0.268970  val RMSE: 105.817620
# Epoch 9/100 — train loss: 0.262774  val RMSE: 105.528259
# Epoch 10/100 — train loss: 0.254624  val RMSE: 104.949376
# Epoch 11/100 — train loss: 0.244327  val RMSE: 103.976435
# Early stopping at epoch 11 (best val RMSE: 85.201676)
# Training complete for run 36 (best val RMSE: 85.201676)
# Run 36 — RMSE: 51.788090, MSE: 2682.006301, NMSE: 0.0125993761
#
# ===== RUN 37/60 =====
# Epoch 1/100 — train loss: 0.320856  val RMSE: 88.268610
# Epoch 2/100 — train loss: 0.289725  val RMSE: 98.382459
# Epoch 3/100 — train loss: 0.285494  val RMSE: 103.289948
# Epoch 4/100 — train loss: 0.287900  val RMSE: 104.199125
# Epoch 5/100 — train loss: 0.287804  val RMSE: 104.487370
# Epoch 6/100 — train loss: 0.287328  val RMSE: 104.664482
# Epoch 7/100 — train loss: 0.286874  val RMSE: 104.819195
# Epoch 8/100 — train loss: 0.286494  val RMSE: 104.959820
# Epoch 9/100 — train loss: 0.286188  val RMSE: 105.097683
# Epoch 10/100 — train loss: 0.285954  val RMSE: 105.233641
# Epoch 11/100 — train loss: 0.285783  val RMSE: 105.365461
# Early stopping at epoch 11 (best val RMSE: 88.268610)
# Training complete for run 37 (best val RMSE: 88.268610)
# Run 37 — RMSE: 53.199161, MSE: 2830.150731, NMSE: 0.0132953205
#
# ===== RUN 38/60 =====
# Epoch 1/100 — train loss: 0.531527  val RMSE: 75.235995
# Epoch 2/100 — train loss: 0.322117  val RMSE: 97.132206
# Epoch 3/100 — train loss: 0.292403  val RMSE: 102.053813
# Epoch 4/100 — train loss: 0.292152  val RMSE: 103.365069
# Epoch 5/100 — train loss: 0.291625  val RMSE: 103.874765
# Epoch 6/100 — train loss: 0.290898  val RMSE: 104.241552
# Epoch 7/100 — train loss: 0.290299  val RMSE: 104.608089
# Epoch 8/100 — train loss: 0.289894  val RMSE: 105.040081
# Epoch 9/100 — train loss: 0.289659  val RMSE: 105.584147
# Epoch 10/100 — train loss: 0.289663  val RMSE: 106.793127
# Epoch 11/100 — train loss: 0.290405  val RMSE: 115.248023
# Early stopping at epoch 11 (best val RMSE: 75.235995)
# Training complete for run 38 (best val RMSE: 75.235995)
# Run 38 — RMSE: 52.430645, MSE: 2748.972577, NMSE: 0.0129139664
#
# ===== RUN 39/60 =====
# Epoch 1/100 — train loss: 0.280882  val RMSE: 94.376715
# Epoch 2/100 — train loss: 0.269136  val RMSE: 97.771794
# Epoch 3/100 — train loss: 0.263762  val RMSE: 100.304700
# Epoch 4/100 — train loss: 0.260457  val RMSE: 102.107950
# Epoch 5/100 — train loss: 0.257234  val RMSE: 103.137337
# Epoch 6/100 — train loss: 0.252393  val RMSE: 103.215150
# Epoch 7/100 — train loss: 0.244823  val RMSE: 102.181091
# Epoch 8/100 — train loss: 0.234336  val RMSE: 100.114475
# Epoch 9/100 — train loss: 0.222461  val RMSE: 113.425420
# Epoch 10/100 — train loss: 0.213680  val RMSE: 98.615424
# Epoch 11/100 — train loss: 0.202551  val RMSE: 95.769546
# Early stopping at epoch 11 (best val RMSE: 94.376715)
# Training complete for run 39 (best val RMSE: 94.376715)
# Run 39 — RMSE: 54.090121, MSE: 2925.741159, NMSE: 0.0137443798
#
# ===== RUN 40/60 =====
# Epoch 1/100 — train loss: 0.417235  val RMSE: 77.025284
# Epoch 2/100 — train loss: 0.347139  val RMSE: 86.639580
# Epoch 3/100 — train loss: 0.298310  val RMSE: 97.966571
# Epoch 4/100 — train loss: 0.291120  val RMSE: 102.100732
# Epoch 5/100 — train loss: 0.291913  val RMSE: 103.313624
# Epoch 6/100 — train loss: 0.291812  val RMSE: 104.072167
# Epoch 7/100 — train loss: 0.291671  val RMSE: 104.670105
# Epoch 8/100 — train loss: 0.291652  val RMSE: 105.206134
# Epoch 9/100 — train loss: 0.291775  val RMSE: 105.706012
# Epoch 10/100 — train loss: 0.292050  val RMSE: 106.173232
# Epoch 11/100 — train loss: 0.292480  val RMSE: 106.614201
# Early stopping at epoch 11 (best val RMSE: 77.025284)
# Training complete for run 40 (best val RMSE: 77.025284)
# Run 40 — RMSE: 52.985111, MSE: 2807.421940, NMSE: 0.0131885465
#
# ===== RUN 41/60 =====
# Epoch 1/100 — train loss: 0.295987  val RMSE: 106.737782
# Epoch 2/100 — train loss: 0.289556  val RMSE: 106.439669
# Epoch 3/100 — train loss: 0.283266  val RMSE: 106.127231
# Epoch 4/100 — train loss: 0.275822  val RMSE: 105.662333
# Epoch 5/100 — train loss: 0.265807  val RMSE: 104.874777
# Epoch 6/100 — train loss: 0.251843  val RMSE: 103.547618
# Epoch 7/100 — train loss: 0.234471  val RMSE: 101.612084
# Epoch 8/100 — train loss: 0.217113  val RMSE: 99.274542
# Epoch 9/100 — train loss: 0.202596  val RMSE: 97.004032
# Epoch 10/100 — train loss: 0.191311  val RMSE: 95.055036
# Epoch 11/100 — train loss: 0.182727  val RMSE: 93.540997
# Epoch 12/100 — train loss: 0.175803  val RMSE: 92.326127
# Epoch 13/100 — train loss: 0.169680  val RMSE: 91.274522
# Epoch 14/100 — train loss: 0.164091  val RMSE: 90.294338
# Epoch 15/100 — train loss: 0.158997  val RMSE: 89.466990
# Epoch 16/100 — train loss: 0.154415  val RMSE: 89.007129
# Epoch 17/100 — train loss: 0.150540  val RMSE: 88.988310
# Epoch 18/100 — train loss: 0.147508  val RMSE: 89.287050
# Epoch 19/100 — train loss: 0.145145  val RMSE: 90.384793
# Epoch 20/100 — train loss: 0.143841  val RMSE: 91.828982
# Epoch 21/100 — train loss: 0.142928  val RMSE: 92.729915
# Epoch 22/100 — train loss: 0.141887  val RMSE: 92.837993
# Epoch 23/100 — train loss: 0.140635  val RMSE: 92.546840
# Epoch 24/100 — train loss: 0.139754  val RMSE: 92.201484
# Epoch 25/100 — train loss: 0.139077  val RMSE: 91.821596
# Epoch 26/100 — train loss: 0.138286  val RMSE: 91.312712
# Epoch 27/100 — train loss: 0.137414  val RMSE: 90.653876
# Early stopping at epoch 27 (best val RMSE: 88.988310)
# Training complete for run 41 (best val RMSE: 88.988310)
# Run 41 — RMSE: 76.812100, MSE: 5900.098657, NMSE: 0.0277171467
#
# ===== RUN 42/60 =====
# Epoch 1/100 — train loss: 0.279632  val RMSE: 104.652295
# Epoch 2/100 — train loss: 0.273795  val RMSE: 104.449299
# Epoch 3/100 — train loss: 0.266491  val RMSE: 104.114289
# Epoch 4/100 — train loss: 0.256121  val RMSE: 103.497527
# Epoch 5/100 — train loss: 0.241803  val RMSE: 102.399019
# Epoch 6/100 — train loss: 0.224942  val RMSE: 100.698699
# Epoch 7/100 — train loss: 0.209271  val RMSE: 98.650120
# Epoch 8/100 — train loss: 0.197169  val RMSE: 96.674949
# Epoch 9/100 — train loss: 0.188666  val RMSE: 94.957271
# Epoch 10/100 — train loss: 0.182997  val RMSE: 93.561357
# Epoch 11/100 — train loss: 0.179295  val RMSE: 92.430771
# Epoch 12/100 — train loss: 0.176960  val RMSE: 91.520024
# Epoch 13/100 — train loss: 0.175615  val RMSE: 90.790020
# Epoch 14/100 — train loss: 0.174962  val RMSE: 90.211358
# Epoch 15/100 — train loss: 0.174668  val RMSE: 89.734334
# Epoch 16/100 — train loss: 0.174527  val RMSE: 89.332485
# Epoch 17/100 — train loss: 0.174390  val RMSE: 88.957545
# Epoch 18/100 — train loss: 0.174201  val RMSE: 88.584497
# Epoch 19/100 — train loss: 0.173959  val RMSE: 88.213644
# Epoch 20/100 — train loss: 0.173668  val RMSE: 87.844174
# Epoch 21/100 — train loss: 0.173362  val RMSE: 87.484727
# Epoch 22/100 — train loss: 0.173120  val RMSE: 87.148321
# Epoch 23/100 — train loss: 0.172870  val RMSE: 86.844984
# Epoch 24/100 — train loss: 0.172612  val RMSE: 86.563502
# Epoch 25/100 — train loss: 0.172359  val RMSE: 86.299219
# Epoch 26/100 — train loss: 0.172112  val RMSE: 86.046816
# Epoch 27/100 — train loss: 0.171894  val RMSE: 85.829452
# Epoch 28/100 — train loss: 0.171663  val RMSE: 85.619638
# Epoch 29/100 — train loss: 0.171439  val RMSE: 85.418181
# Epoch 30/100 — train loss: 0.171217  val RMSE: 85.225958
# Epoch 31/100 — train loss: 0.170992  val RMSE: 85.042239
# Epoch 32/100 — train loss: 0.170759  val RMSE: 84.873763
# Epoch 33/100 — train loss: 0.170499  val RMSE: 84.735718
# Epoch 34/100 — train loss: 0.170187  val RMSE: 84.607414
# Epoch 35/100 — train loss: 0.169860  val RMSE: 84.487584
# Epoch 36/100 — train loss: 0.169521  val RMSE: 84.374527
# Epoch 37/100 — train loss: 0.169171  val RMSE: 84.266966
# Epoch 38/100 — train loss: 0.168811  val RMSE: 84.163816
# Epoch 39/100 — train loss: 0.168450  val RMSE: 84.043872
# Epoch 40/100 — train loss: 0.168111  val RMSE: 83.931102
# Epoch 41/100 — train loss: 0.167772  val RMSE: 83.835458
# Epoch 42/100 — train loss: 0.167426  val RMSE: 83.741209
# Epoch 43/100 — train loss: 0.167083  val RMSE: 83.672487
# Epoch 44/100 — train loss: 0.166702  val RMSE: 83.589120
# Epoch 45/100 — train loss: 0.166334  val RMSE: 83.524704
# Epoch 46/100 — train loss: 0.165938  val RMSE: 83.445879
# Epoch 47/100 — train loss: 0.165549  val RMSE: 83.374172
# Epoch 48/100 — train loss: 0.165130  val RMSE: 83.318285
# Epoch 49/100 — train loss: 0.164675  val RMSE: 83.242667
# Epoch 50/100 — train loss: 0.164235  val RMSE: 83.167714
# Epoch 51/100 — train loss: 0.163776  val RMSE: 83.090296
# Epoch 52/100 — train loss: 0.163288  val RMSE: 83.024485
# Epoch 53/100 — train loss: 0.162756  val RMSE: 82.937296
# Epoch 54/100 — train loss: 0.162222  val RMSE: 82.851809
# Epoch 55/100 — train loss: 0.161647  val RMSE: 82.763436
# Epoch 56/100 — train loss: 0.161035  val RMSE: 82.671787
# Epoch 57/100 — train loss: 0.160356  val RMSE: 82.576288
# Epoch 58/100 — train loss: 0.159675  val RMSE: 82.479302
# Epoch 59/100 — train loss: 0.158904  val RMSE: 82.382964
# Epoch 60/100 — train loss: 0.158040  val RMSE: 82.286503
# Epoch 61/100 — train loss: 0.157111  val RMSE: 82.184058
# Epoch 62/100 — train loss: 0.156099  val RMSE: 82.076793
# Epoch 63/100 — train loss: 0.155005  val RMSE: 81.966067
# Epoch 64/100 — train loss: 0.153836  val RMSE: 81.852130
# Epoch 65/100 — train loss: 0.152602  val RMSE: 81.740039
# Epoch 66/100 — train loss: 0.151329  val RMSE: 81.618321
# Epoch 67/100 — train loss: 0.150040  val RMSE: 81.510846
# Epoch 68/100 — train loss: 0.148817  val RMSE: 81.438032
# Epoch 69/100 — train loss: 0.147776  val RMSE: 81.439693
# Epoch 70/100 — train loss: 0.147173  val RMSE: 81.551074
# Epoch 71/100 — train loss: 0.146981  val RMSE: 81.755637
# Epoch 72/100 — train loss: 0.147071  val RMSE: 82.074496
# Epoch 73/100 — train loss: 0.147392  val RMSE: 82.447343
# Epoch 74/100 — train loss: 0.147920  val RMSE: 82.772420
# Epoch 75/100 — train loss: 0.148544  val RMSE: 82.985323
# Epoch 76/100 — train loss: 0.149186  val RMSE: 83.002750
# Epoch 77/100 — train loss: 0.149771  val RMSE: 82.760006
# Epoch 78/100 — train loss: 0.150246  val RMSE: 82.235304
# Early stopping at epoch 78 (best val RMSE: 81.438032)
# Training complete for run 42 (best val RMSE: 81.438032)
# Run 42 — RMSE: 78.704866, MSE: 6194.455913, NMSE: 0.0290999614
#
# ===== RUN 43/60 =====
# ...
# Epoch 8/100 — train loss: 0.280734  val RMSE: 104.049743
# Epoch 9/100 — train loss: 0.280338  val RMSE: 104.133400
# Epoch 10/100 — train loss: 0.279877  val RMSE: 104.194109
# Epoch 11/100 — train loss: 0.279322  val RMSE: 104.229778
# Early stopping at epoch 11 (best val RMSE: 80.162876)
# Training complete for run 48 (best val RMSE: 80.162876)
# Run 48 — RMSE: 50.728317, MSE: 2573.362106, NMSE: 0.0120889936
#
# ===== RUN 49/60 =====
# Epoch 1/100 — train loss: 0.283346  val RMSE: 102.230510
# Epoch 2/100 — train loss: 0.276802  val RMSE: 101.976675
# Epoch 3/100 — train loss: 0.271997  val RMSE: 101.844263
# Epoch 4/100 — train loss: 0.267546  val RMSE: 101.725036
# Epoch 5/100 — train loss: 0.263016  val RMSE: 101.568366
# Epoch 6/100 — train loss: 0.258217  val RMSE: 101.331549
# Epoch 7/100 — train loss: 0.253096  val RMSE: 101.024459
# Epoch 8/100 — train loss: 0.247701  val RMSE: 100.656365
# Epoch 9/100 — train loss: 0.242140  val RMSE: 100.269049
# Epoch 10/100 — train loss: 0.236603  val RMSE: 99.836015
# Epoch 11/100 — train loss: 0.231249  val RMSE: 99.415635
# Epoch 12/100 — train loss: 0.226298  val RMSE: 99.096008
# Epoch 13/100 — train loss: 0.221961  val RMSE: 98.940335
# Epoch 14/100 — train loss: 0.218406  val RMSE: 99.072404
# Epoch 15/100 — train loss: 0.215762  val RMSE: 99.631709
# Epoch 16/100 — train loss: 0.214105  val RMSE: 100.767095
# Epoch 17/100 — train loss: 0.213412  val RMSE: 102.418051
# Epoch 18/100 — train loss: 0.213443  val RMSE: 104.227315
# Epoch 19/100 — train loss: 0.213697  val RMSE: 105.846591
# Epoch 20/100 — train loss: 0.213781  val RMSE: 107.027335
# Epoch 21/100 — train loss: 0.213359  val RMSE: 107.768331
# Epoch 22/100 — train loss: 0.212266  val RMSE: 108.214111
# Epoch 23/100 — train loss: 0.210486  val RMSE: 108.482459
# Early stopping at epoch 23 (best val RMSE: 98.940335)
# Training complete for run 49 (best val RMSE: 98.940335)
# Run 49 — RMSE: 67.424056, MSE: 4546.003382, NMSE: 0.0213559552
#
# ===== RUN 50/60 =====
# Epoch 1/100 — train loss: 0.275465  val RMSE: 97.398068
# Epoch 2/100 — train loss: 0.272501  val RMSE: 99.143521
# Epoch 3/100 — train loss: 0.270429  val RMSE: 100.321537
# Epoch 4/100 — train loss: 0.267910  val RMSE: 101.123078
# Epoch 5/100 — train loss: 0.264364  val RMSE: 101.689665
# Epoch 6/100 — train loss: 0.259539  val RMSE: 102.052283
# Epoch 7/100 — train loss: 0.253303  val RMSE: 102.115030
# Epoch 8/100 — train loss: 0.245727  val RMSE: 101.868737
# Epoch 9/100 — train loss: 0.237291  val RMSE: 101.450013
# Epoch 10/100 — train loss: 0.228397  val RMSE: 100.951823
# Epoch 11/100 — train loss: 0.219277  val RMSE: 100.248466
# Early stopping at epoch 11 (best val RMSE: 97.398068)
# Training complete for run 50 (best val RMSE: 97.398068)
# Run 50 — RMSE: 54.731947, MSE: 2995.586005, NMSE: 0.0140724929
#
# ===== RUN 51/60 =====
# Epoch 1/100 — train loss: 0.281326  val RMSE: 95.351455
# Epoch 2/100 — train loss: 0.277075  val RMSE: 98.109859
# Epoch 3/100 — train loss: 0.275747  val RMSE: 100.335883
# Epoch 4/100 — train loss: 0.275650  val RMSE: 101.878086
# Epoch 5/100 — train loss: 0.275634  val RMSE: 102.912178
# Epoch 6/100 — train loss: 0.275414  val RMSE: 103.637085
# Epoch 7/100 — train loss: 0.274943  val RMSE: 104.157869
# Epoch 8/100 — train loss: 0.274140  val RMSE: 104.526665
# Epoch 9/100 — train loss: 0.272908  val RMSE: 104.754287
# Epoch 10/100 — train loss: 0.271154  val RMSE: 104.857215
# Epoch 11/100 — train loss: 0.268817  val RMSE: 104.840871
# Early stopping at epoch 11 (best val RMSE: 95.351455)
# Training complete for run 51 (best val RMSE: 95.351455)
# Run 51 — RMSE: 53.181208, MSE: 2828.240855, NMSE: 0.0132863484
#
# ===== RUN 52/60 =====
# Epoch 1/100 — train loss: 0.488024  val RMSE: 73.438606
# Epoch 2/100 — train loss: 0.325781  val RMSE: 108.301825
# Epoch 3/100 — train loss: 0.302850  val RMSE: 103.257478
# Epoch 4/100 — train loss: 0.295415  val RMSE: 105.070498
# Epoch 5/100 — train loss: 0.295206  val RMSE: 105.560317
# Epoch 6/100 — train loss: 0.294369  val RMSE: 105.999228
# Epoch 7/100 — train loss: 0.293660  val RMSE: 106.334505
# Epoch 8/100 — train loss: 0.292940  val RMSE: 106.623688
# Epoch 9/100 — train loss: 0.292204  val RMSE: 106.893601
# Epoch 10/100 — train loss: 0.291505  val RMSE: 107.158372
# Epoch 11/100 — train loss: 0.290888  val RMSE: 107.422061
# Early stopping at epoch 11 (best val RMSE: 73.438606)
# Training complete for run 52 (best val RMSE: 73.438606)
# Run 52 — RMSE: 55.494890, MSE: 3079.682843, NMSE: 0.0144675583
#
# ===== RUN 53/60 =====
# Epoch 1/100 — train loss: 0.356836  val RMSE: 83.522591
# Epoch 2/100 — train loss: 0.305744  val RMSE: 92.944484
# Epoch 3/100 — train loss: 0.281205  val RMSE: 100.080481
# Epoch 4/100 — train loss: 0.279428  val RMSE: 103.350113
# Epoch 5/100 — train loss: 0.280189  val RMSE: 104.669800
# Epoch 6/100 — train loss: 0.279935  val RMSE: 105.380697
# Epoch 7/100 — train loss: 0.279389  val RMSE: 105.878234
# Epoch 8/100 — train loss: 0.278836  val RMSE: 106.281432
# Epoch 9/100 — train loss: 0.278275  val RMSE: 106.613591
# Epoch 10/100 — train loss: 0.277643  val RMSE: 106.876363
# Epoch 11/100 — train loss: 0.276866  val RMSE: 107.081389
# Early stopping at epoch 11 (best val RMSE: 83.522591)
# Training complete for run 53 (best val RMSE: 83.522591)
# Run 53 — RMSE: 51.911971, MSE: 2694.852714, NMSE: 0.0126597252
#
# ===== RUN 54/60 =====
# Epoch 1/100 — train loss: 0.279627  val RMSE: 101.572790
# Epoch 2/100 — train loss: 0.266979  val RMSE: 101.824266
# Epoch 3/100 — train loss: 0.247613  val RMSE: 101.331448
# Epoch 4/100 — train loss: 0.220417  val RMSE: 99.956893
# Epoch 5/100 — train loss: 0.197994  val RMSE: 98.352148
# Epoch 6/100 — train loss: 0.187625  val RMSE: 96.816037
# Epoch 7/100 — train loss: 0.182602  val RMSE: 95.467616
# Epoch 8/100 — train loss: 0.178389  val RMSE: 94.395322
# Epoch 9/100 — train loss: 0.174788  val RMSE: 93.576248
# Epoch 10/100 — train loss: 0.171830  val RMSE: 92.984659
# Epoch 11/100 — train loss: 0.169530  val RMSE: 92.553936
# Epoch 12/100 — train loss: 0.167813  val RMSE: 92.112486
# Epoch 13/100 — train loss: 0.166672  val RMSE: 91.566158
# Epoch 14/100 — train loss: 0.166094  val RMSE: 91.000068
# Epoch 15/100 — train loss: 0.166005  val RMSE: 90.571572
# Epoch 16/100 — train loss: 0.166109  val RMSE: 90.340821
# Epoch 17/100 — train loss: 0.166162  val RMSE: 90.316438
# Epoch 18/100 — train loss: 0.165888  val RMSE: 90.402636
# Epoch 19/100 — train loss: 0.164809  val RMSE: 90.289672
# Epoch 20/100 — train loss: 0.163200  val RMSE: 89.908859
# Epoch 21/100 — train loss: 0.161688  val RMSE: 89.469546
# Epoch 22/100 — train loss: 0.160344  val RMSE: 89.060978
# Epoch 23/100 — train loss: 0.159236  val RMSE: 88.686419
# Epoch 24/100 — train loss: 0.158350  val RMSE: 88.332922
# Epoch 25/100 — train loss: 0.157606  val RMSE: 87.994346
# Epoch 26/100 — train loss: 0.156958  val RMSE: 87.669071
# Epoch 27/100 — train loss: 0.156346  val RMSE: 87.361337
# Epoch 28/100 — train loss: 0.155759  val RMSE: 87.076549
# Epoch 29/100 — train loss: 0.155176  val RMSE: 86.812375
# Epoch 30/100 — train loss: 0.154635  val RMSE: 86.568374
# Epoch 31/100 — train loss: 0.154135  val RMSE: 86.342101
# Epoch 32/100 — train loss: 0.153676  val RMSE: 86.138316
# Epoch 33/100 — train loss: 0.153239  val RMSE: 85.956960
# Epoch 34/100 — train loss: 0.152827  val RMSE: 85.795841
# Epoch 35/100 — train loss: 0.152446  val RMSE: 85.649718
# Epoch 36/100 — train loss: 0.152094  val RMSE: 85.516329
# Epoch 37/100 — train loss: 0.151760  val RMSE: 85.399481
# Epoch 38/100 — train loss: 0.151434  val RMSE: 85.294159
# Epoch 39/100 — train loss: 0.151110  val RMSE: 85.194623
# Epoch 40/100 — train loss: 0.150815  val RMSE: 85.104630
# Epoch 41/100 — train loss: 0.150519  val RMSE: 85.023645
# Epoch 42/100 — train loss: 0.150223  val RMSE: 84.949921
# Epoch 43/100 — train loss: 0.149928  val RMSE: 84.882254
# Epoch 44/100 — train loss: 0.149632  val RMSE: 84.819835
# Epoch 45/100 — train loss: 0.149336  val RMSE: 84.762006
# Epoch 46/100 — train loss: 0.149036  val RMSE: 84.708269
# Epoch 47/100 — train loss: 0.148733  val RMSE: 84.657862
# Epoch 48/100 — train loss: 0.148430  val RMSE: 84.608278
# Epoch 49/100 — train loss: 0.148123  val RMSE: 84.560415
# Epoch 50/100 — train loss: 0.147810  val RMSE: 84.514454
# Epoch 51/100 — train loss: 0.147487  val RMSE: 84.470259
# Epoch 52/100 — train loss: 0.147154  val RMSE: 84.427593
# Epoch 53/100 — train loss: 0.146810  val RMSE: 84.386260
# Epoch 54/100 — train loss: 0.146455  val RMSE: 84.346000
# Epoch 55/100 — train loss: 0.146086  val RMSE: 84.306624
# Epoch 56/100 — train loss: 0.145704  val RMSE: 84.267540
# Epoch 57/100 — train loss: 0.145316  val RMSE: 84.224416
# Epoch 58/100 — train loss: 0.144911  val RMSE: 84.180326
# Epoch 59/100 — train loss: 0.144489  val RMSE: 84.136034
# Epoch 60/100 — train loss: 0.144049  val RMSE: 84.091646
# Epoch 61/100 — train loss: 0.143589  val RMSE: 84.047029
# Epoch 62/100 — train loss: 0.143106  val RMSE: 84.001940
# Epoch 63/100 — train loss: 0.142600  val RMSE: 83.956144
# Epoch 64/100 — train loss: 0.142067  val RMSE: 83.910387
# Epoch 65/100 — train loss: 0.141499  val RMSE: 83.871223
# Epoch 66/100 — train loss: 0.140902  val RMSE: 83.830662
# Epoch 67/100 — train loss: 0.140272  val RMSE: 83.787546
# Epoch 68/100 — train loss: 0.139606  val RMSE: 83.742210
# Epoch 69/100 — train loss: 0.138895  val RMSE: 83.691871
# Epoch 70/100 — train loss: 0.138155  val RMSE: 83.647861
# Epoch 71/100 — train loss: 0.137359  val RMSE: 83.607554
# Epoch 72/100 — train loss: 0.136510  val RMSE: 83.566769
# Epoch 73/100 — train loss: 0.135612  val RMSE: 83.523999
# Epoch 74/100 — train loss: 0.134665  val RMSE: 83.478934
# Epoch 75/100 — train loss: 0.133667  val RMSE: 83.434199
# Epoch 76/100 — train loss: 0.132622  val RMSE: 83.388282
# Epoch 77/100 — train loss: 0.131521  val RMSE: 83.339629
# Epoch 78/100 — train loss: 0.130366  val RMSE: 83.287382
# Epoch 79/100 — train loss: 0.129158  val RMSE: 83.231548
# Epoch 80/100 — train loss: 0.127892  val RMSE: 83.172225
# Epoch 81/100 — train loss: 0.126566  val RMSE: 83.109387
# Epoch 82/100 — train loss: 0.125178  val RMSE: 83.042994
# Epoch 83/100 — train loss: 0.123728  val RMSE: 82.972119
# Epoch 84/100 — train loss: 0.122214  val RMSE: 82.896659
# Epoch 85/100 — train loss: 0.120626  val RMSE: 82.817899
# Epoch 86/100 — train loss: 0.118959  val RMSE: 82.733357
# Epoch 87/100 — train loss: 0.117207  val RMSE: 82.644011
# Epoch 88/100 — train loss: 0.115348  val RMSE: 82.561586
# Epoch 89/100 — train loss: 0.113411  val RMSE: 82.473056
# Epoch 90/100 — train loss: 0.111404  val RMSE: 82.379459
# Epoch 91/100 — train loss: 0.109330  val RMSE: 82.281797
# Epoch 92/100 — train loss: 0.107200  val RMSE: 82.178568
# Epoch 93/100 — train loss: 0.105033  val RMSE: 82.068154
# Epoch 94/100 — train loss: 0.102840  val RMSE: 81.951189
# Epoch 95/100 — train loss: 0.100618  val RMSE: 81.830046
# Epoch 96/100 — train loss: 0.098364  val RMSE: 81.706013
# Epoch 97/100 — train loss: 0.096080  val RMSE: 81.579229
# Epoch 98/100 — train loss: 0.093774  val RMSE: 81.448148
# Epoch 99/100 — train loss: 0.091448  val RMSE: 81.314045
# Epoch 100/100 — train loss: 0.089122  val RMSE: 81.181936
# Training complete for run 54 (best val RMSE: 81.181936)
# Run 54 — RMSE: 77.480386, MSE: 6003.210156, NMSE: 0.0282015380
#
# ===== RUN 55/60 =====
# Epoch 1/100 — train loss: 0.296037  val RMSE: 92.066011
# Epoch 2/100 — train loss: 0.281410  val RMSE: 95.354262
# Epoch 3/100 — train loss: 0.274133  val RMSE: 98.917520
# Epoch 4/100 — train loss: 0.273815  val RMSE: 101.732852
# Epoch 5/100 — train loss: 0.275705  val RMSE: 103.265560
# Epoch 6/100 — train loss: 0.276434  val RMSE: 104.070663
# Epoch 7/100 — train loss: 0.276118  val RMSE: 104.628253
# Epoch 8/100 — train loss: 0.275235  val RMSE: 105.105679
# Epoch 9/100 — train loss: 0.273891  val RMSE: 105.569715
# Epoch 10/100 — train loss: 0.271984  val RMSE: 106.034891
# Epoch 11/100 — train loss: 0.269250  val RMSE: 106.459834
# Early stopping at epoch 11 (best val RMSE: 92.066011)
# Training complete for run 55 (best val RMSE: 92.066011)
# Run 55 — RMSE: 52.971023, MSE: 2805.929252, NMSE: 0.0131815343
#
# ===== RUN 56/60 =====
# Epoch 1/100 — train loss: 0.336612  val RMSE: 84.743042
# Epoch 2/100 — train loss: 0.298367  val RMSE: 93.415829
# Epoch 3/100 — train loss: 0.283333  val RMSE: 101.032824
# Epoch 4/100 — train loss: 0.285788  val RMSE: 103.090801
# Epoch 5/100 — train loss: 0.286349  val RMSE: 103.720231
# Epoch 6/100 — train loss: 0.286064  val RMSE: 104.190128
# Epoch 7/100 — train loss: 0.285856  val RMSE: 104.624901
# Epoch 8/100 — train loss: 0.285802  val RMSE: 105.024075
# Epoch 9/100 — train loss: 0.285878  val RMSE: 105.402691
# Epoch 10/100 — train loss: 0.286059  val RMSE: 105.747408
# Epoch 11/100 — train loss: 0.286294  val RMSE: 106.056775
# Early stopping at epoch 11 (best val RMSE: 84.743042)
# Training complete for run 56 (best val RMSE: 84.743042)
# Run 56 — RMSE: 52.103130, MSE: 2714.736145, NMSE: 0.0127531325
#
# ===== RUN 57/60 =====
# Epoch 1/100 — train loss: 0.391194  val RMSE: 78.099689
# Epoch 2/100 — train loss: 0.339601  val RMSE: 84.477803
# Epoch 3/100 — train loss: 0.289030  val RMSE: 103.825564
# Epoch 4/100 — train loss: 0.290100  val RMSE: 97.905259
# Epoch 5/100 — train loss: 0.288725  val RMSE: 95.681795
# Epoch 6/100 — train loss: 0.290759  val RMSE: 95.868637
# Epoch 7/100 — train loss: 0.291675  val RMSE: 96.884158
# Epoch 8/100 — train loss: 0.290914  val RMSE: 97.790367
# Epoch 9/100 — train loss: 0.289009  val RMSE: 98.575429
# Epoch 10/100 — train loss: 0.286975  val RMSE: 98.981438
# Epoch 11/100 — train loss: 0.285193  val RMSE: 99.116253
# Early stopping at epoch 11 (best val RMSE: 78.099689)
# Training complete for run 57 (best val RMSE: 78.099689)
# Run 57 — RMSE: 53.523436, MSE: 2864.758151, NMSE: 0.0134578973
#
# ===== RUN 58/60 =====
# Epoch 1/100 — train loss: 0.303226  val RMSE: 90.274393
# Epoch 2/100 — train loss: 0.278802  val RMSE: 98.338602
# Epoch 3/100 — train loss: 0.276736  val RMSE: 102.504941
# Epoch 4/100 — train loss: 0.278942  val RMSE: 103.837402
# Epoch 5/100 — train loss: 0.279463  val RMSE: 104.436827
# Epoch 6/100 — train loss: 0.279476  val RMSE: 104.830589
# Epoch 7/100 — train loss: 0.279379  val RMSE: 105.137471
# Epoch 8/100 — train loss: 0.279277  val RMSE: 105.402127
# Epoch 9/100 — train loss: 0.279182  val RMSE: 105.643223
# Epoch 10/100 — train loss: 0.279077  val RMSE: 105.861447
# Epoch 11/100 — train loss: 0.278931  val RMSE: 106.043218
# Early stopping at epoch 11 (best val RMSE: 90.274393)
# Training complete for run 58 (best val RMSE: 90.274393)
# Run 58 — RMSE: 52.006481, MSE: 2704.674077, NMSE: 0.0127058635
#
# ===== RUN 59/60 =====
# Epoch 1/100 — train loss: 0.279809  val RMSE: 100.756324
# Epoch 2/100 — train loss: 0.278698  val RMSE: 101.680197
# Epoch 3/100 — train loss: 0.277706  val RMSE: 102.359782
# Epoch 4/100 — train loss: 0.276282  val RMSE: 102.806498
# Epoch 5/100 — train loss: 0.274273  val RMSE: 103.057726
# Epoch 6/100 — train loss: 0.271683  val RMSE: 103.161806
# Epoch 7/100 — train loss: 0.268558  val RMSE: 103.135333
# Epoch 8/100 — train loss: 0.264954  val RMSE: 102.995808
# Epoch 9/100 — train loss: 0.260963  val RMSE: 102.766673
# Epoch 10/100 — train loss: 0.256665  val RMSE: 102.475188
# Epoch 11/100 — train loss: 0.252116  val RMSE: 102.106471
# Early stopping at epoch 11 (best val RMSE: 100.756324)
# Training complete for run 59 (best val RMSE: 100.756324)
# Run 59 — RMSE: 55.329505, MSE: 3061.354112, NMSE: 0.0143814546
#
# ===== RUN 60/60 =====
# Epoch 1/100 — train loss: 0.306467  val RMSE: 88.677633
# Epoch 2/100 — train loss: 0.283439  val RMSE: 95.291641
# Epoch 3/100 — train loss: 0.276197  val RMSE: 99.841087
# Epoch 4/100 — train loss: 0.274587  val RMSE: 101.495315
# Epoch 5/100 — train loss: 0.272111  val RMSE: 102.377959
# Epoch 6/100 — train loss: 0.269343  val RMSE: 103.058545
# Epoch 7/100 — train loss: 0.266538  val RMSE: 103.639505
# Epoch 8/100 — train loss: 0.263579  val RMSE: 104.143223
# Epoch 9/100 — train loss: 0.260257  val RMSE: 104.502245
# Epoch 10/100 — train loss: 0.256340  val RMSE: 104.743277
# Epoch 11/100 — train loss: 0.251736  val RMSE: 104.885261
# Early stopping at epoch 11 (best val RMSE: 88.677633)
# Training complete for run 60 (best val RMSE: 88.677633)
# Run 60 — RMSE: 51.923062, MSE: 2696.004349, NMSE: 0.0126651353

# %%
#Noise-robustness sweep (averaged over multiple noise draws, with explicit clean baseline)

N_NOISE_DRAWS = 10  # average over multiple ε(t) realizations per model, per level

# Re-evaluate the clean (0% noise) baseline through evaluate_on_test, so it
# uses the exact same evaluation path as the noisy conditions below.
clean_rmse, clean_mse, clean_nmse = [], [], []
for model in all_models:
    _, rmse, mse, nmse = evaluate_on_test(model, X_test, train, train_scaled, raw_values, scaler, device)
    clean_rmse.append(rmse)
    clean_mse.append(mse)
    clean_nmse.append(nmse)

print(f"[{'no noise':>10}]  "
      f"RMSE: {np.mean(clean_rmse):.6f} ± {np.std(clean_rmse):.6f}  |  "
      f"MSE: {np.mean(clean_mse):.6f} ± {np.std(clean_mse):.6f}  |  "
      f"NMSE: {np.mean(clean_nmse):.10f} ± {np.std(clean_nmse):.10f}")

noise_robustness = {}  # noise_level -> dict of per-model RMSE/MSE/NMSE (averaged over draws)

for noise_level in NOISE_LEVELS:
    level_rmse, level_mse, level_nmse = [], [], []

    for run, model in enumerate(all_models):
        draw_rmse, draw_mse, draw_nmse = [], [], []
        for draw in range(N_NOISE_DRAWS):
            seed = hash((noise_level, run, draw)) % (2 ** 32)
            X_test_noisy = add_gaussian_noise(X_test, noise_level, ref_std, seed=seed)
            _, rmse, mse, nmse = evaluate_on_test(
                model, X_test_noisy, train, train_scaled, raw_values, scaler, device
            )
            draw_rmse.append(rmse)
            draw_mse.append(mse)
            draw_nmse.append(nmse)

        level_rmse.append(np.mean(draw_rmse))  # this model's average over noise draws
        level_mse.append(np.mean(draw_mse))
        level_nmse.append(np.mean(draw_nmse))

    noise_robustness[noise_level] = {'rmse': level_rmse, 'mse': level_mse, 'nmse': level_nmse}
    print(f"[{noise_level * 100:5.1f}% noise]  "
          f"RMSE: {np.mean(level_rmse):.6f} ± {np.std(level_rmse):.6f}  |  "
          f"MSE: {np.mean(level_mse):.6f} ± {np.std(level_mse):.6f}  |  "
          f"NMSE: {np.mean(level_nmse):.10f} ± {np.std(level_nmse):.10f}")
# Out:
# [  no noise]  RMSE: 56.439505 ± 8.249305  |  MSE: 3253.468708 ± 1071.949623  |  NMSE: 0.0152839596 ± 0.0050357437
# [  0.5% noise]  RMSE: 56.439279 ± 8.248760  |  MSE: 3253.434329 ± 1071.856068  |  NMSE: 0.0152837981 ± 0.0050353043
# [  5.0% noise]  RMSE: 56.437488 ± 8.244459  |  MSE: 3253.172677 ± 1071.107579  |  NMSE: 0.0152825689 ± 0.0050317880
# [ 10.0% noise]  RMSE: 56.440111 ± 8.250247  |  MSE: 3253.599286 ± 1072.119906  |  NMSE: 0.0152845730 ± 0.0050365437
# [ 15.0% noise]  RMSE: 56.441493 ± 8.257143  |  MSE: 3253.927400 ± 1073.020220  |  NMSE: 0.0152861144 ± 0.0050407731
