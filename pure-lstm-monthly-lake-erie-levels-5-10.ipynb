# %% [markdown]
# # Pure LSTM — Monthly Lake Erie Levels (Gaussian Noise Evaluation)
#
# Time series forecasting with Gaussian noise robustness analysis.
# - Noise levels: [0.05, 0.1]
# - 60 runs × 100 epochs per noise level
# - Last 60 for test, rest for training, NO validation

# %%
# ============================================================
# ALL IMPORTS
# ============================================================

import numpy as np
import pandas as pd
import torch
import torch.nn as nn
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from math import sqrt
import matplotlib.pyplot as plt
import warnings
import os

warnings.filterwarnings('ignore')
print(f"PyTorch version: {torch.__version__}")
print(f"NumPy version: {np.__version__}")
# Out:
# PyTorch version: 2.10.0+cu128
# NumPy version: 2.0.2

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

class PureLSTM(nn.Module):
    """
    Standard LSTM (Hochreiter & Schmidhuber, 1997) for time series forecasting.
    Stateful: maintains hidden and cell states across sequence steps.
    Same hyperparameters as LSTM-SNP for fair comparison.
    """
    def __init__(self, input_dim=1, hidden_dim=8, output_dim=1):
        super().__init__()
        self.hidden_dim = hidden_dim
        self.lstm = nn.LSTM(input_dim, hidden_dim, batch_first=True)
        self.fc = nn.Linear(hidden_dim, output_dim)
        self.u = None  # (h, c) state

    def reset_states(self, batch_size, device):
        h0 = torch.zeros(1, batch_size, self.hidden_dim, device=device)
        c0 = torch.zeros(1, batch_size, self.hidden_dim, device=device)
        self.u = (h0, c0)
        
    def detach_states(self):
        if self.u is not None:
            self.u = (self.u[0].detach(), self.u[1].detach())

    def forward(self, x):
        if self.u is None or self.u[0].device != x.device:
            self.reset_states(x.size(0), x.device)
            
        lstm_out, self.u = self.lstm(x, self.u)
        out = self.fc(lstm_out[:, -1, :])
        return out


def build_model(input_dim, units):
    return PureLSTM(input_dim=input_dim, hidden_dim=units, output_dim=1)

# %%
# Quick model check
model = build_model(input_dim=1, units=8)
print(model)
print(f"Total params: {sum(p.numel() for p in model.parameters())}")
# Out:
# PureLSTM(
#   (lstm): LSTM(1, 8, batch_first=True)
#   (fc): Linear(in_features=8, out_features=1, bias=True)
# )
# Total params: 361

# %% [markdown]
# ## Data Pipeline — Monthly Lake Erie Levels

# %%
import os
for f in os.listdir('/kaggle/input/datasets/satabartosarkar123/monthly-lake-erie-levels-1921-19-csv'):
    print(f)
# Out:
# monthly-lake-erie-levels-1921-19.csv

# %%
# ============================================================
# 1. Load Time Series Data
# ============================================================
series = pd.read_csv(
    '/kaggle/input/datasets/satabartosarkar123/monthly-lake-erie-levels-1921-19-csv/monthly-lake-erie-levels-1921-19.csv',
    header=0,
    parse_dates=[0],
    index_col=0
)

original_raw_values = series.values.flatten()
print(f"Base data shape: {original_raw_values.shape}")
print(f"First 5 values: {original_raw_values[:5]}")
# Out:
# Base data shape: (600,)
# First 5 values: [14.763 14.649 15.085 16.376 16.926]

# %%
# ============================================================
# 2. First-Order Differencing
# ============================================================

def difference(dataset, interval=1):
    diff = []
    for i in range(interval, len(dataset)):
        value = dataset[i] - dataset[i - interval]
        diff.append(value)
    return np.array(diff)

# %%
# ============================================================
# 3. Convert to Supervised Learning Format (lag=1)
# ============================================================

def timeseries_to_supervised(data, lag=1):
    df = pd.DataFrame(data)
    columns = [df.shift(i) for i in range(1, lag+1)]
    columns.append(df)
    df = pd.concat(columns, axis=1)
    df.fillna(0, inplace=True)
    return df.values

# %% [markdown]
# ## Training Loop

# %%
# ============================================================
# Gaussian Noise Evaluation + 60-Run Experiment Protocol (PyTorch)
# ============================================================
import torch
import torch.nn as nn

s_x = np.std(original_raw_values)
noise_levels = [0.05, 0.1]
_molab_results = []

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"\n--- [PyTorch] RUNNING ON {device} ---\n")

for lam in noise_levels:
    sigma = lam * s_x
    print("\n" + "="*80)
    print(f"EVALUATING NOISE LEVEL: {lam*100:.1f}% (lambda={lam}, sigma={sigma:.6f})")
    print("="*80 + "\n")
    
    np.random.seed(42)
    torch.manual_seed(42)
    noise = np.random.normal(0, sigma, size=original_raw_values.shape)
    raw_values = original_raw_values + noise
    
    # 2. Difference
    diff_values = difference(raw_values, 1)
    # 3. Supervised (lag=1)
    supervised = timeseries_to_supervised(diff_values, 1)
    # 4. Split (Last 60 for test, NO validation)
    train, test = supervised[:-60], supervised[-60:]
    # 5. Scale
    scaler = MinMaxScaler(feature_range=(-1, 1))
    scaler.fit(train)
    train_scaled = scaler.transform(train)
    test_scaled = scaler.transform(test)
    # 6. Reshape
    X_train, y_train = train_scaled[:, 0:-1], train_scaled[:, -1]
    X_train = X_train.reshape((X_train.shape[0], 1, X_train.shape[1]))
    
    print(f"X_train shape: {X_train.shape}, y_train shape: {y_train.shape}")
    
    all_rmse = []
    all_mse = []
    all_nmse = []
    all_predictions = []
    all_losses = []
    
    for run in range(60):
        print(f'\n===== RUN {run+1}/60 [Noise {lam*100:.1f}%] =====')
        
        np.random.seed(run)
        torch.manual_seed(run)
        
        model = build_model(input_dim=1, units=8).to(device)
        optimizer = torch.optim.Adam(model.parameters(), lr=0.001)
        criterion = nn.MSELoss()
        
        # Pre-tensorize training data
        X_train_t = torch.tensor(X_train, dtype=torch.float32).to(device)
        y_train_t = torch.tensor(y_train, dtype=torch.float32).to(device)
        n_samples = X_train_t.size(0)
        
        run_losses = []
        for epoch in range(100):
            model.train()
            model.reset_states(1, device)
            
            epoch_loss = 0.0
            for i in range(n_samples):
                x_i = X_train_t[i:i+1]
                y_i = y_train_t[i:i+1]
                
                optimizer.zero_grad()
                pred = model(x_i)
                loss = criterion(pred.squeeze(-1), y_i)
                loss.backward()
                optimizer.step()
                model.detach_states()
                epoch_loss += loss.item()
            
            avg_loss = epoch_loss / n_samples
            run_losses.append(avg_loss)
            if (epoch+1) % 10 == 0:
                print(f"  Epoch {epoch+1}/100, Loss: {avg_loss:.6f}")
        
        all_losses.append(run_losses)
        print(f'Training complete for run {run+1}')
        
        # Warm-up: condition hidden states on training data
        model.eval()
        with torch.no_grad():
            model.reset_states(1, device)
            for i in range(len(train_scaled)):
                X_raw = train_scaled[i, 0:-1]
                X_input = torch.tensor(X_raw, dtype=torch.float32).view(1, 1, len(X_raw)).to(device)
                model(X_input)
        
        # Test predictions (single-step)
        predictions = []
        model.eval()
        with torch.no_grad():
            for i in range(len(test_scaled)):
                X = test_scaled[i, 0:-1]
                X_input = torch.tensor(X, dtype=torch.float32).view(1, 1, len(X)).to(device)
                yhat = model(X_input).item()
                
                # Invert scaling
                new_row = list(X) + [yhat]
                array = np.array(new_row).reshape(1, len(new_row))
                inverted = scaler.inverse_transform(array)[0, -1]
                
                # Invert differencing
                inverted = inverted + raw_values[len(train) + i]
                predictions.append(inverted)
        
        # Compute metrics
        actual = raw_values[-len(predictions):]
        rmse = sqrt(mean_squared_error(actual, predictions))
        mse = mean_squared_error(actual, predictions)
        meanV = np.mean(actual)
        dominator = np.linalg.norm(np.array(predictions) - meanV, 2)
        nmse = mse / np.power(dominator, 2)
        
        all_rmse.append(rmse)
        all_mse.append(mse)
        all_nmse.append(nmse)
        all_predictions.append(predictions)
        
        print(f'Run {run+1} \u2014 RMSE: {rmse:.6f}, MSE: {mse:.6f}, NMSE: {nmse:.10f}')
    
    # End of 60 runs for this noise level
    best_idx = np.argmin(all_rmse)
    
    print(f'\n===== STATS FOR NOISE {lam*100:.1f}% (60 runs) =====')
    print(f'RMSE: {np.mean(all_rmse):.6f} +/- {np.std(all_rmse):.6f}')
    print(f'MSE:  {np.mean(all_mse):.6f} +/- {np.std(all_mse):.6f}')
    print(f'NMSE: {np.mean(all_nmse):.10f} +/- {np.std(all_nmse):.10f}')
    print(f'Best run: {best_idx+1} (RMSE: {all_rmse[best_idx]:.6f})')
    
    _molab_results.append([lam, 
        np.mean(all_rmse), np.std(all_rmse),
        np.mean(all_mse), np.std(all_mse),
        np.mean(all_nmse), np.std(all_nmse),
        all_rmse[best_idx], all_predictions[best_idx], all_losses[best_idx], raw_values.copy()])
# Out:
# --- [PyTorch] RUNNING ON cuda ---
#
#
# ================================================================================
# EVALUATING NOISE LEVEL: 5.0% (lambda=0.05, sigma=0.100521)
# ================================================================================
#
# X_train shape: (539, 1, 1), y_train shape: (539,)
#
# ===== RUN 1/60 [Noise 5.0%] =====
#   Epoch 10/100, Loss: 0.055649
#   Epoch 20/100, Loss: 0.055902
#   Epoch 30/100, Loss: 0.054272
#   Epoch 40/100, Loss: 0.053693
#   Epoch 50/100, Loss: 0.051785
#   Epoch 60/100, Loss: 0.048696
#   Epoch 70/100, Loss: 0.047176
#   Epoch 80/100, Loss: 0.046588
#   Epoch 90/100, Loss: 0.046275
#   Epoch 100/100, Loss: 0.046021
# Training complete for run 1
# Run 1 — RMSE: 0.465485, MSE: 0.216676, NMSE: 0.0019229733
#
# ===== RUN 2/60 [Noise 5.0%] =====
#   Epoch 10/100, Loss: 0.061605
#   Epoch 20/100, Loss: 0.061993
#   Epoch 30/100, Loss: 0.061952
#   Epoch 40/100, Loss: 0.063194
#   Epoch 50/100, Loss: 0.062358
#   Epoch 60/100, Loss: 0.057640
#   Epoch 70/100, Loss: 0.056311
#   Epoch 80/100, Loss: 0.055509
#   Epoch 90/100, Loss: 0.055020
#   Epoch 100/100, Loss: 0.054531
# Training complete for run 2
# Run 2 — RMSE: 0.492531, MSE: 0.242587, NMSE: 0.0019461635
#
# ===== RUN 3/60 [Noise 5.0%] =====
#   Epoch 10/100, Loss: 0.064764
#   Epoch 20/100, Loss: 0.061450
#   Epoch 30/100, Loss: 0.059688
#   Epoch 40/100, Loss: 0.058356
#   Epoch 50/100, Loss: 0.056600
#   Epoch 60/100, Loss: 0.055835
#   Epoch 70/100, Loss: 0.055788
#   Epoch 80/100, Loss: 0.054573
#   Epoch 90/100, Loss: 0.051049
#   Epoch 100/100, Loss: 0.048330
# Training complete for run 3
# Run 3 — RMSE: 0.473677, MSE: 0.224370, NMSE: 0.0019101515
#
# ===== RUN 4/60 [Noise 5.0%] =====
#   Epoch 10/100, Loss: 0.057895
#   Epoch 20/100, Loss: 0.055638
#   Epoch 30/100, Loss: 0.055256
#   Epoch 40/100, Loss: 0.055204
#   Epoch 50/100, Loss: 0.055116
#   Epoch 60/100, Loss: 0.054546
#   Epoch 70/100, Loss: 0.053688
#   Epoch 80/100, Loss: 0.053333
#   Epoch 90/100, Loss: 0.052970
#   Epoch 100/100, Loss: 0.052634
# Training complete for run 4
# Run 4 — RMSE: 3.299910, MSE: 10.889406, NMSE: 0.0144972462
#
# ===== RUN 5/60 [Noise 5.0%] =====
#   Epoch 10/100, Loss: 0.058983
#   Epoch 20/100, Loss: 0.049856
#   Epoch 30/100, Loss: 0.048571
#   Epoch 40/100, Loss: 0.047734
#   Epoch 50/100, Loss: 0.046911
#   Epoch 60/100, Loss: 0.046370
#   Epoch 70/100, Loss: 0.046303
#   Epoch 80/100, Loss: 0.046541
#   Epoch 90/100, Loss: 0.048358
#   Epoch 100/100, Loss: 0.050872
# Training complete for run 5
# Run 5 — RMSE: 0.472929, MSE: 0.223662, NMSE: 0.0019265250
#
# ===== RUN 6/60 [Noise 5.0%] =====
#   Epoch 10/100, Loss: 0.054404
#   Epoch 20/100, Loss: 0.052291
#   Epoch 30/100, Loss: 0.052460
#   Epoch 40/100, Loss: 0.051165
#   Epoch 50/100, Loss: 0.048629
#   Epoch 60/100, Loss: 0.046849
#   Epoch 70/100, Loss: 0.045952
#   Epoch 80/100, Loss: 0.045463
#   Epoch 90/100, Loss: 0.045236
#   Epoch 100/100, Loss: 0.045202
# Training complete for run 6
# Run 6 — RMSE: 0.465006, MSE: 0.216231, NMSE: 0.0018094947
#
# ===== RUN 7/60 [Noise 5.0%] =====
#   Epoch 10/100, Loss: 0.064002
#   Epoch 20/100, Loss: 0.061138
#   Epoch 30/100, Loss: 0.060173
#   Epoch 40/100, Loss: 0.058962
#   Epoch 50/100, Loss: 0.057818
#   Epoch 60/100, Loss: 0.056299
#   Epoch 70/100, Loss: 0.054872
#   Epoch 80/100, Loss: 0.053596
#   Epoch 90/100, Loss: 0.052464
#   Epoch 100/100, Loss: 0.051555
# Training complete for run 7
# Run 7 — RMSE: 0.495305, MSE: 0.245327, NMSE: 0.0020840757
#
# ===== RUN 8/60 [Noise 5.0%] =====
#   Epoch 10/100, Loss: 0.063036
#   Epoch 20/100, Loss: 0.061669
#   Epoch 30/100, Loss: 0.060129
#   Epoch 40/100, Loss: 0.058109
#   Epoch 50/100, Loss: 0.055707
#   Epoch 60/100, Loss: 0.053464
#   Epoch 70/100, Loss: 0.051797
#   Epoch 80/100, Loss: 0.050570
#   Epoch 90/100, Loss: 0.049526
#   Epoch 100/100, Loss: 0.048569
# Training complete for run 8
# Run 8 — RMSE: 0.476131, MSE: 0.226701, NMSE: 0.0019471905
#
# ===== RUN 9/60 [Noise 5.0%] =====
#   Epoch 10/100, Loss: 0.065579
#   Epoch 20/100, Loss: 0.065266
#   Epoch 30/100, Loss: 0.065152
#   Epoch 40/100, Loss: 0.064669
#   Epoch 50/100, Loss: 0.063647
#   Epoch 60/100, Loss: 0.054096
#   Epoch 70/100, Loss: 0.053428
#   Epoch 80/100, Loss: 0.052216
#   Epoch 90/100, Loss: 0.051238
#   Epoch 100/100, Loss: 0.050434
# Training complete for run 9
# Run 9 — RMSE: 0.477793, MSE: 0.228286, NMSE: 0.0019086372
#
# ===== RUN 10/60 [Noise 5.0%] =====
#   Epoch 10/100, Loss: 0.052914
#   Epoch 20/100, Loss: 0.054536
#   Epoch 30/100, Loss: 0.055128
#   Epoch 40/100, Loss: 0.053676
#   Epoch 50/100, Loss: 0.052255
#   Epoch 60/100, Loss: 0.051142
#   Epoch 70/100, Loss: 0.050393
#   Epoch 80/100, Loss: 0.050029
#   Epoch 90/100, Loss: 0.049875
#   Epoch 100/100, Loss: 0.049892
# Training complete for run 10
# Run 10 — RMSE: 0.483043, MSE: 0.233330, NMSE: 0.0020298223
#
# ===== RUN 11/60 [Noise 5.0%] =====
#   Epoch 10/100, Loss: 0.064065
#   Epoch 20/100, Loss: 0.065017
#   Epoch 30/100, Loss: 0.062523
#   Epoch 40/100, Loss: 0.051318
#   Epoch 50/100, Loss: 0.051239
#   Epoch 60/100, Loss: 0.051307
#   Epoch 70/100, Loss: 0.051323
#   Epoch 80/100, Loss: 0.051339
#   Epoch 90/100, Loss: 0.051331
#   Epoch 100/100, Loss: 0.050215
# Training complete for run 11
# Run 11 — RMSE: 0.473564, MSE: 0.224263, NMSE: 0.0019303956
#
# ===== RUN 12/60 [Noise 5.0%] =====
#   Epoch 10/100, Loss: 0.055281
#   Epoch 20/100, Loss: 0.055906
#   Epoch 30/100, Loss: 0.056111
#   Epoch 40/100, Loss: 0.055296
#   Epoch 50/100, Loss: 0.054905
#   Epoch 60/100, Loss: 0.054634
#   Epoch 70/100, Loss: 0.053865
#   Epoch 80/100, Loss: 0.053007
#   Epoch 90/100, Loss: 0.052338
#   Epoch 100/100, Loss: 0.051860
# Training complete for run 12
# Run 12 — RMSE: 0.480268, MSE: 0.230658, NMSE: 0.0019603748
#
# ===== RUN 13/60 [Noise 5.0%] =====
#   Epoch 10/100, Loss: 0.065546
#   Epoch 20/100, Loss: 0.061624
#   Epoch 30/100, Loss: 0.058561
#   Epoch 40/100, Loss: 0.055856
#   Epoch 50/100, Loss: 0.054784
#   Epoch 60/100, Loss: 0.053123
#   Epoch 70/100, Loss: 0.050951
#   Epoch 80/100, Loss: 0.049466
#   Epoch 90/100, Loss: 0.048803
#   Epoch 100/100, Loss: 0.048544
# Training complete for run 13
# Run 13 — RMSE: 0.475130, MSE: 0.225748, NMSE: 0.0018947768
#
# ===== RUN 14/60 [Noise 5.0%] =====
#   Epoch 10/100, Loss: 0.053024
#   Epoch 20/100, Loss: 0.053941
#   Epoch 30/100, Loss: 0.054883
#   Epoch 40/100, Loss: 0.053573
#   Epoch 50/100, Loss: 0.051300
#   Epoch 60/100, Loss: 0.048529
#   Epoch 70/100, Loss: 0.048548
#   Epoch 80/100, Loss: 0.048699
#   Epoch 90/100, Loss: 0.048570
#   Epoch 100/100, Loss: 0.048168
# Training complete for run 14
# Run 14 — RMSE: 0.458890, MSE: 0.210580, NMSE: 0.0017902882
#
# ===== RUN 15/60 [Noise 5.0%] =====
#   Epoch 10/100, Loss: 0.059840
#   Epoch 20/100, Loss: 0.057832
#   Epoch 30/100, Loss: 0.056509
#   Epoch 40/100, Loss: 0.051086
#   Epoch 50/100, Loss: 0.049295
#   Epoch 60/100, Loss: 0.048677
#   Epoch 70/100, Loss: 0.048455
#   Epoch 80/100, Loss: 0.048387
#   Epoch 90/100, Loss: 0.048334
#   Epoch 100/100, Loss: 0.048165
# Training complete for run 15
# Run 15 — RMSE: 0.477037, MSE: 0.227564, NMSE: 0.0019211160
#
# ===== RUN 16/60 [Noise 5.0%] =====
#   Epoch 10/100, Loss: 0.067218
#   Epoch 20/100, Loss: 0.062751
#   Epoch 30/100, Loss: 0.057931
#   Epoch 40/100, Loss: 0.053581
#   Epoch 50/100, Loss: 0.049728
#   Epoch 60/100, Loss: 0.050872
#   Epoch 70/100, Loss: 0.051071
#   Epoch 80/100, Loss: 0.049875
#   Epoch 90/100, Loss: 0.049119
#   Epoch 100/100, Loss: 0.048345
# Training complete for run 16
# Run 16 — RMSE: 0.470822, MSE: 0.221674, NMSE: 0.0018991606
#
# ===== RUN 17/60 [Noise 5.0%] =====
#   Epoch 10/100, Loss: 0.057901
#   Epoch 20/100, Loss: 0.053917
#   Epoch 30/100, Loss: 0.052952
#   Epoch 40/100, Loss: 0.051698
#   Epoch 50/100, Loss: 0.051164
#   Epoch 60/100, Loss: 0.050542
#   Epoch 70/100, Loss: 0.049582
#   Epoch 80/100, Loss: 0.048583
#   Epoch 90/100, Loss: 0.047809
#   Epoch 100/100, Loss: 0.047288
# Training complete for run 17
# Run 17 — RMSE: 0.464027, MSE: 0.215321, NMSE: 0.0018518856
#
# ===== RUN 18/60 [Noise 5.0%] =====
#   Epoch 10/100, Loss: 0.057823
#   Epoch 20/100, Loss: 0.055276
#   Epoch 30/100, Loss: 0.053746
#   Epoch 40/100, Loss: 0.053586
#   Epoch 50/100, Loss: 0.053504
#   Epoch 60/100, Loss: 0.053328
#   Epoch 70/100, Loss: 0.052915
#   Epoch 80/100, Loss: 0.052344
#   Epoch 90/100, Loss: 0.051873
#   Epoch 100/100, Loss: 0.051446
# Training complete for run 18
# Run 18 — RMSE: 0.487668, MSE: 0.237821, NMSE: 0.0019277931
#
# ===== RUN 19/60 [Noise 5.0%] =====
#   Epoch 10/100, Loss: 0.065555
#   Epoch 20/100, Loss: 0.064879
#   Epoch 30/100, Loss: 0.063907
#   Epoch 40/100, Loss: 0.062632
#   Epoch 50/100, Loss: 0.061159
#   Epoch 60/100, Loss: 0.058312
#   Epoch 70/100, Loss: 0.053727
#   Epoch 80/100, Loss: 0.050916
#   Epoch 90/100, Loss: 0.049608
#   Epoch 100/100, Loss: 0.048794
# Training complete for run 19
# Run 19 — RMSE: 0.475750, MSE: 0.226338, NMSE: 0.0019523777
#
# ===== RUN 20/60 [Noise 5.0%] =====
#   Epoch 10/100, Loss: 0.062440
#   Epoch 20/100, Loss: 0.060259
#   Epoch 30/100, Loss: 0.054332
#   Epoch 40/100, Loss: 0.051556
#   Epoch 50/100, Loss: 0.050646
#   Epoch 60/100, Loss: 0.048358
#   Epoch 70/100, Loss: 0.046727
#   Epoch 80/100, Loss: 0.045631
#   Epoch 90/100, Loss: 0.045032
#   Epoch 100/100, Loss: 0.044879
# Training complete for run 20
# Run 20 — RMSE: 0.452941, MSE: 0.205156, NMSE: 0.0018390985
#
# ===== RUN 21/60 [Noise 5.0%] =====
#   Epoch 10/100, Loss: 0.064597
#   Epoch 20/100, Loss: 0.063705
#   Epoch 30/100, Loss: 0.062929
#   Epoch 40/100, Loss: 0.058947
#   Epoch 50/100, Loss: 0.055546
#   Epoch 60/100, Loss: 0.054068
#   Epoch 70/100, Loss: 0.053318
#   Epoch 80/100, Loss: 0.053573
#   Epoch 90/100, Loss: 0.053154
#   Epoch 100/100, Loss: 0.052016
# Training complete for run 21
# Run 21 — RMSE: 0.531445, MSE: 0.282434, NMSE: 0.0022547970
#
# ===== RUN 22/60 [Noise 5.0%] =====
#   Epoch 10/100, Loss: 0.065904
#   Epoch 20/100, Loss: 0.062643
#   Epoch 30/100, Loss: 0.061762
#   Epoch 40/100, Loss: 0.059135
#   Epoch 50/100, Loss: 0.057386
#   Epoch 60/100, Loss: 0.055599
#   Epoch 70/100, Loss: 0.053757
#   Epoch 80/100, Loss: 0.052149
#   Epoch 90/100, Loss: 0.051115
#   Epoch 100/100, Loss: 0.049916
# Training complete for run 22
# Run 22 — RMSE: 0.479044, MSE: 0.229483, NMSE: 0.0019771890
#
# ===== RUN 23/60 [Noise 5.0%] =====
#   Epoch 10/100, Loss: 0.065750
#   Epoch 20/100, Loss: 0.065496
#   Epoch 30/100, Loss: 0.062214
#   Epoch 40/100, Loss: 0.060990
#   Epoch 50/100, Loss: 0.054664
#   Epoch 60/100, Loss: 0.054862
#   Epoch 70/100, Loss: 0.054545
#   Epoch 80/100, Loss: 0.054185
#   Epoch 90/100, Loss: 0.054183
#   Epoch 100/100, Loss: 0.053620
# Training complete for run 23
# Run 23 — RMSE: 0.493501, MSE: 0.243544, NMSE: 0.0020674188
#
# ===== RUN 24/60 [Noise 5.0%] =====
#   Epoch 10/100, Loss: 0.065650
#   Epoch 20/100, Loss: 0.064630
#   Epoch 30/100, Loss: 0.063678
#   Epoch 40/100, Loss: 0.057691
#   Epoch 50/100, Loss: 0.049235
#   Epoch 60/100, Loss: 0.047131
#   Epoch 70/100, Loss: 0.046451
#   Epoch 80/100, Loss: 0.045928
#   Epoch 90/100, Loss: 0.045460
#   Epoch 100/100, Loss: 0.045057
# Training complete for run 24
# Run 24 — RMSE: 0.473156, MSE: 0.223877, NMSE: 0.0020677441
#
# ===== RUN 25/60 [Noise 5.0%] =====
#   Epoch 10/100, Loss: 0.061526
#   Epoch 20/100, Loss: 0.060063
#   Epoch 30/100, Loss: 0.058878
#   Epoch 40/100, Loss: 0.052675
#   Epoch 50/100, Loss: 0.052209
#   Epoch 60/100, Loss: 0.052784
#   Epoch 70/100, Loss: 0.052235
#   Epoch 80/100, Loss: 0.051433
#   Epoch 90/100, Loss: 0.050485
#   Epoch 100/100, Loss: 0.048835
# Training complete for run 25
# Run 25 — RMSE: 0.474846, MSE: 0.225479, NMSE: 0.0019177060
#
# ===== RUN 26/60 [Noise 5.0%] =====
#   Epoch 10/100, Loss: 0.063214
#   Epoch 20/100, Loss: 0.059241
#   Epoch 30/100, Loss: 0.054399
#   Epoch 40/100, Loss: 0.053778
#   Epoch 50/100, Loss: 0.053789
#   Epoch 60/100, Loss: 0.053497
#   Epoch 70/100, Loss: 0.053038
#   Epoch 80/100, Loss: 0.052214
#   Epoch 90/100, Loss: 0.050581
#   Epoch 100/100, Loss: 0.048358
# Training complete for run 26
# Run 26 — RMSE: 0.473038, MSE: 0.223765, NMSE: 0.0019489208
#
# ===== RUN 27/60 [Noise 5.0%] =====
#   Epoch 10/100, Loss: 0.065009
#   Epoch 20/100, Loss: 0.063047
#   Epoch 30/100, Loss: 0.055532
#   Epoch 40/100, Loss: 0.054800
#   Epoch 50/100, Loss: 0.054771
#   Epoch 60/100, Loss: 0.054373
#   Epoch 70/100, Loss: 0.053948
#   Epoch 80/100, Loss: 0.053724
#   Epoch 90/100, Loss: 0.053253
#   Epoch 100/100, Loss: 0.052786
# Training complete for run 27
# Run 27 — RMSE: 0.505764, MSE: 0.255798, NMSE: 0.0021263735
#
# ===== RUN 28/60 [Noise 5.0%] =====
#   Epoch 10/100, Loss: 0.062096
#   Epoch 20/100, Loss: 0.061255
#   Epoch 30/100, Loss: 0.061114
#   Epoch 40/100, Loss: 0.061206
#   Epoch 50/100, Loss: 0.061339
#   Epoch 60/100, Loss: 0.061329
#   Epoch 70/100, Loss: 0.060784
#   Epoch 80/100, Loss: 0.058184
#   Epoch 90/100, Loss: 0.055517
#   Epoch 100/100, Loss: 0.053567
# Training complete for run 28
# Run 28 — RMSE: 0.520279, MSE: 0.270690, NMSE: 0.0021831788
#
# ===== RUN 29/60 [Noise 5.0%] =====
#   Epoch 10/100, Loss: 0.063656
#   Epoch 20/100, Loss: 0.057305
#   Epoch 30/100, Loss: 0.054326
#   Epoch 40/100, Loss: 0.053055
#   Epoch 50/100, Loss: 0.051954
#   Epoch 60/100, Loss: 0.050968
#   Epoch 70/100, Loss: 0.049950
#   Epoch 80/100, Loss: 0.048987
#   Epoch 90/100, Loss: 0.047855
#   Epoch 100/100, Loss: 0.046883
# Training complete for run 29
# Run 29 — RMSE: 0.457877, MSE: 0.209651, NMSE: 0.0018253246
#
# ===== RUN 30/60 [Noise 5.0%] =====
#   Epoch 10/100, Loss: 0.066028
#   Epoch 20/100, Loss: 0.064300
#   Epoch 30/100, Loss: 0.064308
#   Epoch 40/100, Loss: 0.064158
#   Epoch 50/100, Loss: 0.051733
#   Epoch 60/100, Loss: 0.053494
#   Epoch 70/100, Loss: 0.054484
#   Epoch 80/100, Loss: 0.054616
#   Epoch 90/100, Loss: 0.054294
#   Epoch 100/100, Loss: 0.054574
# Training complete for run 30
# Run 30 — RMSE: 0.494980, MSE: 0.245006, NMSE: 0.0020160236
#
# ===== RUN 31/60 [Noise 5.0%] =====
#   Epoch 10/100, Loss: 0.055471
#   Epoch 20/100, Loss: 0.055166
#   Epoch 30/100, Loss: 0.055507
#   Epoch 40/100, Loss: 0.055118
#   Epoch 50/100, Loss: 0.053999
#   Epoch 60/100, Loss: 0.053244
#   Epoch 70/100, Loss: 0.052606
#   Epoch 80/100, Loss: 0.051990
#   Epoch 90/100, Loss: 0.051469
#   Epoch 100/100, Loss: 0.050997
# Training complete for run 31
# Run 31 — RMSE: 0.482051, MSE: 0.232373, NMSE: 0.0020011327
#
# ===== RUN 32/60 [Noise 5.0%] =====
#   Epoch 10/100, Loss: 0.063715
#   Epoch 20/100, Loss: 0.061159
#   Epoch 30/100, Loss: 0.060996
#   Epoch 40/100, Loss: 0.060107
#   Epoch 50/100, Loss: 0.059588
#   Epoch 60/100, Loss: 0.054001
#   Epoch 70/100, Loss: 0.053047
#   Epoch 80/100, Loss: 0.052634
#   Epoch 90/100, Loss: 0.052340
#   Epoch 100/100, Loss: 0.052163
# Training complete for run 32
# Run 32 — RMSE: 0.508863, MSE: 0.258941, NMSE: 0.0021499898
#
# ===== RUN 33/60 [Noise 5.0%] =====
#   Epoch 10/100, Loss: 0.064048
#   Epoch 20/100, Loss: 0.059356
#   Epoch 30/100, Loss: 0.057831
#   Epoch 40/100, Loss: 0.056015
#   Epoch 50/100, Loss: 0.054123
#   Epoch 60/100, Loss: 0.051933
#   Epoch 70/100, Loss: 0.050735
#   Epoch 80/100, Loss: 0.050405
#   Epoch 90/100, Loss: 0.050239
#   Epoch 100/100, Loss: 0.049763
# Training complete for run 33
# Run 33 — RMSE: 0.468475, MSE: 0.219469, NMSE: 0.0018676121
#
# ===== RUN 34/60 [Noise 5.0%] =====
#   Epoch 10/100, Loss: 0.064104
#   Epoch 20/100, Loss: 0.060961
#   Epoch 30/100, Loss: 0.058339
#   Epoch 40/100, Loss: 0.050828
#   Epoch 50/100, Loss: 0.055731
#   Epoch 60/100, Loss: 0.055309
#   Epoch 70/100, Loss: 0.055669
#   Epoch 80/100, Loss: 0.054924
#   Epoch 90/100, Loss: 0.053633
#   Epoch 100/100, Loss: 0.052828
# Training complete for run 34
# Run 34 — RMSE: 0.574051, MSE: 0.329534, NMSE: 0.0025674124
#
# ===== RUN 35/60 [Noise 5.0%] =====
#   Epoch 10/100, Loss: 0.057442
#   Epoch 20/100, Loss: 0.056849
#   Epoch 30/100, Loss: 0.056928
#   Epoch 40/100, Loss: 0.057372
#   Epoch 50/100, Loss: 0.057693
#   Epoch 60/100, Loss: 0.057199
#   Epoch 70/100, Loss: 0.056379
#   Epoch 80/100, Loss: 0.055517
#   Epoch 90/100, Loss: 0.053793
#   Epoch 100/100, Loss: 0.051185
# Training complete for run 35
# Run 35 — RMSE: 0.495094, MSE: 0.245119, NMSE: 0.0020896780
#
# ===== RUN 36/60 [Noise 5.0%] =====
#   Epoch 10/100, Loss: 0.062816
#   Epoch 20/100, Loss: 0.062180
#   Epoch 30/100, Loss: 0.054864
#   Epoch 40/100, Loss: 0.048364
#   Epoch 50/100, Loss: 0.046948
#   Epoch 60/100, Loss: 0.046010
#   Epoch 70/100, Loss: 0.045442
#   Epoch 80/100, Loss: 0.045525
#   Epoch 90/100, Loss: 0.045577
#   Epoch 100/100, Loss: 0.045491
# Training complete for run 36
# Run 36 — RMSE: 0.463397, MSE: 0.214736, NMSE: 0.0017819031
#
# ===== RUN 37/60 [Noise 5.0%] =====
#   Epoch 10/100, Loss: 0.065174
#   Epoch 20/100, Loss: 0.064884
#   Epoch 30/100, Loss: 0.062467
#   Epoch 40/100, Loss: 0.053763
#   Epoch 50/100, Loss: 0.053684
#   Epoch 60/100, Loss: 0.051975
#   Epoch 70/100, Loss: 0.050353
#   Epoch 80/100, Loss: 0.049164
#   Epoch 90/100, Loss: 0.048303
#   Epoch 100/100, Loss: 0.047494
# Training complete for run 37
# Run 37 — RMSE: 0.471661, MSE: 0.222464, NMSE: 0.0019159937
#
# ===== RUN 38/60 [Noise 5.0%] =====
#   Epoch 10/100, Loss: 0.061465
#   Epoch 20/100, Loss: 0.057450
#   Epoch 30/100, Loss: 0.052796
#   Epoch 40/100, Loss: 0.049841
#   Epoch 50/100, Loss: 0.048204
#   Epoch 60/100, Loss: 0.047237
#   Epoch 70/100, Loss: 0.046835
#   Epoch 80/100, Loss: 0.046560
#   Epoch 90/100, Loss: 0.046358
#   Epoch 100/100, Loss: 0.046235
# Training complete for run 38
# Run 38 — RMSE: 0.458685, MSE: 0.210392, NMSE: 0.0018454686
#
# ===== RUN 39/60 [Noise 5.0%] =====
#   Epoch 10/100, Loss: 0.059093
#   Epoch 20/100, Loss: 0.056199
#   Epoch 30/100, Loss: 0.052143
#   Epoch 40/100, Loss: 0.048822
#   Epoch 50/100, Loss: 0.047816
#   Epoch 60/100, Loss: 0.047376
#   Epoch 70/100, Loss: 0.047206
#   Epoch 80/100, Loss: 0.047415
#   Epoch 90/100, Loss: 0.048383
#   Epoch 100/100, Loss: 0.049609
# Training complete for run 39
# Run 39 — RMSE: 0.468589, MSE: 0.219575, NMSE: 0.0019375195
#
# ===== RUN 40/60 [Noise 5.0%] =====
#   Epoch 10/100, Loss: 0.061142
#   Epoch 20/100, Loss: 0.060797
#   Epoch 30/100, Loss: 0.059822
#   Epoch 40/100, Loss: 0.052828
#   Epoch 50/100, Loss: 0.049759
#   Epoch 60/100, Loss: 0.049016
#   Epoch 70/100, Loss: 0.048919
#   Epoch 80/100, Loss: 0.048375
#   Epoch 90/100, Loss: 0.047046
#   Epoch 100/100, Loss: 0.049406
# Training complete for run 40
# Run 40 — RMSE: 0.461855, MSE: 0.213310, NMSE: 0.0019040888
#
# ===== RUN 41/60 [Noise 5.0%] =====
#   Epoch 10/100, Loss: 0.062869
#   Epoch 20/100, Loss: 0.061886
#   Epoch 30/100, Loss: 0.057839
#   Epoch 40/100, Loss: 0.048155
#   Epoch 50/100, Loss: 0.047991
#   Epoch 60/100, Loss: 0.047470
#   Epoch 70/100, Loss: 0.046848
#   Epoch 80/100, Loss: 0.046511
#   Epoch 90/100, Loss: 0.046351
#   Epoch 100/100, Loss: 0.046264
# Training complete for run 41
# Run 41 — RMSE: 0.447513, MSE: 0.200268, NMSE: 0.0017653169
#
# ===== RUN 42/60 [Noise 5.0%] =====
#   Epoch 10/100, Loss: 0.056396
#   Epoch 20/100, Loss: 0.051371
#   Epoch 30/100, Loss: 0.049227
#   Epoch 40/100, Loss: 0.047899
#   Epoch 50/100, Loss: 0.047144
#   Epoch 60/100, Loss: 0.046758
#   Epoch 70/100, Loss: 0.046576
#   Epoch 80/100, Loss: 0.046495
#   Epoch 90/100, Loss: 0.046572
#   Epoch 100/100, Loss: 0.046684
# Training complete for run 42
# Run 42 — RMSE: 0.462062, MSE: 0.213502, NMSE: 0.0019283735
#
# ===== RUN 43/60 [Noise 5.0%] =====
#   Epoch 10/100, Loss: 0.063086
#   Epoch 20/100, Loss: 0.062394
#   Epoch 30/100, Loss: 0.060590
#   Epoch 40/100, Loss: 0.058617
#   Epoch 50/100, Loss: 0.056357
#   Epoch 60/100, Loss: 0.054248
#   Epoch 70/100, Loss: 0.051430
#   Epoch 80/100, Loss: 0.048654
#   Epoch 90/100, Loss: 0.047047
#   Epoch 100/100, Loss: 0.046309
# Training complete for run 43
# Run 43 — RMSE: 0.460226, MSE: 0.211808, NMSE: 0.0018985181
#
# ===== RUN 44/60 [Noise 5.0%] =====
#   Epoch 10/100, Loss: 0.065620
#   Epoch 20/100, Loss: 0.064600
#   Epoch 30/100, Loss: 0.060374
#   Epoch 40/100, Loss: 0.060062
#   Epoch 50/100, Loss: 0.058775
#   Epoch 60/100, Loss: 0.053538
#   Epoch 70/100, Loss: 0.051020
#   Epoch 80/100, Loss: 0.050896
#   Epoch 90/100, Loss: 0.050227
#   Epoch 100/100, Loss: 0.049531
# Training complete for run 44
# Run 44 — RMSE: 0.478465, MSE: 0.228929, NMSE: 0.0019625885
#
# ===== RUN 45/60 [Noise 5.0%] =====
#   Epoch 10/100, Loss: 0.063249
#   Epoch 20/100, Loss: 0.060742
#   Epoch 30/100, Loss: 0.058798
#   Epoch 40/100, Loss: 0.058530
#   Epoch 50/100, Loss: 0.057718
#   Epoch 60/100, Loss: 0.056358
#   Epoch 70/100, Loss: 0.054986
#   Epoch 80/100, Loss: 0.053917
#   Epoch 90/100, Loss: 0.053164
#   Epoch 100/100, Loss: 0.052530
# Training complete for run 45
# Run 45 — RMSE: 0.506781, MSE: 0.256827, NMSE: 0.0021258932
#
# ===== RUN 46/60 [Noise 5.0%] =====
#   Epoch 10/100, Loss: 0.064454
#   Epoch 20/100, Loss: 0.063965
#   Epoch 30/100, Loss: 0.062912
#   Epoch 40/100, Loss: 0.061861
#   Epoch 50/100, Loss: 0.057651
#   Epoch 60/100, Loss: 0.056577
#   Epoch 70/100, Loss: 0.056187
#   Epoch 80/100, Loss: 0.055632
#   Epoch 90/100, Loss: 0.054923
#   Epoch 100/100, Loss: 0.053919
# Training complete for run 46
# Run 46 — RMSE: 0.517576, MSE: 0.267885, NMSE: 0.0021673209
#
# ===== RUN 47/60 [Noise 5.0%] =====
#   Epoch 10/100, Loss: 0.065810
#   Epoch 20/100, Loss: 0.065698
#   Epoch 30/100, Loss: 0.064933
#   Epoch 40/100, Loss: 0.064189
#   Epoch 50/100, Loss: 0.063436
#   Epoch 60/100, Loss: 0.061774
#   Epoch 70/100, Loss: 0.054094
#   Epoch 80/100, Loss: 0.051291
#   Epoch 90/100, Loss: 0.051180
#   Epoch 100/100, Loss: 0.051609
# Training complete for run 47
# Run 47 — RMSE: 0.490503, MSE: 0.240593, NMSE: 0.0020344587
#
# ===== RUN 48/60 [Noise 5.0%] =====
#   Epoch 10/100, Loss: 0.057416
#   Epoch 20/100, Loss: 0.058083
#   Epoch 30/100, Loss: 0.059489
#   Epoch 40/100, Loss: 0.055373
#   Epoch 50/100, Loss: 0.049700
#   Epoch 60/100, Loss: 0.048472
#   Epoch 70/100, Loss: 0.048544
#   Epoch 80/100, Loss: 0.048582
#   Epoch 90/100, Loss: 0.048035
#   Epoch 100/100, Loss: 0.047367
# Training complete for run 48
# Run 48 — RMSE: 0.460925, MSE: 0.212452, NMSE: 0.0018985137
#
# ===== RUN 49/60 [Noise 5.0%] =====
#   Epoch 10/100, Loss: 0.062823
#   Epoch 20/100, Loss: 0.060329
#   Epoch 30/100, Loss: 0.062431
#   Epoch 40/100, Loss: 0.065146
#   Epoch 50/100, Loss: 0.063689
#   Epoch 60/100, Loss: 0.060096
#   Epoch 70/100, Loss: 0.057917
#   Epoch 80/100, Loss: 0.055666
#   Epoch 90/100, Loss: 0.053598
#   Epoch 100/100, Loss: 0.052262
# Training complete for run 49
# Run 49 — RMSE: 0.499135, MSE: 0.249136, NMSE: 0.0019630250
#
# ===== RUN 50/60 [Noise 5.0%] =====
#   Epoch 10/100, Loss: 0.056895
#   Epoch 20/100, Loss: 0.054887
#   Epoch 30/100, Loss: 0.053239
#   Epoch 40/100, Loss: 0.052935
#   Epoch 50/100, Loss: 0.052648
#   Epoch 60/100, Loss: 0.051776
#   Epoch 70/100, Loss: 0.050400
#   Epoch 80/100, Loss: 0.048929
#   Epoch 90/100, Loss: 0.048057
#   Epoch 100/100, Loss: 0.047699
# Training complete for run 50
# Run 50 — RMSE: 0.474907, MSE: 0.225536, NMSE: 0.0019538333
#
# ===== RUN 51/60 [Noise 5.0%] =====
#   Epoch 10/100, Loss: 0.063154
#   Epoch 20/100, Loss: 0.062023
#   Epoch 30/100, Loss: 0.060670
#   Epoch 40/100, Loss: 0.056058
#   Epoch 50/100, Loss: 0.050382
#   Epoch 60/100, Loss: 0.047934
#   Epoch 70/100, Loss: 0.047715
#   Epoch 80/100, Loss: 0.048033
#   Epoch 90/100, Loss: 0.048460
#   Epoch 100/100, Loss: 0.048435
# Training complete for run 51
# Run 51 — RMSE: 0.456275, MSE: 0.208187, NMSE: 0.0018033637
#
# ===== RUN 52/60 [Noise 5.0%] =====
#   Epoch 10/100, Loss: 0.061552
#   Epoch 20/100, Loss: 0.057259
#   Epoch 30/100, Loss: 0.057646
#   Epoch 40/100, Loss: 0.055940
#   Epoch 50/100, Loss: 0.053310
#   Epoch 60/100, Loss: 0.051651
#   Epoch 70/100, Loss: 0.051259
#   Epoch 80/100, Loss: 0.051212
#   Epoch 90/100, Loss: 0.051174
#   Epoch 100/100, Loss: 0.050962
# Training complete for run 52
# Run 52 — RMSE: 0.485438, MSE: 0.235650, NMSE: 0.0019735885
#
# ===== RUN 53/60 [Noise 5.0%] =====
#   Epoch 10/100, Loss: 0.063778
#   Epoch 20/100, Loss: 0.064672
#   Epoch 30/100, Loss: 0.063964
#   Epoch 40/100, Loss: 0.055626
#   Epoch 50/100, Loss: 0.052199
#   Epoch 60/100, Loss: 0.051400
#   Epoch 70/100, Loss: 0.050143
#   Epoch 80/100, Loss: 0.048517
#   Epoch 90/100, Loss: 0.046837
#   Epoch 100/100, Loss: 0.045728
# Training complete for run 53
# Run 53 — RMSE: 0.466298, MSE: 0.217434, NMSE: 0.0018820481
#
# ===== RUN 54/60 [Noise 5.0%] =====
#   Epoch 10/100, Loss: 0.061580
#   Epoch 20/100, Loss: 0.060418
#   Epoch 30/100, Loss: 0.052716
#   Epoch 40/100, Loss: 0.050804
#   Epoch 50/100, Loss: 0.050458
#   Epoch 60/100, Loss: 0.050105
#   Epoch 70/100, Loss: 0.049827
#   Epoch 80/100, Loss: 0.049391
#   Epoch 90/100, Loss: 0.048543
#   Epoch 100/100, Loss: 0.048093
# Training complete for run 54
# Run 54 — RMSE: 0.468927, MSE: 0.219892, NMSE: 0.0018567272
#
# ===== RUN 55/60 [Noise 5.0%] =====
#   Epoch 10/100, Loss: 0.051456
#   Epoch 20/100, Loss: 0.050957
#   Epoch 30/100, Loss: 0.049392
#   Epoch 40/100, Loss: 0.048107
#   Epoch 50/100, Loss: 0.047556
#   Epoch 60/100, Loss: 0.047300
#   Epoch 70/100, Loss: 0.047130
#   Epoch 80/100, Loss: 0.047029
#   Epoch 90/100, Loss: 0.047056
#   Epoch 100/100, Loss: 0.047294
# Training complete for run 55
# Run 55 — RMSE: 0.460570, MSE: 0.212125, NMSE: 0.0018281694
#
# ===== RUN 56/60 [Noise 5.0%] =====
#   Epoch 10/100, Loss: 0.049861
#   Epoch 20/100, Loss: 0.048583
#   Epoch 30/100, Loss: 0.048170
#   Epoch 40/100, Loss: 0.048031
#   Epoch 50/100, Loss: 0.048242
#   Epoch 60/100, Loss: 0.048904
#   Epoch 70/100, Loss: 0.049182
#   Epoch 80/100, Loss: 0.048428
#   Epoch 90/100, Loss: 0.048176
#   Epoch 100/100, Loss: 0.048256
# Training complete for run 56
# Run 56 — RMSE: 0.466249, MSE: 0.217388, NMSE: 0.0018806478
#
# ===== RUN 57/60 [Noise 5.0%] =====
#   Epoch 10/100, Loss: 0.063805
#   Epoch 20/100, Loss: 0.060980
#   Epoch 30/100, Loss: 0.056827
#   Epoch 40/100, Loss: 0.053449
#   Epoch 50/100, Loss: 0.051438
#   Epoch 60/100, Loss: 0.050180
#   Epoch 70/100, Loss: 0.049075
#   Epoch 80/100, Loss: 0.048274
#   Epoch 90/100, Loss: 0.047698
#   Epoch 100/100, Loss: 0.047246
# Training complete for run 57
# Run 57 — RMSE: 0.468981, MSE: 0.219943, NMSE: 0.0018959515
#
# ===== RUN 58/60 [Noise 5.0%] =====
#   Epoch 10/100, Loss: 0.062135
#   Epoch 20/100, Loss: 0.056918
#   Epoch 30/100, Loss: 0.057967
#   Epoch 40/100, Loss: 0.056091
#   Epoch 50/100, Loss: 0.051670
#   Epoch 60/100, Loss: 0.049416
#   Epoch 70/100, Loss: 0.048339
#   Epoch 80/100, Loss: 0.047972
#   Epoch 90/100, Loss: 0.047686
#   Epoch 100/100, Loss: 0.047373
# Training complete for run 58
# Run 58 — RMSE: 0.455650, MSE: 0.207617, NMSE: 0.0018118325
#
# ===== RUN 59/60 [Noise 5.0%] =====
#   Epoch 10/100, Loss: 0.060757
#   Epoch 20/100, Loss: 0.059471
#   Epoch 30/100, Loss: 0.058832
#   Epoch 40/100, Loss: 0.058310
#   Epoch 50/100, Loss: 0.053129
#   Epoch 60/100, Loss: 0.052016
#   Epoch 70/100, Loss: 0.059836
#   Epoch 80/100, Loss: 0.057965
#   Epoch 90/100, Loss: 0.055448
#   Epoch 100/100, Loss: 0.051519
# Training complete for run 59
# Run 59 — RMSE: 0.490347, MSE: 0.240440, NMSE: 0.0020224334
#
# ===== RUN 60/60 [Noise 5.0%] =====
#   Epoch 10/100, Loss: 0.059613
#   Epoch 20/100, Loss: 0.059659
#   Epoch 30/100, Loss: 0.058618
#   Epoch 40/100, Loss: 0.056701
#   Epoch 50/100, Loss: 0.056058
#   Epoch 60/100, Loss: 0.055204
#   Epoch 70/100, Loss: 0.053525
#   Epoch 80/100, Loss: 0.051147
#   Epoch 90/100, Loss: 0.049974
#   Epoch 100/100, Loss: 0.049558
# Training complete for run 60
# Run 60 — RMSE: 0.477919, MSE: 0.228406, NMSE: 0.0020043774
#
# ===== STATS FOR NOISE 5.0% (60 runs) =====
# RMSE: 0.526155 +/- 0.361732
# MSE:  0.407689 +/- 1.364767
# NMSE: 0.0021675334 +/- 0.0016105326
# Best run: 41 (RMSE: 0.447513)
#
# ================================================================================
# EVALUATING NOISE LEVEL: 10.0% (lambda=0.1, sigma=0.201042)
# ================================================================================
#
# X_train shape: (539, 1, 1), y_train shape: (539,)
#
# ===== RUN 1/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.065012
#   Epoch 20/100, Loss: 0.062901
#   Epoch 30/100, Loss: 0.060765
#   Epoch 40/100, Loss: 0.058430
#   Epoch 50/100, Loss: 0.056042
#   Epoch 60/100, Loss: 0.053827
#   Epoch 70/100, Loss: 0.052419
#   Epoch 80/100, Loss: 0.051756
#   Epoch 90/100, Loss: 0.051449
#   Epoch 100/100, Loss: 0.051341
# Training complete for run 1
# Run 1 — RMSE: 0.541965, MSE: 0.293726, NMSE: 0.0025446453
#
# ===== RUN 2/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.068377
#   Epoch 20/100, Loss: 0.068835
#   Epoch 30/100, Loss: 0.069933
#   Epoch 40/100, Loss: 0.070373
#   Epoch 50/100, Loss: 0.070875
#   Epoch 60/100, Loss: 0.069392
#   Epoch 70/100, Loss: 0.068147
#   Epoch 80/100, Loss: 0.066859
#   Epoch 90/100, Loss: 0.065154
#   Epoch 100/100, Loss: 0.063105
# Training complete for run 2
# Run 2 — RMSE: 0.617720, MSE: 0.381578, NMSE: 0.0028904123
#
# ===== RUN 3/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.074408
#   Epoch 20/100, Loss: 0.071623
#   Epoch 30/100, Loss: 0.068844
#   Epoch 40/100, Loss: 0.067378
#   Epoch 50/100, Loss: 0.065280
#   Epoch 60/100, Loss: 0.065124
#   Epoch 70/100, Loss: 0.064755
#   Epoch 80/100, Loss: 0.064326
#   Epoch 90/100, Loss: 0.064132
#   Epoch 100/100, Loss: 0.063823
# Training complete for run 3
# Run 3 — RMSE: 0.583638, MSE: 0.340633, NMSE: 0.0028415658
#
# ===== RUN 4/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.065240
#   Epoch 20/100, Loss: 0.064652
#   Epoch 30/100, Loss: 0.065056
#   Epoch 40/100, Loss: 0.066281
#   Epoch 50/100, Loss: 0.067198
#   Epoch 60/100, Loss: 0.067116
#   Epoch 70/100, Loss: 0.066886
#   Epoch 80/100, Loss: 0.064282
#   Epoch 90/100, Loss: 0.061007
#   Epoch 100/100, Loss: 0.059310
# Training complete for run 4
# Run 4 — RMSE: 0.578800, MSE: 0.335010, NMSE: 0.0027000068
#
# ===== RUN 5/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.070539
#   Epoch 20/100, Loss: 0.057470
#   Epoch 30/100, Loss: 0.053717
#   Epoch 40/100, Loss: 0.054043
#   Epoch 50/100, Loss: 0.054832
#   Epoch 60/100, Loss: 0.056269
#   Epoch 70/100, Loss: 0.057906
#   Epoch 80/100, Loss: 0.057669
#   Epoch 90/100, Loss: 0.056825
#   Epoch 100/100, Loss: 0.056907
# Training complete for run 5
# Run 5 — RMSE: 0.575585, MSE: 0.331298, NMSE: 0.0029473224
#
# ===== RUN 6/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.063164
#   Epoch 20/100, Loss: 0.057055
#   Epoch 30/100, Loss: 0.054927
#   Epoch 40/100, Loss: 0.054114
#   Epoch 50/100, Loss: 0.053810
#   Epoch 60/100, Loss: 0.053658
#   Epoch 70/100, Loss: 0.053556
#   Epoch 80/100, Loss: 0.053313
#   Epoch 90/100, Loss: 0.053006
#   Epoch 100/100, Loss: 0.052824
# Training complete for run 6
# Run 6 — RMSE: 0.534994, MSE: 0.286218, NMSE: 0.0025651673
#
# ===== RUN 7/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.072531
#   Epoch 20/100, Loss: 0.069463
#   Epoch 30/100, Loss: 0.067314
#   Epoch 40/100, Loss: 0.066129
#   Epoch 50/100, Loss: 0.063823
#   Epoch 60/100, Loss: 0.060979
#   Epoch 70/100, Loss: 0.058244
#   Epoch 80/100, Loss: 0.055664
#   Epoch 90/100, Loss: 0.053873
#   Epoch 100/100, Loss: 0.052755
# Training complete for run 7
# Run 7 — RMSE: 0.545565, MSE: 0.297642, NMSE: 0.0025787973
#
# ===== RUN 8/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.073886
#   Epoch 20/100, Loss: 0.071025
#   Epoch 30/100, Loss: 0.067548
#   Epoch 40/100, Loss: 0.062704
#   Epoch 50/100, Loss: 0.057278
#   Epoch 60/100, Loss: 0.053880
#   Epoch 70/100, Loss: 0.052134
#   Epoch 80/100, Loss: 0.051232
#   Epoch 90/100, Loss: 0.050761
#   Epoch 100/100, Loss: 0.050519
# Training complete for run 8
# Run 8 — RMSE: 0.537193, MSE: 0.288576, NMSE: 0.0025554659
#
# ===== RUN 9/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.073462
#   Epoch 20/100, Loss: 0.073217
#   Epoch 30/100, Loss: 0.073485
#   Epoch 40/100, Loss: 0.072740
#   Epoch 50/100, Loss: 0.071791
#   Epoch 60/100, Loss: 0.062091
#   Epoch 70/100, Loss: 0.061486
#   Epoch 80/100, Loss: 0.060155
#   Epoch 90/100, Loss: 0.058443
#   Epoch 100/100, Loss: 0.056691
# Training complete for run 10
# Run 10 — RMSE: 0.572073, MSE: 0.327268, NMSE: 0.0026844511
#
# ===== RUN 11/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.072833
#   Epoch 20/100, Loss: 0.070026
#   Epoch 30/100, Loss: 0.069846
#   Epoch 40/100, Loss: 0.059963
#   Epoch 50/100, Loss: 0.056479
#   Epoch 60/100, Loss: 0.054394
#   Epoch 70/100, Loss: 0.054373
#   Epoch 80/100, Loss: 0.053714
#   Epoch 90/100, Loss: 0.052803
#   Epoch 100/100, Loss: 0.052305
# Training complete for run 11
# Run 11 — RMSE: 0.525992, MSE: 0.276668, NMSE: 0.0023617794
#
# ===== RUN 12/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.063349
#   Epoch 20/100, Loss: 0.064370
#   Epoch 30/100, Loss: 0.065796
#   Epoch 40/100, Loss: 0.066995
#   Epoch 50/100, Loss: 0.067211
#   Epoch 60/100, Loss: 0.067049
#   Epoch 70/100, Loss: 0.066406
#   Epoch 80/100, Loss: 0.065082
#   Epoch 90/100, Loss: 0.063661
#   Epoch 100/100, Loss: 0.062240
# Training complete for run 12
# Run 12 — RMSE: 0.573730, MSE: 0.329166, NMSE: 0.0026728539
#
# ===== RUN 13/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.074392
#   Epoch 20/100, Loss: 0.071265
#   Epoch 30/100, Loss: 0.069365
#   Epoch 40/100, Loss: 0.067602
#   Epoch 50/100, Loss: 0.063723
#   Epoch 60/100, Loss: 0.060840
#   Epoch 70/100, Loss: 0.058636
#   Epoch 80/100, Loss: 0.056432
#   Epoch 90/100, Loss: 0.054786
#   Epoch 100/100, Loss: 0.053727
# Training complete for run 13
# Run 13 — RMSE: 0.540843, MSE: 0.292511, NMSE: 0.0025509528
#
# ===== RUN 14/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.059381
#   Epoch 20/100, Loss: 0.062331
#   Epoch 30/100, Loss: 0.066139
#   Epoch 40/100, Loss: 0.067690
#   Epoch 50/100, Loss: 0.066777
#   Epoch 60/100, Loss: 0.065552
#   Epoch 70/100, Loss: 0.065578
#   Epoch 80/100, Loss: 0.065282
#   Epoch 90/100, Loss: 0.064285
#   Epoch 100/100, Loss: 0.061299
# Training complete for run 14
# Run 14 — RMSE: 0.584502, MSE: 0.341643, NMSE: 0.0028512640
#
# ===== RUN 15/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.068109
#   Epoch 20/100, Loss: 0.067148
#   Epoch 30/100, Loss: 0.065141
#   Epoch 40/100, Loss: 0.056687
#   Epoch 50/100, Loss: 0.054881
#   Epoch 60/100, Loss: 0.054488
#   Epoch 70/100, Loss: 0.054470
#   Epoch 80/100, Loss: 0.054690
#   Epoch 90/100, Loss: 0.055074
#   Epoch 100/100, Loss: 0.055285
# Training complete for run 15
# Run 15 — RMSE: 0.544847, MSE: 0.296859, NMSE: 0.0025598728
#
# ===== RUN 16/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.075337
#   Epoch 20/100, Loss: 0.073140
#   Epoch 30/100, Loss: 0.072153
#   Epoch 40/100, Loss: 0.070713
#   Epoch 50/100, Loss: 0.069796
#   Epoch 60/100, Loss: 0.068834
#   Epoch 70/100, Loss: 0.067683
#   Epoch 80/100, Loss: 0.066729
#   Epoch 90/100, Loss: 0.065991
#   Epoch 100/100, Loss: 0.065311
# Training complete for run 16
# Run 16 — RMSE: 0.595471, MSE: 0.354586, NMSE: 0.0028559809
#
# ===== RUN 17/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.070008
#   Epoch 20/100, Loss: 0.064190
#   Epoch 30/100, Loss: 0.063555
#   Epoch 40/100, Loss: 0.062857
#   Epoch 50/100, Loss: 0.061961
#   Epoch 60/100, Loss: 0.061718
#   Epoch 70/100, Loss: 0.061196
#   Epoch 80/100, Loss: 0.060685
#   Epoch 90/100, Loss: 0.060380
#   Epoch 100/100, Loss: 0.060251
# Training complete for run 17
# Run 17 — RMSE: 0.596870, MSE: 0.356254, NMSE: 0.0028711571
#
# ===== RUN 18/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.063881
#   Epoch 20/100, Loss: 0.061197
#   Epoch 30/100, Loss: 0.059858
#   Epoch 40/100, Loss: 0.059180
#   Epoch 50/100, Loss: 0.058595
#   Epoch 60/100, Loss: 0.057960
#   Epoch 70/100, Loss: 0.058672
#   Epoch 80/100, Loss: 0.059664
#   Epoch 90/100, Loss: 0.057643
#   Epoch 100/100, Loss: 0.056077
# Training complete for run 18
# Run 18 — RMSE: 0.558957, MSE: 0.312433, NMSE: 0.0027918360
#
# ===== RUN 19/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.074601
#   Epoch 20/100, Loss: 0.073948
#   Epoch 30/100, Loss: 0.073398
#   Epoch 40/100, Loss: 0.072077
#   Epoch 50/100, Loss: 0.069260
#   Epoch 60/100, Loss: 0.066118
#   Epoch 70/100, Loss: 0.059104
#   Epoch 80/100, Loss: 0.056475
#   Epoch 90/100, Loss: 0.055087
#   Epoch 100/100, Loss: 0.053960
# Training complete for run 19
# Run 19 — RMSE: 0.560099, MSE: 0.313711, NMSE: 0.0026308210
#
# ===== RUN 20/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.071951
#   Epoch 20/100, Loss: 0.070467
#   Epoch 30/100, Loss: 0.065294
#   Epoch 40/100, Loss: 0.057428
#   Epoch 50/100, Loss: 0.056696
#   Epoch 60/100, Loss: 0.056514
#   Epoch 70/100, Loss: 0.055012
#   Epoch 80/100, Loss: 0.053775
#   Epoch 90/100, Loss: 0.055075
#   Epoch 100/100, Loss: 0.056926
# Training complete for run 20
# Run 20 — RMSE: 0.561226, MSE: 0.314975, NMSE: 0.0027102661
#
# ===== RUN 21/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.073778
#   Epoch 20/100, Loss: 0.073057
#   Epoch 30/100, Loss: 0.072382
#   Epoch 40/100, Loss: 0.070889
#   Epoch 50/100, Loss: 0.068260
#   Epoch 60/100, Loss: 0.065416
#   Epoch 70/100, Loss: 0.063364
#   Epoch 80/100, Loss: 0.061297
#   Epoch 90/100, Loss: 0.058967
#   Epoch 100/100, Loss: 0.056492
# Training complete for run 21
# Run 21 — RMSE: 0.574074, MSE: 0.329561, NMSE: 0.0027159150
#
# ===== RUN 22/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.074353
#   Epoch 20/100, Loss: 0.067867
#   Epoch 30/100, Loss: 0.066051
#   Epoch 40/100, Loss: 0.063052
#   Epoch 50/100, Loss: 0.060737
#   Epoch 60/100, Loss: 0.058504
#   Epoch 70/100, Loss: 0.056712
#   Epoch 80/100, Loss: 0.055482
#   Epoch 90/100, Loss: 0.054283
#   Epoch 100/100, Loss: 0.053458
# Training complete for run 22
# Run 22 — RMSE: 0.556691, MSE: 0.309905, NMSE: 0.0027442504
#
# ===== RUN 23/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.074635
#   Epoch 20/100, Loss: 0.074506
#   Epoch 30/100, Loss: 0.073115
#   Epoch 40/100, Loss: 0.069915
#   Epoch 50/100, Loss: 0.067900
#   Epoch 60/100, Loss: 0.065471
#   Epoch 70/100, Loss: 0.063991
#   Epoch 80/100, Loss: 0.063032
#   Epoch 90/100, Loss: 0.058456
#   Epoch 100/100, Loss: 0.056392
# Training complete for run 23
# Run 23 — RMSE: 0.555237, MSE: 0.308288, NMSE: 0.0026737221
#
# ===== RUN 24/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.074711
#   Epoch 20/100, Loss: 0.074080
#   Epoch 30/100, Loss: 0.073628
#   Epoch 40/100, Loss: 0.071782
#   Epoch 50/100, Loss: 0.056275
#   Epoch 60/100, Loss: 0.055442
#   Epoch 70/100, Loss: 0.054513
#   Epoch 80/100, Loss: 0.054179
#   Epoch 90/100, Loss: 0.053884
#   Epoch 100/100, Loss: 0.053437
# Training complete for run 24
# Run 24 — RMSE: 0.528739, MSE: 0.279565, NMSE: 0.0024186231
#
# ===== RUN 25/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.071337
#   Epoch 20/100, Loss: 0.069631
#   Epoch 30/100, Loss: 0.067387
#   Epoch 40/100, Loss: 0.065874
#   Epoch 50/100, Loss: 0.064154
#   Epoch 60/100, Loss: 0.061804
#   Epoch 70/100, Loss: 0.059115
#   Epoch 80/100, Loss: 0.055250
#   Epoch 90/100, Loss: 0.053132
#   Epoch 100/100, Loss: 0.052336
# Training complete for run 25
# Run 25 — RMSE: 0.542102, MSE: 0.293874, NMSE: 0.0024983670
#
# ===== RUN 26/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.070229
#   Epoch 20/100, Loss: 0.066303
#   Epoch 30/100, Loss: 0.061852
#   Epoch 40/100, Loss: 0.060831
#   Epoch 50/100, Loss: 0.060816
#   Epoch 60/100, Loss: 0.060268
#   Epoch 70/100, Loss: 0.059162
#   Epoch 80/100, Loss: 0.057761
#   Epoch 90/100, Loss: 0.056414
#   Epoch 100/100, Loss: 0.055425
# Training complete for run 26
# Run 26 — RMSE: 0.555349, MSE: 0.308413, NMSE: 0.0027120131
#
# ===== RUN 27/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.073574
#   Epoch 20/100, Loss: 0.067265
#   Epoch 30/100, Loss: 0.061853
#   Epoch 40/100, Loss: 0.061909
#   Epoch 50/100, Loss: 0.061982
#   Epoch 60/100, Loss: 0.061836
#   Epoch 70/100, Loss: 0.061364
#   Epoch 80/100, Loss: 0.060711
#   Epoch 90/100, Loss: 0.060145
#   Epoch 100/100, Loss: 0.059719
# Training complete for run 27
# Run 27 — RMSE: 0.567679, MSE: 0.322259, NMSE: 0.0026812919
#
# ===== RUN 28/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.073377
#   Epoch 20/100, Loss: 0.072437
#   Epoch 30/100, Loss: 0.071770
#   Epoch 40/100, Loss: 0.071723
#   Epoch 50/100, Loss: 0.071738
#   Epoch 60/100, Loss: 0.071923
#   Epoch 70/100, Loss: 0.072306
#   Epoch 80/100, Loss: 0.073002
#   Epoch 90/100, Loss: 0.073344
#   Epoch 100/100, Loss: 0.072011
# Training complete for run 28
# Run 28 — RMSE: 0.608560, MSE: 0.370346, NMSE: 0.0027332030
#
# ===== RUN 29/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.072975
#   Epoch 20/100, Loss: 0.071077
#   Epoch 30/100, Loss: 0.061983
#   Epoch 40/100, Loss: 0.059943
#   Epoch 50/100, Loss: 0.057526
#   Epoch 60/100, Loss: 0.055503
#   Epoch 70/100, Loss: 0.054072
#   Epoch 80/100, Loss: 0.053262
#   Epoch 90/100, Loss: 0.052862
#   Epoch 100/100, Loss: 0.052680
# Training complete for run 29
# Run 29 — RMSE: 0.529417, MSE: 0.280283, NMSE: 0.0023753782
#
# ===== RUN 30/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.075424
#   Epoch 20/100, Loss: 0.073869
#   Epoch 30/100, Loss: 0.073554
#   Epoch 40/100, Loss: 0.073274
#   Epoch 50/100, Loss: 0.072560
#   Epoch 60/100, Loss: 0.070819
#   Epoch 70/100, Loss: 0.066683
#   Epoch 80/100, Loss: 0.065764
#   Epoch 90/100, Loss: 0.065519
#   Epoch 100/100, Loss: 0.064175
# Training complete for run 30
# Run 30 — RMSE: 0.574357, MSE: 0.329886, NMSE: 0.0027475565
#
# ===== RUN 31/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.068765
#   Epoch 20/100, Loss: 0.063330
#   Epoch 30/100, Loss: 0.061227
#   Epoch 40/100, Loss: 0.059396
#   Epoch 50/100, Loss: 0.056396
#   Epoch 60/100, Loss: 0.054813
#   Epoch 70/100, Loss: 0.053998
#   Epoch 80/100, Loss: 0.053355
#   Epoch 90/100, Loss: 0.052801
#   Epoch 100/100, Loss: 0.052322
# Training complete for run 31
# Run 31 — RMSE: 0.530929, MSE: 0.281886, NMSE: 0.0024840271
#
# ===== RUN 32/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.071820
#   Epoch 20/100, Loss: 0.072811
#   Epoch 30/100, Loss: 0.068869
#   Epoch 40/100, Loss: 0.064585
#   Epoch 50/100, Loss: 0.061789
#   Epoch 60/100, Loss: 0.060668
#   Epoch 70/100, Loss: 0.059837
#   Epoch 80/100, Loss: 0.059686
#   Epoch 90/100, Loss: 0.058915
#   Epoch 100/100, Loss: 0.058062
# Training complete for run 32
# Run 32 — RMSE: 0.570921, MSE: 0.325951, NMSE: 0.0026370357
#
# ===== RUN 33/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.072888
#   Epoch 20/100, Loss: 0.069386
#   Epoch 30/100, Loss: 0.066977
#   Epoch 40/100, Loss: 0.062671
#   Epoch 50/100, Loss: 0.059072
#   Epoch 60/100, Loss: 0.055666
#   Epoch 70/100, Loss: 0.053027
#   Epoch 80/100, Loss: 0.051530
#   Epoch 90/100, Loss: 0.050887
#   Epoch 100/100, Loss: 0.050633
# Training complete for run 33
# Run 33 — RMSE: 0.536281, MSE: 0.287597, NMSE: 0.0024343531
#
# ===== RUN 34/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.073279
#   Epoch 20/100, Loss: 0.072452
#   Epoch 30/100, Loss: 0.068835
#   Epoch 40/100, Loss: 0.059244
#   Epoch 50/100, Loss: 0.056321
#   Epoch 60/100, Loss: 0.055798
#   Epoch 70/100, Loss: 0.056180
#   Epoch 80/100, Loss: 0.061639
#   Epoch 90/100, Loss: 0.063524
#   Epoch 100/100, Loss: 0.063566
# Training complete for run 34
# Run 34 — RMSE: 0.591432, MSE: 0.349792, NMSE: 0.0028070610
#
# ===== RUN 35/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.063748
#   Epoch 20/100, Loss: 0.066048
#   Epoch 30/100, Loss: 0.073440
#   Epoch 40/100, Loss: 0.070715
#   Epoch 50/100, Loss: 0.071902
#   Epoch 60/100, Loss: 0.070614
#   Epoch 70/100, Loss: 0.068935
#   Epoch 80/100, Loss: 0.067537
#   Epoch 90/100, Loss: 0.066291
#   Epoch 100/100, Loss: 0.065104
# Training complete for run 35
# Run 35 — RMSE: 0.598048, MSE: 0.357661, NMSE: 0.0028625086
#
# ===== RUN 36/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.073867
#   Epoch 20/100, Loss: 0.072893
#   Epoch 30/100, Loss: 0.069248
#   Epoch 40/100, Loss: 0.055011
#   Epoch 50/100, Loss: 0.053651
#   Epoch 60/100, Loss: 0.052843
#   Epoch 70/100, Loss: 0.052710
#   Epoch 80/100, Loss: 0.052776
#   Epoch 90/100, Loss: 0.052777
#   Epoch 100/100, Loss: 0.052631
# Training complete for run 36
# Run 36 — RMSE: 0.538419, MSE: 0.289895, NMSE: 0.0025413715
#
# ===== RUN 37/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.073939
#   Epoch 20/100, Loss: 0.073657
#   Epoch 30/100, Loss: 0.073238
#   Epoch 40/100, Loss: 0.060532
#   Epoch 50/100, Loss: 0.058042
#   Epoch 60/100, Loss: 0.056466
#   Epoch 70/100, Loss: 0.056195
#   Epoch 80/100, Loss: 0.056317
#   Epoch 90/100, Loss: 0.054947
#   Epoch 100/100, Loss: 0.053789
# Training complete for run 37
# Run 37 — RMSE: 0.534595, MSE: 0.285792, NMSE: 0.0024276985
#
# ===== RUN 38/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.073172
#   Epoch 20/100, Loss: 0.067579
#   Epoch 30/100, Loss: 0.061639
#   Epoch 40/100, Loss: 0.058034
#   Epoch 50/100, Loss: 0.055071
#   Epoch 60/100, Loss: 0.053473
#   Epoch 70/100, Loss: 0.052803
#   Epoch 80/100, Loss: 0.052478
#   Epoch 90/100, Loss: 0.052294
#   Epoch 100/100, Loss: 0.052199
# Training complete for run 38
# Run 38 — RMSE: 0.535855, MSE: 0.287141, NMSE: 0.0025119674
#
# ===== RUN 39/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.068766
#   Epoch 20/100, Loss: 0.066432
#   Epoch 30/100, Loss: 0.063038
#   Epoch 40/100, Loss: 0.060265
#   Epoch 50/100, Loss: 0.058402
#   Epoch 60/100, Loss: 0.057042
#   Epoch 70/100, Loss: 0.056660
#   Epoch 80/100, Loss: 0.056023
#   Epoch 90/100, Loss: 0.055150
#   Epoch 100/100, Loss: 0.054397
# Training complete for run 39
# Run 39 — RMSE: 0.556753, MSE: 0.309974, NMSE: 0.0027708238
#
# ===== RUN 40/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.070702
#   Epoch 20/100, Loss: 0.069715
#   Epoch 30/100, Loss: 0.068565
#   Epoch 40/100, Loss: 0.060326
#   Epoch 50/100, Loss: 0.055140
#   Epoch 60/100, Loss: 0.054383
#   Epoch 70/100, Loss: 0.053840
#   Epoch 80/100, Loss: 0.054493
#   Epoch 90/100, Loss: 0.060651
#   Epoch 100/100, Loss: 0.057717
# Training complete for run 40
# Run 40 — RMSE: 0.570175, MSE: 0.325100, NMSE: 0.0028820891
#
# ===== RUN 41/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.072902
#   Epoch 20/100, Loss: 0.071075
#   Epoch 30/100, Loss: 0.064793
#   Epoch 40/100, Loss: 0.057730
#   Epoch 50/100, Loss: 0.056072
#   Epoch 60/100, Loss: 0.055883
#   Epoch 70/100, Loss: 0.056292
#   Epoch 80/100, Loss: 0.056264
#   Epoch 90/100, Loss: 0.055687
#   Epoch 100/100, Loss: 0.054873
# Training complete for run 41
# Run 41 — RMSE: 0.533759, MSE: 0.284899, NMSE: 0.0024989351
#
# ===== RUN 42/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.062154
#   Epoch 20/100, Loss: 0.057162
#   Epoch 30/100, Loss: 0.054289
#   Epoch 40/100, Loss: 0.052502
#   Epoch 50/100, Loss: 0.051573
#   Epoch 60/100, Loss: 0.051095
#   Epoch 70/100, Loss: 0.050895
#   Epoch 80/100, Loss: 0.050941
#   Epoch 90/100, Loss: 0.051173
#   Epoch 100/100, Loss: 0.051514
# Training complete for run 42
# Run 42 — RMSE: 0.533462, MSE: 0.284582, NMSE: 0.0024873272
#
# ===== RUN 43/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.072133
#   Epoch 20/100, Loss: 0.069510
#   Epoch 30/100, Loss: 0.066183
#   Epoch 40/100, Loss: 0.063252
#   Epoch 50/100, Loss: 0.059736
#   Epoch 60/100, Loss: 0.057312
#   Epoch 70/100, Loss: 0.055262
#   Epoch 80/100, Loss: 0.053303
#   Epoch 90/100, Loss: 0.051995
#   Epoch 100/100, Loss: 0.051165
# Training complete for run 43
# Run 43 — RMSE: 0.546294, MSE: 0.298437, NMSE: 0.0026011029
#
# ===== RUN 44/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.074087
#   Epoch 20/100, Loss: 0.070374
#   Epoch 30/100, Loss: 0.064388
#   Epoch 40/100, Loss: 0.064937
#   Epoch 50/100, Loss: 0.063502
#   Epoch 60/100, Loss: 0.061405
#   Epoch 70/100, Loss: 0.058049
#   Epoch 80/100, Loss: 0.055058
#   Epoch 90/100, Loss: 0.053958
#   Epoch 100/100, Loss: 0.053760
# Training complete for run 44
# Run 44 — RMSE: 0.544116, MSE: 0.296062, NMSE: 0.0025272075
#
# ===== RUN 45/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.072569
#   Epoch 20/100, Loss: 0.068778
#   Epoch 30/100, Loss: 0.067204
#   Epoch 40/100, Loss: 0.066758
#   Epoch 50/100, Loss: 0.066398
#   Epoch 60/100, Loss: 0.065873
#   Epoch 70/100, Loss: 0.063896
#   Epoch 80/100, Loss: 0.061700
#   Epoch 90/100, Loss: 0.059518
#   Epoch 100/100, Loss: 0.057282
# Training complete for run 45
# Run 45 — RMSE: 0.554728, MSE: 0.307723, NMSE: 0.0025390320
#
# ===== RUN 46/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.073146
#   Epoch 20/100, Loss: 0.071270
#   Epoch 30/100, Loss: 0.069733
#   Epoch 40/100, Loss: 0.067422
#   Epoch 50/100, Loss: 0.065224
#   Epoch 60/100, Loss: 0.063335
#   Epoch 70/100, Loss: 0.061515
#   Epoch 80/100, Loss: 0.059671
#   Epoch 90/100, Loss: 0.057688
#   Epoch 100/100, Loss: 0.056143
# Training complete for run 46
# Run 46 — RMSE: 0.561767, MSE: 0.315583, NMSE: 0.0028001519
#
# ===== RUN 47/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.073915
#   Epoch 20/100, Loss: 0.073886
#   Epoch 30/100, Loss: 0.073435
#   Epoch 40/100, Loss: 0.072730
#   Epoch 50/100, Loss: 0.071568
#   Epoch 60/100, Loss: 0.070019
#   Epoch 70/100, Loss: 0.067707
#   Epoch 80/100, Loss: 0.063274
#   Epoch 90/100, Loss: 0.058302
#   Epoch 100/100, Loss: 0.055104
# Training complete for run 47
# Run 47 — RMSE: 0.564742, MSE: 0.318934, NMSE: 0.0027492695
#
# ===== RUN 48/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.069243
#   Epoch 20/100, Loss: 0.066740
#   Epoch 30/100, Loss: 0.061606
#   Epoch 40/100, Loss: 0.058044
#   Epoch 50/100, Loss: 0.056069
#   Epoch 60/100, Loss: 0.054946
#   Epoch 70/100, Loss: 0.054293
#   Epoch 80/100, Loss: 0.053741
#   Epoch 90/100, Loss: 0.053287
#   Epoch 100/100, Loss: 0.052936
# Training complete for run 48
# Run 48 — RMSE: 0.548359, MSE: 0.300697, NMSE: 0.0025997894
#
# ===== RUN 49/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.071558
#   Epoch 20/100, Loss: 0.072990
#   Epoch 30/100, Loss: 0.072847
#   Epoch 40/100, Loss: 0.072892
#   Epoch 50/100, Loss: 0.072438
#   Epoch 60/100, Loss: 0.071178
#   Epoch 70/100, Loss: 0.069597
#   Epoch 80/100, Loss: 0.068551
#   Epoch 90/100, Loss: 0.068336
#   Epoch 100/100, Loss: 0.158930
# Training complete for run 49
# Run 49 — RMSE: 1.469821, MSE: 2.160374, NMSE: 0.0090889323
#
# ===== RUN 50/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.059922
#   Epoch 20/100, Loss: 0.058609
#   Epoch 30/100, Loss: 0.057451
#   Epoch 40/100, Loss: 0.056578
#   Epoch 50/100, Loss: 0.055429
#   Epoch 60/100, Loss: 0.054092
#   Epoch 70/100, Loss: 0.053093
#   Epoch 80/100, Loss: 0.052532
#   Epoch 90/100, Loss: 0.052217
#   Epoch 100/100, Loss: 0.051997
# Training complete for run 50
# Run 50 — RMSE: 0.529962, MSE: 0.280859, NMSE: 0.0023502306
#
# ===== RUN 51/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.072711
#   Epoch 20/100, Loss: 0.072204
#   Epoch 30/100, Loss: 0.071728
#   Epoch 40/100, Loss: 0.066801
#   Epoch 50/100, Loss: 0.058722
#   Epoch 60/100, Loss: 0.055348
#   Epoch 70/100, Loss: 0.054517
#   Epoch 80/100, Loss: 0.054037
#   Epoch 90/100, Loss: 0.054698
#   Epoch 100/100, Loss: 0.056488
# Training complete for run 51
# Run 51 — RMSE: 0.538572, MSE: 0.290060, NMSE: 0.0025818731
#
# ===== RUN 52/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.071584
#   Epoch 20/100, Loss: 0.066584
#   Epoch 30/100, Loss: 0.066119
#   Epoch 40/100, Loss: 0.063143
#   Epoch 50/100, Loss: 0.062528
#   Epoch 60/100, Loss: 0.066020
#   Epoch 70/100, Loss: 0.066210
#   Epoch 80/100, Loss: 0.065022
#   Epoch 90/100, Loss: 0.064056
#   Epoch 100/100, Loss: 0.063170
# Training complete for run 52
# Run 52 — RMSE: 0.578028, MSE: 0.334117, NMSE: 0.0027171349
#
# ===== RUN 53/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.073193
#   Epoch 20/100, Loss: 0.073867
#   Epoch 30/100, Loss: 0.073589
#   Epoch 40/100, Loss: 0.072319
#   Epoch 50/100, Loss: 0.066790
#   Epoch 60/100, Loss: 0.061531
#   Epoch 70/100, Loss: 0.059012
#   Epoch 80/100, Loss: 0.055037
#   Epoch 90/100, Loss: 0.052752
#   Epoch 100/100, Loss: 0.052003
# Training complete for run 53
# Run 53 — RMSE: 0.535991, MSE: 0.287286, NMSE: 0.0025207916
#
# ===== RUN 54/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.063632
#   Epoch 20/100, Loss: 0.059180
#   Epoch 30/100, Loss: 0.057413
#   Epoch 40/100, Loss: 0.055929
#   Epoch 50/100, Loss: 0.054708
#   Epoch 60/100, Loss: 0.053314
#   Epoch 70/100, Loss: 0.051561
#   Epoch 80/100, Loss: 0.050465
#   Epoch 90/100, Loss: 0.049923
#   Epoch 100/100, Loss: 0.049498
# Training complete for run 54
# Run 54 — RMSE: 0.531318, MSE: 0.282298, NMSE: 0.0023108047
#
# ===== RUN 55/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.065240
#   Epoch 20/100, Loss: 0.060308
#   Epoch 30/100, Loss: 0.059825
#   Epoch 40/100, Loss: 0.059436
#   Epoch 50/100, Loss: 0.058875
#   Epoch 60/100, Loss: 0.058278
#   Epoch 70/100, Loss: 0.057703
#   Epoch 80/100, Loss: 0.057118
#   Epoch 90/100, Loss: 0.056608
#   Epoch 100/100, Loss: 0.056383
# Training complete for run 55
# Run 55 — RMSE: 0.547853, MSE: 0.300143, NMSE: 0.0024916770
#
# ===== RUN 56/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.058498
#   Epoch 20/100, Loss: 0.052155
#   Epoch 30/100, Loss: 0.052361
#   Epoch 40/100, Loss: 0.055345
#   Epoch 50/100, Loss: 0.057319
#   Epoch 60/100, Loss: 0.058081
#   Epoch 70/100, Loss: 0.058823
#   Epoch 80/100, Loss: 0.059597
#   Epoch 90/100, Loss: 0.058174
#   Epoch 100/100, Loss: 0.055565
# Training complete for run 56
# Run 56 — RMSE: 0.546576, MSE: 0.298746, NMSE: 0.0024585979
#
# ===== RUN 57/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.072983
#   Epoch 20/100, Loss: 0.068318
#   Epoch 30/100, Loss: 0.063539
#   Epoch 40/100, Loss: 0.060239
#   Epoch 50/100, Loss: 0.057551
#   Epoch 60/100, Loss: 0.055624
#   Epoch 70/100, Loss: 0.054439
#   Epoch 80/100, Loss: 0.053655
#   Epoch 90/100, Loss: 0.053152
#   Epoch 100/100, Loss: 0.052838
# Training complete for run 57
# Run 57 — RMSE: 0.545622, MSE: 0.297703, NMSE: 0.0026137268
#
# ===== RUN 58/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.069312
#   Epoch 20/100, Loss: 0.064757
#   Epoch 30/100, Loss: 0.059148
#   Epoch 40/100, Loss: 0.057085
#   Epoch 50/100, Loss: 0.053873
#   Epoch 60/100, Loss: 0.052388
#   Epoch 70/100, Loss: 0.051827
#   Epoch 80/100, Loss: 0.051569
#   Epoch 90/100, Loss: 0.051376
#   Epoch 100/100, Loss: 0.051187
# Training complete for run 58
# Run 58 — RMSE: 0.537811, MSE: 0.289241, NMSE: 0.0023956476
#
# ===== RUN 59/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.068670
#   Epoch 20/100, Loss: 0.066923
#   Epoch 30/100, Loss: 0.066170
#   Epoch 40/100, Loss: 0.065995
#   Epoch 50/100, Loss: 0.065298
#   Epoch 60/100, Loss: 0.064413
#   Epoch 70/100, Loss: 0.063494
#   Epoch 80/100, Loss: 0.062546
#   Epoch 90/100, Loss: 0.061367
#   Epoch 100/100, Loss: 0.058444
# Training complete for run 59
# Run 59 — RMSE: 0.567981, MSE: 0.322603, NMSE: 0.0027130887
#
# ===== RUN 60/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.069405
#   Epoch 20/100, Loss: 0.069519
#   Epoch 30/100, Loss: 0.067595
#   Epoch 40/100, Loss: 0.064504
#   Epoch 50/100, Loss: 0.062858
#   Epoch 60/100, Loss: 0.061222
#   Epoch 70/100, Loss: 0.059069
#   Epoch 80/100, Loss: 0.057974
#   Epoch 90/100, Loss: 0.057464
#   Epoch 100/100, Loss: 0.057143
# Training complete for run 60
# Run 60 — RMSE: 0.553104, MSE: 0.305924, NMSE: 0.0026048637
#
# ===== STATS FOR NOISE 10.0% (60 runs) =====
# RMSE: 0.572341 +/- 0.118874
# MSE:  0.341705 +/- 0.238058
# NMSE: 0.0027368548 +/- 0.0008411249
# Best run: 11 (RMSE: 0.525992)

# %% [markdown]
# ## Results

# %%
# ============================================================
# Final Metrics Summary & Plots per Noise Level
# ============================================================
from tabulate import tabulate

for entry in _molab_results:
    lam = entry[0]
    mean_rmse, std_rmse = entry[1], entry[2]
    mean_mse, std_mse = entry[3], entry[4]
    mean_nmse, std_nmse = entry[5], entry[6]
    best_rmse_val = entry[7]
    best_predictions = entry[8]
    best_losses = entry[9]
    raw_values_for_plot = entry[10]
    
    print("\n" + "="*80)
    print(f"RESULTS FOR NOISE LEVEL: {lam*100:.1f}%")
    print("="*80)
    
    print(f'Mean RMSE: {mean_rmse:.6f} +/- {std_rmse:.6f}')
    print(f'Mean MSE:  {mean_mse:.6f} +/- {std_mse:.6f}')
    print(f'Mean NMSE: {mean_nmse:.10f} +/- {std_nmse:.10f}')
    print(f'Best RMSE: {best_rmse_val:.6f}')
    
    actual = raw_values_for_plot[-60:]
    
    plt.figure(figsize=(12, 5))
    plt.plot(actual, label='Actual', color='blue', linewidth=1.5)
    plt.plot(best_predictions, label='Predicted (Best Run)', color='red',
             linewidth=1.5, linestyle='--')
    plt.title(f'Predictions vs Actual (Noise {lam*100:.1f}%)')
    plt.xlabel('Time Step')
    plt.ylabel('Value')
    plt.legend()
    plt.grid(True, alpha=0.3)
    plt.tight_layout()
    plt.show()

    plt.figure(figsize=(12, 4))
    plt.plot(best_losses, color='green', linewidth=1.0)
    plt.title(f'Training Loss (Best Run, Noise {lam*100:.1f}%)')
    plt.xlabel('Epoch')
    plt.ylabel('MSE Loss')
    plt.grid(True, alpha=0.3)
    plt.tight_layout()
    plt.show()

print("\n" + "="*80)
print("FINAL RESULTS TABLE ACROSS ALL NOISE LEVELS")
print("="*80)
df_res = pd.DataFrame(
    [[r[0], f'{r[1]:.6f} +/- {r[2]:.6f}', f'{r[3]:.6f} +/- {r[4]:.6f}', 
      f'{r[5]:.10f} +/- {r[6]:.10f}', f'{r[7]:.6f}'] for r in _molab_results],
    columns=['Noise Level', 'RMSE (mean+/-std)', 'MSE (mean+/-std)', 'NMSE (mean+/-std)', 'Best RMSE']
)
print(tabulate(df_res, headers='keys', tablefmt='github', showindex=False))
# Out:
# ================================================================================
# RESULTS FOR NOISE LEVEL: 5.0%
# ================================================================================
# Mean RMSE: 0.526155 +/- 0.361732
# Mean MSE:  0.407689 +/- 1.364767
# Mean NMSE: 0.0021675334 +/- 0.0016105326
# Best RMSE: 0.447513
# ================================================================================
# RESULTS FOR NOISE LEVEL: 10.0%
# ================================================================================
# Mean RMSE: 0.572341 +/- 0.118874
# Mean MSE:  0.341705 +/- 0.238058
# Mean NMSE: 0.0027368548 +/- 0.0008411249
# Best RMSE: 0.525992
# ================================================================================
# FINAL RESULTS TABLE ACROSS ALL NOISE LEVELS
# ================================================================================
# |   Noise Level | RMSE (mean+/-std)     | MSE (mean+/-std)      | NMSE (mean+/-std)             |   Best RMSE |
# |---------------|-----------------------|-----------------------|-------------------------------|-------------|
# |          0.05 | 0.526155 +/- 0.361732 | 0.407689 +/- 1.364767 | 0.0021675334 +/- 0.0016105326 |    0.447513 |
# |          0.1  | 0.572341 +/- 0.118874 | 0.341705 +/- 0.238058 | 0.0027368548 +/- 0.0008411249 |    0.525992 |
