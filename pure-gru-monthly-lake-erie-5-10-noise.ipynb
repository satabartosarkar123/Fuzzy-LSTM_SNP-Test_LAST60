# %% [markdown]
# # Pure GRU — Monthly Lake Erie Levels (Gaussian Noise Evaluation)
#
# Time series forecasting with Gaussian noise robustness analysis.
# - Noise levels: [0.05, 0.1]
# - 60 runs × 100 epochs per noise level
# - Last 60 for test, rest for training, NO validation

# %%
# ============================================================
# ALL IMPORTS
# ============================================================

import numpy as np
import pandas as pd
import torch
import torch.nn as nn
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from math import sqrt
import matplotlib.pyplot as plt
import warnings
import os

warnings.filterwarnings('ignore')
print(f"PyTorch version: {torch.__version__}")
print(f"NumPy version: {np.__version__}")
# Out:
# PyTorch version: 2.10.0+cu128
# NumPy version: 2.0.2

# %%
# ============================================================
# Pure GRU — Gated Recurrent Unit (Stateful)
# ============================================================
# Cho et al. (2014) GRU.
# Maintained hidden state across sequence steps to match LSTM-SNP.

import torch
import torch.nn as nn

class PureGRU(nn.Module):
    def __init__(self, input_dim=1, hidden_dim=8, output_dim=1):
        super().__init__()
        self.hidden_dim = hidden_dim
        self.gru = nn.GRU(input_dim, hidden_dim, batch_first=True)
        self.fc = nn.Linear(hidden_dim, output_dim)
        self.u = None  # Internal state matching LSTM-SNP interface

    def reset_states(self, batch_size, device):
        self.u = torch.zeros(1, batch_size, self.hidden_dim, device=device)

    def detach_states(self):
        if self.u is not None:
            self.u = self.u.detach()

    def forward(self, x):
        if self.u is None or self.u.device != x.device:
            self.reset_states(x.size(0), x.device)
            
        gru_out, self.u = self.gru(x, self.u)
        out = self.fc(gru_out[:, -1, :])
        return out

def build_model(input_dim=1, units=8):
    return PureGRU(input_dim=input_dim, hidden_dim=units, output_dim=1)

# Quick architecture check
model = build_model(input_dim=1, units=8)
print(model)
print(f"Total params: {sum(p.numel() for p in model.parameters())}")
# Out:
# PureGRU(
#   (gru): GRU(1, 8, batch_first=True)
#   (fc): Linear(in_features=8, out_features=1, bias=True)
# )
# Total params: 273

# %%
# Quick model check
model = build_model(input_dim=1, units=8)
print(model)
print(f"Total params: {sum(p.numel() for p in model.parameters())}")
# Out:
# PureGRU(
#   (gru): GRU(1, 8, batch_first=True)
#   (fc): Linear(in_features=8, out_features=1, bias=True)
# )
# Total params: 273

# %% [markdown]
# ## Data Pipeline — Monthly Lake Erie Levels

# %%
import os
for f in os.listdir('/kaggle/input/datasets/satabartosarkar123/monthly-lake-erie-levels-1921-19-csv'):
    print(f)
# Out:
# monthly-lake-erie-levels-1921-19.csv

# %%
# ============================================================
# 1. Load Time Series Data
# ============================================================
series = pd.read_csv(
    '/kaggle/input/datasets/satabartosarkar123/monthly-lake-erie-levels-1921-19-csv/monthly-lake-erie-levels-1921-19.csv',
    header=0,
    parse_dates=[0],
    index_col=0
)

original_raw_values = series.values.flatten()
print(f"Base data shape: {original_raw_values.shape}")
print(f"First 5 values: {original_raw_values[:5]}")
# Out:
# Base data shape: (600,)
# First 5 values: [14.763 14.649 15.085 16.376 16.926]

# %%
# ============================================================
# 2. First-Order Differencing
# ============================================================

def difference(dataset, interval=1):
    diff = []
    for i in range(interval, len(dataset)):
        value = dataset[i] - dataset[i - interval]
        diff.append(value)
    return np.array(diff)

# %%
# ============================================================
# 3. Convert to Supervised Learning Format (lag=1)
# ============================================================

def timeseries_to_supervised(data, lag=1):
    df = pd.DataFrame(data)
    columns = [df.shift(i) for i in range(1, lag+1)]
    columns.append(df)
    df = pd.concat(columns, axis=1)
    df.fillna(0, inplace=True)
    return df.values

# %% [markdown]
# ## Training Loop

# %%
# ============================================================
# Gaussian Noise Evaluation + 60-Run Experiment Protocol (PyTorch)
# ============================================================
import torch
import torch.nn as nn

s_x = np.std(original_raw_values)
noise_levels = [0.05, 0.1]
_molab_results = []

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"\n--- [PyTorch] RUNNING ON {device} ---\n")

for lam in noise_levels:
    sigma = lam * s_x
    print("\n" + "="*80)
    print(f"EVALUATING NOISE LEVEL: {lam*100:.1f}% (lambda={lam}, sigma={sigma:.6f})")
    print("="*80 + "\n")
    
    np.random.seed(42)
    torch.manual_seed(42)
    noise = np.random.normal(0, sigma, size=original_raw_values.shape)
    raw_values = original_raw_values + noise
    
    # 2. Difference
    diff_values = difference(raw_values, 1)
    # 3. Supervised (lag=1)
    supervised = timeseries_to_supervised(diff_values, 1)
    # 4. Split (Last 60 for test, NO validation)
    train, test = supervised[:-60], supervised[-60:]
    # 5. Scale
    scaler = MinMaxScaler(feature_range=(-1, 1))
    scaler.fit(train)
    train_scaled = scaler.transform(train)
    test_scaled = scaler.transform(test)
    # 6. Reshape
    X_train, y_train = train_scaled[:, 0:-1], train_scaled[:, -1]
    X_train = X_train.reshape((X_train.shape[0], 1, X_train.shape[1]))
    
    print(f"X_train shape: {X_train.shape}, y_train shape: {y_train.shape}")
    
    all_rmse = []
    all_mse = []
    all_nmse = []
    all_predictions = []
    all_losses = []
    
    for run in range(60):
        print(f'\n===== RUN {run+1}/60 [Noise {lam*100:.1f}%] =====')
        
        np.random.seed(run)
        torch.manual_seed(run)
        
        model = build_model(input_dim=1, units=8).to(device)
        optimizer = torch.optim.Adam(model.parameters(), lr=0.001)
        criterion = nn.MSELoss()
        
        # Pre-tensorize training data
        X_train_t = torch.tensor(X_train, dtype=torch.float32).to(device)
        y_train_t = torch.tensor(y_train, dtype=torch.float32).to(device)
        n_samples = X_train_t.size(0)
        
        run_losses = []
        for epoch in range(100):
            model.train()
            model.reset_states(1, device)
            
            epoch_loss = 0.0
            for i in range(n_samples):
                x_i = X_train_t[i:i+1]
                y_i = y_train_t[i:i+1]
                
                optimizer.zero_grad()
                pred = model(x_i)
                loss = criterion(pred.squeeze(-1), y_i)
                loss.backward()
                optimizer.step()
                model.detach_states()
                epoch_loss += loss.item()
            
            avg_loss = epoch_loss / n_samples
            run_losses.append(avg_loss)
            if (epoch+1) % 10 == 0:
                print(f"  Epoch {epoch+1}/100, Loss: {avg_loss:.6f}")
        
        all_losses.append(run_losses)
        print(f'Training complete for run {run+1}')
        
        # Warm-up: condition hidden states on training data
        model.eval()
        with torch.no_grad():
            model.reset_states(1, device)
            for i in range(len(train_scaled)):
                X_raw = train_scaled[i, 0:-1]
                X_input = torch.tensor(X_raw, dtype=torch.float32).view(1, 1, len(X_raw)).to(device)
                model(X_input)
        
        # Test predictions (single-step)
        predictions = []
        model.eval()
        with torch.no_grad():
            for i in range(len(test_scaled)):
                X = test_scaled[i, 0:-1]
                X_input = torch.tensor(X, dtype=torch.float32).view(1, 1, len(X)).to(device)
                yhat = model(X_input).item()
                
                # Invert scaling
                new_row = list(X) + [yhat]
                array = np.array(new_row).reshape(1, len(new_row))
                inverted = scaler.inverse_transform(array)[0, -1]
                
                # Invert differencing
                inverted = inverted + raw_values[len(train) + i]
                predictions.append(inverted)
        
        # Compute metrics
        actual = raw_values[-len(predictions):]
        rmse = sqrt(mean_squared_error(actual, predictions))
        mse = mean_squared_error(actual, predictions)
        meanV = np.mean(actual)
        dominator = np.linalg.norm(np.array(predictions) - meanV, 2)
        nmse = mse / np.power(dominator, 2)
        
        all_rmse.append(rmse)
        all_mse.append(mse)
        all_nmse.append(nmse)
        all_predictions.append(predictions)
        
        print(f'Run {run+1} \u2014 RMSE: {rmse:.6f}, MSE: {mse:.6f}, NMSE: {nmse:.10f}')
    
    # End of 60 runs for this noise level
    best_idx = np.argmin(all_rmse)
    
    print(f'\n===== STATS FOR NOISE {lam*100:.1f}% (60 runs) =====')
    print(f'RMSE: {np.mean(all_rmse):.6f} +/- {np.std(all_rmse):.6f}')
    print(f'MSE:  {np.mean(all_mse):.6f} +/- {np.std(all_mse):.6f}')
    print(f'NMSE: {np.mean(all_nmse):.10f} +/- {np.std(all_nmse):.10f}')
    print(f'Best run: {best_idx+1} (RMSE: {all_rmse[best_idx]:.6f})')
    
    _molab_results.append([lam, 
        np.mean(all_rmse), np.std(all_rmse),
        np.mean(all_mse), np.std(all_mse),
        np.mean(all_nmse), np.std(all_nmse),
        all_rmse[best_idx], all_predictions[best_idx], all_losses[best_idx], raw_values.copy()])
# Out:
# --- [PyTorch] RUNNING ON cuda ---
#
#
# ================================================================================
# EVALUATING NOISE LEVEL: 5.0% (lambda=0.05, sigma=0.100521)
# ================================================================================
#
# X_train shape: (539, 1, 1), y_train shape: (539,)
#
# ===== RUN 1/60 [Noise 5.0%] =====
#   Epoch 10/100, Loss: 0.059096
#   Epoch 20/100, Loss: 0.060435
#   Epoch 30/100, Loss: 0.059907
#   Epoch 40/100, Loss: 0.058638
#   Epoch 50/100, Loss: 0.058556
#   Epoch 60/100, Loss: 0.058792
#   Epoch 70/100, Loss: 0.058687
#   Epoch 80/100, Loss: 0.058006
#   Epoch 90/100, Loss: 0.056999
#   Epoch 100/100, Loss: 0.056343
# Training complete for run 1
# Run 1 — RMSE: 0.488442, MSE: 0.238575, NMSE: 0.0019203323
#
# ===== RUN 2/60 [Noise 5.0%] =====
#   Epoch 10/100, Loss: 0.064460
#   Epoch 20/100, Loss: 0.063163
#   Epoch 30/100, Loss: 0.060555
#   Epoch 40/100, Loss: 0.058295
#   Epoch 50/100, Loss: 0.056594
#   Epoch 60/100, Loss: 0.054912
#   Epoch 70/100, Loss: 0.053776
#   Epoch 80/100, Loss: 0.053268
#   Epoch 90/100, Loss: 0.053261
#   Epoch 100/100, Loss: 0.053659
# Training complete for run 2
# Run 2 — RMSE: 0.481826, MSE: 0.232156, NMSE: 0.0019382279
#
# ===== RUN 3/60 [Noise 5.0%] =====
#   Epoch 10/100, Loss: 0.059581
#   Epoch 20/100, Loss: 0.059747
#   Epoch 30/100, Loss: 0.060167
#   Epoch 40/100, Loss: 0.060268
#   Epoch 50/100, Loss: 0.059830
#   Epoch 60/100, Loss: 0.058809
#   Epoch 70/100, Loss: 0.057377
#   Epoch 80/100, Loss: 0.056825
#   Epoch 90/100, Loss: 0.056645
#   Epoch 100/100, Loss: 0.056298
# Training complete for run 3
# Run 3 — RMSE: 0.487271, MSE: 0.237433, NMSE: 0.0019812525
#
# ===== RUN 4/60 [Noise 5.0%] =====
#   Epoch 10/100, Loss: 0.058834
#   Epoch 20/100, Loss: 0.059555
#   Epoch 30/100, Loss: 0.059034
#   Epoch 40/100, Loss: 0.058046
#   Epoch 50/100, Loss: 0.057249
#   Epoch 60/100, Loss: 0.056616
#   Epoch 70/100, Loss: 0.055579
#   Epoch 80/100, Loss: 0.054510
#   Epoch 90/100, Loss: 0.053521
#   Epoch 100/100, Loss: 0.052964
# Training complete for run 4
# Run 4 — RMSE: 0.482796, MSE: 0.233092, NMSE: 0.0020155872
#
# ===== RUN 5/60 [Noise 5.0%] =====
#   Epoch 10/100, Loss: 0.062019
#   Epoch 20/100, Loss: 0.059944
#   Epoch 30/100, Loss: 0.060698
#   Epoch 40/100, Loss: 0.059873
#   Epoch 50/100, Loss: 0.058688
#   Epoch 60/100, Loss: 0.057866
#   Epoch 70/100, Loss: 0.057513
#   Epoch 80/100, Loss: 0.057214
#   Epoch 90/100, Loss: 0.056734
#   Epoch 100/100, Loss: 0.056070
# Training complete for run 5
# Run 5 — RMSE: 0.490316, MSE: 0.240410, NMSE: 0.0020358944
#
# ===== RUN 6/60 [Noise 5.0%] =====
#   Epoch 10/100, Loss: 0.060668
#   Epoch 20/100, Loss: 0.059497
#   Epoch 30/100, Loss: 0.058422
#   Epoch 40/100, Loss: 0.056864
#   Epoch 50/100, Loss: 0.055743
#   Epoch 60/100, Loss: 0.055144
#   Epoch 70/100, Loss: 0.054792
#   Epoch 80/100, Loss: 0.053985
#   Epoch 90/100, Loss: 0.053658
#   Epoch 100/100, Loss: 0.053508
# Training complete for run 6
# Run 6 — RMSE: 0.477972, MSE: 0.228458, NMSE: 0.0020000894
#
# ===== RUN 7/60 [Noise 5.0%] =====
#   Epoch 10/100, Loss: 0.064956
#   Epoch 20/100, Loss: 0.063417
#   Epoch 30/100, Loss: 0.060601
#   Epoch 40/100, Loss: 0.060018
#   Epoch 50/100, Loss: 0.059467
#   Epoch 60/100, Loss: 0.058959
#   Epoch 70/100, Loss: 0.058625
#   Epoch 80/100, Loss: 0.058433
#   Epoch 90/100, Loss: 0.058137
#   Epoch 100/100, Loss: 0.057713
# Training complete for run 7
# Run 7 — RMSE: 0.493107, MSE: 0.243155, NMSE: 0.0019830033
#
# ===== RUN 8/60 [Noise 5.0%] =====
#   Epoch 10/100, Loss: 0.063621
#   Epoch 20/100, Loss: 0.060030
#   Epoch 30/100, Loss: 0.058672
#   Epoch 40/100, Loss: 0.057590
#   Epoch 50/100, Loss: 0.057262
#   Epoch 60/100, Loss: 0.056787
#   Epoch 70/100, Loss: 0.056239
#   Epoch 80/100, Loss: 0.056040
#   Epoch 90/100, Loss: 0.055278
#   Epoch 100/100, Loss: 0.054900
# Training complete for run 8
# Run 8 — RMSE: 0.486014, MSE: 0.236210, NMSE: 0.0019505114
#
# ===== RUN 9/60 [Noise 5.0%] =====
#   Epoch 10/100, Loss: 0.064489
#   Epoch 20/100, Loss: 0.060693
#   Epoch 30/100, Loss: 0.059407
#   Epoch 40/100, Loss: 0.058208
#   Epoch 50/100, Loss: 0.057759
#   Epoch 60/100, Loss: 0.057994
#   Epoch 70/100, Loss: 0.058272
#   Epoch 80/100, Loss: 0.058156
#   Epoch 90/100, Loss: 0.057728
#   Epoch 100/100, Loss: 0.057213
# Training complete for run 9
# Run 9 — RMSE: 0.494094, MSE: 0.244129, NMSE: 0.0020326021
#
# ===== RUN 10/60 [Noise 5.0%] =====
#   Epoch 10/100, Loss: 0.063583
#   Epoch 20/100, Loss: 0.059786
#   Epoch 30/100, Loss: 0.057794
#   Epoch 40/100, Loss: 0.056437
#   Epoch 50/100, Loss: 0.055671
#   Epoch 60/100, Loss: 0.055313
#   Epoch 70/100, Loss: 0.055110
#   Epoch 80/100, Loss: 0.055137
#   Epoch 90/100, Loss: 0.055003
#   Epoch 100/100, Loss: 0.055107
# Training complete for run 10
# Run 10 — RMSE: 0.488520, MSE: 0.238652, NMSE: 0.0020399927
#
# ===== RUN 11/60 [Noise 5.0%] =====
#   Epoch 10/100, Loss: 0.062942
#   Epoch 20/100, Loss: 0.058136
#   Epoch 30/100, Loss: 0.057549
#   Epoch 40/100, Loss: 0.056980
#   Epoch 50/100, Loss: 0.056529
#   Epoch 60/100, Loss: 0.056304
#   Epoch 70/100, Loss: 0.056684
#   Epoch 80/100, Loss: 0.056935
#   Epoch 90/100, Loss: 0.057116
#   Epoch 100/100, Loss: 0.057390
# Training complete for run 11
# Run 11 — RMSE: 0.486172, MSE: 0.236363, NMSE: 0.0019409134
#
# ===== RUN 12/60 [Noise 5.0%] =====
#   Epoch 10/100, Loss: 0.063846
#   Epoch 20/100, Loss: 0.060302
#   Epoch 30/100, Loss: 0.059222
#   Epoch 40/100, Loss: 0.057504
#   Epoch 50/100, Loss: 0.056689
#   Epoch 60/100, Loss: 0.056569
#   Epoch 70/100, Loss: 0.056403
#   Epoch 80/100, Loss: 0.056186
#   Epoch 90/100, Loss: 0.056170
#   Epoch 100/100, Loss: 0.056082
# Training complete for run 12
# Run 12 — RMSE: 0.485924, MSE: 0.236122, NMSE: 0.0019793972
#
# ===== RUN 13/60 [Noise 5.0%] =====
#   Epoch 10/100, Loss: 0.054470
#   Epoch 20/100, Loss: 0.057059
#   Epoch 30/100, Loss: 0.058435
#   Epoch 40/100, Loss: 0.058545
#   Epoch 50/100, Loss: 0.058419
#   Epoch 60/100, Loss: 0.058231
#   Epoch 70/100, Loss: 0.058098
#   Epoch 80/100, Loss: 0.057932
#   Epoch 90/100, Loss: 0.057213
#   Epoch 100/100, Loss: 0.056531
# Training complete for run 13
# Run 13 — RMSE: 0.497425, MSE: 0.247432, NMSE: 0.0020902744
#
# ===== RUN 14/60 [Noise 5.0%] =====
#   Epoch 10/100, Loss: 0.062994
#   Epoch 20/100, Loss: 0.059489
#   Epoch 30/100, Loss: 0.058398
#   Epoch 40/100, Loss: 0.056847
#   Epoch 50/100, Loss: 0.056730
#   Epoch 60/100, Loss: 0.057003
#   Epoch 70/100, Loss: 0.056316
#   Epoch 80/100, Loss: 0.054821
#   Epoch 90/100, Loss: 0.052548
#   Epoch 100/100, Loss: 0.052485
# Training complete for run 14
# Run 14 — RMSE: 0.485341, MSE: 0.235556, NMSE: 0.0020314300
#
# ===== RUN 15/60 [Noise 5.0%] =====
#   Epoch 10/100, Loss: 0.058842
#   Epoch 20/100, Loss: 0.050376
#   Epoch 30/100, Loss: 0.050606
#   Epoch 40/100, Loss: 0.051817
#   Epoch 50/100, Loss: 0.051747
#   Epoch 60/100, Loss: 0.052184
#   Epoch 70/100, Loss: 0.051944
#   Epoch 80/100, Loss: 0.052552
#   Epoch 90/100, Loss: 0.052547
#   Epoch 100/100, Loss: 0.051459
# Training complete for run 15
# Run 15 — RMSE: 0.474553, MSE: 0.225200, NMSE: 0.0019090059
#
# ===== RUN 16/60 [Noise 5.0%] =====
#   Epoch 10/100, Loss: 0.064269
#   Epoch 20/100, Loss: 0.060912
#   Epoch 30/100, Loss: 0.060514
#   Epoch 40/100, Loss: 0.060723
#   Epoch 50/100, Loss: 0.060621
#   Epoch 60/100, Loss: 0.060324
#   Epoch 70/100, Loss: 0.059908
#   Epoch 80/100, Loss: 0.059490
#   Epoch 90/100, Loss: 0.059158
#   Epoch 100/100, Loss: 0.058889
# Training complete for run 16
# Run 16 — RMSE: 0.498031, MSE: 0.248035, NMSE: 0.0019747867
#
# ===== RUN 17/60 [Noise 5.0%] =====
#   Epoch 10/100, Loss: 0.056722
#   Epoch 20/100, Loss: 0.056976
#   Epoch 30/100, Loss: 0.057130
#   Epoch 40/100, Loss: 0.057057
#   Epoch 50/100, Loss: 0.056873
#   Epoch 60/100, Loss: 0.056756
#   Epoch 70/100, Loss: 0.056466
#   Epoch 80/100, Loss: 0.055846
#   Epoch 90/100, Loss: 0.054731
#   Epoch 100/100, Loss: 0.053161
# Training complete for run 17
# Run 17 — RMSE: 0.482138, MSE: 0.232458, NMSE: 0.0019803020
#
# ===== RUN 18/60 [Noise 5.0%] =====
#   Epoch 10/100, Loss: 0.063132
#   Epoch 20/100, Loss: 0.060762
#   Epoch 30/100, Loss: 0.059028
#   Epoch 40/100, Loss: 0.057809
#   Epoch 50/100, Loss: 0.057253
#   Epoch 60/100, Loss: 0.057001
#   Epoch 70/100, Loss: 0.056789
#   Epoch 80/100, Loss: 0.056570
#   Epoch 90/100, Loss: 0.056343
#   Epoch 100/100, Loss: 0.056104
# Training complete for run 18
# Run 18 — RMSE: 0.494266, MSE: 0.244299, NMSE: 0.0020585864
#
# ===== RUN 19/60 [Noise 5.0%] =====
#   Epoch 10/100, Loss: 0.065237
#   Epoch 20/100, Loss: 0.061793
#   Epoch 30/100, Loss: 0.061469
#   Epoch 40/100, Loss: 0.060381
#   Epoch 50/100, Loss: 0.059283
#   Epoch 60/100, Loss: 0.058727
#   Epoch 70/100, Loss: 0.058398
#   Epoch 80/100, Loss: 0.058042
#   Epoch 90/100, Loss: 0.057710
#   Epoch 100/100, Loss: 0.057297
# Training complete for run 19
# Run 19 — RMSE: 0.502605, MSE: 0.252612, NMSE: 0.0020931263
#
# ===== RUN 20/60 [Noise 5.0%] =====
#   Epoch 10/100, Loss: 0.063473
#   Epoch 20/100, Loss: 0.057094
#   Epoch 30/100, Loss: 0.057122
#   Epoch 40/100, Loss: 0.056842
#   Epoch 50/100, Loss: 0.056715
#   Epoch 60/100, Loss: 0.056527
#   Epoch 70/100, Loss: 0.055917
#   Epoch 80/100, Loss: 0.054833
#   Epoch 90/100, Loss: 0.053409
#   Epoch 100/100, Loss: 0.052100
# Training complete for run 20
# Run 20 — RMSE: 0.484049, MSE: 0.234304, NMSE: 0.0019900012
#
# ===== RUN 21/60 [Noise 5.0%] =====
#   Epoch 10/100, Loss: 0.064775
#   Epoch 20/100, Loss: 0.061409
#   Epoch 30/100, Loss: 0.059216
#   Epoch 40/100, Loss: 0.057886
#   Epoch 50/100, Loss: 0.057236
#   Epoch 60/100, Loss: 0.056976
#   Epoch 70/100, Loss: 0.056860
#   Epoch 80/100, Loss: 0.056821
#   Epoch 90/100, Loss: 0.056791
#   Epoch 100/100, Loss: 0.056680
# Training complete for run 21
# Run 21 — RMSE: 0.491112, MSE: 0.241191, NMSE: 0.0020449475
#
# ===== RUN 22/60 [Noise 5.0%] =====
#   Epoch 10/100, Loss: 0.060861
#   Epoch 20/100, Loss: 0.058942
#   Epoch 30/100, Loss: 0.058014
#   Epoch 40/100, Loss: 0.056789
#   Epoch 50/100, Loss: 0.056516
#   Epoch 60/100, Loss: 0.057117
#   Epoch 70/100, Loss: 0.057561
#   Epoch 80/100, Loss: 0.057661
#   Epoch 90/100, Loss: 0.057559
#   Epoch 100/100, Loss: 0.057549
# Training complete for run 22
# Run 22 — RMSE: 0.496874, MSE: 0.246884, NMSE: 0.0020482371
#
# ===== RUN 23/60 [Noise 5.0%] =====
#   Epoch 10/100, Loss: 0.064439
#   Epoch 20/100, Loss: 0.059833
#   Epoch 30/100, Loss: 0.059379
#   Epoch 40/100, Loss: 0.059013
#   Epoch 50/100, Loss: 0.058547
#   Epoch 60/100, Loss: 0.058182
#   Epoch 70/100, Loss: 0.057630
#   Epoch 80/100, Loss: 0.056982
#   Epoch 90/100, Loss: 0.056400
#   Epoch 100/100, Loss: 0.055685
# Training complete for run 23
# Run 23 — RMSE: 0.487866, MSE: 0.238013, NMSE: 0.0020038751
#
# ===== RUN 24/60 [Noise 5.0%] =====
#   Epoch 10/100, Loss: 0.061672
#   Epoch 20/100, Loss: 0.053941
#   Epoch 30/100, Loss: 0.054572
#   Epoch 40/100, Loss: 0.053578
#   Epoch 50/100, Loss: 0.053170
#   Epoch 60/100, Loss: 0.053446
#   Epoch 70/100, Loss: 0.053925
#   Epoch 80/100, Loss: 0.054149
#   Epoch 90/100, Loss: 0.053836
#   Epoch 100/100, Loss: 0.052794
# Training complete for run 24
# Run 24 — RMSE: 0.473390, MSE: 0.224098, NMSE: 0.0019309613
#
# ===== RUN 25/60 [Noise 5.0%] =====
#   Epoch 10/100, Loss: 0.064900
#   Epoch 20/100, Loss: 0.062718
#   Epoch 30/100, Loss: 0.059686
#   Epoch 40/100, Loss: 0.057870
#   Epoch 50/100, Loss: 0.056720
#   Epoch 60/100, Loss: 0.055920
#   Epoch 70/100, Loss: 0.055191
#   Epoch 80/100, Loss: 0.054516
#   Epoch 90/100, Loss: 0.053946
#   Epoch 100/100, Loss: 0.053747
# Training complete for run 25
# Run 25 — RMSE: 0.506859, MSE: 0.256906, NMSE: 0.0020930586
#
# ===== RUN 26/60 [Noise 5.0%] =====
#   Epoch 10/100, Loss: 0.064599
#   Epoch 20/100, Loss: 0.060295
#   Epoch 30/100, Loss: 0.059461
#   Epoch 40/100, Loss: 0.058849
#   Epoch 50/100, Loss: 0.058616
#   Epoch 60/100, Loss: 0.057734
#   Epoch 70/100, Loss: 0.056945
#   Epoch 80/100, Loss: 0.056581
#   Epoch 90/100, Loss: 0.056357
#   Epoch 100/100, Loss: 0.056182
# Training complete for run 26
# Run 26 — RMSE: 0.486360, MSE: 0.236546, NMSE: 0.0019880696
#
# ===== RUN 27/60 [Noise 5.0%] =====
#   Epoch 10/100, Loss: 0.063691
#   Epoch 20/100, Loss: 0.060335
#   Epoch 30/100, Loss: 0.059248
#   Epoch 40/100, Loss: 0.058314
#   Epoch 50/100, Loss: 0.057629
#   Epoch 60/100, Loss: 0.057272
#   Epoch 70/100, Loss: 0.057154
#   Epoch 80/100, Loss: 0.057171
#   Epoch 90/100, Loss: 0.057223
#   Epoch 100/100, Loss: 0.057251
# Training complete for run 27
# Run 27 — RMSE: 0.498934, MSE: 0.248935, NMSE: 0.0020762601
#
# ===== RUN 28/60 [Noise 5.0%] =====
#   Epoch 10/100, Loss: 0.064909
#   Epoch 20/100, Loss: 0.061648
#   Epoch 30/100, Loss: 0.061708
#   Epoch 40/100, Loss: 0.061080
#   Epoch 50/100, Loss: 0.060439
#   Epoch 60/100, Loss: 0.059851
#   Epoch 70/100, Loss: 0.059190
#   Epoch 80/100, Loss: 0.058568
#   Epoch 90/100, Loss: 0.058240
#   Epoch 100/100, Loss: 0.057895
# Training complete for run 28
# Run 28 — RMSE: 0.495174, MSE: 0.245197, NMSE: 0.0020218005
#
# ===== RUN 29/60 [Noise 5.0%] =====
#   Epoch 10/100, Loss: 0.060173
#   Epoch 20/100, Loss: 0.055787
#   Epoch 30/100, Loss: 0.054317
#   Epoch 40/100, Loss: 0.053964
#   Epoch 50/100, Loss: 0.054513
#   Epoch 60/100, Loss: 0.055145
#   Epoch 70/100, Loss: 0.055397
#   Epoch 80/100, Loss: 0.053402
#   Epoch 90/100, Loss: 0.053576
#   Epoch 100/100, Loss: 0.051959
# Training complete for run 29
# Run 29 — RMSE: 0.486401, MSE: 0.236586, NMSE: 0.0019723107
#
# ===== RUN 30/60 [Noise 5.0%] =====
#   Epoch 10/100, Loss: 0.064237
#   Epoch 20/100, Loss: 0.062221
#   Epoch 30/100, Loss: 0.060420
#   Epoch 40/100, Loss: 0.060133
#   Epoch 50/100, Loss: 0.059486
#   Epoch 60/100, Loss: 0.058859
#   Epoch 70/100, Loss: 0.058412
#   Epoch 80/100, Loss: 0.058373
#   Epoch 90/100, Loss: 0.057585
#   Epoch 100/100, Loss: 0.056811
# Training complete for run 30
# Run 30 — RMSE: 0.500307, MSE: 0.250308, NMSE: 0.0020920668
#
# ===== RUN 31/60 [Noise 5.0%] =====
#   Epoch 10/100, Loss: 0.064746
#   Epoch 20/100, Loss: 0.064810
#   Epoch 30/100, Loss: 0.065220
#   Epoch 40/100, Loss: 0.064812
#   Epoch 50/100, Loss: 0.063717
#   Epoch 60/100, Loss: 0.062629
#   Epoch 70/100, Loss: 0.061146
#   Epoch 80/100, Loss: 0.058974
#   Epoch 90/100, Loss: 0.057195
#   Epoch 100/100, Loss: 0.056855
# Training complete for run 31
# Run 31 — RMSE: 0.503737, MSE: 0.253751, NMSE: 0.0020305628
#
# ===== RUN 32/60 [Noise 5.0%] =====
#   Epoch 10/100, Loss: 0.058934
#   Epoch 20/100, Loss: 0.058369
#   Epoch 30/100, Loss: 0.058643
#   Epoch 40/100, Loss: 0.058560
#   Epoch 50/100, Loss: 0.058339
#   Epoch 60/100, Loss: 0.057395
#   Epoch 70/100, Loss: 0.056210
#   Epoch 80/100, Loss: 0.055047
#   Epoch 90/100, Loss: 0.055625
#   Epoch 100/100, Loss: 0.056195
# Training complete for run 32
# Run 32 — RMSE: 0.486751, MSE: 0.236926, NMSE: 0.0019724186
#
# ===== RUN 33/60 [Noise 5.0%] =====
#   Epoch 10/100, Loss: 0.066419
#   Epoch 20/100, Loss: 0.066006
#   Epoch 30/100, Loss: 0.065709
#   Epoch 60/100, Loss: 0.052502
#   Epoch 70/100, Loss: 0.051726
#   Epoch 80/100, Loss: 0.050980
#   Epoch 90/100, Loss: 0.050332
#   Epoch 100/100, Loss: 0.049830
# Training complete for run 34
# Run 34 — RMSE: 0.457654, MSE: 0.209447, NMSE: 0.0018451214
#
# ===== RUN 35/60 [Noise 5.0%] =====
#   Epoch 10/100, Loss: 0.064997
#   Epoch 20/100, Loss: 0.063829
#   Epoch 30/100, Loss: 0.064687
#   Epoch 40/100, Loss: 0.064917
#   Epoch 50/100, Loss: 0.063192
#   Epoch 60/100, Loss: 0.061736
#   Epoch 70/100, Loss: 0.060774
#   Epoch 80/100, Loss: 0.059926
#   Epoch 90/100, Loss: 0.059308
#   Epoch 100/100, Loss: 0.058901
# Training complete for run 35
# Run 35 — RMSE: 0.504353, MSE: 0.254372, NMSE: 0.0020620136
#
# ===== RUN 36/60 [Noise 5.0%] =====
#   Epoch 10/100, Loss: 0.065850
#   Epoch 20/100, Loss: 0.062046
#   Epoch 30/100, Loss: 0.060106
#   Epoch 40/100, Loss: 0.059426
#   Epoch 50/100, Loss: 0.058949
#   Epoch 60/100, Loss: 0.058457
#   Epoch 70/100, Loss: 0.058055
#   Epoch 80/100, Loss: 0.057911
#   Epoch 90/100, Loss: 0.057620
#   Epoch 100/100, Loss: 0.056601
# Training complete for run 36
# Run 36 — RMSE: 0.493747, MSE: 0.243787, NMSE: 0.0020056114
#
# ===== RUN 37/60 [Noise 5.0%] =====
#   Epoch 10/100, Loss: 0.064644
#   Epoch 20/100, Loss: 0.061210
#   Epoch 30/100, Loss: 0.059190
#   Epoch 40/100, Loss: 0.059050
#   Epoch 50/100, Loss: 0.058675
#   Epoch 60/100, Loss: 0.056537
#   Epoch 70/100, Loss: 0.055377
#   Epoch 80/100, Loss: 0.054767
#   Epoch 90/100, Loss: 0.054308
#   Epoch 100/100, Loss: 0.053743
# Training complete for run 37
# Run 37 — RMSE: 0.490895, MSE: 0.240978, NMSE: 0.0020686653
#
# ===== RUN 38/60 [Noise 5.0%] =====
#   Epoch 10/100, Loss: 0.062576
#   Epoch 20/100, Loss: 0.060335
#   Epoch 30/100, Loss: 0.059406
#   Epoch 40/100, Loss: 0.058510
#   Epoch 50/100, Loss: 0.058033
#   Epoch 60/100, Loss: 0.057646
#   Epoch 70/100, Loss: 0.057093
#   Epoch 80/100, Loss: 0.056874
#   Epoch 90/100, Loss: 0.056677
#   Epoch 100/100, Loss: 0.056252
# Training complete for run 38
# Run 38 — RMSE: 0.489081, MSE: 0.239200, NMSE: 0.0020060566
#
# ===== RUN 39/60 [Noise 5.0%] =====
#   Epoch 10/100, Loss: 0.063531
#   Epoch 20/100, Loss: 0.061744
#   Epoch 30/100, Loss: 0.060394
#   Epoch 40/100, Loss: 0.059991
#   Epoch 50/100, Loss: 0.059367
#   Epoch 60/100, Loss: 0.058810
#   Epoch 70/100, Loss: 0.058337
#   Epoch 80/100, Loss: 0.057990
#   Epoch 90/100, Loss: 0.057281
#   Epoch 100/100, Loss: 0.056543
# Training complete for run 39
# Run 39 — RMSE: 0.489537, MSE: 0.239646, NMSE: 0.0019896720
#
# ===== RUN 40/60 [Noise 5.0%] =====
#   Epoch 10/100, Loss: 0.055262
#   Epoch 20/100, Loss: 0.054953
#   Epoch 30/100, Loss: 0.054363
#   Epoch 40/100, Loss: 0.053839
#   Epoch 50/100, Loss: 0.053182
#   Epoch 60/100, Loss: 0.050834
#   Epoch 70/100, Loss: 0.050055
#   Epoch 80/100, Loss: 0.049543
#   Epoch 90/100, Loss: 0.049280
#   Epoch 100/100, Loss: 0.048806
# Training complete for run 40
# Run 40 — RMSE: 0.446039, MSE: 0.198951, NMSE: 0.0017504424
#
# ===== RUN 41/60 [Noise 5.0%] =====
#   Epoch 10/100, Loss: 0.062978
#   Epoch 20/100, Loss: 0.061065
#   Epoch 30/100, Loss: 0.061019
#   Epoch 40/100, Loss: 0.060553
#   Epoch 50/100, Loss: 0.059591
#   Epoch 60/100, Loss: 0.058661
#   Epoch 70/100, Loss: 0.058075
#   Epoch 80/100, Loss: 0.057691
#   Epoch 90/100, Loss: 0.057407
#   Epoch 100/100, Loss: 0.057124
# Training complete for run 41
# Run 41 — RMSE: 0.495439, MSE: 0.245460, NMSE: 0.0020430985
#
# ===== RUN 42/60 [Noise 5.0%] =====
#   Epoch 10/100, Loss: 0.065456
#   Epoch 20/100, Loss: 0.065285
#   Epoch 30/100, Loss: 0.064804
#   Epoch 40/100, Loss: 0.062950
#   Epoch 50/100, Loss: 0.059956
#   Epoch 60/100, Loss: 0.059706
#   Epoch 70/100, Loss: 0.059488
#   Epoch 80/100, Loss: 0.060226
#   Epoch 90/100, Loss: 0.060645
#   Epoch 100/100, Loss: 0.060465
# Training complete for run 42
# Run 42 — RMSE: 0.507054, MSE: 0.257104, NMSE: 0.0020248758
#
# ===== RUN 43/60 [Noise 5.0%] =====
#   Epoch 10/100, Loss: 0.065756
#   Epoch 20/100, Loss: 0.063775
#   Epoch 30/100, Loss: 0.060232
#   Epoch 40/100, Loss: 0.059043
#   Epoch 50/100, Loss: 0.057943
#   Epoch 60/100, Loss: 0.057378
#   Epoch 70/100, Loss: 0.057144
#   Epoch 80/100, Loss: 0.057072
#   Epoch 90/100, Loss: 0.057090
#   Epoch 100/100, Loss: 0.057149
# Training complete for run 43
# Run 43 — RMSE: 0.492335, MSE: 0.242394, NMSE: 0.0020021783
#
# ===== RUN 44/60 [Noise 5.0%] =====
#   Epoch 10/100, Loss: 0.065960
#   Epoch 20/100, Loss: 0.065358
#   Epoch 30/100, Loss: 0.064785
#   Epoch 40/100, Loss: 0.064167
#   Epoch 50/100, Loss: 0.063555
#   Epoch 60/100, Loss: 0.062960
#   Epoch 70/100, Loss: 0.061997
#   Epoch 80/100, Loss: 0.060122
#   Epoch 90/100, Loss: 0.057900
#   Epoch 100/100, Loss: 0.057988
# Training complete for run 44
# Run 44 — RMSE: 0.497871, MSE: 0.247875, NMSE: 0.0019995442
#
# ===== RUN 45/60 [Noise 5.0%] =====
#   Epoch 10/100, Loss: 0.065491
#   Epoch 20/100, Loss: 0.064923
#   Epoch 30/100, Loss: 0.063166
#   Epoch 40/100, Loss: 0.060382
#   Epoch 50/100, Loss: 0.060056
#   Epoch 60/100, Loss: 0.059408
#   Epoch 70/100, Loss: 0.058835
#   Epoch 80/100, Loss: 0.058336
#   Epoch 90/100, Loss: 0.058080
#   Epoch 100/100, Loss: 0.057968
# Training complete for run 45
# Run 45 — RMSE: 0.490892, MSE: 0.240975, NMSE: 0.0019996397
#
# ===== RUN 46/60 [Noise 5.0%] =====
#   Epoch 10/100, Loss: 0.061744
#   Epoch 20/100, Loss: 0.059722
#   Epoch 30/100, Loss: 0.059204
#   Epoch 40/100, Loss: 0.058943
#   Epoch 50/100, Loss: 0.058719
#   Epoch 60/100, Loss: 0.058783
#   Epoch 70/100, Loss: 0.058187
#   Epoch 80/100, Loss: 0.056205
#   Epoch 90/100, Loss: 0.056726
#   Epoch 100/100, Loss: 0.056726
# Training complete for run 46
# Run 46 — RMSE: 0.483504, MSE: 0.233777, NMSE: 0.0019762055
#
# ===== RUN 47/60 [Noise 5.0%] =====
#   Epoch 10/100, Loss: 0.064387
#   Epoch 20/100, Loss: 0.061529
#   Epoch 30/100, Loss: 0.057984
#   Epoch 40/100, Loss: 0.057369
#   Epoch 50/100, Loss: 0.056771
#   Epoch 60/100, Loss: 0.056336
#   Epoch 70/100, Loss: 0.056244
#   Epoch 80/100, Loss: 0.056619
#   Epoch 90/100, Loss: 0.057593
#   Epoch 100/100, Loss: 0.058639
# Training complete for run 47
# Run 47 — RMSE: 0.492745, MSE: 0.242797, NMSE: 0.0020223510
#
# ===== RUN 48/60 [Noise 5.0%] =====
#   Epoch 10/100, Loss: 0.063898
#   Epoch 20/100, Loss: 0.061518
#   Epoch 30/100, Loss: 0.060798
#   Epoch 40/100, Loss: 0.059446
#   Epoch 50/100, Loss: 0.058085
#   Epoch 60/100, Loss: 0.057351
#   Epoch 70/100, Loss: 0.057077
#   Epoch 80/100, Loss: 0.056976
#   Epoch 90/100, Loss: 0.056923
#   Epoch 100/100, Loss: 0.056887
# Training complete for run 48
# Run 48 — RMSE: 0.488846, MSE: 0.238971, NMSE: 0.0019975245
#
# ===== RUN 49/60 [Noise 5.0%] =====
#   Epoch 10/100, Loss: 0.065139
#   Epoch 20/100, Loss: 0.063692
#   Epoch 30/100, Loss: 0.062400
#   Epoch 40/100, Loss: 0.061943
#   Epoch 50/100, Loss: 0.061282
#   Epoch 60/100, Loss: 0.060458
#   Epoch 70/100, Loss: 0.059699
#   Epoch 80/100, Loss: 0.058597
#   Epoch 90/100, Loss: 0.057051
#   Epoch 100/100, Loss: 0.055868
# Training complete for run 49
# Run 49 — RMSE: 0.488730, MSE: 0.238857, NMSE: 0.0020284707
#
# ===== RUN 50/60 [Noise 5.0%] =====
#   Epoch 10/100, Loss: 0.064912
#   Epoch 20/100, Loss: 0.062651
#   Epoch 30/100, Loss: 0.061569
#   Epoch 40/100, Loss: 0.060625
#   Epoch 50/100, Loss: 0.059675
#   Epoch 60/100, Loss: 0.058798
#   Epoch 70/100, Loss: 0.058325
#   Epoch 80/100, Loss: 0.058189
#   Epoch 90/100, Loss: 0.058126
#   Epoch 100/100, Loss: 0.057512
# Training complete for run 50
# Run 50 — RMSE: 0.496302, MSE: 0.246316, NMSE: 0.0019282468
#
# ===== RUN 51/60 [Noise 5.0%] =====
#   Epoch 10/100, Loss: 0.056976
#   Epoch 20/100, Loss: 0.057628
#   Epoch 30/100, Loss: 0.056198
#   Epoch 40/100, Loss: 0.054676
#   Epoch 50/100, Loss: 0.053654
#   Epoch 60/100, Loss: 0.052974
#   Epoch 70/100, Loss: 0.052559
#   Epoch 80/100, Loss: 0.051452
#   Epoch 90/100, Loss: 0.050574
#   Epoch 100/100, Loss: 0.049384
# Training complete for run 51
# Run 51 — RMSE: 0.460546, MSE: 0.212103, NMSE: 0.0018054371
#
# ===== RUN 52/60 [Noise 5.0%] =====
#   Epoch 10/100, Loss: 0.064294
#   Epoch 20/100, Loss: 0.061782
#   Epoch 30/100, Loss: 0.061450
#   Epoch 40/100, Loss: 0.060571
#   Epoch 50/100, Loss: 0.059549
#   Epoch 60/100, Loss: 0.058890
#   Epoch 70/100, Loss: 0.058354
#   Epoch 80/100, Loss: 0.057526
#   Epoch 90/100, Loss: 0.056818
#   Epoch 100/100, Loss: 0.056327
# Training complete for run 52
# Run 52 — RMSE: 0.495835, MSE: 0.245853, NMSE: 0.0019729968
#
# ===== RUN 53/60 [Noise 5.0%] =====
#   Epoch 10/100, Loss: 0.063307
#   Epoch 20/100, Loss: 0.059468
#   Epoch 30/100, Loss: 0.059007
#   Epoch 40/100, Loss: 0.057742
#   Epoch 50/100, Loss: 0.056494
#   Epoch 60/100, Loss: 0.055883
#   Epoch 70/100, Loss: 0.055648
#   Epoch 80/100, Loss: 0.055567
#   Epoch 90/100, Loss: 0.055535
#   Epoch 100/100, Loss: 0.055510
# Training complete for run 53
# Run 53 — RMSE: 0.489609, MSE: 0.239717, NMSE: 0.0019584838
#
# ===== RUN 54/60 [Noise 5.0%] =====
#   Epoch 10/100, Loss: 0.063138
#   Epoch 20/100, Loss: 0.056404
#   Epoch 30/100, Loss: 0.055653
#   Epoch 40/100, Loss: 0.055242
#   Epoch 50/100, Loss: 0.054238
#   Epoch 60/100, Loss: 0.053265
#   Epoch 70/100, Loss: 0.052449
#   Epoch 80/100, Loss: 0.051855
#   Epoch 90/100, Loss: 0.051496
#   Epoch 100/100, Loss: 0.051425
# Training complete for run 54
# Run 54 — RMSE: 0.470286, MSE: 0.221169, NMSE: 0.0019025618
#
# ===== RUN 55/60 [Noise 5.0%] =====
#   Epoch 10/100, Loss: 0.057484
#   Epoch 20/100, Loss: 0.056981
#   Epoch 30/100, Loss: 0.056362
#   Epoch 40/100, Loss: 0.055382
#   Epoch 50/100, Loss: 0.054745
#   Epoch 60/100, Loss: 0.054544
#   Epoch 70/100, Loss: 0.053329
#   Epoch 80/100, Loss: 0.051746
#   Epoch 90/100, Loss: 0.050819
#   Epoch 100/100, Loss: 0.049812
# Training complete for run 55
# Run 55 — RMSE: 0.467999, MSE: 0.219023, NMSE: 0.0018714348
#
# ===== RUN 56/60 [Noise 5.0%] =====
#   Epoch 10/100, Loss: 0.065394
#   Epoch 20/100, Loss: 0.064467
#   Epoch 30/100, Loss: 0.062678
#   Epoch 40/100, Loss: 0.058196
#   Epoch 50/100, Loss: 0.054834
#   Epoch 60/100, Loss: 0.054223
#   Epoch 70/100, Loss: 0.054078
#   Epoch 80/100, Loss: 0.053953
#   Epoch 90/100, Loss: 0.053431
#   Epoch 100/100, Loss: 0.052115
# Training complete for run 56
# Run 56 — RMSE: 0.475561, MSE: 0.226158, NMSE: 0.0018462984
#
# ===== RUN 57/60 [Noise 5.0%] =====
#   Epoch 10/100, Loss: 0.064376
#   Epoch 20/100, Loss: 0.062795
#   Epoch 30/100, Loss: 0.058599
#   Epoch 40/100, Loss: 0.058338
#   Epoch 50/100, Loss: 0.058204
#   Epoch 60/100, Loss: 0.057585
#   Epoch 70/100, Loss: 0.056892
#   Epoch 80/100, Loss: 0.056331
#   Epoch 90/100, Loss: 0.055951
#   Epoch 100/100, Loss: 0.055745
# Training complete for run 57
# Run 57 — RMSE: 0.482938, MSE: 0.233229, NMSE: 0.0019644025
#
# ===== RUN 58/60 [Noise 5.0%] =====
#   Epoch 10/100, Loss: 0.063210
#   Epoch 20/100, Loss: 0.059493
#   Epoch 30/100, Loss: 0.060677
#   Epoch 40/100, Loss: 0.060597
#   Epoch 50/100, Loss: 0.060234
#   Epoch 60/100, Loss: 0.059856
#   Epoch 70/100, Loss: 0.059338
#   Epoch 80/100, Loss: 0.058893
#   Epoch 90/100, Loss: 0.058488
#   Epoch 100/100, Loss: 0.058125
# Training complete for run 58
# Run 58 — RMSE: 0.495013, MSE: 0.245038, NMSE: 0.0020122327
#
# ===== RUN 59/60 [Noise 5.0%] =====
#   Epoch 10/100, Loss: 0.065111
#   Epoch 20/100, Loss: 0.064623
#   Epoch 30/100, Loss: 0.064108
#   Epoch 40/100, Loss: 0.062518
#   Epoch 50/100, Loss: 0.058721
#   Epoch 60/100, Loss: 0.058323
#   Epoch 70/100, Loss: 0.058083
#   Epoch 80/100, Loss: 0.057973
#   Epoch 90/100, Loss: 0.057577
#   Epoch 100/100, Loss: 0.057127
# Training complete for run 59
# Run 59 — RMSE: 0.498081, MSE: 0.248085, NMSE: 0.0020691772
#
# ===== RUN 60/60 [Noise 5.0%] =====
#   Epoch 10/100, Loss: 0.059242
#   Epoch 20/100, Loss: 0.059866
#   Epoch 30/100, Loss: 0.058624
#   Epoch 40/100, Loss: 0.057980
#   Epoch 50/100, Loss: 0.057359
#   Epoch 60/100, Loss: 0.057087
#   Epoch 70/100, Loss: 0.056993
#   Epoch 80/100, Loss: 0.056938
#   Epoch 90/100, Loss: 0.056910
#   Epoch 100/100, Loss: 0.056662
# Training complete for run 60
# Run 60 — RMSE: 0.495390, MSE: 0.245411, NMSE: 0.0020692960
#
# ===== STATS FOR NOISE 5.0% (60 runs) =====
# RMSE: 0.488215 +/- 0.011374
# MSE:  0.238484 +/- 0.010940
# NMSE: 0.0019904178 +/- 0.0000692116
# Best run: 40 (RMSE: 0.446039)
#
# ================================================================================
# EVALUATING NOISE LEVEL: 10.0% (lambda=0.1, sigma=0.201042)
# ================================================================================
#
# X_train shape: (539, 1, 1), y_train shape: (539,)
#
# ===== RUN 1/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.070131
#   Epoch 20/100, Loss: 0.067494
#   Epoch 30/100, Loss: 0.068633
#   Epoch 40/100, Loss: 0.069207
#   Epoch 50/100, Loss: 0.069392
#   Epoch 60/100, Loss: 0.069386
#   Epoch 70/100, Loss: 0.069578
#   Epoch 80/100, Loss: 0.069484
#   Epoch 90/100, Loss: 0.069141
#   Epoch 100/100, Loss: 0.068846
# Training complete for run 1
# Run 1 — RMSE: 0.595767, MSE: 0.354938, NMSE: 0.0027736997
#
# ===== RUN 2/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.073380
#   Epoch 20/100, Loss: 0.072678
#   Epoch 30/100, Loss: 0.071091
#   Epoch 40/100, Loss: 0.068179
#   Epoch 50/100, Loss: 0.068813
#   Epoch 60/100, Loss: 0.068945
#   Epoch 70/100, Loss: 0.068793
#   Epoch 80/100, Loss: 0.068711
#   Epoch 90/100, Loss: 0.068858
#   Epoch 100/100, Loss: 0.068698
# Training complete for run 2
# Run 2 — RMSE: 0.588311, MSE: 0.346110, NMSE: 0.0027623308
#
# ===== RUN 3/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.068938
#   Epoch 20/100, Loss: 0.067753
#   Epoch 30/100, Loss: 0.068595
#   Epoch 40/100, Loss: 0.069248
#   Epoch 50/100, Loss: 0.069342
#   Epoch 60/100, Loss: 0.069232
#   Epoch 70/100, Loss: 0.068807
#   Epoch 80/100, Loss: 0.068225
#   Epoch 90/100, Loss: 0.067377
#   Epoch 100/100, Loss: 0.065604
# Training complete for run 3
# Run 3 — RMSE: 0.574681, MSE: 0.330259, NMSE: 0.0027346173
#
# ===== RUN 4/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.067092
#   Epoch 20/100, Loss: 0.066970
#   Epoch 30/100, Loss: 0.067661
#   Epoch 40/100, Loss: 0.067688
#   Epoch 50/100, Loss: 0.067295
#   Epoch 60/100, Loss: 0.066801
#   Epoch 70/100, Loss: 0.066779
#   Epoch 80/100, Loss: 0.066417
#   Epoch 90/100, Loss: 0.065799
#   Epoch 100/100, Loss: 0.065450
# Training complete for run 4
# Run 4 — RMSE: 0.575558, MSE: 0.331267, NMSE: 0.0027284318
#
# ===== RUN 5/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.070776
#   Epoch 20/100, Loss: 0.068637
#   Epoch 30/100, Loss: 0.069616
#   Epoch 40/100, Loss: 0.069733
#   Epoch 50/100, Loss: 0.069144
#   Epoch 60/100, Loss: 0.068620
#   Epoch 70/100, Loss: 0.068480
#   Epoch 80/100, Loss: 0.068493
#   Epoch 90/100, Loss: 0.068440
#   Epoch 100/100, Loss: 0.068216
# Training complete for run 5
# Run 5 — RMSE: 0.589498, MSE: 0.347508, NMSE: 0.0027837742
#
# ===== RUN 6/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.069043
#   Epoch 20/100, Loss: 0.066716
#   Epoch 30/100, Loss: 0.066941
#   Epoch 40/100, Loss: 0.063682
#   Epoch 50/100, Loss: 0.061775
#   Epoch 60/100, Loss: 0.062303
#   Epoch 70/100, Loss: 0.063486
#   Epoch 80/100, Loss: 0.064429
#   Epoch 90/100, Loss: 0.065161
#   Epoch 100/100, Loss: 0.065757
# Training complete for run 6
# Run 6 — RMSE: 0.575498, MSE: 0.331198, NMSE: 0.0027560282
#
# ===== RUN 7/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.073322
#   Epoch 20/100, Loss: 0.071761
#   Epoch 30/100, Loss: 0.068739
#   Epoch 40/100, Loss: 0.068690
#   Epoch 50/100, Loss: 0.068796
#   Epoch 60/100, Loss: 0.068881
#   Epoch 70/100, Loss: 0.069083
#   Epoch 80/100, Loss: 0.069350
#   Epoch 90/100, Loss: 0.069597
#   Epoch 100/100, Loss: 0.069756
# Training complete for run 7
# Run 7 — RMSE: 0.595279, MSE: 0.354357, NMSE: 0.0028536599
#
# ===== RUN 8/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.073027
#   Epoch 20/100, Loss: 0.070798
#   Epoch 30/100, Loss: 0.068184
#   Epoch 40/100, Loss: 0.068104
#   Epoch 50/100, Loss: 0.067955
#   Epoch 60/100, Loss: 0.067985
#   Epoch 70/100, Loss: 0.068145
#   Epoch 80/100, Loss: 0.068312
#   Epoch 90/100, Loss: 0.068462
#   Epoch 100/100, Loss: 0.068486
# Training complete for run 8
# Run 8 — RMSE: 0.587583, MSE: 0.345254, NMSE: 0.0027642757
#
# ===== RUN 9/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.073197
#   Epoch 20/100, Loss: 0.071954
#   Epoch 30/100, Loss: 0.068786
#   Epoch 40/100, Loss: 0.068800
#   Epoch 50/100, Loss: 0.068463
#   Epoch 60/100, Loss: 0.068225
#   Epoch 70/100, Loss: 0.068254
#   Epoch 80/100, Loss: 0.068514
#   Epoch 90/100, Loss: 0.068858
#   Epoch 100/100, Loss: 0.069132
# Training complete for run 9
# Run 9 — RMSE: 0.593525, MSE: 0.352272, NMSE: 0.0027902417
#
# ===== RUN 10/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.071339
#   Epoch 20/100, Loss: 0.067524
#   Epoch 30/100, Loss: 0.066538
#   Epoch 40/100, Loss: 0.066548
#   Epoch 50/100, Loss: 0.065670
#   Epoch 60/100, Loss: 0.065101
#   Epoch 70/100, Loss: 0.064956
#   Epoch 80/100, Loss: 0.064849
#   Epoch 90/100, Loss: 0.064458
#   Epoch 100/100, Loss: 0.065714
# Training complete for run 10
# Run 10 — RMSE: 0.576298, MSE: 0.332120, NMSE: 0.0027996237
#
# ===== RUN 11/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.073188
#   Epoch 20/100, Loss: 0.072069
#   Epoch 30/100, Loss: 0.069089
#   Epoch 40/100, Loss: 0.065451
#   Epoch 50/100, Loss: 0.065881
#   Epoch 60/100, Loss: 0.066519
#   Epoch 70/100, Loss: 0.067350
#   Epoch 80/100, Loss: 0.067437
#   Epoch 90/100, Loss: 0.067148
#   Epoch 100/100, Loss: 0.066475
# Training complete for run 11
# Run 11 — RMSE: 0.571754, MSE: 0.326902, NMSE: 0.0025668615
#
# ===== RUN 12/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.072727
#   Epoch 20/100, Loss: 0.069999
#   Epoch 30/100, Loss: 0.068652
#   Epoch 40/100, Loss: 0.068399
#   Epoch 50/100, Loss: 0.067751
#   Epoch 60/100, Loss: 0.067450
#   Epoch 70/100, Loss: 0.067229
#   Epoch 80/100, Loss: 0.065866
#   Epoch 90/100, Loss: 0.065473
#   Epoch 100/100, Loss: 0.065883
# Training complete for run 12
# Run 12 — RMSE: 0.588207, MSE: 0.345987, NMSE: 0.0028054591
#
# ===== RUN 13/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.064486
#   Epoch 20/100, Loss: 0.065067
#   Epoch 30/100, Loss: 0.067668
#   Epoch 40/100, Loss: 0.069468
#   Epoch 50/100, Loss: 0.069442
#   Epoch 60/100, Loss: 0.069041
#   Epoch 70/100, Loss: 0.069065
#   Epoch 80/100, Loss: 0.069177
#   Epoch 90/100, Loss: 0.069227
#   Epoch 100/100, Loss: 0.069295
# Training complete for run 13
# Run 13 — RMSE: 0.597125, MSE: 0.356558, NMSE: 0.0028816835
#
# ===== RUN 14/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.072175
#   Epoch 20/100, Loss: 0.066629
#   Epoch 30/100, Loss: 0.067579
#   Epoch 40/100, Loss: 0.067114
#   Epoch 50/100, Loss: 0.065823
#   Epoch 60/100, Loss: 0.064127
#   Epoch 70/100, Loss: 0.061517
#   Epoch 80/100, Loss: 0.061657
#   Epoch 90/100, Loss: 0.062288
#   Epoch 100/100, Loss: 0.062413
# Training complete for run 14
# Run 14 — RMSE: 0.559658, MSE: 0.313217, NMSE: 0.0026342279
#
# ===== RUN 15/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.068043
#   Epoch 20/100, Loss: 0.058535
#   Epoch 30/100, Loss: 0.060733
#   Epoch 40/100, Loss: 0.061086
#   Epoch 50/100, Loss: 0.063693
#   Epoch 60/100, Loss: 0.063685
#   Epoch 70/100, Loss: 0.062513
#   Epoch 80/100, Loss: 0.061056
#   Epoch 90/100, Loss: 0.061734
#   Epoch 100/100, Loss: 0.062852
# Training complete for run 15
# Run 15 — RMSE: 0.587044, MSE: 0.344620, NMSE: 0.0029413981
#
# ===== RUN 16/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.073196
#   Epoch 20/100, Loss: 0.071702
#   Epoch 30/100, Loss: 0.067858
#   Epoch 40/100, Loss: 0.068708
#   Epoch 50/100, Loss: 0.069469
#   Epoch 60/100, Loss: 0.069586
#   Epoch 70/100, Loss: 0.069559
#   Epoch 80/100, Loss: 0.069652
#   Epoch 90/100, Loss: 0.069902
#   Epoch 100/100, Loss: 0.070171
# Training complete for run 16
# Run 16 — RMSE: 0.589929, MSE: 0.348016, NMSE: 0.0027127700
#
# ===== RUN 17/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.066367
#   Epoch 20/100, Loss: 0.066109
#   Epoch 30/100, Loss: 0.066498
#   Epoch 40/100, Loss: 0.067324
#   Epoch 50/100, Loss: 0.067686
#   Epoch 60/100, Loss: 0.067423
#   Epoch 70/100, Loss: 0.067523
#   Epoch 80/100, Loss: 0.067388
#   Epoch 90/100, Loss: 0.067721
#   Epoch 100/100, Loss: 0.067649
# Training complete for run 17
# Run 17 — RMSE: 0.578845, MSE: 0.335062, NMSE: 0.0027404563
#
# ===== RUN 18/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.071805
#   Epoch 20/100, Loss: 0.068942
#   Epoch 30/100, Loss: 0.068467
#   Epoch 40/100, Loss: 0.067926
#   Epoch 50/100, Loss: 0.067967
#   Epoch 60/100, Loss: 0.068321
#   Epoch 70/100, Loss: 0.068670
#   Epoch 80/100, Loss: 0.068894
#   Epoch 90/100, Loss: 0.068634
#   Epoch 100/100, Loss: 0.068185
# Training complete for run 18
# Run 18 — RMSE: 0.598543, MSE: 0.358254, NMSE: 0.0028955123
#
# ===== RUN 19/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.073300
#   Epoch 20/100, Loss: 0.071184
#   Epoch 30/100, Loss: 0.069819
#   Epoch 40/100, Loss: 0.070292
#   Epoch 50/100, Loss: 0.069624
#   Epoch 60/100, Loss: 0.068688
#   Epoch 70/100, Loss: 0.068215
#   Epoch 80/100, Loss: 0.068287
#   Epoch 90/100, Loss: 0.068332
#   Epoch 100/100, Loss: 0.068291
# Training complete for run 19
# Run 19 — RMSE: 0.597039, MSE: 0.356455, NMSE: 0.0029092136
#
# ===== RUN 20/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.072395
#   Epoch 20/100, Loss: 0.065348
#   Epoch 30/100, Loss: 0.066969
#   Epoch 40/100, Loss: 0.068003
#   Epoch 50/100, Loss: 0.068262
#   Epoch 60/100, Loss: 0.068070
#   Epoch 70/100, Loss: 0.066930
#   Epoch 80/100, Loss: 0.065235
#   Epoch 90/100, Loss: 0.063685
#   Epoch 100/100, Loss: 0.062889
# Training complete for run 20
# Run 20 — RMSE: 0.654557, MSE: 0.428445, NMSE: 0.0036689647
#
# ===== RUN 21/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.073067
#   Epoch 20/100, Loss: 0.070320
#   Epoch 30/100, Loss: 0.067172
#   Epoch 40/100, Loss: 0.067393
#   Epoch 50/100, Loss: 0.067672
#   Epoch 60/100, Loss: 0.068422
#   Epoch 70/100, Loss: 0.069200
#   Epoch 80/100, Loss: 0.069358
#   Epoch 90/100, Loss: 0.068797
#   Epoch 100/100, Loss: 0.068419
# Training complete for run 21
# Run 21 — RMSE: 0.582862, MSE: 0.339729, NMSE: 0.0026878628
#
# ===== RUN 22/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.070514
#   Epoch 20/100, Loss: 0.066358
#   Epoch 30/100, Loss: 0.067219
#   Epoch 40/100, Loss: 0.067770
#   Epoch 50/100, Loss: 0.067605
#   Epoch 60/100, Loss: 0.067478
#   Epoch 70/100, Loss: 0.067840
#   Epoch 80/100, Loss: 0.067951
#   Epoch 90/100, Loss: 0.068415
#   Epoch 100/100, Loss: 0.068590
# Training complete for run 22
# Run 22 — RMSE: 0.589272, MSE: 0.347241, NMSE: 0.0027625109
#
# ===== RUN 23/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.073755
#   Epoch 20/100, Loss: 0.072919
#   Epoch 30/100, Loss: 0.069015
#   Epoch 40/100, Loss: 0.069073
#   Epoch 50/100, Loss: 0.069641
#   Epoch 60/100, Loss: 0.069493
#   Epoch 70/100, Loss: 0.069244
#   Epoch 80/100, Loss: 0.068910
#   Epoch 90/100, Loss: 0.068300
#   Epoch 100/100, Loss: 0.067613
# Training complete for run 23
# Run 23 — RMSE: 0.580957, MSE: 0.337511, NMSE: 0.0027303439
#
# ===== RUN 24/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.072060
#   Epoch 20/100, Loss: 0.064079
#   Epoch 30/100, Loss: 0.061267
#   Epoch 40/100, Loss: 0.063769
#   Epoch 50/100, Loss: 0.064259
#   Epoch 60/100, Loss: 0.064134
#   Epoch 70/100, Loss: 0.063661
#   Epoch 80/100, Loss: 0.063777
#   Epoch 90/100, Loss: 0.062040
#   Epoch 100/100, Loss: 0.059040
# Training complete for run 24
# Run 24 — RMSE: 0.559677, MSE: 0.313239, NMSE: 0.0026319608
#
# ===== RUN 25/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.073443
#   Epoch 20/100, Loss: 0.072314
#   Epoch 30/100, Loss: 0.069380
#   Epoch 40/100, Loss: 0.068800
#   Epoch 50/100, Loss: 0.068797
#   Epoch 60/100, Loss: 0.068852
#   Epoch 70/100, Loss: 0.068864
#   Epoch 80/100, Loss: 0.069021
#   Epoch 90/100, Loss: 0.069076
#   Epoch 100/100, Loss: 0.068849
# Training complete for run 25
# Run 25 — RMSE: 0.587037, MSE: 0.344612, NMSE: 0.0027391791
#
# ===== RUN 26/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.070284
#   Epoch 20/100, Loss: 0.068064
#   Epoch 30/100, Loss: 0.067719
#   Epoch 40/100, Loss: 0.068120
#   Epoch 50/100, Loss: 0.068051
#   Epoch 60/100, Loss: 0.067591
#   Epoch 70/100, Loss: 0.067255
#   Epoch 80/100, Loss: 0.067014
#   Epoch 90/100, Loss: 0.066843
#   Epoch 100/100, Loss: 0.066773
# Training complete for run 26
# Run 26 — RMSE: 0.592212, MSE: 0.350715, NMSE: 0.0028963080
#
# ===== RUN 27/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.072164
#   Epoch 20/100, Loss: 0.068183
#   Epoch 30/100, Loss: 0.067815
#   Epoch 40/100, Loss: 0.066796
#   Epoch 50/100, Loss: 0.066008
#   Epoch 60/100, Loss: 0.065675
#   Epoch 70/100, Loss: 0.065710
#   Epoch 80/100, Loss: 0.066297
#   Epoch 90/100, Loss: 0.067023
#   Epoch 100/100, Loss: 0.066423
# Training complete for run 27
# Run 27 — RMSE: 0.572530, MSE: 0.327790, NMSE: 0.0025925436
#
# ===== RUN 28/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.072825
#   Epoch 20/100, Loss: 0.070150
#   Epoch 30/100, Loss: 0.070380
#   Epoch 40/100, Loss: 0.070413
#   Epoch 50/100, Loss: 0.070123
#   Epoch 60/100, Loss: 0.069713
#   Epoch 70/100, Loss: 0.069638
#   Epoch 80/100, Loss: 0.069518
#   Epoch 90/100, Loss: 0.069314
#   Epoch 100/100, Loss: 0.068900
# Training complete for run 28
# Run 28 — RMSE: 0.614305, MSE: 0.377371, NMSE: 0.0031171360
#
# ===== RUN 29/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.071283
#   Epoch 20/100, Loss: 0.066503
#   Epoch 30/100, Loss: 0.061762
#   Epoch 40/100, Loss: 0.062123
#   Epoch 50/100, Loss: 0.063307
#   Epoch 60/100, Loss: 0.063729
#   Epoch 70/100, Loss: 0.063288
#   Epoch 80/100, Loss: 0.061462
#   Epoch 90/100, Loss: 0.058620
#   Epoch 100/100, Loss: 0.056575
# Training complete for run 29
# Run 29 — RMSE: 0.573896, MSE: 0.329356, NMSE: 0.0029243711
#
# ===== RUN 30/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.073034
#   Epoch 20/100, Loss: 0.072167
#   Epoch 30/100, Loss: 0.069626
#   Epoch 40/100, Loss: 0.067622
#   Epoch 50/100, Loss: 0.068232
#   Epoch 60/100, Loss: 0.068394
#   Epoch 70/100, Loss: 0.068463
#   Epoch 80/100, Loss: 0.068494
#   Epoch 90/100, Loss: 0.068432
#   Epoch 100/100, Loss: 0.068154
# Training complete for run 30
# Run 30 — RMSE: 0.590348, MSE: 0.348511, NMSE: 0.0028148606
#
# ===== RUN 31/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.072393
#   Epoch 20/100, Loss: 0.071969
#   Epoch 30/100, Loss: 0.072353
#   Epoch 40/100, Loss: 0.072370
#   Epoch 50/100, Loss: 0.070516
#   Epoch 60/100, Loss: 0.067274
#   Epoch 70/100, Loss: 0.066312
#   Epoch 80/100, Loss: 0.065723
#   Epoch 90/100, Loss: 0.065431
#   Epoch 100/100, Loss: 0.065436
# Training complete for run 31
# Run 31 — RMSE: 0.571014, MSE: 0.326058, NMSE: 0.0027335294
#
# ===== RUN 32/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.068274
#   Epoch 20/100, Loss: 0.065990
#   Epoch 30/100, Loss: 0.066127
#   Epoch 40/100, Loss: 0.067199
#   Epoch 50/100, Loss: 0.068662
#   Epoch 60/100, Loss: 0.069238
#   Epoch 70/100, Loss: 0.069263
#   Epoch 80/100, Loss: 0.067717
#   Epoch 90/100, Loss: 0.063711
#   Epoch 100/100, Loss: 0.062591
# Training complete for run 32
# Run 32 — RMSE: 0.570035, MSE: 0.324940, NMSE: 0.0026427260
#
# ===== RUN 33/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.074740
#   Epoch 20/100, Loss: 0.074053
#   Epoch 30/100, Loss: 0.073496
#   Epoch 40/100, Loss: 0.072460
#   Epoch 50/100, Loss: 0.070298
#   Epoch 60/100, Loss: 0.068998
#   Epoch 70/100, Loss: 0.068857
#   Epoch 80/100, Loss: 0.068476
#   Epoch 90/100, Loss: 0.067838
#   Epoch 100/100, Loss: 0.067316
# Training complete for run 33
# Run 33 — RMSE: 0.585580, MSE: 0.342904, NMSE: 0.0027497013
#
# ===== RUN 34/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.069301
#   Epoch 20/100, Loss: 0.064678
#   Epoch 30/100, Loss: 0.064618
#   Epoch 40/100, Loss: 0.062499
#   Epoch 50/100, Loss: 0.059648
#   Epoch 60/100, Loss: 0.058698
#   Epoch 70/100, Loss: 0.058256
#   Epoch 80/100, Loss: 0.058274
#   Epoch 90/100, Loss: 0.059929
#   Epoch 100/100, Loss: 0.061556
# Training complete for run 34
# Run 34 — RMSE: 0.566598, MSE: 0.321034, NMSE: 0.0027869844
#
# ===== RUN 35/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.073253
#   Epoch 20/100, Loss: 0.071757
#   Epoch 30/100, Loss: 0.069677
#   Epoch 40/100, Loss: 0.069537
#   Epoch 50/100, Loss: 0.069880
#   Epoch 60/100, Loss: 0.069748
#   Epoch 70/100, Loss: 0.069738
#   Epoch 80/100, Loss: 0.069555
#   Epoch 90/100, Loss: 0.069137
#   Epoch 100/100, Loss: 0.068610
# Training complete for run 35
# Run 35 — RMSE: 0.590751, MSE: 0.348987, NMSE: 0.0028306235
#
# ===== RUN 36/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.074402
#   Epoch 20/100, Loss: 0.072709
#   Epoch 30/100, Loss: 0.067879
#   Epoch 40/100, Loss: 0.068262
#   Epoch 50/100, Loss: 0.068224
#   Epoch 60/100, Loss: 0.068345
#   Epoch 70/100, Loss: 0.068520
#   Epoch 80/100, Loss: 0.068555
#   Epoch 90/100, Loss: 0.068333
#   Epoch 100/100, Loss: 0.067340
# Training complete for run 36
# Run 36 — RMSE: 0.598690, MSE: 0.358430, NMSE: 0.0028672340
#
# ===== RUN 37/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.073068
#   Epoch 20/100, Loss: 0.069322
#   Epoch 30/100, Loss: 0.068567
#   Epoch 40/100, Loss: 0.067384
#   Epoch 50/100, Loss: 0.067057
#   Epoch 60/100, Loss: 0.067348
#   Epoch 70/100, Loss: 0.067734
#   Epoch 80/100, Loss: 0.068401
#   Epoch 90/100, Loss: 0.068708
#   Epoch 100/100, Loss: 0.069289
# Training complete for run 37
# Run 37 — RMSE: 0.588574, MSE: 0.346420, NMSE: 0.0027313174
#
# ===== RUN 38/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.071670
#   Epoch 20/100, Loss: 0.067914
#   Epoch 30/100, Loss: 0.067099
#   Epoch 40/100, Loss: 0.066660
#   Epoch 50/100, Loss: 0.065825
#   Epoch 60/100, Loss: 0.064201
#   Epoch 70/100, Loss: 0.062972
#   Epoch 80/100, Loss: 0.063042
#   Epoch 90/100, Loss: 0.063295
#   Epoch 100/100, Loss: 0.063928
# Training complete for run 38
# Run 38 — RMSE: 0.568189, MSE: 0.322839, NMSE: 0.0026385349
#
# ===== RUN 39/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.072173
#   Epoch 20/100, Loss: 0.071362
#   Epoch 30/100, Loss: 0.069894
#   Epoch 40/100, Loss: 0.069325
#   Epoch 50/100, Loss: 0.069507
#   Epoch 60/100, Loss: 0.069382
#   Epoch 70/100, Loss: 0.069157
#   Epoch 80/100, Loss: 0.068912
#   Epoch 90/100, Loss: 0.068582
#   Epoch 100/100, Loss: 0.068196
# Training complete for run 39
# Run 39 — RMSE: 0.583613, MSE: 0.340604, NMSE: 0.0027013619
#
# ===== RUN 40/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.062839
#   Epoch 20/100, Loss: 0.062169
#   Epoch 30/100, Loss: 0.062554
#   Epoch 40/100, Loss: 0.062761
#   Epoch 50/100, Loss: 0.062747
#   Epoch 60/100, Loss: 0.062670
#   Epoch 70/100, Loss: 0.062790
#   Epoch 80/100, Loss: 0.062969
#   Epoch 90/100, Loss: 0.062973
#   Epoch 100/100, Loss: 0.062618
# Training complete for run 40
# Run 40 — RMSE: 0.544937, MSE: 0.296956, NMSE: 0.0025373610
#
# ===== RUN 41/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.072128
#   Epoch 20/100, Loss: 0.069507
#   Epoch 30/100, Loss: 0.069666
#   Epoch 40/100, Loss: 0.069996
#   Epoch 50/100, Loss: 0.069545
#   Epoch 60/100, Loss: 0.068955
#   Epoch 70/100, Loss: 0.068502
#   Epoch 80/100, Loss: 0.067956
#   Epoch 90/100, Loss: 0.067352
#   Epoch 100/100, Loss: 0.066937
# Training complete for run 41
# Run 41 — RMSE: 0.583260, MSE: 0.340192, NMSE: 0.0027800920
#
# ===== RUN 42/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.073594
#   Epoch 20/100, Loss: 0.072301
#   Epoch 30/100, Loss: 0.066076
#   Epoch 40/100, Loss: 0.067094
#   Epoch 50/100, Loss: 0.068404
#   Epoch 60/100, Loss: 0.069154
#   Epoch 70/100, Loss: 0.069287
#   Epoch 80/100, Loss: 0.069271
#   Epoch 90/100, Loss: 0.069283
#   Epoch 100/100, Loss: 0.069297
# Training complete for run 42
# Run 42 — RMSE: 0.589878, MSE: 0.347956, NMSE: 0.0027332351
#
# ===== RUN 43/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.074110
#   Epoch 20/100, Loss: 0.072989
#   Epoch 30/100, Loss: 0.069945
#   Epoch 40/100, Loss: 0.068227
#   Epoch 50/100, Loss: 0.067915
#   Epoch 60/100, Loss: 0.067734
#   Epoch 70/100, Loss: 0.067905
#   Epoch 80/100, Loss: 0.068356
#   Epoch 90/100, Loss: 0.068977
#   Epoch 100/100, Loss: 0.069681
# Training complete for run 43
# Run 43 — RMSE: 0.591178, MSE: 0.349492, NMSE: 0.0027393093
#
# ===== RUN 44/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.074486
#   Epoch 20/100, Loss: 0.073907
#   Epoch 30/100, Loss: 0.073402
#   Epoch 40/100, Loss: 0.072808
#   Epoch 50/100, Loss: 0.072064
#   Epoch 60/100, Loss: 0.071109
#   Epoch 70/100, Loss: 0.069938
#   Epoch 80/100, Loss: 0.067950
#   Epoch 90/100, Loss: 0.067567
#   Epoch 100/100, Loss: 0.068015
# Training complete for run 44
# Run 44 — RMSE: 0.587890, MSE: 0.345615, NMSE: 0.0027430557
#
# ===== RUN 45/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.073816
#   Epoch 20/100, Loss: 0.072956
#   Epoch 30/100, Loss: 0.069872
#   Epoch 40/100, Loss: 0.069399
#   Epoch 50/100, Loss: 0.069461
#   Epoch 60/100, Loss: 0.069173
#   Epoch 70/100, Loss: 0.069112
#   Epoch 80/100, Loss: 0.068791
#   Epoch 90/100, Loss: 0.068356
#   Epoch 100/100, Loss: 0.066681
# Training complete for run 45
# Run 45 — RMSE: 0.611584, MSE: 0.374035, NMSE: 0.0032050651
#
# ===== RUN 46/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.071911
#   Epoch 20/100, Loss: 0.069435
#   Epoch 30/100, Loss: 0.067387
#   Epoch 40/100, Loss: 0.067610
#   Epoch 50/100, Loss: 0.067855
#   Epoch 60/100, Loss: 0.067999
#   Epoch 70/100, Loss: 0.068454
#   Epoch 80/100, Loss: 0.068645
#   Epoch 90/100, Loss: 0.068315
#   Epoch 100/100, Loss: 0.066638
# Training complete for run 46
# Run 46 — RMSE: 0.582056, MSE: 0.338789, NMSE: 0.0027089500
#
# ===== RUN 47/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.073072
#   Epoch 20/100, Loss: 0.071775
#   Epoch 30/100, Loss: 0.068196
#   Epoch 40/100, Loss: 0.066009
#   Epoch 50/100, Loss: 0.066488
#   Epoch 60/100, Loss: 0.066904
#   Epoch 70/100, Loss: 0.067219
#   Epoch 80/100, Loss: 0.067630
#   Epoch 90/100, Loss: 0.068203
#   Epoch 100/100, Loss: 0.068633
# Training complete for run 47
# Run 47 — RMSE: 0.583635, MSE: 0.340630, NMSE: 0.0027058753
#
# ===== RUN 48/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.072293
#   Epoch 20/100, Loss: 0.069189
#   Epoch 30/100, Loss: 0.070198
#   Epoch 40/100, Loss: 0.070536
#   Epoch 50/100, Loss: 0.070286
#   Epoch 60/100, Loss: 0.069887
#   Epoch 70/100, Loss: 0.069554
#   Epoch 80/100, Loss: 0.069322
#   Epoch 90/100, Loss: 0.069172
#   Epoch 100/100, Loss: 0.069005
# Training complete for run 48
# Run 48 — RMSE: 0.587388, MSE: 0.345025, NMSE: 0.0027556196
#
# ===== RUN 49/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.073370
#   Epoch 20/100, Loss: 0.071467
#   Epoch 30/100, Loss: 0.071108
#   Epoch 40/100, Loss: 0.070753
#   Epoch 50/100, Loss: 0.070460
#   Epoch 60/100, Loss: 0.070175
#   Epoch 70/100, Loss: 0.069947
#   Epoch 80/100, Loss: 0.069871
#   Epoch 90/100, Loss: 0.069926
#   Epoch 100/100, Loss: 0.070022
# Training complete for run 49
# Run 49 — RMSE: 0.593433, MSE: 0.352162, NMSE: 0.0027866391
#
# ===== RUN 50/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.073376
#   Epoch 20/100, Loss: 0.072569
#   Epoch 30/100, Loss: 0.071034
#   Epoch 40/100, Loss: 0.069628
#   Epoch 50/100, Loss: 0.069037
#   Epoch 60/100, Loss: 0.068877
#   Epoch 70/100, Loss: 0.068618
#   Epoch 80/100, Loss: 0.068385
#   Epoch 90/100, Loss: 0.068249
#   Epoch 100/100, Loss: 0.068093
# Training complete for run 50
# Run 50 — RMSE: 0.580132, MSE: 0.336553, NMSE: 0.0026019055
#
# ===== RUN 51/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.062418
#   Epoch 20/100, Loss: 0.061958
#   Epoch 30/100, Loss: 0.062652
#   Epoch 40/100, Loss: 0.062956
#   Epoch 50/100, Loss: 0.063276
#   Epoch 60/100, Loss: 0.064184
#   Epoch 70/100, Loss: 0.064531
#   Epoch 80/100, Loss: 0.064564
#   Epoch 90/100, Loss: 0.061792
#   Epoch 100/100, Loss: 0.060203
# Training complete for run 51
# Run 51 — RMSE: 0.590700, MSE: 0.348927, NMSE: 0.0030852379
#
# ===== RUN 52/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.072319
#   Epoch 20/100, Loss: 0.068406
#   Epoch 30/100, Loss: 0.069378
#   Epoch 40/100, Loss: 0.069544
#   Epoch 50/100, Loss: 0.069338
#   Epoch 60/100, Loss: 0.069073
#   Epoch 70/100, Loss: 0.068346
#   Epoch 80/100, Loss: 0.066314
#   Epoch 90/100, Loss: 0.064009
#   Epoch 100/100, Loss: 0.062863
# Training complete for run 52
# Run 52 — RMSE: 0.571221, MSE: 0.326293, NMSE: 0.0026814701
#
# ===== RUN 53/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.071319
#   Epoch 20/100, Loss: 0.066594
#   Epoch 30/100, Loss: 0.066744
#   Epoch 40/100, Loss: 0.066247
#   Epoch 50/100, Loss: 0.065651
#   Epoch 60/100, Loss: 0.065395
#   Epoch 70/100, Loss: 0.065430
#   Epoch 80/100, Loss: 0.065642
#   Epoch 90/100, Loss: 0.066024
#   Epoch 100/100, Loss: 0.066545
# Training complete for run 53
# Run 53 — RMSE: 0.575882, MSE: 0.331640, NMSE: 0.0026726417
#
# ===== RUN 54/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.073573
#   Epoch 20/100, Loss: 0.072379
#   Epoch 30/100, Loss: 0.063590
#   Epoch 40/100, Loss: 0.062886
#   Epoch 50/100, Loss: 0.063772
#   Epoch 60/100, Loss: 0.063704
#   Epoch 70/100, Loss: 0.063374
#   Epoch 80/100, Loss: 0.063510
#   Epoch 90/100, Loss: 0.064739
#   Epoch 100/100, Loss: 0.066070
# Training complete for run 54
# Run 54 — RMSE: 0.565775, MSE: 0.320102, NMSE: 0.0026293996
#
# ===== RUN 55/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.066111
#   Epoch 20/100, Loss: 0.064803
#   Epoch 30/100, Loss: 0.064831
#   Epoch 40/100, Loss: 0.064908
#   Epoch 50/100, Loss: 0.065227
#   Epoch 60/100, Loss: 0.065670
#   Epoch 70/100, Loss: 0.065669
#   Epoch 80/100, Loss: 0.064505
#   Epoch 90/100, Loss: 0.062859
#   Epoch 100/100, Loss: 0.062582
# Training complete for run 55
# Run 55 — RMSE: 0.567702, MSE: 0.322286, NMSE: 0.0027102117
#
# ===== RUN 56/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.074066
#   Epoch 20/100, Loss: 0.073591
#   Epoch 30/100, Loss: 0.072852
#   Epoch 40/100, Loss: 0.071167
#   Epoch 50/100, Loss: 0.065494
#   Epoch 60/100, Loss: 0.063818
#   Epoch 70/100, Loss: 0.065461
#   Epoch 80/100, Loss: 0.066166
#   Epoch 90/100, Loss: 0.065957
#   Epoch 100/100, Loss: 0.065810
# Training complete for run 56
# Run 56 — RMSE: 0.572306, MSE: 0.327534, NMSE: 0.0026791385
#
# ===== RUN 57/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.073367
#   Epoch 20/100, Loss: 0.073392
#   Epoch 30/100, Loss: 0.073006
#   Epoch 40/100, Loss: 0.071757
#   Epoch 50/100, Loss: 0.068285
#   Epoch 60/100, Loss: 0.065975
#   Epoch 70/100, Loss: 0.067484
#   Epoch 80/100, Loss: 0.068347
#   Epoch 90/100, Loss: 0.068405
#   Epoch 100/100, Loss: 0.068698
# Training complete for run 57
# Run 57 — RMSE: 0.579675, MSE: 0.336023, NMSE: 0.0026829294
#
# ===== RUN 58/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.072882
#   Epoch 20/100, Loss: 0.069923
#   Epoch 30/100, Loss: 0.069333
#   Epoch 40/100, Loss: 0.070280
#   Epoch 50/100, Loss: 0.070486
#   Epoch 60/100, Loss: 0.070224
#   Epoch 70/100, Loss: 0.070084
#   Epoch 80/100, Loss: 0.069770
#   Epoch 90/100, Loss: 0.069728
#   Epoch 100/100, Loss: 0.069664
# Training complete for run 58
# Run 58 — RMSE: 0.586622, MSE: 0.344125, NMSE: 0.0027153499
#
# ===== RUN 59/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.073025
#   Epoch 20/100, Loss: 0.072704
#   Epoch 30/100, Loss: 0.070761
#   Epoch 40/100, Loss: 0.066281
#   Epoch 50/100, Loss: 0.066999
#   Epoch 60/100, Loss: 0.066844
#   Epoch 70/100, Loss: 0.066681
#   Epoch 80/100, Loss: 0.066832
#   Epoch 90/100, Loss: 0.066448
#   Epoch 100/100, Loss: 0.066129
# Training complete for run 59
# Run 59 — RMSE: 0.576426, MSE: 0.332267, NMSE: 0.0027300477
#
# ===== RUN 60/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.066736
#   Epoch 20/100, Loss: 0.067847
#   Epoch 30/100, Loss: 0.068197
#   Epoch 40/100, Loss: 0.067958
#   Epoch 50/100, Loss: 0.067822
#   Epoch 60/100, Loss: 0.067810
#   Epoch 70/100, Loss: 0.067968
#   Epoch 80/100, Loss: 0.068058
#   Epoch 90/100, Loss: 0.067929
#   Epoch 100/100, Loss: 0.067514
# Training complete for run 60
# Run 60 — RMSE: 0.591485, MSE: 0.349855, NMSE: 0.0029193582
#
# ===== STATS FOR NOISE 10.0% (60 runs) =====
# RMSE: 0.584233 +/- 0.015179
# MSE:  0.341559 +/- 0.018058
# NMSE: 0.0027814202 +/- 0.0001681786
# Best run: 40 (RMSE: 0.544937)

# %% [markdown]
# ## Results

# %%
# ============================================================
# Final Metrics Summary & Plots per Noise Level
# ============================================================
from tabulate import tabulate

for entry in _molab_results:
    lam = entry[0]
    mean_rmse, std_rmse = entry[1], entry[2]
    mean_mse, std_mse = entry[3], entry[4]
    mean_nmse, std_nmse = entry[5], entry[6]
    best_rmse_val = entry[7]
    best_predictions = entry[8]
    best_losses = entry[9]
    raw_values_for_plot = entry[10]
    
    print("\n" + "="*80)
    print(f"RESULTS FOR NOISE LEVEL: {lam*100:.1f}%")
    print("="*80)
    
    print(f'Mean RMSE: {mean_rmse:.6f} +/- {std_rmse:.6f}')
    print(f'Mean MSE:  {mean_mse:.6f} +/- {std_mse:.6f}')
    print(f'Mean NMSE: {mean_nmse:.10f} +/- {std_nmse:.10f}')
    print(f'Best RMSE: {best_rmse_val:.6f}')
    
    actual = raw_values_for_plot[-60:]
    
    plt.figure(figsize=(12, 5))
    plt.plot(actual, label='Actual', color='blue', linewidth=1.5)
    plt.plot(best_predictions, label='Predicted (Best Run)', color='red',
             linewidth=1.5, linestyle='--')
    plt.title(f'Predictions vs Actual (Noise {lam*100:.1f}%)')
    plt.xlabel('Time Step')
    plt.ylabel('Value')
    plt.legend()
    plt.grid(True, alpha=0.3)
    plt.tight_layout()
    plt.show()

    plt.figure(figsize=(12, 4))
    plt.plot(best_losses, color='green', linewidth=1.0)
    plt.title(f'Training Loss (Best Run, Noise {lam*100:.1f}%)')
    plt.xlabel('Epoch')
    plt.ylabel('MSE Loss')
    plt.grid(True, alpha=0.3)
    plt.tight_layout()
    plt.show()

print("\n" + "="*80)
print("FINAL RESULTS TABLE ACROSS ALL NOISE LEVELS")
print("="*80)
df_res = pd.DataFrame(
    [[r[0], f'{r[1]:.6f} +/- {r[2]:.6f}', f'{r[3]:.6f} +/- {r[4]:.6f}', 
      f'{r[5]:.10f} +/- {r[6]:.10f}', f'{r[7]:.6f}'] for r in _molab_results],
    columns=['Noise Level', 'RMSE (mean+/-std)', 'MSE (mean+/-std)', 'NMSE (mean+/-std)', 'Best RMSE']
)
print(tabulate(df_res, headers='keys', tablefmt='github', showindex=False))
# Out:
# ================================================================================
# RESULTS FOR NOISE LEVEL: 5.0%
# ================================================================================
# Mean RMSE: 0.488215 +/- 0.011374
# Mean MSE:  0.238484 +/- 0.010940
# Mean NMSE: 0.0019904178 +/- 0.0000692116
# Best RMSE: 0.446039
# ================================================================================
# RESULTS FOR NOISE LEVEL: 10.0%
# ================================================================================
# Mean RMSE: 0.584233 +/- 0.015179
# Mean MSE:  0.341559 +/- 0.018058
# Mean NMSE: 0.0027814202 +/- 0.0001681786
# Best RMSE: 0.544937
# ================================================================================
# FINAL RESULTS TABLE ACROSS ALL NOISE LEVELS
# ================================================================================
# |   Noise Level | RMSE (mean+/-std)     | MSE (mean+/-std)      | NMSE (mean+/-std)             |   Best RMSE |
# |---------------|-----------------------|-----------------------|-------------------------------|-------------|
# |          0.05 | 0.488215 +/- 0.011374 | 0.238484 +/- 0.010940 | 0.0019904178 +/- 0.0000692116 |    0.446039 |
# |          0.1  | 0.584233 +/- 0.015179 | 0.341559 +/- 0.018058 | 0.0027814202 +/- 0.0001681786 |    0.544937 |
