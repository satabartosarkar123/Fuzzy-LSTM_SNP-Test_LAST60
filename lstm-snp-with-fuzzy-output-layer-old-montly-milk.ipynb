# %% [markdown]
# # Notebook 4: LSTM-SNP with Fuzzy Output Layer
#
# **Dataset**: Monthly Milk Production
#
# ## Description
# This notebook implements a **fuzzy output layer** for the LSTM-SNP model. The internal
# LSTM-SNP structure is kept completely intact. The final Dense(1) layer is replaced with a
# fuzzy inference system that takes the RNN hidden state h(t) and produces the prediction
# through Takagi-Sugeno rules.
#
# The fuzzy output layer aggregates h(t) into 2 summary features via mean-pooling, then applies
# 4 rules with fixed Gaussian membership functions and trainable consequent parameters.

# %% [markdown]
# ## Theory: Fuzzy Output Layer
#
# ### LSTM-SNP Cell (Unchanged)
# All internal LSTM-SNP equations remain exactly as in the baseline.
#
# ### Fuzzy Output Computation
# The Dense(1) output layer is replaced with fuzzy inference:
#
# **Input**: $h(t) \in \mathbb{R}^{units}$ from the RNN
#
# **Feature Aggregation**: Mean-pooling into 2 summary statistics:
# - $s_1 = \text{mean}(h_{1:units/2})$
# - $s_2 = \text{mean}(h_{units/2+1:units})$
#
# **Membership Functions** (Fixed Gaussian):
# - $\mu_{low}(s) = \exp\left(-\frac{(s-(-1))^2}{2 \cdot 0.5^2}\right)$
# - $\mu_{high}(s) = \exp\left(-\frac{(s-(+1))^2}{2 \cdot 0.5^2}\right)$
#
# **4 Takagi-Sugeno Rules** (trainable consequents):
# $y_i = a_i s_1 + b_i s_2 + c_i$
#
# **Defuzzification**: $\hat{y} = \frac{\sum_i w_i y_i}{\sum_i w_i}$

# %% [markdown]
# ## Model Architecture & Implementation

# %%
# ============================================================
# ALL IMPORTS
# ============================================================

import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras import layers
from tensorflow.keras import Model
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from math import sqrt
import matplotlib.pyplot as plt
import warnings
import os

warnings.filterwarnings('ignore')
print(f"TensorFlow version: {tf.__version__}")
print(f"NumPy version: {np.__version__}")
# Out:
# TensorFlow version: 2.20.0
# NumPy version: 2.0.2

# %% [markdown]
# ### LSTM-SNP Cell

# %%
# ============================================================
# LSTM-SNP Cell (Original — Unmodified)
# ============================================================

class LSTMSNPCell(layers.Layer):
    """
    LSTM-SNP Cell: A long short-term memory model inspired from
    spiking neural P systems.

    Gates:
      r(t) = ρ(W_r x(t) + U_r u(t-1) + b_r)   [reset]
      c(t) = ρ(W_c x(t) + U_c u(t-1) + b_c)   [consumption]
      o(t) = ρ(W_o x(t) + U_o u(t-1) + b_o)   [output/generation]
      a(t) = f(W_a x(t) + U_a u(t-1) + b_a)   [generated spikes]

    State update:
      u(t) = r(t) * u(t-1) - c(t) * a(t)
      h(t) = o(t) * a(t)

    ρ = hard_sigmoid, f = tanh
    """
    def __init__(self, units,
                 activation='tanh',
                 recurrent_activation='hard_sigmoid',
                 **kwargs):
        super().__init__(**kwargs)
        self.units = units
        self.state_size = units
        self.output_size = units

        self.activation = tf.keras.activations.get(activation)
        self.recurrent_activation = tf.keras.activations.get(recurrent_activation)

    def build(self, input_shape):
        input_dim = input_shape[-1]

        self.kernel = self.add_weight(
            shape=(input_dim, self.units * 4),
            initializer='glorot_uniform',
            name='kernel'
        )
        self.recurrent_kernel = self.add_weight(
            shape=(self.units, self.units * 4),
            initializer='orthogonal',
            name='recurrent_kernel'
        )
        self.bias = self.add_weight(
            shape=(self.units * 4,),
            initializer='zeros',
            name='bias'
        )

    def call(self, inputs, states):
        u_tm1 = states[0]

        z = tf.matmul(inputs, self.kernel) + \
            tf.matmul(u_tm1, self.recurrent_kernel) + self.bias

        z0 = z[:, :self.units]
        z1 = z[:, self.units:2*self.units]
        z2 = z[:, 2*self.units:3*self.units]
        z3 = z[:, 3*self.units:]

        r = self.recurrent_activation(z0)  # reset
        c = self.recurrent_activation(z1)  # consumption
        o = self.recurrent_activation(z2)  # output/generation
        a = self.activation(z3)            # generated spikes

        u = r * u_tm1 - c * a  # internal state
        h = o * a              # output

        return h, [u]

    def get_config(self):
        config = super().get_config()
        config.update({
            'units': self.units,
        })
        return config

# %% [markdown]
# ### Fuzzy Output Layer

# %%
# ============================================================
# Fuzzy Output Layer
# Replaces Dense(1) with fuzzy inference.
#
# Takes RNN output h(t) ∈ R^units, produces scalar prediction.
# Aggregates h(t) into 2 summary features via mean-pooling:
#   s1 = mean(h[:units//2])
#   s2 = mean(h[units//2:])
#
# Then applies 4 Takagi-Sugeno rules.
# Fixed Gaussian MFs. Trainable consequent parameters.
# ============================================================

class FuzzyOutputLayer(layers.Layer):
    """
    Fuzzy output layer: replaces Dense(1).
    Input: h(t) from RNN (shape: [batch, units])
    Output: scalar prediction (shape: [batch, 1])
    """
    def __init__(self, units_in, **kwargs):
        super().__init__(**kwargs)
        self.units_in = units_in
        self.mu_low = -1.0
        self.mu_high = 1.0
        self.sigma = 0.5

    def build(self, input_shape):
        # 4 rules, each with 3 consequent params (a, b, c)
        # y_i = a_i * s1 + b_i * s2 + c_i
        self.rule_a = self.add_weight(shape=(4,), initializer='glorot_uniform', name='rule_a')
        self.rule_b = self.add_weight(shape=(4,), initializer='glorot_uniform', name='rule_b')
        self.rule_c = self.add_weight(shape=(4,), initializer='zeros', name='rule_c')

    def _gaussian_mf(self, x, center):
        return tf.exp(-tf.square(x - center) / (2.0 * self.sigma ** 2))

    def call(self, inputs):
        half = self.units_in // 2
        # Aggregate to 2 summary features
        s1 = tf.reduce_mean(inputs[:, :half], axis=-1, keepdims=True)  # [batch, 1]
        s2 = tf.reduce_mean(inputs[:, half:], axis=-1, keepdims=True)  # [batch, 1]

        # Membership degrees
        mu_low_s1 = self._gaussian_mf(s1, self.mu_low)
        mu_high_s1 = self._gaussian_mf(s1, self.mu_high)
        mu_low_s2 = self._gaussian_mf(s2, self.mu_low)
        mu_high_s2 = self._gaussian_mf(s2, self.mu_high)

        # Rule weights
        w1 = mu_low_s1 * mu_low_s2
        w2 = mu_low_s1 * mu_high_s2
        w3 = mu_high_s1 * mu_low_s2
        w4 = mu_high_s1 * mu_high_s2

        # Consequent outputs
        y1 = self.rule_a[0] * s1 + self.rule_b[0] * s2 + self.rule_c[0]
        y2 = self.rule_a[1] * s1 + self.rule_b[1] * s2 + self.rule_c[1]
        y3 = self.rule_a[2] * s1 + self.rule_b[2] * s2 + self.rule_c[2]
        y4 = self.rule_a[3] * s1 + self.rule_b[3] * s2 + self.rule_c[3]

        # Defuzzification
        numerator = w1 * y1 + w2 * y2 + w3 * y3 + w4 * y4
        denominator = w1 + w2 + w3 + w4 + 1e-8

        return numerator / denominator

    def get_config(self):
        config = super().get_config()
        config.update({'units_in': self.units_in})
        return config

# %% [markdown]
# ### Build Model

# %%
# ============================================================
# Model Construction: LSTM-SNP with Fuzzy Output Layer
# LSTMSNPCell is UNMODIFIED.
# Dense(1) is replaced by FuzzyOutputLayer.
# ============================================================

def build_model(input_dim, units, batch_size):
    cell = LSTMSNPCell(units)
    rnn = layers.RNN(cell, return_sequences=False, stateful=True)

    inputs = tf.keras.Input(batch_shape=(batch_size, 1, input_dim))
    x = rnn(inputs)
    outputs = FuzzyOutputLayer(units_in=units)(x)

    model = tf.keras.Model(inputs, outputs)
    model.compile(optimizer='adam', loss='mean_squared_error')
    return model

# %%
# Quick model check
model = build_model(input_dim=1, units=8, batch_size=1)
model.summary()
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1787834189.725282  128993 gpu_device.cc:2020] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13756 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# I0000 00:00:1787834189.727592  128993 gpu_device.cc:2020] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 13756 MB memory:  -> device: 1, name: Tesla T4, pci bus id: 0000:00:05.0, compute capability: 7.5
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (1, 1, 1)              │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ rnn (RNN)                       │ (1, 8)                 │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ fuzzy_output_layer              │ (1, 1)                 │            12 │
# │ (FuzzyOutputLayer)              │                        │               │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 332 (1.30 KB)
#  Trainable params: 332 (1.30 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ## Data Pipeline — Monthly Milk Production

# %%
import os
for f in os.listdir('/kaggle/input/datasets/satabartosarkar1/monthly-milk-production-pounds-p-csv/'):
    print(f)
# Out:
# monthly-milk-production-pounds-p.csv

# %%
# ============================================================
# 1. Load Time Series Data
# ============================================================
series = pd.read_csv(
    '/kaggle/input/datasets/satabartosarkar1/monthly-milk-production-pounds-p-csv/monthly-milk-production-pounds-p.csv',
    header=0,
    parse_dates=[0],
    index_col=0
)

original_raw_values = series.values.flatten()
print(f"Base data shape: {original_raw_values.shape}")
print(f"Base data first 5 values: {original_raw_values[:5]}")
# Out:
# Base data shape: (168,)
# Base data first 5 values: [589 561 640 656 727]

# %%
# ============================================================
# 2. First-Order Differencing
# ============================================================

def difference(dataset, interval=1):
    diff = []
    for i in range(interval, len(dataset)):
        value = dataset[i] - dataset[i - interval]
        diff.append(value)
    return np.array(diff)

# %%
# ============================================================
# 3. Convert to Supervised Learning Format (lag=1)
# ============================================================

def timeseries_to_supervised(data, lag=1):
    df = pd.DataFrame(data)
    columns = [df.shift(i) for i in range(1, lag+1)]
    columns.append(df)
    df = pd.concat(columns, axis=1)
    df.fillna(0, inplace=True)
    return df.values

# %%
# ============================================================
# 4 & 5. Train-Test Split and Feature Scaling
# ============================================================
# NOTE: The actual application of differencing, splitting (last 60 for test), 
# and scaling is performed inside the Gaussian Noise loop below to prevent data leakage.
print("Split protocol: Last 60 samples for Testing, remainder for Training.")
# Out:
# Split protocol: Last 60 samples for Testing, remainder for Training.

# %%
# ============================================================
# 6. Reshape for RNN Input
# ============================================================
print("Reshape protocol: (samples, time_steps, features)")
# Out:
# Reshape protocol: (samples, time_steps, features)

# %% [markdown]
# ## Training Loop

# %%
# ============================================================
# Gaussian Noise Evaluation + 60-Run Experiment Protocol (Keras)
# ============================================================
s_x = np.std(original_raw_values)
noise_levels = [0.0, 0.005, 0.05, 0.10]
_molab_results = []

for lam in noise_levels:
    sigma = lam * s_x
    print("\n" + "="*80)
    print(f"EVALUATING NOISE LEVEL: {lam*100:.1f}% (lambda={lam}, sigma={sigma:.6f})")
    print("="*80 + "\n")
    
    np.random.seed(42)
    tf.random.set_seed(42)
    noise = np.random.normal(0, sigma, size=original_raw_values.shape)
    raw_values = original_raw_values + noise
    
    # 2. Difference
    diff_values = difference(raw_values, 1)
    # 3. Supervised
    supervised = timeseries_to_supervised(diff_values, 1)
    # 4. Split (Last 60 for test, no validation)
    train, test = supervised[:-60], supervised[-60:]
    # 5. Scale
    scaler = MinMaxScaler(feature_range=(-1, 1))
    scaler.fit(train)
    train_scaled = scaler.transform(train)
    test_scaled = scaler.transform(test)
    # 6. Reshape
    X_train, y_train = train_scaled[:, 0:-1], train_scaled[:, -1]
    X_train = X_train.reshape((X_train.shape[0], 1, X_train.shape[1]))
    X_test, y_test = test_scaled[:, 0:-1], test_scaled[:, -1]
    
    all_rmse = []
    all_mse = []
    all_nmse = []
    all_predictions = []
    all_losses = []
    
    # 60 RUNS, 100 EPOCHS
    for run in range(60):
        print(f'\n===== RUN {run+1}/60 [Noise {lam*100:.1f}%] =====')

        np.random.seed(run)
        tf.random.set_seed(run)

        tf.keras.backend.clear_session()
        model = build_model(input_dim=1, units=8, batch_size=1)

        # Set consumption gate (c) bias to 1.0 (unit forget bias)
        rnn_layer = model.layers[1]
        cell = rnn_layer.cell
        weights = cell.get_weights()
        bias = weights[2].copy()
        bias[8:16] = 1.0  # units=8, bias[units:2*units]
        weights[2] = bias
        cell.set_weights(weights)

        run_losses = []
        for epoch in range(100):
            history = model.fit(
                X_train, y_train,
                epochs=1, batch_size=1,
                verbose=0, shuffle=False
            )
            run_losses.append(history.history['loss'][0])
            if (epoch+1) % 10 == 0:
                print(f'  Epoch {epoch+1}/100 completed, Loss: {history.history["loss"][0]:.6f}')
            rnn_layer.reset_states()

        all_losses.append(run_losses)
        print(f'Training complete for run {run+1}')

        # Warm-up: condition hidden states on training data
        train_reshaped = train_scaled[:, 0].reshape(len(train_scaled), 1, 1)
        model.predict(train_reshaped, batch_size=1, verbose=0)

        # Test predictions (single-step)
        predictions = []
        for i in range(len(test_scaled)):
            X, y = test_scaled[i, 0:-1], test_scaled[i, -1]
            X_input = X.reshape(1, 1, len(X))
            yhat = model.predict(X_input, batch_size=1, verbose=0)[0, 0]
            
            # Invert scaling
            new_row = [x for x in X] + [yhat]
            array = np.array(new_row).reshape(1, len(new_row))
            inverted = scaler.inverse_transform(array)[0, -1]
            
            # Invert differencing
            inverted = inverted + raw_values[len(train) + i]
            predictions.append(inverted)
            expected = raw_values[len(train) + i + 1]

        # Compute metrics
        actual = raw_values[-len(predictions):]
        rmse = sqrt(mean_squared_error(actual, predictions))
        mse = mean_squared_error(actual, predictions)
        meanV = np.mean(actual)
        dominator = np.linalg.norm(np.array(predictions) - meanV, 2)
        nmse = mse / np.power(dominator, 2)
        all_rmse.append(rmse)
        all_mse.append(mse)
        all_nmse.append(nmse)
        all_predictions.append(predictions)
        print(f'Run {run+1} Metrics — RMSE: {rmse:.6f}, MSE: {mse:.6f}, NMSE: {nmse:.10f}')

    # End of 60 runs for this noise level - save best run data
    best_idx = np.argmin(all_rmse)
    _molab_results.append([lam, all_rmse[best_idx], all_mse[best_idx], all_nmse[best_idx], 
                           all_predictions[best_idx], all_losses[best_idx], raw_values])
    print(f"\nBest run for {lam*100:.1f}% noise: Run {best_idx+1} (RMSE: {all_rmse[best_idx]:.6f})")
# Out:
# ================================================================================
# EVALUATING NOISE LEVEL: 0.0% (lambda=0.0, sigma=0.000000)
# ================================================================================
#
#
# ===== RUN 1/60 [Noise 0.0%] =====
# I0000 00:00:1787834194.354246  129050 device_compiler.h:196] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
#   Epoch 10/100 completed, Loss: 0.281895
#   Epoch 20/100 completed, Loss: 0.280886
#   Epoch 30/100 completed, Loss: 0.279887
#   Epoch 40/100 completed, Loss: 0.278718
#   Epoch 50/100 completed, Loss: 0.277179
#   Epoch 60/100 completed, Loss: 0.274770
#   Epoch 70/100 completed, Loss: 0.269926
#   Epoch 80/100 completed, Loss: 0.255929
#   Epoch 90/100 completed, Loss: 0.241312
#   Epoch 100/100 completed, Loss: 0.251030
# Training complete for run 1
# Run 1 Metrics — RMSE: 48.037401, MSE: 2307.591852, NMSE: 0.0106508804
#
# ===== RUN 2/60 [Noise 0.0%] =====
#   Epoch 10/100 completed, Loss: 0.284291
#   Epoch 20/100 completed, Loss: 0.278884
#   Epoch 30/100 completed, Loss: 0.266511
#   Epoch 40/100 completed, Loss: 0.256339
#   Epoch 50/100 completed, Loss: 0.248313
#   Epoch 60/100 completed, Loss: 0.241085
#   Epoch 70/100 completed, Loss: 0.225503
#   Epoch 80/100 completed, Loss: 0.192903
#   Epoch 90/100 completed, Loss: 0.263018
#   Epoch 100/100 completed, Loss: 0.237631
# Training complete for run 2
# Run 2 Metrics — RMSE: 34.729618, MSE: 1206.146384, NMSE: 0.0063821299
#
# ===== RUN 3/60 [Noise 0.0%] =====
#   Epoch 10/100 completed, Loss: 0.260328
#   Epoch 20/100 completed, Loss: 0.229094
#   Epoch 30/100 completed, Loss: 0.211314
#   Epoch 40/100 completed, Loss: 0.158803
#   Epoch 50/100 completed, Loss: 0.085055
#   Epoch 60/100 completed, Loss: 0.066902
#   Epoch 70/100 completed, Loss: 0.054347
#   Epoch 80/100 completed, Loss: 0.049504
#   Epoch 90/100 completed, Loss: 0.050454
#   Epoch 100/100 completed, Loss: 0.046187
# Training complete for run 3
# Run 3 Metrics — RMSE: 18.630540, MSE: 347.097024, NMSE: 0.0017828186
#
# ===== RUN 4/60 [Noise 0.0%] =====
#   Epoch 10/100 completed, Loss: 0.257243
#   Epoch 20/100 completed, Loss: 0.235787
#   Epoch 30/100 completed, Loss: 0.218109
#   Epoch 40/100 completed, Loss: 0.202652
#   Epoch 50/100 completed, Loss: 0.189524
#   Epoch 60/100 completed, Loss: 0.242999
#   Epoch 70/100 completed, Loss: 0.184127
#   Epoch 80/100 completed, Loss: 0.199199
#   Epoch 90/100 completed, Loss: 0.198799
#   Epoch 100/100 completed, Loss: 0.198812
# Training complete for run 4
# Run 4 Metrics — RMSE: 34.096554, MSE: 1162.574972, NMSE: 0.0055129451
#
# ===== RUN 5/60 [Noise 0.0%] =====
#   Epoch 10/100 completed, Loss: 0.259154
#   Epoch 20/100 completed, Loss: 0.241750
#   Epoch 30/100 completed, Loss: 0.235881
#   Epoch 40/100 completed, Loss: 0.227421
#   Epoch 50/100 completed, Loss: 0.224697
#   Epoch 60/100 completed, Loss: 0.221500
#   Epoch 70/100 completed, Loss: 0.214035
#   Epoch 80/100 completed, Loss: 0.197336
#   Epoch 90/100 completed, Loss: 0.168348
#   Epoch 100/100 completed, Loss: 0.134739
# Training complete for run 5
# Run 5 Metrics — RMSE: 30.220931, MSE: 913.304697, NMSE: 0.0045060965
#
# ===== RUN 6/60 [Noise 0.0%] =====
#   Epoch 10/100 completed, Loss: 0.253517
#   Epoch 20/100 completed, Loss: 0.199009
#   Epoch 30/100 completed, Loss: 0.146057
#   Epoch 40/100 completed, Loss: 0.156714
#   Epoch 50/100 completed, Loss: 0.132439
#   Epoch 60/100 completed, Loss: 0.105442
#   Epoch 70/100 completed, Loss: 0.102980
#   Epoch 80/100 completed, Loss: 0.101117
#   Epoch 90/100 completed, Loss: 0.092723
#   Epoch 100/100 completed, Loss: 0.082856
# Training complete for run 6
# Run 6 Metrics — RMSE: 21.261948, MSE: 452.070438, NMSE: 0.0021800487
#
# ===== RUN 7/60 [Noise 0.0%] =====
#   Epoch 10/100 completed, Loss: 0.272425
#   Epoch 20/100 completed, Loss: 0.192148
#   Epoch 30/100 completed, Loss: 0.180316
#   Epoch 40/100 completed, Loss: 0.116818
#   Epoch 50/100 completed, Loss: 0.085933
#   Epoch 60/100 completed, Loss: 0.079684
#   Epoch 70/100 completed, Loss: 0.075444
#   Epoch 80/100 completed, Loss: 0.071731
#   Epoch 90/100 completed, Loss: 0.070662
#   Epoch 100/100 completed, Loss: 0.070248
# Training complete for run 7
# Run 7 Metrics — RMSE: 17.360288, MSE: 301.379612, NMSE: 0.0016032110
#
# ===== RUN 8/60 [Noise 0.0%] =====
#   Epoch 10/100 completed, Loss: 0.257934
#   Epoch 20/100 completed, Loss: 0.206369
#   Epoch 30/100 completed, Loss: 0.123105
#   Epoch 40/100 completed, Loss: 0.125005
#   Epoch 50/100 completed, Loss: 0.127101
#   Epoch 60/100 completed, Loss: 0.129061
#   Epoch 70/100 completed, Loss: 0.120114
#   Epoch 80/100 completed, Loss: 0.108231
#   Epoch 90/100 completed, Loss: 0.100628
#   Epoch 100/100 completed, Loss: 0.097926
# Training complete for run 8
# Run 8 Metrics — RMSE: 24.230789, MSE: 587.131136, NMSE: 0.0028865479
#
# ===== RUN 9/60 [Noise 0.0%] =====
#   Epoch 10/100 completed, Loss: 0.190874
#   Epoch 20/100 completed, Loss: 0.112972
#   Epoch 30/100 completed, Loss: 0.072720
#   Epoch 40/100 completed, Loss: 0.071604
#   Epoch 50/100 completed, Loss: 0.063778
#   Epoch 60/100 completed, Loss: 0.058109
#   Epoch 70/100 completed, Loss: 0.055676
#   Epoch 80/100 completed, Loss: 0.055706
#   Epoch 90/100 completed, Loss: 0.059911
#   Epoch 100/100 completed, Loss: 0.063560
# Training complete for run 9
# Run 9 Metrics — RMSE: 16.079969, MSE: 258.565405, NMSE: 0.0011739148
#
# ===== RUN 10/60 [Noise 0.0%] =====
#   Epoch 10/100 completed, Loss: 0.280335
#   Epoch 20/100 completed, Loss: 0.255812
#   Epoch 30/100 completed, Loss: 0.230322
#   Epoch 40/100 completed, Loss: 0.222557
#   Epoch 50/100 completed, Loss: 0.332342
#   Epoch 60/100 completed, Loss: 0.261451
#   Epoch 70/100 completed, Loss: 0.262991
#   Epoch 80/100 completed, Loss: 0.266559
#   Epoch 90/100 completed, Loss: 0.259779
#   Epoch 100/100 completed, Loss: 0.265983
# Training complete for run 10
# Run 10 Metrics — RMSE: 46.331612, MSE: 2146.618279, NMSE: 0.0096802763
#
# ===== RUN 11/60 [Noise 0.0%] =====
#   Epoch 10/100 completed, Loss: 0.285085
#   Epoch 20/100 completed, Loss: 0.284083
#   Epoch 30/100 completed, Loss: 0.283050
#   Epoch 40/100 completed, Loss: 0.282683
#   Epoch 50/100 completed, Loss: 0.282367
#   Epoch 60/100 completed, Loss: 0.281333
#   Epoch 70/100 completed, Loss: 0.280361
#   Epoch 80/100 completed, Loss: 0.278252
#   Epoch 90/100 completed, Loss: 0.288763
#   Epoch 100/100 completed, Loss: 0.278444
# Training complete for run 11
# Run 11 Metrics — RMSE: 47.948060, MSE: 2299.016477, NMSE: 0.0102670495
#
# ===== RUN 12/60 [Noise 0.0%] =====
#   Epoch 10/100 completed, Loss: 0.233614
#   Epoch 20/100 completed, Loss: 0.177178
#   Epoch 30/100 completed, Loss: 0.163121
#   Epoch 40/100 completed, Loss: 0.154029
#   Epoch 50/100 completed, Loss: 0.150589
#   Epoch 60/100 completed, Loss: 0.143964
#   Epoch 70/100 completed, Loss: 0.136212
#   Epoch 80/100 completed, Loss: 0.131355
#   Epoch 90/100 completed, Loss: 0.127987
#   Epoch 100/100 completed, Loss: 0.123657
# Training complete for run 12
# Run 12 Metrics — RMSE: 29.757040, MSE: 885.481456, NMSE: 0.0044678198
#
# ===== RUN 13/60 [Noise 0.0%] =====
#   Epoch 10/100 completed, Loss: 0.216778
#   Epoch 20/100 completed, Loss: 0.175849
#   Epoch 30/100 completed, Loss: 0.143982
#   Epoch 40/100 completed, Loss: 0.140216
#   Epoch 50/100 completed, Loss: 0.136889
#   Epoch 60/100 completed, Loss: 0.124143
#   Epoch 70/100 completed, Loss: 0.111515
#   Epoch 80/100 completed, Loss: 0.100342
#   Epoch 90/100 completed, Loss: 0.093649
#   Epoch 100/100 completed, Loss: 0.089193
# Training complete for run 13
# Run 13 Metrics — RMSE: 18.542794, MSE: 343.835205, NMSE: 0.0018539919
#
# ===== RUN 14/60 [Noise 0.0%] =====
#   Epoch 10/100 completed, Loss: 0.277104
#   Epoch 20/100 completed, Loss: 0.263651
#   Epoch 30/100 completed, Loss: 0.251603
#   Epoch 40/100 completed, Loss: 0.240209
#   Epoch 50/100 completed, Loss: 0.230822
#   Epoch 60/100 completed, Loss: 0.223351
#   Epoch 70/100 completed, Loss: 0.215163
#   Epoch 80/100 completed, Loss: 0.199304
#   Epoch 90/100 completed, Loss: 0.175306
#   Epoch 100/100 completed, Loss: 0.157665
# Training complete for run 14
# Run 14 Metrics — RMSE: 33.329268, MSE: 1110.840097, NMSE: 0.0054856222
#
# ===== RUN 15/60 [Noise 0.0%] =====
#   Epoch 10/100 completed, Loss: 0.276237
#   Epoch 20/100 completed, Loss: 0.231725
#   Epoch 30/100 completed, Loss: 0.284099
#   Epoch 40/100 completed, Loss: 0.279550
#   Epoch 50/100 completed, Loss: 0.278904
#   Epoch 60/100 completed, Loss: 0.277121
#   Epoch 70/100 completed, Loss: 0.255966
#   Epoch 80/100 completed, Loss: 0.245272
#   Epoch 90/100 completed, Loss: 0.177405
#   Epoch 100/100 completed, Loss: 0.128548
# Training complete for run 15
# Run 15 Metrics — RMSE: 28.777681, MSE: 828.154901, NMSE: 0.0050367940
#
# ===== RUN 16/60 [Noise 0.0%] =====
#   Epoch 10/100 completed, Loss: 0.228613
#   Epoch 20/100 completed, Loss: 0.127052
#   Epoch 30/100 completed, Loss: 0.110885
#   Epoch 40/100 completed, Loss: 0.104155
#   Epoch 50/100 completed, Loss: 0.100037
#   Epoch 60/100 completed, Loss: 0.094766
#   Epoch 70/100 completed, Loss: 0.088655
#   Epoch 80/100 completed, Loss: 0.081500
#   Epoch 90/100 completed, Loss: 0.074719
#   Epoch 100/100 completed, Loss: 0.068157
# Training complete for run 16
# Run 16 Metrics — RMSE: 18.252060, MSE: 333.137702, NMSE: 0.0017660710
#
# ===== RUN 17/60 [Noise 0.0%] =====
#   Epoch 10/100 completed, Loss: 0.214719
#   Epoch 20/100 completed, Loss: 0.161181
#   Epoch 30/100 completed, Loss: 0.123213
#   Epoch 40/100 completed, Loss: 0.087321
#   Epoch 50/100 completed, Loss: 0.083174
#   Epoch 60/100 completed, Loss: 0.081222
#   Epoch 70/100 completed, Loss: 0.083020
#   Epoch 80/100 completed, Loss: 0.080591
#   Epoch 90/100 completed, Loss: 0.078285
#   Epoch 100/100 completed, Loss: 0.072659
# Training complete for run 17
# Run 17 Metrics — RMSE: 18.655134, MSE: 348.014034, NMSE: 0.0017762142
#
# ===== RUN 18/60 [Noise 0.0%] =====
#   Epoch 10/100 completed, Loss: 0.272374
#   Epoch 20/100 completed, Loss: 0.263607
#   Epoch 30/100 completed, Loss: 0.258488
#   Epoch 40/100 completed, Loss: 0.253649
#   Epoch 50/100 completed, Loss: 0.246614
#   Epoch 60/100 completed, Loss: 0.234428
#   Epoch 70/100 completed, Loss: 0.216605
#   Epoch 80/100 completed, Loss: 0.198290
#   Epoch 90/100 completed, Loss: 0.193455
#   Epoch 100/100 completed, Loss: 0.182794
# Training complete for run 18
# Run 18 Metrics — RMSE: 36.722360, MSE: 1348.531711, NMSE: 0.0071646307
#
# ===== RUN 19/60 [Noise 0.0%] =====
#   Epoch 10/100 completed, Loss: 0.284831
#   Epoch 20/100 completed, Loss: 0.283811
#   Epoch 30/100 completed, Loss: 0.282494
#   Epoch 40/100 completed, Loss: 0.280740
#   Epoch 50/100 completed, Loss: 0.278031
#   Epoch 60/100 completed, Loss: 0.272557
#   Epoch 70/100 completed, Loss: 0.264400
#   Epoch 80/100 completed, Loss: 0.256634
#   Epoch 90/100 completed, Loss: 0.250184
#   Epoch 100/100 completed, Loss: 0.248535
# Training complete for run 19
# Run 19 Metrics — RMSE: 45.224318, MSE: 2045.238911, NMSE: 0.0085455224
#
# ===== RUN 20/60 [Noise 0.0%] =====
#   Epoch 10/100 completed, Loss: 0.281286
#   Epoch 20/100 completed, Loss: 0.274689
#   Epoch 30/100 completed, Loss: 0.267198
#   Epoch 40/100 completed, Loss: 0.263441
#   Epoch 50/100 completed, Loss: 0.258773
#   Epoch 60/100 completed, Loss: 0.255428
#   Epoch 70/100 completed, Loss: 0.244254
#   Epoch 80/100 completed, Loss: 0.219228
#   Epoch 90/100 completed, Loss: 0.195756
#   Epoch 100/100 completed, Loss: 0.189504
# Training complete for run 20
# Run 20 Metrics — RMSE: 37.701327, MSE: 1421.390046, NMSE: 0.0079569254
#
# ===== RUN 21/60 [Noise 0.0%] =====
#   Epoch 10/100 completed, Loss: 0.273735
#   Epoch 20/100 completed, Loss: 0.254002
#   Epoch 30/100 completed, Loss: 0.207017
#   Epoch 40/100 completed, Loss: 0.185774
#   Epoch 50/100 completed, Loss: 0.164729
#   Epoch 60/100 completed, Loss: 0.182296
#   Epoch 70/100 completed, Loss: 0.154728
#   Epoch 80/100 completed, Loss: 0.126019
#   Epoch 90/100 completed, Loss: 0.102129
#   Epoch 100/100 completed, Loss: 0.074770
# Training complete for run 21
# Run 21 Metrics — RMSE: 23.163626, MSE: 536.553561, NMSE: 0.0032469865
#
# ===== RUN 22/60 [Noise 0.0%] =====
#   Epoch 10/100 completed, Loss: 0.281037
#   Epoch 20/100 completed, Loss: 0.275499
#   Epoch 30/100 completed, Loss: 0.266633
#   Epoch 40/100 completed, Loss: 0.250647
#   Epoch 50/100 completed, Loss: 0.240648
#   Epoch 60/100 completed, Loss: 0.238007
#   Epoch 70/100 completed, Loss: 0.237265
#   Epoch 80/100 completed, Loss: 0.232597
#   Epoch 90/100 completed, Loss: 0.227308
#   Epoch 100/100 completed, Loss: 0.223712
# Training complete for run 22
# Run 22 Metrics — RMSE: 41.521954, MSE: 1724.072670, NMSE: 0.0089874069
#
# ===== RUN 23/60 [Noise 0.0%] =====
#   Epoch 10/100 completed, Loss: 0.226291
#   Epoch 20/100 completed, Loss: 0.193697
#   Epoch 30/100 completed, Loss: 0.150420
#   Epoch 40/100 completed, Loss: 0.129274
#   Epoch 50/100 completed, Loss: 0.119353
#   Epoch 60/100 completed, Loss: 0.109580
#   Epoch 70/100 completed, Loss: 0.103606
#   Epoch 80/100 completed, Loss: 0.101075
#   Epoch 90/100 completed, Loss: 0.110827
#   Epoch 100/100 completed, Loss: 0.105363
# Training complete for run 23
# Run 23 Metrics — RMSE: 29.628570, MSE: 877.852136, NMSE: 0.0045810818
#
# ===== RUN 24/60 [Noise 0.0%] =====
#   Epoch 10/100 completed, Loss: 0.283584
#   Epoch 20/100 completed, Loss: 0.281879
#   Epoch 30/100 completed, Loss: 0.276904
#   Epoch 40/100 completed, Loss: 0.268669
#   Epoch 50/100 completed, Loss: 0.258253
#   Epoch 60/100 completed, Loss: 0.249062
#   Epoch 70/100 completed, Loss: 0.240490
#   Epoch 80/100 completed, Loss: 0.230189
#   Epoch 90/100 completed, Loss: 0.226221
#   Epoch 100/100 completed, Loss: 0.219333
# Training complete for run 24
# Run 24 Metrics — RMSE: 42.952461, MSE: 1844.913913, NMSE: 0.0082165127
#
# ===== RUN 25/60 [Noise 0.0%] =====
#   Epoch 10/100 completed, Loss: 0.271180
#   Epoch 20/100 completed, Loss: 0.247243
#   Epoch 30/100 completed, Loss: 0.232783
#   Epoch 40/100 completed, Loss: 0.245465
#   Epoch 50/100 completed, Loss: 0.238048
#   Epoch 60/100 completed, Loss: 0.217447
#   Epoch 70/100 completed, Loss: 0.184840
#   Epoch 80/100 completed, Loss: 0.252141
#   Epoch 90/100 completed, Loss: 0.226240
#   Epoch 100/100 completed, Loss: 0.215398
# Training complete for run 25
# Run 25 Metrics — RMSE: 58.594424, MSE: 3433.306580, NMSE: 0.0110493825
#
# ===== RUN 26/60 [Noise 0.0%] =====
#   Epoch 10/100 completed, Loss: 0.264252
#   Epoch 20/100 completed, Loss: 0.220368
#   Epoch 30/100 completed, Loss: 0.181985
#   Epoch 40/100 completed, Loss: 0.157755
#   Epoch 50/100 completed, Loss: 0.124958
#   Epoch 60/100 completed, Loss: 0.110279
#   Epoch 70/100 completed, Loss: 0.088553
#   Epoch 80/100 completed, Loss: 0.078445
#   Epoch 90/100 completed, Loss: 0.070770
#   Epoch 100/100 completed, Loss: 0.064264
# Training complete for run 26
# Run 26 Metrics — RMSE: 20.584584, MSE: 423.725083, NMSE: 0.0023523813
#
# ===== RUN 27/60 [Noise 0.0%] =====
#   Epoch 10/100 completed, Loss: 0.257735
#   Epoch 20/100 completed, Loss: 0.236108
#   Epoch 30/100 completed, Loss: 0.236307
#   Epoch 40/100 completed, Loss: 0.246477
#   Epoch 50/100 completed, Loss: 0.237362
#   Epoch 60/100 completed, Loss: 0.236611
#   Epoch 70/100 completed, Loss: 0.230749
#   Epoch 80/100 completed, Loss: 0.224845
#   Epoch 90/100 completed, Loss: 0.216257
#   Epoch 100/100 completed, Loss: 0.201651
# Training complete for run 27
# Run 27 Metrics — RMSE: 37.081782, MSE: 1375.058520, NMSE: 0.0068672263
#
# ===== RUN 28/60 [Noise 0.0%] =====
#   Epoch 10/100 completed, Loss: 0.269153
#   Epoch 20/100 completed, Loss: 0.237257
#   Epoch 30/100 completed, Loss: 0.202087
#   Epoch 40/100 completed, Loss: 0.173774
#   Epoch 50/100 completed, Loss: 0.162954
#   Epoch 60/100 completed, Loss: 0.146108
#   Epoch 70/100 completed, Loss: 0.142920
#   Epoch 80/100 completed, Loss: 0.249032
#   Epoch 90/100 completed, Loss: 0.217059
#   Epoch 100/100 completed, Loss: 0.134179
# Training complete for run 28
# Run 28 Metrics — RMSE: 30.081722, MSE: 904.909985, NMSE: 0.0060281241
#
# ===== RUN 29/60 [Noise 0.0%] =====
#   Epoch 10/100 completed, Loss: 0.283570
#   Epoch 20/100 completed, Loss: 0.282304
#   Epoch 30/100 completed, Loss: 0.280320
#   Epoch 40/100 completed, Loss: 0.276916
#   Epoch 50/100 completed, Loss: 0.270354
#   Epoch 60/100 completed, Loss: 0.240470
#   Epoch 70/100 completed, Loss: 0.177969
#   Epoch 80/100 completed, Loss: 0.173360
#   Epoch 90/100 completed, Loss: 0.145201
#   Epoch 100/100 completed, Loss: 0.138195
# Training complete for run 29
# Run 29 Metrics — RMSE: 26.395882, MSE: 696.742602, NMSE: 0.0037186471
#
# ===== RUN 30/60 [Noise 0.0%] =====
#   Epoch 10/100 completed, Loss: 0.286450
#   Epoch 20/100 completed, Loss: 0.284009
#   Epoch 30/100 completed, Loss: 0.281642
#   Epoch 40/100 completed, Loss: 0.279266
#   Epoch 50/100 completed, Loss: 0.276963
#   Epoch 60/100 completed, Loss: 0.274621
#   Epoch 70/100 completed, Loss: 0.272536
#   Epoch 80/100 completed, Loss: 0.272585
#   Epoch 90/100 completed, Loss: 0.272782
#   Epoch 100/100 completed, Loss: 0.282528
# Training complete for run 30
# Run 30 Metrics — RMSE: 48.119488, MSE: 2315.485079, NMSE: 0.0100892546
#
# ===== RUN 31/60 [Noise 0.0%] =====
#   Epoch 10/100 completed, Loss: 0.260121
#   Epoch 20/100 completed, Loss: 0.178957
#   Epoch 30/100 completed, Loss: 0.188280
#   Epoch 40/100 completed, Loss: 0.227625
#   Epoch 50/100 completed, Loss: 0.175410
#   Epoch 60/100 completed, Loss: 0.201554
#   Epoch 70/100 completed, Loss: 0.122849
#   Epoch 80/100 completed, Loss: 0.082608
#   Epoch 90/100 completed, Loss: 0.071299
#   Epoch 100/100 completed, Loss: 0.068589
# Training complete for run 31
# Run 31 Metrics — RMSE: 54.044027, MSE: 2920.756844, NMSE: 0.0096432741
#
# ===== RUN 32/60 [Noise 0.0%] =====
#   Epoch 10/100 completed, Loss: 0.281384
#   Epoch 20/100 completed, Loss: 0.278973
#   Epoch 30/100 completed, Loss: 0.276532
#   Epoch 40/100 completed, Loss: 0.273118
#   Epoch 50/100 completed, Loss: 0.267865
#   Epoch 60/100 completed, Loss: 0.260623
#   Epoch 70/100 completed, Loss: 0.252720
#   Epoch 80/100 completed, Loss: 0.247345
#   Epoch 90/100 completed, Loss: 0.235766
#   Epoch 100/100 completed, Loss: 0.232973
# Training complete for run 32
# Run 32 Metrics — RMSE: 42.173593, MSE: 1778.611957, NMSE: 0.0085774673
#
# ===== RUN 33/60 [Noise 0.0%] =====
#   Epoch 10/100 completed, Loss: 0.276764
#   Epoch 20/100 completed, Loss: 0.276067
#   Epoch 30/100 completed, Loss: 0.274580
#   Epoch 40/100 completed, Loss: 0.274337
#   Epoch 50/100 completed, Loss: 0.273468
#   Epoch 60/100 completed, Loss: 0.271271
#   Epoch 70/100 completed, Loss: 0.330352
#   Epoch 80/100 completed, Loss: 0.281027
#   Epoch 90/100 completed, Loss: 0.259042
#   Epoch 100/100 completed, Loss: 0.232608
# Training complete for run 33
# Run 33 Metrics — RMSE: 43.717287, MSE: 1911.201152, NMSE: 0.0086535698
#
# ===== RUN 34/60 [Noise 0.0%] =====
#   Epoch 10/100 completed, Loss: 0.238448
#   Epoch 20/100 completed, Loss: 0.172674
#   Epoch 30/100 completed, Loss: 0.178604
#   Epoch 40/100 completed, Loss: 0.152708
#   Epoch 50/100 completed, Loss: 0.132084
#   Epoch 60/100 completed, Loss: 0.116553
#   Epoch 70/100 completed, Loss: 0.101144
#   Epoch 80/100 completed, Loss: 0.083805
#   Epoch 90/100 completed, Loss: 0.068112
#   Epoch 100/100 completed, Loss: 0.055370
# Training complete for run 34
# Run 34 Metrics — RMSE: 19.218465, MSE: 369.349416, NMSE: 0.0017159398
#
# ===== RUN 35/60 [Noise 0.0%] =====
#   Epoch 10/100 completed, Loss: 0.278098
#   Epoch 20/100 completed, Loss: 0.262927
#   Epoch 30/100 completed, Loss: 0.224424
#   Epoch 40/100 completed, Loss: 0.179456
#   Epoch 50/100 completed, Loss: 0.161357
#   Epoch 60/100 completed, Loss: 0.153526
#   Epoch 70/100 completed, Loss: 0.148224
#   Epoch 80/100 completed, Loss: 0.148300
#   Epoch 90/100 completed, Loss: 0.152607
#   Epoch 100/100 completed, Loss: 0.211370
# Training complete for run 35
# Run 35 Metrics — RMSE: 37.878772, MSE: 1434.801379, NMSE: 0.0064228839
#
# ===== RUN 36/60 [Noise 0.0%] =====
#   Epoch 10/100 completed, Loss: 0.270066
#   Epoch 20/100 completed, Loss: 0.217372
#   Epoch 30/100 completed, Loss: 0.164008
#   Epoch 40/100 completed, Loss: 0.132872
#   Epoch 50/100 completed, Loss: 0.117544
#   Epoch 60/100 completed, Loss: 0.101284
#   Epoch 70/100 completed, Loss: 0.086939
#   Epoch 80/100 completed, Loss: 0.079943
#   Epoch 90/100 completed, Loss: 0.071825
#   Epoch 100/100 completed, Loss: 0.070288
# Training complete for run 36
# Run 36 Metrics — RMSE: 19.926556, MSE: 397.067650, NMSE: 0.0021232989
#
# ===== RUN 37/60 [Noise 0.0%] =====
#   Epoch 10/100 completed, Loss: 0.274243
#   Epoch 20/100 completed, Loss: 0.259222
#   Epoch 30/100 completed, Loss: 0.228629
#   Epoch 40/100 completed, Loss: 0.214593
#   Epoch 50/100 completed, Loss: 0.220783
#   Epoch 60/100 completed, Loss: 0.215376
#   Epoch 70/100 completed, Loss: 0.185588
#   Epoch 80/100 completed, Loss: 0.161129
#   Epoch 90/100 completed, Loss: 0.117985
#   Epoch 100/100 completed, Loss: 0.085878
# Training complete for run 37
# Run 37 Metrics — RMSE: 28.677027, MSE: 822.371867, NMSE: 0.0041140669
#
# ===== RUN 38/60 [Noise 0.0%] =====
#   Epoch 10/100 completed, Loss: 0.283793
#   Epoch 20/100 completed, Loss: 0.276942
#   Epoch 30/100 completed, Loss: 0.277367
#   Epoch 40/100 completed, Loss: 0.277634
#   Epoch 50/100 completed, Loss: 0.278407
#   Epoch 60/100 completed, Loss: 0.279138
#   Epoch 70/100 completed, Loss: 0.278878
#   Epoch 80/100 completed, Loss: 0.277861
#   Epoch 90/100 completed, Loss: 0.276520
#   Epoch 100/100 completed, Loss: 0.274975
# Training complete for run 38
# Run 38 Metrics — RMSE: 47.917033, MSE: 2296.042051, NMSE: 0.0099231760
#
# ===== RUN 39/60 [Noise 0.0%] =====
#   Epoch 10/100 completed, Loss: 0.274255
#   Epoch 20/100 completed, Loss: 0.263534
#   Epoch 30/100 completed, Loss: 0.248175
#   Epoch 40/100 completed, Loss: 0.228220
#   Epoch 50/100 completed, Loss: 0.208514
#   Epoch 60/100 completed, Loss: 0.186600
#   Epoch 70/100 completed, Loss: 0.176033
#   Epoch 80/100 completed, Loss: 0.170977
#   Epoch 90/100 completed, Loss: 0.161001
#   Epoch 100/100 completed, Loss: 0.150035
# Training complete for run 39
# Run 39 Metrics — RMSE: 31.459936, MSE: 989.727557, NMSE: 0.0054317050
#
# ===== RUN 40/60 [Noise 0.0%] =====
#   Epoch 10/100 completed, Loss: 0.278935
#   Epoch 20/100 completed, Loss: 0.276124
#   Epoch 30/100 completed, Loss: 0.271595
#   Epoch 40/100 completed, Loss: 0.260434
#   Epoch 50/100 completed, Loss: 0.226557
#   Epoch 60/100 completed, Loss: 0.172515
#   Epoch 70/100 completed, Loss: 0.156946
#   Epoch 80/100 completed, Loss: 0.141090
#   Epoch 90/100 completed, Loss: 0.132522
#   Epoch 100/100 completed, Loss: 0.115881
# Training complete for run 40
# Run 40 Metrics — RMSE: 27.541466, MSE: 758.532332, NMSE: 0.0048216065
#
# ===== RUN 41/60 [Noise 0.0%] =====
#   Epoch 10/100 completed, Loss: 0.271494
#   Epoch 20/100 completed, Loss: 0.261475
#   Epoch 30/100 completed, Loss: 0.255765
#   Epoch 40/100 completed, Loss: 0.249999
#   Epoch 50/100 completed, Loss: 0.241886
#   Epoch 60/100 completed, Loss: 0.226174
#   Epoch 70/100 completed, Loss: 0.217319
#   Epoch 80/100 completed, Loss: 0.215303
#   Epoch 90/100 completed, Loss: 0.214952
#   Epoch 100/100 completed, Loss: 0.261527
# Training complete for run 41
# Run 41 Metrics — RMSE: 45.628064, MSE: 2081.920242, NMSE: 0.0092756261
#
# ===== RUN 42/60 [Noise 0.0%] =====
#   Epoch 10/100 completed, Loss: 0.283013
#   Epoch 20/100 completed, Loss: 0.245040
#   Epoch 30/100 completed, Loss: 0.214072
#   Epoch 40/100 completed, Loss: 0.184656
#   Epoch 50/100 completed, Loss: 0.183364
#   Epoch 60/100 completed, Loss: 0.191451
#   Epoch 70/100 completed, Loss: 0.184790
#   Epoch 80/100 completed, Loss: 0.221541
#   Epoch 90/100 completed, Loss: 0.155912
#   Epoch 100/100 completed, Loss: 0.143870
# Training complete for run 42
# Run 42 Metrics — RMSE: 33.763010, MSE: 1139.940860, NMSE: 0.0075818648
#
# ===== RUN 43/60 [Noise 0.0%] =====
#   Epoch 10/100 completed, Loss: 0.277333
#   Epoch 20/100 completed, Loss: 0.273040
#   Epoch 30/100 completed, Loss: 0.267738
#   Epoch 40/100 completed, Loss: 0.256561
#   Epoch 50/100 completed, Loss: 0.234368
#   Epoch 60/100 completed, Loss: 0.203399
#   Epoch 70/100 completed, Loss: 0.182780
#   Epoch 80/100 completed, Loss: 0.172244
#   Epoch 90/100 completed, Loss: 0.161399
#   Epoch 100/100 completed, Loss: 0.147458
# Training complete for run 43
# Run 43 Metrics — RMSE: 29.916750, MSE: 895.011920, NMSE: 0.0048501076
#
# ===== RUN 44/60 [Noise 0.0%] =====
#   Epoch 10/100 completed, Loss: 0.277836
#   Epoch 20/100 completed, Loss: 0.277431
#   Epoch 30/100 completed, Loss: 0.279388
#   Epoch 40/100 completed, Loss: 0.278476
#   Epoch 50/100 completed, Loss: 0.277883
#   Epoch 60/100 completed, Loss: 0.277097
#   Epoch 70/100 completed, Loss: 0.275477
#   Epoch 80/100 completed, Loss: 0.272951
#   Epoch 90/100 completed, Loss: 0.269806
#   Epoch 100/100 completed, Loss: 0.264899
# Training complete for run 44
# Run 44 Metrics — RMSE: 47.314204, MSE: 2238.633905, NMSE: 0.0097538833
#
# ===== RUN 45/60 [Noise 0.0%] =====
#   Epoch 10/100 completed, Loss: 0.261362
#   Epoch 20/100 completed, Loss: 0.249862
#   Epoch 30/100 completed, Loss: 0.238176
#   Epoch 40/100 completed, Loss: 0.229462
#   Epoch 50/100 completed, Loss: 0.217146
#   Epoch 60/100 completed, Loss: 0.205561
#   Epoch 70/100 completed, Loss: 0.203508
#   Epoch 80/100 completed, Loss: 0.201367
#   Epoch 90/100 completed, Loss: 0.196312
#   Epoch 100/100 completed, Loss: 0.187360
# Training complete for run 45
# Run 45 Metrics — RMSE: 37.143565, MSE: 1379.644433, NMSE: 0.0077387300
#
# ===== RUN 46/60 [Noise 0.0%] =====
#   Epoch 10/100 completed, Loss: 0.281561
#   Epoch 20/100 completed, Loss: 0.279765
#   Epoch 30/100 completed, Loss: 0.277949
#   Epoch 40/100 completed, Loss: 0.276298
#   Epoch 50/100 completed, Loss: 0.275078
#   Epoch 60/100 completed, Loss: 0.274213
#   Epoch 70/100 completed, Loss: 0.273666
#   Epoch 80/100 completed, Loss: 0.273294
#   Epoch 90/100 completed, Loss: 0.272495
#   Epoch 100/100 completed, Loss: 0.270221
# Training complete for run 46
# Run 46 Metrics — RMSE: 47.866662, MSE: 2291.217292, NMSE: 0.0101679672
#
# ===== RUN 47/60 [Noise 0.0%] =====
#   Epoch 10/100 completed, Loss: 0.193346
#   Epoch 20/100 completed, Loss: 0.136308
#   Epoch 30/100 completed, Loss: 0.123148
#   Epoch 40/100 completed, Loss: 0.126176
#   Epoch 50/100 completed, Loss: 0.123115
#   Epoch 60/100 completed, Loss: 0.117533
#   Epoch 70/100 completed, Loss: 0.111647
#   Epoch 80/100 completed, Loss: 0.105587
#   Epoch 90/100 completed, Loss: 0.098204
#   Epoch 100/100 completed, Loss: 0.087723
# Training complete for run 47
# Run 47 Metrics — RMSE: 20.783155, MSE: 431.939552, NMSE: 0.0024643005
#
# ===== RUN 48/60 [Noise 0.0%] =====
#   Epoch 10/100 completed, Loss: 0.281766
#   Epoch 20/100 completed, Loss: 0.270077
#   Epoch 30/100 completed, Loss: 0.249093
#   Epoch 40/100 completed, Loss: 0.209680
#   Epoch 50/100 completed, Loss: 0.191279
#   Epoch 60/100 completed, Loss: 0.174891
#   Epoch 70/100 completed, Loss: 0.133370
#   Epoch 80/100 completed, Loss: 0.145664
#   Epoch 90/100 completed, Loss: 0.116506
#   Epoch 100/100 completed, Loss: 0.096506
# Training complete for run 48
# Run 48 Metrics — RMSE: 44.255806, MSE: 1958.576340, NMSE: 0.0086218549
#
# ===== RUN 49/60 [Noise 0.0%] =====
#   Epoch 10/100 completed, Loss: 0.252405
#   Epoch 20/100 completed, Loss: 0.220348
#   Epoch 30/100 completed, Loss: 0.205523
#   Epoch 40/100 completed, Loss: 0.191334
#   Epoch 50/100 completed, Loss: 0.188873
#   Epoch 60/100 completed, Loss: 0.169911
#   Epoch 70/100 completed, Loss: 0.149219
#   Epoch 80/100 completed, Loss: 0.116438
#   Epoch 90/100 completed, Loss: 0.098152
#   Epoch 100/100 completed, Loss: 0.076382
# Training complete for run 49
# Run 49 Metrics — RMSE: 19.932944, MSE: 397.322239, NMSE: 0.0019485778
#
# ===== RUN 50/60 [Noise 0.0%] =====
#   Epoch 10/100 completed, Loss: 0.219300
#   Epoch 20/100 completed, Loss: 0.190506
#   Epoch 30/100 completed, Loss: 0.189239
#   Epoch 40/100 completed, Loss: 0.187542
#   Epoch 50/100 completed, Loss: 0.179982
#   Epoch 60/100 completed, Loss: 0.172325
#   Epoch 70/100 completed, Loss: 0.166198
#   Epoch 80/100 completed, Loss: 0.166778
#   Epoch 90/100 completed, Loss: 0.172989
#   Epoch 100/100 completed, Loss: 0.165023
# Training complete for run 50
# Run 50 Metrics — RMSE: 36.636826, MSE: 1342.257022, NMSE: 0.0078680363
#
# ===== RUN 51/60 [Noise 0.0%] =====
#   Epoch 10/100 completed, Loss: 0.279192
#   Epoch 20/100 completed, Loss: 0.264710
#   Epoch 30/100 completed, Loss: 0.236732
#   Epoch 40/100 completed, Loss: 0.253065
#   Epoch 50/100 completed, Loss: 0.247270
#   Epoch 60/100 completed, Loss: 0.229787
#   Epoch 70/100 completed, Loss: 0.209154
#   Epoch 80/100 completed, Loss: 0.172545
#   Epoch 90/100 completed, Loss: 0.134910
#   Epoch 100/100 completed, Loss: 0.299977
# Training complete for run 51
# Run 51 Metrics — RMSE: 29.478692, MSE: 868.993303, NMSE: 0.0041819947
#
# ===== RUN 52/60 [Noise 0.0%] =====
#   Epoch 10/100 completed, Loss: 0.263640
#   Epoch 20/100 completed, Loss: 0.240229
#   Epoch 30/100 completed, Loss: 0.219675
#   Epoch 40/100 completed, Loss: 0.196575
#   Epoch 50/100 completed, Loss: 0.177296
#   Epoch 60/100 completed, Loss: 0.166188
#   Epoch 70/100 completed, Loss: 0.157924
#   Epoch 80/100 completed, Loss: 0.150759
#   Epoch 90/100 completed, Loss: 0.143736
#   Epoch 100/100 completed, Loss: 0.136326
# Training complete for run 52
# Run 52 Metrics — RMSE: 31.583363, MSE: 997.508810, NMSE: 0.0060963115
#
# ===== RUN 53/60 [Noise 0.0%] =====
#   Epoch 10/100 completed, Loss: 0.234665
#   Epoch 20/100 completed, Loss: 0.177632
#   Epoch 30/100 completed, Loss: 0.129978
#   Epoch 40/100 completed, Loss: 0.110932
#   Epoch 50/100 completed, Loss: 0.103665
#   Epoch 60/100 completed, Loss: 0.098673
#   Epoch 70/100 completed, Loss: 0.094713
#   Epoch 80/100 completed, Loss: 0.091941
#   Epoch 90/100 completed, Loss: 0.091082
#   Epoch 100/100 completed, Loss: 0.088368
# Training complete for run 53
# Run 53 Metrics — RMSE: 17.130629, MSE: 293.458464, NMSE: 0.0012768810
#
# ===== RUN 54/60 [Noise 0.0%] =====
#   Epoch 10/100 completed, Loss: 0.273653
#   Epoch 20/100 completed, Loss: 0.267698
#   Epoch 30/100 completed, Loss: 0.262052
#   Epoch 40/100 completed, Loss: 0.246421
#   Epoch 50/100 completed, Loss: 0.228407
#   Epoch 60/100 completed, Loss: 0.222612
#   Epoch 70/100 completed, Loss: 0.219139
#   Epoch 80/100 completed, Loss: 0.216152
#   Epoch 90/100 completed, Loss: 0.210706
#   Epoch 100/100 completed, Loss: 0.202285
# Training complete for run 54
# Run 54 Metrics — RMSE: 37.718745, MSE: 1422.703692, NMSE: 0.0076613703
#
# ===== RUN 55/60 [Noise 0.0%] =====
#   Epoch 10/100 completed, Loss: 0.278580
#   Epoch 20/100 completed, Loss: 0.271545
#   Epoch 30/100 completed, Loss: 0.263122
#   Epoch 40/100 completed, Loss: 0.250764
#   Epoch 50/100 completed, Loss: 0.234560
#   Epoch 60/100 completed, Loss: 0.217847
#   Epoch 70/100 completed, Loss: 0.200079
#   Epoch 80/100 completed, Loss: 0.180524
#   Epoch 90/100 completed, Loss: 0.163653
#   Epoch 100/100 completed, Loss: 0.145211
# Training complete for run 55
# Run 55 Metrics — RMSE: 33.086778, MSE: 1094.734862, NMSE: 0.0072998731
#
# ===== RUN 56/60 [Noise 0.0%] =====
#   Epoch 10/100 completed, Loss: 0.253876
#   Epoch 20/100 completed, Loss: 0.227512
#   Epoch 30/100 completed, Loss: 0.153476
#   Epoch 40/100 completed, Loss: 0.138283
#   Epoch 50/100 completed, Loss: 0.119900
#   Epoch 60/100 completed, Loss: 0.102718
#   Epoch 70/100 completed, Loss: 0.090382
#   Epoch 80/100 completed, Loss: 0.080971
#   Epoch 90/100 completed, Loss: 0.074702
#   Epoch 100/100 completed, Loss: 0.069513
# Training complete for run 56
# Run 56 Metrics — RMSE: 17.236264, MSE: 297.088810, NMSE: 0.0012417374
#
# ===== RUN 57/60 [Noise 0.0%] =====
#   Epoch 10/100 completed, Loss: 0.282308
#   Epoch 20/100 completed, Loss: 0.279691
#   Epoch 30/100 completed, Loss: 0.277390
#   Epoch 40/100 completed, Loss: 0.274532
#   Epoch 50/100 completed, Loss: 0.286822
#   Epoch 60/100 completed, Loss: 0.281148
#   Epoch 70/100 completed, Loss: 0.276751
#   Epoch 80/100 completed, Loss: 0.261893
#   Epoch 90/100 completed, Loss: 0.232846
#   Epoch 100/100 completed, Loss: 0.207559
# Training complete for run 57
# Run 57 Metrics — RMSE: 40.692174, MSE: 1655.853057, NMSE: 0.0086172715
#
# ===== RUN 58/60 [Noise 0.0%] =====
#   Epoch 10/100 completed, Loss: 0.273817
#   Epoch 20/100 completed, Loss: 0.264441
#   Epoch 30/100 completed, Loss: 0.256858
#   Epoch 40/100 completed, Loss: 0.250001
#   Epoch 50/100 completed, Loss: 0.243708
#   Epoch 60/100 completed, Loss: 0.237549
#   Epoch 70/100 completed, Loss: 0.231517
#   Epoch 80/100 completed, Loss: 0.226178
#   Epoch 90/100 completed, Loss: 0.222469
#   Epoch 100/100 completed, Loss: 0.221089
# Training complete for run 58
# Run 58 Metrics — RMSE: 40.721896, MSE: 1658.272829, NMSE: 0.0067633323
#
# ===== RUN 59/60 [Noise 0.0%] =====
#   Epoch 10/100 completed, Loss: 0.275495
#   Epoch 20/100 completed, Loss: 0.266561
#   Epoch 30/100 completed, Loss: 0.257768
#   Epoch 40/100 completed, Loss: 0.248303
#   Epoch 50/100 completed, Loss: 0.240853
#   Epoch 60/100 completed, Loss: 0.237617
#   Epoch 70/100 completed, Loss: 0.232956
#   Epoch 80/100 completed, Loss: 0.217303
#   Epoch 90/100 completed, Loss: 0.202689
#   Epoch 100/100 completed, Loss: 0.194895
# Training complete for run 59
# Run 59 Metrics — RMSE: 42.834404, MSE: 1834.786161, NMSE: 0.0098230919
#
# ===== RUN 60/60 [Noise 0.0%] =====
#   Epoch 10/100 completed, Loss: 0.270316
#   Epoch 20/100 completed, Loss: 0.259647
#   Epoch 30/100 completed, Loss: 0.237434
#   Epoch 40/100 completed, Loss: 0.221653
#   Epoch 50/100 completed, Loss: 0.205319
#   Epoch 60/100 completed, Loss: 0.185871
#   Epoch 70/100 completed, Loss: 0.233317
#   Epoch 80/100 completed, Loss: 0.236822
#   Epoch 90/100 completed, Loss: 0.202006
#   Epoch 100/100 completed, Loss: 0.156157
# Training complete for run 60
# Run 60 Metrics — RMSE: 34.127597, MSE: 1164.692853, NMSE: 0.0054231404
#
# Best run for 0.0% noise: Run 9 (RMSE: 16.079969)
#
# ================================================================================
# EVALUATING NOISE LEVEL: 0.5% (lambda=0.005, sigma=0.509499)
# ================================================================================
#
#
# ===== RUN 1/60 [Noise 0.5%] =====
#   Epoch 10/100 completed, Loss: 0.258569
#   Epoch 20/100 completed, Loss: 0.250712
#   Epoch 30/100 completed, Loss: 0.245873
#   Epoch 40/100 completed, Loss: 0.239791
#   Epoch 50/100 completed, Loss: 0.230775
#   Epoch 60/100 completed, Loss: 0.216536
#   Epoch 70/100 completed, Loss: 0.195889
#   Epoch 80/100 completed, Loss: 0.179085
#   Epoch 90/100 completed, Loss: 0.164811
#   Epoch 100/100 completed, Loss: 0.150883
# Training complete for run 1
# Run 1 Metrics — RMSE: 34.638316, MSE: 1199.812912, NMSE: 0.0071074162
#
# ===== RUN 2/60 [Noise 0.5%] =====
#   Epoch 10/100 completed, Loss: 0.271415
#   Epoch 20/100 completed, Loss: 0.263045
#   Epoch 30/100 completed, Loss: 0.250273
#   Epoch 40/100 completed, Loss: 0.233535
#   Epoch 50/100 completed, Loss: 0.221049
#   Epoch 60/100 completed, Loss: 0.208322
#   Epoch 70/100 completed, Loss: 0.191611
#   Epoch 80/100 completed, Loss: 0.175159
#   Epoch 90/100 completed, Loss: 0.171465
#   Epoch 100/100 completed, Loss: 0.171981
# Training complete for run 2
# Run 2 Metrics — RMSE: 32.972435, MSE: 1087.181447, NMSE: 0.0056743703
#
# ===== RUN 3/60 [Noise 0.5%] =====
#   Epoch 10/100 completed, Loss: 0.278789
#   Epoch 20/100 completed, Loss: 0.277352
#   Epoch 30/100 completed, Loss: 0.275524
#   Epoch 40/100 completed, Loss: 0.272322
#   Epoch 50/100 completed, Loss: 0.263905
#   Epoch 60/100 completed, Loss: 0.219357
#   Epoch 70/100 completed, Loss: 0.210746
#   Epoch 80/100 completed, Loss: 0.195166
#   Epoch 90/100 completed, Loss: 0.188314
#   Epoch 100/100 completed, Loss: 0.183472
# Training complete for run 3
# Run 3 Metrics — RMSE: 36.565904, MSE: 1337.065307, NMSE: 0.0065767097
#
# ===== RUN 4/60 [Noise 0.5%] =====
#   Epoch 10/100 completed, Loss: 0.276738
#   Epoch 20/100 completed, Loss: 0.275095
#   Epoch 30/100 completed, Loss: 0.273907
#   Epoch 40/100 completed, Loss: 0.272456
#   Epoch 50/100 completed, Loss: 0.270479
#   Epoch 60/100 completed, Loss: 0.267702
#   Epoch 70/100 completed, Loss: 0.263848
#   Epoch 80/100 completed, Loss: 0.258773
#   Epoch 90/100 completed, Loss: 0.252390
#   Epoch 100/100 completed, Loss: 0.244635
# Training complete for run 4
# Run 4 Metrics — RMSE: 44.718030, MSE: 1999.702164, NMSE: 0.0095771407
#
# ===== RUN 5/60 [Noise 0.5%] =====
#   Epoch 10/100 completed, Loss: 0.267275
#   Epoch 20/100 completed, Loss: 0.194872
#   Epoch 30/100 completed, Loss: 0.167453
#   Epoch 40/100 completed, Loss: 0.180412
#   Epoch 50/100 completed, Loss: 0.181217
#   Epoch 60/100 completed, Loss: 0.163461
#   Epoch 70/100 completed, Loss: 0.119770
#   Epoch 80/100 completed, Loss: 0.093958
#   Epoch 90/100 completed, Loss: 0.090190
#   Epoch 100/100 completed, Loss: 0.080652
# Training complete for run 5
# Run 5 Metrics — RMSE: 21.130941, MSE: 446.516657, NMSE: 0.0023768804
#
# ===== RUN 6/60 [Noise 0.5%] =====
#   Epoch 10/100 completed, Loss: 0.257618
#   Epoch 20/100 completed, Loss: 0.224168
#   Epoch 30/100 completed, Loss: 0.205071
#   Epoch 40/100 completed, Loss: 0.186262
#   Epoch 50/100 completed, Loss: 0.180026
#   Epoch 60/100 completed, Loss: 0.174339
#   Epoch 70/100 completed, Loss: 0.172827
#   Epoch 80/100 completed, Loss: 0.178779
#   Epoch 90/100 completed, Loss: 0.189372
#   Epoch 100/100 completed, Loss: 0.197506
# Training complete for run 6
# Run 6 Metrics — RMSE: 40.275171, MSE: 1622.089399, NMSE: 0.0083193289
#
# ===== RUN 7/60 [Noise 0.5%] =====
#   Epoch 10/100 completed, Loss: 0.279168
#   Epoch 20/100 completed, Loss: 0.277194
#   Epoch 30/100 completed, Loss: 0.276275
#   Epoch 40/100 completed, Loss: 0.275696
#   Epoch 50/100 completed, Loss: 0.275092
#   Epoch 60/100 completed, Loss: 0.274047
#   Epoch 70/100 completed, Loss: 0.271947
#   Epoch 80/100 completed, Loss: 0.267899
#   Epoch 90/100 completed, Loss: 0.259834
#   Epoch 100/100 completed, Loss: 0.248624
# Training complete for run 7
# Run 7 Metrics — RMSE: 45.010324, MSE: 2025.929308, NMSE: 0.0092170162
#
# ===== RUN 8/60 [Noise 0.5%] =====
#   Epoch 10/100 completed, Loss: 0.278428
#   Epoch 20/100 completed, Loss: 0.275743
#   Epoch 30/100 completed, Loss: 0.272811
#   Epoch 40/100 completed, Loss: 0.270045
#   Epoch 50/100 completed, Loss: 0.269339
#   Epoch 60/100 completed, Loss: 0.268380
#   Epoch 70/100 completed, Loss: 0.266549
#   Epoch 80/100 completed, Loss: 0.263637
#   Epoch 90/100 completed, Loss: 0.260597
#   Epoch 100/100 completed, Loss: 0.258821
# Training complete for run 8
# Run 8 Metrics — RMSE: 46.264796, MSE: 2140.431335, NMSE: 0.0095391101
#
# ===== RUN 9/60 [Noise 0.5%] =====
#   Epoch 10/100 completed, Loss: 0.275202
#   Epoch 20/100 completed, Loss: 0.268010
#   Epoch 30/100 completed, Loss: 0.259411
#   Epoch 40/100 completed, Loss: 0.256236
#   Epoch 50/100 completed, Loss: 0.247497
#   Epoch 60/100 completed, Loss: 0.230865
#   Epoch 70/100 completed, Loss: 0.296069
#   Epoch 80/100 completed, Loss: 0.280626
#   Epoch 90/100 completed, Loss: 0.280928
#   Epoch 100/100 completed, Loss: 0.280974
# Training complete for run 9
# Run 9 Metrics — RMSE: 48.355573, MSE: 2338.261473, NMSE: 0.0103223955
#
# ===== RUN 10/60 [Noise 0.5%] =====
#   Epoch 10/100 completed, Loss: 0.276145
#   Epoch 20/100 completed, Loss: 0.270347
#   Epoch 30/100 completed, Loss: 0.263797
#   Epoch 40/100 completed, Loss: 0.259471
#   Epoch 50/100 completed, Loss: 0.259055
#   Epoch 60/100 completed, Loss: 0.260675
#   Epoch 70/100 completed, Loss: 0.269092
#   Epoch 80/100 completed, Loss: 0.276084
#   Epoch 90/100 completed, Loss: 0.264445
#   Epoch 100/100 completed, Loss: 0.255382
# Training complete for run 10
# Run 10 Metrics — RMSE: 45.890229, MSE: 2105.913124, NMSE: 0.0097185190
#
# ===== RUN 11/60 [Noise 0.5%] =====
#   Epoch 10/100 completed, Loss: 0.193119
#   Epoch 20/100 completed, Loss: 0.162978
#   Epoch 30/100 completed, Loss: 0.146311
#   Epoch 40/100 completed, Loss: 0.094310
#   Epoch 50/100 completed, Loss: 0.087234
#   Epoch 60/100 completed, Loss: 0.074306
#   Epoch 70/100 completed, Loss: 0.065538
#   Epoch 80/100 completed, Loss: 0.053846
#   Epoch 90/100 completed, Loss: 0.055301
#   Epoch 100/100 completed, Loss: 0.040609
# Training complete for run 11
# Run 11 Metrics — RMSE: 23.363017, MSE: 545.830545, NMSE: 0.0036426726
#
# ===== RUN 12/60 [Noise 0.5%] =====
#   Epoch 10/100 completed, Loss: 0.227634
#   Epoch 20/100 completed, Loss: 0.186673
#   Epoch 30/100 completed, Loss: 0.160403
#   Epoch 40/100 completed, Loss: 0.151443
#   Epoch 50/100 completed, Loss: 0.132975
#   Epoch 60/100 completed, Loss: 0.118397
#   Epoch 70/100 completed, Loss: 0.109182
#   Epoch 80/100 completed, Loss: 0.101125
#   Epoch 90/100 completed, Loss: 0.093358
#   Epoch 100/100 completed, Loss: 0.084164
# Training complete for run 12
# Run 12 Metrics — RMSE: 22.425977, MSE: 502.924425, NMSE: 0.0027001957
#
# ===== RUN 13/60 [Noise 0.5%] =====
#   Epoch 10/100 completed, Loss: 0.278827
#   Epoch 20/100 completed, Loss: 0.270041
#   Epoch 30/100 completed, Loss: 0.243713
#   Epoch 40/100 completed, Loss: 0.217410
#   Epoch 50/100 completed, Loss: 0.165630
#   Epoch 60/100 completed, Loss: 0.177093
#   Epoch 70/100 completed, Loss: 0.130788
#   Epoch 80/100 completed, Loss: 0.114806
#   Epoch 90/100 completed, Loss: 0.111129
#   Epoch 100/100 completed, Loss: 0.085980
# Training complete for run 13
# Run 13 Metrics — RMSE: 48.646404, MSE: 2366.472577, NMSE: 0.0101935310
#
# ===== RUN 14/60 [Noise 0.5%] =====
#   Epoch 10/100 completed, Loss: 0.276339
#   Epoch 20/100 completed, Loss: 0.226644
#   Epoch 30/100 completed, Loss: 0.200954
#   Epoch 40/100 completed, Loss: 0.179940
#   Epoch 50/100 completed, Loss: 0.161572
#   Epoch 60/100 completed, Loss: 0.144447
#   Epoch 70/100 completed, Loss: 0.126555
#   Epoch 80/100 completed, Loss: 0.108465
#   Epoch 90/100 completed, Loss: 0.095124
#   Epoch 100/100 completed, Loss: 0.086224
# Training complete for run 14
# Run 14 Metrics — RMSE: 23.761981, MSE: 564.631753, NMSE: 0.0028610753
#
# ===== RUN 15/60 [Noise 0.5%] =====
#   Epoch 10/100 completed, Loss: 0.143604
#   Epoch 20/100 completed, Loss: 0.136071
#   Epoch 30/100 completed, Loss: 0.119654
#   Epoch 40/100 completed, Loss: 0.099215
#   Epoch 50/100 completed, Loss: 0.089464
#   Epoch 60/100 completed, Loss: 0.087486
#   Epoch 70/100 completed, Loss: 0.092866
#   Epoch 80/100 completed, Loss: 0.092216
#   Epoch 90/100 completed, Loss: 0.083120
#   Epoch 100/100 completed, Loss: 0.078320
# Training complete for run 15
# Run 15 Metrics — RMSE: 16.692551, MSE: 278.641254, NMSE: 0.0015439214
#
# ===== RUN 16/60 [Noise 0.5%] =====
#   Epoch 10/100 completed, Loss: 0.259449
#   Epoch 20/100 completed, Loss: 0.194010
#   Epoch 30/100 completed, Loss: 0.122356
#   Epoch 40/100 completed, Loss: 0.087937
#   Epoch 50/100 completed, Loss: 0.085003
#   Epoch 60/100 completed, Loss: 0.080217
#   Epoch 70/100 completed, Loss: 0.074481
#   Epoch 80/100 completed, Loss: 0.070417
#   Epoch 90/100 completed, Loss: 0.066775
#   Epoch 100/100 completed, Loss: 0.062398
# Training complete for run 16
# Run 16 Metrics — RMSE: 17.192959, MSE: 295.597827, NMSE: 0.0016059478
#
# ===== RUN 17/60 [Noise 0.5%] =====
#   Epoch 10/100 completed, Loss: 0.279649
#   Epoch 20/100 completed, Loss: 0.281075
#   Epoch 30/100 completed, Loss: 0.277757
#   Epoch 40/100 completed, Loss: 0.276358
#   Epoch 50/100 completed, Loss: 0.276767
#   Epoch 60/100 completed, Loss: 0.273309
#   Epoch 70/100 completed, Loss: 0.269072
#   Epoch 80/100 completed, Loss: 0.262870
#   Epoch 90/100 completed, Loss: 0.256627
#   Epoch 100/100 completed, Loss: 0.238304
# Training complete for run 17
# Run 17 Metrics — RMSE: 43.427044, MSE: 1885.908166, NMSE: 0.0078705754
#
# ===== RUN 18/60 [Noise 0.5%] =====
#   Epoch 10/100 completed, Loss: 0.222553
#   Epoch 20/100 completed, Loss: 0.233266
#   Epoch 30/100 completed, Loss: 0.210810
#   Epoch 40/100 completed, Loss: 0.211754
#   Epoch 50/100 completed, Loss: 0.198426
#   Epoch 60/100 completed, Loss: 0.189062
#   Epoch 70/100 completed, Loss: 0.186519
#   Epoch 80/100 completed, Loss: 0.187541
#   Epoch 90/100 completed, Loss: 0.185452
#   Epoch 100/100 completed, Loss: 0.175514
# Training complete for run 18
# Run 18 Metrics — RMSE: 34.788562, MSE: 1210.244013, NMSE: 0.0070104518
#
# ===== RUN 19/60 [Noise 0.5%] =====
#   Epoch 10/100 completed, Loss: 0.276561
#   Epoch 20/100 completed, Loss: 0.274403
#   Epoch 30/100 completed, Loss: 0.272437
#   Epoch 40/100 completed, Loss: 0.271173
#   Epoch 50/100 completed, Loss: 0.271371
#   Epoch 60/100 completed, Loss: 0.272327
#   Epoch 70/100 completed, Loss: 0.273207
#   Epoch 80/100 completed, Loss: 0.273934
#   Epoch 90/100 completed, Loss: 0.274595
#   Epoch 100/100 completed, Loss: 0.275196
# Training complete for run 19
# Run 19 Metrics — RMSE: 47.940027, MSE: 2298.246144, NMSE: 0.0097989991
#
# ===== RUN 20/60 [Noise 0.5%] =====
#   Epoch 10/100 completed, Loss: 0.280859
#   Epoch 20/100 completed, Loss: 0.275733
#   Epoch 30/100 completed, Loss: 0.266412
#   Epoch 40/100 completed, Loss: 0.252931
#   Epoch 50/100 completed, Loss: 0.233796
#   Epoch 60/100 completed, Loss: 0.219826
#   Epoch 70/100 completed, Loss: 0.212446
#   Epoch 80/100 completed, Loss: 0.206519
#   Epoch 90/100 completed, Loss: 0.205824
#   Epoch 100/100 completed, Loss: 0.197324
# Training complete for run 20
# Run 20 Metrics — RMSE: 39.006563, MSE: 1521.511950, NMSE: 0.0062830053
#
# ===== RUN 21/60 [Noise 0.5%] =====
#   Epoch 10/100 completed, Loss: 0.255410
#   Epoch 20/100 completed, Loss: 0.210111
#   Epoch 30/100 completed, Loss: 0.179822
#   Epoch 40/100 completed, Loss: 0.159911
#   Epoch 50/100 completed, Loss: 0.149192
#   Epoch 60/100 completed, Loss: 0.169880
#   Epoch 70/100 completed, Loss: 0.161826
#   Epoch 80/100 completed, Loss: 0.153225
#   Epoch 90/100 completed, Loss: 0.138540
#   Epoch 100/100 completed, Loss: 0.137610
# Training complete for run 21
# Run 21 Metrics — RMSE: 29.631044, MSE: 877.998783, NMSE: 0.0050983772
#
# ===== RUN 22/60 [Noise 0.5%] =====
#   Epoch 10/100 completed, Loss: 0.275037
#   Epoch 20/100 completed, Loss: 0.250135
#   Epoch 30/100 completed, Loss: 0.155440
#   Epoch 40/100 completed, Loss: 0.120232
#   Epoch 50/100 completed, Loss: 0.117145
#   Epoch 60/100 completed, Loss: 0.106284
#   Epoch 70/100 completed, Loss: 0.090598
#   Epoch 80/100 completed, Loss: 0.080498
#   Epoch 90/100 completed, Loss: 0.072515
#   Epoch 100/100 completed, Loss: 0.069837
# Training complete for run 22
# Run 22 Metrics — RMSE: 22.606814, MSE: 511.068033, NMSE: 0.0026785723
#
# ===== RUN 23/60 [Noise 0.5%] =====
#   Epoch 10/100 completed, Loss: 0.282025
#   Epoch 20/100 completed, Loss: 0.278986
#   Epoch 30/100 completed, Loss: 0.274909
#   Epoch 40/100 completed, Loss: 0.262187
#   Epoch 50/100 completed, Loss: 0.224124
#   Epoch 60/100 completed, Loss: 0.207092
#   Epoch 70/100 completed, Loss: 0.198339
#   Epoch 80/100 completed, Loss: 0.190257
#   Epoch 90/100 completed, Loss: 0.185153
#   Epoch 100/100 completed, Loss: 0.183174
# Training complete for run 23
# Run 23 Metrics — RMSE: 39.762059, MSE: 1581.021317, NMSE: 0.0089535373
#
# ===== RUN 24/60 [Noise 0.5%] =====
#   Epoch 10/100 completed, Loss: 0.263259
#   Epoch 20/100 completed, Loss: 0.242408
#   Epoch 30/100 completed, Loss: 0.227527
#   Epoch 40/100 completed, Loss: 0.211398
#   Epoch 50/100 completed, Loss: 0.187444
#   Epoch 60/100 completed, Loss: 0.160099
#   Epoch 70/100 completed, Loss: 0.138209
#   Epoch 80/100 completed, Loss: 0.094061
#   Epoch 90/100 completed, Loss: 0.056551
#   Epoch 100/100 completed, Loss: 0.047249
# Training complete for run 24
# Run 24 Metrics — RMSE: 14.174047, MSE: 200.903594, NMSE: 0.0010571458
#
# ===== RUN 25/60 [Noise 0.5%] =====
#   Epoch 10/100 completed, Loss: 0.262631
#   Epoch 20/100 completed, Loss: 0.239848
#   Epoch 30/100 completed, Loss: 0.202806
#   Epoch 40/100 completed, Loss: 0.182948
#   Epoch 50/100 completed, Loss: 0.183949
#   Epoch 60/100 completed, Loss: 0.189813
#   Epoch 70/100 completed, Loss: 0.202379
#   Epoch 80/100 completed, Loss: 0.213173
#   Epoch 90/100 completed, Loss: 0.218344
#   Epoch 100/100 completed, Loss: 0.217326
# Training complete for run 25
# Run 25 Metrics — RMSE: 39.173302, MSE: 1534.547562, NMSE: 0.0067578717
#
# ===== RUN 26/60 [Noise 0.5%] =====
#   Epoch 10/100 completed, Loss: 0.261070
#   Epoch 20/100 completed, Loss: 0.230762
#   Epoch 30/100 completed, Loss: 0.206911
#   Epoch 40/100 completed, Loss: 0.217998
#   Epoch 50/100 completed, Loss: 0.211186
#   Epoch 60/100 completed, Loss: 0.213001
#   Epoch 70/100 completed, Loss: 0.216850
#   Epoch 80/100 completed, Loss: 0.220114
#   Epoch 90/100 completed, Loss: 0.223017
#   Epoch 100/100 completed, Loss: 0.227840
# Training complete for run 26
# Run 26 Metrics — RMSE: 40.400090, MSE: 1632.167245, NMSE: 0.0061194049
#
# ===== RUN 27/60 [Noise 0.5%] =====
#   Epoch 10/100 completed, Loss: 0.280708
#   Epoch 20/100 completed, Loss: 0.276549
#   Epoch 30/100 completed, Loss: 0.276636
#   Epoch 40/100 completed, Loss: 0.274410
#   Epoch 50/100 completed, Loss: 0.272128
#   Epoch 60/100 completed, Loss: 0.269603
#   Epoch 70/100 completed, Loss: 0.259601
#   Epoch 80/100 completed, Loss: 0.246657
# ...
#
# ===== RUN 32/60 [Noise 10.0%] =====
#   Epoch 10/100 completed, Loss: 0.222545
#   Epoch 20/100 completed, Loss: 0.221447
#   Epoch 30/100 completed, Loss: 0.220727
#   Epoch 40/100 completed, Loss: 0.219595
#   Epoch 50/100 completed, Loss: 0.217463
#   Epoch 60/100 completed, Loss: 0.213589
#   Epoch 70/100 completed, Loss: 0.211296
#   Epoch 80/100 completed, Loss: 0.205555
#   Epoch 90/100 completed, Loss: 0.201043
#   Epoch 100/100 completed, Loss: 0.197076
# Training complete for run 32
# Run 32 Metrics — RMSE: 45.966979, MSE: 2112.963173, NMSE: 0.0104634942
#
# ===== RUN 33/60 [Noise 10.0%] =====
#   Epoch 10/100 completed, Loss: 0.223477
#   Epoch 20/100 completed, Loss: 0.221468
#   Epoch 30/100 completed, Loss: 0.220013
#   Epoch 40/100 completed, Loss: 0.218325
#   Epoch 50/100 completed, Loss: 0.215722
#   Epoch 60/100 completed, Loss: 0.210120
#   Epoch 70/100 completed, Loss: 0.200445
#   Epoch 80/100 completed, Loss: 0.195231
#   Epoch 90/100 completed, Loss: 0.199290
#   Epoch 100/100 completed, Loss: 0.198691
# Training complete for run 33
# Run 33 Metrics — RMSE: 47.324821, MSE: 2239.638640, NMSE: 0.0101127403
#
# ===== RUN 34/60 [Noise 10.0%] =====
#   Epoch 10/100 completed, Loss: 0.223622
#   Epoch 20/100 completed, Loss: 0.220428
#   Epoch 30/100 completed, Loss: 0.212660
#   Epoch 40/100 completed, Loss: 0.188821
#   Epoch 50/100 completed, Loss: 0.184840
#   Epoch 60/100 completed, Loss: 0.169464
#   Epoch 70/100 completed, Loss: 0.151268
#   Epoch 80/100 completed, Loss: 0.133076
#   Epoch 90/100 completed, Loss: 0.119850
#   Epoch 100/100 completed, Loss: 0.108949
# Training complete for run 34
# Run 34 Metrics — RMSE: 34.234018, MSE: 1171.967982, NMSE: 0.0069916336
#
# ===== RUN 35/60 [Noise 10.0%] =====
#   Epoch 10/100 completed, Loss: 0.219004
#   Epoch 20/100 completed, Loss: 0.214808
#   Epoch 30/100 completed, Loss: 0.213213
#   Epoch 40/100 completed, Loss: 0.212340
#   Epoch 50/100 completed, Loss: 0.211970
#   Epoch 60/100 completed, Loss: 0.211571
#   Epoch 70/100 completed, Loss: 0.211160
#   Epoch 80/100 completed, Loss: 0.210840
#   Epoch 90/100 completed, Loss: 0.210113
#   Epoch 100/100 completed, Loss: 0.208204
# Training complete for run 35
# Run 35 Metrics — RMSE: 48.981072, MSE: 2399.145459, NMSE: 0.0099181455
#
# ===== RUN 36/60 [Noise 10.0%] =====
#   Epoch 10/100 completed, Loss: 0.221823
#   Epoch 20/100 completed, Loss: 0.221047
#   Epoch 30/100 completed, Loss: 0.219675
#   Epoch 40/100 completed, Loss: 0.215859
#   Epoch 50/100 completed, Loss: 0.202800
#   Epoch 60/100 completed, Loss: 0.193411
#   Epoch 70/100 completed, Loss: 0.171271
#   Epoch 80/100 completed, Loss: 0.159632
#   Epoch 90/100 completed, Loss: 0.151868
#   Epoch 100/100 completed, Loss: 0.147887
# Training complete for run 36
# Run 36 Metrics — RMSE: 43.096245, MSE: 1857.286308, NMSE: 0.0096116283
#
# ===== RUN 37/60 [Noise 10.0%] =====
#   Epoch 10/100 completed, Loss: 0.221632
#   Epoch 20/100 completed, Loss: 0.218348
#   Epoch 30/100 completed, Loss: 0.214382
#   Epoch 40/100 completed, Loss: 0.208860
#   Epoch 50/100 completed, Loss: 0.201715
#   Epoch 60/100 completed, Loss: 0.194872
#   Epoch 70/100 completed, Loss: 0.188395
#   Epoch 80/100 completed, Loss: 0.181094
#   Epoch 90/100 completed, Loss: 0.170751
#   Epoch 100/100 completed, Loss: 0.151241
# Training complete for run 37
# Run 37 Metrics — RMSE: 39.336519, MSE: 1547.361762, NMSE: 0.0078532328
#
# ===== RUN 38/60 [Noise 10.0%] =====
#   Epoch 10/100 completed, Loss: 0.221680
#   Epoch 20/100 completed, Loss: 0.218827
#   Epoch 30/100 completed, Loss: 0.216154
#   Epoch 40/100 completed, Loss: 0.213080
#   Epoch 50/100 completed, Loss: 0.208289
#   Epoch 60/100 completed, Loss: 0.198522
#   Epoch 70/100 completed, Loss: 0.176032
#   Epoch 80/100 completed, Loss: 0.152945
#   Epoch 90/100 completed, Loss: 0.149074
#   Epoch 100/100 completed, Loss: 0.145485
# Training complete for run 38
# Run 38 Metrics — RMSE: 40.378795, MSE: 1630.447114, NMSE: 0.0092280950
#
# ===== RUN 39/60 [Noise 10.0%] =====
#   Epoch 10/100 completed, Loss: 0.212826
#   Epoch 20/100 completed, Loss: 0.179142
#   Epoch 30/100 completed, Loss: 0.161520
#   Epoch 40/100 completed, Loss: 0.148827
#   Epoch 50/100 completed, Loss: 0.138756
#   Epoch 60/100 completed, Loss: 0.130600
#   Epoch 70/100 completed, Loss: 0.125078
#   Epoch 80/100 completed, Loss: 0.119031
#   Epoch 90/100 completed, Loss: 0.113094
#   Epoch 100/100 completed, Loss: 0.106642
# Training complete for run 39
# Run 39 Metrics — RMSE: 29.428602, MSE: 866.042611, NMSE: 0.0047740017
#
# ===== RUN 40/60 [Noise 10.0%] =====
#   Epoch 10/100 completed, Loss: 0.222801
#   Epoch 20/100 completed, Loss: 0.221953
#   Epoch 30/100 completed, Loss: 0.220763
#   Epoch 40/100 completed, Loss: 0.217881
#   Epoch 50/100 completed, Loss: 0.213558
#   Epoch 60/100 completed, Loss: 0.212497
#   Epoch 70/100 completed, Loss: 0.210906
#   Epoch 80/100 completed, Loss: 0.208266
#   Epoch 90/100 completed, Loss: 0.203784
#   Epoch 100/100 completed, Loss: 0.196205
# Training complete for run 40
# Run 40 Metrics — RMSE: 46.695455, MSE: 2180.465499, NMSE: 0.0098827367
#
# ===== RUN 41/60 [Noise 10.0%] =====
#   Epoch 10/100 completed, Loss: 0.220965
#   Epoch 20/100 completed, Loss: 0.215737
#   Epoch 30/100 completed, Loss: 0.212808
#   Epoch 40/100 completed, Loss: 0.210098
#   Epoch 50/100 completed, Loss: 0.207202
#   Epoch 60/100 completed, Loss: 0.204218
#   Epoch 70/100 completed, Loss: 0.201291
#   Epoch 80/100 completed, Loss: 0.197764
#   Epoch 90/100 completed, Loss: 0.193085
#   Epoch 100/100 completed, Loss: 0.187331
# Training complete for run 41
# Run 41 Metrics — RMSE: 46.346833, MSE: 2148.028915, NMSE: 0.0090765726
#
# ===== RUN 42/60 [Noise 10.0%] =====
#   Epoch 10/100 completed, Loss: 0.219622
#   Epoch 20/100 completed, Loss: 0.214871
#   Epoch 30/100 completed, Loss: 0.217025
#   Epoch 40/100 completed, Loss: 0.218562
#   Epoch 50/100 completed, Loss: 0.219963
#   Epoch 60/100 completed, Loss: 0.220013
#   Epoch 70/100 completed, Loss: 0.218907
#   Epoch 80/100 completed, Loss: 0.217493
#   Epoch 90/100 completed, Loss: 0.215577
#   Epoch 100/100 completed, Loss: 0.212972
# Training complete for run 42
# Run 42 Metrics — RMSE: 49.504785, MSE: 2450.723772, NMSE: 0.0109991045
#
# ===== RUN 43/60 [Noise 10.0%] =====
#   Epoch 10/100 completed, Loss: 0.220443
#   Epoch 20/100 completed, Loss: 0.217604
#   Epoch 30/100 completed, Loss: 0.215309
#   Epoch 40/100 completed, Loss: 0.212552
#   Epoch 50/100 completed, Loss: 0.209123
#   Epoch 60/100 completed, Loss: 0.205081
#   Epoch 70/100 completed, Loss: 0.200871
#   Epoch 80/100 completed, Loss: 0.197307
#   Epoch 90/100 completed, Loss: 0.195027
#   Epoch 100/100 completed, Loss: 0.193741
# Training complete for run 43
# Run 43 Metrics — RMSE: 46.221506, MSE: 2136.427595, NMSE: 0.0095213548
#
# ===== RUN 44/60 [Noise 10.0%] =====
#   Epoch 10/100 completed, Loss: 0.201408
#   Epoch 20/100 completed, Loss: 0.140886
#   Epoch 30/100 completed, Loss: 0.134990
#   Epoch 40/100 completed, Loss: 0.133836
#   Epoch 50/100 completed, Loss: 0.131255
#   Epoch 60/100 completed, Loss: 0.129167
#   Epoch 70/100 completed, Loss: 0.126137
#   Epoch 80/100 completed, Loss: 0.121800
#   Epoch 90/100 completed, Loss: 0.121272
#   Epoch 100/100 completed, Loss: 0.121132
# Training complete for run 44
# Run 44 Metrics — RMSE: 32.514899, MSE: 1057.218641, NMSE: 0.0054304091
#
# ===== RUN 45/60 [Noise 10.0%] =====
#   Epoch 10/100 completed, Loss: 0.222557
#   Epoch 20/100 completed, Loss: 0.220498
#   Epoch 30/100 completed, Loss: 0.218859
#   Epoch 40/100 completed, Loss: 0.217282
#   Epoch 50/100 completed, Loss: 0.215726
#   Epoch 60/100 completed, Loss: 0.214207
#   Epoch 70/100 completed, Loss: 0.212659
#   Epoch 80/100 completed, Loss: 0.210880
#   Epoch 90/100 completed, Loss: 0.208514
#   Epoch 100/100 completed, Loss: 0.205052
# Training complete for run 45
# Run 45 Metrics — RMSE: 48.489344, MSE: 2351.216461, NMSE: 0.0104949969
#
# ===== RUN 46/60 [Noise 10.0%] =====
#   Epoch 10/100 completed, Loss: 0.220752
#   Epoch 20/100 completed, Loss: 0.217899
#   Epoch 30/100 completed, Loss: 0.215355
#   Epoch 40/100 completed, Loss: 0.212429
#   Epoch 50/100 completed, Loss: 0.207722
#   Epoch 60/100 completed, Loss: 0.197729
#   Epoch 70/100 completed, Loss: 0.172319
#   Epoch 80/100 completed, Loss: 0.141906
#   Epoch 90/100 completed, Loss: 0.141628
#   Epoch 100/100 completed, Loss: 0.141223
# Training complete for run 46
# Run 46 Metrics — RMSE: 36.634663, MSE: 1342.098530, NMSE: 0.0066461261
#
# ===== RUN 47/60 [Noise 10.0%] =====
#   Epoch 10/100 completed, Loss: 0.221644
#   Epoch 20/100 completed, Loss: 0.216792
#   Epoch 30/100 completed, Loss: 0.208657
#   Epoch 40/100 completed, Loss: 0.199445
#   Epoch 50/100 completed, Loss: 0.178258
#   Epoch 60/100 completed, Loss: 0.168099
#   Epoch 70/100 completed, Loss: 0.166430
#   Epoch 80/100 completed, Loss: 0.160417
#   Epoch 90/100 completed, Loss: 0.153986
#   Epoch 100/100 completed, Loss: 0.143245
# Training complete for run 47
# Run 47 Metrics — RMSE: 71.864728, MSE: 5164.539154, NMSE: 0.0118440308
#
# ===== RUN 48/60 [Noise 10.0%] =====
#   Epoch 10/100 completed, Loss: 0.221855
#   Epoch 20/100 completed, Loss: 0.220563
#   Epoch 30/100 completed, Loss: 0.219699
#   Epoch 40/100 completed, Loss: 0.219119
#   Epoch 50/100 completed, Loss: 0.218579
#   Epoch 60/100 completed, Loss: 0.218048
#   Epoch 70/100 completed, Loss: 0.217495
#   Epoch 80/100 completed, Loss: 0.216966
#   Epoch 90/100 completed, Loss: 0.216390
#   Epoch 100/100 completed, Loss: 0.215465
# Training complete for run 48
# Run 48 Metrics — RMSE: 49.577178, MSE: 2457.896544, NMSE: 0.0102756690
#
# ===== RUN 49/60 [Noise 10.0%] =====
#   Epoch 10/100 completed, Loss: 0.221754
#   Epoch 20/100 completed, Loss: 0.219922
#   Epoch 30/100 completed, Loss: 0.216529
#   Epoch 40/100 completed, Loss: 0.204667
#   Epoch 50/100 completed, Loss: 0.203123
#   Epoch 60/100 completed, Loss: 0.192771
#   Epoch 70/100 completed, Loss: 0.201074
#   Epoch 80/100 completed, Loss: 0.194404
#   Epoch 90/100 completed, Loss: 0.188148
#   Epoch 100/100 completed, Loss: 0.185641
# Training complete for run 49
# Run 49 Metrics — RMSE: 55.368123, MSE: 3065.629040, NMSE: 0.0131068546
#
# ===== RUN 50/60 [Noise 10.0%] =====
#   Epoch 10/100 completed, Loss: 0.222249
#   Epoch 20/100 completed, Loss: 0.220976
#   Epoch 30/100 completed, Loss: 0.220183
#   Epoch 40/100 completed, Loss: 0.219581
#   Epoch 50/100 completed, Loss: 0.218563
#   Epoch 60/100 completed, Loss: 0.215901
#   Epoch 70/100 completed, Loss: 0.211048
#   Epoch 80/100 completed, Loss: 0.211743
#   Epoch 90/100 completed, Loss: 0.207075
#   Epoch 100/100 completed, Loss: 0.200541
# Training complete for run 50
# Run 50 Metrics — RMSE: 49.697649, MSE: 2469.856322, NMSE: 0.0105017639
#
# ===== RUN 51/60 [Noise 10.0%] =====
#   Epoch 10/100 completed, Loss: 0.221693
#   Epoch 20/100 completed, Loss: 0.216237
#   Epoch 30/100 completed, Loss: 0.208224
#   Epoch 40/100 completed, Loss: 0.194533
#   Epoch 50/100 completed, Loss: 0.177996
#   Epoch 60/100 completed, Loss: 0.159779
#   Epoch 70/100 completed, Loss: 0.143851
#   Epoch 80/100 completed, Loss: 0.130983
#   Epoch 90/100 completed, Loss: 0.121591
#   Epoch 100/100 completed, Loss: 0.114467
# Training complete for run 51
# Run 51 Metrics — RMSE: 37.756287, MSE: 1425.537203, NMSE: 0.0079764748
#
# ===== RUN 52/60 [Noise 10.0%] =====
#   Epoch 10/100 completed, Loss: 0.210347
#   Epoch 20/100 completed, Loss: 0.149611
#   Epoch 30/100 completed, Loss: 0.144751
#   Epoch 40/100 completed, Loss: 0.134019
#   Epoch 50/100 completed, Loss: 0.122269
#   Epoch 60/100 completed, Loss: 0.087419
#   Epoch 70/100 completed, Loss: 0.080457
#   Epoch 80/100 completed, Loss: 0.079665
#   Epoch 90/100 completed, Loss: 0.079842
#   Epoch 100/100 completed, Loss: 0.081018
# Training complete for run 52
# Run 52 Metrics — RMSE: 30.097648, MSE: 905.868408, NMSE: 0.0044170720
#
# ===== RUN 53/60 [Noise 10.0%] =====
#   Epoch 10/100 completed, Loss: 0.222478
#   Epoch 20/100 completed, Loss: 0.220793
#   Epoch 30/100 completed, Loss: 0.218420
#   Epoch 40/100 completed, Loss: 0.214232
#   Epoch 50/100 completed, Loss: 0.204756
#   Epoch 60/100 completed, Loss: 0.199454
#   Epoch 70/100 completed, Loss: 0.188239
#   Epoch 80/100 completed, Loss: 0.176576
#   Epoch 90/100 completed, Loss: 0.167061
#   Epoch 100/100 completed, Loss: 0.157106
# Training complete for run 53
# Run 53 Metrics — RMSE: 43.138863, MSE: 1860.961507, NMSE: 0.0080107206
#
# ===== RUN 54/60 [Noise 10.0%] =====
#   Epoch 10/100 completed, Loss: 0.220053
#   Epoch 20/100 completed, Loss: 0.214856
#   Epoch 30/100 completed, Loss: 0.191008
#   Epoch 40/100 completed, Loss: 0.192246
#   Epoch 50/100 completed, Loss: 0.164361
#   Epoch 60/100 completed, Loss: 0.134729
#   Epoch 70/100 completed, Loss: 0.120131
#   Epoch 80/100 completed, Loss: 0.110187
#   Epoch 90/100 completed, Loss: 0.088477
#   Epoch 100/100 completed, Loss: 0.071962
# Training complete for run 54
# Run 54 Metrics — RMSE: 28.101282, MSE: 789.682056, NMSE: 0.0041742752
#
# ===== RUN 55/60 [Noise 10.0%] =====
#   Epoch 10/100 completed, Loss: 0.221065
#   Epoch 20/100 completed, Loss: 0.215838
#   Epoch 30/100 completed, Loss: 0.210644
#   Epoch 40/100 completed, Loss: 0.203816
#   Epoch 50/100 completed, Loss: 0.193251
#   Epoch 60/100 completed, Loss: 0.183807
#   Epoch 70/100 completed, Loss: 0.178793
#   Epoch 80/100 completed, Loss: 0.174181
#   Epoch 90/100 completed, Loss: 0.166713
#   Epoch 100/100 completed, Loss: 0.159265
# Training complete for run 55
# Run 55 Metrics — RMSE: 41.207612, MSE: 1698.067270, NMSE: 0.0086874243
#
# ===== RUN 56/60 [Noise 10.0%] =====
#   Epoch 10/100 completed, Loss: 0.220708
#   Epoch 20/100 completed, Loss: 0.216222
#   Epoch 30/100 completed, Loss: 0.210653
#   Epoch 40/100 completed, Loss: 0.205505
#   Epoch 50/100 completed, Loss: 0.201353
#   Epoch 60/100 completed, Loss: 0.197858
#   Epoch 70/100 completed, Loss: 0.194587
#   Epoch 80/100 completed, Loss: 0.191558
#   Epoch 90/100 completed, Loss: 0.189200
#   Epoch 100/100 completed, Loss: 0.187780
# Training complete for run 56
# Run 56 Metrics — RMSE: 45.753008, MSE: 2093.337758, NMSE: 0.0089521637
#
# ===== RUN 57/60 [Noise 10.0%] =====
#   Epoch 10/100 completed, Loss: 0.221034
#   Epoch 20/100 completed, Loss: 0.218877
#   Epoch 30/100 completed, Loss: 0.216125
#   Epoch 40/100 completed, Loss: 0.212807
#   Epoch 50/100 completed, Loss: 0.208820
#   Epoch 60/100 completed, Loss: 0.204223
#   Epoch 70/100 completed, Loss: 0.199528
#   Epoch 80/100 completed, Loss: 0.195386
#   Epoch 90/100 completed, Loss: 0.191521
#   Epoch 100/100 completed, Loss: 0.186853
# Training complete for run 57
# Run 57 Metrics — RMSE: 47.277817, MSE: 2235.191945, NMSE: 0.0091549016
#
# ===== RUN 58/60 [Noise 10.0%] =====
#   Epoch 10/100 completed, Loss: 0.215991
#   Epoch 20/100 completed, Loss: 0.202585
#   Epoch 30/100 completed, Loss: 0.195284
#   Epoch 40/100 completed, Loss: 0.189876
#   Epoch 50/100 completed, Loss: 0.186176
#   Epoch 60/100 completed, Loss: 0.184236
#   Epoch 70/100 completed, Loss: 0.183158
#   Epoch 80/100 completed, Loss: 0.179751
#   Epoch 90/100 completed, Loss: 0.171492
#   Epoch 100/100 completed, Loss: 0.158868
# Training complete for run 58
# Run 58 Metrics — RMSE: 39.034834, MSE: 1523.718236, NMSE: 0.0084017145
#
# ===== RUN 59/60 [Noise 10.0%] =====
#   Epoch 10/100 completed, Loss: 0.219022
#   Epoch 20/100 completed, Loss: 0.213533
#   Epoch 30/100 completed, Loss: 0.207651
#   Epoch 40/100 completed, Loss: 0.199737
#   Epoch 50/100 completed, Loss: 0.191245
#   Epoch 60/100 completed, Loss: 0.182461
#   Epoch 70/100 completed, Loss: 0.164050
#   Epoch 80/100 completed, Loss: 0.147314
#   Epoch 90/100 completed, Loss: 0.133063
#   Epoch 100/100 completed, Loss: 0.124781
# Training complete for run 59
# Run 59 Metrics — RMSE: 35.088619, MSE: 1231.211206, NMSE: 0.0062833018
#
# ===== RUN 60/60 [Noise 10.0%] =====
#   Epoch 10/100 completed, Loss: 0.223438
#   Epoch 20/100 completed, Loss: 0.221651
#   Epoch 30/100 completed, Loss: 0.220466
#   Epoch 40/100 completed, Loss: 0.219015
#   Epoch 50/100 completed, Loss: 0.216625
#   Epoch 60/100 completed, Loss: 0.212983
#   Epoch 70/100 completed, Loss: 0.207956
#   Epoch 80/100 completed, Loss: 0.203913
#   Epoch 90/100 completed, Loss: 0.199017
#   Epoch 100/100 completed, Loss: 0.193089
# Training complete for run 60
# Run 60 Metrics — RMSE: 47.590416, MSE: 2264.847678, NMSE: 0.0091596575
#
# Best run for 10.0% noise: Run 54 (RMSE: 28.101282)

# %% [markdown]
# ## Results

# %%
# ============================================================
# Final Metrics Summary & Plots per Noise Level
# ============================================================
from tabulate import tabulate

for lam, best_rmse, best_mse, best_nmse, best_predictions, best_losses, raw_values_for_plot in _molab_results:
    print("\n" + "="*80)
    print(f"RESULTS FOR NOISE LEVEL: {lam*100:.1f}%")
    print("="*80)
    
    print('=== Best Run Metrics ===')
    print(f'RMSE: {best_rmse:.6f}')
    print(f'MSE:  {best_mse:.6f}')
    print(f'NMSE: {best_nmse:.10f}')
    
    actual = raw_values_for_plot[-60:]
    
    plt.figure(figsize=(12, 5))
    plt.plot(actual, label='Actual', color='blue', linewidth=1.5)
    plt.plot(best_predictions, label='Predicted (Best Run)', color='red',
             linewidth=1.5, linestyle='--')
    plt.title(f'Predictions vs Actual (Noise {lam*100:.1f}%)')
    plt.xlabel('Time Step')
    plt.ylabel('Value')
    plt.legend()
    plt.grid(True, alpha=0.3)
    plt.tight_layout()
    plt.show()

    plt.figure(figsize=(12, 4))
    plt.plot(best_losses, color='green', linewidth=1.0)
    plt.title(f'Training Loss (Best Run, Noise {lam*100:.1f}%)')
    plt.xlabel('Epoch')
    plt.ylabel('MSE Loss')
    plt.grid(True, alpha=0.3)
    plt.tight_layout()
    plt.show()

# Global summary table
print("\n" + "="*80)
print("FINAL RESULTS TABLE ACROSS ALL NOISE LEVELS")
print("="*80)
df_res = pd.DataFrame([r[:4] for r in _molab_results], columns=['Noise Level (lambda)', 'RMSE', 'MSE', 'NMSE'])
print(tabulate(df_res, headers='keys', tablefmt='github', showindex=False))
# Out:
# ================================================================================
# RESULTS FOR NOISE LEVEL: 0.0%
# ================================================================================
# === Best Run Metrics ===
# RMSE: 16.079969
# MSE:  258.565405
# NMSE: 0.0011739148
# ================================================================================
# RESULTS FOR NOISE LEVEL: 0.5%
# ================================================================================
# === Best Run Metrics ===
# RMSE: 14.174047
# MSE:  200.903594
# NMSE: 0.0010571458
# ================================================================================
# RESULTS FOR NOISE LEVEL: 5.0%
# ================================================================================
# === Best Run Metrics ===
# RMSE: 17.973807
# MSE:  323.057753
# NMSE: 0.0018191884
# ================================================================================
# RESULTS FOR NOISE LEVEL: 10.0%
# ================================================================================
# === Best Run Metrics ===
# RMSE: 28.101282
# MSE:  789.682056
# NMSE: 0.0041742752
# ================================================================================
# FINAL RESULTS TABLE ACROSS ALL NOISE LEVELS
# ================================================================================
# |   Noise Level (lambda) |    RMSE |     MSE |       NMSE |
# |------------------------|---------|---------|------------|
# |                  0     | 16.08   | 258.565 | 0.00117391 |
# |                  0.005 | 14.174  | 200.904 | 0.00105715 |
# |                  0.05  | 17.9738 | 323.058 | 0.00181919 |
# |                  0.1   | 28.1013 | 789.682 | 0.00417428 |

# %% [markdown]
# ## Observations
#
# ### Gaussian Noise robustness on Monthly Milk Production
#
# **Run the notebook to populate results.**
