# %% [markdown]
# ## Theory: LSTM-SNP Architecture
#
# The LSTM-SNP model uses a custom recurrent cell inspired by Spiking Neural P (SNP) systems.
#
# ### Gate Equations
#
# $$r(t) = \rho(W_r x(t) + U_r u(t-1) + b_r)$$ — Reset gate
#
# $$c(t) = \rho(W_c x(t) + U_c u(t-1) + b_c)$$ — Consumption gate
#
# $$o(t) = \rho(W_o x(t) + U_o u(t-1) + b_o)$$ — Output gate
#
# $$a(t) = f(W_a x(t) + U_a u(t-1) + b_a)$$ — Generated spikes
#
# ### State Update
#
# $$u(t) = r(t) \cdot u(t-1) - c(t) \cdot a(t)$$
#
# $$h(t) = o(t) \cdot a(t)$$
#
# where $\rho$ = hard sigmoid, $f$ = tanh

# %% [markdown]
# # Baseline LSTM-SNP — Dow Jones Industrial Index
# ## + Gaussian Input-Noise Robustness (0.5% / 5% / 10% / 15%)
#
# x_noisy(t) = x(t) + eps(t),  eps(t) ~ N(0, sigma_eps^2),  sigma_eps = eta * std(x)
#
# Noise is injected into input features only (never targets), so the resulting
# metrics reflect model sensitivity to input perturbation, not label corruption.
#
# This version includes: a corrected NMSE denominator, validation-based early
# stopping, gradient clipping, and noise-sweep averaging over multiple ε(t)
# draws with a paired per-model degradation test.

# %%
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from math import sqrt
from scipy import stats
import matplotlib.pyplot as plt

print(f"PyTorch version: {torch.__version__}")
print(f"NumPy version: {np.__version__}")

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"Using device: {device}")
# Out:
# PyTorch version: 2.11.0+cu128
# NumPy version: 2.5.1
# Using device: cuda

# %% [markdown]
# ## Model Architecture & Implementation

# %% [markdown]
# ### LSTM-SNP Cell

# %%
#with noise


class LSTMSNPCell(nn.Module):
    """
    LSTM-SNP Cell: gates r, c, o (hard sigmoid) and generated spikes a (tanh).
    u(t) = r(t)*u(t-1) - c(t)*a(t)
    h(t) = o(t)*a(t)
    """
    def __init__(self, input_size, hidden_size):
        super().__init__()
        self.hidden_size = hidden_size
        self.kernel = nn.Linear(input_size, hidden_size * 4, bias=False)
        self.recurrent_kernel = nn.Linear(hidden_size, hidden_size * 4, bias=False)
        self.bias = nn.Parameter(torch.zeros(hidden_size * 4))

        nn.init.xavier_uniform_(self.kernel.weight)
        nn.init.orthogonal_(self.recurrent_kernel.weight)

    def hard_sigmoid(self, x):
        return torch.clamp(0.2 * x + 0.5, 0.0, 1.0)

    def forward(self, x, u_tm1):
        z = self.kernel(x) + self.recurrent_kernel(u_tm1) + self.bias
        z0, z1, z2, z3 = z.chunk(4, dim=-1)

        r = self.hard_sigmoid(z0)   # reset
        c = self.hard_sigmoid(z1)   # consumption
        o = self.hard_sigmoid(z2)   # output/generation
        a = torch.tanh(z3)          # generated spikes

        u = r * u_tm1 - c * a
        h = o * a
        return h, u

# %% [markdown]
# ### Build Model

# %%
#with noise
class RNNModel(nn.Module):
    def __init__(self, input_size, hidden_size):
        super().__init__()
        self.hidden_size = hidden_size
        self.cell = LSTMSNPCell(input_size, hidden_size)
        self.out = nn.Linear(hidden_size, 1)
        self.u = None

    def reset_states(self, batch_size, device):
        self.u = torch.zeros(batch_size, self.hidden_size, device=device)

    def forward(self, x):
        # x is (batch, 1, input_size)
        if self.u is None or self.u.device != x.device:
            self.reset_states(x.size(0), x.device)
        h, self.u = self.cell(x[:, 0, :], self.u)
        return self.out(h)


def build_model(input_dim, units):
    return RNNModel(input_dim, units)

# %%
#with noise
model = build_model(input_dim=1, units=8).to(device)
print(model)

total_params = sum(p.numel() for p in model.parameters())
trainable_params = sum(p.numel() for p in model.parameters() if p.requires_grad)
print(f"\nTotal params: {total_params:,}")
print(f"Trainable params: {trainable_params:,}")
# Out:
# RNNModel(
#   (cell): LSTMSNPCell(
#     (kernel): Linear(in_features=1, out_features=32, bias=False)
#     (recurrent_kernel): Linear(in_features=8, out_features=32, bias=False)
#   )
#   (out): Linear(in_features=8, out_features=1, bias=True)
# )
#
# Total params: 329
# Trainable params: 329

# %% [markdown]
# ## Data Pipeline — Dow Jones Industrial Index

# %%
DATA_PATH = r'C:\Users\paulp\OneDrive\Desktop\fuzzy_LSTM\dataset\monthly-lake-erie-levels-1921-19.csv'

series = pd.read_csv(DATA_PATH, header=0, parse_dates=[0], index_col=0)
raw_values = series.values.flatten()

# %%
# ============================================================
# 2. First-Order Differencing
# ============================================================

def difference(dataset, interval=1):
    diff = []
    for i in range(interval, len(dataset)):
        value = dataset[i] - dataset[i - interval]
        diff.append(value)
    return np.array(diff)

diff_values = difference(raw_values, 1)

# %%
# ============================================================
# 3. Convert to Supervised Learning Format (lag=1)
# ============================================================

def timeseries_to_supervised(data, lag=1):
    df = pd.DataFrame(data)
    columns = [df.shift(i) for i in range(1, lag+1)]
    columns.append(df)
    df = pd.concat(columns, axis=1)
    df.fillna(0, inplace=True)
    return df.values

supervised = timeseries_to_supervised(diff_values, 1)
print(f"Supervised data shape: {supervised.shape}")
# Out:
# Supervised data shape: (599, 2)

# %%
#with noise Train-Validation-Test Split (Last 60 points as Test)
n = len(supervised)
test_size = 60
train_val = supervised[:n - test_size]
test = supervised[n - test_size:]

val_size = int(len(train_val) * 0.1)
train = train_val[:-val_size]
val = train_val[-val_size:]

print(f"Train: {train.shape}, Val: {val.shape}, Test: {test.shape}")

scaler = MinMaxScaler(feature_range=(-1, 1))
scaler.fit(train)  # fit only on train to avoid leakage
train_scaled = scaler.transform(train)
val_scaled = scaler.transform(val)
test_scaled = scaler.transform(test)
# Out:
# Train: (486, 2), Val: (53, 2), Test: (60, 2)

# %%
# ============================================================
# 6. Reshape for RNN Input
# ============================================================

X_train, y_train = train_scaled[:, 0:-1], train_scaled[:, -1]
X_train = X_train.reshape((X_train.shape[0], 1, X_train.shape[1]))

X_test, y_test = test_scaled[:, 0:-1], test_scaled[:, -1]
print(f"X_train shape: {X_train.shape}, y_train shape: {y_train.shape}")
# Out:
# X_train shape: (486, 1, 1), y_train shape: (486,)

# %%
#Gaussian noise injection (Eq. 29–30)
ref_std = X_train.std()
print(f"Reference std(x) used for noise scaling (train inputs): {ref_std:.6f}")

NOISE_LEVELS = [0.005, 0.05, 0.10, 0.15]  # 0.5%, 5%, 10%, 15%

def add_gaussian_noise(X, noise_level, ref_std, seed=None):
    """
    x_noisy(t) = x(t) + eps(t),  eps(t) ~ N(0, sigma_eps^2),  sigma_eps = noise_level * std(x)
    Applied to input features X only — never to targets/labels.
    """
    rng = np.random.default_rng(seed)
    sigma_eps = noise_level * ref_std
    eps = rng.normal(loc=0.0, scale=sigma_eps, size=X.shape)
    return X + eps
# Out:
# Reference std(x) used for noise scaling (train inputs): 0.303928

# %%
#Evaluation function

def evaluate_on_test(model, X_test_eval, train, train_scaled, raw_values, scaler, device):
    """
    Warms up the model's recurrent state on clean training data, then runs
    single-step-ahead prediction on X_test_eval (clean or Gaussian-noise-corrupted
    input features). Test targets are always the clean, ground-truth values.
    """
    model.eval()
    model.reset_states(1, device)

    with torch.no_grad():
        for i in range(len(train_scaled)):
            X_raw = train_scaled[i, 0:-1]
            X_input = torch.tensor(X_raw, dtype=torch.float32).view(1, 1, len(X_raw)).to(device)
            model(X_input)

        predictions = []
        for i in range(len(X_test_eval)):
            X = X_test_eval[i]
            X_input = torch.tensor(X, dtype=torch.float32).view(1, 1, len(X)).to(device)
            yhat = model(X_input).item()

            new_row = [x for x in X] + [yhat]
            array = np.array(new_row).reshape(1, len(new_row))
            inverted = scaler.inverse_transform(array)[0, -1]
            inverted = inverted + raw_values[len(train) + i]
            predictions.append(inverted)

    actual = raw_values[-len(X_test_eval):]
    mse = mean_squared_error(actual, predictions)
    rmse = sqrt(mse)
    meanV = np.mean(actual)
    dominator = np.linalg.norm(np.array(actual) - meanV, 2)   # FIX: was predictions - meanV
    nmse = mse / np.power(dominator, 2)
    return predictions, rmse, mse, nmse

# %% [markdown]
# #Training loop

# %%
import os

#Training loop (60 runs, early stopping + gradient clipping) -- with checkpointing
#
# Checkpointing: after every run, the trained (best-val) model's state_dict +
# that run's metrics are written to disk under CHECKPOINT_DIR. If this cell is
# re-run (kernel restart, crash, "Restart & Run All", etc.), it picks up from
# the last completed run instead of retraining from scratch.

CHECKPOINT_DIR = "checkpoints_baseline_dowjones"
os.makedirs(CHECKPOINT_DIR, exist_ok=True)

def _ckpt_path(run):
    return os.path.join(CHECKPOINT_DIR, f"run_{run}.pt")

def _summary_path():
    return os.path.join(CHECKPOINT_DIR, "summary.pt")

all_rmse = []
all_mse = []
all_nmse = []
all_predictions = []
all_losses = []
all_models = []  # keep every trained model for later noise-robustness eval

print(f"\n--- [PyTorch] RUNNING ON {device} ---\n")
print(f"Checkpoints will be read/written under: {os.path.abspath(CHECKPOINT_DIR)}\n")

N_RUNS = 60
val_X = val_scaled[:, 0:-1]
PATIENCE = 10

# If a fully-completed summary already exists (e.g. all 60 runs finished in a
# previous session), just reload it and skip training entirely.
summary_path = _summary_path()
if os.path.exists(summary_path):
    print("Found completed checkpoint summary -> loading, skipping training.")
    saved = torch.load(summary_path, map_location=device, weights_only=False)

    all_models = []
    for sd in saved['model_state_dicts']:
        m = build_model(input_dim=1, units=8).to(device)
        m.load_state_dict(sd)
        m.eval()
        all_models.append(m)

    all_rmse = saved['rmse']
    all_mse = saved['mse']
    all_nmse = saved['nmse']
    all_predictions = saved['predictions']
    all_losses = saved['losses']
    print(f"Loaded {len(all_models)} models from checkpoint.")

else:
    for run in range(N_RUNS):

        # Resume mid-run-set: if this specific run was already checkpointed
        # (e.g. the kernel died partway through), reload it instead of
        # retraining.
        run_ckpt_path = _ckpt_path(run)
        if os.path.exists(run_ckpt_path):
            print(f'\n===== RUN {run + 1}/{N_RUNS} (resumed from checkpoint) =====')
            ckpt = torch.load(run_ckpt_path, map_location=device, weights_only=False)

            model = build_model(input_dim=1, units=8).to(device)
            model.load_state_dict(ckpt['model_state_dict'])
            model.eval()

            all_losses.append(ckpt['run_losses'])
            all_models.append(model)
            all_rmse.append(ckpt['rmse'])
            all_mse.append(ckpt['mse'])
            all_nmse.append(ckpt['nmse'])
            all_predictions.append(ckpt['predictions'])
            print(f"Loaded run {run + 1} -- RMSE: {ckpt['rmse']:.6f}, MSE: {ckpt['mse']:.6f}, NMSE: {ckpt['nmse']:.10f} "
                  f"(best val RMSE: {ckpt['best_val_rmse']:.6f})")
            continue

        print(f'\n===== RUN {run + 1}/{N_RUNS} =====')

        np.random.seed(run)
        torch.manual_seed(run)
        model = build_model(input_dim=1, units=8).to(device)

        with torch.no_grad():
            hs = model.hidden_size
            model.cell.bias.data[hs:2 * hs] = 1.0

        optimizer = torch.optim.Adam(model.parameters(), lr=0.001)
        criterion = nn.MSELoss()
        run_losses = []

        X_train_t = torch.tensor(X_train, dtype=torch.float32).to(device)
        y_train_t = torch.tensor(y_train, dtype=torch.float32).to(device)
        n_samples = X_train_t.size(0)

        best_val_rmse = float('inf')
        best_state = None
        patience_ctr = 0

        for epoch in range(100):
            model.train()
            model.reset_states(1, device)
            epoch_loss = 0.0

            for i in range(n_samples):
                x_i = X_train_t[i:i + 1]
                y_i = y_train_t[i:i + 1]

                optimizer.zero_grad()
                pred = model(x_i)
                loss = criterion(pred.squeeze(-1), y_i)
                loss.backward()
                torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)  # FIX: stabilize online updates
                optimizer.step()

                model.u = model.u.detach()
                epoch_loss += loss.item()

            avg_loss = epoch_loss / n_samples
            run_losses.append(avg_loss)

            # FIX: early stopping on the validation split (previously computed, never used)
            _, val_rmse, _, _ = evaluate_on_test(model, val_X, train, train_scaled, raw_values, scaler, device)
            print(f"Epoch {epoch + 1}/100 — train loss: {avg_loss:.6f}  val RMSE: {val_rmse:.6f}")

            if val_rmse < best_val_rmse:
                best_val_rmse = val_rmse
                best_state = {k: v.clone() for k, v in model.state_dict().items()}
                patience_ctr = 0
            else:
                patience_ctr += 1
                if patience_ctr >= PATIENCE:
                    print(f"Early stopping at epoch {epoch + 1} (best val RMSE: {best_val_rmse:.6f})")
                    break

        model.load_state_dict(best_state)  # restore best-val checkpoint
        model.reset_states(1, device)      # clear stale hidden state before storing

        all_losses.append(run_losses)
        all_models.append(model)
        print(f'Training complete for run {run + 1} (best val RMSE: {best_val_rmse:.6f})')

        predictions, rmse, mse, nmse = evaluate_on_test(
            model, X_test, train, train_scaled, raw_values, scaler, device
        )

        all_rmse.append(rmse)
        all_mse.append(mse)
        all_nmse.append(nmse)
        all_predictions.append(predictions)

        print(f'Run {run + 1} — RMSE: {rmse:.6f}, MSE: {mse:.6f}, NMSE: {nmse:.10f}')

        # Checkpoint this run to disk immediately, so a crash later never
        # loses this run's work.
        torch.save({
            'model_state_dict': model.state_dict(),
            'run_losses': run_losses,
            'rmse': rmse,
            'mse': mse,
            'nmse': nmse,
            'predictions': predictions,
            'best_val_rmse': best_val_rmse,
        }, run_ckpt_path)

    # Consolidated checkpoint (metrics + all 60 state_dicts), so a fully
    # completed run-set never needs to be retrained even if the individual
    # per-run checkpoint files above are deleted/cleaned up later.
    torch.save({
        'rmse': all_rmse,
        'mse': all_mse,
        'nmse': all_nmse,
        'predictions': all_predictions,
        'losses': all_losses,
        'model_state_dicts': [m.state_dict() for m in all_models],
    }, summary_path)
# Out:
# --- [PyTorch] RUNNING ON cuda ---
#
# Checkpoints will be read/written under: c:\Users\paulp\OneDrive\Desktop\fuzzy_LSTM\with noise\type_1\checkpoints_baseline_dowjones
#
#
# ===== RUN 1/60 =====
# Epoch 1/100 — train loss: 0.095156  val RMSE: 3.265553
# Epoch 2/100 — train loss: 0.070748  val RMSE: 3.266412
# Epoch 3/100 — train loss: 0.065058  val RMSE: 3.269048
# Epoch 4/100 — train loss: 0.063205  val RMSE: 3.268773
# Epoch 5/100 — train loss: 0.062305  val RMSE: 3.266804
# Epoch 6/100 — train loss: 0.061578  val RMSE: 3.264047
# Epoch 7/100 — train loss: 0.060949  val RMSE: 3.261152
# Epoch 8/100 — train loss: 0.060411  val RMSE: 3.258352
# Epoch 9/100 — train loss: 0.059949  val RMSE: 3.255682
# Epoch 10/100 — train loss: 0.059539  val RMSE: 3.253074
# Epoch 11/100 — train loss: 0.059158  val RMSE: 3.250668
# Epoch 12/100 — train loss: 0.058785  val RMSE: 3.248118
# Epoch 13/100 — train loss: 0.058401  val RMSE: 3.245283
# Epoch 14/100 — train loss: 0.057992  val RMSE: 3.242055
# Epoch 15/100 — train loss: 0.057551  val RMSE: 3.238328
# Epoch 16/100 — train loss: 0.057080  val RMSE: 3.234026
# Epoch 17/100 — train loss: 0.056589  val RMSE: 3.229110
# Epoch 18/100 — train loss: 0.056099  val RMSE: 3.223641
# Epoch 19/100 — train loss: 0.055635  val RMSE: 3.217816
# Epoch 20/100 — train loss: 0.055223  val RMSE: 3.212068
# Epoch 21/100 — train loss: 0.054871  val RMSE: 3.206869
# Epoch 22/100 — train loss: 0.054569  val RMSE: 3.202627
# Epoch 23/100 — train loss: 0.054307  val RMSE: 3.199592
# Epoch 24/100 — train loss: 0.054073  val RMSE: 3.197735
# Epoch 25/100 — train loss: 0.053857  val RMSE: 3.196989
# Epoch 26/100 — train loss: 0.053649  val RMSE: 3.196972
# Epoch 27/100 — train loss: 0.053448  val RMSE: 3.197809
# Epoch 28/100 — train loss: 0.053251  val RMSE: 3.199228
# Epoch 29/100 — train loss: 0.053054  val RMSE: 3.201365
# Epoch 30/100 — train loss: 0.052864  val RMSE: 3.203494
# Epoch 31/100 — train loss: 0.052676  val RMSE: 3.206630
# Epoch 32/100 — train loss: 0.052488  val RMSE: 3.209790
# Epoch 33/100 — train loss: 0.052292  val RMSE: 3.213526
# Epoch 34/100 — train loss: 0.052098  val RMSE: 3.217438
# Epoch 35/100 — train loss: 0.051896  val RMSE: 3.221733
# Epoch 36/100 — train loss: 0.051685  val RMSE: 3.226636
# Early stopping at epoch 36 (best val RMSE: 3.196972)
# Training complete for run 1 (best val RMSE: 3.196972)
# Run 1 — RMSE: 3.376125, MSE: 11.398217, NMSE: 0.1032864862
#
# ===== RUN 2/60 =====
# Epoch 1/100 — train loss: 0.114570  val RMSE: 3.278139
# Epoch 2/100 — train loss: 0.077979  val RMSE: 3.273864
# Epoch 3/100 — train loss: 0.067550  val RMSE: 3.230763
# Epoch 4/100 — train loss: 0.061557  val RMSE: 3.180560
# Epoch 5/100 — train loss: 0.059939  val RMSE: 3.149773
# Epoch 6/100 — train loss: 0.059333  val RMSE: 3.121280
# Epoch 7/100 — train loss: 0.059108  val RMSE: 3.094633
# Epoch 8/100 — train loss: 0.059073  val RMSE: 3.071935
# Epoch 9/100 — train loss: 0.059122  val RMSE: 3.053603
# Epoch 10/100 — train loss: 0.059197  val RMSE: 3.039728
# Epoch 11/100 — train loss: 0.059282  val RMSE: 3.029551
# Epoch 12/100 — train loss: 0.059368  val RMSE: 3.022907
# Epoch 13/100 — train loss: 0.059439  val RMSE: 3.018357
# Epoch 14/100 — train loss: 0.059492  val RMSE: 3.015829
# Epoch 15/100 — train loss: 0.059522  val RMSE: 3.016570
# Epoch 16/100 — train loss: 0.059521  val RMSE: 3.020109
# Epoch 17/100 — train loss: 0.059490  val RMSE: 3.026147
# Epoch 18/100 — train loss: 0.059429  val RMSE: 3.034356
# Epoch 19/100 — train loss: 0.059338  val RMSE: 3.044157
# Epoch 20/100 — train loss: 0.059217  val RMSE: 3.053522
# Epoch 21/100 — train loss: 0.059077  val RMSE: 3.065091
# Epoch 22/100 — train loss: 0.058904  val RMSE: 3.077330
# Epoch 23/100 — train loss: 0.058701  val RMSE: 3.089017
# Epoch 24/100 — train loss: 0.058481  val RMSE: 3.101344
# Early stopping at epoch 24 (best val RMSE: 3.015829)
# Training complete for run 2 (best val RMSE: 3.015829)
# Run 2 — RMSE: 3.369547, MSE: 11.353847, NMSE: 0.1028844255
#
# ===== RUN 3/60 =====
# Epoch 1/100 — train loss: 0.127739  val RMSE: 3.264728
# Epoch 2/100 — train loss: 0.070889  val RMSE: 3.264371
# Epoch 3/100 — train loss: 0.064192  val RMSE: 3.269559
# Epoch 4/100 — train loss: 0.062987  val RMSE: 3.272113
# Epoch 5/100 — train loss: 0.062631  val RMSE: 3.273612
# Epoch 6/100 — train loss: 0.062497  val RMSE: 3.275239
# Epoch 7/100 — train loss: 0.062443  val RMSE: 3.275845
# Epoch 8/100 — train loss: 0.062388  val RMSE: 3.276447
# Epoch 9/100 — train loss: 0.062330  val RMSE: 3.276990
# Epoch 10/100 — train loss: 0.062300  val RMSE: 3.277005
# Epoch 11/100 — train loss: 0.062258  val RMSE: 3.277727
# Epoch 12/100 — train loss: 0.062277  val RMSE: 3.278381
# Early stopping at epoch 12 (best val RMSE: 3.264371)
# Training complete for run 3 (best val RMSE: 3.264371)
# Run 3 — RMSE: 3.344117, MSE: 11.183120, NMSE: 0.1013373584
#
# ===== RUN 4/60 =====
# Epoch 1/100 — train loss: 0.088364  val RMSE: 3.276072
# Epoch 2/100 — train loss: 0.067733  val RMSE: 3.279741
# Epoch 3/100 — train loss: 0.064440  val RMSE: 3.281134
# Epoch 4/100 — train loss: 0.063293  val RMSE: 3.279190
# Epoch 5/100 — train loss: 0.062380  val RMSE: 3.275865
# Epoch 6/100 — train loss: 0.061502  val RMSE: 3.272289
# Epoch 7/100 — train loss: 0.060713  val RMSE: 3.268948
# Epoch 8/100 — train loss: 0.060041  val RMSE: 3.265832
# Epoch 9/100 — train loss: 0.059482  val RMSE: 3.262877
# Epoch 10/100 — train loss: 0.059019  val RMSE: 3.259768
# Epoch 11/100 — train loss: 0.058628  val RMSE: 3.256381
# Epoch 12/100 — train loss: 0.058289  val RMSE: 3.252552
# Epoch 13/100 — train loss: 0.057980  val RMSE: 3.248071
# Epoch 14/100 — train loss: 0.057685  val RMSE: 3.242679
# Epoch 15/100 — train loss: 0.057390  val RMSE: 3.236065
# Epoch 16/100 — train loss: 0.057086  val RMSE: 3.227890
# Epoch 17/100 — train loss: 0.056767  val RMSE: 3.217841
# Epoch 18/100 — train loss: 0.056437  val RMSE: 3.205791
# Epoch 19/100 — train loss: 0.056107  val RMSE: 3.192352
# Epoch 20/100 — train loss: 0.055790  val RMSE: 3.178003
# Epoch 21/100 — train loss: 0.055497  val RMSE: 3.164070
# Epoch 22/100 — train loss: 0.055233  val RMSE: 3.151971
# Epoch 23/100 — train loss: 0.054990  val RMSE: 3.142485
# Epoch 24/100 — train loss: 0.054757  val RMSE: 3.136001
# Epoch 25/100 — train loss: 0.054521  val RMSE: 3.132304
# Epoch 26/100 — train loss: 0.054274  val RMSE: 3.130927
# Epoch 27/100 — train loss: 0.054018  val RMSE: 3.131350
# Epoch 28/100 — train loss: 0.053757  val RMSE: 3.133194
# Epoch 29/100 — train loss: 0.053495  val RMSE: 3.136222
# Epoch 30/100 — train loss: 0.053235  val RMSE: 3.140326
# Epoch 31/100 — train loss: 0.052980  val RMSE: 3.145473
# Epoch 32/100 — train loss: 0.052734  val RMSE: 3.151824
# Epoch 33/100 — train loss: 0.052495  val RMSE: 3.160046
# Epoch 34/100 — train loss: 0.052268  val RMSE: 3.170067
# Epoch 35/100 — train loss: 0.052025  val RMSE: 3.183334
# Epoch 36/100 — train loss: 0.051783  val RMSE: 3.192735
# Early stopping at epoch 36 (best val RMSE: 3.130927)
# Training complete for run 4 (best val RMSE: 3.130927)
# Run 4 — RMSE: 3.368695, MSE: 11.348109, NMSE: 0.1028324247
#
# ===== RUN 5/60 =====
# Epoch 1/100 — train loss: 0.124129  val RMSE: 3.254244
# Epoch 2/100 — train loss: 0.078289  val RMSE: 3.266105
# Epoch 3/100 — train loss: 0.073232  val RMSE: 3.274299
# Epoch 4/100 — train loss: 0.069667  val RMSE: 3.278158
# Epoch 5/100 — train loss: 0.067684  val RMSE: 3.280791
# Epoch 6/100 — train loss: 0.066711  val RMSE: 3.283010
# Epoch 7/100 — train loss: 0.066200  val RMSE: 3.283573
# Epoch 8/100 — train loss: 0.065796  val RMSE: 3.283230
# Epoch 9/100 — train loss: 0.065407  val RMSE: 3.282490
# Epoch 10/100 — train loss: 0.065018  val RMSE: 3.281485
# Epoch 11/100 — train loss: 0.064630  val RMSE: 3.280319
# Early stopping at epoch 11 (best val RMSE: 3.254244)
# Training complete for run 5 (best val RMSE: 3.254244)
# Run 5 — RMSE: 3.341045, MSE: 11.162579, NMSE: 0.1011512242
#
# ===== RUN 6/60 =====
# Epoch 1/100 — train loss: 0.085619  val RMSE: 3.271182
# Epoch 2/100 — train loss: 0.066604  val RMSE: 3.268894
# Epoch 3/100 — train loss: 0.060113  val RMSE: 3.263317
# Epoch 4/100 — train loss: 0.058229  val RMSE: 3.257049
# Epoch 5/100 — train loss: 0.056982  val RMSE: 3.251514
# Epoch 6/100 — train loss: 0.055850  val RMSE: 3.246808
# Epoch 7/100 — train loss: 0.054795  val RMSE: 3.242949
# Epoch 8/100 — train loss: 0.053819  val RMSE: 3.239874
# Epoch 9/100 — train loss: 0.052939  val RMSE: 3.237581
# Epoch 10/100 — train loss: 0.052176  val RMSE: 3.236352
# Epoch 11/100 — train loss: 0.051545  val RMSE: 3.235910
# Epoch 12/100 — train loss: 0.051042  val RMSE: 3.236002
# Epoch 13/100 — train loss: 0.050649  val RMSE: 3.236370
# Epoch 14/100 — train loss: 0.050341  val RMSE: 3.236917
# Epoch 15/100 — train loss: 0.050094  val RMSE: 3.237588
# Epoch 16/100 — train loss: 0.049888  val RMSE: 3.238341
# Epoch 17/100 — train loss: 0.049708  val RMSE: 3.239184
# Epoch 18/100 — train loss: 0.049543  val RMSE: 3.240102
# Epoch 19/100 — train loss: 0.049389  val RMSE: 3.240988
# Epoch 20/100 — train loss: 0.049240  val RMSE: 3.241833
# Epoch 21/100 — train loss: 0.049096  val RMSE: 3.242624
# Early stopping at epoch 21 (best val RMSE: 3.235910)
# Training complete for run 6 (best val RMSE: 3.235910)
# Run 6 — RMSE: 3.363778, MSE: 11.315000, NMSE: 0.1025324050
#
# ===== RUN 7/60 =====
# Epoch 1/100 — train loss: 0.137584  val RMSE: 3.263984
# Epoch 2/100 — train loss: 0.080106  val RMSE: 3.281442
# Epoch 3/100 — train loss: 0.074006  val RMSE: 3.291248
# Epoch 4/100 — train loss: 0.071562  val RMSE: 3.296395
# Epoch 5/100 — train loss: 0.070855  val RMSE: 3.296824
# Epoch 6/100 — train loss: 0.070452  val RMSE: 3.295416
# Epoch 7/100 — train loss: 0.069958  val RMSE: 3.293793
# Epoch 8/100 — train loss: 0.069361  val RMSE: 3.291976
# Epoch 9/100 — train loss: 0.068696  val RMSE: 3.290049
# Epoch 10/100 — train loss: 0.067972  val RMSE: 3.288014
# Epoch 11/100 — train loss: 0.067209  val RMSE: 3.285861
# Early stopping at epoch 11 (best val RMSE: 3.263984)
# Training complete for run 7 (best val RMSE: 3.263984)
# Run 7 — RMSE: 3.340993, MSE: 11.162236, NMSE: 0.1011481159
#
# ===== RUN 8/60 =====
# Epoch 1/100 — train loss: 0.098538  val RMSE: 3.285704
# Epoch 2/100 — train loss: 0.071092  val RMSE: 3.281690
# Epoch 3/100 — train loss: 0.065795  val RMSE: 3.284387
# Epoch 4/100 — train loss: 0.063882  val RMSE: 3.287800
# Epoch 5/100 — train loss: 0.063363  val RMSE: 3.289643
# Epoch 6/100 — train loss: 0.063173  val RMSE: 3.290391
# Epoch 7/100 — train loss: 0.063002  val RMSE: 3.290352
# Epoch 8/100 — train loss: 0.062797  val RMSE: 3.289581
# Epoch 9/100 — train loss: 0.062552  val RMSE: 3.288200
# Epoch 10/100 — train loss: 0.062276  val RMSE: 3.286297
# Epoch 11/100 — train loss: 0.061973  val RMSE: 3.284126
# Epoch 12/100 — train loss: 0.061634  val RMSE: 3.281753
# Early stopping at epoch 12 (best val RMSE: 3.281690)
# Training complete for run 8 (best val RMSE: 3.281690)
# Run 8 — RMSE: 3.357445, MSE: 11.272438, NMSE: 0.1021467275
#
# ===== RUN 9/60 =====
# Epoch 1/100 — train loss: 0.125901  val RMSE: 3.250714
# Epoch 2/100 — train loss: 0.074788  val RMSE: 3.269951
# Epoch 3/100 — train loss: 0.069257  val RMSE: 3.280061
# Epoch 4/100 — train loss: 0.067749  val RMSE: 3.284908
# Epoch 5/100 — train loss: 0.067121  val RMSE: 3.286943
# Epoch 6/100 — train loss: 0.066621  val RMSE: 3.287483
# Epoch 7/100 — train loss: 0.066107  val RMSE: 3.287389
# Epoch 8/100 — train loss: 0.065654  val RMSE: 3.286979
# Epoch 9/100 — train loss: 0.065233  val RMSE: 3.286380
# Epoch 10/100 — train loss: 0.064857  val RMSE: 3.285619
# Epoch 11/100 — train loss: 0.064507  val RMSE: 3.284823
# Early stopping at epoch 11 (best val RMSE: 3.250714)
# Training complete for run 9 (best val RMSE: 3.250714)
# Run 9 — RMSE: 3.310557, MSE: 10.959788, NMSE: 0.0993136060
#
# ===== RUN 10/60 =====
# Epoch 1/100 — train loss: 0.109808  val RMSE: 3.264231
# Epoch 2/100 — train loss: 0.071643  val RMSE: 3.241950
# Epoch 3/100 — train loss: 0.062130  val RMSE: 3.207175
# Epoch 4/100 — train loss: 0.058008  val RMSE: 3.175317
# Epoch 5/100 — train loss: 0.056672  val RMSE: 3.157601
# Epoch 6/100 — train loss: 0.056049  val RMSE: 3.151292
# Epoch 7/100 — train loss: 0.055593  val RMSE: 3.151377
# Epoch 8/100 — train loss: 0.055211  val RMSE: 3.154394
# Epoch 9/100 — train loss: 0.054888  val RMSE: 3.158566
# Epoch 10/100 — train loss: 0.054607  val RMSE: 3.163057
# Epoch 11/100 — train loss: 0.054360  val RMSE: 3.167396
# Epoch 12/100 — train loss: 0.054140  val RMSE: 3.171504
# Epoch 13/100 — train loss: 0.053942  val RMSE: 3.175323
# Epoch 14/100 — train loss: 0.053761  val RMSE: 3.178838
# Epoch 15/100 — train loss: 0.053595  val RMSE: 3.182072
# Epoch 16/100 — train loss: 0.053441  val RMSE: 3.185060
# Early stopping at epoch 16 (best val RMSE: 3.151292)
# Training complete for run 10 (best val RMSE: 3.151292)
# Run 10 — RMSE: 3.338771, MSE: 11.147393, NMSE: 0.1010136103
#
# ===== RUN 11/60 =====
# Epoch 1/100 — train loss: 0.184728  val RMSE: 3.204844
# Epoch 2/100 — train loss: 0.084622  val RMSE: 3.257669
# Epoch 3/100 — train loss: 0.073535  val RMSE: 3.269442
# Epoch 4/100 — train loss: 0.067758  val RMSE: 3.266443
# Epoch 5/100 — train loss: 0.141803  val RMSE: 3.175528
# Epoch 6/100 — train loss: 0.067250  val RMSE: 3.270202
# Epoch 7/100 — train loss: 0.065523  val RMSE: 3.272489
# Epoch 8/100 — train loss: 0.064771  val RMSE: 3.272529
# Epoch 9/100 — train loss: 0.064352  val RMSE: 3.272013
# Epoch 10/100 — train loss: 0.064009  val RMSE: 3.271854
# Epoch 11/100 — train loss: 0.063790  val RMSE: 3.271865
# Epoch 12/100 — train loss: 0.063653  val RMSE: 3.272031
# Epoch 13/100 — train loss: 0.063579  val RMSE: 3.272147
# Epoch 14/100 — train loss: 0.063461  val RMSE: 3.272183
# Epoch 15/100 — train loss: 0.063379  val RMSE: 3.271577
# Early stopping at epoch 15 (best val RMSE: 3.175528)
# Training complete for run 11 (best val RMSE: 3.175528)
# Run 11 — RMSE: 3.272169, MSE: 10.707093, NMSE: 0.0970237731
#
# ===== RUN 12/60 =====
# Epoch 1/100 — train loss: 0.118361  val RMSE: 3.264719
# Epoch 2/100 — train loss: 0.075619  val RMSE: 3.277283
# Epoch 3/100 — train loss: 0.068328  val RMSE: 3.285913
# Epoch 4/100 — train loss: 0.067167  val RMSE: 3.291945
# Epoch 5/100 — train loss: 0.067087  val RMSE: 3.293999
# Epoch 6/100 — train loss: 0.066988  val RMSE: 3.294706
# Epoch 7/100 — train loss: 0.066788  val RMSE: 3.294887
# Epoch 8/100 — train loss: 0.066637  val RMSE: 3.294797
# Epoch 9/100 — train loss: 0.066474  val RMSE: 3.294558
# Epoch 10/100 — train loss: 0.066304  val RMSE: 3.294080
# Epoch 11/100 — train loss: 0.066131  val RMSE: 3.293555
# Early stopping at epoch 11 (best val RMSE: 3.264719)
# Training complete for run 12 (best val RMSE: 3.264719)
# Run 12 — RMSE: 3.380628, MSE: 11.428647, NMSE: 0.1035622365
#
# ===== RUN 13/60 =====
# Epoch 1/100 — train loss: 0.121922  val RMSE: 3.282210
# Epoch 2/100 — train loss: 0.072797  val RMSE: 3.286966
# Epoch 3/100 — train loss: 0.069227  val RMSE: 3.289980
# Epoch 4/100 — train loss: 0.068124  val RMSE: 3.291113
# Epoch 5/100 — train loss: 0.067665  val RMSE: 3.290827
# Epoch 6/100 — train loss: 0.067265  val RMSE: 3.289880
# Epoch 7/100 — train loss: 0.066832  val RMSE: 3.288581
# Epoch 8/100 — train loss: 0.066352  val RMSE: 3.287051
# Epoch 9/100 — train loss: 0.065849  val RMSE: 3.285384
# Epoch 10/100 — train loss: 0.065331  val RMSE: 3.283505
# Epoch 11/100 — train loss: 0.064812  val RMSE: 3.281483
# Epoch 12/100 — train loss: 0.064293  val RMSE: 3.279297
# Epoch 13/100 — train loss: 0.063776  val RMSE: 3.277003
# Epoch 14/100 — train loss: 0.063263  val RMSE: 3.274581
# Epoch 15/100 — train loss: 0.062754  val RMSE: 3.272147
# Epoch 16/100 — train loss: 0.062252  val RMSE: 3.269704
# Epoch 17/100 — train loss: 0.061753  val RMSE: 3.267055
# Epoch 18/100 — train loss: 0.061263  val RMSE: 3.264133
# Epoch 19/100 — train loss: 0.060777  val RMSE: 3.261043
# Epoch 20/100 — train loss: 0.060304  val RMSE: 3.257813
# Epoch 21/100 — train loss: 0.059846  val RMSE: 3.254399
# Epoch 22/100 — train loss: 0.059400  val RMSE: 3.250701
# Epoch 23/100 — train loss: 0.058971  val RMSE: 3.246586
# Epoch 24/100 — train loss: 0.058558  val RMSE: 3.242294
# Epoch 25/100 — train loss: 0.058168  val RMSE: 3.237570
# Epoch 26/100 — train loss: 0.057802  val RMSE: 3.233041
# Epoch 27/100 — train loss: 0.057462  val RMSE: 3.228400
# Epoch 28/100 — train loss: 0.057147  val RMSE: 3.223960
# Epoch 29/100 — train loss: 0.056859  val RMSE: 3.219685
# Epoch 30/100 — train loss: 0.056598  val RMSE: 3.215497
# Epoch 31/100 — train loss: 0.056364  val RMSE: 3.211731
# Epoch 32/100 — train loss: 0.056157  val RMSE: 3.208158
# Epoch 33/100 — train loss: 0.055974  val RMSE: 3.205058
# Epoch 34/100 — train loss: 0.055812  val RMSE: 3.202586
# Epoch 35/100 — train loss: 0.055666  val RMSE: 3.200604
# Epoch 36/100 — train loss: 0.055536  val RMSE: 3.199464
# Epoch 37/100 — train loss: 0.055419  val RMSE: 3.198536
# Epoch 38/100 — train loss: 0.055306  val RMSE: 3.197932
# Epoch 39/100 — train loss: 0.055207  val RMSE: 3.197398
# Epoch 40/100 — train loss: 0.055112  val RMSE: 3.196970
# Epoch 41/100 — train loss: 0.055025  val RMSE: 3.196606
# Epoch 42/100 — train loss: 0.054939  val RMSE: 3.196354
# Epoch 43/100 — train loss: 0.054864  val RMSE: 3.196164
# Epoch 44/100 — train loss: 0.054788  val RMSE: 3.196075
# Epoch 45/100 — train loss: 0.054714  val RMSE: 3.195949
# Epoch 46/100 — train loss: 0.054648  val RMSE: 3.195951
# Epoch 47/100 — train loss: 0.054580  val RMSE: 3.195859
# Epoch 48/100 — train loss: 0.054516  val RMSE: 3.195962
# Epoch 49/100 — train loss: 0.054459  val RMSE: 3.196076
# Epoch 50/100 — train loss: 0.054401  val RMSE: 3.196136
# Epoch 51/100 — train loss: 0.054344  val RMSE: 3.196247
# Epoch 52/100 — train loss: 0.054292  val RMSE: 3.196351
# Epoch 53/100 — train loss: 0.054234  val RMSE: 3.196368
# Epoch 54/100 — train loss: 0.054182  val RMSE: 3.196420
# Epoch 55/100 — train loss: 0.054131  val RMSE: 3.196427
# Epoch 56/100 — train loss: 0.054082  val RMSE: 3.196541
# Epoch 57/100 — train loss: 0.054033  val RMSE: 3.196490
# Early stopping at epoch 57 (best val RMSE: 3.195859)
# Training complete for run 13 (best val RMSE: 3.195859)
# Run 13 — RMSE: 3.354003, MSE: 11.249339, NMSE: 0.1019374103
#
# ===== RUN 14/60 =====
# Epoch 1/100 — train loss: 0.094156  val RMSE: 3.283494
# Epoch 2/100 — train loss: 0.070023  val RMSE: 3.271742
# Epoch 3/100 — train loss: 0.061935  val RMSE: 3.244553
# Epoch 4/100 — train loss: 0.058823  val RMSE: 3.208995
# Epoch 5/100 — train loss: 0.057789  val RMSE: 3.185997
# Epoch 6/100 — train loss: 0.057227  val RMSE: 3.179858
# Epoch 7/100 — train loss: 0.056707  val RMSE: 3.180393
# Epoch 8/100 — train loss: 0.056223  val RMSE: 3.182783
# Epoch 9/100 — train loss: 0.055790  val RMSE: 3.185522
# Epoch 10/100 — train loss: 0.055406  val RMSE: 3.188209
# Epoch 11/100 — train loss: 0.055065  val RMSE: 3.190779
# Epoch 12/100 — train loss: 0.054759  val RMSE: 3.193294
# Epoch 13/100 — train loss: 0.054478  val RMSE: 3.195794
# Epoch 14/100 — train loss: 0.054213  val RMSE: 3.198314
# Epoch 15/100 — train loss: 0.053957  val RMSE: 3.200876
# Epoch 16/100 — train loss: 0.053702  val RMSE: 3.203495
# Early stopping at epoch 16 (best val RMSE: 3.179858)
# Training complete for run 14 (best val RMSE: 3.179858)
# Run 14 — RMSE: 3.366996, MSE: 11.336662, NMSE: 0.1027286972
#
# ===== RUN 15/60 =====
# Epoch 1/100 — train loss: 0.084089  val RMSE: 3.289492
# Epoch 2/100 — train loss: 0.061339  val RMSE: 3.250283
# Epoch 3/100 — train loss: 0.055728  val RMSE: 3.240416
# Epoch 4/100 — train loss: 0.054397  val RMSE: 3.236494
# Epoch 5/100 — train loss: 0.053463  val RMSE: 3.233369
# Epoch 6/100 — train loss: 0.052740  val RMSE: 3.231354
# Epoch 7/100 — train loss: 0.052178  val RMSE: 3.230292
# Epoch 8/100 — train loss: 0.051725  val RMSE: 3.229955
# Epoch 9/100 — train loss: 0.051345  val RMSE: 3.230105
# Epoch 10/100 — train loss: 0.051016  val RMSE: 3.230560
# Epoch 11/100 — train loss: 0.050723  val RMSE: 3.231263
# Epoch 12/100 — train loss: 0.050457  val RMSE: 3.232265
# Epoch 13/100 — train loss: 0.050209  val RMSE: 3.233324
# Epoch 14/100 — train loss: 0.049977  val RMSE: 3.234352
# Epoch 15/100 — train loss: 0.049759  val RMSE: 3.235334
# Epoch 16/100 — train loss: 0.049553  val RMSE: 3.236262
# Epoch 17/100 — train loss: 0.049359  val RMSE: 3.237119
# Epoch 18/100 — train loss: 0.049175  val RMSE: 3.237967
# Early stopping at epoch 18 (best val RMSE: 3.229955)
# Training complete for run 15 (best val RMSE: 3.229955)
# Run 15 — RMSE: 3.383554, MSE: 11.448436, NMSE: 0.1037415510
#
# ===== RUN 16/60 =====
# Epoch 1/100 — train loss: 0.133443  val RMSE: 3.266865
# Epoch 2/100 — train loss: 0.082397  val RMSE: 3.271013
# Epoch 3/100 — train loss: 0.075073  val RMSE: 3.277331
# Epoch 4/100 — train loss: 0.070013  val RMSE: 3.286420
# Epoch 5/100 — train loss: 0.067583  val RMSE: 3.293336
# Epoch 6/100 — train loss: 0.066836  val RMSE: 3.297691
# Epoch 7/100 — train loss: 0.066711  val RMSE: 3.300018
# Epoch 8/100 — train loss: 0.066695  val RMSE: 3.301250
# Epoch 9/100 — train loss: 0.066643  val RMSE: 3.301894
# Epoch 10/100 — train loss: 0.066546  val RMSE: 3.302128
# Epoch 11/100 — train loss: 0.066421  val RMSE: 3.302174
# Early stopping at epoch 11 (best val RMSE: 3.266865)
# Training complete for run 16 (best val RMSE: 3.266865)
# Run 16 — RMSE: 3.360965, MSE: 11.296083, NMSE: 0.1023609832
#
# ===== RUN 17/60 =====
# Epoch 1/100 — train loss: 0.086124  val RMSE: 3.274914
# Epoch 2/100 — train loss: 0.062805  val RMSE: 3.265492
# Epoch 3/100 — train loss: 0.056757  val RMSE: 3.262769
# Epoch 4/100 — train loss: 0.055481  val RMSE: 3.259556
# Epoch 5/100 — train loss: 0.054601  val RMSE: 3.256797
# Epoch 6/100 — train loss: 0.053895  val RMSE: 3.254568
# Epoch 7/100 — train loss: 0.053323  val RMSE: 3.252626
# Epoch 8/100 — train loss: 0.052845  val RMSE: 3.250895
# Epoch 9/100 — train loss: 0.052435  val RMSE: 3.249400
# Epoch 10/100 — train loss: 0.052074  val RMSE: 3.248049
# Epoch 11/100 — train loss: 0.051750  val RMSE: 3.246817
# Epoch 12/100 — train loss: 0.051457  val RMSE: 3.245687
# Epoch 13/100 — train loss: 0.051190  val RMSE: 3.244666
# Epoch 14/100 — train loss: 0.050948  val RMSE: 3.243774
# Epoch 15/100 — train loss: 0.050725  val RMSE: 3.243012
# Epoch 16/100 — train loss: 0.050518  val RMSE: 3.242523
# Epoch 17/100 — train loss: 0.050324  val RMSE: 3.242184
# Epoch 18/100 — train loss: 0.050141  val RMSE: 3.241928
# Epoch 19/100 — train loss: 0.049963  val RMSE: 3.241735
# Epoch 20/100 — train loss: 0.049791  val RMSE: 3.241632
# Epoch 21/100 — train loss: 0.049622  val RMSE: 3.241568
# Epoch 22/100 — train loss: 0.049456  val RMSE: 3.241516
# Epoch 23/100 — train loss: 0.049297  val RMSE: 3.241523
# Epoch 24/100 — train loss: 0.049145  val RMSE: 3.241501
# Epoch 25/100 — train loss: 0.049002  val RMSE: 3.241425
# Epoch 26/100 — train loss: 0.048868  val RMSE: 3.241292
# Epoch 27/100 — train loss: 0.048745  val RMSE: 3.241112
# Epoch 28/100 — train loss: 0.048631  val RMSE: 3.240901
# Epoch 29/100 — train loss: 0.048527  val RMSE: 3.240651
# Epoch 30/100 — train loss: 0.048432  val RMSE: 3.240372
# Epoch 31/100 — train loss: 0.048346  val RMSE: 3.240079
# Epoch 32/100 — train loss: 0.048266  val RMSE: 3.239783
# Epoch 33/100 — train loss: 0.048191  val RMSE: 3.239453
# Epoch 34/100 — train loss: 0.048126  val RMSE: 3.239202
# Epoch 35/100 — train loss: 0.048063  val RMSE: 3.238957
# Epoch 36/100 — train loss: 0.048002  val RMSE: 3.238737
# Epoch 37/100 — train loss: 0.047944  val RMSE: 3.238510
# Epoch 38/100 — train loss: 0.047889  val RMSE: 3.238318
# Epoch 39/100 — train loss: 0.047838  val RMSE: 3.238192
# Epoch 40/100 — train loss: 0.047789  val RMSE: 3.238084
# Epoch 41/100 — train loss: 0.047741  val RMSE: 3.238019
# Epoch 42/100 — train loss: 0.047695  val RMSE: 3.237974
# Epoch 43/100 — train loss: 0.047650  val RMSE: 3.237927
# Epoch 44/100 — train loss: 0.047607  val RMSE: 3.237683
# Epoch 45/100 — train loss: 0.047573  val RMSE: 3.237654
# Epoch 46/100 — train loss: 0.047537  val RMSE: 3.237632
# Epoch 47/100 — train loss: 0.047503  val RMSE: 3.237594
# Epoch 48/100 — train loss: 0.047471  val RMSE: 3.237576
# Epoch 49/100 — train loss: 0.047441  val RMSE: 3.237570
# Epoch 50/100 — train loss: 0.047414  val RMSE: 3.237602
# Epoch 51/100 — train loss: 0.047385  val RMSE: 3.237615
# Epoch 52/100 — train loss: 0.047361  val RMSE: 3.237721
# Epoch 53/100 — train loss: 0.047334  val RMSE: 3.237807
# Epoch 54/100 — train loss: 0.047309  val RMSE: 3.237902
# Epoch 55/100 — train loss: 0.047284  val RMSE: 3.237998
# Epoch 56/100 — train loss: 0.047261  val RMSE: 3.238083
# Epoch 57/100 — train loss: 0.047238  val RMSE: 3.238105
# Epoch 58/100 — train loss: 0.047222  val RMSE: 3.238085
# Epoch 59/100 — train loss: 0.047217  val RMSE: 3.238058
# Early stopping at epoch 59 (best val RMSE: 3.237570)
# Training complete for run 17 (best val RMSE: 3.237570)
# Run 17 — RMSE: 3.394613, MSE: 11.523394, NMSE: 0.1044207982
#
# ===== RUN 18/60 =====
# Epoch 1/100 — train loss: 0.094285  val RMSE: 3.263457
# Epoch 2/100 — train loss: 0.067312  val RMSE: 3.250629
# Epoch 3/100 — train loss: 0.059679  val RMSE: 3.243045
# Epoch 4/100 — train loss: 0.057648  val RMSE: 3.230436
# Epoch 5/100 — train loss: 0.056466  val RMSE: 3.214491
# Epoch 6/100 — train loss: 0.055576  val RMSE: 3.201059
# Epoch 7/100 — train loss: 0.054882  val RMSE: 3.192578
# Epoch 8/100 — train loss: 0.054304  val RMSE: 3.188547
# Epoch 9/100 — train loss: 0.053784  val RMSE: 3.188268
# Epoch 10/100 — train loss: 0.053309  val RMSE: 3.190950
# Epoch 11/100 — train loss: 0.052861  val RMSE: 3.195243
# Epoch 12/100 — train loss: 0.052439  val RMSE: 3.200380
# Epoch 13/100 — train loss: 0.052020  val RMSE: 3.205801
# Epoch 14/100 — train loss: 0.051626  val RMSE: 3.210925
# Epoch 15/100 — train loss: 0.051250  val RMSE: 3.215353
# Epoch 16/100 — train loss: 0.050900  val RMSE: 3.218562
# Epoch 17/100 — train loss: 0.050567  val RMSE: 3.220512
# Epoch 18/100 — train loss: 0.050255  val RMSE: 3.222028
# Epoch 19/100 — train loss: 0.049966  val RMSE: 3.224220
# Early stopping at epoch 19 (best val RMSE: 3.188268)
# Training complete for run 18 (best val RMSE: 3.188268)
# Run 18 — RMSE: 3.340252, MSE: 11.157283, NMSE: 0.1011032336
#
# ===== RUN 19/60 =====
# Epoch 1/100 — train loss: 0.132273  val RMSE: 3.270815
# Epoch 2/100 — train loss: 0.077010  val RMSE: 3.276202
# Epoch 3/100 — train loss: 0.068992  val RMSE: 3.280490
# Epoch 4/100 — train loss: 0.066380  val RMSE: 3.283032
# Epoch 5/100 — train loss: 0.065633  val RMSE: 3.284871
# Epoch 6/100 — train loss: 0.065213  val RMSE: 3.285494
# Epoch 7/100 — train loss: 0.064807  val RMSE: 3.285543
# Epoch 8/100 — train loss: 0.064373  val RMSE: 3.285029
# Epoch 9/100 — train loss: 0.063952  val RMSE: 3.284376
# Epoch 10/100 — train loss: 0.063636  val RMSE: 3.283652
# Epoch 11/100 — train loss: 0.063387  val RMSE: 3.282964
# Early stopping at epoch 11 (best val RMSE: 3.270815)
# Training complete for run 19 (best val RMSE: 3.270815)
# Run 19 — RMSE: 3.340318, MSE: 11.157727, NMSE: 0.1011072560
#
# ===== RUN 20/60 =====
# Epoch 1/100 — train loss: 0.079674  val RMSE: 3.295787
# Epoch 2/100 — train loss: 0.064584  val RMSE: 3.271577
# Epoch 3/100 — train loss: 0.058799  val RMSE: 3.260826
# Epoch 4/100 — train loss: 0.056851  val RMSE: 3.253900
# Epoch 5/100 — train loss: 0.055465  val RMSE: 3.247122
# Epoch 6/100 — train loss: 0.054275  val RMSE: 3.240017
# Epoch 7/100 — train loss: 0.053297  val RMSE: 3.233348
# Epoch 8/100 — train loss: 0.052538  val RMSE: 3.228433
# Epoch 9/100 — train loss: 0.051967  val RMSE: 3.225999
# Epoch 10/100 — train loss: 0.051533  val RMSE: 3.225717
# Epoch 11/100 — train loss: 0.051192  val RMSE: 3.226825
# Epoch 12/100 — train loss: 0.050911  val RMSE: 3.228575
# Epoch 13/100 — train loss: 0.050670  val RMSE: 3.230565
# Epoch 14/100 — train loss: 0.050455  val RMSE: 3.232627
# Epoch 15/100 — train loss: 0.050260  val RMSE: 3.234375
# Epoch 16/100 — train loss: 0.050080  val RMSE: 3.235741
# Epoch 17/100 — train loss: 0.049910  val RMSE: 3.236660
# Epoch 18/100 — train loss: 0.049746  val RMSE: 3.237119
# Epoch 19/100 — train loss: 0.049580  val RMSE: 3.237311
# Epoch 20/100 — train loss: 0.049394  val RMSE: 3.237722
# Early stopping at epoch 20 (best val RMSE: 3.225717)
# Training complete for run 20 (best val RMSE: 3.225717)
# Run 20 — RMSE: 3.373026, MSE: 11.377305, NMSE: 0.1030969898
#
# ===== RUN 21/60 =====
# Epoch 1/100 — train loss: 0.119517  val RMSE: 3.269916
# Epoch 2/100 — train loss: 0.074211  val RMSE: 3.278216
# Epoch 3/100 — train loss: 0.066351  val RMSE: 3.285117
# Epoch 4/100 — train loss: 0.064858  val RMSE: 3.288392
# Epoch 5/100 — train loss: 0.064599  val RMSE: 3.288823
# Epoch 6/100 — train loss: 0.064310  val RMSE: 3.287942
# Epoch 7/100 — train loss: 0.063895  val RMSE: 3.286563
# Epoch 8/100 — train loss: 0.063448  val RMSE: 3.284944
# Epoch 9/100 — train loss: 0.062976  val RMSE: 3.283007
# Epoch 10/100 — train loss: 0.062537  val RMSE: 3.280771
# Epoch 11/100 — train loss: 0.062080  val RMSE: 3.279577
# Early stopping at epoch 11 (best val RMSE: 3.269916)
# Training complete for run 21 (best val RMSE: 3.269916)
# Run 21 — RMSE: 3.345573, MSE: 11.192857, NMSE: 0.1014255865
#
# ===== RUN 22/60 =====
# Epoch 1/100 — train loss: 0.135871  val RMSE: 3.357571
# Epoch 2/100 — train loss: 0.103315  val RMSE: 3.302188
# Epoch 3/100 — train loss: 0.099083  val RMSE: 3.319558
# Epoch 4/100 — train loss: 0.097215  val RMSE: 3.320922
# Epoch 5/100 — train loss: 0.098716  val RMSE: 3.315882
# Epoch 6/100 — train loss: 0.096228  val RMSE: 3.320082
# Epoch 7/100 — train loss: 0.095433  val RMSE: 3.321854
# Epoch 8/100 — train loss: 0.095342  val RMSE: 3.322705
# Epoch 9/100 — train loss: 0.095286  val RMSE: 3.323242
# Epoch 10/100 — train loss: 0.094965  val RMSE: 3.323520
# Epoch 11/100 — train loss: 0.094926  val RMSE: 3.323701
# Epoch 12/100 — train loss: 0.097324  val RMSE: 3.317805
# Early stopping at epoch 12 (best val RMSE: 3.302188)
# Training complete for run 22 (best val RMSE: 3.302188)
# Run 22 — RMSE: 3.460099, MSE: 11.972287, NMSE: 0.1084885039
#
# ===== RUN 23/60 =====
# Epoch 1/100 — train loss: 0.079874  val RMSE: 3.271781
# Epoch 2/100 — train loss: 0.064128  val RMSE: 3.272034
# Epoch 3/100 — train loss: 0.060933  val RMSE: 3.271903
# Epoch 4/100 — train loss: 0.060451  val RMSE: 3.271830
# Epoch 5/100 — train loss: 0.060162  val RMSE: 3.271479
# Epoch 6/100 — train loss: 0.059837  val RMSE: 3.271070
# Epoch 7/100 — train loss: 0.059499  val RMSE: 3.270814
# Epoch 8/100 — train loss: 0.059169  val RMSE: 3.270697
# Epoch 9/100 — train loss: 0.058868  val RMSE: 3.270089
# Epoch 10/100 — train loss: 0.058600  val RMSE: 3.268394
# Epoch 11/100 — train loss: 0.058330  val RMSE: 3.265634
# Epoch 12/100 — train loss: 0.058000  val RMSE: 3.261992
# Epoch 13/100 — train loss: 0.057573  val RMSE: 3.257387
# Epoch 14/100 — train loss: 0.057048  val RMSE: 3.252435
# Epoch 15/100 — train loss: 0.056448  val RMSE: 3.247294
# Epoch 16/100 — train loss: 0.055812  val RMSE: 3.242386
# Epoch 17/100 — train loss: 0.055188  val RMSE: 3.237493
# Epoch 18/100 — train loss: 0.054597  val RMSE: 3.232697
# Epoch 19/100 — train loss: 0.054054  val RMSE: 3.227988
# Epoch 20/100 — train loss: 0.053572  val RMSE: 3.223909
# Epoch 21/100 — train loss: 0.053136  val RMSE: 3.220447
# Epoch 22/100 — train loss: 0.052744  val RMSE: 3.217543
# Epoch 23/100 — train loss: 0.052386  val RMSE: 3.215067
# Epoch 24/100 — train loss: 0.052058  val RMSE: 3.213377
# Epoch 25/100 — train loss: 0.051739  val RMSE: 3.212735
# Epoch 26/100 — train loss: 0.051440  val RMSE: 3.212641
# Epoch 27/100 — train loss: 0.051174  val RMSE: 3.212851
# Epoch 28/100 — train loss: 0.050932  val RMSE: 3.213458
# Epoch 29/100 — train loss: 0.050714  val RMSE: 3.214490
# Epoch 30/100 — train loss: 0.050517  val RMSE: 3.215894
# Epoch 31/100 — train loss: 0.050343  val RMSE: 3.217631
# Epoch 32/100 — train loss: 0.050185  val RMSE: 3.219717
# Epoch 33/100 — train loss: 0.050047  val RMSE: 3.222093
# Epoch 34/100 — train loss: 0.049926  val RMSE: 3.224816
# Epoch 35/100 — train loss: 0.049819  val RMSE: 3.227903
# Epoch 36/100 — train loss: 0.049721  val RMSE: 3.231358
# Early stopping at epoch 36 (best val RMSE: 3.212641)
# Training complete for run 23 (best val RMSE: 3.212641)
# Run 23 — RMSE: 3.362958, MSE: 11.309485, NMSE: 0.1024824325
#
# ===== RUN 24/60 =====
# Epoch 1/100 — train loss: 0.098177  val RMSE: 3.269630
# Epoch 2/100 — train loss: 0.073801  val RMSE: 3.267250
# Epoch 3/100 — train loss: 0.067047  val RMSE: 3.254807
# Epoch 4/100 — train loss: 0.061846  val RMSE: 3.223532
# Epoch 5/100 — train loss: 0.058807  val RMSE: 3.195616
# Epoch 6/100 — train loss: 0.057447  val RMSE: 3.181299
# Epoch 7/100 — train loss: 0.056754  val RMSE: 3.178908
# Epoch 8/100 — train loss: 0.056368  val RMSE: 3.184040
# Epoch 9/100 — train loss: 0.056127  val RMSE: 3.191928
# Epoch 10/100 — train loss: 0.055961  val RMSE: 3.199932
# Epoch 11/100 — train loss: 0.055838  val RMSE: 3.207138
# Epoch 12/100 — train loss: 0.055735  val RMSE: 3.213483
# Epoch 13/100 — train loss: 0.055637  val RMSE: 3.219119
# Epoch 14/100 — train loss: 0.055535  val RMSE: 3.224020
# Epoch 15/100 — train loss: 0.055428  val RMSE: 3.228338
# Epoch 16/100 — train loss: 0.055316  val RMSE: 3.232222
# Epoch 17/100 — train loss: 0.055198  val RMSE: 3.236039
# Early stopping at epoch 17 (best val RMSE: 3.178908)
# Training complete for run 24 (best val RMSE: 3.178908)
# Run 24 — RMSE: 3.344701, MSE: 11.187026, NMSE: 0.1013727529
#
# ===== RUN 25/60 =====
# Epoch 1/100 — train loss: 0.129782  val RMSE: 3.256323
# Epoch 2/100 — train loss: 0.072863  val RMSE: 3.260718
# Epoch 3/100 — train loss: 0.056692  val RMSE: 3.261720
# Epoch 4/100 — train loss: 0.055606  val RMSE: 3.257942
# Epoch 5/100 — train loss: 0.055225  val RMSE: 3.254638
# Epoch 6/100 — train loss: 0.054857  val RMSE: 3.251838
# Epoch 7/100 — train loss: 0.054512  val RMSE: 3.249148
# Epoch 8/100 — train loss: 0.054178  val RMSE: 3.246419
# Epoch 9/100 — train loss: 0.053846  val RMSE: 3.243601
# Epoch 10/100 — train loss: 0.053514  val RMSE: 3.240699
# Epoch 11/100 — train loss: 0.053183  val RMSE: 3.237746
# Epoch 12/100 — train loss: 0.052853  val RMSE: 3.234793
# Epoch 13/100 — train loss: 0.052526  val RMSE: 3.231899
# Epoch 14/100 — train loss: 0.052203  val RMSE: 3.229116
# Epoch 15/100 — train loss: 0.051884  val RMSE: 3.226504
# Epoch 16/100 — train loss: 0.051571  val RMSE: 3.224112
# Epoch 17/100 — train loss: 0.051263  val RMSE: 3.221987
# Epoch 18/100 — train loss: 0.050962  val RMSE: 3.220240
# Epoch 19/100 — train loss: 0.050666  val RMSE: 3.219144
# Epoch 20/100 — train loss: 0.050372  val RMSE: 3.218525
# Epoch 21/100 — train loss: 0.050081  val RMSE: 3.218211
# Epoch 22/100 — train loss: 0.049791  val RMSE: 3.218201
# Epoch 23/100 — train loss: 0.049502  val RMSE: 3.218583
# Epoch 24/100 — train loss: 0.049212  val RMSE: 3.219206
# Epoch 25/100 — train loss: 0.048921  val RMSE: 3.220040
# Epoch 26/100 — train loss: 0.048629  val RMSE: 3.221051
# Epoch 27/100 — train loss: 0.048335  val RMSE: 3.222228
# Epoch 28/100 — train loss: 0.048041  val RMSE: 3.223562
# Epoch 29/100 — train loss: 0.047748  val RMSE: 3.225000
# Epoch 30/100 — train loss: 0.047460  val RMSE: 3.226493
# Epoch 31/100 — train loss: 0.047177  val RMSE: 3.228016
# Epoch 32/100 — train loss: 0.046904  val RMSE: 3.229534
# Early stopping at epoch 32 (best val RMSE: 3.218201)
# Training complete for run 25 (best val RMSE: 3.218201)
# Run 25 — RMSE: 3.375776, MSE: 11.395860, NMSE: 0.1032651318
#
# ===== RUN 26/60 =====
# Epoch 1/100 — train loss: 0.087407  val RMSE: 3.281210
# Epoch 2/100 — train loss: 0.067419  val RMSE: 3.258468
# Epoch 3/100 — train loss: 0.059876  val RMSE: 3.215574
# Epoch 4/100 — train loss: 0.057992  val RMSE: 3.180630
# Epoch 5/100 — train loss: 0.057480  val RMSE: 3.174002
# Epoch 6/100 — train loss: 0.057012  val RMSE: 3.175082
# Epoch 7/100 — train loss: 0.056574  val RMSE: 3.176638
# Epoch 8/100 — train loss: 0.056195  val RMSE: 3.178085
# Epoch 9/100 — train loss: 0.055868  val RMSE: 3.179520
# Epoch 10/100 — train loss: 0.055582  val RMSE: 3.180975
# Epoch 11/100 — train loss: 0.055326  val RMSE: 3.182473
# Epoch 12/100 — train loss: 0.055092  val RMSE: 3.184022
# Epoch 13/100 — train loss: 0.054873  val RMSE: 3.185601
# Epoch 14/100 — train loss: 0.054665  val RMSE: 3.187208
# Epoch 15/100 — train loss: 0.054464  val RMSE: 3.188836
# Early stopping at epoch 15 (best val RMSE: 3.174002)
# Training complete for run 26 (best val RMSE: 3.174002)
# Run 26 — RMSE: 3.354937, MSE: 11.255606, NMSE: 0.1019941932
#
# ===== RUN 27/60 =====
# Epoch 1/100 — train loss: 0.137312  val RMSE: 3.267946
# Epoch 2/100 — train loss: 0.069203  val RMSE: 3.238993
# Epoch 3/100 — train loss: 0.060314  val RMSE: 3.220486
# Epoch 4/100 — train loss: 0.058389  val RMSE: 3.223649
# Epoch 5/100 — train loss: 0.057271  val RMSE: 3.228761
# Epoch 6/100 — train loss: 0.056404  val RMSE: 3.236020
# Epoch 7/100 — train loss: 0.055661  val RMSE: 3.242384
# Epoch 8/100 — train loss: 0.055089  val RMSE: 3.248164
# Epoch 9/100 — train loss: 0.054617  val RMSE: 3.252600
# Epoch 10/100 — train loss: 0.054251  val RMSE: 3.255616
# Epoch 11/100 — train loss: 0.054147  val RMSE: 3.253560
# Epoch 12/100 — train loss: 0.077027  val RMSE: 3.196163
# Epoch 13/100 — train loss: 0.054112  val RMSE: 3.272986
# Epoch 14/100 — train loss: 0.052884  val RMSE: 3.261542
# Epoch 15/100 — train loss: 0.052758  val RMSE: 3.257683
# Epoch 16/100 — train loss: 0.052674  val RMSE: 3.254527
# Epoch 17/100 — train loss: 0.052575  val RMSE: 3.252907
# Epoch 18/100 — train loss: 0.052403  val RMSE: 3.252134
# Epoch 19/100 — train loss: 0.052211  val RMSE: 3.252035
# Epoch 20/100 — train loss: 0.052034  val RMSE: 3.251997
# Epoch 21/100 — train loss: 0.051878  val RMSE: 3.251954
# Epoch 22/100 — train loss: 0.051744  val RMSE: 3.252159
# Early stopping at epoch 22 (best val RMSE: 3.196163)
# Training complete for run 27 (best val RMSE: 3.196163)
# Run 27 — RMSE: 3.372325, MSE: 11.372575, NMSE: 0.1030541267
#
# ===== RUN 28/60 =====
# Epoch 1/100 — train loss: 0.089512  val RMSE: 3.287957
# Epoch 2/100 — train loss: 0.068931  val RMSE: 3.279151
# Epoch 3/100 — train loss: 0.063887  val RMSE: 3.281655
# Epoch 4/100 — train loss: 0.062965  val RMSE: 3.283546
# Epoch 5/100 — train loss: 0.062767  val RMSE: 3.284295
# Epoch 6/100 — train loss: 0.062568  val RMSE: 3.284486
# Epoch 7/100 — train loss: 0.062345  val RMSE: 3.284416
# Epoch 8/100 — train loss: 0.062123  val RMSE: 3.284208
# Epoch 9/100 — train loss: 0.061916  val RMSE: 3.283883
# Epoch 10/100 — train loss: 0.061726  val RMSE: 3.283515
# Epoch 11/100 — train loss: 0.061555  val RMSE: 3.283112
# Epoch 12/100 — train loss: 0.061402  val RMSE: 3.282748
# Early stopping at epoch 12 (best val RMSE: 3.279151)
# Training complete for run 28 (best val RMSE: 3.279151)
# Run 28 — RMSE: 3.367402, MSE: 11.339399, NMSE: 0.1027534974
#
# ===== RUN 29/60 =====
# Epoch 1/100 — train loss: 0.181764  val RMSE: 3.295563
# Epoch 2/100 — train loss: 0.099257  val RMSE: 3.472422
# Epoch 3/100 — train loss: 0.103397  val RMSE: 3.159655
# Epoch 4/100 — train loss: 0.099392  val RMSE: 3.384227
# Epoch 5/100 — train loss: 0.097181  val RMSE: 2.589287
# Epoch 6/100 — train loss: 0.096341  val RMSE: 3.312364
# Epoch 7/100 — train loss: 0.095855  val RMSE: 3.314941
# Epoch 8/100 — train loss: 0.095464  val RMSE: 3.316267
# Epoch 9/100 — train loss: 0.095227  val RMSE: 3.317002
# Epoch 10/100 — train loss: 0.094955  val RMSE: 3.317406
# Epoch 11/100 — train loss: 0.094877  val RMSE: 3.317606
# Epoch 12/100 — train loss: 0.094755  val RMSE: 3.317708
# Epoch 13/100 — train loss: 0.094479  val RMSE: 3.317739
# Epoch 14/100 — train loss: 0.094132  val RMSE: 3.171909
# Epoch 15/100 — train loss: 0.093875  val RMSE: 3.317338
# Early stopping at epoch 15 (best val RMSE: 2.589287)
# Training complete for run 29 (best val RMSE: 2.589287)
# Run 29 — RMSE: 2.857232, MSE: 8.163777, NMSE: 0.0739771683
#
# ===== RUN 30/60 =====
# Epoch 1/100 — train loss: 0.101216  val RMSE: 3.269712
# Epoch 2/100 — train loss: 0.069337  val RMSE: 3.281283
# Epoch 3/100 — train loss: 0.065615  val RMSE: 3.283838
# Epoch 4/100 — train loss: 0.064410  val RMSE: 3.282402
# Epoch 5/100 — train loss: 0.063540  val RMSE: 3.280061
# Epoch 6/100 — train loss: 0.062808  val RMSE: 3.277901
# Epoch 7/100 — train loss: 0.062174  val RMSE: 3.276041
# Epoch 8/100 — train loss: 0.061586  val RMSE: 3.274052
# Epoch 9/100 — train loss: 0.061116  val RMSE: 3.272359
# Epoch 10/100 — train loss: 0.060709  val RMSE: 3.270856
# Epoch 11/100 — train loss: 0.060340  val RMSE: 3.269005
# Epoch 12/100 — train loss: 0.059994  val RMSE: 3.267151
# Epoch 13/100 — train loss: 0.059663  val RMSE: 3.265277
# Epoch 14/100 — train loss: 0.059355  val RMSE: 3.263232
# Epoch 15/100 — train loss: 0.059059  val RMSE: 3.261449
# Epoch 16/100 — train loss: 0.058784  val RMSE: 3.259597
# Epoch 17/100 — train loss: 0.058517  val RMSE: 3.257758
# Epoch 18/100 — train loss: 0.058259  val RMSE: 3.255960
# Epoch 19/100 — train loss: 0.058009  val RMSE: 3.254194
# Epoch 20/100 — train loss: 0.057765  val RMSE: 3.252467
# Epoch 21/100 — train loss: 0.057523  val RMSE: 3.250523
# Epoch 22/100 — train loss: 0.057285  val RMSE: 3.248849
# Epoch 23/100 — train loss: 0.057050  val RMSE: 3.247218
# Epoch 24/100 — train loss: 0.056819  val RMSE: 3.245592
# Epoch 25/100 — train loss: 0.056591  val RMSE: 3.243988
# Epoch 26/100 — train loss: 0.056366  val RMSE: 3.242433
# Epoch 27/100 — train loss: 0.056135  val RMSE: 3.240766
# Epoch 28/100 — train loss: 0.055905  val RMSE: 3.239360
# Epoch 29/100 — train loss: 0.055691  val RMSE: 3.237933
# Epoch 30/100 — train loss: 0.055489  val RMSE: 3.236646
# Epoch 31/100 — train loss: 0.055292  val RMSE: 3.235340
# Epoch 32/100 — train loss: 0.055084  val RMSE: 3.234316
# Epoch 33/100 — train loss: 0.054893  val RMSE: 3.233290
# Epoch 34/100 — train loss: 0.054706  val RMSE: 3.232486
# Epoch 35/100 — train loss: 0.054531  val RMSE: 3.231537
# Epoch 36/100 — train loss: 0.054379  val RMSE: 3.231423
# Epoch 37/100 — train loss: 0.054241  val RMSE: 3.231046
# Epoch 38/100 — train loss: 0.054124  val RMSE: 3.230479
# Epoch 39/100 — train loss: 0.053992  val RMSE: 3.229432
# Epoch 40/100 — train loss: 0.053871  val RMSE: 3.229007
# Epoch 41/100 — train loss: 0.053746  val RMSE: 3.228291
# Epoch 42/100 — train loss: 0.053622  val RMSE: 3.227441
# Epoch 43/100 — train loss: 0.053505  val RMSE: 3.226817
# Epoch 44/100 — train loss: 0.053382  val RMSE: 3.226225
# Epoch 45/100 — train loss: 0.053266  val RMSE: 3.225672
# Epoch 46/100 — train loss: 0.053155  val RMSE: 3.224578
# Epoch 47/100 — train loss: 0.053055  val RMSE: 3.224029
# Epoch 48/100 — train loss: 0.052956  val RMSE: 3.223477
# Epoch 49/100 — train loss: 0.052853  val RMSE: 3.223136
# Epoch 50/100 — train loss: 0.052750  val RMSE: 3.222794
# Epoch 51/100 — train loss: 0.052643  val RMSE: 3.222584
# Epoch 52/100 — train loss: 0.052526  val RMSE: 3.222620
# Epoch 53/100 — train loss: 0.052407  val RMSE: 3.222390
# Epoch 54/100 — train loss: 0.052298  val RMSE: 3.222267
# Epoch 55/100 — train loss: 0.052182  val RMSE: 3.222106
# Epoch 56/100 — train loss: 0.052058  val RMSE: 3.222493
# Epoch 57/100 — train loss: 0.051931  val RMSE: 3.222636
# Epoch 58/100 — train loss: 0.051824  val RMSE: 3.222975
# Epoch 59/100 — train loss: 0.051625  val RMSE: 3.223882
# Epoch 60/100 — train loss: 0.051621  val RMSE: 3.224294
# Epoch 61/100 — train loss: 0.051148  val RMSE: 3.226368
# Epoch 62/100 — train loss: 0.051606  val RMSE: 3.225307
# Epoch 63/100 — train loss: 0.051311  val RMSE: 3.230831
# Epoch 64/100 — train loss: 0.051591  val RMSE: 3.228339
# Epoch 65/100 — train loss: 0.050938  val RMSE: 3.228563
# Early stopping at epoch 65 (best val RMSE: 3.222106)
# Training complete for run 30 (best val RMSE: 3.222106)
# Run 30 — RMSE: 3.363296, MSE: 11.311761, NMSE: 0.1025030510
#
# ===== RUN 31/60 =====
# Epoch 1/100 — train loss: 0.087872  val RMSE: 3.261182
# Epoch 2/100 — train loss: 0.063865  val RMSE: 3.248651
# Epoch 3/100 — train loss: 0.056759  val RMSE: 3.245157
# Epoch 4/100 — train loss: 0.055175  val RMSE: 3.242742
# Epoch 5/100 — train loss: 0.054177  val RMSE: 3.240265
# Epoch 6/100 — train loss: 0.053345  val RMSE: 3.237936
# Epoch 7/100 — train loss: 0.052658  val RMSE: 3.235882
# Epoch 8/100 — train loss: 0.052102  val RMSE: 3.234117
# Epoch 9/100 — train loss: 0.051654  val RMSE: 3.232683
# Epoch 10/100 — train loss: 0.051297  val RMSE: 3.231468
# Epoch 11/100 — train loss: 0.051017  val RMSE: 3.230449
# Epoch 12/100 — train loss: 0.050795  val RMSE: 3.229605
# Epoch 13/100 — train loss: 0.050619  val RMSE: 3.228910
# Epoch 14/100 — train loss: 0.050475  val RMSE: 3.228345
# Epoch 15/100 — train loss: 0.050356  val RMSE: 3.227893
# Epoch 16/100 — train loss: 0.050252  val RMSE: 3.227538
# Epoch 17/100 — train loss: 0.050159  val RMSE: 3.227272
# Epoch 18/100 — train loss: 0.050072  val RMSE: 3.227089
# Epoch 19/100 — train loss: 0.049987  val RMSE: 3.226986
# Epoch 20/100 — train loss: 0.049903  val RMSE: 3.226962
# Epoch 21/100 — train loss: 0.049816  val RMSE: 3.227018
# Epoch 22/100 — train loss: 0.049727  val RMSE: 3.227155
# Epoch 23/100 — train loss: 0.049634  val RMSE: 3.227376
# Epoch 24/100 — train loss: 0.049537  val RMSE: 3.227681
# Epoch 25/100 — train loss: 0.049436  val RMSE: 3.228074
# Epoch 26/100 — train loss: 0.049330  val RMSE: 3.228555
# Epoch 27/100 — train loss: 0.049221  val RMSE: 3.229124
# Epoch 28/100 — train loss: 0.049108  val RMSE: 3.229779
# Epoch 29/100 — train loss: 0.048991  val RMSE: 3.230538
# Epoch 30/100 — train loss: 0.048872  val RMSE: 3.231367
# Early stopping at epoch 30 (best val RMSE: 3.226962)
# Training complete for run 31 (best val RMSE: 3.226962)
# Run 31 — RMSE: 3.381335, MSE: 11.433425, NMSE: 0.1036055286
#
# ===== RUN 32/60 =====
# Epoch 1/100 — train loss: 0.093748  val RMSE: 3.267113
# Epoch 2/100 — train loss: 0.063594  val RMSE: 3.235887
# Epoch 3/100 — train loss: 0.055946  val RMSE: 3.227988
# Epoch 4/100 — train loss: 0.054970  val RMSE: 3.226079
# Epoch 5/100 — train loss: 0.054465  val RMSE: 3.224680
# Epoch 6/100 — train loss: 0.054065  val RMSE: 3.224042
# Epoch 7/100 — train loss: 0.053724  val RMSE: 3.224241
# Epoch 8/100 — train loss: 0.053406  val RMSE: 3.225104
# Epoch 9/100 — train loss: 0.053091  val RMSE: 3.226404
# Epoch 10/100 — train loss: 0.052765  val RMSE: 3.227980
# Epoch 11/100 — train loss: 0.052417  val RMSE: 3.229801
# Epoch 12/100 — train loss: 0.052041  val RMSE: 3.231730
# Epoch 13/100 — train loss: 0.051637  val RMSE: 3.233623
# Epoch 14/100 — train loss: 0.051212  val RMSE: 3.235487
# Epoch 15/100 — train loss: 0.050777  val RMSE: 3.237375
# Epoch 16/100 — train loss: 0.050353  val RMSE: 3.238948
# Early stopping at epoch 16 (best val RMSE: 3.224042)
# Training complete for run 32 (best val RMSE: 3.224042)
# Run 32 — RMSE: 3.375813, MSE: 11.396116, NMSE: 0.1032674516
#
# ===== RUN 33/60 =====
# Epoch 1/100 — train loss: 0.102793  val RMSE: 3.270793
# Epoch 2/100 — train loss: 0.080353  val RMSE: 3.250598
# Epoch 3/100 — train loss: 0.062403  val RMSE: 3.255893
# Epoch 4/100 — train loss: 0.058228  val RMSE: 3.260576
# Epoch 5/100 — train loss: 0.057470  val RMSE: 3.260663
# Epoch 6/100 — train loss: 0.056946  val RMSE: 3.259340
# Epoch 7/100 — train loss: 0.056460  val RMSE: 3.257549
# Epoch 8/100 — train loss: 0.055963  val RMSE: 3.255345
# Epoch 9/100 — train loss: 0.055419  val RMSE: 3.252736
# Epoch 10/100 — train loss: 0.054803  val RMSE: 3.249778
# Epoch 11/100 — train loss: 0.054110  val RMSE: 3.246502
# Epoch 12/100 — train loss: 0.053331  val RMSE: 3.242949
# Epoch 13/100 — train loss: 0.052491  val RMSE: 3.239261
# Epoch 14/100 — train loss: 0.051608  val RMSE: 3.235871
# Epoch 15/100 — train loss: 0.050723  val RMSE: 3.233776
# Epoch 16/100 — train loss: 0.049848  val RMSE: 3.233054
# Epoch 17/100 — train loss: 0.049027  val RMSE: 3.233566
# Epoch 18/100 — train loss: 0.048324  val RMSE: 3.235007
# Epoch 19/100 — train loss: 0.047795  val RMSE: 3.236147
# Epoch 20/100 — train loss: 0.047432  val RMSE: 3.237417
# Epoch 21/100 — train loss: 0.047168  val RMSE: 3.238132
# Epoch 22/100 — train loss: 0.046968  val RMSE: 3.238731
# Epoch 23/100 — train loss: 0.046804  val RMSE: 3.239313
# Epoch 24/100 — train loss: 0.046656  val RMSE: 3.239816
# Epoch 25/100 — train loss: 0.046526  val RMSE: 3.240313
# Epoch 26/100 — train loss: 0.046408  val RMSE: 3.240797
# Early stopping at epoch 26 (best val RMSE: 3.233054)
# Training complete for run 33 (best val RMSE: 3.233054)
# Run 33 — RMSE: 3.380061, MSE: 11.424809, NMSE: 0.1035274554
#
# ===== RUN 34/60 =====
# Epoch 1/100 — train loss: 0.156689  val RMSE: 3.277506
# Epoch 2/100 — train loss: 0.075343  val RMSE: 3.284022
# Epoch 3/100 — train loss: 0.070166  val RMSE: 3.289731
# Epoch 4/100 — train loss: 0.068048  val RMSE: 3.292300
# Epoch 5/100 — train loss: 0.067064  val RMSE: 3.292814
# Epoch 6/100 — train loss: 0.066364  val RMSE: 3.292110
# Epoch 7/100 — train loss: 0.065734  val RMSE: 3.290290
# Epoch 8/100 — train loss: 0.065087  val RMSE: 3.287380
# Epoch 9/100 — train loss: 0.064396  val RMSE: 3.283357
# Epoch 10/100 — train loss: 0.063605  val RMSE: 3.278297
# Epoch 11/100 — train loss: 0.062711  val RMSE: 3.272159
# ...
# Epoch 21/100 — train loss: 0.050354  val RMSE: 3.223900
# Epoch 22/100 — train loss: 0.050283  val RMSE: 3.225581
# Epoch 23/100 — train loss: 0.050224  val RMSE: 3.226698
# Epoch 24/100 — train loss: 0.050176  val RMSE: 3.227957
# Epoch 25/100 — train loss: 0.050137  val RMSE: 3.228574
# Early stopping at epoch 25 (best val RMSE: 3.216782)
# Training complete for run 47 (best val RMSE: 3.216782)
# Run 47 — RMSE: 3.345714, MSE: 11.193800, NMSE: 0.1014341384
#
# ===== RUN 48/60 =====
# Epoch 1/100 — train loss: 0.128401  val RMSE: 3.269889
# Epoch 2/100 — train loss: 0.079728  val RMSE: 3.261643
# Epoch 3/100 — train loss: 0.073962  val RMSE: 3.259980
# Epoch 4/100 — train loss: 0.067946  val RMSE: 3.270538
# Epoch 5/100 — train loss: 0.064324  val RMSE: 3.278469
# Epoch 6/100 — train loss: 0.063293  val RMSE: 3.282588
# Epoch 7/100 — train loss: 0.062954  val RMSE: 3.283982
# Epoch 8/100 — train loss: 0.062566  val RMSE: 3.283566
# Epoch 9/100 — train loss: 0.062024  val RMSE: 3.282418
# Epoch 10/100 — train loss: 0.061367  val RMSE: 3.280715
# Epoch 11/100 — train loss: 0.060646  val RMSE: 3.278673
# Epoch 12/100 — train loss: 0.059893  val RMSE: 3.276459
# Epoch 13/100 — train loss: 0.059137  val RMSE: 3.274184
# Early stopping at epoch 13 (best val RMSE: 3.259980)
# Training complete for run 48 (best val RMSE: 3.259980)
# Run 48 — RMSE: 3.317250, MSE: 11.004148, NMSE: 0.0997155741
#
# ===== RUN 49/60 =====
# Epoch 1/100 — train loss: 0.084387  val RMSE: 3.277856
# Epoch 2/100 — train loss: 0.064071  val RMSE: 3.232282
# Epoch 3/100 — train loss: 0.056406  val RMSE: 3.214021
# Epoch 4/100 — train loss: 0.054959  val RMSE: 3.211006
# Epoch 5/100 — train loss: 0.054114  val RMSE: 3.211802
# Epoch 6/100 — train loss: 0.053400  val RMSE: 3.214808
# Epoch 7/100 — train loss: 0.052772  val RMSE: 3.218637
# Epoch 8/100 — train loss: 0.052205  val RMSE: 3.222340
# Epoch 9/100 — train loss: 0.051681  val RMSE: 3.225813
# Epoch 10/100 — train loss: 0.051181  val RMSE: 3.228941
# Epoch 11/100 — train loss: 0.050696  val RMSE: 3.231342
# Epoch 12/100 — train loss: 0.050233  val RMSE: 3.233111
# Epoch 13/100 — train loss: 0.049809  val RMSE: 3.234438
# Epoch 14/100 — train loss: 0.049447  val RMSE: 3.235756
# Early stopping at epoch 14 (best val RMSE: 3.211006)
# Training complete for run 49 (best val RMSE: 3.211006)
# Run 49 — RMSE: 3.357987, MSE: 11.276075, NMSE: 0.1021796825
#
# ===== RUN 50/60 =====
# Epoch 1/100 — train loss: 0.090647  val RMSE: 3.276254
# Epoch 2/100 — train loss: 0.062697  val RMSE: 3.235725
# Epoch 3/100 — train loss: 0.055019  val RMSE: 3.218249
# Epoch 4/100 — train loss: 0.054119  val RMSE: 3.215701
# Epoch 5/100 — train loss: 0.053611  val RMSE: 3.216230
# Epoch 6/100 — train loss: 0.053141  val RMSE: 3.217675
# Epoch 7/100 — train loss: 0.052710  val RMSE: 3.219401
# Epoch 8/100 — train loss: 0.052307  val RMSE: 3.221250
# Epoch 9/100 — train loss: 0.051922  val RMSE: 3.223210
# Epoch 10/100 — train loss: 0.051551  val RMSE: 3.225067
# Epoch 11/100 — train loss: 0.051192  val RMSE: 3.226735
# Epoch 12/100 — train loss: 0.050843  val RMSE: 3.228238
# Epoch 13/100 — train loss: 0.050505  val RMSE: 3.229595
# Epoch 14/100 — train loss: 0.050183  val RMSE: 3.230887
# Early stopping at epoch 14 (best val RMSE: 3.215701)
# Training complete for run 50 (best val RMSE: 3.215701)
# Run 50 — RMSE: 3.371079, MSE: 11.364171, NMSE: 0.1029779698
#
# ===== RUN 51/60 =====
# Epoch 1/100 — train loss: 0.093710  val RMSE: 3.280333
# Epoch 2/100 — train loss: 0.073843  val RMSE: 3.277618
# Epoch 3/100 — train loss: 0.066198  val RMSE: 3.278991
# Epoch 4/100 — train loss: 0.064296  val RMSE: 3.278725
# Epoch 5/100 — train loss: 0.063744  val RMSE: 3.276898
# Epoch 6/100 — train loss: 0.063260  val RMSE: 3.274449
# Epoch 7/100 — train loss: 0.062808  val RMSE: 3.271968
# Epoch 8/100 — train loss: 0.062395  val RMSE: 3.269464
# Epoch 9/100 — train loss: 0.062003  val RMSE: 3.266875
# Epoch 10/100 — train loss: 0.061614  val RMSE: 3.264050
# Epoch 11/100 — train loss: 0.061223  val RMSE: 3.260991
# Epoch 12/100 — train loss: 0.060801  val RMSE: 3.257489
# Epoch 13/100 — train loss: 0.060349  val RMSE: 3.253537
# Epoch 14/100 — train loss: 0.059863  val RMSE: 3.249109
# Epoch 15/100 — train loss: 0.059339  val RMSE: 3.244171
# Epoch 16/100 — train loss: 0.058789  val RMSE: 3.238780
# Epoch 17/100 — train loss: 0.058221  val RMSE: 3.232975
# Epoch 18/100 — train loss: 0.057656  val RMSE: 3.226716
# Epoch 19/100 — train loss: 0.057094  val RMSE: 3.220306
# Epoch 20/100 — train loss: 0.056553  val RMSE: 3.213931
# Epoch 21/100 — train loss: 0.056032  val RMSE: 3.208032
# Epoch 22/100 — train loss: 0.055549  val RMSE: 3.202775
# Epoch 23/100 — train loss: 0.055095  val RMSE: 3.198778
# Epoch 24/100 — train loss: 0.054664  val RMSE: 3.196046
# Epoch 25/100 — train loss: 0.054250  val RMSE: 3.194529
# Epoch 26/100 — train loss: 0.053852  val RMSE: 3.194168
# Epoch 27/100 — train loss: 0.053471  val RMSE: 3.194571
# Epoch 28/100 — train loss: 0.053097  val RMSE: 3.195576
# Epoch 29/100 — train loss: 0.052737  val RMSE: 3.197217
# Epoch 30/100 — train loss: 0.052380  val RMSE: 3.199288
# Epoch 31/100 — train loss: 0.052039  val RMSE: 3.201720
# Epoch 32/100 — train loss: 0.051708  val RMSE: 3.204501
# Epoch 33/100 — train loss: 0.051388  val RMSE: 3.207556
# Epoch 34/100 — train loss: 0.051070  val RMSE: 3.210751
# Epoch 35/100 — train loss: 0.050767  val RMSE: 3.213848
# Epoch 36/100 — train loss: 0.050481  val RMSE: 3.216950
# Early stopping at epoch 36 (best val RMSE: 3.194168)
# Training complete for run 51 (best val RMSE: 3.194168)
# Run 51 — RMSE: 3.348428, MSE: 11.211967, NMSE: 0.1015987570
#
# ===== RUN 52/60 =====
# Epoch 1/100 — train loss: 0.153071  val RMSE: 3.234601
# Epoch 2/100 — train loss: 0.081128  val RMSE: 3.262288
# Epoch 3/100 — train loss: 0.072986  val RMSE: 3.280989
# Epoch 4/100 — train loss: 0.068379  val RMSE: 3.285902
# Epoch 5/100 — train loss: 0.066164  val RMSE: 3.284102
# Epoch 6/100 — train loss: 0.064820  val RMSE: 3.280157
# Epoch 7/100 — train loss: 0.063594  val RMSE: 3.274858
# Epoch 8/100 — train loss: 0.062347  val RMSE: 3.268370
# Epoch 9/100 — train loss: 0.061152  val RMSE: 3.261341
# Epoch 10/100 — train loss: 0.060115  val RMSE: 3.254569
# Epoch 11/100 — train loss: 0.059290  val RMSE: 3.248633
# Early stopping at epoch 11 (best val RMSE: 3.234601)
# Training complete for run 52 (best val RMSE: 3.234601)
# Run 52 — RMSE: 3.308254, MSE: 10.944542, NMSE: 0.0991754458
#
# ===== RUN 53/60 =====
# Epoch 1/100 — train loss: 0.112110  val RMSE: 3.259334
# Epoch 2/100 — train loss: 0.069251  val RMSE: 3.252255
# Epoch 3/100 — train loss: 0.060988  val RMSE: 3.245622
# Epoch 4/100 — train loss: 0.058148  val RMSE: 3.239202
# Epoch 5/100 — train loss: 0.056588  val RMSE: 3.232926
# Epoch 6/100 — train loss: 0.055455  val RMSE: 3.227490
# Epoch 7/100 — train loss: 0.054628  val RMSE: 3.222978
# Epoch 8/100 — train loss: 0.054042  val RMSE: 3.219210
# Epoch 9/100 — train loss: 0.053644  val RMSE: 3.216156
# Epoch 10/100 — train loss: 0.053376  val RMSE: 3.213799
# Epoch 11/100 — train loss: 0.053198  val RMSE: 3.211827
# Epoch 12/100 — train loss: 0.053088  val RMSE: 3.210252
# Epoch 13/100 — train loss: 0.053021  val RMSE: 3.208948
# Epoch 14/100 — train loss: 0.052990  val RMSE: 3.207928
# Epoch 15/100 — train loss: 0.052978  val RMSE: 3.206908
# Epoch 16/100 — train loss: 0.052991  val RMSE: 3.206406
# Epoch 17/100 — train loss: 0.053009  val RMSE: 3.205933
# Epoch 18/100 — train loss: 0.053038  val RMSE: 3.205631
# Epoch 19/100 — train loss: 0.053069  val RMSE: 3.205204
# Epoch 20/100 — train loss: 0.053111  val RMSE: 3.205040
# Epoch 21/100 — train loss: 0.053159  val RMSE: 3.204918
# Epoch 22/100 — train loss: 0.053209  val RMSE: 3.204883
# Epoch 23/100 — train loss: 0.053266  val RMSE: 3.205033
# Epoch 24/100 — train loss: 0.053327  val RMSE: 3.205053
# Epoch 25/100 — train loss: 0.053393  val RMSE: 3.205269
# Epoch 26/100 — train loss: 0.053458  val RMSE: 3.205493
# Epoch 27/100 — train loss: 0.053525  val RMSE: 3.205704
# Epoch 28/100 — train loss: 0.053595  val RMSE: 3.205912
# Epoch 29/100 — train loss: 0.053669  val RMSE: 3.206042
# Epoch 30/100 — train loss: 0.053750  val RMSE: 3.206211
# Epoch 31/100 — train loss: 0.053834  val RMSE: 3.206643
# Epoch 32/100 — train loss: 0.053911  val RMSE: 3.206685
# Early stopping at epoch 32 (best val RMSE: 3.204883)
# Training complete for run 53 (best val RMSE: 3.204883)
# Run 53 — RMSE: 3.369217, MSE: 11.351624, NMSE: 0.1028642759
#
# ===== RUN 54/60 =====
# Epoch 1/100 — train loss: 0.091216  val RMSE: 3.276779
# Epoch 2/100 — train loss: 0.065015  val RMSE: 3.243782
# Epoch 3/100 — train loss: 0.053079  val RMSE: 3.236923
# Epoch 4/100 — train loss: 0.051813  val RMSE: 3.238616
# Epoch 5/100 — train loss: 0.051379  val RMSE: 3.238959
# Epoch 6/100 — train loss: 0.051036  val RMSE: 3.238918
# Epoch 7/100 — train loss: 0.050773  val RMSE: 3.238693
# Epoch 8/100 — train loss: 0.050567  val RMSE: 3.238409
# Epoch 9/100 — train loss: 0.050399  val RMSE: 3.238205
# Epoch 10/100 — train loss: 0.050253  val RMSE: 3.238184
# Epoch 11/100 — train loss: 0.050118  val RMSE: 3.238353
# Epoch 12/100 — train loss: 0.049991  val RMSE: 3.238666
# Epoch 13/100 — train loss: 0.049866  val RMSE: 3.239079
# Early stopping at epoch 13 (best val RMSE: 3.236923)
# Training complete for run 54 (best val RMSE: 3.236923)
# Run 54 — RMSE: 3.375595, MSE: 11.394645, NMSE: 0.1032541163
#
# ===== RUN 55/60 =====
# Epoch 1/100 — train loss: 0.098350  val RMSE: 3.286347
# Epoch 2/100 — train loss: 0.069328  val RMSE: 3.282084
# Epoch 3/100 — train loss: 0.064484  val RMSE: 3.278865
# Epoch 4/100 — train loss: 0.062404  val RMSE: 3.275707
# Epoch 5/100 — train loss: 0.060886  val RMSE: 3.269980
# Epoch 6/100 — train loss: 0.059131  val RMSE: 3.260875
# Epoch 7/100 — train loss: 0.056837  val RMSE: 3.250371
# Epoch 8/100 — train loss: 0.054263  val RMSE: 3.240112
# Epoch 9/100 — train loss: 0.052480  val RMSE: 3.235242
# Epoch 10/100 — train loss: 0.051612  val RMSE: 3.235032
# Epoch 11/100 — train loss: 0.051069  val RMSE: 3.236027
# Epoch 12/100 — train loss: 0.050648  val RMSE: 3.237154
# Epoch 13/100 — train loss: 0.050291  val RMSE: 3.238294
# Epoch 14/100 — train loss: 0.049971  val RMSE: 3.239475
# Epoch 15/100 — train loss: 0.049671  val RMSE: 3.240664
# Epoch 16/100 — train loss: 0.049382  val RMSE: 3.241848
# Epoch 17/100 — train loss: 0.049096  val RMSE: 3.242997
# Epoch 18/100 — train loss: 0.048810  val RMSE: 3.244075
# Epoch 19/100 — train loss: 0.048525  val RMSE: 3.245055
# Epoch 20/100 — train loss: 0.048250  val RMSE: 3.245942
# Early stopping at epoch 20 (best val RMSE: 3.235032)
# Training complete for run 55 (best val RMSE: 3.235032)
# Run 55 — RMSE: 3.388493, MSE: 11.481884, NMSE: 0.1040446475
#
# ===== RUN 56/60 =====
# Epoch 1/100 — train loss: 0.111262  val RMSE: 3.257415
# Epoch 2/100 — train loss: 0.073092  val RMSE: 3.269631
# Epoch 3/100 — train loss: 0.068417  val RMSE: 3.277446
# Epoch 4/100 — train loss: 0.067179  val RMSE: 3.279952
# Epoch 5/100 — train loss: 0.066679  val RMSE: 3.280061
# Epoch 6/100 — train loss: 0.066241  val RMSE: 3.279417
# Epoch 7/100 — train loss: 0.065827  val RMSE: 3.278753
# Epoch 8/100 — train loss: 0.065444  val RMSE: 3.277949
# Epoch 9/100 — train loss: 0.065094  val RMSE: 3.277092
# Epoch 10/100 — train loss: 0.064772  val RMSE: 3.276290
# Epoch 11/100 — train loss: 0.064472  val RMSE: 3.275346
# Early stopping at epoch 11 (best val RMSE: 3.257415)
# Training complete for run 56 (best val RMSE: 3.257415)
# Run 56 — RMSE: 3.336993, MSE: 11.135523, NMSE: 0.1009060509
#
# ===== RUN 57/60 =====
# Epoch 1/100 — train loss: 0.164318  val RMSE: 3.291345
# Epoch 2/100 — train loss: 0.096944  val RMSE: 3.329008
# Epoch 3/100 — train loss: 0.095257  val RMSE: 3.328281
# Epoch 4/100 — train loss: 0.094640  val RMSE: 3.320144
# Epoch 5/100 — train loss: 0.094325  val RMSE: 3.328326
# Epoch 6/100 — train loss: 0.094100  val RMSE: 3.332389
# Epoch 7/100 — train loss: 0.095666  val RMSE: 3.319133
# Epoch 8/100 — train loss: 0.094159  val RMSE: 3.317172
# Epoch 9/100 — train loss: 0.093827  val RMSE: 3.317200
# Epoch 10/100 — train loss: 0.093870  val RMSE: 3.320685
# Epoch 11/100 — train loss: 0.093783  val RMSE: 3.317882
# Early stopping at epoch 11 (best val RMSE: 3.291345)
# Training complete for run 57 (best val RMSE: 3.291345)
# Run 57 — RMSE: 3.443702, MSE: 11.859081, NMSE: 0.1074626717
#
# ===== RUN 58/60 =====
# Epoch 1/100 — train loss: 0.097767  val RMSE: 3.274228
# Epoch 2/100 — train loss: 0.068799  val RMSE: 3.278577
# Epoch 3/100 — train loss: 0.064998  val RMSE: 3.283900
# Epoch 4/100 — train loss: 0.064199  val RMSE: 3.286088
# Epoch 5/100 — train loss: 0.063767  val RMSE: 3.286748
# Epoch 6/100 — train loss: 0.063369  val RMSE: 3.286781
# Epoch 7/100 — train loss: 0.062983  val RMSE: 3.286383
# Epoch 8/100 — train loss: 0.062621  val RMSE: 3.285686
# Epoch 9/100 — train loss: 0.062273  val RMSE: 3.284810
# Epoch 10/100 — train loss: 0.061944  val RMSE: 3.283782
# Epoch 11/100 — train loss: 0.061633  val RMSE: 3.282620
# Early stopping at epoch 11 (best val RMSE: 3.274228)
# Training complete for run 58 (best val RMSE: 3.274228)
# Run 58 — RMSE: 3.362368, MSE: 11.305517, NMSE: 0.1024464774
#
# ===== RUN 59/60 =====
# Epoch 1/100 — train loss: 0.084624  val RMSE: 3.296684
# Epoch 2/100 — train loss: 0.066183  val RMSE: 3.276238
# Epoch 3/100 — train loss: 0.058056  val RMSE: 3.265467
# Epoch 4/100 — train loss: 0.055853  val RMSE: 3.260076
# Epoch 5/100 — train loss: 0.054715  val RMSE: 3.256911
# Epoch 6/100 — train loss: 0.053895  val RMSE: 3.254657
# Epoch 7/100 — train loss: 0.053274  val RMSE: 3.252889
# Epoch 8/100 — train loss: 0.052785  val RMSE: 3.251495
# Epoch 9/100 — train loss: 0.052385  val RMSE: 3.250410
# Epoch 10/100 — train loss: 0.052046  val RMSE: 3.249569
# Epoch 11/100 — train loss: 0.051751  val RMSE: 3.248947
# Epoch 12/100 — train loss: 0.051491  val RMSE: 3.248558
# Epoch 13/100 — train loss: 0.051261  val RMSE: 3.248339
# Epoch 14/100 — train loss: 0.051059  val RMSE: 3.248230
# Epoch 15/100 — train loss: 0.050882  val RMSE: 3.248156
# Epoch 16/100 — train loss: 0.050732  val RMSE: 3.248072
# Epoch 17/100 — train loss: 0.050603  val RMSE: 3.247969
# Epoch 18/100 — train loss: 0.050486  val RMSE: 3.247888
# Epoch 19/100 — train loss: 0.050369  val RMSE: 3.247909
# Epoch 20/100 — train loss: 0.050242  val RMSE: 3.248112
# Epoch 21/100 — train loss: 0.050097  val RMSE: 3.248823
# Epoch 22/100 — train loss: 0.049938  val RMSE: 3.249737
# Epoch 23/100 — train loss: 0.049770  val RMSE: 3.250551
# Epoch 24/100 — train loss: 0.049596  val RMSE: 3.251348
# Epoch 25/100 — train loss: 0.049418  val RMSE: 3.252045
# Epoch 26/100 — train loss: 0.049242  val RMSE: 3.252639
# Epoch 27/100 — train loss: 0.049074  val RMSE: 3.253047
# Epoch 28/100 — train loss: 0.048917  val RMSE: 3.253346
# Early stopping at epoch 28 (best val RMSE: 3.247888)
# Training complete for run 59 (best val RMSE: 3.247888)
# Run 59 — RMSE: 3.384288, MSE: 11.453408, NMSE: 0.1037866069
#
# ===== RUN 60/60 =====
# Epoch 1/100 — train loss: 0.099894  val RMSE: 3.258471
# Epoch 2/100 — train loss: 0.071300  val RMSE: 3.267711
# Epoch 3/100 — train loss: 0.065795  val RMSE: 3.272133
# Epoch 4/100 — train loss: 0.064039  val RMSE: 3.272695
# Epoch 5/100 — train loss: 0.063303  val RMSE: 3.268445
# Epoch 6/100 — train loss: 0.062588  val RMSE: 3.258880
# Epoch 7/100 — train loss: 0.061671  val RMSE: 3.242465
# Epoch 8/100 — train loss: 0.060649  val RMSE: 3.219853
# Epoch 9/100 — train loss: 0.059810  val RMSE: 3.199880
# Epoch 10/100 — train loss: 0.059273  val RMSE: 3.190215
# Epoch 11/100 — train loss: 0.058879  val RMSE: 3.188244
# Epoch 12/100 — train loss: 0.058530  val RMSE: 3.189829
# Epoch 13/100 — train loss: 0.058203  val RMSE: 3.192719
# Epoch 14/100 — train loss: 0.057902  val RMSE: 3.195917
# Epoch 15/100 — train loss: 0.057624  val RMSE: 3.198957
# Epoch 16/100 — train loss: 0.057370  val RMSE: 3.201696
# Epoch 17/100 — train loss: 0.057136  val RMSE: 3.204121
# Epoch 18/100 — train loss: 0.056920  val RMSE: 3.206236
# Epoch 19/100 — train loss: 0.056717  val RMSE: 3.208076
# Epoch 20/100 — train loss: 0.056525  val RMSE: 3.209687
# Epoch 21/100 — train loss: 0.056341  val RMSE: 3.211112
# Early stopping at epoch 21 (best val RMSE: 3.188244)
# Training complete for run 60 (best val RMSE: 3.188244)
# Run 60 — RMSE: 3.337851, MSE: 11.141247, NMSE: 0.1009579142

# %%
#Noise-robustness sweep (averaged over multiple noise draws, with explicit clean baseline)

N_NOISE_DRAWS = 10  # average over multiple ε(t) realizations per model, per level

# Re-evaluate the clean (0% noise) baseline through evaluate_on_test, so it
# uses the exact same evaluation path as the noisy conditions below.
clean_rmse, clean_mse, clean_nmse = [], [], []
for model in all_models:
    _, rmse, mse, nmse = evaluate_on_test(model, X_test, train, train_scaled, raw_values, scaler, device)
    clean_rmse.append(rmse)
    clean_mse.append(mse)
    clean_nmse.append(nmse)

print(f"[{'no noise':>10}]  "
      f"RMSE: {np.mean(clean_rmse):.6f} ± {np.std(clean_rmse):.6f}  |  "
      f"MSE: {np.mean(clean_mse):.6f} ± {np.std(clean_mse):.6f}  |  "
      f"NMSE: {np.mean(clean_nmse):.10f} ± {np.std(clean_nmse):.10f}")

noise_robustness = {}  # noise_level -> dict of per-model RMSE/MSE/NMSE (averaged over draws)

for noise_level in NOISE_LEVELS:
    level_rmse, level_mse, level_nmse = [], [], []

    for run, model in enumerate(all_models):
        draw_rmse, draw_mse, draw_nmse = [], [], []
        for draw in range(N_NOISE_DRAWS):
            seed = hash((noise_level, run, draw)) % (2 ** 32)
            X_test_noisy = add_gaussian_noise(X_test, noise_level, ref_std, seed=seed)
            _, rmse, mse, nmse = evaluate_on_test(
                model, X_test_noisy, train, train_scaled, raw_values, scaler, device
            )
            draw_rmse.append(rmse)
            draw_mse.append(mse)
            draw_nmse.append(nmse)

        level_rmse.append(np.mean(draw_rmse))  # this model's average over noise draws
        level_mse.append(np.mean(draw_mse))
        level_nmse.append(np.mean(draw_nmse))

    noise_robustness[noise_level] = {'rmse': level_rmse, 'mse': level_mse, 'nmse': level_nmse}
    print(f"[{noise_level * 100:5.1f}% noise]  "
          f"RMSE: {np.mean(level_rmse):.6f} ± {np.std(level_rmse):.6f}  |  "
          f"MSE: {np.mean(level_mse):.6f} ± {np.std(level_mse):.6f}  |  "
          f"NMSE: {np.mean(level_nmse):.10f} ± {np.std(level_nmse):.10f}")
# Out:
# [  no noise]  RMSE: 3.332749 ± 0.131462  |  MSE: 11.124495 ± 0.794029  |  NMSE: 0.1008061171 ± 0.0071951973
# [  0.5% noise]  RMSE: 3.332664 ± 0.131377  |  MSE: 11.123912 ± 0.793389  |  NMSE: 0.1008008390 ± 0.0071894018
# [  5.0% noise]  RMSE: 3.332710 ± 0.131427  |  MSE: 11.124231 ± 0.793756  |  NMSE: 0.1008037237 ± 0.0071927264
# [ 10.0% noise]  RMSE: 3.332916 ± 0.131445  |  MSE: 11.125623 ± 0.793873  |  NMSE: 0.1008163392 ± 0.0071937836
# [ 15.0% noise]  RMSE: 3.332710 ± 0.131400  |  MSE: 11.124249 ± 0.793544  |  NMSE: 0.1008038924 ± 0.0071908092

# %% [markdown]
# ## Observations
#
# ### Baseline on Dow Jones Industrial Index
#
# **Run the notebook to generate results and fill in observations:**
#
# 1. **Prediction Quality**: Compare RMSE/MSE/NMSE with other variants
# 2. **Training Stability**: Examine loss curves for convergence behavior
# 3. **Prediction Tracking**: Assess how well predictions track actual values
# 4. **Computational Cost**: Note training time per run
#
# *After running all 5 variant notebooks, perform cross-variant comparison to evaluate
# whether fuzzy logic improves nonlinearity handling, interpretability, and prediction performance.*
