# %% [markdown]
# # Pure LSTM — Monthly Lake Erie Levels (Gaussian Noise Evaluation)
#
# Time series forecasting with Gaussian noise robustness analysis.
# - Noise levels: [0.0, 0.005]
# - 60 runs × 100 epochs per noise level
# - Last 60 for test, rest for training, NO validation

# %%
# ============================================================
# ALL IMPORTS
# ============================================================

import numpy as np
import pandas as pd
import torch
import torch.nn as nn
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from math import sqrt
import matplotlib.pyplot as plt
import warnings
import os

warnings.filterwarnings('ignore')
print(f"PyTorch version: {torch.__version__}")
print(f"NumPy version: {np.__version__}")
# Out:
# PyTorch version: 2.10.0+cu128
# NumPy version: 2.0.2

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

class PureLSTM(nn.Module):
    """
    Standard LSTM (Hochreiter & Schmidhuber, 1997) for time series forecasting.
    Stateful: maintains hidden and cell states across sequence steps.
    Same hyperparameters as LSTM-SNP for fair comparison.
    """
    def __init__(self, input_dim=1, hidden_dim=8, output_dim=1):
        super().__init__()
        self.hidden_dim = hidden_dim
        self.lstm = nn.LSTM(input_dim, hidden_dim, batch_first=True)
        self.fc = nn.Linear(hidden_dim, output_dim)
        self.u = None  # (h, c) state

    def reset_states(self, batch_size, device):
        h0 = torch.zeros(1, batch_size, self.hidden_dim, device=device)
        c0 = torch.zeros(1, batch_size, self.hidden_dim, device=device)
        self.u = (h0, c0)
        
    def detach_states(self):
        if self.u is not None:
            self.u = (self.u[0].detach(), self.u[1].detach())

    def forward(self, x):
        if self.u is None or self.u[0].device != x.device:
            self.reset_states(x.size(0), x.device)
            
        lstm_out, self.u = self.lstm(x, self.u)
        out = self.fc(lstm_out[:, -1, :])
        return out


def build_model(input_dim, units):
    return PureLSTM(input_dim=input_dim, hidden_dim=units, output_dim=1)

# %%
# Quick model check
model = build_model(input_dim=1, units=8)
print(model)
print(f"Total params: {sum(p.numel() for p in model.parameters())}")
# Out:
# PureLSTM(
#   (lstm): LSTM(1, 8, batch_first=True)
#   (fc): Linear(in_features=8, out_features=1, bias=True)
# )
# Total params: 361

# %% [markdown]
# ## Data Pipeline — Monthly Lake Erie Levels

# %%
import os
for f in os.listdir('/kaggle/input/datasets/sassyaws123456789/monthly-lake-erie-levels-1921-19-csv'):
    print(f)
# Out:
# monthly-lake-erie-levels-1921-19.csv

# %%
# ============================================================
# 1. Load Time Series Data
# ============================================================
series = pd.read_csv(
    '/kaggle/input/datasets/sassyaws123456789/monthly-lake-erie-levels-1921-19-csv/monthly-lake-erie-levels-1921-19.csv',
    header=0,
    parse_dates=[0],
    index_col=0
)

original_raw_values = series.values.flatten()
print(f"Base data shape: {original_raw_values.shape}")
print(f"First 5 values: {original_raw_values[:5]}")
# Out:
# Base data shape: (600,)
# First 5 values: [14.763 14.649 15.085 16.376 16.926]

# %%
# ============================================================
# 2. First-Order Differencing
# ============================================================

def difference(dataset, interval=1):
    diff = []
    for i in range(interval, len(dataset)):
        value = dataset[i] - dataset[i - interval]
        diff.append(value)
    return np.array(diff)

# %%
# ============================================================
# 3. Convert to Supervised Learning Format (lag=1)
# ============================================================

def timeseries_to_supervised(data, lag=1):
    df = pd.DataFrame(data)
    columns = [df.shift(i) for i in range(1, lag+1)]
    columns.append(df)
    df = pd.concat(columns, axis=1)
    df.fillna(0, inplace=True)
    return df.values

# %% [markdown]
# ## Training Loop

# %%
# ============================================================
# Gaussian Noise Evaluation + 60-Run Experiment Protocol (PyTorch)
# ============================================================
import torch
import torch.nn as nn

s_x = np.std(original_raw_values)
noise_levels = [0.0, 0.005]
_molab_results = []

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"\n--- [PyTorch] RUNNING ON {device} ---\n")

for lam in noise_levels:
    sigma = lam * s_x
    print("\n" + "="*80)
    print(f"EVALUATING NOISE LEVEL: {lam*100:.1f}% (lambda={lam}, sigma={sigma:.6f})")
    print("="*80 + "\n")
    
    np.random.seed(42)
    torch.manual_seed(42)
    noise = np.random.normal(0, sigma, size=original_raw_values.shape)
    raw_values = original_raw_values + noise
    
    # 2. Difference
    diff_values = difference(raw_values, 1)
    # 3. Supervised (lag=1)
    supervised = timeseries_to_supervised(diff_values, 1)
    # 4. Split (Last 60 for test, NO validation)
    train, test = supervised[:-60], supervised[-60:]
    # 5. Scale
    scaler = MinMaxScaler(feature_range=(-1, 1))
    scaler.fit(train)
    train_scaled = scaler.transform(train)
    test_scaled = scaler.transform(test)
    # 6. Reshape
    X_train, y_train = train_scaled[:, 0:-1], train_scaled[:, -1]
    X_train = X_train.reshape((X_train.shape[0], 1, X_train.shape[1]))
    
    print(f"X_train shape: {X_train.shape}, y_train shape: {y_train.shape}")
    
    all_rmse = []
    all_mse = []
    all_nmse = []
    all_predictions = []
    all_losses = []
    
    for run in range(60):
        print(f'\n===== RUN {run+1}/60 [Noise {lam*100:.1f}%] =====')
        
        np.random.seed(run)
        torch.manual_seed(run)
        
        model = build_model(input_dim=1, units=8).to(device)
        optimizer = torch.optim.Adam(model.parameters(), lr=0.001)
        criterion = nn.MSELoss()
        
        # Pre-tensorize training data
        X_train_t = torch.tensor(X_train, dtype=torch.float32).to(device)
        y_train_t = torch.tensor(y_train, dtype=torch.float32).to(device)
        n_samples = X_train_t.size(0)
        
        run_losses = []
        for epoch in range(100):
            model.train()
            model.reset_states(1, device)
            
            epoch_loss = 0.0
            for i in range(n_samples):
                x_i = X_train_t[i:i+1]
                y_i = y_train_t[i:i+1]
                
                optimizer.zero_grad()
                pred = model(x_i)
                loss = criterion(pred.squeeze(-1), y_i)
                loss.backward()
                optimizer.step()
                model.detach_states()
                epoch_loss += loss.item()
            
            avg_loss = epoch_loss / n_samples
            run_losses.append(avg_loss)
            if (epoch+1) % 10 == 0:
                print(f"  Epoch {epoch+1}/100, Loss: {avg_loss:.6f}")
        
        all_losses.append(run_losses)
        print(f'Training complete for run {run+1}')
        
        # Warm-up: condition hidden states on training data
        model.eval()
        with torch.no_grad():
            model.reset_states(1, device)
            for i in range(len(train_scaled)):
                X_raw = train_scaled[i, 0:-1]
                X_input = torch.tensor(X_raw, dtype=torch.float32).view(1, 1, len(X_raw)).to(device)
                model(X_input)
        
        # Test predictions (single-step)
        predictions = []
        model.eval()
        with torch.no_grad():
            for i in range(len(test_scaled)):
                X = test_scaled[i, 0:-1]
                X_input = torch.tensor(X, dtype=torch.float32).view(1, 1, len(X)).to(device)
                yhat = model(X_input).item()
                
                # Invert scaling
                new_row = list(X) + [yhat]
                array = np.array(new_row).reshape(1, len(new_row))
                inverted = scaler.inverse_transform(array)[0, -1]
                
                # Invert differencing
                inverted = inverted + raw_values[len(train) + i]
                predictions.append(inverted)
        
        # Compute metrics
        actual = raw_values[-len(predictions):]
        rmse = sqrt(mean_squared_error(actual, predictions))
        mse = mean_squared_error(actual, predictions)
        meanV = np.mean(actual)
        dominator = np.linalg.norm(np.array(predictions) - meanV, 2)
        nmse = mse / np.power(dominator, 2)
        
        all_rmse.append(rmse)
        all_mse.append(mse)
        all_nmse.append(nmse)
        all_predictions.append(predictions)
        
        print(f'Run {run+1} \u2014 RMSE: {rmse:.6f}, MSE: {mse:.6f}, NMSE: {nmse:.10f}')
    
    # End of 60 runs for this noise level
    best_idx = np.argmin(all_rmse)
    
    print(f'\n===== STATS FOR NOISE {lam*100:.1f}% (60 runs) =====')
    print(f'RMSE: {np.mean(all_rmse):.6f} +/- {np.std(all_rmse):.6f}')
    print(f'MSE:  {np.mean(all_mse):.6f} +/- {np.std(all_mse):.6f}')
    print(f'NMSE: {np.mean(all_nmse):.10f} +/- {np.std(all_nmse):.10f}')
    print(f'Best run: {best_idx+1} (RMSE: {all_rmse[best_idx]:.6f})')
    
    _molab_results.append([lam, 
        np.mean(all_rmse), np.std(all_rmse),
        np.mean(all_mse), np.std(all_mse),
        np.mean(all_nmse), np.std(all_nmse),
        all_rmse[best_idx], all_predictions[best_idx], all_losses[best_idx], raw_values.copy()])
# Out:
# --- [PyTorch] RUNNING ON cuda ---
#
#
# ================================================================================
# EVALUATING NOISE LEVEL: 0.0% (lambda=0.0, sigma=0.000000)
# ================================================================================
#
# X_train shape: (539, 1, 1), y_train shape: (539,)
#
# ===== RUN 1/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.053314
#   Epoch 20/100, Loss: 0.053940
#   Epoch 30/100, Loss: 0.053080
#   Epoch 40/100, Loss: 0.052983
#   Epoch 50/100, Loss: 0.053301
#   Epoch 60/100, Loss: 0.050532
#   Epoch 70/100, Loss: 0.048186
#   Epoch 80/100, Loss: 0.046533
#   Epoch 90/100, Loss: 0.045620
#   Epoch 100/100, Loss: 0.045121
# Training complete for run 1
# Run 1 — RMSE: 0.423993, MSE: 0.179770, NMSE: 0.0015742199
#
# ===== RUN 2/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.059201
#   Epoch 20/100, Loss: 0.060385
#   Epoch 30/100, Loss: 0.059716
#   Epoch 40/100, Loss: 0.063749
#   Epoch 50/100, Loss: 0.058437
#   Epoch 60/100, Loss: 0.057620
#   Epoch 70/100, Loss: 0.057168
#   Epoch 80/100, Loss: 0.056686
#   Epoch 90/100, Loss: 0.056592
#   Epoch 100/100, Loss: 0.053297
# Training complete for run 2
# Run 2 — RMSE: 0.532694, MSE: 0.283763, NMSE: 0.0023279567
#
# ===== RUN 3/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.061006
#   Epoch 20/100, Loss: 0.058272
#   Epoch 30/100, Loss: 0.053441
#   Epoch 40/100, Loss: 0.051014
#   Epoch 50/100, Loss: 0.048417
#   Epoch 60/100, Loss: 0.046767
#   Epoch 70/100, Loss: 0.045678
#   Epoch 80/100, Loss: 0.044375
#   Epoch 90/100, Loss: 0.043164
#   Epoch 100/100, Loss: 0.042400
# Training complete for run 3
# Run 3 — RMSE: 0.426724, MSE: 0.182094, NMSE: 0.0015673015
#
# ===== RUN 4/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.056679
#   Epoch 20/100, Loss: 0.053010
#   Epoch 30/100, Loss: 0.052617
#   Epoch 40/100, Loss: 0.053781
#   Epoch 50/100, Loss: 0.054767
#   Epoch 60/100, Loss: 0.054157
#   Epoch 70/100, Loss: 0.053280
#   Epoch 80/100, Loss: 0.052690
#   Epoch 90/100, Loss: 0.052265
#   Epoch 100/100, Loss: 0.051963
# Training complete for run 4
# Run 4 — RMSE: 0.443664, MSE: 0.196838, NMSE: 0.0015755454
#
# ===== RUN 5/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.055919
#   Epoch 20/100, Loss: 0.048619
#   Epoch 30/100, Loss: 0.047690
#   Epoch 40/100, Loss: 0.047100
#   Epoch 50/100, Loss: 0.045969
#   Epoch 60/100, Loss: 0.044832
#   Epoch 70/100, Loss: 0.044342
#   Epoch 80/100, Loss: 0.044299
#   Epoch 90/100, Loss: 0.044302
#   Epoch 100/100, Loss: 0.044042
# Training complete for run 5
# Run 5 — RMSE: 0.417946, MSE: 0.174679, NMSE: 0.0016012276
#
# ===== RUN 6/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.052941
#   Epoch 20/100, Loss: 0.051815
#   Epoch 30/100, Loss: 0.052700
#   Epoch 40/100, Loss: 0.051011
#   Epoch 50/100, Loss: 0.048634
#   Epoch 60/100, Loss: 0.047736
#   Epoch 70/100, Loss: 0.047571
#   Epoch 80/100, Loss: 0.047444
#   Epoch 90/100, Loss: 0.047113
#   Epoch 100/100, Loss: 0.046676
# Training complete for run 6
# Run 6 — RMSE: 0.431381, MSE: 0.186089, NMSE: 0.0015113161
#
# ===== RUN 7/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.061729
#   Epoch 20/100, Loss: 0.060184
#   Epoch 30/100, Loss: 0.060157
#   Epoch 40/100, Loss: 0.058652
#   Epoch 50/100, Loss: 0.057166
#   Epoch 60/100, Loss: 0.057082
#   Epoch 70/100, Loss: 0.056533
#   Epoch 80/100, Loss: 0.055287
#   Epoch 90/100, Loss: 0.053894
#   Epoch 100/100, Loss: 0.052270
# Training complete for run 7
# Run 7 — RMSE: 0.559399, MSE: 0.312927, NMSE: 0.0025785443
#
# ===== RUN 8/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.060516
#   Epoch 20/100, Loss: 0.059396
#   Epoch 30/100, Loss: 0.058507
#   Epoch 40/100, Loss: 0.057630
#   Epoch 50/100, Loss: 0.056512
#   Epoch 60/100, Loss: 0.054918
#   Epoch 70/100, Loss: 0.053278
#   Epoch 80/100, Loss: 0.052159
#   Epoch 90/100, Loss: 0.051699
#   Epoch 100/100, Loss: 0.051573
# Training complete for run 8
# Run 8 — RMSE: 0.474197, MSE: 0.224863, NMSE: 0.0019048716
#
# ===== RUN 9/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.062865
#   Epoch 20/100, Loss: 0.062507
#   Epoch 30/100, Loss: 0.062122
#   Epoch 40/100, Loss: 0.061718
#   Epoch 50/100, Loss: 0.055100
#   Epoch 60/100, Loss: 0.051373
#   Epoch 70/100, Loss: 0.051477
#   Epoch 80/100, Loss: 0.051439
#   Epoch 90/100, Loss: 0.051298
#   Epoch 100/100, Loss: 0.051471
# Training complete for run 9
# Run 9 — RMSE: 0.446528, MSE: 0.199388, NMSE: 0.0016645805
#
# ===== RUN 10/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.050500
#   Epoch 20/100, Loss: 0.051937
#   Epoch 30/100, Loss: 0.053111
#   Epoch 40/100, Loss: 0.052801
#   Epoch 50/100, Loss: 0.051770
#   Epoch 60/100, Loss: 0.050948
#   Epoch 70/100, Loss: 0.050192
#   Epoch 80/100, Loss: 0.049373
#   Epoch 90/100, Loss: 0.048720
#   Epoch 100/100, Loss: 0.048300
# Training complete for run 10
# Run 10 — RMSE: 0.446602, MSE: 0.199453, NMSE: 0.0017461652
#
# ===== RUN 11/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.061660
#   Epoch 20/100, Loss: 0.062457
#   Epoch 30/100, Loss: 0.059344
#   Epoch 40/100, Loss: 0.051604
#   Epoch 50/100, Loss: 0.051793
#   Epoch 60/100, Loss: 0.051956
#   Epoch 70/100, Loss: 0.050474
#   Epoch 80/100, Loss: 0.049781
#   Epoch 90/100, Loss: 0.049452
#   Epoch 100/100, Loss: 0.049224
# Training complete for run 11
# Run 11 — RMSE: 0.461015, MSE: 0.212535, NMSE: 0.0018282199
#
# ===== RUN 12/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.051760
#   Epoch 20/100, Loss: 0.053348
#   Epoch 30/100, Loss: 0.054678
#   Epoch 40/100, Loss: 0.054532
#   Epoch 50/100, Loss: 0.055027
#   Epoch 60/100, Loss: 0.054464
#   Epoch 70/100, Loss: 0.052352
#   Epoch 80/100, Loss: 0.050914
#   Epoch 90/100, Loss: 0.050335
#   Epoch 100/100, Loss: 0.050193
# Training complete for run 12
# Run 12 — RMSE: 0.446804, MSE: 0.199634, NMSE: 0.0017024535
#
# ===== RUN 13/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.062845
#   Epoch 20/100, Loss: 0.058893
#   Epoch 30/100, Loss: 0.055783
#   Epoch 40/100, Loss: 0.053633
#   Epoch 50/100, Loss: 0.052714
#   Epoch 60/100, Loss: 0.050862
#   Epoch 70/100, Loss: 0.049511
#   Epoch 80/100, Loss: 0.048614
#   Epoch 90/100, Loss: 0.048332
#   Epoch 100/100, Loss: 0.048696
# Training complete for run 13
# Run 13 — RMSE: 0.442619, MSE: 0.195911, NMSE: 0.0016367086
#
# ===== RUN 14/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.051345
#   Epoch 20/100, Loss: 0.050812
#   Epoch 30/100, Loss: 0.049933
#   Epoch 40/100, Loss: 0.046912
#   Epoch 50/100, Loss: 0.045628
#   Epoch 60/100, Loss: 0.044941
#   Epoch 70/100, Loss: 0.044230
#   Epoch 80/100, Loss: 0.043626
#   Epoch 90/100, Loss: 0.043244
#   Epoch 100/100, Loss: 0.043017
# Training complete for run 14
# Run 14 — RMSE: 0.407259, MSE: 0.165860, NMSE: 0.0014325480
#
# ===== RUN 15/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.057725
#   Epoch 20/100, Loss: 0.055607
#   Epoch 30/100, Loss: 0.055158
#   Epoch 40/100, Loss: 0.051154
#   Epoch 50/100, Loss: 0.048549
#   Epoch 60/100, Loss: 0.047753
#   Epoch 70/100, Loss: 0.047445
#   Epoch 80/100, Loss: 0.047307
#   Epoch 90/100, Loss: 0.047183
#   Epoch 100/100, Loss: 0.047000
# Training complete for run 15
# Run 15 — RMSE: 0.450695, MSE: 0.203126, NMSE: 0.0017294076
#
# ===== RUN 16/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.064268
#   Epoch 20/100, Loss: 0.057223
#   Epoch 30/100, Loss: 0.051813
#   Epoch 40/100, Loss: 0.048474
#   Epoch 50/100, Loss: 0.047140
#   Epoch 60/100, Loss: 0.047574
#   Epoch 70/100, Loss: 0.048184
#   Epoch 80/100, Loss: 0.048259
#   Epoch 90/100, Loss: 0.048612
#   Epoch 100/100, Loss: 0.056904
# Training complete for run 16
# Run 16 — RMSE: 0.451152, MSE: 0.203538, NMSE: 0.0017271748
#
# ===== RUN 17/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.054348
#   Epoch 20/100, Loss: 0.051331
#   Epoch 30/100, Loss: 0.051294
#   Epoch 40/100, Loss: 0.051535
#   Epoch 50/100, Loss: 0.051423
#   Epoch 60/100, Loss: 0.050676
#   Epoch 70/100, Loss: 0.049956
#   Epoch 80/100, Loss: 0.050052
#   Epoch 90/100, Loss: 0.051180
#   Epoch 100/100, Loss: 0.049799
# Training complete for run 17
# Run 17 — RMSE: 0.445813, MSE: 0.198749, NMSE: 0.0016526510
#
# ===== RUN 18/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.055682
#   Epoch 20/100, Loss: 0.053698
#   Epoch 30/100, Loss: 0.053253
#   Epoch 40/100, Loss: 0.053060
#   Epoch 50/100, Loss: 0.053131
#   Epoch 60/100, Loss: 0.053788
#   Epoch 70/100, Loss: 0.054295
#   Epoch 80/100, Loss: 0.054410
#   Epoch 90/100, Loss: 0.054449
#   Epoch 100/100, Loss: 0.054493
# Training complete for run 18
# Run 18 — RMSE: 0.461309, MSE: 0.212806, NMSE: 0.0017881343
#
# ===== RUN 19/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.062595
#   Epoch 20/100, Loss: 0.061982
#   Epoch 30/100, Loss: 0.061230
#   Epoch 40/100, Loss: 0.060224
#   Epoch 50/100, Loss: 0.059250
#   Epoch 60/100, Loss: 0.058382
#   Epoch 70/100, Loss: 0.057086
#   Epoch 80/100, Loss: 0.053936
#   Epoch 90/100, Loss: 0.050883
#   Epoch 100/100, Loss: 0.049897
# Training complete for run 19
# Run 19 — RMSE: 0.466562, MSE: 0.217680, NMSE: 0.0018680432
#
# ===== RUN 20/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.058588
#   Epoch 20/100, Loss: 0.054494
#   Epoch 30/100, Loss: 0.053266
#   Epoch 40/100, Loss: 0.050936
#   Epoch 50/100, Loss: 0.050172
#   Epoch 60/100, Loss: 0.049906
#   Epoch 70/100, Loss: 0.048961
#   Epoch 80/100, Loss: 0.047985
#   Epoch 90/100, Loss: 0.047373
#   Epoch 100/100, Loss: 0.047028
# Training complete for run 20
# Run 20 — RMSE: 0.422499, MSE: 0.178505, NMSE: 0.0015669611
#
# ===== RUN 21/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.061861
#   Epoch 20/100, Loss: 0.061057
#   Epoch 30/100, Loss: 0.060499
#   Epoch 40/100, Loss: 0.054780
#   Epoch 50/100, Loss: 0.054259
#   Epoch 60/100, Loss: 0.054106
#   Epoch 70/100, Loss: 0.053691
#   Epoch 80/100, Loss: 0.052562
#   Epoch 90/100, Loss: 0.051363
#   Epoch 100/100, Loss: 0.050442
# Training complete for run 21
# Run 21 — RMSE: 0.445359, MSE: 0.198345, NMSE: 0.0016427001
#
# ===== RUN 22/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.063158
#   Epoch 20/100, Loss: 0.060403
#   Epoch 30/100, Loss: 0.059746
#   Epoch 40/100, Loss: 0.058795
#   Epoch 50/100, Loss: 0.056561
#   Epoch 60/100, Loss: 0.055121
#   Epoch 70/100, Loss: 0.053129
#   Epoch 80/100, Loss: 0.049788
#   Epoch 90/100, Loss: 0.048328
#   Epoch 100/100, Loss: 0.047713
# Training complete for run 22
# Run 22 — RMSE: 0.453587, MSE: 0.205741, NMSE: 0.0017861175
#
# ===== RUN 23/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.063046
#   Epoch 20/100, Loss: 0.062070
#   Epoch 30/100, Loss: 0.059515
#   Epoch 40/100, Loss: 0.058459
#   Epoch 50/100, Loss: 0.056528
#   Epoch 60/100, Loss: 0.049355
#   Epoch 70/100, Loss: 0.048816
#   Epoch 80/100, Loss: 0.047740
#   Epoch 90/100, Loss: 0.046780
#   Epoch 100/100, Loss: 0.045715
# Training complete for run 23
# Run 23 — RMSE: 0.429165, MSE: 0.184182, NMSE: 0.0016120492
#
# ===== RUN 24/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.062701
#   Epoch 20/100, Loss: 0.061363
#   Epoch 30/100, Loss: 0.059935
#   Epoch 40/100, Loss: 0.052917
#   Epoch 50/100, Loss: 0.049114
#   Epoch 60/100, Loss: 0.047556
#   Epoch 70/100, Loss: 0.046326
#   Epoch 80/100, Loss: 0.045331
#   Epoch 90/100, Loss: 0.044458
#   Epoch 100/100, Loss: 0.043728
# Training complete for run 24
# Run 24 — RMSE: 0.421468, MSE: 0.177635, NMSE: 0.0016167834
#
# ===== RUN 25/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.058568
#   Epoch 20/100, Loss: 0.057191
#   Epoch 30/100, Loss: 0.057293
#   Epoch 40/100, Loss: 0.052265
#   Epoch 50/100, Loss: 0.050246
#   Epoch 60/100, Loss: 0.051525
#   Epoch 70/100, Loss: 0.051679
#   Epoch 80/100, Loss: 0.051015
#   Epoch 90/100, Loss: 0.049824
#   Epoch 100/100, Loss: 0.048867
# Training complete for run 25
# Run 25 — RMSE: 0.452547, MSE: 0.204799, NMSE: 0.0017353066
#
# ===== RUN 26/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.061304
#   Epoch 20/100, Loss: 0.058138
#   Epoch 30/100, Loss: 0.053555
#   Epoch 40/100, Loss: 0.052389
#   Epoch 50/100, Loss: 0.052728
#   Epoch 60/100, Loss: 0.052730
#   Epoch 70/100, Loss: 0.052418
#   Epoch 80/100, Loss: 0.051933
#   Epoch 90/100, Loss: 0.051225
#   Epoch 100/100, Loss: 0.050180
# Training complete for run 26
# Run 26 — RMSE: 0.457898, MSE: 0.209670, NMSE: 0.0017897688
#
# ===== RUN 27/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.062178
#   Epoch 20/100, Loss: 0.061148
#   Epoch 30/100, Loss: 0.055497
#   Epoch 40/100, Loss: 0.052775
#   Epoch 50/100, Loss: 0.053292
#   Epoch 60/100, Loss: 0.053093
#   Epoch 70/100, Loss: 0.052616
#   Epoch 80/100, Loss: 0.052160
#   Epoch 90/100, Loss: 0.051628
#   Epoch 100/100, Loss: 0.050876
# Training complete for run 27
# Run 27 — RMSE: 0.468804, MSE: 0.219777, NMSE: 0.0018513233
#
# ===== RUN 28/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.057536
#   Epoch 20/100, Loss: 0.057795
#   Epoch 30/100, Loss: 0.057721
#   Epoch 40/100, Loss: 0.057961
#   Epoch 50/100, Loss: 0.058281
#   Epoch 60/100, Loss: 0.058461
#   Epoch 70/100, Loss: 0.058279
#   Epoch 80/100, Loss: 0.057062
#   Epoch 90/100, Loss: 0.055182
#   Epoch 100/100, Loss: 0.053900
# Training complete for run 28
# Run 28 — RMSE: 0.520015, MSE: 0.270415, NMSE: 0.0022292006
#
# ===== RUN 29/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.060840
#   Epoch 20/100, Loss: 0.053697
#   Epoch 30/100, Loss: 0.052805
#   Epoch 40/100, Loss: 0.051704
#   Epoch 50/100, Loss: 0.050910
#   Epoch 60/100, Loss: 0.050300
#   Epoch 70/100, Loss: 0.049756
#   Epoch 80/100, Loss: 0.049512
#   Epoch 90/100, Loss: 0.048753
#   Epoch 100/100, Loss: 0.047019
# Training complete for run 29
# Run 29 — RMSE: 0.423634, MSE: 0.179466, NMSE: 0.0015522710
#
# ===== RUN 30/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.063088
#   Epoch 20/100, Loss: 0.061490
#   Epoch 30/100, Loss: 0.061272
#   Epoch 40/100, Loss: 0.056071
#   Epoch 50/100, Loss: 0.051548
#   Epoch 60/100, Loss: 0.051679
#   Epoch 70/100, Loss: 0.051548
#   Epoch 80/100, Loss: 0.051654
#   Epoch 90/100, Loss: 0.052567
#   Epoch 100/100, Loss: 0.053995
# Training complete for run 30
# Run 30 — RMSE: 0.490427, MSE: 0.240519, NMSE: 0.0020224817
#
# ===== RUN 31/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.053042
#   Epoch 20/100, Loss: 0.051837
#   Epoch 30/100, Loss: 0.052116
#   Epoch 40/100, Loss: 0.052378
#   Epoch 50/100, Loss: 0.052558
#   Epoch 60/100, Loss: 0.052435
#   Epoch 70/100, Loss: 0.051934
#   Epoch 80/100, Loss: 0.051184
#   Epoch 90/100, Loss: 0.050326
#   Epoch 100/100, Loss: 0.049493
# Training complete for run 31
# Run 31 — RMSE: 0.443346, MSE: 0.196556, NMSE: 0.0016984423
#
# ===== RUN 32/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.061221
#   Epoch 20/100, Loss: 0.058694
#   Epoch 30/100, Loss: 0.058633
#   Epoch 40/100, Loss: 0.058490
#   Epoch 50/100, Loss: 0.057791
#   Epoch 60/100, Loss: 0.061184
#   Epoch 70/100, Loss: 0.053484
#   Epoch 80/100, Loss: 0.051268
#   Epoch 90/100, Loss: 0.049871
#   Epoch 100/100, Loss: 0.050181
# Training complete for run 32
# Run 32 — RMSE: 0.452508, MSE: 0.204764, NMSE: 0.0017735843
#
# ===== RUN 33/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.061082
#   Epoch 20/100, Loss: 0.057290
#   Epoch 30/100, Loss: 0.056113
#   Epoch 40/100, Loss: 0.055448
#   Epoch 50/100, Loss: 0.054201
#   Epoch 60/100, Loss: 0.052815
#   Epoch 70/100, Loss: 0.051474
#   Epoch 80/100, Loss: 0.050847
#   Epoch 90/100, Loss: 0.050394
#   Epoch 100/100, Loss: 0.049783
# Training complete for run 33
# Run 33 — RMSE: 0.455167, MSE: 0.207177, NMSE: 0.0017243845
#
# ===== RUN 34/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.061260
#   Epoch 20/100, Loss: 0.058062
#   Epoch 30/100, Loss: 0.062512
#   Epoch 40/100, Loss: 0.049361
#   Epoch 50/100, Loss: 0.052667
#   Epoch 60/100, Loss: 0.052646
#   Epoch 70/100, Loss: 0.052739
#   Epoch 80/100, Loss: 0.052855
#   Epoch 90/100, Loss: 0.052314
#   Epoch 100/100, Loss: 0.050968
# Training complete for run 34
# Run 34 — RMSE: 0.488188, MSE: 0.238328, NMSE: 0.0020002666
#
# ===== RUN 35/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.057057
#   Epoch 20/100, Loss: 0.056997
#   Epoch 30/100, Loss: 0.057469
#   Epoch 40/100, Loss: 0.058306
#   Epoch 50/100, Loss: 0.059227
#   Epoch 60/100, Loss: 0.059444
#   Epoch 70/100, Loss: 0.058762
#   Epoch 80/100, Loss: 0.057886
#   Epoch 90/100, Loss: 0.057441
#   Epoch 100/100, Loss: 0.057190
# Training complete for run 35
# Run 35 — RMSE: 0.512650, MSE: 0.262810, NMSE: 0.0020940281
#
# ===== RUN 36/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.059016
#   Epoch 20/100, Loss: 0.058867
#   Epoch 30/100, Loss: 0.050793
#   Epoch 40/100, Loss: 0.046581
#   Epoch 50/100, Loss: 0.045200
#   Epoch 60/100, Loss: 0.044153
#   Epoch 70/100, Loss: 0.043709
#   Epoch 80/100, Loss: 0.043647
#   Epoch 90/100, Loss: 0.043450
#   Epoch 100/100, Loss: 0.043201
# Training complete for run 36
# Run 36 — RMSE: 0.410058, MSE: 0.168148, NMSE: 0.0014220343
#
# ===== RUN 37/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.062498
#   Epoch 20/100, Loss: 0.061929
#   Epoch 30/100, Loss: 0.060130
#   Epoch 40/100, Loss: 0.053097
#   Epoch 50/100, Loss: 0.052795
#   Epoch 60/100, Loss: 0.050689
#   Epoch 70/100, Loss: 0.049210
#   Epoch 80/100, Loss: 0.048268
#   Epoch 90/100, Loss: 0.047650
#   Epoch 100/100, Loss: 0.047289
# Training complete for run 37
# Run 37 — RMSE: 0.437779, MSE: 0.191650, NMSE: 0.0016464024
#
# ===== RUN 38/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.057664
#   Epoch 20/100, Loss: 0.053931
#   Epoch 30/100, Loss: 0.050104
#   Epoch 40/100, Loss: 0.047721
#   Epoch 50/100, Loss: 0.046447
#   Epoch 60/100, Loss: 0.045789
#   Epoch 70/100, Loss: 0.045363
#   Epoch 80/100, Loss: 0.044880
#   Epoch 90/100, Loss: 0.044476
#   Epoch 100/100, Loss: 0.044121
# Training complete for run 38
# Run 38 — RMSE: 0.412935, MSE: 0.170516, NMSE: 0.0015032007
#
# ===== RUN 39/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.056522
#   Epoch 20/100, Loss: 0.054136
#   Epoch 30/100, Loss: 0.051114
#   Epoch 40/100, Loss: 0.048398
#   Epoch 50/100, Loss: 0.047165
#   Epoch 60/100, Loss: 0.046500
#   Epoch 70/100, Loss: 0.045870
#   Epoch 80/100, Loss: 0.045275
#   Epoch 90/100, Loss: 0.044714
#   Epoch 100/100, Loss: 0.044205
# Training complete for run 39
# Run 39 — RMSE: 0.410742, MSE: 0.168709, NMSE: 0.0014437464
#
# ===== RUN 40/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.058670
#   Epoch 20/100, Loss: 0.058761
#   Epoch 30/100, Loss: 0.058396
#   Epoch 40/100, Loss: 0.052973
#   Epoch 50/100, Loss: 0.049880
#   Epoch 60/100, Loss: 0.048654
#   Epoch 70/100, Loss: 0.048194
#   Epoch 80/100, Loss: 0.048063
#   Epoch 90/100, Loss: 0.047911
#   Epoch 100/100, Loss: 0.047108
# Training complete for run 40
# Run 40 — RMSE: 0.426099, MSE: 0.181561, NMSE: 0.0015872338
#
# ===== RUN 41/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.059863
#   Epoch 20/100, Loss: 0.059401
#   Epoch 30/100, Loss: 0.057362
#   Epoch 40/100, Loss: 0.047570
#   Epoch 50/100, Loss: 0.046643
#   Epoch 60/100, Loss: 0.046329
#   Epoch 70/100, Loss: 0.045694
#   Epoch 80/100, Loss: 0.045221
#   Epoch 90/100, Loss: 0.044940
#   Epoch 100/100, Loss: 0.044786
# Training complete for run 41
# Run 41 — RMSE: 0.399413, MSE: 0.159531, NMSE: 0.0013904655
#
# ===== RUN 42/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.055877
#   Epoch 20/100, Loss: 0.049991
#   Epoch 30/100, Loss: 0.048275
#   Epoch 40/100, Loss: 0.047116
#   Epoch 50/100, Loss: 0.046397
#   Epoch 60/100, Loss: 0.045927
#   Epoch 70/100, Loss: 0.045548
#   Epoch 80/100, Loss: 0.045235
#   Epoch 90/100, Loss: 0.045002
#   Epoch 100/100, Loss: 0.044738
# Training complete for run 42
# Run 42 — RMSE: 0.414152, MSE: 0.171522, NMSE: 0.0015136715
#
# ===== RUN 43/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.060311
#   Epoch 20/100, Loss: 0.059971
#   Epoch 30/100, Loss: 0.059757
#   Epoch 40/100, Loss: 0.058863
#   Epoch 50/100, Loss: 0.058029
#   Epoch 60/100, Loss: 0.055854
#   Epoch 70/100, Loss: 0.053473
#   Epoch 80/100, Loss: 0.049862
#   Epoch 90/100, Loss: 0.046619
#   Epoch 100/100, Loss: 0.045492
# Training complete for run 43
# Run 43 — RMSE: 0.404728, MSE: 0.163805, NMSE: 0.0014366153
#
# ===== RUN 44/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.062937
#   Epoch 20/100, Loss: 0.062314
#   Epoch 30/100, Loss: 0.059439
#   Epoch 40/100, Loss: 0.058762
#   Epoch 50/100, Loss: 0.058601
#   Epoch 60/100, Loss: 0.055614
#   Epoch 70/100, Loss: 0.050561
#   Epoch 80/100, Loss: 0.050314
#   Epoch 90/100, Loss: 0.050395
#   Epoch 100/100, Loss: 0.050507
# Training complete for run 44
# Run 44 — RMSE: 0.457757, MSE: 0.209541, NMSE: 0.0018188492
#
# ===== RUN 45/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.060636
#   Epoch 20/100, Loss: 0.058556
#   Epoch 30/100, Loss: 0.056563
#   Epoch 40/100, Loss: 0.056319
#   Epoch 50/100, Loss: 0.055783
#   Epoch 60/100, Loss: 0.055058
#   Epoch 70/100, Loss: 0.054757
#   Epoch 80/100, Loss: 0.054277
#   Epoch 90/100, Loss: 0.053834
#   Epoch 100/100, Loss: 0.053598
# Training complete for run 45
# Run 45 — RMSE: 0.496134, MSE: 0.246149, NMSE: 0.0020371066
#
# ===== RUN 46/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.061062
#   Epoch 20/100, Loss: 0.060968
#   Epoch 30/100, Loss: 0.060540
#   Epoch 40/100, Loss: 0.058466
#   Epoch 50/100, Loss: 0.055366
#   Epoch 60/100, Loss: 0.054691
#   Epoch 70/100, Loss: 0.055734
#   Epoch 80/100, Loss: 0.055077
#   Epoch 90/100, Loss: 0.053480
#   Epoch 100/100, Loss: 0.051986
# Training complete for run 46
# Run 46 — RMSE: 0.488574, MSE: 0.238704, NMSE: 0.0020186165
#
# ===== RUN 47/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.063247
#   Epoch 20/100, Loss: 0.062778
#   Epoch 30/100, Loss: 0.061921
#   Epoch 40/100, Loss: 0.061283
#   Epoch 50/100, Loss: 0.060825
#   Epoch 60/100, Loss: 0.060478
#   Epoch 70/100, Loss: 0.060201
#   Epoch 80/100, Loss: 0.059942
#   Epoch 90/100, Loss: 0.059369
#   Epoch 100/100, Loss: 0.058750
# Training complete for run 47
# Run 47 — RMSE: 1.380344, MSE: 1.905350, NMSE: 0.0079216942
#
# ===== RUN 48/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.054868
#   Epoch 20/100, Loss: 0.055475
#   Epoch 30/100, Loss: 0.055497
#   Epoch 40/100, Loss: 0.052220
#   Epoch 50/100, Loss: 0.050005
#   Epoch 60/100, Loss: 0.048413
#   Epoch 70/100, Loss: 0.047357
#   Epoch 80/100, Loss: 0.047179
#   Epoch 90/100, Loss: 0.047899
#   Epoch 100/100, Loss: 0.047721
# Training complete for run 48
# Run 48 — RMSE: 0.501200, MSE: 0.251202, NMSE: 0.0021650361
#
# ===== RUN 49/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.060946
#   Epoch 20/100, Loss: 0.060621
#   Epoch 30/100, Loss: 0.061395
#   Epoch 40/100, Loss: 0.062757
#   Epoch 50/100, Loss: 0.062235
#   Epoch 60/100, Loss: 0.059178
#   Epoch 70/100, Loss: 0.055407
#   Epoch 80/100, Loss: 0.049375
#   Epoch 90/100, Loss: 0.048891
#   Epoch 100/100, Loss: 0.049599
# Training complete for run 49
# Run 49 — RMSE: 0.461623, MSE: 0.213096, NMSE: 0.0017749293
#
# ===== RUN 50/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.054777
#   Epoch 20/100, Loss: 0.053450
#   Epoch 30/100, Loss: 0.051973
#   Epoch 40/100, Loss: 0.051725
#   Epoch 50/100, Loss: 0.051916
#   Epoch 60/100, Loss: 0.051647
#   Epoch 70/100, Loss: 0.050887
#   Epoch 80/100, Loss: 0.050051
#   Epoch 90/100, Loss: 0.049233
#   Epoch 100/100, Loss: 0.048575
# Training complete for run 50
# Run 50 — RMSE: 0.444443, MSE: 0.197530, NMSE: 0.0016917347
#
# ===== RUN 51/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.060084
#   Epoch 20/100, Loss: 0.058579
#   Epoch 30/100, Loss: 0.057731
#   Epoch 40/100, Loss: 0.053055
#   Epoch 50/100, Loss: 0.048423
#   Epoch 60/100, Loss: 0.046792
#   Epoch 70/100, Loss: 0.046464
#   Epoch 80/100, Loss: 0.046067
#   Epoch 90/100, Loss: 0.045628
#   Epoch 100/100, Loss: 0.045225
# Training complete for run 51
# Run 51 — RMSE: 0.409244, MSE: 0.167481, NMSE: 0.0014909761
#
# ===== RUN 52/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.058621
#   Epoch 20/100, Loss: 0.054884
#   Epoch 30/100, Loss: 0.055232
#   Epoch 40/100, Loss: 0.053748
#   Epoch 50/100, Loss: 0.051897
#   Epoch 60/100, Loss: 0.050863
#   Epoch 70/100, Loss: 0.050816
#   Epoch 80/100, Loss: 0.051415
#   Epoch 90/100, Loss: 0.052645
#   Epoch 100/100, Loss: 0.055145
# Training complete for run 52
# Run 52 — RMSE: 0.489446, MSE: 0.239557, NMSE: 0.0018981332
#
# ===== RUN 53/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.060920
#   Epoch 20/100, Loss: 0.062145
#   Epoch 30/100, Loss: 0.060697
#   Epoch 40/100, Loss: 0.057448
#   Epoch 50/100, Loss: 0.053003
#   Epoch 60/100, Loss: 0.052704
#   Epoch 70/100, Loss: 0.051733
#   Epoch 80/100, Loss: 0.048413
#   Epoch 90/100, Loss: 0.045092
#   Epoch 100/100, Loss: 0.043925
# Training complete for run 53
# Run 53 — RMSE: 0.413064, MSE: 0.170622, NMSE: 0.0015171594
#
# ===== RUN 54/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.060590
#   Epoch 20/100, Loss: 0.060680
#   Epoch 30/100, Loss: 0.051844
#   Epoch 40/100, Loss: 0.049622
#   Epoch 50/100, Loss: 0.048827
#   Epoch 60/100, Loss: 0.048159
#   Epoch 70/100, Loss: 0.047536
#   Epoch 80/100, Loss: 0.047004
#   Epoch 90/100, Loss: 0.046035
#   Epoch 100/100, Loss: 0.045430
# Training complete for run 54
# Run 54 — RMSE: 0.406256, MSE: 0.165044, NMSE: 0.0014020994
#
# ===== RUN 55/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.049469
#   Epoch 20/100, Loss: 0.049040
#   Epoch 30/100, Loss: 0.047713
#   Epoch 40/100, Loss: 0.046330
#   Epoch 50/100, Loss: 0.045459
#   Epoch 60/100, Loss: 0.044874
#   Epoch 70/100, Loss: 0.044359
#   Epoch 80/100, Loss: 0.043845
#   Epoch 90/100, Loss: 0.043353
#   Epoch 100/100, Loss: 0.042929
# Training complete for run 55
# Run 55 — RMSE: 0.413146, MSE: 0.170690, NMSE: 0.0015296765
#
# ===== RUN 56/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.049000
#   Epoch 20/100, Loss: 0.047314
#   Epoch 30/100, Loss: 0.047100
#   Epoch 40/100, Loss: 0.048001
#   Epoch 50/100, Loss: 0.048769
#   Epoch 60/100, Loss: 0.048312
#   Epoch 70/100, Loss: 0.048646
#   Epoch 80/100, Loss: 0.050894
#   Epoch 90/100, Loss: 0.055435
#   Epoch 100/100, Loss: 0.054943
# Training complete for run 56
# Run 56 — RMSE: 0.566839, MSE: 0.321306, NMSE: 0.0024205398
#
# ===== RUN 57/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.060985
#   Epoch 20/100, Loss: 0.058945
#   Epoch 30/100, Loss: 0.055715
#   Epoch 40/100, Loss: 0.053422
#   Epoch 50/100, Loss: 0.051386
#   Epoch 60/100, Loss: 0.050251
#   Epoch 70/100, Loss: 0.049227
#   Epoch 80/100, Loss: 0.048054
#   Epoch 90/100, Loss: 0.046917
#   Epoch 100/100, Loss: 0.046053
# Training complete for run 57
# Run 57 — RMSE: 0.429363, MSE: 0.184352, NMSE: 0.0016162636
#
# ===== RUN 58/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.059209
#   Epoch 20/100, Loss: 0.057027
#   Epoch 30/100, Loss: 0.058171
#   Epoch 40/100, Loss: 0.058924
#   Epoch 50/100, Loss: 0.057291
#   Epoch 60/100, Loss: 0.052394
#   Epoch 70/100, Loss: 0.048312
#   Epoch 80/100, Loss: 0.047415
#   Epoch 90/100, Loss: 0.046651
#   Epoch 100/100, Loss: 0.046091
# Training complete for run 58
# Run 58 — RMSE: 0.428414, MSE: 0.183539, NMSE: 0.0016089961
#
# ===== RUN 59/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.059448
#   Epoch 20/100, Loss: 0.058120
#   Epoch 30/100, Loss: 0.057568
#   Epoch 40/100, Loss: 0.052013
#   Epoch 50/100, Loss: 0.049227
#   Epoch 60/100, Loss: 0.053584
#   Epoch 70/100, Loss: 0.052896
#   Epoch 80/100, Loss: 0.058551
#   Epoch 90/100, Loss: 0.052033
#   Epoch 100/100, Loss: 0.056007
# Training complete for run 59
# Run 59 — RMSE: 1.305517, MSE: 1.704375, NMSE: 0.0079581245
#
# ===== RUN 60/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.056715
#   Epoch 20/100, Loss: 0.056402
#   Epoch 30/100, Loss: 0.055870
#   Epoch 40/100, Loss: 0.055300
#   Epoch 50/100, Loss: 0.053631
#   Epoch 60/100, Loss: 0.052685
#   Epoch 70/100, Loss: 0.051581
#   Epoch 80/100, Loss: 0.050703
#   Epoch 90/100, Loss: 0.050185
#   Epoch 100/100, Loss: 0.049498
# Training complete for run 60
# Run 60 — RMSE: 0.441040, MSE: 0.194516, NMSE: 0.0017030480
#
# ===== STATS FOR NOISE 0.0% (60 runs) =====
# RMSE: 0.480365 +/- 0.164409
# MSE:  0.257781 +/- 0.289928
# NMSE: 0.0019438182 +/- 0.0011408619
# Best run: 41 (RMSE: 0.399413)
#
# ================================================================================
# EVALUATING NOISE LEVEL: 0.5% (lambda=0.005, sigma=0.010052)
# ================================================================================
#
# X_train shape: (539, 1, 1), y_train shape: (539,)
#
# ===== RUN 1/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.053271
#   Epoch 20/100, Loss: 0.053886
#   Epoch 30/100, Loss: 0.052966
#   Epoch 40/100, Loss: 0.052831
#   Epoch 50/100, Loss: 0.053145
#   Epoch 60/100, Loss: 0.050415
#   Epoch 70/100, Loss: 0.048106
#   Epoch 80/100, Loss: 0.046494
#   Epoch 90/100, Loss: 0.045598
#   Epoch 100/100, Loss: 0.045097
# Training complete for run 1
# Run 1 — RMSE: 0.426844, MSE: 0.182195, NMSE: 0.0015936131
#
# ===== RUN 2/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.059159
#   Epoch 20/100, Loss: 0.060355
#   Epoch 30/100, Loss: 0.059664
#   Epoch 40/100, Loss: 0.065083
#   Epoch 50/100, Loss: 0.058404
#   Epoch 60/100, Loss: 0.057628
#   Epoch 70/100, Loss: 0.057168
#   Epoch 80/100, Loss: 0.056677
#   Epoch 90/100, Loss: 0.055037
#   Epoch 100/100, Loss: 0.053588
# Training complete for run 2
# Run 2 — RMSE: 0.544726, MSE: 0.296727, NMSE: 0.0024464509
#
# ===== RUN 3/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.060928
#   Epoch 20/100, Loss: 0.058264
#   Epoch 30/100, Loss: 0.053283
#   Epoch 40/100, Loss: 0.050666
#   Epoch 50/100, Loss: 0.047997
#   Epoch 60/100, Loss: 0.046455
#   Epoch 70/100, Loss: 0.045644
#   Epoch 80/100, Loss: 0.044654
#   Epoch 90/100, Loss: 0.043459
#   Epoch 100/100, Loss: 0.042629
# Training complete for run 3
# Run 3 — RMSE: 0.430813, MSE: 0.185600, NMSE: 0.0015821848
#
# ===== RUN 4/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.056643
#   Epoch 20/100, Loss: 0.053023
#   Epoch 30/100, Loss: 0.052663
#   Epoch 40/100, Loss: 0.053864
#   Epoch 50/100, Loss: 0.054863
#   Epoch 60/100, Loss: 0.054194
#   Epoch 70/100, Loss: 0.053339
#   Epoch 80/100, Loss: 0.052763
#   Epoch 90/100, Loss: 0.052364
#   Epoch 100/100, Loss: 0.052086
# Training complete for run 4
# Run 4 — RMSE: 0.445778, MSE: 0.198718, NMSE: 0.0015844729
#
# ===== RUN 5/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.055864
#   Epoch 20/100, Loss: 0.048581
#   Epoch 30/100, Loss: 0.047637
#   Epoch 40/100, Loss: 0.046980
#   Epoch 50/100, Loss: 0.045822
#   Epoch 60/100, Loss: 0.044785
#   Epoch 70/100, Loss: 0.044362
#   Epoch 80/100, Loss: 0.044284
#   Epoch 90/100, Loss: 0.044206
#   Epoch 100/100, Loss: 0.043823
# Training complete for run 5
# Run 5 — RMSE: 0.419308, MSE: 0.175819, NMSE: 0.0016058705
#
# ===== RUN 6/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.052880
#   Epoch 20/100, Loss: 0.051721
#   Epoch 30/100, Loss: 0.052446
#   Epoch 40/100, Loss: 0.050524
#   Epoch 50/100, Loss: 0.048370
#   Epoch 60/100, Loss: 0.047518
#   Epoch 70/100, Loss: 0.047315
#   Epoch 80/100, Loss: 0.047121
#   Epoch 90/100, Loss: 0.046821
#   Epoch 100/100, Loss: 0.046477
# Training complete for run 6
# Run 6 — RMSE: 0.440972, MSE: 0.194456, NMSE: 0.0016227996
#
# ===== RUN 7/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.061695
#   Epoch 20/100, Loss: 0.060151
#   Epoch 30/100, Loss: 0.060102
#   Epoch 40/100, Loss: 0.058795
#   Epoch 50/100, Loss: 0.057639
#   Epoch 60/100, Loss: 0.057607
#   Epoch 70/100, Loss: 0.055969
#   Epoch 80/100, Loss: 0.054411
#   Epoch 90/100, Loss: 0.053046
#   Epoch 100/100, Loss: 0.051572
# Training complete for run 7
# Run 7 — RMSE: 0.523880, MSE: 0.274451, NMSE: 0.0023341323
#
# ===== RUN 8/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.060483
#   Epoch 20/100, Loss: 0.059332
#   Epoch 30/100, Loss: 0.058427
#   Epoch 40/100, Loss: 0.057498
#   Epoch 50/100, Loss: 0.056298
#   Epoch 60/100, Loss: 0.054665
#   Epoch 70/100, Loss: 0.053035
#   Epoch 80/100, Loss: 0.051969
#   Epoch 90/100, Loss: 0.051549
#   Epoch 100/100, Loss: 0.051434
# Training complete for run 8
# Run 8 — RMSE: 0.473168, MSE: 0.223888, NMSE: 0.0018935744
#
# ===== RUN 9/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.062818
#   Epoch 20/100, Loss: 0.062451
#   Epoch 30/100, Loss: 0.062055
#   Epoch 40/100, Loss: 0.061647
#   Epoch 50/100, Loss: 0.054935
#   Epoch 60/100, Loss: 0.051288
#   Epoch 70/100, Loss: 0.051305
#   Epoch 80/100, Loss: 0.051202
#   Epoch 90/100, Loss: 0.051004
#   Epoch 100/100, Loss: 0.051138
# Training complete for run 9
# Run 9 — RMSE: 0.447477, MSE: 0.200235, NMSE: 0.0016711727
#
# ===== RUN 10/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.050451
#   Epoch 20/100, Loss: 0.051852
#   Epoch 30/100, Loss: 0.053038
#   Epoch 40/100, Loss: 0.052718
#   Epoch 50/100, Loss: 0.051651
#   Epoch 60/100, Loss: 0.050810
#   Epoch 70/100, Loss: 0.050035
#   Epoch 80/100, Loss: 0.049242
#   Epoch 90/100, Loss: 0.048631
#   Epoch 100/100, Loss: 0.048220
# Training complete for run 10
# Run 10 — RMSE: 0.447809, MSE: 0.200533, NMSE: 0.0017537569
#
# ===== RUN 11/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.061627
#   Epoch 20/100, Loss: 0.062416
#   Epoch 30/100, Loss: 0.058898
#   Epoch 40/100, Loss: 0.051603
#   Epoch 50/100, Loss: 0.051767
#   Epoch 60/100, Loss: 0.051830
#   Epoch 70/100, Loss: 0.050398
#   Epoch 80/100, Loss: 0.049778
#   Epoch 90/100, Loss: 0.049450
#   Epoch 100/100, Loss: 0.049182
# Training complete for run 11
# Run 11 — RMSE: 0.460705, MSE: 0.212249, NMSE: 0.0018239920
#
# ===== RUN 12/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.051670
#   Epoch 20/100, Loss: 0.053246
#   Epoch 30/100, Loss: 0.054530
#   Epoch 40/100, Loss: 0.054311
#   Epoch 50/100, Loss: 0.054844
#   Epoch 60/100, Loss: 0.054690
#   Epoch 70/100, Loss: 0.052360
#   Epoch 80/100, Loss: 0.050642
#   Epoch 90/100, Loss: 0.049859
#   Epoch 100/100, Loss: 0.049515
# Training complete for run 12
# Run 12 — RMSE: 0.447096, MSE: 0.199895, NMSE: 0.0017100374
#
# ===== RUN 13/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.062805
#   Epoch 20/100, Loss: 0.058778
#   Epoch 30/100, Loss: 0.055684
#   Epoch 40/100, Loss: 0.053534
#   Epoch 50/100, Loss: 0.052569
#   Epoch 60/100, Loss: 0.050771
#   Epoch 70/100, Loss: 0.049476
#   Epoch 80/100, Loss: 0.048617
#   Epoch 90/100, Loss: 0.048293
#   Epoch 100/100, Loss: 0.048594
# Training complete for run 13
# Run 13 — RMSE: 0.443420, MSE: 0.196622, NMSE: 0.0016413518
#
# ===== RUN 14/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.051320
#   Epoch 20/100, Loss: 0.050728
#   Epoch 30/100, Loss: 0.049814
#   Epoch 40/100, Loss: 0.046937
#   Epoch 50/100, Loss: 0.045617
#   Epoch 60/100, Loss: 0.044876
#   Epoch 70/100, Loss: 0.044113
#   Epoch 80/100, Loss: 0.043511
#   Epoch 90/100, Loss: 0.043125
#   Epoch 100/100, Loss: 0.042879
# Training complete for run 14
# Run 14 — RMSE: 0.409538, MSE: 0.167721, NMSE: 0.0014474825
#
# ===== RUN 15/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.057658
#   Epoch 20/100, Loss: 0.055541
#   Epoch 30/100, Loss: 0.051664
#   Epoch 40/100, Loss: 0.048420
#   Epoch 50/100, Loss: 0.047130
#   Epoch 60/100, Loss: 0.047541
#   Epoch 70/100, Loss: 0.048152
#   Epoch 80/100, Loss: 0.048311
#   Epoch 90/100, Loss: 0.048599
#   Epoch 100/100, Loss: 0.053104
# Training complete for run 16
# Run 16 — RMSE: 0.442593, MSE: 0.195888, NMSE: 0.0017002812
#
# ===== RUN 17/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.054260
#   Epoch 20/100, Loss: 0.051283
#   Epoch 30/100, Loss: 0.050995
#   Epoch 40/100, Loss: 0.051199
#   Epoch 50/100, Loss: 0.051154
#   Epoch 60/100, Loss: 0.050722
#   Epoch 70/100, Loss: 0.050026
#   Epoch 80/100, Loss: 0.049639
#   Epoch 90/100, Loss: 0.049722
#   Epoch 100/100, Loss: 0.049496
# Training complete for run 17
# Run 17 — RMSE: 0.456146, MSE: 0.208069, NMSE: 0.0017330465
#
# ===== RUN 18/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.055631
#   Epoch 20/100, Loss: 0.053588
#   Epoch 30/100, Loss: 0.053102
#   Epoch 40/100, Loss: 0.052942
#   Epoch 50/100, Loss: 0.053031
#   Epoch 60/100, Loss: 0.053640
#   Epoch 70/100, Loss: 0.054141
#   Epoch 80/100, Loss: 0.054236
#   Epoch 90/100, Loss: 0.054231
#   Epoch 100/100, Loss: 0.054231
# Training complete for run 18
# Run 18 — RMSE: 0.460862, MSE: 0.212394, NMSE: 0.0017810104
#
# ===== RUN 19/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.062553
#   Epoch 20/100, Loss: 0.061929
#   Epoch 30/100, Loss: 0.061152
#   Epoch 40/100, Loss: 0.060117
#   Epoch 50/100, Loss: 0.059086
#   Epoch 60/100, Loss: 0.058275
#   Epoch 70/100, Loss: 0.056706
#   Epoch 80/100, Loss: 0.053219
#   Epoch 90/100, Loss: 0.050511
#   Epoch 100/100, Loss: 0.049670
# Training complete for run 19
# Run 19 — RMSE: 0.465822, MSE: 0.216990, NMSE: 0.0018589693
#
# ===== RUN 20/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.058509
#   Epoch 20/100, Loss: 0.054349
#   Epoch 30/100, Loss: 0.052976
#   Epoch 40/100, Loss: 0.050878
#   Epoch 50/100, Loss: 0.050135
#   Epoch 60/100, Loss: 0.049902
#   Epoch 70/100, Loss: 0.049048
#   Epoch 80/100, Loss: 0.048068
#   Epoch 90/100, Loss: 0.047422
#   Epoch 100/100, Loss: 0.047004
# Training complete for run 20
# Run 20 — RMSE: 0.425149, MSE: 0.180752, NMSE: 0.0015803004
#
# ===== RUN 21/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.061817
#   Epoch 20/100, Loss: 0.061003
#   Epoch 30/100, Loss: 0.060421
#   Epoch 40/100, Loss: 0.054786
#   Epoch 50/100, Loss: 0.054158
#   Epoch 60/100, Loss: 0.053987
#   Epoch 70/100, Loss: 0.053566
#   Epoch 80/100, Loss: 0.052378
#   Epoch 90/100, Loss: 0.051168
#   Epoch 100/100, Loss: 0.050235
# Training complete for run 21
# Run 21 — RMSE: 0.446382, MSE: 0.199257, NMSE: 0.0016471481
#
# ===== RUN 22/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.063130
#   Epoch 20/100, Loss: 0.060403
#   Epoch 30/100, Loss: 0.059703
#   Epoch 40/100, Loss: 0.058575
#   Epoch 50/100, Loss: 0.056364
#   Epoch 60/100, Loss: 0.054909
#   Epoch 70/100, Loss: 0.052315
#   Epoch 80/100, Loss: 0.049389
#   Epoch 90/100, Loss: 0.048114
#   Epoch 100/100, Loss: 0.047605
# Training complete for run 22
# Run 22 — RMSE: 0.456518, MSE: 0.208409, NMSE: 0.0017994101
#
# ===== RUN 23/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.063011
#   Epoch 20/100, Loss: 0.062005
#   Epoch 30/100, Loss: 0.059452
#   Epoch 40/100, Loss: 0.058366
#   Epoch 50/100, Loss: 0.056298
#   Epoch 60/100, Loss: 0.049270
#   Epoch 70/100, Loss: 0.048711
#   Epoch 80/100, Loss: 0.047685
#   Epoch 90/100, Loss: 0.046809
#   Epoch 100/100, Loss: 0.045819
# Training complete for run 23
# Run 23 — RMSE: 0.431625, MSE: 0.186300, NMSE: 0.0016239632
#
# ===== RUN 24/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.062656
#   Epoch 20/100, Loss: 0.061298
#   Epoch 30/100, Loss: 0.059780
#   Epoch 40/100, Loss: 0.052926
#   Epoch 50/100, Loss: 0.049142
#   Epoch 60/100, Loss: 0.047523
#   Epoch 70/100, Loss: 0.046325
#   Epoch 80/100, Loss: 0.045363
#   Epoch 90/100, Loss: 0.044490
#   Epoch 100/100, Loss: 0.043730
# Training complete for run 24
# Run 24 — RMSE: 0.425084, MSE: 0.180696, NMSE: 0.0016361594
#
# ===== RUN 25/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.058505
#   Epoch 20/100, Loss: 0.057143
#   Epoch 30/100, Loss: 0.057163
#   Epoch 40/100, Loss: 0.052108
#   Epoch 50/100, Loss: 0.050112
#   Epoch 60/100, Loss: 0.051380
#   Epoch 70/100, Loss: 0.051432
#   Epoch 80/100, Loss: 0.050705
#   Epoch 90/100, Loss: 0.049453
#   Epoch 100/100, Loss: 0.048573
# Training complete for run 25
# Run 25 — RMSE: 0.449989, MSE: 0.202490, NMSE: 0.0017128456
#
# ===== RUN 26/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.061282
#   Epoch 20/100, Loss: 0.058124
#   Epoch 30/100, Loss: 0.053514
#   Epoch 40/100, Loss: 0.052313
#   Epoch 50/100, Loss: 0.052622
#   Epoch 60/100, Loss: 0.052605
#   Epoch 70/100, Loss: 0.052311
#   Epoch 80/100, Loss: 0.051853
#   Epoch 90/100, Loss: 0.051181
#   Epoch 100/100, Loss: 0.050197
# Training complete for run 26
# Run 26 — RMSE: 0.458866, MSE: 0.210558, NMSE: 0.0017946768
#
# ===== RUN 27/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.062139
#   Epoch 20/100, Loss: 0.061144
#   Epoch 30/100, Loss: 0.055834
#   Epoch 40/100, Loss: 0.052569
#   Epoch 50/100, Loss: 0.053150
#   Epoch 60/100, Loss: 0.052997
#   Epoch 70/100, Loss: 0.052547
#   Epoch 80/100, Loss: 0.052140
#   Epoch 90/100, Loss: 0.051594
#   Epoch 100/100, Loss: 0.050856
# Training complete for run 27
# Run 27 — RMSE: 0.468574, MSE: 0.219562, NMSE: 0.0018457935
#
# ===== RUN 28/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.057442
#   Epoch 20/100, Loss: 0.057696
#   Epoch 30/100, Loss: 0.057583
#   Epoch 40/100, Loss: 0.057772
#   Epoch 50/100, Loss: 0.058035
#   Epoch 60/100, Loss: 0.058164
#   Epoch 70/100, Loss: 0.057921
#   Epoch 80/100, Loss: 0.056552
#   Epoch 90/100, Loss: 0.054728
#   Epoch 100/100, Loss: 0.053540
# Training complete for run 28
# Run 28 — RMSE: 0.508912, MSE: 0.258991, NMSE: 0.0021282241
#
# ===== RUN 29/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.060799
#   Epoch 20/100, Loss: 0.053555
#   Epoch 30/100, Loss: 0.052732
#   Epoch 40/100, Loss: 0.051663
#   Epoch 50/100, Loss: 0.050883
#   Epoch 60/100, Loss: 0.050250
#   Epoch 70/100, Loss: 0.049610
#   Epoch 80/100, Loss: 0.049281
#   Epoch 90/100, Loss: 0.048303
#   Epoch 100/100, Loss: 0.046651
# Training complete for run 29
# Run 29 — RMSE: 0.420783, MSE: 0.177058, NMSE: 0.0015354707
#
# ===== RUN 30/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.063034
#   Epoch 20/100, Loss: 0.061437
#   Epoch 30/100, Loss: 0.061216
#   Epoch 40/100, Loss: 0.055446
#   Epoch 50/100, Loss: 0.051477
#   Epoch 60/100, Loss: 0.051590
#   Epoch 70/100, Loss: 0.051436
#   Epoch 80/100, Loss: 0.051545
#   Epoch 90/100, Loss: 0.052357
#   Epoch 100/100, Loss: 0.053560
# Training complete for run 30
# Run 30 — RMSE: 0.490691, MSE: 0.240778, NMSE: 0.0020226988
#
# ===== RUN 31/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.053013
#   Epoch 20/100, Loss: 0.051760
#   Epoch 30/100, Loss: 0.051930
#   Epoch 40/100, Loss: 0.052099
#   Epoch 50/100, Loss: 0.052190
#   Epoch 60/100, Loss: 0.051996
#   Epoch 70/100, Loss: 0.051490
#   Epoch 80/100, Loss: 0.050818
#   Epoch 90/100, Loss: 0.050075
#   Epoch 100/100, Loss: 0.049336
# Training complete for run 31
# Run 31 — RMSE: 0.444310, MSE: 0.197411, NMSE: 0.0017067247
#
# ===== RUN 32/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.061187
#   Epoch 20/100, Loss: 0.058666
#   Epoch 30/100, Loss: 0.058572
#   Epoch 40/100, Loss: 0.058221
#   Epoch 50/100, Loss: 0.057598
#   Epoch 60/100, Loss: 0.058931
#   Epoch 70/100, Loss: 0.052816
#   Epoch 80/100, Loss: 0.051148
#   Epoch 90/100, Loss: 0.051170
#   Epoch 100/100, Loss: 0.050877
# Training complete for run 32
# Run 32 — RMSE: 0.439658, MSE: 0.193299, NMSE: 0.0016791671
#
# ===== RUN 33/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.061029
#   Epoch 20/100, Loss: 0.057271
#   Epoch 30/100, Loss: 0.056082
#   Epoch 40/100, Loss: 0.055376
#   Epoch 50/100, Loss: 0.054102
#   Epoch 60/100, Loss: 0.052674
#   Epoch 70/100, Loss: 0.051323
#   Epoch 80/100, Loss: 0.050703
#   Epoch 90/100, Loss: 0.050263
#   Epoch 100/100, Loss: 0.049676
# Training complete for run 33
# Run 33 — RMSE: 0.452621, MSE: 0.204866, NMSE: 0.0017035999
#
# ===== RUN 34/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.061224
#   Epoch 20/100, Loss: 0.058017
#   Epoch 30/100, Loss: 0.061756
#   Epoch 40/100, Loss: 0.049372
#   Epoch 50/100, Loss: 0.052628
#   Epoch 60/100, Loss: 0.052596
#   Epoch 70/100, Loss: 0.052678
#   Epoch 80/100, Loss: 0.052755
#   Epoch 90/100, Loss: 0.052176
#   Epoch 100/100, Loss: 0.050844
# Training complete for run 34
# Run 34 — RMSE: 0.480925, MSE: 0.231289, NMSE: 0.0019384149
#
# ===== RUN 35/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.057032
#   Epoch 20/100, Loss: 0.056951
#   Epoch 30/100, Loss: 0.057399
#   Epoch 40/100, Loss: 0.058208
#   Epoch 50/100, Loss: 0.059068
#   Epoch 60/100, Loss: 0.059240
#   Epoch 70/100, Loss: 0.058540
#   Epoch 80/100, Loss: 0.057728
#   Epoch 90/100, Loss: 0.057318
#   Epoch 100/100, Loss: 0.057112
# Training complete for run 35
# Run 35 — RMSE: 0.521573, MSE: 0.272038, NMSE: 0.0021533800
#
# ===== RUN 36/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.058947
#   Epoch 20/100, Loss: 0.058869
#   Epoch 30/100, Loss: 0.050796
#   Epoch 40/100, Loss: 0.046612
#   Epoch 50/100, Loss: 0.045218
#   Epoch 60/100, Loss: 0.044173
#   Epoch 70/100, Loss: 0.043676
#   Epoch 80/100, Loss: 0.043593
#   Epoch 90/100, Loss: 0.043411
#   Epoch 100/100, Loss: 0.043166
# Training complete for run 36
# Run 36 — RMSE: 0.412052, MSE: 0.169787, NMSE: 0.0014330334
#
# ===== RUN 37/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.062458
#   Epoch 20/100, Loss: 0.061878
#   Epoch 30/100, Loss: 0.059918
#   Epoch 40/100, Loss: 0.052992
#   Epoch 50/100, Loss: 0.052752
#   Epoch 60/100, Loss: 0.050693
#   Epoch 70/100, Loss: 0.049202
#   Epoch 80/100, Loss: 0.048235
#   Epoch 90/100, Loss: 0.047588
#   Epoch 100/100, Loss: 0.047200
# Training complete for run 37
# Run 37 — RMSE: 0.439225, MSE: 0.192918, NMSE: 0.0016555716
#
# ===== RUN 38/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.057586
#   Epoch 20/100, Loss: 0.053830
#   Epoch 30/100, Loss: 0.050038
#   Epoch 40/100, Loss: 0.047693
#   Epoch 50/100, Loss: 0.046416
#   Epoch 60/100, Loss: 0.045761
#   Epoch 70/100, Loss: 0.045335
#   Epoch 80/100, Loss: 0.044851
#   Epoch 90/100, Loss: 0.044441
#   Epoch 100/100, Loss: 0.044073
# Training complete for run 38
# Run 38 — RMSE: 0.414825, MSE: 0.172080, NMSE: 0.0015146096
#
# ===== RUN 39/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.056426
#   Epoch 20/100, Loss: 0.053948
#   Epoch 30/100, Loss: 0.050819
#   Epoch 40/100, Loss: 0.048205
#   Epoch 50/100, Loss: 0.047084
#   Epoch 60/100, Loss: 0.046426
#   Epoch 70/100, Loss: 0.045812
#   Epoch 80/100, Loss: 0.045255
#   Epoch 90/100, Loss: 0.044733
#   Epoch 100/100, Loss: 0.044256
# Training complete for run 39
# Run 39 — RMSE: 0.413690, MSE: 0.171140, NMSE: 0.0014623578
#
# ===== RUN 40/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.058632
#   Epoch 20/100, Loss: 0.058690
#   Epoch 30/100, Loss: 0.058251
#   Epoch 40/100, Loss: 0.052726
#   Epoch 50/100, Loss: 0.049725
#   Epoch 60/100, Loss: 0.048526
#   Epoch 70/100, Loss: 0.048087
#   Epoch 80/100, Loss: 0.047990
#   Epoch 90/100, Loss: 0.047870
#   Epoch 100/100, Loss: 0.047123
# Training complete for run 40
# Run 40 — RMSE: 0.427406, MSE: 0.182676, NMSE: 0.0015921953
#
# ===== RUN 41/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.059812
#   Epoch 20/100, Loss: 0.059348
#   Epoch 30/100, Loss: 0.057203
#   Epoch 40/100, Loss: 0.047489
#   Epoch 50/100, Loss: 0.046658
#   Epoch 60/100, Loss: 0.046327
#   Epoch 70/100, Loss: 0.045698
#   Epoch 80/100, Loss: 0.045234
#   Epoch 90/100, Loss: 0.044958
#   Epoch 100/100, Loss: 0.044806
# Training complete for run 41
# Run 41 — RMSE: 0.401481, MSE: 0.161187, NMSE: 0.0014015614
#
# ===== RUN 42/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.055822
#   Epoch 20/100, Loss: 0.049963
#   Epoch 30/100, Loss: 0.048266
#   Epoch 40/100, Loss: 0.047115
#   Epoch 50/100, Loss: 0.046396
#   Epoch 60/100, Loss: 0.045927
#   Epoch 70/100, Loss: 0.045548
#   Epoch 80/100, Loss: 0.045227
#   Epoch 90/100, Loss: 0.044990
#   Epoch 100/100, Loss: 0.044731
# Training complete for run 42
# Run 42 — RMSE: 0.416500, MSE: 0.173472, NMSE: 0.0015288800
#
# ===== RUN 43/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.060267
#   Epoch 20/100, Loss: 0.059941
#   Epoch 30/100, Loss: 0.059747
#   Epoch 40/100, Loss: 0.058873
#   Epoch 50/100, Loss: 0.057986
#   Epoch 60/100, Loss: 0.055861
#   Epoch 70/100, Loss: 0.053522
#   Epoch 80/100, Loss: 0.050091
#   Epoch 90/100, Loss: 0.046918
#   Epoch 100/100, Loss: 0.045707
# Training complete for run 43
# Run 43 — RMSE: 0.406058, MSE: 0.164883, NMSE: 0.0014311669
#
# ===== RUN 44/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.062905
#   Epoch 20/100, Loss: 0.062281
#   Epoch 30/100, Loss: 0.059584
#   Epoch 40/100, Loss: 0.058692
#   Epoch 50/100, Loss: 0.058454
#   Epoch 60/100, Loss: 0.055168
#   Epoch 70/100, Loss: 0.050463
#   Epoch 80/100, Loss: 0.050209
#   Epoch 90/100, Loss: 0.050167
#   Epoch 100/100, Loss: 0.050073
# Training complete for run 44
# Run 44 — RMSE: 0.457771, MSE: 0.209554, NMSE: 0.0018187404
#
# ===== RUN 45/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.060596
#   Epoch 20/100, Loss: 0.058494
#   Epoch 30/100, Loss: 0.056484
#   Epoch 40/100, Loss: 0.056215
#   Epoch 50/100, Loss: 0.055666
#   Epoch 60/100, Loss: 0.054942
#   Epoch 70/100, Loss: 0.054577
#   Epoch 80/100, Loss: 0.053995
#   Epoch 90/100, Loss: 0.053523
#   Epoch 100/100, Loss: 0.053308
# Training complete for run 45
# Run 45 — RMSE: 0.493951, MSE: 0.243987, NMSE: 0.0020176351
#
# ===== RUN 46/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.061002
#   Epoch 20/100, Loss: 0.060902
#   Epoch 30/100, Loss: 0.060375
#   Epoch 40/100, Loss: 0.057196
#   Epoch 50/100, Loss: 0.055132
#   Epoch 60/100, Loss: 0.054698
#   Epoch 70/100, Loss: 0.053621
#   Epoch 80/100, Loss: 0.052640
#   Epoch 90/100, Loss: 0.052253
#   Epoch 100/100, Loss: 0.051077
# Training complete for run 46
# Run 46 — RMSE: 0.452189, MSE: 0.204475, NMSE: 0.0017741769
#
# ===== RUN 47/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.063216
#   Epoch 20/100, Loss: 0.062726
#   Epoch 30/100, Loss: 0.061861
#   Epoch 40/100, Loss: 0.061221
#   Epoch 50/100, Loss: 0.060762
#   Epoch 60/100, Loss: 0.060413
#   Epoch 70/100, Loss: 0.060115
#   Epoch 80/100, Loss: 0.059732
#   Epoch 90/100, Loss: 0.058741
#   Epoch 100/100, Loss: 0.055879
# Training complete for run 47
# Run 47 — RMSE: 0.529701, MSE: 0.280584, NMSE: 0.0022234904
#
# ===== RUN 48/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.054787
#   Epoch 20/100, Loss: 0.055426
#   Epoch 30/100, Loss: 0.055464
#   Epoch 40/100, Loss: 0.052190
#   Epoch 50/100, Loss: 0.049943
#   Epoch 60/100, Loss: 0.048359
#   Epoch 70/100, Loss: 0.047355
#   Epoch 80/100, Loss: 0.047260
#   Epoch 90/100, Loss: 0.048028
#   Epoch 100/100, Loss: 0.047602
# Training complete for run 48
# Run 48 — RMSE: 0.486947, MSE: 0.237117, NMSE: 0.0020420126
#
# ===== RUN 49/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.060906
#   Epoch 20/100, Loss: 0.060582
#   Epoch 30/100, Loss: 0.061338
#   Epoch 40/100, Loss: 0.062707
#   Epoch 50/100, Loss: 0.062077
#   Epoch 60/100, Loss: 0.059315
#   Epoch 70/100, Loss: 0.057484
#   Epoch 80/100, Loss: 0.049723
#   Epoch 90/100, Loss: 0.049118
#   Epoch 100/100, Loss: 0.049181
# Training complete for run 49
# Run 49 — RMSE: 0.467472, MSE: 0.218530, NMSE: 0.0018231704
#
# ===== RUN 50/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.054743
#   Epoch 20/100, Loss: 0.053415
#   Epoch 30/100, Loss: 0.051936
#   Epoch 40/100, Loss: 0.051686
#   Epoch 50/100, Loss: 0.051872
#   Epoch 60/100, Loss: 0.051591
#   Epoch 70/100, Loss: 0.050826
#   Epoch 80/100, Loss: 0.049994
#   Epoch 90/100, Loss: 0.049194
#   Epoch 100/100, Loss: 0.048550
# Training complete for run 50
# Run 50 — RMSE: 0.445909, MSE: 0.198835, NMSE: 0.0016982409
#
# ===== RUN 51/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.060034
#   Epoch 20/100, Loss: 0.058548
#   Epoch 30/100, Loss: 0.057792
#   Epoch 40/100, Loss: 0.053122
#   Epoch 50/100, Loss: 0.048427
#   Epoch 60/100, Loss: 0.046739
#   Epoch 70/100, Loss: 0.046407
#   Epoch 80/100, Loss: 0.046014
#   Epoch 90/100, Loss: 0.045559
#   Epoch 100/100, Loss: 0.045122
# Training complete for run 51
# Run 51 — RMSE: 0.410962, MSE: 0.168890, NMSE: 0.0014982579
#
# ===== RUN 52/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.058557
#   Epoch 20/100, Loss: 0.054835
#   Epoch 30/100, Loss: 0.055159
#   Epoch 40/100, Loss: 0.053668
#   Epoch 50/100, Loss: 0.051853
#   Epoch 60/100, Loss: 0.050892
#   Epoch 70/100, Loss: 0.050880
#   Epoch 80/100, Loss: 0.051519
#   Epoch 90/100, Loss: 0.052860
#   Epoch 100/100, Loss: 0.055834
# Training complete for run 52
# Run 52 — RMSE: 0.493556, MSE: 0.243597, NMSE: 0.0019159107
#
# ===== RUN 53/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.060879
#   Epoch 20/100, Loss: 0.062133
#   Epoch 30/100, Loss: 0.060506
#   Epoch 40/100, Loss: 0.057065
#   Epoch 50/100, Loss: 0.052771
#   Epoch 60/100, Loss: 0.052557
#   Epoch 70/100, Loss: 0.051496
#   Epoch 80/100, Loss: 0.048149
#   Epoch 90/100, Loss: 0.044847
#   Epoch 100/100, Loss: 0.043719
# Training complete for run 53
# Run 53 — RMSE: 0.415957, MSE: 0.173020, NMSE: 0.0015315016
#
# ===== RUN 54/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.060604
#   Epoch 20/100, Loss: 0.060622
#   Epoch 30/100, Loss: 0.051866
#   Epoch 40/100, Loss: 0.049583
#   Epoch 50/100, Loss: 0.048763
#   Epoch 60/100, Loss: 0.048112
#   Epoch 70/100, Loss: 0.047471
#   Epoch 80/100, Loss: 0.046979
#   Epoch 90/100, Loss: 0.046024
#   Epoch 100/100, Loss: 0.045435
# Training complete for run 54
# Run 54 — RMSE: 0.408229, MSE: 0.166651, NMSE: 0.0014131894
#
# ===== RUN 55/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.049449
#   Epoch 20/100, Loss: 0.048989
#   Epoch 30/100, Loss: 0.047634
#   Epoch 40/100, Loss: 0.046255
#   Epoch 50/100, Loss: 0.045399
#   Epoch 60/100, Loss: 0.044825
#   Epoch 70/100, Loss: 0.044319
#   Epoch 80/100, Loss: 0.043815
#   Epoch 90/100, Loss: 0.043334
#   Epoch 100/100, Loss: 0.042917
# Training complete for run 55
# Run 55 — RMSE: 0.414961, MSE: 0.172192, NMSE: 0.0015399902
#
# ===== RUN 56/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.049043
#   Epoch 20/100, Loss: 0.047327
#   Epoch 30/100, Loss: 0.047111
#   Epoch 40/100, Loss: 0.048081
#   Epoch 50/100, Loss: 0.048797
#   Epoch 60/100, Loss: 0.048337
#   Epoch 70/100, Loss: 0.048757
#   Epoch 80/100, Loss: 0.051342
#   Epoch 90/100, Loss: 0.055563
#   Epoch 100/100, Loss: 0.054517
# Training complete for run 56
# Run 56 — RMSE: 0.566849, MSE: 0.321318, NMSE: 0.0024181043
#
# ===== RUN 57/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.060935
#   Epoch 20/100, Loss: 0.058876
#   Epoch 30/100, Loss: 0.055600
#   Epoch 40/100, Loss: 0.053264
#   Epoch 50/100, Loss: 0.051230
#   Epoch 60/100, Loss: 0.050135
#   Epoch 70/100, Loss: 0.049138
#   Epoch 80/100, Loss: 0.047995
#   Epoch 90/100, Loss: 0.046859
#   Epoch 100/100, Loss: 0.045999
# Training complete for run 57
# Run 57 — RMSE: 0.430805, MSE: 0.185593, NMSE: 0.0016226723
#
# ===== RUN 58/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.059113
#   Epoch 20/100, Loss: 0.056963
#   Epoch 30/100, Loss: 0.058048
#   Epoch 40/100, Loss: 0.058747
#   Epoch 50/100, Loss: 0.056774
#   Epoch 60/100, Loss: 0.051761
#   Epoch 70/100, Loss: 0.048116
#   Epoch 80/100, Loss: 0.047258
#   Epoch 90/100, Loss: 0.046535
#   Epoch 100/100, Loss: 0.046013
# Training complete for run 58
# Run 58 — RMSE: 0.428979, MSE: 0.184023, NMSE: 0.0016106104
#
# ===== RUN 59/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.059416
#   Epoch 20/100, Loss: 0.058013
#   Epoch 30/100, Loss: 0.057519
#   Epoch 40/100, Loss: 0.051551
#   Epoch 50/100, Loss: 0.049986
#   Epoch 60/100, Loss: 0.052459
#   Epoch 70/100, Loss: 0.054177
#   Epoch 80/100, Loss: 0.050475
#   Epoch 90/100, Loss: 0.049446
#   Epoch 100/100, Loss: 0.048512
# Training complete for run 59
# Run 59 — RMSE: 0.443430, MSE: 0.196630, NMSE: 0.0017031327
#
# ===== RUN 60/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.056644
#   Epoch 20/100, Loss: 0.056297
#   Epoch 30/100, Loss: 0.055704
#   Epoch 40/100, Loss: 0.055052
#   Epoch 50/100, Loss: 0.053359
#   Epoch 60/100, Loss: 0.052304
#   Epoch 70/100, Loss: 0.051112
#   Epoch 80/100, Loss: 0.050349
#   Epoch 90/100, Loss: 0.049979
#   Epoch 100/100, Loss: 0.049398
# Training complete for run 60
# Run 60 — RMSE: 0.442665, MSE: 0.195952, NMSE: 0.0017136921
#
# ===== STATS FOR NOISE 0.5% (60 runs) =====
# RMSE: 0.451346 +/- 0.035478
# MSE:  0.204972 +/- 0.033554
# NMSE: 0.0017399875 +/- 0.0002368266
# Best run: 41 (RMSE: 0.401481)

# %% [markdown]
# ## Results

# %%
# ============================================================
# Final Metrics Summary & Plots per Noise Level
# ============================================================
from tabulate import tabulate

for entry in _molab_results:
    lam = entry[0]
    mean_rmse, std_rmse = entry[1], entry[2]
    mean_mse, std_mse = entry[3], entry[4]
    mean_nmse, std_nmse = entry[5], entry[6]
    best_rmse_val = entry[7]
    best_predictions = entry[8]
    best_losses = entry[9]
    raw_values_for_plot = entry[10]
    
    print("\n" + "="*80)
    print(f"RESULTS FOR NOISE LEVEL: {lam*100:.1f}%")
    print("="*80)
    
    print(f'Mean RMSE: {mean_rmse:.6f} +/- {std_rmse:.6f}')
    print(f'Mean MSE:  {mean_mse:.6f} +/- {std_mse:.6f}')
    print(f'Mean NMSE: {mean_nmse:.10f} +/- {std_nmse:.10f}')
    print(f'Best RMSE: {best_rmse_val:.6f}')
    
    actual = raw_values_for_plot[-60:]
    
    plt.figure(figsize=(12, 5))
    plt.plot(actual, label='Actual', color='blue', linewidth=1.5)
    plt.plot(best_predictions, label='Predicted (Best Run)', color='red',
             linewidth=1.5, linestyle='--')
    plt.title(f'Predictions vs Actual (Noise {lam*100:.1f}%)')
    plt.xlabel('Time Step')
    plt.ylabel('Value')
    plt.legend()
    plt.grid(True, alpha=0.3)
    plt.tight_layout()
    plt.show()

    plt.figure(figsize=(12, 4))
    plt.plot(best_losses, color='green', linewidth=1.0)
    plt.title(f'Training Loss (Best Run, Noise {lam*100:.1f}%)')
    plt.xlabel('Epoch')
    plt.ylabel('MSE Loss')
    plt.grid(True, alpha=0.3)
    plt.tight_layout()
    plt.show()

print("\n" + "="*80)
print("FINAL RESULTS TABLE ACROSS ALL NOISE LEVELS")
print("="*80)
df_res = pd.DataFrame(
    [[r[0], f'{r[1]:.6f} +/- {r[2]:.6f}', f'{r[3]:.6f} +/- {r[4]:.6f}', 
      f'{r[5]:.10f} +/- {r[6]:.10f}', f'{r[7]:.6f}'] for r in _molab_results],
    columns=['Noise Level', 'RMSE (mean+/-std)', 'MSE (mean+/-std)', 'NMSE (mean+/-std)', 'Best RMSE']
)
print(tabulate(df_res, headers='keys', tablefmt='github', showindex=False))
# Out:
# ================================================================================
# RESULTS FOR NOISE LEVEL: 0.0%
# ================================================================================
# Mean RMSE: 0.480365 +/- 0.164409
# Mean MSE:  0.257781 +/- 0.289928
# Mean NMSE: 0.0019438182 +/- 0.0011408619
# Best RMSE: 0.399413
# ================================================================================
# RESULTS FOR NOISE LEVEL: 0.5%
# ================================================================================
# Mean RMSE: 0.451346 +/- 0.035478
# Mean MSE:  0.204972 +/- 0.033554
# Mean NMSE: 0.0017399875 +/- 0.0002368266
# Best RMSE: 0.401481
# ================================================================================
# FINAL RESULTS TABLE ACROSS ALL NOISE LEVELS
# ================================================================================
# |   Noise Level | RMSE (mean+/-std)     | MSE (mean+/-std)      | NMSE (mean+/-std)             |   Best RMSE |
# |---------------|-----------------------|-----------------------|-------------------------------|-------------|
# |         0     | 0.480365 +/- 0.164409 | 0.257781 +/- 0.289928 | 0.0019438182 +/- 0.0011408619 |    0.399413 |
# |         0.005 | 0.451346 +/- 0.035478 | 0.204972 +/- 0.033554 | 0.0017399875 +/- 0.0002368266 |    0.401481 |
