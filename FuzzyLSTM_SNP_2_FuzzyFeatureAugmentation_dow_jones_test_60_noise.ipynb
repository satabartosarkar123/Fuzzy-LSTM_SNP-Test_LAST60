# %% [markdown]
# # Notebook 2: LSTM-SNP with Fuzzy Feature Augmentation
#
# **Dataset**: Dow Jones Industrial Index
#
# ## Description
# This notebook implements **fuzzy feature augmentation** for the LSTM-SNP model. A Takagi-Sugeno
# fuzzy inference system processes the current and previous input values to generate an additional
# feature, which is concatenated with the original input before being fed into the unmodified
# LSTM-SNP cell.
#
# The LSTM-SNP cell itself is **NOT modified** — only the input representation is enriched with
# fuzzy-derived features.

# %% [markdown]
# ## Theory: Fuzzy Feature Augmentation
#
# ### LSTM-SNP Cell (Unchanged)
# The LSTM-SNP cell equations remain exactly as in the baseline.
#
# ### Fuzzy Inference System
# A Takagi-Sugeno fuzzy system augments the input:
#
# **Membership Functions** (Fixed Gaussian):
# - $\mu_{low}(x) = \exp\left(-\frac{(x - (-1))^2}{2 \cdot 0.5^2}\right)$
# - $\mu_{high}(x) = \exp\left(-\frac{(x - (+1))^2}{2 \cdot 0.5^2}\right)$
#
# **Rules** (4 Takagi-Sugeno rules):
# 1. IF $x(t)$ is low AND $x(t-1)$ is low → $y_1 = a_1 x(t) + b_1 x(t-1) + c_1$
# 2. IF $x(t)$ is low AND $x(t-1)$ is high → $y_2 = a_2 x(t) + b_2 x(t-1) + c_2$
# 3. IF $x(t)$ is high AND $x(t-1)$ is low → $y_3 = a_3 x(t) + b_3 x(t-1) + c_3$
# 4. IF $x(t)$ is high AND $x(t-1)$ is high → $y_4 = a_4 x(t) + b_4 x(t-1) + c_4$
#
# **Defuzzification**: $y_{fuzzy} = \frac{\sum_i w_i y_i}{\sum_i w_i}$ where $w_i = \prod_j \mu_j(x_j)$
#
# **Augmented Input**: $x'(t) = [x(t), y_{fuzzy}(t)]$

# %% [markdown]
# ## Model Architecture & Implementation

# %%
# ============================================================
# ALL IMPORTS
# ============================================================

import os
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from math import sqrt
from scipy import stats
import matplotlib.pyplot as plt

print(f"PyTorch version: {torch.__version__}")
print(f"NumPy version: {np.__version__}")

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"Using device: {device}")
# Out:
# PyTorch version: 2.11.0+cu128
# NumPy version: 2.5.1
# Using device: cuda

# %% [markdown]
# ### Fuzzy Inference System (NumPy — for preprocessing)

# %%
# ============================================================
# Fuzzy Inference System (NumPy — for preprocessing)
#
# Fixed Gaussian membership functions:
#   μ_low(x)  = exp(-(x - (-1))² / (2·0.5²))
#   μ_high(x) = exp(-(x - (+1))² / (2·0.5²))
#
# 4 Takagi-Sugeno rules with fixed consequent parameters:
#   IF x(t) is low  AND x(t-1) is low  → y₁ = 0.5·x(t) + 0.5·x(t-1)
#   IF x(t) is low  AND x(t-1) is high → y₂ = 0.7·x(t) + 0.3·x(t-1) - 0.1
#   IF x(t) is high AND x(t-1) is low  → y₃ = 0.3·x(t) + 0.7·x(t-1) + 0.1
#   IF x(t) is high AND x(t-1) is high → y₄ = 0.5·x(t) + 0.5·x(t-1)
#
# Output: y = Σ(wᵢ·yᵢ) / Σ(wᵢ)
# ============================================================

def gaussian_mf(x, center, sigma=0.5):
    """Fixed Gaussian membership function."""
    return np.exp(-(x - center)**2 / (2 * sigma**2))

def fuzzy_inference_numpy(x_t, x_tm1):
    """
    Compute fuzzy feature from x(t) and x(t-1).
    Uses fixed membership functions and fixed consequent parameters.
    """
    # Membership degrees
    mu_low_xt = gaussian_mf(x_t, center=-1.0)
    mu_high_xt = gaussian_mf(x_t, center=1.0)
    mu_low_xtm1 = gaussian_mf(x_tm1, center=-1.0)
    mu_high_xtm1 = gaussian_mf(x_tm1, center=1.0)

    # Rule firing strengths (product)
    w1 = mu_low_xt * mu_low_xtm1      # low-low
    w2 = mu_low_xt * mu_high_xtm1     # low-high
    w3 = mu_high_xt * mu_low_xtm1     # high-low
    w4 = mu_high_xt * mu_high_xtm1    # high-high

    # Consequent outputs (fixed linear functions)
    y1 = 0.5 * x_t + 0.5 * x_tm1
    y2 = 0.7 * x_t + 0.3 * x_tm1 - 0.1
    y3 = 0.3 * x_t + 0.7 * x_tm1 + 0.1
    y4 = 0.5 * x_t + 0.5 * x_tm1

    # Weighted average defuzzification
    numerator = w1 * y1 + w2 * y2 + w3 * y3 + w4 * y4
    denominator = w1 + w2 + w3 + w4 + 1e-8

    return numerator / denominator

# %% [markdown]
# ### LSTM-SNP Cell

# %%
# ============================================================
# LSTM-SNP Cell (Original — Unmodified)
# ============================================================

class LSTMSNPCell(nn.Module):
    """
    LSTM-SNP Cell: gates r, c, o (hard sigmoid) and generated spikes a (tanh).
    u(t) = r(t)*u(t-1) - c(t)*a(t)
    h(t) = o(t)*a(t)
    """
    def __init__(self, input_size, hidden_size):
        super().__init__()
        self.hidden_size = hidden_size
        self.kernel = nn.Linear(input_size, hidden_size * 4, bias=False)
        self.recurrent_kernel = nn.Linear(hidden_size, hidden_size * 4, bias=False)
        self.bias = nn.Parameter(torch.zeros(hidden_size * 4))

        nn.init.xavier_uniform_(self.kernel.weight)
        nn.init.orthogonal_(self.recurrent_kernel.weight)

    def hard_sigmoid(self, x):
        return torch.clamp(0.2 * x + 0.5, 0.0, 1.0)

    def forward(self, x, u_tm1):
        z = self.kernel(x) + self.recurrent_kernel(u_tm1) + self.bias
        z0, z1, z2, z3 = z.chunk(4, dim=-1)

        r = self.hard_sigmoid(z0)   # reset
        c = self.hard_sigmoid(z1)   # consumption
        o = self.hard_sigmoid(z2)   # output/generation
        a = torch.tanh(z3)          # generated spikes

        u = r * u_tm1 - c * a
        h = o * a
        return h, u

# %% [markdown]
# ### Build Model

# %%
# ============================================================
# Model Construction: LSTM-SNP with Fuzzy Feature Augmentation
# input_dim=2: [x(t), y_fuzzy(t)]
# The LSTM-SNP cell is UNMODIFIED.
# ============================================================

class RNNModel(nn.Module):
    def __init__(self, input_size, hidden_size):
        super().__init__()
        self.hidden_size = hidden_size
        self.cell = LSTMSNPCell(input_size, hidden_size)
        self.out = nn.Linear(hidden_size, 1)
        self.u = None

    def reset_states(self, batch_size, device):
        self.u = torch.zeros(batch_size, self.hidden_size, device=device)

    def forward(self, x):
        # x is (batch, 1, input_size)
        if self.u is None or self.u.device != x.device:
            self.reset_states(x.size(0), x.device)
        h, self.u = self.cell(x[:, 0, :], self.u)
        return self.out(h)


def build_model_torch(input_dim, units, batch_size=1):
    # batch_size accepted for call-signature compatibility with the Keras
    # build_model, unused here — batch size is set dynamically via reset_states().
    return RNNModel(input_dim, units)

# %%
model = build_model_torch(input_dim=2, units=8, batch_size=1).to(device)
print(model)

total_params = sum(p.numel() for p in model.parameters())
trainable_params = sum(p.numel() for p in model.parameters() if p.requires_grad)
print(f"\nTotal params: {total_params:,}")
print(f"Trainable params: {trainable_params:,}")
# Out:
# RNNModel(
#   (cell): LSTMSNPCell(
#     (kernel): Linear(in_features=2, out_features=32, bias=False)
#     (recurrent_kernel): Linear(in_features=8, out_features=32, bias=False)
#   )
#   (out): Linear(in_features=8, out_features=1, bias=True)
# )
#
# Total params: 361
# Trainable params: 361

# %% [markdown]
# ## Data Pipeline — Dow Jones Industrial Index

# %%
series = pd.read_csv(
    r'C:\Users\paulp\OneDrive\Desktop\fuzzy_LSTM\dataset\monthly-closings-of-the-dowjones.csv',
    header=0,
    parse_dates=[0],
    index_col=0
)
raw_values = series.values.flatten()

# %%
# ============================================================
# 2. First-Order Differencing
# ============================================================

def difference(dataset, interval=1):
    diff = []
    for i in range(interval, len(dataset)):
        value = dataset[i] - dataset[i - interval]
        diff.append(value)
    return np.array(diff)

diff_values = difference(raw_values, 1)
print(f"Differenced data shape: {diff_values.shape}")
# Out:
# Differenced data shape: (290,)

# %%
# ============================================================
# 3. Convert to Supervised Learning Format (lag=1)
# ============================================================

def timeseries_to_supervised(data, lag=1):
    df = pd.DataFrame(data)
    columns = [df.shift(i) for i in range(1, lag+1)]
    columns.append(df)
    df = pd.concat(columns, axis=1)
    df.fillna(0, inplace=True)
    return df.values

supervised = timeseries_to_supervised(diff_values, 1)
print(f"Supervised data shape: {supervised.shape}")
# Out:
# Supervised data shape: (290, 2)

# %%
# ============================================================
# 4. Train-Test Split (Last 60 points as Test)
# ============================================================
train, test = supervised[:-60], supervised[-60:]

print(f"Train: {train.shape}, Test: {test.shape}")

# ============================================================
# 5. Feature Scaling
# ============================================================
scaler = MinMaxScaler(feature_range=(-1, 1))
scaler.fit(train)  # fit only on train to avoid leakage
train_scaled = scaler.transform(train)
test_scaled = scaler.transform(test)
# Out:
# Train: (230, 2), Test: (60, 2)

# %%
# ============================================================
# 6. Reshape for RNN Input + Fuzzy Feature Augmentation
#    x'(t) = [x(t), y_fuzzy(t)],  y_fuzzy(t) = fuzzy_inference_numpy(x(t), x(t-1))
# ============================================================
X_train_raw, y_train = train_scaled[:, 0:-1], train_scaled[:, -1]
X_test_raw,  y_test  = test_scaled[:, 0:-1],  test_scaled[:, -1]

def build_fuzzy_augmented(X_raw, prev_last=0.0):
    """X_raw: (N,1) scaled lag feature. Returns (N,1,2) augmented tensor."""
    X_aug = np.zeros((X_raw.shape[0], 2))
    for i in range(X_raw.shape[0]):
        x_t = X_raw[i, 0]
        x_tm1 = X_raw[i - 1, 0] if i > 0 else prev_last
        X_aug[i, 0] = x_t
        X_aug[i, 1] = fuzzy_inference_numpy(x_t, x_tm1)
    return X_aug.reshape((X_aug.shape[0], 1, 2))

X_train = build_fuzzy_augmented(X_train_raw, prev_last=0.0)
X_test  = build_fuzzy_augmented(X_test_raw,  prev_last=X_train_raw[-1, 0])

print(f"X_train shape: {X_train.shape}, y_train shape: {y_train.shape}")
print(f"X_test shape:  {X_test.shape}")
# Out:
# X_train shape: (230, 1, 2), y_train shape: (230,)
# X_test shape:  (60, 1, 2)

# %% [markdown]
# ## Training Loop

# %%
#Training loop (60 runs) -- with checkpointing

CHECKPOINT_DIR = "checkpoints_fuzzy_feature_dowjones"
os.makedirs(CHECKPOINT_DIR, exist_ok=True)

def _ckpt_path(run):
    return os.path.join(CHECKPOINT_DIR, f"run_{run}.pt")

def _summary_path():
    return os.path.join(CHECKPOINT_DIR, "summary.pt")

all_rmse = []
all_mse = []
all_nmse = []
all_predictions = []
all_losses = []
all_models = []  # keep every trained model for later noise-robustness eval

print(f"\n--- [PyTorch] RUNNING ON {device} ---\n")
print(f"Checkpoints will be read/written under: {os.path.abspath(CHECKPOINT_DIR)}\n")

N_RUNS = 60
summary_path = _summary_path()

if os.path.exists(summary_path):
    print("Found completed checkpoint summary -> loading, skipping training.")
    saved = torch.load(summary_path, map_location=device, weights_only=False)

    all_models = []
    for sd in saved['model_state_dicts']:
        m = build_model_torch(input_dim=2, units=8).to(device)
        m.load_state_dict(sd)
        m.eval()
        all_models.append(m)

    all_rmse = saved['rmse']
    all_mse = saved['mse']
    all_nmse = saved['nmse']
    all_predictions = saved['predictions']
    all_losses = saved['losses']
    print(f"Loaded {len(all_models)} models from checkpoint.")

else:
    for run in range(N_RUNS):

        run_ckpt_path = _ckpt_path(run)
        if os.path.exists(run_ckpt_path):
            print(f'\n===== RUN {run + 1}/{N_RUNS} (resumed from checkpoint) =====')
            ckpt = torch.load(run_ckpt_path, map_location=device, weights_only=False)

            model = build_model_torch(input_dim=2, units=8).to(device)
            model.load_state_dict(ckpt['model_state_dict'])
            model.eval()

            all_losses.append(ckpt['run_losses'])
            all_models.append(model)
            all_rmse.append(ckpt['rmse'])
            all_mse.append(ckpt['mse'])
            all_nmse.append(ckpt['nmse'])
            all_predictions.append(ckpt['predictions'])
            print(f"Loaded run {run + 1} -- RMSE: {ckpt['rmse']:.6f}, MSE: {ckpt['mse']:.6f}, NMSE: {ckpt['nmse']:.10f}")
            continue

        print(f'\n===== RUN {run + 1}/{N_RUNS} =====')

        np.random.seed(run)
        torch.manual_seed(run)

        model = build_model_torch(input_dim=2, units=8).to(device)

        # Initialize consumption gate bias to 1.0 (forget gate equivalent)
        with torch.no_grad():
            hs = model.hidden_size
            model.cell.bias.data[hs:2 * hs] = 1.0

        optimizer = torch.optim.Adam(model.parameters(), lr=0.001)
        criterion = nn.MSELoss()

        run_losses = []
        X_train_t = torch.tensor(X_train, dtype=torch.float32).to(device)
        y_train_t = torch.tensor(y_train, dtype=torch.float32).to(device)
        n_samples = X_train_t.size(0)

        for epoch in range(100):
            model.train()
            model.reset_states(1, device)
            epoch_loss = 0.0
            for i in range(n_samples):
                x_i = X_train_t[i:i + 1]
                y_i = y_train_t[i:i + 1]

                optimizer.zero_grad()
                pred = model(x_i)
                loss = criterion(pred.squeeze(-1), y_i)
                loss.backward()
                torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)
                optimizer.step()

                model.u = model.u.detach()
                epoch_loss += loss.item()

            avg_loss = epoch_loss / n_samples
            run_losses.append(avg_loss)
            print(f"Epoch {epoch + 1}/100 completed. Loss: {avg_loss:.6f}")

        all_losses.append(run_losses)
        model.reset_states(1, device)
        all_models.append(model)
        print(f'Training complete for run {run + 1}')

        model.eval()
        with torch.no_grad():
            for i in range(len(X_train)):
                X_input = torch.tensor(X_train[i:i+1], dtype=torch.float32).to(device)
                model(X_input)

        predictions = []
        model.eval()
        with torch.no_grad():
            for i in range(len(X_test)):
                X_input = torch.tensor(X_test[i:i+1], dtype=torch.float32).to(device)
                yhat = model(X_input).item()

                x_val = X_test[i, 0, 0]  # original scaled feature only (2-col scaler)
                new_row = np.array([x_val, yhat]).reshape(1, 2)
                inverted = scaler.inverse_transform(new_row)[0, -1]
                inverted = inverted + raw_values[len(train) + i]
                predictions.append(inverted)

        actual = raw_values[-len(X_test):]
        rmse = sqrt(mean_squared_error(actual, predictions))
        mse = mean_squared_error(actual, predictions)
        meanV = np.mean(actual)
        denominator = np.linalg.norm(np.array(actual) - meanV, 2)
        nmse = mse / np.power(denominator, 2)

        all_rmse.append(rmse)
        all_mse.append(mse)
        all_nmse.append(nmse)
        all_predictions.append(predictions)

        print(f'Run {run + 1} -- RMSE: {rmse:.6f}, MSE: {mse:.6f}, NMSE: {nmse:.10f}')

        torch.save({
            'model_state_dict': model.state_dict(),
            'run_losses': run_losses,
            'rmse': rmse,
            'mse': mse,
            'nmse': nmse,
            'predictions': predictions,
        }, run_ckpt_path)

    torch.save({
        'rmse': all_rmse,
        'mse': all_mse,
        'nmse': all_nmse,
        'predictions': all_predictions,
        'losses': all_losses,
        'model_state_dicts': [m.state_dict() for m in all_models],
    }, summary_path)

print(f'\n--- Training Summary (60 runs) ---')
print(f'RMSE: {np.mean(all_rmse):.6f} ± {np.std(all_rmse):.6f}')
print(f'MSE:  {np.mean(all_mse):.6f} ± {np.std(all_mse):.6f}')
print(f'NMSE: {np.mean(all_nmse):.10f} ± {np.std(all_nmse):.10f}')
# Out:
# --- [PyTorch] RUNNING ON cuda ---
#
# Checkpoints will be read/written under: c:\Users\paulp\OneDrive\Desktop\Type_2\Type_2\checkpoints_fuzzy_feature_dowjones
#
#
# ===== RUN 1/60 =====
# Epoch 1/100 completed. Loss: 0.135959
# Epoch 2/100 completed. Loss: 0.105200
# Epoch 3/100 completed. Loss: 0.088822
# Epoch 4/100 completed. Loss: 0.087659
# Epoch 5/100 completed. Loss: 0.087217
# Epoch 6/100 completed. Loss: 0.088816
# Epoch 7/100 completed. Loss: 0.090920
# Epoch 8/100 completed. Loss: 0.089889
# Epoch 9/100 completed. Loss: 0.087533
# Epoch 10/100 completed. Loss: 0.086534
# Epoch 11/100 completed. Loss: 0.085269
# Epoch 12/100 completed. Loss: 0.085644
# Epoch 13/100 completed. Loss: 0.089798
# Epoch 14/100 completed. Loss: 0.085116
# Epoch 15/100 completed. Loss: 0.085957
# Epoch 16/100 completed. Loss: 0.085213
# Epoch 17/100 completed. Loss: 0.086283
# Epoch 18/100 completed. Loss: 0.086433
# Epoch 19/100 completed. Loss: 0.087739
# Epoch 20/100 completed. Loss: 0.086459
# Epoch 21/100 completed. Loss: 0.087487
# Epoch 22/100 completed. Loss: 0.086590
# Epoch 23/100 completed. Loss: 0.086348
# Epoch 24/100 completed. Loss: 0.087337
# Epoch 25/100 completed. Loss: 0.086361
# Epoch 26/100 completed. Loss: 0.085772
# Epoch 27/100 completed. Loss: 0.086132
# Epoch 28/100 completed. Loss: 0.086889
# Epoch 29/100 completed. Loss: 0.086617
# Epoch 30/100 completed. Loss: 0.085985
# Epoch 31/100 completed. Loss: 0.086865
# Epoch 32/100 completed. Loss: 0.086211
# Epoch 33/100 completed. Loss: 0.086225
# Epoch 34/100 completed. Loss: 0.085911
# Epoch 35/100 completed. Loss: 0.085901
# Epoch 36/100 completed. Loss: 0.086172
# Epoch 37/100 completed. Loss: 0.087897
# Epoch 38/100 completed. Loss: 0.086023
# Epoch 39/100 completed. Loss: 0.089476
# Epoch 40/100 completed. Loss: 0.085914
# Epoch 41/100 completed. Loss: 0.086749
# Epoch 42/100 completed. Loss: 0.087868
# Epoch 43/100 completed. Loss: 0.105603
# Epoch 44/100 completed. Loss: 0.089413
# Epoch 45/100 completed. Loss: 0.086522
# Epoch 46/100 completed. Loss: 0.088724
# Epoch 47/100 completed. Loss: 0.087084
# Epoch 48/100 completed. Loss: 0.087114
# Epoch 49/100 completed. Loss: 0.085692
# Epoch 50/100 completed. Loss: 0.086030
# Epoch 51/100 completed. Loss: 0.085712
# Epoch 52/100 completed. Loss: 0.085329
# Epoch 53/100 completed. Loss: 0.086960
# Epoch 54/100 completed. Loss: 0.085535
# Epoch 55/100 completed. Loss: 0.085247
# Epoch 56/100 completed. Loss: 0.085182
# Epoch 57/100 completed. Loss: 0.085069
# Epoch 58/100 completed. Loss: 0.085018
# Epoch 59/100 completed. Loss: 0.084988
# Epoch 60/100 completed. Loss: 0.084938
# Epoch 61/100 completed. Loss: 0.084926
# Epoch 62/100 completed. Loss: 0.084894
# Epoch 63/100 completed. Loss: 0.084859
# Epoch 64/100 completed. Loss: 0.084847
# Epoch 65/100 completed. Loss: 0.084846
# Epoch 66/100 completed. Loss: 0.084813
# Epoch 67/100 completed. Loss: 0.084776
# Epoch 68/100 completed. Loss: 0.084815
# Epoch 69/100 completed. Loss: 0.084771
# Epoch 70/100 completed. Loss: 0.084728
# Epoch 71/100 completed. Loss: 0.084729
# Epoch 72/100 completed. Loss: 0.084684
# Epoch 73/100 completed. Loss: 0.084703
# Epoch 74/100 completed. Loss: 0.084671
# Epoch 75/100 completed. Loss: 0.084651
# Epoch 76/100 completed. Loss: 0.084649
# Epoch 77/100 completed. Loss: 0.084634
# Epoch 78/100 completed. Loss: 0.084630
# Epoch 79/100 completed. Loss: 0.084610
# Epoch 80/100 completed. Loss: 0.084582
# Epoch 81/100 completed. Loss: 0.084621
# Epoch 82/100 completed. Loss: 0.084556
# Epoch 83/100 completed. Loss: 0.084576
# Epoch 84/100 completed. Loss: 0.084569
# Epoch 85/100 completed. Loss: 0.084539
# Epoch 86/100 completed. Loss: 0.084550
# Epoch 87/100 completed. Loss: 0.084545
# Epoch 88/100 completed. Loss: 0.084508
# Epoch 89/100 completed. Loss: 0.084537
# Epoch 90/100 completed. Loss: 0.084533
# Epoch 91/100 completed. Loss: 0.084505
# Epoch 92/100 completed. Loss: 0.084513
# Epoch 93/100 completed. Loss: 0.084518
# Epoch 94/100 completed. Loss: 0.084488
# Epoch 95/100 completed. Loss: 0.084515
# Epoch 96/100 completed. Loss: 0.084496
# Epoch 97/100 completed. Loss: 0.084494
# Epoch 98/100 completed. Loss: 0.084499
# Epoch 99/100 completed. Loss: 0.084537
# Epoch 100/100 completed. Loss: 0.084508
# Training complete for run 1
# Run 1 -- RMSE: 24.466173, MSE: 598.593600, NMSE: 0.0027718025
#
# ===== RUN 2/60 =====
# Epoch 1/100 completed. Loss: 0.147971
# Epoch 2/100 completed. Loss: 0.090182
# Epoch 3/100 completed. Loss: 0.089169
# Epoch 4/100 completed. Loss: 0.088595
# Epoch 5/100 completed. Loss: 0.088274
# Epoch 6/100 completed. Loss: 0.088096
# Epoch 7/100 completed. Loss: 0.087992
# Epoch 8/100 completed. Loss: 0.087923
# Epoch 9/100 completed. Loss: 0.087874
# Epoch 10/100 completed. Loss: 0.087835
# Epoch 11/100 completed. Loss: 0.087801
# Epoch 12/100 completed. Loss: 0.087768
# Epoch 13/100 completed. Loss: 0.087735
# Epoch 14/100 completed. Loss: 0.087702
# Epoch 15/100 completed. Loss: 0.087667
# Epoch 16/100 completed. Loss: 0.087630
# Epoch 17/100 completed. Loss: 0.087597
# Epoch 18/100 completed. Loss: 0.087570
# Epoch 19/100 completed. Loss: 0.087548
# Epoch 20/100 completed. Loss: 0.087514
# Epoch 21/100 completed. Loss: 0.087479
# Epoch 22/100 completed. Loss: 0.087452
# Epoch 23/100 completed. Loss: 0.087425
# Epoch 24/100 completed. Loss: 0.087402
# Epoch 25/100 completed. Loss: 0.087378
# Epoch 26/100 completed. Loss: 0.087356
# Epoch 27/100 completed. Loss: 0.087339
# Epoch 28/100 completed. Loss: 0.087333
# Epoch 29/100 completed. Loss: 0.087347
# Epoch 30/100 completed. Loss: 0.087351
# Epoch 31/100 completed. Loss: 0.087387
# Epoch 32/100 completed. Loss: 0.087395
# Epoch 33/100 completed. Loss: 0.087415
# Epoch 34/100 completed. Loss: 0.087393
# Epoch 35/100 completed. Loss: 0.087332
# Epoch 36/100 completed. Loss: 0.086382
# Epoch 37/100 completed. Loss: 0.089192
# Epoch 38/100 completed. Loss: 0.088256
# Epoch 39/100 completed. Loss: 0.088542
# Epoch 40/100 completed. Loss: 0.088006
# Epoch 41/100 completed. Loss: 0.087615
# Epoch 42/100 completed. Loss: 0.087394
# Epoch 43/100 completed. Loss: 0.087305
# Epoch 44/100 completed. Loss: 0.087350
# Epoch 45/100 completed. Loss: 0.087331
# Epoch 46/100 completed. Loss: 0.087305
# Epoch 47/100 completed. Loss: 0.087245
# Epoch 48/100 completed. Loss: 0.087202
# Epoch 49/100 completed. Loss: 0.087163
# Epoch 50/100 completed. Loss: 0.087096
# Epoch 51/100 completed. Loss: 0.087059
# Epoch 52/100 completed. Loss: 0.087022
# Epoch 53/100 completed. Loss: 0.087011
# Epoch 54/100 completed. Loss: 0.087011
# Epoch 55/100 completed. Loss: 0.087091
# Epoch 56/100 completed. Loss: 0.087203
# Epoch 57/100 completed. Loss: 0.087345
# Epoch 58/100 completed. Loss: 0.087428
# Epoch 59/100 completed. Loss: 0.087501
# Epoch 60/100 completed. Loss: 0.087549
# Epoch 61/100 completed. Loss: 0.087328
# Epoch 62/100 completed. Loss: 0.087420
# Epoch 63/100 completed. Loss: 0.087040
# Epoch 64/100 completed. Loss: 0.087109
# Epoch 65/100 completed. Loss: 0.088553
# Epoch 66/100 completed. Loss: 0.086946
# Epoch 67/100 completed. Loss: 0.086554
# Epoch 68/100 completed. Loss: 0.086762
# Epoch 69/100 completed. Loss: 0.087345
# Epoch 70/100 completed. Loss: 0.086381
# Epoch 71/100 completed. Loss: 0.087023
# Epoch 72/100 completed. Loss: 0.087168
# Epoch 73/100 completed. Loss: 0.086895
# Epoch 74/100 completed. Loss: 0.086042
# Epoch 75/100 completed. Loss: 0.087041
# Epoch 76/100 completed. Loss: 0.085970
# Epoch 77/100 completed. Loss: 0.087046
# Epoch 78/100 completed. Loss: 0.085858
# Epoch 79/100 completed. Loss: 0.085909
# Epoch 80/100 completed. Loss: 0.085146
# Epoch 81/100 completed. Loss: 0.084798
# Epoch 82/100 completed. Loss: 0.084902
# Epoch 83/100 completed. Loss: 0.084962
# Epoch 84/100 completed. Loss: 0.084745
# Epoch 85/100 completed. Loss: 0.084612
# Epoch 86/100 completed. Loss: 0.084815
# Epoch 87/100 completed. Loss: 0.084735
# Epoch 88/100 completed. Loss: 0.084649
# Epoch 89/100 completed. Loss: 0.084616
# Epoch 90/100 completed. Loss: 0.084525
# Epoch 91/100 completed. Loss: 0.084565
# Epoch 92/100 completed. Loss: 0.084350
# Epoch 93/100 completed. Loss: 0.084224
# Epoch 94/100 completed. Loss: 0.084184
# Epoch 95/100 completed. Loss: 0.084109
# Epoch 96/100 completed. Loss: 0.084010
# Epoch 97/100 completed. Loss: 0.083916
# Epoch 98/100 completed. Loss: 0.083971
# Epoch 99/100 completed. Loss: 0.083916
# Epoch 100/100 completed. Loss: 0.083841
# Training complete for run 2
# Run 2 -- RMSE: 24.463684, MSE: 598.471850, NMSE: 0.0027712387
#
# ===== RUN 3/60 =====
# Epoch 1/100 completed. Loss: 0.099238
# Epoch 2/100 completed. Loss: 0.087373
# Epoch 3/100 completed. Loss: 0.087204
# Epoch 4/100 completed. Loss: 0.087098
# Epoch 5/100 completed. Loss: 0.087027
# Epoch 6/100 completed. Loss: 0.086977
# Epoch 7/100 completed. Loss: 0.086941
# Epoch 8/100 completed. Loss: 0.086913
# Epoch 9/100 completed. Loss: 0.086892
# Epoch 10/100 completed. Loss: 0.086873
# Epoch 11/100 completed. Loss: 0.086857
# Epoch 12/100 completed. Loss: 0.086841
# Epoch 13/100 completed. Loss: 0.086825
# Epoch 14/100 completed. Loss: 0.086809
# Epoch 15/100 completed. Loss: 0.086792
# Epoch 16/100 completed. Loss: 0.086775
# Epoch 17/100 completed. Loss: 0.086756
# Epoch 18/100 completed. Loss: 0.086736
# Epoch 19/100 completed. Loss: 0.086716
# Epoch 20/100 completed. Loss: 0.086694
# Epoch 21/100 completed. Loss: 0.086671
# Epoch 22/100 completed. Loss: 0.086647
# Epoch 23/100 completed. Loss: 0.086623
# Epoch 24/100 completed. Loss: 0.086597
# Epoch 25/100 completed. Loss: 0.086571
# Epoch 26/100 completed. Loss: 0.086544
# Epoch 27/100 completed. Loss: 0.086516
# Epoch 28/100 completed. Loss: 0.086487
# Epoch 29/100 completed. Loss: 0.086458
# Epoch 30/100 completed. Loss: 0.086428
# Epoch 31/100 completed. Loss: 0.086402
# Epoch 32/100 completed. Loss: 0.086377
# Epoch 33/100 completed. Loss: 0.086356
# Epoch 34/100 completed. Loss: 0.086329
# Epoch 35/100 completed. Loss: 0.086319
# Epoch 36/100 completed. Loss: 0.086307
# Epoch 37/100 completed. Loss: 0.086298
# Epoch 38/100 completed. Loss: 0.086288
# Epoch 39/100 completed. Loss: 0.086275
# Epoch 40/100 completed. Loss: 0.086265
# Epoch 41/100 completed. Loss: 0.086255
# Epoch 42/100 completed. Loss: 0.086245
# Epoch 43/100 completed. Loss: 0.086230
# Epoch 44/100 completed. Loss: 0.086211
# Epoch 45/100 completed. Loss: 0.086192
# Epoch 46/100 completed. Loss: 0.086170
# Epoch 47/100 completed. Loss: 0.086151
# Epoch 48/100 completed. Loss: 0.086141
# Epoch 49/100 completed. Loss: 0.086132
# Epoch 50/100 completed. Loss: 0.086128
# Epoch 51/100 completed. Loss: 0.086118
# Epoch 52/100 completed. Loss: 0.086116
# Epoch 53/100 completed. Loss: 0.086115
# Epoch 54/100 completed. Loss: 0.086108
# Epoch 55/100 completed. Loss: 0.086102
# Epoch 56/100 completed. Loss: 0.086110
# Epoch 57/100 completed. Loss: 0.086186
# Epoch 58/100 completed. Loss: 0.086364
# Epoch 59/100 completed. Loss: 0.086579
# Epoch 60/100 completed. Loss: 0.086848
# Epoch 61/100 completed. Loss: 0.086905
# Epoch 62/100 completed. Loss: 0.087173
# Epoch 63/100 completed. Loss: 0.087154
# Epoch 64/100 completed. Loss: 0.086967
# Epoch 65/100 completed. Loss: 0.086762
# Epoch 66/100 completed. Loss: 0.086565
# Epoch 67/100 completed. Loss: 0.086395
# Epoch 68/100 completed. Loss: 0.086240
# Epoch 69/100 completed. Loss: 0.086072
# Epoch 70/100 completed. Loss: 0.085926
# Epoch 71/100 completed. Loss: 0.085796
# Epoch 72/100 completed. Loss: 0.085675
# Epoch 73/100 completed. Loss: 0.085565
# Epoch 74/100 completed. Loss: 0.085464
# Epoch 75/100 completed. Loss: 0.085368
# Epoch 76/100 completed. Loss: 0.085279
# Epoch 77/100 completed. Loss: 0.085193
# Epoch 78/100 completed. Loss: 0.085104
# Epoch 79/100 completed. Loss: 0.085015
# Epoch 80/100 completed. Loss: 0.084922
# Epoch 81/100 completed. Loss: 0.084826
# Epoch 82/100 completed. Loss: 0.084723
# Epoch 83/100 completed. Loss: 0.084608
# Epoch 84/100 completed. Loss: 0.084483
# Epoch 85/100 completed. Loss: 0.084316
# Epoch 86/100 completed. Loss: 0.084221
# Epoch 87/100 completed. Loss: 0.084052
# Epoch 88/100 completed. Loss: 0.083870
# Epoch 89/100 completed. Loss: 0.083770
# Epoch 90/100 completed. Loss: 0.083637
# Epoch 91/100 completed. Loss: 0.083454
# Epoch 92/100 completed. Loss: 0.083425
# Epoch 93/100 completed. Loss: 0.083248
# Epoch 94/100 completed. Loss: 0.083196
# Epoch 95/100 completed. Loss: 0.083040
# Epoch 96/100 completed. Loss: 0.083027
# Epoch 97/100 completed. Loss: 0.082903
# Epoch 98/100 completed. Loss: 0.082785
# Epoch 99/100 completed. Loss: 0.082656
# Epoch 100/100 completed. Loss: 0.082546
# Training complete for run 3
# Run 3 -- RMSE: 24.084520, MSE: 580.064082, NMSE: 0.0026860011
#
# ===== RUN 4/60 =====
# Epoch 1/100 completed. Loss: 0.089995
# Epoch 2/100 completed. Loss: 0.087897
# Epoch 3/100 completed. Loss: 0.087212
# Epoch 4/100 completed. Loss: 0.086786
# Epoch 5/100 completed. Loss: 0.086524
# Epoch 6/100 completed. Loss: 0.086364
# Epoch 7/100 completed. Loss: 0.086264
# Epoch 8/100 completed. Loss: 0.086202
# Epoch 9/100 completed. Loss: 0.086163
# Epoch 10/100 completed. Loss: 0.086139
# Epoch 11/100 completed. Loss: 0.086123
# Epoch 12/100 completed. Loss: 0.086112
# Epoch 13/100 completed. Loss: 0.086104
# Epoch 14/100 completed. Loss: 0.086098
# Epoch 15/100 completed. Loss: 0.086092
# Epoch 16/100 completed. Loss: 0.086085
# Epoch 17/100 completed. Loss: 0.086079
# Epoch 18/100 completed. Loss: 0.086072
# Epoch 19/100 completed. Loss: 0.086064
# Epoch 20/100 completed. Loss: 0.086056
# Epoch 21/100 completed. Loss: 0.086047
# Epoch 22/100 completed. Loss: 0.086036
# Epoch 23/100 completed. Loss: 0.086025
# Epoch 24/100 completed. Loss: 0.086014
# Epoch 25/100 completed. Loss: 0.086003
# Epoch 26/100 completed. Loss: 0.085991
# Epoch 27/100 completed. Loss: 0.085979
# Epoch 28/100 completed. Loss: 0.085967
# Epoch 29/100 completed. Loss: 0.085956
# Epoch 30/100 completed. Loss: 0.085944
# Epoch 31/100 completed. Loss: 0.085933
# Epoch 32/100 completed. Loss: 0.085922
# Epoch 33/100 completed. Loss: 0.085911
# Epoch 34/100 completed. Loss: 0.085900
# Epoch 35/100 completed. Loss: 0.085889
# Epoch 36/100 completed. Loss: 0.085879
# Epoch 37/100 completed. Loss: 0.085868
# Epoch 38/100 completed. Loss: 0.085858
# Epoch 39/100 completed. Loss: 0.085847
# Epoch 40/100 completed. Loss: 0.085837
# Epoch 41/100 completed. Loss: 0.085826
# Epoch 42/100 completed. Loss: 0.085814
# Epoch 43/100 completed. Loss: 0.085803
# Epoch 44/100 completed. Loss: 0.085791
# Epoch 45/100 completed. Loss: 0.085779
# Epoch 46/100 completed. Loss: 0.085767
# Epoch 47/100 completed. Loss: 0.085755
# Epoch 48/100 completed. Loss: 0.085748
# Epoch 49/100 completed. Loss: 0.085733
# Epoch 50/100 completed. Loss: 0.085717
# Epoch 51/100 completed. Loss: 0.085702
# Epoch 52/100 completed. Loss: 0.085688
# Epoch 53/100 completed. Loss: 0.085674
# Epoch 54/100 completed. Loss: 0.085660
# Epoch 55/100 completed. Loss: 0.085647
# Epoch 56/100 completed. Loss: 0.085634
# Epoch 57/100 completed. Loss: 0.085619
# Epoch 58/100 completed. Loss: 0.085603
# Epoch 59/100 completed. Loss: 0.085585
# Epoch 60/100 completed. Loss: 0.085567
# Epoch 61/100 completed. Loss: 0.085547
# Epoch 62/100 completed. Loss: 0.085524
# Epoch 63/100 completed. Loss: 0.085497
# Epoch 64/100 completed. Loss: 0.085467
# Epoch 65/100 completed. Loss: 0.085429
# Epoch 66/100 completed. Loss: 0.085400
# Epoch 67/100 completed. Loss: 0.085364
# Epoch 68/100 completed. Loss: 0.085332
# Epoch 69/100 completed. Loss: 0.085311
# Epoch 70/100 completed. Loss: 0.085302
# Epoch 71/100 completed. Loss: 0.085291
# Epoch 72/100 completed. Loss: 0.085308
# Epoch 73/100 completed. Loss: 0.085365
# Epoch 74/100 completed. Loss: 0.085553
# Epoch 75/100 completed. Loss: 0.085825
# Epoch 76/100 completed. Loss: 0.086017
# Epoch 77/100 completed. Loss: 0.085907
# Epoch 78/100 completed. Loss: 0.085605
# Epoch 79/100 completed. Loss: 0.085481
# Epoch 80/100 completed. Loss: 0.085375
# Epoch 81/100 completed. Loss: 0.085320
# Epoch 82/100 completed. Loss: 0.085294
# Epoch 83/100 completed. Loss: 0.085301
# Epoch 84/100 completed. Loss: 0.085284
# Epoch 85/100 completed. Loss: 0.085276
# Epoch 86/100 completed. Loss: 0.085236
# Epoch 87/100 completed. Loss: 0.085189
# Epoch 88/100 completed. Loss: 0.085228
# Epoch 89/100 completed. Loss: 0.085070
# Epoch 90/100 completed. Loss: 0.086326
# Epoch 91/100 completed. Loss: 0.085427
# Epoch 92/100 completed. Loss: 0.084893
# Epoch 93/100 completed. Loss: 0.084871
# Epoch 94/100 completed. Loss: 0.093041
# Epoch 95/100 completed. Loss: 0.086952
# Epoch 96/100 completed. Loss: 0.086381
# Epoch 97/100 completed. Loss: 0.085908
# Epoch 98/100 completed. Loss: 0.085616
# Epoch 99/100 completed. Loss: 0.085515
# Epoch 100/100 completed. Loss: 0.085530
# Training complete for run 4
# Run 4 -- RMSE: 24.437798, MSE: 597.205976, NMSE: 0.0027653770
#
# ===== RUN 5/60 =====
# Epoch 1/100 completed. Loss: 0.175820
# Epoch 2/100 completed. Loss: 0.089318
# Epoch 3/100 completed. Loss: 0.088667
# Epoch 4/100 completed. Loss: 0.088278
# Epoch 5/100 completed. Loss: 0.088045
# Epoch 6/100 completed. Loss: 0.087899
# Epoch 7/100 completed. Loss: 0.087803
# Epoch 8/100 completed. Loss: 0.087737
# Epoch 9/100 completed. Loss: 0.087688
# Epoch 10/100 completed. Loss: 0.087652
# Epoch 11/100 completed. Loss: 0.087622
# Epoch 12/100 completed. Loss: 0.087596
# Epoch 13/100 completed. Loss: 0.087574
# Epoch 14/100 completed. Loss: 0.087552
# Epoch 15/100 completed. Loss: 0.087532
# Epoch 16/100 completed. Loss: 0.087512
# Epoch 17/100 completed. Loss: 0.087493
# Epoch 18/100 completed. Loss: 0.087474
# Epoch 19/100 completed. Loss: 0.087455
# Epoch 20/100 completed. Loss: 0.087437
# Epoch 21/100 completed. Loss: 0.087420
# Epoch 22/100 completed. Loss: 0.087402
# Epoch 23/100 completed. Loss: 0.087385
# Epoch 24/100 completed. Loss: 0.087368
# Epoch 25/100 completed. Loss: 0.087351
# Epoch 26/100 completed. Loss: 0.087335
# Epoch 27/100 completed. Loss: 0.087318
# Epoch 28/100 completed. Loss: 0.087302
# Epoch 29/100 completed. Loss: 0.087286
# Epoch 30/100 completed. Loss: 0.087270
# Epoch 31/100 completed. Loss: 0.087255
# Epoch 32/100 completed. Loss: 0.087240
# Epoch 33/100 completed. Loss: 0.087225
# Epoch 34/100 completed. Loss: 0.087210
# Epoch 35/100 completed. Loss: 0.087195
# Epoch 36/100 completed. Loss: 0.087181
# Epoch 37/100 completed. Loss: 0.087167
# Epoch 38/100 completed. Loss: 0.087153
# Epoch 39/100 completed. Loss: 0.087139
# Epoch 40/100 completed. Loss: 0.087126
# Epoch 41/100 completed. Loss: 0.087113
# Epoch 42/100 completed. Loss: 0.087100
# Epoch 43/100 completed. Loss: 0.087087
# Epoch 44/100 completed. Loss: 0.087075
# Epoch 45/100 completed. Loss: 0.087062
# Epoch 46/100 completed. Loss: 0.087051
# Epoch 47/100 completed. Loss: 0.087039
# Epoch 48/100 completed. Loss: 0.087028
# Epoch 49/100 completed. Loss: 0.087018
# Epoch 50/100 completed. Loss: 0.087008
# Epoch 51/100 completed. Loss: 0.086999
# Epoch 52/100 completed. Loss: 0.086991
# Epoch 53/100 completed. Loss: 0.086984
# Epoch 54/100 completed. Loss: 0.086978
# Epoch 55/100 completed. Loss: 0.086974
# Epoch 56/100 completed. Loss: 0.086972
# Epoch 57/100 completed. Loss: 0.086971
# Epoch 58/100 completed. Loss: 0.086973
# Epoch 59/100 completed. Loss: 0.086975
# Epoch 60/100 completed. Loss: 0.086976
# Epoch 61/100 completed. Loss: 0.086973
# Epoch 62/100 completed. Loss: 0.086967
# Epoch 63/100 completed. Loss: 0.086958
# Epoch 64/100 completed. Loss: 0.086948
# Epoch 65/100 completed. Loss: 0.086939
# Epoch 66/100 completed. Loss: 0.086929
# Epoch 67/100 completed. Loss: 0.086921
# Epoch 68/100 completed. Loss: 0.086912
# Epoch 69/100 completed. Loss: 0.086904
# Epoch 70/100 completed. Loss: 0.086896
# Epoch 71/100 completed. Loss: 0.086889
# Epoch 72/100 completed. Loss: 0.086881
# Epoch 73/100 completed. Loss: 0.086874
# Epoch 74/100 completed. Loss: 0.086866
# Epoch 75/100 completed. Loss: 0.086859
# Epoch 76/100 completed. Loss: 0.086852
# Epoch 77/100 completed. Loss: 0.086844
# Epoch 78/100 completed. Loss: 0.086836
# Epoch 79/100 completed. Loss: 0.086827
# Epoch 80/100 completed. Loss: 0.086814
# Epoch 81/100 completed. Loss: 0.086811
# Epoch 82/100 completed. Loss: 0.086802
# Epoch 83/100 completed. Loss: 0.086794
# Epoch 84/100 completed. Loss: 0.086794
# Epoch 85/100 completed. Loss: 0.086783
# Epoch 86/100 completed. Loss: 0.086776
# Epoch 87/100 completed. Loss: 0.086758
# Epoch 88/100 completed. Loss: 0.086756
# Epoch 89/100 completed. Loss: 0.086729
# Epoch 90/100 completed. Loss: 0.086741
# Epoch 91/100 completed. Loss: 0.086687
# Epoch 92/100 completed. Loss: 0.086766
# Epoch 93/100 completed. Loss: 0.086633
# Epoch 94/100 completed. Loss: 0.086861
# Epoch 95/100 completed. Loss: 0.086731
# Epoch 96/100 completed. Loss: 0.086698
# Epoch 97/100 completed. Loss: 0.086781
# Epoch 98/100 completed. Loss: 0.086801
# Epoch 99/100 completed. Loss: 0.086856
# Epoch 100/100 completed. Loss: 0.086890
# Training complete for run 5
# Run 5 -- RMSE: 24.546927, MSE: 602.551632, NMSE: 0.0027901302
#
# ===== RUN 6/60 =====
# Epoch 1/100 completed. Loss: 0.136619
# Epoch 2/100 completed. Loss: 0.088961
# Epoch 3/100 completed. Loss: 0.088492
# Epoch 4/100 completed. Loss: 0.088144
# Epoch 5/100 completed. Loss: 0.087886
# Epoch 6/100 completed. Loss: 0.087692
# Epoch 7/100 completed. Loss: 0.087544
# Epoch 8/100 completed. Loss: 0.087428
# Epoch 9/100 completed. Loss: 0.087338
# Epoch 10/100 completed. Loss: 0.087267
# Epoch 11/100 completed. Loss: 0.087209
# Epoch 12/100 completed. Loss: 0.087161
# Epoch 13/100 completed. Loss: 0.087122
# Epoch 14/100 completed. Loss: 0.087088
# Epoch 15/100 completed. Loss: 0.087060
# Epoch 16/100 completed. Loss: 0.087035
# Epoch 17/100 completed. Loss: 0.087013
# Epoch 18/100 completed. Loss: 0.086993
# Epoch 19/100 completed. Loss: 0.086975
# Epoch 20/100 completed. Loss: 0.086958
# Epoch 21/100 completed. Loss: 0.086942
# Epoch 22/100 completed. Loss: 0.086926
# Epoch 23/100 completed. Loss: 0.086911
# Epoch 24/100 completed. Loss: 0.086897
# Epoch 25/100 completed. Loss: 0.086883
# Epoch 26/100 completed. Loss: 0.086870
# Epoch 27/100 completed. Loss: 0.086858
# Epoch 28/100 completed. Loss: 0.086846
# Epoch 29/100 completed. Loss: 0.086835
# Epoch 30/100 completed. Loss: 0.086824
# Epoch 31/100 completed. Loss: 0.086814
# Epoch 32/100 completed. Loss: 0.086804
# Epoch 33/100 completed. Loss: 0.086796
# Epoch 34/100 completed. Loss: 0.086787
# Epoch 35/100 completed. Loss: 0.086779
# Epoch 36/100 completed. Loss: 0.086771
# Epoch 37/100 completed. Loss: 0.086763
# Epoch 38/100 completed. Loss: 0.086755
# Epoch 39/100 completed. Loss: 0.086748
# Epoch 40/100 completed. Loss: 0.086741
# Epoch 41/100 completed. Loss: 0.086734
# Epoch 42/100 completed. Loss: 0.086727
# Epoch 43/100 completed. Loss: 0.086719
# Epoch 44/100 completed. Loss: 0.086712
# Epoch 45/100 completed. Loss: 0.086705
# Epoch 46/100 completed. Loss: 0.086697
# Epoch 47/100 completed. Loss: 0.086690
# Epoch 48/100 completed. Loss: 0.086682
# Epoch 49/100 completed. Loss: 0.086674
# Epoch 50/100 completed. Loss: 0.086666
# Epoch 51/100 completed. Loss: 0.086658
# Epoch 52/100 completed. Loss: 0.086650
# Epoch 53/100 completed. Loss: 0.086641
# Epoch 54/100 completed. Loss: 0.086632
# Epoch 55/100 completed. Loss: 0.086623
# Epoch 56/100 completed. Loss: 0.086614
# Epoch 57/100 completed. Loss: 0.086605
# Epoch 58/100 completed. Loss: 0.086596
# Epoch 59/100 completed. Loss: 0.086587
# Epoch 60/100 completed. Loss: 0.086585
# Epoch 61/100 completed. Loss: 0.086591
# Epoch 62/100 completed. Loss: 0.086591
# Epoch 63/100 completed. Loss: 0.086583
# Epoch 64/100 completed. Loss: 0.086583
# Epoch 65/100 completed. Loss: 0.086579
# Epoch 66/100 completed. Loss: 0.086574
# Epoch 67/100 completed. Loss: 0.086565
# Epoch 68/100 completed. Loss: 0.086563
# Epoch 69/100 completed. Loss: 0.086555
# Epoch 70/100 completed. Loss: 0.086553
# Epoch 71/100 completed. Loss: 0.086549
# Epoch 72/100 completed. Loss: 0.086546
# Epoch 73/100 completed. Loss: 0.086543
# Epoch 74/100 completed. Loss: 0.086545
# Epoch 75/100 completed. Loss: 0.086537
# Epoch 76/100 completed. Loss: 0.086534
# Epoch 77/100 completed. Loss: 0.086543
# Epoch 78/100 completed. Loss: 0.086545
# Epoch 79/100 completed. Loss: 0.086546
# Epoch 80/100 completed. Loss: 0.086547
# Epoch 81/100 completed. Loss: 0.086553
# Epoch 82/100 completed. Loss: 0.086562
# Epoch 83/100 completed. Loss: 0.086533
# Epoch 84/100 completed. Loss: 0.086572
# Epoch 85/100 completed. Loss: 0.086542
# Epoch 86/100 completed. Loss: 0.086586
# Epoch 87/100 completed. Loss: 0.086543
# Epoch 88/100 completed. Loss: 0.086558
# Epoch 89/100 completed. Loss: 0.086580
# Epoch 90/100 completed. Loss: 0.086564
# Epoch 91/100 completed. Loss: 0.086567
# Epoch 92/100 completed. Loss: 0.086565
# Epoch 93/100 completed. Loss: 0.086566
# Epoch 94/100 completed. Loss: 0.086565
# Epoch 95/100 completed. Loss: 0.086565
# Epoch 96/100 completed. Loss: 0.086564
# Epoch 97/100 completed. Loss: 0.086570
# Epoch 98/100 completed. Loss: 0.086567
# Epoch 99/100 completed. Loss: 0.086576
# Epoch 100/100 completed. Loss: 0.086577
# Training complete for run 6
# Run 6 -- RMSE: 24.254651, MSE: 588.288099, NMSE: 0.0027240826
#
# ===== RUN 7/60 =====
# Epoch 1/100 completed. Loss: 0.108346
# Epoch 2/100 completed. Loss: 0.087856
# Epoch 3/100 completed. Loss: 0.087280
# Epoch 4/100 completed. Loss: 0.086951
# Epoch 5/100 completed. Loss: 0.086756
# Epoch 6/100 completed. Loss: 0.086641
# Epoch 7/100 completed. Loss: 0.086575
# Epoch 8/100 completed. Loss: 0.086536
# Epoch 9/100 completed. Loss: 0.086512
# Epoch 10/100 completed. Loss: 0.086496
# Epoch 11/100 completed. Loss: 0.086485
# Epoch 12/100 completed. Loss: 0.086477
# Epoch 13/100 completed. Loss: 0.086470
# Epoch 14/100 completed. Loss: 0.086463
# Epoch 15/100 completed. Loss: 0.086456
# Epoch 16/100 completed. Loss: 0.086449
# Epoch 17/100 completed. Loss: 0.086441
# Epoch 18/100 completed. Loss: 0.086432
# Epoch 19/100 completed. Loss: 0.086423
# Epoch 20/100 completed. Loss: 0.086414
# Epoch 21/100 completed. Loss: 0.086403
# Epoch 22/100 completed. Loss: 0.086392
# Epoch 23/100 completed. Loss: 0.086381
# Epoch 24/100 completed. Loss: 0.086369
# Epoch 25/100 completed. Loss: 0.086357
# Epoch 26/100 completed. Loss: 0.086345
# Epoch 27/100 completed. Loss: 0.086332
# Epoch 28/100 completed. Loss: 0.086320
# Epoch 29/100 completed. Loss: 0.086307
# Epoch 30/100 completed. Loss: 0.086295
# Epoch 31/100 completed. Loss: 0.086282
# Epoch 32/100 completed. Loss: 0.086270
# Epoch 33/100 completed. Loss: 0.086258
# Epoch 34/100 completed. Loss: 0.086246
# Epoch 35/100 completed. Loss: 0.086234
# Epoch 36/100 completed. Loss: 0.086222
# Epoch 37/100 completed. Loss: 0.086211
# Epoch 38/100 completed. Loss: 0.086199
# Epoch 39/100 completed. Loss: 0.086187
# Epoch 40/100 completed. Loss: 0.086176
# Epoch 41/100 completed. Loss: 0.086164
# Epoch 42/100 completed. Loss: 0.086153
# Epoch 43/100 completed. Loss: 0.086142
# Epoch 44/100 completed. Loss: 0.086131
# Epoch 45/100 completed. Loss: 0.086124
# Epoch 46/100 completed. Loss: 0.086121
# Epoch 47/100 completed. Loss: 0.086121
# Epoch 48/100 completed. Loss: 0.086123
# Epoch 49/100 completed. Loss: 0.086129
# Epoch 50/100 completed. Loss: 0.086134
# Epoch 51/100 completed. Loss: 0.086145
# Epoch 52/100 completed. Loss: 0.086167
# Epoch 53/100 completed. Loss: 0.086189
# Epoch 54/100 completed. Loss: 0.086206
# Epoch 55/100 completed. Loss: 0.086221
# Epoch 56/100 completed. Loss: 0.086217
# Epoch 57/100 completed. Loss: 0.086215
# Epoch 58/100 completed. Loss: 0.086219
# Epoch 59/100 completed. Loss: 0.086201
# Epoch 60/100 completed. Loss: 0.086192
# Epoch 61/100 completed. Loss: 0.086169
# Epoch 62/100 completed. Loss: 0.086140
# Epoch 63/100 completed. Loss: 0.086117
# Epoch 64/100 completed. Loss: 0.086090
# Epoch 65/100 completed. Loss: 0.086057
# Epoch 66/100 completed. Loss: 0.086020
# Epoch 67/100 completed. Loss: 0.085972
# Epoch 68/100 completed. Loss: 0.085929
# Epoch 69/100 completed. Loss: 0.085884
# Epoch 70/100 completed. Loss: 0.085835
# Epoch 71/100 completed. Loss: 0.085787
# Epoch 72/100 completed. Loss: 0.085736
# Epoch 73/100 completed. Loss: 0.085684
# Epoch 74/100 completed. Loss: 0.085633
# Epoch 75/100 completed. Loss: 0.085592
# Epoch 76/100 completed. Loss: 0.085511
# Epoch 77/100 completed. Loss: 0.085501
# Epoch 78/100 completed. Loss: 0.085407
# Epoch 79/100 completed. Loss: 0.085375
# Epoch 80/100 completed. Loss: 0.085283
# Epoch 81/100 completed. Loss: 0.085271
# Epoch 82/100 completed. Loss: 0.085192
# Epoch 83/100 completed. Loss: 0.085179
# Epoch 84/100 completed. Loss: 0.085134
# Epoch 85/100 completed. Loss: 0.085079
# Epoch 86/100 completed. Loss: 0.085036
# Epoch 87/100 completed. Loss: 0.084991
# Epoch 88/100 completed. Loss: 0.084953
# Epoch 89/100 completed. Loss: 0.084926
# Epoch 90/100 completed. Loss: 0.084893
# Epoch 91/100 completed. Loss: 0.084892
# Epoch 92/100 completed. Loss: 0.084845
# Epoch 93/100 completed. Loss: 0.084776
# Epoch 94/100 completed. Loss: 0.084750
# Epoch 95/100 completed. Loss: 0.084676
# Epoch 96/100 completed. Loss: 0.084653
# Epoch 97/100 completed. Loss: 0.084564
# Epoch 98/100 completed. Loss: 0.084482
# Epoch 99/100 completed. Loss: 0.084425
# Epoch 100/100 completed. Loss: 0.084433
# Training complete for run 7
# Run 7 -- RMSE: 24.285541, MSE: 589.787498, NMSE: 0.0027310256
#
# ===== RUN 8/60 =====
# Epoch 1/100 completed. Loss: 0.195967
# Epoch 2/100 completed. Loss: 0.088162
# Epoch 3/100 completed. Loss: 0.087771
# Epoch 4/100 completed. Loss: 0.087571
# Epoch 5/100 completed. Loss: 0.087470
# Epoch 6/100 completed. Loss: 0.087426
# Epoch 7/100 completed. Loss: 0.087414
# Epoch 8/100 completed. Loss: 0.087416
# Epoch 9/100 completed. Loss: 0.087424
# Epoch 10/100 completed. Loss: 0.087431
# Epoch 11/100 completed. Loss: 0.087436
# Epoch 12/100 completed. Loss: 0.087437
# Epoch 13/100 completed. Loss: 0.087431
# Epoch 14/100 completed. Loss: 0.087421
# Epoch 15/100 completed. Loss: 0.087408
# Epoch 16/100 completed. Loss: 0.087391
# Epoch 17/100 completed. Loss: 0.087371
# Epoch 18/100 completed. Loss: 0.087349
# Epoch 19/100 completed. Loss: 0.087326
# Epoch 20/100 completed. Loss: 0.087301
# Epoch 21/100 completed. Loss: 0.087275
# Epoch 22/100 completed. Loss: 0.087248
# Epoch 23/100 completed. Loss: 0.087220
# Epoch 24/100 completed. Loss: 0.087194
# Epoch 25/100 completed. Loss: 0.087167
# Epoch 26/100 completed. Loss: 0.087141
# Epoch 27/100 completed. Loss: 0.087115
# Epoch 28/100 completed. Loss: 0.087089
# Epoch 29/100 completed. Loss: 0.087064
# Epoch 30/100 completed. Loss: 0.087040
# Epoch 31/100 completed. Loss: 0.087017
# Epoch 32/100 completed. Loss: 0.086996
# Epoch 33/100 completed. Loss: 0.086976
# Epoch 34/100 completed. Loss: 0.086957
# Epoch 35/100 completed. Loss: 0.086939
# Epoch 36/100 completed. Loss: 0.086922
# Epoch 37/100 completed. Loss: 0.086906
# Epoch 38/100 completed. Loss: 0.086891
# Epoch 39/100 completed. Loss: 0.086876
# Epoch 40/100 completed. Loss: 0.086861
# Epoch 41/100 completed. Loss: 0.086847
# Epoch 42/100 completed. Loss: 0.086834
# Epoch 43/100 completed. Loss: 0.086822
# Epoch 44/100 completed. Loss: 0.086810
# Epoch 45/100 completed. Loss: 0.086799
# Epoch 46/100 completed. Loss: 0.086788
# Epoch 47/100 completed. Loss: 0.086776
# Epoch 48/100 completed. Loss: 0.086763
# Epoch 49/100 completed. Loss: 0.086747
# Epoch 50/100 completed. Loss: 0.086726
# Epoch 51/100 completed. Loss: 0.086702
# Epoch 52/100 completed. Loss: 0.086684
# Epoch 53/100 completed. Loss: 0.086673
# Epoch 54/100 completed. Loss: 0.086668
# Epoch 55/100 completed. Loss: 0.086666
# Epoch 56/100 completed. Loss: 0.086662
# Epoch 57/100 completed. Loss: 0.086656
# Epoch 58/100 completed. Loss: 0.086647
# Epoch 59/100 completed. Loss: 0.086638
# Epoch 60/100 completed. Loss: 0.086628
# Epoch 61/100 completed. Loss: 0.086618
# Epoch 62/100 completed. Loss: 0.086608
# Epoch 63/100 completed. Loss: 0.086599
# Epoch 64/100 completed. Loss: 0.086593
# Epoch 65/100 completed. Loss: 0.086587
# Epoch 66/100 completed. Loss: 0.086582
# Epoch 67/100 completed. Loss: 0.086576
# Epoch 68/100 completed. Loss: 0.086569
# Epoch 69/100 completed. Loss: 0.086562
# Epoch 70/100 completed. Loss: 0.086555
# Epoch 71/100 completed. Loss: 0.086548
# Epoch 72/100 completed. Loss: 0.086542
# Epoch 73/100 completed. Loss: 0.086536
# Epoch 74/100 completed. Loss: 0.086531
# Epoch 75/100 completed. Loss: 0.086526
# Epoch 76/100 completed. Loss: 0.086520
# Epoch 77/100 completed. Loss: 0.086514
# Epoch 78/100 completed. Loss: 0.086509
# Epoch 79/100 completed. Loss: 0.086503
# Epoch 80/100 completed. Loss: 0.086495
# Epoch 81/100 completed. Loss: 0.086487
# Epoch 82/100 completed. Loss: 0.086478
# Epoch 83/100 completed. Loss: 0.086466
# Epoch 84/100 completed. Loss: 0.086454
# Epoch 85/100 completed. Loss: 0.086447
# Epoch 86/100 completed. Loss: 0.086438
# Epoch 87/100 completed. Loss: 0.086431
# Epoch 88/100 completed. Loss: 0.086426
# Epoch 89/100 completed. Loss: 0.086425
# Epoch 90/100 completed. Loss: 0.086426
# Epoch 91/100 completed. Loss: 0.086426
# Epoch 92/100 completed. Loss: 0.086425
# Epoch 93/100 completed. Loss: 0.086427
# Epoch 94/100 completed. Loss: 0.086439
# Epoch 95/100 completed. Loss: 0.086443
# Epoch 96/100 completed. Loss: 0.086431
# Epoch 97/100 completed. Loss: 0.086422
# Epoch 98/100 completed. Loss: 0.086413
# Epoch 99/100 completed. Loss: 0.086419
# Epoch 100/100 completed. Loss: 0.086380
# Training complete for run 8
# Run 8 -- RMSE: 24.534843, MSE: 601.958505, NMSE: 0.0027873838
#
# ===== RUN 9/60 =====
# Epoch 1/100 completed. Loss: 0.160041
# Epoch 2/100 completed. Loss: 0.091940
# Epoch 3/100 completed. Loss: 0.089834
# Epoch 4/100 completed. Loss: 0.088642
# Epoch 5/100 completed. Loss: 0.087973
# Epoch 6/100 completed. Loss: 0.087619
# Epoch 7/100 completed. Loss: 0.087442
# Epoch 8/100 completed. Loss: 0.087362
# Epoch 9/100 completed. Loss: 0.087338
# Epoch 10/100 completed. Loss: 0.087342
# Epoch 11/100 completed. Loss: 0.087358
# Epoch 12/100 completed. Loss: 0.087378
# Epoch 13/100 completed. Loss: 0.087398
# Epoch 14/100 completed. Loss: 0.087415
# Epoch 15/100 completed. Loss: 0.087425
# Epoch 16/100 completed. Loss: 0.087433
# Epoch 17/100 completed. Loss: 0.087436
# Epoch 18/100 completed. Loss: 0.087438
# Epoch 19/100 completed. Loss: 0.087437
# Epoch 20/100 completed. Loss: 0.087432
# Epoch 21/100 completed. Loss: 0.087424
# Epoch 22/100 completed. Loss: 0.087412
# Epoch 23/100 completed. Loss: 0.087396
# Epoch 24/100 completed. Loss: 0.087374
# Epoch 25/100 completed. Loss: 0.087347
# Epoch 26/100 completed. Loss: 0.087314
# Epoch 27/100 completed. Loss: 0.087277
# Epoch 28/100 completed. Loss: 0.087239
# Epoch 29/100 completed. Loss: 0.087201
# Epoch 30/100 completed. Loss: 0.087166
# Epoch 31/100 completed. Loss: 0.087134
# Epoch 32/100 completed. Loss: 0.087104
# Epoch 33/100 completed. Loss: 0.087077
# Epoch 34/100 completed. Loss: 0.087052
# Epoch 35/100 completed. Loss: 0.087028
# Epoch 36/100 completed. Loss: 0.087005
# Epoch 37/100 completed. Loss: 0.086984
# Epoch 38/100 completed. Loss: 0.086963
# Epoch 39/100 completed. Loss: 0.086945
# Epoch 40/100 completed. Loss: 0.086927
# Epoch 41/100 completed. Loss: 0.086911
# Epoch 42/100 completed. Loss: 0.086896
# Epoch 43/100 completed. Loss: 0.086884
# Epoch 44/100 completed. Loss: 0.086872
# Epoch 45/100 completed. Loss: 0.086861
# Epoch 46/100 completed. Loss: 0.086849
# Epoch 47/100 completed. Loss: 0.086837
# Epoch 48/100 completed. Loss: 0.086825
# Epoch 49/100 completed. Loss: 0.086809
# Epoch 50/100 completed. Loss: 0.086792
# Epoch 51/100 completed. Loss: 0.086774
# Epoch 52/100 completed. Loss: 0.086759
# Epoch 53/100 completed. Loss: 0.086744
# Epoch 54/100 completed. Loss: 0.086731
# Epoch 55/100 completed. Loss: 0.086717
# Epoch 56/100 completed. Loss: 0.086706
# Epoch 57/100 completed. Loss: 0.086692
# Epoch 58/100 completed. Loss: 0.086684
# Epoch 59/100 completed. Loss: 0.086670
# Epoch 60/100 completed. Loss: 0.086665
# Epoch 61/100 completed. Loss: 0.086648
# Epoch 62/100 completed. Loss: 0.086648
# Epoch 63/100 completed. Loss: 0.086629
# Epoch 64/100 completed. Loss: 0.086634
# Epoch 65/100 completed. Loss: 0.086624
# Epoch 66/100 completed. Loss: 0.086621
# Epoch 67/100 completed. Loss: 0.086420
# Epoch 68/100 completed. Loss: 0.086449
# Epoch 69/100 completed. Loss: 0.086443
# Epoch 70/100 completed. Loss: 0.086451
# Epoch 71/100 completed. Loss: 0.086429
# Epoch 72/100 completed. Loss: 0.086420
# Epoch 73/100 completed. Loss: 0.086466
# Epoch 74/100 completed. Loss: 0.086294
# Epoch 75/100 completed. Loss: 0.086406
# Epoch 76/100 completed. Loss: 0.086238
# Epoch 77/100 completed. Loss: 0.086283
# Epoch 78/100 completed. Loss: 0.086124
# Epoch 79/100 completed. Loss: 0.086141
# Epoch 80/100 completed. Loss: 0.086138
# Epoch 81/100 completed. Loss: 0.086145
# Epoch 82/100 completed. Loss: 0.086130
# Epoch 83/100 completed. Loss: 0.086149
# Epoch 84/100 completed. Loss: 0.086158
# Epoch 85/100 completed. Loss: 0.086169
# Epoch 86/100 completed. Loss: 0.086176
# Epoch 87/100 completed. Loss: 0.086183
# Epoch 88/100 completed. Loss: 0.086184
# Epoch 89/100 completed. Loss: 0.086188
# Epoch 90/100 completed. Loss: 0.086187
# Epoch 91/100 completed. Loss: 0.086182
# Epoch 92/100 completed. Loss: 0.086178
# Epoch 93/100 completed. Loss: 0.086169
# Epoch 94/100 completed. Loss: 0.086163
# Epoch 95/100 completed. Loss: 0.086147
# Epoch 96/100 completed. Loss: 0.086132
# Epoch 97/100 completed. Loss: 0.086120
# Epoch 98/100 completed. Loss: 0.086106
# Epoch 99/100 completed. Loss: 0.086106
# Epoch 100/100 completed. Loss: 0.086093
# Training complete for run 9
# Run 9 -- RMSE: 24.453291, MSE: 597.963452, NMSE: 0.0027688846
#
# ===== RUN 10/60 =====
# Epoch 1/100 completed. Loss: 0.150041
# Epoch 2/100 completed. Loss: 0.088488
# Epoch 3/100 completed. Loss: 0.087646
# Epoch 4/100 completed. Loss: 0.087258
# Epoch 5/100 completed. Loss: 0.087102
# Epoch 6/100 completed. Loss: 0.087063
# Epoch 7/100 completed. Loss: 0.087079
# Epoch 8/100 completed. Loss: 0.087110
# Epoch 9/100 completed. Loss: 0.087137
# Epoch 10/100 completed. Loss: 0.087158
# Epoch 11/100 completed. Loss: 0.087170
# Epoch 12/100 completed. Loss: 0.087173
# Epoch 13/100 completed. Loss: 0.087169
# Epoch 14/100 completed. Loss: 0.087160
# Epoch 15/100 completed. Loss: 0.087147
# Epoch 16/100 completed. Loss: 0.087131
# Epoch 17/100 completed. Loss: 0.087112
# Epoch 18/100 completed. Loss: 0.087093
# Epoch 19/100 completed. Loss: 0.087073
# Epoch 20/100 completed. Loss: 0.087052
# Epoch 21/100 completed. Loss: 0.087031
# Epoch 22/100 completed. Loss: 0.087011
# Epoch 23/100 completed. Loss: 0.086991
# Epoch 24/100 completed. Loss: 0.086971
# Epoch 25/100 completed. Loss: 0.086951
# Epoch 26/100 completed. Loss: 0.086931
# Epoch 27/100 completed. Loss: 0.086911
# Epoch 28/100 completed. Loss: 0.086891
# Epoch 29/100 completed. Loss: 0.086871
# Epoch 30/100 completed. Loss: 0.086850
# Epoch 31/100 completed. Loss: 0.086831
# Epoch 32/100 completed. Loss: 0.086811
# Epoch 33/100 completed. Loss: 0.086793
# Epoch 34/100 completed. Loss: 0.086776
# Epoch 35/100 completed. Loss: 0.086759
# Epoch 36/100 completed. Loss: 0.086744
# Epoch 37/100 completed. Loss: 0.086729
# Epoch 38/100 completed. Loss: 0.086715
# Epoch 39/100 completed. Loss: 0.086701
# Epoch 40/100 completed. Loss: 0.086688
# Epoch 41/100 completed. Loss: 0.086676
# Epoch 42/100 completed. Loss: 0.086664
# Epoch 43/100 completed. Loss: 0.086652
# Epoch 44/100 completed. Loss: 0.086641
# Epoch 45/100 completed. Loss: 0.086630
# Epoch 46/100 completed. Loss: 0.086619
# Epoch 47/100 completed. Loss: 0.086609
# Epoch 48/100 completed. Loss: 0.086599
# Epoch 49/100 completed. Loss: 0.086589
# Epoch 50/100 completed. Loss: 0.086579
# Epoch 51/100 completed. Loss: 0.086569
# Epoch 52/100 completed. Loss: 0.086560
# Epoch 53/100 completed. Loss: 0.086551
# Epoch 54/100 completed. Loss: 0.086542
# Epoch 55/100 completed. Loss: 0.086533
# Epoch 56/100 completed. Loss: 0.086525
# Epoch 57/100 completed. Loss: 0.086517
# Epoch 58/100 completed. Loss: 0.086509
# Epoch 59/100 completed. Loss: 0.086501
# Epoch 60/100 completed. Loss: 0.086493
# Epoch 61/100 completed. Loss: 0.086486
# Epoch 62/100 completed. Loss: 0.086478
# Epoch 63/100 completed. Loss: 0.086471
# Epoch 64/100 completed. Loss: 0.086465
# Epoch 65/100 completed. Loss: 0.086458
# Epoch 66/100 completed. Loss: 0.086451
# Epoch 67/100 completed. Loss: 0.086445
# Epoch 68/100 completed. Loss: 0.086438
# Epoch 69/100 completed. Loss: 0.086432
# Epoch 70/100 completed. Loss: 0.086426
# Epoch 71/100 completed. Loss: 0.086420
# Epoch 72/100 completed. Loss: 0.086414
# Epoch 73/100 completed. Loss: 0.086408
# Epoch 74/100 completed. Loss: 0.086402
# Epoch 75/100 completed. Loss: 0.086397
# Epoch 76/100 completed. Loss: 0.086391
# Epoch 77/100 completed. Loss: 0.086385
# Epoch 78/100 completed. Loss: 0.086379
# Epoch 79/100 completed. Loss: 0.086373
# Epoch 80/100 completed. Loss: 0.086363
# Epoch 81/100 completed. Loss: 0.086354
# Epoch 82/100 completed. Loss: 0.086345
# Epoch 83/100 completed. Loss: 0.086341
# Epoch 84/100 completed. Loss: 0.086337
# Epoch 85/100 completed. Loss: 0.086332
# Epoch 86/100 completed. Loss: 0.086327
# Epoch 87/100 completed. Loss: 0.086322
# Epoch 88/100 completed. Loss: 0.086317
# Epoch 89/100 completed. Loss: 0.086309
# Epoch 90/100 completed. Loss: 0.086301
# Epoch 91/100 completed. Loss: 0.086291
# Epoch 92/100 completed. Loss: 0.086283
# Epoch 93/100 completed. Loss: 0.086277
# Epoch 94/100 completed. Loss: 0.086268
# Epoch 95/100 completed. Loss: 0.086259
# Epoch 96/100 completed. Loss: 0.086250
# Epoch 97/100 completed. Loss: 0.086240
# Epoch 98/100 completed. Loss: 0.086223
# Epoch 99/100 completed. Loss: 0.086219
# Epoch 100/100 completed. Loss: 0.086208
# Training complete for run 10
# Run 10 -- RMSE: 24.608439, MSE: 605.575282, NMSE: 0.0028041313
#
# ===== RUN 11/60 =====
# Epoch 1/100 completed. Loss: 0.087547
# Epoch 2/100 completed. Loss: 0.085840
# Epoch 3/100 completed. Loss: 0.085764
# Epoch 4/100 completed. Loss: 0.085729
# Epoch 5/100 completed. Loss: 0.085721
# Epoch 6/100 completed. Loss: 0.085729
# Epoch 7/100 completed. Loss: 0.085741
# Epoch 8/100 completed. Loss: 0.085750
# Epoch 9/100 completed. Loss: 0.085755
# Epoch 10/100 completed. Loss: 0.085756
# Epoch 11/100 completed. Loss: 0.085754
# Epoch 12/100 completed. Loss: 0.085749
# Epoch 13/100 completed. Loss: 0.085742
# Epoch 14/100 completed. Loss: 0.085733
# Epoch 15/100 completed. Loss: 0.085723
# Epoch 16/100 completed. Loss: 0.085711
# Epoch 17/100 completed. Loss: 0.085697
# Epoch 18/100 completed. Loss: 0.085683
# Epoch 19/100 completed. Loss: 0.085668
# Epoch 20/100 completed. Loss: 0.085653
# Epoch 21/100 completed. Loss: 0.085638
# Epoch 22/100 completed. Loss: 0.085622
# Epoch 23/100 completed. Loss: 0.085606
# Epoch 24/100 completed. Loss: 0.085590
# Epoch 25/100 completed. Loss: 0.085575
# Epoch 26/100 completed. Loss: 0.085559
# Epoch 27/100 completed. Loss: 0.085543
# Epoch 28/100 completed. Loss: 0.085527
# Epoch 29/100 completed. Loss: 0.085512
# Epoch 30/100 completed. Loss: 0.085496
# Epoch 31/100 completed. Loss: 0.085480
# Epoch 32/100 completed. Loss: 0.085464
# Epoch 33/100 completed. Loss: 0.085448
# Epoch 34/100 completed. Loss: 0.085431
# Epoch 35/100 completed. Loss: 0.085415
# Epoch 36/100 completed. Loss: 0.085398
# Epoch 37/100 completed. Loss: 0.085381
# Epoch 38/100 completed. Loss: 0.085364
# Epoch 39/100 completed. Loss: 0.085347
# Epoch 40/100 completed. Loss: 0.085329
# Epoch 41/100 completed. Loss: 0.085311
# Epoch 42/100 completed. Loss: 0.085292
# Epoch 43/100 completed. Loss: 0.085274
# Epoch 44/100 completed. Loss: 0.085256
# Epoch 45/100 completed. Loss: 0.085239
# Epoch 46/100 completed. Loss: 0.085222
# Epoch 47/100 completed. Loss: 0.085205
# Epoch 48/100 completed. Loss: 0.085190
# Epoch 49/100 completed. Loss: 0.085176
# Epoch 50/100 completed. Loss: 0.085163
# Epoch 51/100 completed. Loss: 0.085152
# Epoch 52/100 completed. Loss: 0.085142
# Epoch 53/100 completed. Loss: 0.085134
# Epoch 54/100 completed. Loss: 0.085127
# Epoch 55/100 completed. Loss: 0.085122
# Epoch 56/100 completed. Loss: 0.085119
# Epoch 57/100 completed. Loss: 0.085116
# Epoch 58/100 completed. Loss: 0.085115
# Epoch 59/100 completed. Loss: 0.085114
# Epoch 60/100 completed. Loss: 0.085114
# Epoch 61/100 completed. Loss: 0.085113
# Epoch 62/100 completed. Loss: 0.085113
# Epoch 63/100 completed. Loss: 0.085112
# Epoch 64/100 completed. Loss: 0.085111
# Epoch 65/100 completed. Loss: 0.085109
# Epoch 66/100 completed. Loss: 0.085107
# Epoch 67/100 completed. Loss: 0.085104
# Epoch 68/100 completed. Loss: 0.085101
# Epoch 69/100 completed. Loss: 0.085097
# Epoch 70/100 completed. Loss: 0.085093
# Epoch 71/100 completed. Loss: 0.085089
# Epoch 72/100 completed. Loss: 0.085085
# Epoch 73/100 completed. Loss: 0.085082
# Epoch 74/100 completed. Loss: 0.085078
# Epoch 75/100 completed. Loss: 0.085074
# Epoch 76/100 completed. Loss: 0.085069
# Epoch 77/100 completed. Loss: 0.085063
# Epoch 78/100 completed. Loss: 0.085057
# Epoch 79/100 completed. Loss: 0.085050
# Epoch 80/100 completed. Loss: 0.085042
# Epoch 81/100 completed. Loss: 0.085034
# Epoch 82/100 completed. Loss: 0.085026
# Epoch 83/100 completed. Loss: 0.085017
# Epoch 84/100 completed. Loss: 0.085008
# Epoch 85/100 completed. Loss: 0.084999
# Epoch 86/100 completed. Loss: 0.084989
# Epoch 87/100 completed. Loss: 0.084978
# Epoch 88/100 completed. Loss: 0.084968
# Epoch 89/100 completed. Loss: 0.084957
# Epoch 90/100 completed. Loss: 0.084946
# Epoch 91/100 completed. Loss: 0.084934
# Epoch 92/100 completed. Loss: 0.084923
# Epoch 93/100 completed. Loss: 0.084910
# Epoch 94/100 completed. Loss: 0.084898
# Epoch 95/100 completed. Loss: 0.084886
# Epoch 96/100 completed. Loss: 0.084873
# Epoch 97/100 completed. Loss: 0.084860
# Epoch 98/100 completed. Loss: 0.084847
# Epoch 99/100 completed. Loss: 0.084835
# Epoch 100/100 completed. Loss: 0.084825
# Training complete for run 11
# Run 11 -- RMSE: 24.416726, MSE: 596.176533, NMSE: 0.0027606102
#
# ===== RUN 12/60 =====
# Epoch 1/100 completed. Loss: 0.088704
# Epoch 2/100 completed. Loss: 0.086447
# Epoch 3/100 completed. Loss: 0.086032
# Epoch 4/100 completed. Loss: 0.085803
# Epoch 5/100 completed. Loss: 0.085679
# Epoch 6/100 completed. Loss: 0.085614
# Epoch 7/100 completed. Loss: 0.085584
# Epoch 8/100 completed. Loss: 0.085573
# Epoch 9/100 completed. Loss: 0.085573
# Epoch 10/100 completed. Loss: 0.085578
# Epoch 11/100 completed. Loss: 0.085584
# Epoch 12/100 completed. Loss: 0.085590
# Epoch 13/100 completed. Loss: 0.085594
# Epoch 14/100 completed. Loss: 0.085598
# Epoch 15/100 completed. Loss: 0.085600
# Epoch 16/100 completed. Loss: 0.085600
# Epoch 17/100 completed. Loss: 0.085599
# Epoch 18/100 completed. Loss: 0.085596
# Epoch 19/100 completed. Loss: 0.085592
# Epoch 20/100 completed. Loss: 0.085588
# Epoch 21/100 completed. Loss: 0.085582
# Epoch 22/100 completed. Loss: 0.085576
# Epoch 23/100 completed. Loss: 0.085569
# Epoch 24/100 completed. Loss: 0.085562
# Epoch 25/100 completed. Loss: 0.085554
# Epoch 26/100 completed. Loss: 0.085546
# Epoch 27/100 completed. Loss: 0.085537
# Epoch 28/100 completed. Loss: 0.085528
# Epoch 29/100 completed. Loss: 0.085519
# Epoch 30/100 completed. Loss: 0.085510
# Epoch 31/100 completed. Loss: 0.085500
# Epoch 32/100 completed. Loss: 0.085490
# Epoch 33/100 completed. Loss: 0.085480
# Epoch 34/100 completed. Loss: 0.085470
# Epoch 35/100 completed. Loss: 0.085459
# Epoch 36/100 completed. Loss: 0.085448
# Epoch 37/100 completed. Loss: 0.085437
# Epoch 38/100 completed. Loss: 0.085426
# Epoch 39/100 completed. Loss: 0.085415
# Epoch 40/100 completed. Loss: 0.085404
# Epoch 41/100 completed. Loss: 0.085392
# Epoch 42/100 completed. Loss: 0.085380
# Epoch 43/100 completed. Loss: 0.085368
# Epoch 44/100 completed. Loss: 0.085356
# Epoch 45/100 completed. Loss: 0.085343
# Epoch 46/100 completed. Loss: 0.085331
# Epoch 47/100 completed. Loss: 0.085318
# Epoch 48/100 completed. Loss: 0.085305
# Epoch 49/100 completed. Loss: 0.085291
# Epoch 50/100 completed. Loss: 0.085278
# Epoch 51/100 completed. Loss: 0.085264
# Epoch 52/100 completed. Loss: 0.085250
# Epoch 53/100 completed. Loss: 0.085235
# Epoch 54/100 completed. Loss: 0.085220
# Epoch 55/100 completed. Loss: 0.085205
# Epoch 56/100 completed. Loss: 0.085190
# Epoch 57/100 completed. Loss: 0.085174
# Epoch 58/100 completed. Loss: 0.085159
# Epoch 59/100 completed. Loss: 0.085142
# Epoch 60/100 completed. Loss: 0.085126
# Epoch 61/100 completed. Loss: 0.085109
# Epoch 62/100 completed. Loss: 0.085091
# Epoch 63/100 completed. Loss: 0.085073
# Epoch 64/100 completed. Loss: 0.085055
# Epoch 65/100 completed. Loss: 0.085037
# Epoch 66/100 completed. Loss: 0.085018
# Epoch 67/100 completed. Loss: 0.084999
# Epoch 68/100 completed. Loss: 0.084979
# Epoch 69/100 completed. Loss: 0.084959
# Epoch 70/100 completed. Loss: 0.084938
# Epoch 71/100 completed. Loss: 0.084917
# Epoch 72/100 completed. Loss: 0.084896
# Epoch 73/100 completed. Loss: 0.084874
# Epoch 74/100 completed. Loss: 0.084852
# Epoch 75/100 completed. Loss: 0.084830
# Epoch 76/100 completed. Loss: 0.084807
# Epoch 77/100 completed. Loss: 0.084784
# Epoch 78/100 completed. Loss: 0.084761
# Epoch 79/100 completed. Loss: 0.084737
# Epoch 80/100 completed. Loss: 0.084713
# Epoch 81/100 completed. Loss: 0.084688
# Epoch 82/100 completed. Loss: 0.084663
# Epoch 83/100 completed. Loss: 0.084638
# Epoch 84/100 completed. Loss: 0.084612
# Epoch 85/100 completed. Loss: 0.084586
# Epoch 86/100 completed. Loss: 0.084560
# Epoch 87/100 completed. Loss: 0.084533
# Epoch 88/100 completed. Loss: 0.084506
# Epoch 89/100 completed. Loss: 0.084479
# Epoch 90/100 completed. Loss: 0.084452
# Epoch 91/100 completed. Loss: 0.084424
# Epoch 92/100 completed. Loss: 0.084396
# Epoch 93/100 completed. Loss: 0.084368
# Epoch 94/100 completed. Loss: 0.084340
# Epoch 95/100 completed. Loss: 0.084312
# Epoch 96/100 completed. Loss: 0.084283
# ...
# Epoch 5/100 completed. Loss: 0.086327
# Epoch 6/100 completed. Loss: 0.086268
# Epoch 7/100 completed. Loss: 0.086230
# Epoch 8/100 completed. Loss: 0.086205
# Epoch 9/100 completed. Loss: 0.086188
# Epoch 10/100 completed. Loss: 0.086174
# Epoch 11/100 completed. Loss: 0.086163
# Epoch 12/100 completed. Loss: 0.086153
# Epoch 13/100 completed. Loss: 0.086143
# Epoch 14/100 completed. Loss: 0.086134
# Epoch 15/100 completed. Loss: 0.086124
# Epoch 16/100 completed. Loss: 0.086114
# Epoch 17/100 completed. Loss: 0.086105
# Epoch 18/100 completed. Loss: 0.086095
# Epoch 19/100 completed. Loss: 0.086086
# Epoch 20/100 completed. Loss: 0.086076
# Epoch 21/100 completed. Loss: 0.086066
# Epoch 22/100 completed. Loss: 0.086057
# Epoch 23/100 completed. Loss: 0.086047
# Epoch 24/100 completed. Loss: 0.086037
# Epoch 25/100 completed. Loss: 0.086028
# Epoch 26/100 completed. Loss: 0.086018
# Epoch 27/100 completed. Loss: 0.086009
# Epoch 28/100 completed. Loss: 0.086000
# Epoch 29/100 completed. Loss: 0.085991
# Epoch 30/100 completed. Loss: 0.085982
# Epoch 31/100 completed. Loss: 0.085973
# Epoch 32/100 completed. Loss: 0.085964
# Epoch 33/100 completed. Loss: 0.085955
# Epoch 34/100 completed. Loss: 0.085946
# Epoch 35/100 completed. Loss: 0.085938
# Epoch 36/100 completed. Loss: 0.085929
# Epoch 37/100 completed. Loss: 0.085921
# Epoch 38/100 completed. Loss: 0.085913
# Epoch 39/100 completed. Loss: 0.085905
# Epoch 40/100 completed. Loss: 0.085897
# Epoch 41/100 completed. Loss: 0.085890
# Epoch 42/100 completed. Loss: 0.085882
# Epoch 43/100 completed. Loss: 0.085875
# Epoch 44/100 completed. Loss: 0.085867
# Epoch 45/100 completed. Loss: 0.085860
# Epoch 46/100 completed. Loss: 0.085853
# Epoch 47/100 completed. Loss: 0.085845
# Epoch 48/100 completed. Loss: 0.085838
# Epoch 49/100 completed. Loss: 0.085831
# Epoch 50/100 completed. Loss: 0.085824
# Epoch 51/100 completed. Loss: 0.085817
# Epoch 52/100 completed. Loss: 0.085810
# Epoch 53/100 completed. Loss: 0.085802
# Epoch 54/100 completed. Loss: 0.085795
# Epoch 55/100 completed. Loss: 0.085788
# Epoch 56/100 completed. Loss: 0.085781
# Epoch 57/100 completed. Loss: 0.085773
# Epoch 58/100 completed. Loss: 0.085766
# Epoch 59/100 completed. Loss: 0.085759
# Epoch 60/100 completed. Loss: 0.085752
# Epoch 61/100 completed. Loss: 0.085744
# Epoch 62/100 completed. Loss: 0.085737
# Epoch 63/100 completed. Loss: 0.085730
# Epoch 64/100 completed. Loss: 0.085723
# Epoch 65/100 completed. Loss: 0.085716
# Epoch 66/100 completed. Loss: 0.085710
# Epoch 67/100 completed. Loss: 0.085703
# Epoch 68/100 completed. Loss: 0.085698
# Epoch 69/100 completed. Loss: 0.085693
# Epoch 70/100 completed. Loss: 0.085688
# Epoch 71/100 completed. Loss: 0.085684
# Epoch 72/100 completed. Loss: 0.085681
# Epoch 73/100 completed. Loss: 0.085678
# Epoch 74/100 completed. Loss: 0.085674
# Epoch 75/100 completed. Loss: 0.085671
# Epoch 76/100 completed. Loss: 0.085666
# Epoch 77/100 completed. Loss: 0.085661
# Epoch 78/100 completed. Loss: 0.085654
# Epoch 79/100 completed. Loss: 0.085647
# Epoch 80/100 completed. Loss: 0.085638
# Epoch 81/100 completed. Loss: 0.085630
# Epoch 82/100 completed. Loss: 0.085625
# Epoch 83/100 completed. Loss: 0.085615
# Epoch 84/100 completed. Loss: 0.085602
# Epoch 85/100 completed. Loss: 0.085592
# Epoch 86/100 completed. Loss: 0.085583
# Epoch 87/100 completed. Loss: 0.085575
# Epoch 88/100 completed. Loss: 0.085570
# Epoch 89/100 completed. Loss: 0.085572
# Epoch 90/100 completed. Loss: 0.085593
# Epoch 91/100 completed. Loss: 0.085580
# Epoch 92/100 completed. Loss: 0.085567
# Epoch 93/100 completed. Loss: 0.085565
# Epoch 94/100 completed. Loss: 0.085559
# Epoch 95/100 completed. Loss: 0.085549
# Epoch 96/100 completed. Loss: 0.085532
# Epoch 97/100 completed. Loss: 0.085510
# Epoch 98/100 completed. Loss: 0.085489
# Epoch 99/100 completed. Loss: 0.085556
# Epoch 100/100 completed. Loss: 0.085463
# Training complete for run 57
# Run 57 -- RMSE: 24.232028, MSE: 587.191165, NMSE: 0.0027190032
#
# ===== RUN 58/60 =====
# Epoch 1/100 completed. Loss: 0.104755
# Epoch 2/100 completed. Loss: 0.087943
# Epoch 3/100 completed. Loss: 0.087098
# Epoch 4/100 completed. Loss: 0.086646
# Epoch 5/100 completed. Loss: 0.086392
# Epoch 6/100 completed. Loss: 0.086252
# Epoch 7/100 completed. Loss: 0.086181
# Epoch 8/100 completed. Loss: 0.086151
# Epoch 9/100 completed. Loss: 0.086143
# Epoch 10/100 completed. Loss: 0.086145
# Epoch 11/100 completed. Loss: 0.086150
# Epoch 12/100 completed. Loss: 0.086153
# Epoch 13/100 completed. Loss: 0.086153
# Epoch 14/100 completed. Loss: 0.086150
# Epoch 15/100 completed. Loss: 0.086143
# Epoch 16/100 completed. Loss: 0.086135
# Epoch 17/100 completed. Loss: 0.086124
# Epoch 18/100 completed. Loss: 0.086112
# Epoch 19/100 completed. Loss: 0.086098
# Epoch 20/100 completed. Loss: 0.086084
# Epoch 21/100 completed. Loss: 0.086070
# Epoch 22/100 completed. Loss: 0.086055
# Epoch 23/100 completed. Loss: 0.086039
# Epoch 24/100 completed. Loss: 0.086024
# Epoch 25/100 completed. Loss: 0.086009
# Epoch 26/100 completed. Loss: 0.085995
# Epoch 27/100 completed. Loss: 0.085980
# Epoch 28/100 completed. Loss: 0.085966
# Epoch 29/100 completed. Loss: 0.085953
# Epoch 30/100 completed. Loss: 0.085940
# Epoch 31/100 completed. Loss: 0.085928
# Epoch 32/100 completed. Loss: 0.085916
# Epoch 33/100 completed. Loss: 0.085905
# Epoch 34/100 completed. Loss: 0.085895
# Epoch 35/100 completed. Loss: 0.085886
# Epoch 36/100 completed. Loss: 0.085877
# Epoch 37/100 completed. Loss: 0.085868
# Epoch 38/100 completed. Loss: 0.085861
# Epoch 39/100 completed. Loss: 0.085854
# Epoch 40/100 completed. Loss: 0.085847
# Epoch 41/100 completed. Loss: 0.085841
# Epoch 42/100 completed. Loss: 0.085836
# Epoch 43/100 completed. Loss: 0.085832
# Epoch 44/100 completed. Loss: 0.085829
# Epoch 45/100 completed. Loss: 0.085826
# Epoch 46/100 completed. Loss: 0.085823
# Epoch 47/100 completed. Loss: 0.085821
# Epoch 48/100 completed. Loss: 0.085818
# Epoch 49/100 completed. Loss: 0.085815
# Epoch 50/100 completed. Loss: 0.085810
# Epoch 51/100 completed. Loss: 0.085805
# Epoch 52/100 completed. Loss: 0.085800
# Epoch 53/100 completed. Loss: 0.085794
# Epoch 54/100 completed. Loss: 0.085788
# Epoch 55/100 completed. Loss: 0.085782
# Epoch 56/100 completed. Loss: 0.085775
# Epoch 57/100 completed. Loss: 0.085768
# Epoch 58/100 completed. Loss: 0.085761
# Epoch 59/100 completed. Loss: 0.085753
# Epoch 60/100 completed. Loss: 0.085745
# Epoch 61/100 completed. Loss: 0.085737
# Epoch 62/100 completed. Loss: 0.085729
# Epoch 63/100 completed. Loss: 0.085720
# Epoch 64/100 completed. Loss: 0.085711
# Epoch 65/100 completed. Loss: 0.085702
# Epoch 66/100 completed. Loss: 0.085692
# Epoch 67/100 completed. Loss: 0.085682
# Epoch 68/100 completed. Loss: 0.085671
# Epoch 69/100 completed. Loss: 0.085660
# Epoch 70/100 completed. Loss: 0.085647
# Epoch 71/100 completed. Loss: 0.085632
# Epoch 72/100 completed. Loss: 0.085616
# Epoch 73/100 completed. Loss: 0.085603
# Epoch 74/100 completed. Loss: 0.085598
# Epoch 75/100 completed. Loss: 0.085600
# Epoch 76/100 completed. Loss: 0.085619
# Epoch 77/100 completed. Loss: 0.085641
# Epoch 78/100 completed. Loss: 0.085657
# Epoch 79/100 completed. Loss: 0.085683
# Epoch 80/100 completed. Loss: 0.085705
# Epoch 81/100 completed. Loss: 0.085722
# Epoch 82/100 completed. Loss: 0.085732
# Epoch 83/100 completed. Loss: 0.085743
# Epoch 84/100 completed. Loss: 0.085743
# Epoch 85/100 completed. Loss: 0.085735
# Epoch 86/100 completed. Loss: 0.085730
# Epoch 87/100 completed. Loss: 0.085722
# Epoch 88/100 completed. Loss: 0.085707
# Epoch 89/100 completed. Loss: 0.085688
# Epoch 90/100 completed. Loss: 0.085672
# Epoch 91/100 completed. Loss: 0.085650
# Epoch 92/100 completed. Loss: 0.085626
# Epoch 93/100 completed. Loss: 0.085600
# Epoch 94/100 completed. Loss: 0.085574
# Epoch 95/100 completed. Loss: 0.085556
# Epoch 96/100 completed. Loss: 0.085523
# Epoch 97/100 completed. Loss: 0.085506
# Epoch 98/100 completed. Loss: 0.085472
# Epoch 99/100 completed. Loss: 0.085456
# Epoch 100/100 completed. Loss: 0.085422
# Training complete for run 58
# Run 58 -- RMSE: 24.118241, MSE: 581.689530, NMSE: 0.0026935278
#
# ===== RUN 59/60 =====
# Epoch 1/100 completed. Loss: 0.092280
# Epoch 2/100 completed. Loss: 0.086911
# Epoch 3/100 completed. Loss: 0.086554
# Epoch 4/100 completed. Loss: 0.086325
# Epoch 5/100 completed. Loss: 0.086179
# Epoch 6/100 completed. Loss: 0.086087
# Epoch 7/100 completed. Loss: 0.086031
# Epoch 8/100 completed. Loss: 0.085997
# Epoch 9/100 completed. Loss: 0.085977
# Epoch 10/100 completed. Loss: 0.085965
# Epoch 11/100 completed. Loss: 0.085958
# Epoch 12/100 completed. Loss: 0.085952
# Epoch 13/100 completed. Loss: 0.085947
# Epoch 14/100 completed. Loss: 0.085941
# Epoch 15/100 completed. Loss: 0.085935
# Epoch 16/100 completed. Loss: 0.085928
# Epoch 17/100 completed. Loss: 0.085920
# Epoch 18/100 completed. Loss: 0.085912
# Epoch 19/100 completed. Loss: 0.085902
# Epoch 20/100 completed. Loss: 0.085893
# Epoch 21/100 completed. Loss: 0.085882
# Epoch 22/100 completed. Loss: 0.085872
# Epoch 23/100 completed. Loss: 0.085861
# Epoch 24/100 completed. Loss: 0.085851
# Epoch 25/100 completed. Loss: 0.085841
# Epoch 26/100 completed. Loss: 0.085832
# Epoch 27/100 completed. Loss: 0.085824
# Epoch 28/100 completed. Loss: 0.085817
# Epoch 29/100 completed. Loss: 0.085812
# Epoch 30/100 completed. Loss: 0.085807
# Epoch 31/100 completed. Loss: 0.085803
# Epoch 32/100 completed. Loss: 0.085800
# Epoch 33/100 completed. Loss: 0.085796
# Epoch 34/100 completed. Loss: 0.085793
# Epoch 35/100 completed. Loss: 0.085788
# Epoch 36/100 completed. Loss: 0.085784
# Epoch 37/100 completed. Loss: 0.085779
# Epoch 38/100 completed. Loss: 0.085773
# Epoch 39/100 completed. Loss: 0.085768
# Epoch 40/100 completed. Loss: 0.085761
# Epoch 41/100 completed. Loss: 0.085754
# Epoch 42/100 completed. Loss: 0.085747
# Epoch 43/100 completed. Loss: 0.085739
# Epoch 44/100 completed. Loss: 0.085731
# Epoch 45/100 completed. Loss: 0.085723
# Epoch 46/100 completed. Loss: 0.085715
# Epoch 47/100 completed. Loss: 0.085707
# Epoch 48/100 completed. Loss: 0.085699
# Epoch 49/100 completed. Loss: 0.085692
# Epoch 50/100 completed. Loss: 0.085685
# Epoch 51/100 completed. Loss: 0.085678
# Epoch 52/100 completed. Loss: 0.085671
# Epoch 53/100 completed. Loss: 0.085664
# Epoch 54/100 completed. Loss: 0.085657
# Epoch 55/100 completed. Loss: 0.085649
# Epoch 56/100 completed. Loss: 0.085641
# Epoch 57/100 completed. Loss: 0.085631
# Epoch 58/100 completed. Loss: 0.085622
# Epoch 59/100 completed. Loss: 0.085612
# Epoch 60/100 completed. Loss: 0.085601
# Epoch 61/100 completed. Loss: 0.085590
# Epoch 62/100 completed. Loss: 0.085579
# Epoch 63/100 completed. Loss: 0.085568
# Epoch 64/100 completed. Loss: 0.085556
# Epoch 65/100 completed. Loss: 0.085543
# Epoch 66/100 completed. Loss: 0.085530
# Epoch 67/100 completed. Loss: 0.085516
# Epoch 68/100 completed. Loss: 0.085502
# Epoch 69/100 completed. Loss: 0.085489
# Epoch 70/100 completed. Loss: 0.085477
# Epoch 71/100 completed. Loss: 0.085465
# Epoch 72/100 completed. Loss: 0.085455
# Epoch 73/100 completed. Loss: 0.085445
# Epoch 74/100 completed. Loss: 0.085437
# Epoch 75/100 completed. Loss: 0.085429
# Epoch 76/100 completed. Loss: 0.085422
# Epoch 77/100 completed. Loss: 0.085415
# Epoch 78/100 completed. Loss: 0.085409
# Epoch 79/100 completed. Loss: 0.085403
# Epoch 80/100 completed. Loss: 0.085397
# Epoch 81/100 completed. Loss: 0.085391
# Epoch 82/100 completed. Loss: 0.085384
# Epoch 83/100 completed. Loss: 0.085377
# Epoch 84/100 completed. Loss: 0.085368
# Epoch 85/100 completed. Loss: 0.085358
# Epoch 86/100 completed. Loss: 0.085347
# Epoch 87/100 completed. Loss: 0.085340
# Epoch 88/100 completed. Loss: 0.085335
# Epoch 89/100 completed. Loss: 0.085332
# Epoch 90/100 completed. Loss: 0.085335
# Epoch 91/100 completed. Loss: 0.085342
# Epoch 92/100 completed. Loss: 0.085347
# Epoch 93/100 completed. Loss: 0.085350
# Epoch 94/100 completed. Loss: 0.085351
# Epoch 95/100 completed. Loss: 0.085333
# Epoch 96/100 completed. Loss: 0.085312
# Epoch 97/100 completed. Loss: 0.085283
# Epoch 98/100 completed. Loss: 0.085249
# Epoch 99/100 completed. Loss: 0.085225
# Epoch 100/100 completed. Loss: 0.085208
# Training complete for run 59
# Run 59 -- RMSE: 24.086549, MSE: 580.161830, NMSE: 0.0026864537
#
# ===== RUN 60/60 =====
# Epoch 1/100 completed. Loss: 0.165070
# Epoch 2/100 completed. Loss: 0.089298
# Epoch 3/100 completed. Loss: 0.088917
# Epoch 4/100 completed. Loss: 0.088631
# Epoch 5/100 completed. Loss: 0.088411
# Epoch 6/100 completed. Loss: 0.088237
# Epoch 7/100 completed. Loss: 0.088097
# Epoch 8/100 completed. Loss: 0.087981
# Epoch 9/100 completed. Loss: 0.087881
# Epoch 10/100 completed. Loss: 0.087794
# Epoch 11/100 completed. Loss: 0.087717
# Epoch 12/100 completed. Loss: 0.087648
# Epoch 13/100 completed. Loss: 0.087586
# Epoch 14/100 completed. Loss: 0.087529
# Epoch 15/100 completed. Loss: 0.087477
# Epoch 16/100 completed. Loss: 0.087429
# Epoch 17/100 completed. Loss: 0.087385
# Epoch 18/100 completed. Loss: 0.087344
# Epoch 19/100 completed. Loss: 0.087306
# Epoch 20/100 completed. Loss: 0.087270
# Epoch 21/100 completed. Loss: 0.087238
# Epoch 22/100 completed. Loss: 0.087207
# Epoch 23/100 completed. Loss: 0.087179
# Epoch 24/100 completed. Loss: 0.087154
# Epoch 25/100 completed. Loss: 0.087129
# Epoch 26/100 completed. Loss: 0.087107
# Epoch 27/100 completed. Loss: 0.087086
# Epoch 28/100 completed. Loss: 0.087066
# Epoch 29/100 completed. Loss: 0.087047
# Epoch 30/100 completed. Loss: 0.087028
# Epoch 31/100 completed. Loss: 0.087010
# Epoch 32/100 completed. Loss: 0.086992
# Epoch 33/100 completed. Loss: 0.086975
# Epoch 34/100 completed. Loss: 0.086957
# Epoch 35/100 completed. Loss: 0.086940
# Epoch 36/100 completed. Loss: 0.086923
# Epoch 37/100 completed. Loss: 0.086906
# Epoch 38/100 completed. Loss: 0.086890
# Epoch 39/100 completed. Loss: 0.086874
# Epoch 40/100 completed. Loss: 0.086859
# Epoch 41/100 completed. Loss: 0.086845
# Epoch 42/100 completed. Loss: 0.086832
# Epoch 43/100 completed. Loss: 0.086820
# Epoch 44/100 completed. Loss: 0.086810
# Epoch 45/100 completed. Loss: 0.086802
# Epoch 46/100 completed. Loss: 0.086795
# Epoch 47/100 completed. Loss: 0.086788
# Epoch 48/100 completed. Loss: 0.086781
# Epoch 49/100 completed. Loss: 0.086773
# Epoch 50/100 completed. Loss: 0.086764
# Epoch 51/100 completed. Loss: 0.086754
# Epoch 52/100 completed. Loss: 0.086743
# Epoch 53/100 completed. Loss: 0.086733
# Epoch 54/100 completed. Loss: 0.086722
# Epoch 55/100 completed. Loss: 0.086711
# Epoch 56/100 completed. Loss: 0.086700
# Epoch 57/100 completed. Loss: 0.086688
# Epoch 58/100 completed. Loss: 0.086676
# Epoch 59/100 completed. Loss: 0.086662
# Epoch 60/100 completed. Loss: 0.086648
# Epoch 61/100 completed. Loss: 0.086632
# Epoch 62/100 completed. Loss: 0.086614
# Epoch 63/100 completed. Loss: 0.086595
# Epoch 64/100 completed. Loss: 0.086578
# Epoch 65/100 completed. Loss: 0.086551
# Epoch 66/100 completed. Loss: 0.086530
# Epoch 67/100 completed. Loss: 0.086495
# Epoch 68/100 completed. Loss: 0.086479
# Epoch 69/100 completed. Loss: 0.086451
# Epoch 70/100 completed. Loss: 0.086405
# Epoch 71/100 completed. Loss: 0.086381
# Epoch 72/100 completed. Loss: 0.086375
# Epoch 73/100 completed. Loss: 0.086351
# Epoch 74/100 completed. Loss: 0.086381
# Epoch 75/100 completed. Loss: 0.086361
# Epoch 76/100 completed. Loss: 0.086306
# Epoch 77/100 completed. Loss: 0.086468
# Epoch 78/100 completed. Loss: 0.086339
# Epoch 79/100 completed. Loss: 0.086380
# Epoch 80/100 completed. Loss: 0.086385
# Epoch 81/100 completed. Loss: 0.086383
# Epoch 82/100 completed. Loss: 0.086396
# Epoch 83/100 completed. Loss: 0.086400
# Epoch 84/100 completed. Loss: 0.086381
# Epoch 85/100 completed. Loss: 0.086380
# Epoch 86/100 completed. Loss: 0.086381
# Epoch 87/100 completed. Loss: 0.086392
# Epoch 88/100 completed. Loss: 0.086349
# Epoch 89/100 completed. Loss: 0.086339
# Epoch 90/100 completed. Loss: 0.086325
# Epoch 91/100 completed. Loss: 0.086277
# Epoch 92/100 completed. Loss: 0.086277
# Epoch 93/100 completed. Loss: 0.086221
# Epoch 94/100 completed. Loss: 0.086210
# Epoch 95/100 completed. Loss: 0.086167
# Epoch 96/100 completed. Loss: 0.086146
# Epoch 97/100 completed. Loss: 0.086102
# Epoch 98/100 completed. Loss: 0.086076
# Epoch 99/100 completed. Loss: 0.086046
# Epoch 100/100 completed. Loss: 0.086014
# Training complete for run 60
# Run 60 -- RMSE: 24.602223, MSE: 605.269373, NMSE: 0.0028027148
#
# --- Training Summary (60 runs) ---
# RMSE: 24.380609 ± 0.172296
# MSE:  594.443804 ± 8.398140
# NMSE: 0.0027525867 ± 0.0000388878

# %% [markdown]
# ## Gaussian Noise-Robustness Sweep (0.5% / 5% / 10% / 15%)
#
# Same protocol as the SNN-Transformer / LSTM-SNP noise-robustness notebooks:
#
# `x_noisy(t) = x(t) + eps(t)`,  `eps(t) ~ N(0, sigma_eps^2)`,  `sigma_eps = eta * std(x)`
#
# Noise is injected into the **input features only** (never the targets), using the 60 models
# already trained for each sigma above (`sigma_results[sigma]['models']`) -- no retraining is
# needed. Each (sigma, noise level) combination is evaluated over multiple noise draws and
# reported as a mean +/- std over the 60 runs, exactly mirroring the clean-data summary.

# %%
# ============================================================
# Gaussian noise injection
# ============================================================
ref_std = X_train.std()
print(f"Reference std(x) used for noise scaling (train inputs): {ref_std:.6f}")

NOISE_LEVELS = [0.005, 0.05, 0.10, 0.15]  # 0.5%, 5%, 10%, 15%
N_NOISE_DRAWS = 10  # average over multiple eps(t) realizations per model, per level

def add_gaussian_noise(X, noise_level, ref_std, seed=None):
    """
    x_noisy(t) = x(t) + eps(t),  eps(t) ~ N(0, sigma_eps^2),  sigma_eps = noise_level * std(x)
    Applied to input features X only -- never to targets/labels.
    """
    rng = np.random.default_rng(seed)
    sigma_eps = noise_level * ref_std
    eps = rng.normal(loc=0.0, scale=sigma_eps, size=X.shape)
    return X + eps
# Out:
# Reference std(x) used for noise scaling (train inputs): 0.261378

# %%
# ============================================================
# Evaluation helper -- warms the recurrent state up on clean training data,
# then predicts on X_eval (clean or Gaussian-noise-corrupted, fuzzy-augmented
# test inputs, shape (N,1,2)). Test targets are always the clean,
# ground-truth values.
# ============================================================

def evaluate_on_test(model, X_eval, train, raw_values, scaler, device):
    model.eval()
    model.reset_states(1, device)

    with torch.no_grad():
        for i in range(len(X_train)):
            X_input = torch.tensor(X_train[i:i+1], dtype=torch.float32).to(device)
            model(X_input)

        predictions = []
        for i in range(len(X_eval)):
            X_input = torch.tensor(X_eval[i:i+1], dtype=torch.float32).to(device)
            yhat = model(X_input).item()

            x_val = X_eval[i, 0, 0]  # original (possibly noisy) scaled feature only
            new_row = np.array([x_val, yhat]).reshape(1, 2)
            inverted = scaler.inverse_transform(new_row)[0, -1]
            inverted = inverted + raw_values[len(train) + i]
            predictions.append(inverted)

    actual = raw_values[-len(X_eval):]
    mse = mean_squared_error(actual, predictions)
    rmse = sqrt(mse)
    meanV = np.mean(actual)
    denominator = np.linalg.norm(np.array(actual) - meanV, 2)
    nmse = mse / np.power(denominator, 2)
    return predictions, rmse, mse, nmse

# %% [markdown]
# ## Results

# %%
print(f'\n{"="*60}')
print(f'  NOISE SWEEP -- FUZZY FEATURE AUGMENTATION MODEL')
print(f'{"="*60}')

clean_rmse, clean_mse, clean_nmse = [], [], []
for model in all_models:
    _, rmse, mse, nmse = evaluate_on_test(model, X_test, train, raw_values, scaler, device)
    clean_rmse.append(rmse)
    clean_mse.append(mse)
    clean_nmse.append(nmse)

print(f"[{'no noise':>10}]  "
      f"RMSE: {np.mean(clean_rmse):.6f} +/- {np.std(clean_rmse):.6f}  |  "
      f"MSE: {np.mean(clean_mse):.6f} +/- {np.std(clean_mse):.6f}  |  "
      f"NMSE: {np.mean(clean_nmse):.10f} +/- {np.std(clean_nmse):.10f}")

noise_robustness = {}
for noise_level in NOISE_LEVELS:
    level_rmse, level_mse, level_nmse = [], [], []

    for run, model in enumerate(all_models):
        draw_rmse, draw_mse, draw_nmse = [], [], []
        for draw in range(N_NOISE_DRAWS):
            seed = hash((noise_level, run, draw)) % (2 ** 32)
            X_test_noisy = add_gaussian_noise(X_test, noise_level, ref_std, seed=seed)
            _, rmse, mse, nmse = evaluate_on_test(model, X_test_noisy, train, raw_values, scaler, device)
            draw_rmse.append(rmse)
            draw_mse.append(mse)
            draw_nmse.append(nmse)

        level_rmse.append(np.mean(draw_rmse))
        level_mse.append(np.mean(draw_mse))
        level_nmse.append(np.mean(draw_nmse))

    noise_robustness[noise_level] = {'rmse': level_rmse, 'mse': level_mse, 'nmse': level_nmse}
    print(f"[{noise_level * 100:5.1f}% noise]  "
          f"RMSE: {np.mean(level_rmse):.6f} +/- {np.std(level_rmse):.6f}  |  "
          f"MSE: {np.mean(level_mse):.6f} +/- {np.std(level_mse):.6f}  |  "
          f"NMSE: {np.mean(level_nmse):.10f} +/- {np.std(level_nmse):.10f}")
# Out:
# ============================================================
#   NOISE SWEEP -- FUZZY FEATURE AUGMENTATION MODEL
# ============================================================
# [  no noise]  RMSE: 24.380609 +/- 0.172296  |  MSE: 594.443804 +/- 8.398140  |  NMSE: 0.0027525867 +/- 0.0000388878
# [  0.5% noise]  RMSE: 24.380775 +/- 0.172311  |  MSE: 594.451902 +/- 8.399019  |  NMSE: 0.0027526242 +/- 0.0000388919
# [  5.0% noise]  RMSE: 24.380981 +/- 0.173329  |  MSE: 594.462876 +/- 8.449728  |  NMSE: 0.0027526751 +/- 0.0000391267
# [ 10.0% noise]  RMSE: 24.381569 +/- 0.170835  |  MSE: 594.492478 +/- 8.327740  |  NMSE: 0.0027528121 +/- 0.0000385618
# [ 15.0% noise]  RMSE: 24.384092 +/- 0.168934  |  MSE: 594.618226 +/- 8.235778  |  NMSE: 0.0027533944 +/- 0.0000381360

# %%
print('===== ROBUSTNESS SUMMARY (60 runs per condition, averaged over 10 noise draws) =====')
print(f"{'Condition':<12}{'RMSE':>14}{'MSE':>16}{'NMSE':>16}")
print(f"{'Clean':<12}{np.mean(clean_rmse):>14.6f}{np.mean(clean_mse):>16.6f}{np.mean(clean_nmse):>16.10f}")
for noise_level in NOISE_LEVELS:
    r = noise_robustness[noise_level]
    label = f"{noise_level * 100:.1f}% noise"
    print(f"{label:<12}{np.mean(r['rmse']):>14.6f}{np.mean(r['mse']):>16.6f}{np.mean(r['nmse']):>16.10f}")

print('\n===== PAIRED DEGRADATION (per-model delta vs its own clean RMSE) =====')
for noise_level in NOISE_LEVELS:
    delta = np.array(noise_robustness[noise_level]['rmse']) - np.array(clean_rmse)
    t_stat, p_val = stats.ttest_rel(noise_robustness[noise_level]['rmse'], clean_rmse)
    print(f"{noise_level*100:5.1f}% noise — ΔRMSE: {delta.mean():.6f} ± {delta.std():.6f}  "
          f"(paired t-test p={p_val:.4f})")

# %% [markdown]
# ## Observations
#
# ### Gaussian Noise robustness on Dow Jones Industrial Index
#
# **Run the notebook to populate results.**
