# %% [markdown]
# # Notebook 5: Hybrid LSTM-SNP (Fuzzy Feature Aug + Fuzzy Gates)
#
# **Dataset**: Dow Jones Industrial Index
#
# ## Description
# This notebook implements the **hybrid model** that combines:
# 1. **Fuzzy Feature Augmentation** (from Notebook 2): Input is augmented with fuzzy-derived features
# 2. **Fuzzy Gate Replacement** (from Notebook 3): Gates use fuzzy inference instead of sigmoid
#
# This represents the most complex integration of fuzzy logic with LSTM-SNP. Gradient clipping
# (norm=1.0) and careful weight initialization are applied for training stability.
#
# The interaction between input-level and gate-level fuzzy reasoning is documented and analyzed.

# %% [markdown]
# ## Theory: Hybrid Fuzzy LSTM-SNP
#
# This model combines two fuzzy integration strategies:
#
# ### 1. Input-Level: Fuzzy Feature Augmentation
# Same as Notebook 2:
# - Fuzzy inference on $x(t)$ and $x(t-1)$
# - Augmented input: $x'(t) = [x(t), y_{fuzzy}]$
# - Input dimension becomes 2
#
# ### 2. Gate-Level: Fuzzy Gate Replacement
# Same as Notebook 3:
# - Gates r, c, o computed via fuzzy inference
# - Fixed Gaussian MFs, trainable consequent parameters
# - Generation gate a retains tanh
#
# ### Interaction Between Levels
# - The fuzzy-augmented input provides richer information to the cell
# - The fuzzy gates process this enriched input with adaptive, rule-based gating
# - This creates a two-level fuzzy reasoning pipeline
#
# ### Stability Measures
# - Gradient clipping (norm ≤ 1.0)
# - Careful weight initialization
# - Fuzzy weights are clipped to valid ranges

# %% [markdown]
# ## Model Architecture & Implementation

# %%
# ============================================================
# ALL IMPORTS
# ============================================================

import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras import layers
from tensorflow.keras import Model
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from math import sqrt
import matplotlib.pyplot as plt

print(f"TensorFlow version: {tf.__version__}")
print(f"NumPy version: {np.__version__}")
# Out:
# TensorFlow version: 2.20.0
# NumPy version: 2.0.2

# %% [markdown]
# ### Fuzzy Inference System (NumPy — for preprocessing)

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

# ============================================================
# Fuzzy Inference System (NumPy — for preprocessing)
#
# Fixed Gaussian membership functions:
#   μ_low(x)  = exp(-(x - (-1))² / (2·0.5²))
#   μ_high(x) = exp(-(x - (+1))² / (2·0.5²))
#
# 4 Takagi-Sugeno rules with fixed consequent parameters:
#   IF x(t) is low  AND x(t-1) is low  → y₁ = 0.5·x(t) + 0.5·x(t-1)
#   IF x(t) is low  AND x(t-1) is high → y₂ = 0.7·x(t) + 0.3·x(t-1) - 0.1
#   IF x(t) is high AND x(t-1) is low  → y₃ = 0.3·x(t) + 0.7·x(t-1) + 0.1
#   IF x(t) is high AND x(t-1) is high → y₄ = 0.5·x(t) + 0.5·x(t-1)
#
# Output: y = Σ(wᵢ·yᵢ) / Σ(wᵢ)
# ============================================================

def gaussian_mf(x, center, sigma=0.5):
    """Fixed Gaussian membership function."""
    return np.exp(-(x - center)**2 / (2 * sigma**2))

def fuzzy_inference_numpy(x_t, x_tm1):
    """
    Compute fuzzy feature from x(t) and x(t-1).
    Uses fixed membership functions and fixed consequent parameters.
    """
    # Membership degrees
    mu_low_xt = gaussian_mf(x_t, center=-1.0)
    mu_high_xt = gaussian_mf(x_t, center=1.0)
    mu_low_xtm1 = gaussian_mf(x_tm1, center=-1.0)
    mu_high_xtm1 = gaussian_mf(x_tm1, center=1.0)

    # Rule firing strengths (product)
    w1 = mu_low_xt * mu_low_xtm1      # low-low
    w2 = mu_low_xt * mu_high_xtm1     # low-high
    w3 = mu_high_xt * mu_low_xtm1     # high-low
    w4 = mu_high_xt * mu_high_xtm1    # high-high

    # Consequent outputs (fixed linear functions)
    y1 = 0.5 * x_t + 0.5 * x_tm1
    y2 = 0.7 * x_t + 0.3 * x_tm1 - 0.1
    y3 = 0.3 * x_t + 0.7 * x_tm1 + 0.1
    y4 = 0.5 * x_t + 0.5 * x_tm1

    # Weighted average defuzzification
    numerator = w1 * y1 + w2 * y2 + w3 * y3 + w4 * y4
    denominator = w1 + w2 + w3 + w4 + 1e-8

    return numerator / denominator

# %% [markdown]
# ### Fuzzy Gate LSTM-SNP Cell

# %%
# ============================================================
# Fuzzy Gate LSTM-SNP Cell (PyTorch Implementation)
# Gates r, c, o use fuzzy inference instead of hard sigmoid.
# Generation gate 'a' keeps tanh (unchanged).
# ============================================================
import torch
import torch.nn as nn
import torch.nn.functional as F

class FuzzyGateType5(nn.Module):
    def __init__(self, hidden_size, sigma=0.5):
        super().__init__()
        self.hidden_size = hidden_size
        self.sigma = sigma
        self.mu_low = -1.0
        self.mu_high = 1.0
        
        # Rule 0 (Low)
        self.a0 = nn.Parameter(torch.empty(hidden_size).uniform_(-0.1, 0.1))
        self.b0 = nn.Parameter(torch.empty(hidden_size).uniform_(-0.1, 0.1))
        self.c0 = nn.Parameter(torch.zeros(hidden_size))
        
        # Rule 1 (High)
        self.a1 = nn.Parameter(torch.empty(hidden_size).uniform_(-0.1, 0.1))
        self.b1 = nn.Parameter(torch.empty(hidden_size).uniform_(-0.1, 0.1))
        self.c1 = nn.Parameter(torch.zeros(hidden_size))

    def _gaussian_mf(self, x, center):
        return torch.exp(-(x - center)**2 / (2.0 * self.sigma**2))

    def forward(self, z_gate, u_mean):
        w_low = self._gaussian_mf(z_gate, self.mu_low)
        w_high = self._gaussian_mf(z_gate, self.mu_high)
        
        y0 = self.a0 * z_gate + self.b0 * u_mean + self.c0
        y1 = self.a1 * z_gate + self.b1 * u_mean + self.c1
        
        numerator = w_low * y0 + w_high * y1
        denominator = w_low + w_high + 1e-8
        output = numerator / denominator
        return torch.clamp(output, 0.0, 1.0)


class FuzzyLSTMSNPCell(nn.Module):
    """
    LSTM-SNP Cell with fuzzy gate replacement.
    Gates r, c, o are computed via fuzzy inference.
    Gate a keeps tanh activation.
    """
    def __init__(self, input_size, hidden_size):
        super().__init__()
        self.input_size = input_size
        self.hidden_size = hidden_size
        
        self.W = nn.Linear(input_size, 4 * hidden_size, bias=True)
        self.U = nn.Linear(hidden_size, 4 * hidden_size, bias=True)
        
        nn.init.xavier_uniform_(self.W.weight)
        nn.init.orthogonal_(self.U.weight)
        nn.init.zeros_(self.W.bias)
        nn.init.zeros_(self.U.bias)
        
        self.fuzzy_r = FuzzyGateType5(hidden_size)
        self.fuzzy_c = FuzzyGateType5(hidden_size)
        self.fuzzy_o = FuzzyGateType5(hidden_size)

    def forward(self, x, u_prev):
        z = self.W(x) + self.U(u_prev)
        
        z0 = z[:, :self.hidden_size]
        z1 = z[:, self.hidden_size:2*self.hidden_size]
        z2 = z[:, 2*self.hidden_size:3*self.hidden_size]
        z3 = z[:, 3*self.hidden_size:]
        
        # Mean of previous state for fuzzy rule input
        u_mean = u_prev.mean(dim=-1, keepdim=True).expand_as(u_prev)
        
        r = self.fuzzy_r(z0, u_mean)
        c = self.fuzzy_c(z1, u_mean)
        o = self.fuzzy_o(z2, u_mean)
        a = torch.tanh(z3)
        
        u = r * u_prev - c * a
        h = o * a
        
        return h, u

# %% [markdown]
# ### Build Model

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

# ============================================================
# Model Construction (PyTorch)
# ============================================================

class RNNModel(nn.Module):
    def __init__(self, input_size, hidden_size):
        super().__init__()
        self.hidden_size = hidden_size
        
        # Select cell
        if 5 in [1, 2, 4]:
            self.cell = LSTMSNPCell(input_size, hidden_size)
        else:
            self.cell = FuzzyLSTMSNPCell(input_size, hidden_size)
            
        # Select output layer
        if 5 == 4:
            self.out = FuzzyOutputLayer(hidden_size)
        else:
            self.out = nn.Linear(hidden_size, 1)
            
        self.u = None
        
    def reset_states(self, batch_size, device):
        self.u = torch.zeros(batch_size, self.hidden_size, device=device)
        
    def forward(self, x):
        # x is (batch, 1, input_size)
        if self.u is None or self.u.device != x.device:
            self.reset_states(x.size(0), x.device)
            
        h, self.u = self.cell(x[:, 0, :], self.u)
        return self.out(h)
        
def build_model(input_dim, units):
    return RNNModel(input_dim, units)

# %%
# Quick model check
model = build_model(input_dim=2, units=8)
print(model)
# Out:
# RNNModel(
#   (cell): FuzzyLSTMSNPCell(
#     (W): Linear(in_features=2, out_features=32, bias=True)
#     (U): Linear(in_features=8, out_features=32, bias=True)
#     (fuzzy_r): FuzzyGateType5()
#     (fuzzy_c): FuzzyGateType5()
#     (fuzzy_o): FuzzyGateType5()
#   )
#   (out): Linear(in_features=8, out_features=1, bias=True)
# )

# %% [markdown]
# ## Data Pipeline — Dow Jones Industrial Index

# %%
import os
for f in os.listdir('/kaggle/input/datasets/satabartosarkar123/monthly-closings-of-the-dowjones-csv'):
    print(f)
# Out:
# monthly-closings-of-the-dowjones.csv

# %%
# ============================================================
# 1. Load Time Series Data
# ============================================================
series = pd.read_csv(
    '/kaggle/input/datasets/satabartosarkar123/monthly-closings-of-the-dowjones-csv/monthly-closings-of-the-dowjones.csv',
    header=0,
    parse_dates=[0],
    index_col=0
)

original_raw_values = series.values.flatten()
print(f"Base data shape: {original_raw_values.shape}")
print(f"First 5 values: {original_raw_values[:5]}")
# Out:
# Base data shape: (291,)
# First 5 values: [3645.  3626.  3634.  3620.5 3607. ]

# %%
# ============================================================
# 2. First-Order Differencing
# ============================================================

def difference(dataset, interval=1):
    diff = []
    for i in range(interval, len(dataset)):
        value = dataset[i] - dataset[i - interval]
        diff.append(value)
    return np.array(diff)

# %%
# ============================================================
# 3. Convert to Supervised Learning Format (lag=1)
# ============================================================

def timeseries_to_supervised(data, lag=1):
    df = pd.DataFrame(data)
    columns = [df.shift(i) for i in range(1, lag+1)]
    columns.append(df)
    df = pd.concat(columns, axis=1)
    df.fillna(0, inplace=True)
    return df.values

# %%
# ============================================================
# 4-5-6. Split / Scale / Reshape (inside noise loop below)
# ============================================================
# - Last 60 for test, rest for training, NO validation
# - MinMaxScaler(-1, 1)
# - Fuzzy augmentation: fuzzy_inference_numpy(x_t, x_tm1) -> input_dim=2
print("Split: last 60 for test, rest for training, no validation")
print("Fuzzy augmentation: input_dim=2")
# Out:
# Split: last 60 for test, rest for training, no validation
# Fuzzy augmentation: input_dim=2

# %% [markdown]
# ## Training Loop

# %%
# ============================================================
# Gaussian Noise Evaluation + 60-Run Experiment Protocol (PyTorch)
# ============================================================
import torch
import torch.nn as nn

s_x = np.std(original_raw_values)
noise_levels = [0.0, 0.005, 0.05, 0.10]
_molab_results = []

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"\n--- [PyTorch] RUNNING ON {device} ---\n")

for lam in noise_levels:
    sigma = lam * s_x
    print("\n" + "="*80)
    print(f"EVALUATING NOISE LEVEL: {lam*100:.1f}% (lambda={lam}, sigma={sigma:.6f})")
    print("="*80 + "\n")
    
    np.random.seed(42)
    torch.manual_seed(42)
    noise = np.random.normal(0, sigma, size=original_raw_values.shape)
    raw_values = original_raw_values + noise
    
    # 2. Difference
    diff_values = difference(raw_values, 1)
    # 3. Supervised (lag=1)
    supervised = timeseries_to_supervised(diff_values, 1)
    # 4. Split (Last 60 for test, NO validation)
    train, test = supervised[:-60], supervised[-60:]
    # 5. Scale
    scaler = MinMaxScaler(feature_range=(-1, 1))
    scaler.fit(train)
    train_scaled = scaler.transform(train)
    test_scaled = scaler.transform(test)
    
    # 6. Reshape with Fuzzy Feature Augmentation (input_dim=2)
    X_train_raw = train_scaled[:, 0:1]
    y_train = train_scaled[:, 1]
    
    X_train_fuzzy = np.zeros((X_train_raw.shape[0], 2))
    for i in range(X_train_raw.shape[0]):
        x_t = X_train_raw[i, 0]
        x_tm1 = X_train_raw[i-1, 0] if i > 0 else x_t
        y_fuzz = fuzzy_inference_numpy(x_t, x_tm1)
        X_train_fuzzy[i, 0] = x_t
        X_train_fuzzy[i, 1] = y_fuzz
    
    X_train = X_train_fuzzy.reshape((X_train_fuzzy.shape[0], 1, 2))
    
    print(f"X_train shape: {X_train.shape}, y_train shape: {y_train.shape}")
    
    all_rmse = []
    all_mse = []
    all_nmse = []
    all_predictions = []
    all_losses = []
    
    for run in range(60):
        print(f'\n===== RUN {run+1}/60 [Noise {lam*100:.1f}%] =====')
        
        np.random.seed(run)
        torch.manual_seed(run)
        
        model = build_model(input_dim=2, units=8).to(device)
        optimizer = torch.optim.Adam(model.parameters(), lr=0.001)
        criterion = nn.MSELoss()
        
        # Pre-tensorize training data
        X_train_t = torch.tensor(X_train, dtype=torch.float32).to(device)
        y_train_t = torch.tensor(y_train, dtype=torch.float32).to(device)
        n_samples = X_train_t.size(0)
        
        run_losses = []
        for epoch in range(100):
            model.train()
            model.reset_states(1, device)
            
            epoch_loss = 0.0
            for i in range(n_samples):
                x_i = X_train_t[i:i+1]
                y_i = y_train_t[i:i+1]
                
                optimizer.zero_grad()
                pred = model(x_i)
                loss = criterion(pred.squeeze(-1), y_i)
                loss.backward()
                torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)
                optimizer.step()
                model.u = model.u.detach()
                epoch_loss += loss.item()
            
            avg_loss = epoch_loss / n_samples
            run_losses.append(avg_loss)
            if (epoch+1) % 10 == 0:
                print(f"  Epoch {epoch+1}/100, Loss: {avg_loss:.6f}")
        
        all_losses.append(run_losses)
        print(f'Training complete for run {run+1}')
        
        # Warm-up: condition hidden states on training data
        model.eval()
        with torch.no_grad():
            model.reset_states(1, device)
            prev_x = None
            for i in range(len(train_scaled)):
                x_t = train_scaled[i, 0]
                x_tm1 = prev_x if prev_x is not None else x_t
                y_fuzz = fuzzy_inference_numpy(x_t, x_tm1)
                X_aug = torch.tensor([x_t, y_fuzz], dtype=torch.float32).view(1, 1, 2).to(device)
                model(X_aug)
                prev_x = x_t
        
        # Test predictions (single-step) with fuzzy feature augmentation
        predictions = []
        model.eval()
        with torch.no_grad():
            x_tm1 = train_scaled[-1, 0]  # last training value
            for i in range(len(test_scaled)):
                x_t = test_scaled[i, 0]
                y_fuzz = fuzzy_inference_numpy(x_t, x_tm1)
                X_aug = torch.tensor([x_t, y_fuzz], dtype=torch.float32).view(1, 1, 2).to(device)
                yhat = model(X_aug).item()
                
                # Invert scaling
                X_raw = test_scaled[i, 0:-1]
                new_row = list(X_raw) + [yhat]
                array = np.array(new_row).reshape(1, len(new_row))
                inverted = scaler.inverse_transform(array)[0, -1]
                
                # Invert differencing
                inverted = inverted + raw_values[len(train) + i]
                predictions.append(inverted)
                
                x_tm1 = x_t  # update for next step
        
        # Compute metrics
        actual = raw_values[-len(predictions):]
        rmse = sqrt(mean_squared_error(actual, predictions))
        mse = mean_squared_error(actual, predictions)
        meanV = np.mean(actual)
        dominator = np.linalg.norm(np.array(predictions) - meanV, 2)
        nmse = mse / np.power(dominator, 2)
        
        all_rmse.append(rmse)
        all_mse.append(mse)
        all_nmse.append(nmse)
        all_predictions.append(predictions)
        
        print(f'Run {run+1} — RMSE: {rmse:.6f}, MSE: {mse:.6f}, NMSE: {nmse:.10f}')
    
    # End of 60 runs for this noise level
    best_idx = np.argmin(all_rmse)
    
    print(f'\n===== STATS FOR NOISE {lam*100:.1f}% (60 runs) =====')
    print(f'RMSE: {np.mean(all_rmse):.6f} +/- {np.std(all_rmse):.6f}')
    print(f'MSE:  {np.mean(all_mse):.6f} +/- {np.std(all_mse):.6f}')
    print(f'NMSE: {np.mean(all_nmse):.10f} +/- {np.std(all_nmse):.10f}')
    print(f'Best run: {best_idx+1} (RMSE: {all_rmse[best_idx]:.6f})')
    
    _molab_results.append([lam, 
        np.mean(all_rmse), np.std(all_rmse),
        np.mean(all_mse), np.std(all_mse),
        np.mean(all_nmse), np.std(all_nmse),
        all_rmse[best_idx], all_predictions[best_idx], all_losses[best_idx], raw_values.copy()])
# Out:
# --- [PyTorch] RUNNING ON cuda ---
#
#
# ================================================================================
# EVALUATING NOISE LEVEL: 0.0% (lambda=0.0, sigma=0.000000)
# ================================================================================
#
# X_train shape: (230, 1, 2), y_train shape: (230,)
#
# ===== RUN 1/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.085449
#   Epoch 20/100, Loss: 0.085472
#   Epoch 30/100, Loss: 0.085514
#   Epoch 40/100, Loss: 0.085521
#   Epoch 50/100, Loss: 0.085500
#   Epoch 60/100, Loss: 0.085460
#   Epoch 70/100, Loss: 0.085397
#   Epoch 80/100, Loss: 0.085269
#   Epoch 90/100, Loss: 0.085061
#   Epoch 100/100, Loss: 0.084796
# Training complete for run 1
# Run 1 — RMSE: 24.249239, MSE: 588.025593, NMSE: 0.0026846370
#
# ===== RUN 2/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.086287
#   Epoch 20/100, Loss: 0.086590
#   Epoch 30/100, Loss: 0.086762
#   Epoch 40/100, Loss: 0.086766
#   Epoch 50/100, Loss: 0.086735
#   Epoch 60/100, Loss: 0.086691
#   Epoch 70/100, Loss: 0.086628
#   Epoch 80/100, Loss: 0.086516
#   Epoch 90/100, Loss: 0.086363
#   Epoch 100/100, Loss: 0.086196
# Training complete for run 2
# Run 2 — RMSE: 24.288864, MSE: 589.948927, NMSE: 0.0027127159
#
# ===== RUN 3/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.085327
#   Epoch 20/100, Loss: 0.085222
#   Epoch 30/100, Loss: 0.084709
#   Epoch 40/100, Loss: 0.084150
#   Epoch 50/100, Loss: 0.083939
#   Epoch 60/100, Loss: 0.083870
#   Epoch 70/100, Loss: 0.083810
#   Epoch 80/100, Loss: 0.083781
#   Epoch 90/100, Loss: 0.083767
#   Epoch 100/100, Loss: 0.083722
# Training complete for run 3
# Run 3 — RMSE: 24.425522, MSE: 596.606121, NMSE: 0.0027453434
#
# ===== RUN 4/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.085548
#   Epoch 20/100, Loss: 0.085548
#   Epoch 30/100, Loss: 0.085533
#   Epoch 40/100, Loss: 0.085469
#   Epoch 50/100, Loss: 0.085342
#   Epoch 60/100, Loss: 0.085179
#   Epoch 70/100, Loss: 0.084987
#   Epoch 80/100, Loss: 0.084779
#   Epoch 90/100, Loss: 0.084529
#   Epoch 100/100, Loss: 0.084353
# Training complete for run 4
# Run 4 — RMSE: 24.152639, MSE: 583.349990, NMSE: 0.0026685759
#
# ===== RUN 5/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.085355
#   Epoch 20/100, Loss: 0.085134
#   Epoch 30/100, Loss: 0.084870
#   Epoch 40/100, Loss: 0.084686
#   Epoch 50/100, Loss: 0.084539
#   Epoch 60/100, Loss: 0.084404
#   Epoch 70/100, Loss: 0.084330
#   Epoch 80/100, Loss: 0.084268
#   Epoch 90/100, Loss: 0.084220
#   Epoch 100/100, Loss: 0.084176
# Training complete for run 5
# Run 5 — RMSE: 24.399626, MSE: 595.341773, NMSE: 0.0027353837
#
# ===== RUN 6/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.086028
#   Epoch 20/100, Loss: 0.086150
#   Epoch 30/100, Loss: 0.086355
#   Epoch 40/100, Loss: 0.086418
#   Epoch 50/100, Loss: 0.086426
#   Epoch 60/100, Loss: 0.086415
#   Epoch 70/100, Loss: 0.086397
#   Epoch 80/100, Loss: 0.086375
#   Epoch 90/100, Loss: 0.086342
#   Epoch 100/100, Loss: 0.086273
# Training complete for run 6
# Run 6 — RMSE: 24.387683, MSE: 594.759104, NMSE: 0.0027307298
#
# ===== RUN 7/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.085223
#   Epoch 20/100, Loss: 0.085202
#   Epoch 30/100, Loss: 0.085190
#   Epoch 40/100, Loss: 0.085178
#   Epoch 50/100, Loss: 0.085164
#   Epoch 60/100, Loss: 0.085091
#   Epoch 70/100, Loss: 0.084975
#   Epoch 80/100, Loss: 0.084803
#   Epoch 90/100, Loss: 0.084597
#   Epoch 100/100, Loss: 0.084361
# Training complete for run 7
# Run 7 — RMSE: 24.236091, MSE: 587.388090, NMSE: 0.0026957041
#
# ===== RUN 8/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.086170
#   Epoch 20/100, Loss: 0.086241
#   Epoch 30/100, Loss: 0.086064
#   Epoch 40/100, Loss: 0.085910
#   Epoch 50/100, Loss: 0.085816
#   Epoch 60/100, Loss: 0.085765
#   Epoch 70/100, Loss: 0.085692
#   Epoch 80/100, Loss: 0.085623
#   Epoch 90/100, Loss: 0.085554
#   Epoch 100/100, Loss: 0.085490
# Training complete for run 8
# Run 8 — RMSE: 24.345150, MSE: 592.686321, NMSE: 0.0027061376
#
# ===== RUN 9/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.085810
#   Epoch 20/100, Loss: 0.085852
#   Epoch 30/100, Loss: 0.085713
#   Epoch 40/100, Loss: 0.085482
#   Epoch 50/100, Loss: 0.085236
#   Epoch 60/100, Loss: 0.085036
#   Epoch 70/100, Loss: 0.084903
#   Epoch 80/100, Loss: 0.084794
#   Epoch 90/100, Loss: 0.084690
#   Epoch 100/100, Loss: 0.084615
# Training complete for run 9
# Run 9 — RMSE: 24.164539, MSE: 583.924957, NMSE: 0.0026816870
#
# ===== RUN 10/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.086327
#   Epoch 20/100, Loss: 0.086599
#   Epoch 30/100, Loss: 0.086641
#   Epoch 40/100, Loss: 0.086532
#   Epoch 50/100, Loss: 0.086346
#   Epoch 60/100, Loss: 0.086112
#   Epoch 70/100, Loss: 0.085847
#   Epoch 80/100, Loss: 0.085585
#   Epoch 90/100, Loss: 0.085356
#   Epoch 100/100, Loss: 0.085140
# Training complete for run 10
# Run 10 — RMSE: 24.283839, MSE: 589.704855, NMSE: 0.0027127689
#
# ===== RUN 11/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.085686
#   Epoch 20/100, Loss: 0.085488
#   Epoch 30/100, Loss: 0.085354
#   Epoch 40/100, Loss: 0.085181
#   Epoch 50/100, Loss: 0.084974
#   Epoch 60/100, Loss: 0.084736
#   Epoch 70/100, Loss: 0.084515
#   Epoch 80/100, Loss: 0.084224
#   Epoch 90/100, Loss: 0.084014
#   Epoch 100/100, Loss: 0.083851
# Training complete for run 11
# Run 11 — RMSE: 24.119753, MSE: 581.762490, NMSE: 0.0026730027
#
# ===== RUN 12/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.086650
#   Epoch 20/100, Loss: 0.086659
#   Epoch 30/100, Loss: 0.086425
#   Epoch 40/100, Loss: 0.086224
#   Epoch 50/100, Loss: 0.086023
#   Epoch 60/100, Loss: 0.085815
#   Epoch 70/100, Loss: 0.085626
#   Epoch 80/100, Loss: 0.085454
#   Epoch 90/100, Loss: 0.085291
#   Epoch 100/100, Loss: 0.085145
# Training complete for run 12
# Run 12 — RMSE: 24.286223, MSE: 589.820649, NMSE: 0.0027102052
#
# ===== RUN 13/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.086022
#   Epoch 20/100, Loss: 0.086217
#   Epoch 30/100, Loss: 0.086145
#   Epoch 40/100, Loss: 0.085959
#   Epoch 50/100, Loss: 0.085710
#   Epoch 60/100, Loss: 0.085438
#   Epoch 70/100, Loss: 0.085167
#   Epoch 80/100, Loss: 0.084871
#   Epoch 90/100, Loss: 0.084601
#   Epoch 100/100, Loss: 0.084364
# Training complete for run 13
# Run 13 — RMSE: 24.201973, MSE: 585.735516, NMSE: 0.0026841467
#
# ===== RUN 14/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.086773
#   Epoch 20/100, Loss: 0.086879
#   Epoch 30/100, Loss: 0.086700
#   Epoch 40/100, Loss: 0.086485
#   Epoch 50/100, Loss: 0.086253
#   Epoch 60/100, Loss: 0.085987
#   Epoch 70/100, Loss: 0.085719
#   Epoch 80/100, Loss: 0.085504
#   Epoch 90/100, Loss: 0.085313
#   Epoch 100/100, Loss: 0.085174
# Training complete for run 14
# Run 14 — RMSE: 24.355358, MSE: 593.183479, NMSE: 0.0027189850
#
# ===== RUN 15/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.085321
#   Epoch 20/100, Loss: 0.085319
#   Epoch 30/100, Loss: 0.085299
#   Epoch 40/100, Loss: 0.085150
#   Epoch 50/100, Loss: 0.084935
#   Epoch 60/100, Loss: 0.084747
#   Epoch 70/100, Loss: 0.084573
#   Epoch 80/100, Loss: 0.084439
#   Epoch 90/100, Loss: 0.084313
#   Epoch 100/100, Loss: 0.084255
# Training complete for run 15
# Run 15 — RMSE: 24.214363, MSE: 586.335393, NMSE: 0.0026955019
#
# ===== RUN 16/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.086604
#   Epoch 20/100, Loss: 0.086854
#   Epoch 30/100, Loss: 0.086806
#   Epoch 40/100, Loss: 0.086723
#   Epoch 50/100, Loss: 0.086609
#   Epoch 60/100, Loss: 0.086439
#   Epoch 70/100, Loss: 0.086288
#   Epoch 80/100, Loss: 0.086137
#   Epoch 90/100, Loss: 0.085971
#   Epoch 100/100, Loss: 0.085803
# Training complete for run 16
# Run 16 — RMSE: 24.288602, MSE: 589.936177, NMSE: 0.0027074415
#
# ===== RUN 17/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.086006
#   Epoch 20/100, Loss: 0.086272
#   Epoch 30/100, Loss: 0.086380
#   Epoch 40/100, Loss: 0.086384
#   Epoch 50/100, Loss: 0.086365
#   Epoch 60/100, Loss: 0.086338
#   Epoch 70/100, Loss: 0.086306
#   Epoch 80/100, Loss: 0.086262
#   Epoch 90/100, Loss: 0.086206
#   Epoch 100/100, Loss: 0.086132
# Training complete for run 17
# Run 17 — RMSE: 24.455783, MSE: 598.085341, NMSE: 0.0027460232
#
# ===== RUN 18/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.086136
#   Epoch 20/100, Loss: 0.086290
#   Epoch 30/100, Loss: 0.086127
#   Epoch 40/100, Loss: 0.085894
#   Epoch 50/100, Loss: 0.085634
#   Epoch 60/100, Loss: 0.085348
#   Epoch 70/100, Loss: 0.085079
#   Epoch 80/100, Loss: 0.084848
#   Epoch 90/100, Loss: 0.084609
#   Epoch 100/100, Loss: 0.084403
# Training complete for run 18
# Run 18 — RMSE: 24.150617, MSE: 583.252288, NMSE: 0.0026752823
#
# ===== RUN 19/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.085841
#   Epoch 20/100, Loss: 0.086053
#   Epoch 30/100, Loss: 0.086157
#   Epoch 40/100, Loss: 0.086173
#   Epoch 50/100, Loss: 0.086157
#   Epoch 60/100, Loss: 0.086134
#   Epoch 70/100, Loss: 0.086108
#   Epoch 80/100, Loss: 0.086077
#   Epoch 90/100, Loss: 0.086039
#   Epoch 100/100, Loss: 0.085989
# Training complete for run 19
# Run 19 — RMSE: 24.415083, MSE: 596.096268, NMSE: 0.0027366909
#
# ===== RUN 20/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.085399
#   Epoch 20/100, Loss: 0.085307
#   Epoch 30/100, Loss: 0.085099
#   Epoch 40/100, Loss: 0.084862
#   Epoch 50/100, Loss: 0.084669
#   Epoch 60/100, Loss: 0.084523
#   Epoch 70/100, Loss: 0.084423
#   Epoch 80/100, Loss: 0.084363
#   Epoch 90/100, Loss: 0.084298
#   Epoch 100/100, Loss: 0.084198
# Training complete for run 20
# Run 20 — RMSE: 24.143514, MSE: 582.909266, NMSE: 0.0026684607
#
# ===== RUN 21/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.085388
#   Epoch 20/100, Loss: 0.085338
#   Epoch 30/100, Loss: 0.085247
#   Epoch 40/100, Loss: 0.085162
#   Epoch 50/100, Loss: 0.084984
#   Epoch 60/100, Loss: 0.084772
#   Epoch 70/100, Loss: 0.084571
#   Epoch 80/100, Loss: 0.084449
#   Epoch 90/100, Loss: 0.084312
#   Epoch 100/100, Loss: 0.084027
# Training complete for run 21
# Run 21 — RMSE: 24.191860, MSE: 585.246112, NMSE: 0.0026925944
#
# ===== RUN 22/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.086617
#   Epoch 20/100, Loss: 0.086901
#   Epoch 30/100, Loss: 0.086874
#   Epoch 40/100, Loss: 0.086820
#   Epoch 50/100, Loss: 0.086732
#   Epoch 60/100, Loss: 0.086588
#   Epoch 70/100, Loss: 0.086420
#   Epoch 80/100, Loss: 0.086223
#   Epoch 90/100, Loss: 0.086001
#   Epoch 100/100, Loss: 0.085774
# Training complete for run 22
# Run 22 — RMSE: 24.227437, MSE: 586.968718, NMSE: 0.0026955702
#
# ===== RUN 23/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.086649
#   Epoch 20/100, Loss: 0.086494
#   Epoch 30/100, Loss: 0.086176
#   Epoch 40/100, Loss: 0.085879
#   Epoch 50/100, Loss: 0.085637
#   Epoch 60/100, Loss: 0.085437
#   Epoch 70/100, Loss: 0.085263
#   Epoch 80/100, Loss: 0.085107
#   Epoch 90/100, Loss: 0.084960
#   Epoch 100/100, Loss: 0.084818
# Training complete for run 23
# Run 23 — RMSE: 24.134356, MSE: 582.467147, NMSE: 0.0026762790
#
# ===== RUN 24/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.086104
#   Epoch 20/100, Loss: 0.086056
#   Epoch 30/100, Loss: 0.085957
#   Epoch 40/100, Loss: 0.085695
#   Epoch 50/100, Loss: 0.085288
#   Epoch 60/100, Loss: 0.084859
#   Epoch 70/100, Loss: 0.084584
#   Epoch 80/100, Loss: 0.084379
#   Epoch 90/100, Loss: 0.084208
#   Epoch 100/100, Loss: 0.084077
# Training complete for run 24
# Run 24 — RMSE: 24.296895, MSE: 590.339093, NMSE: 0.0027164524
#
# ===== RUN 25/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.085265
#   Epoch 20/100, Loss: 0.085195
#   Epoch 30/100, Loss: 0.085111
#   Epoch 40/100, Loss: 0.085005
#   Epoch 50/100, Loss: 0.084877
#   Epoch 60/100, Loss: 0.084734
#   Epoch 70/100, Loss: 0.084591
#   Epoch 80/100, Loss: 0.084467
#   Epoch 90/100, Loss: 0.084372
#   Epoch 100/100, Loss: 0.084306
# Training complete for run 25
# Run 25 — RMSE: 24.134641, MSE: 582.480913, NMSE: 0.0026698889
#
# ===== RUN 26/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.086143
#   Epoch 20/100, Loss: 0.086354
#   Epoch 30/100, Loss: 0.086297
#   Epoch 40/100, Loss: 0.086213
#   Epoch 50/100, Loss: 0.086112
#   Epoch 60/100, Loss: 0.085993
#   Epoch 70/100, Loss: 0.085844
#   Epoch 80/100, Loss: 0.085663
#   Epoch 90/100, Loss: 0.085471
#   Epoch 100/100, Loss: 0.085289
# Training complete for run 26
# Run 26 — RMSE: 24.263667, MSE: 588.725558, NMSE: 0.0027073204
#
# ===== RUN 27/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.086675
#   Epoch 20/100, Loss: 0.086650
#   Epoch 30/100, Loss: 0.086395
#   Epoch 40/100, Loss: 0.086030
#   Epoch 50/100, Loss: 0.085715
#   Epoch 60/100, Loss: 0.085469
#   Epoch 70/100, Loss: 0.085275
#   Epoch 80/100, Loss: 0.085134
#   Epoch 90/100, Loss: 0.085005
#   Epoch 100/100, Loss: 0.084911
# Training complete for run 27
# Run 27 — RMSE: 24.232201, MSE: 587.199549, NMSE: 0.0027031865
#
# ===== RUN 28/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.085413
#   Epoch 20/100, Loss: 0.085285
#   Epoch 30/100, Loss: 0.084934
#   Epoch 40/100, Loss: 0.084470
#   Epoch 50/100, Loss: 0.084188
#   Epoch 60/100, Loss: 0.084060
#   Epoch 70/100, Loss: 0.083997
#   Epoch 80/100, Loss: 0.083963
#   Epoch 90/100, Loss: 0.083932
#   Epoch 100/100, Loss: 0.083906
# Training complete for run 28
# Run 28 — RMSE: 24.337064, MSE: 592.292671, NMSE: 0.0027234693
#
# ===== RUN 29/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.085270
#   Epoch 20/100, Loss: 0.085134
#   Epoch 30/100, Loss: 0.084878
#   Epoch 40/100, Loss: 0.084563
#   Epoch 50/100, Loss: 0.084308
#   Epoch 60/100, Loss: 0.084154
#   Epoch 70/100, Loss: 0.084073
#   Epoch 80/100, Loss: 0.084030
#   Epoch 90/100, Loss: 0.083996
#   Epoch 100/100, Loss: 0.083968
# Training complete for run 29
# Run 29 — RMSE: 24.393607, MSE: 595.048071, NMSE: 0.0027363048
#
# ===== RUN 30/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.085464
#   Epoch 20/100, Loss: 0.085228
#   Epoch 30/100, Loss: 0.085125
#   Epoch 40/100, Loss: 0.085054
#   Epoch 50/100, Loss: 0.084934
#   Epoch 60/100, Loss: 0.084782
#   Epoch 70/100, Loss: 0.084622
#   Epoch 80/100, Loss: 0.084451
#   Epoch 90/100, Loss: 0.084297
#   Epoch 100/100, Loss: 0.084171
# Training complete for run 30
# Run 30 — RMSE: 24.143617, MSE: 582.914221, NMSE: 0.0026717492
#
# ===== RUN 31/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.085245
#   Epoch 20/100, Loss: 0.085191
#   Epoch 30/100, Loss: 0.085032
#   Epoch 40/100, Loss: 0.084644
#   Epoch 50/100, Loss: 0.084259
#   Epoch 60/100, Loss: 0.083965
#   Epoch 70/100, Loss: 0.083849
#   Epoch 80/100, Loss: 0.083758
#   Epoch 90/100, Loss: 0.083683
#   Epoch 100/100, Loss: 0.083616
# Training complete for run 31
# Run 31 — RMSE: 24.257655, MSE: 588.433833, NMSE: 0.0026985066
#
# ===== RUN 32/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.086455
#   Epoch 20/100, Loss: 0.086409
#   Epoch 30/100, Loss: 0.086180
#   Epoch 40/100, Loss: 0.085939
#   Epoch 50/100, Loss: 0.085683
#   Epoch 60/100, Loss: 0.085425
#   Epoch 70/100, Loss: 0.085122
#   Epoch 80/100, Loss: 0.084844
#   Epoch 90/100, Loss: 0.084643
#   Epoch 100/100, Loss: 0.084450
# Training complete for run 32
# Run 32 — RMSE: 24.219947, MSE: 586.605825, NMSE: 0.0026946780
#
# ===== RUN 33/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.086204
#   Epoch 20/100, Loss: 0.086479
#   Epoch 30/100, Loss: 0.086375
#   Epoch 40/100, Loss: 0.086236
#   Epoch 50/100, Loss: 0.086061
#   Epoch 60/100, Loss: 0.085883
#   Epoch 70/100, Loss: 0.085756
#   Epoch 80/100, Loss: 0.085665
#   Epoch 90/100, Loss: 0.085573
#   Epoch 100/100, Loss: 0.085482
# Training complete for run 33
# Run 33 — RMSE: 24.241658, MSE: 587.658006, NMSE: 0.0026995616
#
# ===== RUN 34/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.086823
#   Epoch 20/100, Loss: 0.086871
#   Epoch 30/100, Loss: 0.086770
#   Epoch 40/100, Loss: 0.086688
#   Epoch 50/100, Loss: 0.086609
#   Epoch 60/100, Loss: 0.086524
#   Epoch 70/100, Loss: 0.086403
#   Epoch 80/100, Loss: 0.086189
#   Epoch 90/100, Loss: 0.085986
#   Epoch 100/100, Loss: 0.085714
# Training complete for run 34
# Run 34 — RMSE: 24.361072, MSE: 593.461820, NMSE: 0.0027111879
#
# ===== RUN 35/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.086340
#   Epoch 20/100, Loss: 0.086447
#   Epoch 30/100, Loss: 0.086700
#   Epoch 40/100, Loss: 0.086730
#   Epoch 50/100, Loss: 0.086661
#   Epoch 60/100, Loss: 0.086435
#   Epoch 70/100, Loss: 0.086214
#   Epoch 80/100, Loss: 0.085974
#   Epoch 90/100, Loss: 0.085728
#   Epoch 100/100, Loss: 0.085477
# Training complete for run 35
# Run 35 — RMSE: 24.296063, MSE: 590.298696, NMSE: 0.0027003535
#
# ===== RUN 36/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.086027
#   Epoch 20/100, Loss: 0.086200
#   Epoch 30/100, Loss: 0.086111
#   Epoch 40/100, Loss: 0.085973
#   Epoch 50/100, Loss: 0.085852
#   Epoch 60/100, Loss: 0.085677
#   Epoch 70/100, Loss: 0.085435
#   Epoch 80/100, Loss: 0.085255
#   Epoch 90/100, Loss: 0.085121
#   Epoch 100/100, Loss: 0.085008
# Training complete for run 36
# Run 36 — RMSE: 24.281361, MSE: 589.584504, NMSE: 0.0027068660
#
# ===== RUN 37/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.085251
#   Epoch 20/100, Loss: 0.085169
#   Epoch 30/100, Loss: 0.084853
#   Epoch 40/100, Loss: 0.084488
#   Epoch 50/100, Loss: 0.084294
#   Epoch 60/100, Loss: 0.084191
#   Epoch 70/100, Loss: 0.084154
#   Epoch 80/100, Loss: 0.084091
#   Epoch 90/100, Loss: 0.084038
#   Epoch 100/100, Loss: 0.084079
# Training complete for run 37
# Run 37 — RMSE: 24.054753, MSE: 578.631145, NMSE: 0.0026556802
#
# ===== RUN 38/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.085314
#   Epoch 20/100, Loss: 0.085264
#   Epoch 30/100, Loss: 0.085116
#   Epoch 40/100, Loss: 0.084978
#   Epoch 50/100, Loss: 0.084883
#   Epoch 60/100, Loss: 0.084818
#   Epoch 70/100, Loss: 0.084764
#   Epoch 80/100, Loss: 0.084733
#   Epoch 90/100, Loss: 0.084546
#   Epoch 100/100, Loss: 0.084358
# Training complete for run 38
# Run 38 — RMSE: 24.100243, MSE: 580.821733, NMSE: 0.0026688017
#
# ===== RUN 39/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.086078
#   Epoch 20/100, Loss: 0.086401
#   Epoch 30/100, Loss: 0.086488
#   Epoch 40/100, Loss: 0.086480
#   Epoch 50/100, Loss: 0.086453
#   Epoch 60/100, Loss: 0.086419
#   Epoch 70/100, Loss: 0.086378
#   Epoch 80/100, Loss: 0.086319
#   Epoch 90/100, Loss: 0.086244
#   Epoch 100/100, Loss: 0.086150
# Training complete for run 39
# Run 39 — RMSE: 24.447243, MSE: 597.667714, NMSE: 0.0027455217
#
# ===== RUN 40/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.085288
#   Epoch 20/100, Loss: 0.084917
#   Epoch 30/100, Loss: 0.084285
#   Epoch 40/100, Loss: 0.084007
#   Epoch 50/100, Loss: 0.083917
#   Epoch 60/100, Loss: 0.083881
#   Epoch 70/100, Loss: 0.083853
#   Epoch 80/100, Loss: 0.083840
#   Epoch 90/100, Loss: 0.083821
#   Epoch 100/100, Loss: 0.083810
# Training complete for run 40
# Run 40 — RMSE: 24.354372, MSE: 593.135425, NMSE: 0.0027254744
#
# ===== RUN 41/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.085236
#   Epoch 20/100, Loss: 0.084967
#   Epoch 30/100, Loss: 0.084680
#   Epoch 40/100, Loss: 0.084453
#   Epoch 50/100, Loss: 0.084262
#   Epoch 60/100, Loss: 0.084124
#   Epoch 70/100, Loss: 0.083962
#   Epoch 80/100, Loss: 0.083882
#   Epoch 90/100, Loss: 0.083765
#   Epoch 100/100, Loss: 0.083714
# Training complete for run 41
# Run 41 — RMSE: 24.213551, MSE: 586.296029, NMSE: 0.0026540853
#
# ===== RUN 42/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.085878
#   Epoch 20/100, Loss: 0.085894
#   Epoch 30/100, Loss: 0.085823
#   Epoch 40/100, Loss: 0.085673
#   Epoch 50/100, Loss: 0.085433
#   Epoch 60/100, Loss: 0.085117
#   Epoch 70/100, Loss: 0.084808
#   Epoch 80/100, Loss: 0.084630
#   Epoch 90/100, Loss: 0.084495
#   Epoch 100/100, Loss: 0.084396
# Training complete for run 42
# Run 42 — RMSE: 24.096159, MSE: 580.624898, NMSE: 0.0026671858
#
# ===== RUN 43/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.085313
#   Epoch 20/100, Loss: 0.085148
#   Epoch 30/100, Loss: 0.084726
#   Epoch 40/100, Loss: 0.084403
#   Epoch 50/100, Loss: 0.084306
#   Epoch 60/100, Loss: 0.084069
#   Epoch 70/100, Loss: 0.083968
#   Epoch 80/100, Loss: 0.083860
#   Epoch 90/100, Loss: 0.083780
#   Epoch 100/100, Loss: 0.083720
# Training complete for run 43
# Run 43 — RMSE: 24.070542, MSE: 579.391011, NMSE: 0.0026561347
#
# ===== RUN 44/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.085177
#   Epoch 20/100, Loss: 0.085076
#   Epoch 30/100, Loss: 0.084846
#   Epoch 40/100, Loss: 0.084370
#   Epoch 50/100, Loss: 0.083924
#   Epoch 60/100, Loss: 0.083516
#   Epoch 70/100, Loss: 0.083326
#   Epoch 80/100, Loss: 0.083245
#   Epoch 90/100, Loss: 0.083127
#   Epoch 100/100, Loss: 0.082953
# Training complete for run 44
# Run 44 — RMSE: 24.091058, MSE: 580.379084, NMSE: 0.0026499991
#
# ===== RUN 45/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.085684
#   Epoch 20/100, Loss: 0.085503
#   Epoch 30/100, Loss: 0.085213
#   Epoch 40/100, Loss: 0.084871
#   Epoch 50/100, Loss: 0.084533
#   Epoch 60/100, Loss: 0.084316
#   Epoch 70/100, Loss: 0.084190
#   Epoch 80/100, Loss: 0.084112
#   Epoch 90/100, Loss: 0.084060
#   Epoch 100/100, Loss: 0.084020
# Training complete for run 45
# Run 45 — RMSE: 24.455267, MSE: 598.060086, NMSE: 0.0027467739
#
# ===== RUN 46/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.086572
#   Epoch 20/100, Loss: 0.086888
#   Epoch 30/100, Loss: 0.086872
#   Epoch 40/100, Loss: 0.086818
#   Epoch 50/100, Loss: 0.086772
#   Epoch 60/100, Loss: 0.086726
#   Epoch 70/100, Loss: 0.086659
#   Epoch 80/100, Loss: 0.086617
#   Epoch 90/100, Loss: 0.086536
#   Epoch 100/100, Loss: 0.086464
# Training complete for run 46
# Run 46 — RMSE: 24.426512, MSE: 596.654474, NMSE: 0.0027426952
#
# ===== RUN 47/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.085312
#   Epoch 20/100, Loss: 0.085270
#   Epoch 30/100, Loss: 0.085143
#   Epoch 40/100, Loss: 0.084982
#   Epoch 50/100, Loss: 0.084789
#   Epoch 60/100, Loss: 0.084587
#   Epoch 70/100, Loss: 0.084520
#   Epoch 80/100, Loss: 0.084451
#   Epoch 90/100, Loss: 0.084376
#   Epoch 100/100, Loss: 0.084356
# Training complete for run 47
# Run 47 — RMSE: 24.466240, MSE: 598.596918, NMSE: 0.0027444341
#
# ===== RUN 48/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.085310
#   Epoch 20/100, Loss: 0.085058
#   Epoch 30/100, Loss: 0.084620
#   Epoch 40/100, Loss: 0.084383
#   Epoch 50/100, Loss: 0.084099
#   Epoch 60/100, Loss: 0.083908
#   Epoch 70/100, Loss: 0.083849
#   Epoch 80/100, Loss: 0.083777
#   Epoch 90/100, Loss: 0.083757
#   Epoch 100/100, Loss: 0.083710
# Training complete for run 48
# Run 48 — RMSE: 24.458374, MSE: 598.212042, NMSE: 0.0027772281
#
# ===== RUN 49/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.086127
#   Epoch 20/100, Loss: 0.086236
#   Epoch 30/100, Loss: 0.086087
#   Epoch 40/100, Loss: 0.085838
#   Epoch 50/100, Loss: 0.085620
#   Epoch 60/100, Loss: 0.085461
#   Epoch 70/100, Loss: 0.085315
#   Epoch 80/100, Loss: 0.085202
#   Epoch 90/100, Loss: 0.085100
#   Epoch 100/100, Loss: 0.085006
# Training complete for run 49
# Run 49 — RMSE: 24.286665, MSE: 589.842082, NMSE: 0.0027159270
#
# ===== RUN 50/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.085165
#   Epoch 20/100, Loss: 0.085089
#   Epoch 30/100, Loss: 0.084846
#   Epoch 40/100, Loss: 0.084694
#   Epoch 50/100, Loss: 0.084526
#   Epoch 60/100, Loss: 0.084171
#   Epoch 70/100, Loss: 0.083910
#   Epoch 80/100, Loss: 0.083699
#   Epoch 90/100, Loss: 0.083567
#   Epoch 100/100, Loss: 0.083446
# Training complete for run 50
# Run 50 — RMSE: 24.132240, MSE: 582.365009, NMSE: 0.0026623665
#
# ===== RUN 51/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.085327
#   Epoch 20/100, Loss: 0.085307
#   Epoch 30/100, Loss: 0.085300
#   Epoch 40/100, Loss: 0.085258
#   Epoch 50/100, Loss: 0.085214
#   Epoch 60/100, Loss: 0.085149
#   Epoch 70/100, Loss: 0.085040
#   Epoch 80/100, Loss: 0.084966
#   Epoch 90/100, Loss: 0.084857
#   Epoch 100/100, Loss: 0.084764
# Training complete for run 51
# Run 51 — RMSE: 24.269856, MSE: 589.025903, NMSE: 0.0026731709
#
# ===== RUN 52/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.085871
#   Epoch 20/100, Loss: 0.086109
#   Epoch 30/100, Loss: 0.086250
#   Epoch 40/100, Loss: 0.086206
#   Epoch 50/100, Loss: 0.086065
#   Epoch 60/100, Loss: 0.085880
#   Epoch 70/100, Loss: 0.085654
#   Epoch 80/100, Loss: 0.085392
#   Epoch 90/100, Loss: 0.085182
#   Epoch 100/100, Loss: 0.085030
# Training complete for run 52
# Run 52 — RMSE: 24.415693, MSE: 596.126047, NMSE: 0.0027419219
#
# ===== RUN 53/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.086928
#   Epoch 20/100, Loss: 0.086894
#   Epoch 30/100, Loss: 0.086616
#   Epoch 40/100, Loss: 0.086302
#   Epoch 50/100, Loss: 0.086009
#   Epoch 60/100, Loss: 0.085763
#   Epoch 70/100, Loss: 0.085550
#   Epoch 80/100, Loss: 0.085357
#   Epoch 90/100, Loss: 0.085181
#   Epoch 100/100, Loss: 0.085019
# Training complete for run 53
# Run 53 — RMSE: 24.182663, MSE: 584.801214, NMSE: 0.0026974754
#
# ===== RUN 54/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.085350
#   Epoch 20/100, Loss: 0.085348
#   Epoch 30/100, Loss: 0.085343
#   Epoch 40/100, Loss: 0.085299
#   Epoch 50/100, Loss: 0.085183
#   Epoch 60/100, Loss: 0.084990
#   Epoch 70/100, Loss: 0.084766
#   Epoch 80/100, Loss: 0.084575
#   Epoch 90/100, Loss: 0.084456
#   Epoch 100/100, Loss: 0.084347
# Training complete for run 54
# Run 54 — RMSE: 24.180209, MSE: 584.682497, NMSE: 0.0026826911
#
# ===== RUN 55/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.086600
#   Epoch 20/100, Loss: 0.086252
#   Epoch 30/100, Loss: 0.085694
#   Epoch 40/100, Loss: 0.085408
#   Epoch 50/100, Loss: 0.085244
#   Epoch 60/100, Loss: 0.085136
#   Epoch 70/100, Loss: 0.085052
#   Epoch 80/100, Loss: 0.084977
#   Epoch 90/100, Loss: 0.084906
#   Epoch 100/100, Loss: 0.084836
# Training complete for run 55
# Run 55 — RMSE: 24.340139, MSE: 592.442345, NMSE: 0.0027318429
#
# ===== RUN 56/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.085342
#   Epoch 20/100, Loss: 0.085139
#   Epoch 30/100, Loss: 0.084510
#   Epoch 40/100, Loss: 0.084189
#   Epoch 50/100, Loss: 0.083954
#   Epoch 60/100, Loss: 0.083836
#   Epoch 70/100, Loss: 0.083757
#   Epoch 80/100, Loss: 0.083716
#   Epoch 90/100, Loss: 0.083708
#   Epoch 100/100, Loss: 0.083677
# Training complete for run 56
# Run 56 — RMSE: 24.286086, MSE: 589.813966, NMSE: 0.0027137808
#
# ===== RUN 57/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.085303
#   Epoch 20/100, Loss: 0.085178
#   Epoch 30/100, Loss: 0.085055
#   Epoch 40/100, Loss: 0.084786
#   Epoch 50/100, Loss: 0.084358
#   Epoch 60/100, Loss: 0.084138
#   Epoch 70/100, Loss: 0.083993
#   Epoch 80/100, Loss: 0.083886
#   Epoch 90/100, Loss: 0.083814
#   Epoch 100/100, Loss: 0.083750
# Training complete for run 57
# Run 57 — RMSE: 24.151435, MSE: 583.291806, NMSE: 0.0026440920
#
# ===== RUN 58/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.085228
#   Epoch 20/100, Loss: 0.085211
#   Epoch 30/100, Loss: 0.085187
#   Epoch 40/100, Loss: 0.085152
#   Epoch 50/100, Loss: 0.085100
#   Epoch 60/100, Loss: 0.085034
#   Epoch 70/100, Loss: 0.084937
#   Epoch 80/100, Loss: 0.084813
#   Epoch 90/100, Loss: 0.084601
#   Epoch 100/100, Loss: 0.084381
# Training complete for run 58
# Run 58 — RMSE: 24.127961, MSE: 582.158496, NMSE: 0.0026601011
#
# ===== RUN 59/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.085289
#   Epoch 20/100, Loss: 0.085136
#   Epoch 30/100, Loss: 0.084774
#   Epoch 40/100, Loss: 0.084518
#   Epoch 50/100, Loss: 0.084372
#   Epoch 60/100, Loss: 0.084237
#   Epoch 70/100, Loss: 0.084096
#   Epoch 80/100, Loss: 0.083976
#   Epoch 90/100, Loss: 0.083923
#   Epoch 100/100, Loss: 0.083882
# Training complete for run 59
# Run 59 — RMSE: 24.324678, MSE: 591.689937, NMSE: 0.0027172960
#
# ===== RUN 60/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.085226
#   Epoch 20/100, Loss: 0.085143
#   Epoch 30/100, Loss: 0.084977
#   Epoch 40/100, Loss: 0.084810
#   Epoch 50/100, Loss: 0.084562
#   Epoch 60/100, Loss: 0.084311
#   Epoch 70/100, Loss: 0.084089
#   Epoch 80/100, Loss: 0.083926
#   Epoch 90/100, Loss: 0.083732
#   Epoch 100/100, Loss: 0.083696
# Training complete for run 60
# Run 60 — RMSE: 24.187277, MSE: 585.024350, NMSE: 0.0026811258
#
# ===== STATS FOR NOISE 0.0% (60 runs) =====
# RMSE: 24.261613 +/- 0.112514
# MSE:  588.638526 +/- 5.461513
# NMSE: 0.0027008200 +/- 0.0000299271
# Best run: 37 (RMSE: 24.054753)
#
# ================================================================================
# EVALUATING NOISE LEVEL: 0.5% (lambda=0.005, sigma=0.526428)
# ================================================================================
#
# X_train shape: (230, 1, 2), y_train shape: (230,)
#
# ===== RUN 1/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.086991
#   Epoch 20/100, Loss: 0.087015
#   Epoch 30/100, Loss: 0.087062
#   Epoch 40/100, Loss: 0.087071
#   Epoch 50/100, Loss: 0.087051
#   Epoch 60/100, Loss: 0.087011
#   Epoch 70/100, Loss: 0.086961
#   Epoch 80/100, Loss: 0.086867
#   Epoch 90/100, Loss: 0.086677
#   Epoch 100/100, Loss: 0.086382
# Training complete for run 1
# Run 1 — RMSE: 24.261664, MSE: 588.628316, NMSE: 0.0026889793
#
# ===== RUN 2/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.087815
#   Epoch 20/100, Loss: 0.088107
#   Epoch 30/100, Loss: 0.088292
#   Epoch 40/100, Loss: 0.088301
#   Epoch 50/100, Loss: 0.088272
#   Epoch 60/100, Loss: 0.088231
#   Epoch 70/100, Loss: 0.088172
#   Epoch 80/100, Loss: 0.088067
#   Epoch 90/100, Loss: 0.087932
#   Epoch 100/100, Loss: 0.087765
# Training complete for run 2
# Run 2 — RMSE: 24.325477, MSE: 591.728835, NMSE: 0.0027218303
#
# ===== RUN 3/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.086860
#   Epoch 20/100, Loss: 0.086752
#   Epoch 30/100, Loss: 0.086167
#   Epoch 40/100, Loss: 0.085559
#   Epoch 50/100, Loss: 0.085351
#   Epoch 60/100, Loss: 0.085277
#   Epoch 70/100, Loss: 0.085231
#   Epoch 80/100, Loss: 0.085198
#   Epoch 90/100, Loss: 0.085175
#   Epoch 100/100, Loss: 0.085158
# Training complete for run 3
# Run 3 — RMSE: 24.365435, MSE: 593.674425, NMSE: 0.0027305747
#
# ===== RUN 4/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.087088
#   Epoch 20/100, Loss: 0.087086
#   Epoch 30/100, Loss: 0.087071
#   Epoch 40/100, Loss: 0.087001
#   Epoch 50/100, Loss: 0.086859
#   Epoch 60/100, Loss: 0.086674
#   Epoch 70/100, Loss: 0.086459
#   Epoch 80/100, Loss: 0.086220
#   Epoch 90/100, Loss: 0.085946
#   Epoch 100/100, Loss: 0.085763
# Training complete for run 4
# Run 4 — RMSE: 24.149959, MSE: 583.220526, NMSE: 0.0026706109
#
# ===== RUN 5/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.086877
#   Epoch 20/100, Loss: 0.086576
#   Epoch 30/100, Loss: 0.086217
#   Epoch 40/100, Loss: 0.086032
#   Epoch 50/100, Loss: 0.085874
#   Epoch 60/100, Loss: 0.085745
#   Epoch 70/100, Loss: 0.085664
#   Epoch 80/100, Loss: 0.085587
#   Epoch 90/100, Loss: 0.085525
#   Epoch 100/100, Loss: 0.085483
# Training complete for run 5
# Run 5 — RMSE: 24.339698, MSE: 592.420921, NMSE: 0.0027201128
#
# ===== RUN 6/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.087569
#   Epoch 20/100, Loss: 0.087683
#   Epoch 30/100, Loss: 0.087899
#   Epoch 40/100, Loss: 0.087967
#   Epoch 50/100, Loss: 0.087976
#   Epoch 60/100, Loss: 0.087965
#   Epoch 70/100, Loss: 0.087949
#   Epoch 80/100, Loss: 0.087928
#   Epoch 90/100, Loss: 0.087902
#   Epoch 100/100, Loss: 0.087858
# Training complete for run 6
# Run 6 — RMSE: 24.426999, MSE: 596.678295, NMSE: 0.0027414223
#
# ===== RUN 7/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.086767
#   Epoch 20/100, Loss: 0.086735
#   Epoch 30/100, Loss: 0.086726
#   Epoch 40/100, Loss: 0.086732
#   Epoch 50/100, Loss: 0.086680
#   Epoch 60/100, Loss: 0.086595
#   Epoch 70/100, Loss: 0.086451
#   Epoch 80/100, Loss: 0.086252
#   Epoch 90/100, Loss: 0.086011
#   Epoch 100/100, Loss: 0.085714
# Training complete for run 7
# Run 7 — RMSE: 24.220968, MSE: 586.655282, NMSE: 0.0026959900
#
# ===== RUN 8/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.087672
#   Epoch 20/100, Loss: 0.087765
#   Epoch 30/100, Loss: 0.087564
#   Epoch 40/100, Loss: 0.087392
#   Epoch 50/100, Loss: 0.087312
#   Epoch 60/100, Loss: 0.087252
#   Epoch 70/100, Loss: 0.087172
#   Epoch 80/100, Loss: 0.087092
#   Epoch 90/100, Loss: 0.087009
#   Epoch 100/100, Loss: 0.086933
# Training complete for run 8
# Run 8 — RMSE: 24.326986, MSE: 591.802248, NMSE: 0.0027038063
#
# ===== RUN 9/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.087365
#   Epoch 20/100, Loss: 0.087437
#   Epoch 30/100, Loss: 0.087301
#   Epoch 40/100, Loss: 0.087072
#   Epoch 50/100, Loss: 0.086805
#   Epoch 60/100, Loss: 0.086573
#   Epoch 70/100, Loss: 0.086402
#   Epoch 80/100, Loss: 0.086261
#   Epoch 90/100, Loss: 0.086117
#   Epoch 100/100, Loss: 0.086016
# Training complete for run 9
# Run 9 — RMSE: 24.146833, MSE: 583.069520, NMSE: 0.0026790505
#
# ===== RUN 10/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.087857
#   Epoch 20/100, Loss: 0.088132
#   Epoch 30/100, Loss: 0.088179
#   Epoch 40/100, Loss: 0.088064
#   Epoch 50/100, Loss: 0.087867
#   Epoch 60/100, Loss: 0.087619
#   Epoch 70/100, Loss: 0.087332
#   Epoch 80/100, Loss: 0.087069
#   Epoch 90/100, Loss: 0.086822
#   Epoch 100/100, Loss: 0.086592
# Training complete for run 10
# Run 10 — RMSE: 24.298950, MSE: 590.438963, NMSE: 0.0027170173
#
# ===== RUN 11/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.087231
#   Epoch 20/100, Loss: 0.087096
#   Epoch 30/100, Loss: 0.086936
#   Epoch 40/100, Loss: 0.086799
#   Epoch 50/100, Loss: 0.086586
#   Epoch 60/100, Loss: 0.086313
#   Epoch 70/100, Loss: 0.086005
#   Epoch 80/100, Loss: 0.085736
#   Epoch 90/100, Loss: 0.085557
#   Epoch 100/100, Loss: 0.085449
# Training complete for run 11
# Run 11 — RMSE: 24.244456, MSE: 587.793643, NMSE: 0.0027053145
#
# ===== RUN 12/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.088164
#   Epoch 20/100, Loss: 0.088144
#   Epoch 30/100, Loss: 0.087904
#   Epoch 40/100, Loss: 0.087707
#   Epoch 50/100, Loss: 0.087505
#   Epoch 60/100, Loss: 0.087289
#   Epoch 70/100, Loss: 0.087092
#   Epoch 80/100, Loss: 0.086911
#   Epoch 90/100, Loss: 0.086734
#   Epoch 100/100, Loss: 0.086582
# Training complete for run 12
# Run 12 — RMSE: 24.298269, MSE: 590.405884, NMSE: 0.0027152984
#
# ===== RUN 13/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.087560
#   Epoch 20/100, Loss: 0.087761
#   Epoch 30/100, Loss: 0.087684
#   Epoch 40/100, Loss: 0.087494
#   Epoch 50/100, Loss: 0.087243
#   Epoch 60/100, Loss: 0.086956
#   Epoch 70/100, Loss: 0.086640
#   Epoch 80/100, Loss: 0.086324
#   Epoch 90/100, Loss: 0.086041
#   Epoch 100/100, Loss: 0.085806
# Training complete for run 13
# Run 13 — RMSE: 24.184308, MSE: 584.880736, NMSE: 0.0026829170
#
# ===== RUN 14/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.088303
#   Epoch 20/100, Loss: 0.088364
#   Epoch 30/100, Loss: 0.088131
#   Epoch 40/100, Loss: 0.087795
#   Epoch 50/100, Loss: 0.087392
#   Epoch 60/100, Loss: 0.087038
#   Epoch 70/100, Loss: 0.086719
#   Epoch 80/100, Loss: 0.086481
#   Epoch 90/100, Loss: 0.086272
#   Epoch 100/100, Loss: 0.086118
# Training complete for run 14
# Run 14 — RMSE: 24.324607, MSE: 591.686494, NMSE: 0.0027204713
#
# ===== RUN 15/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.086876
#   Epoch 20/100, Loss: 0.086856
#   Epoch 30/100, Loss: 0.086770
#   Epoch 40/100, Loss: 0.086602
#   Epoch 50/100, Loss: 0.086389
#   Epoch 60/100, Loss: 0.086199
#   Epoch 70/100, Loss: 0.086026
#   Epoch 80/100, Loss: 0.085874
#   Epoch 90/100, Loss: 0.085775
#   Epoch 100/100, Loss: 0.085698
# Training complete for run 15
# Run 15 — RMSE: 24.252748, MSE: 588.195806, NMSE: 0.0027132567
#
# ===== RUN 16/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.088196
#   Epoch 20/100, Loss: 0.088394
#   Epoch 30/100, Loss: 0.088330
#   Epoch 40/100, Loss: 0.088246
#   Epoch 50/100, Loss: 0.088133
#   Epoch 60/100, Loss: 0.087984
#   Epoch 70/100, Loss: 0.087807
#   Epoch 80/100, Loss: 0.087611
#   Epoch 90/100, Loss: 0.087428
#   Epoch 100/100, Loss: 0.087259
# Training complete for run 16
# Run 16 — RMSE: 24.318309, MSE: 591.380145, NMSE: 0.0027171128
#
# ===== RUN 17/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.087598
#   Epoch 20/100, Loss: 0.087893
#   Epoch 30/100, Loss: 0.087979
#   Epoch 40/100, Loss: 0.087971
#   Epoch 50/100, Loss: 0.087942
#   Epoch 60/100, Loss: 0.087908
#   Epoch 70/100, Loss: 0.087865
#   Epoch 80/100, Loss: 0.087811
#   Epoch 90/100, Loss: 0.087741
#   Epoch 100/100, Loss: 0.087640
# Training complete for run 17
# Run 17 — RMSE: 24.470431, MSE: 598.802001, NMSE: 0.0027496861
#
# ===== RUN 18/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.087672
#   Epoch 20/100, Loss: 0.087827
#   Epoch 30/100, Loss: 0.087647
#   Epoch 40/100, Loss: 0.087394
#   Epoch 50/100, Loss: 0.087113
#   Epoch 60/100, Loss: 0.086820
#   Epoch 70/100, Loss: 0.086518
#   Epoch 80/100, Loss: 0.086255
#   Epoch 90/100, Loss: 0.086037
#   Epoch 100/100, Loss: 0.085837
# Training complete for run 18
# Run 18 — RMSE: 24.157862, MSE: 583.602309, NMSE: 0.0026785058
#
# ===== RUN 19/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.087376
#   Epoch 20/100, Loss: 0.087594
#   Epoch 30/100, Loss: 0.087707
#   Epoch 40/100, Loss: 0.087727
#   Epoch 50/100, Loss: 0.087715
#   Epoch 60/100, Loss: 0.087694
#   Epoch 70/100, Loss: 0.087669
#   Epoch 80/100, Loss: 0.087641
#   Epoch 90/100, Loss: 0.087608
#   Epoch 100/100, Loss: 0.087568
# Training complete for run 19
# Run 19 — RMSE: 24.443740, MSE: 597.496432, NMSE: 0.0027448034
#
# ===== RUN 20/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.086966
#   Epoch 20/100, Loss: 0.086865
#   Epoch 30/100, Loss: 0.086594
#   Epoch 40/100, Loss: 0.086284
#   Epoch 50/100, Loss: 0.086062
#   Epoch 60/100, Loss: 0.085923
#   Epoch 70/100, Loss: 0.085791
#   Epoch 80/100, Loss: 0.085733
#   Epoch 90/100, Loss: 0.085582
#   Epoch 100/100, Loss: 0.085488
# Training complete for run 20
# Run 20 — RMSE: 24.118598, MSE: 581.706747, NMSE: 0.0026760074
#
# ===== RUN 21/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.086887
#   Epoch 20/100, Loss: 0.086850
#   Epoch 30/100, Loss: 0.086797
#   Epoch 40/100, Loss: 0.086699
#   Epoch 50/100, Loss: 0.086664
#   Epoch 60/100, Loss: 0.086560
#   Epoch 70/100, Loss: 0.086443
#   Epoch 80/100, Loss: 0.086297
#   Epoch 90/100, Loss: 0.086152
#   Epoch 100/100, Loss: 0.086093
# Training complete for run 21
# Run 21 — RMSE: 24.279554, MSE: 589.496725, NMSE: 0.0027063355
#
# ===== RUN 22/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.088196
#   Epoch 20/100, Loss: 0.088438
#   Epoch 30/100, Loss: 0.088411
#   Epoch 40/100, Loss: 0.088367
#   Epoch 50/100, Loss: 0.088316
#   Epoch 60/100, Loss: 0.088225
#   Epoch 70/100, Loss: 0.088084
#   Epoch 80/100, Loss: 0.087894
#   Epoch 90/100, Loss: 0.087677
#   Epoch 100/100, Loss: 0.087440
# Training complete for run 22
# Run 22 — RMSE: 24.319418, MSE: 591.434101, NMSE: 0.0027113792
#
# ===== RUN 23/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.088191
#   Epoch 20/100, Loss: 0.088028
#   Epoch 30/100, Loss: 0.087683
#   Epoch 40/100, Loss: 0.087361
#   Epoch 50/100, Loss: 0.087101
#   Epoch 60/100, Loss: 0.086887
#   Epoch 70/100, Loss: 0.086709
#   Epoch 80/100, Loss: 0.086554
#   Epoch 90/100, Loss: 0.086420
#   Epoch 100/100, Loss: 0.086297
# Training complete for run 23
# Run 23 — RMSE: 24.142804, MSE: 582.874997, NMSE: 0.0026825987
#
# ===== RUN 24/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.087656
#   Epoch 20/100, Loss: 0.087603
#   Epoch 30/100, Loss: 0.087473
#   Epoch 40/100, Loss: 0.087201
#   Epoch 50/100, Loss: 0.086769
#   Epoch 60/100, Loss: 0.086290
#   Epoch 70/100, Loss: 0.086032
#   Epoch 80/100, Loss: 0.085779
#   Epoch 90/100, Loss: 0.085600
#   Epoch 100/100, Loss: 0.085453
# Training complete for run 24
# Run 24 — RMSE: 24.304392, MSE: 590.703469, NMSE: 0.0027156713
#
# ===== RUN 25/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.086779
#   Epoch 20/100, Loss: 0.086701
#   Epoch 30/100, Loss: 0.086602
#   Epoch 40/100, Loss: 0.086468
#   Epoch 50/100, Loss: 0.086304
#   Epoch 60/100, Loss: 0.086126
#   Epoch 70/100, Loss: 0.085963
#   Epoch 80/100, Loss: 0.085837
#   Epoch 90/100, Loss: 0.085749
#   Epoch 100/100, Loss: 0.085694
# Training complete for run 25
# Run 25 — RMSE: 24.108359, MSE: 581.212973, NMSE: 0.0026683311
#
# ===== RUN 26/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.087679
#   Epoch 20/100, Loss: 0.087919
#   Epoch 30/100, Loss: 0.087860
#   Epoch 40/100, Loss: 0.087774
#   Epoch 50/100, Loss: 0.087665
#   Epoch 60/100, Loss: 0.087530
#   Epoch 70/100, Loss: 0.087355
#   Epoch 80/100, Loss: 0.087129
#   Epoch 90/100, Loss: 0.086887
#   Epoch 100/100, Loss: 0.086700
# Training complete for run 26
# Run 26 — RMSE: 24.273558, MSE: 589.205616, NMSE: 0.0027109178
#
# ===== RUN 27/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.088221
#   Epoch 20/100, Loss: 0.088181
#   Epoch 30/100, Loss: 0.087876
#   Epoch 40/100, Loss: 0.087433
#   Epoch 50/100, Loss: 0.087109
#   Epoch 60/100, Loss: 0.086852
#   Epoch 70/100, Loss: 0.086678
#   Epoch 80/100, Loss: 0.086515
#   Epoch 90/100, Loss: 0.086389
#   Epoch 100/100, Loss: 0.086282
# Training complete for run 27
# Run 27 — RMSE: 24.264821, MSE: 588.781555, NMSE: 0.0027142210
#
# ===== RUN 28/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.086945
#   Epoch 20/100, Loss: 0.086819
#   Epoch 30/100, Loss: 0.086468
#   Epoch 40/100, Loss: 0.085969
#   Epoch 50/100, Loss: 0.085643
#   Epoch 60/100, Loss: 0.085499
#   Epoch 70/100, Loss: 0.085423
#   Epoch 80/100, Loss: 0.085376
#   Epoch 90/100, Loss: 0.085351
#   Epoch 100/100, Loss: 0.085324
# Training complete for run 28
# Run 28 — RMSE: 24.321619, MSE: 591.541174, NMSE: 0.0027246771
#
# ===== RUN 29/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.086812
#   Epoch 20/100, Loss: 0.086665
#   Epoch 30/100, Loss: 0.086409
#   Epoch 40/100, Loss: 0.086084
#   Epoch 50/100, Loss: 0.085809
#   Epoch 60/100, Loss: 0.085637
#   Epoch 70/100, Loss: 0.085534
#   Epoch 80/100, Loss: 0.085479
#   Epoch 90/100, Loss: 0.085442
#   Epoch 100/100, Loss: 0.085419
# Training complete for run 29
# Run 29 — RMSE: 24.387581, MSE: 594.754108, NMSE: 0.0027380572
#
# ===== RUN 30/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.087013
#   Epoch 20/100, Loss: 0.086752
#   Epoch 30/100, Loss: 0.086627
#   Epoch 40/100, Loss: 0.086540
#   Epoch 50/100, Loss: 0.086397
#   Epoch 60/100, Loss: 0.086220
#   Epoch 70/100, Loss: 0.086034
#   Epoch 80/100, Loss: 0.085826
#   Epoch 90/100, Loss: 0.085674
#   Epoch 100/100, Loss: 0.085533
# Training complete for run 30
# Run 30 — RMSE: 24.122593, MSE: 581.899504, NMSE: 0.0026699590
#
# ===== RUN 31/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.086781
#   Epoch 20/100, Loss: 0.086721
#   Epoch 30/100, Loss: 0.086510
#   Epoch 40/100, Loss: 0.086199
#   Epoch 50/100, Loss: 0.085915
#   Epoch 60/100, Loss: 0.085710
#   Epoch 70/100, Loss: 0.085609
#   Epoch 80/100, Loss: 0.085516
#   Epoch 90/100, Loss: 0.085429
#   Epoch 100/100, Loss: 0.085364
# Training complete for run 31
# Run 31 — RMSE: 24.275385, MSE: 589.294328, NMSE: 0.0027214308
#
# ===== RUN 32/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.087940
#   Epoch 20/100, Loss: 0.087894
#   Epoch 30/100, Loss: 0.087661
#   Epoch 40/100, Loss: 0.087412
#   Epoch 50/100, Loss: 0.087138
#   Epoch 60/100, Loss: 0.086840
#   Epoch 70/100, Loss: 0.086542
#   Epoch 80/100, Loss: 0.086325
#   Epoch 90/100, Loss: 0.086155
#   Epoch 100/100, Loss: 0.086022
# Training complete for run 32
# Run 32 — RMSE: 24.273337, MSE: 589.194902, NMSE: 0.0027102362
#
# ===== RUN 33/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.087760
#   Epoch 20/100, Loss: 0.088025
#   Epoch 30/100, Loss: 0.087922
#   Epoch 40/100, Loss: 0.087798
#   Epoch 50/100, Loss: 0.087669
#   Epoch 60/100, Loss: 0.087503
#   Epoch 70/100, Loss: 0.087349
#   Epoch 80/100, Loss: 0.087233
#   Epoch 90/100, Loss: 0.087143
#   Epoch 100/100, Loss: 0.087041
# Training complete for run 33
# Run 33 — RMSE: 24.293633, MSE: 590.180618, NMSE: 0.0027117089
#
# ===== RUN 34/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.088357
#   Epoch 20/100, Loss: 0.088411
#   Epoch 30/100, Loss: 0.088304
#   Epoch 40/100, Loss: 0.088215
#   Epoch 50/100, Loss: 0.088134
#   Epoch 60/100, Loss: 0.088043
#   Epoch 70/100, Loss: 0.087914
#   Epoch 80/100, Loss: 0.087683
#   Epoch 90/100, Loss: 0.087444
#   Epoch 100/100, Loss: 0.087141
# Training complete for run 34
# Run 34 — RMSE: 24.348914, MSE: 592.869596, NMSE: 0.0027112836
#
# ===== RUN 35/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.087891
#   Epoch 20/100, Loss: 0.087958
#   Epoch 30/100, Loss: 0.088222
#   Epoch 40/100, Loss: 0.088257
#   Epoch 50/100, Loss: 0.088189
#   Epoch 60/100, Loss: 0.087952
#   Epoch 70/100, Loss: 0.087717
#   Epoch 80/100, Loss: 0.087462
#   Epoch 90/100, Loss: 0.087202
#   Epoch 100/100, Loss: 0.086947
# Training complete for run 35
# Run 35 — RMSE: 24.305230, MSE: 590.744223, NMSE: 0.0027041940
#
# ===== RUN 36/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.087559
#   Epoch 20/100, Loss: 0.087736
#   Epoch 30/100, Loss: 0.087637
#   Epoch 40/100, Loss: 0.087511
#   Epoch 50/100, Loss: 0.087388
#   Epoch 60/100, Loss: 0.087201
#   Epoch 70/100, Loss: 0.086967
#   Epoch 80/100, Loss: 0.086781
#   Epoch 90/100, Loss: 0.086630
#   Epoch 100/100, Loss: 0.086486
# Training complete for run 36
# Run 36 — RMSE: 24.288462, MSE: 589.929376, NMSE: 0.0027092104
#
# ===== RUN 37/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.086785
#   Epoch 20/100, Loss: 0.086729
#   Epoch 30/100, Loss: 0.086572
#   Epoch 40/100, Loss: 0.086263
#   Epoch 50/100, Loss: 0.085995
#   Epoch 60/100, Loss: 0.085715
#   Epoch 70/100, Loss: 0.085597
#   Epoch 80/100, Loss: 0.085529
#   Epoch 90/100, Loss: 0.085423
#   Epoch 100/100, Loss: 0.085276
# Training complete for run 37
# Run 37 — RMSE: 24.086362, MSE: 580.152832, NMSE: 0.0026690541
#
# ===== RUN 38/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.086849
#   Epoch 20/100, Loss: 0.086773
#   Epoch 30/100, Loss: 0.086593
#   Epoch 40/100, Loss: 0.086429
#   Epoch 50/100, Loss: 0.086316
#   Epoch 60/100, Loss: 0.086241
#   Epoch 70/100, Loss: 0.086190
#   Epoch 80/100, Loss: 0.086151
#   Epoch 90/100, Loss: 0.086119
#   Epoch 100/100, Loss: 0.085911
# Training complete for run 38
# Run 38 — RMSE: 24.078340, MSE: 579.766475, NMSE: 0.0026675171
#
# ===== RUN 39/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.087609
#   Epoch 20/100, Loss: 0.087941
#   Epoch 30/100, Loss: 0.088034
#   Epoch 40/100, Loss: 0.088024
#   Epoch 50/100, Loss: 0.087995
#   Epoch 60/100, Loss: 0.087956
#   Epoch 70/100, Loss: 0.087906
#   Epoch 80/100, Loss: 0.087843
#   Epoch 90/100, Loss: 0.087779
#   Epoch 100/100, Loss: 0.087695
# Training complete for run 39
# Run 39 — RMSE: 24.481183, MSE: 599.328313, NMSE: 0.0027544601
#
# ===== RUN 40/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.086835
#   Epoch 20/100, Loss: 0.086512
#   Epoch 30/100, Loss: 0.085857
#   Epoch 40/100, Loss: 0.085426
#   Epoch 50/100, Loss: 0.085194
#   Epoch 60/100, Loss: 0.084884
#   Epoch 70/100, Loss: 0.084685
#   Epoch 80/100, Loss: 0.084570
#   Epoch 90/100, Loss: 0.084442
#   Epoch 100/100, Loss: 0.084378
# Training complete for run 40
# Run 40 — RMSE: 24.199947, MSE: 585.637445, NMSE: 0.0027024151
#
# ===== RUN 41/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.086770
#   Epoch 20/100, Loss: 0.086522
#   Epoch 30/100, Loss: 0.086277
#   Epoch 40/100, Loss: 0.086080
#   Epoch 50/100, Loss: 0.085924
#   Epoch 60/100, Loss: 0.085777
#   Epoch 70/100, Loss: 0.085605
#   Epoch 80/100, Loss: 0.085469
#   Epoch 90/100, Loss: 0.085338
#   Epoch 100/100, Loss: 0.085230
# Training complete for run 41
# Run 41 — RMSE: 24.426700, MSE: 596.663676, NMSE: 0.0027253039
#
# ===== RUN 42/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.087387
#   Epoch 20/100, Loss: 0.087449
#   Epoch 30/100, Loss: 0.087302
#   Epoch 40/100, Loss: 0.087050
#   Epoch 50/100, Loss: 0.086727
#   Epoch 60/100, Loss: 0.086404
#   Epoch 70/100, Loss: 0.086146
#   Epoch 80/100, Loss: 0.085882
#   Epoch 90/100, Loss: 0.085737
#   Epoch 100/100, Loss: 0.085644
# Training complete for run 42
# Run 42 — RMSE: 24.109362, MSE: 581.261335, NMSE: 0.0026766751
#
# ===== RUN 43/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.086855
#   Epoch 20/100, Loss: 0.086711
#   Epoch 30/100, Loss: 0.086186
#   Epoch 40/100, Loss: 0.085604
#   Epoch 50/100, Loss: 0.085386
#   Epoch 60/100, Loss: 0.085142
#   Epoch 70/100, Loss: 0.085066
#   Epoch 80/100, Loss: 0.085002
#   Epoch 90/100, Loss: 0.084900
#   Epoch 100/100, Loss: 0.084951
# Training complete for run 43
# Run 43 — RMSE: 24.219662, MSE: 586.592019, NMSE: 0.0027102247
#
# ===== RUN 44/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.086734
#   Epoch 20/100, Loss: 0.086639
#   Epoch 30/100, Loss: 0.086496
#   Epoch 40/100, Loss: 0.086220
#   Epoch 50/100, Loss: 0.085921
#   Epoch 60/100, Loss: 0.085743
#   Epoch 70/100, Loss: 0.085562
#   Epoch 80/100, Loss: 0.085459
#   Epoch 90/100, Loss: 0.085307
#   Epoch 100/100, Loss: 0.085211
# Training complete for run 44
# Run 44 — RMSE: 24.083342, MSE: 580.007379, NMSE: 0.0026412844
#
# ===== RUN 45/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.087226
#   Epoch 20/100, Loss: 0.087019
#   Epoch 30/100, Loss: 0.086721
#   Epoch 40/100, Loss: 0.086354
#   Epoch 50/100, Loss: 0.085987
#   Epoch 60/100, Loss: 0.085756
#   Epoch 70/100, Loss: 0.085623
#   Epoch 80/100, Loss: 0.085542
#   Epoch 90/100, Loss: 0.085488
#   Epoch 100/100, Loss: 0.085449
# Training complete for run 45
# Run 45 — RMSE: 24.456515, MSE: 598.121122, NMSE: 0.0027504698
#
# ===== RUN 46/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.088083
#   Epoch 20/100, Loss: 0.088397
#   Epoch 30/100, Loss: 0.088388
#   Epoch 40/100, Loss: 0.088335
#   Epoch 50/100, Loss: 0.088288
#   Epoch 60/100, Loss: 0.088244
#   Epoch 70/100, Loss: 0.088192
#   Epoch 80/100, Loss: 0.088133
#   Epoch 90/100, Loss: 0.088070
#   Epoch 100/100, Loss: 0.088014
# Training complete for run 46
# Run 46 — RMSE: 24.460459, MSE: 598.314049, NMSE: 0.0027501106
#
# ===== RUN 47/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.086832
#   Epoch 20/100, Loss: 0.086648
#   Epoch 30/100, Loss: 0.086494
#   Epoch 40/100, Loss: 0.086440
#   Epoch 50/100, Loss: 0.086331
#   Epoch 60/100, Loss: 0.086214
#   Epoch 70/100, Loss: 0.086105
#   Epoch 80/100, Loss: 0.086009
#   Epoch 90/100, Loss: 0.085930
#   Epoch 100/100, Loss: 0.085762
# Training complete for run 47
# Run 47 — RMSE: 24.251350, MSE: 588.127982, NMSE: 0.0026600947
#
# ===== RUN 48/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.086829
#   Epoch 20/100, Loss: 0.086408
#   Epoch 30/100, Loss: 0.085622
#   Epoch 40/100, Loss: 0.085191
#   Epoch 50/100, Loss: 0.085056
#   Epoch 60/100, Loss: 0.084986
#   Epoch 70/100, Loss: 0.084963
#   Epoch 80/100, Loss: 0.084920
#   Epoch 90/100, Loss: 0.084868
#   Epoch 100/100, Loss: 0.084856
# Training complete for run 48
# ...
#
# ===== RUN 25/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.115412
#   Epoch 20/100, Loss: 0.114978
#   Epoch 30/100, Loss: 0.114533
#   Epoch 40/100, Loss: 0.114194
#   Epoch 50/100, Loss: 0.113944
#   Epoch 60/100, Loss: 0.113759
#   Epoch 70/100, Loss: 0.113602
#   Epoch 80/100, Loss: 0.113467
#   Epoch 90/100, Loss: 0.113332
#   Epoch 100/100, Loss: 0.113202
# Training complete for run 25
# Run 25 — RMSE: 30.396599, MSE: 923.953260, NMSE: 0.0042928219
#
# ===== RUN 26/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.115593
#   Epoch 20/100, Loss: 0.115213
#   Epoch 30/100, Loss: 0.114643
#   Epoch 40/100, Loss: 0.114214
#   Epoch 50/100, Loss: 0.114020
#   Epoch 60/100, Loss: 0.113909
#   Epoch 70/100, Loss: 0.113844
#   Epoch 80/100, Loss: 0.113793
#   Epoch 90/100, Loss: 0.113753
#   Epoch 100/100, Loss: 0.113729
# Training complete for run 26
# Run 26 — RMSE: 30.337513, MSE: 920.364719, NMSE: 0.0042697291
#
# ===== RUN 27/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.115893
#   Epoch 20/100, Loss: 0.115341
#   Epoch 30/100, Loss: 0.114874
#   Epoch 40/100, Loss: 0.114519
#   Epoch 50/100, Loss: 0.114323
#   Epoch 60/100, Loss: 0.114182
#   Epoch 70/100, Loss: 0.114045
#   Epoch 80/100, Loss: 0.113911
#   Epoch 90/100, Loss: 0.113769
#   Epoch 100/100, Loss: 0.113613
# Training complete for run 27
# Run 27 — RMSE: 30.313188, MSE: 918.889364, NMSE: 0.0042796938
#
# ===== RUN 28/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.115224
#   Epoch 20/100, Loss: 0.114781
#   Epoch 30/100, Loss: 0.114467
#   Epoch 40/100, Loss: 0.114265
#   Epoch 50/100, Loss: 0.114089
#   Epoch 60/100, Loss: 0.113858
#   Epoch 70/100, Loss: 0.113627
#   Epoch 80/100, Loss: 0.113394
#   Epoch 90/100, Loss: 0.113177
#   Epoch 100/100, Loss: 0.112982
# Training complete for run 28
# Run 28 — RMSE: 30.388668, MSE: 923.471150, NMSE: 0.0042907591
#
# ===== RUN 29/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.114176
#   Epoch 20/100, Loss: 0.113653
#   Epoch 30/100, Loss: 0.113350
#   Epoch 40/100, Loss: 0.113152
#   Epoch 50/100, Loss: 0.113035
#   Epoch 60/100, Loss: 0.112949
#   Epoch 70/100, Loss: 0.112873
#   Epoch 80/100, Loss: 0.112826
#   Epoch 90/100, Loss: 0.112774
#   Epoch 100/100, Loss: 0.112720
# Training complete for run 29
# Run 29 — RMSE: 30.408933, MSE: 924.703234, NMSE: 0.0043160657
#
# ===== RUN 30/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.114656
#   Epoch 20/100, Loss: 0.114289
#   Epoch 30/100, Loss: 0.113709
#   Epoch 40/100, Loss: 0.113448
#   Epoch 50/100, Loss: 0.113217
#   Epoch 60/100, Loss: 0.113000
#   Epoch 70/100, Loss: 0.112764
#   Epoch 80/100, Loss: 0.112550
#   Epoch 90/100, Loss: 0.112347
#   Epoch 100/100, Loss: 0.112187
# Training complete for run 30
# Run 30 — RMSE: 30.317171, MSE: 919.130885, NMSE: 0.0042770574
#
# ===== RUN 31/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.114304
#   Epoch 20/100, Loss: 0.113701
#   Epoch 30/100, Loss: 0.113383
#   Epoch 40/100, Loss: 0.113207
#   Epoch 50/100, Loss: 0.113101
#   Epoch 60/100, Loss: 0.113030
#   Epoch 70/100, Loss: 0.112954
#   Epoch 80/100, Loss: 0.112885
#   Epoch 90/100, Loss: 0.112818
#   Epoch 100/100, Loss: 0.112746
# Training complete for run 31
# Run 31 — RMSE: 30.513588, MSE: 931.079052, NMSE: 0.0043657999
#
# ===== RUN 32/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.115886
#   Epoch 20/100, Loss: 0.115398
#   Epoch 30/100, Loss: 0.114985
#   Epoch 40/100, Loss: 0.114584
#   Epoch 50/100, Loss: 0.114291
#   Epoch 60/100, Loss: 0.114119
#   Epoch 70/100, Loss: 0.113995
#   Epoch 80/100, Loss: 0.113883
#   Epoch 90/100, Loss: 0.113773
#   Epoch 100/100, Loss: 0.113660
# Training complete for run 32
# Run 32 — RMSE: 30.403588, MSE: 924.378192, NMSE: 0.0043095595
#
# ===== RUN 33/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.115724
#   Epoch 20/100, Loss: 0.115604
#   Epoch 30/100, Loss: 0.115396
#   Epoch 40/100, Loss: 0.115203
#   Epoch 50/100, Loss: 0.115028
#   Epoch 60/100, Loss: 0.114822
#   Epoch 70/100, Loss: 0.114481
#   Epoch 80/100, Loss: 0.114140
#   Epoch 90/100, Loss: 0.113864
#   Epoch 100/100, Loss: 0.113617
# Training complete for run 33
# Run 33 — RMSE: 30.495336, MSE: 929.965511, NMSE: 0.0043306683
#
# ===== RUN 34/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.115575
#   Epoch 20/100, Loss: 0.115171
#   Epoch 30/100, Loss: 0.114912
#   Epoch 40/100, Loss: 0.114495
#   Epoch 50/100, Loss: 0.114206
#   Epoch 60/100, Loss: 0.113974
#   Epoch 70/100, Loss: 0.113762
#   Epoch 80/100, Loss: 0.113558
#   Epoch 90/100, Loss: 0.113331
#   Epoch 100/100, Loss: 0.113145
# Training complete for run 34
# Run 34 — RMSE: 30.353222, MSE: 921.318112, NMSE: 0.0042954181
#
# ===== RUN 35/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.115559
#   Epoch 20/100, Loss: 0.115229
#   Epoch 30/100, Loss: 0.114949
#   Epoch 40/100, Loss: 0.114746
#   Epoch 50/100, Loss: 0.114596
#   Epoch 60/100, Loss: 0.114455
#   Epoch 70/100, Loss: 0.114314
#   Epoch 80/100, Loss: 0.114151
#   Epoch 90/100, Loss: 0.113976
#   Epoch 100/100, Loss: 0.113814
# Training complete for run 35
# Run 35 — RMSE: 30.338608, MSE: 920.431155, NMSE: 0.0042809161
#
# ===== RUN 36/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.115418
#   Epoch 20/100, Loss: 0.115038
#   Epoch 30/100, Loss: 0.114590
#   Epoch 40/100, Loss: 0.114214
#   Epoch 50/100, Loss: 0.113944
#   Epoch 60/100, Loss: 0.113773
#   Epoch 70/100, Loss: 0.113631
#   Epoch 80/100, Loss: 0.113503
#   Epoch 90/100, Loss: 0.113417
#   Epoch 100/100, Loss: 0.113334
# Training complete for run 36
# Run 36 — RMSE: 30.273535, MSE: 916.486949, NMSE: 0.0042578141
#
# ===== RUN 37/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.113932
#   Epoch 20/100, Loss: 0.113521
#   Epoch 30/100, Loss: 0.113275
#   Epoch 40/100, Loss: 0.113116
#   Epoch 50/100, Loss: 0.112995
#   Epoch 60/100, Loss: 0.112896
#   Epoch 70/100, Loss: 0.112790
#   Epoch 80/100, Loss: 0.112698
#   Epoch 90/100, Loss: 0.112598
#   Epoch 100/100, Loss: 0.112447
# Training complete for run 37
# Run 37 — RMSE: 30.468858, MSE: 928.351284, NMSE: 0.0043289673
#
# ===== RUN 38/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.114267
#   Epoch 20/100, Loss: 0.113925
#   Epoch 30/100, Loss: 0.113664
#   Epoch 40/100, Loss: 0.113466
#   Epoch 50/100, Loss: 0.113241
#   Epoch 60/100, Loss: 0.113054
#   Epoch 70/100, Loss: 0.112907
#   Epoch 80/100, Loss: 0.112801
#   Epoch 90/100, Loss: 0.112698
#   Epoch 100/100, Loss: 0.112587
# Training complete for run 38
# Run 38 — RMSE: 30.460914, MSE: 927.867283, NMSE: 0.0043275173
#
# ===== RUN 39/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.115484
#   Epoch 20/100, Loss: 0.115518
#   Epoch 30/100, Loss: 0.115200
#   Epoch 40/100, Loss: 0.114816
#   Epoch 50/100, Loss: 0.114525
#   Epoch 60/100, Loss: 0.114303
#   Epoch 70/100, Loss: 0.114104
#   Epoch 80/100, Loss: 0.113996
#   Epoch 90/100, Loss: 0.113933
#   Epoch 100/100, Loss: 0.113874
# Training complete for run 39
# Run 39 — RMSE: 30.309339, MSE: 918.656024, NMSE: 0.0042528234
#
# ===== RUN 40/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.114085
#   Epoch 20/100, Loss: 0.113744
#   Epoch 30/100, Loss: 0.113459
#   Epoch 40/100, Loss: 0.113265
#   Epoch 50/100, Loss: 0.113095
#   Epoch 60/100, Loss: 0.112965
#   Epoch 70/100, Loss: 0.112837
#   Epoch 80/100, Loss: 0.112706
#   Epoch 90/100, Loss: 0.112585
#   Epoch 100/100, Loss: 0.112459
# Training complete for run 40
# Run 40 — RMSE: 30.512146, MSE: 930.991030, NMSE: 0.0043520954
#
# ===== RUN 41/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.114085
#   Epoch 20/100, Loss: 0.113586
#   Epoch 30/100, Loss: 0.113337
#   Epoch 40/100, Loss: 0.113143
#   Epoch 50/100, Loss: 0.112870
#   Epoch 60/100, Loss: 0.112610
#   Epoch 70/100, Loss: 0.112445
#   Epoch 80/100, Loss: 0.112343
#   Epoch 90/100, Loss: 0.112257
#   Epoch 100/100, Loss: 0.112183
# Training complete for run 41
# Run 41 — RMSE: 30.572023, MSE: 934.648617, NMSE: 0.0043817346
#
# ===== RUN 42/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.115278
#   Epoch 20/100, Loss: 0.115068
#   Epoch 30/100, Loss: 0.114736
#   Epoch 40/100, Loss: 0.114473
#   Epoch 50/100, Loss: 0.114251
#   Epoch 60/100, Loss: 0.113973
#   Epoch 70/100, Loss: 0.113711
#   Epoch 80/100, Loss: 0.113478
#   Epoch 90/100, Loss: 0.113266
#   Epoch 100/100, Loss: 0.113072
# Training complete for run 42
# Run 42 — RMSE: 30.456151, MSE: 927.577158, NMSE: 0.0043221292
#
# ===== RUN 43/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.114156
#   Epoch 20/100, Loss: 0.113820
#   Epoch 30/100, Loss: 0.113559
#   Epoch 40/100, Loss: 0.113372
#   Epoch 50/100, Loss: 0.113200
#   Epoch 60/100, Loss: 0.113066
#   Epoch 70/100, Loss: 0.112953
#   Epoch 80/100, Loss: 0.112853
#   Epoch 90/100, Loss: 0.112743
#   Epoch 100/100, Loss: 0.112635
# Training complete for run 43
# Run 43 — RMSE: 30.482351, MSE: 929.173713, NMSE: 0.0043346945
#
# ===== RUN 44/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.114317
#   Epoch 20/100, Loss: 0.113837
#   Epoch 30/100, Loss: 0.113486
#   Epoch 40/100, Loss: 0.113178
#   Epoch 50/100, Loss: 0.112936
#   Epoch 60/100, Loss: 0.112705
#   Epoch 70/100, Loss: 0.112521
#   Epoch 80/100, Loss: 0.112341
#   Epoch 90/100, Loss: 0.112191
#   Epoch 100/100, Loss: 0.112031
# Training complete for run 44
# Run 44 — RMSE: 30.379223, MSE: 922.897216, NMSE: 0.0043071155
#
# ===== RUN 45/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.115470
#   Epoch 20/100, Loss: 0.114745
#   Epoch 30/100, Loss: 0.114243
#   Epoch 40/100, Loss: 0.113877
#   Epoch 50/100, Loss: 0.113672
#   Epoch 60/100, Loss: 0.113504
#   Epoch 70/100, Loss: 0.113425
#   Epoch 80/100, Loss: 0.113359
#   Epoch 90/100, Loss: 0.113282
#   Epoch 100/100, Loss: 0.113191
# Training complete for run 45
# Run 45 — RMSE: 30.211420, MSE: 912.729889, NMSE: 0.0042278918
#
# ===== RUN 46/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.115580
#   Epoch 20/100, Loss: 0.115342
#   Epoch 30/100, Loss: 0.115071
#   Epoch 40/100, Loss: 0.114858
#   Epoch 50/100, Loss: 0.114692
#   Epoch 60/100, Loss: 0.114561
#   Epoch 70/100, Loss: 0.114450
#   Epoch 80/100, Loss: 0.114358
#   Epoch 90/100, Loss: 0.114288
#   Epoch 100/100, Loss: 0.114216
# Training complete for run 46
# Run 46 — RMSE: 30.373289, MSE: 922.536703, NMSE: 0.0042783958
#
# ===== RUN 47/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.114104
#   Epoch 20/100, Loss: 0.113717
#   Epoch 30/100, Loss: 0.113481
#   Epoch 40/100, Loss: 0.113284
#   Epoch 50/100, Loss: 0.113126
#   Epoch 60/100, Loss: 0.112928
#   Epoch 70/100, Loss: 0.112793
#   Epoch 80/100, Loss: 0.112672
#   Epoch 90/100, Loss: 0.112564
#   Epoch 100/100, Loss: 0.112462
# Training complete for run 47
# Run 47 — RMSE: 30.515965, MSE: 931.224145, NMSE: 0.0043606096
#
# ===== RUN 48/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.114005
#   Epoch 20/100, Loss: 0.113595
#   Epoch 30/100, Loss: 0.113301
#   Epoch 40/100, Loss: 0.113083
#   Epoch 50/100, Loss: 0.112840
#   Epoch 60/100, Loss: 0.112614
#   Epoch 70/100, Loss: 0.112474
#   Epoch 80/100, Loss: 0.112362
#   Epoch 90/100, Loss: 0.112276
#   Epoch 100/100, Loss: 0.112209
# Training complete for run 48
# Run 48 — RMSE: 30.552955, MSE: 933.483059, NMSE: 0.0043743275
#
# ===== RUN 49/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.115500
#   Epoch 20/100, Loss: 0.114842
#   Epoch 30/100, Loss: 0.114323
#   Epoch 40/100, Loss: 0.114016
#   Epoch 50/100, Loss: 0.113835
#   Epoch 60/100, Loss: 0.113684
#   Epoch 70/100, Loss: 0.113583
#   Epoch 80/100, Loss: 0.113537
#   Epoch 90/100, Loss: 0.113477
#   Epoch 100/100, Loss: 0.113432
# Training complete for run 49
# Run 49 — RMSE: 30.317009, MSE: 919.121064, NMSE: 0.0042665861
#
# ===== RUN 50/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.114636
#   Epoch 20/100, Loss: 0.114306
#   Epoch 30/100, Loss: 0.113622
#   Epoch 40/100, Loss: 0.113284
#   Epoch 50/100, Loss: 0.113044
#   Epoch 60/100, Loss: 0.112864
#   Epoch 70/100, Loss: 0.112698
#   Epoch 80/100, Loss: 0.112541
#   Epoch 90/100, Loss: 0.112398
#   Epoch 100/100, Loss: 0.112267
# Training complete for run 50
# Run 50 — RMSE: 30.414177, MSE: 925.022162, NMSE: 0.0043197854
#
# ===== RUN 51/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.114775
#   Epoch 20/100, Loss: 0.114575
#   Epoch 30/100, Loss: 0.114277
#   Epoch 40/100, Loss: 0.113582
#   Epoch 50/100, Loss: 0.113248
#   Epoch 60/100, Loss: 0.112982
#   Epoch 70/100, Loss: 0.112716
#   Epoch 80/100, Loss: 0.112453
#   Epoch 90/100, Loss: 0.112252
#   Epoch 100/100, Loss: 0.112088
# Training complete for run 51
# Run 51 — RMSE: 30.410849, MSE: 924.819742, NMSE: 0.0043228533
#
# ===== RUN 52/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.114988
#   Epoch 20/100, Loss: 0.114709
#   Epoch 30/100, Loss: 0.114358
#   Epoch 40/100, Loss: 0.114121
#   Epoch 50/100, Loss: 0.113994
#   Epoch 60/100, Loss: 0.113915
#   Epoch 70/100, Loss: 0.113863
#   Epoch 80/100, Loss: 0.113826
#   Epoch 90/100, Loss: 0.113755
#   Epoch 100/100, Loss: 0.113764
# Training complete for run 52
# Run 52 — RMSE: 30.372064, MSE: 922.462261, NMSE: 0.0042719480
#
# ===== RUN 53/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.115969
#   Epoch 20/100, Loss: 0.115334
#   Epoch 30/100, Loss: 0.114859
#   Epoch 40/100, Loss: 0.114519
#   Epoch 50/100, Loss: 0.114294
#   Epoch 60/100, Loss: 0.114162
#   Epoch 70/100, Loss: 0.114041
#   Epoch 80/100, Loss: 0.113974
#   Epoch 90/100, Loss: 0.113890
#   Epoch 100/100, Loss: 0.113770
# Training complete for run 53
# Run 53 — RMSE: 30.360823, MSE: 921.779583, NMSE: 0.0042943958
#
# ===== RUN 54/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.115624
#   Epoch 20/100, Loss: 0.115045
#   Epoch 30/100, Loss: 0.114906
#   Epoch 40/100, Loss: 0.114660
#   Epoch 50/100, Loss: 0.114223
#   Epoch 60/100, Loss: 0.113823
#   Epoch 70/100, Loss: 0.113489
#   Epoch 80/100, Loss: 0.113293
#   Epoch 90/100, Loss: 0.113148
#   Epoch 100/100, Loss: 0.113033
# Training complete for run 54
# Run 54 — RMSE: 30.396436, MSE: 923.943292, NMSE: 0.0042960764
#
# ===== RUN 55/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.116139
#   Epoch 20/100, Loss: 0.115339
#   Epoch 30/100, Loss: 0.114724
#   Epoch 40/100, Loss: 0.114355
#   Epoch 50/100, Loss: 0.114112
#   Epoch 60/100, Loss: 0.113961
#   Epoch 70/100, Loss: 0.113856
#   Epoch 80/100, Loss: 0.113800
#   Epoch 90/100, Loss: 0.113745
#   Epoch 100/100, Loss: 0.113671
# Training complete for run 55
# Run 55 — RMSE: 30.363446, MSE: 921.938847, NMSE: 0.0042778699
#
# ===== RUN 56/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.114244
#   Epoch 20/100, Loss: 0.113972
#   Epoch 30/100, Loss: 0.113702
#   Epoch 40/100, Loss: 0.113379
#   Epoch 50/100, Loss: 0.113119
#   Epoch 60/100, Loss: 0.112891
#   Epoch 70/100, Loss: 0.112720
#   Epoch 80/100, Loss: 0.112597
#   Epoch 90/100, Loss: 0.112497
#   Epoch 100/100, Loss: 0.112393
# Training complete for run 56
# Run 56 — RMSE: 30.485905, MSE: 929.390420, NMSE: 0.0043407498
#
# ===== RUN 57/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.113593
#   Epoch 20/100, Loss: 0.113344
#   Epoch 30/100, Loss: 0.113176
#   Epoch 40/100, Loss: 0.113036
#   Epoch 50/100, Loss: 0.112903
#   Epoch 60/100, Loss: 0.112767
#   Epoch 70/100, Loss: 0.112623
#   Epoch 80/100, Loss: 0.112471
#   Epoch 90/100, Loss: 0.112344
#   Epoch 100/100, Loss: 0.112216
# Training complete for run 57
# Run 57 — RMSE: 30.460206, MSE: 927.824180, NMSE: 0.0043304138
#
# ===== RUN 58/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.113953
#   Epoch 20/100, Loss: 0.113666
#   Epoch 30/100, Loss: 0.113467
#   Epoch 40/100, Loss: 0.113288
#   Epoch 50/100, Loss: 0.113132
#   Epoch 60/100, Loss: 0.112995
#   Epoch 70/100, Loss: 0.112875
#   Epoch 80/100, Loss: 0.112745
#   Epoch 90/100, Loss: 0.112622
#   Epoch 100/100, Loss: 0.112482
# Training complete for run 58
# Run 58 — RMSE: 30.510656, MSE: 930.900111, NMSE: 0.0043540403
#
# ===== RUN 59/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.113927
#   Epoch 20/100, Loss: 0.113617
#   Epoch 30/100, Loss: 0.113440
#   Epoch 40/100, Loss: 0.113228
#   Epoch 50/100, Loss: 0.113103
#   Epoch 60/100, Loss: 0.113005
#   Epoch 70/100, Loss: 0.112918
#   Epoch 80/100, Loss: 0.112845
#   Epoch 90/100, Loss: 0.112771
#   Epoch 100/100, Loss: 0.112714
# Training complete for run 59
# Run 59 — RMSE: 30.483587, MSE: 929.249077, NMSE: 0.0043423421
#
# ===== RUN 60/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.114736
#   Epoch 20/100, Loss: 0.113833
#   Epoch 30/100, Loss: 0.113392
#   Epoch 40/100, Loss: 0.113176
#   Epoch 50/100, Loss: 0.113045
#   Epoch 60/100, Loss: 0.112954
#   Epoch 70/100, Loss: 0.112876
#   Epoch 80/100, Loss: 0.112819
#   Epoch 90/100, Loss: 0.112726
#   Epoch 100/100, Loss: 0.112658
# Training complete for run 60
# Run 60 — RMSE: 30.409778, MSE: 924.754623, NMSE: 0.0043246345
#
# ===== STATS FOR NOISE 10.0% (60 runs) =====
# RMSE: 30.403414 +/- 0.074173
# MSE:  924.373093 +/- 4.510010
# NMSE: 0.0043042646 +/- 0.0000330504
# Best run: 45 (RMSE: 30.211420)

# %% [markdown]
# ## Results

# %%
# ============================================================
# Final Metrics Summary & Plots per Noise Level
# ============================================================
from tabulate import tabulate

for entry in _molab_results:
    lam = entry[0]
    mean_rmse, std_rmse = entry[1], entry[2]
    mean_mse, std_mse = entry[3], entry[4]
    mean_nmse, std_nmse = entry[5], entry[6]
    best_rmse_val = entry[7]
    best_predictions = entry[8]
    best_losses = entry[9]
    raw_values_for_plot = entry[10]
    
    print("\n" + "="*80)
    print(f"RESULTS FOR NOISE LEVEL: {lam*100:.1f}%")
    print("="*80)
    
    print(f'Mean RMSE: {mean_rmse:.6f} +/- {std_rmse:.6f}')
    print(f'Mean MSE:  {mean_mse:.6f} +/- {std_mse:.6f}')
    print(f'Mean NMSE: {mean_nmse:.10f} +/- {std_nmse:.10f}')
    print(f'Best RMSE: {best_rmse_val:.6f}')
    
    actual = raw_values_for_plot[-60:]
    
    plt.figure(figsize=(12, 5))
    plt.plot(actual, label='Actual', color='blue', linewidth=1.5)
    plt.plot(best_predictions, label='Predicted (Best Run)', color='red',
             linewidth=1.5, linestyle='--')
    plt.title(f'Predictions vs Actual (Noise {lam*100:.1f}%)')
    plt.xlabel('Time Step')
    plt.ylabel('Value')
    plt.legend()
    plt.grid(True, alpha=0.3)
    plt.tight_layout()
    plt.show()

    plt.figure(figsize=(12, 4))
    plt.plot(best_losses, color='green', linewidth=1.0)
    plt.title(f'Training Loss (Best Run, Noise {lam*100:.1f}%)')
    plt.xlabel('Epoch')
    plt.ylabel('MSE Loss')
    plt.grid(True, alpha=0.3)
    plt.tight_layout()
    plt.show()

print("\n" + "="*80)
print("FINAL RESULTS TABLE ACROSS ALL NOISE LEVELS")
print("="*80)
df_res = pd.DataFrame(
    [[r[0], f'{r[1]:.6f} +/- {r[2]:.6f}', f'{r[3]:.6f} +/- {r[4]:.6f}', 
      f'{r[5]:.10f} +/- {r[6]:.10f}', f'{r[7]:.6f}'] for r in _molab_results],
    columns=['Noise Level', 'RMSE (mean+/-std)', 'MSE (mean+/-std)', 'NMSE (mean+/-std)', 'Best RMSE']
)
print(tabulate(df_res, headers='keys', tablefmt='github', showindex=False))
# Out:
# ================================================================================
# RESULTS FOR NOISE LEVEL: 0.0%
# ================================================================================
# Mean RMSE: 24.261613 +/- 0.112514
# Mean MSE:  588.638526 +/- 5.461513
# Mean NMSE: 0.0027008200 +/- 0.0000299271
# Best RMSE: 24.054753
# ================================================================================
# RESULTS FOR NOISE LEVEL: 0.5%
# ================================================================================
# Mean RMSE: 24.270619 +/- 0.108168
# Mean MSE:  589.074665 +/- 5.248856
# Mean NMSE: 0.0027053458 +/- 0.0000274372
# Best RMSE: 24.004665
# ================================================================================
# RESULTS FOR NOISE LEVEL: 5.0%
# ================================================================================
# Mean RMSE: 25.816434 +/- 0.197894
# Mean MSE:  666.527428 +/- 10.204695
# Mean NMSE: 0.0030878451 +/- 0.0000420095
# Best RMSE: 25.299608
# ================================================================================
# RESULTS FOR NOISE LEVEL: 10.0%
# ================================================================================
# Mean RMSE: 30.403414 +/- 0.074173
# Mean MSE:  924.373093 +/- 4.510010
# Mean NMSE: 0.0043042646 +/- 0.0000330504
# Best RMSE: 30.211420
# ================================================================================
# FINAL RESULTS TABLE ACROSS ALL NOISE LEVELS
# ================================================================================
# |   Noise Level | RMSE (mean+/-std)      | MSE (mean+/-std)         | NMSE (mean+/-std)             |   Best RMSE |
# |---------------|------------------------|--------------------------|-------------------------------|-------------|
# |         0     | 24.261613 +/- 0.112514 | 588.638526 +/- 5.461513  | 0.0027008200 +/- 0.0000299271 |     24.0548 |
# |         0.005 | 24.270619 +/- 0.108168 | 589.074665 +/- 5.248856  | 0.0027053458 +/- 0.0000274372 |     24.0047 |
# |         0.05  | 25.816434 +/- 0.197894 | 666.527428 +/- 10.204695 | 0.0030878451 +/- 0.0000420095 |     25.2996 |
# |         0.1   | 30.403414 +/- 0.074173 | 924.373093 +/- 4.510010  | 0.0043042646 +/- 0.0000330504 |     30.2114 |

# %% [markdown]
# ## Observations
#
# ### Gaussian Noise robustness on Dow Jones Industrial Index
#
# **Run the notebook to populate results.**
