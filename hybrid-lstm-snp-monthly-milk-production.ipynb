# %% [markdown]
# # Notebook 5: Hybrid LSTM-SNP (Fuzzy Feature Aug + Fuzzy Gates)
#
# **Dataset**: Monthly Milk Production
#
# ## Description
# This notebook implements the **hybrid model** that combines:
# 1. **Fuzzy Feature Augmentation** (from Notebook 2): Input is augmented with fuzzy-derived features
# 2. **Fuzzy Gate Replacement** (from Notebook 3): Gates use fuzzy inference instead of sigmoid
#
# This represents the most complex integration of fuzzy logic with LSTM-SNP. Gradient clipping
# (norm=1.0) and careful weight initialization are applied for training stability.
#
# The interaction between input-level and gate-level fuzzy reasoning is documented and analyzed.

# %% [markdown]
# ## Theory: Hybrid Fuzzy LSTM-SNP
#
# This model combines two fuzzy integration strategies:
#
# ### 1. Input-Level: Fuzzy Feature Augmentation
# Same as Notebook 2:
# - Fuzzy inference on $x(t)$ and $x(t-1)$
# - Augmented input: $x'(t) = [x(t), y_{fuzzy}]$
# - Input dimension becomes 2
#
# ### 2. Gate-Level: Fuzzy Gate Replacement
# Same as Notebook 3:
# - Gates r, c, o computed via fuzzy inference
# - Fixed Gaussian MFs, trainable consequent parameters
# - Generation gate a retains tanh
#
# ### Interaction Between Levels
# - The fuzzy-augmented input provides richer information to the cell
# - The fuzzy gates process this enriched input with adaptive, rule-based gating
# - This creates a two-level fuzzy reasoning pipeline
#
# ### Stability Measures
# - Gradient clipping (norm ≤ 1.0)
# - Careful weight initialization
# - Fuzzy weights are clipped to valid ranges

# %% [markdown]
# ## Model Architecture & Implementation

# %%
# ============================================================
# ALL IMPORTS
# ============================================================

import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras import layers
from tensorflow.keras import Model
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from math import sqrt
import matplotlib.pyplot as plt

print(f"TensorFlow version: {tf.__version__}")
print(f"NumPy version: {np.__version__}")
# Out:
# TensorFlow version: 2.20.0
# NumPy version: 2.0.2

# %% [markdown]
# ### Fuzzy Inference System (NumPy — for preprocessing)

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

# ============================================================
# Fuzzy Inference System (NumPy — for preprocessing)
#
# Fixed Gaussian membership functions:
#   μ_low(x)  = exp(-(x - (-1))² / (2·0.5²))
#   μ_high(x) = exp(-(x - (+1))² / (2·0.5²))
#
# 4 Takagi-Sugeno rules with fixed consequent parameters:
#   IF x(t) is low  AND x(t-1) is low  → y₁ = 0.5·x(t) + 0.5·x(t-1)
#   IF x(t) is low  AND x(t-1) is high → y₂ = 0.7·x(t) + 0.3·x(t-1) - 0.1
#   IF x(t) is high AND x(t-1) is low  → y₃ = 0.3·x(t) + 0.7·x(t-1) + 0.1
#   IF x(t) is high AND x(t-1) is high → y₄ = 0.5·x(t) + 0.5·x(t-1)
#
# Output: y = Σ(wᵢ·yᵢ) / Σ(wᵢ)
# ============================================================

def gaussian_mf(x, center, sigma=0.5):
    """Fixed Gaussian membership function."""
    return np.exp(-(x - center)**2 / (2 * sigma**2))

def fuzzy_inference_numpy(x_t, x_tm1):
    """
    Compute fuzzy feature from x(t) and x(t-1).
    Uses fixed membership functions and fixed consequent parameters.
    """
    # Membership degrees
    mu_low_xt = gaussian_mf(x_t, center=-1.0)
    mu_high_xt = gaussian_mf(x_t, center=1.0)
    mu_low_xtm1 = gaussian_mf(x_tm1, center=-1.0)
    mu_high_xtm1 = gaussian_mf(x_tm1, center=1.0)

    # Rule firing strengths (product)
    w1 = mu_low_xt * mu_low_xtm1      # low-low
    w2 = mu_low_xt * mu_high_xtm1     # low-high
    w3 = mu_high_xt * mu_low_xtm1     # high-low
    w4 = mu_high_xt * mu_high_xtm1    # high-high

    # Consequent outputs (fixed linear functions)
    y1 = 0.5 * x_t + 0.5 * x_tm1
    y2 = 0.7 * x_t + 0.3 * x_tm1 - 0.1
    y3 = 0.3 * x_t + 0.7 * x_tm1 + 0.1
    y4 = 0.5 * x_t + 0.5 * x_tm1

    # Weighted average defuzzification
    numerator = w1 * y1 + w2 * y2 + w3 * y3 + w4 * y4
    denominator = w1 + w2 + w3 + w4 + 1e-8

    return numerator / denominator

# %% [markdown]
# ### Fuzzy Gate LSTM-SNP Cell

# %%
# ============================================================
# Fuzzy Gate LSTM-SNP Cell (PyTorch Implementation)
# Gates r, c, o use fuzzy inference instead of hard sigmoid.
# Generation gate 'a' keeps tanh (unchanged).
# ============================================================
import torch
import torch.nn as nn
import torch.nn.functional as F

class FuzzyGateType5(nn.Module):
    def __init__(self, hidden_size, sigma=0.5):
        super().__init__()
        self.hidden_size = hidden_size
        self.sigma = sigma
        self.mu_low = -1.0
        self.mu_high = 1.0
        
        # Rule 0 (Low)
        self.a0 = nn.Parameter(torch.empty(hidden_size).uniform_(-0.1, 0.1))
        self.b0 = nn.Parameter(torch.empty(hidden_size).uniform_(-0.1, 0.1))
        self.c0 = nn.Parameter(torch.zeros(hidden_size))
        
        # Rule 1 (High)
        self.a1 = nn.Parameter(torch.empty(hidden_size).uniform_(-0.1, 0.1))
        self.b1 = nn.Parameter(torch.empty(hidden_size).uniform_(-0.1, 0.1))
        self.c1 = nn.Parameter(torch.zeros(hidden_size))

    def _gaussian_mf(self, x, center):
        return torch.exp(-(x - center)**2 / (2.0 * self.sigma**2))

    def forward(self, z_gate, u_mean):
        w_low = self._gaussian_mf(z_gate, self.mu_low)
        w_high = self._gaussian_mf(z_gate, self.mu_high)
        
        y0 = self.a0 * z_gate + self.b0 * u_mean + self.c0
        y1 = self.a1 * z_gate + self.b1 * u_mean + self.c1
        
        numerator = w_low * y0 + w_high * y1
        denominator = w_low + w_high + 1e-8
        output = numerator / denominator
        return torch.clamp(output, 0.0, 1.0)


class FuzzyLSTMSNPCell(nn.Module):
    """
    LSTM-SNP Cell with fuzzy gate replacement.
    Gates r, c, o are computed via fuzzy inference.
    Gate a keeps tanh activation.
    """
    def __init__(self, input_size, hidden_size):
        super().__init__()
        self.input_size = input_size
        self.hidden_size = hidden_size
        
        self.W = nn.Linear(input_size, 4 * hidden_size, bias=True)
        self.U = nn.Linear(hidden_size, 4 * hidden_size, bias=True)
        
        nn.init.xavier_uniform_(self.W.weight)
        nn.init.orthogonal_(self.U.weight)
        nn.init.zeros_(self.W.bias)
        nn.init.zeros_(self.U.bias)
        
        self.fuzzy_r = FuzzyGateType5(hidden_size)
        self.fuzzy_c = FuzzyGateType5(hidden_size)
        self.fuzzy_o = FuzzyGateType5(hidden_size)

    def forward(self, x, u_prev):
        z = self.W(x) + self.U(u_prev)
        
        z0 = z[:, :self.hidden_size]
        z1 = z[:, self.hidden_size:2*self.hidden_size]
        z2 = z[:, 2*self.hidden_size:3*self.hidden_size]
        z3 = z[:, 3*self.hidden_size:]
        
        # Mean of previous state for fuzzy rule input
        u_mean = u_prev.mean(dim=-1, keepdim=True).expand_as(u_prev)
        
        r = self.fuzzy_r(z0, u_mean)
        c = self.fuzzy_c(z1, u_mean)
        o = self.fuzzy_o(z2, u_mean)
        a = torch.tanh(z3)
        
        u = r * u_prev - c * a
        h = o * a
        
        return h, u

# %% [markdown]
# ### Build Model

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

# ============================================================
# Model Construction (PyTorch)
# ============================================================

class RNNModel(nn.Module):
    def __init__(self, input_size, hidden_size):
        super().__init__()
        self.hidden_size = hidden_size
        
        # Select cell
        if 5 in [1, 2, 4]:
            self.cell = LSTMSNPCell(input_size, hidden_size)
        else:
            self.cell = FuzzyLSTMSNPCell(input_size, hidden_size)
            
        # Select output layer
        if 5 == 4:
            self.out = FuzzyOutputLayer(hidden_size)
        else:
            self.out = nn.Linear(hidden_size, 1)
            
        self.u = None
        
    def reset_states(self, batch_size, device):
        self.u = torch.zeros(batch_size, self.hidden_size, device=device)
        
    def forward(self, x):
        # x is (batch, 1, input_size)
        if self.u is None or self.u.device != x.device:
            self.reset_states(x.size(0), x.device)
            
        h, self.u = self.cell(x[:, 0, :], self.u)
        return self.out(h)
        
def build_model(input_dim, units):
    return RNNModel(input_dim, units)

# %%
# Quick model check
model = build_model(input_dim=2, units=8)
print(model)
# Out:
# RNNModel(
#   (cell): FuzzyLSTMSNPCell(
#     (W): Linear(in_features=2, out_features=32, bias=True)
#     (U): Linear(in_features=8, out_features=32, bias=True)
#     (fuzzy_r): FuzzyGateType5()
#     (fuzzy_c): FuzzyGateType5()
#     (fuzzy_o): FuzzyGateType5()
#   )
#   (out): Linear(in_features=8, out_features=1, bias=True)
# )

# %% [markdown]
# ## Data Pipeline — Monthly Milk Production

# %%
import os
for f in os.listdir('/kaggle/input/datasets/satabartosarkar/monthly-milk-production-pounds-p-csv'):
    print(f)
# Out:
# monthly-milk-production-pounds-p.csv

# %%
# ============================================================
# 1. Load Time Series Data
# ============================================================
series = pd.read_csv(
    '/kaggle/input/datasets/satabartosarkar/monthly-milk-production-pounds-p-csv/monthly-milk-production-pounds-p.csv',
    header=0,
    parse_dates=[0],
    index_col=0
)

original_raw_values = series.values.flatten()
print(f"Base data shape: {original_raw_values.shape}")
print(f"First 5 values: {original_raw_values[:5]}")
# Out:
# Base data shape: (168,)
# First 5 values: [589 561 640 656 727]

# %%
# ============================================================
# 2. First-Order Differencing
# ============================================================

def difference(dataset, interval=1):
    diff = []
    for i in range(interval, len(dataset)):
        value = dataset[i] - dataset[i - interval]
        diff.append(value)
    return np.array(diff)

# %%
# ============================================================
# 3. Convert to Supervised Learning Format (lag=1)
# ============================================================

def timeseries_to_supervised(data, lag=1):
    df = pd.DataFrame(data)
    columns = [df.shift(i) for i in range(1, lag+1)]
    columns.append(df)
    df = pd.concat(columns, axis=1)
    df.fillna(0, inplace=True)
    return df.values

# %%
# ============================================================
# 4-5-6. Split / Scale / Reshape (inside noise loop below)
# ============================================================
# - Last 60 for test, rest for training, NO validation
# - MinMaxScaler(-1, 1)
# - Fuzzy augmentation: fuzzy_inference_numpy(x_t, x_tm1) -> input_dim=2
print("Split: last 60 for test, rest for training, no validation")
print("Fuzzy augmentation: input_dim=2")
# Out:
# Split: last 60 for test, rest for training, no validation
# Fuzzy augmentation: input_dim=2

# %% [markdown]
# ## Training Loop

# %%
# ============================================================
# Gaussian Noise Evaluation + 60-Run Experiment Protocol (PyTorch)
# ============================================================
import torch
import torch.nn as nn

s_x = np.std(original_raw_values)
noise_levels = [0.0, 0.005, 0.05, 0.10]
_molab_results = []

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"\n--- [PyTorch] RUNNING ON {device} ---\n")

for lam in noise_levels:
    sigma = lam * s_x
    print("\n" + "="*80)
    print(f"EVALUATING NOISE LEVEL: {lam*100:.1f}% (lambda={lam}, sigma={sigma:.6f})")
    print("="*80 + "\n")
    
    np.random.seed(42)
    torch.manual_seed(42)
    noise = np.random.normal(0, sigma, size=original_raw_values.shape)
    raw_values = original_raw_values + noise
    
    # 2. Difference
    diff_values = difference(raw_values, 1)
    # 3. Supervised (lag=1)
    supervised = timeseries_to_supervised(diff_values, 1)
    # 4. Split (Last 60 for test, NO validation)
    train, test = supervised[:-60], supervised[-60:]
    # 5. Scale
    scaler = MinMaxScaler(feature_range=(-1, 1))
    scaler.fit(train)
    train_scaled = scaler.transform(train)
    test_scaled = scaler.transform(test)
    
    # 6. Reshape with Fuzzy Feature Augmentation (input_dim=2)
    X_train_raw = train_scaled[:, 0:1]
    y_train = train_scaled[:, 1]
    
    X_train_fuzzy = np.zeros((X_train_raw.shape[0], 2))
    for i in range(X_train_raw.shape[0]):
        x_t = X_train_raw[i, 0]
        x_tm1 = X_train_raw[i-1, 0] if i > 0 else x_t
        y_fuzz = fuzzy_inference_numpy(x_t, x_tm1)
        X_train_fuzzy[i, 0] = x_t
        X_train_fuzzy[i, 1] = y_fuzz
    
    X_train = X_train_fuzzy.reshape((X_train_fuzzy.shape[0], 1, 2))
    
    print(f"X_train shape: {X_train.shape}, y_train shape: {y_train.shape}")
    
    all_rmse = []
    all_mse = []
    all_nmse = []
    all_predictions = []
    all_losses = []
    
    for run in range(60):
        print(f'\n===== RUN {run+1}/60 [Noise {lam*100:.1f}%] =====')
        
        np.random.seed(run)
        torch.manual_seed(run)
        
        model = build_model(input_dim=2, units=8).to(device)
        optimizer = torch.optim.Adam(model.parameters(), lr=0.001)
        criterion = nn.MSELoss()
        
        # Pre-tensorize training data
        X_train_t = torch.tensor(X_train, dtype=torch.float32).to(device)
        y_train_t = torch.tensor(y_train, dtype=torch.float32).to(device)
        n_samples = X_train_t.size(0)
        
        run_losses = []
        for epoch in range(100):
            model.train()
            model.reset_states(1, device)
            
            epoch_loss = 0.0
            for i in range(n_samples):
                x_i = X_train_t[i:i+1]
                y_i = y_train_t[i:i+1]
                
                optimizer.zero_grad()
                pred = model(x_i)
                loss = criterion(pred.squeeze(-1), y_i)
                loss.backward()
                torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)
                optimizer.step()
                model.u = model.u.detach()
                epoch_loss += loss.item()
            
            avg_loss = epoch_loss / n_samples
            run_losses.append(avg_loss)
            if (epoch+1) % 10 == 0:
                print(f"  Epoch {epoch+1}/100, Loss: {avg_loss:.6f}")
        
        all_losses.append(run_losses)
        print(f'Training complete for run {run+1}')
        
        # Warm-up: condition hidden states on training data
        model.eval()
        with torch.no_grad():
            model.reset_states(1, device)
            prev_x = None
            for i in range(len(train_scaled)):
                x_t = train_scaled[i, 0]
                x_tm1 = prev_x if prev_x is not None else x_t
                y_fuzz = fuzzy_inference_numpy(x_t, x_tm1)
                X_aug = torch.tensor([x_t, y_fuzz], dtype=torch.float32).view(1, 1, 2).to(device)
                model(X_aug)
                prev_x = x_t
        
        # Test predictions (single-step) with fuzzy feature augmentation
        predictions = []
        model.eval()
        with torch.no_grad():
            x_tm1 = train_scaled[-1, 0]  # last training value
            for i in range(len(test_scaled)):
                x_t = test_scaled[i, 0]
                y_fuzz = fuzzy_inference_numpy(x_t, x_tm1)
                X_aug = torch.tensor([x_t, y_fuzz], dtype=torch.float32).view(1, 1, 2).to(device)
                yhat = model(X_aug).item()
                
                # Invert scaling
                X_raw = test_scaled[i, 0:-1]
                new_row = list(X_raw) + [yhat]
                array = np.array(new_row).reshape(1, len(new_row))
                inverted = scaler.inverse_transform(array)[0, -1]
                
                # Invert differencing
                inverted = inverted + raw_values[len(train) + i]
                predictions.append(inverted)
                
                x_tm1 = x_t  # update for next step
        
        # Compute metrics
        actual = raw_values[-len(predictions):]
        rmse = sqrt(mean_squared_error(actual, predictions))
        mse = mean_squared_error(actual, predictions)
        meanV = np.mean(actual)
        dominator = np.linalg.norm(np.array(predictions) - meanV, 2)
        nmse = mse / np.power(dominator, 2)
        
        all_rmse.append(rmse)
        all_mse.append(mse)
        all_nmse.append(nmse)
        all_predictions.append(predictions)
        
        print(f'Run {run+1} — RMSE: {rmse:.6f}, MSE: {mse:.6f}, NMSE: {nmse:.10f}')
    
    # End of 60 runs for this noise level
    best_idx = np.argmin(all_rmse)
    
    print(f'\n===== STATS FOR NOISE {lam*100:.1f}% (60 runs) =====')
    print(f'RMSE: {np.mean(all_rmse):.6f} +/- {np.std(all_rmse):.6f}')
    print(f'MSE:  {np.mean(all_mse):.6f} +/- {np.std(all_mse):.6f}')
    print(f'NMSE: {np.mean(all_nmse):.10f} +/- {np.std(all_nmse):.10f}')
    print(f'Best run: {best_idx+1} (RMSE: {all_rmse[best_idx]:.6f})')
    
    _molab_results.append([lam, 
        np.mean(all_rmse), np.std(all_rmse),
        np.mean(all_mse), np.std(all_mse),
        np.mean(all_nmse), np.std(all_nmse),
        all_rmse[best_idx], all_predictions[best_idx], all_losses[best_idx], raw_values.copy()])
# Out:
# --- [PyTorch] RUNNING ON cuda ---
#
#
# ================================================================================
# EVALUATING NOISE LEVEL: 0.0% (lambda=0.0, sigma=0.000000)
# ================================================================================
#
# X_train shape: (107, 1, 2), y_train shape: (107,)
#
# ===== RUN 1/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.279773
#   Epoch 20/100, Loss: 0.278397
#   Epoch 30/100, Loss: 0.275722
#   Epoch 40/100, Loss: 0.271224
#   Epoch 50/100, Loss: 0.265944
#   Epoch 60/100, Loss: 0.261179
#   Epoch 70/100, Loss: 0.255924
#   Epoch 80/100, Loss: 0.249535
#   Epoch 90/100, Loss: 0.241752
#   Epoch 100/100, Loss: 0.235472
# Training complete for run 1
# Run 1 — RMSE: 44.702430, MSE: 1998.307273, NMSE: 0.0077673906
#
# ===== RUN 2/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.278802
#   Epoch 20/100, Loss: 0.247106
#   Epoch 30/100, Loss: 0.236542
#   Epoch 40/100, Loss: 0.230756
#   Epoch 50/100, Loss: 0.226779
#   Epoch 60/100, Loss: 0.223000
#   Epoch 70/100, Loss: 0.219706
#   Epoch 80/100, Loss: 0.216164
#   Epoch 90/100, Loss: 0.208700
#   Epoch 100/100, Loss: 0.201060
# Training complete for run 2
# Run 2 — RMSE: 42.099823, MSE: 1772.395063, NMSE: 0.0057406712
#
# ===== RUN 3/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.278897
#   Epoch 20/100, Loss: 0.277216
#   Epoch 30/100, Loss: 0.275314
#   Epoch 40/100, Loss: 0.272589
#   Epoch 50/100, Loss: 0.266843
#   Epoch 60/100, Loss: 0.256835
#   Epoch 70/100, Loss: 0.247225
#   Epoch 80/100, Loss: 0.240446
#   Epoch 90/100, Loss: 0.234844
#   Epoch 100/100, Loss: 0.230334
# Training complete for run 3
# Run 3 — RMSE: 44.051167, MSE: 1940.505355, NMSE: 0.0072017706
#
# ===== RUN 4/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.283042
#   Epoch 20/100, Loss: 0.281670
#   Epoch 30/100, Loss: 0.279648
#   Epoch 40/100, Loss: 0.276240
#   Epoch 50/100, Loss: 0.272274
#   Epoch 60/100, Loss: 0.267401
#   Epoch 70/100, Loss: 0.261475
#   Epoch 80/100, Loss: 0.254296
#   Epoch 90/100, Loss: 0.248418
#   Epoch 100/100, Loss: 0.239049
# Training complete for run 4
# Run 4 — RMSE: 43.238846, MSE: 1869.597769, NMSE: 0.0075234310
#
# ===== RUN 5/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.279375
#   Epoch 20/100, Loss: 0.266159
#   Epoch 30/100, Loss: 0.253605
#   Epoch 40/100, Loss: 0.246938
#   Epoch 50/100, Loss: 0.239746
#   Epoch 60/100, Loss: 0.232392
#   Epoch 70/100, Loss: 0.226124
#   Epoch 80/100, Loss: 0.219711
#   Epoch 90/100, Loss: 0.211037
#   Epoch 100/100, Loss: 0.204199
# Training complete for run 5
# Run 5 — RMSE: 41.839674, MSE: 1750.558320, NMSE: 0.0062923222
#
# ===== RUN 6/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.284512
#   Epoch 20/100, Loss: 0.264701
#   Epoch 30/100, Loss: 0.240940
#   Epoch 40/100, Loss: 0.228535
#   Epoch 50/100, Loss: 0.216792
#   Epoch 60/100, Loss: 0.208457
#   Epoch 70/100, Loss: 0.201902
#   Epoch 80/100, Loss: 0.196375
#   Epoch 90/100, Loss: 0.191050
#   Epoch 100/100, Loss: 0.186279
# Training complete for run 6
# Run 6 — RMSE: 38.654444, MSE: 1494.166043, NMSE: 0.0050191908
#
# ===== RUN 7/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.280207
#   Epoch 20/100, Loss: 0.268494
#   Epoch 30/100, Loss: 0.248807
#   Epoch 40/100, Loss: 0.240615
#   Epoch 50/100, Loss: 0.237430
#   Epoch 60/100, Loss: 0.235157
#   Epoch 70/100, Loss: 0.233969
#   Epoch 80/100, Loss: 0.233071
#   Epoch 90/100, Loss: 0.232323
#   Epoch 100/100, Loss: 0.231821
# Training complete for run 7
# Run 7 — RMSE: 45.701689, MSE: 2088.644406, NMSE: 0.0072278503
#
# ===== RUN 8/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.280019
#   Epoch 20/100, Loss: 0.260096
#   Epoch 30/100, Loss: 0.253896
#   Epoch 40/100, Loss: 0.248990
#   Epoch 50/100, Loss: 0.231831
#   Epoch 60/100, Loss: 0.207253
#   Epoch 70/100, Loss: 0.194456
#   Epoch 80/100, Loss: 0.185376
#   Epoch 90/100, Loss: 0.179617
#   Epoch 100/100, Loss: 0.174957
# Training complete for run 8
# Run 8 — RMSE: 40.007553, MSE: 1600.604286, NMSE: 0.0055020056
#
# ===== RUN 9/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.278089
#   Epoch 20/100, Loss: 0.262966
#   Epoch 30/100, Loss: 0.255085
#   Epoch 40/100, Loss: 0.248792
#   Epoch 50/100, Loss: 0.241870
#   Epoch 60/100, Loss: 0.235405
#   Epoch 70/100, Loss: 0.229339
#   Epoch 80/100, Loss: 0.222058
#   Epoch 90/100, Loss: 0.216820
#   Epoch 100/100, Loss: 0.213213
# Training complete for run 9
# Run 9 — RMSE: 42.603699, MSE: 1815.075138, NMSE: 0.0067645702
#
# ===== RUN 10/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.285847
#   Epoch 20/100, Loss: 0.274588
#   Epoch 30/100, Loss: 0.266416
#   Epoch 40/100, Loss: 0.257080
#   Epoch 50/100, Loss: 0.250815
#   Epoch 60/100, Loss: 0.245075
#   Epoch 70/100, Loss: 0.237827
#   Epoch 80/100, Loss: 0.229298
#   Epoch 90/100, Loss: 0.224257
#   Epoch 100/100, Loss: 0.220217
# Training complete for run 10
# Run 10 — RMSE: 42.206358, MSE: 1781.376626, NMSE: 0.0067325471
#
# ===== RUN 11/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.276264
#   Epoch 20/100, Loss: 0.252967
#   Epoch 30/100, Loss: 0.239588
#   Epoch 40/100, Loss: 0.225532
#   Epoch 50/100, Loss: 0.212584
#   Epoch 60/100, Loss: 0.199885
#   Epoch 70/100, Loss: 0.189331
#   Epoch 80/100, Loss: 0.181128
#   Epoch 90/100, Loss: 0.173084
#   Epoch 100/100, Loss: 0.165998
# Training complete for run 11
# Run 11 — RMSE: 38.557027, MSE: 1486.644320, NMSE: 0.0057610517
#
# ===== RUN 12/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.282279
#   Epoch 20/100, Loss: 0.257869
#   Epoch 30/100, Loss: 0.244262
#   Epoch 40/100, Loss: 0.235118
#   Epoch 50/100, Loss: 0.228998
#   Epoch 60/100, Loss: 0.224461
#   Epoch 70/100, Loss: 0.218503
#   Epoch 80/100, Loss: 0.213044
#   Epoch 90/100, Loss: 0.209395
#   Epoch 100/100, Loss: 0.205576
# Training complete for run 12
# Run 12 — RMSE: 42.547806, MSE: 1810.315798, NMSE: 0.0066091389
#
# ===== RUN 13/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.286455
#   Epoch 20/100, Loss: 0.289085
#   Epoch 30/100, Loss: 0.289553
#   Epoch 40/100, Loss: 0.289622
#   Epoch 50/100, Loss: 0.289632
#   Epoch 60/100, Loss: 0.289633
#   Epoch 70/100, Loss: 0.289634
#   Epoch 80/100, Loss: 0.289634
#   Epoch 90/100, Loss: 0.289634
#   Epoch 100/100, Loss: 0.289634
# Training complete for run 13
# Run 13 — RMSE: 48.459014, MSE: 2348.276055, NMSE: 0.0104410851
#
# ===== RUN 14/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.285321
#   Epoch 20/100, Loss: 0.268753
#   Epoch 30/100, Loss: 0.254747
#   Epoch 40/100, Loss: 0.241605
#   Epoch 50/100, Loss: 0.236559
#   Epoch 60/100, Loss: 0.233078
#   Epoch 70/100, Loss: 0.227238
#   Epoch 80/100, Loss: 0.220235
#   Epoch 90/100, Loss: 0.213975
#   Epoch 100/100, Loss: 0.205962
# Training complete for run 14
# Run 14 — RMSE: 43.797465, MSE: 1918.217971, NMSE: 0.0070273267
#
# ===== RUN 15/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.281860
#   Epoch 20/100, Loss: 0.275974
#   Epoch 30/100, Loss: 0.266807
#   Epoch 40/100, Loss: 0.254713
#   Epoch 50/100, Loss: 0.238717
#   Epoch 60/100, Loss: 0.224148
#   Epoch 70/100, Loss: 0.213219
#   Epoch 80/100, Loss: 0.207675
#   Epoch 90/100, Loss: 0.202697
#   Epoch 100/100, Loss: 0.192631
# Training complete for run 15
# Run 15 — RMSE: 41.980738, MSE: 1762.382370, NMSE: 0.0061026162
#
# ===== RUN 16/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.278146
#   Epoch 20/100, Loss: 0.261396
#   Epoch 30/100, Loss: 0.255515
#   Epoch 40/100, Loss: 0.252899
#   Epoch 50/100, Loss: 0.247072
#   Epoch 60/100, Loss: 0.243186
#   Epoch 70/100, Loss: 0.240697
#   Epoch 80/100, Loss: 0.237598
#   Epoch 90/100, Loss: 0.234776
#   Epoch 100/100, Loss: 0.232077
# Training complete for run 16
# Run 16 — RMSE: 44.846982, MSE: 2011.251798, NMSE: 0.0065855045
#
# ===== RUN 17/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.279219
#   Epoch 20/100, Loss: 0.258597
#   Epoch 30/100, Loss: 0.247261
#   Epoch 40/100, Loss: 0.235922
#   Epoch 50/100, Loss: 0.228539
#   Epoch 60/100, Loss: 0.223976
#   Epoch 70/100, Loss: 0.219033
#   Epoch 80/100, Loss: 0.214744
#   Epoch 90/100, Loss: 0.211571
#   Epoch 100/100, Loss: 0.208956
# Training complete for run 17
# Run 17 — RMSE: 42.913060, MSE: 1841.530712, NMSE: 0.0066399972
#
# ===== RUN 18/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.280639
#   Epoch 20/100, Loss: 0.250154
#   Epoch 30/100, Loss: 0.241282
#   Epoch 40/100, Loss: 0.235541
#   Epoch 50/100, Loss: 0.231155
#   Epoch 60/100, Loss: 0.227439
#   Epoch 70/100, Loss: 0.223281
#   Epoch 80/100, Loss: 0.220447
#   Epoch 90/100, Loss: 0.217970
#   Epoch 100/100, Loss: 0.215576
# Training complete for run 18
# Run 18 — RMSE: 44.209082, MSE: 1954.442910, NMSE: 0.0071296897
#
# ===== RUN 19/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.281828
#   Epoch 20/100, Loss: 0.278138
#   Epoch 30/100, Loss: 0.270034
#   Epoch 40/100, Loss: 0.247984
#   Epoch 50/100, Loss: 0.229946
#   Epoch 60/100, Loss: 0.218403
#   Epoch 70/100, Loss: 0.202257
#   Epoch 80/100, Loss: 0.181690
#   Epoch 90/100, Loss: 0.163237
#   Epoch 100/100, Loss: 0.148395
# Training complete for run 19
# Run 19 — RMSE: 33.645095, MSE: 1131.992435, NMSE: 0.0047928230
#
# ===== RUN 20/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.278712
#   Epoch 20/100, Loss: 0.267308
#   Epoch 30/100, Loss: 0.247351
#   Epoch 40/100, Loss: 0.235358
#   Epoch 50/100, Loss: 0.227765
#   Epoch 60/100, Loss: 0.223259
#   Epoch 70/100, Loss: 0.217839
#   Epoch 80/100, Loss: 0.212627
#   Epoch 90/100, Loss: 0.208998
#   Epoch 100/100, Loss: 0.206298
# Training complete for run 20
# Run 20 — RMSE: 42.121189, MSE: 1774.194539, NMSE: 0.0065499345
#
# ===== RUN 21/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.282244
#   Epoch 20/100, Loss: 0.279669
#   Epoch 30/100, Loss: 0.275504
#   Epoch 40/100, Loss: 0.267289
#   Epoch 50/100, Loss: 0.254400
#   Epoch 60/100, Loss: 0.238702
#   Epoch 70/100, Loss: 0.232821
#   Epoch 80/100, Loss: 0.229598
#   Epoch 90/100, Loss: 0.225816
#   Epoch 100/100, Loss: 0.221402
# Training complete for run 21
# Run 21 — RMSE: 43.933092, MSE: 1930.116567, NMSE: 0.0068398493
#
# ===== RUN 22/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.283698
#   Epoch 20/100, Loss: 0.262602
#   Epoch 30/100, Loss: 0.243849
#   Epoch 40/100, Loss: 0.229753
#   Epoch 50/100, Loss: 0.222737
#   Epoch 60/100, Loss: 0.218413
#   Epoch 70/100, Loss: 0.215446
#   Epoch 80/100, Loss: 0.210253
#   Epoch 90/100, Loss: 0.204400
#   Epoch 100/100, Loss: 0.198792
# Training complete for run 22
# Run 22 — RMSE: 43.186732, MSE: 1865.093783, NMSE: 0.0068403601
#
# ===== RUN 23/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.282382
#   Epoch 20/100, Loss: 0.263899
#   Epoch 30/100, Loss: 0.250365
#   Epoch 40/100, Loss: 0.237128
#   Epoch 50/100, Loss: 0.229383
#   Epoch 60/100, Loss: 0.220989
#   Epoch 70/100, Loss: 0.209418
#   Epoch 80/100, Loss: 0.197222
#   Epoch 90/100, Loss: 0.186878
#   Epoch 100/100, Loss: 0.178383
# Training complete for run 23
# Run 23 — RMSE: 38.553724, MSE: 1486.389619, NMSE: 0.0055658414
#
# ===== RUN 24/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.272602
#   Epoch 20/100, Loss: 0.262886
#   Epoch 30/100, Loss: 0.256783
#   Epoch 40/100, Loss: 0.250501
#   Epoch 50/100, Loss: 0.244000
#   Epoch 60/100, Loss: 0.238087
#   Epoch 70/100, Loss: 0.232641
#   Epoch 80/100, Loss: 0.227786
#   Epoch 90/100, Loss: 0.221820
#   Epoch 100/100, Loss: 0.217540
# Training complete for run 24
# Run 24 — RMSE: 43.774255, MSE: 1916.185437, NMSE: 0.0075175314
#
# ===== RUN 25/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.283122
#   Epoch 20/100, Loss: 0.274255
#   Epoch 30/100, Loss: 0.258580
#   Epoch 40/100, Loss: 0.252450
#   Epoch 50/100, Loss: 0.247422
#   Epoch 60/100, Loss: 0.242977
#   Epoch 70/100, Loss: 0.238959
#   Epoch 80/100, Loss: 0.235215
#   Epoch 90/100, Loss: 0.231589
#   Epoch 100/100, Loss: 0.227787
# Training complete for run 25
# Run 25 — RMSE: 44.788359, MSE: 2005.997140, NMSE: 0.0077400323
#
# ===== RUN 26/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.277113
#   Epoch 20/100, Loss: 0.248085
#   Epoch 30/100, Loss: 0.234149
#   Epoch 40/100, Loss: 0.232508
#   Epoch 50/100, Loss: 0.229709
#   Epoch 60/100, Loss: 0.226682
#   Epoch 70/100, Loss: 0.223993
#   Epoch 80/100, Loss: 0.220061
#   Epoch 90/100, Loss: 0.217248
#   Epoch 100/100, Loss: 0.214745
# Training complete for run 26
# Run 26 — RMSE: 37.841606, MSE: 1431.987123, NMSE: 0.0047243618
#
# ===== RUN 27/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.282660
#   Epoch 20/100, Loss: 0.268717
#   Epoch 30/100, Loss: 0.259308
#   Epoch 40/100, Loss: 0.255798
#   Epoch 50/100, Loss: 0.253877
#   Epoch 60/100, Loss: 0.252438
#   Epoch 70/100, Loss: 0.250497
#   Epoch 80/100, Loss: 0.248453
#   Epoch 90/100, Loss: 0.243332
#   Epoch 100/100, Loss: 0.235489
# Training complete for run 27
# Run 27 — RMSE: 44.570856, MSE: 1986.561247, NMSE: 0.0070733294
#
# ===== RUN 28/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.284077
#   Epoch 20/100, Loss: 0.279142
#   Epoch 30/100, Loss: 0.266572
#   Epoch 40/100, Loss: 0.251268
#   Epoch 50/100, Loss: 0.243532
#   Epoch 60/100, Loss: 0.235229
#   Epoch 70/100, Loss: 0.227466
#   Epoch 80/100, Loss: 0.220651
#   Epoch 90/100, Loss: 0.214836
#   Epoch 100/100, Loss: 0.208698
# Training complete for run 28
# Run 28 — RMSE: 42.711450, MSE: 1824.267953, NMSE: 0.0067008711
#
# ===== RUN 29/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.279920
#   Epoch 20/100, Loss: 0.258663
#   Epoch 30/100, Loss: 0.229607
#   Epoch 40/100, Loss: 0.223884
#   Epoch 50/100, Loss: 0.222355
#   Epoch 60/100, Loss: 0.218003
#   Epoch 70/100, Loss: 0.213931
#   Epoch 80/100, Loss: 0.210430
#   Epoch 90/100, Loss: 0.207372
#   Epoch 100/100, Loss: 0.204792
# Training complete for run 29
# Run 29 — RMSE: 38.266582, MSE: 1464.331320, NMSE: 0.0054115566
#
# ===== RUN 30/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.280181
#   Epoch 20/100, Loss: 0.272485
#   Epoch 30/100, Loss: 0.251361
#   Epoch 40/100, Loss: 0.238477
#   Epoch 50/100, Loss: 0.233117
#   Epoch 60/100, Loss: 0.230851
#   Epoch 70/100, Loss: 0.228879
#   Epoch 80/100, Loss: 0.227188
#   Epoch 90/100, Loss: 0.225670
#   Epoch 100/100, Loss: 0.224182
# Training complete for run 30
# Run 30 — RMSE: 44.581048, MSE: 1987.469872, NMSE: 0.0066519985
#
# ===== RUN 31/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.281309
#   Epoch 20/100, Loss: 0.277267
#   Epoch 30/100, Loss: 0.265740
#   Epoch 40/100, Loss: 0.243390
#   Epoch 50/100, Loss: 0.222500
#   Epoch 60/100, Loss: 0.210397
#   Epoch 70/100, Loss: 0.201647
#   Epoch 80/100, Loss: 0.195351
#   Epoch 90/100, Loss: 0.190629
#   Epoch 100/100, Loss: 0.187326
# Training complete for run 31
# Run 31 — RMSE: 41.967361, MSE: 1761.259387, NMSE: 0.0060857799
#
# ===== RUN 32/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.274395
#   Epoch 20/100, Loss: 0.264796
#   Epoch 30/100, Loss: 0.258154
#   Epoch 40/100, Loss: 0.251545
#   Epoch 50/100, Loss: 0.244032
#   Epoch 60/100, Loss: 0.236502
#   Epoch 70/100, Loss: 0.229626
#   Epoch 80/100, Loss: 0.223471
#   Epoch 90/100, Loss: 0.218532
#   Epoch 100/100, Loss: 0.214149
# Training complete for run 32
# Run 32 — RMSE: 44.110499, MSE: 1945.736141, NMSE: 0.0072682399
#
# ===== RUN 33/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.285938
#   Epoch 20/100, Loss: 0.278920
#   Epoch 30/100, Loss: 0.268605
#   Epoch 40/100, Loss: 0.245670
#   Epoch 50/100, Loss: 0.238207
#   Epoch 60/100, Loss: 0.235012
#   Epoch 70/100, Loss: 0.232833
#   Epoch 80/100, Loss: 0.230418
#   Epoch 90/100, Loss: 0.227829
#   Epoch 100/100, Loss: 0.226033
# Training complete for run 33
# Run 33 — RMSE: 45.123833, MSE: 2036.160301, NMSE: 0.0066817415
#
# ===== RUN 34/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.284313
#   Epoch 20/100, Loss: 0.271068
#   Epoch 30/100, Loss: 0.258401
#   Epoch 40/100, Loss: 0.252770
#   Epoch 50/100, Loss: 0.246994
#   Epoch 60/100, Loss: 0.240244
#   Epoch 70/100, Loss: 0.234071
#   Epoch 80/100, Loss: 0.230649
#   Epoch 90/100, Loss: 0.227133
#   Epoch 100/100, Loss: 0.224508
# Training complete for run 34
# Run 34 — RMSE: 40.632915, MSE: 1651.033757, NMSE: 0.0059985785
#
# ===== RUN 35/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.280869
#   Epoch 20/100, Loss: 0.259412
#   Epoch 30/100, Loss: 0.247192
#   Epoch 40/100, Loss: 0.240937
#   Epoch 50/100, Loss: 0.235558
#   Epoch 60/100, Loss: 0.229741
#   Epoch 70/100, Loss: 0.222665
#   Epoch 80/100, Loss: 0.216347
#   Epoch 90/100, Loss: 0.210799
#   Epoch 100/100, Loss: 0.205476
# Training complete for run 35
# Run 35 — RMSE: 39.380508, MSE: 1550.824417, NMSE: 0.0055905828
#
# ===== RUN 36/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.278123
#   Epoch 20/100, Loss: 0.257652
#   Epoch 30/100, Loss: 0.243545
#   Epoch 40/100, Loss: 0.234765
#   Epoch 50/100, Loss: 0.229752
#   Epoch 60/100, Loss: 0.215321
#   Epoch 70/100, Loss: 0.204763
#   Epoch 80/100, Loss: 0.196367
#   Epoch 90/100, Loss: 0.188885
#   Epoch 100/100, Loss: 0.182250
# Training complete for run 36
# Run 36 — RMSE: 45.405903, MSE: 2061.695995, NMSE: 0.0071674860
#
# ===== RUN 37/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.278272
#   Epoch 20/100, Loss: 0.259888
#   Epoch 30/100, Loss: 0.246548
#   Epoch 40/100, Loss: 0.239319
#   Epoch 50/100, Loss: 0.229821
#   Epoch 60/100, Loss: 0.221282
#   Epoch 70/100, Loss: 0.214221
#   Epoch 80/100, Loss: 0.208595
#   Epoch 90/100, Loss: 0.200282
#   Epoch 100/100, Loss: 0.191473
# Training complete for run 37
# Run 37 — RMSE: 40.877964, MSE: 1671.007924, NMSE: 0.0058785019
#
# ===== RUN 38/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.281624
#   Epoch 20/100, Loss: 0.279961
#   Epoch 30/100, Loss: 0.278655
#   Epoch 40/100, Loss: 0.277751
#   Epoch 50/100, Loss: 0.276612
#   Epoch 60/100, Loss: 0.275246
#   Epoch 70/100, Loss: 0.273287
#   Epoch 80/100, Loss: 0.271238
#   Epoch 90/100, Loss: 0.269002
#   Epoch 100/100, Loss: 0.265927
# Training complete for run 38
# Run 38 — RMSE: 47.730512, MSE: 2278.201729, NMSE: 0.0085694187
#
# ===== RUN 39/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.283619
#   Epoch 20/100, Loss: 0.278437
#   Epoch 30/100, Loss: 0.274579
#   Epoch 40/100, Loss: 0.266699
#   Epoch 50/100, Loss: 0.258618
#   Epoch 60/100, Loss: 0.248708
#   Epoch 70/100, Loss: 0.238815
#   Epoch 80/100, Loss: 0.232326
#   Epoch 90/100, Loss: 0.228085
#   Epoch 100/100, Loss: 0.225652
# Training complete for run 39
# Run 39 — RMSE: 42.890479, MSE: 1839.593161, NMSE: 0.0071572984
#
# ===== RUN 40/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.279913
#   Epoch 20/100, Loss: 0.270050
#   Epoch 30/100, Loss: 0.249598
#   Epoch 40/100, Loss: 0.239082
#   Epoch 50/100, Loss: 0.229405
#   Epoch 60/100, Loss: 0.220918
#   Epoch 70/100, Loss: 0.213139
#   Epoch 80/100, Loss: 0.205273
#   Epoch 90/100, Loss: 0.197872
#   Epoch 100/100, Loss: 0.192561
# Training complete for run 40
# Run 40 — RMSE: 40.980241, MSE: 1679.380119, NMSE: 0.0060744652
#
# ===== RUN 41/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.282595
#   Epoch 20/100, Loss: 0.277884
#   Epoch 30/100, Loss: 0.273255
#   Epoch 40/100, Loss: 0.267106
#   Epoch 50/100, Loss: 0.259591
#   Epoch 60/100, Loss: 0.250832
#   Epoch 70/100, Loss: 0.242825
#   Epoch 80/100, Loss: 0.235936
#   Epoch 90/100, Loss: 0.229455
#   Epoch 100/100, Loss: 0.223578
# Training complete for run 41
# Run 41 — RMSE: 45.215241, MSE: 2044.418047, NMSE: 0.0072486109
#
# ===== RUN 42/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.280158
#   Epoch 20/100, Loss: 0.273648
#   Epoch 30/100, Loss: 0.262150
#   Epoch 40/100, Loss: 0.250826
#   Epoch 50/100, Loss: 0.236686
#   Epoch 60/100, Loss: 0.223120
#   Epoch 70/100, Loss: 0.215754
#   Epoch 80/100, Loss: 0.208658
#   Epoch 90/100, Loss: 0.203783
#   Epoch 100/100, Loss: 0.198881
# Training complete for run 42
# Run 42 — RMSE: 42.143167, MSE: 1776.046561, NMSE: 0.0061186957
#
# ===== RUN 43/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.280927
#   Epoch 20/100, Loss: 0.280704
#   Epoch 30/100, Loss: 0.280007
#   Epoch 40/100, Loss: 0.278970
#   Epoch 50/100, Loss: 0.277490
#   Epoch 60/100, Loss: 0.275232
#   Epoch 70/100, Loss: 0.272056
#   Epoch 80/100, Loss: 0.268485
#   Epoch 90/100, Loss: 0.264871
#   Epoch 100/100, Loss: 0.261656
# Training complete for run 43
# Run 43 — RMSE: 48.043934, MSE: 2308.219560, NMSE: 0.0087703366
#
# ===== RUN 44/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.276565
#   Epoch 20/100, Loss: 0.271463
#   Epoch 30/100, Loss: 0.264212
#   Epoch 40/100, Loss: 0.254797
#   Epoch 50/100, Loss: 0.242456
#   Epoch 60/100, Loss: 0.231202
#   Epoch 70/100, Loss: 0.223738
#   Epoch 80/100, Loss: 0.212970
#   Epoch 90/100, Loss: 0.196372
#   Epoch 100/100, Loss: 0.178844
# Training complete for run 44
# Run 44 — RMSE: 39.203275, MSE: 1536.896759, NMSE: 0.0057007133
#
# ===== RUN 45/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.276601
#   Epoch 20/100, Loss: 0.255835
#   Epoch 30/100, Loss: 0.238168
#   Epoch 40/100, Loss: 0.223279
#   Epoch 50/100, Loss: 0.217152
#   Epoch 60/100, Loss: 0.213342
#   Epoch 70/100, Loss: 0.210592
#   Epoch 80/100, Loss: 0.208152
#   Epoch 90/100, Loss: 0.206649
#   Epoch 100/100, Loss: 0.204674
# Training complete for run 45
# Run 45 — RMSE: 42.489179, MSE: 1805.330357, NMSE: 0.0060376053
#
# ===== RUN 46/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.279564
#   Epoch 20/100, Loss: 0.255413
#   Epoch 30/100, Loss: 0.242849
#   Epoch 40/100, Loss: 0.235531
#   Epoch 50/100, Loss: 0.228360
#   Epoch 60/100, Loss: 0.218658
#   Epoch 70/100, Loss: 0.211684
#   Epoch 80/100, Loss: 0.206555
#   Epoch 90/100, Loss: 0.203182
#   Epoch 100/100, Loss: 0.198718
# Training complete for run 46
# Run 46 — RMSE: 40.389806, MSE: 1631.336451, NMSE: 0.0057750977
#
# ===== RUN 47/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.274845
#   Epoch 20/100, Loss: 0.267549
#   Epoch 30/100, Loss: 0.257422
#   Epoch 40/100, Loss: 0.244914
#   Epoch 50/100, Loss: 0.232493
#   Epoch 60/100, Loss: 0.220281
#   Epoch 70/100, Loss: 0.211095
#   Epoch 80/100, Loss: 0.205648
#   Epoch 90/100, Loss: 0.199250
#   Epoch 100/100, Loss: 0.196208
# Training complete for run 47
# Run 47 — RMSE: 39.137442, MSE: 1531.739357, NMSE: 0.0054152160
#
# ===== RUN 48/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.280983
#   Epoch 20/100, Loss: 0.279943
#   Epoch 30/100, Loss: 0.276772
#   Epoch 40/100, Loss: 0.273209
#   Epoch 50/100, Loss: 0.269694
#   Epoch 60/100, Loss: 0.265686
#   Epoch 70/100, Loss: 0.260787
#   Epoch 80/100, Loss: 0.253919
#   Epoch 90/100, Loss: 0.243329
#   Epoch 100/100, Loss: 0.234274
# Training complete for run 48
# Run 48 — RMSE: 46.141441, MSE: 2129.032554, NMSE: 0.0085014450
#
# ===== RUN 49/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.284296
#   Epoch 20/100, Loss: 0.268367
#   Epoch 30/100, Loss: 0.258118
#   Epoch 40/100, Loss: 0.251572
#   Epoch 50/100, Loss: 0.244054
#   Epoch 60/100, Loss: 0.235167
#   Epoch 70/100, Loss: 0.226271
#   Epoch 80/100, Loss: 0.216883
#   Epoch 90/100, Loss: 0.207791
#   Epoch 100/100, Loss: 0.200627
# Training complete for run 49
# Run 49 — RMSE: 41.445839, MSE: 1717.757598, NMSE: 0.0065051219
#
# ===== RUN 50/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.279157
#   Epoch 20/100, Loss: 0.262830
#   Epoch 30/100, Loss: 0.251475
#   Epoch 40/100, Loss: 0.249077
#   Epoch 50/100, Loss: 0.246426
#   Epoch 60/100, Loss: 0.243647
#   Epoch 70/100, Loss: 0.238230
#   Epoch 80/100, Loss: 0.225451
#   Epoch 90/100, Loss: 0.219500
#   Epoch 100/100, Loss: 0.215396
# Training complete for run 50
# Run 50 — RMSE: 43.651074, MSE: 1905.416275, NMSE: 0.0065185507
#
# ===== RUN 51/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.281963
#   Epoch 20/100, Loss: 0.270440
#   Epoch 30/100, Loss: 0.255285
#   Epoch 40/100, Loss: 0.248379
#   Epoch 50/100, Loss: 0.240096
#   Epoch 60/100, Loss: 0.232217
#   Epoch 70/100, Loss: 0.224873
#   Epoch 80/100, Loss: 0.219443
#   Epoch 90/100, Loss: 0.214647
#   Epoch 100/100, Loss: 0.209349
# Training complete for run 51
# Run 51 — RMSE: 42.333668, MSE: 1792.139440, NMSE: 0.0065751991
#
# ===== RUN 52/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.275852
#   Epoch 20/100, Loss: 0.250669
#   Epoch 30/100, Loss: 0.238034
#   Epoch 40/100, Loss: 0.232688
#   Epoch 50/100, Loss: 0.227030
#   Epoch 60/100, Loss: 0.222956
#   Epoch 70/100, Loss: 0.219643
#   Epoch 80/100, Loss: 0.216112
#   Epoch 90/100, Loss: 0.211982
#   Epoch 100/100, Loss: 0.207899
# Training complete for run 52
# Run 52 — RMSE: 42.524125, MSE: 1808.301246, NMSE: 0.0063218266
#
# ===== RUN 53/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.275248
#   Epoch 20/100, Loss: 0.245906
#   Epoch 30/100, Loss: 0.235933
#   Epoch 40/100, Loss: 0.230993
#   Epoch 50/100, Loss: 0.228011
#   Epoch 60/100, Loss: 0.225320
#   Epoch 70/100, Loss: 0.222597
#   Epoch 80/100, Loss: 0.219197
#   Epoch 90/100, Loss: 0.217068
#   Epoch 100/100, Loss: 0.214448
# Training complete for run 53
# Run 53 — RMSE: 43.752274, MSE: 1914.261450, NMSE: 0.0064528763
#
# ===== RUN 54/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.284947
#   Epoch 20/100, Loss: 0.282603
#   Epoch 30/100, Loss: 0.279652
#   Epoch 40/100, Loss: 0.274614
#   Epoch 50/100, Loss: 0.268094
#   Epoch 60/100, Loss: 0.261276
#   Epoch 70/100, Loss: 0.255496
#   Epoch 80/100, Loss: 0.251403
#   Epoch 90/100, Loss: 0.249605
#   Epoch 100/100, Loss: 0.248161
# Training complete for run 54
# Run 54 — RMSE: 46.647718, MSE: 2176.009625, NMSE: 0.0078834606
#
# ===== RUN 55/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.279089
#   Epoch 20/100, Loss: 0.274674
#   Epoch 30/100, Loss: 0.274448
#   Epoch 40/100, Loss: 0.274568
#   Epoch 50/100, Loss: 0.274388
#   Epoch 60/100, Loss: 0.273500
#   Epoch 70/100, Loss: 0.271522
#   Epoch 80/100, Loss: 0.264082
#   Epoch 90/100, Loss: 0.255272
#   Epoch 100/100, Loss: 0.245817
# Training complete for run 55
# Run 55 — RMSE: 43.696103, MSE: 1909.349393, NMSE: 0.0086219729
#
# ===== RUN 56/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.277349
#   Epoch 20/100, Loss: 0.274644
#   Epoch 30/100, Loss: 0.270599
#   Epoch 40/100, Loss: 0.265613
#   Epoch 50/100, Loss: 0.258537
#   Epoch 60/100, Loss: 0.250340
#   Epoch 70/100, Loss: 0.241185
#   Epoch 80/100, Loss: 0.232217
#   Epoch 90/100, Loss: 0.224948
#   Epoch 100/100, Loss: 0.219513
# Training complete for run 56
# Run 56 — RMSE: 43.779513, MSE: 1916.645741, NMSE: 0.0072705583
#
# ===== RUN 57/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.281748
#   Epoch 20/100, Loss: 0.279473
#   Epoch 30/100, Loss: 0.268177
#   Epoch 40/100, Loss: 0.250247
#   Epoch 50/100, Loss: 0.243509
#   Epoch 60/100, Loss: 0.240142
#   Epoch 70/100, Loss: 0.237038
#   Epoch 80/100, Loss: 0.231182
#   Epoch 90/100, Loss: 0.221335
#   Epoch 100/100, Loss: 0.210219
# Training complete for run 57
# Run 57 — RMSE: 44.883755, MSE: 2014.551472, NMSE: 0.0066399279
#
# ===== RUN 58/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.279264
#   Epoch 20/100, Loss: 0.274330
#   Epoch 30/100, Loss: 0.268684
#   Epoch 40/100, Loss: 0.265061
#   Epoch 50/100, Loss: 0.261317
#   Epoch 60/100, Loss: 0.256726
#   Epoch 70/100, Loss: 0.251325
#   Epoch 80/100, Loss: 0.242917
#   Epoch 90/100, Loss: 0.232459
#   Epoch 100/100, Loss: 0.222932
# Training complete for run 58
# Run 58 — RMSE: 43.433437, MSE: 1886.463412, NMSE: 0.0071809401
#
# ===== RUN 59/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.279693
#   Epoch 20/100, Loss: 0.274518
#   Epoch 30/100, Loss: 0.268414
#   Epoch 40/100, Loss: 0.261848
#   Epoch 50/100, Loss: 0.254988
#   Epoch 60/100, Loss: 0.248280
#   Epoch 70/100, Loss: 0.242254
#   Epoch 80/100, Loss: 0.237462
#   Epoch 90/100, Loss: 0.234134
#   Epoch 100/100, Loss: 0.229512
# Training complete for run 59
# Run 59 — RMSE: 44.507507, MSE: 1980.918223, NMSE: 0.0073749665
#
# ===== RUN 60/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.283042
#   Epoch 20/100, Loss: 0.272093
#   Epoch 30/100, Loss: 0.258889
#   Epoch 40/100, Loss: 0.250580
#   Epoch 50/100, Loss: 0.236745
#   Epoch 60/100, Loss: 0.222339
#   Epoch 70/100, Loss: 0.212502
#   Epoch 80/100, Loss: 0.204290
#   Epoch 90/100, Loss: 0.197068
#   Epoch 100/100, Loss: 0.190563
# Training complete for run 60
# Run 60 — RMSE: 42.034559, MSE: 1766.904176, NMSE: 0.0062275446
#
# ===== STATS FOR NOISE 0.0% (60 runs) =====
# RMSE: 42.749069 +/- 2.666264
# MSE:  1834.591831 +/- 224.075255
# NMSE: 0.0067014901 +/- 0.0010152260
# Best run: 19 (RMSE: 33.645095)
#
# ================================================================================
# EVALUATING NOISE LEVEL: 0.5% (lambda=0.005, sigma=0.509499)
# ================================================================================
#
# X_train shape: (107, 1, 2), y_train shape: (107,)
#
# ===== RUN 1/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.276192
#   Epoch 20/100, Loss: 0.274926
#   Epoch 30/100, Loss: 0.272457
#   Epoch 40/100, Loss: 0.268156
#   Epoch 50/100, Loss: 0.262907
#   Epoch 60/100, Loss: 0.258217
#   Epoch 70/100, Loss: 0.253492
#   Epoch 80/100, Loss: 0.248012
#   Epoch 90/100, Loss: 0.240732
#   Epoch 100/100, Loss: 0.235162
# Training complete for run 1
# Run 1 — RMSE: 45.019326, MSE: 2026.739704, NMSE: 0.0078440002
#
# ===== RUN 2/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.275732
#   Epoch 20/100, Loss: 0.245127
#   Epoch 30/100, Loss: 0.234234
#   Epoch 40/100, Loss: 0.228093
#   Epoch 50/100, Loss: 0.224668
#   Epoch 60/100, Loss: 0.220855
#   Epoch 70/100, Loss: 0.217682
#   Epoch 80/100, Loss: 0.210556
#   Epoch 90/100, Loss: 0.204862
#   Epoch 100/100, Loss: 0.198288
# Training complete for run 2
# Run 2 — RMSE: 41.842553, MSE: 1750.799271, NMSE: 0.0057626467
#
# ===== RUN 3/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.275701
#   Epoch 20/100, Loss: 0.274109
#   Epoch 30/100, Loss: 0.272300
#   Epoch 40/100, Loss: 0.269984
#   Epoch 50/100, Loss: 0.266303
#   Epoch 60/100, Loss: 0.259005
#   Epoch 70/100, Loss: 0.247955
#   Epoch 80/100, Loss: 0.238742
#   Epoch 90/100, Loss: 0.232263
#   Epoch 100/100, Loss: 0.227677
# Training complete for run 3
# Run 3 — RMSE: 43.865883, MSE: 1924.215731, NMSE: 0.0070986591
#
# ===== RUN 4/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.279427
#   Epoch 20/100, Loss: 0.278077
#   Epoch 30/100, Loss: 0.276154
#   Epoch 40/100, Loss: 0.272834
#   Epoch 50/100, Loss: 0.268983
#   Epoch 60/100, Loss: 0.264207
#   Epoch 70/100, Loss: 0.258367
#   Epoch 80/100, Loss: 0.251231
#   Epoch 90/100, Loss: 0.244464
#   Epoch 100/100, Loss: 0.237292
# Training complete for run 4
# Run 4 — RMSE: 43.533111, MSE: 1895.131724, NMSE: 0.0075504092
#
# ===== RUN 5/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.275932
#   Epoch 20/100, Loss: 0.262580
#   Epoch 30/100, Loss: 0.250806
#   Epoch 40/100, Loss: 0.245038
#   Epoch 50/100, Loss: 0.238371
#   Epoch 60/100, Loss: 0.231870
#   Epoch 70/100, Loss: 0.226159
#   Epoch 80/100, Loss: 0.220220
#   Epoch 90/100, Loss: 0.212362
#   Epoch 100/100, Loss: 0.205348
# Training complete for run 5
# Run 5 — RMSE: 41.641737, MSE: 1734.034284, NMSE: 0.0062836080
#
# ===== RUN 6/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.280729
#   Epoch 20/100, Loss: 0.261122
#   Epoch 30/100, Loss: 0.237972
#   Epoch 40/100, Loss: 0.224434
#   Epoch 50/100, Loss: 0.213627
#   Epoch 60/100, Loss: 0.205990
#   Epoch 70/100, Loss: 0.199854
#   Epoch 80/100, Loss: 0.193640
#   Epoch 90/100, Loss: 0.189189
#   Epoch 100/100, Loss: 0.183878
# Training complete for run 6
# Run 6 — RMSE: 38.639737, MSE: 1493.029300, NMSE: 0.0050598198
#
# ===== RUN 7/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.276847
#   Epoch 20/100, Loss: 0.265624
#   Epoch 30/100, Loss: 0.246413
#   Epoch 40/100, Loss: 0.238086
#   Epoch 50/100, Loss: 0.234299
#   Epoch 60/100, Loss: 0.232125
#   Epoch 70/100, Loss: 0.230865
#   Epoch 80/100, Loss: 0.229956
#   Epoch 90/100, Loss: 0.229199
#   Epoch 100/100, Loss: 0.228559
# Training complete for run 7
# Run 7 — RMSE: 45.714997, MSE: 2089.860971, NMSE: 0.0068190186
#
# ===== RUN 8/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.276488
#   Epoch 20/100, Loss: 0.257919
#   Epoch 30/100, Loss: 0.251855
#   Epoch 40/100, Loss: 0.248086
#   Epoch 50/100, Loss: 0.240692
#   Epoch 60/100, Loss: 0.219129
#   Epoch 70/100, Loss: 0.198408
#   Epoch 80/100, Loss: 0.188591
#   Epoch 90/100, Loss: 0.179718
#   Epoch 100/100, Loss: 0.175594
# Training complete for run 8
# Run 8 — RMSE: 39.750949, MSE: 1580.137977, NMSE: 0.0054614879
#
# ===== RUN 9/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.274675
#   Epoch 20/100, Loss: 0.259997
#   Epoch 30/100, Loss: 0.252542
#   Epoch 40/100, Loss: 0.246158
#   Epoch 50/100, Loss: 0.239517
#   Epoch 60/100, Loss: 0.233220
#   Epoch 70/100, Loss: 0.226534
#   Epoch 80/100, Loss: 0.219933
#   Epoch 90/100, Loss: 0.215355
#   Epoch 100/100, Loss: 0.210708
# Training complete for run 9
# Run 9 — RMSE: 42.365238, MSE: 1794.813430, NMSE: 0.0066806793
#
# ===== RUN 10/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.282165
#   Epoch 20/100, Loss: 0.271167
#   Epoch 30/100, Loss: 0.263253
#   Epoch 40/100, Loss: 0.254073
#   Epoch 50/100, Loss: 0.248005
#   Epoch 60/100, Loss: 0.242952
#   Epoch 70/100, Loss: 0.236795
#   Epoch 80/100, Loss: 0.228685
#   Epoch 90/100, Loss: 0.223257
#   Epoch 100/100, Loss: 0.219857
# Training complete for run 10
# Run 10 — RMSE: 42.473599, MSE: 1804.006603, NMSE: 0.0067723150
#
# ===== RUN 11/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.272708
#   Epoch 20/100, Loss: 0.250460
#   Epoch 30/100, Loss: 0.237956
#   Epoch 40/100, Loss: 0.225722
#   Epoch 50/100, Loss: 0.215459
#   Epoch 60/100, Loss: 0.203230
#   Epoch 70/100, Loss: 0.192642
#   Epoch 80/100, Loss: 0.184429
#   Epoch 90/100, Loss: 0.176798
#   Epoch 100/100, Loss: 0.170126
# Training complete for run 11
# Run 11 — RMSE: 38.432584, MSE: 1477.063489, NMSE: 0.0056883456
#
# ===== RUN 12/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.279224
#   Epoch 20/100, Loss: 0.257200
#   Epoch 30/100, Loss: 0.243645
#   Epoch 40/100, Loss: 0.233575
#   Epoch 50/100, Loss: 0.225890
#   Epoch 60/100, Loss: 0.218305
#   Epoch 70/100, Loss: 0.210532
#   Epoch 80/100, Loss: 0.202889
#   Epoch 90/100, Loss: 0.195873
#   Epoch 100/100, Loss: 0.189088
# Training complete for run 12
# Run 12 — RMSE: 41.319686, MSE: 1707.316414, NMSE: 0.0063512207
#
# ===== RUN 13/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.282936
#   Epoch 20/100, Loss: 0.285556
#   Epoch 30/100, Loss: 0.286023
#   Epoch 40/100, Loss: 0.286092
#   Epoch 50/100, Loss: 0.286102
#   Epoch 60/100, Loss: 0.286104
#   Epoch 70/100, Loss: 0.286104
#   Epoch 80/100, Loss: 0.286104
#   Epoch 90/100, Loss: 0.286104
#   Epoch 100/100, Loss: 0.286104
# Training complete for run 13
# Run 13 — RMSE: 48.416099, MSE: 2344.118616, NMSE: 0.0104155460
#
# ===== RUN 14/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.281737
#   Epoch 20/100, Loss: 0.264926
#   Epoch 30/100, Loss: 0.251653
#   Epoch 40/100, Loss: 0.240270
#   Epoch 50/100, Loss: 0.235737
#   Epoch 60/100, Loss: 0.232119
#   Epoch 70/100, Loss: 0.227652
#   Epoch 80/100, Loss: 0.222990
#   Epoch 90/100, Loss: 0.218999
#   Epoch 100/100, Loss: 0.216728
# Training complete for run 14
# Run 14 — RMSE: 43.366975, MSE: 1880.694539, NMSE: 0.0070123194
#
# ===== RUN 15/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.278469
#   Epoch 20/100, Loss: 0.272797
#   Epoch 30/100, Loss: 0.264571
#   Epoch 40/100, Loss: 0.252619
#   Epoch 50/100, Loss: 0.238058
#   Epoch 60/100, Loss: 0.223264
#   Epoch 70/100, Loss: 0.213372
#   Epoch 80/100, Loss: 0.208876
#   Epoch 90/100, Loss: 0.204130
#   Epoch 100/100, Loss: 0.199698
# Training complete for run 15
# Run 15 — RMSE: 42.572386, MSE: 1812.408052, NMSE: 0.0061884718
#
# ===== RUN 16/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.275091
#   Epoch 20/100, Loss: 0.258938
#   Epoch 30/100, Loss: 0.253156
#   Epoch 40/100, Loss: 0.250774
#   Epoch 50/100, Loss: 0.245818
#   Epoch 60/100, Loss: 0.241243
#   Epoch 70/100, Loss: 0.238875
#   Epoch 80/100, Loss: 0.235491
#   Epoch 90/100, Loss: 0.232223
#   Epoch 100/100, Loss: 0.229356
# Training complete for run 16
# Run 16 — RMSE: 44.433802, MSE: 1974.362740, NMSE: 0.0065119372
#
# ===== RUN 17/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.275391
#   Epoch 20/100, Loss: 0.255748
#   Epoch 30/100, Loss: 0.244985
#   Epoch 40/100, Loss: 0.234459
#   Epoch 50/100, Loss: 0.227789
#   Epoch 60/100, Loss: 0.223659
#   Epoch 70/100, Loss: 0.218376
#   Epoch 80/100, Loss: 0.211625
#   Epoch 90/100, Loss: 0.201953
#   Epoch 100/100, Loss: 0.192506
# Training complete for run 17
# Run 17 — RMSE: 40.691080, MSE: 1655.764028, NMSE: 0.0060679705
#
# ===== RUN 18/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.277124
#   Epoch 20/100, Loss: 0.247328
#   Epoch 30/100, Loss: 0.239638
#   Epoch 40/100, Loss: 0.234021
#   Epoch 50/100, Loss: 0.229544
#   Epoch 60/100, Loss: 0.225369
#   Epoch 70/100, Loss: 0.221021
#   Epoch 80/100, Loss: 0.216978
#   Epoch 90/100, Loss: 0.213421
#   Epoch 100/100, Loss: 0.210416
# Training complete for run 18
# Run 18 — RMSE: 43.673658, MSE: 1907.388405, NMSE: 0.0069737107
#
# ===== RUN 19/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.278236
#   Epoch 20/100, Loss: 0.274818
#   Epoch 30/100, Loss: 0.268394
#   Epoch 40/100, Loss: 0.249335
#   Epoch 50/100, Loss: 0.229654
#   Epoch 60/100, Loss: 0.218115
#   Epoch 70/100, Loss: 0.202717
#   Epoch 80/100, Loss: 0.183797
#   Epoch 90/100, Loss: 0.165683
#   Epoch 100/100, Loss: 0.151399
# Training complete for run 19
# Run 19 — RMSE: 34.148731, MSE: 1166.135834, NMSE: 0.0048991491
#
# ===== RUN 20/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.275045
#   Epoch 20/100, Loss: 0.263100
#   Epoch 30/100, Loss: 0.244641
#   Epoch 40/100, Loss: 0.234573
#   Epoch 50/100, Loss: 0.226786
#   Epoch 60/100, Loss: 0.222019
#   Epoch 70/100, Loss: 0.217118
#   Epoch 80/100, Loss: 0.212408
#   Epoch 90/100, Loss: 0.208346
#   Epoch 100/100, Loss: 0.205059
# Training complete for run 20
# Run 20 — RMSE: 41.907955, MSE: 1756.276677, NMSE: 0.0064959367
#
# ===== RUN 21/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.278641
#   Epoch 20/100, Loss: 0.276061
#   Epoch 30/100, Loss: 0.273079
#   Epoch 40/100, Loss: 0.267860
#   Epoch 50/100, Loss: 0.262614
#   Epoch 60/100, Loss: 0.256059
#   Epoch 70/100, Loss: 0.248434
#   Epoch 80/100, Loss: 0.238953
#   Epoch 90/100, Loss: 0.228812
#   Epoch 100/100, Loss: 0.218690
# Training complete for run 21
# Run 21 — RMSE: 41.438614, MSE: 1717.158769, NMSE: 0.0067466665
#
# ===== RUN 22/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.279972
#   Epoch 20/100, Loss: 0.260659
#   Epoch 30/100, Loss: 0.244021
#   Epoch 40/100, Loss: 0.229608
#   Epoch 50/100, Loss: 0.222938
#   Epoch 60/100, Loss: 0.218509
#   Epoch 70/100, Loss: 0.214689
#   Epoch 80/100, Loss: 0.210249
#   Epoch 90/100, Loss: 0.205197
#   Epoch 100/100, Loss: 0.200485
# Training complete for run 22
# Run 22 — RMSE: 42.703282, MSE: 1823.570263, NMSE: 0.0066510723
#
# ===== RUN 23/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.278903
#   Epoch 20/100, Loss: 0.260336
#   Epoch 30/100, Loss: 0.248872
#   Epoch 40/100, Loss: 0.237888
#   Epoch 50/100, Loss: 0.232065
#   Epoch 60/100, Loss: 0.225821
#   Epoch 70/100, Loss: 0.215871
#   Epoch 80/100, Loss: 0.202737
#   Epoch 90/100, Loss: 0.189396
#   Epoch 100/100, Loss: 0.179138
# Training complete for run 23
# Run 23 — RMSE: 38.640806, MSE: 1493.111867, NMSE: 0.0056102483
#
# ===== RUN 24/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.269551
#   Epoch 20/100, Loss: 0.259893
#   Epoch 30/100, Loss: 0.254103
#   Epoch 40/100, Loss: 0.247590
#   Epoch 50/100, Loss: 0.242282
#   Epoch 60/100, Loss: 0.236215
#   Epoch 70/100, Loss: 0.231693
#   Epoch 80/100, Loss: 0.227514
#   Epoch 90/100, Loss: 0.221819
#   Epoch 100/100, Loss: 0.218031
# Training complete for run 24
# Run 24 — RMSE: 43.709205, MSE: 1910.494594, NMSE: 0.0075333851
#
# ===== RUN 25/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.279602
#   Epoch 20/100, Loss: 0.270206
#   Epoch 30/100, Loss: 0.255464
#   Epoch 40/100, Loss: 0.250266
#   Epoch 50/100, Loss: 0.245893
#   Epoch 60/100, Loss: 0.242457
#   Epoch 70/100, Loss: 0.237993
#   Epoch 80/100, Loss: 0.232213
#   Epoch 90/100, Loss: 0.227444
#   Epoch 100/100, Loss: 0.223333
# Training complete for run 25
# Run 25 — RMSE: 44.299492, MSE: 1962.444952, NMSE: 0.0074761506
#
# ===== RUN 26/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.273784
#   Epoch 20/100, Loss: 0.245255
#   Epoch 30/100, Loss: 0.231910
#   Epoch 40/100, Loss: 0.230554
#   Epoch 50/100, Loss: 0.227130
#   Epoch 60/100, Loss: 0.223847
#   Epoch 70/100, Loss: 0.221428
#   Epoch 80/100, Loss: 0.216055
#   Epoch 90/100, Loss: 0.212588
#   Epoch 100/100, Loss: 0.210477
# Training complete for run 26
# Run 26 — RMSE: 37.615310, MSE: 1414.911537, NMSE: 0.0047372153
#
# ===== RUN 27/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.279408
#   Epoch 20/100, Loss: 0.265807
#   Epoch 30/100, Loss: 0.256734
#   Epoch 40/100, Loss: 0.253462
#   Epoch 50/100, Loss: 0.251546
#   Epoch 60/100, Loss: 0.249785
#   Epoch 70/100, Loss: 0.247768
#   Epoch 80/100, Loss: 0.244964
#   Epoch 90/100, Loss: 0.239732
#   Epoch 100/100, Loss: 0.222601
# Training complete for run 27
# Run 27 — RMSE: 43.320809, MSE: 1876.692535, NMSE: 0.0064996350
#
# ===== RUN 28/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.280800
#   Epoch 20/100, Loss: 0.275976
#   Epoch 30/100, Loss: 0.263457
#   Epoch 40/100, Loss: 0.248769
#   Epoch 50/100, Loss: 0.241416
#   Epoch 60/100, Loss: 0.233748
#   Epoch 70/100, Loss: 0.226510
#   Epoch 80/100, Loss: 0.220341
#   Epoch 90/100, Loss: 0.215288
#   Epoch 100/100, Loss: 0.209606
# Training complete for run 28
# Run 28 — RMSE: 42.654530, MSE: 1819.408955, NMSE: 0.0066925206
#
# ===== RUN 29/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.276393
#   Epoch 20/100, Loss: 0.255816
#   Epoch 30/100, Loss: 0.227665
#   Epoch 40/100, Loss: 0.222557
#   Epoch 50/100, Loss: 0.220280
#   Epoch 60/100, Loss: 0.216200
#   Epoch 70/100, Loss: 0.212358
#   Epoch 80/100, Loss: 0.209256
#   Epoch 90/100, Loss: 0.206110
#   Epoch 100/100, Loss: 0.203909
# Training complete for run 29
# Run 29 — RMSE: 38.372309, MSE: 1472.434099, NMSE: 0.0054287183
#
# ===== RUN 30/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.276662
#   Epoch 20/100, Loss: 0.268534
#   Epoch 30/100, Loss: 0.247760
#   Epoch 40/100, Loss: 0.235162
#   Epoch 50/100, Loss: 0.230262
#   Epoch 60/100, Loss: 0.228085
#   Epoch 70/100, Loss: 0.226964
#   Epoch 80/100, Loss: 0.225785
#   Epoch 90/100, Loss: 0.224575
#   Epoch 100/100, Loss: 0.223325
# Training complete for run 30
# Run 30 — RMSE: 44.740372, MSE: 2001.700847, NMSE: 0.0070134088
#
# ===== RUN 31/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.277901
#   Epoch 20/100, Loss: 0.274243
#   Epoch 30/100, Loss: 0.263044
#   Epoch 40/100, Loss: 0.242215
#   Epoch 50/100, Loss: 0.222526
#   Epoch 60/100, Loss: 0.210297
#   Epoch 70/100, Loss: 0.201733
#   Epoch 80/100, Loss: 0.195589
#   Epoch 90/100, Loss: 0.191097
#   Epoch 100/100, Loss: 0.187494
# Training complete for run 31
# Run 31 — RMSE: 41.943892, MSE: 1759.290041, NMSE: 0.0060645203
#
# ===== RUN 32/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.270934
#   Epoch 20/100, Loss: 0.261859
#   Epoch 30/100, Loss: 0.255801
#   Epoch 40/100, Loss: 0.249834
#   Epoch 50/100, Loss: 0.243144
#   Epoch 60/100, Loss: 0.236485
#   Epoch 70/100, Loss: 0.230570
#   Epoch 80/100, Loss: 0.224908
#   Epoch 90/100, Loss: 0.220192
#   Epoch 100/100, Loss: 0.215841
# Training complete for run 32
# Run 32 — RMSE: 44.041877, MSE: 1939.686895, NMSE: 0.0072955808
#
# ===== RUN 33/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.282209
#   Epoch 20/100, Loss: 0.274926
#   Epoch 30/100, Loss: 0.265216
#   Epoch 40/100, Loss: 0.243656
#   Epoch 50/100, Loss: 0.236248
#   Epoch 60/100, Loss: 0.233212
#   Epoch 70/100, Loss: 0.230731
#   Epoch 80/100, Loss: 0.228072
#   Epoch 90/100, Loss: 0.225750
#   Epoch 100/100, Loss: 0.224283
# Training complete for run 33
# Run 33 — RMSE: 45.200759, MSE: 2043.108659, NMSE: 0.0068164083
#
# ===== RUN 34/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.280909
#   Epoch 20/100, Loss: 0.268612
#   Epoch 30/100, Loss: 0.256306
#   Epoch 40/100, Loss: 0.250692
#   Epoch 50/100, Loss: 0.245312
#   Epoch 60/100, Loss: 0.238395
#   Epoch 70/100, Loss: 0.231797
#   Epoch 80/100, Loss: 0.228800
#   Epoch 90/100, Loss: 0.225631
#   Epoch 100/100, Loss: 0.223567
# Training complete for run 34
# Run 34 — RMSE: 40.948925, MSE: 1676.814497, NMSE: 0.0060750640
#
# ===== RUN 35/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.277313
#   Epoch 20/100, Loss: 0.254165
#   Epoch 30/100, Loss: 0.240475
#   Epoch 40/100, Loss: 0.237513
#   Epoch 50/100, Loss: 0.234147
#   Epoch 60/100, Loss: 0.228795
#   Epoch 70/100, Loss: 0.219731
#   Epoch 80/100, Loss: 0.211955
#   Epoch 90/100, Loss: 0.203217
#   Epoch 100/100, Loss: 0.194731
# Training complete for run 35
# Run 35 — RMSE: 39.636797, MSE: 1571.075708, NMSE: 0.0055392561
#
# ===== RUN 36/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.274679
#   Epoch 20/100, Loss: 0.254914
#   Epoch 30/100, Loss: 0.241249
#   Epoch 40/100, Loss: 0.232504
#   Epoch 50/100, Loss: 0.228492
#   Epoch 60/100, Loss: 0.217503
#   Epoch 70/100, Loss: 0.205974
#   Epoch 80/100, Loss: 0.196803
#   Epoch 90/100, Loss: 0.190293
#   Epoch 100/100, Loss: 0.182250
# Training complete for run 36
# Run 36 — RMSE: 45.139722, MSE: 2037.594490, NMSE: 0.0071801891
#
# ===== RUN 37/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.274835
#   Epoch 20/100, Loss: 0.257083
#   Epoch 30/100, Loss: 0.244254
#   Epoch 40/100, Loss: 0.236542
#   Epoch 50/100, Loss: 0.227408
#   Epoch 60/100, Loss: 0.219145
#   Epoch 70/100, Loss: 0.212586
#   Epoch 80/100, Loss: 0.206016
#   Epoch 90/100, Loss: 0.197660
#   Epoch 100/100, Loss: 0.189269
# Training complete for run 37
# Run 37 — RMSE: 40.937300, MSE: 1675.862513, NMSE: 0.0059292794
#
# ===== RUN 38/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.278285
#   Epoch 20/100, Loss: 0.276709
#   Epoch 30/100, Loss: 0.275343
#   Epoch 40/100, Loss: 0.274381
#   Epoch 50/100, Loss: 0.273312
#   Epoch 60/100, Loss: 0.272018
#   Epoch 70/100, Loss: 0.270207
#   Epoch 80/100, Loss: 0.268205
#   Epoch 90/100, Loss: 0.266093
#   Epoch 100/100, Loss: 0.263277
# Training complete for run 38
# Run 38 — RMSE: 47.769387, MSE: 2281.914381, NMSE: 0.0085383478
#
# ===== RUN 39/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.279219
#   Epoch 20/100, Loss: 0.270403
#   Epoch 30/100, Loss: 0.260337
#   Epoch 40/100, Loss: 0.250610
#   Epoch 50/100, Loss: 0.244201
#   Epoch 60/100, Loss: 0.241787
#   Epoch 70/100, Loss: 0.239474
#   Epoch 80/100, Loss: 0.233936
#   Epoch 90/100, Loss: 0.226686
#   Epoch 100/100, Loss: 0.218924
# Training complete for run 39
# Run 39 — RMSE: 42.800942, MSE: 1831.920635, NMSE: 0.0069222398
#
# ===== RUN 40/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.276616
#   Epoch 20/100, Loss: 0.266066
#   Epoch 30/100, Loss: 0.246592
#   Epoch 40/100, Loss: 0.237205
#   Epoch 50/100, Loss: 0.227738
#   Epoch 60/100, Loss: 0.220014
#   Epoch 70/100, Loss: 0.213154
#   Epoch 80/100, Loss: 0.205409
#   Epoch 90/100, Loss: 0.198474
#   Epoch 100/100, Loss: 0.193704
# Training complete for run 40
# Run 40 — RMSE: 40.816319, MSE: 1665.971857, NMSE: 0.0060368829
#
# ===== RUN 41/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.279258
#   Epoch 20/100, Loss: 0.274750
#   Epoch 30/100, Loss: 0.269953
#   Epoch 40/100, Loss: 0.263793
#   Epoch 50/100, Loss: 0.256110
#   Epoch 60/100, Loss: 0.247259
#   Epoch 70/100, Loss: 0.239218
#   Epoch 80/100, Loss: 0.231211
#   Epoch 90/100, Loss: 0.224700
#   Epoch 100/100, Loss: 0.220398
# Training complete for run 41
# Run 41 — RMSE: 41.772285, MSE: 1744.923756, NMSE: 0.0065449095
#
# ===== RUN 42/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.276519
#   Epoch 20/100, Loss: 0.270157
#   Epoch 30/100, Loss: 0.259755
#   Epoch 40/100, Loss: 0.247779
#   Epoch 50/100, Loss: 0.235767
#   Epoch 60/100, Loss: 0.223263
#   Epoch 70/100, Loss: 0.218751
#   Epoch 80/100, Loss: 0.216818
#   Epoch 90/100, Loss: 0.215482
#   Epoch 100/100, Loss: 0.213602
# Training complete for run 42
# Run 42 — RMSE: 39.413234, MSE: 1553.403030, NMSE: 0.0058313767
#
# ===== RUN 43/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.276027
#   Epoch 20/100, Loss: 0.275808
#   Epoch 30/100, Loss: 0.274845
#   Epoch 40/100, Loss: 0.273189
#   Epoch 50/100, Loss: 0.270435
#   Epoch 60/100, Loss: 0.265641
#   Epoch 70/100, Loss: 0.259312
#   Epoch 80/100, Loss: 0.251685
#   Epoch 90/100, Loss: 0.242802
#   Epoch 100/100, Loss: 0.233769
# Training complete for run 43
# Run 43 — RMSE: 44.011202, MSE: 1936.985916, NMSE: 0.0074361331
#
# ===== RUN 44/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.273367
#   Epoch 20/100, Loss: 0.268272
#   Epoch 30/100, Loss: 0.261063
#   Epoch 40/100, Loss: 0.251787
#   Epoch 50/100, Loss: 0.239059
#   Epoch 60/100, Loss: 0.230260
#   Epoch 70/100, Loss: 0.223782
#   Epoch 80/100, Loss: 0.213056
#   Epoch 90/100, Loss: 0.196351
#   Epoch 100/100, Loss: 0.178709
# Training complete for run 44
# Run 44 — RMSE: 39.573892, MSE: 1566.092946, NMSE: 0.0057403835
#
# ===== RUN 45/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.273293
#   Epoch 20/100, Loss: 0.252962
#   Epoch 30/100, Loss: 0.243044
#   Epoch 40/100, Loss: 0.232242
#   Epoch 50/100, Loss: 0.224267
#   Epoch 60/100, Loss: 0.218107
#   Epoch 70/100, Loss: 0.212845
#   Epoch 80/100, Loss: 0.207335
#   Epoch 90/100, Loss: 0.202923
#   Epoch 100/100, Loss: 0.199110
# Training complete for run 45
# Run 45 — RMSE: 40.746350, MSE: 1660.265014, NMSE: 0.0061143172
#
# ===== RUN 46/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.276455
#   Epoch 20/100, Loss: 0.253105
#   Epoch 30/100, Loss: 0.241414
#   Epoch 40/100, Loss: 0.235103
#   Epoch 50/100, Loss: 0.227988
#   Epoch 60/100, Loss: 0.219108
#   Epoch 70/100, Loss: 0.210352
#   Epoch 80/100, Loss: 0.204192
#   Epoch 90/100, Loss: 0.199965
#   Epoch 100/100, Loss: 0.195448
# Training complete for run 46
# Run 46 — RMSE: 40.302918, MSE: 1624.325215, NMSE: 0.0057730900
#
# ===== RUN 47/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.261073
#   Epoch 20/100, Loss: 0.237225
#   Epoch 30/100, Loss: 0.226694
#   Epoch 40/100, Loss: 0.222532
#   Epoch 50/100, Loss: 0.217843
#   Epoch 60/100, Loss: 0.214018
#   Epoch 70/100, Loss: 0.188542
#   Epoch 80/100, Loss: 0.173152
#   Epoch 90/100, Loss: 0.150475
#   Epoch 100/100, Loss: 0.135473
# Training complete for run 47
# Run 47 — RMSE: 36.182926, MSE: 1309.204108, NMSE: 0.0057280563
#
# ===== RUN 48/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.277547
#   Epoch 20/100, Loss: 0.276544
#   Epoch 30/100, Loss: 0.273581
#   Epoch 40/100, Loss: 0.270049
#   Epoch 50/100, Loss: 0.266488
#   Epoch 60/100, Loss: 0.262370
#   Epoch 70/100, Loss: 0.257791
#   Epoch 80/100, Loss: 0.250895
#   Epoch 90/100, Loss: 0.240812
# ...
#   Epoch 10/100, Loss: 0.220549
#   Epoch 20/100, Loss: 0.219813
#   Epoch 30/100, Loss: 0.216041
#   Epoch 40/100, Loss: 0.213276
#   Epoch 50/100, Loss: 0.212263
#   Epoch 60/100, Loss: 0.211805
#   Epoch 70/100, Loss: 0.211296
#   Epoch 80/100, Loss: 0.210260
#   Epoch 90/100, Loss: 0.208343
#   Epoch 100/100, Loss: 0.206629
# Training complete for run 25
# Run 25 — RMSE: 50.137764, MSE: 2513.795396, NMSE: 0.0093422123
#
# ===== RUN 26/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.217010
#   Epoch 20/100, Loss: 0.207197
#   Epoch 30/100, Loss: 0.202179
#   Epoch 40/100, Loss: 0.200397
#   Epoch 50/100, Loss: 0.198776
#   Epoch 60/100, Loss: 0.197111
#   Epoch 70/100, Loss: 0.195266
#   Epoch 80/100, Loss: 0.193591
#   Epoch 90/100, Loss: 0.192003
#   Epoch 100/100, Loss: 0.190557
# Training complete for run 26
# Run 26 — RMSE: 47.729940, MSE: 2278.147169, NMSE: 0.0083714284
#
# ===== RUN 27/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.221736
#   Epoch 20/100, Loss: 0.218803
#   Epoch 30/100, Loss: 0.215495
#   Epoch 40/100, Loss: 0.213440
#   Epoch 50/100, Loss: 0.212205
#   Epoch 60/100, Loss: 0.211637
#   Epoch 70/100, Loss: 0.211028
#   Epoch 80/100, Loss: 0.209738
#   Epoch 90/100, Loss: 0.207609
#   Epoch 100/100, Loss: 0.203622
# Training complete for run 27
# Run 27 — RMSE: 48.953988, MSE: 2396.492942, NMSE: 0.0079081716
#
# ===== RUN 28/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.223197
#   Epoch 20/100, Loss: 0.222669
#   Epoch 30/100, Loss: 0.222142
#   Epoch 40/100, Loss: 0.221568
#   Epoch 50/100, Loss: 0.220854
#   Epoch 60/100, Loss: 0.220140
#   Epoch 70/100, Loss: 0.219245
#   Epoch 80/100, Loss: 0.217940
#   Epoch 90/100, Loss: 0.216050
#   Epoch 100/100, Loss: 0.213737
# Training complete for run 28
# Run 28 — RMSE: 50.205318, MSE: 2520.573922, NMSE: 0.0091101353
#
# ===== RUN 29/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.219482
#   Epoch 20/100, Loss: 0.219751
#   Epoch 30/100, Loss: 0.216331
#   Epoch 40/100, Loss: 0.208967
#   Epoch 50/100, Loss: 0.204537
#   Epoch 60/100, Loss: 0.203247
#   Epoch 70/100, Loss: 0.202310
#   Epoch 80/100, Loss: 0.201600
#   Epoch 90/100, Loss: 0.200844
#   Epoch 100/100, Loss: 0.200185
# Training complete for run 29
# Run 29 — RMSE: 49.544476, MSE: 2454.655135, NMSE: 0.0086285734
#
# ===== RUN 30/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.219488
#   Epoch 20/100, Loss: 0.215330
#   Epoch 30/100, Loss: 0.208063
#   Epoch 40/100, Loss: 0.205002
#   Epoch 50/100, Loss: 0.202829
#   Epoch 60/100, Loss: 0.200852
#   Epoch 70/100, Loss: 0.198361
#   Epoch 80/100, Loss: 0.195066
#   Epoch 90/100, Loss: 0.192171
#   Epoch 100/100, Loss: 0.189051
# Training complete for run 30
# Run 30 — RMSE: 47.524190, MSE: 2258.548590, NMSE: 0.0080428197
#
# ===== RUN 31/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.220299
#   Epoch 20/100, Loss: 0.220411
#   Epoch 30/100, Loss: 0.218463
#   Epoch 40/100, Loss: 0.216481
#   Epoch 50/100, Loss: 0.214044
#   Epoch 60/100, Loss: 0.210620
#   Epoch 70/100, Loss: 0.207051
#   Epoch 80/100, Loss: 0.203528
#   Epoch 90/100, Loss: 0.200507
#   Epoch 100/100, Loss: 0.197339
# Training complete for run 31
# Run 31 — RMSE: 47.983543, MSE: 2302.420370, NMSE: 0.0087925702
#
# ===== RUN 32/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.220838
#   Epoch 20/100, Loss: 0.218878
#   Epoch 30/100, Loss: 0.215788
#   Epoch 40/100, Loss: 0.213094
#   Epoch 50/100, Loss: 0.211358
#   Epoch 60/100, Loss: 0.209672
#   Epoch 70/100, Loss: 0.207886
#   Epoch 80/100, Loss: 0.205772
#   Epoch 90/100, Loss: 0.204109
#   Epoch 100/100, Loss: 0.202204
# Training complete for run 32
# Run 32 — RMSE: 50.155759, MSE: 2515.600182, NMSE: 0.0096957910
#
# ===== RUN 33/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.222226
#   Epoch 20/100, Loss: 0.218378
#   Epoch 30/100, Loss: 0.210912
#   Epoch 40/100, Loss: 0.208214
#   Epoch 50/100, Loss: 0.206209
#   Epoch 60/100, Loss: 0.204793
#   Epoch 70/100, Loss: 0.203941
#   Epoch 80/100, Loss: 0.203317
#   Epoch 90/100, Loss: 0.202741
#   Epoch 100/100, Loss: 0.202153
# Training complete for run 33
# Run 33 — RMSE: 50.105165, MSE: 2510.527538, NMSE: 0.0091389516
#
# ===== RUN 34/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.222133
#   Epoch 20/100, Loss: 0.221173
#   Epoch 30/100, Loss: 0.219937
#   Epoch 40/100, Loss: 0.217965
#   Epoch 50/100, Loss: 0.215627
#   Epoch 60/100, Loss: 0.213322
#   Epoch 70/100, Loss: 0.212184
#   Epoch 80/100, Loss: 0.211487
#   Epoch 90/100, Loss: 0.210147
#   Epoch 100/100, Loss: 0.206292
# Training complete for run 34
# Run 34 — RMSE: 49.237113, MSE: 2424.293288, NMSE: 0.0079932712
#
# ===== RUN 35/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.221166
#   Epoch 20/100, Loss: 0.216834
#   Epoch 30/100, Loss: 0.212391
#   Epoch 40/100, Loss: 0.209539
#   Epoch 50/100, Loss: 0.207730
#   Epoch 60/100, Loss: 0.205508
#   Epoch 70/100, Loss: 0.203468
#   Epoch 80/100, Loss: 0.201658
#   Epoch 90/100, Loss: 0.198922
#   Epoch 100/100, Loss: 0.197018
# Training complete for run 35
# Run 35 — RMSE: 47.966589, MSE: 2300.793708, NMSE: 0.0077176067
#
# ===== RUN 36/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.221487
#   Epoch 20/100, Loss: 0.219313
#   Epoch 30/100, Loss: 0.216756
#   Epoch 40/100, Loss: 0.212768
#   Epoch 50/100, Loss: 0.207677
#   Epoch 60/100, Loss: 0.202485
#   Epoch 70/100, Loss: 0.199210
#   Epoch 80/100, Loss: 0.197076
#   Epoch 90/100, Loss: 0.195511
#   Epoch 100/100, Loss: 0.194825
# Training complete for run 36
# Run 36 — RMSE: 47.027694, MSE: 2211.604014, NMSE: 0.0074863651
#
# ===== RUN 37/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.221514
#   Epoch 20/100, Loss: 0.213231
#   Epoch 30/100, Loss: 0.207443
#   Epoch 40/100, Loss: 0.203869
#   Epoch 50/100, Loss: 0.200362
#   Epoch 60/100, Loss: 0.197748
#   Epoch 70/100, Loss: 0.196224
#   Epoch 80/100, Loss: 0.195149
#   Epoch 90/100, Loss: 0.189650
#   Epoch 100/100, Loss: 0.188623
# Training complete for run 37
# Run 37 — RMSE: 45.912962, MSE: 2108.000098, NMSE: 0.0074491222
#
# ===== RUN 38/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.221074
#   Epoch 20/100, Loss: 0.221284
#   Epoch 30/100, Loss: 0.221138
#   Epoch 40/100, Loss: 0.220812
#   Epoch 50/100, Loss: 0.220352
#   Epoch 60/100, Loss: 0.219740
#   Epoch 70/100, Loss: 0.218900
#   Epoch 80/100, Loss: 0.217866
#   Epoch 90/100, Loss: 0.216859
#   Epoch 100/100, Loss: 0.216116
# Training complete for run 38
# Run 38 — RMSE: 50.805114, MSE: 2581.159595, NMSE: 0.0094610282
#
# ===== RUN 39/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.221788
#   Epoch 20/100, Loss: 0.221654
#   Epoch 30/100, Loss: 0.221463
#   Epoch 40/100, Loss: 0.220927
#   Epoch 50/100, Loss: 0.220391
#   Epoch 60/100, Loss: 0.219608
#   Epoch 70/100, Loss: 0.218239
#   Epoch 80/100, Loss: 0.215711
#   Epoch 90/100, Loss: 0.213674
#   Epoch 100/100, Loss: 0.211493
# Training complete for run 39
# Run 39 — RMSE: 49.917613, MSE: 2491.768133, NMSE: 0.0088612348
#
# ===== RUN 40/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.220772
#   Epoch 20/100, Loss: 0.221156
#   Epoch 30/100, Loss: 0.219758
#   Epoch 40/100, Loss: 0.217144
#   Epoch 50/100, Loss: 0.215819
#   Epoch 60/100, Loss: 0.215624
#   Epoch 70/100, Loss: 0.215526
#   Epoch 80/100, Loss: 0.215172
#   Epoch 90/100, Loss: 0.214531
#   Epoch 100/100, Loss: 0.213646
# Training complete for run 40
# Run 40 — RMSE: 50.623646, MSE: 2562.753520, NMSE: 0.0096985823
#
# ===== RUN 41/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.221310
#   Epoch 20/100, Loss: 0.220243
#   Epoch 30/100, Loss: 0.217737
#   Epoch 40/100, Loss: 0.214046
#   Epoch 50/100, Loss: 0.209796
#   Epoch 60/100, Loss: 0.205290
#   Epoch 70/100, Loss: 0.200969
#   Epoch 80/100, Loss: 0.197261
#   Epoch 90/100, Loss: 0.194002
#   Epoch 100/100, Loss: 0.191219
# Training complete for run 41
# Run 41 — RMSE: 46.644144, MSE: 2175.676201, NMSE: 0.0081419950
#
# ===== RUN 42/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.220187
#   Epoch 20/100, Loss: 0.219633
#   Epoch 30/100, Loss: 0.218168
#   Epoch 40/100, Loss: 0.216311
#   Epoch 50/100, Loss: 0.213730
#   Epoch 60/100, Loss: 0.210838
#   Epoch 70/100, Loss: 0.207771
#   Epoch 80/100, Loss: 0.204393
#   Epoch 90/100, Loss: 0.200870
#   Epoch 100/100, Loss: 0.197493
# Training complete for run 42
# Run 42 — RMSE: 47.723485, MSE: 2277.531059, NMSE: 0.0082497571
#
# ===== RUN 43/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.220301
#   Epoch 20/100, Loss: 0.220725
#   Epoch 30/100, Loss: 0.220758
#   Epoch 40/100, Loss: 0.220600
#   Epoch 50/100, Loss: 0.220336
#   Epoch 60/100, Loss: 0.220012
#   Epoch 70/100, Loss: 0.219643
#   Epoch 80/100, Loss: 0.219231
#   Epoch 90/100, Loss: 0.218773
#   Epoch 100/100, Loss: 0.218264
# Training complete for run 43
# Run 43 — RMSE: 50.760894, MSE: 2576.668309, NMSE: 0.0089867575
#
# ===== RUN 44/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.220337
#   Epoch 20/100, Loss: 0.219903
#   Epoch 30/100, Loss: 0.218275
#   Epoch 40/100, Loss: 0.215757
#   Epoch 50/100, Loss: 0.212611
#   Epoch 60/100, Loss: 0.209449
#   Epoch 70/100, Loss: 0.206545
#   Epoch 80/100, Loss: 0.203709
#   Epoch 90/100, Loss: 0.201176
#   Epoch 100/100, Loss: 0.199114
# Training complete for run 44
# Run 44 — RMSE: 48.072436, MSE: 2310.959123, NMSE: 0.0084135429
#
# ===== RUN 45/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.221087
#   Epoch 20/100, Loss: 0.215841
#   Epoch 30/100, Loss: 0.210932
#   Epoch 40/100, Loss: 0.208178
#   Epoch 50/100, Loss: 0.205083
#   Epoch 60/100, Loss: 0.201563
#   Epoch 70/100, Loss: 0.198324
#   Epoch 80/100, Loss: 0.195242
#   Epoch 90/100, Loss: 0.192350
#   Epoch 100/100, Loss: 0.190050
# Training complete for run 45
# Run 45 — RMSE: 48.351646, MSE: 2337.881666, NMSE: 0.0088245610
#
# ===== RUN 46/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.221465
#   Epoch 20/100, Loss: 0.216241
#   Epoch 30/100, Loss: 0.210547
#   Epoch 40/100, Loss: 0.208832
#   Epoch 50/100, Loss: 0.206763
#   Epoch 60/100, Loss: 0.204877
#   Epoch 70/100, Loss: 0.202812
#   Epoch 80/100, Loss: 0.201365
#   Epoch 90/100, Loss: 0.199564
#   Epoch 100/100, Loss: 0.197775
# Training complete for run 46
# Run 46 — RMSE: 48.341506, MSE: 2336.901243, NMSE: 0.0077414435
#
# ===== RUN 47/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.220449
#   Epoch 20/100, Loss: 0.220255
#   Epoch 30/100, Loss: 0.219956
#   Epoch 40/100, Loss: 0.219463
#   Epoch 50/100, Loss: 0.218662
#   Epoch 60/100, Loss: 0.217381
#   Epoch 70/100, Loss: 0.215491
#   Epoch 80/100, Loss: 0.213666
#   Epoch 90/100, Loss: 0.211589
#   Epoch 100/100, Loss: 0.209586
# Training complete for run 47
# Run 47 — RMSE: 49.972216, MSE: 2497.222339, NMSE: 0.0091609874
#
# ===== RUN 48/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.218731
#   Epoch 20/100, Loss: 0.219914
#   Epoch 30/100, Loss: 0.220739
#   Epoch 40/100, Loss: 0.221063
#   Epoch 50/100, Loss: 0.221013
#   Epoch 60/100, Loss: 0.220635
#   Epoch 70/100, Loss: 0.220065
#   Epoch 80/100, Loss: 0.219549
#   Epoch 90/100, Loss: 0.219084
#   Epoch 100/100, Loss: 0.218708
# Training complete for run 48
# Run 48 — RMSE: 51.079946, MSE: 2609.160839, NMSE: 0.0095519153
#
# ===== RUN 49/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.221876
#   Epoch 20/100, Loss: 0.219708
#   Epoch 30/100, Loss: 0.216668
#   Epoch 40/100, Loss: 0.212424
#   Epoch 50/100, Loss: 0.209055
#   Epoch 60/100, Loss: 0.206543
#   Epoch 70/100, Loss: 0.204552
#   Epoch 80/100, Loss: 0.202938
#   Epoch 90/100, Loss: 0.201645
#   Epoch 100/100, Loss: 0.200825
# Training complete for run 49
# Run 49 — RMSE: 49.335217, MSE: 2433.963596, NMSE: 0.0079712734
#
# ===== RUN 50/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.219934
#   Epoch 20/100, Loss: 0.220623
#   Epoch 30/100, Loss: 0.220811
#   Epoch 40/100, Loss: 0.220629
#   Epoch 50/100, Loss: 0.220260
#   Epoch 60/100, Loss: 0.219578
#   Epoch 70/100, Loss: 0.218040
#   Epoch 80/100, Loss: 0.216001
#   Epoch 90/100, Loss: 0.213284
#   Epoch 100/100, Loss: 0.209484
# Training complete for run 50
# Run 50 — RMSE: 49.606566, MSE: 2460.811386, NMSE: 0.0086550586
#
# ===== RUN 51/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.221701
#   Epoch 20/100, Loss: 0.219506
#   Epoch 30/100, Loss: 0.214766
#   Epoch 40/100, Loss: 0.211229
#   Epoch 50/100, Loss: 0.208577
#   Epoch 60/100, Loss: 0.206963
#   Epoch 70/100, Loss: 0.205282
#   Epoch 80/100, Loss: 0.203040
#   Epoch 90/100, Loss: 0.200918
#   Epoch 100/100, Loss: 0.198871
# Training complete for run 51
# Run 51 — RMSE: 49.415378, MSE: 2441.879541, NMSE: 0.0091798949
#
# ===== RUN 52/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.219646
#   Epoch 20/100, Loss: 0.214790
#   Epoch 30/100, Loss: 0.208176
#   Epoch 40/100, Loss: 0.204955
#   Epoch 50/100, Loss: 0.203137
#   Epoch 60/100, Loss: 0.201766
#   Epoch 70/100, Loss: 0.200768
#   Epoch 80/100, Loss: 0.200035
#   Epoch 90/100, Loss: 0.199527
#   Epoch 100/100, Loss: 0.198958
# Training complete for run 52
# Run 52 — RMSE: 49.516074, MSE: 2451.841576, NMSE: 0.0088903371
#
# ===== RUN 53/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.221051
#   Epoch 20/100, Loss: 0.216388
#   Epoch 30/100, Loss: 0.207434
#   Epoch 40/100, Loss: 0.203647
#   Epoch 50/100, Loss: 0.201935
#   Epoch 60/100, Loss: 0.200856
#   Epoch 70/100, Loss: 0.200115
#   Epoch 80/100, Loss: 0.199516
#   Epoch 90/100, Loss: 0.198934
#   Epoch 100/100, Loss: 0.198465
# Training complete for run 53
# Run 53 — RMSE: 48.735951, MSE: 2375.192890, NMSE: 0.0085399512
#
# ===== RUN 54/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.222648
#   Epoch 20/100, Loss: 0.222327
#   Epoch 30/100, Loss: 0.221902
#   Epoch 40/100, Loss: 0.221349
#   Epoch 50/100, Loss: 0.220559
#   Epoch 60/100, Loss: 0.219424
#   Epoch 70/100, Loss: 0.217990
#   Epoch 80/100, Loss: 0.216386
#   Epoch 90/100, Loss: 0.214710
#   Epoch 100/100, Loss: 0.213124
# Training complete for run 54
# Run 54 — RMSE: 50.341662, MSE: 2534.282972, NMSE: 0.0093720555
#
# ===== RUN 55/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.219837
#   Epoch 20/100, Loss: 0.217181
#   Epoch 30/100, Loss: 0.212860
#   Epoch 40/100, Loss: 0.210513
#   Epoch 50/100, Loss: 0.209281
#   Epoch 60/100, Loss: 0.208721
#   Epoch 70/100, Loss: 0.207795
#   Epoch 80/100, Loss: 0.207425
#   Epoch 90/100, Loss: 0.207203
#   Epoch 100/100, Loss: 0.207049
# Training complete for run 55
# Run 55 — RMSE: 49.839175, MSE: 2483.943322, NMSE: 0.0097965656
#
# ===== RUN 56/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.221006
#   Epoch 20/100, Loss: 0.220868
#   Epoch 30/100, Loss: 0.220254
#   Epoch 40/100, Loss: 0.219367
#   Epoch 50/100, Loss: 0.218382
#   Epoch 60/100, Loss: 0.217273
#   Epoch 70/100, Loss: 0.215831
#   Epoch 80/100, Loss: 0.213593
#   Epoch 90/100, Loss: 0.211495
#   Epoch 100/100, Loss: 0.209256
# Training complete for run 56
# Run 56 — RMSE: 49.497801, MSE: 2450.032288, NMSE: 0.0088371156
#
# ===== RUN 57/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.219791
#   Epoch 20/100, Loss: 0.218915
#   Epoch 30/100, Loss: 0.216603
#   Epoch 40/100, Loss: 0.214964
#   Epoch 50/100, Loss: 0.213782
#   Epoch 60/100, Loss: 0.212588
#   Epoch 70/100, Loss: 0.210687
#   Epoch 80/100, Loss: 0.208416
#   Epoch 90/100, Loss: 0.206211
#   Epoch 100/100, Loss: 0.204027
# Training complete for run 57
# Run 57 — RMSE: 49.226565, MSE: 2423.254662, NMSE: 0.0092531231
#
# ===== RUN 58/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.221928
#   Epoch 20/100, Loss: 0.219917
#   Epoch 30/100, Loss: 0.216854
#   Epoch 40/100, Loss: 0.215066
#   Epoch 50/100, Loss: 0.214075
#   Epoch 60/100, Loss: 0.213328
#   Epoch 70/100, Loss: 0.212442
#   Epoch 80/100, Loss: 0.211467
#   Epoch 90/100, Loss: 0.210377
#   Epoch 100/100, Loss: 0.209085
# Training complete for run 58
# Run 58 — RMSE: 49.612668, MSE: 2461.416792, NMSE: 0.0096080563
#
# ===== RUN 59/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.222158
#   Epoch 20/100, Loss: 0.221680
#   Epoch 30/100, Loss: 0.221038
#   Epoch 40/100, Loss: 0.219934
#   Epoch 50/100, Loss: 0.218546
#   Epoch 60/100, Loss: 0.217064
#   Epoch 70/100, Loss: 0.215172
#   Epoch 80/100, Loss: 0.212939
#   Epoch 90/100, Loss: 0.210907
#   Epoch 100/100, Loss: 0.209176
# Training complete for run 59
# Run 59 — RMSE: 49.793443, MSE: 2479.386996, NMSE: 0.0093014143
#
# ===== RUN 60/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.221200
#   Epoch 20/100, Loss: 0.221788
#   Epoch 30/100, Loss: 0.221915
#   Epoch 40/100, Loss: 0.221681
#   Epoch 50/100, Loss: 0.221190
#   Epoch 60/100, Loss: 0.220455
#   Epoch 70/100, Loss: 0.219453
#   Epoch 80/100, Loss: 0.218446
#   Epoch 90/100, Loss: 0.217292
#   Epoch 100/100, Loss: 0.215871
# Training complete for run 60
# Run 60 — RMSE: 50.383253, MSE: 2538.472195, NMSE: 0.0092125375
#
# ===== STATS FOR NOISE 10.0% (60 runs) =====
# RMSE: 49.100725 +/- 1.155656
# MSE:  2412.216728 +/- 112.780998
# NMSE: 0.0087670878 +/- 0.0006680478
# Best run: 37 (RMSE: 45.912962)

# %% [markdown]
# ## Results

# %%
# ============================================================
# Final Metrics Summary & Plots per Noise Level
# ============================================================
from tabulate import tabulate

for entry in _molab_results:
    lam = entry[0]
    mean_rmse, std_rmse = entry[1], entry[2]
    mean_mse, std_mse = entry[3], entry[4]
    mean_nmse, std_nmse = entry[5], entry[6]
    best_rmse_val = entry[7]
    best_predictions = entry[8]
    best_losses = entry[9]
    raw_values_for_plot = entry[10]
    
    print("\n" + "="*80)
    print(f"RESULTS FOR NOISE LEVEL: {lam*100:.1f}%")
    print("="*80)
    
    print(f'Mean RMSE: {mean_rmse:.6f} +/- {std_rmse:.6f}')
    print(f'Mean MSE:  {mean_mse:.6f} +/- {std_mse:.6f}')
    print(f'Mean NMSE: {mean_nmse:.10f} +/- {std_nmse:.10f}')
    print(f'Best RMSE: {best_rmse_val:.6f}')
    
    actual = raw_values_for_plot[-60:]
    
    plt.figure(figsize=(12, 5))
    plt.plot(actual, label='Actual', color='blue', linewidth=1.5)
    plt.plot(best_predictions, label='Predicted (Best Run)', color='red',
             linewidth=1.5, linestyle='--')
    plt.title(f'Predictions vs Actual (Noise {lam*100:.1f}%)')
    plt.xlabel('Time Step')
    plt.ylabel('Value')
    plt.legend()
    plt.grid(True, alpha=0.3)
    plt.tight_layout()
    plt.show()

    plt.figure(figsize=(12, 4))
    plt.plot(best_losses, color='green', linewidth=1.0)
    plt.title(f'Training Loss (Best Run, Noise {lam*100:.1f}%)')
    plt.xlabel('Epoch')
    plt.ylabel('MSE Loss')
    plt.grid(True, alpha=0.3)
    plt.tight_layout()
    plt.show()

print("\n" + "="*80)
print("FINAL RESULTS TABLE ACROSS ALL NOISE LEVELS")
print("="*80)
df_res = pd.DataFrame(
    [[r[0], f'{r[1]:.6f} +/- {r[2]:.6f}', f'{r[3]:.6f} +/- {r[4]:.6f}', 
      f'{r[5]:.10f} +/- {r[6]:.10f}', f'{r[7]:.6f}'] for r in _molab_results],
    columns=['Noise Level', 'RMSE (mean+/-std)', 'MSE (mean+/-std)', 'NMSE (mean+/-std)', 'Best RMSE']
)
print(tabulate(df_res, headers='keys', tablefmt='github', showindex=False))
# Out:
# ================================================================================
# RESULTS FOR NOISE LEVEL: 0.0%
# ================================================================================
# Mean RMSE: 42.749069 +/- 2.666264
# Mean MSE:  1834.591831 +/- 224.075255
# Mean NMSE: 0.0067014901 +/- 0.0010152260
# Best RMSE: 33.645095
# ================================================================================
# RESULTS FOR NOISE LEVEL: 0.5%
# ================================================================================
# Mean RMSE: 42.383696 +/- 2.698122
# Mean MSE:  1803.657566 +/- 225.930947
# Mean NMSE: 0.0066397068 +/- 0.0009855188
# Best RMSE: 34.148731
# ================================================================================
# RESULTS FOR NOISE LEVEL: 5.0%
# ================================================================================
# Mean RMSE: 45.223880 +/- 2.040716
# Mean MSE:  2049.363856 +/- 184.799758
# Mean NMSE: 0.0075156045 +/- 0.0007969639
# Best RMSE: 39.921814
# ================================================================================
# RESULTS FOR NOISE LEVEL: 10.0%
# ================================================================================
# Mean RMSE: 49.100725 +/- 1.155656
# Mean MSE:  2412.216728 +/- 112.780998
# Mean NMSE: 0.0087670878 +/- 0.0006680478
# Best RMSE: 45.912962
# ================================================================================
# FINAL RESULTS TABLE ACROSS ALL NOISE LEVELS
# ================================================================================
# |   Noise Level | RMSE (mean+/-std)      | MSE (mean+/-std)           | NMSE (mean+/-std)             |   Best RMSE |
# |---------------|------------------------|----------------------------|-------------------------------|-------------|
# |         0     | 42.749069 +/- 2.666264 | 1834.591831 +/- 224.075255 | 0.0067014901 +/- 0.0010152260 |     33.6451 |
# |         0.005 | 42.383696 +/- 2.698122 | 1803.657566 +/- 225.930947 | 0.0066397068 +/- 0.0009855188 |     34.1487 |
# |         0.05  | 45.223880 +/- 2.040716 | 2049.363856 +/- 184.799758 | 0.0075156045 +/- 0.0007969639 |     39.9218 |
# |         0.1   | 49.100725 +/- 1.155656 | 2412.216728 +/- 112.780998 | 0.0087670878 +/- 0.0006680478 |     45.913  |

# %% [markdown]
# ## Observations
#
# ### Gaussian Noise robustness on Monthly Milk Production
#
# **Run the notebook to populate results.**
