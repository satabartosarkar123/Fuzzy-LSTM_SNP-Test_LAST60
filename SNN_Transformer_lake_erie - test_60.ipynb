# %% [markdown]
# # Spiking Neural Network Transformer for Time Series Forecasting
# ## Dataset: Lake Erie Levels
#
# **Architecture:** Spike-Driven Transformer (Yao et al., 2024)
# adapted for univariate time series forecasting.
#
# **Reference:** *Spike-driven Transformer V2: Meta Spiking Neural Network Architecture
# Inspiring the Design of Next-generation Neuromorphic Chips* — ICLR 2024
#
# This notebook is a **controlled architectural substitution** of the LSTM-SNP model.
# All preprocessing, training protocol, and evaluation methodology are identical
# to the LSTM-SNP experiments — only the model architecture changes.
#
# ### Key Equations (from the paper)
#
# **LIF Neuron (Eq 1-3):**
# - $U[t] = H[t-1] + X[t]$  — membrane potential accumulation
# - $S[t] = \text{Hea}(U[t] - u_{th})$  — spike generation (Heaviside)
# - $H[t] = V_{reset} \cdot S[t] + (\beta \cdot U[t]) \cdot (1 - S[t])$  — temporal output with reset
#
# **SDSA (Eq 14):**
# - $\text{SDSA}(Q, K, V) = \mathcal{SN}(\text{SUM}_c(Q_S \otimes K_S)) \otimes V_S$
#
# **Membrane Shortcut (Eq 9, 11):**
# - $U'_l = \text{SDSA}(S_{l-1}) + U_{l-1}$
# - $S_l = \mathcal{SN}(\text{MLP}(S'_l) + U'_l)$

# %%
# ============================================================
# GLOBAL IMPORTS (Consolidated)
# ============================================================
from IPython.display import display
from math import sqrt
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt
import numpy as np
import os
import pandas as pd
import platform
import time
import time as _timer_module
import torch
import torch.nn as nn
import torch.nn.functional as F
import warnings

# ============================================================
# GLOBAL CONFIGURATION (CUDA & NOISE)
# ============================================================
import os
os.environ['CUDA_VISIBLE_DEVICES'] = '0' # Enable RTX 6000 Pro
import torch
if torch.cuda.is_available():
    torch.cuda.set_device(0)

noise_levels = [0.0, 0.005, 0.05, 0.10]
_molab_results = []

def add_gaussian_noise(series, noise_level):
    if noise_level == 0.0:
        return series
    noise = np.random.normal(0, noise_level, len(series))
    return series + noise
# ============================================================

# ============================================================
# FINAL RESULTS TABLE ACROSS ALL NOISE LEVELS
# ============================================================
import pandas as pd
from tabulate import tabulate
if len(_molab_results) > 0:
    df_res = pd.DataFrame(_molab_results, columns=['Noise Level (lambda)', 'RMSE', 'MSE', 'NMSE'])
    print('\n' + '='*80)
    print('FINAL RESULTS TABLE ACROSS ALL 4 NOISE LEVELS')
    print('='*80)
    print(tabulate(df_res, headers='keys', tablefmt='github', showindex=False))

# %%
# ============================================================
# GLOBAL IMPORTS (Consolidated)
# ============================================================

# ============================================================
# GLOBAL CONFIGURATION (CUDA & NOISE)
# ============================================================
os.environ['CUDA_VISIBLE_DEVICES'] = '0' # Enable RTX 6000 Pro
if torch.cuda.is_available():
    torch.cuda.set_device(0)

noise_levels = [0.0, 0.005, 0.05, 0.10]
_molab_results = []

def add_gaussian_noise(series, noise_level):
    if noise_level == 0.0:
        return series
    noise = np.random.normal(0, noise_level, len(series))
    return series + noise
# ============================================================

# ============================================================
# FINAL RESULTS TABLE ACROSS ALL NOISE LEVELS
# ============================================================
import pandas as pd
from tabulate import tabulate
if len(_molab_results) > 0:
    df_res = pd.DataFrame(_molab_results, columns=['Noise Level (lambda)', 'RMSE', 'MSE', 'NMSE'])
    print('\n' + '='*80)
    print('FINAL RESULTS TABLE ACROSS ALL 4 NOISE LEVELS')
    print('='*80)
    print(tabulate(df_res, headers='keys', tablefmt='github', showindex=False))

# %%
# ============================================================
# PROCESS IDENTIFICATION
# ============================================================
print(f"Process ID (PID): {os.getpid()}")
# Out:
# Process ID (PID): 14716

# %%
# ============================================================
# NOTEBOOK TIMER — START
# ============================================================
_NOTEBOOK_START_TIME = _timer_module.time()
print(f"Notebook execution started at: {_timer_module.strftime('%Y-%m-%d %H:%M:%S')}")
# Out:
# Notebook execution started at: 2026-08-30 09:57:46

# %%
# ============================================================
# ALL IMPORTS
# ============================================================
warnings.filterwarnings('ignore')

print(f"PyTorch version: {torch.__version__}")
print(f"CUDA available: {torch.cuda.is_available()}")
if hasattr(torch.backends, 'mps'):
    print(f"MPS available: {torch.backends.mps.is_available()}")
# Out:
# PyTorch version: 2.11.0+cu128
# CUDA available: True
# MPS available: False

# %%
# ============================================================
# PREPROCESSING — Identical to LSTM-SNP Pipeline
# ============================================================
# 1. First-order differencing
# 2. Lag-1 supervised learning format
# 3. Train-test split (last 60 = test)
# 4. MinMaxScaler [-1, 1] (fit on train only)
# 5. Reshape to (samples, 1, 1)

def difference(dataset, interval=1):
    """First-order differencing: diff(t) = raw(t) - raw(t-interval)"""
    diff = []
    for i in range(interval, len(dataset)):
        value = dataset[i] - dataset[i - interval]
        diff.append(value)
    return np.array(diff)


def timeseries_to_supervised(data, lag=1):
    """Convert to supervised format: X(t)=data(t-lag), y(t)=data(t). NaN filled with 0."""
    df = pd.DataFrame(data)
    columns = [df.shift(i) for i in range(1, lag + 1)]
    columns.append(df)
    df = pd.concat(columns, axis=1)
    df.fillna(0, inplace=True)
    return df.values


def prepare_data(raw_values, n_test=60):
    """Full preprocessing pipeline (identical to LSTM-SNP notebooks)."""
    # Step 1: First-order differencing
    diff_values = difference(raw_values, 1)

    # Step 2: Convert to supervised format (lag=1)
    supervised = timeseries_to_supervised(diff_values, 1)

    # Step 3: Train-test split
    train, test = supervised[:-n_test], supervised[-n_test:]

    # Step 4: Scale to [-1, 1] — fit on train only
    scaler = MinMaxScaler(feature_range=(-1, 1))
    scaler.fit(train)
    train_scaled = scaler.transform(train)
    test_scaled = scaler.transform(test)

    # Step 5: Split into X, y
    X_train, y_train = train_scaled[:, 0:-1], train_scaled[:, -1]
    X_test, y_test = test_scaled[:, 0:-1], test_scaled[:, -1]

    # Step 6: Reshape X for model input: (samples, 1, features=1)
    X_train = X_train.reshape((X_train.shape[0], 1, X_train.shape[1]))
    X_test = X_test.reshape((X_test.shape[0], 1, X_test.shape[1]))

    return X_train, y_train, X_test, y_test, scaler, raw_values

# %%
# ============================================================
# SPIKING NEURON — Leaky Integrate-and-Fire (LIF)
# ============================================================
# Faithfully implements Equations 1-3 from the Spike-Driven Transformer paper:
#
#   Eq 1: U[t] = H[t-1] + X[t]                              (membrane potential)
#   Eq 2: S[t] = Hea(U[t] - u_th)                           (spike generation)
#   Eq 3: H[t] = V_reset * S[t] + (β * U[t]) * (1 - S[t])  (temporal output)
#
# Where:
#   U[t] = membrane potential at timestep t
#   H[t] = temporal output (decayed potential or reset)
#   S[t] = binary spike output {0, 1}
#   β < 1 = decay factor
#   u_th = firing threshold
#   V_reset = reset potential after spike
#   Hea(·) = Heaviside step function
#
# Surrogate gradient (for backpropagation):
#   ∂S/∂U ≈ 1 / (1 + α|U - u_th|)²


class SurrogateHeaviside(torch.autograd.Function):
    """Heaviside step with surrogate gradient for backpropagation."""
    @staticmethod
    def forward(ctx, input, alpha):
        ctx.save_for_backward(input)
        ctx.alpha = alpha
        return (input >= 0).float()

    @staticmethod
    def backward(ctx, grad_output):
        (input,) = ctx.saved_tensors
        alpha = ctx.alpha
        grad_input = grad_output / (1 + alpha * input.abs()) ** 2
        return grad_input, None


def surrogate_heaviside(x, alpha=2.0):
    return SurrogateHeaviside.apply(x, alpha)


class LIFNeuron(nn.Module):
    """
    Leaky Integrate-and-Fire neuron (Eq 1-3 from the paper).

    Processes input across T spiking timesteps.
    Membrane potential H is maintained across timesteps, reset per forward call.
    """
    def __init__(self, beta=0.5, v_th=0.5, v_reset=0.0, alpha=2.0):
        super().__init__()
        self.beta = beta        # decay factor (β < 1)
        self.v_th = v_th        # firing threshold (u_th)
        self.v_reset = v_reset  # reset potential (V_reset)
        self.alpha = alpha      # surrogate gradient sharpness

    def forward(self, x_seq):
        """
        x_seq: (batch, T, features) — input current across T timesteps.
        Returns: (batch, T, features) — binary spike output.
        """
        batch, T, features = x_seq.shape
        device = x_seq.device

        H = torch.zeros(batch, features, device=device)  # temporal output H[t-1]
        spikes = []

        for t in range(T):
            # Eq 1: U[t] = H[t-1] + X[t]
            U = H + x_seq[:, t, :]

            # Eq 2: S[t] = Hea(U[t] - u_th)
            S = surrogate_heaviside(U - self.v_th, self.alpha)

            # Eq 3: H[t] = V_reset * S[t] + (β * U[t]) * (1 - S[t])
            H = self.v_reset * S + (self.beta * U) * (1 - S.detach())

            spikes.append(S)

        return torch.stack(spikes, dim=1)  # (batch, T, features)

# %%
# ============================================================
# SPIKE-DRIVEN SELF-ATTENTION (SDSA)
# ============================================================
# Implements Equations 14-16 from the Spike-Driven Transformer paper.
#
# Standard Self-Attention (Eq 13):
#   VSA(Q,K,V) = softmax(QK^T / √d) · V     → O(N²D + N²D)
#
# Spike-Driven Self-Attention (Eq 14):
#   SDSA(Q,K,V) = SN(SUM_c(Q_S ⊗ K_S)) ⊗ V_S
#
# Where:
#   Q, K, V = linear projections of spike input S (float-point)
#   Q_S, K_S, V_S = SN(Q), SN(K), SN(V)  (converted to spikes)
#   ⊗ = Hadamard product (element-wise multiplication)
#   SUM_c = column sum (sum over token/temporal dimension)
#   SN = Spiking Neuron (LIF)
#
# The key insight: since spikes are binary {0, 1}, the Hadamard product
# Q_S ⊗ K_S is equivalent to a mask operation. SUM_c aggregates activity
# across tokens to produce a D-dimensional feature attention mask.
# This mask gates V_S, selecting relevant feature channels.
#
# Computational complexity: O(ND) — linear in both N and D.


class SpikeDrivenSelfAttention(nn.Module):
    """
    SDSA adapted for 1D time series.

    Input: spike tensor S ∈ {0,1}^(batch, T, D)
    Output: spike-gated features ∈ R^(batch, T, D)
    """
    def __init__(self, d_model, n_heads, beta=0.5, v_th=0.5):
        super().__init__()
        assert d_model % n_heads == 0
        self.d_model = d_model
        self.n_heads = n_heads
        self.d_k = d_model // n_heads

        # Linear projections (float-point, Eq 14 setup)
        self.W_Q = nn.Linear(d_model, d_model)
        self.W_K = nn.Linear(d_model, d_model)
        self.W_V = nn.Linear(d_model, d_model)
        self.proj = nn.Linear(d_model, d_model)

        # Spiking neurons to convert projections to spike tensors
        self.sn_q = LIFNeuron(beta=beta, v_th=v_th)
        self.sn_k = LIFNeuron(beta=beta, v_th=v_th)
        self.sn_v = LIFNeuron(beta=beta, v_th=v_th)
        # SN for attention mask (Eq 14: SN after SUM_c)
        self.sn_attn = LIFNeuron(beta=beta, v_th=v_th)

    def forward(self, spike_input):
        """
        spike_input: (batch, T, d_model) — spike tensor from previous layer.
        """
        batch, T, D = spike_input.shape

        # Linear projections (float-point)
        Q = self.W_Q(spike_input)
        K = self.W_K(spike_input)
        V = self.W_V(spike_input)

        # Convert to spike tensors via SN (spiking neuron)
        Q_S = self.sn_q(Q)  # (batch, T, D)
        K_S = self.sn_k(K)
        V_S = self.sn_v(V)

        # ── SDSA Computation (Eq 14) ──
        # Step 1: Hadamard product Q_S ⊗ K_S
        QK = Q_S * K_S  # (batch, T, D) — element-wise, spike masking

        # Step 2: SUM_c — sum over temporal dimension (columns)
        # Produces D-dimensional attention vector per batch
        attn_sum = QK.sum(dim=1, keepdim=True)  # (batch, 1, D)

        # Step 3: SN — convert attention map to binary mask
        attn_mask = self.sn_attn(attn_sum)  # (batch, 1, D)

        # Step 4: Hadamard with V_S — gate value spikes by attention mask
        output = attn_mask * V_S  # (batch, T, D) — broadcast across T

        # Output projection
        return self.proj(output)

# %%
# ============================================================
# SPIKING TRANSFORMER BLOCK with Membrane Shortcuts
# ============================================================
# Implements Equations 8-12 from the paper.
#
# The block consists of SDSA + MLP with Membrane Shortcuts (MS):
#
#   Eq 8:  S_0 = SN(U_0)                          (initial spikes)
#   Eq 9:  U'_l = SDSA(S_{l-1}) + U_{l-1}         (MS on SDSA)
#   Eq 10: S'_l = SN(U'_l)
#   Eq 11: S_l = SN(MLP(S'_l) + U'_l)             (MS on MLP)
#   Eq 12: Y = CH(GAP(S_L))                        (output)
#
# Membrane Shortcut (MS) connects membrane potentials between layers,
# ensuring binary spikes are maintained throughout (unlike SEW shortcut).


class SpikingMLP(nn.Module):
    """Simple MLP for the spiking transformer block."""
    def __init__(self, d_model, ff_dim):
        super().__init__()
        self.fc1 = nn.Linear(d_model, ff_dim)
        self.fc2 = nn.Linear(ff_dim, d_model)

    def forward(self, x):
        return self.fc2(F.gelu(self.fc1(x)))


class SpikingTransformerBlock(nn.Module):
    """
    Single Spiking Transformer block with Membrane Shortcuts (Eq 9-11).

    Takes both spike tensor S and membrane potential U from previous layer.
    Returns updated spike tensor and membrane potential.
    """
    def __init__(self, d_model, n_heads, ff_dim, beta=0.5, v_th=0.5):
        super().__init__()
        self.sdsa = SpikeDrivenSelfAttention(d_model, n_heads, beta, v_th)
        self.mlp = SpikingMLP(d_model, ff_dim)

        # SN after SDSA + membrane shortcut (Eq 10)
        self.sn_post_sdsa = LIFNeuron(beta=beta, v_th=v_th)
        # SN after MLP + membrane shortcut (Eq 11)
        self.sn_post_mlp = LIFNeuron(beta=beta, v_th=v_th)

    def forward(self, S_prev, U_prev):
        """
        S_prev: (batch, T, D) — spike tensor from previous layer
        U_prev: (batch, T, D) — membrane potential from previous layer
        """
        # Eq 9: U'_l = SDSA(S_{l-1}) + U_{l-1}  (Membrane Shortcut)
        U_prime = self.sdsa(S_prev) + U_prev

        # Eq 10: S'_l = SN(U'_l)
        S_prime = self.sn_post_sdsa(U_prime)

        # Eq 11: S_l = SN(MLP(S'_l) + U'_l)  (Membrane Shortcut on MLP)
        S_l = self.sn_post_mlp(self.mlp(S_prime) + U_prime)

        return S_l, U_prime

# %%
# ============================================================
# SPIKING TRANSFORMER FORECASTER — Complete Model
# ============================================================
# Adapted from the Spike-Driven Transformer for univariate time series.
#
# Architecture:
#   1. Input Projection: scalar → d_model (replaces SPS from the paper)
#   2. Temporal Expansion: repeat across T spiking timesteps
#   3. Initial SN: S_0 = SN(U_0) (Eq 8)
#   4. L × SpikingTransformerBlock with Membrane Shortcuts (Eq 9-11)
#   5. GAP: Global Average Pooling over T timesteps (Eq 12)
#   6. Regression Head: d_model → 1
#
# Hyperparameters matched to LSTM-SNP:
#   d_model = 8 (same as LSTM-SNP hidden units)
#   n_heads = 2, n_layers = 1, ff_dim = 16, T = 4


class SpikingTransformerForecaster(nn.Module):
    def __init__(self, input_dim=1, d_model=8, n_heads=2, n_layers=1,
                 ff_dim=16, T=4, beta=0.5, v_th=0.5):
        super().__init__()
        self.T = T
        self.d_model = d_model

        # Input projection (replaces Patch Splitting Module from paper)
        self.input_proj = nn.Linear(input_dim, d_model)

        # Initial SN (Eq 8: S_0 = SN(U_0))
        self.sn_init = LIFNeuron(beta=beta, v_th=v_th)

        # Spiking Transformer blocks
        self.blocks = nn.ModuleList([
            SpikingTransformerBlock(d_model, n_heads, ff_dim, beta, v_th)
            for _ in range(n_layers)
        ])

        # Regression head (replaces Classification Head from paper)
        self.head = nn.Linear(d_model, 1)


    def reset_states(self, batch_size, device):
        self.u = torch.zeros(1, device=device)
        
    def detach_states(self):
        if hasattr(self, 'u') and self.u is not None:
            self.u = self.u.detach()

    def forward(self, x):
        """
        x: (batch, 1, 1) — single scaled differenced value
        Returns: (batch, 1) — predicted value
        """
        batch = x.shape[0]
        x = x.view(batch, -1)  # (batch, 1)

        # Input projection: (batch, 1) → (batch, d_model)
        u = self.input_proj(x)

        # Temporal expansion: repeat across T spiking timesteps
        # (analogous to repeating images T times in the paper)
        U_0 = u.unsqueeze(1).repeat(1, self.T, 1)  # (batch, T, d_model)

        # Eq 8: S_0 = SN(U_0)
        S = self.sn_init(U_0)
        U = U_0

        # Pass through L spiking transformer blocks (Eq 9-11)
        for block in self.blocks:
            S, U = block(S, U)

        # Eq 12: Y = CH(GAP(S_L))
        # GAP: Global Average Pooling over T timesteps
        gap = S.mean(dim=1)  # (batch, d_model)

        # Regression head
        output = self.head(gap)  # (batch, 1)
        return output


# Print model summary
model_test = SpikingTransformerForecaster()
total_params = sum(p.numel() for p in model_test.parameters())
print(f"SNN-Transformer parameters: {total_params}")
del model_test
# Out:
# SNN-Transformer parameters: 593

# %%
# ============================================================
# Model Wrapper (PyTorch)
# ============================================================
def build_model(input_dim=1, units=8):
    return SpikingTransformerForecaster(
        input_dim=input_dim, 
        d_model=units, 
        n_heads=2, 
        n_layers=1, 
        ff_dim=16, 
        T=4
    )

# Quick architecture check
model = build_model(input_dim=1, units=8)
print(model)
print(f"Total params: {sum(p.numel() for p in model.parameters())}")
# Out:
# SpikingTransformerForecaster(
#   (input_proj): Linear(in_features=1, out_features=8, bias=True)
#   (sn_init): LIFNeuron()
#   (blocks): ModuleList(
#     (0): SpikingTransformerBlock(
#       (sdsa): SpikeDrivenSelfAttention(
#         (W_Q): Linear(in_features=8, out_features=8, bias=True)
#         (W_K): Linear(in_features=8, out_features=8, bias=True)
#         (W_V): Linear(in_features=8, out_features=8, bias=True)
#         (proj): Linear(in_features=8, out_features=8, bias=True)
#         (sn_q): LIFNeuron()
#         (sn_k): LIFNeuron()
#         (sn_v): LIFNeuron()
#         (sn_attn): LIFNeuron()
#       )
#       (mlp): SpikingMLP(
#         (fc1): Linear(in_features=8, out_features=16, bias=True)
#         (fc2): Linear(in_features=16, out_features=8, bias=True)
#       )
#       (sn_post_sdsa): LIFNeuron()
#       (sn_post_mlp): LIFNeuron()
#     )
#   )
#   (head): Linear(in_features=8, out_features=1, bias=True)
# )
# Total params: 593

# %%
# ============================================================
# 1. Load Time Series Data
# ============================================================
series = pd.read_csv(
    r'C:\Users\paulp\OneDrive\Desktop\fuzzy_LSTM\dataset\monthly-lake-erie-levels-1921-19.csv',
    header=0,
    parse_dates=[0],
    index_col=0
)
raw_values = series.values.flatten()
print(f"Data shape: {raw_values.shape}")
print(f"First 5 values: {raw_values[:5]}")
# Out:
# Data shape: (600,)
# First 5 values: [14.763 14.649 15.085 16.376 16.926]

# %%
# ============================================================
# 2. First-Order Differencing
# ============================================================

def difference(dataset, interval=1):
    diff = []
    for i in range(interval, len(dataset)):
        value = dataset[i] - dataset[i - interval]
        diff.append(value)
    return np.array(diff)

diff_values = difference(raw_values, 1)

# %%
# ============================================================
# 3. Convert to Supervised Learning Format (lag=1)
# ============================================================

def timeseries_to_supervised(data, lag=1):
    df = pd.DataFrame(data)
    columns = [df.shift(i) for i in range(1, lag+1)]
    columns.append(df)
    df = pd.concat(columns, axis=1)
    df.fillna(0, inplace=True)
    return df.values

supervised = timeseries_to_supervised(diff_values, 1)
print(f"Supervised data shape: {supervised.shape}")
# Out:
# Supervised data shape: (599, 2)

# %%
# ============================================================
# 4. Train-Validation-Test Split (Last 60 points as Test)
# ============================================================
n = len(supervised)
test_size = 60
train_val = supervised[:n - test_size]
test = supervised[n - test_size:]

val_size = int(len(train_val) * 0.1)
train = train_val[:-val_size]
val = train_val[-val_size:]

print(f"Train: {train.shape}, Val: {val.shape}, Test: {test.shape}")

# ============================================================
# 5. Feature Scaling
# ============================================================
scaler = MinMaxScaler(feature_range=(-1, 1))
scaler.fit(train)  # fit only on train to avoid leakage
train_scaled = scaler.transform(train)
val_scaled = scaler.transform(val)
test_scaled = scaler.transform(test)
# Out:
# Train: (486, 2), Val: (53, 2), Test: (60, 2)

# %%
# ============================================================
# 6. Reshape for RNN Input
# ============================================================

X_train, y_train = train_scaled[:, 0:-1], train_scaled[:, -1]
X_train = X_train.reshape((X_train.shape[0], 1, X_train.shape[1]))

X_test, y_test = test_scaled[:, 0:-1], test_scaled[:, -1]
print(f"X_train shape: {X_train.shape}, y_train shape: {y_train.shape}")
# Out:
# X_train shape: (486, 1, 1), y_train shape: (486,)

# %%
# ============================================================
# 60-Run Experiment Protocol (PyTorch)
# ============================================================
all_rmse = []
all_mse = []
all_nmse = []
all_predictions = []
all_losses = []
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"\n--- [PyTorch] RUNNING ON {device} ---\n")
for run in range(60):
    print(f'\n===== RUN {run+1}/60 =====')
    np.random.seed(run)
    torch.manual_seed(run)
    model = build_model(input_dim=1, units=8).to(device)
    
    # Initialize consumption gate bias to 1.0 (forget gate equivalent)
    if hasattr(model, 'cell') and hasattr(model.cell, 'U') and True:
        with torch.no_grad():
            model.cell.U.bias.data[model.hidden_size:2*model.hidden_size] = 1.0
    optimizer = torch.optim.Adam(model.parameters(), lr=0.001)
    criterion = nn.MSELoss()
    run_losses = []
    
    # Pre-tensorize training data
    if False:
        X_train_t = torch.tensor(X_train, dtype=torch.float32).to(device)
    else:
        # X_train is (batch, 1, input_dim)
        X_train_t = torch.tensor(X_train, dtype=torch.float32).to(device)
        
    y_train_t = torch.tensor(y_train, dtype=torch.float32).to(device)
    n_samples = X_train_t.size(0)
    for epoch in range(100):
        model.train()
        model.reset_states(1, device) # batch_size=1
        
        epoch_loss = 0.0
        
        for i in range(n_samples):
            x_i = X_train_t[i:i+1] # (1, 1, input_dim)
            y_i = y_train_t[i:i+1] # (1,)
            
            optimizer.zero_grad()
            
            # Forward pass
            pred = model(x_i)
            loss = criterion(pred.squeeze(-1), y_i)
            
            # Backward and optimize
            loss.backward()
            
            # Gradient clipping for FuzzyGate variants
            if 4 in [3, 5]:
                torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)
                
            optimizer.step()
            
            # Detach hidden state so BPTT doesn't go all the way back to t=0
            model.detach_states()
            
            epoch_loss += loss.item()
            
        avg_loss = epoch_loss / n_samples
        run_losses.append(avg_loss)
        print(f"Epoch {epoch+1}/100 completed. Loss: {avg_loss:.6f}")
    all_losses.append(run_losses)
    print(f'Training complete for run {run+1}')
    # Warm-up: condition hidden states on training data
    model.eval()
    with torch.no_grad():
        for i in range(len(train_scaled)):
            X_raw = train_scaled[i, 0:-1]
            X_input = torch.tensor(X_raw, dtype=torch.float32).view(1, 1, len(X_raw)).to(device)
            model(X_input)
    # Test predictions (single-step)
    predictions = []
    model.eval()
    with torch.no_grad():
        for i in range(len(test_scaled)):
            X, y = test_scaled[i, 0:-1], test_scaled[i, -1]
            X_input = torch.tensor(X, dtype=torch.float32).view(1, 1, len(X)).to(device)
            yhat = model(X_input).item()
            # Invert scaling
            new_row = [x for x in X] + [yhat]
            array = np.array(new_row).reshape(1, len(new_row))
            inverted = scaler.inverse_transform(array)[0, -1]
            # Invert differencing
            inverted = inverted + raw_values[len(train) + i]
            predictions.append(inverted)
            expected = raw_values[len(train) + i + 1]
            print(f'Month={i+1}, Predicted={inverted:.4f}, Expected={expected:.4f}')
    # Compute metrics
    actual = raw_values[-len(predictions):]
    rmse = sqrt(mean_squared_error(actual, predictions))
    mse = mean_squared_error(actual, predictions)
    meanV = np.mean(actual)
    dominator = np.linalg.norm(np.array(predictions) - meanV, 2)
    nmse = mse / np.power(dominator, 2)
    all_rmse.append(rmse)
    all_mse.append(mse)
    all_nmse.append(nmse)
    all_predictions.append(predictions)
    print(f'Run {run+1} — RMSE: {rmse:.6f}, MSE: {mse:.6f}, NMSE: {nmse:.10f}')
# Out:
# --- [PyTorch] RUNNING ON cuda ---
#
#
# ===== RUN 1/60 =====
# Epoch 1/100 completed. Loss: 0.096033
# Epoch 2/100 completed. Loss: 0.079586
# Epoch 3/100 completed. Loss: 0.072234
# Epoch 4/100 completed. Loss: 0.066308
# Epoch 5/100 completed. Loss: 0.067039
# Epoch 6/100 completed. Loss: 0.067039
# Epoch 7/100 completed. Loss: 0.067392
# Epoch 8/100 completed. Loss: 0.067575
# Epoch 9/100 completed. Loss: 0.066684
# Epoch 10/100 completed. Loss: 0.066630
# Epoch 11/100 completed. Loss: 0.066474
# Epoch 12/100 completed. Loss: 0.066262
# Epoch 13/100 completed. Loss: 0.065916
# Epoch 14/100 completed. Loss: 0.065963
# Epoch 15/100 completed. Loss: 0.065574
# Epoch 16/100 completed. Loss: 0.065725
# Epoch 17/100 completed. Loss: 0.065757
# Epoch 18/100 completed. Loss: 0.065621
# Epoch 19/100 completed. Loss: 0.065614
# Epoch 20/100 completed. Loss: 0.065600
# Epoch 21/100 completed. Loss: 0.065711
# Epoch 22/100 completed. Loss: 0.065561
# Epoch 23/100 completed. Loss: 0.065739
# Epoch 24/100 completed. Loss: 0.066168
# Epoch 25/100 completed. Loss: 0.066239
# Epoch 26/100 completed. Loss: 0.066423
# Epoch 27/100 completed. Loss: 0.066424
# Epoch 28/100 completed. Loss: 0.065911
# Epoch 29/100 completed. Loss: 0.066156
# Epoch 30/100 completed. Loss: 0.066117
# Epoch 31/100 completed. Loss: 0.066169
# Epoch 32/100 completed. Loss: 0.066270
# Epoch 33/100 completed. Loss: 0.066581
# Epoch 34/100 completed. Loss: 0.066305
# Epoch 35/100 completed. Loss: 0.065950
# Epoch 36/100 completed. Loss: 0.065970
# Epoch 37/100 completed. Loss: 0.065999
# Epoch 38/100 completed. Loss: 0.066472
# Epoch 39/100 completed. Loss: 0.065738
# Epoch 40/100 completed. Loss: 0.066022
# Epoch 41/100 completed. Loss: 0.065918
# Epoch 42/100 completed. Loss: 0.066396
# Epoch 43/100 completed. Loss: 0.066234
# Epoch 44/100 completed. Loss: 0.066214
# Epoch 45/100 completed. Loss: 0.066177
# Epoch 46/100 completed. Loss: 0.066158
# Epoch 47/100 completed. Loss: 0.066513
# Epoch 48/100 completed. Loss: 0.066587
# Epoch 49/100 completed. Loss: 0.066508
# Epoch 50/100 completed. Loss: 0.066635
# Epoch 51/100 completed. Loss: 0.066482
# Epoch 52/100 completed. Loss: 0.066720
# Epoch 53/100 completed. Loss: 0.066511
# Epoch 54/100 completed. Loss: 0.066133
# Epoch 55/100 completed. Loss: 0.066229
# Epoch 56/100 completed. Loss: 0.066352
# Epoch 57/100 completed. Loss: 0.066446
# Epoch 58/100 completed. Loss: 0.066256
# Epoch 59/100 completed. Loss: 0.066410
# Epoch 60/100 completed. Loss: 0.066596
# Epoch 61/100 completed. Loss: 0.066440
# Epoch 62/100 completed. Loss: 0.066524
# Epoch 63/100 completed. Loss: 0.066435
# Epoch 64/100 completed. Loss: 0.066385
# Epoch 65/100 completed. Loss: 0.066507
# Epoch 66/100 completed. Loss: 0.066254
# Epoch 67/100 completed. Loss: 0.066073
# Epoch 68/100 completed. Loss: 0.066611
# Epoch 69/100 completed. Loss: 0.066238
# Epoch 70/100 completed. Loss: 0.066509
# Epoch 71/100 completed. Loss: 0.066736
# Epoch 72/100 completed. Loss: 0.066265
# Epoch 73/100 completed. Loss: 0.066454
# Epoch 74/100 completed. Loss: 0.066460
# Epoch 75/100 completed. Loss: 0.066424
# Epoch 76/100 completed. Loss: 0.066465
# Epoch 77/100 completed. Loss: 0.066201
# Epoch 78/100 completed. Loss: 0.066022
# Epoch 79/100 completed. Loss: 0.065767
# Epoch 80/100 completed. Loss: 0.065760
# Epoch 81/100 completed. Loss: 0.066363
# Epoch 82/100 completed. Loss: 0.066194
# Epoch 83/100 completed. Loss: 0.065959
# Epoch 84/100 completed. Loss: 0.065598
# Epoch 85/100 completed. Loss: 0.065829
# Epoch 86/100 completed. Loss: 0.065923
# Epoch 87/100 completed. Loss: 0.066128
# Epoch 88/100 completed. Loss: 0.065926
# Epoch 89/100 completed. Loss: 0.066433
# Epoch 90/100 completed. Loss: 0.065909
# Epoch 91/100 completed. Loss: 0.065986
# Epoch 92/100 completed. Loss: 0.066001
# Epoch 93/100 completed. Loss: 0.066024
# Epoch 94/100 completed. Loss: 0.065691
# Epoch 95/100 completed. Loss: 0.065791
# Epoch 96/100 completed. Loss: 0.066095
# Epoch 97/100 completed. Loss: 0.066085
# Epoch 98/100 completed. Loss: 0.065881
# Epoch 99/100 completed. Loss: 0.065829
# Epoch 100/100 completed. Loss: 0.065944
# Training complete for run 1
# Month=1, Predicted=17.2679, Expected=17.0780
# Month=2, Predicted=17.3628, Expected=16.5090
# Month=3, Predicted=16.6137, Expected=15.4650
# Month=4, Predicted=15.7498, Expected=14.7060
# Month=5, Predicted=14.9908, Expected=14.2130
# Month=6, Predicted=14.4978, Expected=13.6620
# Month=7, Predicted=13.6809, Expected=13.9280
# Month=8, Predicted=13.8611, Expected=14.5160
# Month=9, Predicted=14.0975, Expected=15.1800
# Month=10, Predicted=14.7615, Expected=15.3510
# Month=11, Predicted=14.9325, Expected=15.5790
# Month=12, Predicted=15.6837, Expected=15.4460
# Month=13, Predicted=16.0395, Expected=15.1990
# Month=14, Predicted=15.1321, Expected=14.7250
# Month=15, Predicted=14.8297, Expected=14.3830
# Month=16, Predicted=14.5777, Expected=14.2310
# Month=17, Predicted=14.8245, Expected=13.7760
# Month=18, Predicted=14.2151, Expected=13.1500
# Month=19, Predicted=13.0831, Expected=12.7130
# Month=20, Predicted=12.8177, Expected=13.2830
# Month=21, Predicted=13.2161, Expected=14.4780
# Month=22, Predicted=14.0595, Expected=14.8580
# Month=23, Predicted=14.4395, Expected=14.7820
# Month=24, Predicted=14.7151, Expected=14.3070
# Month=25, Predicted=14.5918, Expected=14.0230
# Month=26, Predicted=14.2177, Expected=13.5290
# Month=27, Predicted=13.8138, Expected=12.9220
# Month=28, Predicted=12.8551, Expected=12.4100
# Month=29, Predicted=12.6948, Expected=11.9360
# Month=30, Predicted=12.0407, Expected=11.7840
# Month=31, Predicted=12.0688, Expected=11.9920
# Month=32, Predicted=12.0967, Expected=12.6190
# Month=33, Predicted=12.5521, Expected=13.6620
# Month=34, Predicted=13.2435, Expected=14.2310
# Month=35, Predicted=13.8125, Expected=14.0990
# Month=36, Predicted=13.6805, Expected=13.8330
# Month=37, Predicted=14.0277, Expected=13.4160
# Month=38, Predicted=13.5207, Expected=12.9220
# Month=39, Predicted=13.5155, Expected=11.9740
# Month=40, Predicted=11.9071, Expected=11.4610
# Month=41, Predicted=12.0545, Expected=11.4230
# Month=42, Predicted=12.0165, Expected=11.8600
# Month=43, Predicted=12.1448, Expected=12.1630
# Month=44, Predicted=12.4478, Expected=13.2260
# Month=45, Predicted=12.8075, Expected=13.9660
# Month=46, Predicted=13.5475, Expected=14.5350
# Month=47, Predicted=14.1165, Expected=14.5160
# Month=48, Predicted=14.0975, Expected=14.2310
# Month=49, Predicted=14.3357, Expected=13.9660
# Month=50, Predicted=13.5475, Expected=13.7380
# Month=51, Predicted=13.6711, Expected=13.2260
# Month=52, Predicted=13.4207, Expected=12.9980
# Month=53, Predicted=13.5915, Expected=13.1310
# Month=54, Predicted=13.4158, Expected=13.7000
# Month=55, Predicted=13.8947, Expected=13.8140
# Month=56, Predicted=13.7471, Expected=14.3830
# Month=57, Predicted=14.3161, Expected=15.0470
# Month=58, Predicted=14.6285, Expected=15.6930
# Month=59, Predicted=15.2745, Expected=15.8440
# Month=60, Predicted=15.7771, Expected=15.7120
# Run 1 — RMSE: 3.336938, MSE: 11.135157, NMSE: 0.0275344745
#
# ===== RUN 2/60 =====
# Epoch 1/100 completed. Loss: 0.117978
# Epoch 2/100 completed. Loss: 0.071163
# Epoch 3/100 completed. Loss: 0.070393
# Epoch 4/100 completed. Loss: 0.070163
# Epoch 5/100 completed. Loss: 0.069053
# Epoch 6/100 completed. Loss: 0.068886
# Epoch 7/100 completed. Loss: 0.068637
# Epoch 8/100 completed. Loss: 0.069988
# Epoch 9/100 completed. Loss: 0.068530
# Epoch 10/100 completed. Loss: 0.066601
# Epoch 11/100 completed. Loss: 0.066935
# Epoch 12/100 completed. Loss: 0.065813
# Epoch 13/100 completed. Loss: 0.066805
# Epoch 14/100 completed. Loss: 0.067352
# Epoch 15/100 completed. Loss: 0.067795
# Epoch 16/100 completed. Loss: 0.067143
# Epoch 17/100 completed. Loss: 0.067202
# Epoch 18/100 completed. Loss: 0.067256
# Epoch 19/100 completed. Loss: 0.067505
# Epoch 20/100 completed. Loss: 0.067829
# Epoch 21/100 completed. Loss: 0.069153
# Epoch 22/100 completed. Loss: 0.068482
# Epoch 23/100 completed. Loss: 0.068492
# Epoch 24/100 completed. Loss: 0.068568
# Epoch 25/100 completed. Loss: 0.069863
# Epoch 26/100 completed. Loss: 0.068004
# Epoch 27/100 completed. Loss: 0.069342
# Epoch 28/100 completed. Loss: 0.069166
# Epoch 29/100 completed. Loss: 0.069545
# Epoch 30/100 completed. Loss: 0.069038
# Epoch 31/100 completed. Loss: 0.068908
# Epoch 32/100 completed. Loss: 0.068543
# Epoch 33/100 completed. Loss: 0.067818
# Epoch 34/100 completed. Loss: 0.068203
# Epoch 35/100 completed. Loss: 0.067267
# Epoch 36/100 completed. Loss: 0.066886
# Epoch 37/100 completed. Loss: 0.066493
# Epoch 38/100 completed. Loss: 0.067051
# Epoch 39/100 completed. Loss: 0.067244
# Epoch 40/100 completed. Loss: 0.067178
# Epoch 41/100 completed. Loss: 0.066979
# Epoch 42/100 completed. Loss: 0.067400
# Epoch 43/100 completed. Loss: 0.066801
# Epoch 44/100 completed. Loss: 0.067306
# Epoch 45/100 completed. Loss: 0.066941
# Epoch 46/100 completed. Loss: 0.066512
# Epoch 47/100 completed. Loss: 0.066536
# Epoch 48/100 completed. Loss: 0.066985
# Epoch 49/100 completed. Loss: 0.068159
# Epoch 50/100 completed. Loss: 0.068578
# Epoch 51/100 completed. Loss: 0.066948
# Epoch 52/100 completed. Loss: 0.067495
# Epoch 53/100 completed. Loss: 0.067812
# Epoch 54/100 completed. Loss: 0.067241
# Epoch 55/100 completed. Loss: 0.067898
# Epoch 56/100 completed. Loss: 0.067840
# Epoch 57/100 completed. Loss: 0.067990
# Epoch 58/100 completed. Loss: 0.068522
# Epoch 59/100 completed. Loss: 0.066121
# Epoch 60/100 completed. Loss: 0.067192
# Epoch 61/100 completed. Loss: 0.066635
# Epoch 62/100 completed. Loss: 0.066669
# Epoch 63/100 completed. Loss: 0.067502
# Epoch 64/100 completed. Loss: 0.067899
# Epoch 65/100 completed. Loss: 0.068605
# Epoch 66/100 completed. Loss: 0.066739
# Epoch 67/100 completed. Loss: 0.067687
# Epoch 68/100 completed. Loss: 0.066045
# Epoch 69/100 completed. Loss: 0.069817
# Epoch 70/100 completed. Loss: 0.066570
# Epoch 71/100 completed. Loss: 0.067063
# Epoch 72/100 completed. Loss: 0.066968
# Epoch 73/100 completed. Loss: 0.067013
# Epoch 74/100 completed. Loss: 0.067202
# Epoch 75/100 completed. Loss: 0.067191
# Epoch 76/100 completed. Loss: 0.067033
# Epoch 77/100 completed. Loss: 0.067206
# Epoch 78/100 completed. Loss: 0.066930
# Epoch 79/100 completed. Loss: 0.066870
# Epoch 80/100 completed. Loss: 0.066920
# Epoch 81/100 completed. Loss: 0.067219
# Epoch 82/100 completed. Loss: 0.068785
# Epoch 83/100 completed. Loss: 0.065842
# Epoch 84/100 completed. Loss: 0.066231
# Epoch 85/100 completed. Loss: 0.065804
# Epoch 86/100 completed. Loss: 0.066075
# Epoch 87/100 completed. Loss: 0.065643
# Epoch 88/100 completed. Loss: 0.066007
# Epoch 89/100 completed. Loss: 0.066144
# Epoch 90/100 completed. Loss: 0.066226
# Epoch 91/100 completed. Loss: 0.066096
# Epoch 92/100 completed. Loss: 0.066119
# Epoch 93/100 completed. Loss: 0.066433
# Epoch 94/100 completed. Loss: 0.066442
# Epoch 95/100 completed. Loss: 0.066523
# Epoch 96/100 completed. Loss: 0.066760
# Epoch 97/100 completed. Loss: 0.066527
# Epoch 98/100 completed. Loss: 0.066566
# Epoch 99/100 completed. Loss: 0.066301
# Epoch 100/100 completed. Loss: 0.068809
# Training complete for run 2
# Month=1, Predicted=17.3747, Expected=17.0780
# Month=2, Predicted=17.3767, Expected=16.5090
# Month=3, Predicted=16.5459, Expected=15.4650
# Month=4, Predicted=15.7637, Expected=14.7060
# Month=5, Predicted=15.0047, Expected=14.2130
# Month=6, Predicted=14.5117, Expected=13.6620
# Month=7, Predicted=13.7877, Expected=13.9280
# Month=8, Predicted=13.8722, Expected=14.5160
# Month=9, Predicted=14.2883, Expected=15.1800
# Month=10, Predicted=14.7746, Expected=15.3510
# Month=11, Predicted=14.9456, Expected=15.5790
# Month=12, Predicted=15.7047, Expected=15.4460
# Month=13, Predicted=16.0102, Expected=15.1990
# Month=14, Predicted=15.1432, Expected=14.7250
# Month=15, Predicted=14.7619, Expected=14.3830
# Month=16, Predicted=14.5087, Expected=14.2310
# Month=17, Predicted=14.7952, Expected=13.7760
# Month=18, Predicted=14.2476, Expected=13.1500
# Month=19, Predicted=13.2757, Expected=12.7130
# Month=20, Predicted=12.8387, Expected=13.2830
# Month=21, Predicted=13.1394, Expected=14.4780
# Month=22, Predicted=14.0726, Expected=14.8580
# Month=23, Predicted=14.4526, Expected=14.7820
# Month=24, Predicted=14.7262, Expected=14.3070
# Month=25, Predicted=14.5216, Expected=14.0230
# Month=26, Predicted=14.1487, Expected=13.5290
# Month=27, Predicted=13.8277, Expected=12.9220
# Month=28, Predicted=12.9589, Expected=12.4100
# Month=29, Predicted=12.7087, Expected=11.9360
# Month=30, Predicted=11.9729, Expected=11.7840
# Month=31, Predicted=11.9986, Expected=11.9920
# Month=32, Predicted=12.0289, Expected=12.6190
# Month=33, Predicted=12.4754, Expected=13.6620
# Month=34, Predicted=13.2566, Expected=14.2310
# Month=35, Predicted=13.8256, Expected=14.0990
# Month=36, Predicted=13.8713, Expected=13.8330
# Month=37, Predicted=13.9587, Expected=13.4160
# Month=38, Predicted=13.5417, Expected=12.9220
# Month=39, Predicted=13.4862, Expected=11.9740
# Month=40, Predicted=11.8304, Expected=11.4610
# Month=41, Predicted=12.1179, Expected=11.4230
# Month=42, Predicted=11.9872, Expected=11.8600
# Month=43, Predicted=12.1587, Expected=12.1630
# Month=44, Predicted=12.4617, Expected=13.2260
# Month=45, Predicted=12.9983, Expected=13.9660
# Month=46, Predicted=13.5606, Expected=14.5350
# Month=47, Predicted=14.1296, Expected=14.5160
# Month=48, Predicted=14.1106, Expected=14.2310
# Month=49, Predicted=14.3567, Expected=13.9660
# Month=50, Predicted=13.5606, Expected=13.7380
# Month=51, Predicted=13.7749, Expected=13.2260
# Month=52, Predicted=13.3517, Expected=12.9980
# Month=53, Predicted=13.5622, Expected=13.1310
# Month=54, Predicted=13.4297, Expected=13.7000
# Month=55, Predicted=13.8257, Expected=13.8140
# Month=56, Predicted=13.9397, Expected=14.3830
# Month=57, Predicted=14.2394, Expected=15.0470
# Month=58, Predicted=14.6416, Expected=15.6930
# Month=59, Predicted=15.4653, Expected=15.8440
# Month=60, Predicted=15.6956, Expected=15.7120
# Run 2 — RMSE: 3.331087, MSE: 11.096141, NMSE: 0.0276312225
#
# ===== RUN 3/60 =====
# Epoch 1/100 completed. Loss: 0.090318
# Epoch 2/100 completed. Loss: 0.070259
# Epoch 3/100 completed. Loss: 0.069867
# Epoch 4/100 completed. Loss: 0.069893
# Epoch 5/100 completed. Loss: 0.068804
# Epoch 6/100 completed. Loss: 0.068901
# Epoch 7/100 completed. Loss: 0.068547
# Epoch 8/100 completed. Loss: 0.068555
# Epoch 9/100 completed. Loss: 0.069076
# Epoch 10/100 completed. Loss: 0.068216
# Epoch 11/100 completed. Loss: 0.068149
# Epoch 12/100 completed. Loss: 0.068276
# Epoch 13/100 completed. Loss: 0.067363
# Epoch 14/100 completed. Loss: 0.067278
# Epoch 15/100 completed. Loss: 0.068213
# Epoch 16/100 completed. Loss: 0.068034
# Epoch 17/100 completed. Loss: 0.068188
# Epoch 18/100 completed. Loss: 0.068327
# Epoch 19/100 completed. Loss: 0.068268
# Epoch 20/100 completed. Loss: 0.068388
# Epoch 21/100 completed. Loss: 0.068146
# Epoch 22/100 completed. Loss: 0.067885
# Epoch 23/100 completed. Loss: 0.067803
# Epoch 24/100 completed. Loss: 0.067145
# Epoch 25/100 completed. Loss: 0.067486
# Epoch 26/100 completed. Loss: 0.067360
# Epoch 27/100 completed. Loss: 0.067385
# Epoch 28/100 completed. Loss: 0.067373
# Epoch 29/100 completed. Loss: 0.067168
# Epoch 30/100 completed. Loss: 0.067287
# Epoch 31/100 completed. Loss: 0.067027
# Epoch 32/100 completed. Loss: 0.067200
# Epoch 33/100 completed. Loss: 0.067559
# Epoch 34/100 completed. Loss: 0.068141
# Epoch 35/100 completed. Loss: 0.067983
# Epoch 36/100 completed. Loss: 0.068169
# Epoch 37/100 completed. Loss: 0.068152
# Epoch 38/100 completed. Loss: 0.068363
# Epoch 39/100 completed. Loss: 0.068287
# Epoch 40/100 completed. Loss: 0.067581
# Epoch 41/100 completed. Loss: 0.067360
# Epoch 42/100 completed. Loss: 0.067850
# Epoch 43/100 completed. Loss: 0.067129
# Epoch 44/100 completed. Loss: 0.067904
# Epoch 45/100 completed. Loss: 0.067946
# Epoch 46/100 completed. Loss: 0.068029
# Epoch 47/100 completed. Loss: 0.068668
# Epoch 48/100 completed. Loss: 0.068252
# Epoch 49/100 completed. Loss: 0.068447
# Epoch 50/100 completed. Loss: 0.068076
# Epoch 51/100 completed. Loss: 0.068672
# Epoch 52/100 completed. Loss: 0.068148
# Epoch 53/100 completed. Loss: 0.067984
# Epoch 54/100 completed. Loss: 0.067826
# Epoch 55/100 completed. Loss: 0.067159
# Epoch 56/100 completed. Loss: 0.066805
# Epoch 57/100 completed. Loss: 0.066776
# Epoch 58/100 completed. Loss: 0.066985
# Epoch 59/100 completed. Loss: 0.066974
# Epoch 60/100 completed. Loss: 0.067144
# Epoch 61/100 completed. Loss: 0.066769
# Epoch 62/100 completed. Loss: 0.067395
# Epoch 63/100 completed. Loss: 0.067469
# Epoch 64/100 completed. Loss: 0.067321
# Epoch 65/100 completed. Loss: 0.067135
# Epoch 66/100 completed. Loss: 0.067044
# Epoch 67/100 completed. Loss: 0.066956
# Epoch 68/100 completed. Loss: 0.066962
# Epoch 69/100 completed. Loss: 0.066639
# Epoch 70/100 completed. Loss: 0.066661
# Epoch 71/100 completed. Loss: 0.066834
# Epoch 72/100 completed. Loss: 0.066980
# Epoch 73/100 completed. Loss: 0.067818
# Epoch 74/100 completed. Loss: 0.067485
# Epoch 75/100 completed. Loss: 0.067311
# Epoch 76/100 completed. Loss: 0.067465
# Epoch 77/100 completed. Loss: 0.067688
# Epoch 78/100 completed. Loss: 0.067225
# Epoch 79/100 completed. Loss: 0.067386
# Epoch 80/100 completed. Loss: 0.067089
# Epoch 81/100 completed. Loss: 0.066825
# Epoch 82/100 completed. Loss: 0.066874
# Epoch 83/100 completed. Loss: 0.067000
# Epoch 84/100 completed. Loss: 0.067056
# Epoch 85/100 completed. Loss: 0.066750
# Epoch 86/100 completed. Loss: 0.066679
# Epoch 87/100 completed. Loss: 0.066783
# Epoch 88/100 completed. Loss: 0.066707
# Epoch 89/100 completed. Loss: 0.066751
# Epoch 90/100 completed. Loss: 0.066783
# Epoch 91/100 completed. Loss: 0.066811
# Epoch 92/100 completed. Loss: 0.066739
# Epoch 93/100 completed. Loss: 0.066772
# Epoch 94/100 completed. Loss: 0.066767
# Epoch 95/100 completed. Loss: 0.066864
# Epoch 96/100 completed. Loss: 0.066537
# Epoch 97/100 completed. Loss: 0.066341
# Epoch 98/100 completed. Loss: 0.066216
# Epoch 99/100 completed. Loss: 0.065851
# Epoch 100/100 completed. Loss: 0.066607
# Training complete for run 3
# Month=1, Predicted=17.3473, Expected=17.0780
# Month=2, Predicted=17.4359, Expected=16.5090
# Month=3, Predicted=16.6073, Expected=15.4650
# Month=4, Predicted=15.8229, Expected=14.7060
# Month=5, Predicted=15.0639, Expected=14.2130
# Month=6, Predicted=14.5709, Expected=13.6620
# Month=7, Predicted=13.8544, Expected=13.9280
# Month=8, Predicted=13.7631, Expected=14.5160
# Month=9, Predicted=14.1820, Expected=15.1800
# Month=10, Predicted=14.7576, Expected=15.3510
# Month=11, Predicted=14.7559, Expected=15.5790
# Month=12, Predicted=15.6773, Expected=15.4460
# Month=13, Predicted=16.1268, Expected=15.1990
# Month=14, Predicted=15.0341, Expected=14.7250
# Month=15, Predicted=14.8233, Expected=14.3830
# Month=16, Predicted=14.5754, Expected=14.2310
# Month=17, Predicted=14.8638, Expected=13.7760
# Month=18, Predicted=14.2335, Expected=13.1500
# Month=19, Predicted=13.2483, Expected=12.7130
# Month=20, Predicted=12.9054, Expected=13.2830
# Month=21, Predicted=13.1181, Expected=14.4780
# Month=22, Predicted=14.0556, Expected=14.8580
# Month=23, Predicted=14.4356, Expected=14.7820
# Month=24, Predicted=14.6171, Expected=14.3070
# Month=25, Predicted=14.4994, Expected=14.0230
# Month=26, Predicted=14.2154, Expected=13.5290
# Month=27, Predicted=13.8869, Expected=12.9220
# Month=28, Predicted=12.8512, Expected=12.4100
# Month=29, Predicted=12.7679, Expected=11.9360
# Month=30, Predicted=12.0343, Expected=11.7840
# Month=31, Predicted=11.9764, Expected=11.9920
# Month=32, Predicted=12.0903, Expected=12.6190
# Month=33, Predicted=12.4541, Expected=13.6620
# Month=34, Predicted=13.2396, Expected=14.2310
# Month=35, Predicted=13.8086, Expected=14.0990
# Month=36, Predicted=13.7650, Expected=13.8330
# Month=37, Predicted=14.0254, Expected=13.4160
# Month=38, Predicted=13.5143, Expected=12.9220
# Month=39, Predicted=13.5548, Expected=11.9740
# Month=40, Predicted=11.8091, Expected=11.4610
# Month=41, Predicted=12.3651, Expected=11.4230
# Month=42, Predicted=12.1038, Expected=11.8600
# Month=43, Predicted=12.1351, Expected=12.1630
# Month=44, Predicted=12.4381, Expected=13.2260
# Month=45, Predicted=12.9784, Expected=13.9660
# Month=46, Predicted=13.5436, Expected=14.5350
# Month=47, Predicted=14.1126, Expected=14.5160
# Month=48, Predicted=14.0936, Expected=14.2310
# Month=49, Predicted=14.4234, Expected=13.9660
# Month=50, Predicted=13.5436, Expected=13.7380
# Month=51, Predicted=13.6672, Expected=13.2260
# Month=52, Predicted=13.4184, Expected=12.9980
# Month=53, Predicted=13.6308, Expected=13.1310
# Month=54, Predicted=13.4889, Expected=13.7000
# Month=55, Predicted=13.8924, Expected=13.8140
# Month=56, Predicted=13.9123, Expected=14.3830
# Month=57, Predicted=14.2181, Expected=15.0470
# Month=58, Predicted=14.6246, Expected=15.6930
# Month=59, Predicted=15.3590, Expected=15.8440
# Month=60, Predicted=15.6791, Expected=15.7120
# Run 3 — RMSE: 3.317318, MSE: 11.004598, NMSE: 0.0275620273
#
# ===== RUN 4/60 =====
# Epoch 1/100 completed. Loss: 0.135421
# Epoch 2/100 completed. Loss: 0.069576
# Epoch 3/100 completed. Loss: 0.069141
# Epoch 4/100 completed. Loss: 0.069425
# Epoch 5/100 completed. Loss: 0.069127
# Epoch 6/100 completed. Loss: 0.069155
# Epoch 7/100 completed. Loss: 0.069617
# Epoch 8/100 completed. Loss: 0.069544
# Epoch 9/100 completed. Loss: 0.069362
# Epoch 10/100 completed. Loss: 0.070017
# Epoch 11/100 completed. Loss: 0.070071
# Epoch 12/100 completed. Loss: 0.071693
# Epoch 13/100 completed. Loss: 0.071595
# Epoch 14/100 completed. Loss: 0.071184
# Epoch 15/100 completed. Loss: 0.069762
# Epoch 16/100 completed. Loss: 0.068511
# Epoch 17/100 completed. Loss: 0.068350
# Epoch 18/100 completed. Loss: 0.068633
# Epoch 19/100 completed. Loss: 0.067425
# Epoch 20/100 completed. Loss: 0.067508
# Epoch 21/100 completed. Loss: 0.066983
# Epoch 22/100 completed. Loss: 0.067176
# Epoch 23/100 completed. Loss: 0.066995
# Epoch 24/100 completed. Loss: 0.067261
# Epoch 25/100 completed. Loss: 0.067061
# Epoch 26/100 completed. Loss: 0.067089
# Epoch 27/100 completed. Loss: 0.067622
# Epoch 28/100 completed. Loss: 0.067414
# Epoch 29/100 completed. Loss: 0.067321
# Epoch 30/100 completed. Loss: 0.067189
# Epoch 31/100 completed. Loss: 0.066873
# Epoch 32/100 completed. Loss: 0.067017
# Epoch 33/100 completed. Loss: 0.067664
# Epoch 34/100 completed. Loss: 0.067949
# Epoch 35/100 completed. Loss: 0.067416
# Epoch 36/100 completed. Loss: 0.067695
# Epoch 37/100 completed. Loss: 0.068156
# Epoch 38/100 completed. Loss: 0.067281
# Epoch 39/100 completed. Loss: 0.067298
# Epoch 40/100 completed. Loss: 0.067862
# Epoch 41/100 completed. Loss: 0.067135
# Epoch 42/100 completed. Loss: 0.067480
# Epoch 43/100 completed. Loss: 0.067083
# Epoch 44/100 completed. Loss: 0.066585
# Epoch 45/100 completed. Loss: 0.066177
# Epoch 46/100 completed. Loss: 0.066466
# Epoch 47/100 completed. Loss: 0.066443
# Epoch 48/100 completed. Loss: 0.066558
# Epoch 49/100 completed. Loss: 0.066169
# Epoch 50/100 completed. Loss: 0.066512
# Epoch 51/100 completed. Loss: 0.066279
# Epoch 52/100 completed. Loss: 0.066133
# Epoch 53/100 completed. Loss: 0.066429
# Epoch 54/100 completed. Loss: 0.065844
# Epoch 55/100 completed. Loss: 0.065841
# Epoch 56/100 completed. Loss: 0.065954
# Epoch 57/100 completed. Loss: 0.065887
# Epoch 58/100 completed. Loss: 0.065961
# Epoch 59/100 completed. Loss: 0.065699
# Epoch 60/100 completed. Loss: 0.065755
# Epoch 61/100 completed. Loss: 0.065893
# Epoch 62/100 completed. Loss: 0.066608
# Epoch 63/100 completed. Loss: 0.066593
# Epoch 64/100 completed. Loss: 0.066676
# Epoch 65/100 completed. Loss: 0.066725
# Epoch 66/100 completed. Loss: 0.067087
# Epoch 67/100 completed. Loss: 0.066843
# Epoch 68/100 completed. Loss: 0.066680
# Epoch 69/100 completed. Loss: 0.066365
# Epoch 70/100 completed. Loss: 0.066185
# Epoch 71/100 completed. Loss: 0.066106
# Epoch 72/100 completed. Loss: 0.066114
# Epoch 73/100 completed. Loss: 0.066139
# Epoch 74/100 completed. Loss: 0.066319
# Epoch 75/100 completed. Loss: 0.066160
# Epoch 76/100 completed. Loss: 0.065745
# Epoch 77/100 completed. Loss: 0.065935
# Epoch 78/100 completed. Loss: 0.066052
# Epoch 79/100 completed. Loss: 0.066057
# Epoch 80/100 completed. Loss: 0.066094
# Epoch 81/100 completed. Loss: 0.066167
# Epoch 82/100 completed. Loss: 0.066086
# Epoch 83/100 completed. Loss: 0.066057
# Epoch 84/100 completed. Loss: 0.066178
# Epoch 85/100 completed. Loss: 0.066012
# Epoch 86/100 completed. Loss: 0.066210
# Epoch 87/100 completed. Loss: 0.066163
# Epoch 88/100 completed. Loss: 0.066265
# Epoch 89/100 completed. Loss: 0.065952
# Epoch 90/100 completed. Loss: 0.066216
# Epoch 91/100 completed. Loss: 0.065904
# Epoch 92/100 completed. Loss: 0.065955
# Epoch 93/100 completed. Loss: 0.065844
# Epoch 94/100 completed. Loss: 0.065644
# Epoch 95/100 completed. Loss: 0.065708
# Epoch 96/100 completed. Loss: 0.066086
# Epoch 97/100 completed. Loss: 0.065825
# Epoch 98/100 completed. Loss: 0.066275
# Epoch 99/100 completed. Loss: 0.065905
# Epoch 100/100 completed. Loss: 0.066169
# Training complete for run 4
# Month=1, Predicted=17.2807, Expected=17.0780
# Month=2, Predicted=17.3508, Expected=16.5090
# Month=3, Predicted=16.5407, Expected=15.4650
# Month=4, Predicted=15.7378, Expected=14.7060
# Month=5, Predicted=14.9788, Expected=14.2130
# Month=6, Predicted=14.4858, Expected=13.6620
# Month=7, Predicted=13.6937, Expected=13.9280
# Month=8, Predicted=13.7853, Expected=14.5160
# Month=9, Predicted=14.2726, Expected=15.1800
# Month=10, Predicted=14.7550, Expected=15.3510
# Month=11, Predicted=14.9260, Expected=15.5790
# Month=12, Predicted=15.5937, Expected=15.4460
# Month=13, Predicted=16.0509, Expected=15.1990
# Month=14, Predicted=15.0563, Expected=14.7250
# Month=15, Predicted=14.7567, Expected=14.3830
# Month=16, Predicted=14.4984, Expected=14.2310
# Month=17, Predicted=14.8359, Expected=13.7760
# Month=18, Predicted=14.0488, Expected=13.1500
# Month=19, Predicted=13.1647, Expected=12.7130
# Month=20, Predicted=12.8284, Expected=13.2830
# Month=21, Predicted=13.0396, Expected=14.4780
# Month=22, Predicted=14.0530, Expected=14.8580
# Month=23, Predicted=14.6146, Expected=14.7820
# Month=24, Predicted=14.6393, Expected=14.3070
# Month=25, Predicted=14.5798, Expected=14.0230
# Month=26, Predicted=14.2292, Expected=13.5290
# Month=27, Predicted=13.8018, Expected=12.9220
# Month=28, Predicted=12.9367, Expected=12.4100
# Month=29, Predicted=12.6828, Expected=11.9360
# Month=30, Predicted=11.9677, Expected=11.7840
# Month=31, Predicted=12.0568, Expected=11.9920
# Month=32, Predicted=12.0237, Expected=12.6190
# Month=33, Predicted=12.3756, Expected=13.6620
# Month=34, Predicted=13.2370, Expected=14.2310
# Month=35, Predicted=13.8060, Expected=14.0990
# Month=36, Predicted=13.8556, Expected=13.8330
# Month=37, Predicted=13.9484, Expected=13.4160
# Month=38, Predicted=13.4477, Expected=12.9220
# Month=39, Predicted=13.5269, Expected=11.9740
# Month=40, Predicted=11.7306, Expected=11.4610
# Month=41, Predicted=12.0659, Expected=11.4230
# Month=42, Predicted=12.0279, Expected=11.8600
# Month=43, Predicted=12.1328, Expected=12.1630
# Month=44, Predicted=12.4358, Expected=13.2260
# Month=45, Predicted=12.9826, Expected=13.9660
# Month=46, Predicted=13.5410, Expected=14.5350
# Month=47, Predicted=14.1100, Expected=14.5160
# Month=48, Predicted=14.0910, Expected=14.2310
# Month=49, Predicted=14.3464, Expected=13.9660
# Month=50, Predicted=13.5410, Expected=13.7380
# Month=51, Predicted=13.7527, Expected=13.2260
# Month=52, Predicted=13.4322, Expected=12.9980
# Month=53, Predicted=13.6029, Expected=13.1310
# Month=54, Predicted=13.4038, Expected=13.7000
# Month=55, Predicted=13.9062, Expected=13.8140
# Month=56, Predicted=13.8287, Expected=14.3830
# Month=57, Predicted=14.1396, Expected=15.0470
# Month=58, Predicted=14.8036, Expected=15.6930
# Month=59, Predicted=15.4496, Expected=15.8440
# Month=60, Predicted=15.7013, Expected=15.7120
# Run 4 — RMSE: 3.343375, MSE: 11.178156, NMSE: 0.0274415370
#
# ===== RUN 5/60 =====
# Epoch 1/100 completed. Loss: 0.107108
# Epoch 2/100 completed. Loss: 0.067499
# Epoch 3/100 completed. Loss: 0.067338
# Epoch 4/100 completed. Loss: 0.067771
# Epoch 5/100 completed. Loss: 0.067652
# Epoch 6/100 completed. Loss: 0.067388
# Epoch 7/100 completed. Loss: 0.067005
# Epoch 8/100 completed. Loss: 0.067012
# Epoch 9/100 completed. Loss: 0.067681
# Epoch 10/100 completed. Loss: 0.067537
# Epoch 11/100 completed. Loss: 0.067581
# Epoch 12/100 completed. Loss: 0.067905
# Epoch 13/100 completed. Loss: 0.067903
# Epoch 14/100 completed. Loss: 0.067408
# Epoch 15/100 completed. Loss: 0.067519
# Epoch 16/100 completed. Loss: 0.067534
# Epoch 17/100 completed. Loss: 0.067391
# Epoch 18/100 completed. Loss: 0.067421
# Epoch 19/100 completed. Loss: 0.067053
# Epoch 20/100 completed. Loss: 0.066926
# Epoch 21/100 completed. Loss: 0.066966
# Epoch 22/100 completed. Loss: 0.066651
# Epoch 23/100 completed. Loss: 0.066721
# Epoch 24/100 completed. Loss: 0.066852
# Epoch 25/100 completed. Loss: 0.066946
# Epoch 26/100 completed. Loss: 0.066683
# Epoch 27/100 completed. Loss: 0.066830
# Epoch 28/100 completed. Loss: 0.066919
# Epoch 29/100 completed. Loss: 0.066980
# Epoch 30/100 completed. Loss: 0.066732
# Epoch 31/100 completed. Loss: 0.066124
# Epoch 32/100 completed. Loss: 0.066447
# Epoch 33/100 completed. Loss: 0.066561
# Epoch 34/100 completed. Loss: 0.066412
# Epoch 35/100 completed. Loss: 0.066694
# Epoch 36/100 completed. Loss: 0.066674
# Epoch 37/100 completed. Loss: 0.066486
# Epoch 38/100 completed. Loss: 0.066580
# Epoch 39/100 completed. Loss: 0.066581
# Epoch 40/100 completed. Loss: 0.066038
# Epoch 41/100 completed. Loss: 0.066305
# Epoch 42/100 completed. Loss: 0.066406
# Epoch 43/100 completed. Loss: 0.066343
# Epoch 44/100 completed. Loss: 0.066498
# Epoch 45/100 completed. Loss: 0.066311
# Epoch 46/100 completed. Loss: 0.066261
# Epoch 47/100 completed. Loss: 0.066522
# Epoch 48/100 completed. Loss: 0.066286
# Epoch 49/100 completed. Loss: 0.066617
# Epoch 50/100 completed. Loss: 0.066831
# Epoch 51/100 completed. Loss: 0.066766
# Epoch 52/100 completed. Loss: 0.066555
# Epoch 53/100 completed. Loss: 0.066625
# Epoch 54/100 completed. Loss: 0.066268
# Epoch 55/100 completed. Loss: 0.066632
# Epoch 56/100 completed. Loss: 0.066432
# Epoch 57/100 completed. Loss: 0.066323
# Epoch 58/100 completed. Loss: 0.066533
# Epoch 59/100 completed. Loss: 0.066489
# Epoch 60/100 completed. Loss: 0.066685
# Epoch 61/100 completed. Loss: 0.066596
# Epoch 62/100 completed. Loss: 0.066870
# Epoch 63/100 completed. Loss: 0.066256
# Epoch 64/100 completed. Loss: 0.066381
# Epoch 65/100 completed. Loss: 0.066370
# Epoch 66/100 completed. Loss: 0.066085
# Epoch 67/100 completed. Loss: 0.066209
# Epoch 68/100 completed. Loss: 0.065786
# Epoch 69/100 completed. Loss: 0.065838
# Epoch 70/100 completed. Loss: 0.065938
# Epoch 71/100 completed. Loss: 0.065585
# Epoch 72/100 completed. Loss: 0.065649
# Epoch 73/100 completed. Loss: 0.065457
# Epoch 74/100 completed. Loss: 0.065139
# Epoch 75/100 completed. Loss: 0.065464
# Epoch 76/100 completed. Loss: 0.065904
# Epoch 77/100 completed. Loss: 0.065537
# Epoch 78/100 completed. Loss: 0.065333
# Epoch 79/100 completed. Loss: 0.065308
# Epoch 80/100 completed. Loss: 0.065624
# Epoch 81/100 completed. Loss: 0.065617
# Epoch 82/100 completed. Loss: 0.065527
# Epoch 83/100 completed. Loss: 0.065463
# Epoch 84/100 completed. Loss: 0.065374
# Epoch 85/100 completed. Loss: 0.065595
# Epoch 86/100 completed. Loss: 0.065570
# Epoch 87/100 completed. Loss: 0.065640
# Epoch 88/100 completed. Loss: 0.065693
# Epoch 89/100 completed. Loss: 0.065893
# Epoch 90/100 completed. Loss: 0.065322
# Epoch 91/100 completed. Loss: 0.065739
# Epoch 92/100 completed. Loss: 0.065409
# Epoch 93/100 completed. Loss: 0.065355
# Epoch 94/100 completed. Loss: 0.065244
# Epoch 95/100 completed. Loss: 0.065233
# Epoch 96/100 completed. Loss: 0.065214
# Epoch 97/100 completed. Loss: 0.064872
# Epoch 98/100 completed. Loss: 0.064982
# Epoch 99/100 completed. Loss: 0.064994
# Epoch 100/100 completed. Loss: 0.065274
# Training complete for run 5
# Month=1, Predicted=17.2771, Expected=17.0780
# Month=2, Predicted=17.3895, Expected=16.5090
# Month=3, Predicted=16.5371, Expected=15.4650
# Month=4, Predicted=15.7765, Expected=14.7060
# Month=5, Predicted=15.0175, Expected=14.2130
# Month=6, Predicted=14.5245, Expected=13.6620
# Month=7, Predicted=13.6901, Expected=13.9280
# Month=8, Predicted=13.8701, Expected=14.5160
# Month=9, Predicted=14.1807, Expected=15.1800
# Month=10, Predicted=14.7912, Expected=15.3510
# Month=11, Predicted=14.9633, Expected=15.5790
# Month=12, Predicted=15.5641, Expected=15.4460
# Month=13, Predicted=16.0162, Expected=15.1990
# Month=14, Predicted=15.1411, Expected=14.7250
# Month=15, Predicted=14.7531, Expected=14.3830
# Month=16, Predicted=14.6485, Expected=14.2310
# Month=17, Predicted=14.8012, Expected=13.7760
# Month=18, Predicted=14.0875, Expected=13.1500
# Month=19, Predicted=13.1351, Expected=12.7130
# Month=20, Predicted=12.7411, Expected=13.2830
# Month=21, Predicted=13.0864, Expected=14.4780
# Month=22, Predicted=14.0357, Expected=14.8580
# Month=23, Predicted=14.4692, Expected=14.7820
# Month=24, Predicted=14.7241, Expected=14.3070
# Month=25, Predicted=14.6185, Expected=14.0230
# Month=26, Predicted=14.3115, Expected=13.5290
# Month=27, Predicted=13.8405, Expected=12.9220
# Month=28, Predicted=12.9071, Expected=12.4100
# Month=29, Predicted=12.7215, Expected=11.9360
# Month=30, Predicted=11.9641, Expected=11.7840
# Month=31, Predicted=12.0725, Expected=11.9920
# Month=32, Predicted=12.0201, Expected=12.6190
# Month=33, Predicted=12.4224, Expected=13.6620
# Month=34, Predicted=13.2197, Expected=14.2310
# Month=35, Predicted=13.7887, Expected=14.0990
# Month=36, Predicted=13.7837, Expected=13.8330
# Month=37, Predicted=14.0985, Expected=13.4160
# Month=38, Predicted=13.4011, Expected=12.9220
# Month=39, Predicted=13.4922, Expected=11.9740
# Month=40, Predicted=11.7774, Expected=11.4610
# Month=41, Predicted=12.0312, Expected=11.4230
# Month=42, Predicted=11.9932, Expected=11.8600
# Month=43, Predicted=12.1715, Expected=12.1630
# Month=44, Predicted=12.4745, Expected=13.2260
# Month=45, Predicted=12.9107, Expected=13.9660
# Month=46, Predicted=13.6854, Expected=14.5350
# Month=47, Predicted=14.2544, Expected=14.5160
# Month=48, Predicted=14.1272, Expected=14.2310
# Month=49, Predicted=14.2591, Expected=13.9660
# Month=50, Predicted=13.5783, Expected=13.7380
# Month=51, Predicted=13.7231, Expected=13.2260
# Month=52, Predicted=13.5145, Expected=12.9980
# Month=53, Predicted=13.5682, Expected=13.1310
# Month=54, Predicted=13.4425, Expected=13.7000
# Month=55, Predicted=13.9885, Expected=13.8140
# Month=56, Predicted=13.7991, Expected=14.3830
# Month=57, Predicted=14.1864, Expected=15.0470
# Month=58, Predicted=14.6582, Expected=15.6930
# Month=59, Predicted=15.3577, Expected=15.8440
# Month=60, Predicted=15.6474, Expected=15.7120
# Run 5 — RMSE: 3.336790, MSE: 11.134169, NMSE: 0.0275108224
#
# ===== RUN 6/60 =====
# Epoch 1/100 completed. Loss: 0.110614
# Epoch 2/100 completed. Loss: 0.075453
# Epoch 3/100 completed. Loss: 0.070806
# Epoch 4/100 completed. Loss: 0.071406
# Epoch 5/100 completed. Loss: 0.070240
# Epoch 6/100 completed. Loss: 0.069151
# Epoch 7/100 completed. Loss: 0.068963
# Epoch 8/100 completed. Loss: 0.069056
# Epoch 9/100 completed. Loss: 0.068201
# Epoch 10/100 completed. Loss: 0.067098
# Epoch 11/100 completed. Loss: 0.067670
# Epoch 12/100 completed. Loss: 0.067381
# Epoch 13/100 completed. Loss: 0.067656
# Epoch 14/100 completed. Loss: 0.067817
# Epoch 15/100 completed. Loss: 0.067720
# Epoch 16/100 completed. Loss: 0.067063
# Epoch 17/100 completed. Loss: 0.067297
# Epoch 18/100 completed. Loss: 0.067162
# Epoch 19/100 completed. Loss: 0.067002
# Epoch 20/100 completed. Loss: 0.066762
# Epoch 21/100 completed. Loss: 0.067236
# Epoch 22/100 completed. Loss: 0.066732
# Epoch 23/100 completed. Loss: 0.066930
# Epoch 24/100 completed. Loss: 0.066952
# Epoch 25/100 completed. Loss: 0.066918
# Epoch 26/100 completed. Loss: 0.067250
# Epoch 27/100 completed. Loss: 0.067049
# Epoch 28/100 completed. Loss: 0.067761
# Epoch 29/100 completed. Loss: 0.067341
# Epoch 30/100 completed. Loss: 0.067074
# Epoch 31/100 completed. Loss: 0.066741
# Epoch 32/100 completed. Loss: 0.067765
# Epoch 33/100 completed. Loss: 0.066693
# Epoch 34/100 completed. Loss: 0.066670
# Epoch 35/100 completed. Loss: 0.066948
# Epoch 36/100 completed. Loss: 0.067425
# Epoch 37/100 completed. Loss: 0.067445
# Epoch 38/100 completed. Loss: 0.066933
# Epoch 39/100 completed. Loss: 0.067354
# Epoch 40/100 completed. Loss: 0.066331
# Epoch 41/100 completed. Loss: 0.066880
# Epoch 42/100 completed. Loss: 0.067142
# Epoch 43/100 completed. Loss: 0.066264
# Epoch 44/100 completed. Loss: 0.065671
# Epoch 45/100 completed. Loss: 0.066011
# Epoch 46/100 completed. Loss: 0.065180
# Epoch 47/100 completed. Loss: 0.066787
# Epoch 48/100 completed. Loss: 0.065275
# Epoch 49/100 completed. Loss: 0.066300
# Epoch 50/100 completed. Loss: 0.066313
# Epoch 51/100 completed. Loss: 0.065987
# Epoch 52/100 completed. Loss: 0.065820
# Epoch 53/100 completed. Loss: 0.065611
# Epoch 54/100 completed. Loss: 0.065659
# Epoch 55/100 completed. Loss: 0.065938
# Epoch 56/100 completed. Loss: 0.066134
# Epoch 57/100 completed. Loss: 0.065646
# Epoch 58/100 completed. Loss: 0.065950
# Epoch 59/100 completed. Loss: 0.065860
# Epoch 60/100 completed. Loss: 0.065904
# Epoch 61/100 completed. Loss: 0.066104
# Epoch 62/100 completed. Loss: 0.066064
# Epoch 63/100 completed. Loss: 0.066547
# Epoch 64/100 completed. Loss: 0.066623
# Epoch 65/100 completed. Loss: 0.065926
# Epoch 66/100 completed. Loss: 0.066268
# Epoch 67/100 completed. Loss: 0.066436
# Epoch 68/100 completed. Loss: 0.066309
# Epoch 69/100 completed. Loss: 0.065910
# Epoch 70/100 completed. Loss: 0.066071
# Epoch 71/100 completed. Loss: 0.065926
# Epoch 72/100 completed. Loss: 0.065501
# Epoch 73/100 completed. Loss: 0.065719
# Epoch 74/100 completed. Loss: 0.065516
# Epoch 75/100 completed. Loss: 0.065481
# Epoch 76/100 completed. Loss: 0.065884
# Epoch 77/100 completed. Loss: 0.065471
# Epoch 78/100 completed. Loss: 0.065621
# Epoch 79/100 completed. Loss: 0.065766
# Epoch 80/100 completed. Loss: 0.065102
# Epoch 81/100 completed. Loss: 0.065328
# Epoch 82/100 completed. Loss: 0.065762
# Epoch 83/100 completed. Loss: 0.065728
# Epoch 84/100 completed. Loss: 0.065394
# Epoch 85/100 completed. Loss: 0.065661
# Epoch 86/100 completed. Loss: 0.066079
# Epoch 87/100 completed. Loss: 0.065508
# Epoch 88/100 completed. Loss: 0.066175
# Epoch 89/100 completed. Loss: 0.065639
# Epoch 90/100 completed. Loss: 0.065267
# Epoch 91/100 completed. Loss: 0.065397
# Epoch 92/100 completed. Loss: 0.065664
# Epoch 93/100 completed. Loss: 0.065291
# Epoch 94/100 completed. Loss: 0.065359
# Epoch 95/100 completed. Loss: 0.066111
# Epoch 96/100 completed. Loss: 0.065439
# Epoch 97/100 completed. Loss: 0.065458
# Epoch 98/100 completed. Loss: 0.065549
# Epoch 99/100 completed. Loss: 0.065415
# Epoch 100/100 completed. Loss: 0.065171
# Training complete for run 6
# Month=1, Predicted=17.2621, Expected=17.0780
# Month=2, Predicted=17.3978, Expected=16.5090
# Month=3, Predicted=16.5221, Expected=15.4650
# Month=4, Predicted=15.7848, Expected=14.7060
# Month=5, Predicted=15.0258, Expected=14.2130
# Month=6, Predicted=14.5328, Expected=13.6620
# Month=7, Predicted=13.6751, Expected=13.9280
# Month=8, Predicted=13.7698, Expected=14.5160
# Month=9, Predicted=14.1891, Expected=15.1800
# Month=10, Predicted=14.7661, Expected=15.3510
# Month=11, Predicted=14.8154, Expected=15.5790
# Month=12, Predicted=15.5320, Expected=15.4460
# Month=13, Predicted=16.0350, Expected=15.1990
# Month=14, Predicted=15.0408, Expected=14.7250
# Month=15, Predicted=14.7381, Expected=14.3830
# Month=16, Predicted=14.6185, Expected=14.2310
# Month=17, Predicted=14.9780, Expected=13.7760
# Month=18, Predicted=14.0958, Expected=13.1500
# Month=19, Predicted=13.0353, Expected=12.7130
# Month=20, Predicted=12.7261, Expected=13.2830
# Month=21, Predicted=13.1248, Expected=14.4780
# Month=22, Predicted=14.0641, Expected=14.8580
# Month=23, Predicted=14.4876, Expected=14.7820
# Month=24, Predicted=14.6238, Expected=14.3070
# Month=25, Predicted=14.6268, Expected=14.0230
# Month=26, Predicted=14.2316, Expected=13.5290
# Month=27, Predicted=13.8488, Expected=12.9220
# Month=28, Predicted=12.8073, Expected=12.4100
# Month=29, Predicted=12.7298, Expected=11.9360
# Month=30, Predicted=11.9491, Expected=11.7840
# Month=31, Predicted=12.1038, Expected=11.9920
# Month=32, Predicted=12.0051, Expected=12.6190
# Month=33, Predicted=12.4608, Expected=13.6620
# Month=34, Predicted=13.2481, Expected=14.2310
# Month=35, Predicted=13.8171, Expected=14.0990
# Month=36, Predicted=13.9408, Expected=13.8330
# Month=37, Predicted=13.8461, Expected=13.4160
# Month=38, Predicted=13.3690, Expected=12.9220
# Month=39, Predicted=13.6690, Expected=11.9740
# Month=40, Predicted=11.8158, Expected=11.4610
# Month=41, Predicted=11.9657, Expected=11.4230
# Month=42, Predicted=11.8842, Expected=11.8600
# Month=43, Predicted=12.1798, Expected=12.1630
# Month=44, Predicted=12.4828, Expected=13.2260
# Month=45, Predicted=13.0678, Expected=13.9660
# Month=46, Predicted=13.5521, Expected=14.5350
# Month=47, Predicted=14.1211, Expected=14.5160
# Month=48, Predicted=14.1021, Expected=14.2310
# Month=49, Predicted=14.2441, Expected=13.9660
# Month=50, Predicted=13.5521, Expected=13.7380
# Month=51, Predicted=13.6233, Expected=13.2260
# Month=52, Predicted=13.4346, Expected=12.9980
# Month=53, Predicted=13.7450, Expected=13.1310
# Month=54, Predicted=13.4508, Expected=13.7000
# Month=55, Predicted=13.9086, Expected=13.8140
# Month=56, Predicted=13.6993, Expected=14.3830
# Month=57, Predicted=14.2248, Expected=15.0470
# Month=58, Predicted=14.6766, Expected=15.6930
# Month=59, Predicted=15.3661, Expected=15.8440
# Month=60, Predicted=15.6858, Expected=15.7120
# Run 6 — RMSE: 3.342629, MSE: 11.173166, NMSE: 0.0273699523
#
# ===== RUN 7/60 =====
# Epoch 1/100 completed. Loss: 0.133987
# Epoch 2/100 completed. Loss: 0.072608
# Epoch 3/100 completed. Loss: 0.071832
# Epoch 4/100 completed. Loss: 0.076217
# Epoch 5/100 completed. Loss: 0.070867
# Epoch 6/100 completed. Loss: 0.070515
# Epoch 7/100 completed. Loss: 0.069158
# Epoch 8/100 completed. Loss: 0.070335
# Epoch 9/100 completed. Loss: 0.070159
# Epoch 10/100 completed. Loss: 0.070179
# Epoch 11/100 completed. Loss: 0.069956
# Epoch 12/100 completed. Loss: 0.069270
# Epoch 13/100 completed. Loss: 0.069020
# Epoch 14/100 completed. Loss: 0.068587
# Epoch 15/100 completed. Loss: 0.068459
# Epoch 16/100 completed. Loss: 0.067945
# Epoch 17/100 completed. Loss: 0.068008
# Epoch 18/100 completed. Loss: 0.067786
# Epoch 19/100 completed. Loss: 0.067275
# Epoch 20/100 completed. Loss: 0.067224
# Epoch 21/100 completed. Loss: 0.066752
# Epoch 22/100 completed. Loss: 0.067535
# Epoch 23/100 completed. Loss: 0.068000
# Epoch 24/100 completed. Loss: 0.067262
# Epoch 25/100 completed. Loss: 0.067794
# Epoch 26/100 completed. Loss: 0.068088
# Epoch 27/100 completed. Loss: 0.068679
# Epoch 28/100 completed. Loss: 0.068740
# Epoch 29/100 completed. Loss: 0.070358
# Epoch 30/100 completed. Loss: 0.069057
# Epoch 31/100 completed. Loss: 0.068713
# Epoch 32/100 completed. Loss: 0.068124
# Epoch 33/100 completed. Loss: 0.067998
# Epoch 34/100 completed. Loss: 0.067785
# Epoch 35/100 completed. Loss: 0.067392
# Epoch 36/100 completed. Loss: 0.067234
# Epoch 37/100 completed. Loss: 0.066718
# Epoch 38/100 completed. Loss: 0.067047
# Epoch 39/100 completed. Loss: 0.066309
# Epoch 40/100 completed. Loss: 0.067035
# Epoch 41/100 completed. Loss: 0.066366
# Epoch 42/100 completed. Loss: 0.065783
# Epoch 43/100 completed. Loss: 0.065940
# Epoch 44/100 completed. Loss: 0.065806
# Epoch 45/100 completed. Loss: 0.065669
# Epoch 46/100 completed. Loss: 0.066617
# Epoch 47/100 completed. Loss: 0.067082
# Epoch 48/100 completed. Loss: 0.066660
# Epoch 49/100 completed. Loss: 0.066626
# Epoch 50/100 completed. Loss: 0.067036
# Epoch 51/100 completed. Loss: 0.066650
# Epoch 52/100 completed. Loss: 0.066727
# Epoch 53/100 completed. Loss: 0.067540
# Epoch 54/100 completed. Loss: 0.066481
# Epoch 55/100 completed. Loss: 0.066186
# Epoch 56/100 completed. Loss: 0.066159
# Epoch 57/100 completed. Loss: 0.066003
# Epoch 58/100 completed. Loss: 0.065529
# Epoch 59/100 completed. Loss: 0.066032
# Epoch 60/100 completed. Loss: 0.067509
# Epoch 61/100 completed. Loss: 0.067358
# Epoch 62/100 completed. Loss: 0.066398
# Epoch 63/100 completed. Loss: 0.066418
# Epoch 64/100 completed. Loss: 0.066188
# Epoch 65/100 completed. Loss: 0.066145
# Epoch 66/100 completed. Loss: 0.065849
# Epoch 67/100 completed. Loss: 0.066854
# Epoch 68/100 completed. Loss: 0.066363
# Epoch 69/100 completed. Loss: 0.066638
# Epoch 70/100 completed. Loss: 0.066436
# Epoch 71/100 completed. Loss: 0.065670
# Epoch 72/100 completed. Loss: 0.066402
# Epoch 73/100 completed. Loss: 0.067042
# Epoch 74/100 completed. Loss: 0.066535
# Epoch 75/100 completed. Loss: 0.066962
# Epoch 76/100 completed. Loss: 0.067162
# Epoch 77/100 completed. Loss: 0.066359
# Epoch 78/100 completed. Loss: 0.066603
# Epoch 79/100 completed. Loss: 0.066966
# Epoch 80/100 completed. Loss: 0.066967
# Epoch 81/100 completed. Loss: 0.067656
# Epoch 82/100 completed. Loss: 0.067772
# Epoch 83/100 completed. Loss: 0.068152
# Epoch 84/100 completed. Loss: 0.070733
# Epoch 85/100 completed. Loss: 0.067162
# Epoch 86/100 completed. Loss: 0.067963
# Epoch 87/100 completed. Loss: 0.067354
# Epoch 88/100 completed. Loss: 0.067849
# Epoch 89/100 completed. Loss: 0.067202
# Epoch 90/100 completed. Loss: 0.068748
# Epoch 91/100 completed. Loss: 0.068493
# Epoch 92/100 completed. Loss: 0.067353
# Epoch 93/100 completed. Loss: 0.067768
# Epoch 94/100 completed. Loss: 0.066897
# Epoch 95/100 completed. Loss: 0.067462
# Epoch 96/100 completed. Loss: 0.069074
# Epoch 97/100 completed. Loss: 0.068120
# Epoch 98/100 completed. Loss: 0.067494
# Epoch 99/100 completed. Loss: 0.066539
# Epoch 100/100 completed. Loss: 0.066724
# Training complete for run 7
# Month=1, Predicted=17.3408, Expected=17.0780
# Month=2, Predicted=17.4151, Expected=16.5090
# Month=3, Predicted=16.6008, Expected=15.4650
# Month=4, Predicted=15.8021, Expected=14.7060
# Month=5, Predicted=14.9097, Expected=14.2130
# Month=6, Predicted=14.4167, Expected=13.6620
# Month=7, Predicted=13.7538, Expected=13.9280
# Month=8, Predicted=13.7532, Expected=14.5160
# Month=9, Predicted=14.3412, Expected=15.1800
# Month=10, Predicted=14.7814, Expected=15.3510
# Month=11, Predicted=14.9524, Expected=15.5790
# Month=12, Predicted=15.6494, Expected=15.4460
# Month=13, Predicted=16.0283, Expected=15.1990
# Month=14, Predicted=15.0242, Expected=14.7250
# Month=15, Predicted=14.8168, Expected=14.3830
# Month=16, Predicted=14.4748, Expected=14.2310
# Month=17, Predicted=14.8133, Expected=13.7760
# Month=18, Predicted=14.0916, Expected=13.1500
# Month=19, Predicted=13.2204, Expected=12.7130
# Month=20, Predicted=12.8048, Expected=13.2830
# Month=21, Predicted=13.1082, Expected=14.4780
# Month=22, Predicted=14.0794, Expected=14.8580
# Month=23, Predicted=14.4594, Expected=14.7820
# Month=24, Predicted=14.6072, Expected=14.3070
# Month=25, Predicted=14.7762, Expected=14.0230
# Month=26, Predicted=14.1148, Expected=13.5290
# Month=27, Predicted=13.8661, Expected=12.9220
# Month=28, Predicted=13.0138, Expected=12.4100
# Month=29, Predicted=12.7471, Expected=11.9360
# Month=30, Predicted=12.0278, Expected=11.7840
# Month=31, Predicted=12.2532, Expected=11.9920
# Month=32, Predicted=12.0838, Expected=12.6190
# Month=33, Predicted=12.4442, Expected=13.6620
# Month=34, Predicted=13.2634, Expected=14.2310
# Month=35, Predicted=13.8324, Expected=14.0990
# Month=36, Predicted=13.9242, Expected=13.8330
# Month=37, Predicted=13.9248, Expected=13.4160
# Month=38, Predicted=13.6197, Expected=12.9220
# Month=39, Predicted=13.5043, Expected=11.9740
# Month=40, Predicted=11.7992, Expected=11.4610
# Month=41, Predicted=12.0433, Expected=11.4230
# Month=42, Predicted=12.0053, Expected=11.8600
# Month=43, Predicted=12.3292, Expected=12.1630
# Month=44, Predicted=12.6322, Expected=13.2260
# Month=45, Predicted=13.0512, Expected=13.9660
# Month=46, Predicted=13.5674, Expected=14.5350
# Month=47, Predicted=14.1364, Expected=14.5160
# Month=48, Predicted=14.1174, Expected=14.2310
# Month=49, Predicted=14.3228, Expected=13.9660
# Month=50, Predicted=13.5674, Expected=13.7380
# Month=51, Predicted=13.8298, Expected=13.2260
# Month=52, Predicted=13.3178, Expected=12.9980
# Month=53, Predicted=13.5803, Expected=13.1310
# Month=54, Predicted=13.4681, Expected=13.7000
# Month=55, Predicted=13.7918, Expected=13.8140
# Month=56, Predicted=13.8844, Expected=14.3830
# Month=57, Predicted=14.2082, Expected=15.0470
# Month=58, Predicted=14.6484, Expected=15.6930
# Month=59, Predicted=15.2944, Expected=15.8440
# Month=60, Predicted=15.6692, Expected=15.7120
# Run 7 — RMSE: 3.314652, MSE: 10.986921, NMSE: 0.0276097947
#
# ===== RUN 8/60 =====
# Epoch 1/100 completed. Loss: 0.084460
# Epoch 2/100 completed. Loss: 0.067360
# Epoch 3/100 completed. Loss: 0.068066
# Epoch 4/100 completed. Loss: 0.067027
# Epoch 5/100 completed. Loss: 0.067531
# Epoch 6/100 completed. Loss: 0.067438
# Epoch 7/100 completed. Loss: 0.067245
# Epoch 8/100 completed. Loss: 0.067517
# Epoch 9/100 completed. Loss: 0.067482
# Epoch 10/100 completed. Loss: 0.067049
# Epoch 11/100 completed. Loss: 0.067409
# Epoch 12/100 completed. Loss: 0.066772
# Epoch 13/100 completed. Loss: 0.066960
# Epoch 14/100 completed. Loss: 0.066829
# Epoch 15/100 completed. Loss: 0.066993
# Epoch 16/100 completed. Loss: 0.066937
# Epoch 17/100 completed. Loss: 0.066706
# ...
# Month=9, Predicted=14.3397, Expected=15.1800
# Month=10, Predicted=14.7914, Expected=15.3510
# Month=11, Predicted=14.9487, Expected=15.5790
# Month=12, Predicted=15.5593, Expected=15.4460
# Month=13, Predicted=16.0800, Expected=15.1990
# Month=14, Predicted=15.1725, Expected=14.7250
# Month=15, Predicted=14.8081, Expected=14.3830
# Month=16, Predicted=14.6437, Expected=14.2310
# Month=17, Predicted=14.5666, Expected=13.7760
# Month=18, Predicted=14.1116, Expected=13.1500
# Month=19, Predicted=13.1303, Expected=12.7130
# Month=20, Predicted=12.8710, Expected=13.2830
# Month=21, Predicted=13.1067, Expected=14.4780
# Month=22, Predicted=14.0894, Expected=14.8580
# Month=23, Predicted=14.4694, Expected=14.7820
# Month=24, Predicted=14.6125, Expected=14.3070
# Month=25, Predicted=14.6426, Expected=14.0230
# Month=26, Predicted=14.2837, Expected=13.5290
# Month=27, Predicted=13.6870, Expected=12.9220
# Month=28, Predicted=12.9023, Expected=12.4100
# Month=29, Predicted=12.5680, Expected=11.9360
# Month=30, Predicted=12.0191, Expected=11.7840
# Month=31, Predicted=12.1196, Expected=11.9920
# Month=32, Predicted=12.0751, Expected=12.6190
# Month=33, Predicted=12.4427, Expected=13.6620
# Month=34, Predicted=13.2734, Expected=14.2310
# Month=35, Predicted=13.8424, Expected=14.0990
# Month=36, Predicted=13.9227, Expected=13.8330
# Month=37, Predicted=13.9910, Expected=13.4160
# Month=38, Predicted=13.3963, Expected=12.9220
# Month=39, Predicted=13.2576, Expected=11.9740
# Month=40, Predicted=11.7977, Expected=11.4610
# Month=41, Predicted=12.1544, Expected=11.4230
# Month=42, Predicted=12.0570, Expected=11.8600
# Month=43, Predicted=12.0111, Expected=12.1630
# Month=44, Predicted=12.3141, Expected=13.2260
# Month=45, Predicted=13.0497, Expected=13.9660
# Month=46, Predicted=13.5774, Expected=14.5350
# Month=47, Predicted=14.1464, Expected=14.5160
# Month=48, Predicted=14.1274, Expected=14.2310
# Month=49, Predicted=14.3890, Expected=13.9660
# Month=50, Predicted=13.5637, Expected=13.7380
# Month=51, Predicted=13.7183, Expected=13.2260
# Month=52, Predicted=13.4867, Expected=12.9980
# Month=53, Predicted=13.6320, Expected=13.1310
# Month=54, Predicted=13.2890, Expected=13.7000
# Month=55, Predicted=13.9607, Expected=13.8140
# Month=56, Predicted=13.7943, Expected=14.3830
# Month=57, Predicted=14.2067, Expected=15.0470
# Month=58, Predicted=14.6584, Expected=15.6930
# Month=59, Predicted=15.3112, Expected=15.8440
# Month=60, Predicted=15.6677, Expected=15.7120
# Run 58 — RMSE: 3.344657, MSE: 11.186731, NMSE: 0.0275457314
#
# ===== RUN 59/60 =====
# Epoch 1/100 completed. Loss: 0.169225
# Epoch 2/100 completed. Loss: 0.071729
# Epoch 3/100 completed. Loss: 0.069789
# Epoch 4/100 completed. Loss: 0.069037
# Epoch 5/100 completed. Loss: 0.067989
# Epoch 6/100 completed. Loss: 0.068302
# Epoch 7/100 completed. Loss: 0.068411
# Epoch 8/100 completed. Loss: 0.068980
# Epoch 9/100 completed. Loss: 0.068443
# Epoch 10/100 completed. Loss: 0.068347
# Epoch 11/100 completed. Loss: 0.068680
# Epoch 12/100 completed. Loss: 0.068524
# Epoch 13/100 completed. Loss: 0.069103
# Epoch 14/100 completed. Loss: 0.069472
# Epoch 15/100 completed. Loss: 0.068737
# Epoch 16/100 completed. Loss: 0.068130
# Epoch 17/100 completed. Loss: 0.068822
# Epoch 18/100 completed. Loss: 0.068636
# Epoch 19/100 completed. Loss: 0.070117
# Epoch 20/100 completed. Loss: 0.069411
# Epoch 21/100 completed. Loss: 0.069302
# Epoch 22/100 completed. Loss: 0.068348
# Epoch 23/100 completed. Loss: 0.067519
# Epoch 24/100 completed. Loss: 0.066608
# Epoch 25/100 completed. Loss: 0.066881
# Epoch 26/100 completed. Loss: 0.067511
# Epoch 27/100 completed. Loss: 0.067826
# Epoch 28/100 completed. Loss: 0.067479
# Epoch 29/100 completed. Loss: 0.067337
# Epoch 30/100 completed. Loss: 0.067153
# Epoch 31/100 completed. Loss: 0.067002
# Epoch 32/100 completed. Loss: 0.067405
# Epoch 33/100 completed. Loss: 0.067429
# Epoch 34/100 completed. Loss: 0.067766
# Epoch 35/100 completed. Loss: 0.066631
# Epoch 36/100 completed. Loss: 0.067436
# Epoch 37/100 completed. Loss: 0.066258
# Epoch 38/100 completed. Loss: 0.066156
# Epoch 39/100 completed. Loss: 0.066556
# Epoch 40/100 completed. Loss: 0.066365
# Epoch 41/100 completed. Loss: 0.066856
# Epoch 42/100 completed. Loss: 0.066970
# Epoch 43/100 completed. Loss: 0.066859
# Epoch 44/100 completed. Loss: 0.066492
# Epoch 45/100 completed. Loss: 0.066527
# Epoch 46/100 completed. Loss: 0.066467
# Epoch 47/100 completed. Loss: 0.066270
# Epoch 48/100 completed. Loss: 0.066497
# Epoch 49/100 completed. Loss: 0.067120
# Epoch 50/100 completed. Loss: 0.066718
# Epoch 51/100 completed. Loss: 0.066375
# Epoch 52/100 completed. Loss: 0.066528
# Epoch 53/100 completed. Loss: 0.067334
# Epoch 54/100 completed. Loss: 0.065998
# Epoch 55/100 completed. Loss: 0.066130
# Epoch 56/100 completed. Loss: 0.066002
# Epoch 57/100 completed. Loss: 0.066560
# Epoch 58/100 completed. Loss: 0.066759
# Epoch 59/100 completed. Loss: 0.066410
# Epoch 60/100 completed. Loss: 0.067382
# Epoch 61/100 completed. Loss: 0.065925
# Epoch 62/100 completed. Loss: 0.067681
# Epoch 63/100 completed. Loss: 0.066545
# Epoch 64/100 completed. Loss: 0.066433
# Epoch 65/100 completed. Loss: 0.066835
# Epoch 66/100 completed. Loss: 0.066682
# Epoch 67/100 completed. Loss: 0.067104
# Epoch 68/100 completed. Loss: 0.067623
# Epoch 69/100 completed. Loss: 0.066890
# Epoch 70/100 completed. Loss: 0.066549
# Epoch 71/100 completed. Loss: 0.066775
# Epoch 72/100 completed. Loss: 0.067280
# Epoch 73/100 completed. Loss: 0.066776
# Epoch 74/100 completed. Loss: 0.067059
# Epoch 75/100 completed. Loss: 0.066798
# Epoch 76/100 completed. Loss: 0.066947
# Epoch 77/100 completed. Loss: 0.066934
# Epoch 78/100 completed. Loss: 0.066699
# Epoch 79/100 completed. Loss: 0.067210
# Epoch 80/100 completed. Loss: 0.066222
# Epoch 81/100 completed. Loss: 0.066892
# Epoch 82/100 completed. Loss: 0.067066
# Epoch 83/100 completed. Loss: 0.066463
# Epoch 84/100 completed. Loss: 0.066614
# Epoch 85/100 completed. Loss: 0.066458
# Epoch 86/100 completed. Loss: 0.067478
# Epoch 87/100 completed. Loss: 0.066766
# Epoch 88/100 completed. Loss: 0.066652
# Epoch 89/100 completed. Loss: 0.067179
# Epoch 90/100 completed. Loss: 0.066015
# Epoch 91/100 completed. Loss: 0.065959
# Epoch 92/100 completed. Loss: 0.065645
# Epoch 93/100 completed. Loss: 0.065383
# Epoch 94/100 completed. Loss: 0.065627
# Epoch 95/100 completed. Loss: 0.065317
# Epoch 96/100 completed. Loss: 0.065284
# Epoch 97/100 completed. Loss: 0.065203
# Epoch 98/100 completed. Loss: 0.065422
# Epoch 99/100 completed. Loss: 0.065028
# Epoch 100/100 completed. Loss: 0.065013
# Training complete for run 59
# Month=1, Predicted=17.3280, Expected=17.0780
# Month=2, Predicted=17.3773, Expected=16.5090
# Month=3, Predicted=16.5880, Expected=15.4650
# Month=4, Predicted=15.7643, Expected=14.7060
# Month=5, Predicted=15.0053, Expected=14.2130
# Month=6, Predicted=14.5123, Expected=13.6620
# Month=7, Predicted=13.7410, Expected=13.9280
# Month=8, Predicted=13.8840, Expected=14.5160
# Month=9, Predicted=14.3490, Expected=15.1800
# Month=10, Predicted=14.7670, Expected=15.3510
# Month=11, Predicted=14.9380, Expected=15.5790
# Month=12, Predicted=15.6580, Expected=15.4460
# Month=13, Predicted=16.1382, Expected=15.1990
# Month=14, Predicted=15.1550, Expected=14.7250
# Month=15, Predicted=14.8040, Expected=14.3830
# Month=16, Predicted=14.6089, Expected=14.2310
# Month=17, Predicted=14.9232, Expected=13.7760
# Month=18, Predicted=14.0753, Expected=13.1500
# Month=19, Predicted=13.2290, Expected=12.7130
# Month=20, Predicted=12.7920, Expected=13.2830
# Month=21, Predicted=13.1160, Expected=14.4780
# Month=22, Predicted=14.0650, Expected=14.8580
# Month=23, Predicted=14.4450, Expected=14.7820
# Month=24, Predicted=14.6150, Expected=14.3070
# Month=25, Predicted=14.6926, Expected=14.0230
# Month=26, Predicted=14.2489, Expected=13.5290
# Month=27, Predicted=13.8283, Expected=12.9220
# Month=28, Predicted=12.8780, Expected=12.4100
# Month=29, Predicted=12.7093, Expected=11.9360
# Month=30, Predicted=12.0150, Expected=11.7840
# Month=31, Predicted=12.1696, Expected=11.9920
# Month=32, Predicted=12.0710, Expected=12.6190
# Month=33, Predicted=12.4520, Expected=13.6620
# Month=34, Predicted=13.2490, Expected=14.2310
# Month=35, Predicted=13.8180, Expected=14.0990
# Month=36, Predicted=13.9320, Expected=13.8330
# Month=37, Predicted=13.9120, Expected=13.4160
# Month=38, Predicted=13.4950, Expected=12.9220
# Month=39, Predicted=13.6142, Expected=11.9740
# Month=40, Predicted=11.8070, Expected=11.4610
# Month=41, Predicted=12.1532, Expected=11.4230
# Month=42, Predicted=12.1152, Expected=11.8600
# Month=43, Predicted=12.0859, Expected=12.1630
# Month=44, Predicted=12.3889, Expected=13.2260
# Month=45, Predicted=13.0590, Expected=13.9660
# Month=46, Predicted=13.5530, Expected=14.5350
# Month=47, Predicted=14.1220, Expected=14.5160
# Month=48, Predicted=14.1030, Expected=14.2310
# Month=49, Predicted=14.3100, Expected=13.9660
# Month=50, Predicted=13.5530, Expected=13.7380
# Month=51, Predicted=13.6940, Expected=13.2260
# Month=52, Predicted=13.4519, Expected=12.9980
# Month=53, Predicted=13.6902, Expected=13.1310
# Month=54, Predicted=13.3569, Expected=13.7000
# Month=55, Predicted=13.9259, Expected=13.8140
# Month=56, Predicted=13.8930, Expected=14.3830
# Month=57, Predicted=14.2160, Expected=15.0470
# Month=58, Predicted=14.6340, Expected=15.6930
# Month=59, Predicted=15.5260, Expected=15.8440
# Month=60, Predicted=15.6770, Expected=15.7120
# Run 59 — RMSE: 3.323144, MSE: 11.043288, NMSE: 0.0276779541
#
# ===== RUN 60/60 =====
# Epoch 1/100 completed. Loss: 0.081331
# Epoch 2/100 completed. Loss: 0.068369
# Epoch 3/100 completed. Loss: 0.068712
# Epoch 4/100 completed. Loss: 0.068044
# Epoch 5/100 completed. Loss: 0.068282
# Epoch 6/100 completed. Loss: 0.067425
# Epoch 7/100 completed. Loss: 0.067335
# Epoch 8/100 completed. Loss: 0.067136
# Epoch 9/100 completed. Loss: 0.066239
# Epoch 10/100 completed. Loss: 0.066589
# Epoch 11/100 completed. Loss: 0.066234
# Epoch 12/100 completed. Loss: 0.066091
# Epoch 13/100 completed. Loss: 0.066250
# Epoch 14/100 completed. Loss: 0.066526
# Epoch 15/100 completed. Loss: 0.066854
# Epoch 16/100 completed. Loss: 0.067186
# Epoch 17/100 completed. Loss: 0.067409
# Epoch 18/100 completed. Loss: 0.067305
# Epoch 19/100 completed. Loss: 0.067261
# Epoch 20/100 completed. Loss: 0.067745
# Epoch 21/100 completed. Loss: 0.067823
# Epoch 22/100 completed. Loss: 0.067953
# Epoch 23/100 completed. Loss: 0.068151
# Epoch 24/100 completed. Loss: 0.068023
# Epoch 25/100 completed. Loss: 0.067678
# Epoch 26/100 completed. Loss: 0.067831
# Epoch 27/100 completed. Loss: 0.067732
# Epoch 28/100 completed. Loss: 0.067402
# Epoch 29/100 completed. Loss: 0.067177
# Epoch 30/100 completed. Loss: 0.067482
# Epoch 31/100 completed. Loss: 0.067317
# Epoch 32/100 completed. Loss: 0.067472
# Epoch 33/100 completed. Loss: 0.067436
# Epoch 34/100 completed. Loss: 0.067292
# Epoch 35/100 completed. Loss: 0.067422
# Epoch 36/100 completed. Loss: 0.067007
# Epoch 37/100 completed. Loss: 0.066982
# Epoch 38/100 completed. Loss: 0.067282
# Epoch 39/100 completed. Loss: 0.067680
# Epoch 40/100 completed. Loss: 0.067581
# Epoch 41/100 completed. Loss: 0.067551
# Epoch 42/100 completed. Loss: 0.067796
# Epoch 43/100 completed. Loss: 0.067681
# Epoch 44/100 completed. Loss: 0.067644
# Epoch 45/100 completed. Loss: 0.067408
# Epoch 46/100 completed. Loss: 0.067509
# Epoch 47/100 completed. Loss: 0.067536
# Epoch 48/100 completed. Loss: 0.067460
# Epoch 49/100 completed. Loss: 0.067394
# Epoch 50/100 completed. Loss: 0.067396
# Epoch 51/100 completed. Loss: 0.067378
# Epoch 52/100 completed. Loss: 0.067444
# Epoch 53/100 completed. Loss: 0.067794
# Epoch 54/100 completed. Loss: 0.067863
# Epoch 55/100 completed. Loss: 0.068223
# Epoch 56/100 completed. Loss: 0.067906
# Epoch 57/100 completed. Loss: 0.067520
# Epoch 58/100 completed. Loss: 0.067416
# Epoch 59/100 completed. Loss: 0.067467
# Epoch 60/100 completed. Loss: 0.067425
# Epoch 61/100 completed. Loss: 0.067460
# Epoch 62/100 completed. Loss: 0.067117
# Epoch 63/100 completed. Loss: 0.067137
# Epoch 64/100 completed. Loss: 0.067002
# Epoch 65/100 completed. Loss: 0.067257
# Epoch 66/100 completed. Loss: 0.067137
# Epoch 67/100 completed. Loss: 0.067144
# Epoch 68/100 completed. Loss: 0.066886
# Epoch 69/100 completed. Loss: 0.067241
# Epoch 70/100 completed. Loss: 0.067311
# Epoch 71/100 completed. Loss: 0.067299
# Epoch 72/100 completed. Loss: 0.067588
# Epoch 73/100 completed. Loss: 0.067555
# Epoch 74/100 completed. Loss: 0.067099
# Epoch 75/100 completed. Loss: 0.067676
# Epoch 76/100 completed. Loss: 0.067865
# Epoch 77/100 completed. Loss: 0.067731
# Epoch 78/100 completed. Loss: 0.067354
# Epoch 79/100 completed. Loss: 0.067113
# Epoch 80/100 completed. Loss: 0.067764
# Epoch 81/100 completed. Loss: 0.068013
# Epoch 82/100 completed. Loss: 0.067071
# Epoch 83/100 completed. Loss: 0.067008
# Epoch 84/100 completed. Loss: 0.067064
# Epoch 85/100 completed. Loss: 0.066475
# Epoch 86/100 completed. Loss: 0.066642
# Epoch 87/100 completed. Loss: 0.066947
# Epoch 88/100 completed. Loss: 0.066720
# Epoch 89/100 completed. Loss: 0.067326
# Epoch 90/100 completed. Loss: 0.066998
# Epoch 91/100 completed. Loss: 0.067312
# Epoch 92/100 completed. Loss: 0.066944
# Epoch 93/100 completed. Loss: 0.066926
# Epoch 94/100 completed. Loss: 0.066464
# Epoch 95/100 completed. Loss: 0.066486
# Epoch 96/100 completed. Loss: 0.066670
# Epoch 97/100 completed. Loss: 0.066739
# Epoch 98/100 completed. Loss: 0.066661
# Epoch 99/100 completed. Loss: 0.066242
# Epoch 100/100 completed. Loss: 0.066180
# Training complete for run 60
# Month=1, Predicted=17.4050, Expected=17.0780
# Month=2, Predicted=17.3747, Expected=16.5090
# Month=3, Predicted=16.6650, Expected=15.4650
# Month=4, Predicted=15.7617, Expected=14.7060
# Month=5, Predicted=15.1427, Expected=14.2130
# Month=6, Predicted=14.6497, Expected=13.6620
# Month=7, Predicted=13.8180, Expected=13.9280
# Month=8, Predicted=13.8437, Expected=14.5160
# Month=9, Predicted=14.2106, Expected=15.1800
# Month=10, Predicted=14.7894, Expected=15.3510
# Month=11, Predicted=14.9604, Expected=15.5790
# Month=12, Predicted=15.5646, Expected=15.4460
# Month=13, Predicted=16.0719, Expected=15.1990
# Month=14, Predicted=15.1147, Expected=14.7250
# Month=15, Predicted=14.8810, Expected=14.3830
# Month=16, Predicted=14.6090, Expected=14.2310
# Month=17, Predicted=14.7918, Expected=13.7760
# Month=18, Predicted=14.2127, Expected=13.1500
# Month=19, Predicted=13.1356, Expected=12.7130
# Month=20, Predicted=12.9390, Expected=13.2830
# Month=21, Predicted=13.0455, Expected=14.4780
# Month=22, Predicted=14.0874, Expected=14.8580
# Month=23, Predicted=14.4674, Expected=14.7820
# Month=24, Predicted=14.6977, Expected=14.3070
# Month=25, Predicted=14.6037, Expected=14.0230
# Month=26, Predicted=14.2490, Expected=13.5290
# Month=27, Predicted=13.8257, Expected=12.9220
# Month=28, Predicted=12.9076, Expected=12.4100
# Month=29, Predicted=12.7067, Expected=11.9360
# Month=30, Predicted=12.0920, Expected=11.7840
# Month=31, Predicted=12.1133, Expected=11.9920
# Month=32, Predicted=12.1480, Expected=12.6190
# Month=33, Predicted=12.4667, Expected=13.6620
# Month=34, Predicted=13.2714, Expected=14.2310
# Month=35, Predicted=13.8404, Expected=14.0990
# Month=36, Predicted=13.7936, Expected=13.8330
# Month=37, Predicted=14.0590, Expected=13.4160
# Month=38, Predicted=13.4016, Expected=12.9220
# Month=39, Predicted=13.4828, Expected=11.9740
# Month=40, Predicted=11.8217, Expected=11.4610
# Month=41, Predicted=12.1165, Expected=11.4230
# Month=42, Predicted=12.0489, Expected=11.8600
# Month=43, Predicted=12.1567, Expected=12.1630
# Month=44, Predicted=12.4597, Expected=13.2260
# Month=45, Predicted=12.9206, Expected=13.9660
# Month=46, Predicted=13.5754, Expected=14.5350
# Month=47, Predicted=14.1444, Expected=14.5160
# Month=48, Predicted=14.1254, Expected=14.2310
# Month=49, Predicted=14.4570, Expected=13.9660
# Month=50, Predicted=13.5754, Expected=13.7380
# Month=51, Predicted=13.7236, Expected=13.2260
# Month=52, Predicted=13.4520, Expected=12.9980
# Month=53, Predicted=13.6239, Expected=13.1310
# Month=54, Predicted=13.4277, Expected=13.7000
# Month=55, Predicted=13.9260, Expected=13.8140
# Month=56, Predicted=13.7996, Expected=14.3830
# Month=57, Predicted=14.1455, Expected=15.0470
# Month=58, Predicted=14.6564, Expected=15.6930
# Month=59, Predicted=15.3876, Expected=15.8440
# Month=60, Predicted=15.6917, Expected=15.7120
# Run 60 — RMSE: 3.324041, MSE: 11.049250, NMSE: 0.0277340989

# %%
# ============================================================
# Summary Statistics (60 runs)
# ============================================================
print('\n===== FINAL RESULTS (60 runs) =====')
print(f'RMSE: {np.mean(all_rmse):.6f} ± {np.std(all_rmse):.6f}')
print(f'MSE:  {np.mean(all_mse):.6f} ± {np.std(all_mse):.6f}')
print(f'NMSE: {np.mean(all_nmse):.10f} ± {np.std(all_nmse):.10f}')
best_idx = np.argmin(all_rmse)
print(f'\nBest run: {best_idx+1}')
print(f'  RMSE: {all_rmse[best_idx]:.6f}')
print(f'  MSE:  {all_mse[best_idx]:.6f}')
print(f'  NMSE: {all_nmse[best_idx]:.10f}')
# Out:
# ===== FINAL RESULTS (60 runs) =====
# RMSE: 3.323819 ± 0.011790
# MSE:  11.047915 ± 0.078408
# NMSE: 0.0276225559 ± 0.0001127723
#
# Best run: 45
#   RMSE: 3.298953
#   MSE:  10.883092
#   NMSE: 0.0278705274

# %%
# ============================================================
# Predictions vs Actual (Best Run)
# ============================================================
best_predictions = all_predictions[best_idx]
actual = raw_values[-len(best_predictions):]

plt.figure(figsize=(12, 5))
plt.plot(actual, label='Actual', color='blue', linewidth=1.5)
plt.plot(best_predictions, label='Predicted (Best Run)', color='red',
         linewidth=1.5, linestyle='--')
plt.title('Fuzzy Output Layer — Dow Jones Industrial Index\nPredictions vs Actual (Best of 60 runs)')
plt.xlabel('Time Step')
plt.ylabel('Value')
plt.legend()
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

# ============================================================
# Loss Curve (Best Run)
# ============================================================
plt.figure(figsize=(12, 4))
plt.plot(all_losses[best_idx], color='green', linewidth=1.0)
plt.title('Fuzzy Output Layer — Dow Jones Industrial Index\nTraining Loss (Best Run)')
plt.xlabel('Epoch')
plt.ylabel('MSE Loss')
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

# ============================================================
# Final Metrics Summary
# ============================================================
print('=== Best Run Metrics ===')
print(f'RMSE: {all_rmse[best_idx]:.6f}')
print(f'MSE:  {all_mse[best_idx]:.6f}')
print(f'NMSE: {all_nmse[best_idx]:.10f}')
# Out:
# === Best Run Metrics ===
# RMSE: 3.298953
# MSE:  10.883092
# NMSE: 0.0278705274

# %%
# ============================================================
# NOTEBOOK TIMER — END
# ============================================================
import time
_NOTEBOOK_END_TIME = time.time()
try:
    _NOTEBOOK_ELAPSED = _NOTEBOOK_END_TIME - _NOTEBOOK_START_TIME
    print(f"\nNotebook execution complete.\nTotal Elapsed Time: {_NOTEBOOK_ELAPSED/60:.2f} minutes")
except NameError:
    pass
