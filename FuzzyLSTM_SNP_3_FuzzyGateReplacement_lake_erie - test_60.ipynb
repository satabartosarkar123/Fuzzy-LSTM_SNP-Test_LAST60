# %% [markdown]
# # Notebook 3: LSTM-SNP with Fuzzy Gate Replacement
#
# **Dataset**: Monthly Lake Erie Levels
#
# ## Description
# This notebook implements **fuzzy gate replacement** for the LSTM-SNP model. The reset (r),
# consumption (c), and output (o) gates — which normally use hard sigmoid activation — are
# replaced with fuzzy inference systems. Each gate uses 2 Takagi-Sugeno rules with fixed Gaussian
# membership functions and trainable consequent parameters.
#
# The generation gate (a) retains its original tanh activation. The rest of the SNP architecture
# is unchanged. Gradient clipping (norm=1.0) is applied for training stability.

# %%
# ============================================================
# ALL IMPORTS
# ============================================================

import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras import layers
from tensorflow.keras import Model
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from math import sqrt
import matplotlib.pyplot as plt

print(f"TensorFlow version: {tf.__version__}")
print(f"NumPy version: {np.__version__}")
# Out:
# TensorFlow version: 2.21.0
# NumPy version: 2.5.1

# %%
# Default sigma value (will be overridden by the sigma loop)
CURRENT_SIGMA = 0.5

# %% [markdown]
# ## Theory: Fuzzy Gate Replacement
#
# ### Modified Gate Computation
# Instead of applying hard sigmoid directly, each gate (r, c, o) uses fuzzy inference:
#
# **Standard**: $r(t) = \sigma(z_r)$ where $z_r = W_r x(t) + U_r u(t-1) + b_r$
#
# **Fuzzy**: $r(t) = FuzzyInference(z_r, \bar{u}(t-1))$
#
# The fuzzy inference uses:
#
# **Fixed Gaussian Membership Functions**:
# - $\mu_{low}(z) = \exp\left(-\frac{(z - (-1))^2}{2 \cdot 0.5^2}\right)$
# - $\mu_{high}(z) = \exp\left(-\frac{(z - (+1))^2}{2 \cdot 0.5^2}\right)$
#
# **2 Rules per gate** (trainable consequents):
# 1. IF $z_{gate}$ is low → $y_0 = a_0 z + b_0 \bar{u} + c_0$
# 2. IF $z_{gate}$ is high → $y_1 = a_1 z + b_1 \bar{u} + c_1$
#
# **Output**: Gate value bounded via sigmoid to $(0, 1)$
#
# ### Unchanged
# - Generation gate $a(t) = \tanh(\cdot)$ — unchanged
# - State update: $u(t) = r \cdot u_{t-1} - c \cdot a$, $h(t) = o \cdot a$ — unchanged
# - Gradient clipping (norm ≤ 1.0) applied for stability

# %% [markdown]
# ## Model Architecture & Implementation

# %% [markdown]
# ### Fuzzy Gate LSTM-SNP Cell

# %%
import torch
import torch.nn as nn

class LSTMSNPCell(nn.Module):
    """Original LSTM-SNP cell — unchanged (hard_sigmoid gates)."""
    def __init__(self, input_size, hidden_size):
        super().__init__()
        self.input_size = input_size
        self.hidden_size = hidden_size
        self.W = nn.Linear(input_size, 4 * hidden_size, bias=True)
        self.U = nn.Linear(hidden_size, 4 * hidden_size, bias=True)
        nn.init.xavier_uniform_(self.W.weight)
        nn.init.orthogonal_(self.U.weight)

    def forward(self, x, u_prev):
        z = self.W(x) + self.U(u_prev)
        z0 = z[:, :self.hidden_size]
        z1 = z[:, self.hidden_size:2*self.hidden_size]
        z2 = z[:, 2*self.hidden_size:3*self.hidden_size]
        z3 = z[:, 3*self.hidden_size:]
        r = torch.nn.functional.hardsigmoid(z0)
        c = torch.nn.functional.hardsigmoid(z1)
        o = torch.nn.functional.hardsigmoid(z2)
        a = torch.tanh(z3)
        u = r * u_prev - c * a
        h = o * a
        return h, u


class FuzzyLSTMSNPCell(nn.Module):
    """
    LSTM-SNP Cell with fuzzy gate replacement.
    Gates r, c, o computed via 2-rule Takagi-Sugeno fuzzy inference,
    fixed Gaussian MFs (sigma read from global CURRENT_SIGMA at
    construction time, matching the Keras cell's convention),
    trainable consequents, sigmoid-bounded output.
    Gate a keeps tanh (unchanged).
    """
    def __init__(self, input_size, hidden_size):
        super().__init__()
        self.input_size = input_size
        self.hidden_size = hidden_size
        self.mu_low = -1.0
        self.mu_high = 1.0
        # Read from global, exactly like the Keras cell does —
        # CURRENT_SIGMA must be set before this class is instantiated.
        self.sigma = CURRENT_SIGMA

        self.W = nn.Linear(input_size, 4 * hidden_size, bias=True)
        self.U = nn.Linear(hidden_size, 4 * hidden_size, bias=True)
        nn.init.xavier_uniform_(self.W.weight)
        nn.init.orthogonal_(self.U.weight)

        self.fuzzy_params = nn.ParameterDict()
        for gate_name in ['r', 'c', 'o']:
            for rule_idx in range(2):
                self.fuzzy_params[f'{gate_name}_{rule_idx}_a'] = nn.Parameter(
                    torch.empty(hidden_size).uniform_(-0.1, 0.1))
                self.fuzzy_params[f'{gate_name}_{rule_idx}_b'] = nn.Parameter(
                    torch.empty(hidden_size).uniform_(-0.1, 0.1))
                self.fuzzy_params[f'{gate_name}_{rule_idx}_c'] = nn.Parameter(
                    torch.zeros(hidden_size))

    def _gaussian_mf(self, x, center):
        return torch.exp(-(x - center)**2 / (2.0 * self.sigma**2))

    def _fuzzy_gate(self, z_gate, u_mean, gate_name):
        w_low = self._gaussian_mf(z_gate, self.mu_low)
        w_high = self._gaussian_mf(z_gate, self.mu_high)

        a0 = self.fuzzy_params[f'{gate_name}_0_a']
        b0 = self.fuzzy_params[f'{gate_name}_0_b']
        c0 = self.fuzzy_params[f'{gate_name}_0_c']
        a1 = self.fuzzy_params[f'{gate_name}_1_a']
        b1 = self.fuzzy_params[f'{gate_name}_1_b']
        c1 = self.fuzzy_params[f'{gate_name}_1_c']

        y0 = a0 * z_gate + b0 * u_mean + c0
        y1 = a1 * z_gate + b1 * u_mean + c1

        numerator = w_low * y0 + w_high * y1
        denominator = w_low + w_high + 1e-8
        gate_raw = numerator / denominator

        return torch.sigmoid(gate_raw)

    def forward(self, x, u_prev):
        z = self.W(x) + self.U(u_prev)
        z0 = z[:, :self.hidden_size]
        z1 = z[:, self.hidden_size:2*self.hidden_size]
        z2 = z[:, 2*self.hidden_size:3*self.hidden_size]
        z3 = z[:, 3*self.hidden_size:]

        u_mean = u_prev.mean(dim=-1, keepdim=True).expand(-1, self.hidden_size)

        r = self._fuzzy_gate(z0, u_mean, 'r')
        c = self._fuzzy_gate(z1, u_mean, 'c')
        o = self._fuzzy_gate(z2, u_mean, 'o')
        a = torch.tanh(z3)

        u = r * u_prev - c * a
        h = o * a
        return h, u


class RNNModel(nn.Module):
    def __init__(self, input_size, hidden_size):
        super().__init__()
        self.hidden_size = hidden_size
        self.cell = FuzzyLSTMSNPCell(input_size, hidden_size)
        self.out = nn.Linear(hidden_size, 1)
        self.u = None

    def reset_states(self, batch_size, device):
        self.u = torch.zeros(batch_size, self.hidden_size, device=device)

    def detach_states(self):
        if self.u is not None:
            self.u = self.u.detach()

    def forward(self, x):
        if self.u is None or self.u.device != x.device or self.u.size(0) != x.size(0):
            self.reset_states(x.size(0), x.device)
        h, self.u = self.cell(x[:, 0, :], self.u)
        return self.out(h)


def build_model_torch(input_dim, units, batch_size=1):
    # batch_size accepted for call-signature compatibility with build_model_keras,
    # unused here — actual batch size is set dynamically via reset_states().
    return RNNModel(input_size=input_dim, hidden_size=units)


# ============================================================
# Quick model check
# ============================================================
CURRENT_SIGMA = 0.5  # must be set before FuzzyLSTMSNPCell() is constructed
model = build_model_torch(input_dim=1, units=8, batch_size=1)
print(model)
print(f"Total params: {sum(p.numel() for p in model.parameters())}")
# Out:
# RNNModel(
#   (cell): FuzzyLSTMSNPCell(
#     (W): Linear(in_features=1, out_features=32, bias=True)
#     (U): Linear(in_features=8, out_features=32, bias=True)
#     (fuzzy_params): ParameterDict(
#         (r_0_a): Parameter containing: [torch.FloatTensor of size 8]
#         (r_0_b): Parameter containing: [torch.FloatTensor of size 8]
#         (r_0_c): Parameter containing: [torch.FloatTensor of size 8]
#         (r_1_a): Parameter containing: [torch.FloatTensor of size 8]
#         (r_1_b): Parameter containing: [torch.FloatTensor of size 8]
#         (r_1_c): Parameter containing: [torch.FloatTensor of size 8]
#         (c_0_a): Parameter containing: [torch.FloatTensor of size 8]
#         (c_0_b): Parameter containing: [torch.FloatTensor of size 8]
#         (c_0_c): Parameter containing: [torch.FloatTensor of size 8]
#         (c_1_a): Parameter containing: [torch.FloatTensor of size 8]
#         (c_1_b): Parameter containing: [torch.FloatTensor of size 8]
#         (c_1_c): Parameter containing: [torch.FloatTensor of size 8]
#         (o_0_a): Parameter containing: [torch.FloatTensor of size 8]
#         (o_0_b): Parameter containing: [torch.FloatTensor of size 8]
#         (o_0_c): Parameter containing: [torch.FloatTensor of size 8]
#         (o_1_a): Parameter containing: [torch.FloatTensor of size 8]
#         (o_1_b): Parameter containing: [torch.FloatTensor of size 8]
#         (o_1_c): Parameter containing: [torch.FloatTensor of size 8]
#     )
#   )
#   (out): Linear(in_features=8, out_features=1, bias=True)
# )
# Total params: 505

# %% [markdown]
# ### Build Model

# %% [markdown]
# ## Data Pipeline — Monthly Lake Erie Levels

# %%
series = pd.read_csv(
    r'C:\Users\paulp\OneDrive\Desktop\fuzzy_LSTM\dataset\monthly-lake-erie-levels-1921-19.csv',
    header=0,
    parse_dates=[0],
    index_col=0
)
raw_values = series.values.flatten()

# %%
# ============================================================
# 2. First-Order Differencing
# ============================================================

def difference(dataset, interval=1):
    diff = []
    for i in range(interval, len(dataset)):
        value = dataset[i] - dataset[i - interval]
        diff.append(value)
    return np.array(diff)

diff_values = difference(raw_values, 1)

# %%
# ============================================================
# 3. Convert to Supervised Learning Format (lag=1)
# ============================================================

def timeseries_to_supervised(data, lag=1):
    df = pd.DataFrame(data)
    columns = [df.shift(i) for i in range(1, lag+1)]
    columns.append(df)
    df = pd.concat(columns, axis=1)
    df.fillna(0, inplace=True)
    return df.values

supervised = timeseries_to_supervised(diff_values, 1)
print(f"Supervised data shape: {supervised.shape}")
# Out:
# Supervised data shape: (599, 2)

# %%
# ============================================================
# 4. Train-Validation-Test Split (Last 60 points as Test)
# ============================================================
n = len(supervised)
test_size = 60
train_val = supervised[:n - test_size]
test = supervised[n - test_size:]

val_size = int(len(train_val) * 0.1)
train = train_val[:-val_size]
val = train_val[-val_size:]

print(f"Train: {train.shape}, Val: {val.shape}, Test: {test.shape}")

# ============================================================
# 5. Feature Scaling
# ============================================================
scaler = MinMaxScaler(feature_range=(-1, 1))
scaler.fit(train)  # fit only on train to avoid leakage
train_scaled = scaler.transform(train)
val_scaled = scaler.transform(val)
test_scaled = scaler.transform(test)
# Out:
# Train: (486, 2), Val: (53, 2), Test: (60, 2)

# %%
# ============================================================
# 6. Reshape for RNN Input
# ============================================================

X_train, y_train = train_scaled[:, 0:-1], train_scaled[:, -1]
X_train = X_train.reshape((X_train.shape[0], 1, X_train.shape[1]))

X_test, y_test = test_scaled[:, 0:-1], test_scaled[:, -1]
print(f"X_train shape: {X_train.shape}, y_train shape: {y_train.shape}")
# Out:
# X_train shape: (486, 1, 1), y_train shape: (486,)

# %% [markdown]
# ## Training Loop

# %%
# ============================================================
# Multi-Sigma Experiment Protocol (PyTorch)
# σ values from Eq. (21) & (22): 0.25, 0.5, 0.75, 1.0
# ============================================================

SIGMA_VALUES = [0.25, 0.5, 0.75, 1.0]
sigma_results = {}

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"\n--- [PyTorch] RUNNING ON {device} ---\n")

for CURRENT_SIGMA in SIGMA_VALUES:
    print(f'\n{"="*60}')
    print(f'  SIGMA = {CURRENT_SIGMA}')
    print(f'{"="*60}')

    # ============================================================
    # 60-Run Experiment Protocol
    # ============================================================

    all_rmse = []
    all_mse = []
    all_nmse = []
    all_predictions = []
    all_losses = []

    N_RUNS = 60
    for run in range(N_RUNS):
        print(f'\n===== RUN {run+1}/{N_RUNS} =====')

        np.random.seed(run)
        torch.manual_seed(run)

        model = build_model_torch(input_dim=1, units=8, batch_size=1).to(device)

        # Initialize consumption gate bias to 1.0 (forget gate equivalent)
        with torch.no_grad():
            hs = model.hidden_size
            model.cell.U.bias.data[hs:2*hs] = 1.0

        optimizer = torch.optim.Adam(model.parameters(), lr=0.001)
        criterion = nn.MSELoss()

        run_losses = []
        # X_train is (batch, 1, input_dim)
        X_train_t = torch.tensor(X_train, dtype=torch.float32).to(device)
        y_train_t = torch.tensor(y_train, dtype=torch.float32).to(device)
        n_samples = X_train_t.size(0)

        for epoch in range(100):
            model.train()
            model.reset_states(1, device)  # batch_size=1
            epoch_loss = 0.0
            for i in range(n_samples):
                x_i = X_train_t[i:i+1]  # (1, 1, input_dim)
                y_i = y_train_t[i:i+1]  # (1,)

                optimizer.zero_grad()

                # Forward pass
                pred = model(x_i)
                loss = criterion(pred.squeeze(-1), y_i)

                # Backward and optimize
                loss.backward()

                # Gradient clipping (norm ≤ 1.0), applied unconditionally to match
                # the Keras side's Adam(clipnorm=1.0)
                torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)

                optimizer.step()

                # Detach hidden state so BPTT doesn't go all the way back to t=0
                model.detach_states()

                epoch_loss += loss.item()

            avg_loss = epoch_loss / n_samples
            run_losses.append(avg_loss)
            print(f"Epoch {epoch+1}/100 completed. Loss: {avg_loss:.6f}")

        all_losses.append(run_losses)
        print(f'Training complete for run {run+1}')

        # Warm-up: condition hidden states on training data
        model.eval()
        with torch.no_grad():
            for i in range(len(train_scaled)):
                X_raw = train_scaled[i, 0:-1]
                X_input = torch.tensor(X_raw, dtype=torch.float32).view(1, 1, len(X_raw)).to(device)
                model(X_input)

        # Test predictions (single-step)
        predictions = []
        model.eval()
        with torch.no_grad():
            for i in range(len(test_scaled)):
                X, y = test_scaled[i, 0:-1], test_scaled[i, -1]
                X_input = torch.tensor(X, dtype=torch.float32).view(1, 1, len(X)).to(device)
                yhat = model(X_input).item()

                # Invert scaling
                new_row = [x for x in X] + [yhat]
                array = np.array(new_row).reshape(1, len(new_row))
                inverted = scaler.inverse_transform(array)[0, -1]

                # Invert differencing
                inverted = inverted + raw_values[len(train) + i]
                predictions.append(inverted)

                expected = raw_values[len(train) + i + 1]
                print(f'Month={i+1}, Predicted={inverted:.4f}, Expected={expected:.4f}')

        # Compute metrics
        actual = raw_values[-len(test_scaled):]
        rmse = sqrt(mean_squared_error(actual, predictions))
        mse = mean_squared_error(actual, predictions)
        meanV = np.mean(actual)
        dominator = np.linalg.norm(np.array(predictions) - meanV, 2)
        nmse = mse / np.power(dominator, 2)

        all_rmse.append(rmse)
        all_mse.append(mse)
        all_nmse.append(nmse)
        all_predictions.append(predictions)

        print(f'Run {run+1} — RMSE: {rmse:.6f}, MSE: {mse:.6f}, NMSE: {nmse:.10f}')

    # Store results for this sigma
    sigma_results[CURRENT_SIGMA] = {
        'rmse': list(all_rmse),
        'mse': list(all_mse),
        'nmse': list(all_nmse),
        'predictions': list(all_predictions),
        'mean_rmse': float(np.mean(all_rmse)),
        'std_rmse': float(np.std(all_rmse)),
        'mean_mse': float(np.mean(all_mse)),
        'std_mse': float(np.std(all_mse)),
        'mean_nmse': float(np.mean(all_nmse)),
        'std_nmse': float(np.std(all_nmse)),
        'best_idx': int(np.argmin(all_rmse)),
        'best_rmse': float(np.min(all_rmse)),
    }

    print(f'\n--- σ={CURRENT_SIGMA} Summary ---')
    print(f'RMSE: {np.mean(all_rmse):.6f} ± {np.std(all_rmse):.6f}')
    print(f'MSE:  {np.mean(all_mse):.6f} ± {np.std(all_mse):.6f}')
    print(f'NMSE: {np.mean(all_nmse):.10f} ± {np.std(all_nmse):.10f}')
# Out:
# --- [PyTorch] RUNNING ON cuda ---
#
#
# ============================================================
#   SIGMA = 0.25
# ============================================================
#
# ===== RUN 1/60 =====
# Epoch 1/100 completed. Loss: 0.133303
# Epoch 2/100 completed. Loss: 0.081650
# Epoch 3/100 completed. Loss: 0.071384
# Epoch 4/100 completed. Loss: 0.066070
# Epoch 5/100 completed. Loss: 0.064636
# Epoch 6/100 completed. Loss: 0.064371
# Epoch 7/100 completed. Loss: 0.064280
# Epoch 8/100 completed. Loss: 0.064157
# Epoch 9/100 completed. Loss: 0.063997
# Epoch 10/100 completed. Loss: 0.063813
# Epoch 11/100 completed. Loss: 0.063613
# Epoch 12/100 completed. Loss: 0.063403
# Epoch 13/100 completed. Loss: 0.063177
# Epoch 14/100 completed. Loss: 0.062931
# Epoch 15/100 completed. Loss: 0.062710
# Epoch 16/100 completed. Loss: 0.062497
# Epoch 17/100 completed. Loss: 0.062296
# Epoch 18/100 completed. Loss: 0.062106
# Epoch 19/100 completed. Loss: 0.061930
# Epoch 20/100 completed. Loss: 0.061761
# Epoch 21/100 completed. Loss: 0.061603
# Epoch 22/100 completed. Loss: 0.061441
# Epoch 23/100 completed. Loss: 0.061271
# Epoch 24/100 completed. Loss: 0.061082
# Epoch 91/100 completed. Loss: 0.054345
# Epoch 92/100 completed. Loss: 0.054325
# Epoch 93/100 completed. Loss: 0.054305
# Epoch 94/100 completed. Loss: 0.054291
# Epoch 95/100 completed. Loss: 0.054280
# Epoch 96/100 completed. Loss: 0.054271
# Epoch 97/100 completed. Loss: 0.054268
# Epoch 98/100 completed. Loss: 0.054269
# Epoch 99/100 completed. Loss: 0.054248
# Epoch 100/100 completed. Loss: 0.054238
# Training complete for run 1
# Month=1, Predicted=14.5093, Expected=13.9660
# Month=2, Predicted=14.7214, Expected=14.0040
# Month=3, Predicted=14.4770, Expected=15.3130
# Month=4, Predicted=15.7381, Expected=16.3570
# Month=5, Predicted=16.7027, Expected=17.7420
# Month=6, Predicted=17.9751, Expected=17.6090
# Month=7, Predicted=17.5172, Expected=17.2490
# Month=8, Predicted=16.9429, Expected=17.0780
# Month=9, Predicted=16.6194, Expected=16.5090
# Month=10, Predicted=16.0215, Expected=15.4650
# Month=11, Predicted=15.0637, Expected=14.7060
# Month=12, Predicted=14.8979, Expected=14.2130
# Month=13, Predicted=15.1238, Expected=13.6620
# Month=14, Predicted=14.1318, Expected=13.9280
# Month=15, Predicted=14.0073, Expected=14.5160
# Month=16, Predicted=14.5867, Expected=15.1800
# Month=17, Predicted=15.9428, Expected=15.3510
# Month=18, Predicted=15.6000, Expected=15.5790
# Month=19, Predicted=15.4697, Expected=15.4460
# Month=20, Predicted=15.3268, Expected=15.1990
# Month=21, Predicted=14.8321, Expected=14.7250
# Month=22, Predicted=14.1954, Expected=14.3830
# Month=23, Predicted=13.9499, Expected=14.2310
# Month=24, Predicted=14.1247, Expected=13.7760
# Month=25, Predicted=14.2930, Expected=13.1500
# Month=26, Predicted=13.5290, Expected=12.7130
# Month=27, Predicted=13.0784, Expected=13.2830
# Month=28, Predicted=13.2715, Expected=14.4780
# Month=29, Predicted=14.8828, Expected=14.8580
# Month=30, Predicted=14.7953, Expected=14.7820
# Month=31, Predicted=14.9255, Expected=14.3070
# Month=32, Predicted=14.2316, Expected=14.0230
# Month=33, Predicted=13.7456, Expected=13.5290
# Month=34, Predicted=13.0707, Expected=12.9220
# Month=35, Predicted=12.4213, Expected=12.4100
# Month=36, Predicted=12.1292, Expected=11.9360
# Month=37, Predicted=12.2859, Expected=11.7840
# Month=38, Predicted=12.0923, Expected=11.9920
# Month=39, Predicted=12.9152, Expected=12.6190
# Month=40, Predicted=12.9263, Expected=13.6620
# Month=41, Predicted=14.5187, Expected=14.2310
# Month=42, Predicted=14.5363, Expected=14.0990
# Month=43, Predicted=14.1240, Expected=13.8330
# Month=44, Predicted=13.8464, Expected=13.4160
# Month=45, Predicted=12.9758, Expected=12.9220
# Month=46, Predicted=12.1653, Expected=11.9740
# Month=47, Predicted=11.3196, Expected=11.4610
# Month=48, Predicted=11.1059, Expected=11.4230
# Month=49, Predicted=11.8158, Expected=11.8600
# Month=50, Predicted=11.8732, Expected=12.1630
# Month=51, Predicted=12.3659, Expected=13.2260
# Month=52, Predicted=13.5419, Expected=13.9660
# Month=53, Predicted=14.8663, Expected=14.5350
# Month=54, Predicted=14.8751, Expected=14.5160
# Month=55, Predicted=14.5687, Expected=14.2310
# Month=56, Predicted=14.0420, Expected=13.9660
# Month=57, Predicted=13.5670, Expected=13.7380
# Month=58, Predicted=13.2375, Expected=13.2260
# Month=59, Predicted=12.8266, Expected=12.9980
# Month=60, Predicted=12.8273, Expected=13.1310
# Run 1 — RMSE: 3.063310, MSE: 9.383867, NMSE: 0.0233248256
#
# ===== RUN 2/60 =====
# Epoch 1/100 completed. Loss: 0.087018
# Epoch 2/100 completed. Loss: 0.069149
# Epoch 3/100 completed. Loss: 0.064834
# Epoch 4/100 completed. Loss: 0.064325
# Epoch 5/100 completed. Loss: 0.064206
# Epoch 6/100 completed. Loss: 0.064029
# Epoch 7/100 completed. Loss: 0.063775
# Epoch 8/100 completed. Loss: 0.063480
# Epoch 9/100 completed. Loss: 0.063177
# Epoch 10/100 completed. Loss: 0.062869
# Epoch 11/100 completed. Loss: 0.062551
# Epoch 12/100 completed. Loss: 0.062230
# Epoch 13/100 completed. Loss: 0.061909
# Epoch 14/100 completed. Loss: 0.061590
# Epoch 15/100 completed. Loss: 0.061273
# Epoch 16/100 completed. Loss: 0.060963
# Epoch 17/100 completed. Loss: 0.060661
# Epoch 18/100 completed. Loss: 0.060374
# Epoch 19/100 completed. Loss: 0.060105
# Epoch 20/100 completed. Loss: 0.059856
# Epoch 21/100 completed. Loss: 0.059626
# Epoch 22/100 completed. Loss: 0.059414
# Epoch 23/100 completed. Loss: 0.059216
# Epoch 24/100 completed. Loss: 0.059029
# Epoch 25/100 completed. Loss: 0.058851
# Epoch 26/100 completed. Loss: 0.058679
# Epoch 27/100 completed. Loss: 0.058514
# Epoch 28/100 completed. Loss: 0.058353
# Epoch 29/100 completed. Loss: 0.058193
# Epoch 30/100 completed. Loss: 0.058031
# Epoch 31/100 completed. Loss: 0.057868
# Epoch 32/100 completed. Loss: 0.057708
# Epoch 33/100 completed. Loss: 0.057552
# Epoch 34/100 completed. Loss: 0.057396
# Epoch 35/100 completed. Loss: 0.057242
# Epoch 36/100 completed. Loss: 0.057093
# Epoch 37/100 completed. Loss: 0.056947
# Epoch 38/100 completed. Loss: 0.056806
# Epoch 39/100 completed. Loss: 0.056667
# Epoch 40/100 completed. Loss: 0.056530
# Epoch 41/100 completed. Loss: 0.056396
# Epoch 42/100 completed. Loss: 0.056264
# Epoch 43/100 completed. Loss: 0.056132
# Epoch 44/100 completed. Loss: 0.056001
# Epoch 45/100 completed. Loss: 0.055870
# Epoch 46/100 completed. Loss: 0.055734
# Epoch 47/100 completed. Loss: 0.055594
# Epoch 48/100 completed. Loss: 0.055451
# Epoch 49/100 completed. Loss: 0.055303
# Epoch 50/100 completed. Loss: 0.055150
# Epoch 51/100 completed. Loss: 0.054992
# Epoch 52/100 completed. Loss: 0.054829
# Epoch 53/100 completed. Loss: 0.054660
# Epoch 54/100 completed. Loss: 0.054485
# Epoch 55/100 completed. Loss: 0.054306
# Epoch 56/100 completed. Loss: 0.054119
# Epoch 57/100 completed. Loss: 0.053923
# Epoch 58/100 completed. Loss: 0.053687
# Epoch 59/100 completed. Loss: 0.053469
# Epoch 60/100 completed. Loss: 0.053280
# Epoch 61/100 completed. Loss: 0.053081
# Epoch 62/100 completed. Loss: 0.052863
# Epoch 63/100 completed. Loss: 0.052620
# Epoch 64/100 completed. Loss: 0.052365
# Epoch 65/100 completed. Loss: 0.052109
# Epoch 66/100 completed. Loss: 0.051883
# Epoch 67/100 completed. Loss: 0.051682
# Epoch 68/100 completed. Loss: 0.051496
# Epoch 69/100 completed. Loss: 0.051326
# Epoch 70/100 completed. Loss: 0.051170
# Epoch 71/100 completed. Loss: 0.051028
# Epoch 72/100 completed. Loss: 0.050896
# Epoch 73/100 completed. Loss: 0.050778
# Epoch 74/100 completed. Loss: 0.050660
# Epoch 75/100 completed. Loss: 0.050561
# Epoch 76/100 completed. Loss: 0.050462
# Epoch 77/100 completed. Loss: 0.050355
# Epoch 78/100 completed. Loss: 0.050251
# Epoch 79/100 completed. Loss: 0.050148
# Epoch 80/100 completed. Loss: 0.050045
# Epoch 81/100 completed. Loss: 0.049934
# Epoch 82/100 completed. Loss: 0.049816
# Epoch 83/100 completed. Loss: 0.049723
# Epoch 84/100 completed. Loss: 0.049673
# Epoch 85/100 completed. Loss: 0.049609
# Epoch 86/100 completed. Loss: 0.049549
# Epoch 87/100 completed. Loss: 0.049489
# Epoch 88/100 completed. Loss: 0.049424
# Epoch 89/100 completed. Loss: 0.049391
# Epoch 90/100 completed. Loss: 0.049393
# Epoch 91/100 completed. Loss: 0.049422
# Epoch 92/100 completed. Loss: 0.049476
# Epoch 93/100 completed. Loss: 0.049558
# Epoch 94/100 completed. Loss: 0.049652
# Epoch 95/100 completed. Loss: 0.049754
# Epoch 96/100 completed. Loss: 0.049845
# Epoch 97/100 completed. Loss: 0.049953
# Epoch 98/100 completed. Loss: 0.050064
# Epoch 99/100 completed. Loss: 0.050122
# Epoch 100/100 completed. Loss: 0.050031
# Training complete for run 2
# Month=1, Predicted=14.3074, Expected=13.9660
# Month=2, Predicted=14.2713, Expected=14.0040
# Month=3, Predicted=14.3978, Expected=15.3130
# Month=4, Predicted=16.0188, Expected=16.3570
# Month=5, Predicted=16.8425, Expected=17.7420
# Month=6, Predicted=18.0805, Expected=17.6090
# Month=7, Predicted=17.5490, Expected=17.2490
# Month=8, Predicted=16.9140, Expected=17.0780
# Month=9, Predicted=16.5597, Expected=16.5090
# Month=10, Predicted=15.9535, Expected=15.4650
# Month=11, Predicted=14.9759, Expected=14.7060
# Month=12, Predicted=14.8981, Expected=14.2130
# Month=13, Predicted=14.7536, Expected=13.6620
# Month=14, Predicted=14.0010, Expected=13.9280
# Month=15, Predicted=14.4252, Expected=14.5160
# Month=16, Predicted=14.6713, Expected=15.1800
# Month=17, Predicted=15.9246, Expected=15.3510
# Month=18, Predicted=15.7575, Expected=15.5790
# Month=19, Predicted=15.5173, Expected=15.4460
# Month=20, Predicted=15.2959, Expected=15.1990
# Month=21, Predicted=14.6910, Expected=14.7250
# Month=22, Predicted=14.1326, Expected=14.3830
# Month=23, Predicted=13.9769, Expected=14.2310
# Month=24, Predicted=14.1235, Expected=13.7760
# Month=25, Predicted=14.1683, Expected=13.1500
# Month=26, Predicted=13.5837, Expected=12.7130
# Month=27, Predicted=13.3410, Expected=13.2830
# Month=28, Predicted=13.3952, Expected=14.4780
# Month=29, Predicted=14.7749, Expected=14.8580
# Month=30, Predicted=14.7226, Expected=14.7820
# Month=31, Predicted=14.8999, Expected=14.3070
# Month=32, Predicted=14.1807, Expected=14.0230
# Month=33, Predicted=13.6923, Expected=13.5290
# Month=34, Predicted=12.9837, Expected=12.9220
# Month=35, Predicted=12.3431, Expected=12.4100
# Month=36, Predicted=12.2088, Expected=11.9360
# Month=37, Predicted=12.0278, Expected=11.7840
# Month=38, Predicted=12.1027, Expected=11.9920
# Month=39, Predicted=12.9031, Expected=12.6190
# Month=40, Predicted=12.8844, Expected=13.6620
# Month=41, Predicted=14.4894, Expected=14.2310
# Month=42, Predicted=14.5559, Expected=14.0990
# Month=43, Predicted=14.1677, Expected=13.8330
# Month=44, Predicted=13.8363, Expected=13.4160
# Month=45, Predicted=12.8497, Expected=12.9220
# Month=46, Predicted=12.1611, Expected=11.9740
# Month=47, Predicted=11.1701, Expected=11.4610
# Month=48, Predicted=11.1016, Expected=11.4230
# Month=49, Predicted=11.4282, Expected=11.8600
# Month=50, Predicted=11.9932, Expected=12.1630
# Month=51, Predicted=12.7244, Expected=13.2260
# Month=52, Predicted=13.6703, Expected=13.9660
# Month=53, Predicted=14.8112, Expected=14.5350
# Month=54, Predicted=14.9595, Expected=14.5160
# Month=55, Predicted=14.7108, Expected=14.2310
# Month=56, Predicted=14.0856, Expected=13.9660
# Month=57, Predicted=13.5337, Expected=13.7380
# Month=58, Predicted=13.1983, Expected=13.2260
# Month=59, Predicted=12.8951, Expected=12.9980
# Month=60, Predicted=12.9024, Expected=13.1310
# Run 2 — RMSE: 3.063886, MSE: 9.387400, NMSE: 0.0230322520
#
# ===== RUN 3/60 =====
# Epoch 1/100 completed. Loss: 0.090027
# Epoch 2/100 completed. Loss: 0.074390
# Epoch 3/100 completed. Loss: 0.067548
# Epoch 4/100 completed. Loss: 0.065356
# Epoch 5/100 completed. Loss: 0.064989
# Epoch 6/100 completed. Loss: 0.064941
# Epoch 7/100 completed. Loss: 0.064944
# Epoch 8/100 completed. Loss: 0.064812
# Epoch 9/100 completed. Loss: 0.064661
# Epoch 10/100 completed. Loss: 0.064539
# Epoch 11/100 completed. Loss: 0.064419
# Epoch 12/100 completed. Loss: 0.064302
# Epoch 13/100 completed. Loss: 0.064196
# Epoch 14/100 completed. Loss: 0.064115
# Epoch 15/100 completed. Loss: 0.064031
# Epoch 16/100 completed. Loss: 0.063978
# Epoch 17/100 completed. Loss: 0.063939
# Epoch 18/100 completed. Loss: 0.063912
# Epoch 19/100 completed. Loss: 0.063893
# Epoch 20/100 completed. Loss: 0.063884
# Epoch 87/100 completed. Loss: 0.056192
# Epoch 88/100 completed. Loss: 0.056437
# Epoch 89/100 completed. Loss: 0.056668
# Epoch 90/100 completed. Loss: 0.056608
# Epoch 91/100 completed. Loss: 0.056466
# Epoch 92/100 completed. Loss: 0.056178
# Epoch 93/100 completed. Loss: 0.055898
# Epoch 94/100 completed. Loss: 0.055621
# Epoch 95/100 completed. Loss: 0.055362
# Epoch 96/100 completed. Loss: 0.055101
# Epoch 97/100 completed. Loss: 0.054841
# Epoch 98/100 completed. Loss: 0.054549
# Epoch 99/100 completed. Loss: 0.054207
# Epoch 100/100 completed. Loss: 0.053768
# Training complete for run 3
# Month=1, Predicted=14.4747, Expected=13.9660
# Month=2, Predicted=14.5524, Expected=14.0040
# Month=3, Predicted=14.2859, Expected=15.3130
# Month=4, Predicted=15.7510, Expected=16.3570
# Month=5, Predicted=16.7284, Expected=17.7420
# Month=6, Predicted=17.9494, Expected=17.6090
# Month=7, Predicted=17.5411, Expected=17.2490
# Month=8, Predicted=16.9802, Expected=17.0780
# Month=9, Predicted=16.5862, Expected=16.5090
# Month=10, Predicted=15.9993, Expected=15.4650
# Month=11, Predicted=14.9706, Expected=14.7060
# Month=12, Predicted=14.8164, Expected=14.2130
# Month=13, Predicted=14.9344, Expected=13.6620
# Month=14, Predicted=13.9679, Expected=13.9280
# Month=15, Predicted=13.9853, Expected=14.5160
# Month=16, Predicted=14.7001, Expected=15.1800
# Month=17, Predicted=15.8481, Expected=15.3510
# Month=18, Predicted=15.6042, Expected=15.5790
# Month=19, Predicted=15.5044, Expected=15.4460
# Month=20, Predicted=15.2937, Expected=15.1990
# Month=21, Predicted=14.7991, Expected=14.7250
# Month=22, Predicted=14.2402, Expected=14.3830
# Month=23, Predicted=13.9240, Expected=14.2310
# Month=24, Predicted=14.1389, Expected=13.7760
# Month=25, Predicted=14.2649, Expected=13.1500
# Month=26, Predicted=13.4607, Expected=12.7130
# Month=27, Predicted=13.1044, Expected=13.2830
# Month=28, Predicted=13.4317, Expected=14.4780
# Month=29, Predicted=14.8127, Expected=14.8580
# Month=30, Predicted=14.9054, Expected=14.7820
# Month=31, Predicted=14.9065, Expected=14.3070
# Month=32, Predicted=14.2979, Expected=14.0230
# Month=33, Predicted=13.7965, Expected=13.5290
# Month=34, Predicted=13.0999, Expected=12.9220
# Month=35, Predicted=12.4296, Expected=12.4100
# Month=36, Predicted=12.1692, Expected=11.9360
# Month=37, Predicted=12.2936, Expected=11.7840
# Month=38, Predicted=12.0878, Expected=11.9920
# Month=39, Predicted=12.7110, Expected=12.6190
# Month=40, Predicted=12.8591, Expected=13.6620
# Month=41, Predicted=14.4178, Expected=14.2310
# Month=42, Predicted=14.5760, Expected=14.0990
# Month=43, Predicted=14.0164, Expected=13.8330
# Month=44, Predicted=13.6899, Expected=13.4160
# Month=45, Predicted=12.9271, Expected=12.9220
# Month=46, Predicted=12.2452, Expected=11.9740
# Month=47, Predicted=11.3732, Expected=11.4610
# Month=48, Predicted=11.0622, Expected=11.4230
# Month=49, Predicted=11.7737, Expected=11.8600
# Month=50, Predicted=11.7957, Expected=12.1630
# Month=51, Predicted=12.3248, Expected=13.2260
# Month=52, Predicted=13.6991, Expected=13.9660
# Month=53, Predicted=14.6960, Expected=14.5350
# Month=54, Predicted=14.8445, Expected=14.5160
# Month=55, Predicted=14.5356, Expected=14.2310
# Month=56, Predicted=14.0684, Expected=13.9660
# Month=57, Predicted=13.5426, Expected=13.7380
# Month=58, Predicted=13.1836, Expected=13.2260
# Month=59, Predicted=12.7604, Expected=12.9980
# Month=60, Predicted=12.8009, Expected=13.1310
# Run 3 — RMSE: 3.075806, MSE: 9.460585, NMSE: 0.0231561732
#
# ===== RUN 4/60 =====
# Epoch 1/100 completed. Loss: 0.109073
# Epoch 2/100 completed. Loss: 0.074975
# Epoch 3/100 completed. Loss: 0.067424
# Epoch 4/100 completed. Loss: 0.065005
# Epoch 5/100 completed. Loss: 0.064436
# Epoch 6/100 completed. Loss: 0.064037
# Epoch 7/100 completed. Loss: 0.063521
# Epoch 8/100 completed. Loss: 0.062862
# Epoch 9/100 completed. Loss: 0.062071
# Epoch 10/100 completed. Loss: 0.061146
# Epoch 11/100 completed. Loss: 0.060121
# Epoch 12/100 completed. Loss: 0.059069
# Epoch 13/100 completed. Loss: 0.058057
# Epoch 14/100 completed. Loss: 0.057158
# Epoch 15/100 completed. Loss: 0.056373
# Epoch 16/100 completed. Loss: 0.055633
# Epoch 17/100 completed. Loss: 0.055020
# Epoch 18/100 completed. Loss: 0.054515
# Epoch 19/100 completed. Loss: 0.054092
# Epoch 20/100 completed. Loss: 0.053721
# Epoch 21/100 completed. Loss: 0.053371
# Epoch 22/100 completed. Loss: 0.053037
# Epoch 23/100 completed. Loss: 0.052759
# Epoch 24/100 completed. Loss: 0.052533
# Epoch 25/100 completed. Loss: 0.052320
# Epoch 26/100 completed. Loss: 0.052131
# Epoch 27/100 completed. Loss: 0.051965
# Epoch 28/100 completed. Loss: 0.051820
# Epoch 29/100 completed. Loss: 0.051686
# Epoch 30/100 completed. Loss: 0.051549
# Epoch 31/100 completed. Loss: 0.051427
# Epoch 32/100 completed. Loss: 0.051317
# Epoch 33/100 completed. Loss: 0.051229
# Epoch 34/100 completed. Loss: 0.051161
# Epoch 35/100 completed. Loss: 0.051064
# Epoch 36/100 completed. Loss: 0.050983
# Epoch 37/100 completed. Loss: 0.050916
# Epoch 38/100 completed. Loss: 0.050860
# Epoch 39/100 completed. Loss: 0.050816
# Epoch 40/100 completed. Loss: 0.050766
# Epoch 41/100 completed. Loss: 0.050725
# Epoch 42/100 completed. Loss: 0.050695
# Epoch 43/100 completed. Loss: 0.050671
# Epoch 44/100 completed. Loss: 0.050654
# Epoch 45/100 completed. Loss: 0.050631
# Epoch 46/100 completed. Loss: 0.050609
# Epoch 47/100 completed. Loss: 0.050599
# Epoch 48/100 completed. Loss: 0.050594
# Epoch 49/100 completed. Loss: 0.050592
# Epoch 50/100 completed. Loss: 0.050585
# Epoch 51/100 completed. Loss: 0.050572
# Epoch 52/100 completed. Loss: 0.050568
# Epoch 53/100 completed. Loss: 0.050569
# Epoch 54/100 completed. Loss: 0.050572
# Epoch 55/100 completed. Loss: 0.050571
# Epoch 56/100 completed. Loss: 0.050569
# Epoch 57/100 completed. Loss: 0.050572
# Epoch 58/100 completed. Loss: 0.050584
# Epoch 59/100 completed. Loss: 0.050590
# Epoch 60/100 completed. Loss: 0.050601
# Epoch 61/100 completed. Loss: 0.050615
# Epoch 62/100 completed. Loss: 0.050631
# Epoch 63/100 completed. Loss: 0.050647
# Epoch 64/100 completed. Loss: 0.050660
# Epoch 65/100 completed. Loss: 0.050672
# Epoch 66/100 completed. Loss: 0.050689
# Epoch 67/100 completed. Loss: 0.050713
# Epoch 68/100 completed. Loss: 0.050747
# Epoch 69/100 completed. Loss: 0.050769
# Epoch 70/100 completed. Loss: 0.050782
# Epoch 71/100 completed. Loss: 0.050796
# Epoch 72/100 completed. Loss: 0.050809
# Epoch 73/100 completed. Loss: 0.050823
# Epoch 74/100 completed. Loss: 0.050836
# Epoch 75/100 completed. Loss: 0.050846
# Epoch 76/100 completed. Loss: 0.050853
# Epoch 77/100 completed. Loss: 0.050857
# Epoch 78/100 completed. Loss: 0.050858
# Epoch 79/100 completed. Loss: 0.050859
# Epoch 80/100 completed. Loss: 0.050857
# Epoch 81/100 completed. Loss: 0.050854
# Epoch 82/100 completed. Loss: 0.050850
# Epoch 83/100 completed. Loss: 0.050844
# Epoch 84/100 completed. Loss: 0.050837
# Epoch 85/100 completed. Loss: 0.050829
# Epoch 86/100 completed. Loss: 0.050819
# Epoch 87/100 completed. Loss: 0.050809
# Epoch 88/100 completed. Loss: 0.050797
# Epoch 89/100 completed. Loss: 0.050785
# Epoch 90/100 completed. Loss: 0.050771
# Epoch 91/100 completed. Loss: 0.050756
# Epoch 92/100 completed. Loss: 0.050740
# Epoch 93/100 completed. Loss: 0.050723
# Epoch 94/100 completed. Loss: 0.050706
# Epoch 95/100 completed. Loss: 0.050687
# Epoch 96/100 completed. Loss: 0.050668
# Epoch 97/100 completed. Loss: 0.050648
# Epoch 98/100 completed. Loss: 0.050628
# Epoch 99/100 completed. Loss: 0.050606
# Epoch 100/100 completed. Loss: 0.050584
# Training complete for run 4
# Month=1, Predicted=14.3885, Expected=13.9660
# Month=2, Predicted=14.6305, Expected=14.0040
# Month=3, Predicted=14.4418, Expected=15.3130
# Month=4, Predicted=15.8216, Expected=16.3570
# Month=5, Predicted=16.7429, Expected=17.7420
# Month=6, Predicted=17.9818, Expected=17.6090
# Month=7, Predicted=17.4122, Expected=17.2490
# Month=8, Predicted=16.8378, Expected=17.0780
# Month=9, Predicted=16.5703, Expected=16.5090
# Month=10, Predicted=15.9973, Expected=15.4650
# Month=11, Predicted=14.7756, Expected=14.7060
# Month=12, Predicted=14.6807, Expected=14.2130
# Month=13, Predicted=15.0076, Expected=13.6620
# Month=14, Predicted=14.0839, Expected=13.9280
# Month=15, Predicted=14.2064, Expected=14.5160
# Month=16, Predicted=14.7277, Expected=15.1800
# Month=17, Predicted=15.7968, Expected=15.3510
# Month=18, Predicted=15.6236, Expected=15.5790
# Month=19, Predicted=15.3516, Expected=15.4460
# Month=20, Predicted=15.0973, Expected=15.1990
# Month=21, Predicted=14.7416, Expected=14.7250
# Month=22, Predicted=14.1509, Expected=14.3830
# Month=23, Predicted=13.9194, Expected=14.2310
# Month=24, Predicted=14.3287, Expected=13.7760
# Month=25, Predicted=14.3443, Expected=13.1500
# Month=26, Predicted=13.6200, Expected=12.7130
# Month=27, Predicted=13.2043, Expected=13.2830
# Month=28, Predicted=13.4587, Expected=14.4780
# Month=29, Predicted=14.5892, Expected=14.8580
# Month=30, Predicted=14.7505, Expected=14.7820
# Month=31, Predicted=14.6420, Expected=14.3070
# Month=32, Predicted=14.0966, Expected=14.0230
# Month=33, Predicted=13.6503, Expected=13.5290
# Month=34, Predicted=12.9969, Expected=12.9220
# Month=35, Predicted=12.3920, Expected=12.4100
# Month=36, Predicted=12.1685, Expected=11.9360
# Month=37, Predicted=12.3519, Expected=11.7840
# Month=38, Predicted=12.2108, Expected=11.9920
# Month=39, Predicted=12.7693, Expected=12.6190
# Month=40, Predicted=12.8059, Expected=13.6620
# Month=41, Predicted=14.2729, Expected=14.2310
# Month=42, Predicted=14.5135, Expected=14.0990
# Month=43, Predicted=14.0555, Expected=13.8330
# Month=44, Predicted=13.5449, Expected=13.4160
# Month=45, Predicted=12.8820, Expected=12.9220
# Month=46, Predicted=12.1411, Expected=11.9740
# Month=47, Predicted=11.2566, Expected=11.4610
# Month=48, Predicted=10.9192, Expected=11.4230
# Month=49, Predicted=11.6733, Expected=11.8600
# Month=50, Predicted=11.9127, Expected=12.1630
# Month=51, Predicted=12.4507, Expected=13.2260
# Month=52, Predicted=13.7605, Expected=13.9660
# Month=53, Predicted=14.7498, Expected=14.5350
# Month=54, Predicted=14.9260, Expected=14.5160
# Month=55, Predicted=14.7212, Expected=14.2310
# Month=56, Predicted=13.9420, Expected=13.9660
# Month=57, Predicted=13.5143, Expected=13.7380
# Month=58, Predicted=13.2282, Expected=13.2260
# Month=59, Predicted=12.7931, Expected=12.9980
# Month=60, Predicted=13.0074, Expected=13.1310
# Run 4 — RMSE: 3.089201, MSE: 9.543165, NMSE: 0.0232841735
#
# ===== RUN 5/60 =====
# Epoch 1/100 completed. Loss: 0.160574
# Epoch 2/100 completed. Loss: 0.080336
# Epoch 3/100 completed. Loss: 0.069657
# Epoch 4/100 completed. Loss: 0.065183
# Epoch 5/100 completed. Loss: 0.064008
# Epoch 6/100 completed. Loss: 0.063906
# Epoch 7/100 completed. Loss: 0.063921
# Epoch 8/100 completed. Loss: 0.063902
# Epoch 9/100 completed. Loss: 0.063826
# Epoch 10/100 completed. Loss: 0.063734
# Epoch 11/100 completed. Loss: 0.063616
# Epoch 12/100 completed. Loss: 0.063485
# Epoch 13/100 completed. Loss: 0.063354
# Epoch 14/100 completed. Loss: 0.063224
# Epoch 15/100 completed. Loss: 0.063065
# Epoch 16/100 completed. Loss: 0.062923
# Epoch 83/100 completed. Loss: 0.054547
# Epoch 84/100 completed. Loss: 0.054144
# Epoch 85/100 completed. Loss: 0.053735
# Epoch 86/100 completed. Loss: 0.053334
# Epoch 87/100 completed. Loss: 0.052969
# Epoch 88/100 completed. Loss: 0.052690
# Epoch 89/100 completed. Loss: 0.052493
# Epoch 90/100 completed. Loss: 0.052345
# Epoch 91/100 completed. Loss: 0.052230
# Epoch 92/100 completed. Loss: 0.052147
# Epoch 93/100 completed. Loss: 0.052087
# Epoch 94/100 completed. Loss: 0.052033
# Epoch 95/100 completed. Loss: 0.051987
# Epoch 96/100 completed. Loss: 0.051933
# Epoch 97/100 completed. Loss: 0.051878
# Epoch 98/100 completed. Loss: 0.051820
# Epoch 99/100 completed. Loss: 0.051763
# Epoch 100/100 completed. Loss: 0.051712
# Training complete for run 5
# Month=1, Predicted=14.4644, Expected=13.9660
# Month=2, Predicted=14.5478, Expected=14.0040
# Month=3, Predicted=14.3630, Expected=15.3130
# Month=4, Predicted=15.7767, Expected=16.3570
# Month=5, Predicted=16.7696, Expected=17.7420
# Month=6, Predicted=18.0406, Expected=17.6090
# Month=7, Predicted=17.6311, Expected=17.2490
# Month=8, Predicted=16.9681, Expected=17.0780
# Month=9, Predicted=16.6711, Expected=16.5090
# Month=10, Predicted=16.0846, Expected=15.4650
# Month=11, Predicted=14.9261, Expected=14.7060
# Month=12, Predicted=14.8309, Expected=14.2130
# Month=13, Predicted=14.9631, Expected=13.6620
# Month=14, Predicted=13.8807, Expected=13.9280
# Month=15, Predicted=14.1505, Expected=14.5160
# Month=16, Predicted=14.7579, Expected=15.1800
# Month=17, Predicted=15.8832, Expected=15.3510
# Month=18, Predicted=15.6513, Expected=15.5790
# Month=19, Predicted=15.5219, Expected=15.4460
# Month=20, Predicted=15.2480, Expected=15.1990
# Month=21, Predicted=14.8340, Expected=14.7250
# Month=22, Predicted=14.2504, Expected=14.3830
# Month=23, Predicted=14.0566, Expected=14.2310
# Month=24, Predicted=14.1585, Expected=13.7760
# Month=25, Predicted=14.2320, Expected=13.1500
# Month=26, Predicted=13.5489, Expected=12.7130
# Month=27, Predicted=13.1558, Expected=13.2830
# Month=28, Predicted=13.5152, Expected=14.4780
# Month=29, Predicted=14.8307, Expected=14.8580
# Month=30, Predicted=14.9495, Expected=14.7820
# Month=31, Predicted=14.9127, Expected=14.3070
# Month=32, Predicted=14.2456, Expected=14.0230
# Month=33, Predicted=13.7723, Expected=13.5290
# Month=34, Predicted=13.1382, Expected=12.9220
# Month=35, Predicted=12.5220, Expected=12.4100
# Month=36, Predicted=12.2575, Expected=11.9360
# Month=37, Predicted=12.2592, Expected=11.7840
# Month=38, Predicted=12.1223, Expected=11.9920
# Month=39, Predicted=12.8179, Expected=12.6190
# Month=40, Predicted=12.9896, Expected=13.6620
# Month=41, Predicted=14.3714, Expected=14.2310
# Month=42, Predicted=14.5748, Expected=14.0990
# Month=43, Predicted=14.0833, Expected=13.8330
# Month=44, Predicted=13.6226, Expected=13.4160
# Month=45, Predicted=12.8807, Expected=12.9220
# Month=46, Predicted=12.2332, Expected=11.9740
# Month=47, Predicted=11.3629, Expected=11.4610
# Month=48, Predicted=11.1431, Expected=11.4230
# Month=49, Predicted=11.6763, Expected=11.8600
# Month=50, Predicted=11.8910, Expected=12.1630
# Month=51, Predicted=12.5730, Expected=13.2260
# Month=52, Predicted=13.7459, Expected=13.9660
# Month=53, Predicted=14.7852, Expected=14.5350
# Month=54, Predicted=14.9239, Expected=14.5160
# Month=55, Predicted=14.6701, Expected=14.2310
# Month=56, Predicted=14.0786, Expected=13.9660
# Month=57, Predicted=13.5808, Expected=13.7380
# Month=58, Predicted=13.3004, Expected=13.2260
# Month=59, Predicted=12.8674, Expected=12.9980
# Month=60, Predicted=12.8286, Expected=13.1310
# Run 5 — RMSE: 3.049188, MSE: 9.297545, NMSE: 0.0233462807
#
# ===== RUN 6/60 =====
# Epoch 1/100 completed. Loss: 0.141973
# Epoch 2/100 completed. Loss: 0.077987
# Epoch 3/100 completed. Loss: 0.070428
# Epoch 4/100 completed. Loss: 0.065445
# Epoch 5/100 completed. Loss: 0.063311
# Epoch 6/100 completed. Loss: 0.062561
# Epoch 7/100 completed. Loss: 0.062165
# Epoch 8/100 completed. Loss: 0.061749
# Epoch 9/100 completed. Loss: 0.061241
# Epoch 10/100 completed. Loss: 0.060642
# Epoch 11/100 completed. Loss: 0.059953
# Epoch 12/100 completed. Loss: 0.059182
# Epoch 13/100 completed. Loss: 0.058342
# Epoch 14/100 completed. Loss: 0.057492
# Epoch 15/100 completed. Loss: 0.056639
# Epoch 16/100 completed. Loss: 0.055823
# Epoch 17/100 completed. Loss: 0.055064
# Epoch 18/100 completed. Loss: 0.054354
# Epoch 19/100 completed. Loss: 0.053769
# Epoch 20/100 completed. Loss: 0.053291
# Epoch 21/100 completed. Loss: 0.052908
# Epoch 22/100 completed. Loss: 0.052606
# Epoch 23/100 completed. Loss: 0.052367
# Epoch 24/100 completed. Loss: 0.052184
# Epoch 25/100 completed. Loss: 0.052040
# Epoch 26/100 completed. Loss: 0.051915
# Epoch 27/100 completed. Loss: 0.051792
# Epoch 28/100 completed. Loss: 0.051659
# Epoch 29/100 completed. Loss: 0.051510
# Epoch 30/100 completed. Loss: 0.051358
# Epoch 31/100 completed. Loss: 0.051193
# Epoch 32/100 completed. Loss: 0.050953
# Epoch 33/100 completed. Loss: 0.050722
# Epoch 34/100 completed. Loss: 0.050517
# Epoch 35/100 completed. Loss: 0.050313
# Epoch 36/100 completed. Loss: 0.050152
# Epoch 37/100 completed. Loss: 0.050031
# Epoch 38/100 completed. Loss: 0.049897
# Epoch 39/100 completed. Loss: 0.049761
# Epoch 40/100 completed. Loss: 0.049645
# Epoch 41/100 completed. Loss: 0.049539
# Epoch 42/100 completed. Loss: 0.049376
# Epoch 43/100 completed. Loss: 0.049246
# Epoch 44/100 completed. Loss: 0.049173
# Epoch 45/100 completed. Loss: 0.049122
# Epoch 46/100 completed. Loss: 0.049101
# Epoch 47/100 completed. Loss: 0.049110
# Epoch 48/100 completed. Loss: 0.049112
# Epoch 49/100 completed. Loss: 0.049080
# Epoch 50/100 completed. Loss: 0.049032
# Epoch 51/100 completed. Loss: 0.048975
# Epoch 52/100 completed. Loss: 0.048911
# Epoch 53/100 completed. Loss: 0.048846
# Epoch 54/100 completed. Loss: 0.048766
# Epoch 55/100 completed. Loss: 0.048667
# Epoch 56/100 completed. Loss: 0.048546
# Epoch 57/100 completed. Loss: 0.048416
# Epoch 58/100 completed. Loss: 0.048285
# Epoch 59/100 completed. Loss: 0.048168
# Epoch 60/100 completed. Loss: 0.048092
# Epoch 61/100 completed. Loss: 0.048061
# Epoch 62/100 completed. Loss: 0.048045
# Epoch 63/100 completed. Loss: 0.048037
# Epoch 64/100 completed. Loss: 0.048026
# Epoch 65/100 completed. Loss: 0.048011
# Epoch 66/100 completed. Loss: 0.047987
# Epoch 67/100 completed. Loss: 0.047960
# Epoch 68/100 completed. Loss: 0.047939
# Epoch 69/100 completed. Loss: 0.047920
# Epoch 70/100 completed. Loss: 0.047900
# Epoch 71/100 completed. Loss: 0.047879
# Epoch 72/100 completed. Loss: 0.047855
# Epoch 73/100 completed. Loss: 0.047831
# Epoch 74/100 completed. Loss: 0.047807
# Epoch 75/100 completed. Loss: 0.047782
# Epoch 76/100 completed. Loss: 0.047756
# Epoch 77/100 completed. Loss: 0.047732
# Epoch 78/100 completed. Loss: 0.047712
# Epoch 79/100 completed. Loss: 0.047696
# Epoch 80/100 completed. Loss: 0.047684
# Epoch 81/100 completed. Loss: 0.047670
# Epoch 82/100 completed. Loss: 0.047668
# Epoch 83/100 completed. Loss: 0.047681
# Epoch 84/100 completed. Loss: 0.047712
# Epoch 85/100 completed. Loss: 0.047740
# Epoch 86/100 completed. Loss: 0.047758
# Epoch 87/100 completed. Loss: 0.047762
# Epoch 88/100 completed. Loss: 0.047745
# Epoch 89/100 completed. Loss: 0.047738
# Epoch 90/100 completed. Loss: 0.047755
# Epoch 91/100 completed. Loss: 0.047776
# Epoch 92/100 completed. Loss: 0.047791
# Epoch 93/100 completed. Loss: 0.047681
# Epoch 94/100 completed. Loss: 0.047658
# Epoch 95/100 completed. Loss: 0.047553
# Epoch 96/100 completed. Loss: 0.047450
# Epoch 97/100 completed. Loss: 0.047320
# Epoch 98/100 completed. Loss: 0.047192
# Epoch 99/100 completed. Loss: 0.047030
# Epoch 100/100 completed. Loss: 0.046888
# Training complete for run 6
# Month=1, Predicted=14.3062, Expected=13.9660
# Month=2, Predicted=14.2723, Expected=14.0040
# Month=3, Predicted=14.6284, Expected=15.3130
# Month=4, Predicted=15.9236, Expected=16.3570
# Month=5, Predicted=16.8290, Expected=17.7420
# Month=6, Predicted=18.0517, Expected=17.6090
# Month=7, Predicted=17.5185, Expected=17.2490
# Month=8, Predicted=16.8030, Expected=17.0780
# Month=9, Predicted=16.5210, Expected=16.5090
# Month=10, Predicted=15.9161, Expected=15.4650
# Month=11, Predicted=14.7873, Expected=14.7060
# Month=12, Predicted=14.7038, Expected=14.2130
# Month=13, Predicted=14.5664, Expected=13.6620
# Month=14, Predicted=13.9352, Expected=13.9280
# Month=15, Predicted=14.4700, Expected=14.5160
# Month=16, Predicted=15.0081, Expected=15.1800
# Month=17, Predicted=15.8138, Expected=15.3510
# Month=18, Predicted=15.7399, Expected=15.5790
# Month=19, Predicted=15.4621, Expected=15.4460
# Month=20, Predicted=15.0970, Expected=15.1990
# Month=21, Predicted=14.6881, Expected=14.7250
# Month=22, Predicted=14.1190, Expected=14.3830
# Month=23, Predicted=13.8420, Expected=14.2310
# Month=24, Predicted=14.1885, Expected=13.7760
# Month=25, Predicted=13.9922, Expected=13.1500
# Month=26, Predicted=13.5548, Expected=12.7130
# Month=27, Predicted=13.3567, Expected=13.2830
# Month=28, Predicted=13.6544, Expected=14.4780
# Month=29, Predicted=14.8880, Expected=14.8580
# Month=30, Predicted=14.8782, Expected=14.7820
# Month=31, Predicted=14.6801, Expected=14.3070
# Month=32, Predicted=14.0128, Expected=14.0230
# Month=33, Predicted=13.5811, Expected=13.5290
# Month=34, Predicted=12.9785, Expected=12.9220
# Month=35, Predicted=12.3608, Expected=12.4100
# Month=36, Predicted=12.2896, Expected=11.9360
# Month=37, Predicted=12.0969, Expected=11.7840
# Month=38, Predicted=12.2063, Expected=11.9920
# Month=39, Predicted=12.8001, Expected=12.6190
# Month=40, Predicted=12.9078, Expected=13.6620
# Month=41, Predicted=14.2558, Expected=14.2310
# Month=42, Predicted=14.5833, Expected=14.0990
# Month=43, Predicted=14.0171, Expected=13.8330
# Month=44, Predicted=13.6283, Expected=13.4160
# Month=45, Predicted=12.8513, Expected=12.9220
# Month=46, Predicted=12.2028, Expected=11.9740
# Month=47, Predicted=11.2756, Expected=11.4610
# Month=48, Predicted=11.0429, Expected=11.4230
# Month=49, Predicted=11.5254, Expected=11.8600
# Month=50, Predicted=11.7600, Expected=12.1630
# Month=51, Predicted=12.3888, Expected=13.2260
# Month=52, Predicted=13.9779, Expected=13.9660
# Month=53, Predicted=14.7333, Expected=14.5350
# Month=54, Predicted=14.9144, Expected=14.5160
# Month=55, Predicted=14.4600, Expected=14.2310
# Month=56, Predicted=13.9531, Expected=13.9660
# Month=57, Predicted=13.4611, Expected=13.7380
# Month=58, Predicted=13.1474, Expected=13.2260
# Month=59, Predicted=12.6624, Expected=12.9980
# Month=60, Predicted=12.7673, Expected=13.1310
# Run 6 — RMSE: 3.092525, MSE: 9.563713, NMSE: 0.0229778679
#
# ===== RUN 7/60 =====
# Epoch 1/100 completed. Loss: 0.105646
# Epoch 2/100 completed. Loss: 0.073579
# Epoch 3/100 completed. Loss: 0.066674
# Epoch 4/100 completed. Loss: 0.066041
# Epoch 5/100 completed. Loss: 0.066186
# Epoch 6/100 completed. Loss: 0.066276
# Epoch 7/100 completed. Loss: 0.066270
# Epoch 8/100 completed. Loss: 0.066238
# Epoch 9/100 completed. Loss: 0.066197
# Epoch 10/100 completed. Loss: 0.066146
# Epoch 11/100 completed. Loss: 0.066091
# Epoch 12/100 completed. Loss: 0.066035
# Epoch 79/100 completed. Loss: 0.055199
# Epoch 80/100 completed. Loss: 0.055078
# Epoch 81/100 completed. Loss: 0.054959
# Epoch 82/100 completed. Loss: 0.054841
# Epoch 83/100 completed. Loss: 0.054722
# Epoch 84/100 completed. Loss: 0.054598
# Epoch 85/100 completed. Loss: 0.054460
# Epoch 86/100 completed. Loss: 0.054300
# Epoch 87/100 completed. Loss: 0.054107
# Epoch 88/100 completed. Loss: 0.053890
# Epoch 89/100 completed. Loss: 0.053684
# Epoch 90/100 completed. Loss: 0.053490
# Epoch 91/100 completed. Loss: 0.053302
# Epoch 92/100 completed. Loss: 0.053114
# Epoch 93/100 completed. Loss: 0.052920
# Epoch 94/100 completed. Loss: 0.052722
# Epoch 95/100 completed. Loss: 0.052521
# Epoch 96/100 completed. Loss: 0.052324
# Epoch 97/100 completed. Loss: 0.052139
# Epoch 98/100 completed. Loss: 0.051960
# Epoch 99/100 completed. Loss: 0.051794
# Epoch 100/100 completed. Loss: 0.051639
# Training complete for run 7
# Month=1, Predicted=14.3586, Expected=13.9660
# Month=2, Predicted=14.6657, Expected=14.0040
# Month=3, Predicted=14.3883, Expected=15.3130
# Month=4, Predicted=15.7335, Expected=16.3570
# Month=5, Predicted=16.7200, Expected=17.7420
# Month=6, Predicted=17.9692, Expected=17.6090
# Month=7, Predicted=17.4381, Expected=17.2490
# Month=8, Predicted=16.8575, Expected=17.0780
# Month=9, Predicted=16.5542, Expected=16.5090
# Month=10, Predicted=15.9544, Expected=15.4650
# Month=11, Predicted=14.7657, Expected=14.7060
# Month=12, Predicted=14.6783, Expected=14.2130
# Month=13, Predicted=15.0553, Expected=13.6620
# Month=14, Predicted=13.9698, Expected=13.9280
# Month=15, Predicted=14.1224, Expected=14.5160
# Month=16, Predicted=14.6639, Expected=15.1800
# Month=17, Predicted=15.8559, Expected=15.3510
# Month=18, Predicted=15.6714, Expected=15.5790
# Month=19, Predicted=15.3811, Expected=15.4460
# Month=20, Predicted=15.1521, Expected=15.1990
# Month=21, Predicted=14.7359, Expected=14.7250
# Month=22, Predicted=14.1018, Expected=14.3830
# Month=23, Predicted=13.8813, Expected=14.2310
# Month=24, Predicted=14.1531, Expected=13.7760
# Month=25, Predicted=14.2362, Expected=13.1500
# Month=26, Predicted=13.5251, Expected=12.7130
# Month=27, Predicted=13.1149, Expected=13.2830
# Month=28, Predicted=13.3532, Expected=14.4780
# Month=29, Predicted=14.5858, Expected=14.8580
# Month=30, Predicted=14.7490, Expected=14.7820
# Month=31, Predicted=14.7095, Expected=14.3070
# Month=32, Predicted=14.1269, Expected=14.0230
# Month=33, Predicted=13.6384, Expected=13.5290
# Month=34, Predicted=12.9485, Expected=12.9220
# Month=35, Predicted=12.3231, Expected=12.4100
# Month=36, Predicted=12.1788, Expected=11.9360
# Month=37, Predicted=12.2670, Expected=11.7840
# Month=38, Predicted=12.1260, Expected=11.9920
# Month=39, Predicted=12.8375, Expected=12.6190
# Month=40, Predicted=12.7517, Expected=13.6620
# Month=41, Predicted=14.3335, Expected=14.2310
# Month=42, Predicted=14.6174, Expected=14.0990
# Month=43, Predicted=14.0700, Expected=13.8330
# Month=44, Predicted=13.6326, Expected=13.4160
# Month=45, Predicted=12.8901, Expected=12.9220
# Month=46, Predicted=12.0835, Expected=11.9740
# Month=47, Predicted=11.2556, Expected=11.4610
# Month=48, Predicted=11.0097, Expected=11.4230
# Month=49, Predicted=11.7351, Expected=11.8600
# Month=50, Predicted=11.8244, Expected=12.1630
# Month=51, Predicted=12.3620, Expected=13.2260
# Month=52, Predicted=13.7459, Expected=13.9660
# Month=53, Predicted=14.8804, Expected=14.5350
# Month=54, Predicted=14.9578, Expected=14.5160
# Month=55, Predicted=14.6842, Expected=14.2310
# Month=56, Predicted=14.0006, Expected=13.9660
# Month=57, Predicted=13.5419, Expected=13.7380
# Month=58, Predicted=13.2208, Expected=13.2260
# Month=59, Predicted=12.8011, Expected=12.9980
# Month=60, Predicted=12.8954, Expected=13.1310
# Run 7 — RMSE: 3.092712, MSE: 9.564866, NMSE: 0.0230398998
#
# ===== RUN 8/60 =====
# Epoch 1/100 completed. Loss: 0.085885
# Epoch 2/100 completed. Loss: 0.068679
# Epoch 3/100 completed. Loss: 0.063810
# Epoch 4/100 completed. Loss: 0.062957
# Epoch 5/100 completed. Loss: 0.062390
# Epoch 6/100 completed. Loss: 0.061646
# Epoch 7/100 completed. Loss: 0.060786
# Epoch 8/100 completed. Loss: 0.059863
# Epoch 9/100 completed. Loss: 0.058932
# Epoch 10/100 completed. Loss: 0.058037
# Epoch 11/100 completed. Loss: 0.057212
# Epoch 12/100 completed. Loss: 0.056449
# Epoch 13/100 completed. Loss: 0.055747
# Epoch 14/100 completed. Loss: 0.055083
# ...
# Month=11, Predicted=14.8341, Expected=14.7060
# Month=12, Predicted=14.5612, Expected=14.2130
# Month=13, Predicted=14.6326, Expected=13.6620
# Month=14, Predicted=14.0166, Expected=13.9280
# Month=15, Predicted=14.4573, Expected=14.5160
# Month=16, Predicted=15.0492, Expected=15.1800
# Month=17, Predicted=15.8246, Expected=15.3510
# Month=18, Predicted=15.6087, Expected=15.5790
# Month=19, Predicted=15.3816, Expected=15.4460
# Month=20, Predicted=15.1506, Expected=15.1990
# Month=21, Predicted=14.6694, Expected=14.7250
# Month=22, Predicted=14.1233, Expected=14.3830
# Month=23, Predicted=13.9493, Expected=14.2310
# Month=24, Predicted=14.0751, Expected=13.7760
# Month=25, Predicted=14.0379, Expected=13.1500
# Month=26, Predicted=13.6163, Expected=12.7130
# Month=27, Predicted=13.3715, Expected=13.2830
# Month=28, Predicted=13.6910, Expected=14.4780
# Month=29, Predicted=14.9355, Expected=14.8580
# Month=30, Predicted=14.9400, Expected=14.7820
# Month=31, Predicted=14.8111, Expected=14.3070
# Month=32, Predicted=14.0951, Expected=14.0230
# Month=33, Predicted=13.6287, Expected=13.5290
# Month=34, Predicted=13.0398, Expected=12.9220
# Month=35, Predicted=12.4965, Expected=12.4100
# Month=36, Predicted=12.2438, Expected=11.9360
# Month=37, Predicted=12.1548, Expected=11.7840
# Month=38, Predicted=12.1913, Expected=11.9920
# Month=39, Predicted=12.8151, Expected=12.6190
# Month=40, Predicted=12.9420, Expected=13.6620
# Month=41, Predicted=14.3267, Expected=14.2310
# Month=42, Predicted=14.4716, Expected=14.0990
# Month=43, Predicted=13.9533, Expected=13.8330
# Month=44, Predicted=13.5363, Expected=13.4160
# Month=45, Predicted=12.7591, Expected=12.9220
# Month=46, Predicted=12.1371, Expected=11.9740
# Month=47, Predicted=11.3090, Expected=11.4610
# Month=48, Predicted=11.0795, Expected=11.4230
# Month=49, Predicted=11.4785, Expected=11.8600
# Month=50, Predicted=11.8436, Expected=12.1630
# Month=51, Predicted=12.6178, Expected=13.2260
# Month=52, Predicted=13.9221, Expected=13.9660
# Month=53, Predicted=14.7921, Expected=14.5350
# Month=54, Predicted=14.9102, Expected=14.5160
# Month=55, Predicted=14.5752, Expected=14.2310
# Month=56, Predicted=13.9711, Expected=13.9660
# Month=57, Predicted=13.4372, Expected=13.7380
# Month=58, Predicted=13.1173, Expected=13.2260
# Month=59, Predicted=12.7141, Expected=12.9980
# Month=60, Predicted=12.7011, Expected=13.1310
# Run 58 — RMSE: 3.084658, MSE: 9.515115, NMSE: 0.0231348556
#
# ===== RUN 59/60 =====
# Epoch 1/100 completed. Loss: 0.126548
# Epoch 2/100 completed. Loss: 0.072125
# Epoch 3/100 completed. Loss: 0.066482
# Epoch 4/100 completed. Loss: 0.064659
# Epoch 5/100 completed. Loss: 0.064171
# Epoch 6/100 completed. Loss: 0.064026
# Epoch 7/100 completed. Loss: 0.063959
# Epoch 8/100 completed. Loss: 0.063899
# Epoch 9/100 completed. Loss: 0.063829
# Epoch 10/100 completed. Loss: 0.063748
# Epoch 11/100 completed. Loss: 0.063663
# Epoch 12/100 completed. Loss: 0.063578
# Epoch 13/100 completed. Loss: 0.063495
# Epoch 14/100 completed. Loss: 0.063416
# Epoch 15/100 completed. Loss: 0.063341
# Epoch 16/100 completed. Loss: 0.063266
# Epoch 17/100 completed. Loss: 0.063188
# Epoch 18/100 completed. Loss: 0.063102
# Epoch 19/100 completed. Loss: 0.063008
# Epoch 20/100 completed. Loss: 0.062913
# Epoch 21/100 completed. Loss: 0.062823
# Epoch 22/100 completed. Loss: 0.062743
# Epoch 23/100 completed. Loss: 0.062673
# Epoch 24/100 completed. Loss: 0.062610
# Epoch 25/100 completed. Loss: 0.062551
# Epoch 26/100 completed. Loss: 0.062495
# Epoch 27/100 completed. Loss: 0.062438
# Epoch 28/100 completed. Loss: 0.062379
# Epoch 29/100 completed. Loss: 0.062318
# Epoch 30/100 completed. Loss: 0.062254
# Epoch 31/100 completed. Loss: 0.062189
# Epoch 32/100 completed. Loss: 0.062123
# Epoch 33/100 completed. Loss: 0.062058
# Epoch 34/100 completed. Loss: 0.061992
# Epoch 35/100 completed. Loss: 0.061918
# Epoch 36/100 completed. Loss: 0.061827
# Epoch 37/100 completed. Loss: 0.061706
# Epoch 38/100 completed. Loss: 0.061526
# Epoch 39/100 completed. Loss: 0.061285
# Month=5, Predicted=16.7527, Expected=17.7420
# Month=6, Predicted=18.0072, Expected=17.6090
# Month=7, Predicted=17.6008, Expected=17.2490
# Month=8, Predicted=17.0322, Expected=17.0780
# Month=9, Predicted=16.6975, Expected=16.5090
# Month=10, Predicted=16.1093, Expected=15.4650
# Month=11, Predicted=14.8939, Expected=14.7060
# Month=12, Predicted=14.8588, Expected=14.2130
# Month=13, Predicted=15.0826, Expected=13.6620
# Month=14, Predicted=14.0202, Expected=13.9280
# Month=15, Predicted=14.2533, Expected=14.5160
# Month=16, Predicted=14.7821, Expected=15.1800
# Month=17, Predicted=15.7520, Expected=15.3510
# Month=18, Predicted=15.6371, Expected=15.5790
# Month=19, Predicted=15.5307, Expected=15.4460
# Month=20, Predicted=15.4009, Expected=15.1990
# Month=21, Predicted=14.9155, Expected=14.7250
# Month=22, Predicted=14.2733, Expected=14.3830
# Month=23, Predicted=14.0870, Expected=14.2310
# Month=24, Predicted=14.2498, Expected=13.7760
# Month=25, Predicted=14.2629, Expected=13.1500
# Month=26, Predicted=13.6314, Expected=12.7130
# Month=27, Predicted=13.2231, Expected=13.2830
# Month=28, Predicted=13.4443, Expected=14.4780
# Month=29, Predicted=14.8073, Expected=14.8580
# Month=30, Predicted=14.9293, Expected=14.7820
# Month=31, Predicted=14.9532, Expected=14.3070
# Month=32, Predicted=14.3449, Expected=14.0230
# Month=33, Predicted=13.8613, Expected=13.5290
# Month=34, Predicted=13.1681, Expected=12.9220
# Month=35, Predicted=12.5468, Expected=12.4100
# Month=36, Predicted=12.3200, Expected=11.9360
# Month=37, Predicted=12.2890, Expected=11.7840
# Month=38, Predicted=12.1737, Expected=11.9920
# Month=39, Predicted=12.8100, Expected=12.6190
# Month=40, Predicted=12.7667, Expected=13.6620
# Month=41, Predicted=14.3207, Expected=14.2310
# Month=42, Predicted=14.5668, Expected=14.0990
# Month=43, Predicted=14.1412, Expected=13.8330
# Month=44, Predicted=13.8485, Expected=13.4160
# Month=45, Predicted=13.0199, Expected=12.9220
# Month=46, Predicted=12.2085, Expected=11.9740
# Month=47, Predicted=11.3315, Expected=11.4610
# Month=48, Predicted=11.1912, Expected=11.4230
# Month=49, Predicted=11.7388, Expected=11.8600
# Month=50, Predicted=11.7462, Expected=12.1630
# Month=51, Predicted=12.4753, Expected=13.2260
# Month=52, Predicted=13.7357, Expected=13.9660
# Month=53, Predicted=14.7446, Expected=14.5350
# Month=54, Predicted=14.8775, Expected=14.5160
# Month=55, Predicted=14.6615, Expected=14.2310
# Month=56, Predicted=14.1734, Expected=13.9660
# Month=57, Predicted=13.6729, Expected=13.7380
# Month=58, Predicted=13.3345, Expected=13.2260
# Month=59, Predicted=12.9398, Expected=12.9980
# Month=60, Predicted=12.9455, Expected=13.1310
# Run 59 — RMSE: 3.032140, MSE: 9.193870, NMSE: 0.0235201589
#
# ===== RUN 60/60 =====
# Epoch 1/100 completed. Loss: 0.088579
# Epoch 2/100 completed. Loss: 0.077134
# Epoch 3/100 completed. Loss: 0.069340
# Epoch 71/100 completed. Loss: 0.053088
# Epoch 72/100 completed. Loss: 0.052976
# Epoch 73/100 completed. Loss: 0.052836
# Epoch 74/100 completed. Loss: 0.052669
# Epoch 75/100 completed. Loss: 0.052479
# Epoch 76/100 completed. Loss: 0.052270
# Epoch 77/100 completed. Loss: 0.052048
# Epoch 78/100 completed. Loss: 0.051822
# Epoch 79/100 completed. Loss: 0.051599
# Epoch 80/100 completed. Loss: 0.051390
# Epoch 81/100 completed. Loss: 0.051202
# Epoch 82/100 completed. Loss: 0.051043
# Epoch 83/100 completed. Loss: 0.050915
# Epoch 84/100 completed. Loss: 0.050819
# Epoch 85/100 completed. Loss: 0.050752
# Epoch 86/100 completed. Loss: 0.050711
# Epoch 87/100 completed. Loss: 0.050685
# Epoch 88/100 completed. Loss: 0.050667
# Epoch 89/100 completed. Loss: 0.050652
# Epoch 90/100 completed. Loss: 0.050635
# Epoch 91/100 completed. Loss: 0.050613
# Epoch 92/100 completed. Loss: 0.050583
# Epoch 93/100 completed. Loss: 0.050547
# Epoch 94/100 completed. Loss: 0.050514
# Epoch 95/100 completed. Loss: 0.050489
# Epoch 96/100 completed. Loss: 0.050479
# Epoch 97/100 completed. Loss: 0.050489
# Epoch 98/100 completed. Loss: 0.050518
# Epoch 99/100 completed. Loss: 0.050566
# Epoch 100/100 completed. Loss: 0.050628
# Training complete for run 60
# Month=1, Predicted=14.3416, Expected=13.9660
# Month=2, Predicted=14.5561, Expected=14.0040
# Month=3, Predicted=14.4597, Expected=15.3130
# Month=4, Predicted=15.8574, Expected=16.3570
# Month=5, Predicted=16.7848, Expected=17.7420
# Month=6, Predicted=18.0000, Expected=17.6090
# Month=7, Predicted=17.5459, Expected=17.2490
# Month=8, Predicted=16.9403, Expected=17.0780
# Month=9, Predicted=16.6077, Expected=16.5090
# Month=10, Predicted=16.0155, Expected=15.4650
# Month=11, Predicted=14.8657, Expected=14.7060
# Month=12, Predicted=14.6695, Expected=14.2130
# Month=13, Predicted=14.9012, Expected=13.6620
# Month=14, Predicted=13.9748, Expected=13.9280
# Month=15, Predicted=14.2398, Expected=14.5160
# Month=16, Predicted=14.8058, Expected=15.1800
# Month=17, Predicted=15.7213, Expected=15.3510
# Month=18, Predicted=15.5960, Expected=15.5790
# Month=19, Predicted=15.4573, Expected=15.4460
# Month=20, Predicted=15.2353, Expected=15.1990
# Month=21, Predicted=14.8046, Expected=14.7250
# Month=22, Predicted=14.2055, Expected=14.3830
# Month=23, Predicted=13.9894, Expected=14.2310
# Month=24, Predicted=14.1699, Expected=13.7760
# Month=25, Predicted=14.1879, Expected=13.1500
# Month=26, Predicted=13.5953, Expected=12.7130
# Month=27, Predicted=13.2171, Expected=13.2830
# Month=28, Predicted=13.4762, Expected=14.4780
# Month=29, Predicted=14.7580, Expected=14.8580
# Month=30, Predicted=14.8818, Expected=14.7820
# Month=31, Predicted=14.8385, Expected=14.3070
# Month=32, Predicted=14.2305, Expected=14.0230
# Month=33, Predicted=13.7825, Expected=13.5290
# Month=34, Predicted=13.1329, Expected=12.9220
# Month=35, Predicted=12.5059, Expected=12.4100
# Month=36, Predicted=12.2546, Expected=11.9360
# Month=37, Predicted=12.2388, Expected=11.7840
# Month=38, Predicted=12.1663, Expected=11.9920
# Month=39, Predicted=12.7699, Expected=12.6190
# Month=40, Predicted=12.8010, Expected=13.6620
# Month=41, Predicted=14.2365, Expected=14.2310
# Month=42, Predicted=14.4939, Expected=14.0990
# Month=43, Predicted=14.0428, Expected=13.8330
# Month=44, Predicted=13.6585, Expected=13.4160
# Month=45, Predicted=12.9037, Expected=12.9220
# Month=46, Predicted=12.1462, Expected=11.9740
# Month=47, Predicted=11.1989, Expected=11.4610
# Month=48, Predicted=11.0216, Expected=11.4230
# Month=49, Predicted=11.6246, Expected=11.8600
# Month=50, Predicted=11.8561, Expected=12.1630
# Month=51, Predicted=12.5392, Expected=13.2260
# Month=52, Predicted=13.8200, Expected=13.9660
# Month=53, Predicted=14.7652, Expected=14.5350
# Month=54, Predicted=14.9258, Expected=14.5160
# Month=55, Predicted=14.6335, Expected=14.2310
# Month=56, Predicted=14.0718, Expected=13.9660
# Month=57, Predicted=13.5699, Expected=13.7380
# Month=58, Predicted=13.2316, Expected=13.2260
# Month=59, Predicted=12.8177, Expected=12.9980
# Month=60, Predicted=12.8393, Expected=13.1310
# Run 60 — RMSE: 3.074597, MSE: 9.453145, NMSE: 0.0232617036
#
# --- σ=1.0 Summary ---
# RMSE: 3.074589 ± 0.015688
# MSE:  9.453342 ± 0.096128
# NMSE: 0.0232686913 ± 0.0001817883

# %% [markdown]
# ## Results

# %%
# ============================================================
# Summary: All Sigma Results Comparison
# ============================================================

print('\n' + '='*70)
print('  COMPLETE SIGMA SENSITIVITY ANALYSIS')
print('  σ values: 0.25, 0.5, 0.75, 1.0')
print('='*70)

print(f'\n{"σ":>6} | {"RMSE (mean ± std)":>25} | {"MSE (mean ± std)":>25} | {"NMSE (mean ± std)":>30}')
print('-'*95)

for sigma_val in SIGMA_VALUES:
    r = sigma_results[sigma_val]
    print(f'{sigma_val:>6.2f} | '
          f'{r["mean_rmse"]:>10.6f} ± {r["std_rmse"]:<10.6f} | '
          f'{r["mean_mse"]:>10.6f} ± {r["std_mse"]:<10.6f} | '
          f'{r["mean_nmse"]:>13.10f} ± {r["std_nmse"]:<13.10f}')

print('\n' + '-'*95)

# Find best sigma
best_sigma = min(SIGMA_VALUES, key=lambda s: sigma_results[s]['mean_rmse'])
print(f'\nBest σ (lowest mean RMSE): {best_sigma}')
print(f'  RMSE: {sigma_results[best_sigma]["mean_rmse"]:.6f} ± {sigma_results[best_sigma]["std_rmse"]:.6f}')
print(f'  MSE:  {sigma_results[best_sigma]["mean_mse"]:.6f} ± {sigma_results[best_sigma]["std_mse"]:.6f}')
print(f'  NMSE: {sigma_results[best_sigma]["mean_nmse"]:.10f} ± {sigma_results[best_sigma]["std_nmse"]:.10f}')

print('\n--- Per-Sigma Best Run Details ---')
for sigma_val in SIGMA_VALUES:
    r = sigma_results[sigma_val]
    print(f'  σ={sigma_val:.2f}: Best run #{r["best_idx"]+1}, RMSE={r["best_rmse"]:.6f}')
# Out:
# ======================================================================
#   COMPLETE SIGMA SENSITIVITY ANALYSIS
#   σ values: 0.25, 0.5, 0.75, 1.0
# ======================================================================
#
#      σ |         RMSE (mean ± std) |          MSE (mean ± std) |              NMSE (mean ± std)
# -----------------------------------------------------------------------------------------------
#   0.25 |   3.066647 ± 0.038840   |   9.405830 ± 0.232611   |  0.0232176061 ± 0.0003276278
#   0.50 |   3.068622 ± 0.028137   |   9.417231 ± 0.173716   |  0.0231875436 ± 0.0002288063
#   0.75 |   3.076027 ± 0.016397   |   9.462211 ± 0.100840   |  0.0231972264 ± 0.0001790908
#   1.00 |   3.074589 ± 0.015688   |   9.453342 ± 0.096128   |  0.0232686913 ± 0.0001817883
#
# -----------------------------------------------------------------------------------------------
#
# Best σ (lowest mean RMSE): 0.25
#   RMSE: 3.066647 ± 0.038840
#   MSE:  9.405830 ± 0.232611
#   NMSE: 0.0232176061 ± 0.0003276278
#
# --- Per-Sigma Best Run Details ---
#   σ=0.25: Best run #51, RMSE=2.829307
#   σ=0.50: Best run #46, RMSE=3.011751
#   σ=0.75: Best run #20, RMSE=3.040528
#   σ=1.00: Best run #52, RMSE=3.016990

# %%
# ============================================================
# Summary: All Sigma Results Comparison
# ============================================================

print('\n' + '='*70)
print('  COMPLETE SIGMA SENSITIVITY ANALYSIS')
print('  σ values: 0.25, 0.5, 0.75, 1.0')
print('='*70)

print(f'\n{"σ":>6} | {"RMSE (mean ± std)":>25} | {"MSE (mean ± std)":>25} | {"NMSE (mean ± std)":>30}')
print('-'*95)

for sigma_val in SIGMA_VALUES:
    r = sigma_results[sigma_val]
    print(f'{sigma_val:>6.2f} | '
          f'{r["mean_rmse"]:>10.6f} ± {r["std_rmse"]:<10.6f} | '
          f'{r["mean_mse"]:>10.6f} ± {r["std_mse"]:<10.6f} | '
          f'{r["mean_nmse"]:>13.10f} ± {r["std_nmse"]:<13.10f}')

print('\n' + '-'*95)

# Find best sigma
best_sigma = min(SIGMA_VALUES, key=lambda s: sigma_results[s]['mean_rmse'])
print(f'\nBest σ (lowest mean RMSE): {best_sigma}')
print(f'  RMSE: {sigma_results[best_sigma]["mean_rmse"]:.6f} ± {sigma_results[best_sigma]["std_rmse"]:.6f}')
print(f'  MSE:  {sigma_results[best_sigma]["mean_mse"]:.6f} ± {sigma_results[best_sigma]["std_mse"]:.6f}')
print(f'  NMSE: {sigma_results[best_sigma]["mean_nmse"]:.10f} ± {sigma_results[best_sigma]["std_nmse"]:.10f}')

print('\n--- Per-Sigma Best Run Details ---')
for sigma_val in SIGMA_VALUES:
    r = sigma_results[sigma_val]
    print(f'  σ={sigma_val:.2f}: Best run #{r["best_idx"]+1}, RMSE={r["best_rmse"]:.6f}')
# Out:
# ======================================================================
#   COMPLETE SIGMA SENSITIVITY ANALYSIS
#   σ values: 0.25, 0.5, 0.75, 1.0
# ======================================================================
#
#      σ |         RMSE (mean ± std) |          MSE (mean ± std) |              NMSE (mean ± std)
# -----------------------------------------------------------------------------------------------
#   0.25 |   3.066647 ± 0.038840   |   9.405830 ± 0.232611   |  0.0232176061 ± 0.0003276278
#   0.50 |   3.068622 ± 0.028137   |   9.417231 ± 0.173716   |  0.0231875436 ± 0.0002288063
#   0.75 |   3.076027 ± 0.016397   |   9.462211 ± 0.100840   |  0.0231972264 ± 0.0001790908
#   1.00 |   3.074589 ± 0.015688   |   9.453342 ± 0.096128   |  0.0232686913 ± 0.0001817883
#
# -----------------------------------------------------------------------------------------------
#
# Best σ (lowest mean RMSE): 0.25
#   RMSE: 3.066647 ± 0.038840
#   MSE:  9.405830 ± 0.232611
#   NMSE: 0.0232176061 ± 0.0003276278
#
# --- Per-Sigma Best Run Details ---
#   σ=0.25: Best run #51, RMSE=2.829307
#   σ=0.50: Best run #46, RMSE=3.011751
#   σ=0.75: Best run #20, RMSE=3.040528
#   σ=1.00: Best run #52, RMSE=3.016990

# %%
# Use best sigma's results for plotting
best_sigma_key = min(sigma_results.keys(), key=lambda s: sigma_results[s]['mean_rmse'])
best_sigma_data = sigma_results[best_sigma_key]
best_idx = best_sigma_data['best_idx']
all_predictions = best_sigma_data['predictions']
all_rmse = best_sigma_data['rmse']
all_mse = best_sigma_data['mse']
all_nmse = best_sigma_data['nmse']

# ============================================================
# Predictions vs Actual (Best Run)
# ============================================================

actual = raw_values[-60:]
best_predictions = all_predictions[best_idx]

plt.figure(figsize=(12, 5))
plt.plot(actual, label='Actual', color='blue', linewidth=1.5)
plt.plot(best_predictions, label='Predicted (Best Run)', color='red',
         linewidth=1.5, linestyle='--')
plt.title('Fuzzy Gate Replacement — Dow Jones Industrial Index\nPredictions vs Actual (Best of 1 run)')
plt.xlabel('Time Step')
plt.ylabel('Value')
plt.legend()
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

# ============================================================
# Loss Curve (Best Run)
# ============================================================

plt.figure(figsize=(12, 4))
plt.plot(all_losses[best_idx], color='green', linewidth=1.0)
plt.title('Fuzzy Gate Replacement — Dow Jones Industrial Index\nTraining Loss (Best Run)')
plt.xlabel('Epoch')
plt.ylabel('MSE Loss')
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

# ============================================================
# Final Metrics Summary
# ============================================================

print('=== Best Run Metrics ===')
print(f'RMSE: {all_rmse[best_idx]:.6f}')
print(f'MSE:  {all_mse[best_idx]:.6f}')
print(f'NMSE: {all_nmse[best_idx]:.10f}')
print(f'sMAPE: {all_smape[best_idx]:.6f}')
# Out:
# === Best Run Metrics ===
# RMSE: 2.829307
# MSE:  8.004981
# NMSE: 0.0252240754
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 50
#      46 print('=== Best Run Metrics ===')
#      47 print(f'RMSE: {all_rmse[best_idx]:.6f}')
#      48 print(f'MSE:  {all_mse[best_idx]:.6f}')
#      49 print(f'NMSE: {all_nmse[best_idx]:.10f}')
# ---> 50 print(f'sMAPE: {all_smape[best_idx]:.6f}')
#
# NameError: name 'all_smape' is not defined

# %%
print(best_sigma_data.keys())
# Out:
# dict_keys(['rmse', 'mse', 'nmse', 'predictions', 'mean_rmse', 'std_rmse', 'mean_mse', 'std_mse', 'mean_nmse', 'std_nmse', 'best_idx', 'best_rmse'])

# %%
# Use best sigma's results for plotting
best_sigma_key = min(sigma_results.keys(), key=lambda s: sigma_results[s]['mean_rmse'])
best_sigma_data = sigma_results[best_sigma_key]
best_idx = best_sigma_data['best_idx']
all_predictions = best_sigma_data['predictions']
all_rmse = best_sigma_data['rmse']
all_mse = best_sigma_data['mse']
all_nmse = best_sigma_data['nmse']

# ============================================================
# Predictions vs Actual (Best Run)
# ============================================================
actual = raw_values[-60:]
best_predictions = all_predictions[best_idx]

assert len(best_predictions) == len(actual), (
    f"Shape mismatch: predictions len={len(best_predictions)} vs actual len={len(actual)}"
)

plt.figure(figsize=(12, 5))
plt.plot(actual, label='Actual', color='blue', linewidth=1.5)
plt.plot(best_predictions, label='Predicted (Best Run)', color='red',
         linewidth=1.5, linestyle='--')
plt.title('Fuzzy Gate Replacement — Dow Jones Industrial Index\nPredictions vs Actual (Best of 1 run)')
plt.xlabel('Time Step')
plt.ylabel('Value')
plt.legend()
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

# ============================================================
# Loss Curve (Best Run)
# ============================================================
# NOTE: training loss history is not stored in sigma_results.
# If you captured per-epoch losses elsewhere during training
# (e.g. a list built inside the training loop for this sigma/run),
# substitute that variable here. Otherwise this plot must be skipped.
if 'all_losses' in dir():
    plt.figure(figsize=(12, 4))
    plt.plot(all_losses[best_idx], color='green', linewidth=1.0)
    plt.title('Fuzzy Gate Replacement — Dow Jones Industrial Index\nTraining Loss (Best Run)')
    plt.xlabel('Epoch')
    plt.ylabel('MSE Loss')
    plt.grid(True, alpha=0.3)
    plt.tight_layout()
    plt.show()
else:
    print("Skipping loss curve — no per-epoch loss history was stored for this run.")

# ============================================================
# Final Metrics Summary
# ============================================================
def smape(y_true, y_pred, eps=1e-8):
    y_true = np.asarray(y_true, dtype=float)
    y_pred = np.asarray(y_pred, dtype=float)
    denom = (np.abs(y_true) + np.abs(y_pred)) / 2.0 + eps
    return np.mean(np.abs(y_true - y_pred) / denom) * 100

best_smape = smape(actual, best_predictions)

print('=== Best Run Metrics ===')
print(f'RMSE: {all_rmse[best_idx]:.6f}')
print(f'MSE:  {all_mse[best_idx]:.6f}')
print(f'NMSE: {all_nmse[best_idx]:.10f}')
print(f'sMAPE: {best_smape:.6f}')
# Out:
# === Best Run Metrics ===
# RMSE: 2.829307
# MSE:  8.004981
# NMSE: 0.0252240754
# sMAPE: 15.986384

# %% [markdown]
# ## Observations
#
# ### Fuzzy Gate Replacement on Monthly Lake Erie Levels
#
# **Run the notebook to generate results and fill in observations:**
#
# 1. **Prediction Quality**: Compare RMSE/MSE/NMSE with other variants
# 2. **Training Stability**: Examine loss curves for convergence behavior
# 3. **Prediction Tracking**: Assess how well predictions track actual values
# 4. **Computational Cost**: Note training time per run
#
# *After running all 5 variant notebooks, perform cross-variant comparison to evaluate
# whether fuzzy logic improves nonlinearity handling, interpretability, and prediction performance.*

# %%
# ============================================================
# NOTEBOOK TIMER — END
# ============================================================
_NOTEBOOK_END_TIME = _timer_module.time()
_NOTEBOOK_ELAPSED = _NOTEBOOK_END_TIME - _NOTEBOOK_START_TIME
_hours, _rem = divmod(_NOTEBOOK_ELAPSED, 3600)
_minutes, _seconds = divmod(_rem, 60)
print(f"\nTotal notebook execution time: {int(_hours)}h {int(_minutes)}m {_seconds:.2f}s")
print(f"Total seconds: {_NOTEBOOK_ELAPSED:.2f}")
