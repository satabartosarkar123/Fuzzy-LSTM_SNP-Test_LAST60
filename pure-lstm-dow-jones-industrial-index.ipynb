# %% [markdown]
# # Pure LSTM — Dow Jones Industrial Index (Gaussian Noise Evaluation)
#
# Time series forecasting with Gaussian noise robustness analysis.
# - Noise levels: [0.0, 0.005, 0.05, 0.1]
# - 60 runs × 100 epochs per noise level
# - Last 60 for test, rest for training, NO validation

# %%
# ============================================================
# ALL IMPORTS
# ============================================================

import numpy as np
import pandas as pd
import torch
import torch.nn as nn
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from math import sqrt
import matplotlib.pyplot as plt
import warnings
import os

warnings.filterwarnings('ignore')
print(f"PyTorch version: {torch.__version__}")
print(f"NumPy version: {np.__version__}")
# Out:
# PyTorch version: 2.10.0+cu128
# NumPy version: 2.0.2

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

class PureLSTM(nn.Module):
    """
    Standard LSTM (Hochreiter & Schmidhuber, 1997) for time series forecasting.
    Stateful: maintains hidden and cell states across sequence steps.
    Same hyperparameters as LSTM-SNP for fair comparison.
    """
    def __init__(self, input_dim=1, hidden_dim=8, output_dim=1):
        super().__init__()
        self.hidden_dim = hidden_dim
        self.lstm = nn.LSTM(input_dim, hidden_dim, batch_first=True)
        self.fc = nn.Linear(hidden_dim, output_dim)
        self.u = None  # (h, c) state

    def reset_states(self, batch_size, device):
        h0 = torch.zeros(1, batch_size, self.hidden_dim, device=device)
        c0 = torch.zeros(1, batch_size, self.hidden_dim, device=device)
        self.u = (h0, c0)
        
    def detach_states(self):
        if self.u is not None:
            self.u = (self.u[0].detach(), self.u[1].detach())

    def forward(self, x):
        if self.u is None or self.u[0].device != x.device:
            self.reset_states(x.size(0), x.device)
            
        lstm_out, self.u = self.lstm(x, self.u)
        out = self.fc(lstm_out[:, -1, :])
        return out


def build_model(input_dim, units):
    return PureLSTM(input_dim=input_dim, hidden_dim=units, output_dim=1)

# %%
# Quick model check
model = build_model(input_dim=1, units=8)
print(model)
print(f"Total params: {sum(p.numel() for p in model.parameters())}")
# Out:
# PureLSTM(
#   (lstm): LSTM(1, 8, batch_first=True)
#   (fc): Linear(in_features=8, out_features=1, bias=True)
# )
# Total params: 361

# %% [markdown]
# ## Data Pipeline — Dow Jones Industrial Index

# %%
import os
for f in os.listdir('/kaggle/input/datasets/satabartosarkar123/monthly-closings-of-the-dowjones-csv'):
    print(f)
# Out:
# monthly-closings-of-the-dowjones.csv

# %%
# ============================================================
# 1. Load Time Series Data
# ============================================================
series = pd.read_csv(
    '/kaggle/input/datasets/satabartosarkar123/monthly-closings-of-the-dowjones-csv/monthly-closings-of-the-dowjones.csv',
    header=0,
    parse_dates=[0],
    index_col=0
)

original_raw_values = series.values.flatten()
print(f"Base data shape: {original_raw_values.shape}")
print(f"First 5 values: {original_raw_values[:5]}")
# Out:
# Base data shape: (291,)
# First 5 values: [3645.  3626.  3634.  3620.5 3607. ]

# %%
# ============================================================
# 2. First-Order Differencing
# ============================================================

def difference(dataset, interval=1):
    diff = []
    for i in range(interval, len(dataset)):
        value = dataset[i] - dataset[i - interval]
        diff.append(value)
    return np.array(diff)

# %%
# ============================================================
# 3. Convert to Supervised Learning Format (lag=1)
# ============================================================

def timeseries_to_supervised(data, lag=1):
    df = pd.DataFrame(data)
    columns = [df.shift(i) for i in range(1, lag+1)]
    columns.append(df)
    df = pd.concat(columns, axis=1)
    df.fillna(0, inplace=True)
    return df.values

# %% [markdown]
# ## Training Loop

# %%
# ============================================================
# Gaussian Noise Evaluation + 60-Run Experiment Protocol (PyTorch)
# ============================================================
import torch
import torch.nn as nn

s_x = np.std(original_raw_values)
noise_levels = [0.0, 0.005, 0.05, 0.1]
_molab_results = []

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"\n--- [PyTorch] RUNNING ON {device} ---\n")

for lam in noise_levels:
    sigma = lam * s_x
    print("\n" + "="*80)
    print(f"EVALUATING NOISE LEVEL: {lam*100:.1f}% (lambda={lam}, sigma={sigma:.6f})")
    print("="*80 + "\n")
    
    np.random.seed(42)
    torch.manual_seed(42)
    noise = np.random.normal(0, sigma, size=original_raw_values.shape)
    raw_values = original_raw_values + noise
    
    # 2. Difference
    diff_values = difference(raw_values, 1)
    # 3. Supervised (lag=1)
    supervised = timeseries_to_supervised(diff_values, 1)
    # 4. Split (Last 60 for test, NO validation)
    train, test = supervised[:-60], supervised[-60:]
    # 5. Scale
    scaler = MinMaxScaler(feature_range=(-1, 1))
    scaler.fit(train)
    train_scaled = scaler.transform(train)
    test_scaled = scaler.transform(test)
    # 6. Reshape
    X_train, y_train = train_scaled[:, 0:-1], train_scaled[:, -1]
    X_train = X_train.reshape((X_train.shape[0], 1, X_train.shape[1]))
    
    print(f"X_train shape: {X_train.shape}, y_train shape: {y_train.shape}")
    
    all_rmse = []
    all_mse = []
    all_nmse = []
    all_predictions = []
    all_losses = []
    
    for run in range(60):
        print(f'\n===== RUN {run+1}/60 [Noise {lam*100:.1f}%] =====')
        
        np.random.seed(run)
        torch.manual_seed(run)
        
        model = build_model(input_dim=1, units=8).to(device)
        optimizer = torch.optim.Adam(model.parameters(), lr=0.001)
        criterion = nn.MSELoss()
        
        # Pre-tensorize training data
        X_train_t = torch.tensor(X_train, dtype=torch.float32).to(device)
        y_train_t = torch.tensor(y_train, dtype=torch.float32).to(device)
        n_samples = X_train_t.size(0)
        
        run_losses = []
        for epoch in range(100):
            model.train()
            model.reset_states(1, device)
            
            epoch_loss = 0.0
            for i in range(n_samples):
                x_i = X_train_t[i:i+1]
                y_i = y_train_t[i:i+1]
                
                optimizer.zero_grad()
                pred = model(x_i)
                loss = criterion(pred.squeeze(-1), y_i)
                loss.backward()
                optimizer.step()
                model.detach_states()
                epoch_loss += loss.item()
            
            avg_loss = epoch_loss / n_samples
            run_losses.append(avg_loss)
            if (epoch+1) % 10 == 0:
                print(f"  Epoch {epoch+1}/100, Loss: {avg_loss:.6f}")
        
        all_losses.append(run_losses)
        print(f'Training complete for run {run+1}')
        
        # Warm-up: condition hidden states on training data
        model.eval()
        with torch.no_grad():
            model.reset_states(1, device)
            for i in range(len(train_scaled)):
                X_raw = train_scaled[i, 0:-1]
                X_input = torch.tensor(X_raw, dtype=torch.float32).view(1, 1, len(X_raw)).to(device)
                model(X_input)
        
        # Test predictions (single-step)
        predictions = []
        model.eval()
        with torch.no_grad():
            for i in range(len(test_scaled)):
                X = test_scaled[i, 0:-1]
                X_input = torch.tensor(X, dtype=torch.float32).view(1, 1, len(X)).to(device)
                yhat = model(X_input).item()
                
                # Invert scaling
                new_row = list(X) + [yhat]
                array = np.array(new_row).reshape(1, len(new_row))
                inverted = scaler.inverse_transform(array)[0, -1]
                
                # Invert differencing
                inverted = inverted + raw_values[len(train) + i]
                predictions.append(inverted)
        
        # Compute metrics
        actual = raw_values[-len(predictions):]
        rmse = sqrt(mean_squared_error(actual, predictions))
        mse = mean_squared_error(actual, predictions)
        meanV = np.mean(actual)
        dominator = np.linalg.norm(np.array(predictions) - meanV, 2)
        nmse = mse / np.power(dominator, 2)
        
        all_rmse.append(rmse)
        all_mse.append(mse)
        all_nmse.append(nmse)
        all_predictions.append(predictions)
        
        print(f'Run {run+1} \u2014 RMSE: {rmse:.6f}, MSE: {mse:.6f}, NMSE: {nmse:.10f}')
    
    # End of 60 runs for this noise level
    best_idx = np.argmin(all_rmse)
    
    print(f'\n===== STATS FOR NOISE {lam*100:.1f}% (60 runs) =====')
    print(f'RMSE: {np.mean(all_rmse):.6f} +/- {np.std(all_rmse):.6f}')
    print(f'MSE:  {np.mean(all_mse):.6f} +/- {np.std(all_mse):.6f}')
    print(f'NMSE: {np.mean(all_nmse):.10f} +/- {np.std(all_nmse):.10f}')
    print(f'Best run: {best_idx+1} (RMSE: {all_rmse[best_idx]:.6f})')
    
    _molab_results.append([lam, 
        np.mean(all_rmse), np.std(all_rmse),
        np.mean(all_mse), np.std(all_mse),
        np.mean(all_nmse), np.std(all_nmse),
        all_rmse[best_idx], all_predictions[best_idx], all_losses[best_idx], raw_values.copy()])
# Out:
# --- [PyTorch] RUNNING ON cuda ---
#
#
# ================================================================================
# EVALUATING NOISE LEVEL: 0.0% (lambda=0.0, sigma=0.000000)
# ================================================================================
#
# X_train shape: (230, 1, 1), y_train shape: (230,)
#
# ===== RUN 1/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.086202
#   Epoch 20/100, Loss: 0.085993
#   Epoch 30/100, Loss: 0.085887
#   Epoch 40/100, Loss: 0.085818
#   Epoch 50/100, Loss: 0.085768
#   Epoch 60/100, Loss: 0.085729
#   Epoch 70/100, Loss: 0.085696
#   Epoch 80/100, Loss: 0.085667
#   Epoch 90/100, Loss: 0.085642
#   Epoch 100/100, Loss: 0.085618
# Training complete for run 1
# Run 1 — RMSE: 24.405657, MSE: 595.636097, NMSE: 0.0027117777
#
# ===== RUN 2/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.085949
#   Epoch 20/100, Loss: 0.085842
#   Epoch 30/100, Loss: 0.085790
#   Epoch 40/100, Loss: 0.085726
#   Epoch 50/100, Loss: 0.085672
#   Epoch 60/100, Loss: 0.085620
#   Epoch 70/100, Loss: 0.085577
#   Epoch 80/100, Loss: 0.085542
#   Epoch 90/100, Loss: 0.085512
#   Epoch 100/100, Loss: 0.085489
# Training complete for run 2
# Run 2 — RMSE: 24.409921, MSE: 595.844249, NMSE: 0.0027155407
#
# ===== RUN 3/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.085809
#   Epoch 20/100, Loss: 0.085635
#   Epoch 30/100, Loss: 0.085535
#   Epoch 40/100, Loss: 0.085461
#   Epoch 50/100, Loss: 0.085404
#   Epoch 60/100, Loss: 0.085359
#   Epoch 70/100, Loss: 0.085322
#   Epoch 80/100, Loss: 0.085291
#   Epoch 90/100, Loss: 0.085262
#   Epoch 100/100, Loss: 0.085235
# Training complete for run 3
# Run 3 — RMSE: 24.374099, MSE: 594.096708, NMSE: 0.0027084335
#
# ===== RUN 4/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.086149
#   Epoch 20/100, Loss: 0.085991
#   Epoch 30/100, Loss: 0.085906
#   Epoch 40/100, Loss: 0.085851
#   Epoch 50/100, Loss: 0.085813
#   Epoch 60/100, Loss: 0.085779
#   Epoch 70/100, Loss: 0.085748
#   Epoch 80/100, Loss: 0.085718
#   Epoch 90/100, Loss: 0.085690
#   Epoch 100/100, Loss: 0.085664
# Training complete for run 4
# Run 4 — RMSE: 24.389145, MSE: 594.830398, NMSE: 0.0027199715
#
# ===== RUN 5/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.085850
#   Epoch 20/100, Loss: 0.085731
#   Epoch 30/100, Loss: 0.085649
#   Epoch 40/100, Loss: 0.085578
#   Epoch 50/100, Loss: 0.085516
#   Epoch 60/100, Loss: 0.085465
#   Epoch 70/100, Loss: 0.085422
#   Epoch 80/100, Loss: 0.085386
#   Epoch 90/100, Loss: 0.085358
#   Epoch 100/100, Loss: 0.085340
# Training complete for run 5
# Run 5 — RMSE: 24.440230, MSE: 597.324827, NMSE: 0.0027270092
#
# ===== RUN 6/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.085824
#   Epoch 20/100, Loss: 0.085699
#   Epoch 30/100, Loss: 0.085628
#   Epoch 40/100, Loss: 0.085576
#   Epoch 50/100, Loss: 0.085533
#   Epoch 60/100, Loss: 0.085501
#   Epoch 70/100, Loss: 0.085472
#   Epoch 80/100, Loss: 0.085449
#   Epoch 90/100, Loss: 0.085430
#   Epoch 100/100, Loss: 0.085414
# Training complete for run 6
# Run 6 — RMSE: 24.435433, MSE: 597.090404, NMSE: 0.0027177607
#
# ===== RUN 7/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.085695
#   Epoch 20/100, Loss: 0.085583
#   Epoch 30/100, Loss: 0.085501
#   Epoch 40/100, Loss: 0.085432
#   Epoch 50/100, Loss: 0.085380
#   Epoch 60/100, Loss: 0.085345
#   Epoch 70/100, Loss: 0.085316
#   Epoch 80/100, Loss: 0.085292
#   Epoch 90/100, Loss: 0.085274
#   Epoch 100/100, Loss: 0.085256
# Training complete for run 7
# Run 7 — RMSE: 24.396883, MSE: 595.207901, NMSE: 0.0027127658
#
# ===== RUN 8/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.085759
#   Epoch 20/100, Loss: 0.085561
#   Epoch 30/100, Loss: 0.085469
#   Epoch 40/100, Loss: 0.085416
#   Epoch 50/100, Loss: 0.085371
#   Epoch 60/100, Loss: 0.085338
#   Epoch 70/100, Loss: 0.085309
#   Epoch 80/100, Loss: 0.085284
#   Epoch 90/100, Loss: 0.085264
#   Epoch 100/100, Loss: 0.085247
# Training complete for run 8
# Run 8 — RMSE: 24.399991, MSE: 595.359579, NMSE: 0.0027067752
#
# ===== RUN 9/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.085589
#   Epoch 20/100, Loss: 0.085478
#   Epoch 30/100, Loss: 0.085412
#   Epoch 40/100, Loss: 0.085362
#   Epoch 50/100, Loss: 0.085322
#   Epoch 60/100, Loss: 0.085292
#   Epoch 70/100, Loss: 0.085267
#   Epoch 80/100, Loss: 0.085243
#   Epoch 90/100, Loss: 0.085224
#   Epoch 100/100, Loss: 0.085207
# Training complete for run 9
# Run 9 — RMSE: 24.403190, MSE: 595.515682, NMSE: 0.0027138976
#
# ===== RUN 10/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.085750
#   Epoch 20/100, Loss: 0.085600
#   Epoch 30/100, Loss: 0.085538
#   Epoch 40/100, Loss: 0.085506
#   Epoch 50/100, Loss: 0.085489
#   Epoch 60/100, Loss: 0.085474
#   Epoch 70/100, Loss: 0.085464
#   Epoch 80/100, Loss: 0.085446
#   Epoch 90/100, Loss: 0.085434
#   Epoch 100/100, Loss: 0.085420
# Training complete for run 10
# Run 10 — RMSE: 24.414594, MSE: 596.072422, NMSE: 0.0027147238
#
# ===== RUN 11/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.085461
#   Epoch 20/100, Loss: 0.085347
#   Epoch 30/100, Loss: 0.085291
#   Epoch 40/100, Loss: 0.085266
#   Epoch 50/100, Loss: 0.085250
#   Epoch 60/100, Loss: 0.085235
#   Epoch 70/100, Loss: 0.085219
#   Epoch 80/100, Loss: 0.085203
#   Epoch 90/100, Loss: 0.085187
#   Epoch 100/100, Loss: 0.085172
# Training complete for run 11
# Run 11 — RMSE: 24.395901, MSE: 595.159976, NMSE: 0.0027184651
#
# ===== RUN 12/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.086752
#   Epoch 20/100, Loss: 0.086229
#   Epoch 30/100, Loss: 0.086002
#   Epoch 40/100, Loss: 0.085867
#   Epoch 50/100, Loss: 0.085775
#   Epoch 60/100, Loss: 0.085711
#   Epoch 70/100, Loss: 0.085668
#   Epoch 80/100, Loss: 0.085632
#   Epoch 90/100, Loss: 0.085602
#   Epoch 100/100, Loss: 0.085577
# Training complete for run 12
# Run 12 — RMSE: 24.421065, MSE: 596.388419, NMSE: 0.0027205341
#
# ===== RUN 13/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.085794
#   Epoch 20/100, Loss: 0.085621
#   Epoch 30/100, Loss: 0.085523
#   Epoch 40/100, Loss: 0.085436
#   Epoch 50/100, Loss: 0.085366
#   Epoch 60/100, Loss: 0.085307
#   Epoch 70/100, Loss: 0.085258
#   Epoch 80/100, Loss: 0.085218
#   Epoch 90/100, Loss: 0.085186
#   Epoch 100/100, Loss: 0.085159
# Training complete for run 13
# Run 13 — RMSE: 24.386621, MSE: 594.707275, NMSE: 0.0027137142
#
# ===== RUN 14/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.085459
#   Epoch 20/100, Loss: 0.085378
#   Epoch 30/100, Loss: 0.085338
#   Epoch 40/100, Loss: 0.085317
#   Epoch 50/100, Loss: 0.085300
#   Epoch 60/100, Loss: 0.085279
#   Epoch 70/100, Loss: 0.085261
#   Epoch 80/100, Loss: 0.085245
#   Epoch 90/100, Loss: 0.085229
#   Epoch 100/100, Loss: 0.085215
# Training complete for run 14
# Run 14 — RMSE: 24.385608, MSE: 594.657870, NMSE: 0.0027032586
#
# ===== RUN 15/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.085834
#   Epoch 20/100, Loss: 0.085723
#   Epoch 30/100, Loss: 0.085647
#   Epoch 40/100, Loss: 0.085591
#   Epoch 50/100, Loss: 0.085549
#   Epoch 60/100, Loss: 0.085517
#   Epoch 70/100, Loss: 0.085496
#   Epoch 80/100, Loss: 0.085477
#   Epoch 90/100, Loss: 0.085459
#   Epoch 100/100, Loss: 0.085440
# Training complete for run 15
# Run 15 — RMSE: 24.412093, MSE: 595.950268, NMSE: 0.0027169153
#
# ===== RUN 16/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.085719
#   Epoch 20/100, Loss: 0.085563
#   Epoch 30/100, Loss: 0.085479
#   Epoch 40/100, Loss: 0.085420
#   Epoch 50/100, Loss: 0.085375
#   Epoch 60/100, Loss: 0.085341
#   Epoch 70/100, Loss: 0.085318
#   Epoch 80/100, Loss: 0.085296
#   Epoch 90/100, Loss: 0.085273
#   Epoch 100/100, Loss: 0.085253
# Training complete for run 16
# Run 16 — RMSE: 24.410387, MSE: 595.866991, NMSE: 0.0027202365
#
# ===== RUN 17/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.086154
#   Epoch 20/100, Loss: 0.086035
#   Epoch 30/100, Loss: 0.085935
#   Epoch 40/100, Loss: 0.085857
#   Epoch 50/100, Loss: 0.085790
#   Epoch 60/100, Loss: 0.085735
#   Epoch 70/100, Loss: 0.085687
#   Epoch 80/100, Loss: 0.085644
#   Epoch 90/100, Loss: 0.085604
#   Epoch 100/100, Loss: 0.085568
# Training complete for run 17
# Run 17 — RMSE: 24.405623, MSE: 595.634420, NMSE: 0.0027144144
#
# ===== RUN 18/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.085717
#   Epoch 20/100, Loss: 0.085589
#   Epoch 30/100, Loss: 0.085512
#   Epoch 40/100, Loss: 0.085464
#   Epoch 50/100, Loss: 0.085432
#   Epoch 60/100, Loss: 0.085402
#   Epoch 70/100, Loss: 0.085381
#   Epoch 80/100, Loss: 0.085361
#   Epoch 90/100, Loss: 0.085342
#   Epoch 100/100, Loss: 0.085334
# Training complete for run 18
# Run 18 — RMSE: 24.394804, MSE: 595.106479, NMSE: 0.0027099873
#
# ===== RUN 19/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.085682
#   Epoch 20/100, Loss: 0.085645
#   Epoch 30/100, Loss: 0.085617
#   Epoch 40/100, Loss: 0.085594
#   Epoch 50/100, Loss: 0.085575
#   Epoch 60/100, Loss: 0.085559
#   Epoch 70/100, Loss: 0.085537
#   Epoch 80/100, Loss: 0.085518
#   Epoch 90/100, Loss: 0.085500
#   Epoch 100/100, Loss: 0.085483
# Training complete for run 19
# Run 19 — RMSE: 24.408755, MSE: 595.787329, NMSE: 0.0027133587
#
# ===== RUN 20/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.086567
#   Epoch 20/100, Loss: 0.086162
#   Epoch 30/100, Loss: 0.085957
#   Epoch 40/100, Loss: 0.085837
#   Epoch 50/100, Loss: 0.085758
#   Epoch 60/100, Loss: 0.085701
#   Epoch 70/100, Loss: 0.085654
#   Epoch 80/100, Loss: 0.085619
#   Epoch 90/100, Loss: 0.085591
#   Epoch 100/100, Loss: 0.085567
# Training complete for run 20
# Run 20 — RMSE: 24.412977, MSE: 595.993429, NMSE: 0.0027218209
#
# ===== RUN 21/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.085626
#   Epoch 20/100, Loss: 0.085572
#   Epoch 30/100, Loss: 0.085550
#   Epoch 40/100, Loss: 0.085526
#   Epoch 50/100, Loss: 0.085507
#   Epoch 60/100, Loss: 0.085489
#   Epoch 70/100, Loss: 0.085472
#   Epoch 80/100, Loss: 0.085456
#   Epoch 90/100, Loss: 0.085442
#   Epoch 100/100, Loss: 0.085428
# Training complete for run 21
# Run 21 — RMSE: 24.422297, MSE: 596.448608, NMSE: 0.0027219512
#
# ===== RUN 22/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.085675
#   Epoch 20/100, Loss: 0.085519
#   Epoch 30/100, Loss: 0.085440
#   Epoch 40/100, Loss: 0.085388
#   Epoch 50/100, Loss: 0.085350
#   Epoch 60/100, Loss: 0.085318
#   Epoch 70/100, Loss: 0.085296
#   Epoch 80/100, Loss: 0.085276
#   Epoch 90/100, Loss: 0.085259
#   Epoch 100/100, Loss: 0.085244
# Training complete for run 22
# Run 22 — RMSE: 24.407662, MSE: 595.733952, NMSE: 0.0027210411
#
# ===== RUN 23/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.085759
#   Epoch 20/100, Loss: 0.085651
#   Epoch 30/100, Loss: 0.085568
#   Epoch 40/100, Loss: 0.085507
#   Epoch 50/100, Loss: 0.085469
#   Epoch 60/100, Loss: 0.085442
#   Epoch 70/100, Loss: 0.085415
#   Epoch 80/100, Loss: 0.085390
#   Epoch 90/100, Loss: 0.085367
#   Epoch 100/100, Loss: 0.085347
# Training complete for run 23
# Run 23 — RMSE: 24.421556, MSE: 596.412380, NMSE: 0.0027269434
#
# ===== RUN 24/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.085714
#   Epoch 20/100, Loss: 0.085570
#   Epoch 30/100, Loss: 0.085466
#   Epoch 40/100, Loss: 0.085383
#   Epoch 50/100, Loss: 0.085318
#   Epoch 60/100, Loss: 0.085269
#   Epoch 70/100, Loss: 0.085241
#   Epoch 80/100, Loss: 0.085231
#   Epoch 90/100, Loss: 0.085218
#   Epoch 100/100, Loss: 0.085207
# Training complete for run 24
# Run 24 — RMSE: 24.381352, MSE: 594.450346, NMSE: 0.0027121533
#
# ===== RUN 25/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.085508
#   Epoch 20/100, Loss: 0.085442
#   Epoch 30/100, Loss: 0.085398
#   Epoch 40/100, Loss: 0.085369
#   Epoch 50/100, Loss: 0.085343
#   Epoch 60/100, Loss: 0.085320
#   Epoch 70/100, Loss: 0.085300
#   Epoch 80/100, Loss: 0.085283
#   Epoch 90/100, Loss: 0.085267
#   Epoch 100/100, Loss: 0.085252
# Training complete for run 25
# Run 25 — RMSE: 24.399528, MSE: 595.336952, NMSE: 0.0027123896
#
# ===== RUN 26/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.085413
#   Epoch 20/100, Loss: 0.085313
#   Epoch 30/100, Loss: 0.085258
#   Epoch 40/100, Loss: 0.085230
#   Epoch 50/100, Loss: 0.085213
#   Epoch 60/100, Loss: 0.085200
#   Epoch 70/100, Loss: 0.085188
#   Epoch 80/100, Loss: 0.085171
#   Epoch 90/100, Loss: 0.085156
#   Epoch 100/100, Loss: 0.085141
# Training complete for run 26
# Run 26 — RMSE: 24.373682, MSE: 594.076375, NMSE: 0.0027082920
#
# ===== RUN 27/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.085751
#   Epoch 20/100, Loss: 0.085596
#   Epoch 30/100, Loss: 0.085533
#   Epoch 40/100, Loss: 0.085488
#   Epoch 50/100, Loss: 0.085445
#   Epoch 60/100, Loss: 0.085415
#   Epoch 70/100, Loss: 0.085388
#   Epoch 80/100, Loss: 0.085365
#   Epoch 90/100, Loss: 0.085352
#   Epoch 100/100, Loss: 0.085343
# Training complete for run 27
# Run 27 — RMSE: 24.429499, MSE: 596.800400, NMSE: 0.0027281025
#
# ===== RUN 28/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.085976
#   Epoch 20/100, Loss: 0.085775
#   Epoch 30/100, Loss: 0.085676
#   Epoch 40/100, Loss: 0.085605
#   Epoch 50/100, Loss: 0.085557
#   Epoch 60/100, Loss: 0.085521
#   Epoch 70/100, Loss: 0.085494
#   Epoch 80/100, Loss: 0.085473
#   Epoch 90/100, Loss: 0.085454
#   Epoch 100/100, Loss: 0.085440
# Training complete for run 28
# Run 28 — RMSE: 24.432894, MSE: 596.966309, NMSE: 0.0027276880
#
# ===== RUN 29/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.086277
#   Epoch 20/100, Loss: 0.085951
#   Epoch 30/100, Loss: 0.085797
#   Epoch 40/100, Loss: 0.085713
#   Epoch 50/100, Loss: 0.085654
#   Epoch 60/100, Loss: 0.085612
#   Epoch 70/100, Loss: 0.085585
#   Epoch 80/100, Loss: 0.085565
#   Epoch 90/100, Loss: 0.085550
#   Epoch 100/100, Loss: 0.085536
# Training complete for run 29
# Run 29 — RMSE: 24.406052, MSE: 595.655384, NMSE: 0.0027182097
#
# ===== RUN 30/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.085544
#   Epoch 20/100, Loss: 0.085433
#   Epoch 30/100, Loss: 0.085371
#   Epoch 40/100, Loss: 0.085325
#   Epoch 50/100, Loss: 0.085290
#   Epoch 60/100, Loss: 0.085262
#   Epoch 70/100, Loss: 0.085237
#   Epoch 80/100, Loss: 0.085218
#   Epoch 90/100, Loss: 0.085204
#   Epoch 100/100, Loss: 0.085191
# Training complete for run 30
# Run 30 — RMSE: 24.403615, MSE: 595.536447, NMSE: 0.0027197308
#
# ===== RUN 31/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.085724
#   Epoch 20/100, Loss: 0.085618
#   Epoch 30/100, Loss: 0.085562
#   Epoch 40/100, Loss: 0.085511
#   Epoch 50/100, Loss: 0.085467
#   Epoch 60/100, Loss: 0.085438
#   Epoch 70/100, Loss: 0.085417
#   Epoch 80/100, Loss: 0.085399
#   Epoch 90/100, Loss: 0.085381
#   Epoch 100/100, Loss: 0.085362
# Training complete for run 31
# Run 31 — RMSE: 24.425160, MSE: 596.588419, NMSE: 0.0027201863
#
# ===== RUN 32/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.085502
#   Epoch 20/100, Loss: 0.085445
#   Epoch 30/100, Loss: 0.085445
#   Epoch 40/100, Loss: 0.085433
#   Epoch 50/100, Loss: 0.085422
#   Epoch 60/100, Loss: 0.085397
#   Epoch 70/100, Loss: 0.085380
#   Epoch 80/100, Loss: 0.085369
#   Epoch 90/100, Loss: 0.085356
#   Epoch 100/100, Loss: 0.085342
# Training complete for run 32
# Run 32 — RMSE: 24.415039, MSE: 596.094122, NMSE: 0.0027197078
#
# ===== RUN 33/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.085573
#   Epoch 20/100, Loss: 0.085466
#   Epoch 30/100, Loss: 0.085418
#   Epoch 40/100, Loss: 0.085393
#   Epoch 50/100, Loss: 0.085377
#   Epoch 60/100, Loss: 0.085364
#   Epoch 70/100, Loss: 0.085355
#   Epoch 80/100, Loss: 0.085345
#   Epoch 90/100, Loss: 0.085338
#   Epoch 100/100, Loss: 0.085324
# Training complete for run 33
# Run 33 — RMSE: 24.392486, MSE: 594.993363, NMSE: 0.0027128894
#
# ===== RUN 34/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.085450
#   Epoch 20/100, Loss: 0.085374
#   Epoch 30/100, Loss: 0.085330
#   Epoch 40/100, Loss: 0.085295
#   Epoch 50/100, Loss: 0.085267
#   Epoch 60/100, Loss: 0.085242
#   Epoch 70/100, Loss: 0.085218
#   Epoch 80/100, Loss: 0.085196
#   Epoch 90/100, Loss: 0.085180
#   Epoch 100/100, Loss: 0.085169
# Training complete for run 34
# Run 34 — RMSE: 24.381933, MSE: 594.478665, NMSE: 0.0027123326
#
# ===== RUN 35/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.086360
#   Epoch 20/100, Loss: 0.086034
#   Epoch 30/100, Loss: 0.085893
#   Epoch 40/100, Loss: 0.085810
#   Epoch 50/100, Loss: 0.085748
#   Epoch 60/100, Loss: 0.085698
#   Epoch 70/100, Loss: 0.085657
#   Epoch 80/100, Loss: 0.085627
#   Epoch 90/100, Loss: 0.085599
#   Epoch 100/100, Loss: 0.085574
# Training complete for run 35
# Run 35 — RMSE: 24.419738, MSE: 596.323598, NMSE: 0.0027225177
#
# ===== RUN 36/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.085893
#   Epoch 20/100, Loss: 0.085658
#   Epoch 30/100, Loss: 0.085556
#   Epoch 40/100, Loss: 0.085491
#   Epoch 50/100, Loss: 0.085442
#   Epoch 60/100, Loss: 0.085400
#   Epoch 70/100, Loss: 0.085363
#   Epoch 80/100, Loss: 0.085331
#   Epoch 90/100, Loss: 0.085302
#   Epoch 100/100, Loss: 0.085278
# Training complete for run 36
# Run 36 — RMSE: 24.384975, MSE: 594.627029, NMSE: 0.0027067751
#
# ===== RUN 37/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.085528
#   Epoch 20/100, Loss: 0.085426
#   Epoch 30/100, Loss: 0.085354
#   Epoch 40/100, Loss: 0.085303
#   Epoch 50/100, Loss: 0.085271
#   Epoch 60/100, Loss: 0.085244
#   Epoch 70/100, Loss: 0.085225
#   Epoch 80/100, Loss: 0.085212
#   Epoch 90/100, Loss: 0.085199
#   Epoch 100/100, Loss: 0.085186
# Training complete for run 37
# Run 37 — RMSE: 24.397241, MSE: 595.225388, NMSE: 0.0027181682
#
# ===== RUN 38/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.085764
#   Epoch 20/100, Loss: 0.085637
#   Epoch 30/100, Loss: 0.085561
#   Epoch 40/100, Loss: 0.085504
#   Epoch 50/100, Loss: 0.085455
#   Epoch 60/100, Loss: 0.085417
#   Epoch 70/100, Loss: 0.085383
#   Epoch 80/100, Loss: 0.085350
#   Epoch 90/100, Loss: 0.085318
#   Epoch 100/100, Loss: 0.085288
# Training complete for run 38
# Run 38 — RMSE: 24.391968, MSE: 594.968105, NMSE: 0.0027123033
#
# ===== RUN 39/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.085832
#   Epoch 20/100, Loss: 0.085685
#   Epoch 30/100, Loss: 0.085579
#   Epoch 40/100, Loss: 0.085499
#   Epoch 50/100, Loss: 0.085440
#   Epoch 60/100, Loss: 0.085398
#   Epoch 70/100, Loss: 0.085371
#   Epoch 80/100, Loss: 0.085350
#   Epoch 90/100, Loss: 0.085338
#   Epoch 100/100, Loss: 0.085327
# Training complete for run 39
# Run 39 — RMSE: 24.420179, MSE: 596.345135, NMSE: 0.0027208217
#
# ===== RUN 40/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.085537
#   Epoch 20/100, Loss: 0.085433
#   Epoch 30/100, Loss: 0.085367
#   Epoch 40/100, Loss: 0.085320
#   Epoch 50/100, Loss: 0.085289
#   Epoch 60/100, Loss: 0.085264
#   Epoch 70/100, Loss: 0.085248
#   Epoch 80/100, Loss: 0.085234
#   Epoch 90/100, Loss: 0.085221
#   Epoch 100/100, Loss: 0.085207
# Training complete for run 40
# Run 40 — RMSE: 24.388956, MSE: 594.821153, NMSE: 0.0027118419
#
# ===== RUN 41/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.085671
#   Epoch 20/100, Loss: 0.085586
#   Epoch 30/100, Loss: 0.085529
#   Epoch 40/100, Loss: 0.085482
#   Epoch 50/100, Loss: 0.085443
#   Epoch 60/100, Loss: 0.085409
#   Epoch 70/100, Loss: 0.085382
#   Epoch 80/100, Loss: 0.085358
#   Epoch 90/100, Loss: 0.085333
#   Epoch 100/100, Loss: 0.085311
# Training complete for run 41
# Run 41 — RMSE: 24.359864, MSE: 593.402996, NMSE: 0.0027059023
#
# ===== RUN 42/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.085471
#   Epoch 20/100, Loss: 0.085366
#   Epoch 30/100, Loss: 0.085332
#   Epoch 40/100, Loss: 0.085311
#   Epoch 50/100, Loss: 0.085292
#   Epoch 60/100, Loss: 0.085279
#   Epoch 70/100, Loss: 0.085267
#   Epoch 80/100, Loss: 0.085258
#   Epoch 90/100, Loss: 0.085248
#   Epoch 100/100, Loss: 0.085239
# Training complete for run 42
# Run 42 — RMSE: 24.408103, MSE: 595.755507, NMSE: 0.0027118631
#
# ===== RUN 43/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.085654
#   Epoch 20/100, Loss: 0.085536
#   Epoch 30/100, Loss: 0.085464
#   Epoch 40/100, Loss: 0.085411
#   Epoch 50/100, Loss: 0.085370
#   Epoch 60/100, Loss: 0.085337
#   Epoch 70/100, Loss: 0.085307
#   Epoch 80/100, Loss: 0.085285
#   Epoch 90/100, Loss: 0.085263
#   Epoch 100/100, Loss: 0.085245
# Training complete for run 43
# Run 43 — RMSE: 24.428822, MSE: 596.767320, NMSE: 0.0027223183
#
# ===== RUN 44/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.085587
#   Epoch 20/100, Loss: 0.085473
#   Epoch 30/100, Loss: 0.085438
#   Epoch 40/100, Loss: 0.085400
#   Epoch 50/100, Loss: 0.085372
#   Epoch 60/100, Loss: 0.085345
#   Epoch 70/100, Loss: 0.085321
#   Epoch 80/100, Loss: 0.085301
#   Epoch 90/100, Loss: 0.085281
#   Epoch 100/100, Loss: 0.085261
# Training complete for run 44
# Run 44 — RMSE: 24.379818, MSE: 594.375514, NMSE: 0.0027108413
#
# ===== RUN 45/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.086137
#   Epoch 20/100, Loss: 0.085955
#   Epoch 30/100, Loss: 0.085854
#   Epoch 40/100, Loss: 0.085780
#   Epoch 50/100, Loss: 0.085722
#   Epoch 60/100, Loss: 0.085676
#   Epoch 70/100, Loss: 0.085640
#   Epoch 80/100, Loss: 0.085610
#   Epoch 90/100, Loss: 0.085586
#   Epoch 100/100, Loss: 0.085562
# Training complete for run 45
# Run 45 — RMSE: 24.438924, MSE: 597.261011, NMSE: 0.0027258545
#
# ===== RUN 46/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.085829
#   Epoch 20/100, Loss: 0.085729
#   Epoch 30/100, Loss: 0.085665
#   Epoch 40/100, Loss: 0.085617
#   Epoch 50/100, Loss: 0.085579
#   Epoch 60/100, Loss: 0.085546
#   Epoch 70/100, Loss: 0.085510
#   Epoch 80/100, Loss: 0.085476
#   Epoch 90/100, Loss: 0.085444
#   Epoch 100/100, Loss: 0.085409
# Training complete for run 46
# Run 46 — RMSE: 24.402307, MSE: 595.472606, NMSE: 0.0027154875
#
# ===== RUN 47/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.085729
#   Epoch 20/100, Loss: 0.085648
#   Epoch 30/100, Loss: 0.085586
#   Epoch 40/100, Loss: 0.085536
#   Epoch 50/100, Loss: 0.085493
#   Epoch 60/100, Loss: 0.085455
#   Epoch 70/100, Loss: 0.085420
#   Epoch 80/100, Loss: 0.085391
#   Epoch 90/100, Loss: 0.085370
#   Epoch 100/100, Loss: 0.085351
# Training complete for run 47
# Run 47 — RMSE: 24.429006, MSE: 596.776336, NMSE: 0.0027188579
#
# ===== RUN 48/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.085591
#   Epoch 20/100, Loss: 0.085551
#   Epoch 30/100, Loss: 0.085521
#   Epoch 40/100, Loss: 0.085497
#   Epoch 50/100, Loss: 0.085472
#   Epoch 60/100, Loss: 0.085448
#   Epoch 70/100, Loss: 0.085430
#   Epoch 80/100, Loss: 0.085412
#   Epoch 90/100, Loss: 0.085392
#   Epoch 100/100, Loss: 0.085374
# Training complete for run 48
# Run 48 — RMSE: 24.399767, MSE: 595.348651, NMSE: 0.0027118961
#
# ===== RUN 49/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.085944
#   Epoch 20/100, Loss: 0.085706
#   Epoch 30/100, Loss: 0.085614
#   Epoch 40/100, Loss: 0.085548
#   Epoch 50/100, Loss: 0.085493
#   Epoch 60/100, Loss: 0.085443
#   Epoch 70/100, Loss: 0.085403
#   Epoch 80/100, Loss: 0.085369
#   Epoch 90/100, Loss: 0.085342
#   Epoch 100/100, Loss: 0.085323
# Training complete for run 49
# Run 49 — RMSE: 24.408131, MSE: 595.756864, NMSE: 0.0027214002
#
# ===== RUN 50/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.086128
#   Epoch 20/100, Loss: 0.085944
#   Epoch 30/100, Loss: 0.085825
#   Epoch 40/100, Loss: 0.085741
#   Epoch 50/100, Loss: 0.085682
#   Epoch 60/100, Loss: 0.085623
#   Epoch 70/100, Loss: 0.085575
#   Epoch 80/100, Loss: 0.085540
#   Epoch 90/100, Loss: 0.085509
#   Epoch 100/100, Loss: 0.085485
# Training complete for run 50
# Run 50 — RMSE: 24.406317, MSE: 595.668288, NMSE: 0.0027217505
#
# ===== RUN 51/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.086361
#   Epoch 20/100, Loss: 0.086076
#   Epoch 30/100, Loss: 0.085917
#   Epoch 40/100, Loss: 0.085816
#   Epoch 50/100, Loss: 0.085745
#   Epoch 60/100, Loss: 0.085693
#   Epoch 70/100, Loss: 0.085662
#   Epoch 80/100, Loss: 0.085636
#   Epoch 90/100, Loss: 0.085613
#   Epoch 100/100, Loss: 0.085595
# Training complete for run 51
# Run 51 — RMSE: 24.429174, MSE: 596.784530, NMSE: 0.0027244249
#
# ===== RUN 52/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.085559
#   Epoch 20/100, Loss: 0.085470
#   Epoch 30/100, Loss: 0.085426
#   Epoch 40/100, Loss: 0.085385
#   Epoch 50/100, Loss: 0.085354
#   Epoch 60/100, Loss: 0.085327
#   Epoch 70/100, Loss: 0.085304
#   Epoch 80/100, Loss: 0.085282
#   Epoch 90/100, Loss: 0.085260
#   Epoch 100/100, Loss: 0.085236
# Training complete for run 52
# Run 52 — RMSE: 24.392102, MSE: 594.974623, NMSE: 0.0027121811
#
# ===== RUN 53/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.085636
#   Epoch 20/100, Loss: 0.085561
#   Epoch 30/100, Loss: 0.085500
#   Epoch 40/100, Loss: 0.085450
#   Epoch 50/100, Loss: 0.085408
#   Epoch 60/100, Loss: 0.085383
#   Epoch 70/100, Loss: 0.085358
#   Epoch 80/100, Loss: 0.085338
#   Epoch 90/100, Loss: 0.085320
#   Epoch 100/100, Loss: 0.085307
# Training complete for run 53
# Run 53 — RMSE: 24.414054, MSE: 596.046047, NMSE: 0.0027116305
#
# ===== RUN 54/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.085985
#   Epoch 20/100, Loss: 0.085752
#   Epoch 30/100, Loss: 0.085664
#   Epoch 40/100, Loss: 0.085615
#   Epoch 50/100, Loss: 0.085576
#   Epoch 60/100, Loss: 0.085541
#   Epoch 70/100, Loss: 0.085506
#   Epoch 80/100, Loss: 0.085475
#   Epoch 90/100, Loss: 0.085446
#   Epoch 100/100, Loss: 0.085421
# Training complete for run 54
# Run 54 — RMSE: 24.411587, MSE: 595.925557, NMSE: 0.0027236938
#
# ===== RUN 55/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.085774
#   Epoch 20/100, Loss: 0.085703
#   Epoch 30/100, Loss: 0.085656
#   Epoch 40/100, Loss: 0.085623
#   Epoch 50/100, Loss: 0.085597
#   Epoch 60/100, Loss: 0.085557
#   Epoch 70/100, Loss: 0.085524
#   Epoch 80/100, Loss: 0.085496
#   Epoch 90/100, Loss: 0.085467
#   Epoch 100/100, Loss: 0.085440
# Training complete for run 55
# Run 55 — RMSE: 24.419423, MSE: 596.308226, NMSE: 0.0027212898
#
# ===== RUN 56/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.085790
#   Epoch 20/100, Loss: 0.085683
#   Epoch 30/100, Loss: 0.085617
#   Epoch 40/100, Loss: 0.085565
#   Epoch 50/100, Loss: 0.085521
#   Epoch 60/100, Loss: 0.085484
#   Epoch 70/100, Loss: 0.085453
#   Epoch 80/100, Loss: 0.085433
#   Epoch 90/100, Loss: 0.085407
#   Epoch 100/100, Loss: 0.085390
# Training complete for run 56
# Run 56 — RMSE: 24.361537, MSE: 593.484509, NMSE: 0.0027024817
#
# ===== RUN 57/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.085762
#   Epoch 20/100, Loss: 0.085640
#   Epoch 30/100, Loss: 0.085564
#   Epoch 40/100, Loss: 0.085516
#   Epoch 50/100, Loss: 0.085471
#   Epoch 60/100, Loss: 0.085450
#   Epoch 70/100, Loss: 0.085429
#   Epoch 80/100, Loss: 0.085416
#   Epoch 90/100, Loss: 0.085408
#   Epoch 100/100, Loss: 0.085396
# Training complete for run 57
# Run 57 — RMSE: 24.411663, MSE: 595.929315, NMSE: 0.0027220256
#
# ===== RUN 58/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.085685
#   Epoch 20/100, Loss: 0.085552
#   Epoch 30/100, Loss: 0.085482
#   Epoch 40/100, Loss: 0.085436
#   Epoch 50/100, Loss: 0.085407
#   Epoch 60/100, Loss: 0.085385
#   Epoch 70/100, Loss: 0.085369
#   Epoch 80/100, Loss: 0.085352
#   Epoch 90/100, Loss: 0.085337
#   Epoch 100/100, Loss: 0.085324
# Training complete for run 58
# Run 58 — RMSE: 24.413365, MSE: 596.012407, NMSE: 0.0027148027
#
# ===== RUN 59/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.085577
#   Epoch 20/100, Loss: 0.085529
#   Epoch 30/100, Loss: 0.085485
#   Epoch 40/100, Loss: 0.085448
#   Epoch 50/100, Loss: 0.085414
#   Epoch 60/100, Loss: 0.085384
#   Epoch 70/100, Loss: 0.085359
#   Epoch 80/100, Loss: 0.085338
#   Epoch 90/100, Loss: 0.085316
#   Epoch 100/100, Loss: 0.085295
# Training complete for run 59
# Run 59 — RMSE: 24.409425, MSE: 595.820023, NMSE: 0.0027127770
#
# ===== RUN 60/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.085531
#   Epoch 20/100, Loss: 0.085486
#   Epoch 30/100, Loss: 0.085457
#   Epoch 40/100, Loss: 0.085438
#   Epoch 50/100, Loss: 0.085415
#   Epoch 60/100, Loss: 0.085395
#   Epoch 70/100, Loss: 0.085376
#   Epoch 80/100, Loss: 0.085360
#   Epoch 90/100, Loss: 0.085345
#   Epoch 100/100, Loss: 0.085332
# Training complete for run 60
# Run 60 — RMSE: 24.368441, MSE: 593.820939, NMSE: 0.0027009031
#
# ===== STATS FOR NOISE 0.0% (60 runs) =====
# RMSE: 24.404844 +/- 0.018452
# MSE:  595.596735 +/- 0.900509
# NMSE: 0.0027161298 +/- 0.0000063769
# Best run: 41 (RMSE: 24.359864)
#
# ================================================================================
# EVALUATING NOISE LEVEL: 0.5% (lambda=0.005, sigma=0.526428)
# ================================================================================
#
# X_train shape: (230, 1, 1), y_train shape: (230,)
#
# ===== RUN 1/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.087775
#   Epoch 20/100, Loss: 0.087556
#   Epoch 30/100, Loss: 0.087446
#   Epoch 40/100, Loss: 0.087374
#   Epoch 50/100, Loss: 0.087322
#   Epoch 60/100, Loss: 0.087281
#   Epoch 70/100, Loss: 0.087247
#   Epoch 80/100, Loss: 0.087217
#   Epoch 90/100, Loss: 0.087191
#   Epoch 100/100, Loss: 0.087167
# Training complete for run 1
# Run 1 — RMSE: 24.442917, MSE: 597.456205, NMSE: 0.0027208389
#
# ===== RUN 2/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.087518
#   Epoch 20/100, Loss: 0.087400
#   Epoch 30/100, Loss: 0.087345
#   Epoch 40/100, Loss: 0.087277
#   Epoch 50/100, Loss: 0.087222
#   Epoch 60/100, Loss: 0.087169
#   Epoch 70/100, Loss: 0.087125
#   Epoch 80/100, Loss: 0.087089
#   Epoch 90/100, Loss: 0.087058
#   Epoch 100/100, Loss: 0.087035
# Training complete for run 2
# Run 2 — RMSE: 24.444793, MSE: 597.547915, NMSE: 0.0027240695
#
# ===== RUN 3/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.087345
#   Epoch 20/100, Loss: 0.087172
#   Epoch 30/100, Loss: 0.087072
#   Epoch 40/100, Loss: 0.086998
#   Epoch 50/100, Loss: 0.086940
#   Epoch 60/100, Loss: 0.086895
#   Epoch 70/100, Loss: 0.086857
#   Epoch 80/100, Loss: 0.086826
#   Epoch 90/100, Loss: 0.086796
#   Epoch 100/100, Loss: 0.086769
# Training complete for run 3
# Run 3 — RMSE: 24.406572, MSE: 595.680781, NMSE: 0.0027164278
#
# ===== RUN 4/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.087718
#   Epoch 20/100, Loss: 0.087551
#   Epoch 30/100, Loss: 0.087462
#   Epoch 40/100, Loss: 0.087403
#   Epoch 50/100, Loss: 0.087363
#   Epoch 60/100, Loss: 0.087328
#   Epoch 70/100, Loss: 0.087296
#   Epoch 80/100, Loss: 0.087265
#   Epoch 90/100, Loss: 0.087237
#   Epoch 100/100, Loss: 0.087210
# Training complete for run 4
# Run 4 — RMSE: 24.423377, MSE: 596.501327, NMSE: 0.0027286707
#
# ===== RUN 5/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.087411
#   Epoch 20/100, Loss: 0.087284
#   Epoch 30/100, Loss: 0.087197
#   Epoch 40/100, Loss: 0.087124
#   Epoch 50/100, Loss: 0.087061
#   Epoch 60/100, Loss: 0.087010
#   Epoch 70/100, Loss: 0.086966
#   Epoch 80/100, Loss: 0.086929
#   Epoch 90/100, Loss: 0.086900
#   Epoch 100/100, Loss: 0.086882
# Training complete for run 5
# Run 5 — RMSE: 24.475383, MSE: 599.044396, NMSE: 0.0027351743
#
# ===== RUN 6/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.087381
#   Epoch 20/100, Loss: 0.087254
#   Epoch 30/100, Loss: 0.087182
#   Epoch 40/100, Loss: 0.087128
#   Epoch 50/100, Loss: 0.087085
#   Epoch 60/100, Loss: 0.087051
#   Epoch 70/100, Loss: 0.087023
#   Epoch 80/100, Loss: 0.086999
#   Epoch 90/100, Loss: 0.086979
#   Epoch 100/100, Loss: 0.086963
# Training complete for run 6
# Run 6 — RMSE: 24.471517, MSE: 598.855138, NMSE: 0.0027266104
#
# ===== RUN 7/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.087240
#   Epoch 20/100, Loss: 0.087131
#   Epoch 30/100, Loss: 0.087049
#   Epoch 40/100, Loss: 0.086981
#   Epoch 50/100, Loss: 0.086929
#   Epoch 60/100, Loss: 0.086895
#   Epoch 70/100, Loss: 0.086864
#   Epoch 80/100, Loss: 0.086838
#   Epoch 90/100, Loss: 0.086821
#   Epoch 100/100, Loss: 0.086804
# Training complete for run 7
# Run 7 — RMSE: 24.433843, MSE: 597.012681, NMSE: 0.0027212077
#
# ===== RUN 8/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.087290
#   Epoch 20/100, Loss: 0.087096
#   Epoch 30/100, Loss: 0.087006
#   Epoch 40/100, Loss: 0.086953
#   Epoch 50/100, Loss: 0.086910
#   Epoch 60/100, Loss: 0.086876
#   Epoch 70/100, Loss: 0.086846
#   Epoch 80/100, Loss: 0.086821
#   Epoch 90/100, Loss: 0.086800
#   Epoch 100/100, Loss: 0.086783
# Training complete for run 8
# Run 8 — RMSE: 24.436202, MSE: 597.127976, NMSE: 0.0027149560
#
# ===== RUN 9/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.087138
#   Epoch 20/100, Loss: 0.087028
#   Epoch 30/100, Loss: 0.086961
#   Epoch 40/100, Loss: 0.086910
#   Epoch 50/100, Loss: 0.086869
#   Epoch 60/100, Loss: 0.086837
#   Epoch 70/100, Loss: 0.086811
#   Epoch 80/100, Loss: 0.086788
#   Epoch 90/100, Loss: 0.086768
#   Epoch 100/100, Loss: 0.086751
# Training complete for run 9
# Run 9 — RMSE: 24.439700, MSE: 597.298941, NMSE: 0.0027224110
#
# ===== RUN 10/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.087320
#   Epoch 20/100, Loss: 0.087159
#   Epoch 30/100, Loss: 0.087092
#   Epoch 40/100, Loss: 0.087058
#   Epoch 50/100, Loss: 0.087039
#   Epoch 60/100, Loss: 0.087025
#   Epoch 70/100, Loss: 0.087015
#   Epoch 80/100, Loss: 0.086997
#   Epoch 90/100, Loss: 0.086984
#   Epoch 100/100, Loss: 0.086970
# Training complete for run 10
# Run 10 — RMSE: 24.451589, MSE: 597.880199, NMSE: 0.0027232139
#
# ===== RUN 11/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.087011
#   Epoch 20/100, Loss: 0.086894
#   Epoch 30/100, Loss: 0.086836
#   Epoch 40/100, Loss: 0.086806
#   Epoch 50/100, Loss: 0.086790
#   Epoch 60/100, Loss: 0.086774
#   Epoch 70/100, Loss: 0.086759
#   Epoch 80/100, Loss: 0.086743
#   Epoch 90/100, Loss: 0.086728
#   Epoch 100/100, Loss: 0.086713
# Training complete for run 11
# Run 11 — RMSE: 24.431013, MSE: 596.874420, NMSE: 0.0027268056
#
# ===== RUN 12/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.088327
#   Epoch 20/100, Loss: 0.087790
#   Epoch 30/100, Loss: 0.087558
#   Epoch 40/100, Loss: 0.087420
#   Epoch 50/100, Loss: 0.087327
#   Epoch 60/100, Loss: 0.087261
#   Epoch 70/100, Loss: 0.087217
#   Epoch 80/100, Loss: 0.087181
#   Epoch 90/100, Loss: 0.087151
#   Epoch 100/100, Loss: 0.087125
# Training complete for run 12
# Run 12 — RMSE: 24.457042, MSE: 598.146909, NMSE: 0.0027289050
#
# ===== RUN 13/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.087327
#   Epoch 20/100, Loss: 0.087155
#   Epoch 30/100, Loss: 0.087058
#   Epoch 40/100, Loss: 0.086971
#   Epoch 50/100, Loss: 0.086901
#   Epoch 60/100, Loss: 0.086843
#   Epoch 70/100, Loss: 0.086794
#   Epoch 80/100, Loss: 0.086754
#   Epoch 90/100, Loss: 0.086720
#   Epoch 100/100, Loss: 0.086695
# Training complete for run 13
# Run 13 — RMSE: 24.419566, MSE: 596.315184, NMSE: 0.0027211630
#
# ===== RUN 14/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.087008
#   Epoch 20/100, Loss: 0.086930
#   Epoch 30/100, Loss: 0.086887
#   Epoch 40/100, Loss: 0.086866
#   Epoch 50/100, Loss: 0.086851
#   Epoch 60/100, Loss: 0.086830
#   Epoch 70/100, Loss: 0.086813
#   Epoch 80/100, Loss: 0.086796
#   Epoch 90/100, Loss: 0.086781
#   Epoch 100/100, Loss: 0.086767
# Training complete for run 14
# Run 14 — RMSE: 24.417396, MSE: 596.209251, NMSE: 0.0027113269
#
# ===== RUN 15/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.087394
#   Epoch 20/100, Loss: 0.087280
#   Epoch 30/100, Loss: 0.087203
#   Epoch 40/100, Loss: 0.087145
#   Epoch 50/100, Loss: 0.087102
#   Epoch 60/100, Loss: 0.087069
#   Epoch 70/100, Loss: 0.087046
#   Epoch 80/100, Loss: 0.087026
#   Epoch 90/100, Loss: 0.087007
#   Epoch 100/100, Loss: 0.086987
# Training complete for run 15
# Run 15 — RMSE: 24.447934, MSE: 597.701458, NMSE: 0.0027250947
#
# ===== RUN 16/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.087254
#   Epoch 20/100, Loss: 0.087101
#   Epoch 30/100, Loss: 0.087018
#   Epoch 40/100, Loss: 0.086960
#   Epoch 50/100, Loss: 0.086916
#   Epoch 60/100, Loss: 0.086882
#   Epoch 70/100, Loss: 0.086859
#   Epoch 80/100, Loss: 0.086837
#   Epoch 90/100, Loss: 0.086815
#   Epoch 100/100, Loss: 0.086795
# Training complete for run 16
# Run 16 — RMSE: 24.446506, MSE: 597.631675, NMSE: 0.0027288591
#
# ===== RUN 17/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.087724
#   Epoch 20/100, Loss: 0.087596
#   Epoch 30/100, Loss: 0.087493
#   Epoch 40/100, Loss: 0.087414
#   Epoch 50/100, Loss: 0.087345
#   Epoch 60/100, Loss: 0.087285
#   Epoch 70/100, Loss: 0.087242
#   Epoch 80/100, Loss: 0.087194
#   Epoch 90/100, Loss: 0.087151
#   Epoch 100/100, Loss: 0.087113
# Training complete for run 17
# Run 17 — RMSE: 24.441754, MSE: 597.399353, NMSE: 0.0027232952
#
# ===== RUN 18/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.087274
#   Epoch 20/100, Loss: 0.087144
#   Epoch 30/100, Loss: 0.087064
#   Epoch 40/100, Loss: 0.087014
#   Epoch 50/100, Loss: 0.086981
#   Epoch 60/100, Loss: 0.086950
#   Epoch 70/100, Loss: 0.086929
#   Epoch 80/100, Loss: 0.086908
#   Epoch 90/100, Loss: 0.086888
#   Epoch 100/100, Loss: 0.086877
# Training complete for run 18
# Run 18 — RMSE: 24.428240, MSE: 596.738915, NMSE: 0.0027177183
#
# ===== RUN 19/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.087231
#   Epoch 20/100, Loss: 0.087193
#   Epoch 30/100, Loss: 0.087165
#   Epoch 40/100, Loss: 0.087142
#   Epoch 50/100, Loss: 0.087121
#   Epoch 60/100, Loss: 0.087099
#   Epoch 70/100, Loss: 0.087084
#   Epoch 80/100, Loss: 0.087064
#   Epoch 90/100, Loss: 0.087045
#   Epoch 100/100, Loss: 0.087029
# Training complete for run 19
# Run 19 — RMSE: 24.445038, MSE: 597.559905, NMSE: 0.0027218312
#
# ===== RUN 20/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.088144
#   Epoch 20/100, Loss: 0.087726
#   Epoch 30/100, Loss: 0.087516
#   Epoch 40/100, Loss: 0.087392
#   Epoch 50/100, Loss: 0.087311
#   Epoch 60/100, Loss: 0.087253
#   Epoch 70/100, Loss: 0.087205
#   Epoch 80/100, Loss: 0.087170
#   Epoch 90/100, Loss: 0.087140
#   Epoch 100/100, Loss: 0.087118
# Training complete for run 20
# Run 20 — RMSE: 24.450163, MSE: 597.810466, NMSE: 0.0027310959
#
# ===== RUN 21/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.087180
#   Epoch 20/100, Loss: 0.087124
#   Epoch 30/100, Loss: 0.087099
#   Epoch 40/100, Loss: 0.087075
#   Epoch 50/100, Loss: 0.087054
#   Epoch 60/100, Loss: 0.087036
#   Epoch 70/100, Loss: 0.087017
#   Epoch 80/100, Loss: 0.087001
#   Epoch 90/100, Loss: 0.086985
#   Epoch 100/100, Loss: 0.086970
# Training complete for run 21
# Run 21 — RMSE: 24.458277, MSE: 598.207300, NMSE: 0.0027310783
#
# ===== RUN 22/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.087219
#   Epoch 20/100, Loss: 0.087064
#   Epoch 30/100, Loss: 0.086985
#   Epoch 40/100, Loss: 0.086934
#   Epoch 50/100, Loss: 0.086896
#   Epoch 60/100, Loss: 0.086863
#   Epoch 70/100, Loss: 0.086841
#   Epoch 80/100, Loss: 0.086821
#   Epoch 90/100, Loss: 0.086804
#   Epoch 100/100, Loss: 0.086790
# Training complete for run 22
# Run 22 — RMSE: 24.444820, MSE: 597.549232, NMSE: 0.0027298448
#
# ===== RUN 23/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.087302
#   Epoch 20/100, Loss: 0.087196
#   Epoch 30/100, Loss: 0.087115
#   Epoch 40/100, Loss: 0.087052
#   Epoch 50/100, Loss: 0.087009
#   Epoch 60/100, Loss: 0.086981
#   Epoch 70/100, Loss: 0.086955
#   Epoch 80/100, Loss: 0.086930
#   Epoch 90/100, Loss: 0.086907
#   Epoch 100/100, Loss: 0.086887
# Training complete for run 23
# Run 23 — RMSE: 24.457878, MSE: 598.187797, NMSE: 0.0027358619
#
# ===== RUN 24/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.087248
#   Epoch 20/100, Loss: 0.087107
#   Epoch 30/100, Loss: 0.087005
#   Epoch 40/100, Loss: 0.086923
#   Epoch 50/100, Loss: 0.086858
#   Epoch 60/100, Loss: 0.086808
#   Epoch 70/100, Loss: 0.086780
#   Epoch 80/100, Loss: 0.086769
#   Epoch 90/100, Loss: 0.086756
#   Epoch 100/100, Loss: 0.086745
# Training complete for run 24
# Run 24 — RMSE: 24.416883, MSE: 596.184167, NMSE: 0.0027203815
#
# ===== RUN 25/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.087046
#   Epoch 20/100, Loss: 0.086983
#   Epoch 30/100, Loss: 0.086942
#   Epoch 40/100, Loss: 0.086914
#   Epoch 50/100, Loss: 0.086886
#   Epoch 60/100, Loss: 0.086862
#   Epoch 70/100, Loss: 0.086842
#   Epoch 80/100, Loss: 0.086824
#   Epoch 90/100, Loss: 0.086808
#   Epoch 100/100, Loss: 0.086793
# Training complete for run 25
# Run 25 — RMSE: 24.435062, MSE: 597.072231, NMSE: 0.0027206259
#
# ===== RUN 26/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.086948
#   Epoch 20/100, Loss: 0.086855
#   Epoch 30/100, Loss: 0.086801
#   Epoch 40/100, Loss: 0.086773
#   Epoch 50/100, Loss: 0.086757
#   Epoch 60/100, Loss: 0.086745
#   Epoch 70/100, Loss: 0.086730
#   Epoch 80/100, Loss: 0.086714
#   Epoch 90/100, Loss: 0.086697
#   Epoch 100/100, Loss: 0.086680
# Training complete for run 26
# Run 26 — RMSE: 24.405595, MSE: 595.633078, NMSE: 0.0027156719
#
# ===== RUN 27/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.087296
#   Epoch 20/100, Loss: 0.087142
#   Epoch 30/100, Loss: 0.087078
#   Epoch 40/100, Loss: 0.087031
#   Epoch 50/100, Loss: 0.086989
#   Epoch 60/100, Loss: 0.086959
#   Epoch 70/100, Loss: 0.086933
#   Epoch 80/100, Loss: 0.086908
#   Epoch 90/100, Loss: 0.086892
#   Epoch 100/100, Loss: 0.086883
# Training complete for run 27
# Run 27 — RMSE: 24.463848, MSE: 598.479859, NMSE: 0.0027360250
#
# ===== RUN 28/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.087537
#   Epoch 20/100, Loss: 0.087324
#   Epoch 30/100, Loss: 0.087221
#   Epoch 40/100, Loss: 0.087149
#   Epoch 50/100, Loss: 0.087099
#   Epoch 60/100, Loss: 0.087062
#   Epoch 70/100, Loss: 0.087034
#   Epoch 80/100, Loss: 0.087014
#   Epoch 90/100, Loss: 0.086994
#   Epoch 100/100, Loss: 0.086979
# Training complete for run 28
# Run 28 — RMSE: 24.468827, MSE: 598.723472, NMSE: 0.0027366675
#
# ===== RUN 29/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.087850
#   Epoch 20/100, Loss: 0.087509
#   Epoch 30/100, Loss: 0.087349
#   Epoch 40/100, Loss: 0.087262
#   Epoch 50/100, Loss: 0.087203
#   Epoch 60/100, Loss: 0.087161
#   Epoch 70/100, Loss: 0.087133
#   Epoch 80/100, Loss: 0.087112
#   Epoch 90/100, Loss: 0.087097
#   Epoch 100/100, Loss: 0.087083
# Training complete for run 29
# Run 29 — RMSE: 24.442057, MSE: 597.414139, NMSE: 0.0027266565
#
# ===== RUN 30/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.087081
#   Epoch 20/100, Loss: 0.086973
#   Epoch 30/100, Loss: 0.086912
#   Epoch 40/100, Loss: 0.086867
#   Epoch 50/100, Loss: 0.086834
#   Epoch 60/100, Loss: 0.086806
#   Epoch 70/100, Loss: 0.086781
#   Epoch 80/100, Loss: 0.086760
#   Epoch 90/100, Loss: 0.086747
#   Epoch 100/100, Loss: 0.086735
# Training complete for run 30
# Run 30 — RMSE: 24.442413, MSE: 597.431575, NMSE: 0.0027289040
#
# ===== RUN 31/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.087279
#   Epoch 20/100, Loss: 0.087166
#   Epoch 30/100, Loss: 0.087108
#   Epoch 40/100, Loss: 0.087057
#   Epoch 50/100, Loss: 0.087013
#   Epoch 60/100, Loss: 0.086983
#   Epoch 70/100, Loss: 0.086962
#   Epoch 80/100, Loss: 0.086943
#   Epoch 90/100, Loss: 0.086925
#   Epoch 100/100, Loss: 0.086906
# Training complete for run 31
# Run 31 — RMSE: 24.461226, MSE: 598.351589, NMSE: 0.0027286859
#
# ===== RUN 32/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.087054
#   Epoch 20/100, Loss: 0.086998
#   Epoch 30/100, Loss: 0.086993
#   Epoch 40/100, Loss: 0.086982
#   Epoch 50/100, Loss: 0.086970
#   Epoch 60/100, Loss: 0.086946
#   Epoch 70/100, Loss: 0.086926
#   Epoch 80/100, Loss: 0.086914
#   Epoch 90/100, Loss: 0.086901
#   Epoch 100/100, Loss: 0.086889
# Training complete for run 32
# Run 32 — RMSE: 24.451106, MSE: 597.856596, NMSE: 0.0027294244
#
# ===== RUN 33/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.087122
#   Epoch 20/100, Loss: 0.087018
#   Epoch 30/100, Loss: 0.086972
#   Epoch 40/100, Loss: 0.086944
#   Epoch 50/100, Loss: 0.086927
#   Epoch 60/100, Loss: 0.086912
#   Epoch 70/100, Loss: 0.086900
#   Epoch 80/100, Loss: 0.086891
#   Epoch 90/100, Loss: 0.086878
#   Epoch 100/100, Loss: 0.086870
# Training complete for run 33
# Run 33 — RMSE: 24.426977, MSE: 596.677207, NMSE: 0.0027219349
#
# ===== RUN 34/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.086995
#   Epoch 20/100, Loss: 0.086924
#   Epoch 30/100, Loss: 0.086878
#   Epoch 40/100, Loss: 0.086845
#   Epoch 50/100, Loss: 0.086818
#   Epoch 60/100, Loss: 0.086792
#   Epoch 70/100, Loss: 0.086768
#   Epoch 80/100, Loss: 0.086744
#   Epoch 90/100, Loss: 0.086722
#   Epoch 100/100, Loss: 0.086707
# Training complete for run 34
# Run 34 — RMSE: 24.413696, MSE: 596.028544, NMSE: 0.0027193833
#
# ===== RUN 35/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.087931
#   Epoch 20/100, Loss: 0.087591
#   Epoch 30/100, Loss: 0.087445
#   Epoch 40/100, Loss: 0.087361
#   Epoch 50/100, Loss: 0.087297
#   Epoch 60/100, Loss: 0.087246
#   Epoch 70/100, Loss: 0.087204
#   Epoch 80/100, Loss: 0.087172
#   Epoch 90/100, Loss: 0.087144
#   Epoch 100/100, Loss: 0.087118
# Training complete for run 35
# Run 35 — RMSE: 24.454141, MSE: 598.005002, NMSE: 0.0027309031
#
# ===== RUN 36/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.087430
#   Epoch 20/100, Loss: 0.087200
#   Epoch 30/100, Loss: 0.087099
#   Epoch 40/100, Loss: 0.087036
#   Epoch 50/100, Loss: 0.086988
#   Epoch 60/100, Loss: 0.086946
#   Epoch 70/100, Loss: 0.086910
#   Epoch 80/100, Loss: 0.086878
#   Epoch 90/100, Loss: 0.086848
#   Epoch 100/100, Loss: 0.086820
# Training complete for run 36
# Run 36 — RMSE: 24.419728, MSE: 596.323123, NMSE: 0.0027152075
#
# ===== RUN 37/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.087077
#   Epoch 20/100, Loss: 0.086975
#   Epoch 30/100, Loss: 0.086903
#   Epoch 40/100, Loss: 0.086849
#   Epoch 50/100, Loss: 0.086814
#   Epoch 60/100, Loss: 0.086788
#   Epoch 70/100, Loss: 0.086768
#   Epoch 80/100, Loss: 0.086755
#   Epoch 90/100, Loss: 0.086742
#   Epoch 100/100, Loss: 0.086729
# Training complete for run 37
# Run 37 — RMSE: 24.433027, MSE: 596.972798, NMSE: 0.0027264899
#
# ===== RUN 38/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.087303
#   Epoch 20/100, Loss: 0.087177
#   Epoch 30/100, Loss: 0.087100
#   Epoch 40/100, Loss: 0.087043
#   Epoch 50/100, Loss: 0.086994
#   Epoch 60/100, Loss: 0.086957
#   Epoch 70/100, Loss: 0.086924
#   Epoch 80/100, Loss: 0.086890
#   Epoch 90/100, Loss: 0.086858
#   Epoch 100/100, Loss: 0.086827
# Training complete for run 38
# Run 38 — RMSE: 24.426067, MSE: 596.632740, NMSE: 0.0027209887
#
# ===== RUN 39/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.087387
#   Epoch 20/100, Loss: 0.087235
#   Epoch 30/100, Loss: 0.087128
#   Epoch 40/100, Loss: 0.087047
#   Epoch 50/100, Loss: 0.086987
#   Epoch 60/100, Loss: 0.086946
#   Epoch 70/100, Loss: 0.086919
#   Epoch 80/100, Loss: 0.086897
#   Epoch 90/100, Loss: 0.086883
#   Epoch 100/100, Loss: 0.086872
# Training complete for run 39
# Run 39 — RMSE: 24.455450, MSE: 598.069029, NMSE: 0.0027289964
#
# ===== RUN 40/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.087080
#   Epoch 20/100, Loss: 0.086978
#   Epoch 30/100, Loss: 0.086913
#   Epoch 40/100, Loss: 0.086868
#   Epoch 50/100, Loss: 0.086836
#   Epoch 60/100, Loss: 0.086809
#   Epoch 70/100, Loss: 0.086794
#   Epoch 80/100, Loss: 0.086782
#   Epoch 90/100, Loss: 0.086769
#   Epoch 100/100, Loss: 0.086754
# Training complete for run 40
# Run 40 — RMSE: 24.425057, MSE: 596.583414, NMSE: 0.0027204758
#
# ===== RUN 41/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.087221
#   Epoch 20/100, Loss: 0.087136
#   Epoch 30/100, Loss: 0.087079
#   Epoch 40/100, Loss: 0.087033
#   Epoch 50/100, Loss: 0.086995
#   Epoch 60/100, Loss: 0.086961
#   Epoch 70/100, Loss: 0.086933
#   Epoch 80/100, Loss: 0.086911
#   Epoch 90/100, Loss: 0.086884
#   Epoch 100/100, Loss: 0.086860
# Training complete for run 41
# Run 41 — RMSE: 24.393883, MSE: 595.061510, NMSE: 0.0027145844
#
# ===== RUN 42/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.087020
#   Epoch 20/100, Loss: 0.086916
#   Epoch 30/100, Loss: 0.086877
#   Epoch 40/100, Loss: 0.086854
#   Epoch 50/100, Loss: 0.086838
#   Epoch 60/100, Loss: 0.086824
#   Epoch 70/100, Loss: 0.086810
#   Epoch 80/100, Loss: 0.086800
#   Epoch 90/100, Loss: 0.086790
#   Epoch 100/100, Loss: 0.086780
# Training complete for run 42
# Run 42 — RMSE: 24.443460, MSE: 597.482715, NMSE: 0.0027202710
#
# ===== RUN 43/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.087208
#   Epoch 20/100, Loss: 0.087085
#   Epoch 30/100, Loss: 0.087012
#   Epoch 40/100, Loss: 0.086957
#   Epoch 50/100, Loss: 0.086914
#   Epoch 60/100, Loss: 0.086881
#   Epoch 70/100, Loss: 0.086851
#   Epoch 80/100, Loss: 0.086828
#   Epoch 90/100, Loss: 0.086805
#   Epoch 100/100, Loss: 0.086786
# Training complete for run 43
# Run 43 — RMSE: 24.464409, MSE: 598.507291, NMSE: 0.0027308206
#
# ===== RUN 44/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.087131
#   Epoch 20/100, Loss: 0.087021
#   Epoch 30/100, Loss: 0.086984
#   Epoch 40/100, Loss: 0.086942
#   Epoch 50/100, Loss: 0.086902
#   Epoch 60/100, Loss: 0.086883
#   Epoch 70/100, Loss: 0.086862
#   Epoch 80/100, Loss: 0.086842
#   Epoch 90/100, Loss: 0.086824
#   Epoch 100/100, Loss: 0.086801
# Training complete for run 44
# Run 44 — RMSE: 24.412248, MSE: 595.957845, NMSE: 0.0027192368
#
# ===== RUN 45/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.087705
#   Epoch 20/100, Loss: 0.087515
#   Epoch 30/100, Loss: 0.087410
#   Epoch 40/100, Loss: 0.087332
#   Epoch 50/100, Loss: 0.087272
#   Epoch 60/100, Loss: 0.087223
#   Epoch 70/100, Loss: 0.087186
#   Epoch 80/100, Loss: 0.087154
#   Epoch 90/100, Loss: 0.087128
#   Epoch 100/100, Loss: 0.087104
# Training complete for run 45
# Run 45 — RMSE: 24.474407, MSE: 598.996575, NMSE: 0.0027343833
#
# ===== RUN 46/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.087390
#   Epoch 20/100, Loss: 0.087286
#   Epoch 30/100, Loss: 0.087220
#   Epoch 40/100, Loss: 0.087171
#   Epoch 50/100, Loss: 0.087133
#   Epoch 60/100, Loss: 0.087100
#   Epoch 70/100, Loss: 0.087064
#   Epoch 80/100, Loss: 0.087029
#   Epoch 90/100, Loss: 0.086995
#   Epoch 100/100, Loss: 0.086961
# Training complete for run 46
# Run 46 — RMSE: 24.438872, MSE: 597.258473, NMSE: 0.0027245081
#
# ===== RUN 47/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.087284
#   Epoch 20/100, Loss: 0.087202
#   Epoch 30/100, Loss: 0.087140
#   Epoch 40/100, Loss: 0.087088
#   Epoch 50/100, Loss: 0.087044
#   Epoch 60/100, Loss: 0.087005
#   Epoch 70/100, Loss: 0.086970
#   Epoch 80/100, Loss: 0.086939
#   Epoch 90/100, Loss: 0.086916
#   Epoch 100/100, Loss: 0.086897
# Training complete for run 47
# Run 47 — RMSE: 24.464618, MSE: 598.517553, NMSE: 0.0027271715
#
# ===== RUN 48/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.087138
#   Epoch 20/100, Loss: 0.087098
#   Epoch 30/100, Loss: 0.087069
#   Epoch 40/100, Loss: 0.087047
#   Epoch 50/100, Loss: 0.087022
#   Epoch 60/100, Loss: 0.086998
#   Epoch 70/100, Loss: 0.086980
#   Epoch 80/100, Loss: 0.086961
#   Epoch 90/100, Loss: 0.086943
#   Epoch 100/100, Loss: 0.086925
# Training complete for run 48
# ...
#
# ===== RUN 25/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.115204
#   Epoch 20/100, Loss: 0.114665
#   Epoch 30/100, Loss: 0.114291
#   Epoch 40/100, Loss: 0.113931
#   Epoch 50/100, Loss: 0.113569
#   Epoch 60/100, Loss: 0.113216
#   Epoch 70/100, Loss: 0.112885
#   Epoch 80/100, Loss: 0.112586
#   Epoch 90/100, Loss: 0.112329
#   Epoch 100/100, Loss: 0.112116
# Training complete for run 25
# Run 25 — RMSE: 30.547702, MSE: 933.162098, NMSE: 0.0044637984
#
# ===== RUN 26/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.115107
#   Epoch 20/100, Loss: 0.114652
#   Epoch 30/100, Loss: 0.114354
#   Epoch 40/100, Loss: 0.114090
#   Epoch 50/100, Loss: 0.113842
#   Epoch 60/100, Loss: 0.113607
#   Epoch 70/100, Loss: 0.113386
#   Epoch 80/100, Loss: 0.113180
#   Epoch 90/100, Loss: 0.112988
#   Epoch 100/100, Loss: 0.112815
# Training complete for run 26
# Run 26 — RMSE: 30.494791, MSE: 929.932249, NMSE: 0.0043578520
#
# ===== RUN 27/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.114800
#   Epoch 20/100, Loss: 0.114487
#   Epoch 30/100, Loss: 0.114212
#   Epoch 40/100, Loss: 0.113935
#   Epoch 50/100, Loss: 0.113654
#   Epoch 60/100, Loss: 0.113378
#   Epoch 70/100, Loss: 0.113118
#   Epoch 80/100, Loss: 0.112886
#   Epoch 90/100, Loss: 0.112690
#   Epoch 100/100, Loss: 0.112528
# Training complete for run 27
# Run 27 — RMSE: 30.507143, MSE: 930.685746, NMSE: 0.0043569140
#
# ===== RUN 28/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.115313
#   Epoch 20/100, Loss: 0.114666
#   Epoch 30/100, Loss: 0.114382
#   Epoch 40/100, Loss: 0.114110
#   Epoch 50/100, Loss: 0.113872
#   Epoch 60/100, Loss: 0.113665
#   Epoch 70/100, Loss: 0.113480
#   Epoch 80/100, Loss: 0.113306
#   Epoch 90/100, Loss: 0.113144
#   Epoch 100/100, Loss: 0.112991
# Training complete for run 28
# Run 28 — RMSE: 30.545115, MSE: 933.004037, NMSE: 0.0043847376
#
# ===== RUN 29/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.115328
#   Epoch 20/100, Loss: 0.114756
#   Epoch 30/100, Loss: 0.114525
#   Epoch 40/100, Loss: 0.114330
#   Epoch 50/100, Loss: 0.114153
#   Epoch 60/100, Loss: 0.113986
#   Epoch 70/100, Loss: 0.113826
#   Epoch 80/100, Loss: 0.113668
#   Epoch 90/100, Loss: 0.113504
#   Epoch 100/100, Loss: 0.113331
# Training complete for run 29
# Run 29 — RMSE: 30.539917, MSE: 932.686514, NMSE: 0.0043696507
#
# ===== RUN 30/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.115131
#   Epoch 20/100, Loss: 0.114649
#   Epoch 30/100, Loss: 0.114334
#   Epoch 40/100, Loss: 0.114077
#   Epoch 50/100, Loss: 0.113835
#   Epoch 60/100, Loss: 0.113595
#   Epoch 70/100, Loss: 0.113353
#   Epoch 80/100, Loss: 0.113111
#   Epoch 90/100, Loss: 0.112872
#   Epoch 100/100, Loss: 0.112650
# Training complete for run 30
# Run 30 — RMSE: 30.428881, MSE: 925.916823, NMSE: 0.0043949723
#
# ===== RUN 31/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.115433
#   Epoch 20/100, Loss: 0.114868
#   Epoch 30/100, Loss: 0.114609
#   Epoch 40/100, Loss: 0.114346
#   Epoch 50/100, Loss: 0.114061
#   Epoch 60/100, Loss: 0.113765
#   Epoch 70/100, Loss: 0.113482
#   Epoch 80/100, Loss: 0.113230
#   Epoch 90/100, Loss: 0.113030
#   Epoch 100/100, Loss: 0.112867
# Training complete for run 31
# Run 31 — RMSE: 30.626068, MSE: 937.956030, NMSE: 0.0044646104
#
# ===== RUN 32/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.114893
#   Epoch 20/100, Loss: 0.114509
#   Epoch 30/100, Loss: 0.114263
#   Epoch 40/100, Loss: 0.114041
#   Epoch 50/100, Loss: 0.113831
#   Epoch 60/100, Loss: 0.113622
#   Epoch 70/100, Loss: 0.113420
#   Epoch 80/100, Loss: 0.113213
#   Epoch 90/100, Loss: 0.113013
#   Epoch 100/100, Loss: 0.112840
# Training complete for run 32
# Run 32 — RMSE: 30.526121, MSE: 931.844067, NMSE: 0.0043863995
#
# ===== RUN 33/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.114740
#   Epoch 20/100, Loss: 0.114459
#   Epoch 30/100, Loss: 0.114229
#   Epoch 40/100, Loss: 0.114007
#   Epoch 50/100, Loss: 0.113774
#   Epoch 60/100, Loss: 0.113526
#   Epoch 70/100, Loss: 0.113266
#   Epoch 80/100, Loss: 0.113008
#   Epoch 90/100, Loss: 0.112767
#   Epoch 100/100, Loss: 0.112498
# Training complete for run 33
# Run 33 — RMSE: 30.314449, MSE: 918.965808, NMSE: 0.0044179164
#
# ===== RUN 34/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.115045
#   Epoch 20/100, Loss: 0.114528
#   Epoch 30/100, Loss: 0.114217
#   Epoch 40/100, Loss: 0.113953
#   Epoch 50/100, Loss: 0.113702
#   Epoch 60/100, Loss: 0.113464
#   Epoch 70/100, Loss: 0.113233
#   Epoch 80/100, Loss: 0.113009
#   Epoch 90/100, Loss: 0.112805
#   Epoch 100/100, Loss: 0.112623
# Training complete for run 34
# Run 34 — RMSE: 30.478756, MSE: 928.954580, NMSE: 0.0043432543
#
# ===== RUN 35/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.115607
#   Epoch 20/100, Loss: 0.115328
#   Epoch 30/100, Loss: 0.115097
#   Epoch 40/100, Loss: 0.114882
#   Epoch 50/100, Loss: 0.114646
#   Epoch 60/100, Loss: 0.114381
#   Epoch 70/100, Loss: 0.114085
#   Epoch 80/100, Loss: 0.113773
#   Epoch 90/100, Loss: 0.113467
#   Epoch 100/100, Loss: 0.113181
# Training complete for run 35
# Run 35 — RMSE: 30.543480, MSE: 932.904179, NMSE: 0.0043628208
#
# ===== RUN 36/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.115291
#   Epoch 20/100, Loss: 0.114972
#   Epoch 30/100, Loss: 0.114704
#   Epoch 40/100, Loss: 0.114444
#   Epoch 50/100, Loss: 0.114177
#   Epoch 60/100, Loss: 0.113905
#   Epoch 70/100, Loss: 0.113621
#   Epoch 80/100, Loss: 0.113337
#   Epoch 90/100, Loss: 0.113064
#   Epoch 100/100, Loss: 0.112822
# Training complete for run 36
# Run 36 — RMSE: 30.569020, MSE: 934.464965, NMSE: 0.0044574396
#
# ===== RUN 37/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.114994
#   Epoch 20/100, Loss: 0.114490
#   Epoch 30/100, Loss: 0.114181
#   Epoch 40/100, Loss: 0.113918
#   Epoch 50/100, Loss: 0.113679
#   Epoch 60/100, Loss: 0.113454
#   Epoch 70/100, Loss: 0.113229
#   Epoch 80/100, Loss: 0.113013
#   Epoch 90/100, Loss: 0.112814
#   Epoch 100/100, Loss: 0.112642
# Training complete for run 37
# Run 37 — RMSE: 30.541402, MSE: 932.777208, NMSE: 0.0043905025
#
# ===== RUN 38/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.115189
#   Epoch 20/100, Loss: 0.114875
#   Epoch 30/100, Loss: 0.114622
#   Epoch 40/100, Loss: 0.114377
#   Epoch 50/100, Loss: 0.114130
#   Epoch 60/100, Loss: 0.113880
#   Epoch 70/100, Loss: 0.113632
#   Epoch 80/100, Loss: 0.113394
#   Epoch 90/100, Loss: 0.113170
#   Epoch 100/100, Loss: 0.112965
# Training complete for run 38
# Run 38 — RMSE: 30.502507, MSE: 930.402926, NMSE: 0.0043988762
#
# ===== RUN 39/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.115284
#   Epoch 20/100, Loss: 0.114777
#   Epoch 30/100, Loss: 0.114449
#   Epoch 40/100, Loss: 0.114158
#   Epoch 50/100, Loss: 0.113874
#   Epoch 60/100, Loss: 0.113596
#   Epoch 70/100, Loss: 0.113332
#   Epoch 80/100, Loss: 0.113091
#   Epoch 90/100, Loss: 0.112877
#   Epoch 100/100, Loss: 0.112694
# Training complete for run 39
# Run 39 — RMSE: 30.582235, MSE: 935.273115, NMSE: 0.0043598964
#
# ===== RUN 40/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.115002
#   Epoch 20/100, Loss: 0.114676
#   Epoch 30/100, Loss: 0.114424
#   Epoch 40/100, Loss: 0.114171
#   Epoch 50/100, Loss: 0.113906
#   Epoch 60/100, Loss: 0.113634
#   Epoch 70/100, Loss: 0.113364
#   Epoch 80/100, Loss: 0.113109
#   Epoch 90/100, Loss: 0.112878
#   Epoch 100/100, Loss: 0.112680
# Training complete for run 40
# Run 40 — RMSE: 30.413685, MSE: 924.992207, NMSE: 0.0043832612
#
# ===== RUN 41/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.114885
#   Epoch 20/100, Loss: 0.114577
#   Epoch 30/100, Loss: 0.114338
#   Epoch 40/100, Loss: 0.114126
#   Epoch 50/100, Loss: 0.113937
#   Epoch 60/100, Loss: 0.113770
#   Epoch 70/100, Loss: 0.113620
#   Epoch 80/100, Loss: 0.113481
#   Epoch 90/100, Loss: 0.113337
#   Epoch 100/100, Loss: 0.113198
# Training complete for run 41
# Run 41 — RMSE: 30.539022, MSE: 932.631875, NMSE: 0.0043385476
#
# ===== RUN 42/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.114854
#   Epoch 20/100, Loss: 0.114522
#   Epoch 30/100, Loss: 0.114290
#   Epoch 40/100, Loss: 0.114067
#   Epoch 50/100, Loss: 0.113837
#   Epoch 60/100, Loss: 0.113596
#   Epoch 70/100, Loss: 0.113342
#   Epoch 80/100, Loss: 0.113079
#   Epoch 90/100, Loss: 0.112814
#   Epoch 100/100, Loss: 0.112564
# Training complete for run 42
# Run 42 — RMSE: 30.503532, MSE: 930.465459, NMSE: 0.0044126079
#
# ===== RUN 43/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.115248
#   Epoch 20/100, Loss: 0.114743
#   Epoch 30/100, Loss: 0.114501
#   Epoch 40/100, Loss: 0.114281
#   Epoch 50/100, Loss: 0.114056
#   Epoch 60/100, Loss: 0.113828
#   Epoch 70/100, Loss: 0.113599
#   Epoch 80/100, Loss: 0.113375
#   Epoch 90/100, Loss: 0.113171
#   Epoch 100/100, Loss: 0.112990
# Training complete for run 43
# Run 43 — RMSE: 30.581815, MSE: 935.247432, NMSE: 0.0043431014
#
# ===== RUN 44/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.115076
#   Epoch 20/100, Loss: 0.114665
#   Epoch 30/100, Loss: 0.114361
#   Epoch 40/100, Loss: 0.114093
#   Epoch 50/100, Loss: 0.113844
#   Epoch 60/100, Loss: 0.113613
#   Epoch 70/100, Loss: 0.113399
#   Epoch 80/100, Loss: 0.113196
#   Epoch 90/100, Loss: 0.113001
#   Epoch 100/100, Loss: 0.112814
# Training complete for run 44
# Run 44 — RMSE: 30.512665, MSE: 931.022740, NMSE: 0.0043367758
#
# ===== RUN 45/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.115572
#   Epoch 20/100, Loss: 0.115259
#   Epoch 30/100, Loss: 0.115077
#   Epoch 40/100, Loss: 0.114911
#   Epoch 50/100, Loss: 0.114723
#   Epoch 60/100, Loss: 0.114514
#   Epoch 70/100, Loss: 0.114290
#   Epoch 80/100, Loss: 0.114061
#   Epoch 90/100, Loss: 0.113838
#   Epoch 100/100, Loss: 0.113628
# Training complete for run 45
# Run 45 — RMSE: 30.278880, MSE: 916.810575, NMSE: 0.0043827179
#
# ===== RUN 46/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.115187
#   Epoch 20/100, Loss: 0.114744
#   Epoch 30/100, Loss: 0.114468
#   Epoch 40/100, Loss: 0.114198
#   Epoch 50/100, Loss: 0.113921
#   Epoch 60/100, Loss: 0.113639
#   Epoch 70/100, Loss: 0.113365
#   Epoch 80/100, Loss: 0.113112
#   Epoch 90/100, Loss: 0.112891
#   Epoch 100/100, Loss: 0.112707
# Training complete for run 46
# Run 46 — RMSE: 30.475963, MSE: 928.784327, NMSE: 0.0044520842
#
# ===== RUN 47/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.115282
#   Epoch 20/100, Loss: 0.114954
#   Epoch 30/100, Loss: 0.114708
#   Epoch 40/100, Loss: 0.114461
#   Epoch 50/100, Loss: 0.114192
#   Epoch 60/100, Loss: 0.113912
#   Epoch 70/100, Loss: 0.113657
#   Epoch 80/100, Loss: 0.113426
#   Epoch 90/100, Loss: 0.113225
#   Epoch 100/100, Loss: 0.113044
# Training complete for run 47
# Run 47 — RMSE: 30.499357, MSE: 930.210765, NMSE: 0.0043124162
#
# ===== RUN 48/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.115232
#   Epoch 20/100, Loss: 0.114774
#   Epoch 30/100, Loss: 0.114506
#   Epoch 40/100, Loss: 0.114234
#   Epoch 50/100, Loss: 0.113955
#   Epoch 60/100, Loss: 0.113660
#   Epoch 70/100, Loss: 0.113377
#   Epoch 80/100, Loss: 0.113113
#   Epoch 90/100, Loss: 0.112873
#   Epoch 100/100, Loss: 0.112661
# Training complete for run 48
# Run 48 — RMSE: 30.487857, MSE: 929.509441, NMSE: 0.0043982301
#
# ===== RUN 49/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.115914
#   Epoch 20/100, Loss: 0.115190
#   Epoch 30/100, Loss: 0.114961
#   Epoch 40/100, Loss: 0.114699
#   Epoch 50/100, Loss: 0.114380
#   Epoch 60/100, Loss: 0.114032
#   Epoch 70/100, Loss: 0.113699
#   Epoch 80/100, Loss: 0.113398
#   Epoch 90/100, Loss: 0.113136
#   Epoch 100/100, Loss: 0.112917
# Training complete for run 49
# Run 49 — RMSE: 30.434242, MSE: 926.243061, NMSE: 0.0043552164
#
# ===== RUN 50/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.115420
#   Epoch 20/100, Loss: 0.115004
#   Epoch 30/100, Loss: 0.114715
#   Epoch 40/100, Loss: 0.114473
#   Epoch 50/100, Loss: 0.114248
#   Epoch 60/100, Loss: 0.114038
#   Epoch 70/100, Loss: 0.113820
#   Epoch 80/100, Loss: 0.113590
#   Epoch 90/100, Loss: 0.113388
#   Epoch 100/100, Loss: 0.113215
# Training complete for run 50
# Run 50 — RMSE: 30.352035, MSE: 921.246020, NMSE: 0.0043295747
#
# ===== RUN 51/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.115578
#   Epoch 20/100, Loss: 0.115324
#   Epoch 30/100, Loss: 0.115179
#   Epoch 40/100, Loss: 0.115039
#   Epoch 50/100, Loss: 0.114900
#   Epoch 60/100, Loss: 0.114743
#   Epoch 70/100, Loss: 0.114548
#   Epoch 80/100, Loss: 0.114297
#   Epoch 90/100, Loss: 0.113991
#   Epoch 100/100, Loss: 0.113661
# Training complete for run 51
# Run 51 — RMSE: 30.457253, MSE: 927.644290, NMSE: 0.0043140779
#
# ===== RUN 52/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.114881
#   Epoch 20/100, Loss: 0.114496
#   Epoch 30/100, Loss: 0.114228
#   Epoch 40/100, Loss: 0.113972
#   Epoch 50/100, Loss: 0.113712
#   Epoch 60/100, Loss: 0.113454
#   Epoch 70/100, Loss: 0.113211
#   Epoch 80/100, Loss: 0.112993
#   Epoch 90/100, Loss: 0.112810
#   Epoch 100/100, Loss: 0.112668
# Training complete for run 52
# Run 52 — RMSE: 30.541357, MSE: 932.774476, NMSE: 0.0044152608
#
# ===== RUN 53/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.115257
#   Epoch 20/100, Loss: 0.114851
#   Epoch 30/100, Loss: 0.114649
#   Epoch 40/100, Loss: 0.114458
#   Epoch 50/100, Loss: 0.114254
#   Epoch 60/100, Loss: 0.114032
#   Epoch 70/100, Loss: 0.113794
#   Epoch 80/100, Loss: 0.113551
#   Epoch 90/100, Loss: 0.113315
#   Epoch 100/100, Loss: 0.113095
# Training complete for run 53
# Run 53 — RMSE: 30.610943, MSE: 937.029804, NMSE: 0.0043605242
#
# ===== RUN 54/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.115771
#   Epoch 20/100, Loss: 0.114895
#   Epoch 30/100, Loss: 0.114525
#   Epoch 40/100, Loss: 0.114187
#   Epoch 50/100, Loss: 0.113822
#   Epoch 60/100, Loss: 0.113451
#   Epoch 70/100, Loss: 0.113109
#   Epoch 80/100, Loss: 0.112819
#   Epoch 90/100, Loss: 0.112573
#   Epoch 100/100, Loss: 0.112350
# Training complete for run 54
# Run 54 — RMSE: 30.521807, MSE: 931.580700, NMSE: 0.0043821403
#
# ===== RUN 55/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.115098
#   Epoch 20/100, Loss: 0.114821
#   Epoch 30/100, Loss: 0.114587
#   Epoch 40/100, Loss: 0.114375
#   Epoch 50/100, Loss: 0.114172
#   Epoch 60/100, Loss: 0.113974
#   Epoch 70/100, Loss: 0.113780
#   Epoch 80/100, Loss: 0.113595
#   Epoch 90/100, Loss: 0.113415
#   Epoch 100/100, Loss: 0.113235
# Training complete for run 55
# Run 55 — RMSE: 30.523006, MSE: 931.653886, NMSE: 0.0043444628
#
# ===== RUN 56/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.115363
#   Epoch 20/100, Loss: 0.114953
#   Epoch 30/100, Loss: 0.114663
#   Epoch 40/100, Loss: 0.114364
#   Epoch 50/100, Loss: 0.114033
#   Epoch 60/100, Loss: 0.113688
#   Epoch 70/100, Loss: 0.113362
#   Epoch 80/100, Loss: 0.113076
#   Epoch 90/100, Loss: 0.112835
#   Epoch 100/100, Loss: 0.112632
# Training complete for run 56
# Run 56 — RMSE: 30.637686, MSE: 938.667802, NMSE: 0.0044344670
#
# ===== RUN 57/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.115108
#   Epoch 20/100, Loss: 0.114727
#   Epoch 30/100, Loss: 0.114439
#   Epoch 40/100, Loss: 0.114149
#   Epoch 50/100, Loss: 0.113863
#   Epoch 60/100, Loss: 0.113571
#   Epoch 70/100, Loss: 0.113283
#   Epoch 80/100, Loss: 0.113010
#   Epoch 90/100, Loss: 0.112774
#   Epoch 100/100, Loss: 0.112588
# Training complete for run 57
# Run 57 — RMSE: 30.455631, MSE: 927.545455, NMSE: 0.0044758127
#
# ===== RUN 58/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.114944
#   Epoch 20/100, Loss: 0.114663
#   Epoch 30/100, Loss: 0.114425
#   Epoch 40/100, Loss: 0.114179
#   Epoch 50/100, Loss: 0.113923
#   Epoch 60/100, Loss: 0.113669
#   Epoch 70/100, Loss: 0.113429
#   Epoch 80/100, Loss: 0.113213
#   Epoch 90/100, Loss: 0.113015
#   Epoch 100/100, Loss: 0.112832
# Training complete for run 58
# Run 58 — RMSE: 30.431181, MSE: 926.056768, NMSE: 0.0043187964
#
# ===== RUN 59/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.114924
#   Epoch 20/100, Loss: 0.114473
#   Epoch 30/100, Loss: 0.114100
#   Epoch 40/100, Loss: 0.113798
#   Epoch 50/100, Loss: 0.113550
#   Epoch 60/100, Loss: 0.113334
#   Epoch 70/100, Loss: 0.113141
#   Epoch 80/100, Loss: 0.112962
#   Epoch 90/100, Loss: 0.112794
#   Epoch 100/100, Loss: 0.112626
# Training complete for run 59
# Run 59 — RMSE: 30.556329, MSE: 933.689217, NMSE: 0.0043717004
#
# ===== RUN 60/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.114941
#   Epoch 20/100, Loss: 0.114392
#   Epoch 30/100, Loss: 0.114093
#   Epoch 40/100, Loss: 0.113829
#   Epoch 50/100, Loss: 0.113582
#   Epoch 60/100, Loss: 0.113342
#   Epoch 70/100, Loss: 0.113103
#   Epoch 80/100, Loss: 0.112875
#   Epoch 90/100, Loss: 0.112667
#   Epoch 100/100, Loss: 0.112481
# Training complete for run 60
# Run 60 — RMSE: 30.477672, MSE: 928.888474, NMSE: 0.0044109559
#
# ===== STATS FOR NOISE 10.0% (60 runs) =====
# RMSE: 30.509464 +/- 0.074984
# MSE:  930.833025 +/- 4.570305
# NMSE: 0.0043830323 +/- 0.0000458652
# Best run: 45 (RMSE: 30.278880)

# %% [markdown]
# ## Results

# %%
# ============================================================
# Final Metrics Summary & Plots per Noise Level
# ============================================================
from tabulate import tabulate

for entry in _molab_results:
    lam = entry[0]
    mean_rmse, std_rmse = entry[1], entry[2]
    mean_mse, std_mse = entry[3], entry[4]
    mean_nmse, std_nmse = entry[5], entry[6]
    best_rmse_val = entry[7]
    best_predictions = entry[8]
    best_losses = entry[9]
    raw_values_for_plot = entry[10]
    
    print("\n" + "="*80)
    print(f"RESULTS FOR NOISE LEVEL: {lam*100:.1f}%")
    print("="*80)
    
    print(f'Mean RMSE: {mean_rmse:.6f} +/- {std_rmse:.6f}')
    print(f'Mean MSE:  {mean_mse:.6f} +/- {std_mse:.6f}')
    print(f'Mean NMSE: {mean_nmse:.10f} +/- {std_nmse:.10f}')
    print(f'Best RMSE: {best_rmse_val:.6f}')
    
    actual = raw_values_for_plot[-60:]
    
    plt.figure(figsize=(12, 5))
    plt.plot(actual, label='Actual', color='blue', linewidth=1.5)
    plt.plot(best_predictions, label='Predicted (Best Run)', color='red',
             linewidth=1.5, linestyle='--')
    plt.title(f'Predictions vs Actual (Noise {lam*100:.1f}%)')
    plt.xlabel('Time Step')
    plt.ylabel('Value')
    plt.legend()
    plt.grid(True, alpha=0.3)
    plt.tight_layout()
    plt.show()

    plt.figure(figsize=(12, 4))
    plt.plot(best_losses, color='green', linewidth=1.0)
    plt.title(f'Training Loss (Best Run, Noise {lam*100:.1f}%)')
    plt.xlabel('Epoch')
    plt.ylabel('MSE Loss')
    plt.grid(True, alpha=0.3)
    plt.tight_layout()
    plt.show()

print("\n" + "="*80)
print("FINAL RESULTS TABLE ACROSS ALL NOISE LEVELS")
print("="*80)
df_res = pd.DataFrame(
    [[r[0], f'{r[1]:.6f} +/- {r[2]:.6f}', f'{r[3]:.6f} +/- {r[4]:.6f}', 
      f'{r[5]:.10f} +/- {r[6]:.10f}', f'{r[7]:.6f}'] for r in _molab_results],
    columns=['Noise Level', 'RMSE (mean+/-std)', 'MSE (mean+/-std)', 'NMSE (mean+/-std)', 'Best RMSE']
)
print(tabulate(df_res, headers='keys', tablefmt='github', showindex=False))
# Out:
# ================================================================================
# RESULTS FOR NOISE LEVEL: 0.0%
# ================================================================================
# Mean RMSE: 24.404844 +/- 0.018452
# Mean MSE:  595.596735 +/- 0.900509
# Mean NMSE: 0.0027161298 +/- 0.0000063769
# Best RMSE: 24.359864
# ================================================================================
# RESULTS FOR NOISE LEVEL: 0.5%
# ================================================================================
# Mean RMSE: 24.440039 +/- 0.019582
# Mean MSE:  597.315885 +/- 0.956945
# Mean NMSE: 0.0027245887 +/- 0.0000064733
# Best RMSE: 24.386843
# ================================================================================
# RESULTS FOR NOISE LEVEL: 5.0%
# ================================================================================
# Mean RMSE: 26.226959 +/- 0.060719
# Mean MSE:  687.857088 +/- 3.181320
# Mean NMSE: 0.0031599093 +/- 0.0000258179
# Best RMSE: 26.076867
# ================================================================================
# RESULTS FOR NOISE LEVEL: 10.0%
# ================================================================================
# Mean RMSE: 30.509464 +/- 0.074984
# Mean MSE:  930.833025 +/- 4.570305
# Mean NMSE: 0.0043830323 +/- 0.0000458652
# Best RMSE: 30.278880
# ================================================================================
# FINAL RESULTS TABLE ACROSS ALL NOISE LEVELS
# ================================================================================
# |   Noise Level | RMSE (mean+/-std)      | MSE (mean+/-std)        | NMSE (mean+/-std)             |   Best RMSE |
# |---------------|------------------------|-------------------------|-------------------------------|-------------|
# |         0     | 24.404844 +/- 0.018452 | 595.596735 +/- 0.900509 | 0.0027161298 +/- 0.0000063769 |     24.3599 |
# |         0.005 | 24.440039 +/- 0.019582 | 597.315885 +/- 0.956945 | 0.0027245887 +/- 0.0000064733 |     24.3868 |
# |         0.05  | 26.226959 +/- 0.060719 | 687.857088 +/- 3.181320 | 0.0031599093 +/- 0.0000258179 |     26.0769 |
# |         0.1   | 30.509464 +/- 0.074984 | 930.833025 +/- 4.570305 | 0.0043830323 +/- 0.0000458652 |     30.2789 |
