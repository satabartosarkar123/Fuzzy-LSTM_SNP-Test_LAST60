# %% [markdown]
# # Notebook 3: LSTM-SNP with Fuzzy Gate Replacement
#
# **Dataset**: Dow Jones Industrial Index
#
# ## Description
# This notebook implements **fuzzy gate replacement** for the LSTM-SNP model. The reset (r),
# consumption (c), and output (o) gates — which normally use hard sigmoid activation — are
# replaced with fuzzy inference systems. Each gate uses 2 Takagi-Sugeno rules with fixed Gaussian
# membership functions and trainable consequent parameters.
#
# The generation gate (a) retains its original tanh activation. The rest of the SNP architecture
# is unchanged. Gradient clipping (norm=1.0) is applied for training stability.

# %%
import torch
import torch.nn as nn

# %%
# ============================================================
# ALL IMPORTS
# ============================================================

import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras import layers
from tensorflow.keras import Model
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from math import sqrt
import matplotlib.pyplot as plt

print(f"TensorFlow version: {tf.__version__}")
print(f"NumPy version: {np.__version__}")
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1787661023.653938    1497 port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# I0000 00:00:1787661024.164423    1497 cpu_feature_guard.cc:227] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1787661028.326139    1497 port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# TensorFlow version: 2.21.0
# NumPy version: 2.4.4

# %%
# Default sigma value (will be overridden by the sigma loop)
CURRENT_SIGMA = 0.5

# %% [markdown]
# ## Theory: Fuzzy Gate Replacement
#
# ### Modified Gate Computation
# Instead of applying hard sigmoid directly, each gate (r, c, o) uses fuzzy inference:
#
# **Standard**: $r(t) = \sigma(z_r)$ where $z_r = W_r x(t) + U_r u(t-1) + b_r$
#
# **Fuzzy**: $r(t) = FuzzyInference(z_r, \bar{u}(t-1))$
#
# The fuzzy inference uses:
#
# **Fixed Gaussian Membership Functions**:
# - $\mu_{low}(z) = \exp\left(-\frac{(z - (-1))^2}{2 \cdot 0.5^2}\right)$
# - $\mu_{high}(z) = \exp\left(-\frac{(z - (+1))^2}{2 \cdot 0.5^2}\right)$
#
# **2 Rules per gate** (trainable consequents):
# 1. IF $z_{gate}$ is low → $y_0 = a_0 z + b_0 \bar{u} + c_0$
# 2. IF $z_{gate}$ is high → $y_1 = a_1 z + b_1 \bar{u} + c_1$
#
# **Output**: Gate value bounded via sigmoid to $(0, 1)$
#
# ### Unchanged
# - Generation gate $a(t) = \tanh(\cdot)$ — unchanged
# - State update: $u(t) = r \cdot u_{t-1} - c \cdot a$, $h(t) = o \cdot a$ — unchanged
# - Gradient clipping (norm ≤ 1.0) applied for stability

# %% [markdown]
# ## Model Architecture & Implementation

# %% [markdown]
# ### Fuzzy Gate LSTM-SNP Cell

# %%
import torch
import torch.nn as nn

class LSTMSNPCell(nn.Module):
    """Original LSTM-SNP cell — unchanged (hard_sigmoid gates)."""
    def __init__(self, input_size, hidden_size):
        super().__init__()
        self.input_size = input_size
        self.hidden_size = hidden_size
        self.W = nn.Linear(input_size, 4 * hidden_size, bias=True)
        self.U = nn.Linear(hidden_size, 4 * hidden_size, bias=True)
        nn.init.xavier_uniform_(self.W.weight)
        nn.init.orthogonal_(self.U.weight)

    def forward(self, x, u_prev):
        z = self.W(x) + self.U(u_prev)
        z0 = z[:, :self.hidden_size]
        z1 = z[:, self.hidden_size:2*self.hidden_size]
        z2 = z[:, 2*self.hidden_size:3*self.hidden_size]
        z3 = z[:, 3*self.hidden_size:]
        r = torch.nn.functional.hardsigmoid(z0)
        c = torch.nn.functional.hardsigmoid(z1)
        o = torch.nn.functional.hardsigmoid(z2)
        a = torch.tanh(z3)
        u = r * u_prev - c * a
        h = o * a
        return h, u


class FuzzyLSTMSNPCell(nn.Module):
    """
    LSTM-SNP Cell with fuzzy gate replacement.
    Gates r, c, o computed via 2-rule Takagi-Sugeno fuzzy inference,
    fixed Gaussian MFs (sigma read from global CURRENT_SIGMA at
    construction time, matching the Keras cell's convention),
    trainable consequents, sigmoid-bounded output.
    Gate a keeps tanh (unchanged).
    """
    def __init__(self, input_size, hidden_size):
        super().__init__()
        self.input_size = input_size
        self.hidden_size = hidden_size
        self.mu_low = -1.0
        self.mu_high = 1.0
        # Read from global, exactly like the Keras cell does —
        # CURRENT_SIGMA must be set before this class is instantiated.
        self.sigma = CURRENT_SIGMA

        self.W = nn.Linear(input_size, 4 * hidden_size, bias=True)
        self.U = nn.Linear(hidden_size, 4 * hidden_size, bias=True)
        nn.init.xavier_uniform_(self.W.weight)
        nn.init.orthogonal_(self.U.weight)

        self.fuzzy_params = nn.ParameterDict()
        for gate_name in ['r', 'c', 'o']:
            for rule_idx in range(2):
                self.fuzzy_params[f'{gate_name}_{rule_idx}_a'] = nn.Parameter(
                    torch.empty(hidden_size).uniform_(-0.1, 0.1))
                self.fuzzy_params[f'{gate_name}_{rule_idx}_b'] = nn.Parameter(
                    torch.empty(hidden_size).uniform_(-0.1, 0.1))
                self.fuzzy_params[f'{gate_name}_{rule_idx}_c'] = nn.Parameter(
                    torch.zeros(hidden_size))

    def _gaussian_mf(self, x, center):
        return torch.exp(-(x - center)**2 / (2.0 * self.sigma**2))

    def _fuzzy_gate(self, z_gate, u_mean, gate_name):
        w_low = self._gaussian_mf(z_gate, self.mu_low)
        w_high = self._gaussian_mf(z_gate, self.mu_high)

        a0 = self.fuzzy_params[f'{gate_name}_0_a']
        b0 = self.fuzzy_params[f'{gate_name}_0_b']
        c0 = self.fuzzy_params[f'{gate_name}_0_c']
        a1 = self.fuzzy_params[f'{gate_name}_1_a']
        b1 = self.fuzzy_params[f'{gate_name}_1_b']
        c1 = self.fuzzy_params[f'{gate_name}_1_c']

        y0 = a0 * z_gate + b0 * u_mean + c0
        y1 = a1 * z_gate + b1 * u_mean + c1

        numerator = w_low * y0 + w_high * y1
        denominator = w_low + w_high + 1e-8
        gate_raw = numerator / denominator

        return torch.sigmoid(gate_raw)

    def forward(self, x, u_prev):
        z = self.W(x) + self.U(u_prev)
        z0 = z[:, :self.hidden_size]
        z1 = z[:, self.hidden_size:2*self.hidden_size]
        z2 = z[:, 2*self.hidden_size:3*self.hidden_size]
        z3 = z[:, 3*self.hidden_size:]

        u_mean = u_prev.mean(dim=-1, keepdim=True).expand(-1, self.hidden_size)

        r = self._fuzzy_gate(z0, u_mean, 'r')
        c = self._fuzzy_gate(z1, u_mean, 'c')
        o = self._fuzzy_gate(z2, u_mean, 'o')
        a = torch.tanh(z3)

        u = r * u_prev - c * a
        h = o * a
        return h, u


class RNNModel(nn.Module):
    def __init__(self, input_size, hidden_size):
        super().__init__()
        self.hidden_size = hidden_size
        self.cell = FuzzyLSTMSNPCell(input_size, hidden_size)
        self.out = nn.Linear(hidden_size, 1)
        self.u = None

    def reset_states(self, batch_size, device):
        self.u = torch.zeros(batch_size, self.hidden_size, device=device)

    def detach_states(self):
        if self.u is not None:
            self.u = self.u.detach()

    def forward(self, x):
        if self.u is None or self.u.device != x.device or self.u.size(0) != x.size(0):
            self.reset_states(x.size(0), x.device)
        h, self.u = self.cell(x[:, 0, :], self.u)
        return self.out(h)


def build_model_torch(input_dim, units, batch_size=1):
    # batch_size accepted for call-signature compatibility with build_model_keras,
    # unused here — actual batch size is set dynamically via reset_states().
    return RNNModel(input_size=input_dim, hidden_size=units)


# ============================================================
# Quick model check
# ============================================================
CURRENT_SIGMA = 0.5  # must be set before FuzzyLSTMSNPCell() is constructed
model = build_model_torch(input_dim=1, units=8, batch_size=1)
print(model)
print(f"Total params: {sum(p.numel() for p in model.parameters())}")
# Out:
# RNNModel(
#   (cell): FuzzyLSTMSNPCell(
#     (W): Linear(in_features=1, out_features=32, bias=True)
#     (U): Linear(in_features=8, out_features=32, bias=True)
#     (fuzzy_params): ParameterDict(
#         (r_0_a): Parameter containing: [torch.FloatTensor of size 8]
#         (r_0_b): Parameter containing: [torch.FloatTensor of size 8]
#         (r_0_c): Parameter containing: [torch.FloatTensor of size 8]
#         (r_1_a): Parameter containing: [torch.FloatTensor of size 8]
#         (r_1_b): Parameter containing: [torch.FloatTensor of size 8]
#         (r_1_c): Parameter containing: [torch.FloatTensor of size 8]
#         (c_0_a): Parameter containing: [torch.FloatTensor of size 8]
#         (c_0_b): Parameter containing: [torch.FloatTensor of size 8]
#         (c_0_c): Parameter containing: [torch.FloatTensor of size 8]
#         (c_1_a): Parameter containing: [torch.FloatTensor of size 8]
#         (c_1_b): Parameter containing: [torch.FloatTensor of size 8]
#         (c_1_c): Parameter containing: [torch.FloatTensor of size 8]
#         (o_0_a): Parameter containing: [torch.FloatTensor of size 8]
#         (o_0_b): Parameter containing: [torch.FloatTensor of size 8]
#         (o_0_c): Parameter containing: [torch.FloatTensor of size 8]
#         (o_1_a): Parameter containing: [torch.FloatTensor of size 8]
#         (o_1_b): Parameter containing: [torch.FloatTensor of size 8]
#         (o_1_c): Parameter containing: [torch.FloatTensor of size 8]
#     )
#   )
#   (out): Linear(in_features=8, out_features=1, bias=True)
# )
# Total params: 505

# %% [markdown]
# ### Build Model

# %% [markdown]
# ## Data Pipeline — Dow Jones Industrial Index

# %%
# ============================================================
# 1. Load Time Series Data
# ============================================================

series = pd.read_csv(
    '/mnt/c/Users/paulp/OneDrive/Desktop/fuzzy_LSTM/dataset/monthly-closings-of-the-dowjones.csv',
    header=0,
    parse_dates=[0],
    index_col=0
)

raw_values = series.values.flatten()
print(f"Data shape: {raw_values.shape}")
print(f"First 5 values: {raw_values[:5]}")
# Out:
# Data shape: (291,)
# First 5 values: [3645.  3626.  3634.  3620.5 3607. ]

# %%
# ============================================================
# 2. First-Order Differencing
# ============================================================

def difference(dataset, interval=1):
    diff = []
    for i in range(interval, len(dataset)):
        value = dataset[i] - dataset[i - interval]
        diff.append(value)
    return np.array(diff)

diff_values = difference(raw_values, 1)

# %%
# ============================================================
# 3. Convert to Supervised Learning Format (lag=1)
# ============================================================

def timeseries_to_supervised(data, lag=1):
    df = pd.DataFrame(data)
    columns = [df.shift(i) for i in range(1, lag+1)]
    columns.append(df)
    df = pd.concat(columns, axis=1)
    df.fillna(0, inplace=True)
    return df.values

supervised = timeseries_to_supervised(diff_values, 1)
print(f"Supervised data shape: {supervised.shape}")
# Out:
# Supervised data shape: (290, 2)

# %%
# ============================================================
# 4. Train-Validation-Test Split (Chronological, 80/10/10)
# ============================================================
n = len(supervised)
train_end = int(n * 0.8)
val_end = int(n * 0.9)

train = supervised[:train_end]
val = supervised[train_end:val_end]
test = supervised[val_end:]

print(f"Train: {train.shape}, Val: {val.shape}, Test: {test.shape}")

# ============================================================
# 5. Feature Scaling
# ============================================================
scaler = MinMaxScaler(feature_range=(-1, 1))
scaler.fit(train)  # fit only on train to avoid leakage
train_scaled = scaler.transform(train)
val_scaled = scaler.transform(val)
test_scaled = scaler.transform(test)
# Out:
# Train: (232, 2), Val: (29, 2), Test: (29, 2)

# %%
# ============================================================
# 6. Reshape for RNN Input
# ============================================================

X_train, y_train = train_scaled[:, 0:-1], train_scaled[:, -1]
X_train = X_train.reshape((X_train.shape[0], 1, X_train.shape[1]))

X_test, y_test = test_scaled[:, 0:-1], test_scaled[:, -1]
print(f"X_train shape: {X_train.shape}, y_train shape: {y_train.shape}")
# Out:
# X_train shape: (232, 1, 1), y_train shape: (232,)

# %% [markdown]
# ## Training Loop

# %%
# ============================================================
# Multi-Sigma Experiment Protocol (PyTorch)
# σ values from Eq. (21) & (22): 0.25, 0.5, 0.75, 1.0
# ============================================================

SIGMA_VALUES = [0.25, 0.5, 0.75, 1.0]
sigma_results = {}

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"\n--- [PyTorch] RUNNING ON {device} ---\n")

for CURRENT_SIGMA in SIGMA_VALUES:
    print(f'\n{"="*60}')
    print(f'  SIGMA = {CURRENT_SIGMA}')
    print(f'{"="*60}')

    # ============================================================
    # 60-Run Experiment Protocol
    # ============================================================

    all_rmse = []
    all_mse = []
    all_nmse = []
    all_predictions = []
    all_losses = []

    N_RUNS = 60
    for run in range(N_RUNS):
        print(f'\n===== RUN {run+1}/{N_RUNS} =====')

        np.random.seed(run)
        torch.manual_seed(run)

        model = build_model_torch(input_dim=1, units=8, batch_size=1).to(device)

        # Initialize consumption gate bias to 1.0 (forget gate equivalent)
        with torch.no_grad():
            hs = model.hidden_size
            model.cell.U.bias.data[hs:2*hs] = 1.0

        optimizer = torch.optim.Adam(model.parameters(), lr=0.001)
        criterion = nn.MSELoss()

        run_losses = []
        # X_train is (batch, 1, input_dim)
        X_train_t = torch.tensor(X_train, dtype=torch.float32).to(device)
        y_train_t = torch.tensor(y_train, dtype=torch.float32).to(device)
        n_samples = X_train_t.size(0)

        for epoch in range(100):
            model.train()
            model.reset_states(1, device)  # batch_size=1
            epoch_loss = 0.0
            for i in range(n_samples):
                x_i = X_train_t[i:i+1]  # (1, 1, input_dim)
                y_i = y_train_t[i:i+1]  # (1,)

                optimizer.zero_grad()

                # Forward pass
                pred = model(x_i)
                loss = criterion(pred.squeeze(-1), y_i)

                # Backward and optimize
                loss.backward()

                # Gradient clipping (norm ≤ 1.0), applied unconditionally to match
                # the Keras side's Adam(clipnorm=1.0)
                torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)

                optimizer.step()

                # Detach hidden state so BPTT doesn't go all the way back to t=0
                model.detach_states()

                epoch_loss += loss.item()

            avg_loss = epoch_loss / n_samples
            run_losses.append(avg_loss)
            print(f"Epoch {epoch+1}/100 completed. Loss: {avg_loss:.6f}")

        all_losses.append(run_losses)
        print(f'Training complete for run {run+1}')

        # Warm-up: condition hidden states on training data
        model.eval()
        with torch.no_grad():
            for i in range(len(train_scaled)):
                X_raw = train_scaled[i, 0:-1]
                X_input = torch.tensor(X_raw, dtype=torch.float32).view(1, 1, len(X_raw)).to(device)
                model(X_input)

        # Test predictions (single-step)
        predictions = []
        model.eval()
        with torch.no_grad():
            for i in range(len(test_scaled)):
                X, y = test_scaled[i, 0:-1], test_scaled[i, -1]
                X_input = torch.tensor(X, dtype=torch.float32).view(1, 1, len(X)).to(device)
                yhat = model(X_input).item()

                # Invert scaling
                new_row = [x for x in X] + [yhat]
                array = np.array(new_row).reshape(1, len(new_row))
                inverted = scaler.inverse_transform(array)[0, -1]

                # Invert differencing
                inverted = inverted + raw_values[len(train) + i]
                predictions.append(inverted)

                expected = raw_values[len(train) + i + 1]
                print(f'Month={i+1}, Predicted={inverted:.4f}, Expected={expected:.4f}')

        # Compute metrics
        actual = raw_values[-len(test_scaled):]
        rmse = sqrt(mean_squared_error(actual, predictions))
        mse = mean_squared_error(actual, predictions)
        meanV = np.mean(actual)
        dominator = np.linalg.norm(np.array(predictions) - meanV, 2)
        nmse = mse / np.power(dominator, 2)

        all_rmse.append(rmse)
        all_mse.append(mse)
        all_nmse.append(nmse)
        all_predictions.append(predictions)

        print(f'Run {run+1} — RMSE: {rmse:.6f}, MSE: {mse:.6f}, NMSE: {nmse:.10f}')

    # Store results for this sigma
    sigma_results[CURRENT_SIGMA] = {
        'rmse': list(all_rmse),
        'mse': list(all_mse),
        'nmse': list(all_nmse),
        'predictions': list(all_predictions),
        'mean_rmse': float(np.mean(all_rmse)),
        'std_rmse': float(np.std(all_rmse)),
        'mean_mse': float(np.mean(all_mse)),
        'std_mse': float(np.std(all_mse)),
        'mean_nmse': float(np.mean(all_nmse)),
        'std_nmse': float(np.std(all_nmse)),
        'best_idx': int(np.argmin(all_rmse)),
        'best_rmse': float(np.min(all_rmse)),
    }

    print(f'\n--- σ={CURRENT_SIGMA} Summary ---')
    print(f'RMSE: {np.mean(all_rmse):.6f} ± {np.std(all_rmse):.6f}')
    print(f'MSE:  {np.mean(all_mse):.6f} ± {np.std(all_mse):.6f}')
    print(f'NMSE: {np.mean(all_nmse):.10f} ± {np.std(all_nmse):.10f}')
# Out:
# --- [PyTorch] RUNNING ON cuda ---
#
#
# ============================================================
#   SIGMA = 0.25
# ============================================================
#
# ===== RUN 1/60 =====
# Epoch 1/100 completed. Loss: 0.089690
# Epoch 2/100 completed. Loss: 0.086916
# Epoch 3/100 completed. Loss: 0.086761
# Epoch 4/100 completed. Loss: 0.086634
# Epoch 5/100 completed. Loss: 0.086531
# Epoch 6/100 completed. Loss: 0.086446
# Epoch 7/100 completed. Loss: 0.086373
# Epoch 8/100 completed. Loss: 0.086311
# Epoch 9/100 completed. Loss: 0.086256
# Epoch 10/100 completed. Loss: 0.086198
# Epoch 11/100 completed. Loss: 0.086150
# Epoch 12/100 completed. Loss: 0.086110
# Epoch 13/100 completed. Loss: 0.086075
# Epoch 14/100 completed. Loss: 0.086036
# Epoch 15/100 completed. Loss: 0.085998
# Epoch 16/100 completed. Loss: 0.085959
# Epoch 17/100 completed. Loss: 0.085926
# Epoch 18/100 completed. Loss: 0.085897
# Epoch 19/100 completed. Loss: 0.085871
# Epoch 85/100 completed. Loss: 0.084683
# Epoch 86/100 completed. Loss: 0.084666
# Epoch 87/100 completed. Loss: 0.084646
# Epoch 88/100 completed. Loss: 0.084625
# Epoch 89/100 completed. Loss: 0.084601
# Epoch 90/100 completed. Loss: 0.084577
# Epoch 91/100 completed. Loss: 0.084551
# Epoch 92/100 completed. Loss: 0.084525
# Epoch 93/100 completed. Loss: 0.084494
# Epoch 94/100 completed. Loss: 0.084467
# Epoch 95/100 completed. Loss: 0.084431
# Epoch 96/100 completed. Loss: 0.084395
# Epoch 97/100 completed. Loss: 0.084305
# Epoch 98/100 completed. Loss: 0.084350
# Epoch 99/100 completed. Loss: 0.084277
# Epoch 100/100 completed. Loss: 0.084255
# Training complete for run 1
# Month=1, Predicted=3794.3684, Expected=3766.0000
# Month=2, Predicted=3767.2615, Expected=3747.0000
# Month=3, Predicted=3741.7896, Expected=3754.0000
# Month=4, Predicted=3751.7440, Expected=3756.0000
# Month=5, Predicted=3758.3346, Expected=3767.0000
# Month=6, Predicted=3771.9270, Expected=3751.0000
# Month=7, Predicted=3754.9281, Expected=3769.0000
# Month=8, Predicted=3772.1352, Expected=3760.0000
# Month=9, Predicted=3762.7155, Expected=3785.0000
# Month=10, Predicted=3786.2264, Expected=3776.0000
# Month=11, Predicted=3777.3424, Expected=3755.0000
# Month=12, Predicted=3756.3604, Expected=3755.0000
# Month=13, Predicted=3754.3926, Expected=3751.0000
# Month=14, Predicted=3754.0610, Expected=3776.0000
# Month=15, Predicted=3778.3486, Expected=3847.0000
# Month=16, Predicted=3846.1680, Expected=3830.0000
# Month=17, Predicted=3833.5281, Expected=3881.0000
# Month=18, Predicted=3883.9548, Expected=3899.0000
# Month=19, Predicted=3899.1240, Expected=3917.0000
# Month=20, Predicted=3915.9267, Expected=3913.0000
# Month=21, Predicted=3907.8484, Expected=3901.0000
# Month=22, Predicted=3899.6003, Expected=3886.0000
# Month=23, Predicted=3887.6138, Expected=3892.5000
# Month=24, Predicted=3893.5729, Expected=3899.0000
# Month=25, Predicted=3900.2744, Expected=3886.0000
# Month=26, Predicted=3887.9150, Expected=3908.0000
# Month=27, Predicted=3909.5507, Expected=3875.0000
# Month=28, Predicted=3873.9421, Expected=3860.0000
# Month=29, Predicted=3863.2832, Expected=3880.0000
# Run 1 — RMSE: 87.619188, MSE: 7677.122053, NMSE: 0.0435314467
#
# ===== RUN 2/60 =====
# Epoch 1/100 completed. Loss: 0.106646
# Epoch 2/100 completed. Loss: 0.085804
# Epoch 3/100 completed. Loss: 0.085794
# Epoch 4/100 completed. Loss: 0.085795
# Epoch 5/100 completed. Loss: 0.085808
# Epoch 6/100 completed. Loss: 0.085828
# Epoch 7/100 completed. Loss: 0.085852
# Epoch 8/100 completed. Loss: 0.085879
# Epoch 9/100 completed. Loss: 0.085903
# Epoch 10/100 completed. Loss: 0.085930
# Epoch 11/100 completed. Loss: 0.085954
# Epoch 12/100 completed. Loss: 0.085977
# Epoch 13/100 completed. Loss: 0.085998
# Epoch 80/100 completed. Loss: 0.085762
# Epoch 81/100 completed. Loss: 0.085727
# Epoch 82/100 completed. Loss: 0.085736
# Epoch 83/100 completed. Loss: 0.085701
# Epoch 84/100 completed. Loss: 0.085710
# Epoch 85/100 completed. Loss: 0.085672
# Epoch 86/100 completed. Loss: 0.085683
# Epoch 87/100 completed. Loss: 0.085644
# Epoch 88/100 completed. Loss: 0.085658
# Epoch 89/100 completed. Loss: 0.085618
# Epoch 90/100 completed. Loss: 0.085625
# Epoch 91/100 completed. Loss: 0.085589
# Epoch 92/100 completed. Loss: 0.085605
# Epoch 93/100 completed. Loss: 0.085555
# Epoch 94/100 completed. Loss: 0.085559
# Epoch 95/100 completed. Loss: 0.085524
# Epoch 96/100 completed. Loss: 0.085526
# Epoch 97/100 completed. Loss: 0.085460
# Epoch 98/100 completed. Loss: 0.085484
# Epoch 99/100 completed. Loss: 0.085437
# Epoch 100/100 completed. Loss: 0.085493
# Training complete for run 2
# Month=1, Predicted=3793.7043, Expected=3766.0000
# Month=2, Predicted=3767.0810, Expected=3747.0000
# Month=3, Predicted=3743.7458, Expected=3754.0000
# Month=4, Predicted=3756.1358, Expected=3756.0000
# Month=5, Predicted=3757.5019, Expected=3767.0000
# Month=6, Predicted=3770.2475, Expected=3751.0000
# Month=7, Predicted=3753.0086, Expected=3769.0000
# Month=8, Predicted=3771.0124, Expected=3760.0000
# Month=9, Predicted=3761.7546, Expected=3785.0000
# Month=10, Predicted=3785.7312, Expected=3776.0000
# Month=11, Predicted=3777.0620, Expected=3755.0000
# Month=12, Predicted=3756.0320, Expected=3755.0000
# Month=13, Predicted=3757.2217, Expected=3751.0000
# Month=14, Predicted=3752.9521, Expected=3776.0000
# Month=15, Predicted=3777.4836, Expected=3847.0000
# Month=16, Predicted=3849.6351, Expected=3830.0000
# Month=17, Predicted=3831.9720, Expected=3881.0000
# Month=18, Predicted=3882.9241, Expected=3899.0000
# Month=19, Predicted=3899.2576, Expected=3917.0000
# Month=20, Predicted=3917.1403, Expected=3913.0000
# Month=21, Predicted=3909.9313, Expected=3901.0000
# Month=22, Predicted=3902.7046, Expected=3886.0000
# Month=23, Predicted=3887.0873, Expected=3892.5000
# Month=24, Predicted=3893.2528, Expected=3899.0000
# Month=25, Predicted=3900.1425, Expected=3886.0000
# Month=26, Predicted=3887.8180, Expected=3908.0000
# Month=27, Predicted=3908.8082, Expected=3875.0000
# Month=28, Predicted=3877.2504, Expected=3860.0000
# Month=29, Predicted=3862.1305, Expected=3880.0000
# Run 2 — RMSE: 87.464422, MSE: 7650.025097, NMSE: 0.0432883136
#
# ===== RUN 3/60 =====
# Epoch 1/100 completed. Loss: 0.113418
# Epoch 2/100 completed. Loss: 0.085375
# Epoch 3/100 completed. Loss: 0.085298
# Epoch 4/100 completed. Loss: 0.085286
# Epoch 5/100 completed. Loss: 0.085259
# Epoch 6/100 completed. Loss: 0.085247
# Epoch 7/100 completed. Loss: 0.085244
# Epoch 74/100 completed. Loss: 0.085103
# Epoch 75/100 completed. Loss: 0.085089
# Epoch 76/100 completed. Loss: 0.085074
# Epoch 77/100 completed. Loss: 0.085058
# Epoch 78/100 completed. Loss: 0.085043
# Epoch 79/100 completed. Loss: 0.085027
# Epoch 80/100 completed. Loss: 0.085011
# Epoch 81/100 completed. Loss: 0.084996
# Epoch 82/100 completed. Loss: 0.084980
# Epoch 83/100 completed. Loss: 0.084965
# Epoch 84/100 completed. Loss: 0.084951
# Epoch 85/100 completed. Loss: 0.084937
# Epoch 86/100 completed. Loss: 0.084923
# Epoch 87/100 completed. Loss: 0.084910
# Epoch 88/100 completed. Loss: 0.084896
# Epoch 89/100 completed. Loss: 0.084883
# Epoch 90/100 completed. Loss: 0.084870
# Epoch 91/100 completed. Loss: 0.084855
# Epoch 92/100 completed. Loss: 0.084836
# Epoch 93/100 completed. Loss: 0.084815
# Epoch 94/100 completed. Loss: 0.084794
# Epoch 95/100 completed. Loss: 0.084774
# Epoch 96/100 completed. Loss: 0.084755
# Epoch 97/100 completed. Loss: 0.084737
# Epoch 98/100 completed. Loss: 0.084719
# Epoch 99/100 completed. Loss: 0.084702
# Epoch 100/100 completed. Loss: 0.084685
# Training complete for run 3
# Month=1, Predicted=3794.1019, Expected=3766.0000
# Month=2, Predicted=3767.8393, Expected=3747.0000
# Month=3, Predicted=3740.5431, Expected=3754.0000
# Month=4, Predicted=3753.7593, Expected=3756.0000
# Month=5, Predicted=3758.2248, Expected=3767.0000
# Month=6, Predicted=3768.9219, Expected=3751.0000
# Month=7, Predicted=3753.0987, Expected=3769.0000
# Month=8, Predicted=3771.0712, Expected=3760.0000
# Month=9, Predicted=3762.0413, Expected=3785.0000
# Month=10, Predicted=3786.4100, Expected=3776.0000
# Month=11, Predicted=3777.8527, Expected=3755.0000
# Month=12, Predicted=3756.8695, Expected=3755.0000
# Month=13, Predicted=3755.1823, Expected=3751.0000
# Month=14, Predicted=3753.5298, Expected=3776.0000
# Month=15, Predicted=3778.0925, Expected=3847.0000
# Month=16, Predicted=3847.5564, Expected=3830.0000
# Month=17, Predicted=3832.2504, Expected=3881.0000
# Month=18, Predicted=3883.2225, Expected=3899.0000
# Month=19, Predicted=3899.8604, Expected=3917.0000
# Month=20, Predicted=3917.9090, Expected=3913.0000
# Month=21, Predicted=3906.9285, Expected=3901.0000
# Month=22, Predicted=3903.4732, Expected=3886.0000
# Month=23, Predicted=3887.8029, Expected=3892.5000
# Month=24, Predicted=3893.7413, Expected=3899.0000
# Month=25, Predicted=3900.9370, Expected=3886.0000
# Month=26, Predicted=3888.6204, Expected=3908.0000
# Month=27, Predicted=3909.2062, Expected=3875.0000
# Month=28, Predicted=3875.4172, Expected=3860.0000
# Month=29, Predicted=3862.3956, Expected=3880.0000
# Run 3 — RMSE: 87.698971, MSE: 7691.109577, NMSE: 0.0432625235
#
# ===== RUN 4/60 =====
# Epoch 1/100 completed. Loss: 0.088330
# Epoch 2/100 completed. Loss: 0.086108
# Epoch 69/100 completed. Loss: 0.085497
# Epoch 70/100 completed. Loss: 0.085486
# Epoch 71/100 completed. Loss: 0.085473
# Epoch 72/100 completed. Loss: 0.085460
# Epoch 73/100 completed. Loss: 0.085447
# Epoch 74/100 completed. Loss: 0.085436
# Epoch 75/100 completed. Loss: 0.085423
# Epoch 76/100 completed. Loss: 0.085449
# Epoch 77/100 completed. Loss: 0.085496
# Epoch 78/100 completed. Loss: 0.085499
# Epoch 79/100 completed. Loss: 0.085481
# Epoch 80/100 completed. Loss: 0.085468
# Epoch 81/100 completed. Loss: 0.085504
# Epoch 82/100 completed. Loss: 0.085524
# Epoch 83/100 completed. Loss: 0.085491
# Epoch 84/100 completed. Loss: 0.085451
# Epoch 85/100 completed. Loss: 0.085388
# Epoch 86/100 completed. Loss: 0.085314
# Epoch 87/100 completed. Loss: 0.085242
# Epoch 88/100 completed. Loss: 0.085182
# Epoch 89/100 completed. Loss: 0.085123
# Epoch 90/100 completed. Loss: 0.085075
# Epoch 91/100 completed. Loss: 0.085021
# Epoch 92/100 completed. Loss: 0.084985
# Epoch 93/100 completed. Loss: 0.084929
# Epoch 94/100 completed. Loss: 0.084914
# Epoch 95/100 completed. Loss: 0.084850
# Epoch 96/100 completed. Loss: 0.084840
# Epoch 97/100 completed. Loss: 0.084775
# Epoch 98/100 completed. Loss: 0.084777
# Epoch 99/100 completed. Loss: 0.084696
# Epoch 100/100 completed. Loss: 0.084698
# Training complete for run 4
# Month=1, Predicted=3794.7672, Expected=3766.0000
# Month=2, Predicted=3768.2229, Expected=3747.0000
# Month=3, Predicted=3742.0907, Expected=3754.0000
# Month=4, Predicted=3755.4771, Expected=3756.0000
# Month=5, Predicted=3758.2247, Expected=3767.0000
# Month=6, Predicted=3769.5278, Expected=3751.0000
# Month=7, Predicted=3750.7167, Expected=3769.0000
# Month=8, Predicted=3768.8934, Expected=3760.0000
# Month=9, Predicted=3760.1724, Expected=3785.0000
# Month=10, Predicted=3786.4117, Expected=3776.0000
# Month=11, Predicted=3778.2243, Expected=3755.0000
# Month=12, Predicted=3757.2292, Expected=3755.0000
# Month=13, Predicted=3756.7106, Expected=3751.0000
# Month=14, Predicted=3752.1268, Expected=3776.0000
# Month=15, Predicted=3777.6602, Expected=3847.0000
# Month=16, Predicted=3848.1129, Expected=3830.0000
# Month=17, Predicted=3829.9349, Expected=3881.0000
# Month=18, Predicted=3881.1617, Expected=3899.0000
# Month=19, Predicted=3899.0441, Expected=3917.0000
# Month=20, Predicted=3917.3629, Expected=3913.0000
# Month=21, Predicted=3908.2697, Expected=3901.0000
# Month=22, Predicted=3903.2489, Expected=3886.0000
# Month=23, Predicted=3888.1484, Expected=3892.5000
# Month=24, Predicted=3894.3306, Expected=3899.0000
# Month=25, Predicted=3901.2468, Expected=3886.0000
# Month=26, Predicted=3887.8205, Expected=3908.0000
# Month=27, Predicted=3909.9404, Expected=3875.0000
# Month=28, Predicted=3876.7091, Expected=3860.0000
# Epoch 63/100 completed. Loss: 0.085033
# Epoch 64/100 completed. Loss: 0.084972
# Epoch 65/100 completed. Loss: 0.085014
# Epoch 66/100 completed. Loss: 0.084941
# Epoch 67/100 completed. Loss: 0.084993
# Epoch 68/100 completed. Loss: 0.084910
# Epoch 69/100 completed. Loss: 0.084965
# Epoch 70/100 completed. Loss: 0.084878
# Epoch 71/100 completed. Loss: 0.084930
# Epoch 72/100 completed. Loss: 0.084844
# Epoch 73/100 completed. Loss: 0.084890
# Epoch 74/100 completed. Loss: 0.084808
# Epoch 75/100 completed. Loss: 0.084843
# Epoch 76/100 completed. Loss: 0.084770
# Epoch 77/100 completed. Loss: 0.084788
# Epoch 78/100 completed. Loss: 0.084728
# Epoch 79/100 completed. Loss: 0.084725
# Epoch 80/100 completed. Loss: 0.084678
# Epoch 81/100 completed. Loss: 0.084659
# Epoch 82/100 completed. Loss: 0.084622
# Epoch 83/100 completed. Loss: 0.084596
# Epoch 84/100 completed. Loss: 0.084563
# Epoch 85/100 completed. Loss: 0.084533
# Epoch 86/100 completed. Loss: 0.084500
# Epoch 87/100 completed. Loss: 0.084467
# Epoch 88/100 completed. Loss: 0.084435
# Epoch 89/100 completed. Loss: 0.084402
# Epoch 90/100 completed. Loss: 0.084364
# Epoch 91/100 completed. Loss: 0.084325
# Epoch 92/100 completed. Loss: 0.084287
# Epoch 93/100 completed. Loss: 0.084242
# Epoch 94/100 completed. Loss: 0.084198
# Epoch 95/100 completed. Loss: 0.084150
# Epoch 96/100 completed. Loss: 0.084102
# Epoch 97/100 completed. Loss: 0.084054
# Epoch 98/100 completed. Loss: 0.084006
# Epoch 99/100 completed. Loss: 0.083958
# Epoch 100/100 completed. Loss: 0.083910
# Training complete for run 5
# Month=1, Predicted=3794.0753, Expected=3766.0000
# Month=2, Predicted=3766.7277, Expected=3747.0000
# Month=3, Predicted=3743.7245, Expected=3754.0000
# Month=4, Predicted=3751.5955, Expected=3756.0000
# Month=5, Predicted=3758.0815, Expected=3767.0000
# Month=6, Predicted=3777.2865, Expected=3751.0000
# Month=7, Predicted=3754.4019, Expected=3769.0000
# Month=8, Predicted=3771.7293, Expected=3760.0000
# Month=9, Predicted=3762.8032, Expected=3785.0000
# Month=10, Predicted=3786.7432, Expected=3776.0000
# Month=11, Predicted=3776.9954, Expected=3755.0000
# Month=12, Predicted=3755.8321, Expected=3755.0000
# Month=13, Predicted=3754.5300, Expected=3751.0000
# Month=14, Predicted=3753.4789, Expected=3776.0000
# Month=15, Predicted=3778.5527, Expected=3847.0000
# Month=16, Predicted=3846.5024, Expected=3830.0000
# Month=17, Predicted=3833.0593, Expected=3881.0000
# Month=18, Predicted=3883.8823, Expected=3899.0000
# Month=19, Predicted=3900.4281, Expected=3917.0000
# Month=20, Predicted=3917.0630, Expected=3913.0000
# Month=21, Predicted=3909.7249, Expected=3901.0000
# Month=22, Predicted=3899.8270, Expected=3886.0000
# Month=23, Predicted=3887.1115, Expected=3892.5000
# Month=24, Predicted=3893.1990, Expected=3899.0000
# Month=25, Predicted=3899.6551, Expected=3886.0000
# Month=26, Predicted=3886.7683, Expected=3908.0000
# Month=27, Predicted=3909.5383, Expected=3875.0000
# Month=28, Predicted=3874.6098, Expected=3860.0000
# Month=29, Predicted=3862.2856, Expected=3880.0000
# Run 5 — RMSE: 87.547583, MSE: 7664.579259, NMSE: 0.0436207846
#
# ===== RUN 6/60 =====
# Epoch 1/100 completed. Loss: 0.086180
# Epoch 2/100 completed. Loss: 0.085920
# Epoch 3/100 completed. Loss: 0.085907
# Epoch 4/100 completed. Loss: 0.085897
# Epoch 5/100 completed. Loss: 0.085889
# Epoch 6/100 completed. Loss: 0.085881
# Epoch 7/100 completed. Loss: 0.085875
# Epoch 8/100 completed. Loss: 0.085869
# Epoch 9/100 completed. Loss: 0.085864
# Epoch 10/100 completed. Loss: 0.085860
# Epoch 11/100 completed. Loss: 0.085858
# Epoch 12/100 completed. Loss: 0.085858
# Epoch 13/100 completed. Loss: 0.085858
# Epoch 14/100 completed. Loss: 0.085860
# Epoch 15/100 completed. Loss: 0.085862
# Epoch 16/100 completed. Loss: 0.085874
# Epoch 17/100 completed. Loss: 0.085860
# Epoch 18/100 completed. Loss: 0.085846
# Epoch 19/100 completed. Loss: 0.085836
# Epoch 20/100 completed. Loss: 0.085827
# Epoch 21/100 completed. Loss: 0.085816
# Epoch 22/100 completed. Loss: 0.085804
# Epoch 23/100 completed. Loss: 0.085791
# Epoch 24/100 completed. Loss: 0.085777
# Epoch 25/100 completed. Loss: 0.085764
# Epoch 26/100 completed. Loss: 0.085751
# Epoch 27/100 completed. Loss: 0.085740
# Epoch 28/100 completed. Loss: 0.085730
# Epoch 29/100 completed. Loss: 0.085722
# Epoch 30/100 completed. Loss: 0.085712
# Epoch 31/100 completed. Loss: 0.085702
# Epoch 32/100 completed. Loss: 0.085692
# Epoch 33/100 completed. Loss: 0.085682
# Epoch 34/100 completed. Loss: 0.085673
# Epoch 35/100 completed. Loss: 0.085664
# Epoch 36/100 completed. Loss: 0.085657
# Epoch 37/100 completed. Loss: 0.085648
# Epoch 38/100 completed. Loss: 0.085633
# Epoch 39/100 completed. Loss: 0.085616
# Epoch 40/100 completed. Loss: 0.085597
# Epoch 41/100 completed. Loss: 0.085577
# Epoch 42/100 completed. Loss: 0.085556
# Epoch 43/100 completed. Loss: 0.085534
# Epoch 44/100 completed. Loss: 0.085512
# Epoch 45/100 completed. Loss: 0.085489
# Epoch 46/100 completed. Loss: 0.085466
# Epoch 47/100 completed. Loss: 0.085443
# Epoch 48/100 completed. Loss: 0.085419
# Epoch 49/100 completed. Loss: 0.085394
# Epoch 50/100 completed. Loss: 0.085370
# Epoch 51/100 completed. Loss: 0.085344
# Epoch 52/100 completed. Loss: 0.085318
# Epoch 53/100 completed. Loss: 0.085291
# Epoch 54/100 completed. Loss: 0.085264
# Epoch 55/100 completed. Loss: 0.085236
# Epoch 56/100 completed. Loss: 0.085208
# Epoch 57/100 completed. Loss: 0.085179
# Epoch 58/100 completed. Loss: 0.085149
# Epoch 59/100 completed. Loss: 0.085120
# Epoch 60/100 completed. Loss: 0.085090
# Epoch 61/100 completed. Loss: 0.085059
# Epoch 62/100 completed. Loss: 0.085027
# Epoch 63/100 completed. Loss: 0.084994
# Epoch 64/100 completed. Loss: 0.084963
# Epoch 65/100 completed. Loss: 0.084932
# Epoch 66/100 completed. Loss: 0.084896
# Epoch 67/100 completed. Loss: 0.084858
# Epoch 68/100 completed. Loss: 0.084819
# Epoch 69/100 completed. Loss: 0.084785
# Epoch 70/100 completed. Loss: 0.084737
# Epoch 71/100 completed. Loss: 0.084709
# Epoch 72/100 completed. Loss: 0.084647
# Epoch 73/100 completed. Loss: 0.084640
# Epoch 74/100 completed. Loss: 0.084554
# Epoch 75/100 completed. Loss: 0.084574
# Epoch 76/100 completed. Loss: 0.084475
# Epoch 77/100 completed. Loss: 0.084479
# Epoch 78/100 completed. Loss: 0.084402
# Epoch 79/100 completed. Loss: 0.084420
# Epoch 80/100 completed. Loss: 0.084324
# Epoch 81/100 completed. Loss: 0.084346
# Epoch 82/100 completed. Loss: 0.084283
# Epoch 83/100 completed. Loss: 0.084324
# Epoch 84/100 completed. Loss: 0.084241
# Epoch 85/100 completed. Loss: 0.084282
# Epoch 86/100 completed. Loss: 0.084215
# Epoch 87/100 completed. Loss: 0.084278
# Epoch 88/100 completed. Loss: 0.084161
# Epoch 89/100 completed. Loss: 0.084202
# Epoch 90/100 completed. Loss: 0.084117
# Epoch 91/100 completed. Loss: 0.084136
# Epoch 92/100 completed. Loss: 0.084046
# Epoch 93/100 completed. Loss: 0.084078
# Epoch 94/100 completed. Loss: 0.083978
# Epoch 95/100 completed. Loss: 0.084026
# Epoch 96/100 completed. Loss: 0.083917
# Epoch 97/100 completed. Loss: 0.083949
# Epoch 98/100 completed. Loss: 0.083865
# Epoch 99/100 completed. Loss: 0.083859
# Epoch 100/100 completed. Loss: 0.083791
# Training complete for run 6
# Month=1, Predicted=3793.7057, Expected=3766.0000
# Month=2, Predicted=3768.6133, Expected=3747.0000
# Month=3, Predicted=3741.7413, Expected=3754.0000
# Month=4, Predicted=3754.2968, Expected=3756.0000
# Month=5, Predicted=3757.3449, Expected=3767.0000
# Month=6, Predicted=3768.4822, Expected=3751.0000
# Month=7, Predicted=3751.1190, Expected=3769.0000
# Month=8, Predicted=3771.0138, Expected=3760.0000
# Month=9, Predicted=3761.2715, Expected=3785.0000
# Month=10, Predicted=3786.5808, Expected=3776.0000
# Month=11, Predicted=3778.6476, Expected=3755.0000
# Month=12, Predicted=3757.2854, Expected=3755.0000
# Month=13, Predicted=3754.5365, Expected=3751.0000
# Month=14, Predicted=3752.2016, Expected=3776.0000
# Month=15, Predicted=3778.6287, Expected=3847.0000
# Month=16, Predicted=3847.1350, Expected=3830.0000
# Month=17, Predicted=3830.7433, Expected=3881.0000
# Month=18, Predicted=3882.8254, Expected=3899.0000
# Month=19, Predicted=3899.0957, Expected=3917.0000
# Month=20, Predicted=3918.2934, Expected=3913.0000
# Month=21, Predicted=3908.4554, Expected=3901.0000
# Month=22, Predicted=3902.1377, Expected=3886.0000
# Month=23, Predicted=3887.3930, Expected=3892.5000
# Month=24, Predicted=3894.3845, Expected=3899.0000
# Month=25, Predicted=3901.5159, Expected=3886.0000
# Month=26, Predicted=3887.2412, Expected=3908.0000
# Month=27, Predicted=3909.1274, Expected=3875.0000
# Month=28, Predicted=3874.6472, Expected=3860.0000
# Month=29, Predicted=3861.3198, Expected=3880.0000
# Run 6 — RMSE: 87.649797, MSE: 7682.486859, NMSE: 0.0430597970
#
# ===== RUN 7/60 =====
# Epoch 1/100 completed. Loss: 0.093513
# Epoch 2/100 completed. Loss: 0.086054
# Epoch 3/100 completed. Loss: 0.086047
# Epoch 4/100 completed. Loss: 0.086036
# Epoch 5/100 completed. Loss: 0.086022
# Epoch 6/100 completed. Loss: 0.086008
# Epoch 7/100 completed. Loss: 0.085993
# Epoch 8/100 completed. Loss: 0.085978
# Epoch 9/100 completed. Loss: 0.085963
# Epoch 10/100 completed. Loss: 0.085948
# Epoch 11/100 completed. Loss: 0.085934
# Epoch 12/100 completed. Loss: 0.085920
# Epoch 13/100 completed. Loss: 0.085905
# Epoch 14/100 completed. Loss: 0.085891
# Epoch 15/100 completed. Loss: 0.085876
# Epoch 16/100 completed. Loss: 0.085862
# Epoch 17/100 completed. Loss: 0.085847
# Epoch 18/100 completed. Loss: 0.085832
# Epoch 19/100 completed. Loss: 0.085818
# Epoch 20/100 completed. Loss: 0.085803
# Epoch 21/100 completed. Loss: 0.085788
# Epoch 22/100 completed. Loss: 0.085773
# Epoch 23/100 completed. Loss: 0.085758
# Epoch 24/100 completed. Loss: 0.085741
# Epoch 25/100 completed. Loss: 0.085726
# Epoch 26/100 completed. Loss: 0.085711
# Epoch 27/100 completed. Loss: 0.085694
# Epoch 28/100 completed. Loss: 0.085677
# Epoch 29/100 completed. Loss: 0.085660
# Epoch 30/100 completed. Loss: 0.085644
# Epoch 31/100 completed. Loss: 0.085627
# Epoch 32/100 completed. Loss: 0.085610
# Epoch 33/100 completed. Loss: 0.085592
# Epoch 34/100 completed. Loss: 0.085573
# Epoch 35/100 completed. Loss: 0.085549
# Epoch 36/100 completed. Loss: 0.085521
# Epoch 37/100 completed. Loss: 0.085486
# Epoch 38/100 completed. Loss: 0.085465
# Epoch 39/100 completed. Loss: 0.085445
# Epoch 40/100 completed. Loss: 0.085424
# Epoch 41/100 completed. Loss: 0.085404
# Epoch 42/100 completed. Loss: 0.085384
# Epoch 43/100 completed. Loss: 0.085364
# Epoch 44/100 completed. Loss: 0.085344
# Epoch 45/100 completed. Loss: 0.085323
# Epoch 46/100 completed. Loss: 0.085302
# Epoch 47/100 completed. Loss: 0.085280
# Epoch 48/100 completed. Loss: 0.085258
# Epoch 49/100 completed. Loss: 0.085236
# Epoch 50/100 completed. Loss: 0.085212
# Epoch 51/100 completed. Loss: 0.085190
# Epoch 52/100 completed. Loss: 0.085166
# Epoch 53/100 completed. Loss: 0.085142
# Epoch 54/100 completed. Loss: 0.085119
# Epoch 55/100 completed. Loss: 0.085093
# Epoch 56/100 completed. Loss: 0.085071
# Epoch 57/100 completed. Loss: 0.085045
# Epoch 58/100 completed. Loss: 0.085026
# Epoch 59/100 completed. Loss: 0.084994
# Epoch 60/100 completed. Loss: 0.084976
# Epoch 61/100 completed. Loss: 0.084945
# Epoch 62/100 completed. Loss: 0.084931
# Epoch 63/100 completed. Loss: 0.084895
# Epoch 64/100 completed. Loss: 0.084881
# Epoch 65/100 completed. Loss: 0.084845
# Epoch 66/100 completed. Loss: 0.084836
# Epoch 67/100 completed. Loss: 0.084796
# Epoch 68/100 completed. Loss: 0.084788
# Epoch 69/100 completed. Loss: 0.084748
# Epoch 70/100 completed. Loss: 0.084743
# Epoch 71/100 completed. Loss: 0.084700
# Epoch 72/100 completed. Loss: 0.084697
# Epoch 73/100 completed. Loss: 0.084653
# Epoch 74/100 completed. Loss: 0.084654
# Epoch 75/100 completed. Loss: 0.084608
# Epoch 76/100 completed. Loss: 0.084613
# Epoch 77/100 completed. Loss: 0.084567
# Epoch 78/100 completed. Loss: 0.084576
# Epoch 79/100 completed. Loss: 0.084529
# Epoch 80/100 completed. Loss: 0.084540
# Epoch 81/100 completed. Loss: 0.084493
# Epoch 82/100 completed. Loss: 0.084507
# Epoch 83/100 completed. Loss: 0.084459
# Epoch 84/100 completed. Loss: 0.084475
# Epoch 85/100 completed. Loss: 0.084433
# Epoch 86/100 completed. Loss: 0.084440
# Epoch 87/100 completed. Loss: 0.084390
# Epoch 88/100 completed. Loss: 0.084400
# Epoch 89/100 completed. Loss: 0.084354
# Epoch 90/100 completed. Loss: 0.084365
# Epoch 91/100 completed. Loss: 0.084323
# Epoch 92/100 completed. Loss: 0.084333
# Epoch 93/100 completed. Loss: 0.084294
# Epoch 94/100 completed. Loss: 0.084306
# Epoch 95/100 completed. Loss: 0.084269
# Epoch 96/100 completed. Loss: 0.084285
# Epoch 97/100 completed. Loss: 0.084244
# Epoch 98/100 completed. Loss: 0.084269
# Epoch 99/100 completed. Loss: 0.084221
# Epoch 100/100 completed. Loss: 0.084251
# Training complete for run 7
# Month=1, Predicted=3793.9725, Expected=3766.0000
# Month=2, Predicted=3767.4826, Expected=3747.0000
# Month=3, Predicted=3743.4291, Expected=3754.0000
# Month=4, Predicted=3751.4838, Expected=3756.0000
# Month=5, Predicted=3758.2367, Expected=3767.0000
# Month=6, Predicted=3767.8551, Expected=3751.0000
# Month=7, Predicted=3753.8386, Expected=3769.0000
# Month=8, Predicted=3771.6915, Expected=3760.0000
# Month=9, Predicted=3762.0277, Expected=3785.0000
# Month=10, Predicted=3785.4356, Expected=3776.0000
# Month=11, Predicted=3776.9884, Expected=3755.0000
# Month=12, Predicted=3756.1392, Expected=3755.0000
# Month=13, Predicted=3753.0724, Expected=3751.0000
# Month=14, Predicted=3754.1149, Expected=3776.0000
# Month=15, Predicted=3777.8272, Expected=3847.0000
# Month=16, Predicted=3846.4838, Expected=3830.0000
# Month=17, Predicted=3832.7290, Expected=3881.0000
# Month=18, Predicted=3883.5267, Expected=3899.0000
# Month=19, Predicted=3899.0309, Expected=3917.0000
# Month=20, Predicted=3917.0413, Expected=3913.0000
# Month=21, Predicted=3909.4615, Expected=3901.0000
# Month=22, Predicted=3897.6102, Expected=3886.0000
# Month=23, Predicted=3887.5088, Expected=3892.5000
# Month=24, Predicted=3893.5771, Expected=3899.0000
# Month=25, Predicted=3900.6530, Expected=3886.0000
# Month=26, Predicted=3888.8494, Expected=3908.0000
# Month=27, Predicted=3909.0668, Expected=3875.0000
# Month=28, Predicted=3873.4660, Expected=3860.0000
# Month=29, Predicted=3863.5077, Expected=3880.0000
# Run 7 — RMSE: 87.804517, MSE: 7709.633255, NMSE: 0.0432830160
#
# ===== RUN 8/60 =====
# Epoch 1/100 completed. Loss: 0.101872
# Epoch 2/100 completed. Loss: 0.085990
# Epoch 3/100 completed. Loss: 0.085816
# Epoch 4/100 completed. Loss: 0.085719
# Epoch 5/100 completed. Loss: 0.085678
# Epoch 6/100 completed. Loss: 0.085672
# Epoch 7/100 completed. Loss: 0.085685
# Epoch 8/100 completed. Loss: 0.085712
# Epoch 9/100 completed. Loss: 0.085745
# Epoch 10/100 completed. Loss: 0.085781
# Epoch 11/100 completed. Loss: 0.085816
# Epoch 12/100 completed. Loss: 0.085849
# Epoch 13/100 completed. Loss: 0.085879
# Epoch 14/100 completed. Loss: 0.085905
# Epoch 15/100 completed. Loss: 0.085927
# Epoch 16/100 completed. Loss: 0.085945
# Epoch 17/100 completed. Loss: 0.085960
# Epoch 18/100 completed. Loss: 0.085973
# Epoch 19/100 completed. Loss: 0.085982
# Epoch 20/100 completed. Loss: 0.085989
# Epoch 21/100 completed. Loss: 0.085994
# Epoch 22/100 completed. Loss: 0.085997
# Epoch 23/100 completed. Loss: 0.085999
# Epoch 24/100 completed. Loss: 0.085975
# Epoch 25/100 completed. Loss: 0.085972
# Epoch 26/100 completed. Loss: 0.085969
# Epoch 27/100 completed. Loss: 0.085963
# Epoch 28/100 completed. Loss: 0.085960
# Epoch 29/100 completed. Loss: 0.085955
# Epoch 30/100 completed. Loss: 0.085951
# Epoch 31/100 completed. Loss: 0.085946
# Epoch 32/100 completed. Loss: 0.085941
# Epoch 33/100 completed. Loss: 0.085936
# Epoch 34/100 completed. Loss: 0.085930
# Epoch 35/100 completed. Loss: 0.085924
# Epoch 36/100 completed. Loss: 0.085917
# Epoch 37/100 completed. Loss: 0.085911
# Epoch 38/100 completed. Loss: 0.085904
# Epoch 39/100 completed. Loss: 0.085896
# Epoch 40/100 completed. Loss: 0.085889
# Epoch 41/100 completed. Loss: 0.085881
# Epoch 42/100 completed. Loss: 0.085873
# Epoch 43/100 completed. Loss: 0.085865
# Epoch 44/100 completed. Loss: 0.085857
# Epoch 45/100 completed. Loss: 0.085849
# Epoch 46/100 completed. Loss: 0.085840
# Epoch 47/100 completed. Loss: 0.085830
# Epoch 48/100 completed. Loss: 0.085820
# Epoch 49/100 completed. Loss: 0.085810
# Epoch 50/100 completed. Loss: 0.085801
# Epoch 51/100 completed. Loss: 0.085791
# Epoch 52/100 completed. Loss: 0.085782
# Epoch 53/100 completed. Loss: 0.085772
# Epoch 54/100 completed. Loss: 0.085762
# Epoch 55/100 completed. Loss: 0.085752
# Epoch 56/100 completed. Loss: 0.085742
# Epoch 57/100 completed. Loss: 0.085731
# Epoch 58/100 completed. Loss: 0.085720
# Epoch 59/100 completed. Loss: 0.085709
# Epoch 60/100 completed. Loss: 0.085698
# Epoch 61/100 completed. Loss: 0.085686
# Epoch 62/100 completed. Loss: 0.085675
# Epoch 63/100 completed. Loss: 0.085663
# Epoch 64/100 completed. Loss: 0.085650
# Epoch 65/100 completed. Loss: 0.085638
# Epoch 66/100 completed. Loss: 0.085624
# Epoch 67/100 completed. Loss: 0.085611
# Epoch 68/100 completed. Loss: 0.085596
# Epoch 69/100 completed. Loss: 0.085581
# Epoch 70/100 completed. Loss: 0.085565
# Epoch 71/100 completed. Loss: 0.085547
# Epoch 72/100 completed. Loss: 0.085527
# Epoch 73/100 completed. Loss: 0.085506
# Epoch 74/100 completed. Loss: 0.085482
# Epoch 75/100 completed. Loss: 0.085455
# Epoch 76/100 completed. Loss: 0.085424
# Epoch 77/100 completed. Loss: 0.085395
# Epoch 78/100 completed. Loss: 0.085363
# Epoch 79/100 completed. Loss: 0.085338
# Epoch 80/100 completed. Loss: 0.085303
# Epoch 81/100 completed. Loss: 0.085279
# Epoch 82/100 completed. Loss: 0.085237
# Epoch 83/100 completed. Loss: 0.085222
# Epoch 84/100 completed. Loss: 0.085164
# Epoch 85/100 completed. Loss: 0.085176
# Epoch 86/100 completed. Loss: 0.085116
# Epoch 87/100 completed. Loss: 0.085104
# Epoch 88/100 completed. Loss: 0.085038
# Epoch 89/100 completed. Loss: 0.085081
# Epoch 90/100 completed. Loss: 0.084937
# Epoch 91/100 completed. Loss: 0.084968
# Epoch 92/100 completed. Loss: 0.084841
# Epoch 93/100 completed. Loss: 0.084890
# Epoch 94/100 completed. Loss: 0.084751
# Epoch 95/100 completed. Loss: 0.084820
# Epoch 96/100 completed. Loss: 0.084673
# Epoch 97/100 completed. Loss: 0.084751
# Epoch 98/100 completed. Loss: 0.084594
# Epoch 99/100 completed. Loss: 0.084690
# Epoch 100/100 completed. Loss: 0.084514
# Training complete for run 8
# Month=1, Predicted=3793.6433, Expected=3766.0000
# Month=2, Predicted=3766.7110, Expected=3747.0000
# Month=3, Predicted=3745.0167, Expected=3754.0000
# Month=4, Predicted=3754.0584, Expected=3756.0000
# Month=5, Predicted=3757.0468, Expected=3767.0000
# Month=6, Predicted=3773.8058, Expected=3751.0000
# Month=7, Predicted=3754.1915, Expected=3769.0000
# Month=8, Predicted=3771.5450, Expected=3760.0000
# Month=9, Predicted=3761.1430, Expected=3785.0000
# Month=10, Predicted=3784.2584, Expected=3776.0000
# Month=11, Predicted=3777.7894, Expected=3755.0000
# Month=12, Predicted=3756.5052, Expected=3755.0000
# Month=13, Predicted=3756.8543, Expected=3751.0000
# Month=14, Predicted=3753.5524, Expected=3776.0000
# Month=15, Predicted=3778.4741, Expected=3847.0000
# Month=16, Predicted=3850.5973, Expected=3830.0000
# Month=17, Predicted=3832.3589, Expected=3881.0000
# Month=18, Predicted=3882.8438, Expected=3899.0000
# Month=19, Predicted=3896.4057, Expected=3917.0000
# Month=20, Predicted=3918.0885, Expected=3913.0000
# Month=21, Predicted=3911.0898, Expected=3901.0000
# Month=22, Predicted=3901.3487, Expected=3886.0000
# Month=23, Predicted=3886.6674, Expected=3892.5000
# Month=24, Predicted=3892.9868, Expected=3899.0000
# Month=25, Predicted=3899.5391, Expected=3886.0000
# Month=26, Predicted=3886.9984, Expected=3908.0000
# Month=27, Predicted=3909.0365, Expected=3875.0000
# Month=28, Predicted=3876.5473, Expected=3860.0000
# Month=29, Predicted=3862.3826, Expected=3880.0000
# Run 8 — RMSE: 87.405147, MSE: 7639.659766, NMSE: 0.0434873140
#
# ===== RUN 9/60 =====
# Epoch 1/100 completed. Loss: 0.112765
# Epoch 2/100 completed. Loss: 0.085930
# Epoch 3/100 completed. Loss: 0.085968
# Epoch 4/100 completed. Loss: 0.085989
# Epoch 5/100 completed. Loss: 0.086002
# Epoch 6/100 completed. Loss: 0.086013
# Epoch 7/100 completed. Loss: 0.086026
# Epoch 8/100 completed. Loss: 0.086028
# Epoch 9/100 completed. Loss: 0.086033
# Epoch 10/100 completed. Loss: 0.086040
# Epoch 11/100 completed. Loss: 0.086039
# Epoch 12/100 completed. Loss: 0.086043
# Epoch 13/100 completed. Loss: 0.086055
# Epoch 14/100 completed. Loss: 0.086041
# Epoch 15/100 completed. Loss: 0.086046
# Epoch 16/100 completed. Loss: 0.086048
# Epoch 17/100 completed. Loss: 0.086044
# Epoch 18/100 completed. Loss: 0.086057
# Epoch 19/100 completed. Loss: 0.086040
# Epoch 20/100 completed. Loss: 0.086044
# Epoch 21/100 completed. Loss: 0.086029
# Epoch 22/100 completed. Loss: 0.086035
# Epoch 23/100 completed. Loss: 0.086022
# Epoch 24/100 completed. Loss: 0.086025
# Epoch 25/100 completed. Loss: 0.086011
# Epoch 26/100 completed. Loss: 0.086009
# Epoch 27/100 completed. Loss: 0.085998
# Epoch 28/100 completed. Loss: 0.085994
# Epoch 29/100 completed. Loss: 0.085985
# Epoch 30/100 completed. Loss: 0.085978
# Epoch 31/100 completed. Loss: 0.085970
# Epoch 32/100 completed. Loss: 0.085963
# Epoch 33/100 completed. Loss: 0.085957
# Epoch 34/100 completed. Loss: 0.085952
# Epoch 35/100 completed. Loss: 0.085947
# Epoch 36/100 completed. Loss: 0.085942
# Epoch 37/100 completed. Loss: 0.085936
# Epoch 38/100 completed. Loss: 0.085928
# Epoch 39/100 completed. Loss: 0.085921
# Epoch 40/100 completed. Loss: 0.085912
# Epoch 77/100 completed. Loss: 0.085753
# Epoch 78/100 completed. Loss: 0.085747
# Epoch 79/100 completed. Loss: 0.085741
# Epoch 80/100 completed. Loss: 0.085735
# Epoch 81/100 completed. Loss: 0.085729
# Epoch 82/100 completed. Loss: 0.085722
# Epoch 83/100 completed. Loss: 0.085715
# Epoch 84/100 completed. Loss: 0.085708
# Epoch 85/100 completed. Loss: 0.085701
# Epoch 86/100 completed. Loss: 0.085693
# Epoch 87/100 completed. Loss: 0.085686
# Epoch 88/100 completed. Loss: 0.085678
# Epoch 89/100 completed. Loss: 0.085670
# Epoch 90/100 completed. Loss: 0.085663
# Epoch 91/100 completed. Loss: 0.085655
# Epoch 92/100 completed. Loss: 0.085647
# Epoch 93/100 completed. Loss: 0.085639
# Epoch 94/100 completed. Loss: 0.085631
# Epoch 95/100 completed. Loss: 0.085623
# Epoch 96/100 completed. Loss: 0.085615
# Epoch 97/100 completed. Loss: 0.085607
# Epoch 98/100 completed. Loss: 0.085598
# Epoch 99/100 completed. Loss: 0.085590
# Epoch 100/100 completed. Loss: 0.085582
# Training complete for run 58
# Month=1, Predicted=3793.5477, Expected=3766.0000
# Month=2, Predicted=3766.5716, Expected=3747.0000
# Month=3, Predicted=3745.8072, Expected=3754.0000
# Month=4, Predicted=3755.5510, Expected=3756.0000
# Month=5, Predicted=3757.2571, Expected=3767.0000
# Month=6, Predicted=3770.5015, Expected=3751.0000
# Month=7, Predicted=3753.0410, Expected=3769.0000
# Month=8, Predicted=3770.7471, Expected=3760.0000
# Month=9, Predicted=3761.3890, Expected=3785.0000
# Month=10, Predicted=3785.5194, Expected=3776.0000
# Month=11, Predicted=3776.5623, Expected=3755.0000
# Month=12, Predicted=3755.5928, Expected=3755.0000
# Month=13, Predicted=3756.9909, Expected=3751.0000
# Month=14, Predicted=3752.7986, Expected=3776.0000
# Month=15, Predicted=3777.0972, Expected=3847.0000
# Month=16, Predicted=3849.7800, Expected=3830.0000
# Month=17, Predicted=3831.8978, Expected=3881.0000
# Month=18, Predicted=3882.6264, Expected=3899.0000
# Month=19, Predicted=3899.3799, Expected=3917.0000
# Month=20, Predicted=3917.1323, Expected=3913.0000
# Month=21, Predicted=3911.8656, Expected=3901.0000
# Month=22, Predicted=3901.9660, Expected=3886.0000
# Month=23, Predicted=3886.7785, Expected=3892.5000
# Month=24, Predicted=3892.9271, Expected=3899.0000
# Month=25, Predicted=3899.6035, Expected=3886.0000
# Month=26, Predicted=3887.3838, Expected=3908.0000
# Month=27, Predicted=3908.5827, Expected=3875.0000
# Month=28, Predicted=3876.9933, Expected=3860.0000
# Month=29, Predicted=3862.0688, Expected=3880.0000
# Run 58 — RMSE: 87.517944, MSE: 7659.390452, NMSE: 0.0432735554
#
# ===== RUN 59/60 =====
# Epoch 1/100 completed. Loss: 0.086063
# Epoch 2/100 completed. Loss: 0.085899
# Epoch 3/100 completed. Loss: 0.085919
# Epoch 4/100 completed. Loss: 0.085949
# Epoch 71/100 completed. Loss: 0.085997
# Epoch 72/100 completed. Loss: 0.085988
# Epoch 73/100 completed. Loss: 0.085979
# Epoch 74/100 completed. Loss: 0.085969
# Epoch 75/100 completed. Loss: 0.085959
# Epoch 76/100 completed. Loss: 0.085949
# Epoch 77/100 completed. Loss: 0.085937
# Epoch 78/100 completed. Loss: 0.085925
# Epoch 79/100 completed. Loss: 0.085913
# Epoch 80/100 completed. Loss: 0.085899
# Epoch 81/100 completed. Loss: 0.085885
# Epoch 82/100 completed. Loss: 0.085870
# Epoch 83/100 completed. Loss: 0.085854
# Epoch 84/100 completed. Loss: 0.085838
# Epoch 85/100 completed. Loss: 0.085821
# Epoch 86/100 completed. Loss: 0.085804
# Epoch 87/100 completed. Loss: 0.085788
# Epoch 88/100 completed. Loss: 0.085771
# Epoch 89/100 completed. Loss: 0.085754
# Epoch 90/100 completed. Loss: 0.085737
# Epoch 91/100 completed. Loss: 0.085721
# Epoch 92/100 completed. Loss: 0.085707
# Epoch 93/100 completed. Loss: 0.085695
# Epoch 94/100 completed. Loss: 0.085686
# Epoch 95/100 completed. Loss: 0.085680
# Epoch 96/100 completed. Loss: 0.085675
# Epoch 97/100 completed. Loss: 0.085671
# Epoch 98/100 completed. Loss: 0.085667
# Epoch 99/100 completed. Loss: 0.085662
# Epoch 100/100 completed. Loss: 0.085657
# Training complete for run 59
# Month=1, Predicted=3793.1447, Expected=3766.0000
# Month=2, Predicted=3766.3601, Expected=3747.0000
# Month=3, Predicted=3745.6624, Expected=3754.0000
# Month=4, Predicted=3755.5462, Expected=3756.0000
# Month=5, Predicted=3756.6554, Expected=3767.0000
# Month=6, Predicted=3770.9961, Expected=3751.0000
# Month=7, Predicted=3752.4711, Expected=3769.0000
# Month=8, Predicted=3770.8329, Expected=3760.0000
# Month=9, Predicted=3761.5545, Expected=3785.0000
# Month=10, Predicted=3785.7347, Expected=3776.0000
# Month=11, Predicted=3776.6843, Expected=3755.0000
# Month=12, Predicted=3755.5096, Expected=3755.0000
# Month=13, Predicted=3756.8299, Expected=3751.0000
# Month=14, Predicted=3752.4071, Expected=3776.0000
# Month=15, Predicted=3776.9654, Expected=3847.0000
# Month=16, Predicted=3849.9502, Expected=3830.0000
# Month=17, Predicted=3831.5710, Expected=3881.0000
# Month=18, Predicted=3882.6542, Expected=3899.0000
# Month=19, Predicted=3899.5458, Expected=3917.0000
# Month=20, Predicted=3917.3065, Expected=3913.0000
# Month=21, Predicted=3911.8845, Expected=3901.0000
# Month=22, Predicted=3901.8357, Expected=3886.0000
# Month=23, Predicted=3886.2540, Expected=3892.5000
# Month=24, Predicted=3892.6603, Expected=3899.0000
# Month=25, Predicted=3899.3907, Expected=3886.0000
# Month=26, Predicted=3887.1189, Expected=3908.0000
# Month=27, Predicted=3908.3209, Expected=3875.0000
# Month=28, Predicted=3876.9133, Expected=3860.0000
# Month=29, Predicted=3861.7278, Expected=3880.0000
# Run 59 — RMSE: 87.615710, MSE: 7676.512642, NMSE: 0.0432868237
#
# ===== RUN 60/60 =====
# Epoch 1/100 completed. Loss: 0.135692
# Epoch 2/100 completed. Loss: 0.085558
# Epoch 3/100 completed. Loss: 0.085540
# Epoch 4/100 completed. Loss: 0.085524
# Epoch 5/100 completed. Loss: 0.085517
# Epoch 6/100 completed. Loss: 0.085518
# Epoch 7/100 completed. Loss: 0.085523
# Epoch 8/100 completed. Loss: 0.085533
# Epoch 9/100 completed. Loss: 0.085546
# Epoch 10/100 completed. Loss: 0.085560
# Epoch 11/100 completed. Loss: 0.085576
# Epoch 12/100 completed. Loss: 0.085593
# Epoch 13/100 completed. Loss: 0.085611
# Epoch 14/100 completed. Loss: 0.085630
# Epoch 15/100 completed. Loss: 0.085648
# Epoch 16/100 completed. Loss: 0.085666
# Epoch 17/100 completed. Loss: 0.085684
# Epoch 18/100 completed. Loss: 0.085701
# Epoch 19/100 completed. Loss: 0.085717
# Epoch 20/100 completed. Loss: 0.085733
# Epoch 21/100 completed. Loss: 0.085748
# Epoch 22/100 completed. Loss: 0.085763
# Epoch 23/100 completed. Loss: 0.085776
# Epoch 24/100 completed. Loss: 0.085789
# Epoch 25/100 completed. Loss: 0.085800
# Epoch 26/100 completed. Loss: 0.085810
# Epoch 27/100 completed. Loss: 0.085818
# Epoch 28/100 completed. Loss: 0.085826
# Epoch 29/100 completed. Loss: 0.085832
# Epoch 30/100 completed. Loss: 0.085838
# Epoch 31/100 completed. Loss: 0.085842
# Epoch 32/100 completed. Loss: 0.085846
# Epoch 33/100 completed. Loss: 0.085848
# Epoch 34/100 completed. Loss: 0.085850
# Epoch 35/100 completed. Loss: 0.085851
# Epoch 36/100 completed. Loss: 0.085851
# Epoch 37/100 completed. Loss: 0.085852
# Epoch 38/100 completed. Loss: 0.085852
# Epoch 39/100 completed. Loss: 0.085851
# Epoch 40/100 completed. Loss: 0.085851
# Epoch 41/100 completed. Loss: 0.085850
# Epoch 42/100 completed. Loss: 0.085850
# Epoch 43/100 completed. Loss: 0.085849
# Epoch 44/100 completed. Loss: 0.085849
# Epoch 45/100 completed. Loss: 0.085848
# Epoch 46/100 completed. Loss: 0.085848
# Epoch 47/100 completed. Loss: 0.085847
# Epoch 48/100 completed. Loss: 0.085847
# Epoch 49/100 completed. Loss: 0.085846
# Epoch 50/100 completed. Loss: 0.085844
# Epoch 51/100 completed. Loss: 0.085843
# Epoch 52/100 completed. Loss: 0.085841
# Epoch 53/100 completed. Loss: 0.085839
# Epoch 54/100 completed. Loss: 0.085837
# Epoch 55/100 completed. Loss: 0.085835
# Epoch 56/100 completed. Loss: 0.085832
# Epoch 57/100 completed. Loss: 0.085829
# Epoch 58/100 completed. Loss: 0.085826
# Epoch 59/100 completed. Loss: 0.085822
# Epoch 60/100 completed. Loss: 0.085819
# Epoch 61/100 completed. Loss: 0.085815
# Epoch 62/100 completed. Loss: 0.085810
# Epoch 63/100 completed. Loss: 0.085806
# Epoch 64/100 completed. Loss: 0.085801
# Epoch 65/100 completed. Loss: 0.085796
# Epoch 66/100 completed. Loss: 0.085791
# Epoch 67/100 completed. Loss: 0.085785
# Epoch 68/100 completed. Loss: 0.085779
# Epoch 69/100 completed. Loss: 0.085773
# Epoch 70/100 completed. Loss: 0.085767
# Epoch 71/100 completed. Loss: 0.085760
# Epoch 72/100 completed. Loss: 0.085753
# Epoch 73/100 completed. Loss: 0.085746
# Epoch 74/100 completed. Loss: 0.085739
# Epoch 75/100 completed. Loss: 0.085732
# Epoch 76/100 completed. Loss: 0.085724
# Epoch 77/100 completed. Loss: 0.085717
# Epoch 78/100 completed. Loss: 0.085709
# Epoch 79/100 completed. Loss: 0.085702
# Epoch 80/100 completed. Loss: 0.085694
# Epoch 81/100 completed. Loss: 0.085686
# Epoch 82/100 completed. Loss: 0.085679
# Epoch 83/100 completed. Loss: 0.085672
# Epoch 84/100 completed. Loss: 0.085665
# Epoch 85/100 completed. Loss: 0.085658
# Epoch 86/100 completed. Loss: 0.085651
# Epoch 87/100 completed. Loss: 0.085645
# Epoch 88/100 completed. Loss: 0.085639
# Epoch 89/100 completed. Loss: 0.085633
# Epoch 90/100 completed. Loss: 0.085628
# Epoch 91/100 completed. Loss: 0.085623
# Epoch 92/100 completed. Loss: 0.085619
# Epoch 93/100 completed. Loss: 0.085615
# Epoch 94/100 completed. Loss: 0.085612
# Epoch 95/100 completed. Loss: 0.085609
# Epoch 96/100 completed. Loss: 0.085606
# Epoch 97/100 completed. Loss: 0.085604
# Epoch 98/100 completed. Loss: 0.085602
# Epoch 99/100 completed. Loss: 0.085600
# Epoch 100/100 completed. Loss: 0.085599
# Training complete for run 60
# Month=1, Predicted=3793.3134, Expected=3766.0000
# Month=2, Predicted=3766.5591, Expected=3747.0000
# Month=3, Predicted=3743.7863, Expected=3754.0000
# Month=4, Predicted=3756.0393, Expected=3756.0000
# Month=5, Predicted=3757.2373, Expected=3767.0000
# Month=6, Predicted=3770.2562, Expected=3751.0000
# Month=7, Predicted=3752.9908, Expected=3769.0000
# Month=8, Predicted=3770.8841, Expected=3760.0000
# Month=9, Predicted=3761.5599, Expected=3785.0000
# Month=10, Predicted=3785.4263, Expected=3776.0000
# Month=11, Predicted=3776.6372, Expected=3755.0000
# Month=12, Predicted=3755.6233, Expected=3755.0000
# Month=13, Predicted=3757.3311, Expected=3751.0000
# Month=14, Predicted=3752.9522, Expected=3776.0000
# Month=15, Predicted=3777.1684, Expected=3847.0000
# Month=16, Predicted=3849.8865, Expected=3830.0000
# Month=17, Predicted=3831.9694, Expected=3881.0000
# Month=18, Predicted=3882.8087, Expected=3899.0000
# Month=19, Predicted=3899.1619, Expected=3917.0000
# Month=20, Predicted=3916.9766, Expected=3913.0000
# Month=21, Predicted=3910.1804, Expected=3901.0000
# Month=22, Predicted=3902.3729, Expected=3886.0000
# Month=23, Predicted=3886.6440, Expected=3892.5000
# Month=24, Predicted=3892.7302, Expected=3899.0000
# Month=25, Predicted=3899.6200, Expected=3886.0000
# Month=26, Predicted=3887.6769, Expected=3908.0000
# Month=27, Predicted=3908.4007, Expected=3875.0000
# Month=28, Predicted=3877.3325, Expected=3860.0000
# Month=29, Predicted=3862.2305, Expected=3880.0000
# Run 60 — RMSE: 87.601152, MSE: 7673.961918, NMSE: 0.0433212521
#
# --- σ=1.0 Summary ---
# RMSE: 87.539510 ± 0.089462
# MSE:  7663.173805 ± 15.663355
# NMSE: 0.0432327706 ± 0.0001192426

# %% [markdown]
# ## Results

# %%
# ============================================================
# Summary: All Sigma Results Comparison
# ============================================================

print('\n' + '='*70)
print('  COMPLETE SIGMA SENSITIVITY ANALYSIS')
print('  σ values: 0.25, 0.5, 0.75, 1.0')
print('='*70)

print(f'\n{"σ":>6} | {"RMSE (mean ± std)":>25} | {"MSE (mean ± std)":>25} | {"NMSE (mean ± std)":>30}')
print('-'*95)

for sigma_val in SIGMA_VALUES:
    r = sigma_results[sigma_val]
    print(f'{sigma_val:>6.2f} | '
          f'{r["mean_rmse"]:>10.6f} ± {r["std_rmse"]:<10.6f} | '
          f'{r["mean_mse"]:>10.6f} ± {r["std_mse"]:<10.6f} | '
          f'{r["mean_nmse"]:>13.10f} ± {r["std_nmse"]:<13.10f}')

print('\n' + '-'*95)

# Find best sigma
best_sigma = min(SIGMA_VALUES, key=lambda s: sigma_results[s]['mean_rmse'])
print(f'\nBest σ (lowest mean RMSE): {best_sigma}')
print(f'  RMSE: {sigma_results[best_sigma]["mean_rmse"]:.6f} ± {sigma_results[best_sigma]["std_rmse"]:.6f}')
print(f'  MSE:  {sigma_results[best_sigma]["mean_mse"]:.6f} ± {sigma_results[best_sigma]["std_mse"]:.6f}')
print(f'  NMSE: {sigma_results[best_sigma]["mean_nmse"]:.10f} ± {sigma_results[best_sigma]["std_nmse"]:.10f}')

print('\n--- Per-Sigma Best Run Details ---')
for sigma_val in SIGMA_VALUES:
    r = sigma_results[sigma_val]
    print(f'  σ={sigma_val:.2f}: Best run #{r["best_idx"]+1}, RMSE={r["best_rmse"]:.6f}')
# Out:
# ======================================================================
#   COMPLETE SIGMA SENSITIVITY ANALYSIS
#   σ values: 0.25, 0.5, 0.75, 1.0
# ======================================================================
#
#      σ |         RMSE (mean ± std) |          MSE (mean ± std) |              NMSE (mean ± std)
# -----------------------------------------------------------------------------------------------
#   0.25 |  87.499714 ± 0.183979   | 7656.233776 ± 32.212495  |  0.0433048246 ± 0.0001632081
#   0.50 |  87.602048 ± 0.129284   | 7674.135576 ± 22.662853  |  0.0432733940 ± 0.0001505994
#   0.75 |  87.558292 ± 0.096065   | 7666.463734 ± 16.828264  |  0.0432441657 ± 0.0001190660
#   1.00 |  87.539510 ± 0.089462   | 7663.173805 ± 15.663355  |  0.0432327706 ± 0.0001192426
#
# -----------------------------------------------------------------------------------------------
#
# Best σ (lowest mean RMSE): 0.25
#   RMSE: 87.499714 ± 0.183979
#   MSE:  7656.233776 ± 32.212495
#   NMSE: 0.0433048246 ± 0.0001632081
#
# --- Per-Sigma Best Run Details ---
#   σ=0.25: Best run #32, RMSE=87.053964
#   σ=0.50: Best run #56, RMSE=87.381580
#   σ=0.75: Best run #21, RMSE=87.380361
#   σ=1.00: Best run #41, RMSE=87.344869

# %%
# Use best sigma's results for plotting
best_sigma_key = min(sigma_results.keys(), key=lambda s: sigma_results[s]['mean_rmse'])
best_sigma_data = sigma_results[best_sigma_key]
best_idx = best_sigma_data['best_idx']
all_predictions = best_sigma_data['predictions']
all_rmse = best_sigma_data['rmse']
all_mse = best_sigma_data['mse']
all_nmse = best_sigma_data['nmse']

# ============================================================
# Predictions vs Actual (Best Run)
# ============================================================

actual = raw_values[-60:]
best_predictions = all_predictions[best_idx]

plt.figure(figsize=(12, 5))
plt.plot(actual, label='Actual', color='blue', linewidth=1.5)
plt.plot(best_predictions, label='Predicted (Best Run)', color='red',
         linewidth=1.5, linestyle='--')
plt.title('Fuzzy Gate Replacement — Dow Jones Industrial Index\nPredictions vs Actual (Best of 1 run)')
plt.xlabel('Time Step')
plt.ylabel('Value')
plt.legend()
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

# ============================================================
# Loss Curve (Best Run)
# ============================================================

plt.figure(figsize=(12, 4))
plt.plot(all_losses[best_idx], color='green', linewidth=1.0)
plt.title('Fuzzy Gate Replacement — Dow Jones Industrial Index\nTraining Loss (Best Run)')
plt.xlabel('Epoch')
plt.ylabel('MSE Loss')
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

# ============================================================
# Final Metrics Summary
# ============================================================

print('=== Best Run Metrics ===')
print(f'RMSE: {all_rmse[best_idx]:.6f}')
print(f'MSE:  {all_mse[best_idx]:.6f}')
print(f'NMSE: {all_nmse[best_idx]:.10f}')
print(f'sMAPE: {all_smape[best_idx]:.6f}')
# Out:
# === Best Run Metrics ===
# RMSE: 87.053964
# MSE:  7578.392675
# NMSE: 0.0434341812
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[20], line 50
#      46 print('=== Best Run Metrics ===')
#      47 print(f'RMSE: {all_rmse[best_idx]:.6f}')
#      48 print(f'MSE:  {all_mse[best_idx]:.6f}')
#      49 print(f'NMSE: {all_nmse[best_idx]:.10f}')
# ---> 50 print(f'sMAPE: {all_smape[best_idx]:.6f}')
#
# NameError: name 'all_smape' is not defined

# %%
# Use best sigma's results for plotting
best_sigma_key = min(sigma_results.keys(), key=lambda s: sigma_results[s]['mean_rmse'])
best_sigma_data = sigma_results[best_sigma_key]
best_idx = best_sigma_data['best_idx']
all_predictions = best_sigma_data['predictions']
all_rmse = best_sigma_data['rmse']
all_mse = best_sigma_data['mse']
all_nmse = best_sigma_data['nmse']

# ============================================================
# Predictions vs Actual (Best Run)
# ============================================================
best_predictions = all_predictions[best_idx]
actual = raw_values[-len(best_predictions):]

plt.figure(figsize=(12, 5))
plt.plot(actual, label='Actual', color='blue', linewidth=1.5)
plt.plot(best_predictions, label='Predicted (Best Run)', color='red',
         linewidth=1.5, linestyle='--')
plt.title(f'Fuzzy Gate Replacement — Dow Jones Industrial Index\n'
          f'Predictions vs Actual (Best Run, σ={best_sigma_key}, Best of {N_RUNS} runs)')
plt.xlabel('Time Step')
plt.ylabel('Value')
plt.legend()
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

# ============================================================
# Final Metrics Summary
# ============================================================
print(f'=== Best Run Metrics (σ={best_sigma_key}) ===')
print(f'RMSE: {all_rmse[best_idx]:.6f}')
print(f'MSE:  {all_mse[best_idx]:.6f}')
print(f'NMSE: {all_nmse[best_idx]:.10f}')
# Out:
# === Best Run Metrics (σ=0.25) ===
# RMSE: 87.053964
# MSE:  7578.392675
# NMSE: 0.0434341812

# %%
# Use best sigma's results for plotting
best_sigma_key = min(sigma_results.keys(), key=lambda s: sigma_results[s]['mean_rmse'])
best_sigma_data = sigma_results[best_sigma_key]
best_idx = best_sigma_data['best_idx']
all_predictions = best_sigma_data['predictions']
all_rmse = best_sigma_data['rmse']
all_mse = best_sigma_data['mse']
all_nmse = best_sigma_data['nmse']

# ============================================================
# Predictions vs Actual (Best Run)
# ============================================================
actual = raw_values[-60:]
best_predictions = all_predictions[best_idx]

assert len(best_predictions) == len(actual), (
    f"Shape mismatch: predictions len={len(best_predictions)} vs actual len={len(actual)}"
)

plt.figure(figsize=(12, 5))
plt.plot(actual, label='Actual', color='blue', linewidth=1.5)
plt.plot(best_predictions, label='Predicted (Best Run)', color='red',
         linewidth=1.5, linestyle='--')
plt.title('Fuzzy Gate Replacement — Dow Jones Industrial Index\nPredictions vs Actual (Best of 1 run)')
plt.xlabel('Time Step')
plt.ylabel('Value')
plt.legend()
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

# ============================================================
# Loss Curve (Best Run)
# ============================================================
# NOTE: training loss history is not stored in sigma_results.
# If you captured per-epoch losses elsewhere during training
# (e.g. a list built inside the training loop for this sigma/run),
# substitute that variable here. Otherwise this plot must be skipped.
if 'all_losses' in dir():
    plt.figure(figsize=(12, 4))
    plt.plot(all_losses[best_idx], color='green', linewidth=1.0)
    plt.title('Fuzzy Gate Replacement — Dow Jones Industrial Index\nTraining Loss (Best Run)')
    plt.xlabel('Epoch')
    plt.ylabel('MSE Loss')
    plt.grid(True, alpha=0.3)
    plt.tight_layout()
    plt.show()
else:
    print("Skipping loss curve — no per-epoch loss history was stored for this run.")

# ============================================================
# Final Metrics Summary
# ============================================================
def smape(y_true, y_pred, eps=1e-8):
    y_true = np.asarray(y_true, dtype=float)
    y_pred = np.asarray(y_pred, dtype=float)
    denom = (np.abs(y_true) + np.abs(y_pred)) / 2.0 + eps
    return np.mean(np.abs(y_true - y_pred) / denom) * 100

best_smape = smape(actual, best_predictions)

print('=== Best Run Metrics ===')
print(f'RMSE: {all_rmse[best_idx]:.6f}')
print(f'MSE:  {all_mse[best_idx]:.6f}')
print(f'NMSE: {all_nmse[best_idx]:.10f}')
print(f'sMAPE: {best_smape:.6f}')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 2
#       1 # Use best sigma's results for plotting
# ----> 2 best_sigma_key = min(sigma_results.keys(), key=lambda s: sigma_results[s]['mean_rmse'])
#       3 best_sigma_data = sigma_results[best_sigma_key]
#       4 best_idx = best_sigma_data['best_idx']
#       5 all_predictions = best_sigma_data['predictions']
#
# NameError: name 'sigma_results' is not defined

# %% [markdown]
# ## Observations
#
# ### Fuzzy Gate Replacement on Dow Jones Industrial Index
#
# **Run the notebook to generate results and fill in observations:**
#
# 1. **Prediction Quality**: Compare RMSE/MSE/NMSE with other variants
# 2. **Training Stability**: Examine loss curves for convergence behavior
# 3. **Prediction Tracking**: Assess how well predictions track actual values
# 4. **Computational Cost**: Note training time per run
#
# *After running all 5 variant notebooks, perform cross-variant comparison to evaluate
# whether fuzzy logic improves nonlinearity handling, interpretability, and prediction performance.*

# %%
# ============================================================
# NOTEBOOK TIMER — END
# ============================================================
_NOTEBOOK_END_TIME = _timer_module.time()
_NOTEBOOK_ELAPSED = _NOTEBOOK_END_TIME - _NOTEBOOK_START_TIME
_hours, _rem = divmod(_NOTEBOOK_ELAPSED, 3600)
_minutes, _seconds = divmod(_rem, 60)
print(f"\nTotal notebook execution time: {int(_hours)}h {int(_minutes)}m {_seconds:.2f}s")
print(f"Total seconds: {_NOTEBOOK_ELAPSED:.2f}")
