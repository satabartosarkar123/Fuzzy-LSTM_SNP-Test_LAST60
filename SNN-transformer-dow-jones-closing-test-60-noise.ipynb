# %%
# ============================================================
# GLOBAL IMPORTS (Consolidated)
# ============================================================
from IPython.display import display
from math import sqrt
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt
import numpy as np
import os
import pandas as pd
import platform
import time
import time as _timer_module
import torch
import torch.nn as nn
import torch.nn.functional as F
import warnings

# ============================================================
# GLOBAL CONFIGURATION (CUDA & NOISE)
# ============================================================
import os
os.environ['CUDA_VISIBLE_DEVICES'] = '0' # Enable RTX 6000 Pro
import torch
if torch.cuda.is_available():
    torch.cuda.set_device(0)

noise_levels = [0.0, 0.005, 0.05, 0.10]
_molab_results = []

def add_gaussian_noise(series, noise_level):
    if noise_level == 0.0:
        return series
    noise = np.random.normal(0, noise_level, len(series))
    return series + noise
# ============================================================

# ============================================================
# FINAL RESULTS TABLE ACROSS ALL NOISE LEVELS
# ============================================================
import pandas as pd
from tabulate import tabulate
if len(_molab_results) > 0:
    df_res = pd.DataFrame(_molab_results, columns=['Noise Level (lambda)', 'RMSE', 'MSE', 'NMSE'])
    print('\n' + '='*80)
    print('FINAL RESULTS TABLE ACROSS ALL 4 NOISE LEVELS')
    print('='*80)
    print(tabulate(df_res, headers='keys', tablefmt='github', showindex=False))

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import os

# %% [markdown]
# # Spiking Neural Network Transformer for Time Series Forecasting
# ## Dataset: Dow Jones
# ## + Gaussian Input-Noise Robustness (0.5% / 5% / 10% / 15%)
#
# **Architecture:** Spike-Driven Transformer (Yao et al., 2024)
# adapted for univariate time series forecasting.
#
# **Reference:** *Spike-driven Transformer V2: Meta Spiking Neural Network Architecture
# Inspiring the Design of Next-generation Neuromorphic Chips* — ICLR 2024
#
# This notebook is a **controlled architectural substitution** of the LSTM-SNP model.
# All preprocessing, training protocol, and evaluation methodology are identical
# to the LSTM-SNP experiments — only the model architecture changes.
#
# This version additionally injects Gaussian noise into the input features at test time:
#
# x_noisy(t) = x(t) + eps(t),  eps(t) ~ N(0, sigma_eps^2),  sigma_eps = eta * std(x)
#
# Noise is injected into input features only (never targets), so the resulting metrics reflect
# model sensitivity to input perturbation, not label corruption. This mirrors the protocol used
# in the LSTM-SNP baseline and FuzzyGateReplacement noise-robustness notebooks, so results are
# directly comparable across all variants.
#
# This version also adds: validation-based early stopping, gradient clipping (always applied,
# for training stability parity with the other variants), an NMSE denominator computed against
# the actual values (the original cell used `predictions - meanV`, which is corrected here to
# `actual - meanV` for cross-variant comparability), and noise-sweep averaging over multiple
# ε(t) draws with a paired per-model degradation test.
#
# ### Key Equations (from the paper)
#
# **LIF Neuron (Eq 1-3):**
# - $U[t] = H[t-1] + X[t]$  — membrane potential accumulation
# - $S[t] = \text{Hea}(U[t] - u_{th})$  — spike generation (Heaviside)
# - $H[t] = V_{reset} \cdot S[t] + (\beta \cdot U[t]) \cdot (1 - S[t])$  — temporal output with reset
#
# **SDSA (Eq 14):**
# - $\text{SDSA}(Q, K, V) = \mathcal{SN}(\text{SUM}_c(Q_S \otimes K_S)) \otimes V_S$
#
# **Membrane Shortcut (Eq 9, 11):**
# - $U'_l = \text{SDSA}(S_{l-1}) + U_{l-1}$
# - $S_l = \mathcal{SN}(\text{MLP}(S'_l) + U'_l)$

# %%
# ============================================================
# PROCESS IDENTIFICATION
# ============================================================
print(f"Process ID (PID): {os.getpid()}")
# Out:
# Process ID (PID): 29672

# %%
# ============================================================
# NOTEBOOK TIMER — START
# ============================================================
_NOTEBOOK_START_TIME = _timer_module.time()
print(f"Notebook execution started at: {_timer_module.strftime('%Y-%m-%d %H:%M:%S')}")
# Out:
# Notebook execution started at: 2026-09-02 09:48:08

# %%
# ============================================================
# ALL IMPORTS
# ============================================================
warnings.filterwarnings('ignore')

print(f"PyTorch version: {torch.__version__}")
print(f"CUDA available: {torch.cuda.is_available()}")
if hasattr(torch.backends, 'mps'):
    print(f"MPS available: {torch.backends.mps.is_available()}")
from scipy import stats
# Out:
# PyTorch version: 2.11.0+cu128
# CUDA available: True
# MPS available: False

# %%
# ============================================================
# PREPROCESSING — Identical to LSTM-SNP Pipeline
# ============================================================
# 1. First-order differencing
# 2. Lag-1 supervised learning format
# 3. Train-test split (last 60 = test)
# 4. MinMaxScaler [-1, 1] (fit on train only)
# 5. Reshape to (samples, 1, 1)

def difference(dataset, interval=1):
    """First-order differencing: diff(t) = raw(t) - raw(t-interval)"""
    diff = []
    for i in range(interval, len(dataset)):
        value = dataset[i] - dataset[i - interval]
        diff.append(value)
    return np.array(diff)


def timeseries_to_supervised(data, lag=1):
    """Convert to supervised format: X(t)=data(t-lag), y(t)=data(t). NaN filled with 0."""
    df = pd.DataFrame(data)
    columns = [df.shift(i) for i in range(1, lag + 1)]
    columns.append(df)
    df = pd.concat(columns, axis=1)
    df.fillna(0, inplace=True)
    return df.values


def prepare_data(raw_values, n_test=60):
    """Full preprocessing pipeline (identical to LSTM-SNP notebooks)."""
    # Step 1: First-order differencing
    diff_values = difference(raw_values, 1)

    # Step 2: Convert to supervised format (lag=1)
    supervised = timeseries_to_supervised(diff_values, 1)

    # Step 3: Train-test split
    train, test = supervised[:-n_test], supervised[-n_test:]

    # Step 4: Scale to [-1, 1] — fit on train only
    scaler = MinMaxScaler(feature_range=(-1, 1))
    scaler.fit(train)
    train_scaled = scaler.transform(train)
    test_scaled = scaler.transform(test)

    # Step 5: Split into X, y
    X_train, y_train = train_scaled[:, 0:-1], train_scaled[:, -1]
    X_test, y_test = test_scaled[:, 0:-1], test_scaled[:, -1]

    # Step 6: Reshape X for model input: (samples, 1, features=1)
    X_train = X_train.reshape((X_train.shape[0], 1, X_train.shape[1]))
    X_test = X_test.reshape((X_test.shape[0], 1, X_test.shape[1]))

    return X_train, y_train, X_test, y_test, scaler, raw_values

# %%
# ============================================================
# SPIKING NEURON — Leaky Integrate-and-Fire (LIF)
# ============================================================
# Faithfully implements Equations 1-3 from the Spike-Driven Transformer paper:
#
#   Eq 1: U[t] = H[t-1] + X[t]                              (membrane potential)
#   Eq 2: S[t] = Hea(U[t] - u_th)                           (spike generation)
#   Eq 3: H[t] = V_reset * S[t] + (β * U[t]) * (1 - S[t])  (temporal output)
#
# Where:
#   U[t] = membrane potential at timestep t
#   H[t] = temporal output (decayed potential or reset)
#   S[t] = binary spike output {0, 1}
#   β < 1 = decay factor
#   u_th = firing threshold
#   V_reset = reset potential after spike
#   Hea(·) = Heaviside step function
#
# Surrogate gradient (for backpropagation):
#   ∂S/∂U ≈ 1 / (1 + α|U - u_th|)²


class SurrogateHeaviside(torch.autograd.Function):
    """Heaviside step with surrogate gradient for backpropagation."""
    @staticmethod
    def forward(ctx, input, alpha):
        ctx.save_for_backward(input)
        ctx.alpha = alpha
        return (input >= 0).float()

    @staticmethod
    def backward(ctx, grad_output):
        (input,) = ctx.saved_tensors
        alpha = ctx.alpha
        grad_input = grad_output / (1 + alpha * input.abs()) ** 2
        return grad_input, None


def surrogate_heaviside(x, alpha=2.0):
    return SurrogateHeaviside.apply(x, alpha)


class LIFNeuron(nn.Module):
    """
    Leaky Integrate-and-Fire neuron implementing Eq 1-3.
    """
    def __init__(self, beta=0.5, v_th=0.5, v_reset=0.0, alpha=2.0):
        super().__init__()
        self.beta = beta
        self.v_th = v_th
        self.v_reset = v_reset
        self.alpha = alpha

    def forward(self, x_seq):
        """
        x_seq: (batch, T, ...) -- input current over T timesteps
        Returns: spike sequence (batch, T, ...)
        """
        batch_shape = x_seq.shape
        T = batch_shape[1]
        H = torch.zeros_like(x_seq[:, 0])
        spikes = []

        for t in range(T):
            U = H + x_seq[:, t]                          # Eq 1
            S = surrogate_heaviside(U - self.v_th, self.alpha)  # Eq 2
            H = self.v_reset * S + (self.beta * U) * (1 - S)    # Eq 3
            spikes.append(S)

        return torch.stack(spikes, dim=1)

# %%
# ============================================================
# SPIKE-DRIVEN SELF-ATTENTION (SDSA)
# ============================================================
# Implements Equations 14-16 from the Spike-Driven Transformer paper.
#
# Standard Self-Attention (Eq 13):
#   VSA(Q,K,V) = softmax(QK^T / √d) · V     → O(N²D + N²D)
#
# Spike-Driven Self-Attention (Eq 14):
#   SDSA(Q,K,V) = SN(SUM_c(Q_S ⊗ K_S)) ⊗ V_S
#
# Where:
#   Q, K, V = linear projections of spike input S (float-point)
#   Q_S, K_S, V_S = SN(Q), SN(K), SN(V)  (converted to spikes)
#   ⊗ = Hadamard product (element-wise multiplication)
#   SUM_c = column sum (sum over token/temporal dimension)
#   SN = Spiking Neuron (LIF)
#
# The key insight: since spikes are binary {0, 1}, the Hadamard product
# Q_S ⊗ K_S is equivalent to a mask operation. SUM_c aggregates activity
# across tokens to produce a D-dimensional feature attention mask.
# This mask gates V_S, selecting relevant feature channels.
#
# Computational complexity: O(ND) — linear in both N and D.


class SpikeDrivenSelfAttention(nn.Module):
    """
    SDSA adapted for 1D time series.

    Input: spike tensor S ∈ {0,1}^(batch, T, D)
    Output: spike-gated features ∈ R^(batch, T, D)
    """
    def __init__(self, d_model, n_heads, beta=0.5, v_th=0.5):
        super().__init__()
        assert d_model % n_heads == 0
        self.d_model = d_model
        self.n_heads = n_heads
        self.d_k = d_model // n_heads

        # Linear projections (float-point) followed by spiking neurons
        self.q_proj = nn.Linear(d_model, d_model)
        self.k_proj = nn.Linear(d_model, d_model)
        self.v_proj = nn.Linear(d_model, d_model)

        self.sn_q = LIFNeuron(beta=beta, v_th=v_th)
        self.sn_k = LIFNeuron(beta=beta, v_th=v_th)
        self.sn_v = LIFNeuron(beta=beta, v_th=v_th)
        self.sn_out = LIFNeuron(beta=beta, v_th=v_th)

        self.out_proj = nn.Linear(d_model, d_model)

    def forward(self, S):
        """S: (batch, T, D) spike tensor."""
        Q = self.sn_q(self.q_proj(S))
        K = self.sn_k(self.k_proj(S))
        V = self.sn_v(self.v_proj(S))

        # SUM_c(Q_S ⊗ K_S): Hadamard product then sum over channel dim
        mask = (Q * K).sum(dim=-1, keepdim=True)   # (batch, T, 1)
        mask = self.sn_out(mask.expand(-1, -1, self.d_model))

        out = mask * V
        return self.out_proj(out)

# %%
# ============================================================
# SPIKING TRANSFORMER BLOCK with Membrane Shortcuts
# ============================================================
# Implements Equations 8-12 from the paper.
#
# The block consists of SDSA + MLP with Membrane Shortcuts (MS):
#
#   Eq 8:  S_0 = SN(U_0)                          (initial spikes)
#   Eq 9:  U'_l = SDSA(S_{l-1}) + U_{l-1}         (MS on SDSA)
#   Eq 10: S'_l = SN(U'_l)
#   Eq 11: S_l = SN(MLP(S'_l) + U'_l)             (MS on MLP)
#   Eq 12: Y = CH(GAP(S_L))                        (output)
#
# Membrane Shortcut (MS) connects membrane potentials between layers,
# ensuring binary spikes are maintained throughout (unlike SEW shortcut).


class SpikingMLP(nn.Module):
    """Simple MLP for the spiking transformer block."""
    def __init__(self, d_model, ff_dim):
        super().__init__()
        self.fc1 = nn.Linear(d_model, ff_dim)
        self.fc2 = nn.Linear(ff_dim, d_model)

    def forward(self, x):
        return self.fc2(F.gelu(self.fc1(x)))


class SpikingTransformerBlock(nn.Module):
    """
    Single Spiking Transformer block with Membrane Shortcuts (Eq 9-11).

    Takes both spike tensor S and membrane potential U from previous layer.
    Returns updated spike tensor and membrane potential.
    """
    def __init__(self, d_model, n_heads, ff_dim, beta=0.5, v_th=0.5):
        super().__init__()
        self.sdsa = SpikeDrivenSelfAttention(d_model, n_heads, beta, v_th)
        self.mlp = SpikingMLP(d_model, ff_dim)
        self.sn1 = LIFNeuron(beta=beta, v_th=v_th)
        self.sn2 = LIFNeuron(beta=beta, v_th=v_th)

    def forward(self, S_prev, U_prev):
        # Eq 9: U'_l = SDSA(S_{l-1}) + U_{l-1}
        U_prime = self.sdsa(S_prev) + U_prev
        # Eq 10: S'_l = SN(U'_l)
        S_prime = self.sn1(U_prime)
        # Eq 11: S_l = SN(MLP(S'_l) + U'_l)
        U_l = self.mlp(S_prime) + U_prime
        S_l = self.sn2(U_l)
        return S_l, U_l

# %%
# ============================================================
# SPIKING TRANSFORMER FORECASTER — Complete Model
# ============================================================
# Adapted from the Spike-Driven Transformer for univariate time series.
#
# Architecture:
#   1. Input Projection: scalar → d_model (replaces SPS from the paper)
#   2. Temporal Expansion: repeat across T spiking timesteps
#   3. Initial SN: S_0 = SN(U_0) (Eq 8)
#   4. L × SpikingTransformerBlock with Membrane Shortcuts (Eq 9-11)
#   5. GAP: Global Average Pooling over T timesteps (Eq 12)
#   6. Regression Head: d_model → 1
#
# Hyperparameters matched to LSTM-SNP:
#   d_model = 8 (same as LSTM-SNP hidden units)
#   n_heads = 2, n_layers = 1, ff_dim = 16, T = 4


class SpikingTransformerForecaster(nn.Module):
    def __init__(self, input_dim=1, d_model=8, n_heads=2, n_layers=1,
                 ff_dim=16, T=4, beta=0.5, v_th=0.5):
        super().__init__()
        self.T = T
        self.d_model = d_model

        # Input projection (replaces Patch Splitting Module from paper)
        self.input_proj = nn.Linear(input_dim, d_model)

        # Initial SN (Eq 8: S_0 = SN(U_0))
        self.sn_init = LIFNeuron(beta=beta, v_th=v_th)

        # Spiking Transformer blocks
        self.blocks = nn.ModuleList([
            SpikingTransformerBlock(d_model, n_heads, ff_dim, beta, v_th)
            for _ in range(n_layers)
        ])

        # Regression head (replaces Classification Head from paper)
        self.head = nn.Linear(d_model, 1)


    def reset_states(self, batch_size, device):
        self.u = torch.zeros(1, device=device)
        
    def detach_states(self):
        if hasattr(self, 'u') and self.u is not None:
            self.u = self.u.detach()

    def forward(self, x):
        """
        x: (batch, 1, 1) — single scaled differenced value
        Returns: (batch, 1) — predicted value
        """
        batch = x.shape[0]
        x = x.view(batch, -1)  # (batch, 1)

        # Input projection: (batch, 1) → (batch, d_model)
        u = self.input_proj(x)

        # Temporal expansion: repeat across T spiking timesteps
        # (analogous to repeating images T times in the paper)
        U_0 = u.unsqueeze(1).repeat(1, self.T, 1)  # (batch, T, d_model)

        # Eq 8: S_0 = SN(U_0)
        S = self.sn_init(U_0)
        U = U_0

        # Pass through L spiking transformer blocks (Eq 9-11)
        for block in self.blocks:
            S, U = block(S, U)

        # Eq 12: Y = CH(GAP(S_L))
        # GAP: Global Average Pooling over T timesteps
        gap = S.mean(dim=1)  # (batch, d_model)

        # Regression head
        output = self.head(gap)  # (batch, 1)
        return output


# Print model summary
model_test = SpikingTransformerForecaster()
total_params = sum(p.numel() for p in model_test.parameters())
print(f"SNN-Transformer parameters: {total_params}")
del model_test
# Out:
# SNN-Transformer parameters: 593

# %%
# ============================================================
# Model Wrapper (PyTorch)
# ============================================================
def build_model(input_dim=1, units=8):
    return SpikingTransformerForecaster(
        input_dim=input_dim, 
        d_model=units, 
        n_heads=2, 
        n_layers=1, 
        ff_dim=16, 
        T=4
    )

# Quick architecture check
model = build_model(input_dim=1, units=8)
print(model)
print(f"Total params: {sum(p.numel() for p in model.parameters())}")
# Out:
# SpikingTransformerForecaster(
#   (input_proj): Linear(in_features=1, out_features=8, bias=True)
#   (sn_init): LIFNeuron()
#   (blocks): ModuleList(
#     (0): SpikingTransformerBlock(
#       (sdsa): SpikeDrivenSelfAttention(
#         (q_proj): Linear(in_features=8, out_features=8, bias=True)
#         (k_proj): Linear(in_features=8, out_features=8, bias=True)
#         (v_proj): Linear(in_features=8, out_features=8, bias=True)
#         (sn_q): LIFNeuron()
#         (sn_k): LIFNeuron()
#         (sn_v): LIFNeuron()
#         (sn_out): LIFNeuron()
#         (out_proj): Linear(in_features=8, out_features=8, bias=True)
#       )
#       (mlp): SpikingMLP(
#         (fc1): Linear(in_features=8, out_features=16, bias=True)
#         (fc2): Linear(in_features=16, out_features=8, bias=True)
#       )
#       (sn1): LIFNeuron()
#       (sn2): LIFNeuron()
#     )
#   )
#   (head): Linear(in_features=8, out_features=1, bias=True)
# )
# Total params: 593

# %% [markdown]
# ## Data Pipeline — Dow_Jones

# %%
DATA_PATH = r'C:\Users\paulp\OneDrive\Desktop\fuzzy_LSTM\dataset\monthly-closings-of-the-dowjones.csv'

series = pd.read_csv(DATA_PATH, header=0, parse_dates=[0], index_col=0)
raw_values = series.values.flatten()

# %%
series = pd.read_csv(
    r'C:\Users\paulp\OneDrive\Desktop\fuzzy_LSTM\dataset\monthly-closings-of-the-dowjones.csv',
    header=0,
    parse_dates=[0],
    index_col=0
)
raw_values = series.values.flatten()

# %%
# ============================================================
# 2. First-Order Differencing
# ============================================================

def difference(dataset, interval=1):
    diff = []
    for i in range(interval, len(dataset)):
        value = dataset[i] - dataset[i - interval]
        diff.append(value)
    return np.array(diff)

diff_values = difference(raw_values, 1)

# %%
# ============================================================
# 3. Convert to Supervised Learning Format (lag=1)
# ============================================================

def timeseries_to_supervised(data, lag=1):
    df = pd.DataFrame(data)
    columns = [df.shift(i) for i in range(1, lag+1)]
    columns.append(df)
    df = pd.concat(columns, axis=1)
    df.fillna(0, inplace=True)
    return df.values

supervised = timeseries_to_supervised(diff_values, 1)
print(f"Supervised data shape: {supervised.shape}")
# Out:
# Supervised data shape: (290, 2)

# %%
# ============================================================
# 4. Train-Validation-Test Split (Last 60 points as Test)
# ============================================================
n = len(supervised)
test_size = 60
train_val = supervised[:n - test_size]
test = supervised[n - test_size:]

val_size = int(len(train_val) * 0.1)
train = train_val[:-val_size]
val = train_val[-val_size:]

print(f"Train: {train.shape}, Val: {val.shape}, Test: {test.shape}")

# ============================================================
# 5. Feature Scaling
# ============================================================
scaler = MinMaxScaler(feature_range=(-1, 1))
scaler.fit(train)  # fit only on train to avoid leakage
train_scaled = scaler.transform(train)
val_scaled = scaler.transform(val)
test_scaled = scaler.transform(test)
# Out:
# Train: (207, 2), Val: (23, 2), Test: (60, 2)

# %%
# ============================================================
# 6. Reshape for RNN Input
# ============================================================

X_train, y_train = train_scaled[:, 0:-1], train_scaled[:, -1]
X_train = X_train.reshape((X_train.shape[0], 1, X_train.shape[1]))

X_test, y_test = test_scaled[:, 0:-1], test_scaled[:, -1]
print(f"X_train shape: {X_train.shape}, y_train shape: {y_train.shape}")
val_X = val_scaled[:, 0:-1]
# Out:
# X_train shape: (207, 1, 1), y_train shape: (207,)

# %%
# Gaussian noise injection (same protocol as the LSTM-SNP baseline / FuzzyGateReplacement notebooks)
ref_std = X_train.std()
print(f"Reference std(x) used for noise scaling (train inputs): {ref_std:.6f}")

NOISE_LEVELS = [0.005, 0.05, 0.10, 0.15]  # 0.5%, 5%, 10%, 15%

def add_gaussian_noise(X, noise_level, ref_std, seed=None):
    """
    x_noisy(t) = x(t) + eps(t),  eps(t) ~ N(0, sigma_eps^2),  sigma_eps = noise_level * std(x)
    Applied to input features X only -- never to targets/labels.
    """
    rng = np.random.default_rng(seed)
    sigma_eps = noise_level * ref_std
    eps = rng.normal(loc=0.0, scale=sigma_eps, size=X.shape)
    return X + eps
# Out:
# Reference std(x) used for noise scaling (train inputs): 0.295900

# %%
# Evaluation function -- warms up the model's spiking/membrane state on clean training
# data, then runs single-step-ahead prediction on X_eval (clean or Gaussian-noise-corrupted
# input features). Test targets are always the clean, ground-truth values.
# NMSE denominator uses the actual series (corrected from the original `predictions - meanV`).

def evaluate_on_test(model, X_eval, train, train_scaled, raw_values, scaler, device):
    model.eval()
    model.reset_states(1, device)

    with torch.no_grad():
        for i in range(len(train_scaled)):
            X_raw = train_scaled[i, 0:-1]
            X_input = torch.tensor(X_raw, dtype=torch.float32).view(1, 1, len(X_raw)).to(device)
            model(X_input)

        predictions = []
        for i in range(len(X_eval)):
            X = X_eval[i]
            X_input = torch.tensor(X, dtype=torch.float32).view(1, 1, len(X)).to(device)
            yhat = model(X_input).item()

            new_row = [x for x in X] + [yhat]
            array = np.array(new_row).reshape(1, len(new_row))
            inverted = scaler.inverse_transform(array)[0, -1]
            inverted = inverted + raw_values[len(train) + i]
            predictions.append(inverted)

    actual = raw_values[-len(X_eval):]
    mse = mean_squared_error(actual, predictions)
    rmse = sqrt(mse)
    meanV = np.mean(actual)
    dominator = np.linalg.norm(np.array(actual) - meanV, 2)
    nmse = mse / np.power(dominator, 2)
    return predictions, rmse, mse, nmse

# %% [markdown]
# ## Training Loop

# %%
#Training loop (60 runs, early stopping + gradient clipping + per-epoch save)

import os
import csv
import pickle
import time

CHECKPOINT_DIR = 'checkpoints'
os.makedirs(CHECKPOINT_DIR, exist_ok=True)

EPOCH_LOG_PATH = os.path.join(CHECKPOINT_DIR, 'epoch_log.csv')
PROGRESS_PATH = os.path.join(CHECKPOINT_DIR, 'progress.pkl')

# Write CSV header once (if the log doesn't already exist)
if not os.path.exists(EPOCH_LOG_PATH):
    with open(EPOCH_LOG_PATH, 'w', newline='') as f:
        csv.writer(f).writerow(['run', 'epoch', 'train_loss', 'val_rmse', 'timestamp'])

def log_epoch(run, epoch, train_loss, val_rmse):
    """Append one epoch's result to disk immediately (flushed + fsynced)."""
    with open(EPOCH_LOG_PATH, 'a', newline='') as f:
        writer = csv.writer(f)
        writer.writerow([run, epoch, train_loss, val_rmse, time.strftime('%Y-%m-%d %H:%M:%S')])
        f.flush()
        os.fsync(f.fileno())

def save_progress(run, epoch, run_losses_partial):
    """
    Overwrite a resumable snapshot after every epoch: all fully-completed runs'
    results, plus the in-progress run's losses so far. If the kernel dies mid-run,
    you lose at most the current run's partial epochs, not everything.
    """
    snapshot = {
        'all_rmse': all_rmse,
        'all_mse': all_mse,
        'all_nmse': all_nmse,
        'all_predictions': all_predictions,
        'all_losses': all_losses,
        'current_run': run,
        'current_epoch': epoch,
        'current_run_losses_partial': run_losses_partial,
    }
    tmp_path = PROGRESS_PATH + '.tmp'
    with open(tmp_path, 'wb') as f:
        pickle.dump(snapshot, f)
    os.replace(tmp_path, PROGRESS_PATH)  # atomic on POSIX and Windows

all_rmse = []
all_mse = []
all_nmse = []
all_predictions = []
all_losses = []
all_models = []  # keep every trained model for later noise-robustness eval

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"\n--- [PyTorch] RUNNING ON {device} ---\n")

N_RUNS = 60
PATIENCE = 10

for run in range(N_RUNS):
    print(f'\n===== RUN {run + 1}/{N_RUNS} =====')

    np.random.seed(run)
    torch.manual_seed(run)
    model = build_model(input_dim=1, units=8).to(device)

    optimizer = torch.optim.Adam(model.parameters(), lr=0.001)
    criterion = nn.MSELoss()
    run_losses = []

    X_train_t = torch.tensor(X_train, dtype=torch.float32).to(device)
    y_train_t = torch.tensor(y_train, dtype=torch.float32).to(device)
    n_samples = X_train_t.size(0)

    best_val_rmse = float('inf')
    best_state = None
    patience_ctr = 0

    for epoch in range(100):
        model.train()
        model.reset_states(1, device)
        epoch_loss = 0.0

        for i in range(n_samples):
            x_i = X_train_t[i:i + 1]
            y_i = y_train_t[i:i + 1]

            optimizer.zero_grad()
            pred = model(x_i)
            loss = criterion(pred.squeeze(-1), y_i)
            loss.backward()
            torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)
            optimizer.step()

            model.detach_states()
            epoch_loss += loss.item()

        avg_loss = epoch_loss / n_samples
        run_losses.append(avg_loss)

        # Early stopping on the validation split
        _, val_rmse, _, _ = evaluate_on_test(model, val_X, train, train_scaled, raw_values, scaler, device)
        print(f"Epoch {epoch + 1}/100 -- train loss: {avg_loss:.6f}  val RMSE: {val_rmse:.6f}")

        # --- Save results after this epoch ---
        log_epoch(run + 1, epoch + 1, avg_loss, val_rmse)
        save_progress(run + 1, epoch + 1, run_losses)

        if val_rmse < best_val_rmse:
            best_val_rmse = val_rmse
            best_state = {k: v.clone() for k, v in model.state_dict().items()}
            patience_ctr = 0
        else:
            patience_ctr += 1
            if patience_ctr >= PATIENCE:
                print(f"Early stopping at epoch {epoch + 1} (best val RMSE: {best_val_rmse:.6f})")
                break

    model.load_state_dict(best_state)  # restore best-val checkpoint
    model.reset_states(1, device)      # clear stale state before storing

    all_losses.append(run_losses)
    all_models.append(model)
    print(f'Training complete for run {run + 1} (best val RMSE: {best_val_rmse:.6f})')

    predictions, rmse, mse, nmse = evaluate_on_test(
        model, X_test, train, train_scaled, raw_values, scaler, device
    )

    all_rmse.append(rmse)
    all_mse.append(mse)
    all_nmse.append(nmse)
    all_predictions.append(predictions)

    # Save again at run boundary so all_rmse/all_mse/etc. reflect the completed run
    save_progress(run + 1, epoch + 1, run_losses)

    print(f'Run {run + 1} -- RMSE: {rmse:.6f}, MSE: {mse:.6f}, NMSE: {nmse:.10f}')
# Out:
# --- [PyTorch] RUNNING ON cuda ---
#
#
# ===== RUN 1/60 =====
# Epoch 1/100 -- train loss: 0.290792  val RMSE: 160.128205
# Epoch 2/100 -- train loss: 0.091408  val RMSE: 159.429010
# Epoch 3/100 -- train loss: 0.089394  val RMSE: 158.556884
# Epoch 4/100 -- train loss: 0.089503  val RMSE: 158.791352
# Epoch 5/100 -- train loss: 0.091100  val RMSE: 157.729630
# Epoch 6/100 -- train loss: 0.090920  val RMSE: 157.821649
# Epoch 7/100 -- train loss: 0.089575  val RMSE: 156.318170
# Epoch 8/100 -- train loss: 0.089840  val RMSE: 156.751840
# Epoch 9/100 -- train loss: 0.089339  val RMSE: 157.484731
# Epoch 10/100 -- train loss: 0.088501  val RMSE: 157.836947
# Epoch 11/100 -- train loss: 0.088260  val RMSE: 157.746925
# Epoch 12/100 -- train loss: 0.088908  val RMSE: 158.146470
# Epoch 13/100 -- train loss: 0.089564  val RMSE: 159.346444
# Epoch 14/100 -- train loss: 0.089486  val RMSE: 159.285545
# Epoch 15/100 -- train loss: 0.088112  val RMSE: 158.629034
# Epoch 16/100 -- train loss: 0.088747  val RMSE: 159.026279
# Epoch 17/100 -- train loss: 0.087243  val RMSE: 158.466718
# Early stopping at epoch 17 (best val RMSE: 156.318170)
# Training complete for run 1 (best val RMSE: 156.318170)
# Run 1 -- RMSE: 98.305446, MSE: 9663.960781, NMSE: 0.0447492095
#
# ===== RUN 2/60 =====
# Epoch 1/100 -- train loss: 0.095667  val RMSE: 159.183152
# Epoch 2/100 -- train loss: 0.092844  val RMSE: 158.761661
# Epoch 3/100 -- train loss: 0.090605  val RMSE: 158.220668
# Epoch 4/100 -- train loss: 0.090027  val RMSE: 157.816397
# Epoch 5/100 -- train loss: 0.088961  val RMSE: 157.573957
# Epoch 6/100 -- train loss: 0.087670  val RMSE: 157.802649
# Epoch 7/100 -- train loss: 0.087193  val RMSE: 158.065634
# Epoch 8/100 -- train loss: 0.086326  val RMSE: 158.080876
# Epoch 9/100 -- train loss: 0.087587  val RMSE: 158.130661
# Epoch 10/100 -- train loss: 0.087266  val RMSE: 158.045881
# Epoch 11/100 -- train loss: 0.087973  val RMSE: 158.024792
# Epoch 12/100 -- train loss: 0.088033  val RMSE: 158.207969
# Epoch 13/100 -- train loss: 0.088124  val RMSE: 158.350385
# Epoch 14/100 -- train loss: 0.088455  val RMSE: 158.341968
# Epoch 15/100 -- train loss: 0.088507  val RMSE: 158.437856
# Early stopping at epoch 15 (best val RMSE: 157.573957)
# Training complete for run 2 (best val RMSE: 157.573957)
# Run 2 -- RMSE: 99.556871, MSE: 9911.570594, NMSE: 0.0458957728
#
# ===== RUN 3/60 =====
# Epoch 1/100 -- train loss: 0.154181  val RMSE: 158.105820
# Epoch 2/100 -- train loss: 0.100877  val RMSE: 157.759764
# Epoch 3/100 -- train loss: 0.096406  val RMSE: 159.689069
# Epoch 4/100 -- train loss: 0.092546  val RMSE: 158.596758
# Epoch 5/100 -- train loss: 0.094425  val RMSE: 158.368436
# Epoch 6/100 -- train loss: 0.092308  val RMSE: 157.800263
# Epoch 7/100 -- train loss: 0.091091  val RMSE: 157.670533
# Epoch 8/100 -- train loss: 0.090902  val RMSE: 157.686012
# Epoch 9/100 -- train loss: 0.091505  val RMSE: 157.390061
# Epoch 10/100 -- train loss: 0.092318  val RMSE: 157.607905
# Epoch 11/100 -- train loss: 0.091850  val RMSE: 157.896211
# Epoch 12/100 -- train loss: 0.088598  val RMSE: 158.801693
# Epoch 13/100 -- train loss: 0.089057  val RMSE: 158.566887
# Epoch 14/100 -- train loss: 0.091923  val RMSE: 159.190905
# Epoch 15/100 -- train loss: 0.092383  val RMSE: 159.265636
# Epoch 16/100 -- train loss: 0.093367  val RMSE: 158.810925
# Epoch 17/100 -- train loss: 0.093492  val RMSE: 158.898609
# Epoch 18/100 -- train loss: 0.091628  val RMSE: 158.138065
# Epoch 19/100 -- train loss: 0.089500  val RMSE: 157.735518
# Early stopping at epoch 19 (best val RMSE: 157.390061)
# Training complete for run 3 (best val RMSE: 157.390061)
# Run 3 -- RMSE: 99.212185, MSE: 9843.057578, NMSE: 0.0455785216
#
# ===== RUN 4/60 =====
# Epoch 1/100 -- train loss: 0.088255  val RMSE: 157.703908
# Epoch 2/100 -- train loss: 0.087282  val RMSE: 157.797162
# Epoch 3/100 -- train loss: 0.087147  val RMSE: 157.745443
# Epoch 4/100 -- train loss: 0.087298  val RMSE: 157.677883
# Epoch 5/100 -- train loss: 0.086822  val RMSE: 157.685543
# Epoch 6/100 -- train loss: 0.087239  val RMSE: 157.470474
# Epoch 7/100 -- train loss: 0.086832  val RMSE: 157.527744
# Epoch 8/100 -- train loss: 0.086627  val RMSE: 157.600210
# Epoch 9/100 -- train loss: 0.086604  val RMSE: 157.662685
# Epoch 10/100 -- train loss: 0.085936  val RMSE: 157.704780
# Epoch 11/100 -- train loss: 0.086054  val RMSE: 157.768653
# Epoch 12/100 -- train loss: 0.086450  val RMSE: 157.773427
# Epoch 13/100 -- train loss: 0.085745  val RMSE: 157.797291
# Epoch 14/100 -- train loss: 0.085718  val RMSE: 158.075716
# Epoch 15/100 -- train loss: 0.086361  val RMSE: 158.044805
# Epoch 16/100 -- train loss: 0.086301  val RMSE: 157.975236
# Early stopping at epoch 16 (best val RMSE: 157.470474)
# Training complete for run 4 (best val RMSE: 157.470474)
# Run 4 -- RMSE: 100.065554, MSE: 10013.115070, NMSE: 0.0463659770
#
# ===== RUN 5/60 =====
# Epoch 1/100 -- train loss: 0.094084  val RMSE: 158.117771
# Epoch 2/100 -- train loss: 0.090128  val RMSE: 159.202513
# Epoch 3/100 -- train loss: 0.092631  val RMSE: 157.661216
# Epoch 4/100 -- train loss: 0.092044  val RMSE: 157.576692
# Epoch 5/100 -- train loss: 0.089523  val RMSE: 158.004176
# Epoch 6/100 -- train loss: 0.090019  val RMSE: 159.337757
# Epoch 7/100 -- train loss: 0.089777  val RMSE: 157.448290
# Epoch 8/100 -- train loss: 0.089062  val RMSE: 157.214580
# Epoch 9/100 -- train loss: 0.089960  val RMSE: 157.595735
# Epoch 10/100 -- train loss: 0.089234  val RMSE: 158.963599
# Epoch 11/100 -- train loss: 0.088412  val RMSE: 158.187348
# Epoch 12/100 -- train loss: 0.089003  val RMSE: 158.195051
# Epoch 13/100 -- train loss: 0.088795  val RMSE: 158.063915
# Epoch 14/100 -- train loss: 0.090793  val RMSE: 157.621292
# Epoch 15/100 -- train loss: 0.089504  val RMSE: 157.540648
# Epoch 16/100 -- train loss: 0.088865  val RMSE: 157.259427
# Epoch 17/100 -- train loss: 0.088157  val RMSE: 157.744734
# Epoch 18/100 -- train loss: 0.087006  val RMSE: 157.901363
# Early stopping at epoch 18 (best val RMSE: 157.214580)
# Training complete for run 5 (best val RMSE: 157.214580)
# Run 5 -- RMSE: 98.941136, MSE: 9789.348364, NMSE: 0.0453298198
#
# ===== RUN 6/60 =====
# Epoch 1/100 -- train loss: 0.110931  val RMSE: 157.826388
# Epoch 2/100 -- train loss: 0.095523  val RMSE: 158.508601
# Epoch 3/100 -- train loss: 0.094476  val RMSE: 158.345908
# Epoch 4/100 -- train loss: 0.092447  val RMSE: 157.742549
# Epoch 5/100 -- train loss: 0.088949  val RMSE: 155.725828
# Epoch 6/100 -- train loss: 0.089055  val RMSE: 157.237366
# Epoch 7/100 -- train loss: 0.089800  val RMSE: 157.169623
# Epoch 8/100 -- train loss: 0.089546  val RMSE: 156.855486
# Epoch 9/100 -- train loss: 0.089670  val RMSE: 156.809945
# Epoch 10/100 -- train loss: 0.088687  val RMSE: 156.981996
# Epoch 11/100 -- train loss: 0.091448  val RMSE: 157.050073
# Epoch 12/100 -- train loss: 0.088552  val RMSE: 157.546555
# Epoch 13/100 -- train loss: 0.088830  val RMSE: 157.263391
# Epoch 14/100 -- train loss: 0.089037  val RMSE: 157.287515
# Epoch 15/100 -- train loss: 0.090324  val RMSE: 157.662933
# Early stopping at epoch 15 (best val RMSE: 155.725828)
# Training complete for run 6 (best val RMSE: 155.725828)
# Run 6 -- RMSE: 99.516905, MSE: 9903.614398, NMSE: 0.0458589315
#
# ===== RUN 7/60 =====
# Epoch 1/100 -- train loss: 0.111976  val RMSE: 158.735066
# Epoch 2/100 -- train loss: 0.097332  val RMSE: 160.175793
# Epoch 3/100 -- train loss: 0.093781  val RMSE: 158.821767
# Epoch 4/100 -- train loss: 0.093225  val RMSE: 157.744940
# Epoch 5/100 -- train loss: 0.090931  val RMSE: 158.274941
# Epoch 6/100 -- train loss: 0.092185  val RMSE: 157.728639
# Epoch 7/100 -- train loss: 0.090525  val RMSE: 157.716565
# Epoch 8/100 -- train loss: 0.090413  val RMSE: 157.588393
# Epoch 9/100 -- train loss: 0.091025  val RMSE: 157.605702
# Epoch 10/100 -- train loss: 0.091889  val RMSE: 157.656239
# Epoch 11/100 -- train loss: 0.090488  val RMSE: 158.231590
# Epoch 12/100 -- train loss: 0.092424  val RMSE: 158.037300
# Epoch 13/100 -- train loss: 0.092146  val RMSE: 158.030972
# Epoch 14/100 -- train loss: 0.093073  val RMSE: 158.183632
# Epoch 15/100 -- train loss: 0.091826  val RMSE: 158.430688
# Epoch 16/100 -- train loss: 0.091291  val RMSE: 157.540313
# Epoch 17/100 -- train loss: 0.090868  val RMSE: 157.753553
# Epoch 18/100 -- train loss: 0.090263  val RMSE: 158.036964
# Epoch 19/100 -- train loss: 0.090702  val RMSE: 157.694545
# Epoch 20/100 -- train loss: 0.090450  val RMSE: 157.669379
# Epoch 21/100 -- train loss: 0.091270  val RMSE: 157.577933
# Epoch 22/100 -- train loss: 0.090345  val RMSE: 157.726088
# Epoch 23/100 -- train loss: 0.089899  val RMSE: 157.847092
# Epoch 24/100 -- train loss: 0.089385  val RMSE: 157.760835
# Epoch 25/100 -- train loss: 0.090190  val RMSE: 157.299928
# Epoch 26/100 -- train loss: 0.090105  val RMSE: 157.046996
# Epoch 27/100 -- train loss: 0.090026  val RMSE: 156.929279
# Epoch 28/100 -- train loss: 0.089574  val RMSE: 157.077527
# Epoch 29/100 -- train loss: 0.089610  val RMSE: 156.996947
# Epoch 30/100 -- train loss: 0.089725  val RMSE: 156.978210
# Epoch 31/100 -- train loss: 0.088461  val RMSE: 157.417390
# Epoch 32/100 -- train loss: 0.089145  val RMSE: 157.302631
# Epoch 33/100 -- train loss: 0.088352  val RMSE: 157.681553
# Epoch 34/100 -- train loss: 0.088300  val RMSE: 157.489997
# Epoch 35/100 -- train loss: 0.087953  val RMSE: 157.135862
# Epoch 36/100 -- train loss: 0.088503  val RMSE: 157.334671
# Epoch 37/100 -- train loss: 0.087812  val RMSE: 157.406825
# Early stopping at epoch 37 (best val RMSE: 156.929279)
# Training complete for run 7 (best val RMSE: 156.929279)
# Run 7 -- RMSE: 98.795533, MSE: 9760.557347, NMSE: 0.0451965023
#
# ===== RUN 8/60 =====
# Epoch 1/100 -- train loss: 0.315010  val RMSE: 161.841182
# Epoch 2/100 -- train loss: 0.089764  val RMSE: 158.055696
# Epoch 3/100 -- train loss: 0.089634  val RMSE: 157.882748
# Epoch 4/100 -- train loss: 0.088967  val RMSE: 157.418558
# Epoch 5/100 -- train loss: 0.089045  val RMSE: 157.232874
# Epoch 6/100 -- train loss: 0.089200  val RMSE: 157.219169
# Epoch 7/100 -- train loss: 0.089103  val RMSE: 157.346430
# Epoch 8/100 -- train loss: 0.088600  val RMSE: 157.550124
# Epoch 9/100 -- train loss: 0.089158  val RMSE: 156.973856
# Epoch 10/100 -- train loss: 0.089115  val RMSE: 156.919556
# Epoch 11/100 -- train loss: 0.088845  val RMSE: 157.048498
# Epoch 12/100 -- train loss: 0.088584  val RMSE: 156.598855
# Epoch 13/100 -- train loss: 0.088491  val RMSE: 157.319032
# Epoch 14/100 -- train loss: 0.088340  val RMSE: 156.281212
# Epoch 15/100 -- train loss: 0.088905  val RMSE: 157.092128
# Epoch 16/100 -- train loss: 0.087844  val RMSE: 156.393639
# Epoch 17/100 -- train loss: 0.089056  val RMSE: 156.681024
# Epoch 18/100 -- train loss: 0.088497  val RMSE: 156.788510
# Epoch 19/100 -- train loss: 0.089931  val RMSE: 157.075076
# Epoch 20/100 -- train loss: 0.090261  val RMSE: 156.703698
# Epoch 21/100 -- train loss: 0.090748  val RMSE: 157.588269
# Epoch 22/100 -- train loss: 0.090617  val RMSE: 156.640376
# Epoch 23/100 -- train loss: 0.089341  val RMSE: 157.239053
# Epoch 24/100 -- train loss: 0.090352  val RMSE: 157.179898
# Early stopping at epoch 24 (best val RMSE: 156.281212)
# Training complete for run 8 (best val RMSE: 156.281212)
# Run 8 -- RMSE: 99.006938, MSE: 9802.373750, NMSE: 0.0453901342
#
# ===== RUN 9/60 =====
# Epoch 1/100 -- train loss: 0.097131  val RMSE: 159.816969
# Epoch 2/100 -- train loss: 0.090711  val RMSE: 158.870281
# Epoch 3/100 -- train loss: 0.089489  val RMSE: 159.467903
# Epoch 4/100 -- train loss: 0.090801  val RMSE: 159.088239
# Epoch 5/100 -- train loss: 0.090612  val RMSE: 158.757473
# Epoch 6/100 -- train loss: 0.090285  val RMSE: 159.375876
# Epoch 7/100 -- train loss: 0.089766  val RMSE: 158.503151
# Epoch 8/100 -- train loss: 0.090918  val RMSE: 158.535976
# Epoch 9/100 -- train loss: 0.090611  val RMSE: 158.225456
# Epoch 10/100 -- train loss: 0.089645  val RMSE: 158.207478
# Epoch 11/100 -- train loss: 0.088228  val RMSE: 158.639778
# Epoch 12/100 -- train loss: 0.088160  val RMSE: 158.731664
# Epoch 13/100 -- train loss: 0.087778  val RMSE: 158.008326
# Epoch 14/100 -- train loss: 0.088393  val RMSE: 158.661280
# Epoch 15/100 -- train loss: 0.088856  val RMSE: 158.214331
# Epoch 16/100 -- train loss: 0.089187  val RMSE: 158.032379
# Epoch 17/100 -- train loss: 0.089767  val RMSE: 158.267862
# Epoch 18/100 -- train loss: 0.090094  val RMSE: 158.241418
# Epoch 19/100 -- train loss: 0.089078  val RMSE: 158.369340
# Epoch 20/100 -- train loss: 0.088568  val RMSE: 158.283831
# Epoch 21/100 -- train loss: 0.088626  val RMSE: 158.367112
# Epoch 22/100 -- train loss: 0.089173  val RMSE: 158.382231
# Epoch 23/100 -- train loss: 0.089601  val RMSE: 158.300481
# Early stopping at epoch 23 (best val RMSE: 158.008326)
# Training complete for run 9 (best val RMSE: 158.008326)
# Run 9 -- RMSE: 100.567430, MSE: 10113.808029, NMSE: 0.0468322383
#
# ===== RUN 10/60 =====
# Epoch 1/100 -- train loss: 0.092550  val RMSE: 158.320243
# Epoch 2/100 -- train loss: 0.088216  val RMSE: 157.611581
# Epoch 3/100 -- train loss: 0.088105  val RMSE: 157.715039
# Epoch 4/100 -- train loss: 0.087767  val RMSE: 157.729536
# Epoch 5/100 -- train loss: 0.087470  val RMSE: 157.601596
# Epoch 6/100 -- train loss: 0.087604  val RMSE: 157.511695
# Epoch 7/100 -- train loss: 0.087767  val RMSE: 157.504344
# Epoch 8/100 -- train loss: 0.087730  val RMSE: 157.400906
# Epoch 9/100 -- train loss: 0.087565  val RMSE: 157.437578
# Epoch 10/100 -- train loss: 0.087398  val RMSE: 157.344262
# Epoch 11/100 -- train loss: 0.087282  val RMSE: 157.346652
# Epoch 12/100 -- train loss: 0.087420  val RMSE: 157.307199
# Epoch 13/100 -- train loss: 0.087079  val RMSE: 157.298086
# Epoch 14/100 -- train loss: 0.087384  val RMSE: 157.318409
# Epoch 15/100 -- train loss: 0.087455  val RMSE: 157.295142
# Epoch 16/100 -- train loss: 0.087284  val RMSE: 157.293917
# Epoch 17/100 -- train loss: 0.087302  val RMSE: 157.238854
# Epoch 18/100 -- train loss: 0.087311  val RMSE: 157.264544
# Epoch 19/100 -- train loss: 0.087188  val RMSE: 157.224958
# Epoch 20/100 -- train loss: 0.087302  val RMSE: 157.307895
# Epoch 21/100 -- train loss: 0.087466  val RMSE: 157.190061
# Epoch 22/100 -- train loss: 0.087461  val RMSE: 157.425827
# Epoch 23/100 -- train loss: 0.087574  val RMSE: 157.421296
# Epoch 24/100 -- train loss: 0.087338  val RMSE: 157.352784
# Epoch 25/100 -- train loss: 0.087594  val RMSE: 157.339484
# Epoch 26/100 -- train loss: 0.087709  val RMSE: 157.364681
# Epoch 27/100 -- train loss: 0.087402  val RMSE: 157.045412
# Epoch 28/100 -- train loss: 0.087634  val RMSE: 157.030973
# Epoch 29/100 -- train loss: 0.087631  val RMSE: 157.364173
# Epoch 30/100 -- train loss: 0.087678  val RMSE: 157.374984
# Epoch 31/100 -- train loss: 0.087729  val RMSE: 157.096582
# Epoch 32/100 -- train loss: 0.087693  val RMSE: 157.433783
# Epoch 33/100 -- train loss: 0.087653  val RMSE: 157.380331
# Epoch 34/100 -- train loss: 0.087705  val RMSE: 157.362872
# Epoch 35/100 -- train loss: 0.087721  val RMSE: 157.111445
# Epoch 36/100 -- train loss: 0.087712  val RMSE: 157.401745
# Epoch 37/100 -- train loss: 0.087733  val RMSE: 157.407868
# Epoch 38/100 -- train loss: 0.087800  val RMSE: 157.475985
# Early stopping at epoch 38 (best val RMSE: 157.030973)
# Training complete for run 10 (best val RMSE: 157.030973)
# Run 10 -- RMSE: 99.412225, MSE: 9882.790503, NMSE: 0.0457625059
#
# ===== RUN 11/60 =====
# Epoch 1/100 -- train loss: 0.098550  val RMSE: 157.247336
# Epoch 2/100 -- train loss: 0.097510  val RMSE: 158.743012
# Epoch 3/100 -- train loss: 0.092466  val RMSE: 156.949539
# Epoch 4/100 -- train loss: 0.095597  val RMSE: 158.485727
# Epoch 5/100 -- train loss: 0.094577  val RMSE: 157.475957
# Epoch 6/100 -- train loss: 0.093552  val RMSE: 157.522082
# Epoch 7/100 -- train loss: 0.093184  val RMSE: 158.707849
# Epoch 8/100 -- train loss: 0.092318  val RMSE: 158.966465
# Epoch 9/100 -- train loss: 0.091889  val RMSE: 158.668029
# Epoch 10/100 -- train loss: 0.093568  val RMSE: 158.224649
# Epoch 11/100 -- train loss: 0.091153  val RMSE: 158.529630
# Epoch 12/100 -- train loss: 0.092401  val RMSE: 157.447742
# Epoch 13/100 -- train loss: 0.092669  val RMSE: 157.381549
# Early stopping at epoch 13 (best val RMSE: 156.949539)
# Training complete for run 11 (best val RMSE: 156.949539)
# Run 11 -- RMSE: 98.445994, MSE: 9691.613666, NMSE: 0.0448772568
#
# ===== RUN 12/60 =====
# Epoch 1/100 -- train loss: 0.133079  val RMSE: 158.356704
# Epoch 2/100 -- train loss: 0.089550  val RMSE: 158.348451
# Epoch 3/100 -- train loss: 0.089595  val RMSE: 158.367520
# Epoch 4/100 -- train loss: 0.087985  val RMSE: 158.271243
# Epoch 5/100 -- train loss: 0.087768  val RMSE: 158.246255
# Epoch 6/100 -- train loss: 0.087976  val RMSE: 158.186625
# Epoch 7/100 -- train loss: 0.087793  val RMSE: 158.808357
# Epoch 8/100 -- train loss: 0.087378  val RMSE: 159.031596
# Epoch 9/100 -- train loss: 0.087328  val RMSE: 158.349265
# Epoch 10/100 -- train loss: 0.088722  val RMSE: 158.153553
# Epoch 11/100 -- train loss: 0.088635  val RMSE: 158.048342
# Epoch 12/100 -- train loss: 0.089044  val RMSE: 157.918396
# Epoch 13/100 -- train loss: 0.089195  val RMSE: 157.967419
# Epoch 14/100 -- train loss: 0.088844  val RMSE: 158.336787
# Epoch 15/100 -- train loss: 0.088585  val RMSE: 157.807243
# Epoch 16/100 -- train loss: 0.088136  val RMSE: 157.697794
# Epoch 17/100 -- train loss: 0.087852  val RMSE: 157.655969
# Epoch 18/100 -- train loss: 0.088539  val RMSE: 157.981243
# Epoch 19/100 -- train loss: 0.087362  val RMSE: 157.926490
# Epoch 20/100 -- train loss: 0.087485  val RMSE: 157.957686
# Epoch 21/100 -- train loss: 0.087247  val RMSE: 158.000759
# Epoch 22/100 -- train loss: 0.087303  val RMSE: 157.861548
# Epoch 23/100 -- train loss: 0.087410  val RMSE: 157.885893
# Epoch 24/100 -- train loss: 0.087078  val RMSE: 157.934304
# Epoch 25/100 -- train loss: 0.086946  val RMSE: 158.015431
# Epoch 26/100 -- train loss: 0.087006  val RMSE: 158.067207
# Epoch 27/100 -- train loss: 0.086888  val RMSE: 157.589933
# Epoch 28/100 -- train loss: 0.086785  val RMSE: 157.647859
# Epoch 29/100 -- train loss: 0.087315  val RMSE: 157.807358
# Epoch 30/100 -- train loss: 0.087762  val RMSE: 158.043364
# Epoch 31/100 -- train loss: 0.087533  val RMSE: 158.323149
# Epoch 32/100 -- train loss: 0.087218  val RMSE: 158.198308
# Epoch 33/100 -- train loss: 0.086643  val RMSE: 158.035527
# Epoch 34/100 -- train loss: 0.086517  val RMSE: 157.793304
# Epoch 35/100 -- train loss: 0.086566  val RMSE: 158.249627
# Epoch 36/100 -- train loss: 0.086730  val RMSE: 157.985523
# Epoch 37/100 -- train loss: 0.085841  val RMSE: 158.259938
# Early stopping at epoch 37 (best val RMSE: 157.589933)
# Training complete for run 12 (best val RMSE: 157.589933)
# Run 12 -- RMSE: 99.483205, MSE: 9896.908022, NMSE: 0.0458278774
#
# ===== RUN 13/60 =====
# Epoch 1/100 -- train loss: 0.097022  val RMSE: 157.671522
# Epoch 2/100 -- train loss: 0.089525  val RMSE: 157.941952
# Epoch 3/100 -- train loss: 0.088876  val RMSE: 157.936709
# Epoch 4/100 -- train loss: 0.088802  val RMSE: 157.843092
# Epoch 5/100 -- train loss: 0.089055  val RMSE: 157.937226
# Epoch 6/100 -- train loss: 0.088855  val RMSE: 158.022602
# Epoch 7/100 -- train loss: 0.089502  val RMSE: 158.061449
# Epoch 8/100 -- train loss: 0.089362  val RMSE: 158.167150
# Epoch 9/100 -- train loss: 0.089141  val RMSE: 157.937075
# Epoch 10/100 -- train loss: 0.089424  val RMSE: 157.807997
# Epoch 11/100 -- train loss: 0.089727  val RMSE: 157.797510
# Early stopping at epoch 11 (best val RMSE: 157.671522)
# Training complete for run 13 (best val RMSE: 157.671522)
# Run 13 -- RMSE: 100.032095, MSE: 10006.419953, NMSE: 0.0463349751
#
# ===== RUN 14/60 =====
# Epoch 1/100 -- train loss: 0.091745  val RMSE: 157.528459
# Epoch 2/100 -- train loss: 0.089576  val RMSE: 157.293368
# Epoch 3/100 -- train loss: 0.090191  val RMSE: 157.008733
# Epoch 4/100 -- train loss: 0.089954  val RMSE: 157.109909
# Epoch 5/100 -- train loss: 0.089942  val RMSE: 157.301554
# Epoch 6/100 -- train loss: 0.089874  val RMSE: 157.429789
# Epoch 7/100 -- train loss: 0.089418  val RMSE: 157.385287
# Epoch 8/100 -- train loss: 0.089748  val RMSE: 157.649997
# Epoch 9/100 -- train loss: 0.089351  val RMSE: 157.451302
# Epoch 10/100 -- train loss: 0.089476  val RMSE: 157.422122
# Epoch 11/100 -- train loss: 0.088785  val RMSE: 157.302447
# Epoch 12/100 -- train loss: 0.089025  val RMSE: 157.903898
# Epoch 13/100 -- train loss: 0.087941  val RMSE: 157.499542
# Early stopping at epoch 13 (best val RMSE: 157.008733)
# Training complete for run 14 (best val RMSE: 157.008733)
# Run 14 -- RMSE: 99.899133, MSE: 9979.836679, NMSE: 0.0462118806
#
# ===== RUN 15/60 =====
# Epoch 1/100 -- train loss: 0.096282  val RMSE: 158.879931
# Epoch 2/100 -- train loss: 0.088908  val RMSE: 158.204739
# Epoch 3/100 -- train loss: 0.088507  val RMSE: 158.187288
# Epoch 4/100 -- train loss: 0.088914  val RMSE: 158.191131
# Epoch 5/100 -- train loss: 0.088615  val RMSE: 158.038336
# Epoch 6/100 -- train loss: 0.089440  val RMSE: 158.057471
# Epoch 7/100 -- train loss: 0.088489  val RMSE: 158.108083
# Epoch 8/100 -- train loss: 0.088249  val RMSE: 158.113237
# Epoch 9/100 -- train loss: 0.088774  val RMSE: 157.996275
# Epoch 10/100 -- train loss: 0.088346  val RMSE: 158.020235
# Epoch 11/100 -- train loss: 0.087833  val RMSE: 157.920994
# Epoch 12/100 -- train loss: 0.087770  val RMSE: 157.839539
# Epoch 13/100 -- train loss: 0.087921  val RMSE: 157.919213
# Epoch 14/100 -- train loss: 0.087774  val RMSE: 157.953231
# Epoch 15/100 -- train loss: 0.087489  val RMSE: 157.891114
# Epoch 16/100 -- train loss: 0.087433  val RMSE: 157.857328
# Epoch 17/100 -- train loss: 0.087350  val RMSE: 157.905327
# Epoch 18/100 -- train loss: 0.087415  val RMSE: 157.688656
# Epoch 19/100 -- train loss: 0.087304  val RMSE: 157.676078
# Epoch 20/100 -- train loss: 0.087246  val RMSE: 157.680614
# Epoch 21/100 -- train loss: 0.087112  val RMSE: 157.696009
# Epoch 22/100 -- train loss: 0.087188  val RMSE: 157.733724
# Epoch 23/100 -- train loss: 0.086875  val RMSE: 157.720339
# Epoch 24/100 -- train loss: 0.086831  val RMSE: 157.711701
# Epoch 25/100 -- train loss: 0.086939  val RMSE: 157.700386
# Epoch 26/100 -- train loss: 0.086648  val RMSE: 157.569248
# Epoch 27/100 -- train loss: 0.086643  val RMSE: 157.750869
# Epoch 28/100 -- train loss: 0.086469  val RMSE: 157.876250
# Epoch 29/100 -- train loss: 0.086680  val RMSE: 157.774737
# Epoch 30/100 -- train loss: 0.086567  val RMSE: 157.833636
# Epoch 31/100 -- train loss: 0.086538  val RMSE: 157.842692
# Epoch 32/100 -- train loss: 0.086631  val RMSE: 157.961175
# Epoch 33/100 -- train loss: 0.086693  val RMSE: 157.938686
# Epoch 34/100 -- train loss: 0.086751  val RMSE: 157.914527
# Epoch 35/100 -- train loss: 0.086788  val RMSE: 157.911857
# Epoch 36/100 -- train loss: 0.086862  val RMSE: 157.863080
# Early stopping at epoch 36 (best val RMSE: 157.569248)
# Training complete for run 15 (best val RMSE: 157.569248)
# Run 15 -- RMSE: 99.162658, MSE: 9833.232777, NMSE: 0.0455330276
#
# ===== RUN 16/60 =====
# Epoch 1/100 -- train loss: 0.186654  val RMSE: 158.147670
# Epoch 2/100 -- train loss: 0.090469  val RMSE: 158.780156
# Epoch 3/100 -- train loss: 0.090482  val RMSE: 158.016635
# Epoch 4/100 -- train loss: 0.090492  val RMSE: 158.411799
# Epoch 5/100 -- train loss: 0.091154  val RMSE: 158.383518
# Epoch 6/100 -- train loss: 0.091902  val RMSE: 157.893385
# Epoch 7/100 -- train loss: 0.091989  val RMSE: 157.909822
# Epoch 8/100 -- train loss: 0.091598  val RMSE: 157.862044
# Epoch 9/100 -- train loss: 0.090980  val RMSE: 158.095318
# Epoch 10/100 -- train loss: 0.090392  val RMSE: 158.340594
# Epoch 11/100 -- train loss: 0.090589  val RMSE: 159.000172
# Epoch 12/100 -- train loss: 0.090012  val RMSE: 158.585630
# Epoch 13/100 -- train loss: 0.089832  val RMSE: 158.199534
# Epoch 14/100 -- train loss: 0.090149  val RMSE: 158.035786
# Epoch 15/100 -- train loss: 0.090068  val RMSE: 157.598657
# Epoch 16/100 -- train loss: 0.088697  val RMSE: 158.090245
# Epoch 17/100 -- train loss: 0.088581  val RMSE: 157.816223
# Epoch 18/100 -- train loss: 0.088189  val RMSE: 158.022457
# Epoch 19/100 -- train loss: 0.088636  val RMSE: 158.067245
# Epoch 20/100 -- train loss: 0.089127  val RMSE: 158.025396
# Epoch 21/100 -- train loss: 0.088467  val RMSE: 157.907136
# Epoch 22/100 -- train loss: 0.088365  val RMSE: 157.721258
# Epoch 23/100 -- train loss: 0.088449  val RMSE: 158.084517
# Epoch 24/100 -- train loss: 0.088547  val RMSE: 157.632929
# Epoch 25/100 -- train loss: 0.087756  val RMSE: 158.119839
# Early stopping at epoch 25 (best val RMSE: 157.598657)
# Training complete for run 16 (best val RMSE: 157.598657)
# Run 16 -- RMSE: 99.427667, MSE: 9885.860964, NMSE: 0.0457767238
#
# ===== RUN 17/60 =====
# Epoch 1/100 -- train loss: 0.304169  val RMSE: 159.964599
# Epoch 2/100 -- train loss: 0.107006  val RMSE: 157.776743
# Epoch 3/100 -- train loss: 0.102134  val RMSE: 155.910785
# Epoch 4/100 -- train loss: 0.095650  val RMSE: 156.159448
# Epoch 5/100 -- train loss: 0.100486  val RMSE: 158.482166
# Epoch 6/100 -- train loss: 0.097308  val RMSE: 158.789482
# Epoch 7/100 -- train loss: 0.093160  val RMSE: 158.398342
# Epoch 8/100 -- train loss: 0.093029  val RMSE: 159.452652
# Epoch 9/100 -- train loss: 0.094354  val RMSE: 159.307193
# Epoch 10/100 -- train loss: 0.095969  val RMSE: 159.053013
# Epoch 11/100 -- train loss: 0.096848  val RMSE: 159.581313
# Epoch 12/100 -- train loss: 0.097330  val RMSE: 160.614849
# Epoch 13/100 -- train loss: 0.095267  val RMSE: 159.043056
# Early stopping at epoch 13 (best val RMSE: 155.910785)
# Training complete for run 17 (best val RMSE: 155.910785)
# Run 17 -- RMSE: 95.522597, MSE: 9124.566537, NMSE: 0.0422515311
#
# ===== RUN 18/60 =====
# Epoch 1/100 -- train loss: 0.087106  val RMSE: 158.963621
# Epoch 2/100 -- train loss: 0.086968  val RMSE: 158.658036
# Epoch 3/100 -- train loss: 0.086957  val RMSE: 158.532520
# Epoch 4/100 -- train loss: 0.087009  val RMSE: 158.459530
# Epoch 5/100 -- train loss: 0.087006  val RMSE: 158.430276
# Epoch 6/100 -- train loss: 0.086945  val RMSE: 158.445440
# Epoch 7/100 -- train loss: 0.086995  val RMSE: 158.432239
# Epoch 8/100 -- train loss: 0.087235  val RMSE: 158.407290
# Epoch 9/100 -- train loss: 0.087269  val RMSE: 158.371761
# Epoch 10/100 -- train loss: 0.087252  val RMSE: 158.356644
# Epoch 11/100 -- train loss: 0.087236  val RMSE: 158.351006
# Epoch 12/100 -- train loss: 0.087220  val RMSE: 158.349737
# Epoch 13/100 -- train loss: 0.087205  val RMSE: 158.350507
# Epoch 14/100 -- train loss: 0.087191  val RMSE: 158.352231
# Epoch 15/100 -- train loss: 0.087178  val RMSE: 158.354408
# Epoch 16/100 -- train loss: 0.087166  val RMSE: 158.356804
# Epoch 17/100 -- train loss: 0.087154  val RMSE: 158.359305
# Epoch 18/100 -- train loss: 0.087143  val RMSE: 158.361864
# Epoch 19/100 -- train loss: 0.087132  val RMSE: 158.364452
# Epoch 20/100 -- train loss: 0.087122  val RMSE: 158.367079
# Epoch 21/100 -- train loss: 0.087112  val RMSE: 158.369740
# Epoch 22/100 -- train loss: 0.087103  val RMSE: 158.372418
# Early stopping at epoch 22 (best val RMSE: 158.349737)
# Training complete for run 18 (best val RMSE: 158.349737)
# Run 18 -- RMSE: 99.260178, MSE: 9852.582905, NMSE: 0.0456226289
#
# ===== RUN 19/60 =====
# Epoch 1/100 -- train loss: 0.094254  val RMSE: 157.581448
# Epoch 2/100 -- train loss: 0.090159  val RMSE: 157.713760
# Epoch 3/100 -- train loss: 0.089093  val RMSE: 158.155818
# Epoch 4/100 -- train loss: 0.090168  val RMSE: 158.392133
# Epoch 5/100 -- train loss: 0.088493  val RMSE: 157.390991
# Epoch 6/100 -- train loss: 0.088006  val RMSE: 157.450995
# Epoch 7/100 -- train loss: 0.087924  val RMSE: 157.501856
# Epoch 8/100 -- train loss: 0.087645  val RMSE: 157.347359
# Epoch 9/100 -- train loss: 0.087297  val RMSE: 157.333837
# Epoch 10/100 -- train loss: 0.088244  val RMSE: 157.330793
# Epoch 11/100 -- train loss: 0.088446  val RMSE: 157.322998
# Epoch 12/100 -- train loss: 0.088203  val RMSE: 157.327187
# Epoch 13/100 -- train loss: 0.088402  val RMSE: 157.323669
# Epoch 14/100 -- train loss: 0.088367  val RMSE: 157.241233
# Epoch 15/100 -- train loss: 0.088784  val RMSE: 157.245816
# Epoch 16/100 -- train loss: 0.087780  val RMSE: 157.336720
# Epoch 17/100 -- train loss: 0.090344  val RMSE: 158.594321
# Epoch 18/100 -- train loss: 0.090461  val RMSE: 158.276619
# Epoch 19/100 -- train loss: 0.090030  val RMSE: 158.428443
# Epoch 20/100 -- train loss: 0.089661  val RMSE: 158.411250
# Epoch 21/100 -- train loss: 0.089761  val RMSE: 158.484041
# Epoch 22/100 -- train loss: 0.090091  val RMSE: 158.539991
# Epoch 23/100 -- train loss: 0.089243  val RMSE: 158.584313
# Epoch 24/100 -- train loss: 0.090664  val RMSE: 158.489268
# Early stopping at epoch 24 (best val RMSE: 157.241233)
# Training complete for run 19 (best val RMSE: 157.241233)
# Run 19 -- RMSE: 98.849412, MSE: 9771.206349, NMSE: 0.0452458127
#
# ===== RUN 20/60 =====
# Epoch 1/100 -- train loss: 0.133564  val RMSE: 160.282731
# Epoch 2/100 -- train loss: 0.088863  val RMSE: 159.932400
# Epoch 3/100 -- train loss: 0.088611  val RMSE: 159.387453
# Epoch 4/100 -- train loss: 0.088112  val RMSE: 159.357822
# Epoch 5/100 -- train loss: 0.087284  val RMSE: 159.061189
# Epoch 6/100 -- train loss: 0.087499  val RMSE: 158.781290
# Epoch 7/100 -- train loss: 0.087800  val RMSE: 158.959423
# Epoch 8/100 -- train loss: 0.086736  val RMSE: 158.976571
# Epoch 9/100 -- train loss: 0.086628  val RMSE: 158.800225
# Epoch 10/100 -- train loss: 0.086588  val RMSE: 158.670805
# Epoch 11/100 -- train loss: 0.086098  val RMSE: 158.674327
# Epoch 12/100 -- train loss: 0.086073  val RMSE: 158.405140
# Epoch 13/100 -- train loss: 0.086013  val RMSE: 158.727454
# Epoch 14/100 -- train loss: 0.085259  val RMSE: 158.625666
# Epoch 15/100 -- train loss: 0.085108  val RMSE: 158.555802
# Epoch 16/100 -- train loss: 0.085047  val RMSE: 158.534498
# Epoch 17/100 -- train loss: 0.085458  val RMSE: 158.434367
# Epoch 18/100 -- train loss: 0.085147  val RMSE: 158.394528
# Epoch 19/100 -- train loss: 0.085768  val RMSE: 158.362634
# Epoch 20/100 -- train loss: 0.085562  val RMSE: 158.355947
# Epoch 21/100 -- train loss: 0.086006  val RMSE: 158.572963
# Epoch 22/100 -- train loss: 0.086378  val RMSE: 157.491872
# Epoch 23/100 -- train loss: 0.086147  val RMSE: 158.280290
# Epoch 24/100 -- train loss: 0.086087  val RMSE: 158.223859
# Epoch 25/100 -- train loss: 0.086112  val RMSE: 158.209432
# Epoch 26/100 -- train loss: 0.085857  val RMSE: 158.146608
# Epoch 27/100 -- train loss: 0.085734  val RMSE: 158.400735
# Epoch 28/100 -- train loss: 0.086290  val RMSE: 158.264467
# Epoch 29/100 -- train loss: 0.086477  val RMSE: 158.280592
# Epoch 30/100 -- train loss: 0.086512  val RMSE: 158.388202
# Epoch 31/100 -- train loss: 0.086242  val RMSE: 158.328511
# Epoch 32/100 -- train loss: 0.086514  val RMSE: 158.257648
# Early stopping at epoch 32 (best val RMSE: 157.491872)
# Training complete for run 20 (best val RMSE: 157.491872)
# Run 20 -- RMSE: 99.528716, MSE: 9905.965379, NMSE: 0.0458698178
#
# ===== RUN 21/60 =====
# Epoch 1/100 -- train loss: 0.097087  val RMSE: 157.352769
# Epoch 2/100 -- train loss: 0.093418  val RMSE: 157.855842
# Epoch 3/100 -- train loss: 0.092493  val RMSE: 159.035230
# Epoch 4/100 -- train loss: 0.092697  val RMSE: 158.474497
# Epoch 5/100 -- train loss: 0.092356  val RMSE: 158.407340
# Epoch 6/100 -- train loss: 0.090034  val RMSE: 157.257189
# Epoch 7/100 -- train loss: 0.088908  val RMSE: 157.744301
# Epoch 8/100 -- train loss: 0.088608  val RMSE: 157.693905
# Epoch 9/100 -- train loss: 0.088920  val RMSE: 157.644288
# Epoch 10/100 -- train loss: 0.089119  val RMSE: 157.673414
# Epoch 11/100 -- train loss: 0.089032  val RMSE: 157.768273
# Epoch 12/100 -- train loss: 0.088763  val RMSE: 157.809789
# Epoch 13/100 -- train loss: 0.088277  val RMSE: 157.814190
# Epoch 14/100 -- train loss: 0.088563  val RMSE: 157.853307
# Epoch 15/100 -- train loss: 0.088675  val RMSE: 157.945477
# Epoch 16/100 -- train loss: 0.088232  val RMSE: 157.951569
# Early stopping at epoch 16 (best val RMSE: 157.257189)
# Training complete for run 21 (best val RMSE: 157.257189)
# Run 21 -- RMSE: 99.591226, MSE: 9918.412271, NMSE: 0.0459274534
#
# ===== RUN 22/60 =====
# Epoch 1/100 -- train loss: 0.126959  val RMSE: 157.097637
# Epoch 2/100 -- train loss: 0.090963  val RMSE: 157.149461
# Epoch 3/100 -- train loss: 0.089069  val RMSE: 157.952697
# Epoch 4/100 -- train loss: 0.089973  val RMSE: 157.985705
# Epoch 5/100 -- train loss: 0.090019  val RMSE: 157.737014
# Epoch 6/100 -- train loss: 0.088832  val RMSE: 157.949088
# Epoch 7/100 -- train loss: 0.089027  val RMSE: 157.782975
# Epoch 8/100 -- train loss: 0.088351  val RMSE: 157.694803
# Epoch 9/100 -- train loss: 0.089282  val RMSE: 157.427575
# Epoch 10/100 -- train loss: 0.088731  val RMSE: 157.557477
# Epoch 11/100 -- train loss: 0.089243  val RMSE: 157.945220
# Early stopping at epoch 11 (best val RMSE: 157.097637)
# Training complete for run 22 (best val RMSE: 157.097637)
# Run 22 -- RMSE: 99.900660, MSE: 9980.141831, NMSE: 0.0462132936
#
# ===== RUN 23/60 =====
# Epoch 1/100 -- train loss: 0.165258  val RMSE: 158.667457
# Epoch 2/100 -- train loss: 0.093440  val RMSE: 158.459414
# Epoch 3/100 -- train loss: 0.093481  val RMSE: 158.161258
# Epoch 4/100 -- train loss: 0.092936  val RMSE: 158.229461
# Epoch 5/100 -- train loss: 0.090855  val RMSE: 158.326094
# Epoch 6/100 -- train loss: 0.090831  val RMSE: 158.721157
# Epoch 7/100 -- train loss: 0.090121  val RMSE: 158.837788
# Epoch 8/100 -- train loss: 0.089580  val RMSE: 158.147208
# Epoch 9/100 -- train loss: 0.090081  val RMSE: 158.247998
# Epoch 10/100 -- train loss: 0.090375  val RMSE: 158.221914
# Epoch 11/100 -- train loss: 0.089500  val RMSE: 157.673415
# Epoch 12/100 -- train loss: 0.091413  val RMSE: 157.901764
# Epoch 13/100 -- train loss: 0.090922  val RMSE: 157.898743
# Epoch 14/100 -- train loss: 0.090264  val RMSE: 158.508855
# Epoch 15/100 -- train loss: 0.090492  val RMSE: 158.561778
# Epoch 16/100 -- train loss: 0.089874  val RMSE: 158.318629
# Epoch 17/100 -- train loss: 0.090180  val RMSE: 158.646685
# Epoch 18/100 -- train loss: 0.090518  val RMSE: 155.634672
# Epoch 19/100 -- train loss: 0.091363  val RMSE: 157.365747
# Epoch 20/100 -- train loss: 0.089657  val RMSE: 157.584595
# Epoch 21/100 -- train loss: 0.089604  val RMSE: 157.609628
# Epoch 22/100 -- train loss: 0.089499  val RMSE: 157.690069
# Epoch 23/100 -- train loss: 0.089701  val RMSE: 157.861299
# Epoch 24/100 -- train loss: 0.088663  val RMSE: 157.798281
# Epoch 25/100 -- train loss: 0.088345  val RMSE: 157.900927
# Epoch 26/100 -- train loss: 0.088696  val RMSE: 157.978187
# Epoch 27/100 -- train loss: 0.089007  val RMSE: 158.015683
# Epoch 28/100 -- train loss: 0.089152  val RMSE: 157.631476
# Early stopping at epoch 28 (best val RMSE: 155.634672)
# Training complete for run 23 (best val RMSE: 155.634672)
# Run 23 -- RMSE: 97.834112, MSE: 9571.513466, NMSE: 0.0443211299
#
# ===== RUN 24/60 =====
# Epoch 1/100 -- train loss: 0.244241  val RMSE: 161.128750
# Epoch 2/100 -- train loss: 0.101671  val RMSE: 159.146977
# Epoch 3/100 -- train loss: 0.095168  val RMSE: 158.303225
# Epoch 4/100 -- train loss: 0.093172  val RMSE: 158.042650
# Epoch 5/100 -- train loss: 0.091548  val RMSE: 157.644600
# Epoch 6/100 -- train loss: 0.090803  val RMSE: 157.943317
# Epoch 7/100 -- train loss: 0.091080  val RMSE: 157.763142
# Epoch 8/100 -- train loss: 0.090110  val RMSE: 158.083854
# Epoch 9/100 -- train loss: 0.089856  val RMSE: 157.898917
# Epoch 10/100 -- train loss: 0.089387  val RMSE: 157.785995
# Epoch 11/100 -- train loss: 0.089447  val RMSE: 157.822119
# Epoch 12/100 -- train loss: 0.088899  val RMSE: 157.663049
# Epoch 13/100 -- train loss: 0.089178  val RMSE: 157.750584
# Epoch 14/100 -- train loss: 0.088454  val RMSE: 158.110548
# Epoch 15/100 -- train loss: 0.088537  val RMSE: 158.050522
# Early stopping at epoch 15 (best val RMSE: 157.644600)
# Training complete for run 24 (best val RMSE: 157.644600)
# Run 24 -- RMSE: 99.670352, MSE: 9934.178987, NMSE: 0.0460004616
#
# ===== RUN 25/60 =====
# Epoch 1/100 -- train loss: 0.097856  val RMSE: 159.172267
# Epoch 2/100 -- train loss: 0.089370  val RMSE: 157.901294
# Epoch 3/100 -- train loss: 0.089697  val RMSE: 157.950970
# Epoch 4/100 -- train loss: 0.089646  val RMSE: 158.033394
# Epoch 5/100 -- train loss: 0.089976  val RMSE: 157.865896
# Epoch 6/100 -- train loss: 0.089266  val RMSE: 157.556232
# Epoch 7/100 -- train loss: 0.089665  val RMSE: 158.226927
# Epoch 8/100 -- train loss: 0.088901  val RMSE: 158.121585
# Epoch 9/100 -- train loss: 0.088387  val RMSE: 158.324922
# Epoch 10/100 -- train loss: 0.088743  val RMSE: 158.197284
# Epoch 11/100 -- train loss: 0.088478  val RMSE: 158.180868
# Epoch 12/100 -- train loss: 0.089317  val RMSE: 157.563867
# Epoch 13/100 -- train loss: 0.089696  val RMSE: 157.699911
# Epoch 14/100 -- train loss: 0.089313  val RMSE: 157.562941
# Epoch 15/100 -- train loss: 0.088941  val RMSE: 157.788387
# Epoch 16/100 -- train loss: 0.089038  val RMSE: 157.793042
# Early stopping at epoch 16 (best val RMSE: 157.556232)
# Training complete for run 25 (best val RMSE: 157.556232)
# Run 25 -- RMSE: 99.512588, MSE: 9902.755219, NMSE: 0.0458549530
#
# ===== RUN 26/60 =====
# Epoch 1/100 -- train loss: 0.211237  val RMSE: 164.084475
# Epoch 2/100 -- train loss: 0.090098  val RMSE: 158.397491
# Epoch 3/100 -- train loss: 0.088703  val RMSE: 157.857882
# Epoch 4/100 -- train loss: 0.088273  val RMSE: 157.660680
# Epoch 5/100 -- train loss: 0.088383  val RMSE: 157.910931
# Epoch 6/100 -- train loss: 0.088533  val RMSE: 157.867948
# Epoch 7/100 -- train loss: 0.088155  val RMSE: 157.743950
# Epoch 8/100 -- train loss: 0.088312  val RMSE: 157.634631
# Epoch 9/100 -- train loss: 0.088341  val RMSE: 157.595727
# Epoch 10/100 -- train loss: 0.088384  val RMSE: 157.535254
# Epoch 11/100 -- train loss: 0.088404  val RMSE: 157.528924
# Epoch 12/100 -- train loss: 0.088437  val RMSE: 157.487503
# Epoch 13/100 -- train loss: 0.088046  val RMSE: 157.442801
# Epoch 14/100 -- train loss: 0.088071  val RMSE: 157.466627
# Epoch 15/100 -- train loss: 0.088510  val RMSE: 157.440824
# Epoch 16/100 -- train loss: 0.088281  val RMSE: 157.447583
# Epoch 17/100 -- train loss: 0.088509  val RMSE: 157.438847
# Epoch 18/100 -- train loss: 0.088560  val RMSE: 157.455079
# Epoch 19/100 -- train loss: 0.087848  val RMSE: 157.403218
# Epoch 20/100 -- train loss: 0.088283  val RMSE: 157.441545
# Epoch 21/100 -- train loss: 0.088277  val RMSE: 157.448988
# Epoch 22/100 -- train loss: 0.087884  val RMSE: 157.414227
# Epoch 23/100 -- train loss: 0.088436  val RMSE: 157.467265
# Epoch 24/100 -- train loss: 0.088109  val RMSE: 157.407397
# Epoch 25/100 -- train loss: 0.088557  val RMSE: 157.432808
# Epoch 26/100 -- train loss: 0.088550  val RMSE: 157.437977
# Epoch 27/100 -- train loss: 0.088352  val RMSE: 157.424269
# Epoch 28/100 -- train loss: 0.088735  val RMSE: 157.454321
# Epoch 29/100 -- train loss: 0.088809  val RMSE: 157.587121
# Early stopping at epoch 29 (best val RMSE: 157.403218)
# Training complete for run 26 (best val RMSE: 157.403218)
# Run 26 -- RMSE: 99.410265, MSE: 9882.400864, NMSE: 0.0457607017
#
# ===== RUN 27/60 =====
# Epoch 1/100 -- train loss: 0.091854  val RMSE: 157.869151
# Epoch 2/100 -- train loss: 0.091157  val RMSE: 157.960460
# Epoch 3/100 -- train loss: 0.090340  val RMSE: 157.949876
# Epoch 4/100 -- train loss: 0.090322  val RMSE: 157.954056
# Epoch 5/100 -- train loss: 0.090276  val RMSE: 157.965064
# Epoch 6/100 -- train loss: 0.088981  val RMSE: 158.054452
# Epoch 7/100 -- train loss: 0.088742  val RMSE: 158.084443
# Epoch 8/100 -- train loss: 0.088706  val RMSE: 158.088313
# Epoch 9/100 -- train loss: 0.088422  val RMSE: 158.086696
# Epoch 10/100 -- train loss: 0.088286  val RMSE: 158.129619
# Epoch 11/100 -- train loss: 0.088322  val RMSE: 158.066308
# Early stopping at epoch 11 (best val RMSE: 157.869151)
# Training complete for run 27 (best val RMSE: 157.869151)
# Run 27 -- RMSE: 99.089109, MSE: 9818.651539, NMSE: 0.0454655089
#
# ===== RUN 28/60 =====
# Epoch 1/100 -- train loss: 0.098708  val RMSE: 157.662854
# Epoch 2/100 -- train loss: 0.093078  val RMSE: 157.942750
# Epoch 3/100 -- train loss: 0.090577  val RMSE: 157.876857
# Epoch 4/100 -- train loss: 0.090925  val RMSE: 157.778935
# Epoch 5/100 -- train loss: 0.090849  val RMSE: 158.378701
# Epoch 6/100 -- train loss: 0.090388  val RMSE: 158.312968
# Epoch 7/100 -- train loss: 0.090147  val RMSE: 158.290823
# Epoch 8/100 -- train loss: 0.089947  val RMSE: 158.294115
# Epoch 9/100 -- train loss: 0.089341  val RMSE: 157.987967
# Epoch 10/100 -- train loss: 0.088489  val RMSE: 157.904141
# Epoch 11/100 -- train loss: 0.088034  val RMSE: 157.986201
# Early stopping at epoch 11 (best val RMSE: 157.662854)
# Training complete for run 28 (best val RMSE: 157.662854)
# Run 28 -- RMSE: 99.568982, MSE: 9913.982218, NMSE: 0.0459069399
#
# ===== RUN 29/60 =====
# Epoch 1/100 -- train loss: 0.091164  val RMSE: 158.671097
# Epoch 2/100 -- train loss: 0.089722  val RMSE: 158.135308
# Epoch 3/100 -- train loss: 0.089649  val RMSE: 158.063786
# Epoch 4/100 -- train loss: 0.089229  val RMSE: 158.422071
# Epoch 5/100 -- train loss: 0.089452  val RMSE: 158.370878
# Epoch 6/100 -- train loss: 0.088762  val RMSE: 158.377018
# Epoch 7/100 -- train loss: 0.088848  val RMSE: 158.109038
# Epoch 8/100 -- train loss: 0.088501  val RMSE: 157.978143
# Epoch 9/100 -- train loss: 0.088434  val RMSE: 157.920524
# Epoch 10/100 -- train loss: 0.088870  val RMSE: 158.046489
# Epoch 11/100 -- train loss: 0.088798  val RMSE: 157.997149
# Epoch 12/100 -- train loss: 0.088030  val RMSE: 158.070506
# Epoch 13/100 -- train loss: 0.087828  val RMSE: 158.116038
# Epoch 14/100 -- train loss: 0.087444  val RMSE: 157.716156
# Epoch 15/100 -- train loss: 0.087581  val RMSE: 157.416600
# Epoch 16/100 -- train loss: 0.087690  val RMSE: 157.647566
# Epoch 17/100 -- train loss: 0.087799  val RMSE: 157.599223
# Epoch 18/100 -- train loss: 0.087599  val RMSE: 157.368141
# Epoch 19/100 -- train loss: 0.087534  val RMSE: 157.831053
# Epoch 20/100 -- train loss: 0.087177  val RMSE: 156.912012
# Epoch 21/100 -- train loss: 0.086954  val RMSE: 157.847353
# Epoch 22/100 -- train loss: 0.086929  val RMSE: 157.849171
# Epoch 23/100 -- train loss: 0.086346  val RMSE: 157.801548
# Epoch 24/100 -- train loss: 0.086645  val RMSE: 157.730241
# Epoch 25/100 -- train loss: 0.086765  val RMSE: 157.695581
# Epoch 26/100 -- train loss: 0.086113  val RMSE: 157.692914
# Epoch 27/100 -- train loss: 0.086061  val RMSE: 157.643778
# Epoch 28/100 -- train loss: 0.086722  val RMSE: 157.620946
# Epoch 29/100 -- train loss: 0.086527  val RMSE: 157.962634
# Epoch 30/100 -- train loss: 0.086002  val RMSE: 158.083340
# Early stopping at epoch 30 (best val RMSE: 156.912012)
# Training complete for run 29 (best val RMSE: 156.912012)
# Run 29 -- RMSE: 99.440893, MSE: 9888.491295, NMSE: 0.0457889036
#
# ===== RUN 30/60 =====
# Epoch 1/100 -- train loss: 0.094903  val RMSE: 156.656985
# Epoch 2/100 -- train loss: 0.089593  val RMSE: 157.027123
# Epoch 3/100 -- train loss: 0.088762  val RMSE: 157.594753
# Epoch 4/100 -- train loss: 0.088534  val RMSE: 157.408609
# Epoch 5/100 -- train loss: 0.091008  val RMSE: 157.750208
# Epoch 6/100 -- train loss: 0.089519  val RMSE: 157.940906
# Epoch 7/100 -- train loss: 0.088690  val RMSE: 157.594258
# Epoch 8/100 -- train loss: 0.087729  val RMSE: 157.837416
# Epoch 9/100 -- train loss: 0.089097  val RMSE: 158.329887
# Epoch 10/100 -- train loss: 0.087673  val RMSE: 158.056022
# Epoch 11/100 -- train loss: 0.086598  val RMSE: 158.089007
# Early stopping at epoch 11 (best val RMSE: 156.656985)
# Training complete for run 30 (best val RMSE: 156.656985)
# Run 30 -- RMSE: 100.243066, MSE: 10048.672237, NMSE: 0.0465306254
#
# ===== RUN 31/60 =====
# Epoch 1/100 -- train loss: 0.088404  val RMSE: 157.980032
# Epoch 2/100 -- train loss: 0.090089  val RMSE: 157.641725
# Epoch 3/100 -- train loss: 0.089561  val RMSE: 157.409954
# Epoch 4/100 -- train loss: 0.088670  val RMSE: 157.273711
# Epoch 5/100 -- train loss: 0.089033  val RMSE: 157.269155
# Epoch 6/100 -- train loss: 0.088782  val RMSE: 157.283692
# Epoch 7/100 -- train loss: 0.088625  val RMSE: 157.564451
# Epoch 8/100 -- train loss: 0.089360  val RMSE: 157.412822
# Epoch 9/100 -- train loss: 0.089660  val RMSE: 157.548953
# Epoch 10/100 -- train loss: 0.088391  val RMSE: 157.584019
# Epoch 11/100 -- train loss: 0.088125  val RMSE: 157.605949
# Epoch 12/100 -- train loss: 0.088094  val RMSE: 157.091364
# Epoch 13/100 -- train loss: 0.088131  val RMSE: 157.699324
# Epoch 14/100 -- train loss: 0.088543  val RMSE: 157.487635
# Epoch 15/100 -- train loss: 0.088647  val RMSE: 157.522404
# Epoch 16/100 -- train loss: 0.087662  val RMSE: 157.696638
# Epoch 17/100 -- train loss: 0.086955  val RMSE: 157.614492
# Epoch 18/100 -- train loss: 0.087576  val RMSE: 157.489972
# Epoch 19/100 -- train loss: 0.088026  val RMSE: 157.233916
# Epoch 20/100 -- train loss: 0.087727  val RMSE: 157.400215
# Epoch 21/100 -- train loss: 0.088010  val RMSE: 157.857878
# Epoch 22/100 -- train loss: 0.087904  val RMSE: 157.426048
# Early stopping at epoch 22 (best val RMSE: 157.091364)
# Training complete for run 31 (best val RMSE: 157.091364)
# Run 31 -- RMSE: 99.460025, MSE: 9892.296533, NMSE: 0.0458065238
#
# ===== RUN 32/60 =====
# Epoch 1/100 -- train loss: 0.190621  val RMSE: 164.210637
# Epoch 2/100 -- train loss: 0.089171  val RMSE: 157.782275
# Epoch 3/100 -- train loss: 0.087290  val RMSE: 157.166779
# Epoch 4/100 -- train loss: 0.088116  val RMSE: 157.407510
# Epoch 5/100 -- train loss: 0.087317  val RMSE: 157.629002
# Epoch 6/100 -- train loss: 0.086354  val RMSE: 157.416831
# Epoch 7/100 -- train loss: 0.087021  val RMSE: 157.415694
# Epoch 8/100 -- train loss: 0.086853  val RMSE: 157.269501
# Epoch 9/100 -- train loss: 0.087003  val RMSE: 157.107067
# Epoch 10/100 -- train loss: 0.086968  val RMSE: 157.430417
# Epoch 11/100 -- train loss: 0.086988  val RMSE: 158.337328
# Epoch 12/100 -- train loss: 0.087154  val RMSE: 156.875450
# Epoch 13/100 -- train loss: 0.087160  val RMSE: 159.196523
# Epoch 14/100 -- train loss: 0.088903  val RMSE: 158.311481
# Epoch 15/100 -- train loss: 0.089001  val RMSE: 158.249568
# Epoch 16/100 -- train loss: 0.088082  val RMSE: 158.538191
# Epoch 17/100 -- train loss: 0.088107  val RMSE: 158.389503
# Epoch 18/100 -- train loss: 0.089696  val RMSE: 158.130717
# Epoch 19/100 -- train loss: 0.088988  val RMSE: 158.256588
# Epoch 20/100 -- train loss: 0.088694  val RMSE: 158.075962
# Epoch 21/100 -- train loss: 0.088600  val RMSE: 158.008339
# Epoch 22/100 -- train loss: 0.088316  val RMSE: 157.835436
# Early stopping at epoch 22 (best val RMSE: 156.875450)
# Training complete for run 32 (best val RMSE: 156.875450)
# Run 32 -- RMSE: 99.722031, MSE: 9944.483396, NMSE: 0.0460481764
#
# ===== RUN 33/60 =====
# Epoch 1/100 -- train loss: 0.124923  val RMSE: 157.213997
# Epoch 2/100 -- train loss: 0.095551  val RMSE: 156.112615
# Epoch 3/100 -- train loss: 0.093996  val RMSE: 156.288031
# Epoch 4/100 -- train loss: 0.091898  val RMSE: 157.343755
# Epoch 5/100 -- train loss: 0.091420  val RMSE: 158.025567
# Epoch 6/100 -- train loss: 0.090547  val RMSE: 158.052680
# Epoch 7/100 -- train loss: 0.090719  val RMSE: 157.980840
# Epoch 8/100 -- train loss: 0.088972  val RMSE: 158.616795
# Epoch 9/100 -- train loss: 0.089844  val RMSE: 158.839344
# Epoch 10/100 -- train loss: 0.089769  val RMSE: 157.857300
# Epoch 11/100 -- train loss: 0.090735  val RMSE: 157.885274
# Epoch 12/100 -- train loss: 0.089542  val RMSE: 157.991602
# Early stopping at epoch 12 (best val RMSE: 156.112615)
# Training complete for run 33 (best val RMSE: 156.112615)
# Run 33 -- RMSE: 98.612499, MSE: 9724.425034, NMSE: 0.0450291907
#
# ===== RUN 34/60 =====
# Epoch 1/100 -- train loss: 0.104450  val RMSE: 158.681167
# Epoch 2/100 -- train loss: 0.094364  val RMSE: 159.517821
# Epoch 3/100 -- train loss: 0.092110  val RMSE: 156.265063
# Epoch 4/100 -- train loss: 0.091532  val RMSE: 159.189127
# Epoch 5/100 -- train loss: 0.089590  val RMSE: 159.045748
# Epoch 6/100 -- train loss: 0.090613  val RMSE: 158.826556
# Epoch 7/100 -- train loss: 0.090767  val RMSE: 157.531843
# Epoch 8/100 -- train loss: 0.090489  val RMSE: 158.050796
# Epoch 9/100 -- train loss: 0.090285  val RMSE: 157.802425
# Epoch 10/100 -- train loss: 0.090489  val RMSE: 158.614311
# Epoch 11/100 -- train loss: 0.089735  val RMSE: 157.786256
# Epoch 12/100 -- train loss: 0.088411  val RMSE: 157.930166
# Epoch 13/100 -- train loss: 0.088860  val RMSE: 157.941199
# Early stopping at epoch 13 (best val RMSE: 156.265063)
# Training complete for run 34 (best val RMSE: 156.265063)
# Run 34 -- RMSE: 98.146833, MSE: 9632.800740, NMSE: 0.0446049221
#
# ===== RUN 35/60 =====
# Epoch 1/100 -- train loss: 0.105633  val RMSE: 157.227086
# Epoch 2/100 -- train loss: 0.096408  val RMSE: 157.618991
# Epoch 3/100 -- train loss: 0.094414  val RMSE: 157.907689
# Epoch 4/100 -- train loss: 0.091788  val RMSE: 158.148583
# Epoch 5/100 -- train loss: 0.092280  val RMSE: 156.001861
# Epoch 6/100 -- train loss: 0.095910  val RMSE: 156.532080
# Epoch 7/100 -- train loss: 0.093877  val RMSE: 160.700243
# Epoch 8/100 -- train loss: 0.095753  val RMSE: 158.635370
# ...
# Epoch 44/100 -- train loss: 0.084979  val RMSE: 156.870446
# Epoch 45/100 -- train loss: 0.085955  val RMSE: 156.825826
# Epoch 46/100 -- train loss: 0.084482  val RMSE: 156.833753
# Epoch 47/100 -- train loss: 0.084324  val RMSE: 157.077878
# Epoch 48/100 -- train loss: 0.084317  val RMSE: 157.089266
# Epoch 49/100 -- train loss: 0.084359  val RMSE: 157.121227
# Epoch 50/100 -- train loss: 0.084927  val RMSE: 156.783635
# Epoch 51/100 -- train loss: 0.084893  val RMSE: 156.759137
# Epoch 52/100 -- train loss: 0.085615  val RMSE: 156.942494
# Epoch 53/100 -- train loss: 0.086453  val RMSE: 156.966445
# Early stopping at epoch 53 (best val RMSE: 156.601642)
# Training complete for run 48 (best val RMSE: 156.601642)
# Run 48 -- RMSE: 99.522918, MSE: 9904.811283, NMSE: 0.0458644737
#
# ===== RUN 49/60 =====
# Epoch 1/100 -- train loss: 0.182281  val RMSE: 160.591558
# Epoch 2/100 -- train loss: 0.089044  val RMSE: 157.369419
# Epoch 3/100 -- train loss: 0.088621  val RMSE: 157.623480
# Epoch 4/100 -- train loss: 0.088003  val RMSE: 157.558795
# Epoch 5/100 -- train loss: 0.088020  val RMSE: 157.522710
# Epoch 6/100 -- train loss: 0.088329  val RMSE: 157.433138
# Epoch 7/100 -- train loss: 0.088562  val RMSE: 157.424290
# Epoch 8/100 -- train loss: 0.088350  val RMSE: 157.635582
# Epoch 9/100 -- train loss: 0.088152  val RMSE: 157.811519
# Epoch 10/100 -- train loss: 0.088944  val RMSE: 157.664728
# Epoch 11/100 -- train loss: 0.088337  val RMSE: 157.508431
# Epoch 12/100 -- train loss: 0.087807  val RMSE: 157.617020
# Early stopping at epoch 12 (best val RMSE: 157.369419)
# Training complete for run 49 (best val RMSE: 157.369419)
# Run 49 -- RMSE: 99.364035, MSE: 9873.211545, NMSE: 0.0457181503
#
# ===== RUN 50/60 =====
# Epoch 1/100 -- train loss: 0.178088  val RMSE: 157.476851
# Epoch 2/100 -- train loss: 0.092475  val RMSE: 157.535921
# Epoch 3/100 -- train loss: 0.090322  val RMSE: 157.795505
# Epoch 4/100 -- train loss: 0.091619  val RMSE: 156.999345
# Epoch 5/100 -- train loss: 0.091594  val RMSE: 157.728321
# Epoch 6/100 -- train loss: 0.090126  val RMSE: 158.032899
# Epoch 7/100 -- train loss: 0.092000  val RMSE: 158.622218
# Epoch 8/100 -- train loss: 0.090917  val RMSE: 158.494467
# Epoch 9/100 -- train loss: 0.090024  val RMSE: 157.908489
# Epoch 10/100 -- train loss: 0.091043  val RMSE: 158.337435
# Epoch 11/100 -- train loss: 0.089526  val RMSE: 158.726227
# Epoch 12/100 -- train loss: 0.089216  val RMSE: 157.888437
# Epoch 13/100 -- train loss: 0.088353  val RMSE: 157.658641
# Epoch 14/100 -- train loss: 0.088171  val RMSE: 158.355802
# Early stopping at epoch 14 (best val RMSE: 156.999345)
# Training complete for run 50 (best val RMSE: 156.999345)
# Run 50 -- RMSE: 99.615198, MSE: 9923.187600, NMSE: 0.0459495657
#
# ===== RUN 51/60 =====
# Epoch 1/100 -- train loss: 0.109777  val RMSE: 158.876097
# Epoch 2/100 -- train loss: 0.092680  val RMSE: 156.172877
# Epoch 3/100 -- train loss: 0.090777  val RMSE: 159.199446
# Epoch 4/100 -- train loss: 0.093328  val RMSE: 159.124705
# Epoch 5/100 -- train loss: 0.091953  val RMSE: 156.590100
# Epoch 6/100 -- train loss: 0.092486  val RMSE: 157.101024
# Epoch 7/100 -- train loss: 0.090595  val RMSE: 157.123564
# Epoch 8/100 -- train loss: 0.089053  val RMSE: 157.705817
# Epoch 9/100 -- train loss: 0.090217  val RMSE: 157.612632
# Epoch 10/100 -- train loss: 0.091197  val RMSE: 156.983072
# Epoch 11/100 -- train loss: 0.090231  val RMSE: 157.301883
# Epoch 12/100 -- train loss: 0.090094  val RMSE: 157.743934
# Early stopping at epoch 12 (best val RMSE: 156.172877)
# Training complete for run 51 (best val RMSE: 156.172877)
# Run 51 -- RMSE: 97.859188, MSE: 9576.420688, NMSE: 0.0443438529
#
# ===== RUN 52/60 =====
# Epoch 1/100 -- train loss: 0.109568  val RMSE: 157.993786
# Epoch 2/100 -- train loss: 0.097857  val RMSE: 157.612626
# Epoch 3/100 -- train loss: 0.097471  val RMSE: 155.610840
# Epoch 4/100 -- train loss: 0.094741  val RMSE: 157.471509
# Epoch 5/100 -- train loss: 0.094316  val RMSE: 157.791487
# Epoch 6/100 -- train loss: 0.091239  val RMSE: 158.295429
# Epoch 7/100 -- train loss: 0.091925  val RMSE: 158.749784
# Epoch 8/100 -- train loss: 0.090387  val RMSE: 158.121001
# Epoch 9/100 -- train loss: 0.089661  val RMSE: 157.919399
# Epoch 10/100 -- train loss: 0.091107  val RMSE: 158.206838
# Epoch 11/100 -- train loss: 0.090400  val RMSE: 157.955648
# Epoch 12/100 -- train loss: 0.090714  val RMSE: 157.517894
# Epoch 13/100 -- train loss: 0.091503  val RMSE: 157.643223
# Early stopping at epoch 13 (best val RMSE: 155.610840)
# Training complete for run 52 (best val RMSE: 155.610840)
# Run 52 -- RMSE: 97.803732, MSE: 9565.569981, NMSE: 0.0442936084
#
# ===== RUN 53/60 =====
# Epoch 1/100 -- train loss: 0.140442  val RMSE: 158.958616
# Epoch 2/100 -- train loss: 0.092911  val RMSE: 159.334653
# Epoch 3/100 -- train loss: 0.091449  val RMSE: 159.451625
# Epoch 4/100 -- train loss: 0.092002  val RMSE: 159.078656
# Epoch 5/100 -- train loss: 0.091336  val RMSE: 158.919348
# Epoch 6/100 -- train loss: 0.090218  val RMSE: 158.243850
# Epoch 7/100 -- train loss: 0.090537  val RMSE: 157.923668
# Epoch 8/100 -- train loss: 0.090180  val RMSE: 157.743574
# Epoch 9/100 -- train loss: 0.089411  val RMSE: 157.701632
# Epoch 10/100 -- train loss: 0.090041  val RMSE: 157.586985
# Epoch 11/100 -- train loss: 0.090058  val RMSE: 157.749685
# Epoch 12/100 -- train loss: 0.089826  val RMSE: 157.815701
# Epoch 13/100 -- train loss: 0.089777  val RMSE: 158.055403
# Epoch 14/100 -- train loss: 0.090132  val RMSE: 157.844691
# Epoch 15/100 -- train loss: 0.090268  val RMSE: 157.947827
# Epoch 16/100 -- train loss: 0.090254  val RMSE: 157.339341
# Epoch 17/100 -- train loss: 0.090123  val RMSE: 157.422578
# Epoch 18/100 -- train loss: 0.090014  val RMSE: 157.957038
# Epoch 19/100 -- train loss: 0.089730  val RMSE: 158.005210
# Epoch 20/100 -- train loss: 0.089871  val RMSE: 157.769144
# Epoch 21/100 -- train loss: 0.089519  val RMSE: 157.720138
# Epoch 22/100 -- train loss: 0.089069  val RMSE: 157.669937
# Epoch 23/100 -- train loss: 0.089459  val RMSE: 157.746949
# Epoch 24/100 -- train loss: 0.089541  val RMSE: 157.714524
# Epoch 25/100 -- train loss: 0.089453  val RMSE: 157.639129
# Epoch 26/100 -- train loss: 0.089435  val RMSE: 157.724501
# Early stopping at epoch 26 (best val RMSE: 157.339341)
# Training complete for run 53 (best val RMSE: 157.339341)
# Run 53 -- RMSE: 99.586748, MSE: 9917.520312, NMSE: 0.0459233232
#
# ===== RUN 54/60 =====
# Epoch 1/100 -- train loss: 0.100761  val RMSE: 162.624069
# Epoch 2/100 -- train loss: 0.101128  val RMSE: 157.719792
# Epoch 3/100 -- train loss: 0.094996  val RMSE: 158.756327
# Epoch 4/100 -- train loss: 0.093175  val RMSE: 158.058748
# Epoch 5/100 -- train loss: 0.093481  val RMSE: 158.128347
# Epoch 6/100 -- train loss: 0.092012  val RMSE: 158.777265
# Epoch 7/100 -- train loss: 0.091908  val RMSE: 157.912849
# Epoch 8/100 -- train loss: 0.091654  val RMSE: 158.399894
# Epoch 9/100 -- train loss: 0.088582  val RMSE: 158.164353
# Epoch 10/100 -- train loss: 0.090468  val RMSE: 157.442540
# Epoch 11/100 -- train loss: 0.091282  val RMSE: 157.662051
# Epoch 12/100 -- train loss: 0.091903  val RMSE: 157.672195
# Epoch 13/100 -- train loss: 0.089490  val RMSE: 158.673419
# Epoch 14/100 -- train loss: 0.089283  val RMSE: 157.917380
# Epoch 15/100 -- train loss: 0.089463  val RMSE: 157.938615
# Epoch 16/100 -- train loss: 0.088786  val RMSE: 157.989755
# Epoch 17/100 -- train loss: 0.089203  val RMSE: 158.080760
# Epoch 18/100 -- train loss: 0.089164  val RMSE: 157.694951
# Epoch 19/100 -- train loss: 0.088818  val RMSE: 157.897557
# Epoch 20/100 -- train loss: 0.089219  val RMSE: 157.654294
# Early stopping at epoch 20 (best val RMSE: 157.442540)
# Training complete for run 54 (best val RMSE: 157.442540)
# Run 54 -- RMSE: 99.373630, MSE: 9875.118434, NMSE: 0.0457269802
#
# ===== RUN 55/60 =====
# Epoch 1/100 -- train loss: 0.177682  val RMSE: 160.017456
# Epoch 2/100 -- train loss: 0.101413  val RMSE: 159.422096
# Epoch 3/100 -- train loss: 0.098402  val RMSE: 159.537814
# Epoch 4/100 -- train loss: 0.096444  val RMSE: 161.054701
# Epoch 5/100 -- train loss: 0.093754  val RMSE: 159.955129
# Epoch 6/100 -- train loss: 0.093397  val RMSE: 160.322221
# Epoch 7/100 -- train loss: 0.093248  val RMSE: 160.203659
# Epoch 8/100 -- train loss: 0.090073  val RMSE: 160.080359
# Epoch 9/100 -- train loss: 0.089944  val RMSE: 158.967832
# Epoch 10/100 -- train loss: 0.088691  val RMSE: 157.969766
# Epoch 11/100 -- train loss: 0.088739  val RMSE: 158.503322
# Epoch 12/100 -- train loss: 0.089158  val RMSE: 158.457777
# Epoch 13/100 -- train loss: 0.088443  val RMSE: 158.314366
# Epoch 14/100 -- train loss: 0.088229  val RMSE: 158.219196
# Epoch 15/100 -- train loss: 0.088370  val RMSE: 158.387491
# Epoch 16/100 -- train loss: 0.087419  val RMSE: 158.476971
# Epoch 17/100 -- train loss: 0.087325  val RMSE: 158.644195
# Epoch 18/100 -- train loss: 0.087314  val RMSE: 158.639767
# Epoch 19/100 -- train loss: 0.087135  val RMSE: 158.722362
# Epoch 20/100 -- train loss: 0.087394  val RMSE: 158.429237
# Early stopping at epoch 20 (best val RMSE: 157.969766)
# Training complete for run 55 (best val RMSE: 157.969766)
# Run 55 -- RMSE: 100.677798, MSE: 10136.019035, NMSE: 0.0469350869
#
# ===== RUN 56/60 =====
# Epoch 1/100 -- train loss: 0.106298  val RMSE: 157.112764
# Epoch 2/100 -- train loss: 0.089905  val RMSE: 157.414103
# Epoch 3/100 -- train loss: 0.094453  val RMSE: 157.052070
# Epoch 4/100 -- train loss: 0.092839  val RMSE: 158.661829
# Epoch 5/100 -- train loss: 0.090155  val RMSE: 158.379651
# Epoch 6/100 -- train loss: 0.090580  val RMSE: 158.333406
# Epoch 7/100 -- train loss: 0.090473  val RMSE: 158.325851
# Epoch 8/100 -- train loss: 0.089054  val RMSE: 157.795706
# Epoch 9/100 -- train loss: 0.088269  val RMSE: 157.991991
# Epoch 10/100 -- train loss: 0.089544  val RMSE: 158.106214
# Epoch 11/100 -- train loss: 0.088948  val RMSE: 157.981344
# Epoch 12/100 -- train loss: 0.089118  val RMSE: 157.457551
# Epoch 13/100 -- train loss: 0.090024  val RMSE: 157.663252
# Early stopping at epoch 13 (best val RMSE: 157.052070)
# Training complete for run 56 (best val RMSE: 157.052070)
# Run 56 -- RMSE: 98.919111, MSE: 9784.990495, NMSE: 0.0453096406
#
# ===== RUN 57/60 =====
# Epoch 1/100 -- train loss: 0.090290  val RMSE: 158.196981
# Epoch 2/100 -- train loss: 0.088887  val RMSE: 158.031485
# Epoch 3/100 -- train loss: 0.088106  val RMSE: 158.628870
# Epoch 4/100 -- train loss: 0.087692  val RMSE: 158.400431
# Epoch 5/100 -- train loss: 0.088108  val RMSE: 158.506207
# Epoch 6/100 -- train loss: 0.087975  val RMSE: 157.670003
# Epoch 7/100 -- train loss: 0.087905  val RMSE: 158.352169
# Epoch 8/100 -- train loss: 0.087869  val RMSE: 158.252432
# Epoch 9/100 -- train loss: 0.088174  val RMSE: 158.098787
# Epoch 10/100 -- train loss: 0.088271  val RMSE: 158.040975
# Epoch 11/100 -- train loss: 0.088490  val RMSE: 157.906971
# Epoch 12/100 -- train loss: 0.088289  val RMSE: 158.541681
# Epoch 13/100 -- train loss: 0.088092  val RMSE: 158.631050
# Epoch 14/100 -- train loss: 0.087734  val RMSE: 158.599362
# Epoch 15/100 -- train loss: 0.087446  val RMSE: 158.648760
# Epoch 16/100 -- train loss: 0.087772  val RMSE: 158.877970
# Early stopping at epoch 16 (best val RMSE: 157.670003)
# Training complete for run 57 (best val RMSE: 157.670003)
# Run 57 -- RMSE: 99.751160, MSE: 9950.293910, NMSE: 0.0460750821
#
# ===== RUN 58/60 =====
# Epoch 1/100 -- train loss: 0.096029  val RMSE: 159.887939
# Epoch 2/100 -- train loss: 0.097259  val RMSE: 159.406303
# Epoch 3/100 -- train loss: 0.093116  val RMSE: 158.446894
# Epoch 4/100 -- train loss: 0.092873  val RMSE: 154.735208
# Epoch 5/100 -- train loss: 0.091659  val RMSE: 161.997676
# Epoch 6/100 -- train loss: 0.091018  val RMSE: 158.314946
# Epoch 7/100 -- train loss: 0.092493  val RMSE: 158.232069
# Epoch 8/100 -- train loss: 0.089598  val RMSE: 157.861332
# Epoch 9/100 -- train loss: 0.090251  val RMSE: 158.578188
# Epoch 10/100 -- train loss: 0.090078  val RMSE: 158.616613
# Epoch 11/100 -- train loss: 0.089134  val RMSE: 158.649283
# Epoch 12/100 -- train loss: 0.089971  val RMSE: 159.212325
# Epoch 13/100 -- train loss: 0.089944  val RMSE: 156.997543
# Epoch 14/100 -- train loss: 0.088949  val RMSE: 158.793087
# Early stopping at epoch 14 (best val RMSE: 154.735208)
# Training complete for run 58 (best val RMSE: 154.735208)
# Run 58 -- RMSE: 98.551072, MSE: 9712.313889, NMSE: 0.0449731097
#
# ===== RUN 59/60 =====
# Epoch 1/100 -- train loss: 0.101480  val RMSE: 158.800137
# Epoch 2/100 -- train loss: 0.095619  val RMSE: 158.386555
# Epoch 3/100 -- train loss: 0.094924  val RMSE: 158.804446
# Epoch 4/100 -- train loss: 0.094284  val RMSE: 159.054852
# Epoch 5/100 -- train loss: 0.093801  val RMSE: 158.789049
# Epoch 6/100 -- train loss: 0.093796  val RMSE: 157.521753
# Epoch 7/100 -- train loss: 0.094009  val RMSE: 157.463135
# Epoch 8/100 -- train loss: 0.093006  val RMSE: 157.315345
# Epoch 9/100 -- train loss: 0.092335  val RMSE: 156.946884
# Epoch 10/100 -- train loss: 0.093356  val RMSE: 156.990683
# Epoch 11/100 -- train loss: 0.090592  val RMSE: 157.193106
# Epoch 12/100 -- train loss: 0.090468  val RMSE: 157.995664
# Epoch 13/100 -- train loss: 0.090346  val RMSE: 157.401524
# Epoch 14/100 -- train loss: 0.088274  val RMSE: 156.874324
# Epoch 15/100 -- train loss: 0.088987  val RMSE: 156.993422
# Epoch 16/100 -- train loss: 0.087354  val RMSE: 156.799371
# Epoch 17/100 -- train loss: 0.089202  val RMSE: 157.081468
# Epoch 18/100 -- train loss: 0.090269  val RMSE: 157.097041
# Epoch 19/100 -- train loss: 0.088950  val RMSE: 157.225493
# Epoch 20/100 -- train loss: 0.089788  val RMSE: 157.032776
# Epoch 21/100 -- train loss: 0.090701  val RMSE: 157.117354
# Epoch 22/100 -- train loss: 0.089543  val RMSE: 156.687213
# Epoch 23/100 -- train loss: 0.090370  val RMSE: 157.317140
# Epoch 24/100 -- train loss: 0.089794  val RMSE: 156.803902
# Epoch 25/100 -- train loss: 0.089453  val RMSE: 157.256998
# Epoch 26/100 -- train loss: 0.089600  val RMSE: 156.771037
# Epoch 27/100 -- train loss: 0.089821  val RMSE: 156.823961
# Epoch 28/100 -- train loss: 0.090707  val RMSE: 157.172487
# Epoch 29/100 -- train loss: 0.088603  val RMSE: 157.592195
# Epoch 30/100 -- train loss: 0.087915  val RMSE: 157.090496
# Epoch 31/100 -- train loss: 0.089649  val RMSE: 157.051601
# Epoch 32/100 -- train loss: 0.089119  val RMSE: 157.140335
# Early stopping at epoch 32 (best val RMSE: 156.687213)
# Training complete for run 59 (best val RMSE: 156.687213)
# Run 59 -- RMSE: 98.872924, MSE: 9775.855167, NMSE: 0.0452673392
#
# ===== RUN 60/60 =====
# Epoch 1/100 -- train loss: 0.108774  val RMSE: 159.573335
# Epoch 2/100 -- train loss: 0.099284  val RMSE: 159.241190
# Epoch 3/100 -- train loss: 0.096011  val RMSE: 158.808279
# Epoch 4/100 -- train loss: 0.094124  val RMSE: 158.524352
# Epoch 5/100 -- train loss: 0.094991  val RMSE: 158.250678
# Epoch 6/100 -- train loss: 0.093397  val RMSE: 158.974993
# Epoch 7/100 -- train loss: 0.092716  val RMSE: 158.833932
# Epoch 8/100 -- train loss: 0.091976  val RMSE: 158.612136
# Epoch 9/100 -- train loss: 0.091141  val RMSE: 158.111118
# Epoch 10/100 -- train loss: 0.092190  val RMSE: 158.089340
# Epoch 11/100 -- train loss: 0.092110  val RMSE: 158.941034
# Epoch 12/100 -- train loss: 0.091662  val RMSE: 158.424003
# Epoch 13/100 -- train loss: 0.091900  val RMSE: 158.390352
# Epoch 14/100 -- train loss: 0.091230  val RMSE: 158.219722
# Epoch 15/100 -- train loss: 0.092249  val RMSE: 157.472713
# Epoch 16/100 -- train loss: 0.091856  val RMSE: 157.466603
# Epoch 17/100 -- train loss: 0.091963  val RMSE: 156.835322
# Epoch 18/100 -- train loss: 0.091487  val RMSE: 157.596391
# Epoch 19/100 -- train loss: 0.091289  val RMSE: 156.976741
# Epoch 20/100 -- train loss: 0.091208  val RMSE: 157.009947
# Epoch 21/100 -- train loss: 0.090758  val RMSE: 157.569969
# Epoch 22/100 -- train loss: 0.091086  val RMSE: 157.288445
# Epoch 23/100 -- train loss: 0.091261  val RMSE: 157.751115
# Epoch 24/100 -- train loss: 0.091622  val RMSE: 157.464790
# Epoch 25/100 -- train loss: 0.091213  val RMSE: 157.542367
# Epoch 26/100 -- train loss: 0.090855  val RMSE: 157.562904
# Epoch 27/100 -- train loss: 0.091744  val RMSE: 157.390512
# Early stopping at epoch 27 (best val RMSE: 156.835322)
# Training complete for run 60 (best val RMSE: 156.835322)
# Run 60 -- RMSE: 98.860758, MSE: 9773.449552, NMSE: 0.0452561999

# %%
# Fix the flaky save_progress (retry on Windows file lock)
def save_progress(run, epoch, run_losses_partial):
    snapshot = {
        'all_rmse': all_rmse,
        'all_mse': all_mse,
        'all_nmse': all_nmse,
        'all_predictions': all_predictions,
        'all_losses': all_losses,
        'current_run': run,
        'current_epoch': epoch,
        'current_run_losses_partial': run_losses_partial,
    }
    tmp_path = PROGRESS_PATH + '.tmp'
    with open(tmp_path, 'wb') as f:
        pickle.dump(snapshot, f)
    max_attempts = 5
    for attempt in range(max_attempts):
        try:
            os.replace(tmp_path, PROGRESS_PATH)
            return
        except PermissionError:
            if attempt == max_attempts - 1:
                print(f"  [warning] Could not update progress.pkl this epoch -- continuing.")
                return
            time.sleep(0.2 * (attempt + 1))

# Sanity check before continuing
print(f"Completed runs so far: {len(all_rmse)}")  # should print 40
# Out:
# Completed runs so far: 60

# %%
resume_from = len(all_rmse)  # 40 — the next run to do
print(f"Resuming from run {resume_from + 1}/{N_RUNS}")

for run in range(resume_from, N_RUNS):
    print(f'\n===== RUN {run + 1}/{N_RUNS} =====')
    np.random.seed(run)
    torch.manual_seed(run)
    model = build_model(input_dim=1, units=8).to(device)
    optimizer = torch.optim.Adam(model.parameters(), lr=0.001)
    criterion = nn.MSELoss()
    run_losses = []
    X_train_t = torch.tensor(X_train, dtype=torch.float32).to(device)
    y_train_t = torch.tensor(y_train, dtype=torch.float32).to(device)
    n_samples = X_train_t.size(0)
    best_val_rmse = float('inf')
    best_state = None
    patience_ctr = 0

    for epoch in range(100):
        model.train()
        model.reset_states(1, device)
        epoch_loss = 0.0
        for i in range(n_samples):
            x_i = X_train_t[i:i + 1]
            y_i = y_train_t[i:i + 1]
            optimizer.zero_grad()
            pred = model(x_i)
            loss = criterion(pred.squeeze(-1), y_i)
            loss.backward()
            torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)
            optimizer.step()
            model.detach_states()
            epoch_loss += loss.item()
        avg_loss = epoch_loss / n_samples
        run_losses.append(avg_loss)
        _, val_rmse, _, _ = evaluate_on_test(model, val_X, train, train_scaled, raw_values, scaler, device)
        print(f"Epoch {epoch + 1}/100 -- train loss: {avg_loss:.6f}  val RMSE: {val_rmse:.6f}")
        log_epoch(run + 1, epoch + 1, avg_loss, val_rmse)
        save_progress(run + 1, epoch + 1, run_losses)
        if val_rmse < best_val_rmse:
            best_val_rmse = val_rmse
            best_state = {k: v.clone() for k, v in model.state_dict().items()}
            patience_ctr = 0
        else:
            patience_ctr += 1
            if patience_ctr >= PATIENCE:
                print(f"Early stopping at epoch {epoch + 1} (best val RMSE: {best_val_rmse:.6f})")
                break

    model.load_state_dict(best_state)
    model.reset_states(1, device)
    all_losses.append(run_losses)
    all_models.append(model)
    print(f'Training complete for run {run + 1} (best val RMSE: {best_val_rmse:.6f})')
    predictions, rmse, mse, nmse = evaluate_on_test(model, X_test, train, train_scaled, raw_values, scaler, device)
    all_rmse.append(rmse)
    all_mse.append(mse)
    all_nmse.append(nmse)
    all_predictions.append(predictions)
    save_progress(run + 1, epoch + 1, run_losses)
    print(f'Run {run + 1} -- RMSE: {rmse:.6f}, MSE: {mse:.6f}, NMSE: {nmse:.10f}')
# Out:
# Resuming from run 61/60

# %% [markdown]
# ## Results

# %%
#Clean-data summary
print('===== CLEAN-DATA RESULTS (60 runs) =====')
print(f'RMSE: {np.mean(all_rmse):.6f} ± {np.std(all_rmse):.6f}')
print(f'MSE:  {np.mean(all_mse):.6f} ± {np.std(all_mse):.6f}')
print(f'NMSE: {np.mean(all_nmse):.10f} ± {np.std(all_nmse):.10f}')

best_idx = np.argmin(all_rmse)
print(f'\nBest run: {best_idx + 1}')
print(f'  RMSE: {all_rmse[best_idx]:.6f}')
print(f'  MSE:  {all_mse[best_idx]:.6f}')
print(f'  NMSE: {all_nmse[best_idx]:.10f}')
# Out:
# ===== CLEAN-DATA RESULTS (60 runs) =====
# RMSE: 99.215465 ± 0.759667
# MSE:  9844.285667 ± 149.606009
# NMSE: 0.0455842083 ± 0.0006927543
#
# Best run: 17
#   RMSE: 95.522597
#   MSE:  9124.566537
#   NMSE: 0.0422515311

# %%
#Best-run prediction plot
actual = raw_values[-len(test_scaled):]
best_predictions = all_predictions[best_idx]

plt.figure(figsize=(12, 5))
plt.plot(actual, label='Actual', color='blue', linewidth=1.5)
plt.plot(best_predictions, label='Predicted (Best Run)', color='red', linewidth=1.5, linestyle='--')
plt.title('SNN Transformer -- Lake Erie Levels\nPredictions vs Actual (Best of 60 runs, clean data)')
plt.xlabel('Time Step')
plt.ylabel('Value')
plt.legend()
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

plt.figure(figsize=(12, 4))
plt.plot(all_losses[best_idx], color='green', linewidth=1.0)
plt.title('SNN Transformer -- Lake Erie Levels\nTraining Loss (Best Run)')
plt.xlabel('Epoch')
plt.ylabel('MSE Loss')
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Gaussian Noise-Robustness Sweep (0.5% / 5% / 10% / 15%)

# %%
#Noise-robustness sweep (averaged over multiple noise draws)

N_NOISE_DRAWS = 10  # average over multiple ε(t) realizations per model, per level

noise_robustness = {}  # noise_level -> dict of per-model RMSE/MSE/NMSE (averaged over draws)

for noise_level in NOISE_LEVELS:
    level_rmse, level_mse, level_nmse = [], [], []

    for run, model in enumerate(all_models):
        draw_rmse, draw_mse, draw_nmse = [], [], []
        for draw in range(N_NOISE_DRAWS):
            seed = hash((noise_level, run, draw)) % (2 ** 32)
            X_test_noisy = add_gaussian_noise(X_test, noise_level, ref_std, seed=seed)
            _, rmse, mse, nmse = evaluate_on_test(
                model, X_test_noisy, train, train_scaled, raw_values, scaler, device
            )
            draw_rmse.append(rmse)
            draw_mse.append(mse)
            draw_nmse.append(nmse)

        level_rmse.append(np.mean(draw_rmse))  # this model's average over noise draws
        level_mse.append(np.mean(draw_mse))
        level_nmse.append(np.mean(draw_nmse))

    noise_robustness[noise_level] = {'rmse': level_rmse, 'mse': level_mse, 'nmse': level_nmse}
    print(f"[{noise_level * 100:5.1f}% noise]  "
          f"RMSE: {np.mean(level_rmse):.6f} ± {np.std(level_rmse):.6f}  |  "
          f"MSE: {np.mean(level_mse):.6f} ± {np.std(level_mse):.6f}  |  "
          f"NMSE: {np.mean(level_nmse):.10f} ± {np.std(level_nmse):.10f}")
# Out:
# [  0.5% noise]  RMSE: 99.212456 ± 0.757463  |  MSE: 9843.688521 ± 149.167999  |  NMSE: 0.0455814432 ± 0.0006907261
# [  5.0% noise]  RMSE: 99.211339 ± 0.716978  |  MSE: 9843.419837 ± 141.390329  |  NMSE: 0.0455801991 ± 0.0006547114
# [ 10.0% noise]  RMSE: 99.224793 ± 0.696272  |  MSE: 9846.083753 ± 137.509664  |  NMSE: 0.0455925344 ± 0.0006367419
# [ 15.0% noise]  RMSE: 99.240145 ± 0.653378  |  MSE: 9849.085630 ± 129.141874  |  NMSE: 0.0456064347 ± 0.0005979946

# %%
#Summary table + paired degradation test

print('===== ROBUSTNESS SUMMARY (60 runs per condition, averaged over 10 noise draws) =====')
print(f"{'Condition':<12}{'RMSE':>14}{'MSE':>16}{'NMSE':>16}")
print(f"{'Clean':<12}{np.mean(all_rmse):>14.6f}{np.mean(all_mse):>16.6f}{np.mean(all_nmse):>16.10f}")
for noise_level in NOISE_LEVELS:
    r = noise_robustness[noise_level]
    label = f"{noise_level * 100:.1f}% noise"
    print(f"{label:<12}{np.mean(r['rmse']):>14.6f}{np.mean(r['mse']):>16.6f}{np.mean(r['nmse']):>16.10f}")

print('\n===== PAIRED DEGRADATION (per-model delta vs its own clean RMSE) =====')
for noise_level in NOISE_LEVELS:
    delta = np.array(noise_robustness[noise_level]['rmse']) - np.array(all_rmse)
    t_stat, p_val = stats.ttest_rel(noise_robustness[noise_level]['rmse'], all_rmse)
    print(f"{noise_level*100:5.1f}% noise -- ΔRMSE: {delta.mean():.6f} ± {delta.std():.6f}  "
          f"(paired t-test p={p_val:.4f})")
# Out:
# ===== ROBUSTNESS SUMMARY (60 runs per condition, averaged over 10 noise draws) =====
# Condition             RMSE             MSE            NMSE
# Clean            99.215465     9844.285667    0.0455842083
# 0.5% noise       99.212456     9843.688521    0.0455814432
# 5.0% noise       99.211339     9843.419837    0.0455801991
# 10.0% noise      99.224793     9846.083753    0.0455925344
# 15.0% noise      99.240145     9849.085630    0.0456064347
#
# ===== PAIRED DEGRADATION (per-model delta vs its own clean RMSE) =====
#   0.5% noise -- ΔRMSE: -0.003009 ± 0.037543  (paired t-test p=0.5405)
#   5.0% noise -- ΔRMSE: -0.004126 ± 0.145791  (paired t-test p=0.8287)
#  10.0% noise -- ΔRMSE: 0.009328 ± 0.203609  (paired t-test p=0.7262)
#  15.0% noise -- ΔRMSE: 0.024680 ± 0.264816  (paired t-test p=0.4769)

# %%
#RMSE vs. noise-level plot

labels = ['Clean'] + [f"{n * 100:.1f}%" for n in NOISE_LEVELS]
rmse_means = [np.mean(all_rmse)] + [np.mean(noise_robustness[n]['rmse']) for n in NOISE_LEVELS]
rmse_stds = [np.std(all_rmse)] + [np.std(noise_robustness[n]['rmse']) for n in NOISE_LEVELS]

plt.figure(figsize=(8, 5))
plt.errorbar(labels, rmse_means, yerr=rmse_stds, marker='o', capsize=4, color='darkorange')
plt.title('SNN Transformer -- Lake Erie Levels\nRMSE vs. Input Gaussian Noise Level')
plt.xlabel('Noise level')
plt.ylabel('RMSE (60-run mean ± std)')
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

# %%
#Paired RMSE-degradation plot

labels = [f"{n * 100:.1f}%" for n in NOISE_LEVELS]
delta_means = [np.mean(np.array(noise_robustness[n]['rmse']) - np.array(all_rmse)) for n in NOISE_LEVELS]
delta_stds = [np.std(np.array(noise_robustness[n]['rmse']) - np.array(all_rmse)) for n in NOISE_LEVELS]

plt.figure(figsize=(8, 5))
plt.errorbar(labels, delta_means, yerr=delta_stds, marker='o', capsize=4, color='crimson')
plt.axhline(0, color='gray', linestyle='--', linewidth=1)
plt.title('SNN Transformer -- Lake Erie Levels\nRMSE Degradation vs. Input Gaussian Noise Level (paired, per-model)')
plt.xlabel('Noise level')
plt.ylabel('ΔRMSE vs. clean baseline (60-run mean ± std)')
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Observations
#
# ### SNN Transformer on Dow Jones (with Gaussian noise robustness)
#
# **Run the notebook to generate results and fill in observations:**
#
# 1. **Prediction Quality**: Compare clean-data RMSE/MSE/NMSE with the LSTM-SNP baseline and
#    fuzzy-gate variants on the same architecture-substitution protocol.
# 2. **Noise Robustness**: Compare the RMSE degradation curve (0.5% / 5% / 10% / 15%) against
#    the LSTM-SNP-family curves -- does the spiking/attention architecture degrade faster or
#    slower under input perturbation?
# 3. **Statistical Significance**: Check the paired t-test p-values -- at which noise level does
#    degradation become significant for this architecture?
# 4. **Training Stability**: Examine loss curves and how many epochs each run needed before
#    early stopping triggered.
# 5. **Computational Cost**: Note training time per run relative to the LSTM-SNP variants (the
#    spiking transformer block adds attention + MLP + LIF neuron overhead per timestep, over T=4
#    spiking timesteps).
#
# *After running all variant notebooks with the noise-robustness extension, perform a
# cross-architecture comparison of the RMSE-vs-noise-level and ΔRMSE-vs-noise-level curves.*
