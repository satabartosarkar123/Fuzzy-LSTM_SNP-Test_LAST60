# %% [markdown]
# # Pure GRU — Monthly Milk Production (Gaussian Noise Evaluation)
#
# Time series forecasting with Gaussian noise robustness analysis.
# - Noise levels: [0.0, 0.005, 0.05, 0.1]
# - 60 runs × 100 epochs per noise level
# - Last 60 for test, rest for training, NO validation

# %%
# ============================================================
# ALL IMPORTS
# ============================================================

import numpy as np
import pandas as pd
import torch
import torch.nn as nn
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from math import sqrt
import matplotlib.pyplot as plt
import warnings
import os

warnings.filterwarnings('ignore')
print(f"PyTorch version: {torch.__version__}")
print(f"NumPy version: {np.__version__}")
# Out:
# PyTorch version: 2.10.0+cu128
# NumPy version: 2.0.2

# %%
# ============================================================
# Pure GRU — Gated Recurrent Unit (Stateful)
# ============================================================
# Cho et al. (2014) GRU.
# Maintained hidden state across sequence steps to match LSTM-SNP.

import torch
import torch.nn as nn

class PureGRU(nn.Module):
    def __init__(self, input_dim=1, hidden_dim=8, output_dim=1):
        super().__init__()
        self.hidden_dim = hidden_dim
        self.gru = nn.GRU(input_dim, hidden_dim, batch_first=True)
        self.fc = nn.Linear(hidden_dim, output_dim)
        self.u = None  # Internal state matching LSTM-SNP interface

    def reset_states(self, batch_size, device):
        self.u = torch.zeros(1, batch_size, self.hidden_dim, device=device)

    def detach_states(self):
        if self.u is not None:
            self.u = self.u.detach()

    def forward(self, x):
        if self.u is None or self.u.device != x.device:
            self.reset_states(x.size(0), x.device)
            
        gru_out, self.u = self.gru(x, self.u)
        out = self.fc(gru_out[:, -1, :])
        return out

def build_model(input_dim=1, units=8):
    return PureGRU(input_dim=input_dim, hidden_dim=units, output_dim=1)

# Quick architecture check
model = build_model(input_dim=1, units=8)
print(model)
print(f"Total params: {sum(p.numel() for p in model.parameters())}")
# Out:
# PureGRU(
#   (gru): GRU(1, 8, batch_first=True)
#   (fc): Linear(in_features=8, out_features=1, bias=True)
# )
# Total params: 273

# %%
# Quick model check
model = build_model(input_dim=1, units=8)
print(model)
print(f"Total params: {sum(p.numel() for p in model.parameters())}")
# Out:
# PureGRU(
#   (gru): GRU(1, 8, batch_first=True)
#   (fc): Linear(in_features=8, out_features=1, bias=True)
# )
# Total params: 273

# %% [markdown]
# ## Data Pipeline — Monthly Milk Production

# %%
import os
for f in os.listdir('/kaggle/input/datasets/satabartosarkar/monthly-milk-production-pounds-p-csv'):
    print(f)
# Out:
# monthly-milk-production-pounds-p.csv

# %%
# ============================================================
# 1. Load Time Series Data
# ============================================================
series = pd.read_csv(
    '/kaggle/input/datasets/satabartosarkar/monthly-milk-production-pounds-p-csv/monthly-milk-production-pounds-p.csv',
    header=0,
    parse_dates=[0],
    index_col=0
)

original_raw_values = series.values.flatten()
print(f"Base data shape: {original_raw_values.shape}")
print(f"First 5 values: {original_raw_values[:5]}")
# Out:
# Base data shape: (168,)
# First 5 values: [589 561 640 656 727]

# %%
# ============================================================
# 2. First-Order Differencing
# ============================================================

def difference(dataset, interval=1):
    diff = []
    for i in range(interval, len(dataset)):
        value = dataset[i] - dataset[i - interval]
        diff.append(value)
    return np.array(diff)

# %%
# ============================================================
# 3. Convert to Supervised Learning Format (lag=1)
# ============================================================

def timeseries_to_supervised(data, lag=1):
    df = pd.DataFrame(data)
    columns = [df.shift(i) for i in range(1, lag+1)]
    columns.append(df)
    df = pd.concat(columns, axis=1)
    df.fillna(0, inplace=True)
    return df.values

# %% [markdown]
# ## Training Loop

# %%
# ============================================================
# Gaussian Noise Evaluation + 60-Run Experiment Protocol (PyTorch)
# ============================================================
import torch
import torch.nn as nn

s_x = np.std(original_raw_values)
noise_levels = [0.0, 0.005, 0.05, 0.1]
_molab_results = []

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"\n--- [PyTorch] RUNNING ON {device} ---\n")

for lam in noise_levels:
    sigma = lam * s_x
    print("\n" + "="*80)
    print(f"EVALUATING NOISE LEVEL: {lam*100:.1f}% (lambda={lam}, sigma={sigma:.6f})")
    print("="*80 + "\n")
    
    np.random.seed(42)
    torch.manual_seed(42)
    noise = np.random.normal(0, sigma, size=original_raw_values.shape)
    raw_values = original_raw_values + noise
    
    # 2. Difference
    diff_values = difference(raw_values, 1)
    # 3. Supervised (lag=1)
    supervised = timeseries_to_supervised(diff_values, 1)
    # 4. Split (Last 60 for test, NO validation)
    train, test = supervised[:-60], supervised[-60:]
    # 5. Scale
    scaler = MinMaxScaler(feature_range=(-1, 1))
    scaler.fit(train)
    train_scaled = scaler.transform(train)
    test_scaled = scaler.transform(test)
    # 6. Reshape
    X_train, y_train = train_scaled[:, 0:-1], train_scaled[:, -1]
    X_train = X_train.reshape((X_train.shape[0], 1, X_train.shape[1]))
    
    print(f"X_train shape: {X_train.shape}, y_train shape: {y_train.shape}")
    
    all_rmse = []
    all_mse = []
    all_nmse = []
    all_predictions = []
    all_losses = []
    
    for run in range(60):
        print(f'\n===== RUN {run+1}/60 [Noise {lam*100:.1f}%] =====')
        
        np.random.seed(run)
        torch.manual_seed(run)
        
        model = build_model(input_dim=1, units=8).to(device)
        optimizer = torch.optim.Adam(model.parameters(), lr=0.001)
        criterion = nn.MSELoss()
        
        # Pre-tensorize training data
        X_train_t = torch.tensor(X_train, dtype=torch.float32).to(device)
        y_train_t = torch.tensor(y_train, dtype=torch.float32).to(device)
        n_samples = X_train_t.size(0)
        
        run_losses = []
        for epoch in range(100):
            model.train()
            model.reset_states(1, device)
            
            epoch_loss = 0.0
            for i in range(n_samples):
                x_i = X_train_t[i:i+1]
                y_i = y_train_t[i:i+1]
                
                optimizer.zero_grad()
                pred = model(x_i)
                loss = criterion(pred.squeeze(-1), y_i)
                loss.backward()
                optimizer.step()
                model.detach_states()
                epoch_loss += loss.item()
            
            avg_loss = epoch_loss / n_samples
            run_losses.append(avg_loss)
            if (epoch+1) % 10 == 0:
                print(f"  Epoch {epoch+1}/100, Loss: {avg_loss:.6f}")
        
        all_losses.append(run_losses)
        print(f'Training complete for run {run+1}')
        
        # Warm-up: condition hidden states on training data
        model.eval()
        with torch.no_grad():
            model.reset_states(1, device)
            for i in range(len(train_scaled)):
                X_raw = train_scaled[i, 0:-1]
                X_input = torch.tensor(X_raw, dtype=torch.float32).view(1, 1, len(X_raw)).to(device)
                model(X_input)
        
        # Test predictions (single-step)
        predictions = []
        model.eval()
        with torch.no_grad():
            for i in range(len(test_scaled)):
                X = test_scaled[i, 0:-1]
                X_input = torch.tensor(X, dtype=torch.float32).view(1, 1, len(X)).to(device)
                yhat = model(X_input).item()
                
                # Invert scaling
                new_row = list(X) + [yhat]
                array = np.array(new_row).reshape(1, len(new_row))
                inverted = scaler.inverse_transform(array)[0, -1]
                
                # Invert differencing
                inverted = inverted + raw_values[len(train) + i]
                predictions.append(inverted)
        
        # Compute metrics
        actual = raw_values[-len(predictions):]
        rmse = sqrt(mean_squared_error(actual, predictions))
        mse = mean_squared_error(actual, predictions)
        meanV = np.mean(actual)
        dominator = np.linalg.norm(np.array(predictions) - meanV, 2)
        nmse = mse / np.power(dominator, 2)
        
        all_rmse.append(rmse)
        all_mse.append(mse)
        all_nmse.append(nmse)
        all_predictions.append(predictions)
        
        print(f'Run {run+1} \u2014 RMSE: {rmse:.6f}, MSE: {mse:.6f}, NMSE: {nmse:.10f}')
    
    # End of 60 runs for this noise level
    best_idx = np.argmin(all_rmse)
    
    print(f'\n===== STATS FOR NOISE {lam*100:.1f}% (60 runs) =====')
    print(f'RMSE: {np.mean(all_rmse):.6f} +/- {np.std(all_rmse):.6f}')
    print(f'MSE:  {np.mean(all_mse):.6f} +/- {np.std(all_mse):.6f}')
    print(f'NMSE: {np.mean(all_nmse):.10f} +/- {np.std(all_nmse):.10f}')
    print(f'Best run: {best_idx+1} (RMSE: {all_rmse[best_idx]:.6f})')
    
    _molab_results.append([lam, 
        np.mean(all_rmse), np.std(all_rmse),
        np.mean(all_mse), np.std(all_mse),
        np.mean(all_nmse), np.std(all_nmse),
        all_rmse[best_idx], all_predictions[best_idx], all_losses[best_idx], raw_values.copy()])
# Out:
# --- [PyTorch] RUNNING ON cuda ---
#
#
# ================================================================================
# EVALUATING NOISE LEVEL: 0.0% (lambda=0.0, sigma=0.000000)
# ================================================================================
#
# X_train shape: (107, 1, 1), y_train shape: (107,)
#
# ===== RUN 1/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.279145
#   Epoch 20/100, Loss: 0.276377
#   Epoch 30/100, Loss: 0.271686
#   Epoch 40/100, Loss: 0.260289
#   Epoch 50/100, Loss: 0.244419
#   Epoch 60/100, Loss: 0.231116
#   Epoch 70/100, Loss: 0.210096
#   Epoch 80/100, Loss: 0.179601
#   Epoch 90/100, Loss: 0.170758
#   Epoch 100/100, Loss: 0.190219
# Training complete for run 1
# Run 1 — RMSE: 40.181311, MSE: 1614.537776, NMSE: 0.0079532535
#
# ===== RUN 2/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.282588
#   Epoch 20/100, Loss: 0.281326
#   Epoch 30/100, Loss: 0.280711
#   Epoch 40/100, Loss: 0.280327
#   Epoch 50/100, Loss: 0.279818
#   Epoch 60/100, Loss: 0.279026
#   Epoch 70/100, Loss: 0.277770
#   Epoch 80/100, Loss: 0.275855
#   Epoch 90/100, Loss: 0.272748
#   Epoch 100/100, Loss: 0.266864
# Training complete for run 2
# Run 2 — RMSE: 47.081564, MSE: 2216.673641, NMSE: 0.0096179106
#
# ===== RUN 3/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.274808
#   Epoch 20/100, Loss: 0.266449
#   Epoch 30/100, Loss: 0.274986
#   Epoch 40/100, Loss: 0.254890
#   Epoch 50/100, Loss: 0.242013
#   Epoch 60/100, Loss: 0.230015
#   Epoch 70/100, Loss: 0.240219
#   Epoch 80/100, Loss: 0.249044
#   Epoch 90/100, Loss: 0.244891
#   Epoch 100/100, Loss: 0.237488
# Training complete for run 3
# Run 3 — RMSE: 44.658975, MSE: 1994.424033, NMSE: 0.0088310151
#
# ===== RUN 4/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.278791
#   Epoch 20/100, Loss: 0.273442
#   Epoch 30/100, Loss: 0.268266
#   Epoch 40/100, Loss: 0.256747
#   Epoch 50/100, Loss: 0.217080
#   Epoch 60/100, Loss: 0.219828
#   Epoch 70/100, Loss: 0.227978
#   Epoch 80/100, Loss: 0.220154
#   Epoch 90/100, Loss: 0.212152
#   Epoch 100/100, Loss: 0.206667
# Training complete for run 4
# Run 4 — RMSE: 39.180746, MSE: 1535.130874, NMSE: 0.0093194870
#
# ===== RUN 5/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.278939
#   Epoch 20/100, Loss: 0.271843
#   Epoch 30/100, Loss: 0.271115
#   Epoch 40/100, Loss: 0.264289
#   Epoch 50/100, Loss: 0.243976
#   Epoch 60/100, Loss: 0.234962
#   Epoch 70/100, Loss: 0.221562
#   Epoch 80/100, Loss: 0.225346
#   Epoch 90/100, Loss: 0.233779
#   Epoch 100/100, Loss: 0.237802
# Training complete for run 5
# Run 5 — RMSE: 47.066447, MSE: 2215.250436, NMSE: 0.0094331283
#
# ===== RUN 6/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.280649
#   Epoch 20/100, Loss: 0.264875
#   Epoch 30/100, Loss: 0.232158
#   Epoch 40/100, Loss: 0.203845
#   Epoch 50/100, Loss: 0.195207
#   Epoch 60/100, Loss: 0.182040
#   Epoch 70/100, Loss: 0.165222
#   Epoch 80/100, Loss: 0.142232
#   Epoch 90/100, Loss: 0.148552
#   Epoch 100/100, Loss: 0.151796
# Training complete for run 6
# Run 6 — RMSE: 36.631215, MSE: 1341.845932, NMSE: 0.0088302458
#
# ===== RUN 7/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.279390
#   Epoch 20/100, Loss: 0.278562
#   Epoch 30/100, Loss: 0.278139
#   Epoch 40/100, Loss: 0.277506
#   Epoch 50/100, Loss: 0.276430
#   Epoch 60/100, Loss: 0.274695
#   Epoch 70/100, Loss: 0.271932
#   Epoch 80/100, Loss: 0.267395
#   Epoch 90/100, Loss: 0.259397
#   Epoch 100/100, Loss: 0.243301
# Training complete for run 7
# Run 7 — RMSE: 45.094604, MSE: 2033.523322, NMSE: 0.0094997332
#
# ===== RUN 8/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.283099
#   Epoch 20/100, Loss: 0.280162
#   Epoch 30/100, Loss: 0.277073
#   Epoch 40/100, Loss: 0.269454
#   Epoch 50/100, Loss: 0.248610
#   Epoch 60/100, Loss: 0.203532
#   Epoch 70/100, Loss: 0.171969
#   Epoch 80/100, Loss: 0.167221
#   Epoch 90/100, Loss: 0.163088
#   Epoch 100/100, Loss: 0.155441
# Training complete for run 8
# Run 8 — RMSE: 32.752087, MSE: 1072.699171, NMSE: 0.0064671044
#
# ===== RUN 9/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.279418
#   Epoch 20/100, Loss: 0.278876
#   Epoch 30/100, Loss: 0.277763
#   Epoch 40/100, Loss: 0.275835
#   Epoch 50/100, Loss: 0.272690
#   Epoch 60/100, Loss: 0.267153
#   Epoch 70/100, Loss: 0.256473
#   Epoch 80/100, Loss: 0.233332
#   Epoch 90/100, Loss: 0.181621
#   Epoch 100/100, Loss: 0.162101
# Training complete for run 9
# Run 9 — RMSE: 52.792045, MSE: 2787.000030, NMSE: 0.0107278355
#
# ===== RUN 10/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.280319
#   Epoch 20/100, Loss: 0.274582
#   Epoch 30/100, Loss: 0.264185
#   Epoch 40/100, Loss: 0.232798
#   Epoch 50/100, Loss: 0.182992
#   Epoch 60/100, Loss: 0.195942
#   Epoch 70/100, Loss: 0.191677
#   Epoch 80/100, Loss: 0.188861
#   Epoch 90/100, Loss: 0.175308
#   Epoch 100/100, Loss: 0.152285
# Training complete for run 10
# Run 10 — RMSE: 31.402506, MSE: 986.117372, NMSE: 0.0059618727
#
# ===== RUN 11/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.284534
#   Epoch 20/100, Loss: 0.281086
#   Epoch 30/100, Loss: 0.276705
#   Epoch 40/100, Loss: 0.269267
#   Epoch 50/100, Loss: 0.259444
#   Epoch 60/100, Loss: 0.251951
#   Epoch 70/100, Loss: 0.239800
#   Epoch 80/100, Loss: 0.214050
#   Epoch 90/100, Loss: 0.184874
#   Epoch 100/100, Loss: 0.177557
# Training complete for run 11
# Run 11 — RMSE: 40.128796, MSE: 1610.320282, NMSE: 0.0095506232
#
# ===== RUN 12/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.280505
#   Epoch 20/100, Loss: 0.274427
#   Epoch 30/100, Loss: 0.261098
#   Epoch 40/100, Loss: 0.236692
#   Epoch 50/100, Loss: 0.223946
#   Epoch 60/100, Loss: 0.217824
#   Epoch 70/100, Loss: 0.199318
#   Epoch 80/100, Loss: 0.160826
#   Epoch 90/100, Loss: 0.170201
#   Epoch 100/100, Loss: 0.182228
# Training complete for run 12
# Run 12 — RMSE: 36.722587, MSE: 1348.548381, NMSE: 0.0081940136
#
# ===== RUN 13/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.277358
#   Epoch 20/100, Loss: 0.270811
#   Epoch 30/100, Loss: 0.262537
#   Epoch 40/100, Loss: 0.246445
#   Epoch 50/100, Loss: 0.209988
#   Epoch 60/100, Loss: 0.204335
#   Epoch 70/100, Loss: 0.225567
#   Epoch 80/100, Loss: 0.227320
#   Epoch 90/100, Loss: 0.229288
#   Epoch 100/100, Loss: 0.232902
# Training complete for run 13
# Run 13 — RMSE: 49.768642, MSE: 2476.917770, NMSE: 0.0096450451
#
# ===== RUN 14/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.282486
#   Epoch 20/100, Loss: 0.276102
#   Epoch 30/100, Loss: 0.264498
#   Epoch 40/100, Loss: 0.243053
#   Epoch 50/100, Loss: 0.193361
#   Epoch 60/100, Loss: 0.215700
#   Epoch 70/100, Loss: 0.213028
#   Epoch 80/100, Loss: 0.202029
#   Epoch 90/100, Loss: 0.195216
#   Epoch 100/100, Loss: 0.198291
# Training complete for run 14
# Run 14 — RMSE: 38.474335, MSE: 1480.274474, NMSE: 0.0088187559
#
# ===== RUN 15/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.278622
#   Epoch 20/100, Loss: 0.275482
#   Epoch 30/100, Loss: 0.273167
#   Epoch 40/100, Loss: 0.269076
#   Epoch 50/100, Loss: 0.259224
#   Epoch 60/100, Loss: 0.225422
#   Epoch 70/100, Loss: 0.177855
#   Epoch 80/100, Loss: 0.167101
#   Epoch 90/100, Loss: 0.179678
#   Epoch 100/100, Loss: 0.195146
# Training complete for run 15
# Run 15 — RMSE: 36.289671, MSE: 1316.940189, NMSE: 0.0083896813
#
# ===== RUN 16/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.282101
#   Epoch 20/100, Loss: 0.281735
#   Epoch 30/100, Loss: 0.281401
#   Epoch 40/100, Loss: 0.280861
#   Epoch 50/100, Loss: 0.279873
#   Epoch 60/100, Loss: 0.277987
#   Epoch 70/100, Loss: 0.274300
#   Epoch 80/100, Loss: 0.266960
#   Epoch 90/100, Loss: 0.253488
#   Epoch 100/100, Loss: 0.235308
# Training complete for run 16
# Run 16 — RMSE: 44.252932, MSE: 1958.321989, NMSE: 0.0085671331
#
# ===== RUN 17/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.278630
#   Epoch 20/100, Loss: 0.274634
#   Epoch 30/100, Loss: 0.267669
#   Epoch 40/100, Loss: 0.257247
#   Epoch 50/100, Loss: 0.239796
#   Epoch 60/100, Loss: 0.202095
#   Epoch 70/100, Loss: 0.172217
#   Epoch 80/100, Loss: 0.168571
#   Epoch 90/100, Loss: 0.155827
#   Epoch 100/100, Loss: 0.139117
# Training complete for run 17
# Run 17 — RMSE: 28.387849, MSE: 805.869952, NMSE: 0.0039021965
#
# ===== RUN 18/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.281953
#   Epoch 20/100, Loss: 0.271814
#   Epoch 30/100, Loss: 0.266071
#   Epoch 40/100, Loss: 0.259987
#   Epoch 50/100, Loss: 0.248324
#   Epoch 60/100, Loss: 0.224503
#   Epoch 70/100, Loss: 0.191877
#   Epoch 80/100, Loss: 0.182009
#   Epoch 90/100, Loss: 0.196422
#   Epoch 100/100, Loss: 0.184710
# Training complete for run 18
# Run 18 — RMSE: 39.395613, MSE: 1552.014359, NMSE: 0.0069143779
#
# ===== RUN 19/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.277118
#   Epoch 20/100, Loss: 0.265418
#   Epoch 30/100, Loss: 0.243147
#   Epoch 40/100, Loss: 0.210931
#   Epoch 50/100, Loss: 0.199386
#   Epoch 60/100, Loss: 0.194663
#   Epoch 70/100, Loss: 0.201951
#   Epoch 80/100, Loss: 0.209032
#   Epoch 90/100, Loss: 0.207722
#   Epoch 100/100, Loss: 0.200305
# Training complete for run 19
# Run 19 — RMSE: 38.461596, MSE: 1479.294370, NMSE: 0.0081205593
#
# ===== RUN 20/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.280831
#   Epoch 20/100, Loss: 0.278966
#   Epoch 30/100, Loss: 0.275308
#   Epoch 40/100, Loss: 0.263094
#   Epoch 50/100, Loss: 0.168047
#   Epoch 60/100, Loss: 0.140170
#   Epoch 70/100, Loss: 0.123093
#   Epoch 80/100, Loss: 0.118930
#   Epoch 90/100, Loss: 0.112332
#   Epoch 100/100, Loss: 0.122131
# Training complete for run 20
# Run 20 — RMSE: 33.934489, MSE: 1151.549520, NMSE: 0.0044065991
#
# ===== RUN 21/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.283857
#   Epoch 20/100, Loss: 0.280039
#   Epoch 30/100, Loss: 0.277386
#   Epoch 40/100, Loss: 0.275118
#   Epoch 50/100, Loss: 0.270463
#   Epoch 60/100, Loss: 0.253523
#   Epoch 70/100, Loss: 0.202065
#   Epoch 80/100, Loss: 0.187889
#   Epoch 90/100, Loss: 0.198346
#   Epoch 100/100, Loss: 0.201066
# Training complete for run 21
# Run 21 — RMSE: 41.565702, MSE: 1727.707563, NMSE: 0.0083571905
#
# ===== RUN 22/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.279805
#   Epoch 20/100, Loss: 0.276921
#   Epoch 30/100, Loss: 0.272697
#   Epoch 40/100, Loss: 0.263333
#   Epoch 50/100, Loss: 0.235434
#   Epoch 60/100, Loss: 0.171302
#   Epoch 70/100, Loss: 0.180169
#   Epoch 80/100, Loss: 0.200464
#   Epoch 90/100, Loss: 0.219949
#   Epoch 100/100, Loss: 0.219520
# Training complete for run 22
# Run 22 — RMSE: 45.224889, MSE: 2045.290563, NMSE: 0.0095600034
#
# ===== RUN 23/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.282515
#   Epoch 20/100, Loss: 0.281823
#   Epoch 30/100, Loss: 0.281449
#   Epoch 40/100, Loss: 0.281173
#   Epoch 50/100, Loss: 0.280869
#   Epoch 60/100, Loss: 0.280477
#   Epoch 70/100, Loss: 0.279980
#   Epoch 80/100, Loss: 0.279332
#   Epoch 90/100, Loss: 0.278456
#   Epoch 100/100, Loss: 0.277226
# Training complete for run 23
# Run 23 — RMSE: 47.881191, MSE: 2292.608438, NMSE: 0.0095830770
#
# ===== RUN 24/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.279765
#   Epoch 20/100, Loss: 0.278111
#   Epoch 30/100, Loss: 0.276526
#   Epoch 40/100, Loss: 0.274134
#   Epoch 50/100, Loss: 0.269198
#   Epoch 60/100, Loss: 0.253931
#   Epoch 70/100, Loss: 0.213759
#   Epoch 80/100, Loss: 0.192113
#   Epoch 90/100, Loss: 0.182500
#   Epoch 100/100, Loss: 0.181782
# Training complete for run 24
# Run 24 — RMSE: 35.492197, MSE: 1259.696021, NMSE: 0.0078957168
#
# ===== RUN 25/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.282486
#   Epoch 20/100, Loss: 0.281413
#   Epoch 30/100, Loss: 0.278579
#   Epoch 40/100, Loss: 0.276207
#   Epoch 50/100, Loss: 0.273154
#   Epoch 60/100, Loss: 0.267088
#   Epoch 70/100, Loss: 0.255763
#   Epoch 80/100, Loss: 0.238074
#   Epoch 90/100, Loss: 0.218506
#   Epoch 100/100, Loss: 0.193387
# Training complete for run 25
# Run 25 — RMSE: 38.815210, MSE: 1506.620503, NMSE: 0.0069030448
#
# ===== RUN 26/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.290304
#   Epoch 20/100, Loss: 0.285823
#   Epoch 30/100, Loss: 0.279791
#   Epoch 40/100, Loss: 0.268371
#   Epoch 50/100, Loss: 0.248040
#   Epoch 60/100, Loss: 0.224144
#   Epoch 70/100, Loss: 0.211813
#   Epoch 80/100, Loss: 0.197178
#   Epoch 90/100, Loss: 0.186751
#   Epoch 100/100, Loss: 0.192627
# Training complete for run 26
# Run 26 — RMSE: 40.028119, MSE: 1602.250323, NMSE: 0.0099728652
#
# ===== RUN 27/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.280689
#   Epoch 20/100, Loss: 0.277481
#   Epoch 30/100, Loss: 0.273846
#   Epoch 40/100, Loss: 0.270065
#   Epoch 50/100, Loss: 0.265801
#   Epoch 60/100, Loss: 0.264637
#   Epoch 70/100, Loss: 0.260659
#   Epoch 80/100, Loss: 0.251974
#   Epoch 90/100, Loss: 0.236209
#   Epoch 100/100, Loss: 0.213694
# Training complete for run 27
# Run 27 — RMSE: 42.008003, MSE: 1764.672338, NMSE: 0.0096224031
#
# ===== RUN 28/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.279756
#   Epoch 20/100, Loss: 0.277540
#   Epoch 30/100, Loss: 0.270202
#   Epoch 40/100, Loss: 0.271241
#   Epoch 50/100, Loss: 0.257345
#   Epoch 60/100, Loss: 0.234196
#   Epoch 70/100, Loss: 0.233570
#   Epoch 80/100, Loss: 0.228239
#   Epoch 90/100, Loss: 0.227278
#   Epoch 100/100, Loss: 0.224776
# Training complete for run 28
# Run 28 — RMSE: 43.619111, MSE: 1902.626866, NMSE: 0.0090165964
#
# ===== RUN 29/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.277753
#   Epoch 20/100, Loss: 0.270012
#   Epoch 30/100, Loss: 0.260659
#   Epoch 40/100, Loss: 0.268534
#   Epoch 50/100, Loss: 0.264879
#   Epoch 60/100, Loss: 0.264741
#   Epoch 70/100, Loss: 0.264039
#   Epoch 80/100, Loss: 0.262747
#   Epoch 90/100, Loss: 0.260034
#   Epoch 100/100, Loss: 0.254689
# Training complete for run 29
# Run 29 — RMSE: 45.327196, MSE: 2054.554711, NMSE: 0.0093340194
#
# ===== RUN 30/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.277579
#   Epoch 20/100, Loss: 0.273593
#   Epoch 30/100, Loss: 0.269832
#   Epoch 40/100, Loss: 0.265244
#   Epoch 50/100, Loss: 0.258775
#   Epoch 60/100, Loss: 0.249017
#   Epoch 70/100, Loss: 0.233954
#   Epoch 80/100, Loss: 0.217934
#   Epoch 90/100, Loss: 0.205984
#   Epoch 100/100, Loss: 0.200512
# Training complete for run 30
# Run 30 — RMSE: 45.657225, MSE: 2084.582183, NMSE: 0.0106492700
#
# ===== RUN 31/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.282605
#   Epoch 20/100, Loss: 0.281981
#   Epoch 30/100, Loss: 0.280981
#   Epoch 40/100, Loss: 0.279716
#   Epoch 50/100, Loss: 0.278094
#   Epoch 60/100, Loss: 0.275572
#   Epoch 70/100, Loss: 0.270803
#   Epoch 80/100, Loss: 0.262658
#   Epoch 90/100, Loss: 0.251913
#   Epoch 100/100, Loss: 0.233491
# Training complete for run 31
# Run 31 — RMSE: 42.813211, MSE: 1832.971070, NMSE: 0.0073518715
#
# ===== RUN 32/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.282389
#   Epoch 20/100, Loss: 0.280205
#   Epoch 30/100, Loss: 0.277600
#   Epoch 40/100, Loss: 0.273793
#   Epoch 50/100, Loss: 0.267091
#   Epoch 60/100, Loss: 0.253079
#   Epoch 70/100, Loss: 0.232074
#   Epoch 80/100, Loss: 0.214590
#   Epoch 90/100, Loss: 0.206242
#   Epoch 100/100, Loss: 0.199926
# Training complete for run 32
# Run 32 — RMSE: 49.464966, MSE: 2446.782816, NMSE: 0.0101300841
#
# ===== RUN 33/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.284832
#   Epoch 20/100, Loss: 0.282677
#   Epoch 30/100, Loss: 0.279507
#   Epoch 40/100, Loss: 0.275061
#   Epoch 50/100, Loss: 0.267778
#   Epoch 60/100, Loss: 0.257115
#   Epoch 70/100, Loss: 0.242202
#   Epoch 80/100, Loss: 0.193521
#   Epoch 90/100, Loss: 0.131992
#   Epoch 100/100, Loss: 0.113958
# Training complete for run 33
# Run 33 — RMSE: 31.817207, MSE: 1012.334683, NMSE: 0.0058145669
#
# ===== RUN 34/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.276265
#   Epoch 20/100, Loss: 0.268360
#   Epoch 30/100, Loss: 0.256299
#   Epoch 40/100, Loss: 0.231081
#   Epoch 50/100, Loss: 0.184248
#   Epoch 60/100, Loss: 0.184620
#   Epoch 70/100, Loss: 0.188248
#   Epoch 80/100, Loss: 0.195951
#   Epoch 90/100, Loss: 0.176486
#   Epoch 100/100, Loss: 0.254058
# Training complete for run 34
# Run 34 — RMSE: 38.285255, MSE: 1465.760779, NMSE: 0.0052568583
#
# ===== RUN 35/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.281196
#   Epoch 20/100, Loss: 0.281024
#   Epoch 30/100, Loss: 0.280349
#   Epoch 40/100, Loss: 0.279091
#   Epoch 50/100, Loss: 0.276852
#   Epoch 60/100, Loss: 0.272494
#   Epoch 70/100, Loss: 0.262574
#   Epoch 80/100, Loss: 0.231167
#   Epoch 90/100, Loss: 0.250126
#   Epoch 100/100, Loss: 0.182833
# Training complete for run 35
# Run 35 — RMSE: 41.069163, MSE: 1686.676164, NMSE: 0.0089173870
#
# ===== RUN 36/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.282870
#   Epoch 20/100, Loss: 0.281598
#   Epoch 30/100, Loss: 0.279297
#   Epoch 40/100, Loss: 0.275579
#   Epoch 50/100, Loss: 0.267095
#   Epoch 60/100, Loss: 0.244252
#   Epoch 70/100, Loss: 0.209886
#   Epoch 80/100, Loss: 0.244519
#   Epoch 90/100, Loss: 0.286485
#   Epoch 100/100, Loss: 0.261807
# Training complete for run 36
# Run 36 — RMSE: 45.469815, MSE: 2067.504118, NMSE: 0.0088142644
#
# ===== RUN 37/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.280055
#   Epoch 20/100, Loss: 0.278376
#   Epoch 30/100, Loss: 0.276703
#   Epoch 40/100, Loss: 0.273614
#   Epoch 50/100, Loss: 0.267479
#   Epoch 60/100, Loss: 0.263574
#   Epoch 70/100, Loss: 0.254572
#   Epoch 80/100, Loss: 0.240449
#   Epoch 90/100, Loss: 0.210459
#   Epoch 100/100, Loss: 0.188547
# Training complete for run 37
# Run 37 — RMSE: 38.457285, MSE: 1478.962798, NMSE: 0.0082286005
#
# ===== RUN 38/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.281203
#   Epoch 20/100, Loss: 0.277543
#   Epoch 30/100, Loss: 0.270442
#   Epoch 40/100, Loss: 0.252769
#   Epoch 50/100, Loss: 0.235313
#   Epoch 60/100, Loss: 0.218623
#   Epoch 70/100, Loss: 0.192062
#   Epoch 80/100, Loss: 0.156952
#   Epoch 90/100, Loss: 0.187289
#   Epoch 100/100, Loss: 0.174290
# Training complete for run 38
# Run 38 — RMSE: 35.837459, MSE: 1284.323459, NMSE: 0.0062224669
#
# ===== RUN 39/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.276596
#   Epoch 20/100, Loss: 0.272542
#   Epoch 30/100, Loss: 0.269749
#   Epoch 40/100, Loss: 0.266125
#   Epoch 50/100, Loss: 0.258698
#   Epoch 60/100, Loss: 0.239198
#   Epoch 70/100, Loss: 0.217702
#   Epoch 80/100, Loss: 0.218039
#   Epoch 90/100, Loss: 0.169720
#   Epoch 100/100, Loss: 0.187335
# Training complete for run 39
# Run 39 — RMSE: 47.215951, MSE: 2229.346006, NMSE: 0.0106999657
#
# ===== RUN 40/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.282860
#   Epoch 20/100, Loss: 0.277745
#   Epoch 30/100, Loss: 0.262048
#   Epoch 40/100, Loss: 0.209739
#   Epoch 50/100, Loss: 0.239088
#   Epoch 60/100, Loss: 0.251747
#   Epoch 70/100, Loss: 0.232445
#   Epoch 80/100, Loss: 0.221428
#   Epoch 90/100, Loss: 0.212381
#   Epoch 100/100, Loss: 0.205256
# Training complete for run 40
# Run 40 — RMSE: 37.525237, MSE: 1408.143398, NMSE: 0.0081933236
#
# ===== RUN 41/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.277102
#   Epoch 20/100, Loss: 0.272637
#   Epoch 30/100, Loss: 0.267030
#   Epoch 40/100, Loss: 0.261446
#   Epoch 50/100, Loss: 0.253474
#   Epoch 60/100, Loss: 0.238494
#   Epoch 70/100, Loss: 0.211329
#   Epoch 80/100, Loss: 0.195842
#   Epoch 90/100, Loss: 0.194352
#   Epoch 100/100, Loss: 0.209714
# Training complete for run 41
# Run 41 — RMSE: 40.363735, MSE: 1629.231094, NMSE: 0.0089203688
#
# ===== RUN 42/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.282166
#   Epoch 20/100, Loss: 0.280200
#   Epoch 30/100, Loss: 0.277388
#   Epoch 40/100, Loss: 0.269430
#   Epoch 50/100, Loss: 0.239566
#   Epoch 60/100, Loss: 0.173080
#   Epoch 70/100, Loss: 0.215382
#   Epoch 80/100, Loss: 0.223698
#   Epoch 90/100, Loss: 0.228294
#   Epoch 100/100, Loss: 0.240250
# Training complete for run 42
# Run 42 — RMSE: 51.701874, MSE: 2673.083803, NMSE: 0.0104061668
#
# ===== RUN 43/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.281118
#   Epoch 20/100, Loss: 0.279564
#   Epoch 30/100, Loss: 0.278208
#   Epoch 40/100, Loss: 0.276528
#   Epoch 50/100, Loss: 0.274297
#   Epoch 60/100, Loss: 0.270928
#   Epoch 70/100, Loss: 0.265167
#   Epoch 80/100, Loss: 0.257546
#   Epoch 90/100, Loss: 0.245711
#   Epoch 100/100, Loss: 0.223520
# Training complete for run 43
# Run 43 — RMSE: 42.665112, MSE: 1820.311759, NMSE: 0.0101161297
#
# ===== RUN 44/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.282636
#   Epoch 20/100, Loss: 0.281517
#   Epoch 30/100, Loss: 0.280523
#   Epoch 40/100, Loss: 0.278833
#   Epoch 50/100, Loss: 0.275911
#   Epoch 60/100, Loss: 0.270365
#   Epoch 70/100, Loss: 0.260498
#   Epoch 80/100, Loss: 0.253152
#   Epoch 90/100, Loss: 0.254655
#   Epoch 100/100, Loss: 0.254309
# Training complete for run 44
# Run 44 — RMSE: 44.632418, MSE: 1992.052706, NMSE: 0.0080705223
#
# ===== RUN 45/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.281142
#   Epoch 20/100, Loss: 0.279339
#   Epoch 30/100, Loss: 0.277759
#   Epoch 40/100, Loss: 0.275167
#   Epoch 50/100, Loss: 0.271203
#   Epoch 60/100, Loss: 0.265621
#   Epoch 70/100, Loss: 0.255491
#   Epoch 80/100, Loss: 0.231805
#   Epoch 90/100, Loss: 0.201705
#   Epoch 100/100, Loss: 0.189435
# Training complete for run 45
# Run 45 — RMSE: 39.620897, MSE: 1569.815478, NMSE: 0.0084661745
#
# ===== RUN 46/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.278326
#   Epoch 20/100, Loss: 0.274197
#   Epoch 30/100, Loss: 0.268803
#   Epoch 40/100, Loss: 0.248991
#   Epoch 50/100, Loss: 0.196936
#   Epoch 60/100, Loss: 0.159021
#   Epoch 70/100, Loss: 0.153449
#   Epoch 80/100, Loss: 0.143557
#   Epoch 90/100, Loss: 0.138537
#   Epoch 100/100, Loss: 0.146269
# Training complete for run 46
# Run 46 — RMSE: 37.172295, MSE: 1381.779491, NMSE: 0.0072926631
#
# ===== RUN 47/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.282216
#   Epoch 20/100, Loss: 0.281545
#   Epoch 30/100, Loss: 0.280111
#   Epoch 40/100, Loss: 0.277844
#   Epoch 50/100, Loss: 0.274439
#   Epoch 60/100, Loss: 0.269157
#   Epoch 70/100, Loss: 0.261599
#   Epoch 80/100, Loss: 0.252448
#   Epoch 90/100, Loss: 0.242694
#   Epoch 100/100, Loss: 0.232591
# Training complete for run 47
# Run 47 — RMSE: 42.557457, MSE: 1811.137121, NMSE: 0.0084657069
#
# ===== RUN 48/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.280241
#   Epoch 20/100, Loss: 0.279111
#   Epoch 30/100, Loss: 0.278303
#   Epoch 40/100, Loss: 0.276699
#   Epoch 50/100, Loss: 0.271573
#   Epoch 60/100, Loss: 0.265092
#   Epoch 70/100, Loss: 0.258621
#   Epoch 80/100, Loss: 0.247643
#   Epoch 90/100, Loss: 0.230173
#   Epoch 100/100, Loss: 0.206701
# Training complete for run 48
# Run 48 — RMSE: 40.099912, MSE: 1608.002925, NMSE: 0.0075224151
#
# ===== RUN 49/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.281064
#   Epoch 20/100, Loss: 0.279036
#   Epoch 30/100, Loss: 0.274461
#   Epoch 40/100, Loss: 0.269804
#   Epoch 50/100, Loss: 0.261400
#   Epoch 60/100, Loss: 0.240133
#   Epoch 70/100, Loss: 0.206998
#   Epoch 80/100, Loss: 0.178556
#   Epoch 90/100, Loss: 0.164316
#   Epoch 100/100, Loss: 0.167312
# Training complete for run 49
# Run 49 — RMSE: 40.595450, MSE: 1647.990576, NMSE: 0.0100538368
#
# ===== RUN 50/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.279363
#   Epoch 20/100, Loss: 0.278617
#   Epoch 30/100, Loss: 0.277028
#   Epoch 40/100, Loss: 0.274490
#   Epoch 50/100, Loss: 0.270768
#   Epoch 60/100, Loss: 0.267800
#   Epoch 70/100, Loss: 0.263163
#   Epoch 80/100, Loss: 0.255534
#   Epoch 90/100, Loss: 0.246798
#   Epoch 100/100, Loss: 0.237208
# Training complete for run 50
# Run 50 — RMSE: 42.360633, MSE: 1794.423209, NMSE: 0.0098806075
#
# ===== RUN 51/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.281928
#   Epoch 20/100, Loss: 0.279307
#   Epoch 30/100, Loss: 0.274692
#   Epoch 40/100, Loss: 0.257691
#   Epoch 50/100, Loss: 0.156209
#   Epoch 60/100, Loss: 0.152937
#   Epoch 70/100, Loss: 0.149142
#   Epoch 80/100, Loss: 0.129157
#   Epoch 90/100, Loss: 0.108953
#   Epoch 100/100, Loss: 0.097785
# Training complete for run 51
# Run 51 — RMSE: 27.645010, MSE: 764.246568, NMSE: 0.0052428284
#
# ===== RUN 52/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.283434
#   Epoch 20/100, Loss: 0.278718
#   Epoch 30/100, Loss: 0.276527
#   Epoch 40/100, Loss: 0.272037
#   Epoch 50/100, Loss: 0.260970
#   Epoch 60/100, Loss: 0.235656
#   Epoch 70/100, Loss: 0.206255
#   Epoch 80/100, Loss: 0.201015
#   Epoch 90/100, Loss: 0.202922
#   Epoch 100/100, Loss: 0.203360
# Training complete for run 52
# Run 52 — RMSE: 40.499633, MSE: 1640.220256, NMSE: 0.0103840930
#
# ===== RUN 53/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.281447
#   Epoch 20/100, Loss: 0.275617
#   Epoch 30/100, Loss: 0.264136
#   Epoch 40/100, Loss: 0.238597
#   Epoch 50/100, Loss: 0.212356
#   Epoch 60/100, Loss: 0.199451
#   Epoch 70/100, Loss: 0.190620
#   Epoch 80/100, Loss: 0.193601
#   Epoch 90/100, Loss: 0.195275
#   Epoch 100/100, Loss: 0.194486
# Training complete for run 53
# Run 53 — RMSE: 37.255672, MSE: 1387.985074, NMSE: 0.0094280071
#
# ===== RUN 54/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.278019
#   Epoch 20/100, Loss: 0.273460
#   Epoch 30/100, Loss: 0.264511
#   Epoch 40/100, Loss: 0.237375
#   Epoch 50/100, Loss: 0.218108
#   Epoch 60/100, Loss: 0.214816
#   Epoch 70/100, Loss: 0.186560
#   Epoch 80/100, Loss: 0.151601
#   Epoch 90/100, Loss: 0.154259
#   Epoch 100/100, Loss: 0.144583
# Training complete for run 54
# Run 54 — RMSE: 34.802046, MSE: 1211.182440, NMSE: 0.0073047186
#
# ===== RUN 55/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.279466
#   Epoch 20/100, Loss: 0.269728
#   Epoch 30/100, Loss: 0.255670
#   Epoch 40/100, Loss: 0.230417
#   Epoch 50/100, Loss: 0.215571
#   Epoch 60/100, Loss: 0.239633
#   Epoch 70/100, Loss: 0.241586
#   Epoch 80/100, Loss: 0.231089
#   Epoch 90/100, Loss: 0.194292
#   Epoch 100/100, Loss: 0.143125
# Training complete for run 55
# Run 55 — RMSE: 37.193040, MSE: 1383.322213, NMSE: 0.0064864563
#
# ===== RUN 56/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.281515
#   Epoch 20/100, Loss: 0.280860
#   Epoch 30/100, Loss: 0.280070
#   Epoch 40/100, Loss: 0.278713
#   Epoch 50/100, Loss: 0.276318
#   Epoch 60/100, Loss: 0.271866
#   Epoch 70/100, Loss: 0.262540
#   Epoch 80/100, Loss: 0.241052
#   Epoch 90/100, Loss: 0.201524
#   Epoch 100/100, Loss: 0.173577
# Training complete for run 56
# Run 56 — RMSE: 36.856738, MSE: 1358.419133, NMSE: 0.0085850101
#
# ===== RUN 57/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.282741
#   Epoch 20/100, Loss: 0.281956
#   Epoch 30/100, Loss: 0.281609
#   Epoch 40/100, Loss: 0.281471
#   Epoch 50/100, Loss: 0.281461
#   Epoch 60/100, Loss: 0.281542
#   Epoch 70/100, Loss: 0.281635
#   Epoch 80/100, Loss: 0.281402
#   Epoch 90/100, Loss: 0.279630
#   Epoch 100/100, Loss: 0.274876
# Training complete for run 57
# Run 57 — RMSE: 47.583729, MSE: 2264.211260, NMSE: 0.0091845701
#
# ===== RUN 58/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.282793
#   Epoch 20/100, Loss: 0.279680
#   Epoch 30/100, Loss: 0.278374
#   Epoch 40/100, Loss: 0.277097
#   Epoch 50/100, Loss: 0.274739
#   Epoch 60/100, Loss: 0.270226
#   Epoch 70/100, Loss: 0.261007
#   Epoch 80/100, Loss: 0.242159
#   Epoch 90/100, Loss: 0.207401
#   Epoch 100/100, Loss: 0.188972
# Training complete for run 58
# Run 58 — RMSE: 41.556431, MSE: 1726.936918, NMSE: 0.0093191217
#
# ===== RUN 59/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.285399
#   Epoch 20/100, Loss: 0.274517
#   Epoch 30/100, Loss: 0.252757
#   Epoch 40/100, Loss: 0.222482
#   Epoch 50/100, Loss: 0.213125
#   Epoch 60/100, Loss: 0.233688
#   Epoch 70/100, Loss: 0.246659
#   Epoch 80/100, Loss: 0.257050
#   Epoch 90/100, Loss: 0.268092
#   Epoch 100/100, Loss: 0.276706
# Training complete for run 59
# Run 59 — RMSE: 48.930621, MSE: 2394.205690, NMSE: 0.0095155858
#
# ===== RUN 60/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.269963
#   Epoch 20/100, Loss: 0.240725
#   Epoch 30/100, Loss: 0.193650
#   Epoch 40/100, Loss: 0.189421
#   Epoch 50/100, Loss: 0.192934
#   Epoch 60/100, Loss: 0.196342
#   Epoch 70/100, Loss: 0.197845
#   Epoch 80/100, Loss: 0.196380
#   Epoch 90/100, Loss: 0.192820
#   Epoch 100/100, Loss: 0.189055
# Training complete for run 60
# Run 60 — RMSE: 42.680204, MSE: 1821.599805, NMSE: 0.0101425734
#
# ===== STATS FOR NOISE 0.0% (60 runs) =====
# RMSE: 40.883422 +/- 5.359688
# MSE:  1700.180437 +/- 436.890350
# NMSE: 0.0084743617 +/- 0.0015712337
# Best run: 51 (RMSE: 27.645010)
#
# ================================================================================
# EVALUATING NOISE LEVEL: 0.5% (lambda=0.005, sigma=0.509499)
# ================================================================================
#
# X_train shape: (107, 1, 1), y_train shape: (107,)
#
# ===== RUN 1/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.275689
#   Epoch 20/100, Loss: 0.272847
#   Epoch 30/100, Loss: 0.268076
#   Epoch 40/100, Loss: 0.256649
#   Epoch 50/100, Loss: 0.240491
#   Epoch 60/100, Loss: 0.208333
#   Epoch 70/100, Loss: 0.219986
#   Epoch 80/100, Loss: 0.183084
#   Epoch 90/100, Loss: 0.166825
#   Epoch 100/100, Loss: 0.187588
# Training complete for run 1
# Run 1 — RMSE: 39.770458, MSE: 1581.689315, NMSE: 0.0078355509
#
# ===== RUN 2/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.279249
#   Epoch 20/100, Loss: 0.277972
#   Epoch 30/100, Loss: 0.277368
#   Epoch 40/100, Loss: 0.276984
#   Epoch 50/100, Loss: 0.276472
#   Epoch 60/100, Loss: 0.275679
#   Epoch 70/100, Loss: 0.274513
#   Epoch 80/100, Loss: 0.272851
#   Epoch 90/100, Loss: 0.270229
#   Epoch 100/100, Loss: 0.265479
# Training complete for run 2
# Run 2 — RMSE: 47.166808, MSE: 2224.707774, NMSE: 0.0095669739
#
# ===== RUN 3/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.271512
#   Epoch 20/100, Loss: 0.263346
#   Epoch 30/100, Loss: 0.271970
#   Epoch 40/100, Loss: 0.254271
#   Epoch 50/100, Loss: 0.238375
#   Epoch 60/100, Loss: 0.247984
#   Epoch 70/100, Loss: 0.232378
#   Epoch 80/100, Loss: 0.244250
#   Epoch 90/100, Loss: 0.241304
#   Epoch 100/100, Loss: 0.232988
# Training complete for run 3
# Run 3 — RMSE: 46.090680, MSE: 2124.350826, NMSE: 0.0087265289
#
# ===== RUN 4/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.275377
#   Epoch 20/100, Loss: 0.269932
#   Epoch 30/100, Loss: 0.264761
#   Epoch 40/100, Loss: 0.253556
#   Epoch 50/100, Loss: 0.214481
#   Epoch 60/100, Loss: 0.216684
#   Epoch 70/100, Loss: 0.224463
#   Epoch 80/100, Loss: 0.216582
#   Epoch 90/100, Loss: 0.208883
#   Epoch 100/100, Loss: 0.204113
# Training complete for run 4
# Run 4 — RMSE: 39.509794, MSE: 1561.023799, NMSE: 0.0093732859
#
# ===== RUN 5/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.275648
#   Epoch 20/100, Loss: 0.269404
#   Epoch 30/100, Loss: 0.268840
#   Epoch 40/100, Loss: 0.263270
#   Epoch 50/100, Loss: 0.250890
#   Epoch 60/100, Loss: 0.240392
#   Epoch 70/100, Loss: 0.220321
#   Epoch 80/100, Loss: 0.221023
#   Epoch 90/100, Loss: 0.228728
#   Epoch 100/100, Loss: 0.234657
# Training complete for run 5
# Run 5 — RMSE: 46.203309, MSE: 2134.745758, NMSE: 0.0092913514
#
# ===== RUN 6/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.277448
#   Epoch 20/100, Loss: 0.262297
#   Epoch 30/100, Loss: 0.231360
#   Epoch 40/100, Loss: 0.202985
#   Epoch 50/100, Loss: 0.194500
#   Epoch 60/100, Loss: 0.182719
#   Epoch 70/100, Loss: 0.168466
#   Epoch 80/100, Loss: 0.217804
#   Epoch 90/100, Loss: 0.143278
#   Epoch 100/100, Loss: 0.149550
# Training complete for run 6
# Run 6 — RMSE: 37.050057, MSE: 1372.706710, NMSE: 0.0086185304
#
# ===== RUN 7/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.276117
#   Epoch 20/100, Loss: 0.275314
#   Epoch 30/100, Loss: 0.274935
#   Epoch 40/100, Loss: 0.274378
#   Epoch 50/100, Loss: 0.273426
#   Epoch 60/100, Loss: 0.271891
#   Epoch 70/100, Loss: 0.269463
#   Epoch 80/100, Loss: 0.265516
#   Epoch 90/100, Loss: 0.258669
#   Epoch 100/100, Loss: 0.245399
# Training complete for run 7
# Run 7 — RMSE: 45.448352, MSE: 2065.552723, NMSE: 0.0094521666
#
# ===== RUN 8/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.279727
#   Epoch 20/100, Loss: 0.276842
#   Epoch 30/100, Loss: 0.273844
#   Epoch 40/100, Loss: 0.266527
#   Epoch 50/100, Loss: 0.246677
#   Epoch 60/100, Loss: 0.202718
#   Epoch 70/100, Loss: 0.170734
#   Epoch 80/100, Loss: 0.167161
#   Epoch 90/100, Loss: 0.163601
#   Epoch 100/100, Loss: 0.155463
# Training complete for run 8
# Run 8 — RMSE: 32.897866, MSE: 1082.269565, NMSE: 0.0064642051
#
# ===== RUN 9/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.276147
#   Epoch 20/100, Loss: 0.275660
#   Epoch 30/100, Loss: 0.274704
#   Epoch 40/100, Loss: 0.273064
#   Epoch 50/100, Loss: 0.270506
#   Epoch 60/100, Loss: 0.266296
#   Epoch 70/100, Loss: 0.258751
#   Epoch 80/100, Loss: 0.243747
#   Epoch 90/100, Loss: 0.209483
#   Epoch 100/100, Loss: 0.159954
# Training complete for run 9
# Run 9 — RMSE: 44.764832, MSE: 2003.890189, NMSE: 0.0096113316
#
# ===== RUN 10/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.276935
#   Epoch 20/100, Loss: 0.271102
#   Epoch 30/100, Loss: 0.259786
#   Epoch 40/100, Loss: 0.224664
#   Epoch 50/100, Loss: 0.182216
#   Epoch 60/100, Loss: 0.194971
#   Epoch 70/100, Loss: 0.190617
#   Epoch 80/100, Loss: 0.188229
#   Epoch 90/100, Loss: 0.175132
#   Epoch 100/100, Loss: 0.150795
# Training complete for run 10
# Run 10 — RMSE: 31.681134, MSE: 1003.694246, NMSE: 0.0060834554
#
# ===== RUN 11/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.281191
#   Epoch 20/100, Loss: 0.277903
#   Epoch 30/100, Loss: 0.273894
#   Epoch 40/100, Loss: 0.267078
#   Epoch 50/100, Loss: 0.257613
#   Epoch 60/100, Loss: 0.250145
#   Epoch 70/100, Loss: 0.239116
#   Epoch 80/100, Loss: 0.214488
#   Epoch 90/100, Loss: 0.183692
#   Epoch 100/100, Loss: 0.174047
# Training complete for run 11
# Run 11 — RMSE: 40.164015, MSE: 1613.148125, NMSE: 0.0093263485
#
# ===== RUN 12/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.277212
#   Epoch 20/100, Loss: 0.271489
#   Epoch 30/100, Loss: 0.259214
#   Epoch 40/100, Loss: 0.235606
#   Epoch 50/100, Loss: 0.222959
#   Epoch 60/100, Loss: 0.216610
#   Epoch 70/100, Loss: 0.200001
#   Epoch 80/100, Loss: 0.160040
#   Epoch 90/100, Loss: 0.167227
#   Epoch 100/100, Loss: 0.199770
# Training complete for run 12
# Run 12 — RMSE: 37.525669, MSE: 1408.175801, NMSE: 0.0083621362
#
# ===== RUN 13/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.274052
#   Epoch 20/100, Loss: 0.267439
#   Epoch 30/100, Loss: 0.259176
#   Epoch 40/100, Loss: 0.242928
#   Epoch 50/100, Loss: 0.205558
#   Epoch 60/100, Loss: 0.202695
#   Epoch 70/100, Loss: 0.217619
#   Epoch 80/100, Loss: 0.222451
#   Epoch 90/100, Loss: 0.224811
#   Epoch 100/100, Loss: 0.227867
# Training complete for run 13
# Run 13 — RMSE: 49.098180, MSE: 2410.631246, NMSE: 0.0094965867
#
# ===== RUN 14/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.279245
#   Epoch 20/100, Loss: 0.273030
#   Epoch 30/100, Loss: 0.262425
#   Epoch 40/100, Loss: 0.252233
#   Epoch 50/100, Loss: 0.191829
#   Epoch 60/100, Loss: 0.210109
#   Epoch 70/100, Loss: 0.206709
#   Epoch 80/100, Loss: 0.183264
#   Epoch 90/100, Loss: 0.156840
#   Epoch 100/100, Loss: 0.164698
# Training complete for run 14
# Run 14 — RMSE: 39.225046, MSE: 1538.604246, NMSE: 0.0093767527
#
# ===== RUN 15/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.275268
#   Epoch 20/100, Loss: 0.272200
#   Epoch 30/100, Loss: 0.269967
#   Epoch 40/100, Loss: 0.266141
#   Epoch 50/100, Loss: 0.257179
#   Epoch 60/100, Loss: 0.227582
#   Epoch 70/100, Loss: 0.163898
#   Epoch 80/100, Loss: 0.160052
#   Epoch 90/100, Loss: 0.169917
#   Epoch 100/100, Loss: 0.193093
# Training complete for run 15
# Run 15 — RMSE: 36.147584, MSE: 1306.647842, NMSE: 0.0088606465
#
# ===== RUN 16/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.278730
#   Epoch 20/100, Loss: 0.278378
#   Epoch 30/100, Loss: 0.278103
#   Epoch 40/100, Loss: 0.277666
#   Epoch 50/100, Loss: 0.276845
#   Epoch 60/100, Loss: 0.275244
#   Epoch 70/100, Loss: 0.272083
#   Epoch 80/100, Loss: 0.265685
#   Epoch 90/100, Loss: 0.253556
#   Epoch 100/100, Loss: 0.235885
# Training complete for run 16
# Run 16 — RMSE: 44.521556, MSE: 1982.168933, NMSE: 0.0085572843
#
# ===== RUN 17/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.275267
#   Epoch 20/100, Loss: 0.271282
#   Epoch 30/100, Loss: 0.264486
#   Epoch 40/100, Loss: 0.254662
#   Epoch 50/100, Loss: 0.239358
#   Epoch 60/100, Loss: 0.205382
#   Epoch 70/100, Loss: 0.168413
#   Epoch 80/100, Loss: 0.166309
#   Epoch 90/100, Loss: 0.154458
#   Epoch 100/100, Loss: 0.138614
# Training complete for run 17
# Run 17 — RMSE: 28.527637, MSE: 813.826078, NMSE: 0.0039290879
#
# ===== RUN 18/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.278831
#   Epoch 20/100, Loss: 0.268872
#   Epoch 30/100, Loss: 0.263521
#   Epoch 40/100, Loss: 0.258145
#   Epoch 50/100, Loss: 0.248195
#   Epoch 60/100, Loss: 0.227394
#   Epoch 70/100, Loss: 0.195337
#   Epoch 80/100, Loss: 0.183118
#   Epoch 90/100, Loss: 0.190063
#   Epoch 100/100, Loss: 0.182133
# Training complete for run 18
# Run 18 — RMSE: 38.462293, MSE: 1479.347950, NMSE: 0.0065705968
#
# ===== RUN 19/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.274035
#   Epoch 20/100, Loss: 0.263013
#   Epoch 30/100, Loss: 0.242611
#   Epoch 40/100, Loss: 0.211262
#   Epoch 50/100, Loss: 0.198588
#   Epoch 60/100, Loss: 0.191739
#   Epoch 70/100, Loss: 0.197720
#   Epoch 80/100, Loss: 0.206444
#   Epoch 90/100, Loss: 0.206785
#   Epoch 100/100, Loss: 0.201103
# Training complete for run 19
# Run 19 — RMSE: 38.358858, MSE: 1471.402015, NMSE: 0.0079628969
#
# ===== RUN 20/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.277522
#   Epoch 20/100, Loss: 0.275652
#   Epoch 30/100, Loss: 0.272114
#   Epoch 40/100, Loss: 0.260803
#   Epoch 50/100, Loss: 0.170913
#   Epoch 60/100, Loss: 0.142877
#   Epoch 70/100, Loss: 0.120690
#   Epoch 80/100, Loss: 0.116512
#   Epoch 90/100, Loss: 0.108970
#   Epoch 100/100, Loss: 0.117187
# Training complete for run 20
# Run 20 — RMSE: 35.141280, MSE: 1234.909557, NMSE: 0.0047348539
#
# ===== RUN 21/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.280500
#   Epoch 20/100, Loss: 0.276714
#   Epoch 30/100, Loss: 0.274090
#   Epoch 40/100, Loss: 0.271920
#   Epoch 50/100, Loss: 0.267633
#   Epoch 60/100, Loss: 0.252759
#   Epoch 70/100, Loss: 0.210709
#   Epoch 80/100, Loss: 0.190948
#   Epoch 90/100, Loss: 0.198733
#   Epoch 100/100, Loss: 0.202521
# Training complete for run 21
# Run 21 — RMSE: 42.115992, MSE: 1773.756760, NMSE: 0.0083465670
#
# ===== RUN 22/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.276414
#   Epoch 20/100, Loss: 0.273538
#   Epoch 30/100, Loss: 0.269408
#   Epoch 40/100, Loss: 0.260403
#   Epoch 50/100, Loss: 0.233958
#   Epoch 60/100, Loss: 0.170210
#   Epoch 70/100, Loss: 0.178342
#   Epoch 80/100, Loss: 0.196125
#   Epoch 90/100, Loss: 0.213660
#   Epoch 100/100, Loss: 0.214096
# Training complete for run 22
# Run 22 — RMSE: 47.639710, MSE: 2269.541961, NMSE: 0.0096587790
#
# ===== RUN 23/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.279199
#   Epoch 20/100, Loss: 0.278510
#   Epoch 30/100, Loss: 0.278151
#   Epoch 40/100, Loss: 0.277894
#   Epoch 50/100, Loss: 0.277633
#   Epoch 60/100, Loss: 0.277303
#   Epoch 70/100, Loss: 0.276890
#   Epoch 80/100, Loss: 0.276366
#   Epoch 90/100, Loss: 0.275681
#   Epoch 100/100, Loss: 0.274757
# Training complete for run 23
# Run 23 — RMSE: 47.899762, MSE: 2294.387188, NMSE: 0.0095539551
#
# ===== RUN 24/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.276527
#   Epoch 20/100, Loss: 0.274982
#   Epoch 30/100, Loss: 0.273575
#   Epoch 40/100, Loss: 0.271543
#   Epoch 50/100, Loss: 0.267644
#   Epoch 60/100, Loss: 0.256743
#   Epoch 70/100, Loss: 0.225996
#   Epoch 80/100, Loss: 0.198061
#   Epoch 90/100, Loss: 0.187020
#   Epoch 100/100, Loss: 0.178371
# Training complete for run 24
# Run 24 — RMSE: 35.026799, MSE: 1226.876633, NMSE: 0.0075062767
#
# ===== RUN 25/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.279139
#   Epoch 20/100, Loss: 0.278167
#   Epoch 30/100, Loss: 0.275614
#   Epoch 40/100, Loss: 0.273211
#   Epoch 50/100, Loss: 0.270456
#   Epoch 60/100, Loss: 0.264970
#   Epoch 70/100, Loss: 0.254711
#   Epoch 80/100, Loss: 0.238051
#   Epoch 90/100, Loss: 0.218171
#   Epoch 100/100, Loss: 0.193359
# Training complete for run 25
# Run 25 — RMSE: 39.054401, MSE: 1525.246198, NMSE: 0.0070044441
#
# ===== RUN 26/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.286963
#   Epoch 20/100, Loss: 0.282557
#   Epoch 30/100, Loss: 0.276895
#   Epoch 40/100, Loss: 0.266781
#   Epoch 50/100, Loss: 0.248944
#   Epoch 60/100, Loss: 0.224381
#   Epoch 70/100, Loss: 0.210514
#   Epoch 80/100, Loss: 0.197611
#   Epoch 90/100, Loss: 0.184917
#   Epoch 100/100, Loss: 0.189678
# Training complete for run 26
# Run 26 — RMSE: 38.859472, MSE: 1510.058593, NMSE: 0.0097785925
#
# ===== RUN 27/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.277436
#   Epoch 20/100, Loss: 0.274228
#   Epoch 30/100, Loss: 0.270766
#   Epoch 40/100, Loss: 0.267378
#   Epoch 50/100, Loss: 0.263709
#   Epoch 60/100, Loss: 0.262346
#   Epoch 70/100, Loss: 0.259344
#   Epoch 80/100, Loss: 0.251661
#   Epoch 90/100, Loss: 0.237652
#   Epoch 100/100, Loss: 0.216281
# Training complete for run 27
# Run 27 — RMSE: 42.238469, MSE: 1784.088231, NMSE: 0.0094287226
#
# ===== RUN 28/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.276403
#   Epoch 20/100, Loss: 0.274316
#   Epoch 30/100, Loss: 0.267767
#   Epoch 40/100, Loss: 0.272470
#   Epoch 50/100, Loss: 0.257610
#   Epoch 60/100, Loss: 0.260053
#   Epoch 70/100, Loss: 0.232202
#   Epoch 80/100, Loss: 0.226084
#   Epoch 90/100, Loss: 0.225482
#   Epoch 100/100, Loss: 0.222942
# Training complete for run 28
# Run 28 — RMSE: 43.246218, MSE: 1870.235399, NMSE: 0.0089426988
#
# ===== RUN 29/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.274420
#   Epoch 20/100, Loss: 0.266822
#   Epoch 30/100, Loss: 0.258067
#   Epoch 40/100, Loss: 0.264287
#   Epoch 50/100, Loss: 0.262417
#   Epoch 60/100, Loss: 0.262578
#   Epoch 70/100, Loss: 0.262081
#   Epoch 80/100, Loss: 0.261054
#   Epoch 90/100, Loss: 0.258745
#   Epoch 100/100, Loss: 0.254050
# Training complete for run 29
# Run 29 — RMSE: 45.483088, MSE: 2068.711298, NMSE: 0.0092748584
#
# ===== RUN 30/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.274307
#   Epoch 20/100, Loss: 0.270392
#   Epoch 30/100, Loss: 0.266758
#   Epoch 40/100, Loss: 0.262412
#   Epoch 50/100, Loss: 0.256425
#   Epoch 60/100, Loss: 0.247612
#   Epoch 70/100, Loss: 0.234475
#   Epoch 80/100, Loss: 0.206514
#   Epoch 90/100, Loss: 0.204966
#   Epoch 100/100, Loss: 0.202174
# Training complete for run 30
# Run 30 — RMSE: 44.081218, MSE: 1943.153745, NMSE: 0.0097016568
#
# ===== RUN 31/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.279344
#   Epoch 20/100, Loss: 0.278708
#   Epoch 30/100, Loss: 0.277737
#   Epoch 40/100, Loss: 0.276570
#   Epoch 50/100, Loss: 0.275117
#   Epoch 60/100, Loss: 0.272831
#   Epoch 70/100, Loss: 0.268340
#   Epoch 80/100, Loss: 0.260468
#   Epoch 90/100, Loss: 0.249987
#   Epoch 100/100, Loss: 0.231935
# Training complete for run 31
# Run 31 — RMSE: 42.918856, MSE: 1842.028191, NMSE: 0.0073484578
#
# ===== RUN 32/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.278982
#   Epoch 20/100, Loss: 0.276836
#   Epoch 30/100, Loss: 0.274354
#   Epoch 40/100, Loss: 0.270844
#   Epoch 50/100, Loss: 0.264945
#   Epoch 60/100, Loss: 0.253040
#   Epoch 70/100, Loss: 0.234508
#   Epoch 80/100, Loss: 0.216460
#   Epoch 90/100, Loss: 0.205789
#   Epoch 100/100, Loss: 0.200406
# Training complete for run 32
# Run 32 — RMSE: 48.920313, MSE: 2393.197048, NMSE: 0.0099892206
#
# ===== RUN 33/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.281548
#   Epoch 20/100, Loss: 0.279470
#   Epoch 30/100, Loss: 0.276468
#   Epoch 40/100, Loss: 0.272332
#   Epoch 50/100, Loss: 0.265623
#   Epoch 60/100, Loss: 0.255676
#   Epoch 70/100, Loss: 0.242470
#   Epoch 80/100, Loss: 0.201507
#   Epoch 90/100, Loss: 0.133201
#   Epoch 100/100, Loss: 0.112191
# Training complete for run 33
# Run 33 — RMSE: 31.729811, MSE: 1006.780928, NMSE: 0.0057830966
#
# ===== RUN 34/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.273040
#   Epoch 20/100, Loss: 0.265224
#   Epoch 30/100, Loss: 0.253548
#   Epoch 40/100, Loss: 0.229528
#   Epoch 50/100, Loss: 0.184487
#   Epoch 60/100, Loss: 0.181722
#   Epoch 70/100, Loss: 0.186989
#   Epoch 80/100, Loss: 0.188636
#   Epoch 90/100, Loss: 0.195749
#   Epoch 100/100, Loss: 0.281598
# Training complete for run 34
# Run 34 — RMSE: 45.122676, MSE: 2036.055920, NMSE: 0.0082951796
#
# ===== RUN 35/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.277898
#   Epoch 20/100, Loss: 0.277697
#   Epoch 30/100, Loss: 0.277068
#   Epoch 40/100, Loss: 0.275945
#   Epoch 50/100, Loss: 0.273985
#   Epoch 60/100, Loss: 0.270160
#   Epoch 70/100, Loss: 0.261403
#   Epoch 80/100, Loss: 0.235749
#   Epoch 90/100, Loss: 0.170109
#   Epoch 100/100, Loss: 0.188107
# Training complete for run 35
# Run 35 — RMSE: 38.247913, MSE: 1462.902868, NMSE: 0.0086379930
#
# ===== RUN 36/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.279463
#   Epoch 20/100, Loss: 0.278174
#   Epoch 30/100, Loss: 0.275938
#   Epoch 40/100, Loss: 0.272385
#   Epoch 50/100, Loss: 0.264568
#   Epoch 60/100, Loss: 0.244696
#   Epoch 70/100, Loss: 0.206276
#   Epoch 80/100, Loss: 0.232782
#   Epoch 90/100, Loss: 0.285717
#   Epoch 100/100, Loss: 0.264492
# Training complete for run 36
# Run 36 — RMSE: 45.715000, MSE: 2089.861205, NMSE: 0.0088945737
#
# ===== RUN 37/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.276849
#   Epoch 20/100, Loss: 0.275191
#   Epoch 30/100, Loss: 0.273577
#   Epoch 40/100, Loss: 0.270505
#   Epoch 50/100, Loss: 0.264139
#   Epoch 60/100, Loss: 0.260389
#   Epoch 70/100, Loss: 0.252543
#   Epoch 80/100, Loss: 0.243601
#   Epoch 90/100, Loss: 0.228948
#   Epoch 100/100, Loss: 0.202948
# Training complete for run 37
# Run 37 — RMSE: 41.823139, MSE: 1749.174952, NMSE: 0.0086282244
#
# ===== RUN 38/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.277940
#   Epoch 20/100, Loss: 0.274262
#   Epoch 30/100, Loss: 0.267676
#   Epoch 40/100, Loss: 0.250614
#   Epoch 50/100, Loss: 0.233272
#   Epoch 60/100, Loss: 0.218187
#   Epoch 70/100, Loss: 0.194063
#   Epoch 80/100, Loss: 0.156069
#   Epoch 90/100, Loss: 0.183495
#   Epoch 100/100, Loss: 0.175808
# Training complete for run 38
# Run 38 — RMSE: 36.247992, MSE: 1313.916900, NMSE: 0.0065288410
#
# ===== RUN 39/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.273390
#   Epoch 20/100, Loss: 0.269411
#   Epoch 30/100, Loss: 0.266808
#   Epoch 40/100, Loss: 0.263599
#   Epoch 50/100, Loss: 0.257238
#   Epoch 60/100, Loss: 0.240818
#   Epoch 70/100, Loss: 0.226328
#   Epoch 80/100, Loss: 0.224861
#   Epoch 90/100, Loss: 0.171735
#   Epoch 100/100, Loss: 0.176335
# Training complete for run 39
# Run 39 — RMSE: 47.688096, MSE: 2274.154538, NMSE: 0.0105988955
#
# ===== RUN 40/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.279568
#   Epoch 20/100, Loss: 0.274583
#   Epoch 30/100, Loss: 0.259844
#   Epoch 40/100, Loss: 0.210207
#   Epoch 50/100, Loss: 0.231593
#   Epoch 60/100, Loss: 0.247956
#   Epoch 70/100, Loss: 0.226410
#   Epoch 80/100, Loss: 0.220110
#   Epoch 90/100, Loss: 0.212013
#   Epoch 100/100, Loss: 0.204917
# Training complete for run 40
# Run 40 — RMSE: 37.642626, MSE: 1416.967316, NMSE: 0.0081745434
#
# ===== RUN 41/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.273833
#   Epoch 20/100, Loss: 0.269510
#   Epoch 30/100, Loss: 0.264058
#   Epoch 40/100, Loss: 0.258686
#   Epoch 50/100, Loss: 0.251297
#   Epoch 60/100, Loss: 0.237754
#   Epoch 70/100, Loss: 0.210255
#   Epoch 80/100, Loss: 0.188343
#   Epoch 90/100, Loss: 0.191489
#   Epoch 100/100, Loss: 0.207349
# Training complete for run 41
# Run 41 — RMSE: 40.161726, MSE: 1612.964260, NMSE: 0.0088180603
#
# ===== RUN 42/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.278953
#   Epoch 20/100, Loss: 0.277021
#   Epoch 30/100, Loss: 0.274501
#   Epoch 40/100, Loss: 0.267942
#   Epoch 50/100, Loss: 0.243443
#   Epoch 60/100, Loss: 0.172418
#   Epoch 70/100, Loss: 0.209002
#   Epoch 80/100, Loss: 0.221264
#   Epoch 90/100, Loss: 0.224621
#   Epoch 100/100, Loss: 0.235920
# Training complete for run 42
# Run 42 — RMSE: 48.758193, MSE: 2377.361376, NMSE: 0.0101421159
#
# ===== RUN 43/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.277848
#   Epoch 20/100, Loss: 0.276352
#   Epoch 30/100, Loss: 0.275098
#   Epoch 40/100, Loss: 0.273614
#   Epoch 50/100, Loss: 0.271755
#   Epoch 60/100, Loss: 0.269096
#   Epoch 70/100, Loss: 0.264719
#   Epoch 80/100, Loss: 0.258672
#   Epoch 90/100, Loss: 0.250533
#   Epoch 100/100, Loss: 0.234652
# Training complete for run 43
# Run 43 — RMSE: 43.607946, MSE: 1901.652976, NMSE: 0.0098925582
#
# ===== RUN 44/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.279322
#   Epoch 20/100, Loss: 0.278253
#   Epoch 30/100, Loss: 0.277331
#   Epoch 40/100, Loss: 0.275762
#   Epoch 50/100, Loss: 0.273077
#   Epoch 60/100, Loss: 0.268060
#   Epoch 70/100, Loss: 0.258886
#   Epoch 80/100, Loss: 0.250937
#   Epoch 90/100, Loss: 0.252613
#   Epoch 100/100, Loss: 0.252958
# Training complete for run 44
# Run 44 — RMSE: 44.768626, MSE: 2004.229845, NMSE: 0.0081185909
#
# ===== RUN 45/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.277838
#   Epoch 20/100, Loss: 0.276095
#   Epoch 30/100, Loss: 0.274602
#   Epoch 40/100, Loss: 0.272166
#   Epoch 50/100, Loss: 0.268480
#   Epoch 60/100, Loss: 0.263424
#   Epoch 70/100, Loss: 0.254644
#   Epoch 80/100, Loss: 0.233045
#   Epoch 90/100, Loss: 0.199469
#   Epoch 100/100, Loss: 0.186365
# Training complete for run 45
# Run 45 — RMSE: 39.753920, MSE: 1580.374174, NMSE: 0.0083903506
#
# ===== RUN 46/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.275001
#   Epoch 20/100, Loss: 0.270992
#   Epoch 30/100, Loss: 0.265998
#   Epoch 40/100, Loss: 0.249021
#   Epoch 50/100, Loss: 0.200976
#   Epoch 60/100, Loss: 0.162482
#   Epoch 70/100, Loss: 0.154559
#   Epoch 80/100, Loss: 0.145572
#   Epoch 90/100, Loss: 0.141438
#   Epoch 100/100, Loss: 0.143320
# Training complete for run 46
# Run 46 — RMSE: 38.544621, MSE: 1485.687842, NMSE: 0.0077832893
#
# ===== RUN 47/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.278911
#   Epoch 20/100, Loss: 0.278221
#   Epoch 30/100, Loss: 0.276817
#   Epoch 40/100, Loss: 0.274655
#   Epoch 50/100, Loss: 0.271505
#   Epoch 60/100, Loss: 0.266728
#   Epoch 70/100, Loss: 0.259902
#   Epoch 80/100, Loss: 0.251530
#   Epoch 90/100, Loss: 0.242483
#   Epoch 100/100, Loss: 0.233367
# Training complete for run 47
# Run 47 — RMSE: 42.992431, MSE: 1848.349107, NMSE: 0.0085214984
#
# ===== RUN 48/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.276863
#   Epoch 20/100, Loss: 0.275726
#   Epoch 30/100, Loss: 0.274964
#   Epoch 40/100, Loss: 0.273433
#   Epoch 50/100, Loss: 0.268440
#   Epoch 60/100, Loss: 0.262461
#   Epoch 70/100, Loss: 0.256483
#   Epoch 80/100, Loss: 0.246208
#   Epoch 90/100, Loss: 0.229647
# ...
#   Epoch 10/100, Loss: 0.221314
#   Epoch 20/100, Loss: 0.220706
#   Epoch 30/100, Loss: 0.220257
#   Epoch 40/100, Loss: 0.219487
#   Epoch 50/100, Loss: 0.217899
#   Epoch 60/100, Loss: 0.216420
#   Epoch 70/100, Loss: 0.214939
#   Epoch 80/100, Loss: 0.212762
#   Epoch 90/100, Loss: 0.209724
#   Epoch 100/100, Loss: 0.205677
# Training complete for run 25
# Run 25 — RMSE: 47.633141, MSE: 2268.916103, NMSE: 0.0088234065
#
# ===== RUN 26/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.227949
#   Epoch 20/100, Loss: 0.224636
#   Epoch 30/100, Loss: 0.222635
#   Epoch 40/100, Loss: 0.221323
#   Epoch 50/100, Loss: 0.220096
#   Epoch 60/100, Loss: 0.218561
#   Epoch 70/100, Loss: 0.216362
#   Epoch 80/100, Loss: 0.213188
#   Epoch 90/100, Loss: 0.209122
#   Epoch 100/100, Loss: 0.203813
# Training complete for run 26
# Run 26 — RMSE: 47.514833, MSE: 2257.659372, NMSE: 0.0089734000
#
# ===== RUN 27/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.220718
#   Epoch 20/100, Loss: 0.217456
#   Epoch 30/100, Loss: 0.214294
#   Epoch 40/100, Loss: 0.211394
#   Epoch 50/100, Loss: 0.208885
#   Epoch 60/100, Loss: 0.207532
#   Epoch 70/100, Loss: 0.205621
#   Epoch 80/100, Loss: 0.201842
#   Epoch 90/100, Loss: 0.196690
#   Epoch 100/100, Loss: 0.190291
# Training complete for run 27
# Run 27 — RMSE: 44.495911, MSE: 1979.886111, NMSE: 0.0089555649
#
# ===== RUN 28/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.218314
#   Epoch 20/100, Loss: 0.216807
#   Epoch 30/100, Loss: 0.214860
#   Epoch 40/100, Loss: 0.218405
#   Epoch 50/100, Loss: 0.214293
#   Epoch 60/100, Loss: 0.209425
#   Epoch 70/100, Loss: 0.207636
#   Epoch 80/100, Loss: 0.207927
#   Epoch 90/100, Loss: 0.208971
#   Epoch 100/100, Loss: 0.204419
# Training complete for run 28
# Run 28 — RMSE: 48.912980, MSE: 2392.479654, NMSE: 0.0105521717
#
# ===== RUN 29/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.217795
#   Epoch 20/100, Loss: 0.212003
#   Epoch 30/100, Loss: 0.207586
#   Epoch 40/100, Loss: 0.212296
#   Epoch 50/100, Loss: 0.212473
#   Epoch 60/100, Loss: 0.213052
#   Epoch 70/100, Loss: 0.213508
#   Epoch 80/100, Loss: 0.213812
#   Epoch 90/100, Loss: 0.213892
#   Epoch 100/100, Loss: 0.213691
# Training complete for run 29
# Run 29 — RMSE: 48.498692, MSE: 2352.123142, NMSE: 0.0096414379
#
# ===== RUN 30/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.218105
#   Epoch 20/100, Loss: 0.215672
#   Epoch 30/100, Loss: 0.213160
#   Epoch 40/100, Loss: 0.210064
#   Epoch 50/100, Loss: 0.205691
#   Epoch 60/100, Loss: 0.199001
#   Epoch 70/100, Loss: 0.187960
#   Epoch 80/100, Loss: 0.170220
#   Epoch 90/100, Loss: 0.163892
#   Epoch 100/100, Loss: 0.155407
# Training complete for run 30
# Run 30 — RMSE: 38.656208, MSE: 1494.302409, NMSE: 0.0073494196
#
# ===== RUN 31/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.221979
#   Epoch 20/100, Loss: 0.221357
#   Epoch 30/100, Loss: 0.220623
#   Epoch 40/100, Loss: 0.219769
#   Epoch 50/100, Loss: 0.218733
#   Epoch 60/100, Loss: 0.217303
#   Epoch 70/100, Loss: 0.215129
#   Epoch 80/100, Loss: 0.211448
#   Epoch 90/100, Loss: 0.204961
#   Epoch 100/100, Loss: 0.195818
# Training complete for run 31
# Run 31 — RMSE: 46.442471, MSE: 2156.903080, NMSE: 0.0081493067
#
# ===== RUN 32/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.220364
#   Epoch 20/100, Loss: 0.217958
#   Epoch 30/100, Loss: 0.215600
#   Epoch 40/100, Loss: 0.213130
#   Epoch 50/100, Loss: 0.210377
#   Epoch 60/100, Loss: 0.206895
#   Epoch 70/100, Loss: 0.203770
#   Epoch 80/100, Loss: 0.199975
#   Epoch 90/100, Loss: 0.196915
#   Epoch 100/100, Loss: 0.198386
# Training complete for run 32
# Run 32 — RMSE: 55.326855, MSE: 3061.060902, NMSE: 0.0110027892
#
# ===== RUN 33/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.223368
#   Epoch 20/100, Loss: 0.222354
#   Epoch 30/100, Loss: 0.221153
#   Epoch 40/100, Loss: 0.219742
#   Epoch 50/100, Loss: 0.217837
#   Epoch 60/100, Loss: 0.215128
#   Epoch 70/100, Loss: 0.211757
#   Epoch 80/100, Loss: 0.208822
#   Epoch 90/100, Loss: 0.206899
#   Epoch 100/100, Loss: 0.205472
# Training complete for run 33
# Run 33 — RMSE: 47.670309, MSE: 2272.458325, NMSE: 0.0088896005
#
# ===== RUN 34/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.217572
#   Epoch 20/100, Loss: 0.212660
#   Epoch 30/100, Loss: 0.207389
#   Epoch 40/100, Loss: 0.199091
#   Epoch 50/100, Loss: 0.181707
#   Epoch 60/100, Loss: 0.147240
#   Epoch 70/100, Loss: 0.143546
#   Epoch 80/100, Loss: 0.148035
#   Epoch 90/100, Loss: 0.150944
#   Epoch 100/100, Loss: 0.150842
# Training complete for run 34
# Run 34 — RMSE: 40.822466, MSE: 1666.473733, NMSE: 0.0087126885
#
# ===== RUN 35/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.220766
#   Epoch 20/100, Loss: 0.220043
#   Epoch 30/100, Loss: 0.219371
#   Epoch 40/100, Loss: 0.218530
#   Epoch 50/100, Loss: 0.217286
#   Epoch 60/100, Loss: 0.215189
#   Epoch 70/100, Loss: 0.211148
#   Epoch 80/100, Loss: 0.202580
#   Epoch 90/100, Loss: 0.184386
#   Epoch 100/100, Loss: 0.165998
# Training complete for run 35
# Run 35 — RMSE: 41.526983, MSE: 1724.490290, NMSE: 0.0085382707
#
# ===== RUN 36/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.220647
#   Epoch 20/100, Loss: 0.219711
#   Epoch 30/100, Loss: 0.217955
#   Epoch 40/100, Loss: 0.215703
#   Epoch 50/100, Loss: 0.212784
#   Epoch 60/100, Loss: 0.208750
#   Epoch 70/100, Loss: 0.202509
#   Epoch 80/100, Loss: 0.191999
#   Epoch 90/100, Loss: 0.183869
#   Epoch 100/100, Loss: 0.181164
# Training complete for run 36
# Run 36 — RMSE: 42.147923, MSE: 1776.447383, NMSE: 0.0085124189
#
# ===== RUN 37/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.220348
#   Epoch 20/100, Loss: 0.218280
#   Epoch 30/100, Loss: 0.216382
#   Epoch 40/100, Loss: 0.213170
#   Epoch 50/100, Loss: 0.208774
#   Epoch 60/100, Loss: 0.213308
#   Epoch 70/100, Loss: 0.208836
#   Epoch 80/100, Loss: 0.206441
#   Epoch 90/100, Loss: 0.203999
#   Epoch 100/100, Loss: 0.200596
# Training complete for run 37
# Run 37 — RMSE: 101.672288, MSE: 10337.254196, NMSE: 0.0140414495
#
# ===== RUN 38/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.221058
#   Epoch 20/100, Loss: 0.218145
#   Epoch 30/100, Loss: 0.214228
#   Epoch 40/100, Loss: 0.206742
#   Epoch 50/100, Loss: 0.199302
#   Epoch 60/100, Loss: 0.192438
#   Epoch 70/100, Loss: 0.185795
#   Epoch 80/100, Loss: 0.179147
#   Epoch 90/100, Loss: 0.172035
#   Epoch 100/100, Loss: 0.163815
# Training complete for run 38
# Run 38 — RMSE: 39.525428, MSE: 1562.259459, NMSE: 0.0072364431
#
# ===== RUN 39/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.218088
#   Epoch 20/100, Loss: 0.214895
#   Epoch 30/100, Loss: 0.213212
#   Epoch 40/100, Loss: 0.212088
#   Epoch 50/100, Loss: 0.210844
#   Epoch 60/100, Loss: 0.208795
#   Epoch 70/100, Loss: 0.205047
#   Epoch 80/100, Loss: 0.198299
#   Epoch 90/100, Loss: 0.186363
#   Epoch 100/100, Loss: 0.168278
# Training complete for run 39
# Run 39 — RMSE: 46.586019, MSE: 2170.257187, NMSE: 0.0086953415
#
# ===== RUN 40/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.221669
#   Epoch 20/100, Loss: 0.219494
#   Epoch 30/100, Loss: 0.216977
#   Epoch 40/100, Loss: 0.210652
#   Epoch 50/100, Loss: 0.193721
#   Epoch 60/100, Loss: 0.139975
#   Epoch 70/100, Loss: 0.181176
#   Epoch 80/100, Loss: 0.131785
#   Epoch 90/100, Loss: 0.133829
#   Epoch 100/100, Loss: 0.138954
# Training complete for run 40
# Run 40 — RMSE: 35.307792, MSE: 1246.640184, NMSE: 0.0073652423
#
# ===== RUN 41/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.217522
#   Epoch 20/100, Loss: 0.214760
#   Epoch 30/100, Loss: 0.211657
#   Epoch 40/100, Loss: 0.207542
#   Epoch 50/100, Loss: 0.203737
#   Epoch 60/100, Loss: 0.200345
#   Epoch 70/100, Loss: 0.198326
#   Epoch 80/100, Loss: 0.194113
#   Epoch 90/100, Loss: 0.187908
#   Epoch 100/100, Loss: 0.186759
# Training complete for run 41
# Run 41 — RMSE: 52.408817, MSE: 2746.684135, NMSE: 0.0106751505
#
# ===== RUN 42/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.222830
#   Epoch 20/100, Loss: 0.220939
#   Epoch 30/100, Loss: 0.219579
#   Epoch 40/100, Loss: 0.218152
#   Epoch 50/100, Loss: 0.215888
#   Epoch 60/100, Loss: 0.210307
#   Epoch 70/100, Loss: 0.195300
#   Epoch 80/100, Loss: 0.173624
#   Epoch 90/100, Loss: 0.173001
#   Epoch 100/100, Loss: 0.178766
# Training complete for run 42
# Run 42 — RMSE: 40.863345, MSE: 1669.812951, NMSE: 0.0088805824
#
# ===== RUN 43/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.221137
#   Epoch 20/100, Loss: 0.220214
#   Epoch 30/100, Loss: 0.219655
#   Epoch 40/100, Loss: 0.219195
#   Epoch 50/100, Loss: 0.218808
#   Epoch 60/100, Loss: 0.218485
#   Epoch 70/100, Loss: 0.218177
#   Epoch 80/100, Loss: 0.217847
#   Epoch 90/100, Loss: 0.217530
#   Epoch 100/100, Loss: 0.217314
# Training complete for run 43
# Run 43 — RMSE: 49.405427, MSE: 2440.896236, NMSE: 0.0097817599
#
# ===== RUN 44/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.221640
#   Epoch 20/100, Loss: 0.221230
#   Epoch 30/100, Loss: 0.221000
#   Epoch 40/100, Loss: 0.220471
#   Epoch 50/100, Loss: 0.219545
#   Epoch 60/100, Loss: 0.217996
#   Epoch 70/100, Loss: 0.215412
#   Epoch 80/100, Loss: 0.211401
#   Epoch 90/100, Loss: 0.207630
#   Epoch 100/100, Loss: 0.207739
# Training complete for run 44
# Run 44 — RMSE: 47.910196, MSE: 2295.386891, NMSE: 0.0089356276
#
# ===== RUN 45/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.220478
#   Epoch 20/100, Loss: 0.219486
#   Epoch 30/100, Loss: 0.219031
#   Epoch 40/100, Loss: 0.218208
#   Epoch 50/100, Loss: 0.216920
#   Epoch 60/100, Loss: 0.215298
#   Epoch 70/100, Loss: 0.213740
#   Epoch 80/100, Loss: 0.212262
#   Epoch 90/100, Loss: 0.210140
#   Epoch 100/100, Loss: 0.207011
# Training complete for run 45
# Run 45 — RMSE: 47.960116, MSE: 2300.172753, NMSE: 0.0088454442
#
# ===== RUN 46/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.218153
#   Epoch 20/100, Loss: 0.215490
#   Epoch 30/100, Loss: 0.213548
#   Epoch 40/100, Loss: 0.211223
#   Epoch 50/100, Loss: 0.206985
#   Epoch 60/100, Loss: 0.194932
#   Epoch 70/100, Loss: 0.178158
#   Epoch 80/100, Loss: 0.178099
#   Epoch 90/100, Loss: 0.154819
#   Epoch 100/100, Loss: 0.135060
# Training complete for run 46
# Run 46 — RMSE: 41.841146, MSE: 1750.681516, NMSE: 0.0089096786
#
# ===== RUN 47/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.221366
#   Epoch 20/100, Loss: 0.220606
#   Epoch 30/100, Loss: 0.219744
#   Epoch 40/100, Loss: 0.218721
#   Epoch 50/100, Loss: 0.217547
#   Epoch 60/100, Loss: 0.216152
#   Epoch 70/100, Loss: 0.214318
#   Epoch 80/100, Loss: 0.211701
#   Epoch 90/100, Loss: 0.207844
#   Epoch 100/100, Loss: 0.202297
# Training complete for run 47
# Run 47 — RMSE: 47.479528, MSE: 2254.305579, NMSE: 0.0092031496
#
# ===== RUN 48/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.219006
#   Epoch 20/100, Loss: 0.217589
#   Epoch 30/100, Loss: 0.216835
#   Epoch 40/100, Loss: 0.216602
#   Epoch 50/100, Loss: 0.216002
#   Epoch 60/100, Loss: 0.213311
#   Epoch 70/100, Loss: 0.209201
#   Epoch 80/100, Loss: 0.206097
#   Epoch 90/100, Loss: 0.202813
#   Epoch 100/100, Loss: 0.198987
# Training complete for run 48
# Run 48 — RMSE: 46.681390, MSE: 2179.152211, NMSE: 0.0088086724
#
# ===== RUN 49/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.220344
#   Epoch 20/100, Loss: 0.219808
#   Epoch 30/100, Loss: 0.218364
#   Epoch 40/100, Loss: 0.215770
#   Epoch 50/100, Loss: 0.212199
#   Epoch 60/100, Loss: 0.208677
#   Epoch 70/100, Loss: 0.202415
#   Epoch 80/100, Loss: 0.189233
#   Epoch 90/100, Loss: 0.169346
#   Epoch 100/100, Loss: 0.159564
# Training complete for run 49
# Run 49 — RMSE: 40.317349, MSE: 1625.488618, NMSE: 0.0078609629
#
# ===== RUN 50/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.218365
#   Epoch 20/100, Loss: 0.216629
#   Epoch 30/100, Loss: 0.214420
#   Epoch 40/100, Loss: 0.212190
#   Epoch 50/100, Loss: 0.212038
#   Epoch 60/100, Loss: 0.212311
#   Epoch 70/100, Loss: 0.211296
#   Epoch 80/100, Loss: 0.210072
#   Epoch 90/100, Loss: 0.209293
#   Epoch 100/100, Loss: 0.206963
# Training complete for run 50
# Run 50 — RMSE: 49.617887, MSE: 2461.934709, NMSE: 0.0094878568
#
# ===== RUN 51/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.220614
#   Epoch 20/100, Loss: 0.218372
#   Epoch 30/100, Loss: 0.216187
#   Epoch 40/100, Loss: 0.212264
#   Epoch 50/100, Loss: 0.197348
#   Epoch 60/100, Loss: 0.134269
#   Epoch 70/100, Loss: 0.132498
#   Epoch 80/100, Loss: 0.122754
#   Epoch 90/100, Loss: 0.122699
#   Epoch 100/100, Loss: 0.120826
# Training complete for run 51
# Run 51 — RMSE: 37.897295, MSE: 1436.204937, NMSE: 0.0090680932
#
# ===== RUN 52/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.222056
#   Epoch 20/100, Loss: 0.219103
#   Epoch 30/100, Loss: 0.218930
#   Epoch 40/100, Loss: 0.218759
#   Epoch 50/100, Loss: 0.218136
#   Epoch 60/100, Loss: 0.216970
#   Epoch 70/100, Loss: 0.214745
#   Epoch 80/100, Loss: 0.209999
#   Epoch 90/100, Loss: 0.198085
#   Epoch 100/100, Loss: 0.173805
# Training complete for run 52
# Run 52 — RMSE: 43.231647, MSE: 1868.975344, NMSE: 0.0086754451
#
# ===== RUN 53/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.221949
#   Epoch 20/100, Loss: 0.219267
#   Epoch 30/100, Loss: 0.217078
#   Epoch 40/100, Loss: 0.213528
#   Epoch 50/100, Loss: 0.206298
#   Epoch 60/100, Loss: 0.197791
#   Epoch 70/100, Loss: 0.188726
#   Epoch 80/100, Loss: 0.177087
#   Epoch 90/100, Loss: 0.158705
#   Epoch 100/100, Loss: 0.135947
# Training complete for run 53
# Run 53 — RMSE: 38.341872, MSE: 1470.099160, NMSE: 0.0079637844
#
# ===== RUN 54/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.219128
#   Epoch 20/100, Loss: 0.217227
#   Epoch 30/100, Loss: 0.215225
#   Epoch 40/100, Loss: 0.210960
#   Epoch 50/100, Loss: 0.198779
#   Epoch 60/100, Loss: 0.178249
#   Epoch 70/100, Loss: 0.186948
#   Epoch 80/100, Loss: 0.178943
#   Epoch 90/100, Loss: 0.159427
#   Epoch 100/100, Loss: 0.143552
# Training complete for run 54
# Run 54 — RMSE: 40.499007, MSE: 1640.169575, NMSE: 0.0092303259
#
# ===== RUN 55/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.219861
#   Epoch 20/100, Loss: 0.213841
#   Epoch 30/100, Loss: 0.201876
#   Epoch 40/100, Loss: 0.188004
#   Epoch 50/100, Loss: 0.164785
#   Epoch 60/100, Loss: 0.195184
#   Epoch 70/100, Loss: 0.200392
#   Epoch 80/100, Loss: 0.187294
#   Epoch 90/100, Loss: 0.174642
#   Epoch 100/100, Loss: 0.161454
# Training complete for run 55
# Run 55 — RMSE: 38.299901, MSE: 1466.882436, NMSE: 0.0071268518
#
# ===== RUN 56/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.220829
#   Epoch 20/100, Loss: 0.220100
#   Epoch 30/100, Loss: 0.219713
#   Epoch 40/100, Loss: 0.219377
#   Epoch 50/100, Loss: 0.218964
#   Epoch 60/100, Loss: 0.218389
#   Epoch 70/100, Loss: 0.217541
#   Epoch 80/100, Loss: 0.216214
#   Epoch 90/100, Loss: 0.214002
#   Epoch 100/100, Loss: 0.210113
# Training complete for run 56
# Run 56 — RMSE: 48.595085, MSE: 2361.482264, NMSE: 0.0094280478
#
# ===== RUN 57/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.221690
#   Epoch 20/100, Loss: 0.220793
#   Epoch 30/100, Loss: 0.220185
#   Epoch 40/100, Loss: 0.219606
#   Epoch 50/100, Loss: 0.218906
#   Epoch 60/100, Loss: 0.218033
#   Epoch 70/100, Loss: 0.217008
#   Epoch 80/100, Loss: 0.215819
#   Epoch 90/100, Loss: 0.214413
#   Epoch 100/100, Loss: 0.212611
# Training complete for run 57
# Run 57 — RMSE: 48.985667, MSE: 2399.595535, NMSE: 0.0097240691
#
# ===== RUN 58/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.221542
#   Epoch 20/100, Loss: 0.218778
#   Epoch 30/100, Loss: 0.217822
#   Epoch 40/100, Loss: 0.217397
#   Epoch 50/100, Loss: 0.216940
#   Epoch 60/100, Loss: 0.216312
#   Epoch 70/100, Loss: 0.215427
#   Epoch 80/100, Loss: 0.214229
#   Epoch 90/100, Loss: 0.212695
#   Epoch 100/100, Loss: 0.210706
# Training complete for run 58
# Run 58 — RMSE: 48.676932, MSE: 2369.443686, NMSE: 0.0092962600
#
# ===== RUN 59/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.224170
#   Epoch 20/100, Loss: 0.212945
#   Epoch 30/100, Loss: 0.197869
#   Epoch 40/100, Loss: 0.196096
#   Epoch 50/100, Loss: 0.195147
#   Epoch 60/100, Loss: 0.169813
#   Epoch 70/100, Loss: 0.171452
#   Epoch 80/100, Loss: 0.172457
#   Epoch 90/100, Loss: 0.200047
#   Epoch 100/100, Loss: 0.217243
# Training complete for run 59
# Run 59 — RMSE: 49.210286, MSE: 2421.652223, NMSE: 0.0099793864
#
# ===== RUN 60/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.213735
#   Epoch 20/100, Loss: 0.192394
#   Epoch 30/100, Loss: 0.177397
#   Epoch 40/100, Loss: 0.168188
#   Epoch 50/100, Loss: 0.158813
#   Epoch 60/100, Loss: 0.147238
#   Epoch 70/100, Loss: 0.135986
#   Epoch 80/100, Loss: 0.125510
#   Epoch 90/100, Loss: 0.115763
#   Epoch 100/100, Loss: 0.108758
# Training complete for run 60
# Run 60 — RMSE: 36.610989, MSE: 1340.364551, NMSE: 0.0072116722
#
# ===== STATS FOR NOISE 10.0% (60 runs) =====
# RMSE: 44.916587 +/- 8.778482
# MSE:  2094.561496 +/- 1151.388700
# NMSE: 0.0088334190 +/- 0.0011461024
# Best run: 40 (RMSE: 35.307792)

# %% [markdown]
# ## Results

# %%
# ============================================================
# Final Metrics Summary & Plots per Noise Level
# ============================================================
from tabulate import tabulate

for entry in _molab_results:
    lam = entry[0]
    mean_rmse, std_rmse = entry[1], entry[2]
    mean_mse, std_mse = entry[3], entry[4]
    mean_nmse, std_nmse = entry[5], entry[6]
    best_rmse_val = entry[7]
    best_predictions = entry[8]
    best_losses = entry[9]
    raw_values_for_plot = entry[10]
    
    print("\n" + "="*80)
    print(f"RESULTS FOR NOISE LEVEL: {lam*100:.1f}%")
    print("="*80)
    
    print(f'Mean RMSE: {mean_rmse:.6f} +/- {std_rmse:.6f}')
    print(f'Mean MSE:  {mean_mse:.6f} +/- {std_mse:.6f}')
    print(f'Mean NMSE: {mean_nmse:.10f} +/- {std_nmse:.10f}')
    print(f'Best RMSE: {best_rmse_val:.6f}')
    
    actual = raw_values_for_plot[-60:]
    
    plt.figure(figsize=(12, 5))
    plt.plot(actual, label='Actual', color='blue', linewidth=1.5)
    plt.plot(best_predictions, label='Predicted (Best Run)', color='red',
             linewidth=1.5, linestyle='--')
    plt.title(f'Predictions vs Actual (Noise {lam*100:.1f}%)')
    plt.xlabel('Time Step')
    plt.ylabel('Value')
    plt.legend()
    plt.grid(True, alpha=0.3)
    plt.tight_layout()
    plt.show()

    plt.figure(figsize=(12, 4))
    plt.plot(best_losses, color='green', linewidth=1.0)
    plt.title(f'Training Loss (Best Run, Noise {lam*100:.1f}%)')
    plt.xlabel('Epoch')
    plt.ylabel('MSE Loss')
    plt.grid(True, alpha=0.3)
    plt.tight_layout()
    plt.show()

print("\n" + "="*80)
print("FINAL RESULTS TABLE ACROSS ALL NOISE LEVELS")
print("="*80)
df_res = pd.DataFrame(
    [[r[0], f'{r[1]:.6f} +/- {r[2]:.6f}', f'{r[3]:.6f} +/- {r[4]:.6f}', 
      f'{r[5]:.10f} +/- {r[6]:.10f}', f'{r[7]:.6f}'] for r in _molab_results],
    columns=['Noise Level', 'RMSE (mean+/-std)', 'MSE (mean+/-std)', 'NMSE (mean+/-std)', 'Best RMSE']
)
print(tabulate(df_res, headers='keys', tablefmt='github', showindex=False))
# Out:
# ================================================================================
# RESULTS FOR NOISE LEVEL: 0.0%
# ================================================================================
# Mean RMSE: 40.883422 +/- 5.359688
# Mean MSE:  1700.180437 +/- 436.890350
# Mean NMSE: 0.0084743617 +/- 0.0015712337
# Best RMSE: 27.645010
# ================================================================================
# RESULTS FOR NOISE LEVEL: 0.5%
# ================================================================================
# Mean RMSE: 40.817838 +/- 5.158435
# Mean MSE:  1692.705317 +/- 412.216738
# Mean NMSE: 0.0084485477 +/- 0.0014502849
# Best RMSE: 27.022187
# ================================================================================
# RESULTS FOR NOISE LEVEL: 5.0%
# ================================================================================
# Mean RMSE: 46.993741 +/- 29.752982
# Mean MSE:  3093.651601 +/- 7587.340602
# Mean NMSE: 0.0085761820 +/- 0.0018624233
# Best RMSE: 31.863451
# ================================================================================
# RESULTS FOR NOISE LEVEL: 10.0%
# ================================================================================
# Mean RMSE: 44.916587 +/- 8.778482
# Mean MSE:  2094.561496 +/- 1151.388700
# Mean NMSE: 0.0088334190 +/- 0.0011461024
# Best RMSE: 35.307792
# ================================================================================
# FINAL RESULTS TABLE ACROSS ALL NOISE LEVELS
# ================================================================================
# |   Noise Level | RMSE (mean+/-std)       | MSE (mean+/-std)            | NMSE (mean+/-std)             |   Best RMSE |
# |---------------|-------------------------|-----------------------------|-------------------------------|-------------|
# |         0     | 40.883422 +/- 5.359688  | 1700.180437 +/- 436.890350  | 0.0084743617 +/- 0.0015712337 |     27.645  |
# |         0.005 | 40.817838 +/- 5.158435  | 1692.705317 +/- 412.216738  | 0.0084485477 +/- 0.0014502849 |     27.0222 |
# |         0.05  | 46.993741 +/- 29.752982 | 3093.651601 +/- 7587.340602 | 0.0085761820 +/- 0.0018624233 |     31.8635 |
# |         0.1   | 44.916587 +/- 8.778482  | 2094.561496 +/- 1151.388700 | 0.0088334190 +/- 0.0011461024 |     35.3078 |
