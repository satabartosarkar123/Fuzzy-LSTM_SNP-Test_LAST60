# %% [markdown]
# # Pure LSTM — Monthly Milk Production (Gaussian Noise Evaluation)
#
# Time series forecasting with Gaussian noise robustness analysis.
# - Noise levels: [0.0, 0.005, 0.05, 0.1]
# - 60 runs × 100 epochs per noise level
# - Last 60 for test, rest for training, NO validation

# %%
# ============================================================
# ALL IMPORTS
# ============================================================

import numpy as np
import pandas as pd
import torch
import torch.nn as nn
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from math import sqrt
import matplotlib.pyplot as plt
import warnings
import os

warnings.filterwarnings('ignore')
print(f"PyTorch version: {torch.__version__}")
print(f"NumPy version: {np.__version__}")
# Out:
# PyTorch version: 2.10.0+cu128
# NumPy version: 2.0.2

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

class PureLSTM(nn.Module):
    """
    Standard LSTM (Hochreiter & Schmidhuber, 1997) for time series forecasting.
    Stateful: maintains hidden and cell states across sequence steps.
    Same hyperparameters as LSTM-SNP for fair comparison.
    """
    def __init__(self, input_dim=1, hidden_dim=8, output_dim=1):
        super().__init__()
        self.hidden_dim = hidden_dim
        self.lstm = nn.LSTM(input_dim, hidden_dim, batch_first=True)
        self.fc = nn.Linear(hidden_dim, output_dim)
        self.u = None  # (h, c) state

    def reset_states(self, batch_size, device):
        h0 = torch.zeros(1, batch_size, self.hidden_dim, device=device)
        c0 = torch.zeros(1, batch_size, self.hidden_dim, device=device)
        self.u = (h0, c0)
        
    def detach_states(self):
        if self.u is not None:
            self.u = (self.u[0].detach(), self.u[1].detach())

    def forward(self, x):
        if self.u is None or self.u[0].device != x.device:
            self.reset_states(x.size(0), x.device)
            
        lstm_out, self.u = self.lstm(x, self.u)
        out = self.fc(lstm_out[:, -1, :])
        return out


def build_model(input_dim, units):
    return PureLSTM(input_dim=input_dim, hidden_dim=units, output_dim=1)

# %%
# Quick model check
model = build_model(input_dim=1, units=8)
print(model)
print(f"Total params: {sum(p.numel() for p in model.parameters())}")
# Out:
# PureLSTM(
#   (lstm): LSTM(1, 8, batch_first=True)
#   (fc): Linear(in_features=8, out_features=1, bias=True)
# )
# Total params: 361

# %% [markdown]
# ## Data Pipeline — Monthly Milk Production

# %%
import os
for f in os.listdir('/kaggle/input/datasets/satabartosarkar/monthly-milk-production-pounds-p-csv'):
    print(f)
# Out:
# monthly-milk-production-pounds-p.csv

# %%
# ============================================================
# 1. Load Time Series Data
# ============================================================
series = pd.read_csv(
    '/kaggle/input/datasets/satabartosarkar/monthly-milk-production-pounds-p-csv/monthly-milk-production-pounds-p.csv',
    header=0,
    parse_dates=[0],
    index_col=0
)

original_raw_values = series.values.flatten()
print(f"Base data shape: {original_raw_values.shape}")
print(f"First 5 values: {original_raw_values[:5]}")
# Out:
# Base data shape: (168,)
# First 5 values: [589 561 640 656 727]

# %%
# ============================================================
# 2. First-Order Differencing
# ============================================================

def difference(dataset, interval=1):
    diff = []
    for i in range(interval, len(dataset)):
        value = dataset[i] - dataset[i - interval]
        diff.append(value)
    return np.array(diff)

# %%
# ============================================================
# 3. Convert to Supervised Learning Format (lag=1)
# ============================================================

def timeseries_to_supervised(data, lag=1):
    df = pd.DataFrame(data)
    columns = [df.shift(i) for i in range(1, lag+1)]
    columns.append(df)
    df = pd.concat(columns, axis=1)
    df.fillna(0, inplace=True)
    return df.values

# %% [markdown]
# ## Training Loop

# %%
# ============================================================
# Gaussian Noise Evaluation + 60-Run Experiment Protocol (PyTorch)
# ============================================================
import torch
import torch.nn as nn

s_x = np.std(original_raw_values)
noise_levels = [0.0, 0.005, 0.05, 0.1]
_molab_results = []

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"\n--- [PyTorch] RUNNING ON {device} ---\n")

for lam in noise_levels:
    sigma = lam * s_x
    print("\n" + "="*80)
    print(f"EVALUATING NOISE LEVEL: {lam*100:.1f}% (lambda={lam}, sigma={sigma:.6f})")
    print("="*80 + "\n")
    
    np.random.seed(42)
    torch.manual_seed(42)
    noise = np.random.normal(0, sigma, size=original_raw_values.shape)
    raw_values = original_raw_values + noise
    
    # 2. Difference
    diff_values = difference(raw_values, 1)
    # 3. Supervised (lag=1)
    supervised = timeseries_to_supervised(diff_values, 1)
    # 4. Split (Last 60 for test, NO validation)
    train, test = supervised[:-60], supervised[-60:]
    # 5. Scale
    scaler = MinMaxScaler(feature_range=(-1, 1))
    scaler.fit(train)
    train_scaled = scaler.transform(train)
    test_scaled = scaler.transform(test)
    # 6. Reshape
    X_train, y_train = train_scaled[:, 0:-1], train_scaled[:, -1]
    X_train = X_train.reshape((X_train.shape[0], 1, X_train.shape[1]))
    
    print(f"X_train shape: {X_train.shape}, y_train shape: {y_train.shape}")
    
    all_rmse = []
    all_mse = []
    all_nmse = []
    all_predictions = []
    all_losses = []
    
    for run in range(60):
        print(f'\n===== RUN {run+1}/60 [Noise {lam*100:.1f}%] =====')
        
        np.random.seed(run)
        torch.manual_seed(run)
        
        model = build_model(input_dim=1, units=8).to(device)
        optimizer = torch.optim.Adam(model.parameters(), lr=0.001)
        criterion = nn.MSELoss()
        
        # Pre-tensorize training data
        X_train_t = torch.tensor(X_train, dtype=torch.float32).to(device)
        y_train_t = torch.tensor(y_train, dtype=torch.float32).to(device)
        n_samples = X_train_t.size(0)
        
        run_losses = []
        for epoch in range(100):
            model.train()
            model.reset_states(1, device)
            
            epoch_loss = 0.0
            for i in range(n_samples):
                x_i = X_train_t[i:i+1]
                y_i = y_train_t[i:i+1]
                
                optimizer.zero_grad()
                pred = model(x_i)
                loss = criterion(pred.squeeze(-1), y_i)
                loss.backward()
                optimizer.step()
                model.detach_states()
                epoch_loss += loss.item()
            
            avg_loss = epoch_loss / n_samples
            run_losses.append(avg_loss)
            if (epoch+1) % 10 == 0:
                print(f"  Epoch {epoch+1}/100, Loss: {avg_loss:.6f}")
        
        all_losses.append(run_losses)
        print(f'Training complete for run {run+1}')
        
        # Warm-up: condition hidden states on training data
        model.eval()
        with torch.no_grad():
            model.reset_states(1, device)
            for i in range(len(train_scaled)):
                X_raw = train_scaled[i, 0:-1]
                X_input = torch.tensor(X_raw, dtype=torch.float32).view(1, 1, len(X_raw)).to(device)
                model(X_input)
        
        # Test predictions (single-step)
        predictions = []
        model.eval()
        with torch.no_grad():
            for i in range(len(test_scaled)):
                X = test_scaled[i, 0:-1]
                X_input = torch.tensor(X, dtype=torch.float32).view(1, 1, len(X)).to(device)
                yhat = model(X_input).item()
                
                # Invert scaling
                new_row = list(X) + [yhat]
                array = np.array(new_row).reshape(1, len(new_row))
                inverted = scaler.inverse_transform(array)[0, -1]
                
                # Invert differencing
                inverted = inverted + raw_values[len(train) + i]
                predictions.append(inverted)
        
        # Compute metrics
        actual = raw_values[-len(predictions):]
        rmse = sqrt(mean_squared_error(actual, predictions))
        mse = mean_squared_error(actual, predictions)
        meanV = np.mean(actual)
        dominator = np.linalg.norm(np.array(predictions) - meanV, 2)
        nmse = mse / np.power(dominator, 2)
        
        all_rmse.append(rmse)
        all_mse.append(mse)
        all_nmse.append(nmse)
        all_predictions.append(predictions)
        
        print(f'Run {run+1} \u2014 RMSE: {rmse:.6f}, MSE: {mse:.6f}, NMSE: {nmse:.10f}')
    
    # End of 60 runs for this noise level
    best_idx = np.argmin(all_rmse)
    
    print(f'\n===== STATS FOR NOISE {lam*100:.1f}% (60 runs) =====')
    print(f'RMSE: {np.mean(all_rmse):.6f} +/- {np.std(all_rmse):.6f}')
    print(f'MSE:  {np.mean(all_mse):.6f} +/- {np.std(all_mse):.6f}')
    print(f'NMSE: {np.mean(all_nmse):.10f} +/- {np.std(all_nmse):.10f}')
    print(f'Best run: {best_idx+1} (RMSE: {all_rmse[best_idx]:.6f})')
    
    _molab_results.append([lam, 
        np.mean(all_rmse), np.std(all_rmse),
        np.mean(all_mse), np.std(all_mse),
        np.mean(all_nmse), np.std(all_nmse),
        all_rmse[best_idx], all_predictions[best_idx], all_losses[best_idx], raw_values.copy()])
# Out:
# --- [PyTorch] RUNNING ON cuda ---
#
#
# ================================================================================
# EVALUATING NOISE LEVEL: 0.0% (lambda=0.0, sigma=0.000000)
# ================================================================================
#
# X_train shape: (107, 1, 1), y_train shape: (107,)
#
# ===== RUN 1/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.280593
#   Epoch 20/100, Loss: 0.263841
#   Epoch 30/100, Loss: 0.203161
#   Epoch 40/100, Loss: 0.149249
#   Epoch 50/100, Loss: 0.198125
#   Epoch 60/100, Loss: 0.168013
#   Epoch 70/100, Loss: 0.148323
#   Epoch 80/100, Loss: 0.159674
#   Epoch 90/100, Loss: 0.145800
#   Epoch 100/100, Loss: 0.131148
# Training complete for run 1
# Run 1 — RMSE: 36.513032, MSE: 1333.201511, NMSE: 0.0073900613
#
# ===== RUN 2/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.282972
#   Epoch 20/100, Loss: 0.282484
#   Epoch 30/100, Loss: 0.282094
#   Epoch 40/100, Loss: 0.281661
#   Epoch 50/100, Loss: 0.281111
#   Epoch 60/100, Loss: 0.280178
#   Epoch 70/100, Loss: 0.277956
#   Epoch 80/100, Loss: 0.270705
#   Epoch 90/100, Loss: 0.251703
#   Epoch 100/100, Loss: 0.178163
# Training complete for run 2
# Run 2 — RMSE: 40.241223, MSE: 1619.356035, NMSE: 0.0081672323
#
# ===== RUN 3/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.285279
#   Epoch 20/100, Loss: 0.282542
#   Epoch 30/100, Loss: 0.280131
#   Epoch 40/100, Loss: 0.279056
#   Epoch 50/100, Loss: 0.276177
#   Epoch 60/100, Loss: 0.266107
#   Epoch 70/100, Loss: 0.253977
#   Epoch 80/100, Loss: 0.271507
#   Epoch 90/100, Loss: 0.261578
#   Epoch 100/100, Loss: 0.249870
# Training complete for run 3
# Run 3 — RMSE: 45.209452, MSE: 2043.894580, NMSE: 0.0085109275
#
# ===== RUN 4/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.280977
#   Epoch 20/100, Loss: 0.273792
#   Epoch 30/100, Loss: 0.276334
#   Epoch 40/100, Loss: 0.265766
#   Epoch 50/100, Loss: 0.274053
#   Epoch 60/100, Loss: 0.253839
#   Epoch 70/100, Loss: 0.266437
#   Epoch 80/100, Loss: 0.254764
#   Epoch 90/100, Loss: 0.256714
#   Epoch 100/100, Loss: 0.254281
# Training complete for run 4
# Run 4 — RMSE: 44.988615, MSE: 2023.975459, NMSE: 0.0085518839
#
# ===== RUN 5/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.282184
#   Epoch 20/100, Loss: 0.281323
#   Epoch 30/100, Loss: 0.280513
#   Epoch 40/100, Loss: 0.279519
#   Epoch 50/100, Loss: 0.278017
#   Epoch 60/100, Loss: 0.275346
#   Epoch 70/100, Loss: 0.269609
#   Epoch 80/100, Loss: 0.253009
#   Epoch 90/100, Loss: 0.202652
#   Epoch 100/100, Loss: 0.195067
# Training complete for run 5
# Run 5 — RMSE: 38.206671, MSE: 1459.749724, NMSE: 0.0090690639
#
# ===== RUN 6/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.279025
#   Epoch 20/100, Loss: 0.273575
#   Epoch 30/100, Loss: 0.266499
#   Epoch 40/100, Loss: 0.236049
#   Epoch 50/100, Loss: 0.208071
#   Epoch 60/100, Loss: 0.215882
#   Epoch 70/100, Loss: 0.269102
#   Epoch 80/100, Loss: 0.225050
#   Epoch 90/100, Loss: 0.237964
#   Epoch 100/100, Loss: 0.220092
# Training complete for run 6
# Run 6 — RMSE: 45.211698, MSE: 2044.097622, NMSE: 0.0090334201
#
# ===== RUN 7/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.284105
#   Epoch 20/100, Loss: 0.283603
#   Epoch 30/100, Loss: 0.282739
#   Epoch 40/100, Loss: 0.280128
#   Epoch 50/100, Loss: 0.271995
#   Epoch 60/100, Loss: 0.266733
#   Epoch 70/100, Loss: 0.258965
#   Epoch 80/100, Loss: 0.246941
#   Epoch 90/100, Loss: 0.229725
#   Epoch 100/100, Loss: 0.195741
# Training complete for run 7
# Run 7 — RMSE: 41.749989, MSE: 1743.061558, NMSE: 0.0096439111
#
# ===== RUN 8/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.285325
#   Epoch 20/100, Loss: 0.284391
#   Epoch 30/100, Loss: 0.283144
#   Epoch 40/100, Loss: 0.280490
#   Epoch 50/100, Loss: 0.279155
#   Epoch 60/100, Loss: 0.279048
#   Epoch 70/100, Loss: 0.278215
#   Epoch 80/100, Loss: 0.277444
#   Epoch 90/100, Loss: 0.276410
#   Epoch 100/100, Loss: 0.274746
# Training complete for run 8
# Run 8 — RMSE: 48.025560, MSE: 2306.454425, NMSE: 0.0096019498
#
# ===== RUN 9/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.282363
#   Epoch 20/100, Loss: 0.278463
#   Epoch 30/100, Loss: 0.275082
#   Epoch 40/100, Loss: 0.271513
#   Epoch 50/100, Loss: 0.266618
#   Epoch 60/100, Loss: 0.257950
#   Epoch 70/100, Loss: 0.239868
#   Epoch 80/100, Loss: 0.231536
#   Epoch 90/100, Loss: 0.222635
#   Epoch 100/100, Loss: 0.209785
# Training complete for run 9
# Run 9 — RMSE: 39.317383, MSE: 1545.856584, NMSE: 0.0090466947
#
# ===== RUN 10/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.281983
#   Epoch 20/100, Loss: 0.280089
#   Epoch 30/100, Loss: 0.278403
#   Epoch 40/100, Loss: 0.276510
#   Epoch 50/100, Loss: 0.273428
#   Epoch 60/100, Loss: 0.265966
#   Epoch 70/100, Loss: 0.238427
#   Epoch 80/100, Loss: 0.219871
#   Epoch 90/100, Loss: 0.200762
#   Epoch 100/100, Loss: 0.171575
# Training complete for run 10
# Run 10 — RMSE: 38.789735, MSE: 1504.643531, NMSE: 0.0079619549
#
# ===== RUN 11/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.287018
#   Epoch 20/100, Loss: 0.284549
#   Epoch 30/100, Loss: 0.283300
#   Epoch 40/100, Loss: 0.282514
#   Epoch 50/100, Loss: 0.281934
#   Epoch 60/100, Loss: 0.281443
#   Epoch 70/100, Loss: 0.280960
#   Epoch 80/100, Loss: 0.280389
#   Epoch 90/100, Loss: 0.279617
#   Epoch 100/100, Loss: 0.278460
# Training complete for run 11
# Run 11 — RMSE: 48.037233, MSE: 2307.575795, NMSE: 0.0095885274
#
# ===== RUN 12/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.283239
#   Epoch 20/100, Loss: 0.282343
#   Epoch 30/100, Loss: 0.281628
#   Epoch 40/100, Loss: 0.280935
#   Epoch 50/100, Loss: 0.280161
#   Epoch 60/100, Loss: 0.278996
#   Epoch 70/100, Loss: 0.275659
#   Epoch 80/100, Loss: 0.250106
#   Epoch 90/100, Loss: 0.167278
#   Epoch 100/100, Loss: 0.201640
# Training complete for run 12
# Run 12 — RMSE: 40.094914, MSE: 1607.602102, NMSE: 0.0094600101
#
# ===== RUN 13/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.284895
#   Epoch 20/100, Loss: 0.283393
#   Epoch 30/100, Loss: 0.282140
#   Epoch 40/100, Loss: 0.281110
#   Epoch 50/100, Loss: 0.279704
#   Epoch 60/100, Loss: 0.276111
#   Epoch 70/100, Loss: 0.262693
#   Epoch 80/100, Loss: 0.242682
#   Epoch 90/100, Loss: 0.223857
#   Epoch 100/100, Loss: 0.201148
# Training complete for run 13
# Run 13 — RMSE: 39.521888, MSE: 1561.979596, NMSE: 0.0100008423
#
# ===== RUN 14/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.277087
#   Epoch 20/100, Loss: 0.222214
#   Epoch 30/100, Loss: 0.164792
#   Epoch 40/100, Loss: 0.187813
#   Epoch 50/100, Loss: 0.179322
#   Epoch 60/100, Loss: 0.187726
#   Epoch 70/100, Loss: 0.187949
#   Epoch 80/100, Loss: 0.179994
#   Epoch 90/100, Loss: 0.170582
#   Epoch 100/100, Loss: 0.166131
# Training complete for run 14
# Run 14 — RMSE: 33.931121, MSE: 1151.321006, NMSE: 0.0064554023
#
# ===== RUN 15/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.282558
#   Epoch 20/100, Loss: 0.281362
#   Epoch 30/100, Loss: 0.280633
#   Epoch 40/100, Loss: 0.279836
#   Epoch 50/100, Loss: 0.278724
#   Epoch 60/100, Loss: 0.276558
#   Epoch 70/100, Loss: 0.270833
#   Epoch 80/100, Loss: 0.262889
#   Epoch 90/100, Loss: 0.260479
#   Epoch 100/100, Loss: 0.253841
# Training complete for run 15
# Run 15 — RMSE: 47.460948, MSE: 2252.541569, NMSE: 0.0106405021
#
# ===== RUN 16/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.286286
#   Epoch 20/100, Loss: 0.283874
#   Epoch 30/100, Loss: 0.281982
#   Epoch 40/100, Loss: 0.280107
#   Epoch 50/100, Loss: 0.277791
#   Epoch 60/100, Loss: 0.274698
#   Epoch 70/100, Loss: 0.271473
#   Epoch 80/100, Loss: 0.268833
#   Epoch 90/100, Loss: 0.261220
#   Epoch 100/100, Loss: 0.260504
# Training complete for run 16
# Run 16 — RMSE: 45.984078, MSE: 2114.535445, NMSE: 0.0084027179
#
# ===== RUN 17/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.280613
#   Epoch 20/100, Loss: 0.280669
#   Epoch 30/100, Loss: 0.280094
#   Epoch 40/100, Loss: 0.278906
#   Epoch 50/100, Loss: 0.276282
#   Epoch 60/100, Loss: 0.268342
#   Epoch 70/100, Loss: 0.231019
#   Epoch 80/100, Loss: 0.161661
#   Epoch 90/100, Loss: 0.198292
#   Epoch 100/100, Loss: 0.209531
# Training complete for run 17
# Run 17 — RMSE: 40.002475, MSE: 1600.197969, NMSE: 0.0087052167
#
# ===== RUN 18/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.278695
#   Epoch 20/100, Loss: 0.264317
#   Epoch 30/100, Loss: 0.245092
#   Epoch 40/100, Loss: 0.237990
#   Epoch 50/100, Loss: 0.234381
#   Epoch 60/100, Loss: 0.232151
#   Epoch 70/100, Loss: 0.231051
#   Epoch 80/100, Loss: 0.230292
#   Epoch 90/100, Loss: 0.257842
#   Epoch 100/100, Loss: 0.229211
# Training complete for run 18
# Run 18 — RMSE: 66.520665, MSE: 4424.998866, NMSE: 0.0156966087
#
# ===== RUN 19/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.284897
#   Epoch 20/100, Loss: 0.284048
#   Epoch 30/100, Loss: 0.283311
#   Epoch 40/100, Loss: 0.282639
#   Epoch 50/100, Loss: 0.281929
#   Epoch 60/100, Loss: 0.281060
#   Epoch 70/100, Loss: 0.278201
#   Epoch 80/100, Loss: 0.274302
#   Epoch 90/100, Loss: 0.267846
#   Epoch 100/100, Loss: 0.260939
# Training complete for run 19
# Run 19 — RMSE: 46.154866, MSE: 2130.271635, NMSE: 0.0086032301
#
# ===== RUN 20/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.283370
#   Epoch 20/100, Loss: 0.282444
#   Epoch 30/100, Loss: 0.281392
#   Epoch 40/100, Loss: 0.280210
#   Epoch 50/100, Loss: 0.278689
#   Epoch 60/100, Loss: 0.275738
#   Epoch 70/100, Loss: 0.265646
#   Epoch 80/100, Loss: 0.209652
#   Epoch 90/100, Loss: 0.171932
#   Epoch 100/100, Loss: 0.187156
# Training complete for run 20
# Run 20 — RMSE: 38.177646, MSE: 1457.532643, NMSE: 0.0100922984
#
# ===== RUN 21/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.283789
#   Epoch 20/100, Loss: 0.283323
#   Epoch 30/100, Loss: 0.282658
#   Epoch 40/100, Loss: 0.281934
#   Epoch 50/100, Loss: 0.281112
#   Epoch 60/100, Loss: 0.280096
#   Epoch 70/100, Loss: 0.278702
#   Epoch 80/100, Loss: 0.276492
#   Epoch 90/100, Loss: 0.272104
#   Epoch 100/100, Loss: 0.259270
# Training complete for run 21
# Run 21 — RMSE: 46.633665, MSE: 2174.698690, NMSE: 0.0092008808
#
# ===== RUN 22/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.285462
#   Epoch 20/100, Loss: 0.283018
#   Epoch 30/100, Loss: 0.280967
#   Epoch 40/100, Loss: 0.278752
#   Epoch 50/100, Loss: 0.276372
#   Epoch 60/100, Loss: 0.273463
#   Epoch 70/100, Loss: 0.269851
#   Epoch 80/100, Loss: 0.267555
#   Epoch 90/100, Loss: 0.266613
#   Epoch 100/100, Loss: 0.264468
# Training complete for run 22
# Run 22 — RMSE: 46.454427, MSE: 2158.013810, NMSE: 0.0090336723
#
# ===== RUN 23/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.284611
#   Epoch 20/100, Loss: 0.283463
#   Epoch 30/100, Loss: 0.282787
#   Epoch 40/100, Loss: 0.282113
#   Epoch 50/100, Loss: 0.281287
#   Epoch 60/100, Loss: 0.280242
#   Epoch 70/100, Loss: 0.278925
#   Epoch 80/100, Loss: 0.277371
#   Epoch 90/100, Loss: 0.275881
#   Epoch 100/100, Loss: 0.266800
# Training complete for run 23
# Run 23 — RMSE: 46.764097, MSE: 2186.880733, NMSE: 0.0093971234
#
# ===== RUN 24/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.285738
#   Epoch 20/100, Loss: 0.283435
#   Epoch 30/100, Loss: 0.282151
#   Epoch 40/100, Loss: 0.281084
#   Epoch 50/100, Loss: 0.279738
#   Epoch 60/100, Loss: 0.276926
#   Epoch 70/100, Loss: 0.269284
#   Epoch 80/100, Loss: 0.262228
#   Epoch 90/100, Loss: 0.249948
#   Epoch 100/100, Loss: 0.238101
# Training complete for run 24
# Run 24 — RMSE: 45.417988, MSE: 2062.793596, NMSE: 0.0094434473
#
# ===== RUN 25/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.279249
#   Epoch 20/100, Loss: 0.272868
#   Epoch 30/100, Loss: 0.267653
#   Epoch 40/100, Loss: 0.268010
#   Epoch 50/100, Loss: 0.266285
#   Epoch 60/100, Loss: 0.258957
#   Epoch 70/100, Loss: 0.251183
#   Epoch 80/100, Loss: 0.239251
#   Epoch 90/100, Loss: 0.209488
#   Epoch 100/100, Loss: 0.199334
# Training complete for run 25
# Run 25 — RMSE: 39.596498, MSE: 1567.882659, NMSE: 0.0089120469
#
# ===== RUN 26/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.285441
#   Epoch 20/100, Loss: 0.281904
#   Epoch 30/100, Loss: 0.278160
#   Epoch 40/100, Loss: 0.273974
#   Epoch 50/100, Loss: 0.270566
#   Epoch 60/100, Loss: 0.265716
#   Epoch 70/100, Loss: 0.261303
#   Epoch 80/100, Loss: 0.252825
#   Epoch 90/100, Loss: 0.240496
#   Epoch 100/100, Loss: 0.225083
# Training complete for run 26
# Run 26 — RMSE: 48.061474, MSE: 2309.905279, NMSE: 0.0092617923
#
# ===== RUN 27/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.285267
#   Epoch 20/100, Loss: 0.282942
#   Epoch 30/100, Loss: 0.281514
#   Epoch 40/100, Loss: 0.279575
#   Epoch 50/100, Loss: 0.277127
#   Epoch 60/100, Loss: 0.274849
#   Epoch 70/100, Loss: 0.272631
#   Epoch 80/100, Loss: 0.269322
#   Epoch 90/100, Loss: 0.262729
#   Epoch 100/100, Loss: 0.249767
# Training complete for run 27
# Run 27 — RMSE: 44.683004, MSE: 1996.570854, NMSE: 0.0087363752
#
# ===== RUN 28/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.281164
#   Epoch 20/100, Loss: 0.280594
#   Epoch 30/100, Loss: 0.280758
#   Epoch 40/100, Loss: 0.280847
#   Epoch 50/100, Loss: 0.280763
#   Epoch 60/100, Loss: 0.280369
#   Epoch 70/100, Loss: 0.279559
#   Epoch 80/100, Loss: 0.277987
#   Epoch 90/100, Loss: 0.275112
#   Epoch 100/100, Loss: 0.264728
# Training complete for run 28
# Run 28 — RMSE: 55.932553, MSE: 3128.450516, NMSE: 0.0103774100
#
# ===== RUN 29/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.282291
#   Epoch 20/100, Loss: 0.281048
#   Epoch 30/100, Loss: 0.280063
#   Epoch 40/100, Loss: 0.279160
#   Epoch 50/100, Loss: 0.278196
#   Epoch 60/100, Loss: 0.277058
#   Epoch 70/100, Loss: 0.275686
#   Epoch 80/100, Loss: 0.274241
#   Epoch 90/100, Loss: 0.273290
#   Epoch 100/100, Loss: 0.273171
# Training complete for run 29
# Run 29 — RMSE: 47.581960, MSE: 2264.042937, NMSE: 0.0091498905
#
# ===== RUN 30/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.284245
#   Epoch 20/100, Loss: 0.284305
#   Epoch 30/100, Loss: 0.284016
#   Epoch 40/100, Loss: 0.283629
#   Epoch 50/100, Loss: 0.283239
#   Epoch 60/100, Loss: 0.282831
#   Epoch 70/100, Loss: 0.282331
#   Epoch 80/100, Loss: 0.281950
#   Epoch 90/100, Loss: 0.282100
#   Epoch 100/100, Loss: 0.282159
# Training complete for run 30
# Run 30 — RMSE: 48.259948, MSE: 2329.022588, NMSE: 0.0096426680
#
# ===== RUN 31/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.273598
#   Epoch 20/100, Loss: 0.255617
#   Epoch 30/100, Loss: 0.166125
#   Epoch 40/100, Loss: 0.157352
#   Epoch 50/100, Loss: 0.171066
#   Epoch 60/100, Loss: 0.173456
#   Epoch 70/100, Loss: 0.149535
#   Epoch 80/100, Loss: 0.146199
#   Epoch 90/100, Loss: 0.146457
#   Epoch 100/100, Loss: 0.106593
# Training complete for run 31
# Run 31 — RMSE: 42.718931, MSE: 1824.907054, NMSE: 0.0094930823
#
# ===== RUN 32/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.282595
#   Epoch 20/100, Loss: 0.281067
#   Epoch 30/100, Loss: 0.279951
#   Epoch 40/100, Loss: 0.279365
#   Epoch 50/100, Loss: 0.278640
#   Epoch 60/100, Loss: 0.277755
#   Epoch 70/100, Loss: 0.276711
#   Epoch 80/100, Loss: 0.275527
#   Epoch 90/100, Loss: 0.274430
#   Epoch 100/100, Loss: 0.273606
# Training complete for run 32
# Run 32 — RMSE: 47.517412, MSE: 2257.904455, NMSE: 0.0093843101
#
# ===== RUN 33/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.280327
#   Epoch 20/100, Loss: 0.277792
#   Epoch 30/100, Loss: 0.274004
#   Epoch 40/100, Loss: 0.264271
#   Epoch 50/100, Loss: 0.232829
#   Epoch 60/100, Loss: 0.193630
#   Epoch 70/100, Loss: 0.162422
#   Epoch 80/100, Loss: 0.178295
#   Epoch 90/100, Loss: 0.170520
#   Epoch 100/100, Loss: 0.150326
# Training complete for run 33
# Run 33 — RMSE: 33.076708, MSE: 1094.068638, NMSE: 0.0068534800
#
# ===== RUN 34/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.288928
#   Epoch 20/100, Loss: 0.285459
#   Epoch 30/100, Loss: 0.283411
#   Epoch 40/100, Loss: 0.282548
#   Epoch 50/100, Loss: 0.281996
#   Epoch 60/100, Loss: 0.281334
#   Epoch 70/100, Loss: 0.280434
#   Epoch 80/100, Loss: 0.279242
#   Epoch 90/100, Loss: 0.277645
#   Epoch 100/100, Loss: 0.275355
# Training complete for run 34
# Run 34 — RMSE: 47.616647, MSE: 2267.345054, NMSE: 0.0094665151
#
# ===== RUN 35/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.282798
#   Epoch 20/100, Loss: 0.281673
#   Epoch 30/100, Loss: 0.281012
#   Epoch 40/100, Loss: 0.280204
#   Epoch 50/100, Loss: 0.277108
#   Epoch 60/100, Loss: 0.274261
#   Epoch 70/100, Loss: 0.270785
#   Epoch 80/100, Loss: 0.252588
#   Epoch 90/100, Loss: 0.218381
#   Epoch 100/100, Loss: 0.271449
# Training complete for run 35
# Run 35 — RMSE: 42.606765, MSE: 1815.336439, NMSE: 0.0105885626
#
# ===== RUN 36/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.285271
#   Epoch 20/100, Loss: 0.282391
#   Epoch 30/100, Loss: 0.280533
#   Epoch 40/100, Loss: 0.279006
#   Epoch 50/100, Loss: 0.276140
#   Epoch 60/100, Loss: 0.268284
#   Epoch 70/100, Loss: 0.248353
#   Epoch 80/100, Loss: 0.233156
#   Epoch 90/100, Loss: 0.218758
#   Epoch 100/100, Loss: 0.196912
# Training complete for run 36
# Run 36 — RMSE: 84.690017, MSE: 7172.398979, NMSE: 0.0192592159
#
# ===== RUN 37/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.283961
#   Epoch 20/100, Loss: 0.283061
#   Epoch 30/100, Loss: 0.281801
#   Epoch 40/100, Loss: 0.280234
#   Epoch 50/100, Loss: 0.278267
#   Epoch 60/100, Loss: 0.275611
#   Epoch 70/100, Loss: 0.271657
#   Epoch 80/100, Loss: 0.265122
#   Epoch 90/100, Loss: 0.253559
#   Epoch 100/100, Loss: 0.237405
# Training complete for run 37
# Run 37 — RMSE: 43.399421, MSE: 1883.509709, NMSE: 0.0088491208
#
# ===== RUN 38/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.284753
#   Epoch 20/100, Loss: 0.283819
#   Epoch 30/100, Loss: 0.283036
#   Epoch 40/100, Loss: 0.282387
#   Epoch 50/100, Loss: 0.281796
#   Epoch 60/100, Loss: 0.281208
#   Epoch 70/100, Loss: 0.280584
#   Epoch 80/100, Loss: 0.279883
#   Epoch 90/100, Loss: 0.279019
#   Epoch 100/100, Loss: 0.277685
# Training complete for run 38
# Run 38 — RMSE: 48.051143, MSE: 2308.912331, NMSE: 0.0096018784
#
# ===== RUN 39/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.283701
#   Epoch 20/100, Loss: 0.283031
#   Epoch 30/100, Loss: 0.282398
#   Epoch 40/100, Loss: 0.281556
#   Epoch 50/100, Loss: 0.263471
#   Epoch 60/100, Loss: 0.271664
#   Epoch 70/100, Loss: 0.238796
#   Epoch 80/100, Loss: 0.198464
#   Epoch 90/100, Loss: 0.171415
#   Epoch 100/100, Loss: 0.183288
# Training complete for run 39
# Run 39 — RMSE: 39.300353, MSE: 1544.517736, NMSE: 0.0091565827
#
# ===== RUN 40/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.283295
#   Epoch 20/100, Loss: 0.278289
#   Epoch 30/100, Loss: 0.275720
#   Epoch 40/100, Loss: 0.260808
#   Epoch 50/100, Loss: 0.227421
#   Epoch 60/100, Loss: 0.193060
#   Epoch 70/100, Loss: 0.175229
#   Epoch 80/100, Loss: 0.186924
#   Epoch 90/100, Loss: 0.179525
#   Epoch 100/100, Loss: 0.176668
# Training complete for run 40
# Run 40 — RMSE: 35.634396, MSE: 1269.810195, NMSE: 0.0078923767
#
# ===== RUN 41/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.283687
#   Epoch 20/100, Loss: 0.281616
#   Epoch 30/100, Loss: 0.280196
#   Epoch 40/100, Loss: 0.278960
#   Epoch 50/100, Loss: 0.277115
#   Epoch 60/100, Loss: 0.274443
#   Epoch 70/100, Loss: 0.271040
#   Epoch 80/100, Loss: 0.267322
#   Epoch 90/100, Loss: 0.262895
#   Epoch 100/100, Loss: 0.256395
# Training complete for run 41
# Run 41 — RMSE: 45.254712, MSE: 2047.988958, NMSE: 0.0082142101
#
# ===== RUN 42/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.283257
#   Epoch 20/100, Loss: 0.280862
#   Epoch 30/100, Loss: 0.278942
#   Epoch 40/100, Loss: 0.277245
#   Epoch 50/100, Loss: 0.275042
#   Epoch 60/100, Loss: 0.269762
#   Epoch 70/100, Loss: 0.220739
#   Epoch 80/100, Loss: 0.158407
#   Epoch 90/100, Loss: 0.161093
#   Epoch 100/100, Loss: 0.185649
# Training complete for run 42
# Run 42 — RMSE: 39.810232, MSE: 1584.854545, NMSE: 0.0111812200
#
# ===== RUN 43/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.281695
#   Epoch 20/100, Loss: 0.292247
#   Epoch 30/100, Loss: 0.281401
#   Epoch 40/100, Loss: 0.280363
#   Epoch 50/100, Loss: 0.294659
#   Epoch 60/100, Loss: 0.248233
#   Epoch 70/100, Loss: 0.265077
#   Epoch 80/100, Loss: 0.244520
#   Epoch 90/100, Loss: 0.246894
#   Epoch 100/100, Loss: 0.199716
# Training complete for run 43
# Run 43 — RMSE: 45.606087, MSE: 2079.915179, NMSE: 0.0122704745
#
# ===== RUN 44/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.285590
#   Epoch 20/100, Loss: 0.283332
#   Epoch 30/100, Loss: 0.282079
#   Epoch 40/100, Loss: 0.281255
#   Epoch 50/100, Loss: 0.280569
#   Epoch 60/100, Loss: 0.279902
#   Epoch 70/100, Loss: 0.279193
#   Epoch 80/100, Loss: 0.278377
#   Epoch 90/100, Loss: 0.277368
#   Epoch 100/100, Loss: 0.276029
# Training complete for run 44
# Run 44 — RMSE: 47.775141, MSE: 2282.464053, NMSE: 0.0095562890
#
# ===== RUN 45/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.282118
#   Epoch 20/100, Loss: 0.278834
#   Epoch 30/100, Loss: 0.271686
#   Epoch 40/100, Loss: 0.263348
#   Epoch 50/100, Loss: 0.277008
#   Epoch 60/100, Loss: 0.251070
#   Epoch 70/100, Loss: 0.245805
#   Epoch 80/100, Loss: 0.237170
#   Epoch 90/100, Loss: 0.215189
#   Epoch 100/100, Loss: 0.170540
# Training complete for run 45
# Run 45 — RMSE: 37.634324, MSE: 1416.342380, NMSE: 0.0077698954
#
# ===== RUN 46/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.283093
#   Epoch 20/100, Loss: 0.282641
#   Epoch 30/100, Loss: 0.282297
#   Epoch 40/100, Loss: 0.281968
#   Epoch 50/100, Loss: 0.281636
#   Epoch 60/100, Loss: 0.281270
#   Epoch 70/100, Loss: 0.280807
#   Epoch 80/100, Loss: 0.280103
#   Epoch 90/100, Loss: 0.278879
#   Epoch 100/100, Loss: 0.276369
# Training complete for run 46
# Run 46 — RMSE: 47.805126, MSE: 2285.330037, NMSE: 0.0094580687
#
# ===== RUN 47/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.283670
#   Epoch 20/100, Loss: 0.282956
#   Epoch 30/100, Loss: 0.282418
#   Epoch 40/100, Loss: 0.281878
#   Epoch 50/100, Loss: 0.281322
#   Epoch 60/100, Loss: 0.280716
#   Epoch 70/100, Loss: 0.280018
#   Epoch 80/100, Loss: 0.279187
#   Epoch 90/100, Loss: 0.278185
#   Epoch 100/100, Loss: 0.276968
# Training complete for run 47
# Run 47 — RMSE: 48.198557, MSE: 2323.100913, NMSE: 0.0095494369
#
# ===== RUN 48/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.283292
#   Epoch 20/100, Loss: 0.282639
#   Epoch 30/100, Loss: 0.282233
#   Epoch 40/100, Loss: 0.281969
#   Epoch 50/100, Loss: 0.281777
#   Epoch 60/100, Loss: 0.281624
#   Epoch 70/100, Loss: 0.281514
#   Epoch 80/100, Loss: 0.281456
#   Epoch 90/100, Loss: 0.281414
#   Epoch 100/100, Loss: 0.281158
# Training complete for run 48
# Run 48 — RMSE: 48.173310, MSE: 2320.667835, NMSE: 0.0095576839
#
# ===== RUN 49/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.282515
#   Epoch 20/100, Loss: 0.282200
#   Epoch 30/100, Loss: 0.282023
#   Epoch 40/100, Loss: 0.281743
#   Epoch 50/100, Loss: 0.280638
#   Epoch 60/100, Loss: 0.270958
#   Epoch 70/100, Loss: 0.200052
#   Epoch 80/100, Loss: 0.223977
#   Epoch 90/100, Loss: 0.223938
#   Epoch 100/100, Loss: 0.217049
# Training complete for run 49
# Run 49 — RMSE: 39.558088, MSE: 1564.842306, NMSE: 0.0074517228
#
# ===== RUN 50/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.280028
#   Epoch 20/100, Loss: 0.279614
#   Epoch 30/100, Loss: 0.269951
#   Epoch 40/100, Loss: 0.241603
#   Epoch 50/100, Loss: 0.207275
#   Epoch 60/100, Loss: 0.186676
#   Epoch 70/100, Loss: 0.190523
#   Epoch 80/100, Loss: 0.189593
#   Epoch 90/100, Loss: 0.205710
#   Epoch 100/100, Loss: 0.221994
# Training complete for run 50
# Run 50 — RMSE: 40.079707, MSE: 1606.382950, NMSE: 0.0094678987
#
# ===== RUN 51/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.284554
#   Epoch 20/100, Loss: 0.282823
#   Epoch 30/100, Loss: 0.281674
#   Epoch 40/100, Loss: 0.280936
#   Epoch 50/100, Loss: 0.280419
#   Epoch 60/100, Loss: 0.279975
#   Epoch 70/100, Loss: 0.279491
#   Epoch 80/100, Loss: 0.278866
#   Epoch 90/100, Loss: 0.277982
#   Epoch 100/100, Loss: 0.276848
# Training complete for run 51
# Run 51 — RMSE: 47.914115, MSE: 2295.762373, NMSE: 0.0094046366
#
# ===== RUN 52/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.280391
#   Epoch 20/100, Loss: 0.279186
#   Epoch 30/100, Loss: 0.277751
#   Epoch 40/100, Loss: 0.275698
#   Epoch 50/100, Loss: 0.272505
#   Epoch 60/100, Loss: 0.267064
#   Epoch 70/100, Loss: 0.256430
#   Epoch 80/100, Loss: 0.234308
#   Epoch 90/100, Loss: 0.207315
#   Epoch 100/100, Loss: 0.160328
# Training complete for run 52
# Run 52 — RMSE: 36.299829, MSE: 1317.677588, NMSE: 0.0078608514
#
# ===== RUN 53/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.281732
#   Epoch 20/100, Loss: 0.280956
#   Epoch 30/100, Loss: 0.280164
#   Epoch 40/100, Loss: 0.279370
#   Epoch 50/100, Loss: 0.278416
#   Epoch 60/100, Loss: 0.277116
#   Epoch 70/100, Loss: 0.275283
#   Epoch 80/100, Loss: 0.272722
#   Epoch 90/100, Loss: 0.269195
#   Epoch 100/100, Loss: 0.264320
# Training complete for run 53
# Run 53 — RMSE: 47.159343, MSE: 2224.003660, NMSE: 0.0093302439
#
# ===== RUN 54/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.281833
#   Epoch 20/100, Loss: 0.279889
#   Epoch 30/100, Loss: 0.277594
#   Epoch 40/100, Loss: 0.274381
#   Epoch 50/100, Loss: 0.269066
#   Epoch 60/100, Loss: 0.260876
#   Epoch 70/100, Loss: 0.251312
#   Epoch 80/100, Loss: 0.239881
#   Epoch 90/100, Loss: 0.222162
#   Epoch 100/100, Loss: 0.205494
# Training complete for run 54
# Run 54 — RMSE: 54.151399, MSE: 2932.374053, NMSE: 0.0120454718
#
# ===== RUN 55/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.281079
#   Epoch 20/100, Loss: 0.278136
#   Epoch 30/100, Loss: 0.272796
#   Epoch 40/100, Loss: 0.259148
#   Epoch 50/100, Loss: 0.181470
#   Epoch 60/100, Loss: 0.188102
#   Epoch 70/100, Loss: 0.181618
#   Epoch 80/100, Loss: 0.169457
#   Epoch 90/100, Loss: 0.157099
#   Epoch 100/100, Loss: 0.164268
# Training complete for run 55
# Run 55 — RMSE: 36.112245, MSE: 1304.094263, NMSE: 0.0094397274
#
# ===== RUN 56/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.281151
#   Epoch 20/100, Loss: 0.279187
#   Epoch 30/100, Loss: 0.275267
#   Epoch 40/100, Loss: 0.263446
#   Epoch 50/100, Loss: 0.185078
#   Epoch 60/100, Loss: 0.180546
#   Epoch 70/100, Loss: 0.184978
#   Epoch 80/100, Loss: 0.184637
#   Epoch 90/100, Loss: 0.179378
#   Epoch 100/100, Loss: 0.162920
# Training complete for run 56
# Run 56 — RMSE: 33.604576, MSE: 1129.267548, NMSE: 0.0054345860
#
# ===== RUN 57/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.283135
#   Epoch 20/100, Loss: 0.282818
#   Epoch 30/100, Loss: 0.282504
#   Epoch 40/100, Loss: 0.282094
#   Epoch 50/100, Loss: 0.281579
#   Epoch 60/100, Loss: 0.280875
#   Epoch 70/100, Loss: 0.279791
#   Epoch 80/100, Loss: 0.277874
#   Epoch 90/100, Loss: 0.273747
#   Epoch 100/100, Loss: 0.261897
# Training complete for run 57
# Run 57 — RMSE: 46.705661, MSE: 2181.418807, NMSE: 0.0092437423
#
# ===== RUN 58/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.285318
#   Epoch 20/100, Loss: 0.284492
#   Epoch 30/100, Loss: 0.283085
#   Epoch 40/100, Loss: 0.281452
#   Epoch 50/100, Loss: 0.279726
#   Epoch 60/100, Loss: 0.277170
#   Epoch 70/100, Loss: 0.269303
#   Epoch 80/100, Loss: 0.213567
#   Epoch 90/100, Loss: 0.276724
#   Epoch 100/100, Loss: 0.230424
# Training complete for run 58
# Run 58 — RMSE: 47.827078, MSE: 2287.429357, NMSE: 0.0092949666
#
# ===== RUN 59/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.284413
#   Epoch 20/100, Loss: 0.283365
#   Epoch 30/100, Loss: 0.278873
#   Epoch 40/100, Loss: 0.261332
#   Epoch 50/100, Loss: 0.247165
#   Epoch 60/100, Loss: 0.233005
#   Epoch 70/100, Loss: 0.222653
#   Epoch 80/100, Loss: 0.236211
#   Epoch 90/100, Loss: 0.226516
#   Epoch 100/100, Loss: 0.219342
# Training complete for run 59
# Run 59 — RMSE: 50.619491, MSE: 2562.332894, NMSE: 0.0092544768
#
# ===== RUN 60/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.280575
#   Epoch 20/100, Loss: 0.279106
#   Epoch 30/100, Loss: 0.277922
#   Epoch 40/100, Loss: 0.276133
#   Epoch 50/100, Loss: 0.272291
#   Epoch 60/100, Loss: 0.263919
#   Epoch 70/100, Loss: 0.254507
#   Epoch 80/100, Loss: 0.224040
#   Epoch 90/100, Loss: 0.334710
#   Epoch 100/100, Loss: 0.272454
# Training complete for run 60
# Run 60 — RMSE: 47.048560, MSE: 2213.566951, NMSE: 0.0096311176
#
# ===== STATS FOR NOISE 0.0% (60 runs) =====
# RMSE: 44.757903 +/- 7.760416
# MSE:  2063.493943 +/- 853.686806
# NMSE: 0.0093956601 +/- 0.0019006778
# Best run: 33 (RMSE: 33.076708)
#
# ================================================================================
# EVALUATING NOISE LEVEL: 0.5% (lambda=0.005, sigma=0.509499)
# ================================================================================
#
# X_train shape: (107, 1, 1), y_train shape: (107,)
#
# ===== RUN 1/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.277473
#   Epoch 20/100, Loss: 0.262134
#   Epoch 30/100, Loss: 0.209675
#   Epoch 40/100, Loss: 0.152122
#   Epoch 50/100, Loss: 0.175742
#   Epoch 60/100, Loss: 0.162514
#   Epoch 70/100, Loss: 0.156544
#   Epoch 80/100, Loss: 0.165934
#   Epoch 90/100, Loss: 0.143235
#   Epoch 100/100, Loss: 0.133249
# Training complete for run 1
# Run 1 — RMSE: 37.226338, MSE: 1385.800214, NMSE: 0.0079590870
#
# ===== RUN 2/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.279646
#   Epoch 20/100, Loss: 0.279142
#   Epoch 30/100, Loss: 0.278747
#   Epoch 40/100, Loss: 0.278315
#   Epoch 50/100, Loss: 0.277749
#   Epoch 60/100, Loss: 0.276769
#   Epoch 70/100, Loss: 0.274516
#   Epoch 80/100, Loss: 0.267836
#   Epoch 90/100, Loss: 0.255244
#   Epoch 100/100, Loss: 0.317784
# Training complete for run 2
# Run 2 — RMSE: 43.672095, MSE: 1907.251908, NMSE: 0.0098170065
#
# ===== RUN 3/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.281997
#   Epoch 20/100, Loss: 0.279281
#   Epoch 30/100, Loss: 0.276990
#   Epoch 40/100, Loss: 0.276061
#   Epoch 50/100, Loss: 0.273494
#   Epoch 60/100, Loss: 0.265147
#   Epoch 70/100, Loss: 0.250546
#   Epoch 80/100, Loss: 0.272171
#   Epoch 90/100, Loss: 0.259250
#   Epoch 100/100, Loss: 0.247910
# Training complete for run 3
# Run 3 — RMSE: 45.299005, MSE: 2051.999897, NMSE: 0.0085477984
#
# ===== RUN 4/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.277391
#   Epoch 20/100, Loss: 0.270050
#   Epoch 30/100, Loss: 0.273995
#   Epoch 40/100, Loss: 0.263128
#   Epoch 50/100, Loss: 0.269649
#   Epoch 60/100, Loss: 0.251162
#   Epoch 70/100, Loss: 0.261908
#   Epoch 80/100, Loss: 0.251722
#   Epoch 90/100, Loss: 0.253133
#   Epoch 100/100, Loss: 0.250391
# Training complete for run 4
# Run 4 — RMSE: 44.957771, MSE: 2021.201202, NMSE: 0.0085016540
#
# ===== RUN 5/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.278843
#   Epoch 20/100, Loss: 0.277947
#   Epoch 30/100, Loss: 0.277135
#   Epoch 40/100, Loss: 0.276160
#   Epoch 50/100, Loss: 0.274702
#   Epoch 60/100, Loss: 0.272121
#   Epoch 70/100, Loss: 0.266596
#   Epoch 80/100, Loss: 0.250621
#   Epoch 90/100, Loss: 0.200603
#   Epoch 100/100, Loss: 0.193136
# Training complete for run 5
# Run 5 — RMSE: 38.132970, MSE: 1454.123391, NMSE: 0.0089789540
#
# ===== RUN 6/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.275972
#   Epoch 20/100, Loss: 0.270234
#   Epoch 30/100, Loss: 0.262992
#   Epoch 40/100, Loss: 0.229978
#   Epoch 50/100, Loss: 0.199853
#   Epoch 60/100, Loss: 0.206272
#   Epoch 70/100, Loss: 0.237064
#   Epoch 80/100, Loss: 0.227822
#   Epoch 90/100, Loss: 0.227124
#   Epoch 100/100, Loss: 0.226262
# Training complete for run 6
# Run 6 — RMSE: 42.128877, MSE: 1774.842306, NMSE: 0.0091489270
#
# ===== RUN 7/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.280819
#   Epoch 20/100, Loss: 0.280307
#   Epoch 30/100, Loss: 0.279479
#   Epoch 40/100, Loss: 0.277282
#   Epoch 50/100, Loss: 0.275527
#   Epoch 60/100, Loss: 0.268448
#   Epoch 70/100, Loss: 0.259891
#   Epoch 80/100, Loss: 0.248499
#   Epoch 90/100, Loss: 0.235667
#   Epoch 100/100, Loss: 0.213366
# Training complete for run 7
# Run 7 — RMSE: 42.492425, MSE: 1805.606210, NMSE: 0.0091807350
#
# ===== RUN 8/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.282056
#   Epoch 20/100, Loss: 0.281116
#   Epoch 30/100, Loss: 0.279925
#   Epoch 40/100, Loss: 0.277569
#   Epoch 50/100, Loss: 0.277871
#   Epoch 60/100, Loss: 0.276150
#   Epoch 70/100, Loss: 0.275704
#   Epoch 80/100, Loss: 0.274401
#   Epoch 90/100, Loss: 0.275545
#   Epoch 100/100, Loss: 0.276842
# Training complete for run 8
# Run 8 — RMSE: 47.534748, MSE: 2259.552297, NMSE: 0.0099658415
#
# ===== RUN 9/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.279186
#   Epoch 20/100, Loss: 0.275351
#   Epoch 30/100, Loss: 0.272055
#   Epoch 40/100, Loss: 0.268663
#   Epoch 50/100, Loss: 0.264116
#   Epoch 60/100, Loss: 0.256134
#   Epoch 70/100, Loss: 0.239249
#   Epoch 80/100, Loss: 0.226861
#   Epoch 90/100, Loss: 0.225692
#   Epoch 100/100, Loss: 0.212416
# Training complete for run 9
# Run 9 — RMSE: 39.788996, MSE: 1583.164236, NMSE: 0.0090143520
#
# ===== RUN 10/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.278716
#   Epoch 20/100, Loss: 0.276836
#   Epoch 30/100, Loss: 0.275216
#   Epoch 40/100, Loss: 0.273445
#   Epoch 50/100, Loss: 0.270630
#   Epoch 60/100, Loss: 0.264021
#   Epoch 70/100, Loss: 0.240522
#   Epoch 80/100, Loss: 0.226640
#   Epoch 90/100, Loss: 0.204816
#   Epoch 100/100, Loss: 0.175711
# Training complete for run 10
# Run 10 — RMSE: 39.769110, MSE: 1581.582120, NMSE: 0.0080880009
#
# ===== RUN 11/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.283707
#   Epoch 20/100, Loss: 0.281196
#   Epoch 30/100, Loss: 0.279938
#   Epoch 40/100, Loss: 0.279159
#   Epoch 50/100, Loss: 0.278596
#   Epoch 60/100, Loss: 0.278130
#   Epoch 70/100, Loss: 0.277679
#   Epoch 80/100, Loss: 0.277162
#   Epoch 90/100, Loss: 0.276493
#   Epoch 100/100, Loss: 0.275535
# Training complete for run 11
# Run 11 — RMSE: 48.022236, MSE: 2306.135149, NMSE: 0.0095644739
#
# ===== RUN 12/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.279870
#   Epoch 20/100, Loss: 0.278966
#   Epoch 30/100, Loss: 0.278271
#   Epoch 40/100, Loss: 0.277626
#   Epoch 50/100, Loss: 0.276920
#   Epoch 60/100, Loss: 0.275866
#   Epoch 70/100, Loss: 0.272920
#   Epoch 80/100, Loss: 0.247722
#   Epoch 90/100, Loss: 0.169069
#   Epoch 100/100, Loss: 0.195146
# Training complete for run 12
# Run 12 — RMSE: 43.730415, MSE: 1912.349225, NMSE: 0.0091435055
#
# ===== RUN 13/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.281671
#   Epoch 20/100, Loss: 0.280081
#   Epoch 30/100, Loss: 0.278848
#   Epoch 40/100, Loss: 0.277885
#   Epoch 50/100, Loss: 0.276630
#   Epoch 60/100, Loss: 0.273660
#   Epoch 70/100, Loss: 0.263619
#   Epoch 80/100, Loss: 0.258380
#   Epoch 90/100, Loss: 0.225821
#   Epoch 100/100, Loss: 0.201030
# Training complete for run 13
# Run 13 — RMSE: 40.033219, MSE: 1602.658653, NMSE: 0.0097831728
#
# ===== RUN 14/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.273687
#   Epoch 20/100, Loss: 0.212027
#   Epoch 30/100, Loss: 0.166713
#   Epoch 40/100, Loss: 0.185408
#   Epoch 50/100, Loss: 0.178283
#   Epoch 60/100, Loss: 0.179944
#   Epoch 70/100, Loss: 0.178307
#   Epoch 80/100, Loss: 0.176245
#   Epoch 90/100, Loss: 0.166733
#   Epoch 100/100, Loss: 0.159926
# Training complete for run 14
# Run 14 — RMSE: 33.868452, MSE: 1147.072040, NMSE: 0.0062366563
#
# ===== RUN 15/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.279262
#   Epoch 20/100, Loss: 0.278081
#   Epoch 30/100, Loss: 0.277373
#   Epoch 40/100, Loss: 0.276603
#   Epoch 50/100, Loss: 0.275532
#   Epoch 60/100, Loss: 0.273494
#   Epoch 70/100, Loss: 0.268474
#   Epoch 80/100, Loss: 0.260236
#   Epoch 90/100, Loss: 0.259776
#   Epoch 100/100, Loss: 0.254472
# Training complete for run 15
# Run 15 — RMSE: 47.435001, MSE: 2250.079335, NMSE: 0.0104282849
#
# ===== RUN 16/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.283130
#   Epoch 20/100, Loss: 0.280692
#   Epoch 30/100, Loss: 0.278848
#   Epoch 40/100, Loss: 0.277103
#   Epoch 50/100, Loss: 0.275035
#   Epoch 60/100, Loss: 0.272240
#   Epoch 70/100, Loss: 0.268787
#   Epoch 80/100, Loss: 0.264648
#   Epoch 90/100, Loss: 0.249807
#   Epoch 100/100, Loss: 0.250758
# Training complete for run 16
# Run 16 — RMSE: 45.364895, MSE: 2057.973731, NMSE: 0.0096941644
#
# ===== RUN 17/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.277341
#   Epoch 20/100, Loss: 0.277384
#   Epoch 30/100, Loss: 0.276836
#   Epoch 40/100, Loss: 0.275714
#   Epoch 50/100, Loss: 0.273249
#   Epoch 60/100, Loss: 0.265961
#   Epoch 70/100, Loss: 0.233485
#   Epoch 80/100, Loss: 0.158808
#   Epoch 90/100, Loss: 0.192629
#   Epoch 100/100, Loss: 0.203871
# Training complete for run 17
# Run 17 — RMSE: 39.495560, MSE: 1559.899268, NMSE: 0.0085832822
#
# ===== RUN 18/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.275456
#   Epoch 20/100, Loss: 0.261024
#   Epoch 30/100, Loss: 0.243873
#   Epoch 40/100, Loss: 0.236673
#   Epoch 50/100, Loss: 0.232985
#   Epoch 60/100, Loss: 0.230597
#   Epoch 70/100, Loss: 0.229288
#   Epoch 80/100, Loss: 0.228226
#   Epoch 90/100, Loss: 0.249019
#   Epoch 100/100, Loss: 0.226121
# Training complete for run 18
# Run 18 — RMSE: 68.322141, MSE: 4667.914972, NMSE: 0.0156462568
#
# ===== RUN 19/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.281600
#   Epoch 20/100, Loss: 0.280749
#   Epoch 30/100, Loss: 0.280017
#   Epoch 40/100, Loss: 0.279359
#   Epoch 50/100, Loss: 0.278685
#   Epoch 60/100, Loss: 0.277913
#   Epoch 70/100, Loss: 0.275285
#   Epoch 80/100, Loss: 0.274629
#   Epoch 90/100, Loss: 0.269051
#   Epoch 100/100, Loss: 0.261676
# Training complete for run 19
# Run 19 — RMSE: 46.559957, MSE: 2167.829622, NMSE: 0.0087662695
#
# ===== RUN 20/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.280030
#   Epoch 20/100, Loss: 0.279071
#   Epoch 30/100, Loss: 0.278029
#   Epoch 40/100, Loss: 0.276897
#   Epoch 50/100, Loss: 0.275456
#   Epoch 60/100, Loss: 0.272681
#   Epoch 70/100, Loss: 0.263711
#   Epoch 80/100, Loss: 0.214726
#   Epoch 90/100, Loss: 0.168223
#   Epoch 100/100, Loss: 0.179981
# Training complete for run 20
# Run 20 — RMSE: 38.095893, MSE: 1451.297040, NMSE: 0.0100716361
#
# ===== RUN 21/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.280533
#   Epoch 20/100, Loss: 0.280055
#   Epoch 30/100, Loss: 0.279413
#   Epoch 40/100, Loss: 0.278736
#   Epoch 50/100, Loss: 0.277994
#   Epoch 60/100, Loss: 0.277113
#   Epoch 70/100, Loss: 0.275962
#   Epoch 80/100, Loss: 0.274258
#   Epoch 90/100, Loss: 0.271222
#   Epoch 100/100, Loss: 0.263959
# Training complete for run 21
# Run 21 — RMSE: 47.246103, MSE: 2232.194239, NMSE: 0.0092594957
#
# ===== RUN 22/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.282243
#   Epoch 20/100, Loss: 0.279838
#   Epoch 30/100, Loss: 0.277853
#   Epoch 40/100, Loss: 0.275795
#   Epoch 50/100, Loss: 0.273705
#   Epoch 60/100, Loss: 0.271308
#   Epoch 70/100, Loss: 0.268247
#   Epoch 80/100, Loss: 0.265505
#   Epoch 90/100, Loss: 0.264585
#   Epoch 100/100, Loss: 0.263349
# Training complete for run 22
# Run 22 — RMSE: 46.646436, MSE: 2175.889998, NMSE: 0.0090369846
#
# ===== RUN 23/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.281328
#   Epoch 20/100, Loss: 0.280204
#   Epoch 30/100, Loss: 0.279553
#   Epoch 40/100, Loss: 0.278917
#   Epoch 50/100, Loss: 0.278161
#   Epoch 60/100, Loss: 0.277234
#   Epoch 70/100, Loss: 0.276098
#   Epoch 80/100, Loss: 0.274763
#   Epoch 90/100, Loss: 0.273428
#   Epoch 100/100, Loss: 0.266720
# Training complete for run 23
# Run 23 — RMSE: 47.023398, MSE: 2211.199938, NMSE: 0.0093953164
#
# ===== RUN 24/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.282455
#   Epoch 20/100, Loss: 0.280132
#   Epoch 30/100, Loss: 0.278878
#   Epoch 40/100, Loss: 0.277878
#   Epoch 50/100, Loss: 0.276700
#   Epoch 60/100, Loss: 0.274556
#   Epoch 70/100, Loss: 0.268716
#   Epoch 80/100, Loss: 0.262298
#   Epoch 90/100, Loss: 0.251748
#   Epoch 100/100, Loss: 0.239217
# Training complete for run 24
# Run 24 — RMSE: 45.291090, MSE: 2051.282858, NMSE: 0.0092759220
#
# ===== RUN 25/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.276158
#   Epoch 20/100, Loss: 0.269910
#   Epoch 30/100, Loss: 0.264714
#   Epoch 40/100, Loss: 0.266596
#   Epoch 50/100, Loss: 0.263902
#   Epoch 60/100, Loss: 0.257733
#   Epoch 70/100, Loss: 0.250842
#   Epoch 80/100, Loss: 0.241648
#   Epoch 90/100, Loss: 0.226319
#   Epoch 100/100, Loss: 0.204729
# Training complete for run 25
# Run 25 — RMSE: 40.266128, MSE: 1621.361053, NMSE: 0.0091149870
#
# ===== RUN 26/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.282213
#   Epoch 20/100, Loss: 0.278610
#   Epoch 30/100, Loss: 0.274860
#   Epoch 40/100, Loss: 0.270775
#   Epoch 50/100, Loss: 0.265653
#   Epoch 60/100, Loss: 0.262685
#   Epoch 70/100, Loss: 0.260782
#   Epoch 80/100, Loss: 0.254068
#   Epoch 90/100, Loss: 0.243845
#   Epoch 100/100, Loss: 0.229818
# Training complete for run 26
# Run 26 — RMSE: 47.158205, MSE: 2223.896285, NMSE: 0.0092110333
#
# ===== RUN 27/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.281911
#   Epoch 20/100, Loss: 0.279559
#   Epoch 30/100, Loss: 0.278089
#   Epoch 40/100, Loss: 0.276158
#   Epoch 50/100, Loss: 0.273841
#   Epoch 60/100, Loss: 0.271573
#   Epoch 70/100, Loss: 0.268994
#   Epoch 80/100, Loss: 0.264861
#   Epoch 90/100, Loss: 0.256189
#   Epoch 100/100, Loss: 0.238486
# Training complete for run 27
# Run 27 — RMSE: 43.686540, MSE: 1908.513799, NMSE: 0.0085867766
#
# ===== RUN 28/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.277883
#   Epoch 20/100, Loss: 0.277316
#   Epoch 30/100, Loss: 0.277450
#   Epoch 40/100, Loss: 0.277522
#   Epoch 50/100, Loss: 0.277445
#   Epoch 60/100, Loss: 0.277105
#   Epoch 70/100, Loss: 0.276371
#   Epoch 80/100, Loss: 0.275026
#   Epoch 90/100, Loss: 0.272446
#   Epoch 100/100, Loss: 0.262898
# Training complete for run 28
# Run 28 — RMSE: 47.190056, MSE: 2226.901364, NMSE: 0.0097073086
#
# ===== RUN 29/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.278997
#   Epoch 20/100, Loss: 0.277778
#   Epoch 30/100, Loss: 0.276862
#   Epoch 40/100, Loss: 0.276072
#   Epoch 50/100, Loss: 0.275267
#   Epoch 60/100, Loss: 0.274339
#   Epoch 70/100, Loss: 0.273213
#   Epoch 80/100, Loss: 0.271921
#   Epoch 90/100, Loss: 0.270782
#   Epoch 100/100, Loss: 0.270305
# Training complete for run 29
# Run 29 — RMSE: 47.565871, MSE: 2262.512085, NMSE: 0.0091306880
#
# ===== RUN 30/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.281028
#   Epoch 20/100, Loss: 0.281083
#   Epoch 30/100, Loss: 0.280785
#   Epoch 40/100, Loss: 0.280397
#   Epoch 50/100, Loss: 0.280021
#   Epoch 60/100, Loss: 0.279656
#   Epoch 70/100, Loss: 0.279262
#   Epoch 80/100, Loss: 0.278882
#   Epoch 90/100, Loss: 0.278777
#   Epoch 100/100, Loss: 0.278804
# Training complete for run 30
# Run 30 — RMSE: 48.228877, MSE: 2326.024588, NMSE: 0.0096285217
#
# ===== RUN 31/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.270865
#   Epoch 20/100, Loss: 0.257339
#   Epoch 30/100, Loss: 0.167896
#   Epoch 40/100, Loss: 0.161673
#   Epoch 50/100, Loss: 0.170780
#   Epoch 60/100, Loss: 0.170146
#   Epoch 70/100, Loss: 0.162222
#   Epoch 80/100, Loss: 0.179534
#   Epoch 90/100, Loss: 0.128995
#   Epoch 100/100, Loss: 0.188126
# Training complete for run 31
# Run 31 — RMSE: 40.037633, MSE: 1603.012040, NMSE: 0.0105458319
#
# ===== RUN 32/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.279337
#   Epoch 20/100, Loss: 0.277788
#   Epoch 30/100, Loss: 0.276706
#   Epoch 40/100, Loss: 0.276127
#   Epoch 50/100, Loss: 0.275386
#   Epoch 60/100, Loss: 0.274518
#   Epoch 70/100, Loss: 0.273508
#   Epoch 80/100, Loss: 0.272402
#   Epoch 90/100, Loss: 0.271451
#   Epoch 100/100, Loss: 0.270856
# Training complete for run 32
# Run 32 — RMSE: 47.502815, MSE: 2256.517418, NMSE: 0.0093291639
#
# ===== RUN 33/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.277053
#   Epoch 20/100, Loss: 0.274584
#   Epoch 30/100, Loss: 0.271063
#   Epoch 40/100, Loss: 0.262422
#   Epoch 50/100, Loss: 0.234917
#   Epoch 60/100, Loss: 0.237262
#   Epoch 70/100, Loss: 0.176378
#   Epoch 80/100, Loss: 0.150612
#   Epoch 90/100, Loss: 0.165071
#   Epoch 100/100, Loss: 0.153160
# Training complete for run 33
# Run 33 — RMSE: 34.314081, MSE: 1177.456165, NMSE: 0.0072987370
#
# ===== RUN 34/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.285723
#   Epoch 20/100, Loss: 0.282165
#   Epoch 30/100, Loss: 0.280096
#   Epoch 40/100, Loss: 0.279281
#   Epoch 50/100, Loss: 0.278802
#   Epoch 60/100, Loss: 0.278225
#   Epoch 70/100, Loss: 0.277412
#   Epoch 80/100, Loss: 0.276318
#   Epoch 90/100, Loss: 0.274862
#   Epoch 100/100, Loss: 0.272820
# Training complete for run 34
# Run 34 — RMSE: 47.644354, MSE: 2269.984483, NMSE: 0.0094488824
#
# ===== RUN 35/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.279464
#   Epoch 20/100, Loss: 0.278304
#   Epoch 30/100, Loss: 0.277569
#   Epoch 40/100, Loss: 0.276280
#   Epoch 50/100, Loss: 0.273757
#   Epoch 60/100, Loss: 0.275640
#   Epoch 70/100, Loss: 0.252419
#   Epoch 80/100, Loss: 0.270745
#   Epoch 90/100, Loss: 0.243005
#   Epoch 100/100, Loss: 0.278753
# Training complete for run 35
# Run 35 — RMSE: 48.284473, MSE: 2331.390373, NMSE: 0.0102609105
#
# ===== RUN 36/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.282079
#   Epoch 20/100, Loss: 0.279235
#   Epoch 30/100, Loss: 0.277505
#   Epoch 40/100, Loss: 0.276212
#   Epoch 50/100, Loss: 0.274106
#   Epoch 60/100, Loss: 0.265103
#   Epoch 70/100, Loss: 0.251708
#   Epoch 80/100, Loss: 0.237706
#   Epoch 90/100, Loss: 0.224960
#   Epoch 100/100, Loss: 0.219801
# Training complete for run 36
# Run 36 — RMSE: 43.409397, MSE: 1884.375748, NMSE: 0.0087983825
#
# ===== RUN 37/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.280765
#   Epoch 20/100, Loss: 0.279847
#   Epoch 30/100, Loss: 0.278605
#   Epoch 40/100, Loss: 0.277115
#   Epoch 50/100, Loss: 0.275303
#   Epoch 60/100, Loss: 0.272929
#   Epoch 70/100, Loss: 0.269512
#   Epoch 80/100, Loss: 0.264079
#   Epoch 90/100, Loss: 0.254704
#   Epoch 100/100, Loss: 0.240075
# Training complete for run 37
# Run 37 — RMSE: 44.231818, MSE: 1956.453767, NMSE: 0.0089460777
#
# ===== RUN 38/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.281455
#   Epoch 20/100, Loss: 0.280513
#   Epoch 30/100, Loss: 0.279735
#   Epoch 40/100, Loss: 0.279099
#   Epoch 50/100, Loss: 0.278527
#   Epoch 60/100, Loss: 0.277960
#   Epoch 70/100, Loss: 0.277351
#   Epoch 80/100, Loss: 0.276637
#   Epoch 90/100, Loss: 0.275619
#   Epoch 100/100, Loss: 0.272663
# Training complete for run 38
# Run 38 — RMSE: 47.907042, MSE: 2295.084701, NMSE: 0.0096598425
#
# ===== RUN 39/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.280388
#   Epoch 20/100, Loss: 0.279680
#   Epoch 30/100, Loss: 0.278996
#   Epoch 40/100, Loss: 0.277839
#   Epoch 50/100, Loss: 0.255864
#   Epoch 60/100, Loss: 0.242520
#   Epoch 70/100, Loss: 0.244478
#   Epoch 80/100, Loss: 0.226740
#   Epoch 90/100, Loss: 0.231224
#   Epoch 100/100, Loss: 0.188125
# Training complete for run 39
# Run 39 — RMSE: 39.188539, MSE: 1535.741587, NMSE: 0.0097013989
#
# ===== RUN 40/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.280089
#   Epoch 20/100, Loss: 0.274949
#   Epoch 30/100, Loss: 0.266320
#   Epoch 40/100, Loss: 0.258507
#   Epoch 50/100, Loss: 0.226554
#   Epoch 60/100, Loss: 0.192734
#   Epoch 70/100, Loss: 0.273600
#   Epoch 80/100, Loss: 0.182389
#   Epoch 90/100, Loss: 0.176490
#   Epoch 100/100, Loss: 0.171856
# Training complete for run 40
# Run 40 — RMSE: 35.392999, MSE: 1252.664357, NMSE: 0.0078312203
#
# ===== RUN 41/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.280443
#   Epoch 20/100, Loss: 0.278409
#   Epoch 30/100, Loss: 0.277095
#   Epoch 40/100, Loss: 0.276006
#   Epoch 50/100, Loss: 0.274419
#   Epoch 60/100, Loss: 0.272144
#   Epoch 70/100, Loss: 0.269184
#   Epoch 80/100, Loss: 0.265873
#   Epoch 90/100, Loss: 0.262270
#   Epoch 100/100, Loss: 0.257357
# Training complete for run 41
# Run 41 — RMSE: 45.697770, MSE: 2088.286214, NMSE: 0.0082870591
#
# ===== RUN 42/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.279919
#   Epoch 20/100, Loss: 0.277523
#   Epoch 30/100, Loss: 0.275630
#   Epoch 40/100, Loss: 0.273961
#   Epoch 50/100, Loss: 0.271733
#   Epoch 60/100, Loss: 0.265796
#   Epoch 70/100, Loss: 0.273433
#   Epoch 80/100, Loss: 0.158649
#   Epoch 90/100, Loss: 0.171485
#   Epoch 100/100, Loss: 0.197859
# Training complete for run 42
# Run 42 — RMSE: 40.165274, MSE: 1613.249224, NMSE: 0.0107597699
#
# ===== RUN 43/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.278270
#   Epoch 20/100, Loss: 0.283230
#   Epoch 30/100, Loss: 0.281186
#   Epoch 40/100, Loss: 0.287623
#   Epoch 50/100, Loss: 0.243595
#   Epoch 60/100, Loss: 0.249286
#   Epoch 70/100, Loss: 0.259556
#   Epoch 80/100, Loss: 0.259205
#   Epoch 90/100, Loss: 0.238998
#   Epoch 100/100, Loss: 0.205258
# Training complete for run 43
# Run 43 — RMSE: 65.571741, MSE: 4299.653232, NMSE: 0.0170554583
#
# ===== RUN 44/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.282311
#   Epoch 20/100, Loss: 0.280013
#   Epoch 30/100, Loss: 0.278751
#   Epoch 40/100, Loss: 0.277930
#   Epoch 50/100, Loss: 0.277253
#   Epoch 60/100, Loss: 0.276600
#   Epoch 70/100, Loss: 0.275907
#   Epoch 80/100, Loss: 0.275109
#   Epoch 90/100, Loss: 0.274124
#   Epoch 100/100, Loss: 0.272814
# Training complete for run 44
# Run 44 — RMSE: 47.733286, MSE: 2278.466624, NMSE: 0.0095303983
#
# ===== RUN 45/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.278887
#   Epoch 20/100, Loss: 0.276400
#   Epoch 30/100, Loss: 0.271785
#   Epoch 40/100, Loss: 0.271463
#   Epoch 50/100, Loss: 0.271586
#   Epoch 60/100, Loss: 0.270949
#   Epoch 70/100, Loss: 0.268817
#   Epoch 80/100, Loss: 0.266499
#   Epoch 90/100, Loss: 0.266471
#   Epoch 100/100, Loss: 0.277276
# Training complete for run 45
# Run 45 — RMSE: 48.858886, MSE: 2387.190701, NMSE: 0.0097985839
#
# ===== RUN 46/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.279786
#   Epoch 20/100, Loss: 0.279317
#   Epoch 30/100, Loss: 0.278973
#   Epoch 40/100, Loss: 0.278655
#   Epoch 50/100, Loss: 0.278344
#   Epoch 60/100, Loss: 0.278007
#   Epoch 70/100, Loss: 0.277585
#   Epoch 80/100, Loss: 0.276977
#   Epoch 90/100, Loss: 0.276024
#   Epoch 100/100, Loss: 0.274287
# Training complete for run 46
# Run 46 — RMSE: 47.851178, MSE: 2289.735215, NMSE: 0.0094338911
#
# ===== RUN 47/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.280383
#   Epoch 20/100, Loss: 0.279662
#   Epoch 30/100, Loss: 0.279133
#   Epoch 40/100, Loss: 0.278626
#   Epoch 50/100, Loss: 0.278128
#   Epoch 60/100, Loss: 0.277605
#   Epoch 70/100, Loss: 0.277019
#   Epoch 80/100, Loss: 0.276335
#   Epoch 90/100, Loss: 0.275521
#   Epoch 100/100, Loss: 0.274540
# Training complete for run 47
# Run 47 — RMSE: 48.167031, MSE: 2320.062902, NMSE: 0.0095229378
#
# ===== RUN 48/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.280027
#   Epoch 20/100, Loss: 0.279349
#   Epoch 30/100, Loss: 0.278926
#   Epoch 40/100, Loss: 0.278649
#   Epoch 50/100, Loss: 0.278447
#   Epoch 60/100, Loss: 0.278287
#   Epoch 70/100, Loss: 0.278175
#   Epoch 80/100, Loss: 0.278114
#   Epoch 90/100, Loss: 0.278080
# ...
#   Epoch 10/100, Loss: 0.220681
#   Epoch 20/100, Loss: 0.216058
#   Epoch 30/100, Loss: 0.213487
#   Epoch 40/100, Loss: 0.213475
#   Epoch 50/100, Loss: 0.213875
#   Epoch 60/100, Loss: 0.213645
#   Epoch 70/100, Loss: 0.213238
#   Epoch 80/100, Loss: 0.212543
#   Epoch 90/100, Loss: 0.211592
#   Epoch 100/100, Loss: 0.210468
# Training complete for run 25
# Run 25 — RMSE: 51.313319, MSE: 2633.056669, NMSE: 0.0100588685
#
# ===== RUN 26/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.224721
#   Epoch 20/100, Loss: 0.221320
#   Epoch 30/100, Loss: 0.218337
#   Epoch 40/100, Loss: 0.214393
#   Epoch 50/100, Loss: 0.212925
#   Epoch 60/100, Loss: 0.210148
#   Epoch 70/100, Loss: 0.207618
#   Epoch 80/100, Loss: 0.204526
#   Epoch 90/100, Loss: 0.199794
#   Epoch 100/100, Loss: 0.189068
# Training complete for run 26
# Run 26 — RMSE: 106.000990, MSE: 11236.209931, NMSE: 0.0139570720
#
# ===== RUN 27/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.222938
#   Epoch 20/100, Loss: 0.221066
#   Epoch 30/100, Loss: 0.219484
#   Epoch 40/100, Loss: 0.216888
#   Epoch 50/100, Loss: 0.211641
#   Epoch 60/100, Loss: 0.206819
#   Epoch 70/100, Loss: 0.200984
#   Epoch 80/100, Loss: 0.191816
#   Epoch 90/100, Loss: 0.175533
#   Epoch 100/100, Loss: 0.152978
# Training complete for run 27
# Run 27 — RMSE: 42.019002, MSE: 1765.596502, NMSE: 0.0096521997
#
# ===== RUN 28/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.220823
#   Epoch 20/100, Loss: 0.219930
#   Epoch 30/100, Loss: 0.219204
#   Epoch 40/100, Loss: 0.218559
#   Epoch 50/100, Loss: 0.218406
#   Epoch 60/100, Loss: 0.218400
#   Epoch 70/100, Loss: 0.218258
#   Epoch 80/100, Loss: 0.217876
#   Epoch 90/100, Loss: 0.217548
#   Epoch 100/100, Loss: 0.217666
# Training complete for run 28
# Run 28 — RMSE: 50.415915, MSE: 2541.764494, NMSE: 0.0103595644
#
# ===== RUN 29/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.221826
#   Epoch 20/100, Loss: 0.221159
#   Epoch 30/100, Loss: 0.220717
#   Epoch 40/100, Loss: 0.220457
#   Epoch 50/100, Loss: 0.220307
#   Epoch 60/100, Loss: 0.220218
#   Epoch 70/100, Loss: 0.220159
#   Epoch 80/100, Loss: 0.220110
#   Epoch 90/100, Loss: 0.220056
#   Epoch 100/100, Loss: 0.219988
# Training complete for run 29
# Run 29 — RMSE: 49.822992, MSE: 2482.330506, NMSE: 0.0098032370
#
# ===== RUN 30/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.223547
#   Epoch 20/100, Loss: 0.223675
#   Epoch 30/100, Loss: 0.223515
#   Epoch 40/100, Loss: 0.223262
#   Epoch 50/100, Loss: 0.223005
#   Epoch 60/100, Loss: 0.222766
#   Epoch 70/100, Loss: 0.222544
#   Epoch 80/100, Loss: 0.222327
#   Epoch 90/100, Loss: 0.222098
#   Epoch 100/100, Loss: 0.221838
# Training complete for run 30
# Run 30 — RMSE: 50.030545, MSE: 2503.055459, NMSE: 0.0099262425
#
# ===== RUN 31/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.216011
#   Epoch 20/100, Loss: 0.217551
#   Epoch 30/100, Loss: 0.210244
#   Epoch 40/100, Loss: 0.196599
#   Epoch 50/100, Loss: 0.171651
#   Epoch 60/100, Loss: 0.153962
#   Epoch 70/100, Loss: 0.183668
#   Epoch 80/100, Loss: 0.145879
#   Epoch 90/100, Loss: 0.168253
#   Epoch 100/100, Loss: 0.201743
# Training complete for run 31
# Run 31 — RMSE: 47.215315, MSE: 2229.285933, NMSE: 0.0102731204
#
# ===== RUN 32/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.221801
#   Epoch 20/100, Loss: 0.220777
#   Epoch 30/100, Loss: 0.220018
#   Epoch 40/100, Loss: 0.219594
#   Epoch 50/100, Loss: 0.219189
#   Epoch 60/100, Loss: 0.218741
#   Epoch 70/100, Loss: 0.218265
#   Epoch 80/100, Loss: 0.217726
#   Epoch 90/100, Loss: 0.217027
#   Epoch 100/100, Loss: 0.215953
# Training complete for run 32
# Run 32 — RMSE: 49.353007, MSE: 2435.719258, NMSE: 0.0097450909
#
# ===== RUN 33/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.220079
#   Epoch 20/100, Loss: 0.218691
#   Epoch 30/100, Loss: 0.217483
#   Epoch 40/100, Loss: 0.215887
#   Epoch 50/100, Loss: 0.213166
#   Epoch 60/100, Loss: 0.207669
#   Epoch 70/100, Loss: 0.196293
#   Epoch 80/100, Loss: 0.182406
#   Epoch 90/100, Loss: 0.174842
#   Epoch 100/100, Loss: 0.167003
# Training complete for run 33
# Run 33 — RMSE: 40.662828, MSE: 1653.465612, NMSE: 0.0082314472
#
# ===== RUN 34/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.227822
#   Epoch 20/100, Loss: 0.224710
#   Epoch 30/100, Loss: 0.222689
#   Epoch 40/100, Loss: 0.221725
#   Epoch 50/100, Loss: 0.221298
#   Epoch 60/100, Loss: 0.221040
#   Epoch 70/100, Loss: 0.220810
#   Epoch 80/100, Loss: 0.220572
#   Epoch 90/100, Loss: 0.220315
#   Epoch 100/100, Loss: 0.220031
# Training complete for run 34
# Run 34 — RMSE: 49.771111, MSE: 2477.163469, NMSE: 0.0098404181
#
# ===== RUN 35/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.221709
#   Epoch 20/100, Loss: 0.219520
#   Epoch 30/100, Loss: 0.218160
#   Epoch 40/100, Loss: 0.217495
#   Epoch 50/100, Loss: 0.214932
#   Epoch 60/100, Loss: 0.212623
#   Epoch 70/100, Loss: 0.206893
#   Epoch 80/100, Loss: 0.198710
#   Epoch 90/100, Loss: 0.188936
#   Epoch 100/100, Loss: 0.179721
# Training complete for run 35
# Run 35 — RMSE: 104.728984, MSE: 10968.160076, NMSE: 0.0136251463
#
# ===== RUN 36/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.224799
#   Epoch 20/100, Loss: 0.222861
#   Epoch 30/100, Loss: 0.221862
#   Epoch 40/100, Loss: 0.221317
#   Epoch 50/100, Loss: 0.220853
#   Epoch 60/100, Loss: 0.220223
#   Epoch 70/100, Loss: 0.219052
#   Epoch 80/100, Loss: 0.216058
#   Epoch 90/100, Loss: 0.208717
#   Epoch 100/100, Loss: 0.205556
# Training complete for run 36
# Run 36 — RMSE: 48.931748, MSE: 2394.315935, NMSE: 0.0096942567
#
# ===== RUN 37/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.223232
#   Epoch 20/100, Loss: 0.222473
#   Epoch 30/100, Loss: 0.221765
#   Epoch 40/100, Loss: 0.221035
#   Epoch 50/100, Loss: 0.220309
#   Epoch 60/100, Loss: 0.219551
#   Epoch 70/100, Loss: 0.218700
#   Epoch 80/100, Loss: 0.217668
#   Epoch 90/100, Loss: 0.216317
#   Epoch 100/100, Loss: 0.214399
# Training complete for run 37
# Run 37 — RMSE: 49.183670, MSE: 2419.033441, NMSE: 0.0098767905
#
# ===== RUN 38/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.223442
#   Epoch 20/100, Loss: 0.222902
#   Epoch 30/100, Loss: 0.222469
#   Epoch 40/100, Loss: 0.222126
#   Epoch 50/100, Loss: 0.221845
#   Epoch 60/100, Loss: 0.221605
#   Epoch 70/100, Loss: 0.221392
#   Epoch 80/100, Loss: 0.221198
#   Epoch 90/100, Loss: 0.221015
#   Epoch 100/100, Loss: 0.220836
# Training complete for run 38
# Run 38 — RMSE: 49.898091, MSE: 2489.819455, NMSE: 0.0098916472
#
# ===== RUN 39/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.222190
#   Epoch 20/100, Loss: 0.221091
#   Epoch 30/100, Loss: 0.235840
#   Epoch 40/100, Loss: 0.264553
#   Epoch 50/100, Loss: 0.220757
#   Epoch 60/100, Loss: 0.214943
#   Epoch 70/100, Loss: 0.214446
#   Epoch 80/100, Loss: 0.213737
#   Epoch 90/100, Loss: 0.213891
#   Epoch 100/100, Loss: 0.214211
# Training complete for run 39
# Run 39 — RMSE: 49.872723, MSE: 2487.288476, NMSE: 0.0097713723
#
# ===== RUN 40/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.223402
#   Epoch 20/100, Loss: 0.217457
#   Epoch 30/100, Loss: 0.215887
#   Epoch 40/100, Loss: 0.213766
#   Epoch 50/100, Loss: 0.217864
#   Epoch 60/100, Loss: 0.214369
#   Epoch 70/100, Loss: 0.204224
#   Epoch 80/100, Loss: 0.165885
#   Epoch 90/100, Loss: 0.138201
#   Epoch 100/100, Loss: 0.133375
# Training complete for run 40
# Run 40 — RMSE: 39.130628, MSE: 1531.206067, NMSE: 0.0099072204
#
# ===== RUN 41/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.223095
#   Epoch 20/100, Loss: 0.221680
#   Epoch 30/100, Loss: 0.220841
#   Epoch 40/100, Loss: 0.220428
#   Epoch 50/100, Loss: 0.220129
#   Epoch 60/100, Loss: 0.219797
#   Epoch 70/100, Loss: 0.219414
#   Epoch 80/100, Loss: 0.218955
#   Epoch 90/100, Loss: 0.218379
#   Epoch 100/100, Loss: 0.217629
# Training complete for run 41
# Run 41 — RMSE: 49.369245, MSE: 2437.322394, NMSE: 0.0095117630
#
# ===== RUN 42/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.221897
#   Epoch 20/100, Loss: 0.220601
#   Epoch 30/100, Loss: 0.219482
#   Epoch 40/100, Loss: 0.218458
#   Epoch 50/100, Loss: 0.217178
#   Epoch 60/100, Loss: 0.214662
#   Epoch 70/100, Loss: 0.197629
#   Epoch 80/100, Loss: 0.160723
#   Epoch 90/100, Loss: 0.136038
#   Epoch 100/100, Loss: 0.171345
# Training complete for run 42
# Run 42 — RMSE: 42.743972, MSE: 1827.047122, NMSE: 0.0107807686
#
# ===== RUN 43/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.221123
#   Epoch 20/100, Loss: 0.212838
#   Epoch 30/100, Loss: 0.210491
#   Epoch 40/100, Loss: 0.207966
#   Epoch 50/100, Loss: 0.218877
#   Epoch 60/100, Loss: 0.200828
#   Epoch 70/100, Loss: 0.203600
#   Epoch 80/100, Loss: 0.198408
#   Epoch 90/100, Loss: 0.196307
#   Epoch 100/100, Loss: 0.200517
# Training complete for run 43
# Run 43 — RMSE: 48.504342, MSE: 2352.671194, NMSE: 0.0095039522
#
# ===== RUN 44/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.224212
#   Epoch 20/100, Loss: 0.222139
#   Epoch 30/100, Loss: 0.220774
#   Epoch 40/100, Loss: 0.219594
#   Epoch 50/100, Loss: 0.218155
#   Epoch 60/100, Loss: 0.215720
#   Epoch 70/100, Loss: 0.209944
#   Epoch 80/100, Loss: 0.195001
#   Epoch 90/100, Loss: 0.183314
#   Epoch 100/100, Loss: 0.196017
# Training complete for run 44
# Run 44 — RMSE: 52.191308, MSE: 2723.932675, NMSE: 0.0103197543
#
# ===== RUN 45/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.220925
#   Epoch 20/100, Loss: 0.218607
#   Epoch 30/100, Loss: 0.216324
#   Epoch 40/100, Loss: 0.217706
#   Epoch 50/100, Loss: 0.217241
#   Epoch 60/100, Loss: 0.216833
#   Epoch 70/100, Loss: 0.216423
#   Epoch 80/100, Loss: 0.215973
#   Epoch 90/100, Loss: 0.215446
#   Epoch 100/100, Loss: 0.214804
# Training complete for run 45
# Run 45 — RMSE: 50.223169, MSE: 2522.366742, NMSE: 0.0104764463
#
# ===== RUN 46/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.221913
#   Epoch 20/100, Loss: 0.221451
#   Epoch 30/100, Loss: 0.221079
#   Epoch 40/100, Loss: 0.220675
#   Epoch 50/100, Loss: 0.220132
#   Epoch 60/100, Loss: 0.219229
#   Epoch 70/100, Loss: 0.217427
#   Epoch 80/100, Loss: 0.219239
#   Epoch 90/100, Loss: 0.233168
#   Epoch 100/100, Loss: 0.212848
# Training complete for run 46
# Run 46 — RMSE: 77.011426, MSE: 5930.759668, NMSE: 0.0123563671
#
# ===== RUN 47/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.222536
#   Epoch 20/100, Loss: 0.222025
#   Epoch 30/100, Loss: 0.221728
#   Epoch 40/100, Loss: 0.221529
#   Epoch 50/100, Loss: 0.221378
#   Epoch 60/100, Loss: 0.221250
#   Epoch 70/100, Loss: 0.221128
#   Epoch 80/100, Loss: 0.221003
#   Epoch 90/100, Loss: 0.220868
#   Epoch 100/100, Loss: 0.220715
# Training complete for run 47
# Run 47 — RMSE: 49.864212, MSE: 2486.439632, NMSE: 0.0098208854
#
# ===== RUN 48/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.222623
#   Epoch 20/100, Loss: 0.222077
#   Epoch 30/100, Loss: 0.221650
#   Epoch 40/100, Loss: 0.221310
#   Epoch 50/100, Loss: 0.221034
#   Epoch 60/100, Loss: 0.220796
#   Epoch 70/100, Loss: 0.220546
#   Epoch 80/100, Loss: 0.220039
#   Epoch 90/100, Loss: 0.213241
#   Epoch 100/100, Loss: 0.216590
# Training complete for run 48
# Run 48 — RMSE: 51.851425, MSE: 2688.570232, NMSE: 0.0099546114
#
# ===== RUN 49/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.221706
#   Epoch 20/100, Loss: 0.221323
#   Epoch 30/100, Loss: 0.221051
#   Epoch 40/100, Loss: 0.220838
#   Epoch 50/100, Loss: 0.220612
#   Epoch 60/100, Loss: 0.220152
#   Epoch 70/100, Loss: 0.218927
#   Epoch 80/100, Loss: 0.215328
#   Epoch 90/100, Loss: 0.209483
#   Epoch 100/100, Loss: 0.200637
# Training complete for run 49
# Run 49 — RMSE: 53.117827, MSE: 2821.503531, NMSE: 0.0111910635
#
# ===== RUN 50/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.218725
#   Epoch 20/100, Loss: 0.217287
#   Epoch 30/100, Loss: 0.215019
#   Epoch 40/100, Loss: 0.208795
#   Epoch 50/100, Loss: 0.202169
#   Epoch 60/100, Loss: 0.196087
#   Epoch 70/100, Loss: 0.189547
#   Epoch 80/100, Loss: 0.182832
#   Epoch 90/100, Loss: 0.178181
#   Epoch 100/100, Loss: 0.172673
# Training complete for run 50
# Run 50 — RMSE: 44.053155, MSE: 1940.680467, NMSE: 0.0097618043
#
# ===== RUN 51/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.223099
#   Epoch 20/100, Loss: 0.222189
#   Epoch 30/100, Loss: 0.221532
#   Epoch 40/100, Loss: 0.221091
#   Epoch 50/100, Loss: 0.220819
#   Epoch 60/100, Loss: 0.220658
#   Epoch 70/100, Loss: 0.220559
#   Epoch 80/100, Loss: 0.220483
#   Epoch 90/100, Loss: 0.220402
#   Epoch 100/100, Loss: 0.220292
# Training complete for run 51
# Run 51 — RMSE: 49.909991, MSE: 2491.007165, NMSE: 0.0098960295
#
# ===== RUN 52/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.220121
#   Epoch 20/100, Loss: 0.219036
#   Epoch 30/100, Loss: 0.217833
#   Epoch 40/100, Loss: 0.216039
#   Epoch 50/100, Loss: 0.212978
#   Epoch 60/100, Loss: 0.207104
#   Epoch 70/100, Loss: 0.199055
#   Epoch 80/100, Loss: 0.199181
#   Epoch 90/100, Loss: 0.194993
#   Epoch 100/100, Loss: 0.187758
# Training complete for run 52
# Run 52 — RMSE: 46.894447, MSE: 2199.089143, NMSE: 0.0095680044
#
# ===== RUN 53/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.220967
#   Epoch 20/100, Loss: 0.220373
#   Epoch 30/100, Loss: 0.220115
#   Epoch 40/100, Loss: 0.220068
#   Epoch 50/100, Loss: 0.220104
#   Epoch 60/100, Loss: 0.220158
#   Epoch 70/100, Loss: 0.220188
#   Epoch 80/100, Loss: 0.220162
#   Epoch 90/100, Loss: 0.220048
#   Epoch 100/100, Loss: 0.219800
# Training complete for run 53
# Run 53 — RMSE: 49.757326, MSE: 2475.791449, NMSE: 0.0097989682
#
# ===== RUN 54/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.221114
#   Epoch 20/100, Loss: 0.219754
#   Epoch 30/100, Loss: 0.217971
#   Epoch 40/100, Loss: 0.215894
#   Epoch 50/100, Loss: 0.212882
#   Epoch 60/100, Loss: 0.207762
#   Epoch 70/100, Loss: 0.199363
#   Epoch 80/100, Loss: 0.189417
#   Epoch 90/100, Loss: 0.183734
#   Epoch 100/100, Loss: 0.181749
# Training complete for run 54
# Run 54 — RMSE: 49.270442, MSE: 2427.576496, NMSE: 0.0101564701
#
# ===== RUN 55/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.220156
#   Epoch 20/100, Loss: 0.217708
#   Epoch 30/100, Loss: 0.213772
#   Epoch 40/100, Loss: 0.181771
#   Epoch 50/100, Loss: 0.129197
#   Epoch 60/100, Loss: 0.124771
#   Epoch 70/100, Loss: 0.121182
#   Epoch 80/100, Loss: 0.114805
#   Epoch 90/100, Loss: 0.108316
#   Epoch 100/100, Loss: 0.103672
# Training complete for run 55
# Run 55 — RMSE: 38.235188, MSE: 1461.929577, NMSE: 0.0075268990
#
# ===== RUN 56/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.220877
#   Epoch 20/100, Loss: 0.220038
#   Epoch 30/100, Loss: 0.219039
#   Epoch 40/100, Loss: 0.217654
#   Epoch 50/100, Loss: 0.215149
#   Epoch 60/100, Loss: 0.207802
#   Epoch 70/100, Loss: 0.172321
#   Epoch 80/100, Loss: 0.149465
#   Epoch 90/100, Loss: 0.148675
#   Epoch 100/100, Loss: 0.145750
# Training complete for run 56
# Run 56 — RMSE: 39.009563, MSE: 1521.746029, NMSE: 0.0078959274
#
# ===== RUN 57/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.221781
#   Epoch 20/100, Loss: 0.221413
#   Epoch 30/100, Loss: 0.221385
#   Epoch 40/100, Loss: 0.221530
#   Epoch 50/100, Loss: 0.221660
#   Epoch 60/100, Loss: 0.221739
#   Epoch 70/100, Loss: 0.221778
#   Epoch 80/100, Loss: 0.221783
#   Epoch 90/100, Loss: 0.221753
#   Epoch 100/100, Loss: 0.221683
# Training complete for run 57
# Run 57 — RMSE: 49.973444, MSE: 2497.345144, NMSE: 0.0098443804
#
# ===== RUN 58/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.223107
#   Epoch 20/100, Loss: 0.222797
#   Epoch 30/100, Loss: 0.222207
#   Epoch 40/100, Loss: 0.221376
#   Epoch 50/100, Loss: 0.219901
#   Epoch 60/100, Loss: 0.215102
#   Epoch 70/100, Loss: 0.207767
#   Epoch 80/100, Loss: 0.197988
#   Epoch 90/100, Loss: 0.182520
#   Epoch 100/100, Loss: 0.199872
# Training complete for run 58
# Run 58 — RMSE: 45.987012, MSE: 2114.805267, NMSE: 0.0095523747
#
# ===== RUN 59/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.223482
#   Epoch 20/100, Loss: 0.222305
#   Epoch 30/100, Loss: 0.212255
#   Epoch 40/100, Loss: 0.215289
#   Epoch 50/100, Loss: 0.214586
#   Epoch 60/100, Loss: 0.213831
#   Epoch 70/100, Loss: 0.213121
#   Epoch 80/100, Loss: 0.212009
#   Epoch 90/100, Loss: 0.208337
#   Epoch 100/100, Loss: 0.205577
# Training complete for run 59
# Run 59 — RMSE: 47.285604, MSE: 2235.928299, NMSE: 0.0099211307
#
# ===== RUN 60/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.220775
#   Epoch 20/100, Loss: 0.219201
#   Epoch 30/100, Loss: 0.218087
#   Epoch 40/100, Loss: 0.216826
#   Epoch 50/100, Loss: 0.215061
#   Epoch 60/100, Loss: 0.212606
#   Epoch 70/100, Loss: 0.212209
#   Epoch 80/100, Loss: 0.211472
#   Epoch 90/100, Loss: 0.209826
#   Epoch 100/100, Loss: 0.202379
# Training complete for run 60
# Run 60 — RMSE: 47.069333, MSE: 2215.522108, NMSE: 0.0096357109
#
# ===== STATS FOR NOISE 10.0% (60 runs) =====
# RMSE: 51.753248 +/- 13.807961
# MSE:  2869.058474 +/- 2002.858894
# NMSE: 0.0099919413 +/- 0.0012482229
# Best run: 55 (RMSE: 38.235188)

# %% [markdown]
# ## Results

# %%
# ============================================================
# Final Metrics Summary & Plots per Noise Level
# ============================================================
from tabulate import tabulate

for entry in _molab_results:
    lam = entry[0]
    mean_rmse, std_rmse = entry[1], entry[2]
    mean_mse, std_mse = entry[3], entry[4]
    mean_nmse, std_nmse = entry[5], entry[6]
    best_rmse_val = entry[7]
    best_predictions = entry[8]
    best_losses = entry[9]
    raw_values_for_plot = entry[10]
    
    print("\n" + "="*80)
    print(f"RESULTS FOR NOISE LEVEL: {lam*100:.1f}%")
    print("="*80)
    
    print(f'Mean RMSE: {mean_rmse:.6f} +/- {std_rmse:.6f}')
    print(f'Mean MSE:  {mean_mse:.6f} +/- {std_mse:.6f}')
    print(f'Mean NMSE: {mean_nmse:.10f} +/- {std_nmse:.10f}')
    print(f'Best RMSE: {best_rmse_val:.6f}')
    
    actual = raw_values_for_plot[-60:]
    
    plt.figure(figsize=(12, 5))
    plt.plot(actual, label='Actual', color='blue', linewidth=1.5)
    plt.plot(best_predictions, label='Predicted (Best Run)', color='red',
             linewidth=1.5, linestyle='--')
    plt.title(f'Predictions vs Actual (Noise {lam*100:.1f}%)')
    plt.xlabel('Time Step')
    plt.ylabel('Value')
    plt.legend()
    plt.grid(True, alpha=0.3)
    plt.tight_layout()
    plt.show()

    plt.figure(figsize=(12, 4))
    plt.plot(best_losses, color='green', linewidth=1.0)
    plt.title(f'Training Loss (Best Run, Noise {lam*100:.1f}%)')
    plt.xlabel('Epoch')
    plt.ylabel('MSE Loss')
    plt.grid(True, alpha=0.3)
    plt.tight_layout()
    plt.show()

print("\n" + "="*80)
print("FINAL RESULTS TABLE ACROSS ALL NOISE LEVELS")
print("="*80)
df_res = pd.DataFrame(
    [[r[0], f'{r[1]:.6f} +/- {r[2]:.6f}', f'{r[3]:.6f} +/- {r[4]:.6f}', 
      f'{r[5]:.10f} +/- {r[6]:.10f}', f'{r[7]:.6f}'] for r in _molab_results],
    columns=['Noise Level', 'RMSE (mean+/-std)', 'MSE (mean+/-std)', 'NMSE (mean+/-std)', 'Best RMSE']
)
print(tabulate(df_res, headers='keys', tablefmt='github', showindex=False))
# Out:
# ================================================================================
# RESULTS FOR NOISE LEVEL: 0.0%
# ================================================================================
# Mean RMSE: 44.757903 +/- 7.760416
# Mean MSE:  2063.493943 +/- 853.686806
# Mean NMSE: 0.0093956601 +/- 0.0019006778
# Best RMSE: 33.076708
# ================================================================================
# RESULTS FOR NOISE LEVEL: 0.5%
# ================================================================================
# Mean RMSE: 44.409790 +/- 6.138942
# Mean MSE:  2009.916028 +/- 596.950388
# Mean NMSE: 0.0093397666 +/- 0.0015696530
# Best RMSE: 33.868452
# ================================================================================
# RESULTS FOR NOISE LEVEL: 5.0%
# ================================================================================
# Mean RMSE: 46.132896 +/- 7.377555
# Mean MSE:  2182.672399 +/- 789.289100
# Mean NMSE: 0.0093135002 +/- 0.0010980244
# Best RMSE: 33.037418
# ================================================================================
# RESULTS FOR NOISE LEVEL: 10.0%
# ================================================================================
# Mean RMSE: 51.753248 +/- 13.807961
# Mean MSE:  2869.058474 +/- 2002.858894
# Mean NMSE: 0.0099919413 +/- 0.0012482229
# Best RMSE: 38.235188
# ================================================================================
# FINAL RESULTS TABLE ACROSS ALL NOISE LEVELS
# ================================================================================
# |   Noise Level | RMSE (mean+/-std)       | MSE (mean+/-std)            | NMSE (mean+/-std)             |   Best RMSE |
# |---------------|-------------------------|-----------------------------|-------------------------------|-------------|
# |         0     | 44.757903 +/- 7.760416  | 2063.493943 +/- 853.686806  | 0.0093956601 +/- 0.0019006778 |     33.0767 |
# |         0.005 | 44.409790 +/- 6.138942  | 2009.916028 +/- 596.950388  | 0.0093397666 +/- 0.0015696530 |     33.8685 |
# |         0.05  | 46.132896 +/- 7.377555  | 2182.672399 +/- 789.289100  | 0.0093135002 +/- 0.0010980244 |     33.0374 |
# |         0.1   | 51.753248 +/- 13.807961 | 2869.058474 +/- 2002.858894 | 0.0099919413 +/- 0.0012482229 |     38.2352 |
