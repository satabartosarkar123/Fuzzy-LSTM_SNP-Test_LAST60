# %% [markdown]
# # Notebook 4: LSTM-SNP with Fuzzy Output Layer
#
# **Dataset**: Dow Jones Industrial Index
#
# ## Description
# This notebook implements a **fuzzy output layer** for the LSTM-SNP model. The internal
# LSTM-SNP structure is kept completely intact. The final Dense(1) layer is replaced with a
# fuzzy inference system that takes the RNN hidden state h(t) and produces the prediction
# through Takagi-Sugeno rules.
#
# The fuzzy output layer aggregates h(t) into 2 summary features via mean-pooling, then applies
# 4 rules with fixed Gaussian membership functions and trainable consequent parameters.

# %% [markdown]
# ## Theory: Fuzzy Output Layer
#
# ### LSTM-SNP Cell (Unchanged)
# All internal LSTM-SNP equations remain exactly as in the baseline.
#
# ### Fuzzy Output Computation
# The Dense(1) output layer is replaced with fuzzy inference:
#
# **Input**: $h(t) \in \mathbb{R}^{units}$ from the RNN
#
# **Feature Aggregation**: Mean-pooling into 2 summary statistics:
# - $s_1 = \text{mean}(h_{1:units/2})$
# - $s_2 = \text{mean}(h_{units/2+1:units})$
#
# **Membership Functions** (Fixed Gaussian):
# - $\mu_{low}(s) = \exp\left(-\frac{(s-(-1))^2}{2 \cdot 0.5^2}\right)$
# - $\mu_{high}(s) = \exp\left(-\frac{(s-(+1))^2}{2 \cdot 0.5^2}\right)$
#
# **4 Takagi-Sugeno Rules** (trainable consequents):
# $y_i = a_i s_1 + b_i s_2 + c_i$
#
# **Defuzzification**: $\hat{y} = \frac{\sum_i w_i y_i}{\sum_i w_i}$

# %% [markdown]
# ## Model Architecture & Implementation

# %%
# ============================================================
# ALL IMPORTS
# ============================================================

import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras import layers
from tensorflow.keras import Model
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from math import sqrt
import matplotlib.pyplot as plt
import warnings
import os

warnings.filterwarnings('ignore')
print(f"TensorFlow version: {tf.__version__}")
print(f"NumPy version: {np.__version__}")
# Out:
# TensorFlow version: 2.20.0
# NumPy version: 2.0.2

# %% [markdown]
# ### LSTM-SNP Cell

# %%
# ============================================================
# LSTM-SNP Cell (Original — Unmodified)
# ============================================================

class LSTMSNPCell(layers.Layer):
    """
    LSTM-SNP Cell: A long short-term memory model inspired from
    spiking neural P systems.

    Gates:
      r(t) = ρ(W_r x(t) + U_r u(t-1) + b_r)   [reset]
      c(t) = ρ(W_c x(t) + U_c u(t-1) + b_c)   [consumption]
      o(t) = ρ(W_o x(t) + U_o u(t-1) + b_o)   [output/generation]
      a(t) = f(W_a x(t) + U_a u(t-1) + b_a)   [generated spikes]

    State update:
      u(t) = r(t) * u(t-1) - c(t) * a(t)
      h(t) = o(t) * a(t)

    ρ = hard_sigmoid, f = tanh
    """
    def __init__(self, units,
                 activation='tanh',
                 recurrent_activation='hard_sigmoid',
                 **kwargs):
        super().__init__(**kwargs)
        self.units = units
        self.state_size = units
        self.output_size = units

        self.activation = tf.keras.activations.get(activation)
        self.recurrent_activation = tf.keras.activations.get(recurrent_activation)

    def build(self, input_shape):
        input_dim = input_shape[-1]

        self.kernel = self.add_weight(
            shape=(input_dim, self.units * 4),
            initializer='glorot_uniform',
            name='kernel'
        )
        self.recurrent_kernel = self.add_weight(
            shape=(self.units, self.units * 4),
            initializer='orthogonal',
            name='recurrent_kernel'
        )
        self.bias = self.add_weight(
            shape=(self.units * 4,),
            initializer='zeros',
            name='bias'
        )

    def call(self, inputs, states):
        u_tm1 = states[0]

        z = tf.matmul(inputs, self.kernel) + \
            tf.matmul(u_tm1, self.recurrent_kernel) + self.bias

        z0 = z[:, :self.units]
        z1 = z[:, self.units:2*self.units]
        z2 = z[:, 2*self.units:3*self.units]
        z3 = z[:, 3*self.units:]

        r = self.recurrent_activation(z0)  # reset
        c = self.recurrent_activation(z1)  # consumption
        o = self.recurrent_activation(z2)  # output/generation
        a = self.activation(z3)            # generated spikes

        u = r * u_tm1 - c * a  # internal state
        h = o * a              # output

        return h, [u]

    def get_config(self):
        config = super().get_config()
        config.update({
            'units': self.units,
        })
        return config

# %% [markdown]
# ### Fuzzy Output Layer

# %%
# ============================================================
# Fuzzy Output Layer
# Replaces Dense(1) with fuzzy inference.
#
# Takes RNN output h(t) ∈ R^units, produces scalar prediction.
# Aggregates h(t) into 2 summary features via mean-pooling:
#   s1 = mean(h[:units//2])
#   s2 = mean(h[units//2:])
#
# Then applies 4 Takagi-Sugeno rules.
# Fixed Gaussian MFs. Trainable consequent parameters.
# ============================================================

class FuzzyOutputLayer(layers.Layer):
    """
    Fuzzy output layer: replaces Dense(1).
    Input: h(t) from RNN (shape: [batch, units])
    Output: scalar prediction (shape: [batch, 1])
    """
    def __init__(self, units_in, **kwargs):
        super().__init__(**kwargs)
        self.units_in = units_in
        self.mu_low = -1.0
        self.mu_high = 1.0
        self.sigma = 0.5

    def build(self, input_shape):
        # 4 rules, each with 3 consequent params (a, b, c)
        # y_i = a_i * s1 + b_i * s2 + c_i
        self.rule_a = self.add_weight(shape=(4,), initializer='glorot_uniform', name='rule_a')
        self.rule_b = self.add_weight(shape=(4,), initializer='glorot_uniform', name='rule_b')
        self.rule_c = self.add_weight(shape=(4,), initializer='zeros', name='rule_c')

    def _gaussian_mf(self, x, center):
        return tf.exp(-tf.square(x - center) / (2.0 * self.sigma ** 2))

    def call(self, inputs):
        half = self.units_in // 2
        # Aggregate to 2 summary features
        s1 = tf.reduce_mean(inputs[:, :half], axis=-1, keepdims=True)  # [batch, 1]
        s2 = tf.reduce_mean(inputs[:, half:], axis=-1, keepdims=True)  # [batch, 1]

        # Membership degrees
        mu_low_s1 = self._gaussian_mf(s1, self.mu_low)
        mu_high_s1 = self._gaussian_mf(s1, self.mu_high)
        mu_low_s2 = self._gaussian_mf(s2, self.mu_low)
        mu_high_s2 = self._gaussian_mf(s2, self.mu_high)

        # Rule weights
        w1 = mu_low_s1 * mu_low_s2
        w2 = mu_low_s1 * mu_high_s2
        w3 = mu_high_s1 * mu_low_s2
        w4 = mu_high_s1 * mu_high_s2

        # Consequent outputs
        y1 = self.rule_a[0] * s1 + self.rule_b[0] * s2 + self.rule_c[0]
        y2 = self.rule_a[1] * s1 + self.rule_b[1] * s2 + self.rule_c[1]
        y3 = self.rule_a[2] * s1 + self.rule_b[2] * s2 + self.rule_c[2]
        y4 = self.rule_a[3] * s1 + self.rule_b[3] * s2 + self.rule_c[3]

        # Defuzzification
        numerator = w1 * y1 + w2 * y2 + w3 * y3 + w4 * y4
        denominator = w1 + w2 + w3 + w4 + 1e-8

        return numerator / denominator

    def get_config(self):
        config = super().get_config()
        config.update({'units_in': self.units_in})
        return config

# %% [markdown]
# ### Build Model

# %%
# ============================================================
# Model Construction: LSTM-SNP with Fuzzy Output Layer
# LSTMSNPCell is UNMODIFIED.
# Dense(1) is replaced by FuzzyOutputLayer.
# ============================================================

def build_model(input_dim, units, batch_size):
    cell = LSTMSNPCell(units)
    rnn = layers.RNN(cell, return_sequences=False, stateful=True)

    inputs = tf.keras.Input(batch_shape=(batch_size, 1, input_dim))
    x = rnn(inputs)
    outputs = FuzzyOutputLayer(units_in=units)(x)

    model = tf.keras.Model(inputs, outputs)
    model.compile(optimizer='adam', loss='mean_squared_error')
    return model

# %%
# Quick model check
model = build_model(input_dim=1, units=8, batch_size=1)
model.summary()
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1787834052.099128   90349 gpu_device.cc:2020] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13756 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# I0000 00:00:1787834052.101561   90349 gpu_device.cc:2020] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 13756 MB memory:  -> device: 1, name: Tesla T4, pci bus id: 0000:00:05.0, compute capability: 7.5
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (1, 1, 1)              │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ rnn (RNN)                       │ (1, 8)                 │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ fuzzy_output_layer              │ (1, 1)                 │            12 │
# │ (FuzzyOutputLayer)              │                        │               │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 332 (1.30 KB)
#  Trainable params: 332 (1.30 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ## Data Pipeline — Dow Jones Industrial Index

# %%
import os
for f in os.listdir('/kaggle/input/datasets/satabartosarkar123/monthly-closings-of-the-dowjones-csv/'):
    print(f)
# Out:
# monthly-closings-of-the-dowjones.csv

# %%
# ============================================================
# 1. Load Time Series Data
# ============================================================
series = pd.read_csv(
    '/kaggle/input/datasets/satabartosarkar123/monthly-closings-of-the-dowjones-csv/monthly-closings-of-the-dowjones.csv',
    header=0,
    parse_dates=[0],
    index_col=0
)

original_raw_values = series.values.flatten()
print(f"Base data shape: {original_raw_values.shape}")
print(f"Base data first 5 values: {original_raw_values[:5]}")
# Out:
# Base data shape: (291,)
# Base data first 5 values: [3645.  3626.  3634.  3620.5 3607. ]

# %%
# ============================================================
# 2. First-Order Differencing
# ============================================================

def difference(dataset, interval=1):
    diff = []
    for i in range(interval, len(dataset)):
        value = dataset[i] - dataset[i - interval]
        diff.append(value)
    return np.array(diff)

# %%
# ============================================================
# 3. Convert to Supervised Learning Format (lag=1)
# ============================================================

def timeseries_to_supervised(data, lag=1):
    df = pd.DataFrame(data)
    columns = [df.shift(i) for i in range(1, lag+1)]
    columns.append(df)
    df = pd.concat(columns, axis=1)
    df.fillna(0, inplace=True)
    return df.values

# %%
# ============================================================
# 4 & 5. Train-Test Split and Feature Scaling
# ============================================================
# NOTE: The actual application of differencing, splitting (last 60 for test), 
# and scaling is performed inside the Gaussian Noise loop below to prevent data leakage.
print("Split protocol: Last 60 samples for Testing, remainder for Training.")
# Out:
# Split protocol: Last 60 samples for Testing, remainder for Training.

# %%
# ============================================================
# 6. Reshape for RNN Input
# ============================================================
print("Reshape protocol: (samples, time_steps, features)")
# Out:
# Reshape protocol: (samples, time_steps, features)

# %% [markdown]
# ## Training Loop

# %%
# ============================================================
# Gaussian Noise Evaluation + 60-Run Experiment Protocol (Keras)
# ============================================================
s_x = np.std(original_raw_values)
noise_levels = [0.0, 0.005, 0.05, 0.10]
_molab_results = []

for lam in noise_levels:
    sigma = lam * s_x
    print("\n" + "="*80)
    print(f"EVALUATING NOISE LEVEL: {lam*100:.1f}% (lambda={lam}, sigma={sigma:.6f})")
    print("="*80 + "\n")
    
    np.random.seed(42)
    tf.random.set_seed(42)
    noise = np.random.normal(0, sigma, size=original_raw_values.shape)
    raw_values = original_raw_values + noise
    
    # 2. Difference
    diff_values = difference(raw_values, 1)
    # 3. Supervised
    supervised = timeseries_to_supervised(diff_values, 1)
    # 4. Split (Last 60 for test, no validation)
    train, test = supervised[:-60], supervised[-60:]
    # 5. Scale
    scaler = MinMaxScaler(feature_range=(-1, 1))
    scaler.fit(train)
    train_scaled = scaler.transform(train)
    test_scaled = scaler.transform(test)
    # 6. Reshape
    X_train, y_train = train_scaled[:, 0:-1], train_scaled[:, -1]
    X_train = X_train.reshape((X_train.shape[0], 1, X_train.shape[1]))
    X_test, y_test = test_scaled[:, 0:-1], test_scaled[:, -1]
    
    all_rmse = []
    all_mse = []
    all_nmse = []
    all_predictions = []
    all_losses = []
    
    # 60 RUNS, 100 EPOCHS
    for run in range(60):
        print(f'\n===== RUN {run+1}/60 [Noise {lam*100:.1f}%] =====')

        np.random.seed(run)
        tf.random.set_seed(run)

        tf.keras.backend.clear_session()
        model = build_model(input_dim=1, units=8, batch_size=1)

        # Set consumption gate (c) bias to 1.0 (unit forget bias)
        rnn_layer = model.layers[1]
        cell = rnn_layer.cell
        weights = cell.get_weights()
        bias = weights[2].copy()
        bias[8:16] = 1.0  # units=8, bias[units:2*units]
        weights[2] = bias
        cell.set_weights(weights)

        run_losses = []
        for epoch in range(100):
            history = model.fit(
                X_train, y_train,
                epochs=1, batch_size=1,
                verbose=0, shuffle=False
            )
            run_losses.append(history.history['loss'][0])
            if (epoch+1) % 10 == 0:
                print(f'  Epoch {epoch+1}/100 completed, Loss: {history.history["loss"][0]:.6f}')
            rnn_layer.reset_states()

        all_losses.append(run_losses)
        print(f'Training complete for run {run+1}')

        # Warm-up: condition hidden states on training data
        train_reshaped = train_scaled[:, 0].reshape(len(train_scaled), 1, 1)
        model.predict(train_reshaped, batch_size=1, verbose=0)

        # Test predictions (single-step)
        predictions = []
        for i in range(len(test_scaled)):
            X, y = test_scaled[i, 0:-1], test_scaled[i, -1]
            X_input = X.reshape(1, 1, len(X))
            yhat = model.predict(X_input, batch_size=1, verbose=0)[0, 0]
            
            # Invert scaling
            new_row = [x for x in X] + [yhat]
            array = np.array(new_row).reshape(1, len(new_row))
            inverted = scaler.inverse_transform(array)[0, -1]
            
            # Invert differencing
            inverted = inverted + raw_values[len(train) + i]
            predictions.append(inverted)
            expected = raw_values[len(train) + i + 1]

        # Compute metrics
        actual = raw_values[-len(predictions):]
        rmse = sqrt(mean_squared_error(actual, predictions))
        mse = mean_squared_error(actual, predictions)
        meanV = np.mean(actual)
        dominator = np.linalg.norm(np.array(predictions) - meanV, 2)
        nmse = mse / np.power(dominator, 2)
        all_rmse.append(rmse)
        all_mse.append(mse)
        all_nmse.append(nmse)
        all_predictions.append(predictions)
        print(f'Run {run+1} Metrics — RMSE: {rmse:.6f}, MSE: {mse:.6f}, NMSE: {nmse:.10f}')

    # End of 60 runs for this noise level - save best run data
    best_idx = np.argmin(all_rmse)
    _molab_results.append([lam, all_rmse[best_idx], all_mse[best_idx], all_nmse[best_idx], 
                           all_predictions[best_idx], all_losses[best_idx], raw_values])
    print(f"\nBest run for {lam*100:.1f}% noise: Run {best_idx+1} (RMSE: {all_rmse[best_idx]:.6f})")
# Out:
# ================================================================================
# EVALUATING NOISE LEVEL: 0.0% (lambda=0.0, sigma=0.000000)
# ================================================================================
#
#
# ===== RUN 1/60 [Noise 0.0%] =====
# I0000 00:00:1787834057.308156   90402 device_compiler.h:196] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
#   Epoch 10/100 completed, Loss: 0.085685
#   Epoch 20/100 completed, Loss: 0.085529
#   Epoch 30/100 completed, Loss: 0.085453
#   Epoch 40/100 completed, Loss: 0.085364
#   Epoch 50/100 completed, Loss: 0.085164
#   Epoch 60/100 completed, Loss: 0.084931
#   Epoch 70/100 completed, Loss: 0.084728
#   Epoch 80/100 completed, Loss: 0.084493
#   Epoch 90/100 completed, Loss: 0.084279
#   Epoch 100/100 completed, Loss: 0.084153
# Training complete for run 1
# Run 1 Metrics — RMSE: 24.245301, MSE: 587.834606, NMSE: 0.0027141098
#
# ===== RUN 2/60 [Noise 0.0%] =====
#   Epoch 10/100 completed, Loss: 0.085659
#   Epoch 20/100 completed, Loss: 0.085343
#   Epoch 30/100 completed, Loss: 0.085189
#   Epoch 40/100 completed, Loss: 0.085100
#   Epoch 50/100 completed, Loss: 0.085038
#   Epoch 60/100 completed, Loss: 0.084990
#   Epoch 70/100 completed, Loss: 0.084946
#   Epoch 80/100 completed, Loss: 0.084888
#   Epoch 90/100 completed, Loss: 0.084796
#   Epoch 100/100 completed, Loss: 0.084679
# Training complete for run 2
# Run 2 Metrics — RMSE: 24.125768, MSE: 582.052696, NMSE: 0.0026484233
#
# ===== RUN 3/60 [Noise 0.0%] =====
#   Epoch 10/100 completed, Loss: 0.085649
#   Epoch 20/100 completed, Loss: 0.085504
#   Epoch 30/100 completed, Loss: 0.085437
#   Epoch 40/100 completed, Loss: 0.085386
#   Epoch 50/100 completed, Loss: 0.085340
#   Epoch 60/100 completed, Loss: 0.085295
#   Epoch 70/100 completed, Loss: 0.085239
#   Epoch 80/100 completed, Loss: 0.085060
#   Epoch 90/100 completed, Loss: 0.084101
#   Epoch 100/100 completed, Loss: 0.083550
# Training complete for run 3
# Run 3 Metrics — RMSE: 24.259209, MSE: 588.509243, NMSE: 0.0026576752
#
# ===== RUN 4/60 [Noise 0.0%] =====
#   Epoch 10/100 completed, Loss: 0.085840
#   Epoch 20/100 completed, Loss: 0.085594
#   Epoch 30/100 completed, Loss: 0.085474
#   Epoch 40/100 completed, Loss: 0.085397
#   Epoch 50/100 completed, Loss: 0.085341
#   Epoch 60/100 completed, Loss: 0.085300
#   Epoch 70/100 completed, Loss: 0.085268
#   Epoch 80/100 completed, Loss: 0.085241
#   Epoch 90/100 completed, Loss: 0.085215
#   Epoch 100/100 completed, Loss: 0.085188
# Training complete for run 4
# Run 4 Metrics — RMSE: 24.411383, MSE: 595.915609, NMSE: 0.0027335275
#
# ===== RUN 5/60 [Noise 0.0%] =====
#   Epoch 10/100 completed, Loss: 0.085164
#   Epoch 20/100 completed, Loss: 0.084983
#   Epoch 30/100 completed, Loss: 0.084750
#   Epoch 40/100 completed, Loss: 0.084548
#   Epoch 50/100 completed, Loss: 0.084381
#   Epoch 60/100 completed, Loss: 0.084230
#   Epoch 70/100 completed, Loss: 0.084048
#   Epoch 80/100 completed, Loss: 0.083781
#   Epoch 90/100 completed, Loss: 0.083406
#   Epoch 100/100 completed, Loss: 0.082984
# Training complete for run 5
# Run 5 Metrics — RMSE: 23.922575, MSE: 572.289601, NMSE: 0.0026762905
#
# ===== RUN 6/60 [Noise 0.0%] =====
#   Epoch 10/100 completed, Loss: 0.085385
#   Epoch 20/100 completed, Loss: 0.085336
#   Epoch 30/100 completed, Loss: 0.085283
#   Epoch 40/100 completed, Loss: 0.085215
#   Epoch 50/100 completed, Loss: 0.085156
#   Epoch 60/100 completed, Loss: 0.085094
#   Epoch 70/100 completed, Loss: 0.085014
#   Epoch 80/100 completed, Loss: 0.084897
#   Epoch 90/100 completed, Loss: 0.084654
#   Epoch 100/100 completed, Loss: 0.084265
# Training complete for run 6
# Run 6 Metrics — RMSE: 24.367610, MSE: 593.780405, NMSE: 0.0027471176
#
# ===== RUN 7/60 [Noise 0.0%] =====
#   Epoch 10/100 completed, Loss: 0.085191
#   Epoch 20/100 completed, Loss: 0.085149
#   Epoch 30/100 completed, Loss: 0.085122
#   Epoch 40/100 completed, Loss: 0.085110
#   Epoch 40/100 completed, Loss: 0.084678
#   Epoch 50/100 completed, Loss: 0.084294
#   Epoch 60/100 completed, Loss: 0.083918
#   Epoch 70/100 completed, Loss: 0.083626
#   Epoch 80/100 completed, Loss: 0.083412
#   Epoch 90/100 completed, Loss: 0.083242
#   Epoch 100/100 completed, Loss: 0.083106
# Training complete for run 8
# Run 8 Metrics — RMSE: 23.831990, MSE: 567.963745, NMSE: 0.0026502800
#
# ===== RUN 9/60 [Noise 0.0%] =====
#   Epoch 10/100 completed, Loss: 0.085489
#   Epoch 20/100 completed, Loss: 0.085308
#   Epoch 30/100 completed, Loss: 0.085214
#   Epoch 40/100 completed, Loss: 0.085138
#   Epoch 50/100 completed, Loss: 0.085038
#   Epoch 60/100 completed, Loss: 0.084843
#   Epoch 70/100 completed, Loss: 0.084455
#   Epoch 80/100 completed, Loss: 0.083949
#   Epoch 90/100 completed, Loss: 0.083683
#   Epoch 100/100 completed, Loss: 0.083559
# Training complete for run 9
# Run 9 Metrics — RMSE: 24.563207, MSE: 603.351123, NMSE: 0.0028138386
#
# ===== RUN 10/60 [Noise 0.0%] =====
#   Epoch 10/100 completed, Loss: 0.085280
#   Epoch 20/100 completed, Loss: 0.085220
#   Epoch 30/100 completed, Loss: 0.085224
#   Epoch 40/100 completed, Loss: 0.085159
#   Epoch 50/100 completed, Loss: 0.085137
#   Epoch 60/100 completed, Loss: 0.085104
#   Epoch 70/100 completed, Loss: 0.084960
#   Epoch 80/100 completed, Loss: 0.084668
#   Epoch 90/100 completed, Loss: 0.084389
#   Epoch 100/100 completed, Loss: 0.084181
# Training complete for run 10
# Run 10 Metrics — RMSE: 24.483364, MSE: 599.435133, NMSE: 0.0027813944
#
# ===== RUN 11/60 [Noise 0.0%] =====
#   Epoch 10/100 completed, Loss: 0.085468
#   Epoch 20/100 completed, Loss: 0.085292
#   Epoch 30/100 completed, Loss: 0.085196
#   Epoch 40/100 completed, Loss: 0.085182
#   Epoch 50/100 completed, Loss: 0.085169
#   Epoch 60/100 completed, Loss: 0.085160
#   Epoch 70/100 completed, Loss: 0.085153
#   Epoch 80/100 completed, Loss: 0.085147
#   Epoch 90/100 completed, Loss: 0.085156
#   Epoch 100/100 completed, Loss: 0.085162
# Training complete for run 11
# Run 11 Metrics — RMSE: 24.440022, MSE: 597.314676, NMSE: 0.0027346667
#
# ===== RUN 12/60 [Noise 0.0%] =====
#   Epoch 10/100 completed, Loss: 0.085489
#   Epoch 20/100 completed, Loss: 0.085366
#   Epoch 30/100 completed, Loss: 0.085292
#   Epoch 40/100 completed, Loss: 0.085237
#   Epoch 50/100 completed, Loss: 0.085191
#   Epoch 60/100 completed, Loss: 0.085148
#   Epoch 70/100 completed, Loss: 0.085103
#   Epoch 80/100 completed, Loss: 0.085052
#   Epoch 90/100 completed, Loss: 0.084988
#   Epoch 100/100 completed, Loss: 0.084896
# Training complete for run 12
# Run 12 Metrics — RMSE: 24.221011, MSE: 586.657375, NMSE: 0.0026898864
#
# ===== RUN 13/60 [Noise 0.0%] =====
#   Epoch 10/100 completed, Loss: 0.085452
#   Epoch 20/100 completed, Loss: 0.085295
#   Epoch 30/100 completed, Loss: 0.085234
#   Epoch 40/100 completed, Loss: 0.085190
#   Epoch 50/100 completed, Loss: 0.085149
#   Epoch 60/100 completed, Loss: 0.085103
#   Epoch 70/100 completed, Loss: 0.085057
#   Epoch 80/100 completed, Loss: 0.085017
#   Epoch 90/100 completed, Loss: 0.084982
#   Epoch 100/100 completed, Loss: 0.084942
# Training complete for run 13
# Run 13 Metrics — RMSE: 24.437915, MSE: 597.211695, NMSE: 0.0027345477
#
# ===== RUN 14/60 [Noise 0.0%] =====
#   Epoch 10/100 completed, Loss: 0.085331
#   Epoch 20/100 completed, Loss: 0.085199
#   Epoch 30/100 completed, Loss: 0.085137
#   Epoch 40/100 completed, Loss: 0.085100
#   Epoch 50/100 completed, Loss: 0.085070
#   Epoch 60/100 completed, Loss: 0.085044
#   Epoch 70/100 completed, Loss: 0.085017
#   Epoch 80/100 completed, Loss: 0.084984
#   Epoch 90/100 completed, Loss: 0.084942
#   Epoch 100/100 completed, Loss: 0.084886
# Training complete for run 14
# Run 14 Metrics — RMSE: 24.389710, MSE: 594.857940, NMSE: 0.0027276883
#
# ===== RUN 15/60 [Noise 0.0%] =====
#   Epoch 10/100 completed, Loss: 0.085731
#   Epoch 20/100 completed, Loss: 0.085545
#   Epoch 30/100 completed, Loss: 0.085445
#   Epoch 40/100 completed, Loss: 0.085375
#   Epoch 50/100 completed, Loss: 0.085321
#   Epoch 60/100 completed, Loss: 0.085275
#   Epoch 70/100 completed, Loss: 0.085232
#   Epoch 80/100 completed, Loss: 0.085189
#   Epoch 90/100 completed, Loss: 0.085144
#   Epoch 100/100 completed, Loss: 0.085096
# Training complete for run 15
# Run 15 Metrics — RMSE: 24.369086, MSE: 593.852372, NMSE: 0.0027051470
#
# ===== RUN 16/60 [Noise 0.0%] =====
#   Epoch 10/100 completed, Loss: 0.085413
#   Epoch 20/100 completed, Loss: 0.085296
#   Epoch 30/100 completed, Loss: 0.085239
#   Epoch 40/100 completed, Loss: 0.085212
#   Epoch 50/100 completed, Loss: 0.085194
#   Epoch 60/100 completed, Loss: 0.085174
#   Epoch 70/100 completed, Loss: 0.085143
#   Epoch 80/100 completed, Loss: 0.085083
#   Epoch 90/100 completed, Loss: 0.084971
#   Epoch 100/100 completed, Loss: 0.084805
# Training complete for run 16
# Run 16 Metrics — RMSE: 24.450450, MSE: 597.824485, NMSE: 0.0027488000
#
# ===== RUN 17/60 [Noise 0.0%] =====
#   Epoch 10/100 completed, Loss: 0.085524
#   Epoch 20/100 completed, Loss: 0.085331
#   Epoch 30/100 completed, Loss: 0.085232
#   Epoch 40/100 completed, Loss: 0.085172
#   Epoch 50/100 completed, Loss: 0.085134
#   Epoch 60/100 completed, Loss: 0.085098
#   Epoch 70/100 completed, Loss: 0.085044
#   Epoch 80/100 completed, Loss: 0.084906
#   Epoch 90/100 completed, Loss: 0.084542
#   Epoch 100/100 completed, Loss: 0.084025
# Training complete for run 17
# Run 17 Metrics — RMSE: 24.235798, MSE: 587.373928, NMSE: 0.0026997791
#
# ===== RUN 18/60 [Noise 0.0%] =====
#   Epoch 10/100 completed, Loss: 0.085146
#   Epoch 20/100 completed, Loss: 0.085053
#   Epoch 30/100 completed, Loss: 0.085027
#   Epoch 40/100 completed, Loss: 0.085017
#   Epoch 50/100 completed, Loss: 0.084997
#   Epoch 60/100 completed, Loss: 0.084963
#   Epoch 70/100 completed, Loss: 0.084914
#   Epoch 80/100 completed, Loss: 0.084853
#   Epoch 90/100 completed, Loss: 0.084781
#   Epoch 100/100 completed, Loss: 0.084698
# Training complete for run 18
# Run 18 Metrics — RMSE: 24.472310, MSE: 598.893955, NMSE: 0.0027590314
#
# ===== RUN 19/60 [Noise 0.0%] =====
#   Epoch 10/100 completed, Loss: 0.085498
#   Epoch 20/100 completed, Loss: 0.085296
#   Epoch 30/100 completed, Loss: 0.085209
#   Epoch 40/100 completed, Loss: 0.085159
#   Epoch 50/100 completed, Loss: 0.085132
#   Epoch 60/100 completed, Loss: 0.085127
#   Epoch 70/100 completed, Loss: 0.085140
#   Epoch 80/100 completed, Loss: 0.085175
#   Epoch 90/100 completed, Loss: 0.085205
#   Epoch 100/100 completed, Loss: 0.085150
# Training complete for run 19
# Run 19 Metrics — RMSE: 24.390837, MSE: 594.912938, NMSE: 0.0027181242
#
# ===== RUN 20/60 [Noise 0.0%] =====
#   Epoch 10/100 completed, Loss: 0.085789
#   Epoch 20/100 completed, Loss: 0.085596
#   Epoch 30/100 completed, Loss: 0.085492
#   Epoch 40/100 completed, Loss: 0.085420
#   Epoch 50/100 completed, Loss: 0.085366
#   Epoch 60/100 completed, Loss: 0.085324
#   Epoch 70/100 completed, Loss: 0.085291
#   Epoch 80/100 completed, Loss: 0.085265
#   Epoch 90/100 completed, Loss: 0.085243
#   Epoch 100/100 completed, Loss: 0.085224
# Training complete for run 20
# Run 20 Metrics — RMSE: 24.459526, MSE: 598.268429, NMSE: 0.0027351856
#
# ===== RUN 21/60 [Noise 0.0%] =====
#   Epoch 10/100 completed, Loss: 0.085469
#   Epoch 20/100 completed, Loss: 0.085339
#   Epoch 30/100 completed, Loss: 0.085256
#   Epoch 40/100 completed, Loss: 0.085170
#   Epoch 50/100 completed, Loss: 0.085091
#   Epoch 60/100 completed, Loss: 0.084987
#   Epoch 70/100 completed, Loss: 0.084847
#   Epoch 80/100 completed, Loss: 0.084660
#   Epoch 90/100 completed, Loss: 0.084438
#   Epoch 100/100 completed, Loss: 0.084207
# Training complete for run 21
# Run 21 Metrics — RMSE: 24.369405, MSE: 593.867898, NMSE: 0.0027367460
#
# ===== RUN 22/60 [Noise 0.0%] =====
#   Epoch 10/100 completed, Loss: 0.085492
#   Epoch 20/100 completed, Loss: 0.085303
#   Epoch 30/100 completed, Loss: 0.085228
#   Epoch 40/100 completed, Loss: 0.085182
#   Epoch 50/100 completed, Loss: 0.085145
#   Epoch 60/100 completed, Loss: 0.085107
#   Epoch 70/100 completed, Loss: 0.085066
#   Epoch 80/100 completed, Loss: 0.085024
#   Epoch 90/100 completed, Loss: 0.084984
#   Epoch 100/100 completed, Loss: 0.084941
# Training complete for run 22
# Run 22 Metrics — RMSE: 24.427650, MSE: 596.710099, NMSE: 0.0027286904
#
# ===== RUN 23/60 [Noise 0.0%] =====
#   Epoch 10/100 completed, Loss: 0.085901
#   Epoch 20/100 completed, Loss: 0.085660
#   Epoch 30/100 completed, Loss: 0.085547
#   Epoch 40/100 completed, Loss: 0.085465
#   Epoch 50/100 completed, Loss: 0.085397
#   Epoch 60/100 completed, Loss: 0.085341
#   Epoch 70/100 completed, Loss: 0.085292
#   Epoch 80/100 completed, Loss: 0.085251
#   Epoch 90/100 completed, Loss: 0.085215
#   Epoch 100/100 completed, Loss: 0.085180
# Training complete for run 23
# Run 23 Metrics — RMSE: 24.344856, MSE: 592.672030, NMSE: 0.0027073007
#
# ===== RUN 24/60 [Noise 0.0%] =====
#   Epoch 10/100 completed, Loss: 0.084125
#   Epoch 20/100 completed, Loss: 0.084092
#   Epoch 30/100 completed, Loss: 0.084070
#   Epoch 40/100 completed, Loss: 0.083976
#   Epoch 50/100 completed, Loss: 0.084366
#   Epoch 60/100 completed, Loss: 0.084434
#   Epoch 70/100 completed, Loss: 0.086606
#   Epoch 80/100 completed, Loss: 0.084743
#   Epoch 90/100 completed, Loss: 0.084828
#   Epoch 100/100 completed, Loss: 0.084692
# Training complete for run 24
# Run 24 Metrics — RMSE: 24.499603, MSE: 600.230562, NMSE: 0.0027507376
#
# ===== RUN 25/60 [Noise 0.0%] =====
#   Epoch 10/100 completed, Loss: 0.085788
#   Epoch 20/100 completed, Loss: 0.085581
#   Epoch 30/100 completed, Loss: 0.085494
#   Epoch 40/100 completed, Loss: 0.085439
#   Epoch 50/100 completed, Loss: 0.085394
#   Epoch 60/100 completed, Loss: 0.085353
#   Epoch 70/100 completed, Loss: 0.085312
#   Epoch 80/100 completed, Loss: 0.085265
#   Epoch 90/100 completed, Loss: 0.085206
#   Epoch 100/100 completed, Loss: 0.085150
# Training complete for run 25
# Run 25 Metrics — RMSE: 24.422199, MSE: 596.443803, NMSE: 0.0027330176
#
# ===== RUN 26/60 [Noise 0.0%] =====
#   Epoch 10/100 completed, Loss: 0.085771
#   Epoch 20/100 completed, Loss: 0.085575
#   Epoch 30/100 completed, Loss: 0.085472
#   Epoch 40/100 completed, Loss: 0.085404
#   Epoch 50/100 completed, Loss: 0.085354
#   Epoch 60/100 completed, Loss: 0.085315
#   Epoch 70/100 completed, Loss: 0.085283
#   Epoch 80/100 completed, Loss: 0.085255
#   Epoch 90/100 completed, Loss: 0.085231
#   Epoch 100/100 completed, Loss: 0.085210
# Training complete for run 26
# Run 26 Metrics — RMSE: 24.367053, MSE: 593.753265, NMSE: 0.0027066616
#
# ===== RUN 27/60 [Noise 0.0%] =====
#   Epoch 10/100 completed, Loss: 0.085428
#   Epoch 20/100 completed, Loss: 0.085330
#   Epoch 30/100 completed, Loss: 0.085263
#   Epoch 40/100 completed, Loss: 0.085152
#   Epoch 50/100 completed, Loss: 0.084940
#   Epoch 60/100 completed, Loss: 0.084655
#   Epoch 70/100 completed, Loss: 0.084392
#   Epoch 80/100 completed, Loss: 0.084182
#   Epoch 90/100 completed, Loss: 0.083996
#   Epoch 100/100 completed, Loss: 0.083818
# Training complete for run 27
# Run 27 Metrics — RMSE: 24.114741, MSE: 581.520746, NMSE: 0.0026863738
#
# ===== RUN 28/60 [Noise 0.0%] =====
#   Epoch 10/100 completed, Loss: 0.085384
#   Epoch 20/100 completed, Loss: 0.085277
#   Epoch 30/100 completed, Loss: 0.085225
#   Epoch 40/100 completed, Loss: 0.085190
#   Epoch 50/100 completed, Loss: 0.085156
#   Epoch 60/100 completed, Loss: 0.085119
#   Epoch 70/100 completed, Loss: 0.085075
#   Epoch 80/100 completed, Loss: 0.085025
#   Epoch 90/100 completed, Loss: 0.084970
#   Epoch 100/100 completed, Loss: 0.084902
# Training complete for run 28
# Run 28 Metrics — RMSE: 24.425047, MSE: 596.582924, NMSE: 0.0027319701
#
# ===== RUN 29/60 [Noise 0.0%] =====
#   Epoch 10/100 completed, Loss: 0.085677
#   Epoch 20/100 completed, Loss: 0.085489
#   Epoch 30/100 completed, Loss: 0.085358
#   Epoch 40/100 completed, Loss: 0.085263
#   Epoch 50/100 completed, Loss: 0.085222
#   Epoch 60/100 completed, Loss: 0.085192
#   Epoch 70/100 completed, Loss: 0.085174
#   Epoch 80/100 completed, Loss: 0.085159
#   Epoch 90/100 completed, Loss: 0.085146
#   Epoch 100/100 completed, Loss: 0.085128
# Training complete for run 29
# Run 29 Metrics — RMSE: 24.422359, MSE: 596.451632, NMSE: 0.0027286358
#
# ===== RUN 30/60 [Noise 0.0%] =====
#   Epoch 10/100 completed, Loss: 0.085509
#   Epoch 20/100 completed, Loss: 0.085389
#   Epoch 30/100 completed, Loss: 0.085336
#   Epoch 40/100 completed, Loss: 0.085302
#   Epoch 50/100 completed, Loss: 0.085252
#   Epoch 60/100 completed, Loss: 0.085166
#   Epoch 70/100 completed, Loss: 0.085027
#   Epoch 80/100 completed, Loss: 0.084828
#   Epoch 90/100 completed, Loss: 0.084600
#   Epoch 100/100 completed, Loss: 0.084367
# Training complete for run 30
# Run 30 Metrics — RMSE: 24.408725, MSE: 595.785855, NMSE: 0.0027403510
#
# ===== RUN 31/60 [Noise 0.0%] =====
#   Epoch 10/100 completed, Loss: 0.085538
#   Epoch 20/100 completed, Loss: 0.085405
#   Epoch 30/100 completed, Loss: 0.085328
#   Epoch 40/100 completed, Loss: 0.085271
#   Epoch 50/100 completed, Loss: 0.085211
#   Epoch 60/100 completed, Loss: 0.085113
#   Epoch 70/100 completed, Loss: 0.084963
#   Epoch 80/100 completed, Loss: 0.084779
#   Epoch 90/100 completed, Loss: 0.084593
#   Epoch 100/100 completed, Loss: 0.084433
# Training complete for run 31
# Run 31 Metrics — RMSE: 24.155410, MSE: 583.483823, NMSE: 0.0027057985
#
# ===== RUN 32/60 [Noise 0.0%] =====
#   Epoch 10/100 completed, Loss: 0.085625
#   Epoch 20/100 completed, Loss: 0.085502
#   Epoch 30/100 completed, Loss: 0.085426
#   Epoch 40/100 completed, Loss: 0.085373
#   Epoch 50/100 completed, Loss: 0.085333
#   Epoch 60/100 completed, Loss: 0.085302
#   Epoch 70/100 completed, Loss: 0.085277
#   Epoch 80/100 completed, Loss: 0.085254
#   Epoch 90/100 completed, Loss: 0.085233
#   Epoch 100/100 completed, Loss: 0.085211
# Training complete for run 32
# Run 32 Metrics — RMSE: 24.482323, MSE: 599.384135, NMSE: 0.0027445404
#
# ===== RUN 33/60 [Noise 0.0%] =====
#   Epoch 10/100 completed, Loss: 0.085826
#   Epoch 20/100 completed, Loss: 0.085587
#   Epoch 30/100 completed, Loss: 0.085464
#   Epoch 40/100 completed, Loss: 0.085384
#   Epoch 50/100 completed, Loss: 0.085325
#   Epoch 60/100 completed, Loss: 0.085281
#   Epoch 70/100 completed, Loss: 0.085244
#   Epoch 80/100 completed, Loss: 0.085213
#   Epoch 90/100 completed, Loss: 0.085185
#   Epoch 100/100 completed, Loss: 0.085160
# Training complete for run 33
# Run 33 Metrics — RMSE: 24.418878, MSE: 596.281601, NMSE: 0.0027192549
#
# ===== RUN 34/60 [Noise 0.0%] =====
#   Epoch 10/100 completed, Loss: 0.085703
#   Epoch 20/100 completed, Loss: 0.085409
#   Epoch 30/100 completed, Loss: 0.085326
#   Epoch 40/100 completed, Loss: 0.085292
#   Epoch 50/100 completed, Loss: 0.085279
#   Epoch 60/100 completed, Loss: 0.085261
#   Epoch 70/100 completed, Loss: 0.085242
#   Epoch 80/100 completed, Loss: 0.085213
#   Epoch 90/100 completed, Loss: 0.085169
#   Epoch 100/100 completed, Loss: 0.085109
# Training complete for run 34
# Run 34 Metrics — RMSE: 24.370763, MSE: 593.934072, NMSE: 0.0027077162
#
# ===== RUN 35/60 [Noise 0.0%] =====
#   Epoch 10/100 completed, Loss: 0.085578
#   Epoch 20/100 completed, Loss: 0.085387
#   Epoch 30/100 completed, Loss: 0.085309
#   Epoch 40/100 completed, Loss: 0.085255
#   Epoch 50/100 completed, Loss: 0.085208
#   Epoch 60/100 completed, Loss: 0.085160
#   Epoch 70/100 completed, Loss: 0.085099
#   Epoch 80/100 completed, Loss: 0.085072
#   Epoch 90/100 completed, Loss: 0.085071
#   Epoch 100/100 completed, Loss: 0.085074
# Training complete for run 35
# Run 35 Metrics — RMSE: 24.364575, MSE: 593.632532, NMSE: 0.0027060709
#
# ===== RUN 36/60 [Noise 0.0%] =====
#   Epoch 10/100 completed, Loss: 0.085390
#   Epoch 20/100 completed, Loss: 0.085303
#   Epoch 30/100 completed, Loss: 0.085262
#   Epoch 40/100 completed, Loss: 0.085224
#   Epoch 50/100 completed, Loss: 0.085185
#   Epoch 60/100 completed, Loss: 0.085145
#   Epoch 70/100 completed, Loss: 0.085107
#   Epoch 80/100 completed, Loss: 0.085074
#   Epoch 90/100 completed, Loss: 0.085040
#   Epoch 100/100 completed, Loss: 0.084957
# Training complete for run 36
# Run 36 Metrics — RMSE: 24.416099, MSE: 596.145913, NMSE: 0.0027315042
#
# ===== RUN 37/60 [Noise 0.0%] =====
#   Epoch 10/100 completed, Loss: 0.085389
#   Epoch 20/100 completed, Loss: 0.085309
#   Epoch 30/100 completed, Loss: 0.085247
#   Epoch 40/100 completed, Loss: 0.085171
#   Epoch 50/100 completed, Loss: 0.084990
#   Epoch 60/100 completed, Loss: 0.084627
#   Epoch 70/100 completed, Loss: 0.084264
#   Epoch 80/100 completed, Loss: 0.083937
#   Epoch 90/100 completed, Loss: 0.083491
#   Epoch 100/100 completed, Loss: 0.083132
# Training complete for run 37
# Run 37 Metrics — RMSE: 24.141408, MSE: 582.807592, NMSE: 0.0027020115
#
# ===== RUN 38/60 [Noise 0.0%] =====
#   Epoch 10/100 completed, Loss: 0.085191
#   Epoch 20/100 completed, Loss: 0.085119
#   Epoch 30/100 completed, Loss: 0.085118
#   Epoch 40/100 completed, Loss: 0.085113
#   Epoch 50/100 completed, Loss: 0.085101
#   Epoch 60/100 completed, Loss: 0.085084
#   Epoch 70/100 completed, Loss: 0.085058
#   Epoch 80/100 completed, Loss: 0.085018
#   Epoch 90/100 completed, Loss: 0.084965
#   Epoch 100/100 completed, Loss: 0.084892
# Training complete for run 38
# Run 38 Metrics — RMSE: 24.455211, MSE: 598.057338, NMSE: 0.0027377145
#
# ===== RUN 39/60 [Noise 0.0%] =====
#   Epoch 10/100 completed, Loss: 0.085942
#   Epoch 20/100 completed, Loss: 0.085702
#   Epoch 30/100 completed, Loss: 0.085572
#   Epoch 40/100 completed, Loss: 0.085466
#   Epoch 50/100 completed, Loss: 0.085379
#   Epoch 60/100 completed, Loss: 0.085307
#   Epoch 70/100 completed, Loss: 0.085248
#   Epoch 80/100 completed, Loss: 0.085197
#   Epoch 90/100 completed, Loss: 0.085150
#   Epoch 100/100 completed, Loss: 0.085100
# Training complete for run 39
# Run 39 Metrics — RMSE: 24.312165, MSE: 591.081391, NMSE: 0.0026983521
#
# ===== RUN 40/60 [Noise 0.0%] =====
#   Epoch 10/100 completed, Loss: 0.085615
#   Epoch 20/100 completed, Loss: 0.085414
#   Epoch 30/100 completed, Loss: 0.085325
#   Epoch 40/100 completed, Loss: 0.085264
#   Epoch 50/100 completed, Loss: 0.085207
#   Epoch 60/100 completed, Loss: 0.085139
#   Epoch 70/100 completed, Loss: 0.085045
#   Epoch 80/100 completed, Loss: 0.084941
#   Epoch 90/100 completed, Loss: 0.084850
#   Epoch 100/100 completed, Loss: 0.084715
# Training complete for run 40
# Run 40 Metrics — RMSE: 24.174552, MSE: 584.408971, NMSE: 0.0026654702
#
# ===== RUN 41/60 [Noise 0.0%] =====
#   Epoch 10/100 completed, Loss: 0.085718
#   Epoch 20/100 completed, Loss: 0.085439
#   Epoch 30/100 completed, Loss: 0.085286
#   Epoch 40/100 completed, Loss: 0.085156
#   Epoch 50/100 completed, Loss: 0.085013
#   Epoch 60/100 completed, Loss: 0.084837
#   Epoch 70/100 completed, Loss: 0.084616
#   Epoch 80/100 completed, Loss: 0.084351
#   Epoch 90/100 completed, Loss: 0.084069
#   Epoch 100/100 completed, Loss: 0.083799
# Training complete for run 41
# Run 41 Metrics — RMSE: 24.145792, MSE: 583.019267, NMSE: 0.0026528674
#
# ===== RUN 42/60 [Noise 0.0%] =====
#   Epoch 10/100 completed, Loss: 0.085502
#   Epoch 20/100 completed, Loss: 0.085375
#   Epoch 30/100 completed, Loss: 0.085274
#   Epoch 40/100 completed, Loss: 0.085214
#   Epoch 50/100 completed, Loss: 0.085170
#   Epoch 60/100 completed, Loss: 0.085137
#   Epoch 70/100 completed, Loss: 0.085105
#   Epoch 80/100 completed, Loss: 0.085070
#   Epoch 90/100 completed, Loss: 0.085028
#   Epoch 100/100 completed, Loss: 0.084969
# Training complete for run 42
# Run 42 Metrics — RMSE: 24.378415, MSE: 594.307114, NMSE: 0.0027202600
#
# ===== RUN 43/60 [Noise 0.0%] =====
#   Epoch 10/100 completed, Loss: 0.085354
#   Epoch 20/100 completed, Loss: 0.085235
#   Epoch 30/100 completed, Loss: 0.085167
#   Epoch 40/100 completed, Loss: 0.085119
#   Epoch 50/100 completed, Loss: 0.085091
#   Epoch 60/100 completed, Loss: 0.085075
#   Epoch 70/100 completed, Loss: 0.085067
#   Epoch 80/100 completed, Loss: 0.085060
#   Epoch 90/100 completed, Loss: 0.085051
#   Epoch 100/100 completed, Loss: 0.085011
# Training complete for run 43
# Run 43 Metrics — RMSE: 24.423454, MSE: 596.505129, NMSE: 0.0027358352
#
# ===== RUN 44/60 [Noise 0.0%] =====
#   Epoch 10/100 completed, Loss: 0.085481
#   Epoch 20/100 completed, Loss: 0.085348
#   Epoch 30/100 completed, Loss: 0.085280
#   Epoch 40/100 completed, Loss: 0.085224
#   Epoch 50/100 completed, Loss: 0.085181
#   Epoch 60/100 completed, Loss: 0.085137
#   Epoch 70/100 completed, Loss: 0.085093
#   Epoch 80/100 completed, Loss: 0.085049
#   Epoch 90/100 completed, Loss: 0.085000
#   Epoch 100/100 completed, Loss: 0.084944
# Training complete for run 44
# Run 44 Metrics — RMSE: 24.376996, MSE: 594.237916, NMSE: 0.0027231658
#
# ===== RUN 45/60 [Noise 0.0%] =====
#   Epoch 10/100 completed, Loss: 0.085371
#   Epoch 20/100 completed, Loss: 0.085333
#   Epoch 30/100 completed, Loss: 0.085320
#   Epoch 40/100 completed, Loss: 0.085287
#   Epoch 50/100 completed, Loss: 0.085169
#   Epoch 60/100 completed, Loss: 0.084979
#   Epoch 70/100 completed, Loss: 0.084739
#   Epoch 80/100 completed, Loss: 0.084435
#   Epoch 90/100 completed, Loss: 0.083970
#   Epoch 100/100 completed, Loss: 0.083035
# Training complete for run 45
# Run 45 Metrics — RMSE: 24.278747, MSE: 589.457542, NMSE: 0.0027628665
#
# ===== RUN 46/60 [Noise 0.0%] =====
#   Epoch 10/100 completed, Loss: 0.085535
#   Epoch 20/100 completed, Loss: 0.085404
#   Epoch 30/100 completed, Loss: 0.085327
#   Epoch 40/100 completed, Loss: 0.085271
#   Epoch 50/100 completed, Loss: 0.085226
#   Epoch 60/100 completed, Loss: 0.085187
#   Epoch 70/100 completed, Loss: 0.085152
#   Epoch 80/100 completed, Loss: 0.085120
#   Epoch 90/100 completed, Loss: 0.085093
#   Epoch 100/100 completed, Loss: 0.085068
# Training complete for run 46
# Run 46 Metrics — RMSE: 24.384420, MSE: 594.599916, NMSE: 0.0027162388
#
# ===== RUN 47/60 [Noise 0.0%] =====
#   Epoch 10/100 completed, Loss: 0.085870
#   Epoch 20/100 completed, Loss: 0.085638
#   Epoch 30/100 completed, Loss: 0.085514
#   Epoch 40/100 completed, Loss: 0.085432
#   Epoch 50/100 completed, Loss: 0.085368
#   Epoch 60/100 completed, Loss: 0.085311
#   Epoch 70/100 completed, Loss: 0.085236
#   Epoch 80/100 completed, Loss: 0.085147
#   Epoch 90/100 completed, Loss: 0.085049
#   Epoch 100/100 completed, Loss: 0.084995
# Training complete for run 47
# Run 47 Metrics — RMSE: 24.469798, MSE: 598.771035, NMSE: 0.0027450968
#
# ===== RUN 48/60 [Noise 0.0%] =====
#   Epoch 10/100 completed, Loss: 0.085490
#   Epoch 20/100 completed, Loss: 0.085328
#   Epoch 30/100 completed, Loss: 0.085252
#   Epoch 40/100 completed, Loss: 0.085194
#   Epoch 50/100 completed, Loss: 0.085138
#   Epoch 60/100 completed, Loss: 0.085081
#   Epoch 70/100 completed, Loss: 0.085030
#   Epoch 80/100 completed, Loss: 0.084971
#   Epoch 90/100 completed, Loss: 0.084519
#   Epoch 100/100 completed, Loss: 0.083917
# Training complete for run 48
# Run 48 Metrics — RMSE: 24.339225, MSE: 592.397860, NMSE: 0.0027368239
#
# ===== RUN 49/60 [Noise 0.0%] =====
#   Epoch 10/100 completed, Loss: 0.085530
#   Epoch 20/100 completed, Loss: 0.085442
#   Epoch 30/100 completed, Loss: 0.085385
#   Epoch 40/100 completed, Loss: 0.085314
#   Epoch 50/100 completed, Loss: 0.085233
#   Epoch 60/100 completed, Loss: 0.085154
#   Epoch 70/100 completed, Loss: 0.085077
#   Epoch 80/100 completed, Loss: 0.084994
#   Epoch 90/100 completed, Loss: 0.084885
#   Epoch 100/100 completed, Loss: 0.084698
# Training complete for run 49
# Run 49 Metrics — RMSE: 24.453947, MSE: 597.995532, NMSE: 0.0027443460
#
# ===== RUN 50/60 [Noise 0.0%] =====
#   Epoch 10/100 completed, Loss: 0.085444
#   Epoch 20/100 completed, Loss: 0.085293
#   Epoch 30/100 completed, Loss: 0.085245
#   Epoch 40/100 completed, Loss: 0.085206
#   Epoch 50/100 completed, Loss: 0.085177
#   Epoch 60/100 completed, Loss: 0.085112
#   Epoch 70/100 completed, Loss: 0.085066
#   Epoch 80/100 completed, Loss: 0.085019
#   Epoch 90/100 completed, Loss: 0.084992
#   Epoch 100/100 completed, Loss: 0.084898
# Training complete for run 50
# Run 50 Metrics — RMSE: 24.446467, MSE: 597.629765, NMSE: 0.0027387561
#
# ===== RUN 51/60 [Noise 0.0%] =====
#   Epoch 10/100 completed, Loss: 0.085425
#   Epoch 20/100 completed, Loss: 0.085324
#   Epoch 30/100 completed, Loss: 0.085276
#   Epoch 40/100 completed, Loss: 0.085241
#   Epoch 50/100 completed, Loss: 0.085205
#   Epoch 60/100 completed, Loss: 0.085157
#   Epoch 70/100 completed, Loss: 0.085067
#   Epoch 80/100 completed, Loss: 0.084890
#   Epoch 90/100 completed, Loss: 0.084653
#   Epoch 100/100 completed, Loss: 0.084424
# Training complete for run 51
# Run 51 Metrics — RMSE: 24.304943, MSE: 590.730263, NMSE: 0.0027270994
#
# ===== RUN 52/60 [Noise 0.0%] =====
#   Epoch 10/100 completed, Loss: 0.085555
#   Epoch 20/100 completed, Loss: 0.085432
#   Epoch 30/100 completed, Loss: 0.085346
#   Epoch 40/100 completed, Loss: 0.085276
#   Epoch 50/100 completed, Loss: 0.085216
#   Epoch 60/100 completed, Loss: 0.085159
#   Epoch 70/100 completed, Loss: 0.085097
#   Epoch 80/100 completed, Loss: 0.085006
#   Epoch 90/100 completed, Loss: 0.084859
#   Epoch 100/100 completed, Loss: 0.084559
# Training complete for run 52
# Run 52 Metrics — RMSE: 24.274362, MSE: 589.244628, NMSE: 0.0026945742
#
# ===== RUN 53/60 [Noise 0.0%] =====
#   Epoch 10/100 completed, Loss: 0.085398
#   Epoch 20/100 completed, Loss: 0.085296
#   Epoch 30/100 completed, Loss: 0.085229
#   Epoch 40/100 completed, Loss: 0.085172
#   Epoch 50/100 completed, Loss: 0.085125
#   Epoch 60/100 completed, Loss: 0.085087
#   Epoch 70/100 completed, Loss: 0.085048
#   Epoch 80/100 completed, Loss: 0.085009
#   Epoch 90/100 completed, Loss: 0.084973
#   Epoch 100/100 completed, Loss: 0.084934
# Training complete for run 53
# Run 53 Metrics — RMSE: 24.414655, MSE: 596.075369, NMSE: 0.0027291581
#
# ===== RUN 54/60 [Noise 0.0%] =====
#   Epoch 10/100 completed, Loss: 0.085368
#   Epoch 20/100 completed, Loss: 0.085280
#   Epoch 30/100 completed, Loss: 0.085222
#   Epoch 40/100 completed, Loss: 0.085164
#   Epoch 50/100 completed, Loss: 0.085123
#   Epoch 60/100 completed, Loss: 0.085092
#   Epoch 70/100 completed, Loss: 0.085059
#   Epoch 80/100 completed, Loss: 0.085019
#   Epoch 90/100 completed, Loss: 0.084971
#   Epoch 100/100 completed, Loss: 0.084913
# Training complete for run 54
# Run 54 Metrics — RMSE: 24.424336, MSE: 596.548195, NMSE: 0.0027386657
#
# ===== RUN 55/60 [Noise 0.0%] =====
#   Epoch 10/100 completed, Loss: 0.085885
#   Epoch 20/100 completed, Loss: 0.085674
#   Epoch 30/100 completed, Loss: 0.085542
#   Epoch 40/100 completed, Loss: 0.085441
#   Epoch 50/100 completed, Loss: 0.085363
#   Epoch 60/100 completed, Loss: 0.085305
#   Epoch 70/100 completed, Loss: 0.085268
#   Epoch 80/100 completed, Loss: 0.085256
#   Epoch 90/100 completed, Loss: 0.085237
#   Epoch 100/100 completed, Loss: 0.085218
# Training complete for run 55
# Run 55 Metrics — RMSE: 24.382957, MSE: 594.528604, NMSE: 0.0027104676
#
# ===== RUN 56/60 [Noise 0.0%] =====
#   Epoch 10/100 completed, Loss: 0.085823
#   Epoch 20/100 completed, Loss: 0.085546
#   Epoch 30/100 completed, Loss: 0.085414
#   Epoch 40/100 completed, Loss: 0.085333
#   Epoch 50/100 completed, Loss: 0.085276
#   Epoch 60/100 completed, Loss: 0.085233
#   Epoch 70/100 completed, Loss: 0.085203
#   Epoch 80/100 completed, Loss: 0.085185
#   Epoch 90/100 completed, Loss: 0.085175
#   Epoch 100/100 completed, Loss: 0.085160
# Training complete for run 56
# Run 56 Metrics — RMSE: 24.418043, MSE: 596.240825, NMSE: 0.0027320697
#
# ===== RUN 57/60 [Noise 0.0%] =====
#   Epoch 10/100 completed, Loss: 0.085167
#   Epoch 20/100 completed, Loss: 0.085142
#   Epoch 30/100 completed, Loss: 0.085112
#   Epoch 40/100 completed, Loss: 0.085077
#   Epoch 50/100 completed, Loss: 0.085020
#   Epoch 60/100 completed, Loss: 0.084902
#   Epoch 70/100 completed, Loss: 0.084715
#   Epoch 80/100 completed, Loss: 0.084531
#   Epoch 90/100 completed, Loss: 0.084393
#   Epoch 100/100 completed, Loss: 0.084289
# Training complete for run 57
# Run 57 Metrics — RMSE: 24.407861, MSE: 595.743677, NMSE: 0.0027495978
#
# ===== RUN 58/60 [Noise 0.0%] =====
#   Epoch 10/100 completed, Loss: 0.085173
#   Epoch 20/100 completed, Loss: 0.085119
#   Epoch 30/100 completed, Loss: 0.084961
#   Epoch 40/100 completed, Loss: 0.084652
#   Epoch 50/100 completed, Loss: 0.084406
#   Epoch 60/100 completed, Loss: 0.084211
#   Epoch 70/100 completed, Loss: 0.084033
#   Epoch 80/100 completed, Loss: 0.083892
#   Epoch 90/100 completed, Loss: 0.083763
#   Epoch 100/100 completed, Loss: 0.083608
# Training complete for run 58
# Run 58 Metrics — RMSE: 24.344111, MSE: 592.635745, NMSE: 0.0027426805
#
# ===== RUN 59/60 [Noise 0.0%] =====
#   Epoch 10/100 completed, Loss: 0.085491
#   Epoch 20/100 completed, Loss: 0.085353
#   Epoch 30/100 completed, Loss: 0.085298
#   Epoch 40/100 completed, Loss: 0.085247
#   Epoch 50/100 completed, Loss: 0.085196
#   Epoch 60/100 completed, Loss: 0.085145
#   Epoch 70/100 completed, Loss: 0.085090
#   Epoch 80/100 completed, Loss: 0.085030
#   Epoch 90/100 completed, Loss: 0.084964
#   Epoch 100/100 completed, Loss: 0.084886
# Training complete for run 59
# Run 59 Metrics — RMSE: 24.428557, MSE: 596.754375, NMSE: 0.0027292538
#
# ===== RUN 60/60 [Noise 0.0%] =====
#   Epoch 10/100 completed, Loss: 0.085280
#   Epoch 20/100 completed, Loss: 0.085238
#   Epoch 30/100 completed, Loss: 0.085179
#   Epoch 40/100 completed, Loss: 0.085040
#   Epoch 50/100 completed, Loss: 0.084829
#   Epoch 60/100 completed, Loss: 0.084692
#   Epoch 70/100 completed, Loss: 0.084595
#   Epoch 80/100 completed, Loss: 0.084504
#   Epoch 90/100 completed, Loss: 0.084419
#   Epoch 100/100 completed, Loss: 0.084348
# Training complete for run 60
# Run 60 Metrics — RMSE: 24.304004, MSE: 590.684595, NMSE: 0.0027424196
#
# Best run for 0.0% noise: Run 8 (RMSE: 23.831990)
#
# ================================================================================
# EVALUATING NOISE LEVEL: 0.5% (lambda=0.005, sigma=0.526428)
# ================================================================================
#
#
# ===== RUN 1/60 [Noise 0.5%] =====
#   Epoch 10/100 completed, Loss: 0.086893
#   Epoch 20/100 completed, Loss: 0.086797
#   Epoch 30/100 completed, Loss: 0.086706
#   Epoch 40/100 completed, Loss: 0.086600
#   Epoch 50/100 completed, Loss: 0.086506
#   Epoch 60/100 completed, Loss: 0.086466
#   Epoch 70/100 completed, Loss: 0.086434
#   Epoch 80/100 completed, Loss: 0.086398
#   Epoch 90/100 completed, Loss: 0.086742
#   Epoch 100/100 completed, Loss: 0.086669
# Training complete for run 1
# Run 1 Metrics — RMSE: 24.448924, MSE: 597.749863, NMSE: 0.0027398041
#
# ===== RUN 2/60 [Noise 0.5%] =====
#   Epoch 10/100 completed, Loss: 0.087427
#   Epoch 20/100 completed, Loss: 0.087019
#   Epoch 30/100 completed, Loss: 0.086817
#   Epoch 40/100 completed, Loss: 0.086724
#   Epoch 50/100 completed, Loss: 0.086666
#   Epoch 60/100 completed, Loss: 0.086604
#   Epoch 70/100 completed, Loss: 0.086559
#   Epoch 80/100 completed, Loss: 0.086510
#   Epoch 90/100 completed, Loss: 0.086438
#   Epoch 100/100 completed, Loss: 0.086361
# Training complete for run 2
# Run 2 Metrics — RMSE: 24.485583, MSE: 599.543782, NMSE: 0.0027482641
#
# ===== RUN 3/60 [Noise 0.5%] =====
#   Epoch 10/100 completed, Loss: 0.087043
#   Epoch 20/100 completed, Loss: 0.086907
#   Epoch 30/100 completed, Loss: 0.086826
#   Epoch 40/100 completed, Loss: 0.086754
#   Epoch 50/100 completed, Loss: 0.086710
#   Epoch 60/100 completed, Loss: 0.086669
#   Epoch 70/100 completed, Loss: 0.086623
#   Epoch 80/100 completed, Loss: 0.086550
#   Epoch 90/100 completed, Loss: 0.086388
#   Epoch 100/100 completed, Loss: 0.086022
# Training complete for run 3
# Run 3 Metrics — RMSE: 24.258243, MSE: 588.462359, NMSE: 0.0026912900
#
# ===== RUN 4/60 [Noise 0.5%] =====
#   Epoch 10/100 completed, Loss: 0.086971
#   Epoch 20/100 completed, Loss: 0.086889
#   Epoch 30/100 completed, Loss: 0.086848
#   Epoch 40/100 completed, Loss: 0.086820
#   Epoch 50/100 completed, Loss: 0.086797
#   Epoch 60/100 completed, Loss: 0.086776
#   Epoch 70/100 completed, Loss: 0.086751
#   Epoch 80/100 completed, Loss: 0.086713
#   Epoch 90/100 completed, Loss: 0.086647
#   Epoch 100/100 completed, Loss: 0.086540
# Training complete for run 4
# Run 4 Metrics — RMSE: 24.400482, MSE: 595.383530, NMSE: 0.0027368813
#
# ===== RUN 5/60 [Noise 0.5%] =====
#   Epoch 10/100 completed, Loss: 0.086715
#   Epoch 20/100 completed, Loss: 0.086690
#   Epoch 30/100 completed, Loss: 0.086674
#   Epoch 40/100 completed, Loss: 0.086654
#   Epoch 50/100 completed, Loss: 0.086610
#   Epoch 60/100 completed, Loss: 0.086492
#   Epoch 70/100 completed, Loss: 0.086315
#   Epoch 80/100 completed, Loss: 0.086138
#   Epoch 90/100 completed, Loss: 0.085967
#   Epoch 100/100 completed, Loss: 0.085801
# Training complete for run 5
# Run 5 Metrics — RMSE: 24.302194, MSE: 590.596652, NMSE: 0.0027312100
#
# ===== RUN 6/60 [Noise 0.5%] =====
#   Epoch 10/100 completed, Loss: 0.086893
#   Epoch 20/100 completed, Loss: 0.086820
#   Epoch 30/100 completed, Loss: 0.086782
#   Epoch 40/100 completed, Loss: 0.086754
#   Epoch 50/100 completed, Loss: 0.086727
#   Epoch 60/100 completed, Loss: 0.086696
#   Epoch 70/100 completed, Loss: 0.086646
#   Epoch 80/100 completed, Loss: 0.086608
#   Epoch 90/100 completed, Loss: 0.086576
#   Epoch 100/100 completed, Loss: 0.086509
# Training complete for run 6
# Run 6 Metrics — RMSE: 24.537188, MSE: 602.073603, NMSE: 0.0027573913
#
# ===== RUN 7/60 [Noise 0.5%] =====
#   Epoch 10/100 completed, Loss: 0.087667
#   Epoch 20/100 completed, Loss: 0.087282
#   Epoch 30/100 completed, Loss: 0.087089
#   Epoch 40/100 completed, Loss: 0.086957
#   Epoch 50/100 completed, Loss: 0.086852
#   Epoch 60/100 completed, Loss: 0.086765
#   Epoch 70/100 completed, Loss: 0.086692
#   Epoch 80/100 completed, Loss: 0.086622
#   Epoch 90/100 completed, Loss: 0.086534
#   Epoch 100/100 completed, Loss: 0.086410
# Training complete for run 7
# Run 7 Metrics — RMSE: 24.313686, MSE: 591.155308, NMSE: 0.0026822971
#
# ===== RUN 8/60 [Noise 0.5%] =====
#   Epoch 10/100 completed, Loss: 0.087324
#   Epoch 20/100 completed, Loss: 0.087066
#   Epoch 30/100 completed, Loss: 0.086947
#   Epoch 40/100 completed, Loss: 0.086805
#   Epoch 50/100 completed, Loss: 0.086687
#   Epoch 60/100 completed, Loss: 0.086618
#   Epoch 70/100 completed, Loss: 0.086578
#   Epoch 80/100 completed, Loss: 0.086554
#   Epoch 90/100 completed, Loss: 0.086530
#   Epoch 100/100 completed, Loss: 0.086488
# Training complete for run 8
# Run 8 Metrics — RMSE: 24.459268, MSE: 598.255783, NMSE: 0.0027395281
#
# ===== RUN 9/60 [Noise 0.5%] =====
#   Epoch 10/100 completed, Loss: 0.087029
#   Epoch 20/100 completed, Loss: 0.086887
#   Epoch 30/100 completed, Loss: 0.086847
#   Epoch 40/100 completed, Loss: 0.086773
#   Epoch 50/100 completed, Loss: 0.086726
#   Epoch 60/100 completed, Loss: 0.086687
#   Epoch 70/100 completed, Loss: 0.086647
#   Epoch 80/100 completed, Loss: 0.086612
#   Epoch 90/100 completed, Loss: 0.086563
#   Epoch 100/100 completed, Loss: 0.086484
# Training complete for run 9
# Run 9 Metrics — RMSE: 24.529066, MSE: 601.675089, NMSE: 0.0027568737
#
# ===== RUN 10/60 [Noise 0.5%] =====
#   Epoch 10/100 completed, Loss: 0.087231
#   Epoch 20/100 completed, Loss: 0.087086
#   Epoch 30/100 completed, Loss: 0.086985
#   Epoch 40/100 completed, Loss: 0.086906
#   Epoch 50/100 completed, Loss: 0.086845
#   Epoch 60/100 completed, Loss: 0.086800
#   Epoch 70/100 completed, Loss: 0.086760
#   Epoch 80/100 completed, Loss: 0.086737
#   Epoch 90/100 completed, Loss: 0.086719
#   Epoch 100/100 completed, Loss: 0.086678
# Training complete for run 10
# Run 10 Metrics — RMSE: 24.479899, MSE: 599.265433, NMSE: 0.0027403814
#
# ===== RUN 11/60 [Noise 0.5%] =====
#   Epoch 10/100 completed, Loss: 0.087092
#   Epoch 20/100 completed, Loss: 0.086978
#   Epoch 30/100 completed, Loss: 0.086914
#   Epoch 40/100 completed, Loss: 0.086869
#   Epoch 50/100 completed, Loss: 0.086834
#   Epoch 60/100 completed, Loss: 0.086804
#   Epoch 70/100 completed, Loss: 0.086778
#   Epoch 80/100 completed, Loss: 0.086753
#   Epoch 90/100 completed, Loss: 0.086730
#   Epoch 100/100 completed, Loss: 0.086710
# Training complete for run 11
# Run 11 Metrics — RMSE: 24.389576, MSE: 594.851420, NMSE: 0.0027273384
#
# ===== RUN 12/60 [Noise 0.5%] =====
#   Epoch 10/100 completed, Loss: 0.087192
#   Epoch 20/100 completed, Loss: 0.087037
#   Epoch 30/100 completed, Loss: 0.086955
#   Epoch 40/100 completed, Loss: 0.086893
#   Epoch 50/100 completed, Loss: 0.086845
#   Epoch 60/100 completed, Loss: 0.086804
#   Epoch 70/100 completed, Loss: 0.086767
#   Epoch 80/100 completed, Loss: 0.086730
#   Epoch 90/100 completed, Loss: 0.086699
#   Epoch 100/100 completed, Loss: 0.086663
# Training complete for run 12
# Run 12 Metrics — RMSE: 24.420348, MSE: 596.353374, NMSE: 0.0027155748
#
# ===== RUN 13/60 [Noise 0.5%] =====
#   Epoch 10/100 completed, Loss: 0.087180
#   Epoch 20/100 completed, Loss: 0.087050
#   Epoch 30/100 completed, Loss: 0.086920
#   Epoch 40/100 completed, Loss: 0.086844
#   Epoch 50/100 completed, Loss: 0.086753
#   Epoch 60/100 completed, Loss: 0.086696
#   Epoch 70/100 completed, Loss: 0.086619
#   Epoch 80/100 completed, Loss: 0.086454
#   Epoch 90/100 completed, Loss: 0.086628
#   Epoch 100/100 completed, Loss: 0.086321
# Training complete for run 13
# Run 13 Metrics — RMSE: 24.483011, MSE: 599.417809, NMSE: 0.0027423151
#
# ===== RUN 14/60 [Noise 0.5%] =====
#   Epoch 10/100 completed, Loss: 0.086978
#   Epoch 20/100 completed, Loss: 0.086898
#   Epoch 30/100 completed, Loss: 0.086849
#   Epoch 40/100 completed, Loss: 0.086804
#   Epoch 50/100 completed, Loss: 0.086761
#   Epoch 60/100 completed, Loss: 0.086713
#   Epoch 70/100 completed, Loss: 0.086640
#   Epoch 80/100 completed, Loss: 0.086508
#   Epoch 90/100 completed, Loss: 0.086251
#   Epoch 100/100 completed, Loss: 0.085816
# Training complete for run 14
# Run 14 Metrics — RMSE: 24.175872, MSE: 584.472776, NMSE: 0.0026728728
#
# ===== RUN 15/60 [Noise 0.5%] =====
#   Epoch 10/100 completed, Loss: 0.086695
#   Epoch 20/100 completed, Loss: 0.086668
#   Epoch 30/100 completed, Loss: 0.086631
#   Epoch 40/100 completed, Loss: 0.086583
#   Epoch 50/100 completed, Loss: 0.086521
#   Epoch 60/100 completed, Loss: 0.086444
#   Epoch 70/100 completed, Loss: 0.086346
#   Epoch 80/100 completed, Loss: 0.086224
#   Epoch 90/100 completed, Loss: 0.087001
#   Epoch 100/100 completed, Loss: 0.086355
# Training complete for run 15
# Run 15 Metrics — RMSE: 24.510970, MSE: 600.787642, NMSE: 0.0027544257
#
# ===== RUN 16/60 [Noise 0.5%] =====
#   Epoch 10/100 completed, Loss: 0.087486
#   Epoch 20/100 completed, Loss: 0.087149
#   Epoch 30/100 completed, Loss: 0.087025
#   Epoch 40/100 completed, Loss: 0.086950
#   Epoch 50/100 completed, Loss: 0.086893
#   Epoch 60/100 completed, Loss: 0.086847
#   Epoch 70/100 completed, Loss: 0.086809
#   Epoch 80/100 completed, Loss: 0.086777
#   Epoch 90/100 completed, Loss: 0.086749
#   Epoch 100/100 completed, Loss: 0.086724
# Training complete for run 16
# Run 16 Metrics — RMSE: 24.375647, MSE: 594.172176, NMSE: 0.0027023532
#
# ===== RUN 17/60 [Noise 0.5%] =====
#   Epoch 10/100 completed, Loss: 0.087407
#   Epoch 20/100 completed, Loss: 0.087111
#   Epoch 30/100 completed, Loss: 0.086969
#   Epoch 40/100 completed, Loss: 0.086883
#   Epoch 50/100 completed, Loss: 0.086826
#   Epoch 60/100 completed, Loss: 0.086789
#   Epoch 70/100 completed, Loss: 0.086768
#   Epoch 80/100 completed, Loss: 0.086756
#   Epoch 90/100 completed, Loss: 0.086743
#   Epoch 100/100 completed, Loss: 0.086723
# Training complete for run 17
# Run 17 Metrics — RMSE: 24.439100, MSE: 597.269633, NMSE: 0.0027296901
#
# ===== RUN 18/60 [Noise 0.5%] =====
#   Epoch 10/100 completed, Loss: 0.086962
#   Epoch 20/100 completed, Loss: 0.086844
#   Epoch 30/100 completed, Loss: 0.086771
#   Epoch 40/100 completed, Loss: 0.086733
#   Epoch 50/100 completed, Loss: 0.086695
#   Epoch 60/100 completed, Loss: 0.086656
#   Epoch 70/100 completed, Loss: 0.086622
#   Epoch 80/100 completed, Loss: 0.086592
#   Epoch 90/100 completed, Loss: 0.086547
#   Epoch 100/100 completed, Loss: 0.086501
# Training complete for run 18
# Run 18 Metrics — RMSE: 24.504219, MSE: 600.456739, NMSE: 0.0027527897
#
# ===== RUN 19/60 [Noise 0.5%] =====
#   Epoch 10/100 completed, Loss: 0.087007
#   Epoch 20/100 completed, Loss: 0.086807
#   Epoch 30/100 completed, Loss: 0.086741
#   Epoch 40/100 completed, Loss: 0.086712
#   Epoch 50/100 completed, Loss: 0.086694
#   Epoch 60/100 completed, Loss: 0.086677
#   Epoch 70/100 completed, Loss: 0.086660
#   Epoch 80/100 completed, Loss: 0.086641
#   Epoch 90/100 completed, Loss: 0.086620
#   Epoch 100/100 completed, Loss: 0.086592
# Training complete for run 19
# Run 19 Metrics — RMSE: 24.363752, MSE: 593.592434, NMSE: 0.0027383092
#
# ===== RUN 20/60 [Noise 0.5%] =====
#   Epoch 10/100 completed, Loss: 0.087189
#   Epoch 20/100 completed, Loss: 0.087017
#   Epoch 30/100 completed, Loss: 0.086933
#   Epoch 40/100 completed, Loss: 0.086874
#   Epoch 50/100 completed, Loss: 0.086825
#   Epoch 60/100 completed, Loss: 0.086780
#   Epoch 70/100 completed, Loss: 0.086736
#   Epoch 80/100 completed, Loss: 0.086698
#   Epoch 90/100 completed, Loss: 0.086662
#   Epoch 100/100 completed, Loss: 0.086643
# Training complete for run 20
# Run 20 Metrics — RMSE: 24.485892, MSE: 599.558925, NMSE: 0.0027459993
#
# ===== RUN 21/60 [Noise 0.5%] =====
#   Epoch 10/100 completed, Loss: 0.086865
#   Epoch 20/100 completed, Loss: 0.086745
#   Epoch 30/100 completed, Loss: 0.086671
#   Epoch 40/100 completed, Loss: 0.086632
#   Epoch 50/100 completed, Loss: 0.086606
#   Epoch 60/100 completed, Loss: 0.086556
#   Epoch 70/100 completed, Loss: 0.086459
#   Epoch 80/100 completed, Loss: 0.086293
#   Epoch 90/100 completed, Loss: 0.086072
#   Epoch 100/100 completed, Loss: 0.085816
# Training complete for run 21
# Run 21 Metrics — RMSE: 24.313262, MSE: 591.134698, NMSE: 0.0026988293
#
# ===== RUN 22/60 [Noise 0.5%] =====
#   Epoch 10/100 completed, Loss: 0.086699
#   Epoch 20/100 completed, Loss: 0.086691
#   Epoch 30/100 completed, Loss: 0.086670
#   Epoch 40/100 completed, Loss: 0.086652
#   Epoch 50/100 completed, Loss: 0.086635
#   Epoch 60/100 completed, Loss: 0.086618
#   Epoch 70/100 completed, Loss: 0.086592
#   Epoch 80/100 completed, Loss: 0.086530
#   Epoch 90/100 completed, Loss: 0.086507
#   Epoch 100/100 completed, Loss: 0.086320
# Training complete for run 22
# Run 22 Metrics — RMSE: 24.397687, MSE: 595.247131, NMSE: 0.0027396103
#
# ===== RUN 23/60 [Noise 0.5%] =====
#   Epoch 10/100 completed, Loss: 0.087179
#   Epoch 20/100 completed, Loss: 0.086998
#   Epoch 30/100 completed, Loss: 0.086897
#   Epoch 40/100 completed, Loss: 0.086829
#   Epoch 50/100 completed, Loss: 0.086784
#   Epoch 60/100 completed, Loss: 0.086752
#   Epoch 70/100 completed, Loss: 0.086748
#   Epoch 80/100 completed, Loss: 0.086724
#   Epoch 90/100 completed, Loss: 0.086709
#   Epoch 100/100 completed, Loss: 0.086689
# Training complete for run 23
# Run 23 Metrics — RMSE: 24.429638, MSE: 596.807215, NMSE: 0.0027373680
#
# ===== RUN 24/60 [Noise 0.5%] =====
#   Epoch 10/100 completed, Loss: 0.087205
#   Epoch 20/100 completed, Loss: 0.087009
#   Epoch 30/100 completed, Loss: 0.086927
#   Epoch 40/100 completed, Loss: 0.086876
#   Epoch 50/100 completed, Loss: 0.086831
#   Epoch 60/100 completed, Loss: 0.086785
#   Epoch 70/100 completed, Loss: 0.086731
#   Epoch 80/100 completed, Loss: 0.086664
#   Epoch 90/100 completed, Loss: 0.086566
#   Epoch 100/100 completed, Loss: 0.086526
# Training complete for run 24
# Run 24 Metrics — RMSE: 24.346297, MSE: 592.742172, NMSE: 0.0027222786
#
# ===== RUN 25/60 [Noise 0.5%] =====
#   Epoch 10/100 completed, Loss: 0.086906
#   Epoch 20/100 completed, Loss: 0.086834
#   Epoch 30/100 completed, Loss: 0.086792
#   Epoch 40/100 completed, Loss: 0.086734
#   Epoch 50/100 completed, Loss: 0.086632
#   Epoch 60/100 completed, Loss: 0.086443
#   Epoch 70/100 completed, Loss: 0.086159
#   Epoch 80/100 completed, Loss: 0.085823
#   Epoch 90/100 completed, Loss: 0.085405
#   Epoch 100/100 completed, Loss: 0.085006
# Training complete for run 25
# Run 25 Metrics — RMSE: 24.365269, MSE: 593.666325, NMSE: 0.0027376836
#
# ===== RUN 26/60 [Noise 0.5%] =====
#   Epoch 10/100 completed, Loss: 0.087336
#   Epoch 20/100 completed, Loss: 0.087107
#   Epoch 30/100 completed, Loss: 0.086994
#   Epoch 40/100 completed, Loss: 0.086915
#   Epoch 50/100 completed, Loss: 0.086854
#   Epoch 60/100 completed, Loss: 0.086807
#   Epoch 70/100 completed, Loss: 0.086770
#   Epoch 80/100 completed, Loss: 0.086739
#   Epoch 90/100 completed, Loss: 0.086713
#   Epoch 100/100 completed, Loss: 0.086691
# Training complete for run 26
# Run 26 Metrics — RMSE: 24.385347, MSE: 594.645157, NMSE: 0.0027117995
#
# ===== RUN 27/60 [Noise 0.5%] =====
#   Epoch 10/100 completed, Loss: 0.087401
#   Epoch 20/100 completed, Loss: 0.087176
#   Epoch 30/100 completed, Loss: 0.087068
#   Epoch 40/100 completed, Loss: 0.086992
#   Epoch 50/100 completed, Loss: 0.086934
#   Epoch 60/100 completed, Loss: 0.086887
#   Epoch 70/100 completed, Loss: 0.086850
#   Epoch 80/100 completed, Loss: 0.086819
#   Epoch 90/100 completed, Loss: 0.086794
#   Epoch 100/100 completed, Loss: 0.086772
# Training complete for run 27
# Run 27 Metrics — RMSE: 24.474097, MSE: 598.981442, NMSE: 0.0027369176
#
# ===== RUN 28/60 [Noise 0.5%] =====
#   Epoch 10/100 completed, Loss: 0.087159
#   Epoch 20/100 completed, Loss: 0.086990
#   Epoch 30/100 completed, Loss: 0.086899
#   Epoch 40/100 completed, Loss: 0.086841
#   Epoch 50/100 completed, Loss: 0.086799
#   Epoch 60/100 completed, Loss: 0.086768
#   Epoch 70/100 completed, Loss: 0.086748
#   Epoch 80/100 completed, Loss: 0.086737
# ...
# Run 31 Metrics — RMSE: 30.364113, MSE: 921.979370, NMSE: 0.0046359395
#
# ===== RUN 32/60 [Noise 10.0%] =====
#   Epoch 10/100 completed, Loss: 0.114884
#   Epoch 20/100 completed, Loss: 0.114290
#   Epoch 30/100 completed, Loss: 0.113954
#   Epoch 40/100 completed, Loss: 0.113614
#   Epoch 50/100 completed, Loss: 0.113178
#   Epoch 60/100 completed, Loss: 0.112501
#   Epoch 70/100 completed, Loss: 0.111221
#   Epoch 80/100 completed, Loss: 0.110260
#   Epoch 90/100 completed, Loss: 0.109619
#   Epoch 100/100 completed, Loss: 0.109278
# Training complete for run 32
# Run 32 Metrics — RMSE: 31.247823, MSE: 976.426422, NMSE: 0.0049631686
#
# ===== RUN 33/60 [Noise 10.0%] =====
#   Epoch 10/100 completed, Loss: 0.115167
#   Epoch 20/100 completed, Loss: 0.114853
#   Epoch 30/100 completed, Loss: 0.114530
#   Epoch 40/100 completed, Loss: 0.114066
#   Epoch 50/100 completed, Loss: 0.113457
#   Epoch 60/100 completed, Loss: 0.112928
#   Epoch 70/100 completed, Loss: 0.112599
#   Epoch 80/100 completed, Loss: 0.112387
#   Epoch 90/100 completed, Loss: 0.112221
#   Epoch 100/100 completed, Loss: 0.112067
# Training complete for run 33
# Run 33 Metrics — RMSE: 30.368796, MSE: 922.263777, NMSE: 0.0044620316
#
# ===== RUN 34/60 [Noise 10.0%] =====
#   Epoch 10/100 completed, Loss: 0.115269
#   Epoch 20/100 completed, Loss: 0.115028
#   Epoch 30/100 completed, Loss: 0.114833
#   Epoch 40/100 completed, Loss: 0.114594
#   Epoch 50/100 completed, Loss: 0.114271
#   Epoch 60/100 completed, Loss: 0.113824
#   Epoch 70/100 completed, Loss: 0.113192
#   Epoch 80/100 completed, Loss: 0.112422
#   Epoch 90/100 completed, Loss: 0.111763
#   Epoch 100/100 completed, Loss: 0.111306
# Training complete for run 34
# Run 34 Metrics — RMSE: 30.480248, MSE: 929.045507, NMSE: 0.0045965408
#
# ===== RUN 35/60 [Noise 10.0%] =====
#   Epoch 10/100 completed, Loss: 0.116018
#   Epoch 20/100 completed, Loss: 0.114968
#   Epoch 30/100 completed, Loss: 0.114505
#   Epoch 40/100 completed, Loss: 0.114076
#   Epoch 50/100 completed, Loss: 0.113585
#   Epoch 60/100 completed, Loss: 0.113070
#   Epoch 70/100 completed, Loss: 0.112692
#   Epoch 80/100 completed, Loss: 0.112500
#   Epoch 90/100 completed, Loss: 0.112391
#   Epoch 100/100 completed, Loss: 0.112309
# Training complete for run 35
# Run 35 Metrics — RMSE: 30.635420, MSE: 938.528981, NMSE: 0.0045605550
#
# ===== RUN 36/60 [Noise 10.0%] =====
#   Epoch 10/100 completed, Loss: 0.115045
#   Epoch 20/100 completed, Loss: 0.114657
#   Epoch 30/100 completed, Loss: 0.114375
#   Epoch 40/100 completed, Loss: 0.114086
#   Epoch 50/100 completed, Loss: 0.113773
#   Epoch 60/100 completed, Loss: 0.113437
#   Epoch 70/100 completed, Loss: 0.113090
#   Epoch 80/100 completed, Loss: 0.112778
#   Epoch 90/100 completed, Loss: 0.112540
#   Epoch 100/100 completed, Loss: 0.112363
# Training complete for run 36
# Run 36 Metrics — RMSE: 30.358606, MSE: 921.644958, NMSE: 0.0044570265
#
# ===== RUN 37/60 [Noise 10.0%] =====
#   Epoch 10/100 completed, Loss: 0.114327
#   Epoch 20/100 completed, Loss: 0.113447
#   Epoch 30/100 completed, Loss: 0.113004
#   Epoch 40/100 completed, Loss: 0.112753
#   Epoch 50/100 completed, Loss: 0.112604
#   Epoch 60/100 completed, Loss: 0.112492
#   Epoch 70/100 completed, Loss: 0.112390
#   Epoch 80/100 completed, Loss: 0.112300
#   Epoch 90/100 completed, Loss: 0.112213
#   Epoch 100/100 completed, Loss: 0.112120
# Training complete for run 37
# Run 37 Metrics — RMSE: 30.697181, MSE: 942.316938, NMSE: 0.0045271750
#
# ===== RUN 38/60 [Noise 10.0%] =====
#   Epoch 10/100 completed, Loss: 0.114778
#   Epoch 20/100 completed, Loss: 0.114154
#   Epoch 30/100 completed, Loss: 0.113692
#   Epoch 40/100 completed, Loss: 0.113334
#   Epoch 50/100 completed, Loss: 0.113067
#   Epoch 60/100 completed, Loss: 0.112817
#   Epoch 70/100 completed, Loss: 0.112606
#   Epoch 80/100 completed, Loss: 0.112446
#   Epoch 90/100 completed, Loss: 0.112312
#   Epoch 100/100 completed, Loss: 0.112151
# Training complete for run 38
# Run 38 Metrics — RMSE: 30.335279, MSE: 920.229141, NMSE: 0.0044083554
#
# ===== RUN 39/60 [Noise 10.0%] =====
#   Epoch 10/100 completed, Loss: 0.115590
#   Epoch 20/100 completed, Loss: 0.114955
#   Epoch 30/100 completed, Loss: 0.114773
#   Epoch 40/100 completed, Loss: 0.114605
#   Epoch 50/100 completed, Loss: 0.114403
#   Epoch 60/100 completed, Loss: 0.114147
#   Epoch 70/100 completed, Loss: 0.113854
#   Epoch 80/100 completed, Loss: 0.113595
#   Epoch 90/100 completed, Loss: 0.113215
#   Epoch 100/100 completed, Loss: 0.112716
# Training complete for run 39
# Run 39 Metrics — RMSE: 30.440545, MSE: 926.626782, NMSE: 0.0044190646
#
# ===== RUN 40/60 [Noise 10.0%] =====
#   Epoch 10/100 completed, Loss: 0.115322
#   Epoch 20/100 completed, Loss: 0.115138
#   Epoch 30/100 completed, Loss: 0.114992
#   Epoch 40/100 completed, Loss: 0.114840
#   Epoch 50/100 completed, Loss: 0.114678
#   Epoch 60/100 completed, Loss: 0.114505
#   Epoch 70/100 completed, Loss: 0.114318
#   Epoch 80/100 completed, Loss: 0.114113
#   Epoch 90/100 completed, Loss: 0.113888
#   Epoch 100/100 completed, Loss: 0.113645
# Training complete for run 40
# Run 40 Metrics — RMSE: 30.463817, MSE: 928.044124, NMSE: 0.0043155846
#
# ===== RUN 41/60 [Noise 10.0%] =====
#   Epoch 10/100 completed, Loss: 0.115611
#   Epoch 20/100 completed, Loss: 0.114695
#   Epoch 30/100 completed, Loss: 0.113939
#   Epoch 40/100 completed, Loss: 0.113544
#   Epoch 50/100 completed, Loss: 0.113227
#   Epoch 60/100 completed, Loss: 0.112944
#   Epoch 70/100 completed, Loss: 0.112667
#   Epoch 80/100 completed, Loss: 0.112396
#   Epoch 90/100 completed, Loss: 0.112172
#   Epoch 100/100 completed, Loss: 0.111918
# Training complete for run 41
# Run 41 Metrics — RMSE: 30.552009, MSE: 933.425246, NMSE: 0.0045982551
#
# ===== RUN 42/60 [Noise 10.0%] =====
#   Epoch 10/100 completed, Loss: 0.115258
#   Epoch 20/100 completed, Loss: 0.114359
#   Epoch 30/100 completed, Loss: 0.113753
#   Epoch 40/100 completed, Loss: 0.113176
#   Epoch 50/100 completed, Loss: 0.112763
#   Epoch 60/100 completed, Loss: 0.112517
#   Epoch 70/100 completed, Loss: 0.112356
#   Epoch 80/100 completed, Loss: 0.112227
#   Epoch 90/100 completed, Loss: 0.112114
#   Epoch 100/100 completed, Loss: 0.111992
# Training complete for run 42
# Run 42 Metrics — RMSE: 30.492016, MSE: 929.763049, NMSE: 0.0045058479
#
# ===== RUN 43/60 [Noise 10.0%] =====
#   Epoch 10/100 completed, Loss: 0.114168
#   Epoch 20/100 completed, Loss: 0.113305
#   Epoch 30/100 completed, Loss: 0.112886
#   Epoch 40/100 completed, Loss: 0.112711
#   Epoch 50/100 completed, Loss: 0.112640
#   Epoch 60/100 completed, Loss: 0.112591
#   Epoch 70/100 completed, Loss: 0.112511
#   Epoch 80/100 completed, Loss: 0.112336
#   Epoch 90/100 completed, Loss: 0.111952
#   Epoch 100/100 completed, Loss: 0.111270
# Training complete for run 43
# Run 43 Metrics — RMSE: 30.864996, MSE: 952.647967, NMSE: 0.0048524196
#
# ===== RUN 44/60 [Noise 10.0%] =====
#   Epoch 10/100 completed, Loss: 0.114937
#   Epoch 20/100 completed, Loss: 0.114484
#   Epoch 30/100 completed, Loss: 0.114108
#   Epoch 40/100 completed, Loss: 0.113734
#   Epoch 50/100 completed, Loss: 0.113397
#   Epoch 60/100 completed, Loss: 0.113117
#   Epoch 70/100 completed, Loss: 0.112876
#   Epoch 80/100 completed, Loss: 0.112654
#   Epoch 90/100 completed, Loss: 0.112437
#   Epoch 100/100 completed, Loss: 0.112219
# Training complete for run 44
# Run 44 Metrics — RMSE: 30.270326, MSE: 916.292616, NMSE: 0.0044247059
#
# ===== RUN 45/60 [Noise 10.0%] =====
#   Epoch 10/100 completed, Loss: 0.114569
#   Epoch 20/100 completed, Loss: 0.113568
#   Epoch 30/100 completed, Loss: 0.112710
#   Epoch 40/100 completed, Loss: 0.111768
#   Epoch 50/100 completed, Loss: 0.111243
#   Epoch 60/100 completed, Loss: 0.111419
#   Epoch 70/100 completed, Loss: 0.111187
#   Epoch 80/100 completed, Loss: 0.110648
#   Epoch 90/100 completed, Loss: 0.110404
#   Epoch 100/100 completed, Loss: 0.110132
# Training complete for run 45
# Run 45 Metrics — RMSE: 31.394919, MSE: 985.640935, NMSE: 0.0051100176
#
# ===== RUN 46/60 [Noise 10.0%] =====
#   Epoch 10/100 completed, Loss: 0.115501
#   Epoch 20/100 completed, Loss: 0.115281
#   Epoch 30/100 completed, Loss: 0.115079
#   Epoch 40/100 completed, Loss: 0.114796
#   Epoch 50/100 completed, Loss: 0.114361
#   Epoch 60/100 completed, Loss: 0.113854
#   Epoch 70/100 completed, Loss: 0.113387
#   Epoch 80/100 completed, Loss: 0.112990
#   Epoch 90/100 completed, Loss: 0.112688
#   Epoch 100/100 completed, Loss: 0.112454
# Training complete for run 46
# Run 46 Metrics — RMSE: 30.455087, MSE: 927.512327, NMSE: 0.0044836924
#
# ===== RUN 47/60 [Noise 10.0%] =====
#   Epoch 10/100 completed, Loss: 0.114948
#   Epoch 20/100 completed, Loss: 0.114628
#   Epoch 30/100 completed, Loss: 0.114476
#   Epoch 40/100 completed, Loss: 0.114318
#   Epoch 50/100 completed, Loss: 0.114146
#   Epoch 60/100 completed, Loss: 0.113963
#   Epoch 70/100 completed, Loss: 0.113765
#   Epoch 80/100 completed, Loss: 0.113533
#   Epoch 90/100 completed, Loss: 0.113244
#   Epoch 100/100 completed, Loss: 0.112897
# Training complete for run 47
# Run 47 Metrics — RMSE: 30.479419, MSE: 928.994956, NMSE: 0.0043977085
#
# ===== RUN 48/60 [Noise 10.0%] =====
#   Epoch 10/100 completed, Loss: 0.115371
#   Epoch 20/100 completed, Loss: 0.114993
#   Epoch 30/100 completed, Loss: 0.114741
#   Epoch 40/100 completed, Loss: 0.114421
#   Epoch 50/100 completed, Loss: 0.114026
#   Epoch 60/100 completed, Loss: 0.113572
#   Epoch 70/100 completed, Loss: 0.113115
#   Epoch 80/100 completed, Loss: 0.112740
#   Epoch 90/100 completed, Loss: 0.112449
#   Epoch 100/100 completed, Loss: 0.112224
# Training complete for run 48
# Run 48 Metrics — RMSE: 30.321967, MSE: 919.421658, NMSE: 0.0044682289
#
# ===== RUN 49/60 [Noise 10.0%] =====
#   Epoch 10/100 completed, Loss: 0.115291
#   Epoch 20/100 completed, Loss: 0.114872
#   Epoch 30/100 completed, Loss: 0.114423
#   Epoch 40/100 completed, Loss: 0.114144
#   Epoch 50/100 completed, Loss: 0.113944
#   Epoch 60/100 completed, Loss: 0.113724
#   Epoch 70/100 completed, Loss: 0.113468
#   Epoch 80/100 completed, Loss: 0.113170
#   Epoch 90/100 completed, Loss: 0.112765
#   Epoch 100/100 completed, Loss: 0.112437
# Training complete for run 49
# Run 49 Metrics — RMSE: 30.532304, MSE: 932.221560, NMSE: 0.0044173459
#
# ===== RUN 50/60 [Noise 10.0%] =====
#   Epoch 10/100 completed, Loss: 0.115924
#   Epoch 20/100 completed, Loss: 0.115070
#   Epoch 30/100 completed, Loss: 0.114730
#   Epoch 40/100 completed, Loss: 0.114407
#   Epoch 50/100 completed, Loss: 0.114087
#   Epoch 60/100 completed, Loss: 0.113776
#   Epoch 70/100 completed, Loss: 0.113481
#   Epoch 80/100 completed, Loss: 0.113211
#   Epoch 90/100 completed, Loss: 0.112962
#   Epoch 100/100 completed, Loss: 0.112722
# Training complete for run 50
# Run 50 Metrics — RMSE: 30.783384, MSE: 947.616708, NMSE: 0.0045158776
#
# ===== RUN 51/60 [Noise 10.0%] =====
#   Epoch 10/100 completed, Loss: 0.115402
#   Epoch 20/100 completed, Loss: 0.114955
#   Epoch 30/100 completed, Loss: 0.114631
#   Epoch 40/100 completed, Loss: 0.114269
#   Epoch 50/100 completed, Loss: 0.113896
#   Epoch 60/100 completed, Loss: 0.113589
#   Epoch 70/100 completed, Loss: 0.113347
#   Epoch 80/100 completed, Loss: 0.113157
#   Epoch 90/100 completed, Loss: 0.113006
#   Epoch 100/100 completed, Loss: 0.112867
# Training complete for run 51
# Run 51 Metrics — RMSE: 30.440016, MSE: 926.594553, NMSE: 0.0044773599
#
# ===== RUN 52/60 [Noise 10.0%] =====
#   Epoch 10/100 completed, Loss: 0.115601
#   Epoch 20/100 completed, Loss: 0.115130
#   Epoch 30/100 completed, Loss: 0.114913
#   Epoch 40/100 completed, Loss: 0.114597
#   Epoch 50/100 completed, Loss: 0.114129
#   Epoch 60/100 completed, Loss: 0.113661
#   Epoch 70/100 completed, Loss: 0.113280
#   Epoch 80/100 completed, Loss: 0.112978
#   Epoch 90/100 completed, Loss: 0.112745
#   Epoch 100/100 completed, Loss: 0.112561
# Training complete for run 52
# Run 52 Metrics — RMSE: 30.602607, MSE: 936.519558, NMSE: 0.0044759942
#
# ===== RUN 53/60 [Noise 10.0%] =====
#   Epoch 10/100 completed, Loss: 0.115038
#   Epoch 20/100 completed, Loss: 0.114611
#   Epoch 30/100 completed, Loss: 0.114398
#   Epoch 40/100 completed, Loss: 0.114104
#   Epoch 50/100 completed, Loss: 0.113719
#   Epoch 60/100 completed, Loss: 0.113275
#   Epoch 70/100 completed, Loss: 0.112837
#   Epoch 80/100 completed, Loss: 0.112522
#   Epoch 90/100 completed, Loss: 0.112365
#   Epoch 100/100 completed, Loss: 0.112185
# Training complete for run 53
# Run 53 Metrics — RMSE: 30.256346, MSE: 915.446489, NMSE: 0.0044059381
#
# ===== RUN 54/60 [Noise 10.0%] =====
#   Epoch 10/100 completed, Loss: 0.115686
#   Epoch 20/100 completed, Loss: 0.115213
#   Epoch 30/100 completed, Loss: 0.115000
#   Epoch 40/100 completed, Loss: 0.114841
#   Epoch 50/100 completed, Loss: 0.114700
#   Epoch 60/100 completed, Loss: 0.114561
#   Epoch 70/100 completed, Loss: 0.114413
#   Epoch 80/100 completed, Loss: 0.114248
#   Epoch 90/100 completed, Loss: 0.114053
#   Epoch 100/100 completed, Loss: 0.113820
# Training complete for run 54
# Run 54 Metrics — RMSE: 30.593046, MSE: 935.934464, NMSE: 0.0043403428
#
# ===== RUN 55/60 [Noise 10.0%] =====
#   Epoch 10/100 completed, Loss: 0.113955
#   Epoch 20/100 completed, Loss: 0.113257
#   Epoch 30/100 completed, Loss: 0.113008
#   Epoch 40/100 completed, Loss: 0.112872
#   Epoch 50/100 completed, Loss: 0.112745
#   Epoch 60/100 completed, Loss: 0.112556
#   Epoch 70/100 completed, Loss: 0.112187
#   Epoch 80/100 completed, Loss: 0.111320
#   Epoch 90/100 completed, Loss: 0.110807
#   Epoch 100/100 completed, Loss: 0.111217
# Training complete for run 55
# Run 55 Metrics — RMSE: 31.425667, MSE: 987.572543, NMSE: 0.0051110713
#
# ===== RUN 56/60 [Noise 10.0%] =====
#   Epoch 10/100 completed, Loss: 0.115151
#   Epoch 20/100 completed, Loss: 0.114813
#   Epoch 30/100 completed, Loss: 0.114651
#   Epoch 40/100 completed, Loss: 0.114498
#   Epoch 50/100 completed, Loss: 0.114338
#   Epoch 60/100 completed, Loss: 0.114170
#   Epoch 70/100 completed, Loss: 0.113989
#   Epoch 80/100 completed, Loss: 0.113782
#   Epoch 90/100 completed, Loss: 0.113542
#   Epoch 100/100 completed, Loss: 0.113258
# Training complete for run 56
# Run 56 Metrics — RMSE: 30.563214, MSE: 934.110043, NMSE: 0.0043366443
#
# ===== RUN 57/60 [Noise 10.0%] =====
#   Epoch 10/100 completed, Loss: 0.115404
#   Epoch 20/100 completed, Loss: 0.114414
#   Epoch 30/100 completed, Loss: 0.113874
#   Epoch 40/100 completed, Loss: 0.113474
#   Epoch 50/100 completed, Loss: 0.113080
#   Epoch 60/100 completed, Loss: 0.112787
#   Epoch 70/100 completed, Loss: 0.112526
#   Epoch 80/100 completed, Loss: 0.112308
#   Epoch 90/100 completed, Loss: 0.112092
#   Epoch 100/100 completed, Loss: 0.111711
# Training complete for run 57
# Run 57 Metrics — RMSE: 30.384785, MSE: 923.235173, NMSE: 0.0045627814
#
# ===== RUN 58/60 [Noise 10.0%] =====
#   Epoch 10/100 completed, Loss: 0.115753
#   Epoch 20/100 completed, Loss: 0.115224
#   Epoch 30/100 completed, Loss: 0.114892
#   Epoch 40/100 completed, Loss: 0.114467
#   Epoch 50/100 completed, Loss: 0.113918
#   Epoch 60/100 completed, Loss: 0.113410
#   Epoch 70/100 completed, Loss: 0.113034
#   Epoch 80/100 completed, Loss: 0.112773
#   Epoch 90/100 completed, Loss: 0.112593
#   Epoch 100/100 completed, Loss: 0.112457
# Training complete for run 58
# Run 58 Metrics — RMSE: 30.403773, MSE: 924.389405, NMSE: 0.0044455273
#
# ===== RUN 59/60 [Noise 10.0%] =====
#   Epoch 10/100 completed, Loss: 0.114434
#   Epoch 20/100 completed, Loss: 0.113318
#   Epoch 30/100 completed, Loss: 0.112414
#   Epoch 40/100 completed, Loss: 0.111654
#   Epoch 50/100 completed, Loss: 0.110527
#   Epoch 60/100 completed, Loss: 0.110387
#   Epoch 70/100 completed, Loss: 0.110645
#   Epoch 80/100 completed, Loss: 0.112084
#   Epoch 90/100 completed, Loss: 0.110478
#   Epoch 100/100 completed, Loss: 0.109040
# Training complete for run 59
# Run 59 Metrics — RMSE: 30.638809, MSE: 938.736614, NMSE: 0.0049590719
#
# ===== RUN 60/60 [Noise 10.0%] =====
#   Epoch 10/100 completed, Loss: 0.114651
#   Epoch 20/100 completed, Loss: 0.114191
#   Epoch 30/100 completed, Loss: 0.113810
#   Epoch 40/100 completed, Loss: 0.113479
#   Epoch 50/100 completed, Loss: 0.113182
#   Epoch 60/100 completed, Loss: 0.112902
#   Epoch 70/100 completed, Loss: 0.112626
#   Epoch 80/100 completed, Loss: 0.112345
#   Epoch 90/100 completed, Loss: 0.112049
#   Epoch 100/100 completed, Loss: 0.111728
# Training complete for run 60
# Run 60 Metrics — RMSE: 30.527405, MSE: 931.922454, NMSE: 0.0044951171
#
# Best run for 10.0% noise: Run 16 (RMSE: 29.778351)

# %% [markdown]
# ## Results

# %%
# ============================================================
# Final Metrics Summary & Plots per Noise Level
# ============================================================
from tabulate import tabulate

for lam, best_rmse, best_mse, best_nmse, best_predictions, best_losses, raw_values_for_plot in _molab_results:
    print("\n" + "="*80)
    print(f"RESULTS FOR NOISE LEVEL: {lam*100:.1f}%")
    print("="*80)
    
    print('=== Best Run Metrics ===')
    print(f'RMSE: {best_rmse:.6f}')
    print(f'MSE:  {best_mse:.6f}')
    print(f'NMSE: {best_nmse:.10f}')
    
    actual = raw_values_for_plot[-60:]
    
    plt.figure(figsize=(12, 5))
    plt.plot(actual, label='Actual', color='blue', linewidth=1.5)
    plt.plot(best_predictions, label='Predicted (Best Run)', color='red',
             linewidth=1.5, linestyle='--')
    plt.title(f'Predictions vs Actual (Noise {lam*100:.1f}%)')
    plt.xlabel('Time Step')
    plt.ylabel('Value')
    plt.legend()
    plt.grid(True, alpha=0.3)
    plt.tight_layout()
    plt.show()

    plt.figure(figsize=(12, 4))
    plt.plot(best_losses, color='green', linewidth=1.0)
    plt.title(f'Training Loss (Best Run, Noise {lam*100:.1f}%)')
    plt.xlabel('Epoch')
    plt.ylabel('MSE Loss')
    plt.grid(True, alpha=0.3)
    plt.tight_layout()
    plt.show()

# Global summary table
print("\n" + "="*80)
print("FINAL RESULTS TABLE ACROSS ALL NOISE LEVELS")
print("="*80)
df_res = pd.DataFrame([r[:4] for r in _molab_results], columns=['Noise Level (lambda)', 'RMSE', 'MSE', 'NMSE'])
print(tabulate(df_res, headers='keys', tablefmt='github', showindex=False))
# Out:
# ================================================================================
# RESULTS FOR NOISE LEVEL: 0.0%
# ================================================================================
# === Best Run Metrics ===
# RMSE: 23.831990
# MSE:  567.963745
# NMSE: 0.0026502800
# ================================================================================
# RESULTS FOR NOISE LEVEL: 0.5%
# ================================================================================
# === Best Run Metrics ===
# RMSE: 23.902755
# MSE:  571.341709
# NMSE: 0.0026693147
# ================================================================================
# RESULTS FOR NOISE LEVEL: 5.0%
# ================================================================================
# === Best Run Metrics ===
# RMSE: 25.431510
# MSE:  646.761690
# NMSE: 0.0031604590
# ================================================================================
# RESULTS FOR NOISE LEVEL: 10.0%
# ================================================================================
# === Best Run Metrics ===
# RMSE: 29.778351
# MSE:  886.750179
# NMSE: 0.0045698515
# ================================================================================
# FINAL RESULTS TABLE ACROSS ALL NOISE LEVELS
# ================================================================================
# |   Noise Level (lambda) |    RMSE |     MSE |       NMSE |
# |------------------------|---------|---------|------------|
# |                  0     | 23.832  | 567.964 | 0.00265028 |
# |                  0.005 | 23.9028 | 571.342 | 0.00266931 |
# |                  0.05  | 25.4315 | 646.762 | 0.00316046 |
# |                  0.1   | 29.7784 | 886.75  | 0.00456985 |

# %% [markdown]
# ## Observations
#
# ### Gaussian Noise robustness on Dow Jones Industrial Index
#
# **Run the notebook to populate results.**
