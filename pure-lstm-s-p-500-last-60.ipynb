# %% [markdown]
# # Pure LSTM — S&P 500 (Gaussian Noise Evaluation)
#
# Time series forecasting with Gaussian noise robustness analysis.
# - Noise levels: [0.0, 0.005, 0.05, 0.1]
# - 60 runs × 100 epochs per noise level
# - Last 60 for test, rest for training, NO validation

# %%
# ============================================================
# ALL IMPORTS
# ============================================================

import numpy as np
import pandas as pd
import torch
import torch.nn as nn
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from math import sqrt
import matplotlib.pyplot as plt
import warnings
import os

warnings.filterwarnings('ignore')
print(f"PyTorch version: {torch.__version__}")
print(f"NumPy version: {np.__version__}")
# Out:
# PyTorch version: 2.10.0+cu128
# NumPy version: 2.0.2

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

class PureLSTM(nn.Module):
    """
    Standard LSTM (Hochreiter & Schmidhuber, 1997) for time series forecasting.
    Stateful: maintains hidden and cell states across sequence steps.
    Same hyperparameters as LSTM-SNP for fair comparison.
    """
    def __init__(self, input_dim=1, hidden_dim=8, output_dim=1):
        super().__init__()
        self.hidden_dim = hidden_dim
        self.lstm = nn.LSTM(input_dim, hidden_dim, batch_first=True)
        self.fc = nn.Linear(hidden_dim, output_dim)
        self.u = None  # (h, c) state

    def reset_states(self, batch_size, device):
        h0 = torch.zeros(1, batch_size, self.hidden_dim, device=device)
        c0 = torch.zeros(1, batch_size, self.hidden_dim, device=device)
        self.u = (h0, c0)
        
    def detach_states(self):
        if self.u is not None:
            self.u = (self.u[0].detach(), self.u[1].detach())

    def forward(self, x):
        if self.u is None or self.u[0].device != x.device:
            self.reset_states(x.size(0), x.device)
            
        lstm_out, self.u = self.lstm(x, self.u)
        out = self.fc(lstm_out[:, -1, :])
        return out


def build_model(input_dim, units):
    return PureLSTM(input_dim=input_dim, hidden_dim=units, output_dim=1)

# %%
# Quick model check
model = build_model(input_dim=1, units=8)
print(model)
print(f"Total params: {sum(p.numel() for p in model.parameters())}")
# Out:
# PureLSTM(
#   (lstm): LSTM(1, 8, batch_first=True)
#   (fc): Linear(in_features=8, out_features=1, bias=True)
# )
# Total params: 361

# %% [markdown]
# ## Data Pipeline — S&P 500

# %%
import os
for f in os.listdir('/kaggle/input/datasets/satabartosarkar1/sp500-csv'):
    print(f)
# Out:
# sp500.csv

# %%
# ============================================================
# 1. Load Time Series Data
# ============================================================
series = pd.read_csv(
    '/kaggle/input/datasets/satabartosarkar1/sp500-csv/sp500.csv',
    header=0,
    parse_dates=[0],
    index_col=0
)

original_raw_values = series.values.flatten()
print(f"Base data shape: {original_raw_values.shape}")
print(f"First 5 values: {original_raw_values[:5]}")
# Out:
# Base data shape: (251,)
# First 5 values: [2038.199951 2013.780029 2011.709961 1985.319946 1945.969971]

# %%
# ============================================================
# 2. First-Order Differencing
# ============================================================

def difference(dataset, interval=1):
    diff = []
    for i in range(interval, len(dataset)):
        value = dataset[i] - dataset[i - interval]
        diff.append(value)
    return np.array(diff)

# %%
# ============================================================
# 3. Convert to Supervised Learning Format (lag=1)
# ============================================================

def timeseries_to_supervised(data, lag=1):
    df = pd.DataFrame(data)
    columns = [df.shift(i) for i in range(1, lag+1)]
    columns.append(df)
    df = pd.concat(columns, axis=1)
    df.fillna(0, inplace=True)
    return df.values

# %% [markdown]
# ## Training Loop

# %%
# ============================================================
# Gaussian Noise Evaluation + 60-Run Experiment Protocol (PyTorch)
# ============================================================
import torch
import torch.nn as nn

s_x = np.std(original_raw_values)
noise_levels = [0.0, 0.005, 0.05, 0.1]
_molab_results = []

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"\n--- [PyTorch] RUNNING ON {device} ---\n")

for lam in noise_levels:
    sigma = lam * s_x
    print("\n" + "="*80)
    print(f"EVALUATING NOISE LEVEL: {lam*100:.1f}% (lambda={lam}, sigma={sigma:.6f})")
    print("="*80 + "\n")
    
    np.random.seed(42)
    torch.manual_seed(42)
    noise = np.random.normal(0, sigma, size=original_raw_values.shape)
    raw_values = original_raw_values + noise
    
    # 2. Difference
    diff_values = difference(raw_values, 1)
    # 3. Supervised (lag=1)
    supervised = timeseries_to_supervised(diff_values, 1)
    # 4. Split (Last 60 for test, NO validation)
    train, test = supervised[:-60], supervised[-60:]
    # 5. Scale
    scaler = MinMaxScaler(feature_range=(-1, 1))
    scaler.fit(train)
    train_scaled = scaler.transform(train)
    test_scaled = scaler.transform(test)
    # 6. Reshape
    X_train, y_train = train_scaled[:, 0:-1], train_scaled[:, -1]
    X_train = X_train.reshape((X_train.shape[0], 1, X_train.shape[1]))
    
    print(f"X_train shape: {X_train.shape}, y_train shape: {y_train.shape}")
    
    all_rmse = []
    all_mse = []
    all_nmse = []
    all_predictions = []
    all_losses = []
    
    for run in range(60):
        print(f'\n===== RUN {run+1}/60 [Noise {lam*100:.1f}%] =====')
        
        np.random.seed(run)
        torch.manual_seed(run)
        
        model = build_model(input_dim=1, units=8).to(device)
        optimizer = torch.optim.Adam(model.parameters(), lr=0.001)
        criterion = nn.MSELoss()
        
        # Pre-tensorize training data
        X_train_t = torch.tensor(X_train, dtype=torch.float32).to(device)
        y_train_t = torch.tensor(y_train, dtype=torch.float32).to(device)
        n_samples = X_train_t.size(0)
        
        run_losses = []
        for epoch in range(100):
            model.train()
            model.reset_states(1, device)
            
            epoch_loss = 0.0
            for i in range(n_samples):
                x_i = X_train_t[i:i+1]
                y_i = y_train_t[i:i+1]
                
                optimizer.zero_grad()
                pred = model(x_i)
                loss = criterion(pred.squeeze(-1), y_i)
                loss.backward()
                optimizer.step()
                model.detach_states()
                epoch_loss += loss.item()
            
            avg_loss = epoch_loss / n_samples
            run_losses.append(avg_loss)
            if (epoch+1) % 10 == 0:
                print(f"  Epoch {epoch+1}/100, Loss: {avg_loss:.6f}")
        
        all_losses.append(run_losses)
        print(f'Training complete for run {run+1}')
        
        # Warm-up: condition hidden states on training data
        model.eval()
        with torch.no_grad():
            model.reset_states(1, device)
            for i in range(len(train_scaled)):
                X_raw = train_scaled[i, 0:-1]
                X_input = torch.tensor(X_raw, dtype=torch.float32).view(1, 1, len(X_raw)).to(device)
                model(X_input)
        
        # Test predictions (single-step)
        predictions = []
        model.eval()
        with torch.no_grad():
            for i in range(len(test_scaled)):
                X = test_scaled[i, 0:-1]
                X_input = torch.tensor(X, dtype=torch.float32).view(1, 1, len(X)).to(device)
                yhat = model(X_input).item()
                
                # Invert scaling
                new_row = list(X) + [yhat]
                array = np.array(new_row).reshape(1, len(new_row))
                inverted = scaler.inverse_transform(array)[0, -1]
                
                # Invert differencing
                inverted = inverted + raw_values[len(train) + i]
                predictions.append(inverted)
        
        # Compute metrics
        actual = raw_values[-len(predictions):]
        rmse = sqrt(mean_squared_error(actual, predictions))
        mse = mean_squared_error(actual, predictions)
        meanV = np.mean(actual)
        dominator = np.linalg.norm(np.array(predictions) - meanV, 2)
        nmse = mse / np.power(dominator, 2)
        
        all_rmse.append(rmse)
        all_mse.append(mse)
        all_nmse.append(nmse)
        all_predictions.append(predictions)
        
        print(f'Run {run+1} \u2014 RMSE: {rmse:.6f}, MSE: {mse:.6f}, NMSE: {nmse:.10f}')
    
    # End of 60 runs for this noise level
    best_idx = np.argmin(all_rmse)
    
    print(f'\n===== STATS FOR NOISE {lam*100:.1f}% (60 runs) =====')
    print(f'RMSE: {np.mean(all_rmse):.6f} +/- {np.std(all_rmse):.6f}')
    print(f'MSE:  {np.mean(all_mse):.6f} +/- {np.std(all_mse):.6f}')
    print(f'NMSE: {np.mean(all_nmse):.10f} +/- {np.std(all_nmse):.10f}')
    print(f'Best run: {best_idx+1} (RMSE: {all_rmse[best_idx]:.6f})')
    
    _molab_results.append([lam, 
        np.mean(all_rmse), np.std(all_rmse),
        np.mean(all_mse), np.std(all_mse),
        np.mean(all_nmse), np.std(all_nmse),
        all_rmse[best_idx], all_predictions[best_idx], all_losses[best_idx], raw_values.copy()])
# Out:
# --- [PyTorch] RUNNING ON cuda ---
#
#
# ================================================================================
# EVALUATING NOISE LEVEL: 0.0% (lambda=0.0, sigma=0.000000)
# ================================================================================
#
# X_train shape: (190, 1, 1), y_train shape: (190,)
#
# ===== RUN 1/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.056444
#   Epoch 20/100, Loss: 0.056432
#   Epoch 30/100, Loss: 0.056417
#   Epoch 40/100, Loss: 0.056389
#   Epoch 50/100, Loss: 0.056349
#   Epoch 60/100, Loss: 0.056295
#   Epoch 70/100, Loss: 0.056221
#   Epoch 80/100, Loss: 0.056111
#   Epoch 90/100, Loss: 0.055938
#   Epoch 100/100, Loss: 0.055621
# Training complete for run 1
# Run 1 — RMSE: 11.306811, MSE: 127.843978, NMSE: 0.0007933481
#
# ===== RUN 2/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.056615
#   Epoch 20/100, Loss: 0.056558
#   Epoch 30/100, Loss: 0.056521
#   Epoch 40/100, Loss: 0.056494
#   Epoch 50/100, Loss: 0.056475
#   Epoch 60/100, Loss: 0.056460
#   Epoch 70/100, Loss: 0.056438
#   Epoch 80/100, Loss: 0.056406
#   Epoch 90/100, Loss: 0.056365
#   Epoch 100/100, Loss: 0.056322
# Training complete for run 2
# Run 2 — RMSE: 11.212268, MSE: 125.714951, NMSE: 0.0007737262
#
# ===== RUN 3/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.058375
#   Epoch 20/100, Loss: 0.057837
#   Epoch 30/100, Loss: 0.057507
#   Epoch 40/100, Loss: 0.057288
#   Epoch 50/100, Loss: 0.057133
#   Epoch 60/100, Loss: 0.057000
#   Epoch 70/100, Loss: 0.056875
#   Epoch 80/100, Loss: 0.056760
#   Epoch 90/100, Loss: 0.056639
#   Epoch 100/100, Loss: 0.056483
# Training complete for run 3
# Run 3 — RMSE: 11.202884, MSE: 125.504610, NMSE: 0.0007713799
#
# ===== RUN 4/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.056419
#   Epoch 20/100, Loss: 0.056258
#   Epoch 30/100, Loss: 0.056136
#   Epoch 40/100, Loss: 0.056029
#   Epoch 50/100, Loss: 0.055931
#   Epoch 60/100, Loss: 0.055836
#   Epoch 70/100, Loss: 0.055735
#   Epoch 80/100, Loss: 0.055605
#   Epoch 90/100, Loss: 0.055416
#   Epoch 100/100, Loss: 0.055140
# Training complete for run 4
# Run 4 — RMSE: 11.402546, MSE: 130.018049, NMSE: 0.0008096976
#
# ===== RUN 5/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.056749
#   Epoch 20/100, Loss: 0.056547
#   Epoch 30/100, Loss: 0.056411
#   Epoch 40/100, Loss: 0.056288
#   Epoch 50/100, Loss: 0.056184
#   Epoch 60/100, Loss: 0.056088
#   Epoch 70/100, Loss: 0.056002
#   Epoch 80/100, Loss: 0.055920
#   Epoch 90/100, Loss: 0.055839
#   Epoch 100/100, Loss: 0.055767
# Training complete for run 5
# Run 5 — RMSE: 11.273338, MSE: 127.088160, NMSE: 0.0007878055
#
# ===== RUN 6/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.056588
#   Epoch 20/100, Loss: 0.056511
#   Epoch 30/100, Loss: 0.056435
#   Epoch 40/100, Loss: 0.056361
#   Epoch 50/100, Loss: 0.056282
#   Epoch 60/100, Loss: 0.056200
#   Epoch 70/100, Loss: 0.056123
#   Epoch 80/100, Loss: 0.056052
#   Epoch 90/100, Loss: 0.055977
#   Epoch 100/100, Loss: 0.055892
# Training complete for run 6
# Run 6 — RMSE: 11.285775, MSE: 127.368725, NMSE: 0.0007895019
#
# ===== RUN 7/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.057334
#   Epoch 20/100, Loss: 0.056992
#   Epoch 30/100, Loss: 0.056725
#   Epoch 40/100, Loss: 0.056489
#   Epoch 50/100, Loss: 0.056289
#   Epoch 60/100, Loss: 0.056110
#   Epoch 70/100, Loss: 0.055960
#   Epoch 80/100, Loss: 0.055846
#   Epoch 90/100, Loss: 0.055774
#   Epoch 100/100, Loss: 0.055778
# Training complete for run 7
# Run 7 — RMSE: 11.227123, MSE: 126.048298, NMSE: 0.0007824902
#
# ===== RUN 8/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.058431
#   Epoch 20/100, Loss: 0.057907
#   Epoch 30/100, Loss: 0.057582
#   Epoch 40/100, Loss: 0.057335
#   Epoch 50/100, Loss: 0.057117
#   Epoch 60/100, Loss: 0.056896
#   Epoch 70/100, Loss: 0.056641
#   Epoch 80/100, Loss: 0.056324
#   Epoch 90/100, Loss: 0.055962
#   Epoch 100/100, Loss: 0.055668
# Training complete for run 8
# Run 8 — RMSE: 11.258893, MSE: 126.762680, NMSE: 0.0007816316
#
# ===== RUN 9/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.057574
#   Epoch 20/100, Loss: 0.057361
#   Epoch 30/100, Loss: 0.057234
#   Epoch 40/100, Loss: 0.057149
#   Epoch 50/100, Loss: 0.057087
#   Epoch 60/100, Loss: 0.057041
#   Epoch 70/100, Loss: 0.057006
#   Epoch 80/100, Loss: 0.056977
#   Epoch 90/100, Loss: 0.056952
#   Epoch 100/100, Loss: 0.056929
# Training complete for run 9
# Run 9 — RMSE: 11.138477, MSE: 124.065664, NMSE: 0.0007540674
#
# ===== RUN 10/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.057129
#   Epoch 20/100, Loss: 0.056996
#   Epoch 30/100, Loss: 0.056919
#   Epoch 40/100, Loss: 0.056861
#   Epoch 50/100, Loss: 0.056822
#   Epoch 60/100, Loss: 0.056790
#   Epoch 70/100, Loss: 0.056762
#   Epoch 80/100, Loss: 0.056735
#   Epoch 90/100, Loss: 0.056709
#   Epoch 100/100, Loss: 0.056685
# Training complete for run 10
# Run 10 — RMSE: 11.154407, MSE: 124.420804, NMSE: 0.0007577020
#
# ===== RUN 11/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.058459
#   Epoch 20/100, Loss: 0.057868
#   Epoch 30/100, Loss: 0.057552
#   Epoch 40/100, Loss: 0.057353
#   Epoch 50/100, Loss: 0.057216
#   Epoch 60/100, Loss: 0.057115
#   Epoch 70/100, Loss: 0.057035
#   Epoch 80/100, Loss: 0.056966
#   Epoch 90/100, Loss: 0.056900
#   Epoch 100/100, Loss: 0.056832
# Training complete for run 11
# Run 11 — RMSE: 11.140610, MSE: 124.113189, NMSE: 0.0007552275
#
# ===== RUN 12/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.056123
#   Epoch 20/100, Loss: 0.056113
#   Epoch 30/100, Loss: 0.056105
#   Epoch 40/100, Loss: 0.056079
#   Epoch 50/100, Loss: 0.056043
#   Epoch 60/100, Loss: 0.056005
#   Epoch 70/100, Loss: 0.055979
#   Epoch 80/100, Loss: 0.055954
#   Epoch 90/100, Loss: 0.055917
#   Epoch 100/100, Loss: 0.055878
# Training complete for run 12
# Run 12 — RMSE: 11.312686, MSE: 127.976866, NMSE: 0.0007917527
#
# ===== RUN 13/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.059049
#   Epoch 20/100, Loss: 0.058240
#   Epoch 30/100, Loss: 0.057809
#   Epoch 40/100, Loss: 0.057432
#   Epoch 50/100, Loss: 0.057042
#   Epoch 60/100, Loss: 0.056627
#   Epoch 70/100, Loss: 0.056259
#   Epoch 80/100, Loss: 0.055976
#   Epoch 90/100, Loss: 0.055740
#   Epoch 100/100, Loss: 0.055512
# Training complete for run 13
# Run 13 — RMSE: 11.188698, MSE: 125.186953, NMSE: 0.0007822143
#
# ===== RUN 14/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.057536
#   Epoch 20/100, Loss: 0.057270
#   Epoch 30/100, Loss: 0.057093
#   Epoch 40/100, Loss: 0.056957
#   Epoch 50/100, Loss: 0.056851
#   Epoch 60/100, Loss: 0.056771
#   Epoch 70/100, Loss: 0.056713
#   Epoch 80/100, Loss: 0.056667
#   Epoch 90/100, Loss: 0.056623
#   Epoch 100/100, Loss: 0.056575
# Training complete for run 14
# Run 14 — RMSE: 11.192348, MSE: 125.268650, NMSE: 0.0007652318
#
# ===== RUN 15/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.056675
#   Epoch 20/100, Loss: 0.056541
#   Epoch 30/100, Loss: 0.056421
#   Epoch 40/100, Loss: 0.056278
#   Epoch 50/100, Loss: 0.056103
#   Epoch 60/100, Loss: 0.055901
#   Epoch 70/100, Loss: 0.055672
#   Epoch 80/100, Loss: 0.055397
#   Epoch 90/100, Loss: 0.054993
#   Epoch 100/100, Loss: 0.054418
# Training complete for run 15
# Run 15 — RMSE: 11.312942, MSE: 127.982657, NMSE: 0.0007938733
#
# ===== RUN 16/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.058149
#   Epoch 20/100, Loss: 0.057716
#   Epoch 30/100, Loss: 0.057453
#   Epoch 40/100, Loss: 0.057269
#   Epoch 50/100, Loss: 0.057126
#   Epoch 60/100, Loss: 0.057006
#   Epoch 70/100, Loss: 0.056895
#   Epoch 80/100, Loss: 0.056779
#   Epoch 90/100, Loss: 0.056648
#   Epoch 100/100, Loss: 0.056492
# Training complete for run 16
# Run 16 — RMSE: 11.193235, MSE: 125.288505, NMSE: 0.0007657345
#
# ===== RUN 17/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.056486
#   Epoch 20/100, Loss: 0.056506
#   Epoch 30/100, Loss: 0.056553
#   Epoch 40/100, Loss: 0.056597
#   Epoch 50/100, Loss: 0.056596
#   Epoch 60/100, Loss: 0.056569
#   Epoch 70/100, Loss: 0.056537
#   Epoch 80/100, Loss: 0.056518
#   Epoch 90/100, Loss: 0.056515
#   Epoch 100/100, Loss: 0.056523
# Training complete for run 17
# Run 17 — RMSE: 11.257201, MSE: 126.724565, NMSE: 0.0007773832
#
# ===== RUN 18/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.056929
#   Epoch 20/100, Loss: 0.056775
#   Epoch 30/100, Loss: 0.056660
#   Epoch 40/100, Loss: 0.056565
#   Epoch 50/100, Loss: 0.056481
#   Epoch 60/100, Loss: 0.056399
#   Epoch 70/100, Loss: 0.056311
#   Epoch 80/100, Loss: 0.056209
#   Epoch 90/100, Loss: 0.056083
#   Epoch 100/100, Loss: 0.055924
# Training complete for run 18
# Run 18 — RMSE: 11.277663, MSE: 127.185676, NMSE: 0.0007815271
#
# ===== RUN 19/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.056790
#   Epoch 20/100, Loss: 0.056696
#   Epoch 30/100, Loss: 0.056643
#   Epoch 40/100, Loss: 0.056608
#   Epoch 50/100, Loss: 0.056571
#   Epoch 60/100, Loss: 0.056524
#   Epoch 70/100, Loss: 0.056463
#   Epoch 80/100, Loss: 0.056380
#   Epoch 90/100, Loss: 0.056268
#   Epoch 100/100, Loss: 0.056116
# Training complete for run 19
# Run 19 — RMSE: 11.204332, MSE: 125.537059, NMSE: 0.0007723884
#
# ===== RUN 20/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.056044
#   Epoch 20/100, Loss: 0.056001
#   Epoch 30/100, Loss: 0.055977
#   Epoch 40/100, Loss: 0.055944
#   Epoch 50/100, Loss: 0.055901
#   Epoch 60/100, Loss: 0.055851
#   Epoch 70/100, Loss: 0.055794
#   Epoch 80/100, Loss: 0.055734
#   Epoch 90/100, Loss: 0.055671
#   Epoch 100/100, Loss: 0.055607
# Training complete for run 20
# Run 20 — RMSE: 11.300146, MSE: 127.693303, NMSE: 0.0007861142
#
# ===== RUN 21/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.056698
#   Epoch 20/100, Loss: 0.056610
#   Epoch 30/100, Loss: 0.056560
#   Epoch 40/100, Loss: 0.056527
#   Epoch 50/100, Loss: 0.056502
#   Epoch 60/100, Loss: 0.056477
#   Epoch 70/100, Loss: 0.056450
#   Epoch 80/100, Loss: 0.056421
#   Epoch 90/100, Loss: 0.056382
#   Epoch 100/100, Loss: 0.056310
# Training complete for run 21
# Run 21 — RMSE: 11.160634, MSE: 124.559741, NMSE: 0.0007676323
#
# ===== RUN 22/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.057251
#   Epoch 20/100, Loss: 0.057117
#   Epoch 30/100, Loss: 0.057019
#   Epoch 40/100, Loss: 0.056933
#   Epoch 50/100, Loss: 0.056853
#   Epoch 60/100, Loss: 0.056780
#   Epoch 70/100, Loss: 0.056714
#   Epoch 80/100, Loss: 0.056658
#   Epoch 90/100, Loss: 0.056610
#   Epoch 100/100, Loss: 0.056564
# Training complete for run 22
# Run 22 — RMSE: 11.169636, MSE: 124.760769, NMSE: 0.0007642472
#
# ===== RUN 23/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.057530
#   Epoch 20/100, Loss: 0.057368
#   Epoch 30/100, Loss: 0.057279
#   Epoch 40/100, Loss: 0.057196
#   Epoch 50/100, Loss: 0.057122
#   Epoch 60/100, Loss: 0.057058
#   Epoch 70/100, Loss: 0.056989
#   Epoch 80/100, Loss: 0.056904
#   Epoch 90/100, Loss: 0.056786
#   Epoch 100/100, Loss: 0.056632
# Training complete for run 23
# Run 23 — RMSE: 11.180527, MSE: 125.004190, NMSE: 0.0007640349
#
# ===== RUN 24/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.058779
#   Epoch 20/100, Loss: 0.058131
#   Epoch 30/100, Loss: 0.057755
#   Epoch 40/100, Loss: 0.057470
#   Epoch 50/100, Loss: 0.057211
#   Epoch 60/100, Loss: 0.056912
#   Epoch 70/100, Loss: 0.056522
#   Epoch 80/100, Loss: 0.056113
#   Epoch 90/100, Loss: 0.055823
#   Epoch 100/100, Loss: 0.055643
# Training complete for run 24
# Run 24 — RMSE: 11.278260, MSE: 127.199144, NMSE: 0.0007852089
#
# ===== RUN 25/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.058400
#   Epoch 20/100, Loss: 0.057847
#   Epoch 30/100, Loss: 0.057537
#   Epoch 40/100, Loss: 0.057324
#   Epoch 50/100, Loss: 0.057158
#   Epoch 60/100, Loss: 0.057029
#   Epoch 70/100, Loss: 0.056929
#   Epoch 80/100, Loss: 0.056846
#   Epoch 90/100, Loss: 0.056753
#   Epoch 100/100, Loss: 0.056634
# Training complete for run 25
# Run 25 — RMSE: 11.159007, MSE: 124.523434, NMSE: 0.0007624861
#
# ===== RUN 26/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.058158
#   Epoch 20/100, Loss: 0.057686
#   Epoch 30/100, Loss: 0.057402
#   Epoch 40/100, Loss: 0.057202
#   Epoch 50/100, Loss: 0.057047
#   Epoch 60/100, Loss: 0.056921
#   Epoch 70/100, Loss: 0.056823
#   Epoch 80/100, Loss: 0.056750
#   Epoch 90/100, Loss: 0.056691
#   Epoch 100/100, Loss: 0.056640
# Training complete for run 26
# Run 26 — RMSE: 11.195689, MSE: 125.343460, NMSE: 0.0007683061
#
# ===== RUN 27/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.056424
#   Epoch 20/100, Loss: 0.056235
#   Epoch 30/100, Loss: 0.056153
#   Epoch 40/100, Loss: 0.056074
#   Epoch 50/100, Loss: 0.055986
#   Epoch 60/100, Loss: 0.055886
#   Epoch 70/100, Loss: 0.055764
#   Epoch 80/100, Loss: 0.055619
#   Epoch 90/100, Loss: 0.055467
#   Epoch 100/100, Loss: 0.055323
# Training complete for run 27
# Run 27 — RMSE: 11.319136, MSE: 128.122846, NMSE: 0.0007954803
#
# ===== RUN 28/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.056104
#   Epoch 20/100, Loss: 0.055981
#   Epoch 30/100, Loss: 0.055922
#   Epoch 40/100, Loss: 0.055848
#   Epoch 50/100, Loss: 0.055759
#   Epoch 60/100, Loss: 0.055657
#   Epoch 70/100, Loss: 0.055529
#   Epoch 80/100, Loss: 0.055349
#   Epoch 90/100, Loss: 0.055069
#   Epoch 100/100, Loss: 0.054624
# Training complete for run 28
# Run 28 — RMSE: 11.435444, MSE: 130.769381, NMSE: 0.0008202584
#
# ===== RUN 29/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.056140
#   Epoch 20/100, Loss: 0.055938
#   Epoch 30/100, Loss: 0.055797
#   Epoch 40/100, Loss: 0.055657
#   Epoch 50/100, Loss: 0.055498
#   Epoch 60/100, Loss: 0.055310
#   Epoch 70/100, Loss: 0.055082
#   Epoch 80/100, Loss: 0.054805
#   Epoch 90/100, Loss: 0.054488
#   Epoch 100/100, Loss: 0.054181
# Training complete for run 29
# Run 29 — RMSE: 11.329483, MSE: 128.357192, NMSE: 0.0007943620
#
# ===== RUN 30/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.057749
#   Epoch 20/100, Loss: 0.057471
#   Epoch 30/100, Loss: 0.057324
#   Epoch 40/100, Loss: 0.057232
#   Epoch 50/100, Loss: 0.057147
#   Epoch 60/100, Loss: 0.057066
#   Epoch 70/100, Loss: 0.056988
#   Epoch 80/100, Loss: 0.056917
#   Epoch 90/100, Loss: 0.056866
#   Epoch 100/100, Loss: 0.056836
# Training complete for run 30
# Run 30 — RMSE: 11.145106, MSE: 124.213381, NMSE: 0.0007572619
#
# ===== RUN 31/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.057196
#   Epoch 20/100, Loss: 0.056940
#   Epoch 30/100, Loss: 0.056794
#   Epoch 40/100, Loss: 0.056687
#   Epoch 50/100, Loss: 0.056622
#   Epoch 60/100, Loss: 0.056556
#   Epoch 70/100, Loss: 0.056483
#   Epoch 80/100, Loss: 0.056399
#   Epoch 90/100, Loss: 0.056302
#   Epoch 100/100, Loss: 0.056185
# Training complete for run 31
# Run 31 — RMSE: 11.206158, MSE: 125.577982, NMSE: 0.0007702290
#
# ===== RUN 32/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.056889
#   Epoch 20/100, Loss: 0.056716
#   Epoch 30/100, Loss: 0.056623
#   Epoch 40/100, Loss: 0.056572
#   Epoch 50/100, Loss: 0.056537
#   Epoch 60/100, Loss: 0.056512
#   Epoch 70/100, Loss: 0.056504
#   Epoch 80/100, Loss: 0.056520
#   Epoch 90/100, Loss: 0.056541
#   Epoch 100/100, Loss: 0.056530
# Training complete for run 32
# Run 32 — RMSE: 11.163557, MSE: 124.625014, NMSE: 0.0007635973
#
# ===== RUN 33/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.057309
#   Epoch 20/100, Loss: 0.057097
#   Epoch 30/100, Loss: 0.056968
#   Epoch 40/100, Loss: 0.056868
#   Epoch 50/100, Loss: 0.056786
#   Epoch 60/100, Loss: 0.056721
#   Epoch 70/100, Loss: 0.056676
#   Epoch 80/100, Loss: 0.056650
#   Epoch 90/100, Loss: 0.056642
#   Epoch 100/100, Loss: 0.056651
# Training complete for run 33
# Run 33 — RMSE: 11.175698, MSE: 124.896216, NMSE: 0.0007651063
#
# ===== RUN 34/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.057995
#   Epoch 20/100, Loss: 0.057483
#   Epoch 30/100, Loss: 0.056733
#   Epoch 40/100, Loss: 0.055401
#   Epoch 50/100, Loss: 0.055007
#   Epoch 60/100, Loss: 0.056108
#   Epoch 70/100, Loss: 0.056769
#   Epoch 80/100, Loss: 0.056863
#   Epoch 90/100, Loss: 0.056879
#   Epoch 100/100, Loss: 0.056864
# Training complete for run 34
# Run 34 — RMSE: 11.142094, MSE: 124.146270, NMSE: 0.0007632342
#
# ===== RUN 35/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.056407
#   Epoch 20/100, Loss: 0.056242
#   Epoch 30/100, Loss: 0.056152
#   Epoch 40/100, Loss: 0.056110
#   Epoch 50/100, Loss: 0.056052
#   Epoch 60/100, Loss: 0.055970
#   Epoch 70/100, Loss: 0.055869
#   Epoch 80/100, Loss: 0.055751
#   Epoch 90/100, Loss: 0.055591
#   Epoch 100/100, Loss: 0.055387
# Training complete for run 35
# Run 35 — RMSE: 11.357422, MSE: 128.991024, NMSE: 0.0007962323
#
# ===== RUN 36/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.058508
#   Epoch 20/100, Loss: 0.057905
#   Epoch 30/100, Loss: 0.057584
#   Epoch 40/100, Loss: 0.057368
#   Epoch 50/100, Loss: 0.057201
#   Epoch 60/100, Loss: 0.057058
#   Epoch 70/100, Loss: 0.056914
#   Epoch 80/100, Loss: 0.056781
#   Epoch 90/100, Loss: 0.056683
#   Epoch 100/100, Loss: 0.056643
# Training complete for run 36
# Run 36 — RMSE: 11.163240, MSE: 124.617921, NMSE: 0.0007662119
#
# ===== RUN 37/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.057605
#   Epoch 20/100, Loss: 0.057382
#   Epoch 30/100, Loss: 0.057239
#   Epoch 40/100, Loss: 0.057139
#   Epoch 50/100, Loss: 0.057057
#   Epoch 60/100, Loss: 0.056983
#   Epoch 70/100, Loss: 0.056911
#   Epoch 80/100, Loss: 0.056837
#   Epoch 90/100, Loss: 0.056762
#   Epoch 100/100, Loss: 0.056686
# Training complete for run 37
# Run 37 — RMSE: 11.171092, MSE: 124.793288, NMSE: 0.0007624985
#
# ===== RUN 38/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.057857
#   Epoch 20/100, Loss: 0.057547
#   Epoch 30/100, Loss: 0.057340
#   Epoch 40/100, Loss: 0.057185
#   Epoch 50/100, Loss: 0.057059
#   Epoch 60/100, Loss: 0.056951
#   Epoch 70/100, Loss: 0.056852
#   Epoch 80/100, Loss: 0.056760
#   Epoch 90/100, Loss: 0.056668
#   Epoch 100/100, Loss: 0.056568
# Training complete for run 38
# Run 38 — RMSE: 11.197326, MSE: 125.380105, NMSE: 0.0007674612
#
# ===== RUN 39/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.056365
#   Epoch 20/100, Loss: 0.056342
#   Epoch 30/100, Loss: 0.056321
#   Epoch 40/100, Loss: 0.056245
#   Epoch 50/100, Loss: 0.056125
#   Epoch 60/100, Loss: 0.055980
#   Epoch 70/100, Loss: 0.055812
#   Epoch 80/100, Loss: 0.055613
#   Epoch 90/100, Loss: 0.055370
#   Epoch 100/100, Loss: 0.055062
# Training complete for run 39
# Run 39 — RMSE: 11.318040, MSE: 128.098040, NMSE: 0.0007928793
#
# ===== RUN 40/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.057655
#   Epoch 20/100, Loss: 0.057367
#   Epoch 30/100, Loss: 0.057199
#   Epoch 40/100, Loss: 0.057094
#   Epoch 50/100, Loss: 0.057005
#   Epoch 60/100, Loss: 0.056930
#   Epoch 70/100, Loss: 0.056859
#   Epoch 80/100, Loss: 0.056782
#   Epoch 90/100, Loss: 0.056691
#   Epoch 100/100, Loss: 0.056575
# Training complete for run 40
# Run 40 — RMSE: 11.187622, MSE: 125.162891, NMSE: 0.0007650125
#
# ===== RUN 41/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.057305
#   Epoch 20/100, Loss: 0.057105
#   Epoch 30/100, Loss: 0.056952
#   Epoch 40/100, Loss: 0.056819
#   Epoch 50/100, Loss: 0.056688
#   Epoch 60/100, Loss: 0.056550
#   Epoch 70/100, Loss: 0.056397
#   Epoch 80/100, Loss: 0.056234
#   Epoch 90/100, Loss: 0.056070
#   Epoch 100/100, Loss: 0.055900
# Training complete for run 41
# Run 41 — RMSE: 11.326712, MSE: 128.294394, NMSE: 0.0007846332
#
# ===== RUN 42/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.057105
#   Epoch 20/100, Loss: 0.056921
#   Epoch 30/100, Loss: 0.056818
#   Epoch 40/100, Loss: 0.056767
#   Epoch 50/100, Loss: 0.056740
#   Epoch 60/100, Loss: 0.056718
#   Epoch 70/100, Loss: 0.056701
#   Epoch 80/100, Loss: 0.056692
#   Epoch 90/100, Loss: 0.056690
#   Epoch 100/100, Loss: 0.056695
# Training complete for run 42
# Run 42 — RMSE: 11.148553, MSE: 124.290237, NMSE: 0.0007610257
#
# ===== RUN 43/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.056497
#   Epoch 20/100, Loss: 0.056288
#   Epoch 30/100, Loss: 0.056153
#   Epoch 40/100, Loss: 0.056041
#   Epoch 50/100, Loss: 0.055936
#   Epoch 60/100, Loss: 0.055828
#   Epoch 70/100, Loss: 0.055718
#   Epoch 80/100, Loss: 0.055599
#   Epoch 90/100, Loss: 0.055470
#   Epoch 100/100, Loss: 0.055324
# Training complete for run 43
# Run 43 — RMSE: 11.299174, MSE: 127.671326, NMSE: 0.0007936637
#
# ===== RUN 44/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.057882
#   Epoch 20/100, Loss: 0.057404
#   Epoch 30/100, Loss: 0.057162
#   Epoch 40/100, Loss: 0.057007
#   Epoch 50/100, Loss: 0.056902
#   Epoch 60/100, Loss: 0.056842
#   Epoch 70/100, Loss: 0.056832
#   Epoch 80/100, Loss: 0.056871
#   Epoch 90/100, Loss: 0.056851
#   Epoch 100/100, Loss: 0.056817
# Training complete for run 44
# Run 44 — RMSE: 11.195394, MSE: 125.336849, NMSE: 0.0007664867
#
# ===== RUN 45/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.056676
#   Epoch 20/100, Loss: 0.056565
#   Epoch 30/100, Loss: 0.056468
#   Epoch 40/100, Loss: 0.056368
#   Epoch 50/100, Loss: 0.056249
#   Epoch 60/100, Loss: 0.056093
#   Epoch 70/100, Loss: 0.055861
#   Epoch 80/100, Loss: 0.055442
#   Epoch 90/100, Loss: 0.054758
#   Epoch 100/100, Loss: 0.054178
# Training complete for run 45
# Run 45 — RMSE: 11.454288, MSE: 131.200712, NMSE: 0.0008207201
#
# ===== RUN 46/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.056601
#   Epoch 20/100, Loss: 0.056530
#   Epoch 30/100, Loss: 0.056486
#   Epoch 40/100, Loss: 0.056451
#   Epoch 50/100, Loss: 0.056411
#   Epoch 60/100, Loss: 0.056363
#   Epoch 70/100, Loss: 0.056325
#   Epoch 80/100, Loss: 0.056286
#   Epoch 90/100, Loss: 0.056249
#   Epoch 100/100, Loss: 0.056212
# Training complete for run 46
# Run 46 — RMSE: 11.232786, MSE: 126.175481, NMSE: 0.0007785619
#
# ===== RUN 47/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.057066
#   Epoch 20/100, Loss: 0.056932
#   Epoch 30/100, Loss: 0.056885
#   Epoch 40/100, Loss: 0.056836
#   Epoch 50/100, Loss: 0.056790
#   Epoch 60/100, Loss: 0.056743
#   Epoch 70/100, Loss: 0.056693
#   Epoch 80/100, Loss: 0.056637
#   Epoch 90/100, Loss: 0.056565
#   Epoch 100/100, Loss: 0.056470
# Training complete for run 47
# Run 47 — RMSE: 11.172113, MSE: 124.816099, NMSE: 0.0007663866
#
# ===== RUN 48/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.057001
#   Epoch 20/100, Loss: 0.056788
#   Epoch 30/100, Loss: 0.056638
#   Epoch 40/100, Loss: 0.056530
#   Epoch 50/100, Loss: 0.056469
#   Epoch 60/100, Loss: 0.056456
#   Epoch 70/100, Loss: 0.056467
#   Epoch 80/100, Loss: 0.056471
#   Epoch 90/100, Loss: 0.056430
#   Epoch 100/100, Loss: 0.056343
# Training complete for run 48
# Run 48 — RMSE: 11.191634, MSE: 125.252664, NMSE: 0.0007690861
#
# ===== RUN 49/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.056298
#   Epoch 20/100, Loss: 0.056104
#   Epoch 30/100, Loss: 0.056025
#   Epoch 40/100, Loss: 0.055945
#   Epoch 50/100, Loss: 0.055841
#   Epoch 60/100, Loss: 0.055695
#   Epoch 70/100, Loss: 0.055476
#   Epoch 80/100, Loss: 0.055139
#   Epoch 90/100, Loss: 0.054671
#   Epoch 100/100, Loss: 0.054151
# Training complete for run 49
# Run 49 — RMSE: 11.386104, MSE: 129.643370, NMSE: 0.0008163074
#
# ===== RUN 50/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.056213
#   Epoch 20/100, Loss: 0.056093
#   Epoch 30/100, Loss: 0.055975
#   Epoch 40/100, Loss: 0.055861
#   Epoch 50/100, Loss: 0.055746
#   Epoch 60/100, Loss: 0.055628
#   Epoch 70/100, Loss: 0.055508
#   Epoch 80/100, Loss: 0.055384
#   Epoch 90/100, Loss: 0.055249
#   Epoch 100/100, Loss: 0.055104
# Training complete for run 50
# Run 50 — RMSE: 11.383929, MSE: 129.593844, NMSE: 0.0008088394
#
# ===== RUN 51/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.055869
#   Epoch 20/100, Loss: 0.055708
#   Epoch 30/100, Loss: 0.055594
#   Epoch 40/100, Loss: 0.055488
#   Epoch 50/100, Loss: 0.055378
#   Epoch 60/100, Loss: 0.055259
#   Epoch 70/100, Loss: 0.055078
#   Epoch 80/100, Loss: 0.054863
#   Epoch 90/100, Loss: 0.054647
#   Epoch 100/100, Loss: 0.054438
# Training complete for run 51
# Run 51 — RMSE: 11.547373, MSE: 133.341815, NMSE: 0.0008409359
#
# ===== RUN 52/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.057683
#   Epoch 20/100, Loss: 0.057378
#   Epoch 30/100, Loss: 0.057183
#   Epoch 40/100, Loss: 0.057043
#   Epoch 50/100, Loss: 0.056935
#   Epoch 60/100, Loss: 0.056848
#   Epoch 70/100, Loss: 0.056770
#   Epoch 80/100, Loss: 0.056689
#   Epoch 90/100, Loss: 0.056603
#   Epoch 100/100, Loss: 0.056508
# Training complete for run 52
# Run 52 — RMSE: 11.244404, MSE: 126.436611, NMSE: 0.0007741442
#
# ===== RUN 53/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.057230
#   Epoch 20/100, Loss: 0.057049
#   Epoch 30/100, Loss: 0.056938
#   Epoch 40/100, Loss: 0.056828
#   Epoch 50/100, Loss: 0.056703
#   Epoch 60/100, Loss: 0.056596
#   Epoch 70/100, Loss: 0.056553
#   Epoch 80/100, Loss: 0.056577
#   Epoch 90/100, Loss: 0.056646
#   Epoch 100/100, Loss: 0.056726
# Training complete for run 53
# Run 53 — RMSE: 11.143259, MSE: 124.172210, NMSE: 0.0007600816
#
# ===== RUN 54/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.056104
#   Epoch 20/100, Loss: 0.056020
#   Epoch 30/100, Loss: 0.055940
#   Epoch 40/100, Loss: 0.055860
#   Epoch 50/100, Loss: 0.055782
#   Epoch 60/100, Loss: 0.055720
#   Epoch 70/100, Loss: 0.055670
#   Epoch 80/100, Loss: 0.055635
#   Epoch 90/100, Loss: 0.055615
#   Epoch 100/100, Loss: 0.055612
# Training complete for run 54
# Run 54 — RMSE: 11.325708, MSE: 128.271668, NMSE: 0.0007957464
#
# ===== RUN 55/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.056589
#   Epoch 20/100, Loss: 0.056488
#   Epoch 30/100, Loss: 0.056390
#   Epoch 40/100, Loss: 0.056280
#   Epoch 50/100, Loss: 0.056153
#   Epoch 60/100, Loss: 0.056013
#   Epoch 70/100, Loss: 0.055864
#   Epoch 80/100, Loss: 0.055705
#   Epoch 90/100, Loss: 0.055532
#   Epoch 100/100, Loss: 0.055345
# Training complete for run 55
# Run 55 — RMSE: 11.263387, MSE: 126.863878, NMSE: 0.0007704771
#
# ===== RUN 56/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.056765
#   Epoch 20/100, Loss: 0.056636
#   Epoch 30/100, Loss: 0.056525
#   Epoch 40/100, Loss: 0.056425
#   Epoch 50/100, Loss: 0.056332
#   Epoch 60/100, Loss: 0.056237
#   Epoch 70/100, Loss: 0.056134
#   Epoch 80/100, Loss: 0.056022
#   Epoch 90/100, Loss: 0.055897
#   Epoch 100/100, Loss: 0.055754
# Training complete for run 56
# Run 56 — RMSE: 11.250377, MSE: 126.570988, NMSE: 0.0007855285
#
# ===== RUN 57/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.056478
#   Epoch 20/100, Loss: 0.056383
#   Epoch 30/100, Loss: 0.056299
#   Epoch 40/100, Loss: 0.056218
#   Epoch 50/100, Loss: 0.056138
#   Epoch 60/100, Loss: 0.056061
#   Epoch 70/100, Loss: 0.055974
#   Epoch 80/100, Loss: 0.055852
#   Epoch 90/100, Loss: 0.055661
#   Epoch 100/100, Loss: 0.055389
# Training complete for run 57
# Run 57 — RMSE: 11.301994, MSE: 127.735079, NMSE: 0.0007891086
#
# ===== RUN 58/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.057176
#   Epoch 20/100, Loss: 0.057067
#   Epoch 30/100, Loss: 0.056992
#   Epoch 40/100, Loss: 0.056935
#   Epoch 50/100, Loss: 0.056888
#   Epoch 60/100, Loss: 0.056850
#   Epoch 70/100, Loss: 0.056820
#   Epoch 80/100, Loss: 0.056795
#   Epoch 90/100, Loss: 0.056775
#   Epoch 100/100, Loss: 0.056759
# Training complete for run 58
# Run 58 — RMSE: 11.151602, MSE: 124.358217, NMSE: 0.0007586651
#
# ===== RUN 59/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.056843
#   Epoch 20/100, Loss: 0.056712
#   Epoch 30/100, Loss: 0.056637
#   Epoch 40/100, Loss: 0.056592
#   Epoch 50/100, Loss: 0.056574
#   Epoch 60/100, Loss: 0.056571
#   Epoch 70/100, Loss: 0.056539
#   Epoch 80/100, Loss: 0.056496
#   Epoch 90/100, Loss: 0.056452
#   Epoch 100/100, Loss: 0.056370
# Training complete for run 59
# Run 59 — RMSE: 11.186861, MSE: 125.145868, NMSE: 0.0007675725
#
# ===== RUN 60/60 [Noise 0.0%] =====
#   Epoch 10/100, Loss: 0.057051
#   Epoch 20/100, Loss: 0.056843
#   Epoch 30/100, Loss: 0.056734
#   Epoch 40/100, Loss: 0.056668
#   Epoch 50/100, Loss: 0.056632
#   Epoch 60/100, Loss: 0.056615
#   Epoch 70/100, Loss: 0.056613
#   Epoch 80/100, Loss: 0.056615
#   Epoch 90/100, Loss: 0.056623
#   Epoch 100/100, Loss: 0.056631
# Training complete for run 60
# Run 60 — RMSE: 11.167422, MSE: 124.711311, NMSE: 0.0007637585
#
# ===== STATS FOR NOISE 0.0% (60 runs) =====
# RMSE: 11.244510 +/- 0.089195
# MSE:  126.446971 +/- 2.014374
# NMSE: 0.0007789378 +/- 0.0000183174
# Best run: 9 (RMSE: 11.138477)
#
# ================================================================================
# EVALUATING NOISE LEVEL: 0.5% (lambda=0.005, sigma=0.505155)
# ================================================================================
#
# X_train shape: (190, 1, 1), y_train shape: (190,)
#
# ===== RUN 1/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.056959
#   Epoch 20/100, Loss: 0.056952
#   Epoch 30/100, Loss: 0.056941
#   Epoch 40/100, Loss: 0.056917
#   Epoch 50/100, Loss: 0.056880
#   Epoch 60/100, Loss: 0.056828
#   Epoch 70/100, Loss: 0.056750
#   Epoch 80/100, Loss: 0.056624
#   Epoch 90/100, Loss: 0.056393
#   Epoch 100/100, Loss: 0.055899
# Training complete for run 1
# Run 1 — RMSE: 11.385237, MSE: 129.623631, NMSE: 0.0008064933
#
# ===== RUN 2/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.057149
#   Epoch 20/100, Loss: 0.057097
#   Epoch 30/100, Loss: 0.057065
#   Epoch 40/100, Loss: 0.057040
#   Epoch 50/100, Loss: 0.057020
#   Epoch 60/100, Loss: 0.056995
#   Epoch 70/100, Loss: 0.056967
#   Epoch 80/100, Loss: 0.056933
#   Epoch 90/100, Loss: 0.056892
#   Epoch 100/100, Loss: 0.056848
# Training complete for run 2
# Run 2 — RMSE: 11.270763, MSE: 127.030091, NMSE: 0.0007848478
#
# ===== RUN 3/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.058859
#   Epoch 20/100, Loss: 0.058366
#   Epoch 30/100, Loss: 0.058066
#   Epoch 40/100, Loss: 0.057868
#   Epoch 50/100, Loss: 0.057720
#   Epoch 60/100, Loss: 0.057591
#   Epoch 70/100, Loss: 0.057472
#   Epoch 80/100, Loss: 0.057354
#   Epoch 90/100, Loss: 0.057217
#   Epoch 100/100, Loss: 0.057022
# Training complete for run 3
# Run 3 — RMSE: 11.249381, MSE: 126.548569, NMSE: 0.0007792021
#
# ===== RUN 4/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.056940
#   Epoch 20/100, Loss: 0.056777
#   Epoch 30/100, Loss: 0.056645
#   Epoch 40/100, Loss: 0.056519
#   Epoch 50/100, Loss: 0.056390
#   Epoch 60/100, Loss: 0.056251
#   Epoch 70/100, Loss: 0.056084
#   Epoch 80/100, Loss: 0.055851
#   Epoch 90/100, Loss: 0.055506
#   Epoch 100/100, Loss: 0.055004
# Training complete for run 4
# Run 4 — RMSE: 11.474771, MSE: 131.670370, NMSE: 0.0008261481
#
# ===== RUN 5/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.057254
#   Epoch 20/100, Loss: 0.057055
#   Epoch 30/100, Loss: 0.056912
#   Epoch 40/100, Loss: 0.056774
#   Epoch 50/100, Loss: 0.056666
#   Epoch 60/100, Loss: 0.056568
#   Epoch 70/100, Loss: 0.056478
#   Epoch 80/100, Loss: 0.056387
#   Epoch 90/100, Loss: 0.056301
#   Epoch 100/100, Loss: 0.056225
# Training complete for run 5
# Run 5 — RMSE: 11.337227, MSE: 128.532723, NMSE: 0.0008006275
#
# ===== RUN 6/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.057075
#   Epoch 20/100, Loss: 0.056972
#   Epoch 30/100, Loss: 0.056868
#   Epoch 40/100, Loss: 0.056764
#   Epoch 50/100, Loss: 0.056657
#   Epoch 60/100, Loss: 0.056544
#   Epoch 70/100, Loss: 0.056437
#   Epoch 80/100, Loss: 0.056325
#   Epoch 90/100, Loss: 0.056189
#   Epoch 100/100, Loss: 0.055993
# Training complete for run 6
# Run 6 — RMSE: 11.399499, MSE: 129.948580, NMSE: 0.0008125961
#
# ===== RUN 7/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.057860
#   Epoch 20/100, Loss: 0.057556
#   Epoch 30/100, Loss: 0.057327
#   Epoch 40/100, Loss: 0.057110
#   Epoch 50/100, Loss: 0.056926
#   Epoch 60/100, Loss: 0.056769
#   Epoch 70/100, Loss: 0.056638
#   Epoch 80/100, Loss: 0.056543
#   Epoch 90/100, Loss: 0.056503
#   Epoch 100/100, Loss: 0.056541
# Training complete for run 7
# Run 7 — RMSE: 11.266391, MSE: 126.931572, NMSE: 0.0007891019
#
# ===== RUN 8/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.058881
#   Epoch 20/100, Loss: 0.058392
#   Epoch 30/100, Loss: 0.058085
#   Epoch 40/100, Loss: 0.057844
#   Epoch 50/100, Loss: 0.057622
#   Epoch 60/100, Loss: 0.057380
#   Epoch 70/100, Loss: 0.057080
#   Epoch 80/100, Loss: 0.056691
#   Epoch 90/100, Loss: 0.056261
#   Epoch 100/100, Loss: 0.055988
# Training complete for run 8
# Run 8 — RMSE: 11.365058, MSE: 129.164553, NMSE: 0.0008003795
#
# ===== RUN 9/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.058066
#   Epoch 20/100, Loss: 0.057873
#   Epoch 30/100, Loss: 0.057759
#   Epoch 40/100, Loss: 0.057682
#   Epoch 50/100, Loss: 0.057627
#   Epoch 60/100, Loss: 0.057585
#   Epoch 70/100, Loss: 0.057553
#   Epoch 80/100, Loss: 0.057528
#   Epoch 90/100, Loss: 0.057508
#   Epoch 100/100, Loss: 0.057488
# Training complete for run 9
# Run 9 — RMSE: 11.183893, MSE: 125.079457, NMSE: 0.0007630003
#
# ===== RUN 10/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.057673
#   Epoch 20/100, Loss: 0.057539
#   Epoch 30/100, Loss: 0.057466
#   Epoch 40/100, Loss: 0.057413
#   Epoch 50/100, Loss: 0.057367
#   Epoch 60/100, Loss: 0.057330
#   Epoch 70/100, Loss: 0.057300
#   Epoch 80/100, Loss: 0.057270
#   Epoch 90/100, Loss: 0.057241
#   Epoch 100/100, Loss: 0.057215
# Training complete for run 10
# Run 10 — RMSE: 11.212591, MSE: 125.722203, NMSE: 0.0007690878
#
# ===== RUN 11/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.058901
#   Epoch 20/100, Loss: 0.058355
#   Epoch 30/100, Loss: 0.058062
#   Epoch 40/100, Loss: 0.057879
#   Epoch 50/100, Loss: 0.057753
#   Epoch 60/100, Loss: 0.057662
#   Epoch 70/100, Loss: 0.057592
#   Epoch 80/100, Loss: 0.057530
#   Epoch 90/100, Loss: 0.057469
#   Epoch 100/100, Loss: 0.057401
# Training complete for run 11
# Run 11 — RMSE: 11.186501, MSE: 125.137805, NMSE: 0.0007638149
#
# ===== RUN 12/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.056634
#   Epoch 20/100, Loss: 0.056640
#   Epoch 30/100, Loss: 0.056640
#   Epoch 40/100, Loss: 0.056616
#   Epoch 50/100, Loss: 0.056581
#   Epoch 60/100, Loss: 0.056540
#   Epoch 70/100, Loss: 0.056501
#   Epoch 80/100, Loss: 0.056471
#   Epoch 90/100, Loss: 0.056433
#   Epoch 100/100, Loss: 0.056392
# Training complete for run 12
# Run 12 — RMSE: 11.366238, MSE: 129.191365, NMSE: 0.0008021374
#
# ===== RUN 13/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.059478
#   Epoch 20/100, Loss: 0.058707
#   Epoch 30/100, Loss: 0.058303
#   Epoch 40/100, Loss: 0.057954
#   Epoch 50/100, Loss: 0.057602
#   Epoch 60/100, Loss: 0.057232
#   Epoch 70/100, Loss: 0.056893
#   Epoch 80/100, Loss: 0.056623
#   Epoch 90/100, Loss: 0.056401
#   Epoch 100/100, Loss: 0.056192
# Training complete for run 13
# Run 13 — RMSE: 11.223444, MSE: 125.965704, NMSE: 0.0007884767
#
# ===== RUN 14/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.058033
#   Epoch 20/100, Loss: 0.057789
#   Epoch 30/100, Loss: 0.057629
#   Epoch 40/100, Loss: 0.057510
#   Epoch 50/100, Loss: 0.057418
#   Epoch 60/100, Loss: 0.057348
#   Epoch 70/100, Loss: 0.057298
#   Epoch 80/100, Loss: 0.057264
#   Epoch 90/100, Loss: 0.057237
#   Epoch 100/100, Loss: 0.057214
# Training complete for run 14
# Run 14 — RMSE: 11.223287, MSE: 125.962169, NMSE: 0.0007714212
#
# ===== RUN 15/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.057182
#   Epoch 20/100, Loss: 0.057031
#   Epoch 30/100, Loss: 0.056894
#   Epoch 40/100, Loss: 0.056750
#   Epoch 50/100, Loss: 0.056565
#   Epoch 60/100, Loss: 0.056340
#   Epoch 70/100, Loss: 0.056065
#   Epoch 80/100, Loss: 0.055708
#   Epoch 90/100, Loss: 0.055221
#   Epoch 100/100, Loss: 0.054624
# Training complete for run 15
# Run 15 — RMSE: 11.376619, MSE: 129.427449, NMSE: 0.0008073853
#
# ===== RUN 16/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.058627
#   Epoch 20/100, Loss: 0.058218
#   Epoch 30/100, Loss: 0.057969
#   Epoch 40/100, Loss: 0.057794
#   Epoch 50/100, Loss: 0.057657
#   Epoch 60/100, Loss: 0.057542
#   Epoch 70/100, Loss: 0.057436
#   Epoch 80/100, Loss: 0.057329
#   Epoch 90/100, Loss: 0.057210
#   Epoch 100/100, Loss: 0.057069
# Training complete for run 16
# Run 16 — RMSE: 11.240124, MSE: 126.340397, NMSE: 0.0007751093
#
# ===== RUN 17/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.057019
#   Epoch 20/100, Loss: 0.057048
#   Epoch 30/100, Loss: 0.057102
#   Epoch 40/100, Loss: 0.057144
#   Epoch 50/100, Loss: 0.057129
#   Epoch 60/100, Loss: 0.057092
#   Epoch 70/100, Loss: 0.057056
#   Epoch 80/100, Loss: 0.057034
#   Epoch 90/100, Loss: 0.057027
#   Epoch 100/100, Loss: 0.057028
# Training complete for run 17
# Run 17 — RMSE: 11.297713, MSE: 127.638321, NMSE: 0.0007860246
#
# ===== RUN 18/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.057441
#   Epoch 20/100, Loss: 0.057295
#   Epoch 30/100, Loss: 0.057183
#   Epoch 40/100, Loss: 0.057090
#   Epoch 50/100, Loss: 0.057005
#   Epoch 60/100, Loss: 0.056923
#   Epoch 70/100, Loss: 0.056837
#   Epoch 80/100, Loss: 0.056740
#   Epoch 90/100, Loss: 0.056622
#   Epoch 100/100, Loss: 0.056476
# Training complete for run 18
# Run 18 — RMSE: 11.322847, MSE: 128.206868, NMSE: 0.0007909926
#
# ===== RUN 19/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.057321
#   Epoch 20/100, Loss: 0.057228
#   Epoch 30/100, Loss: 0.057176
#   Epoch 40/100, Loss: 0.057138
#   Epoch 50/100, Loss: 0.057095
#   Epoch 60/100, Loss: 0.057040
#   Epoch 70/100, Loss: 0.056968
#   Epoch 80/100, Loss: 0.056874
#   Epoch 90/100, Loss: 0.056750
#   Epoch 100/100, Loss: 0.056583
# Training complete for run 19
# Run 19 — RMSE: 11.264014, MSE: 126.878011, NMSE: 0.0007840840
#
# ===== RUN 20/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.056564
#   Epoch 20/100, Loss: 0.056534
#   Epoch 30/100, Loss: 0.056519
#   Epoch 40/100, Loss: 0.056490
#   Epoch 50/100, Loss: 0.056449
#   Epoch 60/100, Loss: 0.056399
#   Epoch 70/100, Loss: 0.056342
#   Epoch 80/100, Loss: 0.056279
#   Epoch 90/100, Loss: 0.056211
#   Epoch 100/100, Loss: 0.056137
# Training complete for run 20
# Run 20 — RMSE: 11.344327, MSE: 128.693759, NMSE: 0.0007952544
#
# ===== RUN 21/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.057223
#   Epoch 20/100, Loss: 0.057127
#   Epoch 30/100, Loss: 0.057071
#   Epoch 40/100, Loss: 0.057039
#   Epoch 50/100, Loss: 0.057021
#   Epoch 60/100, Loss: 0.057006
#   Epoch 70/100, Loss: 0.056987
#   Epoch 80/100, Loss: 0.056964
#   Epoch 90/100, Loss: 0.056924
#   Epoch 100/100, Loss: 0.056854
# Training complete for run 21
# Run 21 — RMSE: 11.218755, MSE: 125.860465, NMSE: 0.0007791745
#
# ===== RUN 22/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.057772
#   Epoch 20/100, Loss: 0.057645
#   Epoch 30/100, Loss: 0.057554
#   Epoch 40/100, Loss: 0.057476
#   Epoch 50/100, Loss: 0.057406
#   Epoch 60/100, Loss: 0.057345
#   Epoch 70/100, Loss: 0.057291
#   Epoch 80/100, Loss: 0.057248
#   Epoch 90/100, Loss: 0.057210
#   Epoch 100/100, Loss: 0.057176
# Training complete for run 22
# Run 22 — RMSE: 11.221392, MSE: 125.919632, NMSE: 0.0007733403
#
# ===== RUN 23/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.058052
#   Epoch 20/100, Loss: 0.057910
#   Epoch 30/100, Loss: 0.057823
#   Epoch 40/100, Loss: 0.057739
#   Epoch 50/100, Loss: 0.057670
#   Epoch 60/100, Loss: 0.057609
#   Epoch 70/100, Loss: 0.057545
#   Epoch 80/100, Loss: 0.057470
#   Epoch 90/100, Loss: 0.057373
#   Epoch 100/100, Loss: 0.057249
# Training complete for run 23
# Run 23 — RMSE: 11.226936, MSE: 126.044083, NMSE: 0.0007736618
#
# ===== RUN 24/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.059238
#   Epoch 20/100, Loss: 0.058622
#   Epoch 30/100, Loss: 0.058268
#   Epoch 40/100, Loss: 0.058004
#   Epoch 50/100, Loss: 0.057776
#   Epoch 60/100, Loss: 0.057529
#   Epoch 70/100, Loss: 0.057206
#   Epoch 80/100, Loss: 0.056817
#   Epoch 90/100, Loss: 0.056480
#   Epoch 100/100, Loss: 0.056266
# Training complete for run 24
# Run 24 — RMSE: 11.314030, MSE: 128.007273, NMSE: 0.0007917239
#
# ===== RUN 25/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.058831
#   Epoch 20/100, Loss: 0.058316
#   Epoch 30/100, Loss: 0.058028
#   Epoch 40/100, Loss: 0.057834
#   Epoch 50/100, Loss: 0.057686
#   Epoch 60/100, Loss: 0.057575
#   Epoch 70/100, Loss: 0.057491
#   Epoch 80/100, Loss: 0.057414
#   Epoch 90/100, Loss: 0.057319
#   Epoch 100/100, Loss: 0.057206
# Training complete for run 25
# Run 25 — RMSE: 11.211323, MSE: 125.693763, NMSE: 0.0007724393
#
# ===== RUN 26/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.058616
#   Epoch 20/100, Loss: 0.058178
#   Epoch 30/100, Loss: 0.057914
#   Epoch 40/100, Loss: 0.057728
#   Epoch 50/100, Loss: 0.057584
#   Epoch 60/100, Loss: 0.057468
#   Epoch 70/100, Loss: 0.057380
#   Epoch 80/100, Loss: 0.057322
#   Epoch 90/100, Loss: 0.057281
#   Epoch 100/100, Loss: 0.057250
# Training complete for run 26
# Run 26 — RMSE: 11.234199, MSE: 126.207234, NMSE: 0.0007753423
#
# ===== RUN 27/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.056965
#   Epoch 20/100, Loss: 0.056774
#   Epoch 30/100, Loss: 0.056685
#   Epoch 40/100, Loss: 0.056607
#   Epoch 50/100, Loss: 0.056517
#   Epoch 60/100, Loss: 0.056417
#   Epoch 70/100, Loss: 0.056296
#   Epoch 80/100, Loss: 0.056155
#   Epoch 90/100, Loss: 0.056008
#   Epoch 100/100, Loss: 0.055867
# Training complete for run 27
# Run 27 — RMSE: 11.365814, MSE: 129.181719, NMSE: 0.0008047497
#
# ===== RUN 28/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.056623
#   Epoch 20/100, Loss: 0.056495
#   Epoch 30/100, Loss: 0.056434
#   Epoch 40/100, Loss: 0.056356
#   Epoch 50/100, Loss: 0.056255
#   Epoch 60/100, Loss: 0.056132
#   Epoch 70/100, Loss: 0.055971
#   Epoch 80/100, Loss: 0.055741
#   Epoch 90/100, Loss: 0.055385
#   Epoch 100/100, Loss: 0.054876
# Training complete for run 28
# Run 28 — RMSE: 11.517039, MSE: 132.642193, NMSE: 0.0008370277
#
# ===== RUN 29/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.056638
#   Epoch 20/100, Loss: 0.056427
#   Epoch 30/100, Loss: 0.056287
#   Epoch 40/100, Loss: 0.056148
#   Epoch 50/100, Loss: 0.055990
#   Epoch 60/100, Loss: 0.055805
#   Epoch 70/100, Loss: 0.055586
#   Epoch 80/100, Loss: 0.055327
#   Epoch 90/100, Loss: 0.055031
#   Epoch 100/100, Loss: 0.054732
# Training complete for run 29
# Run 29 — RMSE: 11.378128, MSE: 129.461794, NMSE: 0.0008040900
#
# ===== RUN 30/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.058230
#   Epoch 20/100, Loss: 0.057976
#   Epoch 30/100, Loss: 0.057842
#   Epoch 40/100, Loss: 0.057755
#   Epoch 50/100, Loss: 0.057678
#   Epoch 60/100, Loss: 0.057607
#   Epoch 70/100, Loss: 0.057543
#   Epoch 80/100, Loss: 0.057490
#   Epoch 90/100, Loss: 0.057452
#   Epoch 100/100, Loss: 0.057429
# Training complete for run 30
# Run 30 — RMSE: 11.192628, MSE: 125.274924, NMSE: 0.0007660054
#
# ===== RUN 31/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.057692
#   Epoch 20/100, Loss: 0.057420
#   Epoch 30/100, Loss: 0.057261
#   Epoch 40/100, Loss: 0.057129
#   Epoch 50/100, Loss: 0.057042
#   Epoch 60/100, Loss: 0.056955
#   Epoch 70/100, Loss: 0.056855
#   Epoch 80/100, Loss: 0.056738
#   Epoch 90/100, Loss: 0.056599
#   Epoch 100/100, Loss: 0.056431
# Training complete for run 31
# Run 31 — RMSE: 11.288521, MSE: 127.430702, NMSE: 0.0007868067
#
# ===== RUN 32/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.057387
#   Epoch 20/100, Loss: 0.057228
#   Epoch 30/100, Loss: 0.057147
#   Epoch 40/100, Loss: 0.057100
#   Epoch 50/100, Loss: 0.057065
#   Epoch 60/100, Loss: 0.057047
#   Epoch 70/100, Loss: 0.057048
#   Epoch 80/100, Loss: 0.057073
#   Epoch 90/100, Loss: 0.057072
#   Epoch 100/100, Loss: 0.057062
# Training complete for run 32
# Run 32 — RMSE: 11.215183, MSE: 125.780333, NMSE: 0.0007739045
#
# ===== RUN 33/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.057821
#   Epoch 20/100, Loss: 0.057621
#   Epoch 30/100, Loss: 0.057506
#   Epoch 40/100, Loss: 0.057422
#   Epoch 50/100, Loss: 0.057358
#   Epoch 60/100, Loss: 0.057309
#   Epoch 70/100, Loss: 0.057277
#   Epoch 80/100, Loss: 0.057264
#   Epoch 90/100, Loss: 0.057264
#   Epoch 100/100, Loss: 0.057271
# Training complete for run 33
# Run 33 — RMSE: 11.211829, MSE: 125.705119, NMSE: 0.0007717718
#
# ===== RUN 34/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.058450
#   Epoch 20/100, Loss: 0.058001
#   Epoch 30/100, Loss: 0.057441
#   Epoch 40/100, Loss: 0.056437
#   Epoch 50/100, Loss: 0.056190
#   Epoch 60/100, Loss: 0.056954
#   Epoch 70/100, Loss: 0.057308
#   Epoch 80/100, Loss: 0.057421
#   Epoch 90/100, Loss: 0.057452
#   Epoch 100/100, Loss: 0.057444
# Training complete for run 34
# Run 34 — RMSE: 11.191211, MSE: 125.243211, NMSE: 0.0007710447
#
# ===== RUN 35/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.056944
#   Epoch 20/100, Loss: 0.056776
#   Epoch 30/100, Loss: 0.056675
#   Epoch 40/100, Loss: 0.056618
#   Epoch 50/100, Loss: 0.056546
#   Epoch 60/100, Loss: 0.056448
#   Epoch 70/100, Loss: 0.056319
#   Epoch 80/100, Loss: 0.056156
#   Epoch 90/100, Loss: 0.055920
#   Epoch 100/100, Loss: 0.055568
# Training complete for run 35
# Run 35 — RMSE: 11.442462, MSE: 130.929926, NMSE: 0.0008118221
#
# ===== RUN 36/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.058977
#   Epoch 20/100, Loss: 0.058416
#   Epoch 30/100, Loss: 0.058119
#   Epoch 40/100, Loss: 0.057925
#   Epoch 50/100, Loss: 0.057781
#   Epoch 60/100, Loss: 0.057673
#   Epoch 70/100, Loss: 0.057585
#   Epoch 80/100, Loss: 0.057507
#   Epoch 90/100, Loss: 0.057443
#   Epoch 100/100, Loss: 0.057404
# Training complete for run 36
# Run 36 — RMSE: 11.196168, MSE: 125.354167, NMSE: 0.0007690556
#
# ===== RUN 37/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.058112
#   Epoch 20/100, Loss: 0.057902
#   Epoch 30/100, Loss: 0.057767
#   Epoch 40/100, Loss: 0.057676
#   Epoch 50/100, Loss: 0.057605
#   Epoch 60/100, Loss: 0.057544
#   Epoch 70/100, Loss: 0.057488
#   Epoch 80/100, Loss: 0.057434
#   Epoch 90/100, Loss: 0.057381
#   Epoch 100/100, Loss: 0.057328
# Training complete for run 37
# Run 37 — RMSE: 11.213418, MSE: 125.740740, NMSE: 0.0007696357
#
# ===== RUN 38/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.058351
#   Epoch 20/100, Loss: 0.058052
#   Epoch 30/100, Loss: 0.057851
#   Epoch 40/100, Loss: 0.057698
#   Epoch 50/100, Loss: 0.057571
#   Epoch 60/100, Loss: 0.057459
#   Epoch 70/100, Loss: 0.057354
#   Epoch 80/100, Loss: 0.057252
#   Epoch 90/100, Loss: 0.057145
#   Epoch 100/100, Loss: 0.057025
# Training complete for run 38
# Run 38 — RMSE: 11.255494, MSE: 126.686142, NMSE: 0.0007783174
#
# ===== RUN 39/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.056881
#   Epoch 20/100, Loss: 0.056855
#   Epoch 30/100, Loss: 0.056815
#   Epoch 40/100, Loss: 0.056711
#   Epoch 50/100, Loss: 0.056574
#   Epoch 60/100, Loss: 0.056415
#   Epoch 70/100, Loss: 0.056234
#   Epoch 80/100, Loss: 0.056023
#   Epoch 90/100, Loss: 0.055765
#   Epoch 100/100, Loss: 0.055438
# Training complete for run 39
# Run 39 — RMSE: 11.405572, MSE: 130.087063, NMSE: 0.0008100979
#
# ===== RUN 40/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.058145
#   Epoch 20/100, Loss: 0.057883
#   Epoch 30/100, Loss: 0.057725
#   Epoch 40/100, Loss: 0.057627
#   Epoch 50/100, Loss: 0.057550
#   Epoch 60/100, Loss: 0.057486
#   Epoch 70/100, Loss: 0.057430
#   Epoch 80/100, Loss: 0.057376
#   Epoch 90/100, Loss: 0.057316
#   Epoch 100/100, Loss: 0.057244
# Training complete for run 40
# Run 40 — RMSE: 11.224363, MSE: 125.986320, NMSE: 0.0007723900
#
# ===== RUN 41/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.057836
#   Epoch 20/100, Loss: 0.057655
#   Epoch 30/100, Loss: 0.057518
#   Epoch 40/100, Loss: 0.057401
#   Epoch 50/100, Loss: 0.057293
#   Epoch 60/100, Loss: 0.057184
#   Epoch 70/100, Loss: 0.057065
#   Epoch 80/100, Loss: 0.056934
#   Epoch 90/100, Loss: 0.056789
#   Epoch 100/100, Loss: 0.056629
# Training complete for run 41
# Run 41 — RMSE: 11.358356, MSE: 129.012253, NMSE: 0.0007916420
#
# ===== RUN 42/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.057607
#   Epoch 20/100, Loss: 0.057431
#   Epoch 30/100, Loss: 0.057331
#   Epoch 40/100, Loss: 0.057295
#   Epoch 50/100, Loss: 0.057267
#   Epoch 60/100, Loss: 0.057244
#   Epoch 70/100, Loss: 0.057226
#   Epoch 80/100, Loss: 0.057214
#   Epoch 90/100, Loss: 0.057210
#   Epoch 100/100, Loss: 0.057212
# Training complete for run 42
# Run 42 — RMSE: 11.204124, MSE: 125.532403, NMSE: 0.0007727989
#
# ===== RUN 43/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.056983
#   Epoch 20/100, Loss: 0.056773
#   Epoch 30/100, Loss: 0.056638
#   Epoch 40/100, Loss: 0.056521
#   Epoch 50/100, Loss: 0.056410
#   Epoch 60/100, Loss: 0.056294
#   Epoch 70/100, Loss: 0.056176
#   Epoch 80/100, Loss: 0.056051
#   Epoch 90/100, Loss: 0.055911
#   Epoch 100/100, Loss: 0.055755
# Training complete for run 43
# Run 43 — RMSE: 11.364879, MSE: 129.160481, NMSE: 0.0008062825
#
# ===== RUN 44/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.058343
#   Epoch 20/100, Loss: 0.057910
#   Epoch 30/100, Loss: 0.057693
#   Epoch 40/100, Loss: 0.057557
#   Epoch 50/100, Loss: 0.057474
#   Epoch 60/100, Loss: 0.057439
#   Epoch 70/100, Loss: 0.057455
#   Epoch 80/100, Loss: 0.057460
#   Epoch 90/100, Loss: 0.057431
#   Epoch 100/100, Loss: 0.057416
# Training complete for run 44
# Run 44 — RMSE: 11.234769, MSE: 126.220035, NMSE: 0.0007743673
#
# ===== RUN 45/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.057180
#   Epoch 20/100, Loss: 0.057057
#   Epoch 30/100, Loss: 0.056949
#   Epoch 40/100, Loss: 0.056835
#   Epoch 50/100, Loss: 0.056699
#   Epoch 60/100, Loss: 0.056523
#   Epoch 70/100, Loss: 0.056258
#   Epoch 80/100, Loss: 0.055751
#   Epoch 90/100, Loss: 0.054941
#   Epoch 100/100, Loss: 0.054327
# Training complete for run 45
# Run 45 — RMSE: 11.531024, MSE: 132.964519, NMSE: 0.0008366623
#
# ===== RUN 46/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.057113
#   Epoch 20/100, Loss: 0.057044
#   Epoch 30/100, Loss: 0.057008
#   Epoch 40/100, Loss: 0.056981
#   Epoch 50/100, Loss: 0.056955
#   Epoch 60/100, Loss: 0.056919
#   Epoch 70/100, Loss: 0.056878
#   Epoch 80/100, Loss: 0.056845
#   Epoch 90/100, Loss: 0.056810
#   Epoch 100/100, Loss: 0.056777
# Training complete for run 46
# Run 46 — RMSE: 11.286457, MSE: 127.384102, NMSE: 0.0007893724
#
# ===== RUN 47/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.057618
#   Epoch 20/100, Loss: 0.057482
#   Epoch 30/100, Loss: 0.057418
#   Epoch 40/100, Loss: 0.057370
#   Epoch 50/100, Loss: 0.057321
#   Epoch 60/100, Loss: 0.057272
#   Epoch 70/100, Loss: 0.057221
#   Epoch 80/100, Loss: 0.057162
#   Epoch 90/100, Loss: 0.057068
#   Epoch 100/100, Loss: 0.056942
# Training complete for run 47
# Run 47 — RMSE: 11.230573, MSE: 126.125773, NMSE: 0.0007775842
#
# ===== RUN 48/60 [Noise 0.5%] =====
#   Epoch 10/100, Loss: 0.057533
#   Epoch 20/100, Loss: 0.057328
#   Epoch 30/100, Loss: 0.057191
#   Epoch 40/100, Loss: 0.057096
#   Epoch 50/100, Loss: 0.057039
#   Epoch 60/100, Loss: 0.057024
#   Epoch 70/100, Loss: 0.057035
#   Epoch 80/100, Loss: 0.057025
#   Epoch 90/100, Loss: 0.056992
#   Epoch 100/100, Loss: 0.056935
# Training complete for run 48
# Run 48 — RMSE: 11.235203, MSE: 126.229782, NMSE: 0.0007780173
# ...
#
# ===== RUN 25/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.084989
#   Epoch 20/100, Loss: 0.084223
#   Epoch 30/100, Loss: 0.084074
#   Epoch 40/100, Loss: 0.083940
#   Epoch 50/100, Loss: 0.083786
#   Epoch 60/100, Loss: 0.083664
#   Epoch 70/100, Loss: 0.083542
#   Epoch 80/100, Loss: 0.083415
#   Epoch 90/100, Loss: 0.083275
#   Epoch 100/100, Loss: 0.083115
# Training complete for run 25
# Run 25 — RMSE: 17.881534, MSE: 319.749247, NMSE: 0.0020687014
#
# ===== RUN 26/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.085063
#   Epoch 20/100, Loss: 0.084321
#   Epoch 30/100, Loss: 0.084144
#   Epoch 40/100, Loss: 0.084021
#   Epoch 50/100, Loss: 0.083924
#   Epoch 60/100, Loss: 0.083823
#   Epoch 70/100, Loss: 0.083704
#   Epoch 80/100, Loss: 0.083549
#   Epoch 90/100, Loss: 0.083338
#   Epoch 100/100, Loss: 0.083069
# Training complete for run 26
# Run 26 — RMSE: 17.870977, MSE: 319.371836, NMSE: 0.0020685192
#
# ===== RUN 27/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.083985
#   Epoch 20/100, Loss: 0.083471
#   Epoch 30/100, Loss: 0.083272
#   Epoch 40/100, Loss: 0.083110
#   Epoch 50/100, Loss: 0.082954
#   Epoch 60/100, Loss: 0.082792
#   Epoch 70/100, Loss: 0.082618
#   Epoch 80/100, Loss: 0.082439
#   Epoch 90/100, Loss: 0.082250
#   Epoch 100/100, Loss: 0.082042
# Training complete for run 27
# Run 27 — RMSE: 17.821280, MSE: 317.598013, NMSE: 0.0020820692
#
# ===== RUN 28/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.085132
#   Epoch 20/100, Loss: 0.083636
#   Epoch 30/100, Loss: 0.083154
#   Epoch 40/100, Loss: 0.082853
#   Epoch 50/100, Loss: 0.082545
#   Epoch 60/100, Loss: 0.082190
#   Epoch 70/100, Loss: 0.081782
#   Epoch 80/100, Loss: 0.081313
#   Epoch 90/100, Loss: 0.080786
#   Epoch 100/100, Loss: 0.080211
# Training complete for run 28
# Run 28 — RMSE: 17.902438, MSE: 320.497280, NMSE: 0.0020997978
#
# ===== RUN 29/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.084416
#   Epoch 20/100, Loss: 0.083088
#   Epoch 30/100, Loss: 0.082784
#   Epoch 40/100, Loss: 0.082582
#   Epoch 50/100, Loss: 0.082388
#   Epoch 60/100, Loss: 0.082182
#   Epoch 70/100, Loss: 0.081955
#   Epoch 80/100, Loss: 0.081702
#   Epoch 90/100, Loss: 0.081423
#   Epoch 100/100, Loss: 0.081113
# Training complete for run 29
# Run 29 — RMSE: 17.909591, MSE: 320.753443, NMSE: 0.0021030511
#
# ===== RUN 30/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.085899
#   Epoch 20/100, Loss: 0.084593
#   Epoch 30/100, Loss: 0.084359
#   Epoch 40/100, Loss: 0.084236
#   Epoch 50/100, Loss: 0.084148
#   Epoch 60/100, Loss: 0.084065
#   Epoch 70/100, Loss: 0.083985
#   Epoch 80/100, Loss: 0.083907
#   Epoch 90/100, Loss: 0.083829
#   Epoch 100/100, Loss: 0.083756
# Training complete for run 30
# Run 30 — RMSE: 17.896721, MSE: 320.292632, NMSE: 0.0020789535
#
# ===== RUN 31/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.085456
#   Epoch 20/100, Loss: 0.083093
#   Epoch 30/100, Loss: 0.082523
#   Epoch 40/100, Loss: 0.082065
#   Epoch 50/100, Loss: 0.081660
#   Epoch 60/100, Loss: 0.081292
#   Epoch 70/100, Loss: 0.080946
#   Epoch 80/100, Loss: 0.080602
#   Epoch 90/100, Loss: 0.080235
#   Epoch 100/100, Loss: 0.079815
# Training complete for run 31
# Run 31 — RMSE: 17.955120, MSE: 322.386350, NMSE: 0.0021310413
#
# ===== RUN 32/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.084470
#   Epoch 20/100, Loss: 0.083486
#   Epoch 30/100, Loss: 0.083350
#   Epoch 40/100, Loss: 0.083288
#   Epoch 50/100, Loss: 0.083225
#   Epoch 60/100, Loss: 0.083130
#   Epoch 70/100, Loss: 0.083029
#   Epoch 80/100, Loss: 0.082908
#   Epoch 90/100, Loss: 0.082788
#   Epoch 100/100, Loss: 0.082647
# Training complete for run 32
# Run 32 — RMSE: 17.967620, MSE: 322.835369, NMSE: 0.0020858018
#
# ===== RUN 33/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.084479
#   Epoch 20/100, Loss: 0.084135
#   Epoch 30/100, Loss: 0.084021
#   Epoch 40/100, Loss: 0.083925
#   Epoch 50/100, Loss: 0.083831
#   Epoch 60/100, Loss: 0.083733
#   Epoch 70/100, Loss: 0.083625
#   Epoch 80/100, Loss: 0.083502
#   Epoch 90/100, Loss: 0.083360
#   Epoch 100/100, Loss: 0.083190
# Training complete for run 33
# Run 33 — RMSE: 17.834136, MSE: 318.056416, NMSE: 0.0020692176
#
# ===== RUN 34/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.085925
#   Epoch 20/100, Loss: 0.084423
#   Epoch 30/100, Loss: 0.084206
#   Epoch 40/100, Loss: 0.084086
#   Epoch 50/100, Loss: 0.083993
#   Epoch 60/100, Loss: 0.083910
#   Epoch 70/100, Loss: 0.083833
#   Epoch 80/100, Loss: 0.083759
#   Epoch 90/100, Loss: 0.083688
#   Epoch 100/100, Loss: 0.083618
# Training complete for run 34
# Run 34 — RMSE: 17.843209, MSE: 318.380115, NMSE: 0.0020729079
#
# ===== RUN 35/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.085145
#   Epoch 20/100, Loss: 0.083674
#   Epoch 30/100, Loss: 0.083181
#   Epoch 40/100, Loss: 0.082941
#   Epoch 50/100, Loss: 0.082732
#   Epoch 60/100, Loss: 0.082495
#   Epoch 70/100, Loss: 0.082196
#   Epoch 80/100, Loss: 0.081799
#   Epoch 90/100, Loss: 0.081288
#   Epoch 100/100, Loss: 0.080705
# Training complete for run 35
# Run 35 — RMSE: 17.971131, MSE: 322.961545, NMSE: 0.0021203477
#
# ===== RUN 36/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.085851
#   Epoch 20/100, Loss: 0.084994
#   Epoch 30/100, Loss: 0.084694
#   Epoch 40/100, Loss: 0.084484
#   Epoch 50/100, Loss: 0.084293
#   Epoch 60/100, Loss: 0.084096
#   Epoch 70/100, Loss: 0.083882
#   Epoch 80/100, Loss: 0.083646
#   Epoch 90/100, Loss: 0.083395
#   Epoch 100/100, Loss: 0.083141
# Training complete for run 36
# Run 36 — RMSE: 17.898632, MSE: 320.361037, NMSE: 0.0020692884
#
# ===== RUN 37/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.085382
#   Epoch 20/100, Loss: 0.084228
#   Epoch 30/100, Loss: 0.083964
#   Epoch 40/100, Loss: 0.083752
#   Epoch 50/100, Loss: 0.083526
#   Epoch 60/100, Loss: 0.083260
#   Epoch 70/100, Loss: 0.082930
#   Epoch 80/100, Loss: 0.082509
#   Epoch 90/100, Loss: 0.082002
#   Epoch 100/100, Loss: 0.081536
# Training complete for run 37
# Run 37 — RMSE: 17.859619, MSE: 318.965993, NMSE: 0.0020315837
#
# ===== RUN 38/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.085284
#   Epoch 20/100, Loss: 0.084292
#   Epoch 30/100, Loss: 0.083973
#   Epoch 40/100, Loss: 0.083744
#   Epoch 50/100, Loss: 0.083524
#   Epoch 60/100, Loss: 0.083287
#   Epoch 70/100, Loss: 0.083022
#   Epoch 80/100, Loss: 0.082721
#   Epoch 90/100, Loss: 0.082382
#   Epoch 100/100, Loss: 0.082016
# Training complete for run 38
# Run 38 — RMSE: 17.877854, MSE: 319.617658, NMSE: 0.0020699993
#
# ===== RUN 39/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.083679
#   Epoch 20/100, Loss: 0.082553
#   Epoch 30/100, Loss: 0.082202
#   Epoch 40/100, Loss: 0.081960
#   Epoch 50/100, Loss: 0.081712
#   Epoch 60/100, Loss: 0.081436
#   Epoch 70/100, Loss: 0.081118
#   Epoch 80/100, Loss: 0.080754
#   Epoch 90/100, Loss: 0.080336
#   Epoch 100/100, Loss: 0.079863
# Training complete for run 39
# Run 39 — RMSE: 18.030082, MSE: 325.083858, NMSE: 0.0021567623
#
# ===== RUN 40/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.084992
#   Epoch 20/100, Loss: 0.084398
#   Epoch 30/100, Loss: 0.084193
#   Epoch 40/100, Loss: 0.084021
#   Epoch 50/100, Loss: 0.083849
#   Epoch 60/100, Loss: 0.083660
#   Epoch 70/100, Loss: 0.083440
#   Epoch 80/100, Loss: 0.083178
#   Epoch 90/100, Loss: 0.082868
#   Epoch 100/100, Loss: 0.082527
# Training complete for run 40
# Run 40 — RMSE: 17.816895, MSE: 317.441761, NMSE: 0.0020583335
#
# ===== RUN 41/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.084622
#   Epoch 20/100, Loss: 0.084166
#   Epoch 30/100, Loss: 0.084023
#   Epoch 40/100, Loss: 0.083907
#   Epoch 50/100, Loss: 0.083790
#   Epoch 60/100, Loss: 0.083655
#   Epoch 70/100, Loss: 0.083488
#   Epoch 80/100, Loss: 0.083269
#   Epoch 90/100, Loss: 0.082984
#   Epoch 100/100, Loss: 0.082631
# Training complete for run 41
# Run 41 — RMSE: 17.817528, MSE: 317.464291, NMSE: 0.0020584306
#
# ===== RUN 42/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.084421
#   Epoch 20/100, Loss: 0.083911
#   Epoch 30/100, Loss: 0.083760
#   Epoch 40/100, Loss: 0.083623
#   Epoch 50/100, Loss: 0.083469
#   Epoch 60/100, Loss: 0.083287
#   Epoch 70/100, Loss: 0.083071
#   Epoch 80/100, Loss: 0.082815
#   Epoch 90/100, Loss: 0.082510
#   Epoch 100/100, Loss: 0.082148
# Training complete for run 42
# Run 42 — RMSE: 17.885241, MSE: 319.881853, NMSE: 0.0020999045
#
# ===== RUN 43/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.083962
#   Epoch 20/100, Loss: 0.082872
#   Epoch 30/100, Loss: 0.082622
#   Epoch 40/100, Loss: 0.082403
#   Epoch 50/100, Loss: 0.082174
#   Epoch 60/100, Loss: 0.081920
#   Epoch 70/100, Loss: 0.081637
#   Epoch 80/100, Loss: 0.081327
#   Epoch 90/100, Loss: 0.080998
#   Epoch 100/100, Loss: 0.080669
# Training complete for run 43
# Run 43 — RMSE: 17.902439, MSE: 320.497317, NMSE: 0.0020762097
#
# ===== RUN 44/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.085147
#   Epoch 20/100, Loss: 0.084020
#   Epoch 30/100, Loss: 0.083777
#   Epoch 40/100, Loss: 0.083629
#   Epoch 50/100, Loss: 0.083517
#   Epoch 60/100, Loss: 0.083433
#   Epoch 70/100, Loss: 0.083364
#   Epoch 80/100, Loss: 0.083261
#   Epoch 90/100, Loss: 0.083127
#   Epoch 100/100, Loss: 0.082940
# Training complete for run 44
# Run 44 — RMSE: 17.861280, MSE: 319.025321, NMSE: 0.0020900203
#
# ===== RUN 45/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.083536
#   Epoch 20/100, Loss: 0.082424
#   Epoch 30/100, Loss: 0.082016
#   Epoch 40/100, Loss: 0.081591
#   Epoch 50/100, Loss: 0.081076
#   Epoch 60/100, Loss: 0.080450
#   Epoch 70/100, Loss: 0.079792
#   Epoch 80/100, Loss: 0.079231
#   Epoch 90/100, Loss: 0.078755
#   Epoch 100/100, Loss: 0.078306
# Training complete for run 45
# Run 45 — RMSE: 18.007229, MSE: 324.260302, NMSE: 0.0021391075
#
# ===== RUN 46/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.084177
#   Epoch 20/100, Loss: 0.083437
#   Epoch 30/100, Loss: 0.083358
#   Epoch 40/100, Loss: 0.083295
#   Epoch 50/100, Loss: 0.083221
#   Epoch 60/100, Loss: 0.083124
#   Epoch 70/100, Loss: 0.082989
#   Epoch 80/100, Loss: 0.082800
#   Epoch 90/100, Loss: 0.082532
#   Epoch 100/100, Loss: 0.082151
# Training complete for run 46
# Run 46 — RMSE: 17.883278, MSE: 319.811619, NMSE: 0.0021056436
#
# ===== RUN 47/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.084692
#   Epoch 20/100, Loss: 0.084208
#   Epoch 30/100, Loss: 0.084029
#   Epoch 40/100, Loss: 0.083867
#   Epoch 50/100, Loss: 0.083697
#   Epoch 60/100, Loss: 0.083506
#   Epoch 70/100, Loss: 0.083286
#   Epoch 80/100, Loss: 0.083038
#   Epoch 90/100, Loss: 0.082762
#   Epoch 100/100, Loss: 0.082424
# Training complete for run 47
# Run 47 — RMSE: 17.949908, MSE: 322.199209, NMSE: 0.0020806460
#
# ===== RUN 48/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.085669
#   Epoch 20/100, Loss: 0.084215
#   Epoch 30/100, Loss: 0.084044
#   Epoch 40/100, Loss: 0.083914
#   Epoch 50/100, Loss: 0.083783
#   Epoch 60/100, Loss: 0.083637
#   Epoch 70/100, Loss: 0.083474
#   Epoch 80/100, Loss: 0.083292
#   Epoch 90/100, Loss: 0.083073
#   Epoch 100/100, Loss: 0.082843
# Training complete for run 48
# Run 48 — RMSE: 17.836386, MSE: 318.136673, NMSE: 0.0020879376
#
# ===== RUN 49/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.086400
#   Epoch 20/100, Loss: 0.084608
#   Epoch 30/100, Loss: 0.084279
#   Epoch 40/100, Loss: 0.084117
#   Epoch 50/100, Loss: 0.084016
#   Epoch 60/100, Loss: 0.083939
#   Epoch 70/100, Loss: 0.083867
#   Epoch 80/100, Loss: 0.083791
#   Epoch 90/100, Loss: 0.083703
#   Epoch 100/100, Loss: 0.083600
# Training complete for run 49
# Run 49 — RMSE: 17.930526, MSE: 321.503749, NMSE: 0.0020996708
#
# ===== RUN 50/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.084674
#   Epoch 20/100, Loss: 0.083674
#   Epoch 30/100, Loss: 0.083370
#   Epoch 40/100, Loss: 0.083214
#   Epoch 50/100, Loss: 0.083094
#   Epoch 60/100, Loss: 0.082977
#   Epoch 70/100, Loss: 0.082851
#   Epoch 80/100, Loss: 0.082705
#   Epoch 90/100, Loss: 0.082531
#   Epoch 100/100, Loss: 0.082306
# Training complete for run 50
# Run 50 — RMSE: 17.904439, MSE: 320.568936, NMSE: 0.0021224063
#
# ===== RUN 51/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.083656
#   Epoch 20/100, Loss: 0.083383
#   Epoch 30/100, Loss: 0.083315
#   Epoch 40/100, Loss: 0.083252
#   Epoch 50/100, Loss: 0.083185
#   Epoch 60/100, Loss: 0.083102
#   Epoch 70/100, Loss: 0.082999
#   Epoch 80/100, Loss: 0.082870
#   Epoch 90/100, Loss: 0.082716
#   Epoch 100/100, Loss: 0.082535
# Training complete for run 51
# Run 51 — RMSE: 18.026170, MSE: 324.942788, NMSE: 0.0021133867
#
# ===== RUN 52/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.085396
#   Epoch 20/100, Loss: 0.084287
#   Epoch 30/100, Loss: 0.084070
#   Epoch 40/100, Loss: 0.083933
#   Epoch 50/100, Loss: 0.083804
#   Epoch 60/100, Loss: 0.083667
#   Epoch 70/100, Loss: 0.083533
#   Epoch 80/100, Loss: 0.083387
#   Epoch 90/100, Loss: 0.083227
#   Epoch 100/100, Loss: 0.083048
# Training complete for run 52
# Run 52 — RMSE: 17.834211, MSE: 318.059091, NMSE: 0.0020601161
#
# ===== RUN 53/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.085882
#   Epoch 20/100, Loss: 0.084167
#   Epoch 30/100, Loss: 0.083853
#   Epoch 40/100, Loss: 0.083662
#   Epoch 50/100, Loss: 0.083495
#   Epoch 60/100, Loss: 0.083319
#   Epoch 70/100, Loss: 0.083130
#   Epoch 80/100, Loss: 0.082928
#   Epoch 90/100, Loss: 0.082714
#   Epoch 100/100, Loss: 0.082473
# Training complete for run 53
# Run 53 — RMSE: 17.940968, MSE: 321.878331, NMSE: 0.0020952621
#
# ===== RUN 54/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.085972
#   Epoch 20/100, Loss: 0.083123
#   Epoch 30/100, Loss: 0.082222
#   Epoch 40/100, Loss: 0.081721
#   Epoch 50/100, Loss: 0.081194
#   Epoch 60/100, Loss: 0.080543
#   Epoch 70/100, Loss: 0.079753
#   Epoch 80/100, Loss: 0.078982
#   Epoch 90/100, Loss: 0.078370
#   Epoch 100/100, Loss: 0.077854
# Training complete for run 54
# Run 54 — RMSE: 17.900133, MSE: 320.414753, NMSE: 0.0021475236
#
# ===== RUN 55/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.084728
#   Epoch 20/100, Loss: 0.083780
#   Epoch 30/100, Loss: 0.083420
#   Epoch 40/100, Loss: 0.083135
#   Epoch 50/100, Loss: 0.082841
#   Epoch 60/100, Loss: 0.082496
#   Epoch 70/100, Loss: 0.082069
#   Epoch 80/100, Loss: 0.081544
#   Epoch 90/100, Loss: 0.080950
#   Epoch 100/100, Loss: 0.080359
# Training complete for run 55
# Run 55 — RMSE: 17.903989, MSE: 320.552810, NMSE: 0.0020861038
#
# ===== RUN 56/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.085495
#   Epoch 20/100, Loss: 0.083881
#   Epoch 30/100, Loss: 0.083435
#   Epoch 40/100, Loss: 0.083338
#   Epoch 50/100, Loss: 0.083252
#   Epoch 60/100, Loss: 0.083107
#   Epoch 70/100, Loss: 0.082900
#   Epoch 80/100, Loss: 0.082618
#   Epoch 90/100, Loss: 0.082230
#   Epoch 100/100, Loss: 0.081726
# Training complete for run 56
# Run 56 — RMSE: 17.967030, MSE: 322.814150, NMSE: 0.0021118380
#
# ===== RUN 57/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.085363
#   Epoch 20/100, Loss: 0.084338
#   Epoch 30/100, Loss: 0.083963
#   Epoch 40/100, Loss: 0.083828
#   Epoch 50/100, Loss: 0.083770
#   Epoch 60/100, Loss: 0.083731
#   Epoch 70/100, Loss: 0.083697
#   Epoch 80/100, Loss: 0.083644
#   Epoch 90/100, Loss: 0.083579
#   Epoch 100/100, Loss: 0.083495
# Training complete for run 57
# Run 57 — RMSE: 17.870850, MSE: 319.367291, NMSE: 0.0020868333
#
# ===== RUN 58/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.084600
#   Epoch 20/100, Loss: 0.084191
#   Epoch 30/100, Loss: 0.084014
#   Epoch 40/100, Loss: 0.083856
#   Epoch 50/100, Loss: 0.083695
#   Epoch 60/100, Loss: 0.083527
#   Epoch 70/100, Loss: 0.083350
#   Epoch 80/100, Loss: 0.083163
#   Epoch 90/100, Loss: 0.082963
#   Epoch 100/100, Loss: 0.082748
# Training complete for run 58
# Run 58 — RMSE: 17.895929, MSE: 320.264267, NMSE: 0.0020869613
#
# ===== RUN 59/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.084990
#   Epoch 20/100, Loss: 0.083994
#   Epoch 30/100, Loss: 0.083724
#   Epoch 40/100, Loss: 0.083567
#   Epoch 50/100, Loss: 0.083424
#   Epoch 60/100, Loss: 0.083273
#   Epoch 70/100, Loss: 0.083106
#   Epoch 80/100, Loss: 0.082917
#   Epoch 90/100, Loss: 0.082702
#   Epoch 100/100, Loss: 0.082455
# Training complete for run 59
# Run 59 — RMSE: 17.879703, MSE: 319.683788, NMSE: 0.0020790587
#
# ===== RUN 60/60 [Noise 10.0%] =====
#   Epoch 10/100, Loss: 0.084416
#   Epoch 20/100, Loss: 0.083579
#   Epoch 30/100, Loss: 0.083424
#   Epoch 40/100, Loss: 0.083298
#   Epoch 50/100, Loss: 0.083170
#   Epoch 60/100, Loss: 0.083030
#   Epoch 70/100, Loss: 0.082859
#   Epoch 80/100, Loss: 0.082599
#   Epoch 90/100, Loss: 0.082242
#   Epoch 100/100, Loss: 0.081852
# Training complete for run 60
# Run 60 — RMSE: 17.746923, MSE: 314.953289, NMSE: 0.0020646781
#
# ===== STATS FOR NOISE 10.0% (60 runs) =====
# RMSE: 17.896344 +/- 0.061065
# MSE:  320.282845 +/- 2.186022
# NMSE: 0.0020896438 +/- 0.0000253003
# Best run: 60 (RMSE: 17.746923)

# %% [markdown]
# ## Results

# %%
# ============================================================
# Final Metrics Summary & Plots per Noise Level
# ============================================================
from tabulate import tabulate

for entry in _molab_results:
    lam = entry[0]
    mean_rmse, std_rmse = entry[1], entry[2]
    mean_mse, std_mse = entry[3], entry[4]
    mean_nmse, std_nmse = entry[5], entry[6]
    best_rmse_val = entry[7]
    best_predictions = entry[8]
    best_losses = entry[9]
    raw_values_for_plot = entry[10]
    
    print("\n" + "="*80)
    print(f"RESULTS FOR NOISE LEVEL: {lam*100:.1f}%")
    print("="*80)
    
    print(f'Mean RMSE: {mean_rmse:.6f} +/- {std_rmse:.6f}')
    print(f'Mean MSE:  {mean_mse:.6f} +/- {std_mse:.6f}')
    print(f'Mean NMSE: {mean_nmse:.10f} +/- {std_nmse:.10f}')
    print(f'Best RMSE: {best_rmse_val:.6f}')
    
    actual = raw_values_for_plot[-60:]
    
    plt.figure(figsize=(12, 5))
    plt.plot(actual, label='Actual', color='blue', linewidth=1.5)
    plt.plot(best_predictions, label='Predicted (Best Run)', color='red',
             linewidth=1.5, linestyle='--')
    plt.title(f'Predictions vs Actual (Noise {lam*100:.1f}%)')
    plt.xlabel('Time Step')
    plt.ylabel('Value')
    plt.legend()
    plt.grid(True, alpha=0.3)
    plt.tight_layout()
    plt.show()

    plt.figure(figsize=(12, 4))
    plt.plot(best_losses, color='green', linewidth=1.0)
    plt.title(f'Training Loss (Best Run, Noise {lam*100:.1f}%)')
    plt.xlabel('Epoch')
    plt.ylabel('MSE Loss')
    plt.grid(True, alpha=0.3)
    plt.tight_layout()
    plt.show()

print("\n" + "="*80)
print("FINAL RESULTS TABLE ACROSS ALL NOISE LEVELS")
print("="*80)
df_res = pd.DataFrame(
    [[r[0], f'{r[1]:.6f} +/- {r[2]:.6f}', f'{r[3]:.6f} +/- {r[4]:.6f}', 
      f'{r[5]:.10f} +/- {r[6]:.10f}', f'{r[7]:.6f}'] for r in _molab_results],
    columns=['Noise Level', 'RMSE (mean+/-std)', 'MSE (mean+/-std)', 'NMSE (mean+/-std)', 'Best RMSE']
)
print(tabulate(df_res, headers='keys', tablefmt='github', showindex=False))
# Out:
# ================================================================================
# RESULTS FOR NOISE LEVEL: 0.0%
# ================================================================================
# Mean RMSE: 11.244510 +/- 0.089195
# Mean MSE:  126.446971 +/- 2.014374
# Mean NMSE: 0.0007789378 +/- 0.0000183174
# Best RMSE: 11.138477
# ================================================================================
# RESULTS FOR NOISE LEVEL: 0.5%
# ================================================================================
# Mean RMSE: 11.300051 +/- 0.096867
# Mean MSE:  127.700544 +/- 2.197645
# Mean NMSE: 0.0007897759 +/- 0.0000200828
# Best RMSE: 11.183893
# ================================================================================
# RESULTS FOR NOISE LEVEL: 5.0%
# ================================================================================
# Mean RMSE: 13.542101 +/- 0.078044
# Mean MSE:  183.394597 +/- 2.116309
# Mean NMSE: 0.0011658714 +/- 0.0000230930
# Best RMSE: 13.424940
# ================================================================================
# RESULTS FOR NOISE LEVEL: 10.0%
# ================================================================================
# Mean RMSE: 17.896344 +/- 0.061065
# Mean MSE:  320.282845 +/- 2.186022
# Mean NMSE: 0.0020896438 +/- 0.0000253003
# Best RMSE: 17.746923
# ================================================================================
# FINAL RESULTS TABLE ACROSS ALL NOISE LEVELS
# ================================================================================
# |   Noise Level | RMSE (mean+/-std)      | MSE (mean+/-std)        | NMSE (mean+/-std)             |   Best RMSE |
# |---------------|------------------------|-------------------------|-------------------------------|-------------|
# |         0     | 11.244510 +/- 0.089195 | 126.446971 +/- 2.014374 | 0.0007789378 +/- 0.0000183174 |     11.1385 |
# |         0.005 | 11.300051 +/- 0.096867 | 127.700544 +/- 2.197645 | 0.0007897759 +/- 0.0000200828 |     11.1839 |
# |         0.05  | 13.542101 +/- 0.078044 | 183.394597 +/- 2.116309 | 0.0011658714 +/- 0.0000230930 |     13.4249 |
# |         0.1   | 17.896344 +/- 0.061065 | 320.282845 +/- 2.186022 | 0.0020896438 +/- 0.0000253003 |     17.7469 |
