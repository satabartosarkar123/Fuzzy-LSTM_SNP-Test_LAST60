# %% [markdown]
# # Notebook 4: LSTM-SNP with Fuzzy Output Layer
#
# **Dataset**: Monthly Lake Erie Levels
#
# ## Description
# This notebook implements a **fuzzy output layer** for the LSTM-SNP model. The internal
# LSTM-SNP structure is kept completely intact. The final Dense(1) layer is replaced with a
# fuzzy inference system that takes the RNN hidden state h(t) and produces the prediction
# through Takagi-Sugeno rules.
#
# The fuzzy output layer aggregates h(t) into 2 summary features via mean-pooling, then applies
# 4 rules with fixed Gaussian membership functions and trainable consequent parameters.

# %% [markdown]
# ## Theory: Fuzzy Output Layer
#
# ### LSTM-SNP Cell (Unchanged)
# All internal LSTM-SNP equations remain exactly as in the baseline.
#
# ### Fuzzy Output Computation
# The Dense(1) output layer is replaced with fuzzy inference:
#
# **Input**: $h(t) \in \mathbb{R}^{units}$ from the RNN
#
# **Feature Aggregation**: Mean-pooling into 2 summary statistics:
# - $s_1 = \text{mean}(h_{1:units/2})$
# - $s_2 = \text{mean}(h_{units/2+1:units})$
#
# **Membership Functions** (Fixed Gaussian):
# - $\mu_{low}(s) = \exp\left(-\frac{(s-(-1))^2}{2 \cdot 0.5^2}\right)$
# - $\mu_{high}(s) = \exp\left(-\frac{(s-(+1))^2}{2 \cdot 0.5^2}\right)$
#
# **4 Takagi-Sugeno Rules** (trainable consequents):
# $y_i = a_i s_1 + b_i s_2 + c_i$
#
# **Defuzzification**: $\hat{y} = \frac{\sum_i w_i y_i}{\sum_i w_i}$

# %% [markdown]
# ## Model Architecture & Implementation

# %%
# ============================================================
# ALL IMPORTS
# ============================================================

import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras import layers
from tensorflow.keras import Model
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from math import sqrt
import matplotlib.pyplot as plt
import warnings
import os

warnings.filterwarnings('ignore')
print(f"TensorFlow version: {tf.__version__}")
print(f"NumPy version: {np.__version__}")
# Out:
# TensorFlow version: 2.20.0
# NumPy version: 2.0.2

# %% [markdown]
# ### LSTM-SNP Cell

# %%
# ============================================================
# LSTM-SNP Cell (Original — Unmodified)
# ============================================================

class LSTMSNPCell(layers.Layer):
    """
    LSTM-SNP Cell: A long short-term memory model inspired from
    spiking neural P systems.

    Gates:
      r(t) = ρ(W_r x(t) + U_r u(t-1) + b_r)   [reset]
      c(t) = ρ(W_c x(t) + U_c u(t-1) + b_c)   [consumption]
      o(t) = ρ(W_o x(t) + U_o u(t-1) + b_o)   [output/generation]
      a(t) = f(W_a x(t) + U_a u(t-1) + b_a)   [generated spikes]

    State update:
      u(t) = r(t) * u(t-1) - c(t) * a(t)
      h(t) = o(t) * a(t)

    ρ = hard_sigmoid, f = tanh
    """
    def __init__(self, units,
                 activation='tanh',
                 recurrent_activation='hard_sigmoid',
                 **kwargs):
        super().__init__(**kwargs)
        self.units = units
        self.state_size = units
        self.output_size = units

        self.activation = tf.keras.activations.get(activation)
        self.recurrent_activation = tf.keras.activations.get(recurrent_activation)

    def build(self, input_shape):
        input_dim = input_shape[-1]

        self.kernel = self.add_weight(
            shape=(input_dim, self.units * 4),
            initializer='glorot_uniform',
            name='kernel'
        )
        self.recurrent_kernel = self.add_weight(
            shape=(self.units, self.units * 4),
            initializer='orthogonal',
            name='recurrent_kernel'
        )
        self.bias = self.add_weight(
            shape=(self.units * 4,),
            initializer='zeros',
            name='bias'
        )

    def call(self, inputs, states):
        u_tm1 = states[0]

        z = tf.matmul(inputs, self.kernel) + \
            tf.matmul(u_tm1, self.recurrent_kernel) + self.bias

        z0 = z[:, :self.units]
        z1 = z[:, self.units:2*self.units]
        z2 = z[:, 2*self.units:3*self.units]
        z3 = z[:, 3*self.units:]

        r = self.recurrent_activation(z0)  # reset
        c = self.recurrent_activation(z1)  # consumption
        o = self.recurrent_activation(z2)  # output/generation
        a = self.activation(z3)            # generated spikes

        u = r * u_tm1 - c * a  # internal state
        h = o * a              # output

        return h, [u]

    def get_config(self):
        config = super().get_config()
        config.update({
            'units': self.units,
        })
        return config

# %% [markdown]
# ### Fuzzy Output Layer

# %%
# ============================================================
# Fuzzy Output Layer
# Replaces Dense(1) with fuzzy inference.
#
# Takes RNN output h(t) ∈ R^units, produces scalar prediction.
# Aggregates h(t) into 2 summary features via mean-pooling:
#   s1 = mean(h[:units//2])
#   s2 = mean(h[units//2:])
#
# Then applies 4 Takagi-Sugeno rules.
# Fixed Gaussian MFs. Trainable consequent parameters.
# ============================================================

class FuzzyOutputLayer(layers.Layer):
    """
    Fuzzy output layer: replaces Dense(1).
    Input: h(t) from RNN (shape: [batch, units])
    Output: scalar prediction (shape: [batch, 1])
    """
    def __init__(self, units_in, **kwargs):
        super().__init__(**kwargs)
        self.units_in = units_in
        self.mu_low = -1.0
        self.mu_high = 1.0
        self.sigma = 0.5

    def build(self, input_shape):
        # 4 rules, each with 3 consequent params (a, b, c)
        # y_i = a_i * s1 + b_i * s2 + c_i
        self.rule_a = self.add_weight(shape=(4,), initializer='glorot_uniform', name='rule_a')
        self.rule_b = self.add_weight(shape=(4,), initializer='glorot_uniform', name='rule_b')
        self.rule_c = self.add_weight(shape=(4,), initializer='zeros', name='rule_c')

    def _gaussian_mf(self, x, center):
        return tf.exp(-tf.square(x - center) / (2.0 * self.sigma ** 2))

    def call(self, inputs):
        half = self.units_in // 2
        # Aggregate to 2 summary features
        s1 = tf.reduce_mean(inputs[:, :half], axis=-1, keepdims=True)  # [batch, 1]
        s2 = tf.reduce_mean(inputs[:, half:], axis=-1, keepdims=True)  # [batch, 1]

        # Membership degrees
        mu_low_s1 = self._gaussian_mf(s1, self.mu_low)
        mu_high_s1 = self._gaussian_mf(s1, self.mu_high)
        mu_low_s2 = self._gaussian_mf(s2, self.mu_low)
        mu_high_s2 = self._gaussian_mf(s2, self.mu_high)

        # Rule weights
        w1 = mu_low_s1 * mu_low_s2
        w2 = mu_low_s1 * mu_high_s2
        w3 = mu_high_s1 * mu_low_s2
        w4 = mu_high_s1 * mu_high_s2

        # Consequent outputs
        y1 = self.rule_a[0] * s1 + self.rule_b[0] * s2 + self.rule_c[0]
        y2 = self.rule_a[1] * s1 + self.rule_b[1] * s2 + self.rule_c[1]
        y3 = self.rule_a[2] * s1 + self.rule_b[2] * s2 + self.rule_c[2]
        y4 = self.rule_a[3] * s1 + self.rule_b[3] * s2 + self.rule_c[3]

        # Defuzzification
        numerator = w1 * y1 + w2 * y2 + w3 * y3 + w4 * y4
        denominator = w1 + w2 + w3 + w4 + 1e-8

        return numerator / denominator

    def get_config(self):
        config = super().get_config()
        config.update({'units_in': self.units_in})
        return config

# %% [markdown]
# ### Build Model

# %%
# ============================================================
# Model Construction: LSTM-SNP with Fuzzy Output Layer
# LSTMSNPCell is UNMODIFIED.
# Dense(1) is replaced by FuzzyOutputLayer.
# ============================================================

def build_model(input_dim, units, batch_size):
    cell = LSTMSNPCell(units)
    rnn = layers.RNN(cell, return_sequences=False, stateful=True)

    inputs = tf.keras.Input(batch_shape=(batch_size, 1, input_dim))
    x = rnn(inputs)
    outputs = FuzzyOutputLayer(units_in=units)(x)

    model = tf.keras.Model(inputs, outputs)
    model.compile(optimizer='adam', loss='mean_squared_error')
    return model

# %%
# Quick model check
model = build_model(input_dim=1, units=8, batch_size=1)
model.summary()
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1787834140.584607      85 gpu_device.cc:2020] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13756 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# I0000 00:00:1787834140.587444      85 gpu_device.cc:2020] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 13756 MB memory:  -> device: 1, name: Tesla T4, pci bus id: 0000:00:05.0, compute capability: 7.5
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (1, 1, 1)              │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ rnn (RNN)                       │ (1, 8)                 │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ fuzzy_output_layer              │ (1, 1)                 │            12 │
# │ (FuzzyOutputLayer)              │                        │               │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 332 (1.30 KB)
#  Trainable params: 332 (1.30 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ## Data Pipeline — Monthly Lake Erie Levels

# %%
import os
for f in os.listdir('/kaggle/input/datasets/satabartosarkar/monthly-lake-erie-levels-1921-19-csv/'):
    print(f)
# Out:
# monthly-lake-erie-levels-1921-19.csv

# %%
# ============================================================
# 1. Load Time Series Data
# ============================================================
series = pd.read_csv(
    '/kaggle/input/datasets/satabartosarkar/monthly-lake-erie-levels-1921-19-csv/monthly-lake-erie-levels-1921-19.csv',
    header=0,
    parse_dates=[0],
    index_col=0
)

original_raw_values = series.values.flatten()
print(f"Base data shape: {original_raw_values.shape}")
print(f"Base data first 5 values: {original_raw_values[:5]}")
# Out:
# Base data shape: (600,)
# Base data first 5 values: [14.763 14.649 15.085 16.376 16.926]

# %%
# ============================================================
# 2. First-Order Differencing
# ============================================================

def difference(dataset, interval=1):
    diff = []
    for i in range(interval, len(dataset)):
        value = dataset[i] - dataset[i - interval]
        diff.append(value)
    return np.array(diff)

# %%
# ============================================================
# 3. Convert to Supervised Learning Format (lag=1)
# ============================================================

def timeseries_to_supervised(data, lag=1):
    df = pd.DataFrame(data)
    columns = [df.shift(i) for i in range(1, lag+1)]
    columns.append(df)
    df = pd.concat(columns, axis=1)
    df.fillna(0, inplace=True)
    return df.values

# %%
# ============================================================
# 4 & 5. Train-Test Split and Feature Scaling
# ============================================================
# NOTE: The actual application of differencing, splitting (last 60 for test), 
# and scaling is performed inside the Gaussian Noise loop below to prevent data leakage.
print("Split protocol: Last 60 samples for Testing, remainder for Training.")
# Out:
# Split protocol: Last 60 samples for Testing, remainder for Training.

# %%
# ============================================================
# 6. Reshape for RNN Input
# ============================================================
print("Reshape protocol: (samples, time_steps, features)")
# Out:
# Reshape protocol: (samples, time_steps, features)

# %% [markdown]
# ## Training Loop

# %%
# ============================================================
# Gaussian Noise Evaluation + 60-Run Experiment Protocol (Keras)
# ============================================================
s_x = np.std(original_raw_values)
noise_levels = [0.0, 0.005, 0.05, 0.10]
_molab_results = []

for lam in noise_levels:
    sigma = lam * s_x
    print("\n" + "="*80)
    print(f"EVALUATING NOISE LEVEL: {lam*100:.1f}% (lambda={lam}, sigma={sigma:.6f})")
    print("="*80 + "\n")
    
    np.random.seed(42)
    tf.random.set_seed(42)
    noise = np.random.normal(0, sigma, size=original_raw_values.shape)
    raw_values = original_raw_values + noise
    
    # 2. Difference
    diff_values = difference(raw_values, 1)
    # 3. Supervised
    supervised = timeseries_to_supervised(diff_values, 1)
    # 4. Split (Last 60 for test, no validation)
    train, test = supervised[:-60], supervised[-60:]
    # 5. Scale
    scaler = MinMaxScaler(feature_range=(-1, 1))
    scaler.fit(train)
    train_scaled = scaler.transform(train)
    test_scaled = scaler.transform(test)
    # 6. Reshape
    X_train, y_train = train_scaled[:, 0:-1], train_scaled[:, -1]
    X_train = X_train.reshape((X_train.shape[0], 1, X_train.shape[1]))
    X_test, y_test = test_scaled[:, 0:-1], test_scaled[:, -1]
    
    all_rmse = []
    all_mse = []
    all_nmse = []
    all_predictions = []
    all_losses = []
    
    # 60 RUNS, 100 EPOCHS
    for run in range(60):
        print(f'\n===== RUN {run+1}/60 [Noise {lam*100:.1f}%] =====')

        np.random.seed(run)
        tf.random.set_seed(run)

        tf.keras.backend.clear_session()
        model = build_model(input_dim=1, units=8, batch_size=1)

        # Set consumption gate (c) bias to 1.0 (unit forget bias)
        rnn_layer = model.layers[1]
        cell = rnn_layer.cell
        weights = cell.get_weights()
        bias = weights[2].copy()
        bias[8:16] = 1.0  # units=8, bias[units:2*units]
        weights[2] = bias
        cell.set_weights(weights)

        run_losses = []
        for epoch in range(100):
            history = model.fit(
                X_train, y_train,
                epochs=1, batch_size=1,
                verbose=0, shuffle=False
            )
            run_losses.append(history.history['loss'][0])
            if (epoch+1) % 10 == 0:
                print(f'  Epoch {epoch+1}/100 completed, Loss: {history.history["loss"][0]:.6f}')
            rnn_layer.reset_states()

        all_losses.append(run_losses)
        print(f'Training complete for run {run+1}')

        # Warm-up: condition hidden states on training data
        train_reshaped = train_scaled[:, 0].reshape(len(train_scaled), 1, 1)
        model.predict(train_reshaped, batch_size=1, verbose=0)

        # Test predictions (single-step)
        predictions = []
        for i in range(len(test_scaled)):
            X, y = test_scaled[i, 0:-1], test_scaled[i, -1]
            X_input = X.reshape(1, 1, len(X))
            yhat = model.predict(X_input, batch_size=1, verbose=0)[0, 0]
            
            # Invert scaling
            new_row = [x for x in X] + [yhat]
            array = np.array(new_row).reshape(1, len(new_row))
            inverted = scaler.inverse_transform(array)[0, -1]
            
            # Invert differencing
            inverted = inverted + raw_values[len(train) + i]
            predictions.append(inverted)
            expected = raw_values[len(train) + i + 1]

        # Compute metrics
        actual = raw_values[-len(predictions):]
        rmse = sqrt(mean_squared_error(actual, predictions))
        mse = mean_squared_error(actual, predictions)
        meanV = np.mean(actual)
        dominator = np.linalg.norm(np.array(predictions) - meanV, 2)
        nmse = mse / np.power(dominator, 2)
        all_rmse.append(rmse)
        all_mse.append(mse)
        all_nmse.append(nmse)
        all_predictions.append(predictions)
        print(f'Run {run+1} Metrics — RMSE: {rmse:.6f}, MSE: {mse:.6f}, NMSE: {nmse:.10f}')

    # End of 60 runs for this noise level - save best run data
    best_idx = np.argmin(all_rmse)
    _molab_results.append([lam, all_rmse[best_idx], all_mse[best_idx], all_nmse[best_idx], 
                           all_predictions[best_idx], all_losses[best_idx], raw_values])
    print(f"\nBest run for {lam*100:.1f}% noise: Run {best_idx+1} (RMSE: {all_rmse[best_idx]:.6f})")
# Out:
# ================================================================================
# EVALUATING NOISE LEVEL: 0.0% (lambda=0.0, sigma=0.000000)
# ================================================================================
#
#
# ===== RUN 1/60 [Noise 0.0%] =====
# I0000 00:00:1787834146.561967     130 device_compiler.h:196] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
#   Epoch 10/100 completed, Loss: 0.055012
#   Epoch 20/100 completed, Loss: 0.048794
#   Epoch 30/100 completed, Loss: 0.046906
#   Epoch 40/100 completed, Loss: 0.045968
#   Epoch 50/100 completed, Loss: 0.043961
#   Epoch 60/100 completed, Loss: 0.042759
#   Epoch 70/100 completed, Loss: 0.041714
#   Epoch 80/100 completed, Loss: 0.040963
#   Epoch 90/100 completed, Loss: 0.040067
#   Epoch 100/100 completed, Loss: 0.038851
# Training complete for run 1
# Run 1 Metrics — RMSE: 0.407098, MSE: 0.165729, NMSE: 0.0014914996
#
# ===== RUN 2/60 [Noise 0.0%] =====
#   Epoch 10/100 completed, Loss: 0.060151
#   Epoch 20/100 completed, Loss: 0.056612
#   Epoch 30/100 completed, Loss: 0.053153
#   Epoch 40/100 completed, Loss: 0.051672
#   Epoch 50/100 completed, Loss: 0.050774
#   Epoch 60/100 completed, Loss: 0.049557
#   Epoch 70/100 completed, Loss: 0.048364
#   Epoch 80/100 completed, Loss: 0.047497
#   Epoch 90/100 completed, Loss: 0.046743
#   Epoch 100/100 completed, Loss: 0.044931
# Training complete for run 2
# Run 2 Metrics — RMSE: 0.421447, MSE: 0.177618, NMSE: 0.0015417286
#
# ===== RUN 3/60 [Noise 0.0%] =====
#   Epoch 10/100 completed, Loss: 0.054591
#   Epoch 20/100 completed, Loss: 0.052756
#   Epoch 30/100 completed, Loss: 0.053133
#   Epoch 40/100 completed, Loss: 0.053358
#   Epoch 50/100 completed, Loss: 0.052896
#   Epoch 60/100 completed, Loss: 0.052411
#   Epoch 70/100 completed, Loss: 0.050984
#   Epoch 80/100 completed, Loss: 0.048143
#   Epoch 90/100 completed, Loss: 0.046922
#   Epoch 100/100 completed, Loss: 0.046693
# Training complete for run 3
# Run 3 Metrics — RMSE: 0.432589, MSE: 0.187133, NMSE: 0.0016835052
#
# ===== RUN 4/60 [Noise 0.0%] =====
#   Epoch 10/100 completed, Loss: 0.058989
#   Epoch 20/100 completed, Loss: 0.057641
#   Epoch 30/100 completed, Loss: 0.055584
#   Epoch 40/100 completed, Loss: 0.053835
#   Epoch 50/100 completed, Loss: 0.050149
#   Epoch 60/100 completed, Loss: 0.047886
#   Epoch 70/100 completed, Loss: 0.048136
#   Epoch 80/100 completed, Loss: 0.047936
#   Epoch 90/100 completed, Loss: 0.047175
#   Epoch 100/100 completed, Loss: 0.046152
# Training complete for run 4
# Run 4 Metrics — RMSE: 0.484814, MSE: 0.235044, NMSE: 0.0022497156
#
# ===== RUN 5/60 [Noise 0.0%] =====
#   Epoch 10/100 completed, Loss: 0.056123
#   Epoch 20/100 completed, Loss: 0.054030
#   Epoch 30/100 completed, Loss: 0.052587
#   Epoch 40/100 completed, Loss: 0.051986
#   Epoch 50/100 completed, Loss: 0.051470
#   Epoch 60/100 completed, Loss: 0.049882
#   Epoch 70/100 completed, Loss: 0.047111
#   Epoch 80/100 completed, Loss: 0.045275
#   Epoch 90/100 completed, Loss: 0.044590
#   Epoch 100/100 completed, Loss: 0.043490
# Training complete for run 5
# Run 5 Metrics — RMSE: 0.455518, MSE: 0.207497, NMSE: 0.0020596265
#
# ===== RUN 6/60 [Noise 0.0%] =====
#   Epoch 10/100 completed, Loss: 0.061016
#   Epoch 20/100 completed, Loss: 0.055779
#   Epoch 30/100 completed, Loss: 0.055342
#   Epoch 40/100 completed, Loss: 0.053957
#   Epoch 50/100 completed, Loss: 0.053340
#   Epoch 60/100 completed, Loss: 0.055039
#   Epoch 70/100 completed, Loss: 0.056467
#   Epoch 80/100 completed, Loss: 0.056425
#   Epoch 90/100 completed, Loss: 0.055280
#   Epoch 100/100 completed, Loss: 0.059646
# Training complete for run 6
# Run 6 Metrics — RMSE: 0.502389, MSE: 0.252395, NMSE: 0.0020371998
#
# ===== RUN 7/60 [Noise 0.0%] =====
#   Epoch 10/100 completed, Loss: 0.057273
#   Epoch 20/100 completed, Loss: 0.055609
#   Epoch 30/100 completed, Loss: 0.054042
#   Epoch 40/100 completed, Loss: 0.053773
#   Epoch 50/100 completed, Loss: 0.053055
#   Epoch 60/100 completed, Loss: 0.051443
#   Epoch 70/100 completed, Loss: 0.049839
#   Epoch 80/100 completed, Loss: 0.047779
#   Epoch 90/100 completed, Loss: 0.045374
#   Epoch 100/100 completed, Loss: 0.044427
# Training complete for run 7
# Run 7 Metrics — RMSE: 0.416205, MSE: 0.173227, NMSE: 0.0015404980
#
# ===== RUN 8/60 [Noise 0.0%] =====
#   Epoch 10/100 completed, Loss: 0.059028
#   Epoch 20/100 completed, Loss: 0.058169
#   Epoch 30/100 completed, Loss: 0.056193
#   Epoch 40/100 completed, Loss: 0.054396
#   Epoch 50/100 completed, Loss: 0.053293
#   Epoch 60/100 completed, Loss: 0.061659
#   Epoch 70/100 completed, Loss: 0.054822
#   Epoch 80/100 completed, Loss: 0.051125
#   Epoch 90/100 completed, Loss: 0.044968
#   Epoch 100/100 completed, Loss: 0.044740
# Training complete for run 8
# Run 8 Metrics — RMSE: 0.474298, MSE: 0.224958, NMSE: 0.0021833176
#
# ===== RUN 9/60 [Noise 0.0%] =====
#   Epoch 10/100 completed, Loss: 0.054143
#   Epoch 20/100 completed, Loss: 0.047600
#   Epoch 30/100 completed, Loss: 0.045036
#   Epoch 40/100 completed, Loss: 0.044159
#   Epoch 50/100 completed, Loss: 0.043760
#   Epoch 60/100 completed, Loss: 0.043279
#   Epoch 70/100 completed, Loss: 0.043161
#   Epoch 80/100 completed, Loss: 0.043041
#   Epoch 90/100 completed, Loss: 0.042701
#   Epoch 100/100 completed, Loss: 0.042315
# Training complete for run 9
# Run 9 Metrics — RMSE: 0.412048, MSE: 0.169784, NMSE: 0.0014413256
#
# ===== RUN 10/60 [Noise 0.0%] =====
#   Epoch 10/100 completed, Loss: 0.050693
#   Epoch 20/100 completed, Loss: 0.049514
#   Epoch 30/100 completed, Loss: 0.046812
#   Epoch 40/100 completed, Loss: 0.045122
#   Epoch 50/100 completed, Loss: 0.044613
#   Epoch 60/100 completed, Loss: 0.044581
#   Epoch 70/100 completed, Loss: 0.044474
#   Epoch 80/100 completed, Loss: 0.043740
#   Epoch 90/100 completed, Loss: 0.043680
#   Epoch 100/100 completed, Loss: 0.043713
# Training complete for run 10
# Run 10 Metrics — RMSE: 0.413646, MSE: 0.171103, NMSE: 0.0015023338
#
# ===== RUN 11/60 [Noise 0.0%] =====
#   Epoch 10/100 completed, Loss: 0.057036
#   Epoch 20/100 completed, Loss: 0.048647
#   Epoch 30/100 completed, Loss: 0.061386
#   Epoch 40/100 completed, Loss: 0.059147
#   Epoch 50/100 completed, Loss: 0.057636
#   Epoch 60/100 completed, Loss: 0.048700
#   Epoch 70/100 completed, Loss: 0.048139
#   Epoch 80/100 completed, Loss: 0.047394
#   Epoch 90/100 completed, Loss: 0.046362
#   Epoch 100/100 completed, Loss: 0.045298
# Training complete for run 11
# Run 11 Metrics — RMSE: 0.431922, MSE: 0.186556, NMSE: 0.0016827188
#
# ===== RUN 12/60 [Noise 0.0%] =====
#   Epoch 10/100 completed, Loss: 0.057792
#   Epoch 20/100 completed, Loss: 0.056928
#   Epoch 30/100 completed, Loss: 0.055322
#   Epoch 40/100 completed, Loss: 0.051355
#   Epoch 50/100 completed, Loss: 0.048597
#   Epoch 60/100 completed, Loss: 0.047276
#   Epoch 70/100 completed, Loss: 0.045754
#   Epoch 80/100 completed, Loss: 0.044440
#   Epoch 90/100 completed, Loss: 0.043935
#   Epoch 100/100 completed, Loss: 0.044202
# Training complete for run 12
# Run 12 Metrics — RMSE: 0.427407, MSE: 0.182677, NMSE: 0.0015472347
#
# ===== RUN 13/60 [Noise 0.0%] =====
#   Epoch 10/100 completed, Loss: 0.061597
#   Epoch 20/100 completed, Loss: 0.060973
#   Epoch 30/100 completed, Loss: 0.060523
#   Epoch 40/100 completed, Loss: 0.060153
#   Epoch 50/100 completed, Loss: 0.059030
#   Epoch 60/100 completed, Loss: 0.056742
#   Epoch 70/100 completed, Loss: 0.055766
#   Epoch 80/100 completed, Loss: 0.054260
#   Epoch 90/100 completed, Loss: 0.051538
#   Epoch 100/100 completed, Loss: 0.048137
# Training complete for run 13
# Run 13 Metrics — RMSE: 0.446676, MSE: 0.199520, NMSE: 0.0016823032
#
# ===== RUN 14/60 [Noise 0.0%] =====
#   Epoch 10/100 completed, Loss: 0.056924
#   Epoch 20/100 completed, Loss: 0.055556
#   Epoch 30/100 completed, Loss: 0.053983
#   Epoch 40/100 completed, Loss: 0.051845
#   Epoch 50/100 completed, Loss: 0.048281
#   Epoch 60/100 completed, Loss: 0.042170
#   Epoch 70/100 completed, Loss: 0.040967
#   Epoch 80/100 completed, Loss: 0.040160
#   Epoch 90/100 completed, Loss: 0.039350
#   Epoch 100/100 completed, Loss: 0.039118
# Training complete for run 14
# Run 14 Metrics — RMSE: 0.409528, MSE: 0.167713, NMSE: 0.0014971300
#
# ===== RUN 15/60 [Noise 0.0%] =====
#   Epoch 10/100 completed, Loss: 0.060026
#   Epoch 20/100 completed, Loss: 0.047286
#   Epoch 30/100 completed, Loss: 0.046337
#   Epoch 40/100 completed, Loss: 0.045802
#   Epoch 50/100 completed, Loss: 0.045272
#   Epoch 60/100 completed, Loss: 0.044977
#   Epoch 70/100 completed, Loss: 0.045050
#   Epoch 80/100 completed, Loss: 0.045290
#   Epoch 90/100 completed, Loss: 0.045279
#   Epoch 100/100 completed, Loss: 0.044934
# Training complete for run 15
# Run 15 Metrics — RMSE: 0.428136, MSE: 0.183300, NMSE: 0.0017276264
#
# ===== RUN 16/60 [Noise 0.0%] =====
#   Epoch 10/100 completed, Loss: 0.059485
#   Epoch 20/100 completed, Loss: 0.057672
#   Epoch 30/100 completed, Loss: 0.056292
#   Epoch 40/100 completed, Loss: 0.055269
#   Epoch 50/100 completed, Loss: 0.054744
#   Epoch 60/100 completed, Loss: 0.059970
#   Epoch 70/100 completed, Loss: 0.058386
#   Epoch 80/100 completed, Loss: 0.055921
#   Epoch 90/100 completed, Loss: 0.051197
#   Epoch 100/100 completed, Loss: 0.050494
# Training complete for run 16
# Run 16 Metrics — RMSE: 0.440791, MSE: 0.194297, NMSE: 0.0017112706
#
# ===== RUN 17/60 [Noise 0.0%] =====
#   Epoch 10/100 completed, Loss: 0.058293
#   Epoch 20/100 completed, Loss: 0.056532
#   Epoch 30/100 completed, Loss: 0.053865
#   Epoch 40/100 completed, Loss: 0.053469
#   Epoch 50/100 completed, Loss: 0.054452
#   Epoch 60/100 completed, Loss: 0.055686
#   Epoch 70/100 completed, Loss: 0.057427
#   Epoch 80/100 completed, Loss: 0.057771
#   Epoch 90/100 completed, Loss: 0.056027
#   Epoch 100/100 completed, Loss: 0.051056
# Training complete for run 17
# Run 17 Metrics — RMSE: 0.449999, MSE: 0.202499, NMSE: 0.0016732051
#
# ===== RUN 18/60 [Noise 0.0%] =====
#   Epoch 10/100 completed, Loss: 0.052084
#   Epoch 20/100 completed, Loss: 0.049479
#   Epoch 30/100 completed, Loss: 0.046512
#   Epoch 40/100 completed, Loss: 0.044767
#   Epoch 50/100 completed, Loss: 0.042451
#   Epoch 60/100 completed, Loss: 0.041108
#   Epoch 70/100 completed, Loss: 0.040363
#   Epoch 80/100 completed, Loss: 0.039478
#   Epoch 90/100 completed, Loss: 0.038916
#   Epoch 100/100 completed, Loss: 0.038856
# Training complete for run 18
# Run 18 Metrics — RMSE: 0.417508, MSE: 0.174313, NMSE: 0.0016013742
#
# ===== RUN 19/60 [Noise 0.0%] =====
#   Epoch 10/100 completed, Loss: 0.046847
#   Epoch 20/100 completed, Loss: 0.043585
#   Epoch 30/100 completed, Loss: 0.043101
#   Epoch 40/100 completed, Loss: 0.042929
#   Epoch 50/100 completed, Loss: 0.042631
#   Epoch 60/100 completed, Loss: 0.042221
#   Epoch 70/100 completed, Loss: 0.041786
#   Epoch 80/100 completed, Loss: 0.041440
#   Epoch 90/100 completed, Loss: 0.041146
#   Epoch 100/100 completed, Loss: 0.040934
# Training complete for run 19
# Run 19 Metrics — RMSE: 0.412980, MSE: 0.170553, NMSE: 0.0015671168
#
# ===== RUN 20/60 [Noise 0.0%] =====
#   Epoch 10/100 completed, Loss: 0.051617
#   Epoch 20/100 completed, Loss: 0.050260
#   Epoch 30/100 completed, Loss: 0.048646
#   Epoch 40/100 completed, Loss: 0.048017
#   Epoch 50/100 completed, Loss: 0.048075
#   Epoch 60/100 completed, Loss: 0.047104
#   Epoch 70/100 completed, Loss: 0.046334
#   Epoch 80/100 completed, Loss: 0.046142
#   Epoch 90/100 completed, Loss: 0.046515
#   Epoch 100/100 completed, Loss: 0.046763
# Training complete for run 20
# Run 20 Metrics — RMSE: 0.424655, MSE: 0.180332, NMSE: 0.0016401282
#
# ===== RUN 21/60 [Noise 0.0%] =====
#   Epoch 10/100 completed, Loss: 0.060427
#   Epoch 20/100 completed, Loss: 0.058869
#   Epoch 30/100 completed, Loss: 0.057974
#   Epoch 40/100 completed, Loss: 0.056978
#   Epoch 50/100 completed, Loss: 0.056528
#   Epoch 60/100 completed, Loss: 0.055672
#   Epoch 70/100 completed, Loss: 0.054030
#   Epoch 80/100 completed, Loss: 0.052764
#   Epoch 90/100 completed, Loss: 0.052017
#   Epoch 100/100 completed, Loss: 0.051425
# Training complete for run 21
# Run 21 Metrics — RMSE: 0.438408, MSE: 0.192201, NMSE: 0.0016368425
#
# ===== RUN 22/60 [Noise 0.0%] =====
#   Epoch 10/100 completed, Loss: 0.056643
#   Epoch 20/100 completed, Loss: 0.055285
#   Epoch 30/100 completed, Loss: 0.053803
#   Epoch 40/100 completed, Loss: 0.052431
#   Epoch 50/100 completed, Loss: 0.050360
#   Epoch 60/100 completed, Loss: 0.048100
#   Epoch 70/100 completed, Loss: 0.046253
#   Epoch 80/100 completed, Loss: 0.044240
#   Epoch 90/100 completed, Loss: 0.041795
#   Epoch 100/100 completed, Loss: 0.044313
# Training complete for run 22
# Run 22 Metrics — RMSE: 0.415705, MSE: 0.172810, NMSE: 0.0015704642
#
# ===== RUN 23/60 [Noise 0.0%] =====
#   Epoch 10/100 completed, Loss: 0.088517
#   Epoch 20/100 completed, Loss: 0.087381
#   Epoch 30/100 completed, Loss: 0.086451
#   Epoch 40/100 completed, Loss: 0.085286
#   Epoch 50/100 completed, Loss: 0.087203
#   Epoch 60/100 completed, Loss: 0.081313
#   Epoch 70/100 completed, Loss: 0.068907
#   Epoch 80/100 completed, Loss: 0.061450
#   Epoch 90/100 completed, Loss: 0.060104
#   Epoch 100/100 completed, Loss: 0.060201
# Training complete for run 23
# Run 23 Metrics — RMSE: 0.486780, MSE: 0.236955, NMSE: 0.0020430209
#
# ===== RUN 24/60 [Noise 0.0%] =====
#   Epoch 10/100 completed, Loss: 0.060862
#   Epoch 20/100 completed, Loss: 0.059416
#   Epoch 30/100 completed, Loss: 0.056981
#   Epoch 40/100 completed, Loss: 0.052723
#   Epoch 50/100 completed, Loss: 0.049288
#   Epoch 60/100 completed, Loss: 0.046423
#   Epoch 70/100 completed, Loss: 0.042855
#   Epoch 80/100 completed, Loss: 0.042449
#   Epoch 90/100 completed, Loss: 0.042436
#   Epoch 100/100 completed, Loss: 0.042069
# Training complete for run 24
# Run 24 Metrics — RMSE: 0.422756, MSE: 0.178723, NMSE: 0.0016263089
#
# ===== RUN 25/60 [Noise 0.0%] =====
#   Epoch 10/100 completed, Loss: 0.046797
#   Epoch 20/100 completed, Loss: 0.043765
#   Epoch 30/100 completed, Loss: 0.042369
#   Epoch 40/100 completed, Loss: 0.042142
#   Epoch 50/100 completed, Loss: 0.042321
#   Epoch 60/100 completed, Loss: 0.042641
#   Epoch 70/100 completed, Loss: 0.042856
#   Epoch 80/100 completed, Loss: 0.042733
#   Epoch 90/100 completed, Loss: 0.042223
#   Epoch 100/100 completed, Loss: 0.041722
# Training complete for run 25
# Run 25 Metrics — RMSE: 0.412272, MSE: 0.169968, NMSE: 0.0015828168
#
# ===== RUN 26/60 [Noise 0.0%] =====
#   Epoch 10/100 completed, Loss: 0.054358
#   Epoch 20/100 completed, Loss: 0.051774
#   Epoch 30/100 completed, Loss: 0.050690
#   Epoch 40/100 completed, Loss: 0.049950
#   Epoch 50/100 completed, Loss: 0.049611
#   Epoch 60/100 completed, Loss: 0.049399
#   Epoch 70/100 completed, Loss: 0.046778
#   Epoch 80/100 completed, Loss: 0.044585
#   Epoch 90/100 completed, Loss: 0.043825
#   Epoch 100/100 completed, Loss: 0.043427
# Training complete for run 26
# Run 26 Metrics — RMSE: 0.436741, MSE: 0.190743, NMSE: 0.0018670336
#
# ===== RUN 27/60 [Noise 0.0%] =====
#   Epoch 10/100 completed, Loss: 0.055974
#   Epoch 20/100 completed, Loss: 0.053862
#   Epoch 30/100 completed, Loss: 0.052678
#   Epoch 40/100 completed, Loss: 0.051633
#   Epoch 50/100 completed, Loss: 0.050253
#   Epoch 60/100 completed, Loss: 0.049778
#   Epoch 70/100 completed, Loss: 0.048503
#   Epoch 80/100 completed, Loss: 0.047589
#   Epoch 90/100 completed, Loss: 0.046215
#   Epoch 100/100 completed, Loss: 0.046275
# Training complete for run 27
# Run 27 Metrics — RMSE: 0.423502, MSE: 0.179354, NMSE: 0.0016330631
#
# ===== RUN 28/60 [Noise 0.0%] =====
#   Epoch 10/100 completed, Loss: 0.054006
#   Epoch 20/100 completed, Loss: 0.047340
#   Epoch 30/100 completed, Loss: 0.044932
#   Epoch 40/100 completed, Loss: 0.044024
#   Epoch 50/100 completed, Loss: 0.043490
#   Epoch 60/100 completed, Loss: 0.043032
#   Epoch 70/100 completed, Loss: 0.042626
#   Epoch 80/100 completed, Loss: 0.042420
#   Epoch 90/100 completed, Loss: 0.042410
#   Epoch 100/100 completed, Loss: 0.042637
# Training complete for run 28
# Run 28 Metrics — RMSE: 0.415848, MSE: 0.172929, NMSE: 0.0016276408
#
# ===== RUN 29/60 [Noise 0.0%] =====
#   Epoch 10/100 completed, Loss: 0.053607
#   Epoch 20/100 completed, Loss: 0.058451
#   Epoch 30/100 completed, Loss: 0.055241
#   Epoch 40/100 completed, Loss: 0.056580
#   Epoch 50/100 completed, Loss: 0.058714
#   Epoch 60/100 completed, Loss: 0.057593
#   Epoch 70/100 completed, Loss: 0.055045
#   Epoch 80/100 completed, Loss: 0.052533
#   Epoch 90/100 completed, Loss: 0.051121
#   Epoch 100/100 completed, Loss: 0.050023
# Training complete for run 29
# Run 29 Metrics — RMSE: 0.446529, MSE: 0.199388, NMSE: 0.0016952548
#
# ===== RUN 30/60 [Noise 0.0%] =====
#   Epoch 10/100 completed, Loss: 0.050649
#   Epoch 20/100 completed, Loss: 0.047619
#   Epoch 30/100 completed, Loss: 0.046269
#   Epoch 40/100 completed, Loss: 0.045806
#   Epoch 50/100 completed, Loss: 0.045740
#   Epoch 60/100 completed, Loss: 0.045373
#   Epoch 70/100 completed, Loss: 0.044511
#   Epoch 80/100 completed, Loss: 0.043779
#   Epoch 90/100 completed, Loss: 0.043212
#   Epoch 100/100 completed, Loss: 0.042828
# Training complete for run 30
# Run 30 Metrics — RMSE: 0.423921, MSE: 0.179709, NMSE: 0.0017154424
#
# ===== RUN 31/60 [Noise 0.0%] =====
#   Epoch 10/100 completed, Loss: 0.056496
#   Epoch 20/100 completed, Loss: 0.055597
#   Epoch 30/100 completed, Loss: 0.054532
#   Epoch 40/100 completed, Loss: 0.051949
#   Epoch 50/100 completed, Loss: 0.050311
#   Epoch 60/100 completed, Loss: 0.048482
#   Epoch 70/100 completed, Loss: 0.047983
#   Epoch 80/100 completed, Loss: 0.047594
#   Epoch 90/100 completed, Loss: 0.046999
#   Epoch 100/100 completed, Loss: 0.045482
# Training complete for run 31
# Run 31 Metrics — RMSE: 0.417786, MSE: 0.174545, NMSE: 0.0015838392
#
# ===== RUN 32/60 [Noise 0.0%] =====
#   Epoch 10/100 completed, Loss: 0.089053
#   Epoch 20/100 completed, Loss: 0.088687
#   Epoch 30/100 completed, Loss: 0.088508
#   Epoch 40/100 completed, Loss: 0.087958
#   Epoch 50/100 completed, Loss: 0.087966
#   Epoch 60/100 completed, Loss: 0.087817
#   Epoch 70/100 completed, Loss: 0.087729
#   Epoch 80/100 completed, Loss: 0.087653
#   Epoch 90/100 completed, Loss: 0.087555
#   Epoch 100/100 completed, Loss: 0.087336
# Training complete for run 32
# Run 32 Metrics — RMSE: 0.562445, MSE: 0.316344, NMSE: 0.0026327260
#
# ===== RUN 33/60 [Noise 0.0%] =====
#   Epoch 10/100 completed, Loss: 0.086879
#   Epoch 20/100 completed, Loss: 0.086485
#   Epoch 30/100 completed, Loss: 0.086107
#   Epoch 40/100 completed, Loss: 0.086287
#   Epoch 50/100 completed, Loss: 0.085740
#   Epoch 60/100 completed, Loss: 0.085791
#   Epoch 70/100 completed, Loss: 0.085278
#   Epoch 80/100 completed, Loss: 0.088244
#   Epoch 90/100 completed, Loss: 0.082951
#   Epoch 100/100 completed, Loss: 0.057420
# Training complete for run 33
# Run 33 Metrics — RMSE: 0.489860, MSE: 0.239963, NMSE: 0.0019372978
#
# ===== RUN 34/60 [Noise 0.0%] =====
#   Epoch 10/100 completed, Loss: 0.057869
#   Epoch 20/100 completed, Loss: 0.055165
#   Epoch 30/100 completed, Loss: 0.053465
#   Epoch 40/100 completed, Loss: 0.053700
#   Epoch 50/100 completed, Loss: 0.089146
#   Epoch 60/100 completed, Loss: 0.088696
#   Epoch 70/100 completed, Loss: 0.088708
#   Epoch 80/100 completed, Loss: 0.061288
#   Epoch 90/100 completed, Loss: 0.060667
#   Epoch 100/100 completed, Loss: 0.060078
# Training complete for run 34
# Run 34 Metrics — RMSE: 0.505829, MSE: 0.255863, NMSE: 0.0020371790
#
# ===== RUN 35/60 [Noise 0.0%] =====
#   Epoch 10/100 completed, Loss: 0.055753
#   Epoch 20/100 completed, Loss: 0.047707
#   Epoch 30/100 completed, Loss: 0.046798
#   Epoch 40/100 completed, Loss: 0.045820
#   Epoch 50/100 completed, Loss: 0.046147
#   Epoch 60/100 completed, Loss: 0.046526
#   Epoch 70/100 completed, Loss: 0.046407
#   Epoch 80/100 completed, Loss: 0.045914
#   Epoch 90/100 completed, Loss: 0.045169
#   Epoch 100/100 completed, Loss: 0.044306
# Training complete for run 35
# Run 35 Metrics — RMSE: 0.450315, MSE: 0.202784, NMSE: 0.0019361403
#
# ===== RUN 36/60 [Noise 0.0%] =====
#   Epoch 10/100 completed, Loss: 0.046235
#   Epoch 20/100 completed, Loss: 0.046489
#   Epoch 30/100 completed, Loss: 0.046300
#   Epoch 40/100 completed, Loss: 0.045688
#   Epoch 50/100 completed, Loss: 0.043885
#   Epoch 60/100 completed, Loss: 0.043268
#   Epoch 70/100 completed, Loss: 0.043212
#   Epoch 80/100 completed, Loss: 0.041730
#   Epoch 90/100 completed, Loss: 0.041574
#   Epoch 100/100 completed, Loss: 0.041597
# Training complete for run 36
# Run 36 Metrics — RMSE: 0.397729, MSE: 0.158188, NMSE: 0.0014623938
#
# ===== RUN 37/60 [Noise 0.0%] =====
#   Epoch 10/100 completed, Loss: 0.054327
#   Epoch 20/100 completed, Loss: 0.056372
#   Epoch 30/100 completed, Loss: 0.055088
#   Epoch 40/100 completed, Loss: 0.053931
#   Epoch 50/100 completed, Loss: 0.052835
#   Epoch 60/100 completed, Loss: 0.052175
#   Epoch 70/100 completed, Loss: 0.051387
#   Epoch 80/100 completed, Loss: 0.046587
#   Epoch 90/100 completed, Loss: 0.045237
#   Epoch 100/100 completed, Loss: 0.049352
# Training complete for run 37
# Run 37 Metrics — RMSE: 0.440948, MSE: 0.194435, NMSE: 0.0016629334
#
# ===== RUN 38/60 [Noise 0.0%] =====
#   Epoch 10/100 completed, Loss: 0.060418
#   Epoch 20/100 completed, Loss: 0.059017
#   Epoch 30/100 completed, Loss: 0.057703
#   Epoch 40/100 completed, Loss: 0.055497
#   Epoch 50/100 completed, Loss: 0.053173
#   Epoch 60/100 completed, Loss: 0.049993
#   Epoch 70/100 completed, Loss: 0.046859
#   Epoch 80/100 completed, Loss: 0.044115
#   Epoch 90/100 completed, Loss: 0.046333
#   Epoch 100/100 completed, Loss: 0.046088
# Training complete for run 38
# Run 38 Metrics — RMSE: 0.402686, MSE: 0.162156, NMSE: 0.0014161250
#
# ===== RUN 39/60 [Noise 0.0%] =====
#   Epoch 10/100 completed, Loss: 0.057627
#   Epoch 20/100 completed, Loss: 0.054756
#   Epoch 30/100 completed, Loss: 0.051937
#   Epoch 40/100 completed, Loss: 0.049200
#   Epoch 50/100 completed, Loss: 0.045787
#   Epoch 60/100 completed, Loss: 0.045246
#   Epoch 70/100 completed, Loss: 0.045269
#   Epoch 80/100 completed, Loss: 0.045389
#   Epoch 90/100 completed, Loss: 0.045502
#   Epoch 100/100 completed, Loss: 0.045532
# Training complete for run 39
# Run 39 Metrics — RMSE: 0.429528, MSE: 0.184494, NMSE: 0.0016599837
#
# ===== RUN 40/60 [Noise 0.0%] =====
#   Epoch 10/100 completed, Loss: 0.088784
#   Epoch 20/100 completed, Loss: 0.054206
#   Epoch 30/100 completed, Loss: 0.049867
#   Epoch 40/100 completed, Loss: 0.046853
#   Epoch 50/100 completed, Loss: 0.044988
#   Epoch 60/100 completed, Loss: 0.043559
#   Epoch 70/100 completed, Loss: 0.042375
#   Epoch 80/100 completed, Loss: 0.041582
#   Epoch 90/100 completed, Loss: 0.041479
#   Epoch 100/100 completed, Loss: 0.041756
# Training complete for run 40
# Run 40 Metrics — RMSE: 0.430598, MSE: 0.185414, NMSE: 0.0018013418
#
# ===== RUN 41/60 [Noise 0.0%] =====
#   Epoch 10/100 completed, Loss: 0.053395
#   Epoch 20/100 completed, Loss: 0.051860
#   Epoch 30/100 completed, Loss: 0.048593
#   Epoch 40/100 completed, Loss: 0.047155
#   Epoch 50/100 completed, Loss: 0.046057
#   Epoch 60/100 completed, Loss: 0.045019
#   Epoch 70/100 completed, Loss: 0.045896
#   Epoch 80/100 completed, Loss: 0.047576
#   Epoch 90/100 completed, Loss: 0.068375
#   Epoch 100/100 completed, Loss: 0.044778
# Training complete for run 41
# Run 41 Metrics — RMSE: 0.428481, MSE: 0.183596, NMSE: 0.0017508116
#
# ===== RUN 42/60 [Noise 0.0%] =====
#   Epoch 10/100 completed, Loss: 0.059690
#   Epoch 20/100 completed, Loss: 0.058016
#   Epoch 30/100 completed, Loss: 0.057028
#   Epoch 40/100 completed, Loss: 0.054078
#   Epoch 50/100 completed, Loss: 0.049741
#   Epoch 60/100 completed, Loss: 0.048284
#   Epoch 70/100 completed, Loss: 0.046937
#   Epoch 80/100 completed, Loss: 0.045950
#   Epoch 90/100 completed, Loss: 0.045560
#   Epoch 100/100 completed, Loss: 0.045550
# Training complete for run 42
# Run 42 Metrics — RMSE: 0.417853, MSE: 0.174601, NMSE: 0.0015996804
#
# ===== RUN 43/60 [Noise 0.0%] =====
#   Epoch 10/100 completed, Loss: 0.053101
#   Epoch 20/100 completed, Loss: 0.050620
#   Epoch 30/100 completed, Loss: 0.046331
#   Epoch 40/100 completed, Loss: 0.044183
#   Epoch 50/100 completed, Loss: 0.044095
#   Epoch 60/100 completed, Loss: 0.043731
#   Epoch 70/100 completed, Loss: 0.042897
#   Epoch 80/100 completed, Loss: 0.042979
#   Epoch 90/100 completed, Loss: 0.043210
#   Epoch 100/100 completed, Loss: 0.043078
# Training complete for run 43
# Run 43 Metrics — RMSE: 0.411121, MSE: 0.169021, NMSE: 0.0015435387
#
# ===== RUN 44/60 [Noise 0.0%] =====
#   Epoch 10/100 completed, Loss: 0.055089
#   Epoch 20/100 completed, Loss: 0.054655
#   Epoch 30/100 completed, Loss: 0.055277
#   Epoch 40/100 completed, Loss: 0.055086
#   Epoch 50/100 completed, Loss: 0.053834
#   Epoch 60/100 completed, Loss: 0.056083
#   Epoch 70/100 completed, Loss: 0.049969
#   Epoch 80/100 completed, Loss: 0.060539
#   Epoch 90/100 completed, Loss: 0.059157
#   Epoch 100/100 completed, Loss: 0.058198
# Training complete for run 44
# Run 44 Metrics — RMSE: 0.496871, MSE: 0.246880, NMSE: 0.0019488379
#
# ===== RUN 45/60 [Noise 0.0%] =====
#   Epoch 10/100 completed, Loss: 0.050746
#   Epoch 20/100 completed, Loss: 0.047162
#   Epoch 30/100 completed, Loss: 0.045559
#   Epoch 40/100 completed, Loss: 0.044688
#   Epoch 50/100 completed, Loss: 0.044942
#   Epoch 60/100 completed, Loss: 0.045901
#   Epoch 70/100 completed, Loss: 0.047171
#   Epoch 80/100 completed, Loss: 0.048458
#   Epoch 90/100 completed, Loss: 0.049400
#   Epoch 100/100 completed, Loss: 0.051775
# Training complete for run 45
# Run 45 Metrics — RMSE: 0.471106, MSE: 0.221941, NMSE: 0.0018490529
#
# ===== RUN 46/60 [Noise 0.0%] =====
#   Epoch 10/100 completed, Loss: 0.053926
#   Epoch 20/100 completed, Loss: 0.050112
#   Epoch 30/100 completed, Loss: 0.046128
#   Epoch 40/100 completed, Loss: 0.045091
#   Epoch 50/100 completed, Loss: 0.043697
#   Epoch 60/100 completed, Loss: 0.042495
#   Epoch 70/100 completed, Loss: 0.041715
#   Epoch 80/100 completed, Loss: 0.041018
#   Epoch 90/100 completed, Loss: 0.040269
#   Epoch 100/100 completed, Loss: 0.039581
# Training complete for run 46
# Run 46 Metrics — RMSE: 0.399970, MSE: 0.159976, NMSE: 0.0014203681
#
# ===== RUN 47/60 [Noise 0.0%] =====
#   Epoch 10/100 completed, Loss: 0.055569
#   Epoch 20/100 completed, Loss: 0.053259
#   Epoch 30/100 completed, Loss: 0.052787
#   Epoch 40/100 completed, Loss: 0.050921
#   Epoch 50/100 completed, Loss: 0.050078
#   Epoch 60/100 completed, Loss: 0.050355
#   Epoch 70/100 completed, Loss: 0.050729
#   Epoch 80/100 completed, Loss: 0.050606
#   Epoch 90/100 completed, Loss: 0.049762
#   Epoch 100/100 completed, Loss: 0.048853
# Training complete for run 47
# Run 47 Metrics — RMSE: 0.457022, MSE: 0.208869, NMSE: 0.0017280390
#
# ===== RUN 48/60 [Noise 0.0%] =====
#   Epoch 10/100 completed, Loss: 0.058952
#   Epoch 20/100 completed, Loss: 0.058258
#   Epoch 30/100 completed, Loss: 0.059951
#   Epoch 40/100 completed, Loss: 0.057762
#   Epoch 50/100 completed, Loss: 0.055599
#   Epoch 60/100 completed, Loss: 0.054437
#   Epoch 70/100 completed, Loss: 0.054107
#   Epoch 80/100 completed, Loss: 0.054163
#   Epoch 90/100 completed, Loss: 0.053675
#   Epoch 100/100 completed, Loss: 0.051728
# Training complete for run 48
# Run 48 Metrics — RMSE: 0.486611, MSE: 0.236790, NMSE: 0.0019031548
#
# ===== RUN 49/60 [Noise 0.0%] =====
#   Epoch 10/100 completed, Loss: 0.057490
#   Epoch 20/100 completed, Loss: 0.053382
#   Epoch 30/100 completed, Loss: 0.052541
#   Epoch 40/100 completed, Loss: 0.049773
#   Epoch 50/100 completed, Loss: 0.047229
#   Epoch 60/100 completed, Loss: 0.045136
#   Epoch 70/100 completed, Loss: 0.043657
#   Epoch 80/100 completed, Loss: 0.042734
#   Epoch 90/100 completed, Loss: 0.042577
#   Epoch 100/100 completed, Loss: 0.041897
# Training complete for run 49
# Run 49 Metrics — RMSE: 0.442436, MSE: 0.195750, NMSE: 0.0019088483
#
# ===== RUN 50/60 [Noise 0.0%] =====
#   Epoch 10/100 completed, Loss: 0.057425
#   Epoch 20/100 completed, Loss: 0.051097
#   Epoch 30/100 completed, Loss: 0.047026
#   Epoch 40/100 completed, Loss: 0.045517
#   Epoch 50/100 completed, Loss: 0.043861
#   Epoch 60/100 completed, Loss: 0.042391
#   Epoch 70/100 completed, Loss: 0.041479
#   Epoch 80/100 completed, Loss: 0.094137
#   Epoch 90/100 completed, Loss: 0.063076
#   Epoch 100/100 completed, Loss: 0.059088
# Training complete for run 50
# Run 50 Metrics — RMSE: 0.487976, MSE: 0.238120, NMSE: 0.0019818191
#
# ===== RUN 51/60 [Noise 0.0%] =====
#   Epoch 10/100 completed, Loss: 0.055209
#   Epoch 20/100 completed, Loss: 0.051924
#   Epoch 30/100 completed, Loss: 0.049518
#   Epoch 40/100 completed, Loss: 0.047908
#   Epoch 50/100 completed, Loss: 0.046589
#   Epoch 60/100 completed, Loss: 0.045457
#   Epoch 70/100 completed, Loss: 0.044682
#   Epoch 80/100 completed, Loss: 0.044144
#   Epoch 90/100 completed, Loss: 0.043707
#   Epoch 100/100 completed, Loss: 0.043697
# Training complete for run 51
# Run 51 Metrics — RMSE: 0.427584, MSE: 0.182828, NMSE: 0.0016080696
#
# ===== RUN 52/60 [Noise 0.0%] =====
#   Epoch 10/100 completed, Loss: 0.053224
#   Epoch 20/100 completed, Loss: 0.051318
#   Epoch 30/100 completed, Loss: 0.054110
#   Epoch 40/100 completed, Loss: 0.054849
#   Epoch 50/100 completed, Loss: 0.054380
#   Epoch 60/100 completed, Loss: 0.053335
#   Epoch 70/100 completed, Loss: 0.077538
#   Epoch 80/100 completed, Loss: 0.043524
#   Epoch 90/100 completed, Loss: 0.041536
#   Epoch 100/100 completed, Loss: 0.040602
# Training complete for run 52
# Run 52 Metrics — RMSE: 0.413461, MSE: 0.170950, NMSE: 0.0016136682
#
# ===== RUN 53/60 [Noise 0.0%] =====
#   Epoch 10/100 completed, Loss: 0.052229
#   Epoch 20/100 completed, Loss: 0.046653
#   Epoch 30/100 completed, Loss: 0.042715
#   Epoch 40/100 completed, Loss: 0.041580
#   Epoch 50/100 completed, Loss: 0.041160
#   Epoch 60/100 completed, Loss: 0.040693
#   Epoch 70/100 completed, Loss: 0.056218
#   Epoch 80/100 completed, Loss: 0.044045
#   Epoch 90/100 completed, Loss: 0.042327
#   Epoch 100/100 completed, Loss: 0.040742
# Training complete for run 53
# Run 53 Metrics — RMSE: 0.402548, MSE: 0.162045, NMSE: 0.0014238714
#
# ===== RUN 54/60 [Noise 0.0%] =====
#   Epoch 10/100 completed, Loss: 0.057739
#   Epoch 20/100 completed, Loss: 0.056725
#   Epoch 30/100 completed, Loss: 0.056562
#   Epoch 40/100 completed, Loss: 0.059130
#   Epoch 50/100 completed, Loss: 0.052701
#   Epoch 60/100 completed, Loss: 0.056023
#   Epoch 70/100 completed, Loss: 0.052639
#   Epoch 80/100 completed, Loss: 0.054250
#   Epoch 90/100 completed, Loss: 0.052776
#   Epoch 100/100 completed, Loss: 0.050437
# Training complete for run 54
# Run 54 Metrics — RMSE: 0.445814, MSE: 0.198750, NMSE: 0.0016408323
#
# ===== RUN 55/60 [Noise 0.0%] =====
#   Epoch 10/100 completed, Loss: 0.049628
#   Epoch 20/100 completed, Loss: 0.046739
#   Epoch 30/100 completed, Loss: 0.044600
#   Epoch 40/100 completed, Loss: 0.042616
#   Epoch 50/100 completed, Loss: 0.041229
#   Epoch 60/100 completed, Loss: 0.040907
#   Epoch 70/100 completed, Loss: 0.040553
#   Epoch 80/100 completed, Loss: 0.040371
#   Epoch 90/100 completed, Loss: 0.040795
#   Epoch 100/100 completed, Loss: 0.041446
# Training complete for run 55
# Run 55 Metrics — RMSE: 0.403630, MSE: 0.162917, NMSE: 0.0015195298
#
# ===== RUN 56/60 [Noise 0.0%] =====
#   Epoch 10/100 completed, Loss: 0.047802
#   Epoch 20/100 completed, Loss: 0.044654
#   Epoch 30/100 completed, Loss: 0.043229
#   Epoch 40/100 completed, Loss: 0.041901
#   Epoch 50/100 completed, Loss: 0.040619
#   Epoch 60/100 completed, Loss: 0.039417
#   Epoch 70/100 completed, Loss: 0.039223
#   Epoch 80/100 completed, Loss: 0.039596
#   Epoch 90/100 completed, Loss: 0.039653
#   Epoch 100/100 completed, Loss: 0.039381
# Training complete for run 56
# Run 56 Metrics — RMSE: 0.405805, MSE: 0.164677, NMSE: 0.0014986099
#
# ===== RUN 57/60 [Noise 0.0%] =====
#   Epoch 10/100 completed, Loss: 0.047964
#   Epoch 20/100 completed, Loss: 0.046198
#   Epoch 30/100 completed, Loss: 0.044506
#   Epoch 40/100 completed, Loss: 0.043382
#   Epoch 50/100 completed, Loss: 0.042808
#   Epoch 60/100 completed, Loss: 0.042493
#   Epoch 70/100 completed, Loss: 0.042148
#   Epoch 80/100 completed, Loss: 0.041478
#   Epoch 90/100 completed, Loss: 0.040920
#   Epoch 100/100 completed, Loss: 0.040477
# Training complete for run 57
# Run 57 Metrics — RMSE: 0.432591, MSE: 0.187135, NMSE: 0.0018387193
#
# ===== RUN 58/60 [Noise 0.0%] =====
#   Epoch 10/100 completed, Loss: 0.057917
#   Epoch 20/100 completed, Loss: 0.053504
#   Epoch 30/100 completed, Loss: 0.051120
#   Epoch 40/100 completed, Loss: 0.049388
#   Epoch 50/100 completed, Loss: 0.048259
#   Epoch 60/100 completed, Loss: 0.047446
#   Epoch 70/100 completed, Loss: 0.046733
#   Epoch 80/100 completed, Loss: 0.046079
#   Epoch 90/100 completed, Loss: 0.045394
#   Epoch 100/100 completed, Loss: 0.044958
# Training complete for run 58
# Run 58 Metrics — RMSE: 0.425318, MSE: 0.180896, NMSE: 0.0016253792
#
# ===== RUN 59/60 [Noise 0.0%] =====
#   Epoch 10/100 completed, Loss: 0.058056
#   Epoch 20/100 completed, Loss: 0.055973
#   Epoch 30/100 completed, Loss: 0.053945
#   Epoch 40/100 completed, Loss: 0.053311
#   Epoch 50/100 completed, Loss: 0.051927
#   Epoch 60/100 completed, Loss: 0.048781
#   Epoch 70/100 completed, Loss: 0.045507
#   Epoch 80/100 completed, Loss: 0.043672
#   Epoch 90/100 completed, Loss: 0.043471
#   Epoch 100/100 completed, Loss: 0.043451
# Training complete for run 59
# Run 59 Metrics — RMSE: 0.417863, MSE: 0.174609, NMSE: 0.0016280362
#
# ===== RUN 60/60 [Noise 0.0%] =====
#   Epoch 10/100 completed, Loss: 0.054627
#   Epoch 20/100 completed, Loss: 0.049056
#   Epoch 30/100 completed, Loss: 0.046020
#   Epoch 40/100 completed, Loss: 0.044236
#   Epoch 50/100 completed, Loss: 0.043087
#   Epoch 60/100 completed, Loss: 0.042312
#   Epoch 70/100 completed, Loss: 0.041380
#   Epoch 80/100 completed, Loss: 0.040181
#   Epoch 90/100 completed, Loss: 0.039060
#   Epoch 100/100 completed, Loss: 0.038598
# Training complete for run 60
# Run 60 Metrics — RMSE: 0.418297, MSE: 0.174972, NMSE: 0.0016507006
#
# Best run for 0.0% noise: Run 36 (RMSE: 0.397729)
#
# ================================================================================
# EVALUATING NOISE LEVEL: 0.5% (lambda=0.005, sigma=0.010052)
# ================================================================================
#
#
# ===== RUN 1/60 [Noise 0.5%] =====
#   Epoch 10/100 completed, Loss: 0.047287
#   Epoch 20/100 completed, Loss: 0.045077
#   Epoch 30/100 completed, Loss: 0.043918
#   Epoch 40/100 completed, Loss: 0.042663
#   Epoch 50/100 completed, Loss: 0.039803
#   Epoch 60/100 completed, Loss: 0.038242
#   Epoch 70/100 completed, Loss: 0.037752
#   Epoch 80/100 completed, Loss: 0.037624
#   Epoch 90/100 completed, Loss: 0.037364
#   Epoch 100/100 completed, Loss: 0.037007
# Training complete for run 1
# Run 1 Metrics — RMSE: 0.404064, MSE: 0.163268, NMSE: 0.0014449452
#
# ===== RUN 2/60 [Noise 0.5%] =====
#   Epoch 10/100 completed, Loss: 0.056312
#   Epoch 20/100 completed, Loss: 0.050418
#   Epoch 30/100 completed, Loss: 0.047378
#   Epoch 40/100 completed, Loss: 0.045510
#   Epoch 50/100 completed, Loss: 0.044465
#   Epoch 60/100 completed, Loss: 0.044616
#   Epoch 70/100 completed, Loss: 0.044159
#   Epoch 80/100 completed, Loss: 0.043331
#   Epoch 90/100 completed, Loss: 0.043104
#   Epoch 100/100 completed, Loss: 0.043301
# Training complete for run 2
# Run 2 Metrics — RMSE: 0.392989, MSE: 0.154440, NMSE: 0.0013553779
#
# ===== RUN 3/60 [Noise 0.5%] =====
#   Epoch 10/100 completed, Loss: 0.054175
#   Epoch 20/100 completed, Loss: 0.052870
#   Epoch 30/100 completed, Loss: 0.053874
#   Epoch 40/100 completed, Loss: 0.052577
#   Epoch 50/100 completed, Loss: 0.052128
#   Epoch 60/100 completed, Loss: 0.050645
#   Epoch 70/100 completed, Loss: 0.048306
#   Epoch 80/100 completed, Loss: 0.047063
#   Epoch 90/100 completed, Loss: 0.047965
#   Epoch 100/100 completed, Loss: 0.048589
# Training complete for run 3
# Run 3 Metrics — RMSE: 0.454102, MSE: 0.206209, NMSE: 0.0018337532
#
# ===== RUN 4/60 [Noise 0.5%] =====
#   Epoch 10/100 completed, Loss: 0.050836
#   Epoch 20/100 completed, Loss: 0.047876
#   Epoch 30/100 completed, Loss: 0.044732
#   Epoch 40/100 completed, Loss: 0.043629
#   Epoch 50/100 completed, Loss: 0.043339
#   Epoch 60/100 completed, Loss: 0.043035
#   Epoch 70/100 completed, Loss: 0.042723
#   Epoch 80/100 completed, Loss: 0.042523
#   Epoch 90/100 completed, Loss: 0.042424
#   Epoch 100/100 completed, Loss: 0.042456
# Training complete for run 4
# Run 4 Metrics — RMSE: 0.427302, MSE: 0.182587, NMSE: 0.0016756398
#
# ===== RUN 5/60 [Noise 0.5%] =====
#   Epoch 10/100 completed, Loss: 0.054937
#   Epoch 20/100 completed, Loss: 0.055056
#   Epoch 30/100 completed, Loss: 0.055214
#   Epoch 40/100 completed, Loss: 0.053328
#   Epoch 50/100 completed, Loss: 0.051511
#   Epoch 60/100 completed, Loss: 0.049391
#   Epoch 70/100 completed, Loss: 0.046239
#   Epoch 80/100 completed, Loss: 0.045931
#   Epoch 90/100 completed, Loss: 0.045644
#   Epoch 100/100 completed, Loss: 0.045159
# Training complete for run 5
# Run 5 Metrics — RMSE: 0.427878, MSE: 0.183080, NMSE: 0.0017327936
#
# ===== RUN 6/60 [Noise 0.5%] =====
#   Epoch 10/100 completed, Loss: 0.089336
#   Epoch 20/100 completed, Loss: 0.088884
#   Epoch 30/100 completed, Loss: 0.088229
#   Epoch 40/100 completed, Loss: 0.088471
#   Epoch 50/100 completed, Loss: 0.049940
#   Epoch 60/100 completed, Loss: 0.090637
#   Epoch 70/100 completed, Loss: 0.074417
#   Epoch 80/100 completed, Loss: 0.082673
#   Epoch 90/100 completed, Loss: 0.078146
#   Epoch 100/100 completed, Loss: 0.076380
# Training complete for run 6
# Run 6 Metrics — RMSE: 0.572989, MSE: 0.328316, NMSE: 0.0027147645
#
# ===== RUN 7/60 [Noise 0.5%] =====
#   Epoch 10/100 completed, Loss: 0.052998
#   Epoch 20/100 completed, Loss: 0.051197
#   Epoch 30/100 completed, Loss: 0.051054
#   Epoch 40/100 completed, Loss: 0.051926
#   Epoch 50/100 completed, Loss: 0.052742
#   Epoch 60/100 completed, Loss: 0.050518
#   Epoch 70/100 completed, Loss: 0.049287
#   Epoch 80/100 completed, Loss: 0.052538
#   Epoch 90/100 completed, Loss: 0.043556
#   Epoch 100/100 completed, Loss: 0.041847
# Training complete for run 7
# Run 7 Metrics — RMSE: 0.418412, MSE: 0.175069, NMSE: 0.0016180744
#
# ===== RUN 8/60 [Noise 0.5%] =====
#   Epoch 10/100 completed, Loss: 0.059628
#   Epoch 20/100 completed, Loss: 0.057436
#   Epoch 30/100 completed, Loss: 0.054438
#   Epoch 40/100 completed, Loss: 0.051405
#   Epoch 50/100 completed, Loss: 0.064902
#   Epoch 60/100 completed, Loss: 0.058716
#   Epoch 70/100 completed, Loss: 0.056197
#   Epoch 80/100 completed, Loss: 0.054544
#   Epoch 90/100 completed, Loss: 0.051825
#   Epoch 100/100 completed, Loss: 0.046706
# Training complete for run 8
# Run 8 Metrics — RMSE: 0.427909, MSE: 0.183106, NMSE: 0.0016137572
#
# ===== RUN 9/60 [Noise 0.5%] =====
#   Epoch 10/100 completed, Loss: 0.055316
#   Epoch 20/100 completed, Loss: 0.050593
#   Epoch 30/100 completed, Loss: 0.049623
#   Epoch 40/100 completed, Loss: 0.049792
#   Epoch 50/100 completed, Loss: 0.046861
#   Epoch 60/100 completed, Loss: 0.046255
#   Epoch 70/100 completed, Loss: 0.042186
#   Epoch 80/100 completed, Loss: 0.041983
#   Epoch 90/100 completed, Loss: 0.041494
#   Epoch 100/100 completed, Loss: 0.041128
# Training complete for run 9
# Run 9 Metrics — RMSE: 0.420281, MSE: 0.176636, NMSE: 0.0016532343
#
# ===== RUN 10/60 [Noise 0.5%] =====
#   Epoch 10/100 completed, Loss: 0.058441
#   Epoch 20/100 completed, Loss: 0.058383
#   Epoch 30/100 completed, Loss: 0.057998
#   Epoch 40/100 completed, Loss: 0.057166
#   Epoch 50/100 completed, Loss: 0.055545
#   Epoch 60/100 completed, Loss: 0.053988
#   Epoch 70/100 completed, Loss: 0.053235
#   Epoch 80/100 completed, Loss: 0.053645
#   Epoch 90/100 completed, Loss: 0.052917
#   Epoch 100/100 completed, Loss: 0.047315
# Training complete for run 10
# Run 10 Metrics — RMSE: 0.444025, MSE: 0.197158, NMSE: 0.0017458021
#
# ===== RUN 11/60 [Noise 0.5%] =====
#   Epoch 10/100 completed, Loss: 0.057096
#   Epoch 20/100 completed, Loss: 0.057305
#   Epoch 30/100 completed, Loss: 0.056591
#   Epoch 40/100 completed, Loss: 0.055316
#   Epoch 50/100 completed, Loss: 0.053932
#   Epoch 60/100 completed, Loss: 0.052675
#   Epoch 70/100 completed, Loss: 0.051418
#   Epoch 80/100 completed, Loss: 0.049485
#   Epoch 90/100 completed, Loss: 0.055469
#   Epoch 100/100 completed, Loss: 0.056931
# Training complete for run 11
# Run 11 Metrics — RMSE: 0.477906, MSE: 0.228394, NMSE: 0.0018157872
#
# ===== RUN 12/60 [Noise 0.5%] =====
#   Epoch 10/100 completed, Loss: 0.059767
#   Epoch 20/100 completed, Loss: 0.056857
#   Epoch 30/100 completed, Loss: 0.052069
#   Epoch 40/100 completed, Loss: 0.048119
#   Epoch 50/100 completed, Loss: 0.044969
#   Epoch 60/100 completed, Loss: 0.045033
#   Epoch 70/100 completed, Loss: 0.045298
#   Epoch 80/100 completed, Loss: 0.044617
#   Epoch 90/100 completed, Loss: 0.044490
#   Epoch 100/100 completed, Loss: 0.044574
# Training complete for run 12
# Run 12 Metrics — RMSE: 0.422110, MSE: 0.178177, NMSE: 0.0016548178
#
# ===== RUN 13/60 [Noise 0.5%] =====
#   Epoch 10/100 completed, Loss: 0.053988
#   Epoch 20/100 completed, Loss: 0.050772
#   Epoch 30/100 completed, Loss: 0.051185
#   Epoch 40/100 completed, Loss: 0.052682
#   Epoch 50/100 completed, Loss: 0.054446
#   Epoch 60/100 completed, Loss: 0.053195
#   Epoch 70/100 completed, Loss: 0.055810
#   Epoch 80/100 completed, Loss: 0.056631
#   Epoch 90/100 completed, Loss: 0.057698
#   Epoch 100/100 completed, Loss: 0.056788
# Training complete for run 13
# Run 13 Metrics — RMSE: 0.470746, MSE: 0.221601, NMSE: 0.0018139289
#
# ===== RUN 14/60 [Noise 0.5%] =====
#   Epoch 10/100 completed, Loss: 0.057292
#   Epoch 20/100 completed, Loss: 0.057144
#   Epoch 30/100 completed, Loss: 0.056383
#   Epoch 40/100 completed, Loss: 0.060099
#   Epoch 50/100 completed, Loss: 0.060943
#   Epoch 60/100 completed, Loss: 0.060171
#   Epoch 70/100 completed, Loss: 0.059747
#   Epoch 80/100 completed, Loss: 0.059219
#   Epoch 90/100 completed, Loss: 0.058567
#   Epoch 100/100 completed, Loss: 0.057947
# Training complete for run 14
# Run 14 Metrics — RMSE: 0.499547, MSE: 0.249548, NMSE: 0.0020625063
#
# ===== RUN 15/60 [Noise 0.5%] =====
#   Epoch 10/100 completed, Loss: 0.058226
#   Epoch 20/100 completed, Loss: 0.056426
#   Epoch 30/100 completed, Loss: 0.054130
#   Epoch 40/100 completed, Loss: 0.052399
#   Epoch 50/100 completed, Loss: 0.052269
#   Epoch 60/100 completed, Loss: 0.052542
#   Epoch 70/100 completed, Loss: 0.051403
#   Epoch 80/100 completed, Loss: 0.050332
#   Epoch 90/100 completed, Loss: 0.043048
#   Epoch 100/100 completed, Loss: 0.040571
# Training complete for run 15
# Run 15 Metrics — RMSE: 0.404417, MSE: 0.163553, NMSE: 0.0014387594
#
# ===== RUN 16/60 [Noise 0.5%] =====
#   Epoch 10/100 completed, Loss: 0.052530
#   Epoch 20/100 completed, Loss: 0.049276
#   Epoch 30/100 completed, Loss: 0.044520
#   Epoch 40/100 completed, Loss: 0.042534
#   Epoch 50/100 completed, Loss: 0.042704
#   Epoch 60/100 completed, Loss: 0.042753
#   Epoch 70/100 completed, Loss: 0.042124
#   Epoch 80/100 completed, Loss: 0.041475
#   Epoch 90/100 completed, Loss: 0.041007
#   Epoch 100/100 completed, Loss: 0.041039
# Training complete for run 16
# Run 16 Metrics — RMSE: 0.405361, MSE: 0.164318, NMSE: 0.0014617966
#
# ===== RUN 17/60 [Noise 0.5%] =====
#   Epoch 10/100 completed, Loss: 0.055663
#   Epoch 20/100 completed, Loss: 0.053697
#   Epoch 30/100 completed, Loss: 0.047010
#   Epoch 40/100 completed, Loss: 0.047143
#   Epoch 50/100 completed, Loss: 0.046590
#   Epoch 60/100 completed, Loss: 0.045533
#   Epoch 70/100 completed, Loss: 0.044162
#   Epoch 80/100 completed, Loss: 0.043372
#   Epoch 90/100 completed, Loss: 0.044316
#   Epoch 100/100 completed, Loss: 0.043547
# Training complete for run 17
# Run 17 Metrics — RMSE: 0.414548, MSE: 0.171850, NMSE: 0.0015737133
#
# ===== RUN 18/60 [Noise 0.5%] =====
#   Epoch 10/100 completed, Loss: 0.060181
#   Epoch 20/100 completed, Loss: 0.056712
#   Epoch 30/100 completed, Loss: 0.055014
#   Epoch 40/100 completed, Loss: 0.053245
#   Epoch 50/100 completed, Loss: 0.050564
#   Epoch 60/100 completed, Loss: 0.048397
#   Epoch 70/100 completed, Loss: 0.045355
#   Epoch 80/100 completed, Loss: 0.043924
#   Epoch 90/100 completed, Loss: 0.042834
#   Epoch 100/100 completed, Loss: 0.041995
# Training complete for run 18
# Run 18 Metrics — RMSE: 0.418867, MSE: 0.175450, NMSE: 0.0015736867
#
# ===== RUN 19/60 [Noise 0.5%] =====
#   Epoch 10/100 completed, Loss: 0.047557
#   Epoch 20/100 completed, Loss: 0.044530
#   Epoch 30/100 completed, Loss: 0.043789
#   Epoch 40/100 completed, Loss: 0.043478
#   Epoch 50/100 completed, Loss: 0.043058
#   Epoch 60/100 completed, Loss: 0.043311
#   Epoch 70/100 completed, Loss: 0.043565
#   Epoch 80/100 completed, Loss: 0.043394
#   Epoch 90/100 completed, Loss: 0.044562
#   Epoch 100/100 completed, Loss: 0.044722
# Training complete for run 19
# Run 19 Metrics — RMSE: 0.411710, MSE: 0.169505, NMSE: 0.0015059565
#
# ===== RUN 20/60 [Noise 0.5%] =====
#   Epoch 10/100 completed, Loss: 0.058720
#   Epoch 20/100 completed, Loss: 0.056318
#   Epoch 30/100 completed, Loss: 0.050936
#   Epoch 40/100 completed, Loss: 0.048280
#   Epoch 50/100 completed, Loss: 0.046449
#   Epoch 60/100 completed, Loss: 0.045000
#   Epoch 70/100 completed, Loss: 0.044096
#   Epoch 80/100 completed, Loss: 0.043639
#   Epoch 90/100 completed, Loss: 0.043192
#   Epoch 100/100 completed, Loss: 0.042954
# Training complete for run 20
# Run 20 Metrics — RMSE: 0.410599, MSE: 0.168591, NMSE: 0.0014672209
#
# ===== RUN 21/60 [Noise 0.5%] =====
#   Epoch 10/100 completed, Loss: 0.056125
#   Epoch 20/100 completed, Loss: 0.055370
#   Epoch 30/100 completed, Loss: 0.053553
#   Epoch 40/100 completed, Loss: 0.052029
#   Epoch 50/100 completed, Loss: 0.054190
#   Epoch 60/100 completed, Loss: 0.054451
#   Epoch 70/100 completed, Loss: 0.053606
#   Epoch 80/100 completed, Loss: 0.052811
#   Epoch 90/100 completed, Loss: 0.054089
#   Epoch 100/100 completed, Loss: 0.052664
# Training complete for run 21
# Run 21 Metrics — RMSE: 0.474021, MSE: 0.224696, NMSE: 0.0018416355
#
# ===== RUN 22/60 [Noise 0.5%] =====
#   Epoch 10/100 completed, Loss: 0.059424
#   Epoch 20/100 completed, Loss: 0.057929
#   Epoch 30/100 completed, Loss: 0.058222
#   Epoch 40/100 completed, Loss: 0.058264
#   Epoch 50/100 completed, Loss: 0.057816
#   Epoch 60/100 completed, Loss: 0.056705
#   Epoch 70/100 completed, Loss: 0.055282
#   Epoch 80/100 completed, Loss: 0.054247
#   Epoch 90/100 completed, Loss: 0.053767
#   Epoch 100/100 completed, Loss: 0.053558
# Training complete for run 22
# Run 22 Metrics — RMSE: 0.484511, MSE: 0.234751, NMSE: 0.0019444193
#
# ===== RUN 23/60 [Noise 0.5%] =====
#   Epoch 10/100 completed, Loss: 0.057018
#   Epoch 20/100 completed, Loss: 0.057102
#   Epoch 30/100 completed, Loss: 0.057100
#   Epoch 40/100 completed, Loss: 0.055601
#   Epoch 50/100 completed, Loss: 0.052634
#   Epoch 60/100 completed, Loss: 0.050521
#   Epoch 70/100 completed, Loss: 0.047555
#   Epoch 80/100 completed, Loss: 0.045422
#   Epoch 90/100 completed, Loss: 0.044769
#   Epoch 100/100 completed, Loss: 0.043967
# Training complete for run 23
# Run 23 Metrics — RMSE: 0.415323, MSE: 0.172493, NMSE: 0.0015334587
#
# ===== RUN 24/60 [Noise 0.5%] =====
#   Epoch 10/100 completed, Loss: 0.059047
#   Epoch 20/100 completed, Loss: 0.057910
#   Epoch 30/100 completed, Loss: 0.057375
#   Epoch 40/100 completed, Loss: 0.055142
#   Epoch 50/100 completed, Loss: 0.054069
#   Epoch 60/100 completed, Loss: 0.052255
#   Epoch 70/100 completed, Loss: 0.051264
#   Epoch 80/100 completed, Loss: 0.050748
#   Epoch 90/100 completed, Loss: 0.050611
#   Epoch 100/100 completed, Loss: 0.050446
# Training complete for run 24
# Run 24 Metrics — RMSE: 0.463567, MSE: 0.214894, NMSE: 0.0017909138
#
# ===== RUN 25/60 [Noise 0.5%] =====
#   Epoch 10/100 completed, Loss: 0.054125
#   Epoch 20/100 completed, Loss: 0.050235
#   Epoch 30/100 completed, Loss: 0.048931
#   Epoch 40/100 completed, Loss: 0.047441
#   Epoch 50/100 completed, Loss: 0.045700
#   Epoch 60/100 completed, Loss: 0.044727
#   Epoch 70/100 completed, Loss: 0.045372
#   Epoch 80/100 completed, Loss: 0.046210
#   Epoch 90/100 completed, Loss: 0.044961
#   Epoch 100/100 completed, Loss: 0.044117
# Training complete for run 25
# Run 25 Metrics — RMSE: 0.417339, MSE: 0.174172, NMSE: 0.0016052769
#
# ===== RUN 26/60 [Noise 0.5%] =====
#   Epoch 10/100 completed, Loss: 0.056514
#   Epoch 20/100 completed, Loss: 0.054159
#   Epoch 30/100 completed, Loss: 0.062335
#   Epoch 40/100 completed, Loss: 0.049602
#   Epoch 50/100 completed, Loss: 0.049073
#   Epoch 60/100 completed, Loss: 0.048982
#   Epoch 70/100 completed, Loss: 0.048463
#   Epoch 80/100 completed, Loss: 0.048399
#   Epoch 90/100 completed, Loss: 0.048163
#   Epoch 100/100 completed, Loss: 0.047369
# Training complete for run 26
# Run 26 Metrics — RMSE: 0.430212, MSE: 0.185083, NMSE: 0.0016327393
#
# ===== RUN 27/60 [Noise 0.5%] =====
#   Epoch 10/100 completed, Loss: 0.058945
#   Epoch 20/100 completed, Loss: 0.054305
#   Epoch 30/100 completed, Loss: 0.051272
#   Epoch 40/100 completed, Loss: 0.050641
#   Epoch 50/100 completed, Loss: 0.050326
#   Epoch 60/100 completed, Loss: 0.048138
#   Epoch 70/100 completed, Loss: 0.048301
#   Epoch 80/100 completed, Loss: 0.049407
#   Epoch 90/100 completed, Loss: 0.056861
#   Epoch 100/100 completed, Loss: 0.054998
# Training complete for run 27
# Run 27 Metrics — RMSE: 0.452521, MSE: 0.204775, NMSE: 0.0016455150
#
# ===== RUN 28/60 [Noise 0.5%] =====
#   Epoch 10/100 completed, Loss: 0.058658
#   Epoch 20/100 completed, Loss: 0.056754
#   Epoch 30/100 completed, Loss: 0.054012
# ...
#   Epoch 100/100 completed, Loss: 0.060283
# Training complete for run 31
# Run 31 Metrics — RMSE: 0.592857, MSE: 0.351480, NMSE: 0.0028294895
#
# ===== RUN 32/60 [Noise 10.0%] =====
#   Epoch 10/100 completed, Loss: 0.069303
#   Epoch 20/100 completed, Loss: 0.064756
#   Epoch 30/100 completed, Loss: 0.062174
#   Epoch 40/100 completed, Loss: 0.060117
#   Epoch 50/100 completed, Loss: 0.057590
#   Epoch 60/100 completed, Loss: 0.054628
#   Epoch 70/100 completed, Loss: 0.053704
#   Epoch 80/100 completed, Loss: 0.053037
#   Epoch 90/100 completed, Loss: 0.053298
#   Epoch 100/100 completed, Loss: 0.051823
# Training complete for run 32
# Run 32 Metrics — RMSE: 0.545539, MSE: 0.297613, NMSE: 0.0026967519
#
# ===== RUN 33/60 [Noise 10.0%] =====
#   Epoch 10/100 completed, Loss: 0.064756
#   Epoch 20/100 completed, Loss: 0.069390
#   Epoch 30/100 completed, Loss: 0.066520
#   Epoch 40/100 completed, Loss: 0.061995
#   Epoch 50/100 completed, Loss: 0.058984
#   Epoch 60/100 completed, Loss: 0.054781
#   Epoch 70/100 completed, Loss: 0.053171
#   Epoch 80/100 completed, Loss: 0.051976
#   Epoch 90/100 completed, Loss: 0.051393
#   Epoch 100/100 completed, Loss: 0.049571
# Training complete for run 33
# Run 33 Metrics — RMSE: 0.566020, MSE: 0.320378, NMSE: 0.0029491735
#
# ===== RUN 34/60 [Noise 10.0%] =====
#   Epoch 10/100 completed, Loss: 0.058973
#   Epoch 20/100 completed, Loss: 0.053518
#   Epoch 30/100 completed, Loss: 0.052886
#   Epoch 40/100 completed, Loss: 0.052095
#   Epoch 50/100 completed, Loss: 0.051544
#   Epoch 60/100 completed, Loss: 0.050854
#   Epoch 70/100 completed, Loss: 0.050156
#   Epoch 80/100 completed, Loss: 0.049511
#   Epoch 90/100 completed, Loss: 0.049067
#   Epoch 100/100 completed, Loss: 0.048885
# Training complete for run 34
# Run 34 Metrics — RMSE: 0.573164, MSE: 0.328517, NMSE: 0.0032020500
#
# ===== RUN 35/60 [Noise 10.0%] =====
#   Epoch 10/100 completed, Loss: 0.057904
#   Epoch 20/100 completed, Loss: 0.054854
#   Epoch 30/100 completed, Loss: 0.054203
#   Epoch 40/100 completed, Loss: 0.053480
#   Epoch 50/100 completed, Loss: 0.052583
#   Epoch 60/100 completed, Loss: 0.051647
#   Epoch 70/100 completed, Loss: 0.051354
#   Epoch 80/100 completed, Loss: 0.052234
#   Epoch 90/100 completed, Loss: 0.052302
#   Epoch 100/100 completed, Loss: 0.050217
# Training complete for run 35
# Run 35 Metrics — RMSE: 0.543900, MSE: 0.295827, NMSE: 0.0026574594
#
# ===== RUN 36/60 [Noise 10.0%] =====
#   Epoch 10/100 completed, Loss: 0.065379
#   Epoch 20/100 completed, Loss: 0.057605
#   Epoch 30/100 completed, Loss: 0.057896
#   Epoch 40/100 completed, Loss: 0.054967
#   Epoch 50/100 completed, Loss: 0.053875
#   Epoch 60/100 completed, Loss: 0.052488
#   Epoch 70/100 completed, Loss: 0.051630
#   Epoch 80/100 completed, Loss: 0.051742
#   Epoch 90/100 completed, Loss: 0.052276
#   Epoch 100/100 completed, Loss: 0.051965
# Training complete for run 36
# Run 36 Metrics — RMSE: 0.597948, MSE: 0.357542, NMSE: 0.0035047173
#
# ===== RUN 37/60 [Noise 10.0%] =====
#   Epoch 10/100 completed, Loss: 0.069865
#   Epoch 20/100 completed, Loss: 0.065508
#   Epoch 30/100 completed, Loss: 0.060367
#   Epoch 40/100 completed, Loss: 0.059152
#   Epoch 50/100 completed, Loss: 0.058526
#   Epoch 60/100 completed, Loss: 0.058160
#   Epoch 70/100 completed, Loss: 0.057842
#   Epoch 80/100 completed, Loss: 0.057292
#   Epoch 90/100 completed, Loss: 0.054169
#   Epoch 100/100 completed, Loss: 0.052479
# Training complete for run 37
# Run 37 Metrics — RMSE: 0.546847, MSE: 0.299042, NMSE: 0.0025532466
#
# ===== RUN 38/60 [Noise 10.0%] =====
#   Epoch 10/100 completed, Loss: 0.068884
#   Epoch 20/100 completed, Loss: 0.059311
#   Epoch 30/100 completed, Loss: 0.058694
#   Epoch 40/100 completed, Loss: 0.058038
#   Epoch 50/100 completed, Loss: 0.057427
#   Epoch 60/100 completed, Loss: 0.056533
#   Epoch 70/100 completed, Loss: 0.055049
#   Epoch 80/100 completed, Loss: 0.052494
#   Epoch 90/100 completed, Loss: 0.055321
#   Epoch 100/100 completed, Loss: 0.056914
# Training complete for run 38
# Run 38 Metrics — RMSE: 0.558950, MSE: 0.312426, NMSE: 0.0025656643
#
# ===== RUN 39/60 [Noise 10.0%] =====
#   Epoch 10/100 completed, Loss: 0.071069
#   Epoch 20/100 completed, Loss: 0.071311
#   Epoch 30/100 completed, Loss: 0.069757
#   Epoch 40/100 completed, Loss: 0.065569
#   Epoch 50/100 completed, Loss: 0.059108
#   Epoch 60/100 completed, Loss: 0.054831
#   Epoch 70/100 completed, Loss: 0.053716
#   Epoch 80/100 completed, Loss: 0.052137
#   Epoch 90/100 completed, Loss: 0.051225
#   Epoch 100/100 completed, Loss: 0.051554
# Training complete for run 39
# Run 39 Metrics — RMSE: 0.552918, MSE: 0.305718, NMSE: 0.0028003026
#
# ===== RUN 40/60 [Noise 10.0%] =====
#   Epoch 10/100 completed, Loss: 0.062042
#   Epoch 20/100 completed, Loss: 0.057121
#   Epoch 30/100 completed, Loss: 0.054366
#   Epoch 40/100 completed, Loss: 0.052481
#   Epoch 50/100 completed, Loss: 0.052319
#   Epoch 60/100 completed, Loss: 0.052250
#   Epoch 70/100 completed, Loss: 0.053937
#   Epoch 80/100 completed, Loss: 0.054228
#   Epoch 90/100 completed, Loss: 0.055854
#   Epoch 100/100 completed, Loss: 0.054910
# Training complete for run 40
# Run 40 Metrics — RMSE: 0.566361, MSE: 0.320764, NMSE: 0.0028089804
#
# ===== RUN 41/60 [Noise 10.0%] =====
#   Epoch 10/100 completed, Loss: 0.088213
#   Epoch 20/100 completed, Loss: 0.087690
#   Epoch 30/100 completed, Loss: 0.087229
#   Epoch 40/100 completed, Loss: 0.086829
#   Epoch 50/100 completed, Loss: 0.086598
#   Epoch 60/100 completed, Loss: 0.086546
#   Epoch 70/100 completed, Loss: 0.087591
#   Epoch 80/100 completed, Loss: 0.086595
#   Epoch 90/100 completed, Loss: 0.086608
#   Epoch 100/100 completed, Loss: 0.086434
# Training complete for run 41
# Run 41 Metrics — RMSE: 0.643591, MSE: 0.414209, NMSE: 0.0033111118
#
# ===== RUN 42/60 [Noise 10.0%] =====
#   Epoch 10/100 completed, Loss: 0.059534
#   Epoch 20/100 completed, Loss: 0.053503
#   Epoch 30/100 completed, Loss: 0.051121
#   Epoch 40/100 completed, Loss: 0.050752
#   Epoch 50/100 completed, Loss: 0.050884
#   Epoch 60/100 completed, Loss: 0.051114
#   Epoch 70/100 completed, Loss: 0.051396
#   Epoch 80/100 completed, Loss: 0.051677
#   Epoch 90/100 completed, Loss: 0.051802
#   Epoch 100/100 completed, Loss: 0.051848
# Training complete for run 42
# Run 42 Metrics — RMSE: 0.626847, MSE: 0.392937, NMSE: 0.0035399251
#
# ===== RUN 43/60 [Noise 10.0%] =====
#   Epoch 10/100 completed, Loss: 0.068179
#   Epoch 20/100 completed, Loss: 0.065268
#   Epoch 30/100 completed, Loss: 0.060017
#   Epoch 40/100 completed, Loss: 0.051214
#   Epoch 50/100 completed, Loss: 0.049756
#   Epoch 60/100 completed, Loss: 0.048633
#   Epoch 70/100 completed, Loss: 0.047336
#   Epoch 80/100 completed, Loss: 0.046642
#   Epoch 90/100 completed, Loss: 0.046192
#   Epoch 100/100 completed, Loss: 0.046126
# Training complete for run 43
# Run 43 Metrics — RMSE: 0.523718, MSE: 0.274281, NMSE: 0.0024422188
#
# ===== RUN 44/60 [Noise 10.0%] =====
#   Epoch 10/100 completed, Loss: 0.064658
#   Epoch 20/100 completed, Loss: 0.055980
#   Epoch 30/100 completed, Loss: 0.053648
#   Epoch 40/100 completed, Loss: 0.053028
#   Epoch 50/100 completed, Loss: 0.052309
#   Epoch 60/100 completed, Loss: 0.050998
#   Epoch 70/100 completed, Loss: 0.049631
#   Epoch 80/100 completed, Loss: 0.048949
#   Epoch 90/100 completed, Loss: 0.048767
#   Epoch 100/100 completed, Loss: 0.048610
# Training complete for run 44
# Run 44 Metrics — RMSE: 0.528854, MSE: 0.279687, NMSE: 0.0024687796
#
# ===== RUN 45/60 [Noise 10.0%] =====
#   Epoch 10/100 completed, Loss: 0.071146
#   Epoch 20/100 completed, Loss: 0.064626
#   Epoch 30/100 completed, Loss: 0.076996
#   Epoch 40/100 completed, Loss: 0.069693
#   Epoch 50/100 completed, Loss: 0.068997
#   Epoch 60/100 completed, Loss: 0.069668
#   Epoch 70/100 completed, Loss: 0.068684
#   Epoch 80/100 completed, Loss: 0.067030
#   Epoch 90/100 completed, Loss: 0.065449
#   Epoch 100/100 completed, Loss: 0.063927
# Training complete for run 45
# Run 45 Metrics — RMSE: 0.588808, MSE: 0.346695, NMSE: 0.0027001429
#
# ===== RUN 46/60 [Noise 10.0%] =====
#   Epoch 10/100 completed, Loss: 0.058383
#   Epoch 20/100 completed, Loss: 0.055999
#   Epoch 30/100 completed, Loss: 0.053862
#   Epoch 40/100 completed, Loss: 0.051801
#   Epoch 50/100 completed, Loss: 0.051033
#   Epoch 60/100 completed, Loss: 0.050736
#   Epoch 70/100 completed, Loss: 0.050440
#   Epoch 80/100 completed, Loss: 0.050010
#   Epoch 90/100 completed, Loss: 0.049432
#   Epoch 100/100 completed, Loss: 0.049116
# Training complete for run 46
# Run 46 Metrics — RMSE: 0.561774, MSE: 0.315591, NMSE: 0.0030375996
#
# ===== RUN 47/60 [Noise 10.0%] =====
#   Epoch 10/100 completed, Loss: 0.063605
#   Epoch 20/100 completed, Loss: 0.067904
#   Epoch 30/100 completed, Loss: 0.064285
#   Epoch 40/100 completed, Loss: 0.063218
#   Epoch 50/100 completed, Loss: 0.061508
#   Epoch 60/100 completed, Loss: 0.059212
#   Epoch 70/100 completed, Loss: 0.050093
#   Epoch 80/100 completed, Loss: 0.050885
#   Epoch 90/100 completed, Loss: 0.052796
#   Epoch 100/100 completed, Loss: 0.051449
# Training complete for run 47
# Run 47 Metrics — RMSE: 0.542591, MSE: 0.294405, NMSE: 0.0025414888
#
# ===== RUN 48/60 [Noise 10.0%] =====
#   Epoch 10/100 completed, Loss: 0.061283
#   Epoch 20/100 completed, Loss: 0.060979
#   Epoch 30/100 completed, Loss: 0.058430
#   Epoch 40/100 completed, Loss: 0.055225
#   Epoch 50/100 completed, Loss: 0.052511
#   Epoch 60/100 completed, Loss: 0.051323
#   Epoch 70/100 completed, Loss: 0.051802
#   Epoch 80/100 completed, Loss: 0.056401
#   Epoch 90/100 completed, Loss: 0.066159
#   Epoch 100/100 completed, Loss: 0.050917
# Training complete for run 48
# Run 48 Metrics — RMSE: 0.565038, MSE: 0.319268, NMSE: 0.0029120221
#
# ===== RUN 49/60 [Noise 10.0%] =====
#   Epoch 10/100 completed, Loss: 0.065655
#   Epoch 20/100 completed, Loss: 0.067574
#   Epoch 30/100 completed, Loss: 0.062499
#   Epoch 40/100 completed, Loss: 0.056651
#   Epoch 50/100 completed, Loss: 0.056111
#   Epoch 60/100 completed, Loss: 0.055643
#   Epoch 70/100 completed, Loss: 0.050761
#   Epoch 80/100 completed, Loss: 0.050297
#   Epoch 90/100 completed, Loss: 0.052026
#   Epoch 100/100 completed, Loss: 0.050813
# Training complete for run 49
# Run 49 Metrics — RMSE: 0.544841, MSE: 0.296852, NMSE: 0.0027140148
#
# ===== RUN 50/60 [Noise 10.0%] =====
#   Epoch 10/100 completed, Loss: 0.067301
#   Epoch 20/100 completed, Loss: 0.062241
#   Epoch 30/100 completed, Loss: 0.062149
#   Epoch 40/100 completed, Loss: 0.061575
#   Epoch 50/100 completed, Loss: 0.062114
#   Epoch 60/100 completed, Loss: 0.067126
#   Epoch 70/100 completed, Loss: 0.060496
#   Epoch 80/100 completed, Loss: 0.053769
#   Epoch 90/100 completed, Loss: 0.054675
#   Epoch 100/100 completed, Loss: 0.052439
# Training complete for run 50
# Run 50 Metrics — RMSE: 0.562263, MSE: 0.316140, NMSE: 0.0029969173
#
# ===== RUN 51/60 [Noise 10.0%] =====
#   Epoch 10/100 completed, Loss: 0.072999
#   Epoch 20/100 completed, Loss: 0.072317
#   Epoch 30/100 completed, Loss: 0.070167
#   Epoch 40/100 completed, Loss: 0.067354
#   Epoch 50/100 completed, Loss: 0.063688
#   Epoch 60/100 completed, Loss: 0.060035
#   Epoch 70/100 completed, Loss: 0.056003
#   Epoch 80/100 completed, Loss: 0.052993
#   Epoch 90/100 completed, Loss: 0.051414
#   Epoch 100/100 completed, Loss: 0.050500
# Training complete for run 51
# Run 51 Metrics — RMSE: 0.525825, MSE: 0.276491, NMSE: 0.0023903424
#
# ===== RUN 52/60 [Noise 10.0%] =====
#   Epoch 10/100 completed, Loss: 0.069525
#   Epoch 20/100 completed, Loss: 0.059201
#   Epoch 30/100 completed, Loss: 0.055904
#   Epoch 40/100 completed, Loss: 0.053645
#   Epoch 50/100 completed, Loss: 0.052915
#   Epoch 60/100 completed, Loss: 0.053000
#   Epoch 70/100 completed, Loss: 0.053471
#   Epoch 80/100 completed, Loss: 0.054334
#   Epoch 90/100 completed, Loss: 0.055874
#   Epoch 100/100 completed, Loss: 0.056535
# Training complete for run 52
# Run 52 Metrics — RMSE: 0.545824, MSE: 0.297923, NMSE: 0.0027189696
#
# ===== RUN 53/60 [Noise 10.0%] =====
#   Epoch 10/100 completed, Loss: 0.059909
#   Epoch 20/100 completed, Loss: 0.054509
#   Epoch 30/100 completed, Loss: 0.053997
#   Epoch 40/100 completed, Loss: 0.055136
#   Epoch 50/100 completed, Loss: 0.054481
#   Epoch 60/100 completed, Loss: 0.053476
#   Epoch 70/100 completed, Loss: 0.051660
#   Epoch 80/100 completed, Loss: 0.051057
#   Epoch 90/100 completed, Loss: 0.051742
#   Epoch 100/100 completed, Loss: 0.051527
# Training complete for run 53
# Run 53 Metrics — RMSE: 0.606091, MSE: 0.367346, NMSE: 0.0034577133
#
# ===== RUN 54/60 [Noise 10.0%] =====
#   Epoch 10/100 completed, Loss: 0.062866
#   Epoch 20/100 completed, Loss: 0.054098
#   Epoch 30/100 completed, Loss: 0.053575
#   Epoch 40/100 completed, Loss: 0.053635
#   Epoch 50/100 completed, Loss: 0.053807
#   Epoch 60/100 completed, Loss: 0.053539
#   Epoch 70/100 completed, Loss: 0.053363
#   Epoch 80/100 completed, Loss: 0.055131
#   Epoch 90/100 completed, Loss: 0.051818
#   Epoch 100/100 completed, Loss: 0.050213
# Training complete for run 54
# Run 54 Metrics — RMSE: 0.523977, MSE: 0.274552, NMSE: 0.0025022770
#
# ===== RUN 55/60 [Noise 10.0%] =====
#   Epoch 10/100 completed, Loss: 0.057442
#   Epoch 20/100 completed, Loss: 0.053208
#   Epoch 30/100 completed, Loss: 0.052629
#   Epoch 40/100 completed, Loss: 0.052664
#   Epoch 50/100 completed, Loss: 0.050283
#   Epoch 60/100 completed, Loss: 0.049372
#   Epoch 70/100 completed, Loss: 0.049374
#   Epoch 80/100 completed, Loss: 0.050169
#   Epoch 90/100 completed, Loss: 0.089374
#   Epoch 100/100 completed, Loss: 0.051860
# Training complete for run 55
# Run 55 Metrics — RMSE: 0.680360, MSE: 0.462890, NMSE: 0.0037387437
#
# ===== RUN 56/60 [Noise 10.0%] =====
#   Epoch 10/100 completed, Loss: 0.063846
#   Epoch 20/100 completed, Loss: 0.063061
#   Epoch 30/100 completed, Loss: 0.060716
#   Epoch 40/100 completed, Loss: 0.057564
#   Epoch 50/100 completed, Loss: 0.056668
#   Epoch 60/100 completed, Loss: 0.055844
#   Epoch 70/100 completed, Loss: 0.055179
#   Epoch 80/100 completed, Loss: 0.055589
#   Epoch 90/100 completed, Loss: 0.056106
#   Epoch 100/100 completed, Loss: 0.055613
# Training complete for run 56
# Run 56 Metrics — RMSE: 0.606919, MSE: 0.368351, NMSE: 0.0030424620
#
# ===== RUN 57/60 [Noise 10.0%] =====
#   Epoch 10/100 completed, Loss: 0.066271
#   Epoch 20/100 completed, Loss: 0.069176
#   Epoch 30/100 completed, Loss: 0.069781
#   Epoch 40/100 completed, Loss: 0.068336
#   Epoch 50/100 completed, Loss: 0.065063
#   Epoch 60/100 completed, Loss: 0.061817
#   Epoch 70/100 completed, Loss: 0.060610
#   Epoch 80/100 completed, Loss: 0.057043
#   Epoch 90/100 completed, Loss: 0.052221
#   Epoch 100/100 completed, Loss: 0.051609
# Training complete for run 57
# Run 57 Metrics — RMSE: 0.530682, MSE: 0.281624, NMSE: 0.0025656690
#
# ===== RUN 58/60 [Noise 10.0%] =====
#   Epoch 10/100 completed, Loss: 0.057229
#   Epoch 20/100 completed, Loss: 0.055512
#   Epoch 30/100 completed, Loss: 0.054694
#   Epoch 40/100 completed, Loss: 0.054832
#   Epoch 50/100 completed, Loss: 0.054326
#   Epoch 60/100 completed, Loss: 0.052316
#   Epoch 70/100 completed, Loss: 0.050364
#   Epoch 80/100 completed, Loss: 0.049839
#   Epoch 90/100 completed, Loss: 0.049827
#   Epoch 100/100 completed, Loss: 0.050672
# Training complete for run 58
# Run 58 Metrics — RMSE: 0.528814, MSE: 0.279644, NMSE: 0.0023977516
#
# ===== RUN 59/60 [Noise 10.0%] =====
#   Epoch 10/100 completed, Loss: 0.059795
#   Epoch 20/100 completed, Loss: 0.053135
#   Epoch 30/100 completed, Loss: 0.054359
#   Epoch 40/100 completed, Loss: 0.053920
#   Epoch 50/100 completed, Loss: 0.055876
#   Epoch 60/100 completed, Loss: 0.051650
#   Epoch 70/100 completed, Loss: 0.050690
#   Epoch 80/100 completed, Loss: 0.050058
#   Epoch 90/100 completed, Loss: 0.049611
#   Epoch 100/100 completed, Loss: 0.049275
# Training complete for run 59
# Run 59 Metrics — RMSE: 0.578718, MSE: 0.334914, NMSE: 0.0031931895
#
# ===== RUN 60/60 [Noise 10.0%] =====
#   Epoch 10/100 completed, Loss: 0.060918
#   Epoch 20/100 completed, Loss: 0.056568
#   Epoch 30/100 completed, Loss: 0.054016
#   Epoch 40/100 completed, Loss: 0.051638
#   Epoch 50/100 completed, Loss: 0.050108
#   Epoch 60/100 completed, Loss: 0.049195
#   Epoch 70/100 completed, Loss: 0.048623
#   Epoch 80/100 completed, Loss: 0.048247
#   Epoch 90/100 completed, Loss: 0.047899
#   Epoch 100/100 completed, Loss: 0.047431
# Training complete for run 60
# Run 60 Metrics — RMSE: 0.539868, MSE: 0.291458, NMSE: 0.0025236991
#
# Best run for 10.0% noise: Run 43 (RMSE: 0.523718)

# %% [markdown]
# ## Results

# %%
# ============================================================
# Final Metrics Summary & Plots per Noise Level
# ============================================================
from tabulate import tabulate

for lam, best_rmse, best_mse, best_nmse, best_predictions, best_losses, raw_values_for_plot in _molab_results:
    print("\n" + "="*80)
    print(f"RESULTS FOR NOISE LEVEL: {lam*100:.1f}%")
    print("="*80)
    
    print('=== Best Run Metrics ===')
    print(f'RMSE: {best_rmse:.6f}')
    print(f'MSE:  {best_mse:.6f}')
    print(f'NMSE: {best_nmse:.10f}')
    
    actual = raw_values_for_plot[-60:]
    
    plt.figure(figsize=(12, 5))
    plt.plot(actual, label='Actual', color='blue', linewidth=1.5)
    plt.plot(best_predictions, label='Predicted (Best Run)', color='red',
             linewidth=1.5, linestyle='--')
    plt.title(f'Predictions vs Actual (Noise {lam*100:.1f}%)')
    plt.xlabel('Time Step')
    plt.ylabel('Value')
    plt.legend()
    plt.grid(True, alpha=0.3)
    plt.tight_layout()
    plt.show()

    plt.figure(figsize=(12, 4))
    plt.plot(best_losses, color='green', linewidth=1.0)
    plt.title(f'Training Loss (Best Run, Noise {lam*100:.1f}%)')
    plt.xlabel('Epoch')
    plt.ylabel('MSE Loss')
    plt.grid(True, alpha=0.3)
    plt.tight_layout()
    plt.show()

# Global summary table
print("\n" + "="*80)
print("FINAL RESULTS TABLE ACROSS ALL NOISE LEVELS")
print("="*80)
df_res = pd.DataFrame([r[:4] for r in _molab_results], columns=['Noise Level (lambda)', 'RMSE', 'MSE', 'NMSE'])
print(tabulate(df_res, headers='keys', tablefmt='github', showindex=False))
# Out:
# ================================================================================
# RESULTS FOR NOISE LEVEL: 0.0%
# ================================================================================
# === Best Run Metrics ===
# RMSE: 0.397729
# MSE:  0.158188
# NMSE: 0.0014623938
# ================================================================================
# RESULTS FOR NOISE LEVEL: 0.5%
# ================================================================================
# === Best Run Metrics ===
# RMSE: 0.392989
# MSE:  0.154440
# NMSE: 0.0013553779
# ================================================================================
# RESULTS FOR NOISE LEVEL: 5.0%
# ================================================================================
# === Best Run Metrics ===
# RMSE: 0.434104
# MSE:  0.188446
# NMSE: 0.0016026716
# ================================================================================
# RESULTS FOR NOISE LEVEL: 10.0%
# ================================================================================
# === Best Run Metrics ===
# RMSE: 0.523718
# MSE:  0.274281
# NMSE: 0.0024422188
# ================================================================================
# FINAL RESULTS TABLE ACROSS ALL NOISE LEVELS
# ================================================================================
# |   Noise Level (lambda) |     RMSE |      MSE |       NMSE |
# |------------------------|----------|----------|------------|
# |                  0     | 0.397729 | 0.158188 | 0.00146239 |
# |                  0.005 | 0.392989 | 0.15444  | 0.00135538 |
# |                  0.05  | 0.434104 | 0.188446 | 0.00160267 |
# |                  0.1   | 0.523718 | 0.274281 | 0.00244222 |

# %% [markdown]
# ## Observations
#
# ### Gaussian Noise robustness on Monthly Lake Erie Levels
#
# **Run the notebook to populate results.**
